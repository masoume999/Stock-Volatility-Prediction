# %%
import pandas as pd
import numpy as np
import builtins
import yfinance as yf
from google.colab import drive
from datetime import datetime
import matplotlib.pyplot as plt
from functools import reduce

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Functions

# %%
def select_strategy():
    path = '/content/drive/MyDrive/Strategy/MA/HV/HV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_HV = pd.DataFrame()
    y2_2024_HV = pd.DataFrame()
    F_2024_2y1_HV = pd.DataFrame()

    y1_2024_HV = file.loc[file['Year'] == '2024_y1']
    y2_2024_HV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_HV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_HV = y1_2024_HV.loc[(y1_2024_HV['HV_sharpe > 0'] == True) & (y1_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y1_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_HV = y2_2024_HV.loc[(y2_2024_HV['HV_sharpe > 0'] == True) & (y2_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y2_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_HV = F_2024_2y1_HV.loc[(F_2024_2y1_HV['HV_sharpe > 0'] == True) & (F_2024_2y1_HV['HV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_HV['HV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_HV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_HV = pd.merge(Filtered_y1_2024_HV, Filtered_y2_2024_HV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/PV/PV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_PV = pd.DataFrame()
    y2_2024_PV = pd.DataFrame()
    F_2024_2y1_PV = pd.DataFrame()

    y1_2024_PV = file.loc[file['Year'] == '2024_y1']
    y2_2024_PV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_PV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_PV = y1_2024_PV.loc[(y1_2024_PV['PV_sharpe > 0'] == True) & (y1_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y1_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_PV = y2_2024_PV.loc[(y2_2024_PV['PV_sharpe > 0'] == True) & (y2_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y2_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_PV = F_2024_2y1_PV.loc[(F_2024_2y1_PV['PV_sharpe > 0'] == True) & (F_2024_2y1_PV['PV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_PV['PV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_PV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_PV = pd.merge(Filtered_y1_2024_PV, Filtered_y2_2024_PV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/CCV/CCV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_CCV = pd.DataFrame()
    y2_2024_CCV = pd.DataFrame()
    F_2024_2y1_CCV = pd.DataFrame()

    y1_2024_CCV = file.loc[file['Year'] == '2024_y1']
    y2_2024_CCV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_CCV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_CCV = y1_2024_CCV.loc[(y1_2024_CCV['CCV_sharpe > 0'] == True) & (y1_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y1_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_CCV = y2_2024_CCV.loc[(y2_2024_CCV['CCV_sharpe > 0'] == True) & (y2_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y2_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_CCV = F_2024_2y1_CCV.loc[(F_2024_2y1_CCV['CCV_sharpe > 0'] == True) & (F_2024_2y1_CCV['CCV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_CCV = pd.merge(Filtered_y1_2024_CCV, Filtered_y2_2024_CCV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKV/GKV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_GKV = pd.DataFrame()
    y2_2024_GKV = pd.DataFrame()
    F_2024_2y1_GKV = pd.DataFrame()

    y1_2024_GKV = file.loc[file['Year'] == '2024_y1']
    y2_2024_GKV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_GKV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_GKV = y1_2024_GKV.loc[(y1_2024_GKV['GKV_sharpe > 0'] == True) & (y1_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_GKV = y2_2024_GKV.loc[(y2_2024_GKV['GKV_sharpe > 0'] == True) & (y2_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_GKV = F_2024_2y1_GKV.loc[(F_2024_2y1_GKV['GKV_sharpe > 0'] == True) & (F_2024_2y1_GKV['GKV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_GKV = pd.merge(Filtered_y1_2024_GKV, Filtered_y2_2024_GKV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/YZV/YZV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_YZV = pd.DataFrame()
    y2_2024_YZV = pd.DataFrame()
    F_2024_2y1_YZV = pd.DataFrame()

    y1_2024_YZV = file.loc[file['Year'] == '2024_y1']
    y2_2024_YZV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_YZV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_YZV = y1_2024_YZV.loc[(y1_2024_YZV['YZV_sharpe > 0'] == True) & (y1_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y1_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_YZV = y2_2024_YZV.loc[(y2_2024_YZV['YZV_sharpe > 0'] == True) & (y2_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y2_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_YZV = F_2024_2y1_YZV.loc[(F_2024_2y1_YZV['YZV_sharpe > 0'] == True) & (F_2024_2y1_YZV['YZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_YZV = pd.merge(Filtered_y1_2024_YZV, Filtered_y2_2024_YZV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKYZV/GKYZV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_GKYZV = pd.DataFrame()
    y2_2024_GKYZV = pd.DataFrame()
    F_2024_2y1_GKYZV = pd.DataFrame()

    y1_2024_GKYZV = file.loc[file['Year'] == '2024_y1']
    y2_2024_GKYZV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_GKYZV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_GKYZV = y1_2024_GKYZV.loc[(y1_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y1_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_GKYZV = y2_2024_GKYZV.loc[(y2_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y2_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_GKYZV = F_2024_2y1_GKYZV.loc[(F_2024_2y1_GKYZV['GKYZV_sharpe > 0'] == True) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_GKYZV = pd.merge(Filtered_y1_2024_GKYZV, Filtered_y2_2024_GKYZV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/RSV/RSV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_RSV = pd.DataFrame()
    y2_2024_RSV = pd.DataFrame()
    F_2024_2y1_RSV = pd.DataFrame()

    y1_2024_RSV = file.loc[file['Year'] == '2024_y1']
    y2_2024_RSV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_RSV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_RSV = y1_2024_RSV.loc[(y1_2024_RSV['RSV_sharpe > 0'] == True) & (y1_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y1_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_RSV = y2_2024_RSV.loc[(y2_2024_RSV['RSV_sharpe > 0'] == True) & (y2_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y2_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_RSV = F_2024_2y1_RSV.loc[(F_2024_2y1_RSV['RSV_sharpe > 0'] == True) & (F_2024_2y1_RSV['RSV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_RSV = pd.merge(Filtered_y1_2024_RSV, Filtered_y2_2024_RSV, on=['Strategy'])

    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [common_rows_HV['Strategy'], common_rows_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_1['Strategy'], common_rows_CCV['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_2['Strategy'], common_rows_GKV['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_3['Strategy'], common_rows_YZV['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_4['Strategy'], common_rows_GKYZV['Strategy']])
    Filtered_y1_y2_2024 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_5['Strategy'], common_rows_RSV['Strategy']])


    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_HV['Strategy'], Filtered_2024_2y1_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_CCV['Strategy'], common_rows_2y_1['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKV['Strategy'], common_rows_2y_2['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_YZV['Strategy'], common_rows_2y_3['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKYZV['Strategy'], common_rows_2y_4['Strategy']])
    Filtered_2y_2024 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_RSV['Strategy'], common_rows_2y_5['Strategy']])


    return Filtered_y1_y2_2024, Filtered_2y_2024, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV, common_rows_HV, common_rows_PV, common_rows_CCV, common_rows_GKV, common_rows_YZV, common_rows_GKYZV, common_rows_RSV

# %%
def select_strategy_dw():
    path = '/content/drive/MyDrive/Strategy/MA/HV/DW_HV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_HV = pd.DataFrame()
    y2_2024_HV = pd.DataFrame()
    F_2024_2y1_HV = pd.DataFrame()

    y1_2024_HV = file.loc[file['Year'] == '2024_y1']
    y2_2024_HV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_HV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_HV = y1_2024_HV.loc[(y1_2024_HV['HV_sharpe > 0'] == True) & (y1_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y1_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_HV = y2_2024_HV.loc[(y2_2024_HV['HV_sharpe > 0'] == True) & (y2_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y2_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_HV = F_2024_2y1_HV.loc[(F_2024_2y1_HV['HV_sharpe > 0'] == True) & (F_2024_2y1_HV['HV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_HV['HV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_HV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_HV = pd.merge(Filtered_y1_2024_HV, Filtered_y2_2024_HV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/PV/DW_PV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_PV = pd.DataFrame()
    y2_2024_PV = pd.DataFrame()
    F_2024_2y1_PV = pd.DataFrame()

    y1_2024_PV = file.loc[file['Year'] == '2024_y1']
    y2_2024_PV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_PV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_PV = y1_2024_PV.loc[(y1_2024_PV['PV_sharpe > 0'] == True) & (y1_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y1_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_PV = y2_2024_PV.loc[(y2_2024_PV['PV_sharpe > 0'] == True) & (y2_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y2_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_PV = F_2024_2y1_PV.loc[(F_2024_2y1_PV['PV_sharpe > 0'] == True) & (F_2024_2y1_PV['PV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_PV['PV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_PV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_PV = pd.merge(Filtered_y1_2024_PV, Filtered_y2_2024_PV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/CCV/DW_CCV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_CCV = pd.DataFrame()
    y2_2024_CCV = pd.DataFrame()
    F_2024_2y1_CCV = pd.DataFrame()

    y1_2024_CCV = file.loc[file['Year'] == '2024_y1']
    y2_2024_CCV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_CCV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_CCV = y1_2024_CCV.loc[(y1_2024_CCV['CCV_sharpe > 0'] == True) & (y1_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y1_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_CCV = y2_2024_CCV.loc[(y2_2024_CCV['CCV_sharpe > 0'] == True) & (y2_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y2_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_CCV = F_2024_2y1_CCV.loc[(F_2024_2y1_CCV['CCV_sharpe > 0'] == True) & (F_2024_2y1_CCV['CCV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_CCV = pd.merge(Filtered_y1_2024_CCV, Filtered_y2_2024_CCV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKV/DW_GKV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_GKV = pd.DataFrame()
    y2_2024_GKV = pd.DataFrame()
    F_2024_2y1_GKV = pd.DataFrame()

    y1_2024_GKV = file.loc[file['Year'] == '2024_y1']
    y2_2024_GKV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_GKV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_GKV = y1_2024_GKV.loc[(y1_2024_GKV['GKV_sharpe > 0'] == True) & (y1_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_GKV = y2_2024_GKV.loc[(y2_2024_GKV['GKV_sharpe > 0'] == True) & (y2_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_GKV = F_2024_2y1_GKV.loc[(F_2024_2y1_GKV['GKV_sharpe > 0'] == True) & (F_2024_2y1_GKV['GKV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_GKV = pd.merge(Filtered_y1_2024_GKV, Filtered_y2_2024_GKV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/YZV/DW_YZV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_YZV = pd.DataFrame()
    y2_2024_YZV = pd.DataFrame()
    F_2024_2y1_YZV = pd.DataFrame()

    y1_2024_YZV = file.loc[file['Year'] == '2024_y1']
    y2_2024_YZV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_YZV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_YZV = y1_2024_YZV.loc[(y1_2024_YZV['YZV_sharpe > 0'] == True) & (y1_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y1_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_YZV = y2_2024_YZV.loc[(y2_2024_YZV['YZV_sharpe > 0'] == True) & (y2_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y2_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_YZV = F_2024_2y1_YZV.loc[(F_2024_2y1_YZV['YZV_sharpe > 0'] == True) & (F_2024_2y1_YZV['YZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_YZV = pd.merge(Filtered_y1_2024_YZV, Filtered_y2_2024_YZV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKYZV/DW_GKYZV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_GKYZV = pd.DataFrame()
    y2_2024_GKYZV = pd.DataFrame()
    F_2024_2y1_GKYZV = pd.DataFrame()

    y1_2024_GKYZV = file.loc[file['Year'] == '2024_y1']
    y2_2024_GKYZV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_GKYZV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_GKYZV = y1_2024_GKYZV.loc[(y1_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y1_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_GKYZV = y2_2024_GKYZV.loc[(y2_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y2_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_GKYZV = F_2024_2y1_GKYZV.loc[(F_2024_2y1_GKYZV['GKYZV_sharpe > 0'] == True) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_GKYZV = pd.merge(Filtered_y1_2024_GKYZV, Filtered_y2_2024_GKYZV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/RSV/DW_RSV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_RSV = pd.DataFrame()
    y2_2024_RSV = pd.DataFrame()
    F_2024_2y1_RSV = pd.DataFrame()

    y1_2024_RSV = file.loc[file['Year'] == '2024_y1']
    y2_2024_RSV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_RSV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_RSV = y1_2024_RSV.loc[(y1_2024_RSV['RSV_sharpe > 0'] == True) & (y1_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y1_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_RSV = y2_2024_RSV.loc[(y2_2024_RSV['RSV_sharpe > 0'] == True) & (y2_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y2_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_RSV = F_2024_2y1_RSV.loc[(F_2024_2y1_RSV['RSV_sharpe > 0'] == True) & (F_2024_2y1_RSV['RSV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_RSV = pd.merge(Filtered_y1_2024_RSV, Filtered_y2_2024_RSV, on=['Strategy'])

    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [common_rows_HV['Strategy'], common_rows_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_1['Strategy'], common_rows_CCV['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_2['Strategy'], common_rows_GKV['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_3['Strategy'], common_rows_YZV['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_4['Strategy'], common_rows_GKYZV['Strategy']])
    Filtered_y1_y2_2024 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_5['Strategy'], common_rows_RSV['Strategy']])


    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_HV['Strategy'], Filtered_2024_2y1_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_CCV['Strategy'], common_rows_2y_1['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKV['Strategy'], common_rows_2y_2['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_YZV['Strategy'], common_rows_2y_3['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKYZV['Strategy'], common_rows_2y_4['Strategy']])
    Filtered_2y_2024 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_RSV['Strategy'], common_rows_2y_5['Strategy']])


    return Filtered_y1_y2_2024, Filtered_2y_2024, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV, common_rows_HV, common_rows_PV, common_rows_CCV, common_rows_GKV, common_rows_YZV, common_rows_GKYZV, common_rows_RSV

# %%
def select_strategy_cw():
    path = '/content/drive/MyDrive/Strategy/MA/HV/CW_HV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_HV = pd.DataFrame()
    y2_2024_HV = pd.DataFrame()
    F_2024_2y1_HV = pd.DataFrame()

    y1_2024_HV = file.loc[file['Year'] == '2024_y1']
    y2_2024_HV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_HV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_HV = y1_2024_HV.loc[(y1_2024_HV['HV_sharpe > 0'] == True) & (y1_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y1_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_HV = y2_2024_HV.loc[(y2_2024_HV['HV_sharpe > 0'] == True) & (y2_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y2_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_HV = F_2024_2y1_HV.loc[(F_2024_2y1_HV['HV_sharpe > 0'] == True) & (F_2024_2y1_HV['HV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_HV['HV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_HV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_HV = pd.merge(Filtered_y1_2024_HV, Filtered_y2_2024_HV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/PV/CW_PV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_PV = pd.DataFrame()
    y2_2024_PV = pd.DataFrame()
    F_2024_2y1_PV = pd.DataFrame()

    y1_2024_PV = file.loc[file['Year'] == '2024_y1']
    y2_2024_PV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_PV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_PV = y1_2024_PV.loc[(y1_2024_PV['PV_sharpe > 0'] == True) & (y1_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y1_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_PV = y2_2024_PV.loc[(y2_2024_PV['PV_sharpe > 0'] == True) & (y2_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y2_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_PV = F_2024_2y1_PV.loc[(F_2024_2y1_PV['PV_sharpe > 0'] == True) & (F_2024_2y1_PV['PV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_PV['PV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_PV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_PV = pd.merge(Filtered_y1_2024_PV, Filtered_y2_2024_PV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/CCV/CW_CCV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_CCV = pd.DataFrame()
    y2_2024_CCV = pd.DataFrame()
    F_2024_2y1_CCV = pd.DataFrame()

    y1_2024_CCV = file.loc[file['Year'] == '2024_y1']
    y2_2024_CCV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_CCV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_CCV = y1_2024_CCV.loc[(y1_2024_CCV['CCV_sharpe > 0'] == True) & (y1_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y1_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_CCV = y2_2024_CCV.loc[(y2_2024_CCV['CCV_sharpe > 0'] == True) & (y2_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y2_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_CCV = F_2024_2y1_CCV.loc[(F_2024_2y1_CCV['CCV_sharpe > 0'] == True) & (F_2024_2y1_CCV['CCV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_CCV = pd.merge(Filtered_y1_2024_CCV, Filtered_y2_2024_CCV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKV/CW_GKV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_GKV = pd.DataFrame()
    y2_2024_GKV = pd.DataFrame()
    F_2024_2y1_GKV = pd.DataFrame()

    y1_2024_GKV = file.loc[file['Year'] == '2024_y1']
    y2_2024_GKV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_GKV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_GKV = y1_2024_GKV.loc[(y1_2024_GKV['GKV_sharpe > 0'] == True) & (y1_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_GKV = y2_2024_GKV.loc[(y2_2024_GKV['GKV_sharpe > 0'] == True) & (y2_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_GKV = F_2024_2y1_GKV.loc[(F_2024_2y1_GKV['GKV_sharpe > 0'] == True) & (F_2024_2y1_GKV['GKV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_GKV = pd.merge(Filtered_y1_2024_GKV, Filtered_y2_2024_GKV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/YZV/CW_YZV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_YZV = pd.DataFrame()
    y2_2024_YZV = pd.DataFrame()
    F_2024_2y1_YZV = pd.DataFrame()

    y1_2024_YZV = file.loc[file['Year'] == '2024_y1']
    y2_2024_YZV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_YZV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_YZV = y1_2024_YZV.loc[(y1_2024_YZV['YZV_sharpe > 0'] == True) & (y1_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y1_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_YZV = y2_2024_YZV.loc[(y2_2024_YZV['YZV_sharpe > 0'] == True) & (y2_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y2_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_YZV = F_2024_2y1_YZV.loc[(F_2024_2y1_YZV['YZV_sharpe > 0'] == True) & (F_2024_2y1_YZV['YZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_YZV = pd.merge(Filtered_y1_2024_YZV, Filtered_y2_2024_YZV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKYZV/CW_GKYZV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_GKYZV = pd.DataFrame()
    y2_2024_GKYZV = pd.DataFrame()
    F_2024_2y1_GKYZV = pd.DataFrame()

    y1_2024_GKYZV = file.loc[file['Year'] == '2024_y1']
    y2_2024_GKYZV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_GKYZV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_GKYZV = y1_2024_GKYZV.loc[(y1_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y1_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_GKYZV = y2_2024_GKYZV.loc[(y2_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y2_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_GKYZV = F_2024_2y1_GKYZV.loc[(F_2024_2y1_GKYZV['GKYZV_sharpe > 0'] == True) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_GKYZV = pd.merge(Filtered_y1_2024_GKYZV, Filtered_y2_2024_GKYZV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/RSV/CW_RSV/'

    filename = 'file_2.csv'
    file = pd.read_csv(path + filename)

    y1_2024_RSV = pd.DataFrame()
    y2_2024_RSV = pd.DataFrame()
    F_2024_2y1_RSV = pd.DataFrame()

    y1_2024_RSV = file.loc[file['Year'] == '2024_y1']
    y2_2024_RSV = file.loc[file['Year'] == '2024_y2']
    F_2024_2y1_RSV = file.loc[file['Year'] == '2024_2y1']

    Filtered_y1_2024_RSV = y1_2024_RSV.loc[(y1_2024_RSV['RSV_sharpe > 0'] == True) & (y1_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y1_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y1_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_y2_2024_RSV = y2_2024_RSV.loc[(y2_2024_RSV['RSV_sharpe > 0'] == True) & (y2_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y2_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 50.0) & (y2_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]
    Filtered_2024_2y1_RSV = F_2024_2y1_RSV.loc[(F_2024_2y1_RSV['RSV_sharpe > 0'] == True) & (F_2024_2y1_RSV['RSV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 50.0) & (F_2024_2y1_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 50.0)]

    common_rows_RSV = pd.merge(Filtered_y1_2024_RSV, Filtered_y2_2024_RSV, on=['Strategy'])

    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [common_rows_HV['Strategy'], common_rows_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_1['Strategy'], common_rows_CCV['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_2['Strategy'], common_rows_GKV['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_3['Strategy'], common_rows_YZV['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_4['Strategy'], common_rows_GKYZV['Strategy']])
    Filtered_y1_y2_2024 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_5['Strategy'], common_rows_RSV['Strategy']])


    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_HV['Strategy'], Filtered_2024_2y1_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_CCV['Strategy'], common_rows_2y_1['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKV['Strategy'], common_rows_2y_2['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_YZV['Strategy'], common_rows_2y_3['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKYZV['Strategy'], common_rows_2y_4['Strategy']])
    Filtered_2y_2024 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_RSV['Strategy'], common_rows_2y_5['Strategy']])


    return Filtered_y1_y2_2024, Filtered_2y_2024, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV, common_rows_HV, common_rows_PV, common_rows_CCV, common_rows_GKV, common_rows_YZV, common_rows_GKYZV, common_rows_RSV

# %% [markdown]
# # Results

# %%
Filtered_y1_y2_2024, Filtered_2y_2024, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV, common_rows_HV, common_rows_PV, common_rows_CCV, common_rows_GKV, common_rows_YZV, common_rows_GKYZV, common_rows_RSV = select_strategy()

# %%
Filtered_2y_2024
# Out:
#         Strategy
# 0    Strategy_31
# 1    Strategy_31
# 2    Strategy_31
# 3    Strategy_31
# 4    Strategy_31
# ..           ...
# 139  Strategy_42
# 140  Strategy_42
# 141  Strategy_42
# 142  Strategy_42
# 143  Strategy_42
#
# [144 rows x 1 columns]

# %%
Filtered_2024_2y1_HV
# Out:
#      Unnamed: 0      Year     Strategy Abs  HV_sharpe > 0  \
# 468         468  2024_2y1  Strategy_29   -           True
# 470         470  2024_2y1  Strategy_31   -           True
# 481         481  2024_2y1  Strategy_42   -           True
# 514         514  2024_2y1  Strategy_31   +           True
# 515         515  2024_2y1  Strategy_32   +           True
# 525         525  2024_2y1  Strategy_42   +           True
# 526         526  2024_2y1  Strategy_43   +           True
#
#      HV_sharpe > Pure_sharpe  HV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 468                     True             True                  75.0
# 470                     True             True                 100.0
# 481                     True             True                 100.0
# 514                     True             True                 100.0
# 515                     True             True                 100.0
# 525                     True             True                 100.0
# ...

# %%
Filtered_2024_2y1_CCV
# Out:
#      Unnamed: 0      Year     Strategy Abs  CCV_sharpe > 0  \
# 440         440  2024_2y1   Strategy_1   -            True
# 446         446  2024_2y1   Strategy_7   -            True
# 447         447  2024_2y1   Strategy_8   -            True
# 470         470  2024_2y1  Strategy_31   -            True
# 471         471  2024_2y1  Strategy_32   -            True
# 481         481  2024_2y1  Strategy_42   -            True
# 482         482  2024_2y1  Strategy_43   -            True
# 514         514  2024_2y1  Strategy_31   +            True
# 515         515  2024_2y1  Strategy_32   +            True
# 525         525  2024_2y1  Strategy_42   +            True
# 526         526  2024_2y1  Strategy_43   +            True
#
#      CCV_sharpe > Pure_sharpe  CCV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 440                      True              True                  87.5
# 446                      True             False                  87.5
# ...

# %%
Filtered_2024_2y1_PV
# Out:
#      Unnamed: 0      Year     Strategy Abs  PV_sharpe > 0  \
# 470         470  2024_2y1  Strategy_31   -           True
# 481         481  2024_2y1  Strategy_42   -           True
# 514         514  2024_2y1  Strategy_31   +           True
# 525         525  2024_2y1  Strategy_42   +           True
#
#      PV_sharpe > Pure_sharpe  PV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 470                     True             True                 100.0
# 481                     True            False                 100.0
# 514                     True             True                 100.0
# 525                     True            False                 100.0
#
#      PV_sharpe > Pred_sharpe (%)  PV_dd > Pred_dd (%)  PV_tp > Pred_tp (%)  \
# 470                         50.0                100.0                  0.0
# 481                         62.5                 37.5                 12.5
# 514                         50.0                100.0                  0.0
# ...

# %%
Filtered_2024_2y1_GKV
# Out:
#      Unnamed: 0      Year     Strategy Abs  GKV_sharpe > 0  \
# 462         462  2024_2y1  Strategy_23   -            True
# 470         470  2024_2y1  Strategy_31   -            True
# 471         471  2024_2y1  Strategy_32   -            True
# 473         473  2024_2y1  Strategy_34   -            True
# 481         481  2024_2y1  Strategy_42   -            True
# 482         482  2024_2y1  Strategy_43   -            True
# 514         514  2024_2y1  Strategy_31   +            True
# 525         525  2024_2y1  Strategy_42   +            True
# 526         526  2024_2y1  Strategy_43   +            True
#
#      GKV_sharpe > Pure_sharpe  GKV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 462                      True             False                  87.5
# 470                      True              True                 100.0
# 471                      True             False                 100.0
# 473                      True              True                  87.5
# ...

# %%
Filtered_2024_2y1_YZV
# Out:
#      Unnamed: 0      Year     Strategy Abs  YZV_sharpe > 0  \
# 470         470  2024_2y1  Strategy_31   -            True
# 481         481  2024_2y1  Strategy_42   -            True
# 482         482  2024_2y1  Strategy_43   -            True
# 502         502  2024_2y1  Strategy_19   +            True
# 525         525  2024_2y1  Strategy_42   +            True
#
#      YZV_sharpe > Pure_sharpe  YZV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 470                      True              True                 100.0
# 481                      True              True                 100.0
# 482                      True             False                 100.0
# 502                      True              True                  75.0
# 525                      True              True                 100.0
#
#      YZV_sharpe > Pred_sharpe (%)  YZV_dd > Pred_dd (%)  YZV_tp > Pred_tp (%)  \
# 470                         100.0                  50.0                 100.0
# ...

# %%
Filtered_2024_2y1_GKYZV
# Out:
#      Unnamed: 0      Year     Strategy Abs  GKYZV_sharpe > 0  \
# 441         441  2024_2y1   Strategy_2   -              True
# 467         467  2024_2y1  Strategy_28   -              True
# 468         468  2024_2y1  Strategy_29   -              True
# 470         470  2024_2y1  Strategy_31   -              True
# 471         471  2024_2y1  Strategy_32   -              True
# 477         477  2024_2y1  Strategy_38   -              True
# 481         481  2024_2y1  Strategy_42   -              True
# 482         482  2024_2y1  Strategy_43   -              True
# 483         483  2024_2y1  Strategy_44   -              True
# 490         490  2024_2y1   Strategy_7   +              True
# 525         525  2024_2y1  Strategy_42   +              True
#
#      GKYZV_sharpe > Pure_sharpe  GKYZV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 441                        True                True                  75.0
# 467                        True                True                  75.0
# ...

# %%
Filtered_2024_2y1_RSV
# Out:
#      Unnamed: 0      Year     Strategy Abs  RSV_sharpe > 0  \
# 470         470  2024_2y1  Strategy_31   -            True
# 481         481  2024_2y1  Strategy_42   -            True
# 525         525  2024_2y1  Strategy_42   +            True
#
#      RSV_sharpe > Pure_sharpe  RSV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 470                      True              True                 100.0
# 481                      True              True                 100.0
# 525                      True              True                 100.0
#
#      RSV_sharpe > Pred_sharpe (%)  RSV_dd > Pred_dd (%)  RSV_tp > Pred_tp (%)  \
# 470                         100.0                  87.5                 100.0
# 481                         100.0                  75.0                 100.0
# 525                         100.0                  62.5                 100.0
#
#      Pred_sharpe > Pure_sharpe (%)
# 470                           50.0
# 481                           50.0
# ...

# %%
Filtered_y1_y2_2024, Filtered_2y_2024, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV, common_rows_HV, common_rows_PV, common_rows_CCV, common_rows_GKV, common_rows_YZV, common_rows_GKYZV, common_rows_RSV = select_strategy_dw()

# %%
Filtered_2y_2024
# Out:
#      Strategy
# 0  Strategy_9

# %%
Filtered_2024_2y1_HV
# Out:
#      Unnamed: 0      Year     Strategy Abs  HV_sharpe > 0  \
# 445         445  2024_2y1   Strategy_6   -           True
# 448         448  2024_2y1   Strategy_9   -           True
# 456         456  2024_2y1  Strategy_17   -           True
# 468         468  2024_2y1  Strategy_29   -           True
# 489         489  2024_2y1   Strategy_6   +           True
# 526         526  2024_2y1  Strategy_43   +           True
#
#      HV_sharpe > Pure_sharpe  HV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 445                     True             True                  87.5
# 448                     True            False                 100.0
# 456                     True             True                  87.5
# 468                     True             True                  75.0
# 489                     True             True                  87.5
# 526                     True             True                 100.0
#
#      HV_sharpe > Pred_sharpe (%)  HV_dd > Pred_dd (%)  HV_tp > Pred_tp (%)  \
# ...

# %%
Filtered_2024_2y1_PV
# Out:
#      Unnamed: 0      Year     Strategy Abs  PV_sharpe > 0  \
# 445         445  2024_2y1   Strategy_6   -           True
# 448         448  2024_2y1   Strategy_9   -           True
# 456         456  2024_2y1  Strategy_17   -           True
# 459         459  2024_2y1  Strategy_20   -           True
# 481         481  2024_2y1  Strategy_42   -           True
# 489         489  2024_2y1   Strategy_6   +           True
# 525         525  2024_2y1  Strategy_42   +           True
#
#      PV_sharpe > Pure_sharpe  PV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 445                     True             True                  75.0
# 448                     True             True                 100.0
# 456                     True            False                  75.0
# 459                     True            False                 100.0
# 481                     True             True                 100.0
# 489                     True             True                  75.0
# ...

# %%
Filtered_2024_2y1_CCV
# Out:
#      Unnamed: 0      Year     Strategy Abs  CCV_sharpe > 0  \
# 440         440  2024_2y1   Strategy_1   -            True
# 445         445  2024_2y1   Strategy_6   -            True
# 446         446  2024_2y1   Strategy_7   -            True
# 447         447  2024_2y1   Strategy_8   -            True
# 448         448  2024_2y1   Strategy_9   -            True
# 456         456  2024_2y1  Strategy_17   -            True
# 457         457  2024_2y1  Strategy_18   -            True
# 459         459  2024_2y1  Strategy_20   -            True
# 514         514  2024_2y1  Strategy_31   +            True
# 526         526  2024_2y1  Strategy_43   +            True
#
#      CCV_sharpe > Pure_sharpe  CCV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 440                      True              True                  87.5
# 445                      True             False                  87.5
# 446                      True              True                  87.5
# ...

# %%
Filtered_2024_2y1_GKV
# Out:
#      Unnamed: 0      Year     Strategy Abs  GKV_sharpe > 0  \
# 445         445  2024_2y1   Strategy_6   -            True
# 446         446  2024_2y1   Strategy_7   -            True
# 448         448  2024_2y1   Strategy_9   -            True
# 456         456  2024_2y1  Strategy_17   -            True
# 457         457  2024_2y1  Strategy_18   -            True
# 459         459  2024_2y1  Strategy_20   -            True
# 462         462  2024_2y1  Strategy_23   -            True
# 473         473  2024_2y1  Strategy_34   -            True
# 481         481  2024_2y1  Strategy_42   -            True
# 514         514  2024_2y1  Strategy_31   +            True
# 525         525  2024_2y1  Strategy_42   +            True
#
#      GKV_sharpe > Pure_sharpe  GKV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 445                      True              True                  87.5
# 446                      True              True                  87.5
# ...

# %%
Filtered_2024_2y1_YZV
# Out:
#      Unnamed: 0      Year     Strategy Abs  YZV_sharpe > 0  \
# 442         442  2024_2y1   Strategy_3   -            True
# 445         445  2024_2y1   Strategy_6   -            True
# 446         446  2024_2y1   Strategy_7   -            True
# 448         448  2024_2y1   Strategy_9   -            True
# 451         451  2024_2y1  Strategy_12   -            True
# 456         456  2024_2y1  Strategy_17   -            True
# 457         457  2024_2y1  Strategy_18   -            True
# 459         459  2024_2y1  Strategy_20   -            True
# 481         481  2024_2y1  Strategy_42   -            True
# 489         489  2024_2y1   Strategy_6   +            True
# 490         490  2024_2y1   Strategy_7   +            True
# 500         500  2024_2y1  Strategy_17   +            True
# 502         502  2024_2y1  Strategy_19   +            True
#
#      YZV_sharpe > Pure_sharpe  YZV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# ...

# %%
Filtered_2024_2y1_GKYZV
# Out:
#      Unnamed: 0      Year     Strategy Abs  GKYZV_sharpe > 0  \
# 441         441  2024_2y1   Strategy_2   -              True
# 442         442  2024_2y1   Strategy_3   -              True
# 443         443  2024_2y1   Strategy_4   -              True
# 444         444  2024_2y1   Strategy_5   -              True
# 445         445  2024_2y1   Strategy_6   -              True
# 446         446  2024_2y1   Strategy_7   -              True
# 448         448  2024_2y1   Strategy_9   -              True
# 449         449  2024_2y1  Strategy_10   -              True
# 452         452  2024_2y1  Strategy_13   -              True
# 453         453  2024_2y1  Strategy_14   -              True
# 454         454  2024_2y1  Strategy_15   -              True
# 455         455  2024_2y1  Strategy_16   -              True
# 456         456  2024_2y1  Strategy_17   -              True
# 457         457  2024_2y1  Strategy_18   -              True
# ...

# %%
Filtered_2024_2y1_RSV
# Out:
#      Unnamed: 0      Year     Strategy Abs  RSV_sharpe > 0  \
# 442         442  2024_2y1   Strategy_3   -            True
# 448         448  2024_2y1   Strategy_9   -            True
# 481         481  2024_2y1  Strategy_42   -            True
# 490         490  2024_2y1   Strategy_7   +            True
#
#      RSV_sharpe > Pure_sharpe  RSV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 442                      True              True                  62.5
# 448                      True              True                 100.0
# 481                      True             False                 100.0
# 490                      True              True                  87.5
#
#      RSV_sharpe > Pred_sharpe (%)  RSV_dd > Pred_dd (%)  RSV_tp > Pred_tp (%)  \
# 442                          62.5                  87.5                  62.5
# 448                         100.0                  87.5                 100.0
# 481                         100.0                  37.5                 100.0
# ...

# %%
Filtered_y1_y2_2024, Filtered_2y_2024, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV, common_rows_HV, common_rows_PV, common_rows_CCV, common_rows_GKV, common_rows_YZV, common_rows_GKYZV, common_rows_RSV = select_strategy_cw()

# %%
Filtered_2y_2024
# Out:
# Empty DataFrame
# Columns: [Strategy]
# Index: []

# %%
Filtered_2024_2y1_HV
# Out:
#      Unnamed: 0      Year     Strategy Abs  HV_sharpe > 0  \
# 470         470  2024_2y1  Strategy_31   -           True
# 481         481  2024_2y1  Strategy_42   -           True
# 503         503  2024_2y1  Strategy_20   +           True
# 514         514  2024_2y1  Strategy_31   +           True
# 515         515  2024_2y1  Strategy_32   +           True
# 525         525  2024_2y1  Strategy_42   +           True
# 526         526  2024_2y1  Strategy_43   +           True
#
#      HV_sharpe > Pure_sharpe  HV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 470                     True            False                 100.0
# 481                     True             True                 100.0
# 503                     True            False                 100.0
# 514                     True            False                 100.0
# 515                     True            False                 100.0
# 525                     True             True                 100.0
# ...

# %%
Filtered_2024_2y1_PV
# Out:
#      Unnamed: 0      Year     Strategy Abs  PV_sharpe > 0  \
# 448         448  2024_2y1   Strategy_9   -           True
# 449         449  2024_2y1  Strategy_10   -           True
#
#      PV_sharpe > Pure_sharpe  PV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 448                     True            False                 100.0
# 449                     True            False                 100.0
#
#      PV_sharpe > Pred_sharpe (%)  PV_dd > Pred_dd (%)  PV_tp > Pred_tp (%)  \
# 448                         62.5                 12.5                 75.0
# 449                        100.0                 12.5                100.0
#
#      Pred_sharpe > Pure_sharpe (%)
# 448                           50.0
# 449                           50.0

# %%
Filtered_2024_2y1_CCV
# Out:
#      Unnamed: 0      Year     Strategy Abs  CCV_sharpe > 0  \
# 470         470  2024_2y1  Strategy_31   -            True
# 471         471  2024_2y1  Strategy_32   -            True
# 481         481  2024_2y1  Strategy_42   -            True
# 482         482  2024_2y1  Strategy_43   -            True
# 514         514  2024_2y1  Strategy_31   +            True
# 515         515  2024_2y1  Strategy_32   +            True
# 525         525  2024_2y1  Strategy_42   +            True
# 526         526  2024_2y1  Strategy_43   +            True
#
#      CCV_sharpe > Pure_sharpe  CCV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 470                      True              True                 100.0
# 471                      True             False                 100.0
# 481                      True             False                 100.0
# 482                      True             False                 100.0
# 514                      True              True                 100.0
# ...

# %%
Filtered_2024_2y1_GKV
# Out:
#      Unnamed: 0      Year     Strategy Abs  GKV_sharpe > 0  \
# 470         470  2024_2y1  Strategy_31   -            True
# 471         471  2024_2y1  Strategy_32   -            True
# 481         481  2024_2y1  Strategy_42   -            True
# 482         482  2024_2y1  Strategy_43   -            True
# 514         514  2024_2y1  Strategy_31   +            True
# 525         525  2024_2y1  Strategy_42   +            True
# 526         526  2024_2y1  Strategy_43   +            True
#
#      GKV_sharpe > Pure_sharpe  GKV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 470                      True              True                 100.0
# 471                      True             False                 100.0
# 481                      True              True                 100.0
# 482                      True              True                 100.0
# 514                      True              True                 100.0
# 525                      True              True                 100.0
# ...

# %%
Filtered_2024_2y1_YZV
# Out:
#      Unnamed: 0      Year     Strategy Abs  YZV_sharpe > 0  \
# 448         448  2024_2y1   Strategy_9   -            True
# 482         482  2024_2y1  Strategy_43   -            True
# 525         525  2024_2y1  Strategy_42   +            True
#
#      YZV_sharpe > Pure_sharpe  YZV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 448                      True              True                 100.0
# 482                      True              True                 100.0
# 525                      True              True                 100.0
#
#      YZV_sharpe > Pred_sharpe (%)  YZV_dd > Pred_dd (%)  YZV_tp > Pred_tp (%)  \
# 448                          50.0                  75.0                  62.5
# 482                          75.0                  75.0                  62.5
# 525                          75.0                  62.5                  75.0
#
#      Pred_sharpe > Pure_sharpe (%)
# 448                           62.5
# 482                           50.0
# ...

# %%
Filtered_2024_2y1_GKYZV
# Out:
#      Unnamed: 0      Year     Strategy Abs  GKYZV_sharpe > 0  \
# 452         452  2024_2y1  Strategy_13   -              True
# 492         492  2024_2y1   Strategy_9   +              True
# 525         525  2024_2y1  Strategy_42   +              True
#
#      GKYZV_sharpe > Pure_sharpe  GKYZV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 452                        True               False                  87.5
# 492                        True               False                 100.0
# 525                        True                True                 100.0
#
#      GKYZV_sharpe > Pred_sharpe (%)  GKYZV_dd > Pred_dd (%)  \
# 452                            75.0                    37.5
# 492                            75.0                    25.0
# 525                            75.0                    87.5
#
#      GKYZV_tp > Pred_tp (%)  Pred_sharpe > Pure_sharpe (%)
# 452                    75.0                           50.0
# ...

# %%
Filtered_2024_2y1_RSV
# Out:
#      Unnamed: 0      Year     Strategy Abs  RSV_sharpe > 0  \
# 470         470  2024_2y1  Strategy_31   -            True
# 481         481  2024_2y1  Strategy_42   -            True
# 525         525  2024_2y1  Strategy_42   +            True
#
#      RSV_sharpe > Pure_sharpe  RSV_dd > Pure_dd  Pred_sharpes > 0 (%)  \
# 470                      True             False                 100.0
# 481                      True             False                 100.0
# 525                      True             False                 100.0
#
#      RSV_sharpe > Pred_sharpe (%)  RSV_dd > Pred_dd (%)  RSV_tp > Pred_tp (%)  \
# 470                          50.0                  50.0                  37.5
# 481                          62.5                  37.5                  37.5
# 525                          62.5                  25.0                  50.0
#
#      Pred_sharpe > Pure_sharpe (%)
# 470                           50.0
# 481                           50.0
# ...
