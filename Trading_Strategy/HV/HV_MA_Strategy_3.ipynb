# %%
import pandas as pd
import numpy as np
import yfinance as yf
from google.colab import drive
from datetime import datetime
import matplotlib.pyplot as plt
import builtins

# %% [markdown]
# # Loading data

# %%
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Volatility/'
path_1 = '/content/drive/MyDrive/Volatility/Predictions/HV/'
path_2 = '/content/drive/MyDrive/Volatility/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/Not_normal_wc_real/'

def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

filename = 'HV_data.csv'
HV_dw = pd.read_csv(path_2 + filename)

filename = 'HV_data.csv'
HV_cw = pd.read_csv(path_3 + filename)

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path_1 + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path_1 + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path_1 + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path_1 + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path_1 + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(HV_dw)
set_index(HV_cw)

start = datetime(2020, 11, 5)
end = datetime(2022, 12, 23)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")

data_s['Close'] = ticker_historical.Close.values

start = datetime(2020, 10, 1)
end = datetime(2022, 12, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")

data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['HV'] = volatility_proxies['HV'].loc['2020-10-01':'2022-12-30'].values
data_s['HV'] = volatility_proxies['HV'].loc['2020-11-05':'2022-12-22'].values

data_l['HV_dw'] = HV_dw['HV'].loc['2020-10-01':'2022-12-30'].values
data_s['HV_dw'] = HV_dw['HV'].loc['2020-11-05':'2022-12-22'].values

data_l['HV_cw'] = HV_cw['HV'].loc['2020-10-01':'2022-12-30'].values
data_s['HV_cw'] = HV_cw['HV'].loc['2020-11-05':'2022-12-22'].values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2020-11-05':'2022-12-22']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2020-11-05':'2022-12-22']

data_2022_y1 = data_s.head(268)
data_2022_y2 = data_s.tail(269)
data_2022_2y = data_s
# Out:
# Mounted at /content/drive
# <ipython-input-2-ff306df51396>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %%
path_1 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/'
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/HV/'
path_2 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
path_4 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/'

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path_1 + filename)

filename = 'HV_data.csv'
HV_dw = pd.read_csv(path_2 + filename)

filename = 'HV_data.csv'
HV_cw = pd.read_csv(path_3 + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path_4 + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path_4 + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(HV_dw)
set_index(HV_cw)

start = datetime(2022, 7, 14)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")
data_s['Close'] = ticker_historical.Close.values

start = datetime(2022, 5, 31)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")
data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['HV'] = (volatility_proxies['HV'].loc['2022-05-31':'2024-8-30']).values
data_s['HV'] = (volatility_proxies['HV'].loc['2022-07-14':'2024-8-30']).values

data_l['HV_dw'] = (HV_dw['HV'].loc['2022-05-31':'2024-8-30']).values
data_s['HV_dw'] = (HV_dw['HV'].loc['2022-07-14':'2024-8-30']).values

data_l['HV_cw'] = (HV_cw['HV'].loc['2022-05-31':'2024-8-30']).values
data_s['HV_cw'] = (HV_cw['HV'].loc['2022-07-14':'2024-8-30']).values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2022-07-14':'2024-8-30']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2022-07-14':'2024-8-30']

data_2024_y1 = data_s.head(268)
data_2024_y2 = data_s.tail(269)
data_2024_2y1 = data_s
# Out:
# <ipython-input-2-ff306df51396>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %% [markdown]
# # Strategy

# %% [markdown]
# ## Without volatility

# %%
def strategy(data, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0

  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# ## With volatility

# %%
def strategy_with_vol_1(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_2(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_3(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_4(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_5(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_6(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_7(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_8(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_9(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_10(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_11(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_12(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_13(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_14(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_15(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_16(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_17(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_18(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_19(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_20(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_21(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_22(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_23(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_24(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_25(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_26(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_27(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_28(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_29(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_30(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_31(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_32(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_33(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_34(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_35(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_36(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_37(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_38(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_39(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_40(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_41(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_42(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_43(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_44(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# # Backtest

# %%
def backtest_function(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, data_f[vol], short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
def backtest_function_abs(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, abs(data_f[vol]), short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
volatility = ['HV', 'HV_dw', 'HV_cw', 'LSTM_pred', 'GRU_pred', 'LSTM_GRU_pred', 'BiLSTM_pred',
              'BiLSTM_GRU_pred', 'QRNN_pred', 'ESN_pred', 'BNN_pred']

# %%
def backtest(data_s, short_window=50, long_window=200):
  S1_results = backtest_function(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results = backtest_function(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results = backtest_function(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results = backtest_function(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results = backtest_function(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results = backtest_function(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results = backtest_function(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results = backtest_function(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results = backtest_function(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results = backtest_function(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results = backtest_function(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results = backtest_function(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results = backtest_function(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results = backtest_function(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results = backtest_function(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results = backtest_function(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results = backtest_function(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results = backtest_function(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results = backtest_function(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results = backtest_function(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results = backtest_function(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results = backtest_function(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results = backtest_function(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results = backtest_function(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results = backtest_function(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results = backtest_function(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results = backtest_function(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results = backtest_function(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results = backtest_function(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results = backtest_function(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results = backtest_function(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results = backtest_function(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results = backtest_function(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results = backtest_function(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results = backtest_function(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results = backtest_function(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results = backtest_function(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results = backtest_function(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results = backtest_function(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results = backtest_function(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results = backtest_function(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results = backtest_function(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results = backtest_function(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results = backtest_function(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results.loc[len(S1_results)] = new_row
  S2_results.loc[len(S2_results)] = new_row
  S3_results.loc[len(S3_results)] = new_row
  S4_results.loc[len(S4_results)] = new_row
  S5_results.loc[len(S5_results)] = new_row
  S6_results.loc[len(S6_results)] = new_row
  S7_results.loc[len(S7_results)] = new_row
  S8_results.loc[len(S8_results)] = new_row
  S9_results.loc[len(S9_results)] = new_row
  S10_results.loc[len(S10_results)] = new_row
  S11_results.loc[len(S11_results)] = new_row
  S12_results.loc[len(S12_results)] = new_row
  S13_results.loc[len(S13_results)] = new_row
  S14_results.loc[len(S14_results)] = new_row
  S15_results.loc[len(S15_results)] = new_row
  S16_results.loc[len(S16_results)] = new_row
  S17_results.loc[len(S17_results)] = new_row
  S18_results.loc[len(S18_results)] = new_row
  S19_results.loc[len(S19_results)] = new_row
  S20_results.loc[len(S20_results)] = new_row
  S21_results.loc[len(S21_results)] = new_row
  S22_results.loc[len(S22_results)] = new_row

  S23_results.loc[len(S23_results)] = new_row
  S24_results.loc[len(S24_results)] = new_row
  S25_results.loc[len(S25_results)] = new_row
  S26_results.loc[len(S26_results)] = new_row
  S27_results.loc[len(S27_results)] = new_row
  S28_results.loc[len(S28_results)] = new_row
  S29_results.loc[len(S29_results)] = new_row
  S30_results.loc[len(S30_results)] = new_row
  S31_results.loc[len(S31_results)] = new_row
  S32_results.loc[len(S32_results)] = new_row
  S33_results.loc[len(S33_results)] = new_row
  S34_results.loc[len(S34_results)] = new_row
  S35_results.loc[len(S35_results)] = new_row
  S36_results.loc[len(S36_results)] = new_row
  S37_results.loc[len(S37_results)] = new_row
  S38_results.loc[len(S38_results)] = new_row
  S39_results.loc[len(S39_results)] = new_row
  S40_results.loc[len(S40_results)] = new_row
  S41_results.loc[len(S41_results)] = new_row
  S42_results.loc[len(S42_results)] = new_row
  S43_results.loc[len(S43_results)] = new_row
  S44_results.loc[len(S44_results)] = new_row

  return S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results

# %%
def backtest_abs(data_s, short_window=50, long_window=200):
  S1_results_abs = backtest_function_abs(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results_abs = backtest_function_abs(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results_abs = backtest_function_abs(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results_abs = backtest_function_abs(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results_abs = backtest_function_abs(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results_abs = backtest_function_abs(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results_abs = backtest_function_abs(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results_abs = backtest_function_abs(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results_abs = backtest_function_abs(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results_abs = backtest_function_abs(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results_abs = backtest_function_abs(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results_abs = backtest_function_abs(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results_abs = backtest_function_abs(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results_abs = backtest_function_abs(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results_abs = backtest_function_abs(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results_abs = backtest_function_abs(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results_abs = backtest_function_abs(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results_abs = backtest_function_abs(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results_abs = backtest_function_abs(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results_abs = backtest_function_abs(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results_abs = backtest_function_abs(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results_abs = backtest_function_abs(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results_abs = backtest_function_abs(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results_abs = backtest_function_abs(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results_abs = backtest_function_abs(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results_abs = backtest_function_abs(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results_abs = backtest_function_abs(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results_abs = backtest_function_abs(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results_abs = backtest_function_abs(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results_abs = backtest_function_abs(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results_abs = backtest_function_abs(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results_abs = backtest_function_abs(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results_abs = backtest_function_abs(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results_abs = backtest_function_abs(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results_abs = backtest_function_abs(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results_abs = backtest_function_abs(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results_abs = backtest_function_abs(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results_abs = backtest_function_abs(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results_abs = backtest_function_abs(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results_abs = backtest_function_abs(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results_abs = backtest_function_abs(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results_abs = backtest_function_abs(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results_abs = backtest_function_abs(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results_abs = backtest_function_abs(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results_abs.loc[len(S1_results_abs)] = new_row
  S2_results_abs.loc[len(S2_results_abs)] = new_row
  S3_results_abs.loc[len(S3_results_abs)] = new_row
  S4_results_abs.loc[len(S4_results_abs)] = new_row
  S5_results_abs.loc[len(S5_results_abs)] = new_row
  S6_results_abs.loc[len(S6_results_abs)] = new_row
  S7_results_abs.loc[len(S7_results_abs)] = new_row
  S8_results_abs.loc[len(S8_results_abs)] = new_row
  S9_results_abs.loc[len(S9_results_abs)] = new_row
  S10_results_abs.loc[len(S10_results_abs)] = new_row
  S11_results_abs.loc[len(S11_results_abs)] = new_row
  S12_results_abs.loc[len(S12_results_abs)] = new_row
  S13_results_abs.loc[len(S13_results_abs)] = new_row
  S14_results_abs.loc[len(S14_results_abs)] = new_row
  S15_results_abs.loc[len(S15_results_abs)] = new_row
  S16_results_abs.loc[len(S16_results_abs)] = new_row
  S17_results_abs.loc[len(S17_results_abs)] = new_row
  S18_results_abs.loc[len(S18_results_abs)] = new_row
  S19_results_abs.loc[len(S19_results_abs)] = new_row
  S20_results_abs.loc[len(S20_results_abs)] = new_row
  S21_results_abs.loc[len(S21_results_abs)] = new_row
  S22_results_abs.loc[len(S22_results_abs)] = new_row

  S23_results_abs.loc[len(S23_results_abs)] = new_row
  S24_results_abs.loc[len(S24_results_abs)] = new_row
  S25_results_abs.loc[len(S25_results_abs)] = new_row
  S26_results_abs.loc[len(S26_results_abs)] = new_row
  S27_results_abs.loc[len(S27_results_abs)] = new_row
  S28_results_abs.loc[len(S28_results_abs)] = new_row
  S29_results_abs.loc[len(S29_results_abs)] = new_row
  S30_results_abs.loc[len(S30_results_abs)] = new_row
  S31_results_abs.loc[len(S31_results_abs)] = new_row
  S32_results_abs.loc[len(S32_results_abs)] = new_row
  S33_results_abs.loc[len(S33_results_abs)] = new_row
  S34_results_abs.loc[len(S34_results_abs)] = new_row
  S35_results_abs.loc[len(S35_results_abs)] = new_row
  S36_results_abs.loc[len(S36_results_abs)] = new_row
  S37_results_abs.loc[len(S37_results_abs)] = new_row
  S38_results_abs.loc[len(S38_results_abs)] = new_row
  S39_results_abs.loc[len(S39_results_abs)] = new_row
  S40_results_abs.loc[len(S40_results_abs)] = new_row
  S41_results_abs.loc[len(S41_results_abs)] = new_row
  S42_results_abs.loc[len(S42_results_abs)] = new_row
  S43_results_abs.loc[len(S43_results_abs)] = new_row
  S44_results_abs.loc[len(S44_results_abs)] = new_row

  return S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs

# %% [markdown]
# # Final Results

# %%
def check_strategy(data, HV):

    sharpe_ratio_HV = data.loc[data['Volatility'] == HV, 'Sharpe ratio'].values[0]
    sharpe_ratio_pure = data.loc[data['Volatility'] == '__', 'Sharpe ratio'].values[0]

    max_drawdown_HV = data.loc[data['Volatility'] == HV, 'Max drawdown (%)'].values[0]
    max_drawdown_pure = data.loc[data['Volatility'] == '__', 'Max drawdown (%)'].values[0]

    total_profit_HV = data.loc[data['Volatility'] == HV, 'Total profit'].values[0]
    total_profit_pure = data.loc[data['Volatility'] == '__', 'Total profit'].values[0]

    is_HV_sharpe_positive = sharpe_ratio_HV > 0
    is_HV_sharpe_greater_than_pure_sharpe = sharpe_ratio_HV > sharpe_ratio_pure
    is_HV_dd_greater_than_pure_dd = max_drawdown_HV > max_drawdown_pure
    is_pure_tp_greater_than_HV_tp = total_profit_pure > total_profit_HV

    all_sharpes_greater_than_Pure_sharpe = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Sharpe ratio'] > sharpe_ratio_pure)
    all_sharpes_greater_than_Pure_sharpe_percentage = (all_sharpes_greater_than_Pure_sharpe.sum()/8) * 100

    positive_sharpes = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Sharpe ratio'] > 0)
    positive_sharpes_percentage = (positive_sharpes.sum()/8) * 100

    HV_sharpe_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Sharpe ratio'] < sharpe_ratio_HV)
    HV_sharpe_greater_than_all_percentage = (HV_sharpe_greater_than_all.sum()/8) * 100

    HV_dd_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Max drawdown (%)'] < max_drawdown_HV)
    HV_dd_greater_than_all_percentage = (HV_dd_greater_than_all.sum()/8) * 100

    HV_tp_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Total profit'] < total_profit_HV)
    HV_tp_greater_than_all_percentage = (HV_tp_greater_than_all.sum()/8) * 100

    return is_HV_sharpe_positive, is_HV_sharpe_greater_than_pure_sharpe, is_HV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, HV_sharpe_greater_than_all_percentage, HV_dd_greater_than_all_percentage, HV_tp_greater_than_all_percentage

# %%
def get_final_results(year, final_results, HV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results[f'S{i}_results']

    if(HV == 'HV'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV_cw'])]

    elif(HV == 'HV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV', 'HV_cw'])]

    elif(HV == 'HV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV'])]

    is_HV_sharpe_positive, is_HV_sharpe_greater_than_pure_sharpe, is_HV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, HV_sharpe_greater_than_all_percentage, HV_dd_greater_than_all_percentage, HV_tp_greater_than_all_percentage = check_strategy(strategy_result, HV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '-',
                'HV_sharpe > 0': is_HV_sharpe_positive,
                'HV_sharpe > Pure_sharpe': is_HV_sharpe_greater_than_pure_sharpe,
                'HV_dd > Pure_dd': is_HV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'HV_sharpe > Pred_sharpe (%)': HV_sharpe_greater_than_all_percentage,
                'HV_dd > Pred_dd (%)': HV_dd_greater_than_all_percentage,
                'HV_tp > Pred_tp (%)': HV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
def get_final_results_1(year, final_results, HV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results_abs[f'S{i}_results_abs']

    if(HV == 'HV'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV_cw'])]
      # res_combined
      # res_combined = pd.concat(details, strategy_result.drop())

    elif(HV == 'HV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV', 'HV_cw'])]

    elif(HV == 'HV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV'])]

    is_HV_sharpe_positive, is_HV_sharpe_greater_than_pure_sharpe, is_HV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, HV_sharpe_greater_than_all_percentage, HV_dd_greater_than_all_percentage, HV_tp_greater_than_all_percentage = check_strategy(strategy_result, HV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '+',
                'HV_sharpe > 0': is_HV_sharpe_positive,
                'HV_sharpe > Pure_sharpe': is_HV_sharpe_greater_than_pure_sharpe,
                'HV_dd > Pure_dd': is_HV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'HV_sharpe > Pred_sharpe (%)': HV_sharpe_greater_than_all_percentage,
                'HV_dd > Pred_dd (%)': HV_dd_greater_than_all_percentage,
                'HV_tp > Pred_tp (%)': HV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'HV_sharpe > 0', 'HV_sharpe > Pure_sharpe',
                                              'HV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'HV_sharpe > Pred_sharpe (%)',
                                              'HV_dd > Pred_dd (%)', 'HV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

dw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'HV_sharpe > 0', 'HV_sharpe > Pure_sharpe',
                                              'HV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'HV_sharpe > Pred_sharpe (%)',
                                              'HV_dd > Pred_dd (%)', 'HV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

cw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'HV_sharpe > 0', 'HV_sharpe > Pure_sharpe',
                                              'HV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'HV_sharpe > Pred_sharpe (%)',
                                              'HV_dd > Pred_dd (%)', 'HV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

# %%
# details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# dw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# cw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y1', file, 'HV')
get_final_results_1('2022_y1', file, 'HV')

get_final_results('2022_y1', dw_file, 'HV_dw')
get_final_results_1('2022_y1', dw_file, 'HV_dw')

get_final_results('2022_y1', cw_file, 'HV_cw')
get_final_results_1('2022_y1', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:51: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-37-4662277378c1>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-37-4662277378c1>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-37-4662277378c1>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-37-4662277378c1>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']
# <ipython-input-38-f0ec5dbb9c6c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vol_High_Threshold'] = volatility.quantile(0.75)
# <ipython-input-38-f0ec5dbb9c6c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
# <ipython-input-38-f0ec5dbb9c6c>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vol_Low_Threshold'] = volatility.quantile(0.25)
# <ipython-input-38-f0ec5dbb9c6c>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
# <ipython-input-38-f0ec5dbb9c6c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Long_MA'] = data['Close'].rolling(window=long_window).mean()
# <ipython-input-38-f0ec5dbb9c6c>:11: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-38-f0ec5dbb9c6c>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:63: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-38-f0ec5dbb9c6c>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-38-f0ec5dbb9c6c>:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-38-f0ec5dbb9c6c>:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-38-f0ec5dbb9c6c>:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y2', file, 'HV')
get_final_results_1('2022_y2', file, 'HV')

get_final_results('2022_y2', dw_file, 'HV_dw')
get_final_results_1('2022_y2', dw_file, 'HV_dw')

get_final_results('2022_y2', cw_file, 'HV_cw')
get_final_results_1('2022_y2', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-42-10bad2d7eebf>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-43-afbd323513da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0          -inf               0.0
# 1             HV_dw             0          -inf               0.0
# 2             HV_cw             0          -inf               0.0
# 3         LSTM_pred             0          -inf               0.0
# 4          GRU_pred             0          -inf               0.0
# 5     LSTM_GRU_pred             0          -inf               0.0
# 6       BiLSTM_pred             0          -inf               0.0
# 7   BiLSTM_GRU_pred             0          -inf               0.0
# 8         QRNN_pred             0          -inf               0.0
# 9          ESN_pred             0          -inf               0.0
# 10         BNN_pred             0          -inf               0.0
# 11               __             0          -inf               0.0

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y1', file, 'HV')
get_final_results_1('2024_y1', file, 'HV')

get_final_results('2024_y1', dw_file, 'HV_dw')
get_final_results_1('2024_y1', dw_file, 'HV_dw')

get_final_results('2024_y1', cw_file, 'HV_cw')
get_final_results_1('2024_y1', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-4-b267510ae310>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-4-b267510ae310>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    111.091433      0.795264         -2.417327
# 2             HV_cw     92.376066      0.478431         -2.417327
# 3         LSTM_pred     63.263288      0.883265         -2.417327
# 4          GRU_pred     74.165129      0.314929         -2.417327
# 5     LSTM_GRU_pred     46.793207      0.198687         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      0.000000      0.526043         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     98.799669      0.805491         -2.356724
# 10         BNN_pred     45.594897      0.220959         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     86.638752      0.580419         -2.472094
# 1             HV_dw    111.967517      0.929830         -2.417327
# 2             HV_cw     79.197757      0.203138         -2.417327
# 3         LSTM_pred     84.611538      0.679731         -2.446538
# 4          GRU_pred     85.104913      0.584376         -2.156566
# 5     LSTM_GRU_pred     84.631406      0.591849         -2.156566
# 6       BiLSTM_pred     80.439759      0.216309         -2.417327
# 7   BiLSTM_GRU_pred    107.023932      0.763609         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     81.159888      0.545892         -2.395175
# 10         BNN_pred     64.864148      0.429592         -2.668959
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    117.572602      1.424507         -1.730697
# 1             HV_dw     89.637176      0.560610         -2.417327
# 2             HV_cw     82.556484      0.736279         -2.347752
# 3         LSTM_pred     88.505677      0.761152         -2.393698
# 4          GRU_pred     92.591556      0.765504         -2.143283
# 5     LSTM_GRU_pred     78.247699      0.501825         -2.156566
# 6       BiLSTM_pred     72.248123      0.081713         -2.421536
# 7   BiLSTM_GRU_pred     94.995429      0.583072         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     59.835894      0.181457         -2.407962
# 10         BNN_pred     71.746553      0.584693         -2.293851
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    107.804002      0.932574         -2.326020
# 1             HV_dw    102.241001      0.727830         -2.417327
# 2             HV_cw     68.755960      0.072827         -2.817684
# 3         LSTM_pred     88.505677      0.761152         -2.393698
# 4          GRU_pred     84.254728      0.570105         -2.156566
# 5     LSTM_GRU_pred     85.050351      0.599176         -2.156566
# 6       BiLSTM_pred     86.294103      0.313218         -2.417327
# 7   BiLSTM_GRU_pred     94.572644      0.575571         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     56.841926      0.125838         -2.450288
# 10         BNN_pred     65.652780      0.444203         -2.668959
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     86.638752      0.580419         -2.472094
# 1             HV_dw    111.967517      0.929830         -2.417327
# 2             HV_cw     63.500968     -0.021384         -2.910130
# 3         LSTM_pred     92.982482      0.839458         -2.393698
# 4          GRU_pred     72.946874      0.369978         -2.354519
# 5     LSTM_GRU_pred     72.478672      0.370851         -2.355547
# 6       BiLSTM_pred     80.439759      0.216309         -2.417327
# 7   BiLSTM_GRU_pred    107.023932      0.763609         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     81.159888      0.545892         -2.395175
# 10         BNN_pred     64.864148      0.429592         -2.668959
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.733394         -2.417327
# 1             HV_dw    123.324821      1.007031         -2.417327
# 2             HV_cw     92.798002      0.773083         -2.332995
# 3         LSTM_pred     63.673980      0.890142         -2.417327
# 4          GRU_pred     89.769917      0.419930         -2.417327
# 5     LSTM_GRU_pred     61.150812      0.436459         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      0.000000      0.747110         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     95.002433      0.745854         -2.330629
# 10         BNN_pred     61.347757      0.498968         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    114.785248      0.862229         -2.417327
# 2             HV_cw     92.376066      0.452934         -2.394012
# 3         LSTM_pred     63.673980      0.890142         -2.417327
# 4          GRU_pred     85.905097      0.520453         -2.417327
# 5     LSTM_GRU_pred     59.472868      0.420901         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      0.000000      0.526043         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     94.579646      0.738980         -2.365810
# 10         BNN_pred     58.634881      0.447589         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    111.091433      0.795264         -2.417327
# 2             HV_cw     92.376066      0.481097         -2.417327
# 3         LSTM_pred     63.263288      0.883265         -2.417327
# 4          GRU_pred     74.580031      0.321844         -2.417327
# 5     LSTM_GRU_pred     47.197537      0.205544         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      0.000000      0.526043         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     98.799669      0.805491         -2.356724
# 10         BNN_pred     45.594897      0.220959         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.733394         -2.417327
# 1             HV_dw             0      1.013843         -2.417327
# 2             HV_cw             0      0.532669         -2.417327
# 3         LSTM_pred             0      0.747110         -2.417327
# 4          GRU_pred             0      0.877014         -2.417327
# 5     LSTM_GRU_pred             0      0.877014         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.747110         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.532669         -2.417327
# 10         BNN_pred             0      0.877014         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.747110         -2.417327
# 4          GRU_pred             0      0.747110         -2.417327
# 5     LSTM_GRU_pred             0      0.747110         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.747110         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.532669         -2.417327
# 5     LSTM_GRU_pred             0      0.532669         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.526043         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    106.186056      0.830439         -2.417327
# 2             HV_cw     85.631802      0.342723         -2.996625
# 3         LSTM_pred      4.112624      0.823515         -2.417327
# 4          GRU_pred     46.793207      0.198687         -2.417327
# 5     LSTM_GRU_pred     44.695872      0.163028         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      8.627027      0.525759         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     97.674051      0.787194         -2.359140
# 10         BNN_pred     57.461761      0.427086         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -8.975814      0.610443         -2.417327
# 1             HV_dw    123.939701      1.252813         -1.794471
# 2             HV_cw     97.060466      0.784209         -2.360460
# 3         LSTM_pred     81.132915      0.706936         -2.168054
# 4          GRU_pred     83.818409      0.561319         -2.156566
# 5     LSTM_GRU_pred     94.039405      0.741213         -2.156566
# 6       BiLSTM_pred     91.281838      0.392718         -2.417327
# 7   BiLSTM_GRU_pred      8.004450      0.221546         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred    108.738306      1.010417         -2.335598
# 10         BNN_pred     69.144580      0.482493         -2.554270
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -7.521289      0.278109         -2.417327
# 1             HV_dw    123.018028      1.307410         -1.821752
# 2             HV_cw     98.500857      1.012967         -2.144438
# 3         LSTM_pred     86.508131      0.805005         -2.168054
# 4          GRU_pred     87.924603      0.685178         -1.860710
# 5     LSTM_GRU_pred     88.045138      0.672202         -2.156566
# 6       BiLSTM_pred     77.897706      0.178055         -2.417327
# 7   BiLSTM_GRU_pred    -12.677667     -0.143363         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred    110.983051      1.084093         -1.816100
# 10         BNN_pred     73.683876      0.586362         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.827004      0.802626         -2.417327
# 1             HV_dw    109.632037      1.057197         -1.830419
# 2             HV_cw     77.758474      0.479406         -2.392876
# 3         LSTM_pred     86.508131      0.805005         -2.168054
# 4          GRU_pred     75.513248      0.423660         -2.156566
# 5     LSTM_GRU_pred     87.377574      0.633302         -2.156566
# 6       BiLSTM_pred     98.212566      0.507034         -2.417327
# 7   BiLSTM_GRU_pred     -3.333113      0.046051         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     97.686921      0.831298         -2.359113
# 10         BNN_pred     78.194065      0.645808         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -8.975814      0.610443         -2.417327
# 1             HV_dw    123.939701      1.252813         -1.794471
# 2             HV_cw     85.024949      0.335576         -2.817684
# 3         LSTM_pred     86.106655      0.797870         -2.168054
# 4          GRU_pred     71.674785      0.348035         -2.357314
# 5     LSTM_GRU_pred     94.039405      0.741213         -2.156566
# 6       BiLSTM_pred     91.281838      0.392718         -2.417327
# 7   BiLSTM_GRU_pred     14.199816      0.339207         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred    108.738306      1.010417         -2.335598
# 10         BNN_pred     69.144580      0.482493         -2.554270
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    117.933626      0.965706         -2.417327
# 2             HV_cw    108.926198      1.183814         -2.124966
# 3         LSTM_pred      4.500468      0.753809         -2.417327
# 4          GRU_pred     47.525086      0.238394         -2.417327
# 5     LSTM_GRU_pred     57.471029      0.407208         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred     20.844386      0.490214         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred    110.970025      1.022711         -2.114205
# 10         BNN_pred     65.881472      0.583918         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    109.863562      0.828017         -2.417327
# 2             HV_cw     87.986959      0.647378         -2.371149
# 3         LSTM_pred      4.500468      0.753809         -2.417327
# 4          GRU_pred     52.178650      0.275957         -2.417327
# 5     LSTM_GRU_pred     50.070525      0.239072         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      8.627027      0.634134         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     97.674051      0.787194         -2.359140
# 10         BNN_pred     70.649741      0.664320         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    106.186056      0.830439         -2.417327
# 2             HV_cw     87.986959      0.383207         -2.786188
# 3         LSTM_pred      4.112624      0.746970         -2.417327
# 4          GRU_pred     47.197537      0.205544         -2.417327
# 5     LSTM_GRU_pred     44.695872      0.163028         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      8.627027      0.634134         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     97.674051      0.787194         -2.359140
# 10         BNN_pred     57.461761      0.427086         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.877014         -2.417327
# 3         LSTM_pred             0      0.747110         -2.417327
# 4          GRU_pred             0      0.877014         -2.417327
# 5     LSTM_GRU_pred             0      0.877014         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.747110         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.747110         -2.417327
# 10         BNN_pred             0      0.747110         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.747110         -2.417327
# 4          GRU_pred             0      0.747110         -2.417327
# 5     LSTM_GRU_pred             0      0.747110         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.747110         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.532669         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.526043         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    130.268553      1.341032         -1.786420
# 2             HV_cw      0.000000      0.526043         -2.417327
# 3         LSTM_pred     36.262794      0.443595         -2.417327
# 4          GRU_pred     90.355601      0.677350         -2.156566
# 5     LSTM_GRU_pred     69.051345      0.590646         -2.417327
# 6       BiLSTM_pred     86.897127      0.322018         -2.457965
# 7   BiLSTM_GRU_pred     26.379473      0.150290         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     84.591381      0.594551         -2.387597
# 10         BNN_pred     73.179106      0.557894         -2.668959
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    126.112247      1.304065         -1.792016
# 2             HV_cw     81.365884      0.286867         -2.657530
# 3         LSTM_pred     39.460174     -0.453404         -2.579959
# 4          GRU_pred     95.790888      0.843857         -1.635225
# 5     LSTM_GRU_pred     65.452090      0.274811         -2.156566
# 6       BiLSTM_pred     59.906794      0.169722         -2.590726
# 7   BiLSTM_GRU_pred     15.684372     -0.216669         -2.544966
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred    108.514824      1.049296         -2.336069
# 10         BNN_pred     52.815755      0.204833         -2.206983
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     95.946028      1.051649         -1.861095
# 2             HV_cw     76.382503      0.686748         -2.124157
# 3         LSTM_pred      8.351126     -1.317087         -2.417327
# 4          GRU_pred     62.538965      0.314418         -0.869432
# 5     LSTM_GRU_pred     39.207059     -0.291526         -2.156566
# 6       BiLSTM_pred     75.612692      0.523913         -1.667822
# 7   BiLSTM_GRU_pred    -13.467471     -1.013948         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     21.570516     -0.530824         -1.955144
# 10         BNN_pred     52.743302      0.232075         -2.120230
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     95.134977      1.036045         -1.861754
# 2             HV_cw     77.812217      0.511879         -2.358509
# 3         LSTM_pred     35.289877     -0.602137         -2.417327
# 4          GRU_pred     91.575733      0.777498         -1.635225
# 5     LSTM_GRU_pred     68.718319      0.346936         -2.156566
# 6       BiLSTM_pred     49.667191     -0.038288         -2.469069
# 7   BiLSTM_GRU_pred    -19.737301     -1.116998         -2.954151
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     70.957850      0.411753         -2.382955
# 10         BNN_pred     47.251274      0.105925         -2.120230
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    110.835866      1.086672         -1.827914
# 2             HV_cw     81.365884      0.286867         -2.657530
# 3         LSTM_pred     32.849751     -0.655388         -2.417327
# 4          GRU_pred    101.503832      0.962790         -1.635225
# 5     LSTM_GRU_pred     67.354862      0.311214         -2.156566
# 6       BiLSTM_pred     58.696140      0.147163         -2.186721
# 7   BiLSTM_GRU_pred      2.870288     -0.540241         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     84.261382      0.643496         -2.388324
# 10         BNN_pred     51.566180      0.183818         -2.396018
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    117.377559      1.222727         -1.833705
# 2             HV_cw      0.000000      0.747110         -2.417327
# 3         LSTM_pred     14.967484      0.065000         -2.417327
# 4          GRU_pred     51.198688     -0.015323         -1.904535
# 5     LSTM_GRU_pred     40.804531      0.293521         -2.417327
# 6       BiLSTM_pred     92.095896      0.432173         -2.731744
# 7   BiLSTM_GRU_pred      7.694888     -0.629443         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     56.868963      0.307197         -1.884972
# 10         BNN_pred     74.963690      0.631270         -2.293851
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    116.550648      1.207664         -1.834354
# 2             HV_cw      0.000000      0.532669         -2.417327
# 3         LSTM_pred     31.619841      0.362251         -2.417327
# 4          GRU_pred     89.625880      0.676169         -2.156566
# 5     LSTM_GRU_pred     62.343492      0.513695         -2.417327
# 6       BiLSTM_pred     64.938159     -0.043211         -2.731744
# 7   BiLSTM_GRU_pred     12.448343     -0.110970         -2.446029
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     79.603797      0.511422         -2.363872
# 10         BNN_pred     79.441885      0.678965         -2.293851
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    115.880323      1.148313         -1.822206
# 2             HV_cw      0.000000      0.526043         -2.417327
# 3         LSTM_pred     31.619841      0.362251         -2.417327
# 4          GRU_pred     87.356817      0.626079         -2.156566
# 5     LSTM_GRU_pred     71.160248      0.605807         -2.417327
# 6       BiLSTM_pred     79.477409      0.202139         -2.457965
# 7   BiLSTM_GRU_pred     28.422962      0.187747         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     79.186955      0.504317         -2.399554
# 10         BNN_pred     76.091988      0.609327         -2.668959
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      1.013843         -2.417327
# 2             HV_cw             0      0.747110         -2.417327
# 3         LSTM_pred             0      0.747110         -2.417327
# 4          GRU_pred             0      0.726354         -2.417327
# 5     LSTM_GRU_pred             0      0.877014         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.747110         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.747110         -2.417327
# 10         BNN_pred             0      0.877014         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.532669         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.877014         -2.417327
# 5     LSTM_GRU_pred             0      0.877014         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.532669         -2.417327
# 10         BNN_pred             0      0.747110         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.747110         -2.417327
# 5     LSTM_GRU_pred             0      0.747110         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.747110         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    109.279650      1.171471         -1.800145
# 2             HV_cw      0.000000      0.526043         -2.417327
# 3         LSTM_pred     57.170840      0.585853         -2.417327
# 4          GRU_pred     92.208669      0.709172         -2.156566
# 5     LSTM_GRU_pred     64.364032      0.683901         -2.417327
# 6       BiLSTM_pred     47.511367     -0.067567         -3.248784
# 7   BiLSTM_GRU_pred    -13.658277     -0.662962         -2.801494
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred    119.194311      1.198872         -2.313778
# 10         BNN_pred     63.435363      0.396393         -3.023091
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw    138.388694      1.549567         -1.792184
# 2             HV_cw     90.725605      0.873871         -2.359224
# 3         LSTM_pred      8.515049     -0.830519         -3.092463
# 4          GRU_pred     95.790888      0.843857         -1.635225
# 5     LSTM_GRU_pred     73.214831      0.414311         -2.156566
# 6       BiLSTM_pred     82.608746      0.614502         -2.536399
# 7   BiLSTM_GRU_pred     27.237201      0.015180         -2.544966
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred    111.967354      1.152589         -1.830161
# 10         BNN_pred     48.369211      0.122875         -2.168054
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     67.916077      0.556201         -1.912973
# 2             HV_cw     96.997326      1.122597         -2.124157
# 3         LSTM_pred     -2.884106     -1.984049         -2.393698
# 4          GRU_pred     36.865132     -0.549868         -0.670222
# 5     LSTM_GRU_pred     16.433682     -0.950684         -2.384557
# 6       BiLSTM_pred     57.129260      0.132087         -1.696983
# 7   BiLSTM_GRU_pred     -7.135294     -0.864745         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred      6.073229     -1.026933         -1.821804
# 10         BNN_pred     19.126878     -0.583832         -2.120230
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     92.556510      1.011957         -1.869108
# 2             HV_cw     77.681616      0.704268         -2.353181
# 3         LSTM_pred     12.881450     -0.856426         -2.393698
# 4          GRU_pred     91.575733      0.777498         -1.635225
# 5     LSTM_GRU_pred     50.961114     -0.012168         -2.156566
# 6       BiLSTM_pred     68.531655      0.362046         -1.762628
# 7   BiLSTM_GRU_pred    -19.859122     -1.152971         -3.638648
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     85.633429      0.752239         -1.879199
# 10         BNN_pred     31.305033     -0.249856         -2.120230
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     91.228879      0.974605         -1.866394
# 2             HV_cw     90.725605      0.873871         -2.359224
# 3         LSTM_pred     12.490370     -0.866103         -2.393698
# 4          GRU_pred     84.957464      0.647878         -1.635225
# 5     LSTM_GRU_pred     81.668678      0.586528         -2.156566
# 6       BiLSTM_pred     73.212873      0.440359         -2.414899
# 7   BiLSTM_GRU_pred      4.801834     -0.505439         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     93.373425      0.851373         -1.861284
# 10         BNN_pred     25.553504     -0.351960         -2.019858
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     98.627741      1.074537         -1.846712
# 2             HV_cw      0.000000      0.747110         -2.417327
# 3         LSTM_pred     10.480574     -0.676402         -2.417327
# 4          GRU_pred     44.223157     -0.212943         -1.906654
# 5     LSTM_GRU_pred     39.437753     -0.219145         -2.417327
# 6       BiLSTM_pred     51.070815     -0.008683         -2.731744
# 7   BiLSTM_GRU_pred     -8.592073     -1.052883         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     52.901705      0.240769         -1.878621
# 10         BNN_pred     40.617375     -0.032956         -2.749075
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     97.814706      1.059344         -1.847367
# 2             HV_cw      0.000000      0.532669         -2.417327
# 3         LSTM_pred     54.954405      0.546616         -2.417327
# 4          GRU_pred     89.984239      0.684055         -2.156566
# 5     LSTM_GRU_pred     39.265337      0.263089         -2.417327
# 6       BiLSTM_pred     41.610598     -0.187698         -2.731744
# 7   BiLSTM_GRU_pred    -22.040409     -0.906095         -2.588468
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred    115.917023      1.220477         -1.814015
# 10         BNN_pred     54.577112      0.251407         -2.749075
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     89.704516      0.902566         -1.856156
# 2             HV_cw      0.000000      0.526043         -2.417327
# 3         LSTM_pred     54.547080      0.538878         -2.417327
# 4          GRU_pred     91.477707      0.708578         -2.156566
# 5     LSTM_GRU_pred     62.650842      0.662037         -2.417327
# 6       BiLSTM_pred     35.965006     -0.290204         -3.130730
# 7   BiLSTM_GRU_pred    -11.694503     -0.615586         -2.794937
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred    108.038705      1.019055         -2.337073
# 10         BNN_pred     67.863101      0.480148         -2.649348
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      1.013843         -2.417327
# 2             HV_cw             0      0.747110         -2.417327
# 3         LSTM_pred             0      0.746321         -2.417327
# 4          GRU_pred             0      0.717816         -2.417327
# 5     LSTM_GRU_pred             0      0.877014         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.747110         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.747110         -2.417327
# 10         BNN_pred             0      0.877014         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.532669         -2.417327
# 3         LSTM_pred             0      0.747110         -2.417327
# 4          GRU_pred             0      0.877014         -2.417327
# 5     LSTM_GRU_pred             0      0.877014         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.747110         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.747110         -2.417327
# 10         BNN_pred             0      0.747110         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.877014         -2.417327
# 5     LSTM_GRU_pred             0      0.747110         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.747110         -2.417327
# 11               __             0      0.526043         -2.417327

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     39.017871      0.403398         -2.417327
# 2             HV_cw     92.696560      0.438298         -3.255148
# 3         LSTM_pred      0.000000      0.526043         -2.417327
# 4          GRU_pred      0.000000      0.526043         -2.417327
# 5     LSTM_GRU_pred      0.000000      0.526043         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      0.000000      0.526043         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     98.303095      0.797501         -2.357789
# 10         BNN_pred     57.573080      0.413548         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     86.638752      0.580419         -2.472094
# 1             HV_dw     99.878366      0.762630         -2.417327
# 2             HV_cw    100.195134      0.587203         -2.996625
# 3         LSTM_pred     56.917608      0.277472         -2.417327
# 4          GRU_pred     61.054905      0.248420         -2.406783
# 5     LSTM_GRU_pred     75.387390      0.565930         -2.362120
# 6       BiLSTM_pred     80.439759      0.216309         -2.417327
# 7   BiLSTM_GRU_pred     99.698443      0.884114         -2.305094
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     76.293872      0.637059         -2.095307
# 10         BNN_pred     89.918804      0.443658         -2.382276
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    117.572602      1.424507         -1.730697
# 1             HV_dw     87.402415      0.462840         -2.417327
# 2             HV_cw     90.824845      0.805047         -2.364980
# 3         LSTM_pred     37.904440     -0.242261         -2.465591
# 4          GRU_pred     38.739788     -0.165349         -2.422864
# 5     LSTM_GRU_pred     76.277439      0.618103         -2.372742
# 6       BiLSTM_pred     72.248123      0.081713         -2.421536
# 7   BiLSTM_GRU_pred     85.258126      0.650067         -1.822686
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     78.212195      0.687430         -1.841065
# 10         BNN_pred     90.097621      0.447512         -2.381885
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    107.804002      0.932574         -2.326020
# 1             HV_dw     86.953587      0.482611         -2.417327
# 2             HV_cw    106.946878      0.711099         -2.786188
# 3         LSTM_pred     56.917608      0.277472         -2.417327
# 4          GRU_pred     61.054905      0.248420         -2.406783
# 5     LSTM_GRU_pred     80.503692      0.652480         -2.350935
# 6       BiLSTM_pred     86.294103      0.313218         -2.417327
# 7   BiLSTM_GRU_pred     95.755732      0.834323         -1.805224
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     65.565878      0.444755         -2.103385
# 10         BNN_pred     89.918804      0.443658         -2.382276
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     86.638752      0.580419         -2.472094
# 1             HV_dw     86.953587      0.557419         -2.417327
# 2             HV_cw    113.019167      0.809047         -2.643408
# 3         LSTM_pred     56.917608      0.277472         -2.417327
# 4          GRU_pred     61.054905      0.248420         -2.406783
# 5     LSTM_GRU_pred     75.387390      0.565930         -2.362120
# 6       BiLSTM_pred     80.439759      0.216309         -2.417327
# 7   BiLSTM_GRU_pred     99.698443      0.884114         -2.305094
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     76.293872      0.637059         -2.095307
# 10         BNN_pred     89.918804      0.443658         -2.382276
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.733394         -2.417327
# 1             HV_dw     39.017871      0.338971         -2.417327
# 2             HV_cw     89.839800      0.740515         -2.367117
# 3         LSTM_pred      0.000000      0.526043         -2.417327
# 4          GRU_pred      0.000000      0.532669         -2.417327
# 5     LSTM_GRU_pred      0.000000      0.526043         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      0.000000      0.526043         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     94.084979      0.730977         -2.366879
# 10         BNN_pred     57.573080      0.413548         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     39.017871      0.403398         -2.417327
# 2             HV_cw     96.675382      0.527994         -2.786188
# 3         LSTM_pred      0.000000      0.526043         -2.417327
# 4          GRU_pred      0.000000      0.526043         -2.417327
# 5     LSTM_GRU_pred      0.000000      0.526043         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      0.000000      0.526043         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     94.084979      0.730977         -2.366879
# 10         BNN_pred     57.573080      0.413548         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     39.017871      0.403398         -2.417327
# 2             HV_cw     96.675382      0.505936         -2.902872
# 3         LSTM_pred      0.000000      0.526043         -2.417327
# 4          GRU_pred      0.000000      0.526043         -2.417327
# 5     LSTM_GRU_pred      0.000000      0.526043         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred      0.000000      0.526043         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     98.303095      0.797501         -2.357789
# 10         BNN_pred     57.573080      0.413548         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.733394         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.532669         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.526043         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.526043         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.526043         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.526043         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.526043         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     40.210726      0.423484         -2.417327
# 2             HV_cw     81.462351      0.276232         -2.996625
# 3         LSTM_pred      0.000000      0.526043         -2.417327
# 4          GRU_pred      0.000000      0.526043         -2.417327
# 5     LSTM_GRU_pred      0.000000      0.526043         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred     67.762708      0.452646         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     74.883406      0.437282         -2.114205
# 10         BNN_pred     57.573080      0.413548         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -8.975814      0.610443         -2.417327
# 1             HV_dw     93.053788      0.669468         -2.417327
# 2             HV_cw     90.424603      0.681224         -2.374825
# 3         LSTM_pred     84.936263      0.370131         -2.417327
# 4          GRU_pred     52.674850      0.198612         -2.413085
# 5     LSTM_GRU_pred     67.860547      0.452451         -2.378769
# 6       BiLSTM_pred     91.281838      0.392718         -2.417327
# 7   BiLSTM_GRU_pred     98.347555      0.858538         -2.157119
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     80.761503      0.687737         -1.825008
# 10         BNN_pred     43.354993      0.193593         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -7.521289      0.278109         -2.417327
# 1             HV_dw     70.664366      0.155386         -2.605306
# 2             HV_cw     64.614922      0.405441         -2.422419
# 3         LSTM_pred     84.047967      0.356040         -2.417327
# 4          GRU_pred     42.307983      0.005921         -2.401773
# 5     LSTM_GRU_pred     59.598588      0.330104         -2.410091
# 6       BiLSTM_pred     77.897706      0.178055         -2.417327
# 7   BiLSTM_GRU_pred     76.173646      0.478550         -2.167440
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     79.585779      0.680104         -1.838722
# 10         BNN_pred     56.002089      0.432540         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.827004      0.802626         -2.417327
# 1             HV_dw     70.664366      0.209744         -2.417327
# 2             HV_cw     67.125189      0.300752         -2.416720
# 3         LSTM_pred     84.936263      0.370131         -2.417327
# 4          GRU_pred     52.674850      0.198612         -2.413085
# 5     LSTM_GRU_pred     50.866265      0.163645         -2.417238
# 6       BiLSTM_pred     98.212566      0.507034         -2.417327
# 7   BiLSTM_GRU_pred     87.548057      0.685702         -2.151116
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     69.988977      0.504496         -1.843382
# 10         BNN_pred     43.354993      0.193593         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -8.975814      0.610443         -2.417327
# 1             HV_dw     80.209205      0.454791         -2.417327
# 2             HV_cw     81.966203      0.286554         -2.817684
# 3         LSTM_pred     84.936263      0.370131         -2.417327
# 4          GRU_pred     52.674850      0.198612         -2.413085
# 5     LSTM_GRU_pred     67.860547      0.452451         -2.378769
# 6       BiLSTM_pred     91.281838      0.392718         -2.417327
# 7   BiLSTM_GRU_pred     98.347555      0.858538         -2.157119
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     74.114194      0.575800         -1.836302
# 10         BNN_pred     43.354993      0.193593         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     40.210726      0.359103         -2.417327
# 2             HV_cw     73.617718      0.557976         -2.400422
# 3         LSTM_pred      0.000000      0.526043         -2.417327
# 4          GRU_pred      0.000000      0.532669         -2.417327
# 5     LSTM_GRU_pred      0.000000      0.526043         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred     58.067161      0.102089         -2.418606
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     77.607355      0.485697         -1.850260
# 10         BNN_pred     70.383316      0.633567         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     40.210726      0.359103         -2.417327
# 2             HV_cw     76.149213      0.453022         -2.397231
# 3         LSTM_pred      0.000000      0.526043         -2.417327
# 4          GRU_pred      0.000000      0.526043         -2.417327
# 5     LSTM_GRU_pred      0.000000      0.526043         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred     65.200873      0.219289         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     74.883406      0.437282         -2.114205
# 10         BNN_pred     57.573080      0.413548         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     40.210726      0.423484         -2.417327
# 2             HV_cw     83.808463      0.316238         -2.786188
# 3         LSTM_pred      0.000000      0.526043         -2.417327
# 4          GRU_pred      0.000000      0.526043         -2.417327
# 5     LSTM_GRU_pred      0.000000      0.526043         -2.417327
# 6       BiLSTM_pred      0.000000      0.526043         -2.417327
# 7   BiLSTM_GRU_pred     67.762708      0.452646         -2.417327
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     74.883406      0.437282         -2.114205
# 10         BNN_pred     57.573080      0.413548         -2.417327
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.532669         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.747110         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.526043         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.526043         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.526043         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.526043         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     81.351919      0.601629         -1.825241
# 2             HV_cw      0.000000      0.526043         -2.417327
# 3         LSTM_pred     94.327833      0.735597         -2.372678
# 4          GRU_pred     52.674850      0.198612         -2.413085
# 5     LSTM_GRU_pred     76.232107      0.576969         -2.360266
# 6       BiLSTM_pred     86.897127      0.322018         -2.457965
# 7   BiLSTM_GRU_pred    108.002285      0.973224         -2.128366
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     55.875305      0.249883         -2.433317
# 10         BNN_pred    114.225614      0.841005         -2.156566
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     60.485531      0.195635         -2.629783
# 2             HV_cw      4.941993      0.515662         -2.417327
# 3         LSTM_pred     74.169936      0.445897         -2.709936
# 4          GRU_pred     40.412244     -0.023510         -2.441526
# 5     LSTM_GRU_pred     53.273059      0.221461         -1.866013
# 6       BiLSTM_pred     59.906794      0.169722         -2.590726
# 7   BiLSTM_GRU_pred     77.181809      0.482841         -3.209943
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred    102.888774      1.132815         -1.713689
# 10         BNN_pred     62.196426      0.424223         -2.408870
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     31.594756     -0.445958         -0.979830
# 2             HV_cw      5.446780      0.505985         -2.417327
# 3         LSTM_pred     34.006555     -0.225065         -1.545926
# 4          GRU_pred      7.937337     -0.696256         -2.863558
# 5     LSTM_GRU_pred     -2.183720     -1.311432         -2.826802
# 6       BiLSTM_pred     75.612692      0.523913         -1.667822
# 7   BiLSTM_GRU_pred     74.355588      0.704132         -2.180039
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     46.340737      0.092258         -1.770473
# 10         BNN_pred     48.113778      0.156974         -1.674963
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     27.546199     -0.752649         -1.744410
# 2             HV_cw      4.941993      0.722333         -2.417327
# 3         LSTM_pred     81.119284      0.622871         -1.957024
# 4          GRU_pred     24.356132     -0.343172         -2.853447
# 5     LSTM_GRU_pred     39.841480     -0.048607         -2.529848
# 6       BiLSTM_pred     49.667191     -0.038288         -2.469069
# 7   BiLSTM_GRU_pred     72.222564      0.625666         -2.171581
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     92.767931      0.987050         -1.729561
# 10         BNN_pred     43.342083      0.022840         -1.710920
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     44.961312     -0.161221         -2.204500
# 2             HV_cw      4.941993      0.515662         -2.417327
# 3         LSTM_pred     72.740285      0.417757         -2.713548
# 4          GRU_pred     40.412244     -0.023510         -2.441526
# 5     LSTM_GRU_pred     47.359780      0.108174         -2.498376
# 6       BiLSTM_pred     58.696140      0.147163         -2.186721
# 7   BiLSTM_GRU_pred     93.865925      0.766978         -2.151995
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     87.229536      0.867972         -1.738372
# 10         BNN_pred     65.014234      0.485153         -2.408870
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     68.985744      0.658795         -1.753451
# 2             HV_cw      0.000000      0.532669         -2.417327
# 3         LSTM_pred     55.516701      0.261597         -2.420155
# 4          GRU_pred     32.894889     -0.170579         -2.423661
# 5     LSTM_GRU_pred     39.098015     -0.058379         -2.422029
# 6       BiLSTM_pred     92.095896      0.432173         -2.731744
# 7   BiLSTM_GRU_pred     66.832848      0.486484         -2.397119
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     45.125538      0.061412         -2.422724
# 10         BNN_pred    100.611998      1.283740         -1.646653
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     67.589145      0.373562         -2.015553
# 2             HV_cw      0.000000      0.526043         -2.417327
# 3         LSTM_pred     84.622929      0.588275         -2.393908
# 4          GRU_pred     52.674850      0.198612         -2.413085
# 5     LSTM_GRU_pred     81.616064      0.667994         -2.361031
# 6       BiLSTM_pred     64.938159     -0.043211         -2.731744
# 7   BiLSTM_GRU_pred     69.999578      0.536642         -2.332616
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     65.345521      0.418772         -2.411686
# 10         BNN_pred     90.090509      0.869557         -1.652792
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     55.110379      0.100952         -2.204500
# 2             HV_cw      0.000000      0.526043         -2.417327
# 3         LSTM_pred     98.633997      0.810618         -2.363378
# 4          GRU_pred     52.674850      0.198612         -2.413085
# 5     LSTM_GRU_pred     76.232107      0.576969         -2.360266
# 6       BiLSTM_pred     79.477409      0.202139         -2.457965
# 7   BiLSTM_GRU_pred    104.682037      0.920222         -2.134763
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     55.875305      0.249883         -2.433317
# 10         BNN_pred    114.225614      0.841005         -2.156566
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.532669         -2.417327
# 3         LSTM_pred             0      0.532669         -2.417327
# 4          GRU_pred             0      0.532669         -2.417327
# 5     LSTM_GRU_pred             0      0.532669         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.532669         -2.417327
# 10         BNN_pred             0      0.758085         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.526043         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.747110         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.526043         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.526043         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     60.581018      0.189108         -1.825241
# 2             HV_cw      0.000000      0.526043         -2.417327
# 3         LSTM_pred    106.231435      0.948302         -2.347146
# 4          GRU_pred     52.674850      0.198612         -2.413085
# 5     LSTM_GRU_pred     67.386571      0.455873         -2.410810
# 6       BiLSTM_pred     47.511367     -0.067567         -3.248784
# 7   BiLSTM_GRU_pred     91.325986      0.735001         -2.434856
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     70.019660      0.502541         -1.843329
# 10         BNN_pred     57.004596      0.297786         -2.156566
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     59.521040      0.381043         -1.539211
# 2             HV_cw    104.041023      0.596209         -2.417327
# 3         LSTM_pred     65.495619      0.282519         -2.577137
# 4          GRU_pred      5.515506     -0.814153         -2.525601
# 5     LSTM_GRU_pred     66.332752      0.499197         -1.777825
# 6       BiLSTM_pred     82.608746      0.614502         -2.536399
# 7   BiLSTM_GRU_pred     65.739172      0.292624         -2.576548
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     93.739041      1.080695         -2.404026
# 10         BNN_pred     35.354298     -0.150732         -2.408870
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     36.502708     -0.256605         -0.593909
# 2             HV_cw     74.893259      0.666499         -2.333608
# 3         LSTM_pred      3.338002     -1.273327         -1.784101
# 4          GRU_pred    -24.462860     -1.754552         -3.392035
# 5     LSTM_GRU_pred      2.730467     -1.240040         -2.812948
# 6       BiLSTM_pred     57.129260      0.132087         -1.696983
# 7   BiLSTM_GRU_pred     69.277036      0.674541         -1.494933
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     38.868733     -0.100142         -2.597788
# 10         BNN_pred     30.622401     -0.375780         -1.676392
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     33.058500     -0.348253         -0.979830
# 2             HV_cw     93.802312      0.525933         -2.156566
# 3         LSTM_pred     65.993072      0.523913         -1.674111
# 4          GRU_pred    -24.146694     -1.745871         -3.392035
# 5     LSTM_GRU_pred     18.287081     -0.662670         -3.171677
# 6       BiLSTM_pred     68.531655      0.362046         -1.762628
# 7   BiLSTM_GRU_pred     62.962340      0.483800         -1.676007
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     83.212411      0.908760         -2.155161
# 10         BNN_pred     41.704350     -0.026274         -1.665937
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     13.027357     -0.812738         -2.204500
# 2             HV_cw    104.041023      0.596209         -2.417327
# 3         LSTM_pred     52.384807      0.018306         -2.609243
# 4          GRU_pred      5.515506     -0.814153         -2.525601
# 5     LSTM_GRU_pred     48.939935      0.145869         -2.507905
# 6       BiLSTM_pred     73.212873      0.440359         -2.414899
# 7   BiLSTM_GRU_pred     69.789932      0.401272         -1.676900
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     81.025976      0.836977         -2.472566
# 10         BNN_pred     20.370925     -0.571042         -2.393698
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     32.143477     -0.354075         -1.791004
# 2             HV_cw      0.000000      0.532669         -2.417327
# 3         LSTM_pred     54.067477      0.239357         -2.423483
# 4          GRU_pred     32.894889     -0.170579         -2.423661
# 5     LSTM_GRU_pred     41.800624     -0.008925         -2.449648
# 6       BiLSTM_pred     51.070815     -0.008683         -2.731744
# 7   BiLSTM_GRU_pred     87.904279      0.980219         -2.177490
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     45.186402      0.063095         -2.237195
# 10         BNN_pred     65.793043      0.609021         -1.673283
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     37.996963     -0.428478         -1.797725
# 2             HV_cw      0.000000      0.532669         -2.417327
# 3         LSTM_pred     82.847655      0.733447         -2.385349
# 4          GRU_pred     40.317788     -0.028918         -2.406367
# 5     LSTM_GRU_pred     66.187987      0.470628         -2.428809
# 6       BiLSTM_pred     41.610598     -0.187698         -2.731744
# 7   BiLSTM_GRU_pred     88.496380      0.948136         -2.175274
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     68.066031      0.477732         -1.858554
# 10         BNN_pred     75.673315      0.830812         -1.657874
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.526043         -2.417327
# 1             HV_dw     19.110741     -0.817544         -2.374893
# 2             HV_cw      0.000000      0.526043         -2.417327
# 3         LSTM_pred     92.619373      0.733447         -2.376388
# 4          GRU_pred     52.674850      0.198612         -2.413085
# 5     LSTM_GRU_pred     78.360333      0.658161         -2.401393
# 6       BiLSTM_pred     35.965006     -0.290204         -3.130730
# 7   BiLSTM_GRU_pred     83.194387      0.605824         -2.160840
# 8         QRNN_pred     42.117088     -0.002727         -2.393698
# 9          ESN_pred     65.910169      0.431288         -1.850436
# 10         BNN_pred     36.442633     -0.124576         -2.467313
# 11               __      0.000000      0.526043         -2.417327
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.532669         -2.417327
# 3         LSTM_pred             0      0.532669         -2.417327
# 4          GRU_pred             0      0.532669         -2.417327
# 5     LSTM_GRU_pred             0      0.532669         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.532669         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.532669         -2.417327
# 10         BNN_pred             0      0.758085         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.532669         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.532669         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.725262         -2.417327
# 11               __             0      0.526043         -2.417327
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.526043         -2.417327
# 1             HV_dw             0      0.526043         -2.417327
# 2             HV_cw             0      0.526043         -2.417327
# 3         LSTM_pred             0      0.526043         -2.417327
# 4          GRU_pred             0      0.526043         -2.417327
# 5     LSTM_GRU_pred             0      0.526043         -2.417327
# 6       BiLSTM_pred             0      0.526043         -2.417327
# 7   BiLSTM_GRU_pred             0      0.526043         -2.417327
# 8         QRNN_pred             0      0.526043         -2.417327
# 9          ESN_pred             0      0.526043         -2.417327
# 10         BNN_pred             0      0.526043         -2.417327
# 11               __             0      0.526043         -2.417327

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y2', file, 'HV')
get_final_results_1('2024_y2', file, 'HV')

get_final_results('2024_y2', dw_file, 'HV_dw')
get_final_results_1('2024_y2', dw_file, 'HV_dw')

get_final_results('2024_y2', cw_file, 'HV_cw')
get_final_results_1('2024_y2', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-13-a7cc282ec075>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     30.690531      0.339831         -7.217204
# 1             HV_dw     52.997878      0.270852         -7.729145
# 2             HV_cw     17.883712      0.731605         -5.463941
# 3         LSTM_pred     50.886366      0.131343         -8.485144
# 4          GRU_pred     52.412683      0.202144         -8.484837
# 5     LSTM_GRU_pred     51.633347      0.192288         -8.484837
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     10.133818      0.130824         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     76.706699      0.456697         -7.688132
# 10         BNN_pred     -5.558686      0.151734         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    100.786657      1.043940         -2.801648
# 1             HV_dw     81.476705      0.529391         -6.271406
# 2             HV_cw     40.247627     -0.100492         -5.657823
# 3         LSTM_pred     18.154242     -0.337109         -7.307041
# 4          GRU_pred     56.450567      0.202317         -8.586712
# 5     LSTM_GRU_pred     57.313827      0.213403         -8.573037
# 6       BiLSTM_pred     32.260648     -0.178790         -5.510598
# 7   BiLSTM_GRU_pred     39.712511     -0.146874         -8.028952
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     46.488590      0.077235         -7.912772
# 10         BNN_pred      6.395972     -0.456665        -10.162509
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.295037      0.384578         -1.263221
# 1             HV_dw    102.150134      0.835518         -3.891944
# 2             HV_cw    -20.406506     -1.081763         -5.657823
# 3         LSTM_pred     20.599640     -0.303891         -7.307041
# 4          GRU_pred     78.327856      0.532897         -6.501162
# 5     LSTM_GRU_pred     45.896507      0.068856         -7.861297
# 6       BiLSTM_pred     22.788288     -0.375347         -4.019581
# 7   BiLSTM_GRU_pred     35.985695     -0.060913         -8.028952
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     57.465326      0.267731         -4.786385
# 10         BNN_pred     11.965911     -0.393553        -10.022314
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.993714      0.892588         -1.579248
# 1             HV_dw     84.801809      0.572303         -6.271406
# 2             HV_cw    -16.540757     -1.151135         -6.500563
# 3         LSTM_pred     20.599640     -0.303891         -7.307041
# 4          GRU_pred     73.757921      0.432058         -6.708450
# 5     LSTM_GRU_pred     78.364118      0.492422         -6.697765
# 6       BiLSTM_pred     32.260648     -0.178790         -5.510598
# 7   BiLSTM_GRU_pred     35.985695     -0.060913         -8.028952
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     67.018018      0.390081         -6.024685
# 10         BNN_pred     15.417696     -0.337231        -10.022314
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     29.284297     -0.083361         -6.636864
# 1             HV_dw     81.476705      0.529391         -6.271406
# 2             HV_cw     50.812740      0.129847         -5.657823
# 3         LSTM_pred     31.587021     -0.288313         -7.307041
# 4          GRU_pred     56.450567      0.202317         -8.586712
# 5     LSTM_GRU_pred     57.313827      0.213403         -8.573037
# 6       BiLSTM_pred     32.260648     -0.178790         -5.510598
# 7   BiLSTM_GRU_pred     42.862566     -0.105066         -8.028952
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     54.687437      0.194320         -7.154090
# 10         BNN_pred      6.395972     -0.456665        -10.162509
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.997878      0.364493         -1.392754
# 1             HV_dw     52.997878      0.367221         -7.018341
# 2             HV_cw      7.452463     -0.518280         -5.657823
# 3         LSTM_pred     47.730540      0.092002         -8.485144
# 4          GRU_pred     83.888749      0.485976         -6.699473
# 5     LSTM_GRU_pred     73.896826      0.359506         -6.699473
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     17.644841      0.091477         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     71.416535      0.469674         -6.076435
# 10         BNN_pred      0.000000      0.228927         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.997878      1.183782         -1.336406
# 1             HV_dw     52.997878      0.270852         -7.729145
# 2             HV_cw      7.452463     -0.666029         -6.500563
# 3         LSTM_pred     47.730540      0.092002         -8.485144
# 4          GRU_pred     75.213155      0.497977         -7.099268
# 5     LSTM_GRU_pred     63.560044      0.352056         -7.099268
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     17.644841      0.091477         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     81.095256      0.568245         -7.290056
# 10         BNN_pred      1.835652      0.250173         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     30.690531      0.339831         -7.217204
# 1             HV_dw     52.997878      0.270852         -7.729145
# 2             HV_cw      7.452463      0.265504         -5.647722
# 3         LSTM_pred     50.886366      0.131343         -8.485144
# 4          GRU_pred     52.412683      0.202144         -8.484837
# 5     LSTM_GRU_pred     51.633347      0.192288         -8.484837
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     10.133818      0.130824         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     76.749100      0.457225         -7.688132
# 10         BNN_pred     -5.558686      0.151734         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.264918         -8.485144
# 4          GRU_pred             0      0.173061         -8.485144
# 5     LSTM_GRU_pred             0      0.173061         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.264918         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.228927         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.264918         -8.485144
# 4          GRU_pred             0      0.264918         -8.485144
# 5     LSTM_GRU_pred             0      0.264918         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.264918         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.264918         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.166406         -8.485144
# 5     LSTM_GRU_pred             0      0.166406         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -16.954609      0.109006         -8.655431
# 1             HV_dw     56.445444      0.202707         -7.682955
# 2             HV_cw     14.036852     -0.241299         -8.485144
# 3         LSTM_pred     48.386876      0.100003         -8.485144
# 4          GRU_pred     22.127628      0.071905         -8.603173
# 5     LSTM_GRU_pred     60.305222      0.072858         -8.528839
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     48.386876      0.100003         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     42.135403      0.020729         -9.488954
# 10         BNN_pred     -5.558686      0.151734         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     77.474036      0.567206         -2.906038
# 1             HV_dw     66.439400      0.326567         -7.682955
# 2             HV_cw     15.524879     -0.296564         -9.192980
# 3         LSTM_pred     40.443952     -0.154774         -6.306695
# 4          GRU_pred     46.288287      0.073646         -7.876931
# 5     LSTM_GRU_pred     47.013500      0.082771         -8.603173
# 6       BiLSTM_pred     32.734015     -0.196264         -5.510598
# 7   BiLSTM_GRU_pred     48.193026     -0.035122         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     76.393793      0.344300         -7.269949
# 10         BNN_pred     26.907223     -0.314734         -9.505459
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.997878      0.279115         -1.396637
# 1             HV_dw     63.255045      0.290559         -7.035518
# 2             HV_cw    -25.658257     -1.125078         -8.890511
# 3         LSTM_pred     35.086911     -0.084812         -6.306695
# 4          GRU_pred     78.245994      0.517918         -6.485286
# 5     LSTM_GRU_pred     62.827117      0.301084         -7.853231
# 6       BiLSTM_pred     32.480256     -0.269968         -4.019581
# 7   BiLSTM_GRU_pred     31.749911     -0.115165         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     86.660126      0.866054         -2.794536
# 10         BNN_pred     25.803914     -0.195045         -9.364239
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.997878      0.231661         -1.859265
# 1             HV_dw     55.663122      0.192774         -7.682955
# 2             HV_cw    -28.644782     -1.020985         -8.485144
# 3         LSTM_pred     27.447153     -0.192707         -6.306695
# 4          GRU_pred     74.284711      0.436008         -6.300042
# 5     LSTM_GRU_pred     67.438132      0.348369         -6.768915
# 6       BiLSTM_pred     32.734015     -0.196264         -5.510598
# 7   BiLSTM_GRU_pred     31.972822     -0.110066         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     63.505873      0.325246         -7.487663
# 10         BNN_pred     25.803914     -0.195045         -9.364239
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     11.211938     -0.471175         -9.657751
# 1             HV_dw     55.663122      0.192774         -7.682955
# 2             HV_cw    -14.101830     -0.776790         -8.485144
# 3         LSTM_pred     24.860408     -0.229087         -6.306695
# 4          GRU_pred     68.025992      0.351974         -7.261488
# 5     LSTM_GRU_pred     47.013500      0.082771         -8.603173
# 6       BiLSTM_pred     32.734015     -0.196264         -5.510598
# 7   BiLSTM_GRU_pred     29.374684     -0.143281         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     28.735438     -0.175698        -10.529296
# 10         BNN_pred     26.907223     -0.314734         -9.505459
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     48.501963      0.146687         -2.862087
# 1             HV_dw     64.042994      0.300543         -7.035518
# 2             HV_cw    -12.621040     -0.890079         -8.485144
# 3         LSTM_pred     47.689282      0.091477         -8.485144
# 4          GRU_pred     52.436066      0.539031         -6.469453
# 5     LSTM_GRU_pred     59.326851      0.467046         -6.693578
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     39.731871     -0.010664         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     64.549212      0.390170         -4.707463
# 10         BNN_pred      1.835652      0.250173         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     48.501963      0.116241         -2.862087
# 1             HV_dw     56.445444      0.202707         -7.682955
# 2             HV_cw    -12.621040     -0.747797         -8.485144
# 3         LSTM_pred     39.956508     -0.006840         -8.485144
# 4          GRU_pred     45.181372      0.446166         -6.284661
# 5     LSTM_GRU_pred     57.395341      0.227058         -7.163256
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     39.956508     -0.006840         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     44.511757      0.050195         -9.282564
# 10         BNN_pred      1.835652      0.250173         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -27.737456     -0.039190         -9.657373
# 1             HV_dw     56.445444      0.202707         -7.682955
# 2             HV_cw    -12.621040     -0.685209         -8.485144
# 3         LSTM_pred     39.956508     -0.006840         -8.485144
# 4          GRU_pred     44.271976      0.361995         -7.243760
# 5     LSTM_GRU_pred     60.305222      0.072858         -8.528839
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     39.956508     -0.006840         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     41.288513      0.009911         -9.562508
# 10         BNN_pred     -5.558686      0.151734         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.264918         -8.485144
# 4          GRU_pred             0      0.169755         -8.485144
# 5     LSTM_GRU_pred             0      0.173061         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.264918         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.264918         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.173061         -8.485144
# 5     LSTM_GRU_pred             0      0.264918         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.264918         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.264918         -8.485144
# 5     LSTM_GRU_pred             0      0.166406         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     51.347413     -0.009993         -4.728613
# 1             HV_dw     56.445444      0.202707         -7.682955
# 2             HV_cw      1.810507     -0.635481         -8.485144
# 3         LSTM_pred     42.179676      0.021300         -8.485144
# 4          GRU_pred     17.362842     -0.322013        -10.016782
# 5     LSTM_GRU_pred     29.417059      0.166316         -7.857700
# 6       BiLSTM_pred     32.734015     -0.196264         -5.510598
# 7   BiLSTM_GRU_pred     38.248598      0.102165         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     64.370067      0.166924         -8.485144
# 10         BNN_pred     13.075015     -0.511309         -9.462231
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     41.549966      0.005501         -8.534447
# 1             HV_dw     59.871341      0.120192         -6.439893
# 2             HV_cw    -14.214394     -0.887154         -8.485144
# 3         LSTM_pred     51.959573      0.009950         -8.241084
# 4          GRU_pred     -3.136383     -0.732347         -8.841681
# 5     LSTM_GRU_pred      2.414328     -0.543630        -10.016782
# 6       BiLSTM_pred    -11.885012     -1.002638         -7.828041
# 7   BiLSTM_GRU_pred     44.512207      0.050863         -8.028952
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     64.370067      0.166924         -8.485144
# 10         BNN_pred     20.046084     -0.337439         -7.468630
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     36.605985     -0.129138         -4.236136
# 1             HV_dw     69.869240      0.534080         -2.982694
# 2             HV_cw    -53.496178     -1.678744         -8.485144
# 3         LSTM_pred     40.565219     -0.022263         -5.640955
# 4          GRU_pred     43.596672      0.030353         -4.310938
# 5     LSTM_GRU_pred     36.901043     -0.087236         -4.597974
# 6       BiLSTM_pred      2.268033     -0.950978         -5.889618
# 7   BiLSTM_GRU_pred     18.662350     -0.308006         -7.099768
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred     -8.240872     -1.045165         -6.642765
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     22.634237     -0.419361         -4.236136
# 1             HV_dw     71.297615      0.301242         -5.096428
# 2             HV_cw    -27.756308     -1.226557         -8.485144
# 3         LSTM_pred     31.209084     -0.148927         -6.078530
# 4          GRU_pred     59.485624      0.271999         -5.953708
# 5     LSTM_GRU_pred     70.813045      0.437463         -6.433413
# 6       BiLSTM_pred     23.067064     -0.482990         -5.643780
# 7   BiLSTM_GRU_pred     32.423839     -0.107312         -8.028952
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred     16.039357     -0.467829         -7.123848
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     28.847033     -0.274069         -4.236136
# 1             HV_dw     48.705957     -0.048169         -6.439893
# 2             HV_cw    -28.415095     -1.196280         -8.485144
# 3         LSTM_pred     35.681084     -0.067715         -8.261579
# 4          GRU_pred     23.537543     -0.306190         -7.093304
# 5     LSTM_GRU_pred     86.781619      0.632075         -5.663788
# 6       BiLSTM_pred    -11.885012     -1.031039         -7.828041
# 7   BiLSTM_GRU_pred     42.261824      0.021713         -8.028952
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred      3.061747     -0.636925         -7.324231
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     54.783864      0.251390         -4.728613
# 1             HV_dw     64.042994      0.300543         -7.035518
# 2             HV_cw    -44.290732     -1.455301         -8.485144
# 3         LSTM_pred     22.420415     -0.239199         -8.485144
# 4          GRU_pred     56.401633      0.249596         -4.853215
# 5     LSTM_GRU_pred     34.931576      0.606779         -4.512391
# 6       BiLSTM_pred     26.433726     -0.387033         -4.581673
# 7   BiLSTM_GRU_pred     28.352550     -0.160543         -7.186004
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred    -15.391095     -0.833094         -9.320944
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     40.567108     -0.028615         -4.728613
# 1             HV_dw     64.042994      0.300543         -6.976125
# 2             HV_cw     -5.279215     -0.806403         -8.485144
# 3         LSTM_pred     38.799314     -0.021963         -8.485144
# 4          GRU_pred     74.751956      0.480000         -6.443676
# 5     LSTM_GRU_pred     50.233035      0.517918         -6.469453
# 6       BiLSTM_pred     64.053530      0.259413         -3.183164
# 7   BiLSTM_GRU_pred     37.716142      0.000145         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred     10.397787     -0.411936         -9.320944
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     40.567108     -0.028615         -4.728613
# 1             HV_dw     56.445444      0.202707         -7.682955
# 2             HV_cw    -12.621040     -0.915072         -8.485144
# 3         LSTM_pred     38.799314     -0.021963         -8.485144
# 4          GRU_pred     44.585284      0.050493         -8.573957
# 5     LSTM_GRU_pred     51.719331      0.529657         -6.284661
# 6       BiLSTM_pred     32.734015     -0.221066         -5.510598
# 7   BiLSTM_GRU_pred     37.716142      0.023436         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred      4.517308     -0.489882         -9.320944
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.350153         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0     -0.282088         -8.485144
# 3         LSTM_pred             0      0.264918         -8.485144
# 4          GRU_pred             0      0.269069         -8.485144
# 5     LSTM_GRU_pred             0      0.169755         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.264918         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.228927         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.264918         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.169755         -8.485144
# 5     LSTM_GRU_pred             0      0.169755         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.264918         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.173061         -8.485144
# 5     LSTM_GRU_pred             0      0.264918         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     41.549966      0.005501         -8.534447
# 1             HV_dw     82.568164      0.425000         -5.435068
# 2             HV_cw      4.347421     -0.599672         -8.485144
# 3         LSTM_pred     57.098666      0.077606         -6.306695
# 4          GRU_pred     17.362842     -0.322013        -10.016782
# 5     LSTM_GRU_pred    -34.741709     -0.143409         -9.973799
# 6       BiLSTM_pred     10.593213     -0.576867         -5.810815
# 7   BiLSTM_GRU_pred     46.957004     -0.052745         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     64.370067      0.166924         -8.485144
# 10         BNN_pred     -1.920443     -0.766396         -9.247989
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     41.549966      0.005501         -8.534447
# 1             HV_dw     46.130425     -0.088546         -6.714697
# 2             HV_cw     -8.990108     -0.832349         -8.485144
# 3         LSTM_pred     43.429817      0.034829         -8.265367
# 4          GRU_pred     -3.136383     -0.732347         -8.841681
# 5     LSTM_GRU_pred    -13.729542     -0.791813        -11.465961
# 6       BiLSTM_pred    -32.446729     -1.417060         -7.828041
# 7   BiLSTM_GRU_pred     69.666085      0.240933         -7.687376
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     64.370067      0.166924         -8.485144
# 10         BNN_pred     25.141090     -0.253973         -7.468630
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     36.605985     -0.129138         -4.236136
# 1             HV_dw     45.720167      0.071419         -2.480682
# 2             HV_cw    -54.197086     -1.691958         -8.485144
# 3         LSTM_pred     41.657285     -0.019836         -2.801501
# 4          GRU_pred     43.596672      0.030353         -4.310938
# 5     LSTM_GRU_pred     14.464798     -0.509506         -4.650774
# 6       BiLSTM_pred     -0.241810     -1.043276         -5.325206
# 7   BiLSTM_GRU_pred     12.506296     -0.401024         -7.706493
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred     11.243384     -0.746078         -4.430416
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     22.634237     -0.419361         -4.236136
# 1             HV_dw     42.457605     -0.160886         -5.426282
# 2             HV_cw    -46.267394     -1.516382         -8.485144
# 3         LSTM_pred     36.398828     -0.078397         -6.081318
# 4          GRU_pred     59.485624      0.271999         -5.953708
# 5     LSTM_GRU_pred     48.650930      0.111481         -6.433413
# 6       BiLSTM_pred    -11.050270     -1.235598         -6.373592
# 7   BiLSTM_GRU_pred     25.808884     -0.206321         -7.706493
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred     15.870460     -0.486386         -7.123848
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     22.634237     -0.419361         -4.236136
# 1             HV_dw     39.844903     -0.186399         -7.188476
# 2             HV_cw    -23.266067     -1.148174         -8.485144
# 3         LSTM_pred     32.796065     -0.133014         -6.081318
# 4          GRU_pred     23.537543     -0.306190         -7.093304
# 5     LSTM_GRU_pred     45.028615      0.056416         -8.562883
# 6       BiLSTM_pred      4.196366     -0.844676         -5.643780
# 7   BiLSTM_GRU_pred     50.607325     -0.009143         -7.687376
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred     17.565818     -0.429419         -7.123848
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     36.605985     -0.129138         -4.236136
# 1             HV_dw    114.909065      1.226745         -2.845950
# 2             HV_cw    -44.290732     -1.455301         -8.485144
# 3         LSTM_pred     42.430429      0.009740         -4.652244
# 4          GRU_pred     56.401633      0.249596         -4.853215
# 5     LSTM_GRU_pred      0.222242      0.163256         -4.628090
# 6       BiLSTM_pred     20.813826     -0.534126         -3.931215
# 7   BiLSTM_GRU_pred     31.382601     -0.273483         -7.115997
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred     10.670924     -0.540367         -5.971467
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     22.634237     -0.419361         -4.236136
# 1             HV_dw    103.723111      0.749307         -3.618634
# 2             HV_cw     -3.453038     -0.701831         -8.485144
# 3         LSTM_pred     39.228995     -0.025434         -6.306695
# 4          GRU_pred     74.751956      0.480000         -6.443676
# 5     LSTM_GRU_pred    -15.377140      0.259267         -6.485881
# 6       BiLSTM_pred     18.503775     -0.558143         -4.324535
# 7   BiLSTM_GRU_pred     27.522659     -0.310461         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred     11.594022     -0.432180         -8.452696
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     22.634237     -0.419361         -4.236136
# 1             HV_dw     83.391961      0.443696         -5.435068
# 2             HV_cw    -10.120672     -0.876666         -8.485144
# 3         LSTM_pred     31.558664     -0.133341         -6.306695
# 4          GRU_pred     44.585284      0.050493         -8.573957
# 5     LSTM_GRU_pred    -11.872827      0.188211         -8.573957
# 6       BiLSTM_pred     31.940062     -0.283413         -3.578750
# 7   BiLSTM_GRU_pred     41.847113     -0.119413         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     53.734668      0.166924         -8.485144
# 10         BNN_pred      4.134102     -0.537457         -8.452696
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.350153         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0     -0.282088         -8.485144
# 3         LSTM_pred             0      0.264918         -8.485144
# 4          GRU_pred             0      0.269069         -8.485144
# 5     LSTM_GRU_pred             0      0.169755         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.264918         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.228927         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.269069         -8.485144
# 3         LSTM_pred             0      0.264918         -8.485144
# 4          GRU_pred             0      0.169755         -8.485144
# 5     LSTM_GRU_pred             0      0.169755         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.264918         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.173061         -8.485144
# 5     LSTM_GRU_pred             0      0.173061         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.264918         -8.485144
# 11               __             0      0.166406         -8.485144

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     30.690531      0.339831         -7.217204
# 1             HV_dw     32.457981      0.504324         -7.705191
# 2             HV_cw    -10.628439     -0.306916         -8.748976
# 3         LSTM_pred      0.000000      0.166406         -8.485144
# 4          GRU_pred      0.000000      0.166406         -8.485144
# 5     LSTM_GRU_pred     61.090984      0.082640         -8.528839
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred      0.000000      0.166406         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      6.933382     -0.336717         -8.485144
# 10         BNN_pred     48.505659      0.000657         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    100.786657      1.043940         -2.801648
# 1             HV_dw     88.343246      0.622725         -6.335067
# 2             HV_cw     49.975198      0.111994         -6.242866
# 3         LSTM_pred    -14.357105     -0.354063         -9.030719
# 4          GRU_pred     21.817663     -0.247522         -8.559514
# 5     LSTM_GRU_pred     49.670097      0.123011         -5.706103
# 6       BiLSTM_pred     32.260648     -0.178790         -5.510598
# 7   BiLSTM_GRU_pred     32.994295      0.314854         -4.960019
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     44.841771     -0.079658         -8.469975
# 10         BNN_pred     78.936102      0.405709         -4.811390
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.295037      0.384578         -1.263221
# 1             HV_dw     98.862594      0.844392         -4.643589
# 2             HV_cw     -8.780802     -0.961017         -4.779978
# 3         LSTM_pred     -3.324894     -0.494177         -8.485144
# 4          GRU_pred      7.804058     -0.455501         -8.406431
# 5     LSTM_GRU_pred     48.681404      0.112704         -4.239639
# 6       BiLSTM_pred     22.788288     -0.375347         -4.019581
# 7   BiLSTM_GRU_pred     33.213236      0.008450         -4.581673
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred    -10.586673     -0.936529         -8.485144
# 10         BNN_pred     59.316835      0.190207         -4.811390
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.993714      0.892588         -1.579248
# 1             HV_dw     92.139777      0.675838         -6.335067
# 2             HV_cw     -2.994718     -0.912288         -6.686452
# 3         LSTM_pred    -14.357105     -0.354063         -9.030719
# 4          GRU_pred     15.330336     -0.335554         -8.860751
# 5     LSTM_GRU_pred     43.005940      0.026999         -6.034990
# 6       BiLSTM_pred     32.260648     -0.178790         -5.510598
# 7   BiLSTM_GRU_pred     57.245595      0.666390         -3.862942
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred    -20.201905     -1.061444         -8.485144
# 10         BNN_pred     78.936102      0.405709         -4.811390
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     29.284297     -0.083361         -6.636864
# 1             HV_dw     96.435808      0.730105         -6.335067
# 2             HV_cw     -4.834830     -0.910596         -6.329527
# 3         LSTM_pred    -14.357105     -0.354063         -9.030719
# 4          GRU_pred     21.817663     -0.247522         -8.559514
# 5     LSTM_GRU_pred     43.005940      0.026999         -6.034990
# 6       BiLSTM_pred     32.260648     -0.178790         -5.510598
# 7   BiLSTM_GRU_pred     32.994295      0.314854         -4.960019
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     14.637364     -0.505908         -8.485144
# 10         BNN_pred     78.936102      0.405709         -4.811390
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.997878      0.364493         -1.392754
# 1             HV_dw     17.426834      0.322370         -7.764192
# 2             HV_cw     21.346663     -0.278159         -6.106159
# 3         LSTM_pred      0.000000      0.166406         -8.485144
# 4          GRU_pred      0.000000      0.264918         -8.485144
# 5     LSTM_GRU_pred     68.980907      0.372990         -7.163256
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred      0.000000      0.166406         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred    -18.335296     -0.967360         -8.557715
# 10         BNN_pred     34.673866     -0.137053         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.997878      1.183782         -1.336406
# 1             HV_dw     40.134998      0.607032         -7.705191
# 2             HV_cw     28.915912     -0.277466         -6.083873
# 3         LSTM_pred      0.000000      0.166406         -8.485144
# 4          GRU_pred      0.000000      0.166406         -8.485144
# 5     LSTM_GRU_pred     61.090984      0.082640         -8.528839
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred      0.000000      0.166406         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred    -14.114732     -0.915974         -8.485144
# 10         BNN_pred     48.505659      0.000657         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     30.690531      0.339831         -7.217204
# 1             HV_dw     40.134998      0.607032         -7.705191
# 2             HV_cw     -3.556140     -0.209277         -8.092734
# 3         LSTM_pred      0.000000      0.166406         -8.485144
# 4          GRU_pred      0.000000      0.166406         -8.485144
# 5     LSTM_GRU_pred     61.090984      0.082640         -8.528839
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred      0.000000      0.166406         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      5.352535     -0.386385         -8.485144
# 10         BNN_pred     48.505659      0.000657         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.264918         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.264918         -8.485144
# 5     LSTM_GRU_pred             0      0.264918         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.269069         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.264918         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.166406         -8.485144
# 5     LSTM_GRU_pred             0      0.166406         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.173061         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.264918         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.166406         -8.485144
# 5     LSTM_GRU_pred             0      0.166406         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -16.954609      0.109006         -8.655431
# 1             HV_dw     15.280463      0.280129         -7.705191
# 2             HV_cw     17.824037     -0.395833         -7.611175
# 3         LSTM_pred      0.000000      0.166406         -8.485144
# 4          GRU_pred     61.090984      0.082640         -8.528839
# 5     LSTM_GRU_pred     61.090984      0.082640         -8.528839
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     -0.182726      0.264731         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     48.850956      0.157077         -8.469611
# 10         BNN_pred     48.505659      0.000657         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     77.474036      0.567206         -2.906038
# 1             HV_dw     65.326845      0.319283         -7.706922
# 2             HV_cw     52.314839      0.010312         -7.700587
# 3         LSTM_pred     11.712861     -0.468048         -8.314064
# 4          GRU_pred     40.490888      0.000225         -8.559514
# 5     LSTM_GRU_pred     41.240024     -0.007144         -4.527084
# 6       BiLSTM_pred     32.734015     -0.196264         -5.510598
# 7   BiLSTM_GRU_pred      3.698147     -0.131828         -7.124640
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     -1.554260     -0.754994         -8.485144
# 10         BNN_pred     69.836796      0.277924         -6.649942
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.997878      0.279115         -1.396637
# 1             HV_dw     50.242953      0.129657         -7.764192
# 2             HV_cw     41.214576     -0.239552         -3.181323
# 3         LSTM_pred     18.421446     -0.275394         -6.794612
# 4          GRU_pred     61.549547      0.270970         -7.030697
# 5     LSTM_GRU_pred     51.751835      0.174770         -3.182365
# 6       BiLSTM_pred     32.480256     -0.269968         -4.019581
# 7   BiLSTM_GRU_pred     12.584199     -0.349726         -5.835194
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     -6.617472     -0.916863         -7.192565
# 10         BNN_pred     50.382991      0.066393         -6.649942
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.997878      0.231661         -1.859265
# 1             HV_dw     62.914309      0.291636         -7.764192
# 2             HV_cw     27.392804     -0.469728         -4.779978
# 3         LSTM_pred     11.712861     -0.468048         -8.314064
# 4          GRU_pred     33.885008     -0.084463         -8.860751
# 5     LSTM_GRU_pred     46.685989      0.084861         -3.254053
# 6       BiLSTM_pred     32.734015     -0.196264         -5.510598
# 7   BiLSTM_GRU_pred     -1.916571     -0.289716         -7.842998
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     -8.233537     -0.888500         -8.485144
# 10         BNN_pred     69.836796      0.277924         -6.649942
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     11.211938     -0.471175         -9.657751
# 1             HV_dw     65.326845      0.319283         -7.706922
# 2             HV_cw     34.070161     -0.319163         -5.578679
# 3         LSTM_pred     11.712861     -0.468048         -8.314064
# 4          GRU_pred     33.885008     -0.084463         -8.860751
# 5     LSTM_GRU_pred     41.240024     -0.007144         -4.527084
# 6       BiLSTM_pred     32.734015     -0.196264         -5.510598
# 7   BiLSTM_GRU_pred      3.698147     -0.131828         -7.124640
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     13.770243     -0.532637         -8.485144
# 10         BNN_pred     69.836796      0.277924         -6.649942
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     48.501963      0.146687         -2.862087
# 1             HV_dw      8.630596      0.200007         -7.764192
# 2             HV_cw     47.631026      0.020501         -4.347895
# 3         LSTM_pred      0.000000      0.166406         -8.485144
# 4          GRU_pred     68.980907      0.372990         -7.163256
# 5     LSTM_GRU_pred     68.980907      0.372990         -7.163256
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     -0.182726      0.065102         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      5.888647     -0.625010         -7.426990
# 10         BNN_pred     34.673866     -0.137053         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     48.501963      0.116241         -2.862087
# 1             HV_dw     22.829754      0.382247         -7.705191
# 2             HV_cw     28.373619     -0.151248         -6.106159
# 3         LSTM_pred      0.000000      0.166406         -8.485144
# 4          GRU_pred     61.090984      0.082640         -8.528839
# 5     LSTM_GRU_pred     61.090984      0.271596         -7.163256
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     -0.182726      0.344999         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      3.771852     -0.597671         -8.485144
# 10         BNN_pred     48.505659      0.000657         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -27.737456     -0.039190         -9.657373
# 1             HV_dw     15.280463      0.280129         -7.705191
# 2             HV_cw     26.033980     -0.276092         -6.319775
# 3         LSTM_pred      0.000000      0.166406         -8.485144
# 4          GRU_pred     61.090984      0.082640         -8.528839
# 5     LSTM_GRU_pred     61.090984      0.082640         -8.528839
# 6       BiLSTM_pred      0.000000      0.166406         -8.485144
# 7   BiLSTM_GRU_pred     -0.182726      0.264731         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     31.262277     -0.074311         -8.485144
# 10         BNN_pred     48.505659      0.000657         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.264918         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.264918         -8.485144
# 5     LSTM_GRU_pred             0      0.264918         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.208696         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.264918         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.166406         -8.485144
# 5     LSTM_GRU_pred             0      0.166406         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.169755         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.166406         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.166406         -8.485144
# 5     LSTM_GRU_pred             0      0.166406         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.264918         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     51.347413     -0.009993         -4.728613
# 1             HV_dw     52.851408      0.159149         -7.764192
# 2             HV_cw     26.623918     -0.394475         -6.597365
# 3         LSTM_pred     16.099761     -0.403290         -8.314064
# 4          GRU_pred     18.610411     -0.391461         -4.481478
# 5     LSTM_GRU_pred     10.758053     -0.472386         -5.779497
# 6       BiLSTM_pred     32.734015     -0.196264         -5.510598
# 7   BiLSTM_GRU_pred    -18.107077     -0.415119         -9.192980
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     74.222084      0.478963         -5.223683
# 10         BNN_pred     22.766768     -0.231996         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     41.549966      0.005501         -8.534447
# 1             HV_dw     78.685435      0.363434         -6.354807
# 2             HV_cw     35.902509     -0.243844         -5.972181
# 3         LSTM_pred      3.604666     -0.727258         -6.324071
# 4          GRU_pred      2.094723     -0.632857         -7.104164
# 5     LSTM_GRU_pred     42.062506      0.001215         -3.152101
# 6       BiLSTM_pred    -11.885012     -1.002638         -7.828041
# 7   BiLSTM_GRU_pred     31.682994     -0.238856         -5.762264
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      8.479711     -0.899289         -3.521232
# 10         BNN_pred     75.460754      0.355839         -4.138990
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     36.605985     -0.129138         -4.236136
# 1             HV_dw     88.364634      0.593505         -3.625419
# 2             HV_cw     45.268985      0.094533         -0.862228
# 3         LSTM_pred     55.664248      0.335783         -2.303657
# 4          GRU_pred     29.272564     -0.234488         -3.412743
# 5     LSTM_GRU_pred     20.563436     -0.490124         -4.106938
# 6       BiLSTM_pred      2.268033     -0.950978         -5.889618
# 7   BiLSTM_GRU_pred     23.491106     -0.434814         -2.549502
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred      6.211634     -0.676811         -4.325192
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     22.634237     -0.419361         -4.236136
# 1             HV_dw     81.352983      0.408677         -6.396666
# 2             HV_cw     69.698235      0.775000         -1.252485
# 3         LSTM_pred     15.658099     -0.659171         -5.889618
# 4          GRU_pred      5.036356     -0.652919         -5.247819
# 5     LSTM_GRU_pred      4.835664     -0.824852         -4.106815
# 6       BiLSTM_pred     23.067064     -0.482990         -5.643780
# 7   BiLSTM_GRU_pred     27.022938     -0.430918         -4.587221
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred     60.005371      0.286047         -4.138990
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     28.847033     -0.274069         -4.236136
# 1             HV_dw     69.572143      0.246425         -6.456608
# 2             HV_cw     31.628467     -0.217591         -3.755095
# 3         LSTM_pred     13.042840     -0.577912         -6.324071
# 4          GRU_pred      1.280372     -0.646257         -7.179656
# 5     LSTM_GRU_pred    -11.488385     -1.077681         -5.417484
# 6       BiLSTM_pred    -11.885012     -1.031039         -7.828041
# 7   BiLSTM_GRU_pred     21.812625     -0.398932         -6.491160
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     34.679110     -0.207406         -1.832148
# 10         BNN_pred     76.085972      0.365887         -4.138990
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     54.783864      0.251390         -4.728613
# 1             HV_dw     32.283940     -0.134619         -8.092734
# 2             HV_cw     15.352478     -0.921192         -2.862087
# 3         LSTM_pred     14.666459     -0.426685         -6.794612
# 4          GRU_pred     35.708688     -0.109345         -3.176751
# 5     LSTM_GRU_pred     31.961643     -0.156533         -3.514561
# 6       BiLSTM_pred     26.433726     -0.387033         -4.581673
# 7   BiLSTM_GRU_pred    -22.243757     -0.978039         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred     -2.386255     -0.599206         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     40.567108     -0.028615         -4.728613
# 1             HV_dw     72.184815      0.414206         -7.750985
# 2             HV_cw     41.784570     -0.018875         -2.862087
# 3         LSTM_pred     -0.847152     -0.709436         -8.314064
# 4          GRU_pred     11.320929     -0.520757         -4.873516
# 5     LSTM_GRU_pred     21.310426     -0.327277         -3.972389
# 6       BiLSTM_pred     64.053530      0.259413         -3.183164
# 7   BiLSTM_GRU_pred     -9.716518     -0.605849         -8.485144
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred      7.345773     -0.445012         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     40.567108     -0.028615         -4.728613
# 1             HV_dw     60.680065      0.262063         -7.764192
# 2             HV_cw     10.563538     -0.617646         -5.773193
# 3         LSTM_pred     14.575048     -0.447354         -8.314064
# 4          GRU_pred     11.320929     -0.520757         -4.873516
# 5     LSTM_GRU_pred     10.758053     -0.472386         -5.779497
# 6       BiLSTM_pred     32.734015     -0.221066         -5.510598
# 7   BiLSTM_GRU_pred     -9.445003     -0.348656         -9.192980
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     71.993340      0.632285         -1.347359
# 10         BNN_pred     26.002500     -0.189796         -8.485144
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.350153         -8.485144
# 1             HV_dw             0      0.269069         -8.485144
# 2             HV_cw             0     -0.269429         -8.485144
# 3         LSTM_pred             0      0.032299         -8.485144
# 4          GRU_pred             0      0.264918         -8.485144
# 5     LSTM_GRU_pred             0      0.264918         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0          -inf          0.000000
# 10         BNN_pred             0      0.173061         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.264918         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.166406         -8.485144
# 5     LSTM_GRU_pred             0      0.264918         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0          -inf          0.000000
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.264918         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.166406         -8.485144
# 5     LSTM_GRU_pred             0      0.166406         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.166406         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     41.549966      0.005501         -8.534447
# 1             HV_dw     61.152706      0.265972         -7.706922
# 2             HV_cw     66.678722      0.254860         -2.926842
# 3         LSTM_pred    -10.638140     -0.819404         -8.314064
# 4          GRU_pred     18.610411     -0.391461         -4.481478
# 5     LSTM_GRU_pred     30.850005     -0.184704         -4.527084
# 6       BiLSTM_pred     10.593213     -0.576867         -5.810815
# 7   BiLSTM_GRU_pred     20.291171     -0.416634         -6.498864
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     -9.556473     -1.051855         -3.531717
# 10         BNN_pred     25.966330     -0.208155         -6.663166
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     41.549966      0.005501         -8.534447
# 1             HV_dw     83.059320      0.420379         -6.356378
# 2             HV_cw     19.904141     -0.506075         -5.972181
# 3         LSTM_pred     -5.193466     -0.890251         -6.324071
# 4          GRU_pred     34.173307     -0.119520         -4.754648
# 5     LSTM_GRU_pred     28.194735     -0.361272         -5.878916
# 6       BiLSTM_pred    -32.446729     -1.417060         -7.828041
# 7   BiLSTM_GRU_pred     39.103058     -0.212312         -5.762264
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      8.479711     -0.899289         -3.521232
# 10         BNN_pred     62.150388      0.156793         -4.139168
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     36.605985     -0.129138         -4.236136
# 1             HV_dw     77.249861      0.415344         -3.631203
# 2             HV_cw     38.126582     -0.284309         -0.393724
# 3         LSTM_pred     21.497570     -0.616486         -2.303657
# 4          GRU_pred     33.062915     -0.168200         -3.162804
# 5     LSTM_GRU_pred     32.235004     -0.553388         -2.311236
# 6       BiLSTM_pred     -0.241810     -1.043276         -5.325206
# 7   BiLSTM_GRU_pred     12.077072     -1.141399         -2.570685
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred      6.211634     -0.676811         -4.325192
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     22.634237     -0.419361         -4.236136
# 1             HV_dw     70.070362      0.276914         -5.500584
# 2             HV_cw     56.040118      0.464133         -1.260790
# 3         LSTM_pred     22.839458     -0.558999         -4.407733
# 4          GRU_pred     35.729100     -0.117698         -3.162804
# 5     LSTM_GRU_pred     30.971305     -0.536663         -2.311236
# 6       BiLSTM_pred    -11.050270     -1.235598         -6.373592
# 7   BiLSTM_GRU_pred     46.840046     -0.123702         -3.246145
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred     41.725281      0.004223         -4.139168
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     22.634237     -0.419361         -4.236136
# 1             HV_dw     67.675716      0.221467         -6.466907
# 2             HV_cw     55.324551      0.382254         -1.269544
# 3         LSTM_pred     20.859695     -0.452411         -6.324071
# 4          GRU_pred      7.450000     -0.543382         -6.622980
# 5     LSTM_GRU_pred     31.902797     -0.481527         -2.132913
# 6       BiLSTM_pred      4.196366     -0.844676         -5.643780
# 7   BiLSTM_GRU_pred     44.502146     -0.151847         -4.407733
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     33.388050     -0.355179         -0.019335
# 10         BNN_pred     61.173128      0.142075         -4.139168
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     36.605985     -0.129138         -4.236136
# 1             HV_dw     27.168828     -0.223501         -6.794612
# 2             HV_cw     30.710956     -0.439083         -1.392754
# 3         LSTM_pred     18.360423     -0.427190         -6.083873
# 4          GRU_pred     35.708688     -0.109345         -3.176751
# 5     LSTM_GRU_pred     52.131709      0.191530         -3.182365
# 6       BiLSTM_pred     20.813826     -0.534126         -3.931215
# 7   BiLSTM_GRU_pred    -12.187820     -1.474833         -4.022465
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred    -24.744177     -1.086485         -6.771430
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     22.634237     -0.419361         -4.236136
# 1             HV_dw     32.478423     -0.128436         -7.100868
# 2             HV_cw     65.406406      0.593994         -1.392754
# 3         LSTM_pred     17.675997     -0.449005         -6.794612
# 4          GRU_pred     38.381701     -0.061600         -3.176751
# 5     LSTM_GRU_pred     50.843652      0.161818         -3.182365
# 6       BiLSTM_pred     18.503775     -0.558143         -4.324535
# 7   BiLSTM_GRU_pred     45.341710     -0.063129         -3.991179
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred     11.914788     -0.410904         -6.663166
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     22.634237     -0.419361         -4.236136
# 1             HV_dw     58.749622      0.237495         -7.764192
# 2             HV_cw     57.542866      0.382280         -1.392754
# 3         LSTM_pred     15.272428     -0.452866         -8.314064
# 4          GRU_pred     11.320929     -0.520757         -4.873516
# 5     LSTM_GRU_pred     50.839650      0.157950         -3.254053
# 6       BiLSTM_pred     31.940062     -0.283413         -3.578750
# 7   BiLSTM_GRU_pred     43.007156     -0.096155         -5.023441
# 8         QRNN_pred      8.479711     -0.899289         -3.521232
# 9          ESN_pred     24.251616     -0.663790         -0.761937
# 10         BNN_pred     27.667796     -0.184658         -6.663166
# 11               __      0.000000      0.166406         -8.485144
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.350153         -8.485144
# 1             HV_dw             0      0.269069         -8.485144
# 2             HV_cw             0     -0.269429         -8.485144
# 3         LSTM_pred             0      0.032299         -8.485144
# 4          GRU_pred             0      0.264918         -8.485144
# 5     LSTM_GRU_pred             0      0.264918         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0          -inf          0.000000
# 10         BNN_pred             0      0.173061         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.173061         -8.485144
# 2             HV_cw             0      0.264918         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.264918         -8.485144
# 5     LSTM_GRU_pred             0      0.264918         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0          -inf          0.000000
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.166406         -8.485144
# 1             HV_dw             0      0.264918         -8.485144
# 2             HV_cw             0      0.166406         -8.485144
# 3         LSTM_pred             0      0.166406         -8.485144
# 4          GRU_pred             0      0.166406         -8.485144
# 5     LSTM_GRU_pred             0      0.166406         -8.485144
# 6       BiLSTM_pred             0      0.166406         -8.485144
# 7   BiLSTM_GRU_pred             0      0.166406         -8.485144
# 8         QRNN_pred             0      0.166406         -8.485144
# 9          ESN_pred             0      0.049574         -8.485144
# 10         BNN_pred             0      0.166406         -8.485144
# 11               __             0      0.166406         -8.485144

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_2y)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_2y)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_2y', file, 'HV')
get_final_results_1('2022_2y', file, 'HV')

get_final_results('2022_2y', dw_file, 'HV_dw')
get_final_results_1('2022_2y', dw_file, 'HV_dw')

get_final_results('2022_2y', cw_file, 'HV_cw')
get_final_results_1('2022_2y', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.564692     -0.852420        -12.835189
# 1             HV_dw    -95.006225     -1.009037        -14.950875
# 2             HV_cw    -70.932815     -0.834010        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -74.118887     -0.869320        -13.677670
# 5     LSTM_GRU_pred    -72.806978     -0.842533        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred   -101.981111     -1.044706        -14.847242
# 9          ESN_pred    -70.819447     -0.830716        -13.048098
# 10         BNN_pred    -45.558342     -0.689394        -11.976687
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -140.706559     -1.453730        -16.033104
# 1             HV_dw   -114.079828     -1.174967        -14.603473
# 2             HV_cw    -23.950885     -0.595782         -8.671922
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred    -95.994014     -1.060874        -13.026481
# 5     LSTM_GRU_pred    -70.006089     -0.920639        -12.732441
# 6       BiLSTM_pred    -59.173544     -0.812064        -12.961906
# 7   BiLSTM_GRU_pred    -90.626559     -1.040622        -15.725371
# 8         QRNN_pred    -31.444410     -0.737634        -11.669964
# 9          ESN_pred    -17.456151     -0.587017        -11.765078
# 10         BNN_pred    -84.551903     -0.969664        -14.282209
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -74.139594     -1.511378        -12.874064
# 1             HV_dw   -104.005914     -1.134732        -15.167909
# 2             HV_cw    -42.466758     -0.881404         -8.457767
# 3         LSTM_pred    -49.064513     -0.712170        -11.756427
# 4          GRU_pred    -74.612586     -1.004515        -11.215986
# 5     LSTM_GRU_pred    -72.088898     -1.036435        -10.640655
# 6       BiLSTM_pred    -55.460514     -0.833930        -11.838747
# 7   BiLSTM_GRU_pred   -104.340784     -1.173096        -14.261232
# 8         QRNN_pred    -74.126145     -1.517324        -13.008483
# 9          ESN_pred    -79.003809     -1.076653        -11.656351
# 10         BNN_pred   -101.444725     -1.208127        -15.774188
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -102.655005     -1.444015        -14.959647
# 1             HV_dw   -112.967861     -1.173882        -14.372501
# 2             HV_cw    -41.077973     -0.762801         -6.718681
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred   -127.713985     -1.292088        -15.416300
# 5     LSTM_GRU_pred    -67.580076     -0.938834        -12.393218
# 6       BiLSTM_pred    -90.050844     -1.029329        -14.337458
# 7   BiLSTM_GRU_pred   -100.803155     -1.115328        -15.883250
# 8         QRNN_pred    -59.535263     -1.263912        -13.907900
# 9          ESN_pred    -42.678265     -0.791051        -10.596974
# 10         BNN_pred    -92.073811     -1.031206        -14.237187
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -164.398777     -1.636977        -17.898949
# 1             HV_dw   -107.600331     -1.135411        -14.372501
# 2             HV_cw    -21.542321     -0.579699         -8.671922
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred    -95.994014     -1.060874        -13.026481
# 5     LSTM_GRU_pred    -70.006089     -0.920639        -12.732441
# 6       BiLSTM_pred    -59.173544     -0.812064        -12.961906
# 7   BiLSTM_GRU_pred    -90.626559     -1.040622        -15.725371
# 8         QRNN_pred    -76.870741     -1.063959        -13.117911
# 9          ESN_pred    -53.032494     -0.824757        -10.596974
# 10         BNN_pred    -84.551903     -0.969664        -14.282209
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.719517     -1.325596        -13.819716
# 1             HV_dw    -84.211225     -0.948956        -14.950875
# 2             HV_cw    -67.558648     -0.827001        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -34.571760     -0.681864         -9.981319
# 5     LSTM_GRU_pred   -100.019571     -1.015033        -13.048098
# 6       BiLSTM_pred    -69.795824     -0.824033        -13.048098
# 7   BiLSTM_GRU_pred    -66.418375     -0.805155        -13.048098
# 8         QRNN_pred    -74.126145     -1.517324        -13.008483
# 9          ESN_pred    -64.583523     -0.826240        -11.756427
# 10         BNN_pred    -45.558342     -0.689394        -11.976687
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -43.827141     -0.778209        -11.905617
# 1             HV_dw   -101.792985     -1.054280        -14.950875
# 2             HV_cw    -83.249316     -0.919242        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -97.511495     -1.023464        -13.677670
# 5     LSTM_GRU_pred    -72.806978     -0.842533        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -13.572847     -0.723812        -11.878350
# 9          ESN_pred    -53.961514     -0.758368        -11.756427
# 10         BNN_pred    -45.558342     -0.689394        -11.976687
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -55.658744     -0.756085        -12.835189
# 1             HV_dw    -96.357835     -1.017638        -14.950875
# 2             HV_cw    -74.801940     -0.857657        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -74.118887     -0.869320        -13.677670
# 5     LSTM_GRU_pred    -72.806978     -0.842533        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -72.526146     -0.891815        -11.832793
# 9          ESN_pred    -76.704581     -0.867056        -13.308063
# 10         BNN_pred    -45.558342     -0.689394        -11.976687
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -66.418375     -0.805155        -13.048098
# 2             HV_cw    -64.027159     -0.796764        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -69.795824     -0.824033        -13.048098
# 6       BiLSTM_pred    -69.795824     -0.824033        -13.048098
# 7   BiLSTM_GRU_pred    -66.418375     -0.805155        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -71.856412     -0.836417        -13.048098
# 2             HV_cw    -75.532718     -0.863035        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -71.856412     -0.836417        -13.048098
# 2             HV_cw    -68.404484     -0.815721        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -59.253821     -0.785427        -14.083845
# 1             HV_dw    -65.432490     -0.800811        -13.048098
# 2             HV_cw    -77.534331     -0.874780        -13.363459
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -56.770909     -0.759333        -11.452325
# 5     LSTM_GRU_pred    -74.399295     -0.856524        -13.048098
# 6       BiLSTM_pred    -49.039009     -0.713018        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -77.510017     -0.927763        -14.091488
# 9          ESN_pred    -51.352315     -0.743554        -11.850116
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -143.370398     -1.514392        -16.457434
# 1             HV_dw   -108.333908     -1.130629        -14.701362
# 2             HV_cw    -38.848345     -0.663376         -9.600103
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred    -87.681239     -1.008889        -12.904553
# 5     LSTM_GRU_pred   -150.700117     -1.442760        -17.087479
# 6       BiLSTM_pred    -56.234653     -0.788642        -13.045791
# 7   BiLSTM_GRU_pred    -85.077190     -1.008087        -15.891718
# 8         QRNN_pred     -3.564082     -0.559230         -9.975598
# 9          ESN_pred    -97.856861     -1.039655        -12.114406
# 10         BNN_pred    -50.040417     -0.742685        -12.149064
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -70.077811     -1.768699        -11.578549
# 1             HV_dw    -54.196005     -0.838379         -9.799737
# 2             HV_cw    -30.422819     -0.660612         -9.122794
# 3         LSTM_pred    -49.064513     -0.712170        -11.756427
# 4          GRU_pred    -94.509460     -1.149004        -13.587001
# 5     LSTM_GRU_pred    -34.957778     -0.765648         -9.066797
# 6       BiLSTM_pred    -75.451167     -0.996460        -14.258246
# 7   BiLSTM_GRU_pred    -89.046281     -1.086247        -14.512368
# 8         QRNN_pred    -87.007893     -1.537498        -12.894945
# 9          ESN_pred    -75.974059     -1.001364        -10.809721
# 10         BNN_pred    -91.802422     -1.094274        -13.537523
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -108.291535     -1.711586        -14.340273
# 1             HV_dw   -115.020720     -1.177682        -14.701362
# 2             HV_cw    -12.567162     -0.531671         -9.122794
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred    -53.268152     -0.833374         -9.815368
# 5     LSTM_GRU_pred   -129.160431     -1.319579        -14.422093
# 6       BiLSTM_pred    -82.219674     -1.000869        -15.305127
# 7   BiLSTM_GRU_pred    -94.328058     -1.103239        -15.835161
# 8         QRNN_pred    -60.825322     -1.200222        -12.005385
# 9          ESN_pred    -69.283823     -0.930273        -11.192509
# 10         BNN_pred    -66.757494     -0.858935        -12.728836
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -130.928005     -1.463884        -15.470842
# 1             HV_dw   -109.665613     -1.139522        -14.701362
# 2             HV_cw    -37.607831     -0.659817         -9.450426
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred    -87.681239     -1.008889        -12.904553
# 5     LSTM_GRU_pred   -120.740801     -1.227080        -15.995694
# 6       BiLSTM_pred    -36.616199     -0.680509        -13.045791
# 7   BiLSTM_GRU_pred    -85.077190     -1.008087        -15.891718
# 8         QRNN_pred   -116.010722     -1.391095        -14.435564
# 9          ESN_pred    -41.178095     -0.714012        -10.670223
# 10         BNN_pred    -50.040417     -0.742685        -12.149064
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -31.873392     -1.210629        -10.411368
# 1             HV_dw    -64.118057     -0.813621        -13.048098
# 2             HV_cw    -16.638513     -0.572105         -9.122794
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -46.398360     -0.750867         -9.905566
# 5     LSTM_GRU_pred    -98.924795     -1.050786        -13.048098
# 6       BiLSTM_pred    -51.946941     -0.730263        -13.048098
# 7   BiLSTM_GRU_pred    -66.418375     -0.805155        -13.048098
# 8         QRNN_pred    -90.052907     -1.554158        -13.630858
# 9          ESN_pred    -64.931463     -0.888458        -10.613105
# 10         BNN_pred    -69.795824     -0.824033        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -50.478408     -1.023711        -10.553998
# 1             HV_dw    -62.524007     -0.784026        -13.048098
# 2             HV_cw      1.470995     -0.446486         -9.122794
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -21.191870     -0.580968         -9.333477
# 5     LSTM_GRU_pred    -97.270740     -1.010552        -13.048098
# 6       BiLSTM_pred    -50.459271     -0.721431        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -86.882375     -1.399120        -12.748813
# 9          ESN_pred    -64.238537     -0.872209        -10.653015
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -55.202497     -0.772763        -14.885835
# 1             HV_dw    -66.828269     -0.809146        -13.048098
# 2             HV_cw    -43.250466     -0.687872        -10.465251
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -56.770909     -0.759333        -11.452325
# 5     LSTM_GRU_pred    -76.200091     -0.867449        -13.048098
# 6       BiLSTM_pred    -49.039009     -0.713018        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -87.651199     -1.045403        -13.258177
# 9          ESN_pred    -18.975026     -0.566589        -10.596974
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -77.292733     -0.872933        -13.048098
# 2             HV_cw    -67.200925     -0.818988        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -69.795824     -0.824033        -13.048098
# 7   BiLSTM_GRU_pred    -66.418375     -0.805155        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -74.569229     -0.855969        -13.048098
# 10         BNN_pred    -69.795824     -0.824033        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -71.856412     -0.836417        -13.048098
# 2             HV_cw    -71.255283     -0.838067        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -69.795824     -0.824033        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -71.856412     -0.836417        -13.048098
# 2             HV_cw    -66.418375     -0.805155        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw   -140.830594     -1.374111        -16.983180
# 2             HV_cw    -63.441032     -0.787084        -13.048098
# 3         LSTM_pred    -97.092332     -1.063779        -13.810056
# 4          GRU_pred   -106.626033     -1.117065        -14.713138
# 5     LSTM_GRU_pred    -42.084510     -0.680357         -9.711490
# 6       BiLSTM_pred    -81.953000     -0.945929        -15.609677
# 7   BiLSTM_GRU_pred    -82.921600     -0.919964        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -76.317243     -0.913450        -10.915741
# 10         BNN_pred    -70.673531     -0.887099        -13.888416
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -42.840256     -0.773978        -10.252592
# 1             HV_dw   -130.634180     -1.407730        -15.359991
# 2             HV_cw    -86.012862     -0.992507        -12.212898
# 3         LSTM_pred    -79.259374     -1.166765        -10.918359
# 4          GRU_pred   -134.487175     -1.472373        -15.312492
# 5     LSTM_GRU_pred    -92.644685     -1.056924        -14.325427
# 6       BiLSTM_pred   -106.245604     -1.206144        -14.300901
# 7   BiLSTM_GRU_pred    -61.421078     -0.884986        -14.650025
# 8         QRNN_pred    -38.873703     -0.693491        -11.339676
# 9          ESN_pred   -120.512951     -1.386038        -14.756283
# 10         BNN_pred    -21.947151     -0.668083         -8.802276
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     19.754358     -0.559201         -5.018872
# 1             HV_dw    -12.709619     -0.815662         -5.626705
# 2             HV_cw    -11.432008     -0.597067        -10.068404
# 3         LSTM_pred   -135.809329     -2.054333        -14.297063
# 4          GRU_pred   -116.306329     -1.731490        -15.274959
# 5     LSTM_GRU_pred     -5.569918     -0.660976         -6.706458
# 6       BiLSTM_pred   -131.944306     -1.652565        -14.664844
# 7   BiLSTM_GRU_pred    -52.126569     -1.064680        -10.620052
# 8         QRNN_pred      5.480551     -0.491451         -9.799737
# 9          ESN_pred    -18.127798     -2.284617         -2.308395
# 10         BNN_pred    -73.291853     -1.430867        -12.853682
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -47.395852     -0.911530        -12.492417
# 1             HV_dw    -82.740699     -1.156133        -12.733931
# 2             HV_cw     11.126239     -0.427493         -9.122794
# 3         LSTM_pred   -116.701328     -1.515331        -12.402097
# 4          GRU_pred   -131.303715     -1.686765        -17.863768
# 5     LSTM_GRU_pred    -49.051158     -0.886043        -10.061411
# 6       BiLSTM_pred   -119.511145     -1.429346        -15.247490
# 7   BiLSTM_GRU_pred    -84.563897     -1.194349        -14.306302
# 8         QRNN_pred      5.480551     -0.491451         -9.799737
# 9          ESN_pred    -95.860122     -1.493544        -12.815491
# 10         BNN_pred    -91.361077     -1.428024        -14.267511
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -42.840256     -0.773978        -10.252592
# 1             HV_dw   -120.913395     -1.348442        -14.493827
# 2             HV_cw    -81.143226     -0.962003        -12.212898
# 3         LSTM_pred    -95.052100     -1.310761        -11.814596
# 4          GRU_pred   -155.656387     -1.661870        -17.383828
# 5     LSTM_GRU_pred    -51.562603     -0.821134         -9.692033
# 6       BiLSTM_pred   -115.702267     -1.332167        -14.491166
# 7   BiLSTM_GRU_pred    -64.400033     -0.906188        -14.674953
# 8         QRNN_pred    -38.873703     -0.693491        -11.339676
# 9          ESN_pred    -95.030034     -1.296448        -12.527946
# 10         BNN_pred    -24.422226     -0.708853        -10.052626
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -83.597345     -1.124378        -13.177764
# 2             HV_cw    -35.750898     -0.682202        -13.048098
# 3         LSTM_pred   -109.861894     -1.224344        -15.395996
# 4          GRU_pred    -75.058321     -1.084663        -13.103584
# 5     LSTM_GRU_pred    -27.201189     -0.607182         -9.122794
# 6       BiLSTM_pred   -100.647450     -1.092629        -16.673185
# 7   BiLSTM_GRU_pred   -147.926847     -1.452242        -16.098534
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -28.299227     -2.343981         -3.320404
# 10         BNN_pred   -108.531165     -1.380866        -16.726270
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw   -112.308290     -1.222362        -15.395099
# 2             HV_cw    -32.028647     -0.643128        -13.048098
# 3         LSTM_pred    -97.092332     -1.063779        -13.810056
# 4          GRU_pred    -78.234580     -1.022543        -14.286932
# 5     LSTM_GRU_pred    -44.172668     -0.698367         -9.122794
# 6       BiLSTM_pred    -99.494917     -1.077552        -16.508082
# 7   BiLSTM_GRU_pred   -121.911272     -1.203406        -13.352513
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred   -120.791577     -1.440215        -14.222999
# 10         BNN_pred   -108.279474     -1.232013        -17.584653
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw   -138.133663     -1.365693        -16.507402
# 2             HV_cw    -68.356881     -0.820891        -13.048098
# 3         LSTM_pred    -97.092332     -1.063779        -13.810056
# 4          GRU_pred   -113.032295     -1.161691        -15.022911
# 5     LSTM_GRU_pred    -48.234135     -0.717869         -9.711490
# 6       BiLSTM_pred    -88.232994     -0.988892        -15.266488
# 7   BiLSTM_GRU_pred    -89.497844     -0.962235        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -91.377510     -1.149316        -11.965042
# 10         BNN_pred    -85.315756     -0.990847        -13.888416
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -58.624170     -0.770262        -13.048098
# 2             HV_cw    -63.375914     -0.814506        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -69.795824     -0.824033        -13.048098
# 5     LSTM_GRU_pred    -71.856412     -0.836417        -13.048098
# 6       BiLSTM_pred    -69.795824     -0.824033        -13.048098
# 7   BiLSTM_GRU_pred    -66.418375     -0.805155        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -58.624170     -0.770262        -13.048098
# 10         BNN_pred    -69.795824     -0.824033        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -79.886648     -0.888804        -13.048098
# 2             HV_cw    -41.587547     -0.677286        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -69.795824     -0.824033        -13.048098
# 6       BiLSTM_pred    -69.795824     -0.824033        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -75.532718     -0.863035        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -77.292733     -0.872933        -13.048098
# 2             HV_cw    -68.404484     -0.815721        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -65.620158     -0.813258        -13.806937
# 1             HV_dw   -103.572376     -1.164225        -12.389219
# 2             HV_cw     -1.799282     -0.455798         -9.401787
# 3         LSTM_pred    -80.503334     -1.037595        -12.600257
# 4          GRU_pred    -88.948640     -1.017237        -13.026481
# 5     LSTM_GRU_pred    -80.654024     -0.960117        -12.602826
# 6       BiLSTM_pred    -66.275773     -0.877090        -14.815264
# 7   BiLSTM_GRU_pred    -82.610613     -0.997018        -15.965874
# 8         QRNN_pred    -56.171001     -0.748296        -13.048098
# 9          ESN_pred   -152.422250     -1.502749        -17.058116
# 10         BNN_pred    -41.063213     -0.729528        -12.546359
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -26.099023     -0.655568        -10.617370
# 1             HV_dw    -36.563224     -0.856518        -12.230703
# 2             HV_cw    -95.223664     -1.056816        -12.958573
# 3         LSTM_pred    -30.154207     -0.788999         -7.500939
# 4          GRU_pred   -134.487175     -1.472373        -15.312492
# 5     LSTM_GRU_pred    -61.744548     -0.923124        -10.480819
# 6       BiLSTM_pred   -122.159762     -1.354667        -14.997832
# 7   BiLSTM_GRU_pred   -116.880698     -1.379499        -14.436413
# 8         QRNN_pred    -26.041553     -0.665876         -9.742910
# 9          ESN_pred    -56.912618     -0.910039        -12.830707
# 10         BNN_pred    -12.471599     -0.614780         -8.691683
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     42.290249     -0.387958         -5.018872
# 1             HV_dw     59.601644     -0.239547         -4.743300
# 2             HV_cw    -37.079224     -0.783200        -11.077507
# 3         LSTM_pred   -118.301563     -1.965928        -12.560795
# 4          GRU_pred   -110.522088     -1.999385        -14.228288
# 5     LSTM_GRU_pred     72.233667     -0.126229         -4.309542
# 6       BiLSTM_pred   -143.943736     -1.937533        -15.657626
# 7   BiLSTM_GRU_pred      1.372355     -0.739252         -7.198336
# 8         QRNN_pred     31.501153     -0.462382         -5.018872
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred    -34.781283     -1.132148         -8.882342
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -11.566134     -0.709295         -9.967363
# 1             HV_dw    -21.336916     -0.862215         -9.563591
# 2             HV_cw    -32.899399     -0.727889        -10.068404
# 3         LSTM_pred    -80.919735     -1.314283         -8.853589
# 4          GRU_pred   -131.303715     -1.686765        -17.863768
# 5     LSTM_GRU_pred    -79.628935     -1.222694        -11.183217
# 6       BiLSTM_pred   -104.374700     -1.407914        -13.815536
# 7   BiLSTM_GRU_pred    -53.862772     -1.064078         -9.486337
# 8         QRNN_pred    -35.135379     -0.827926        -11.493259
# 9          ESN_pred     -0.335481     -0.829539         -5.505749
# 10         BNN_pred    -85.357367     -1.430861        -13.163873
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      4.095288     -0.513430         -9.712721
# 1             HV_dw    -50.035546     -0.917436         -9.365165
# 2             HV_cw     -1.132063     -0.498148         -9.122794
# 3         LSTM_pred    -53.915937     -0.982698         -8.824552
# 4          GRU_pred   -153.699545     -1.799735        -18.930534
# 5     LSTM_GRU_pred    -86.789768     -1.223008        -12.170925
# 6       BiLSTM_pred   -138.293072     -1.577033        -17.374504
# 7   BiLSTM_GRU_pred    -89.493354     -1.211939        -12.386828
# 8         QRNN_pred    -18.759767     -0.620436         -9.742910
# 9          ESN_pred    -90.516034     -1.410093        -10.819301
# 10         BNN_pred    -45.570158     -0.887422        -11.545276
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -21.180768     -0.600844        -11.905617
# 1             HV_dw      5.358091     -0.575290         -8.373769
# 2             HV_cw    -24.395306     -0.662357        -11.862691
# 3         LSTM_pred   -101.570445     -1.376557        -14.407711
# 4          GRU_pred    -51.772956     -0.951793        -11.189433
# 5     LSTM_GRU_pred    -53.140744     -0.967002         -9.223529
# 6       BiLSTM_pred   -119.240807     -1.349181        -15.590231
# 7   BiLSTM_GRU_pred    -78.001550     -1.180076        -12.411283
# 8         QRNN_pred    -49.114478     -0.708425        -13.048098
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred    -59.574882     -1.179322        -11.874392
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -21.180768     -0.600844        -11.905617
# 1             HV_dw    -54.135132     -0.944390        -10.501846
# 2             HV_cw    -32.557999     -0.698862        -11.862691
# 3         LSTM_pred    -76.650059     -1.044377        -11.492873
# 4          GRU_pred    -59.098683     -0.907593        -12.507524
# 5     LSTM_GRU_pred    -67.267890     -0.977444        -11.037773
# 6       BiLSTM_pred   -110.922057     -1.271329        -15.304522
# 7   BiLSTM_GRU_pred   -112.360757     -1.296449        -15.725033
# 8         QRNN_pred    -49.114478     -0.708425        -13.048098
# 9          ESN_pred   -106.493365     -1.551419        -12.105588
# 10         BNN_pred   -104.347367     -1.336238        -15.758561
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -57.610465     -0.798168        -11.989802
# 1             HV_dw    -85.427620     -1.056227        -11.887112
# 2             HV_cw      3.202186     -0.432508         -9.122794
# 3         LSTM_pred    -85.112078     -1.070344        -12.600257
# 4          GRU_pred    -70.692388     -0.958545        -11.475181
# 5     LSTM_GRU_pred   -113.353894     -1.234481        -14.850146
# 6       BiLSTM_pred   -106.108092     -1.180843        -16.066299
# 7   BiLSTM_GRU_pred   -106.589108     -1.195830        -15.177647
# 8         QRNN_pred    -49.114478     -0.708425        -13.048098
# 9          ESN_pred   -143.376698     -1.622126        -15.762979
# 10         BNN_pred    -68.137866     -0.935364        -14.535056
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -58.624170     -0.770262        -13.048098
# 2             HV_cw    -60.768248     -0.798901        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -69.795824     -0.824033        -13.048098
# 5     LSTM_GRU_pred    -71.856412     -0.836417        -13.048098
# 6       BiLSTM_pred    -66.418375     -0.805155        -13.048098
# 7   BiLSTM_GRU_pred    -77.580241     -0.874663        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred    -69.795824     -0.824033        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -79.886648     -0.888804        -13.048098
# 2             HV_cw    -50.625226     -0.733303        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -69.795824     -0.824033        -13.048098
# 6       BiLSTM_pred    -69.795824     -0.824033        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -64.027159     -0.796764        -13.048098
# 10         BNN_pred    -69.795824     -0.824033        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -79.886648     -0.888804        -13.048098
# 2             HV_cw    -68.404484     -0.815721        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.564692     -0.852420        -12.835189
# 1             HV_dw   -122.596713     -1.208211        -16.543179
# 2             HV_cw    -47.700901     -0.701124        -11.791693
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -74.118887     -0.869320        -13.677670
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -69.945707     -0.824937        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred   -101.981111     -1.044706        -14.847242
# 9          ESN_pred    -94.469256     -0.986511        -14.195015
# 10         BNN_pred    -67.052262     -0.815922        -11.921230
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -140.706559     -1.453730        -16.033104
# 1             HV_dw   -158.431702     -1.515045        -17.122709
# 2             HV_cw    -30.187256     -0.622389        -10.197657
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred    -95.994014     -1.060874        -13.026481
# 5     LSTM_GRU_pred    -68.476461     -0.881002        -12.616204
# 6       BiLSTM_pred     40.803289     -0.236132         -7.620317
# 7   BiLSTM_GRU_pred    -90.626559     -1.040622        -15.725371
# 8         QRNN_pred    -31.444410     -0.737634        -11.669964
# 9          ESN_pred    -91.569244     -1.045875        -13.125756
# 10         BNN_pred    -18.187584     -0.569607         -9.847488
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -74.139594     -1.511378        -12.874064
# 1             HV_dw   -125.256390     -1.320262        -14.700350
# 2             HV_cw     -6.780113     -0.509859         -9.122794
# 3         LSTM_pred    -49.064513     -0.712170        -11.756427
# 4          GRU_pred    -74.612586     -1.004515        -11.215986
# 5     LSTM_GRU_pred   -127.554742     -1.434606        -14.947340
# 6       BiLSTM_pred     33.549134     -0.292997         -7.303499
# 7   BiLSTM_GRU_pred   -104.340784     -1.173096        -14.261232
# 8         QRNN_pred    -74.126145     -1.517324        -13.008483
# 9          ESN_pred    -45.299966     -0.837060        -10.357746
# 10         BNN_pred     -7.732487     -0.540954         -8.565877
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -102.655005     -1.444015        -14.959647
# 1             HV_dw   -163.118921     -1.560679        -17.111641
# 2             HV_cw    -47.422018     -0.740628         -9.409979
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred   -127.713985     -1.292088        -15.416300
# 5     LSTM_GRU_pred    -94.874726     -1.109790        -13.021958
# 6       BiLSTM_pred     39.346234     -0.244717         -7.620317
# 7   BiLSTM_GRU_pred   -100.803155     -1.115328        -15.883250
# 8         QRNN_pred    -59.535263     -1.263912        -13.907900
# 9          ESN_pred    -73.478625     -0.985497        -12.385895
# 10         BNN_pred     -5.332023     -0.513462         -8.565877
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -164.398777     -1.636977        -17.898949
# 1             HV_dw   -152.276589     -1.475539        -16.391687
# 2             HV_cw    -41.331672     -0.692266        -10.197657
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred    -95.994014     -1.060874        -13.026481
# 5     LSTM_GRU_pred    -68.476461     -0.881002        -12.616204
# 6       BiLSTM_pred     40.803289     -0.236132         -7.620317
# 7   BiLSTM_GRU_pred    -90.626559     -1.040622        -15.725371
# 8         QRNN_pred    -76.870741     -1.063959        -13.117911
# 9          ESN_pred   -100.618316     -1.108517        -13.385488
# 10         BNN_pred    -29.341880     -0.640579         -9.847488
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.719517     -1.325596        -13.819716
# 1             HV_dw   -101.664185     -1.096557        -15.559349
# 2             HV_cw     13.529932     -0.380548         -9.122794
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -34.571760     -0.681864         -9.981319
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -50.496942     -0.724549        -13.048098
# 7   BiLSTM_GRU_pred    -66.418375     -0.805155        -13.048098
# 8         QRNN_pred    -74.126145     -1.517324        -13.008483
# 9          ESN_pred    -54.402383     -0.804729        -11.844781
# 10         BNN_pred    -31.231115     -0.619398        -10.669100
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -43.827141     -0.778209        -11.905617
# 1             HV_dw   -135.112294     -1.296991        -17.112039
# 2             HV_cw    -31.304988     -0.630867         -9.122794
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -97.511495     -1.023464        -13.677670
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -69.945707     -0.824937        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -13.572847     -0.723812        -11.878350
# 9          ESN_pred    -59.503484     -0.815930        -13.467906
# 10         BNN_pred    -48.602032     -0.716904        -10.669100
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -55.658744     -0.756085        -12.835189
# 1             HV_dw   -123.907117     -1.216999        -16.543179
# 2             HV_cw    -52.201236     -0.728068        -11.791693
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -74.118887     -0.869320        -13.677670
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -69.945707     -0.824937        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -72.526146     -0.891815        -11.832793
# 9          ESN_pred    -93.898755     -0.982999        -14.140957
# 10         BNN_pred    -67.052262     -0.815922        -11.921230
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -66.418375     -0.805155        -13.048098
# 2             HV_cw    -64.027159     -0.796764        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -66.418375     -0.805155        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -71.856412     -0.836417        -13.048098
# 2             HV_cw    -75.532718     -0.863035        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -71.856412     -0.836417        -13.048098
# 2             HV_cw    -68.404484     -0.815721        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -59.253821     -0.785427        -14.083845
# 1             HV_dw    -77.393753     -0.876732        -13.119339
# 2             HV_cw    -76.266135     -0.869723        -12.515777
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -56.770909     -0.759333        -11.452325
# 5     LSTM_GRU_pred    -99.311912     -1.028565        -15.884320
# 6       BiLSTM_pred    -50.398801     -0.719543        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -77.510017     -0.927763        -14.091488
# 9          ESN_pred    -55.408310     -0.766309        -12.492155
# 10         BNN_pred    -70.467548     -0.852781        -11.756427
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -143.370398     -1.514392        -16.457434
# 1             HV_dw   -140.456386     -1.331791        -18.122149
# 2             HV_cw    -58.477636     -0.790589        -10.075489
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred    -87.681239     -1.008889        -12.904553
# 5     LSTM_GRU_pred    -43.274676     -0.708612        -11.629946
# 6       BiLSTM_pred     41.664001     -0.233976         -6.725953
# 7   BiLSTM_GRU_pred    -85.077190     -1.008087        -15.891718
# 8         QRNN_pred     -3.564082     -0.559230         -9.975598
# 9          ESN_pred    -88.100946     -0.965284        -12.947695
# 10         BNN_pred    -66.682429     -0.830233        -11.603371
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -70.077811     -1.768699        -11.578549
# 1             HV_dw   -112.177286     -1.167583        -17.156933
# 2             HV_cw    -39.058321     -0.718157         -9.122794
# 3         LSTM_pred    -49.064513     -0.712170        -11.756427
# 4          GRU_pred    -94.509460     -1.149004        -13.587001
# 5     LSTM_GRU_pred    -94.095388     -1.219168        -15.341673
# 6       BiLSTM_pred     24.018825     -0.367644         -4.964251
# 7   BiLSTM_GRU_pred    -89.046281     -1.086247        -14.512368
# 8         QRNN_pred    -87.007893     -1.537498        -12.894945
# 9          ESN_pred    -90.723593     -1.141735        -12.904746
# 10         BNN_pred    -24.662508     -0.625745        -10.709837
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -108.291535     -1.711586        -14.340273
# 1             HV_dw   -124.438235     -1.240457        -16.588381
# 2             HV_cw    -19.600071     -0.576188         -9.122794
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred    -53.268152     -0.833374         -9.815368
# 5     LSTM_GRU_pred    -90.263369     -1.064339        -14.060844
# 6       BiLSTM_pred     40.810557     -0.239040         -6.802373
# 7   BiLSTM_GRU_pred    -94.328058     -1.103239        -15.835161
# 8         QRNN_pred    -60.825322     -1.200222        -12.005385
# 9          ESN_pred    -76.641005     -1.011969        -13.278542
# 10         BNN_pred    -38.578149     -0.707522        -10.709837
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -130.928005     -1.463884        -15.470842
# 1             HV_dw   -140.456386     -1.331791        -18.122149
# 2             HV_cw    -24.400872     -0.597946         -9.122794
# 3         LSTM_pred    -49.980995     -0.717528        -11.756427
# 4          GRU_pred    -87.681239     -1.008889        -12.904553
# 5     LSTM_GRU_pred    -75.015833     -0.931342        -14.512426
# 6       BiLSTM_pred     41.664001     -0.233976         -6.725953
# 7   BiLSTM_GRU_pred    -85.077190     -1.008087        -15.891718
# 8         QRNN_pred   -116.010722     -1.391095        -14.435564
# 9          ESN_pred    -83.010219     -0.984846        -13.955480
# 10         BNN_pred    -58.047860     -0.798617        -10.709837
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -31.873392     -1.210629        -10.411368
# 1             HV_dw    -41.804483     -0.678755        -11.491856
# 2             HV_cw    -22.626318     -0.611878         -9.122794
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -46.398360     -0.750867         -9.905566
# 5     LSTM_GRU_pred    -83.195703     -0.966480        -13.554452
# 6       BiLSTM_pred    -52.494246     -0.741223        -13.048098
# 7   BiLSTM_GRU_pred    -66.418375     -0.805155        -13.048098
# 8         QRNN_pred    -90.052907     -1.554158        -13.630858
# 9          ESN_pred   -111.828739     -1.226698        -16.077499
# 10         BNN_pred    -53.495858     -0.755589        -11.756427
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -50.478408     -1.023711        -10.553998
# 1             HV_dw    -60.200389     -0.783873        -11.491856
# 2             HV_cw     -2.835333     -0.473868         -9.122794
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -21.191870     -0.580968         -9.333477
# 5     LSTM_GRU_pred    -99.311912     -1.028565        -15.884320
# 6       BiLSTM_pred    -50.398801     -0.719543        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -86.882375     -1.399120        -12.748813
# 9          ESN_pred    -90.004467     -1.052375        -16.437678
# 10         BNN_pred    -70.467548     -0.852781        -11.756427
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -55.202497     -0.772763        -14.885835
# 1             HV_dw    -77.393753     -0.876732        -13.119339
# 2             HV_cw    -39.879486     -0.673579         -9.589211
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -56.770909     -0.759333        -11.452325
# 5     LSTM_GRU_pred    -99.311912     -1.028565        -15.884320
# 6       BiLSTM_pred    -50.398801     -0.719543        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -87.651199     -1.045403        -13.258177
# 9          ESN_pred    -61.123071     -0.831271        -14.581538
# 10         BNN_pred    -70.467548     -0.852781        -11.756427
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -66.418375     -0.805155        -13.048098
# 2             HV_cw    -67.200925     -0.818988        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -77.292733     -0.872933        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -66.418375     -0.805155        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -71.856412     -0.836417        -13.048098
# 2             HV_cw    -71.255283     -0.838067        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -68.404484     -0.815721        -13.048098
# 2             HV_cw    -66.418375     -0.805155        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw   -110.717393     -1.156062        -14.456685
# 2             HV_cw    -73.294280     -0.849654        -13.048098
# 3         LSTM_pred    -97.092332     -1.063779        -13.810056
# 4          GRU_pred   -106.626033     -1.117065        -14.713138
# 5     LSTM_GRU_pred    -65.772108     -0.833708        -11.951863
# 6       BiLSTM_pred     21.737359     -0.337998         -8.054513
# 7   BiLSTM_GRU_pred    -82.921600     -0.919964        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -67.712354     -0.833614        -11.147516
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -42.840256     -0.773978        -10.252592
# 1             HV_dw   -118.740176     -1.447839        -12.699742
# 2             HV_cw   -110.288291     -1.169806        -14.604821
# 3         LSTM_pred    -79.259374     -1.166765        -10.918359
# 4          GRU_pred   -134.487175     -1.472373        -15.312492
# 5     LSTM_GRU_pred      0.094724     -0.531841         -8.392402
# 6       BiLSTM_pred     66.275305     -0.112108         -5.860199
# 7   BiLSTM_GRU_pred    -61.421078     -0.884986        -14.650025
# 8         QRNN_pred    -38.873703     -0.693491        -11.339676
# 9          ESN_pred    -50.716701     -0.745054        -12.021383
# 10         BNN_pred    -49.921338     -0.864558        -12.016100
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     19.754358     -0.559201         -5.018872
# 1             HV_dw    -87.097922     -1.459635        -11.065487
# 2             HV_cw    -66.110465     -1.026221        -10.145165
# 3         LSTM_pred   -135.809329     -2.054333        -14.297063
# 4          GRU_pred   -116.306329     -1.731490        -15.274959
# 5     LSTM_GRU_pred    -32.659669     -1.060068         -9.406115
# 6       BiLSTM_pred     15.679877     -0.673308         -4.058449
# 7   BiLSTM_GRU_pred    -52.126569     -1.064680        -10.620052
# 8         QRNN_pred      5.480551     -0.491451         -9.799737
# 9          ESN_pred   -171.622983     -1.744626        -19.448487
# 10         BNN_pred    -39.597499     -1.213236        -10.395986
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -47.395852     -0.911530        -12.492417
# 1             HV_dw    -91.866115     -1.293204        -11.918481
# 2             HV_cw    -33.502117     -0.740167         -9.122794
# 3         LSTM_pred   -116.701328     -1.515331        -12.402097
# 4          GRU_pred   -131.303715     -1.686765        -17.863768
# 5     LSTM_GRU_pred      2.638328     -0.569273         -8.859019
# 6       BiLSTM_pred     75.206254     -0.062797         -4.927637
# 7   BiLSTM_GRU_pred    -84.563897     -1.194349        -14.306302
# 8         QRNN_pred      5.480551     -0.491451         -9.799737
# 9          ESN_pred    -79.194409     -0.963636        -14.176077
# 10         BNN_pred    -53.988910     -0.973871        -13.004116
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -42.840256     -0.773978        -10.252592
# 1             HV_dw    -89.672576     -1.225534        -12.526476
# 2             HV_cw   -108.677480     -1.159490        -14.450214
# 3         LSTM_pred    -95.052100     -1.310761        -11.814596
# 4          GRU_pred   -155.656387     -1.661870        -17.383828
# 5     LSTM_GRU_pred    -15.133223     -0.639946         -8.392402
# 6       BiLSTM_pred    102.523225      0.122849         -4.496887
# 7   BiLSTM_GRU_pred    -64.400033     -0.906188        -14.674953
# 8         QRNN_pred    -38.873703     -0.693491        -11.339676
# 9          ESN_pred    -50.716701     -0.745054        -12.021383
# 10         BNN_pred    -49.200831     -0.895042        -11.591437
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -39.912097     -0.791493        -10.851088
# 2             HV_cw    -55.966818     -0.796092        -13.048098
# 3         LSTM_pred   -109.861894     -1.224344        -15.395996
# 4          GRU_pred    -75.058321     -1.084663        -13.103584
# 5     LSTM_GRU_pred    -83.398692     -1.152597        -11.905617
# 6       BiLSTM_pred    -66.792972     -1.164190         -9.781485
# 7   BiLSTM_GRU_pred   -147.926847     -1.452242        -16.098534
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred     18.247377     -0.427191         -9.236253
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw   -100.667904     -1.147893        -13.049803
# 2             HV_cw    -62.405000     -0.805513        -13.048098
# 3         LSTM_pred    -97.092332     -1.063779        -13.810056
# 4          GRU_pred    -78.234580     -1.022543        -14.286932
# 5     LSTM_GRU_pred    -95.467601     -1.079150        -13.738039
# 6       BiLSTM_pred     28.440318     -0.307126         -8.054513
# 7   BiLSTM_GRU_pred   -121.911272     -1.203406        -13.352513
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred     -4.194451     -0.497834        -10.249374
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw   -100.535932     -1.110023        -13.448259
# 2             HV_cw    -71.616492     -0.839976        -13.048098
# 3         LSTM_pred    -97.092332     -1.063779        -13.810056
# 4          GRU_pred   -113.032295     -1.161691        -15.022911
# 5     LSTM_GRU_pred   -112.578311     -1.167249        -14.108259
# 6       BiLSTM_pred     21.737359     -0.337998         -8.054513
# 7   BiLSTM_GRU_pred    -89.497844     -0.962235        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -30.468530     -0.651903        -10.249374
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -79.886648     -0.888804        -13.048098
# 2             HV_cw    -62.007498     -0.806123        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -69.795824     -0.824033        -13.048098
# 5     LSTM_GRU_pred    -76.751689     -0.870300        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -66.418375     -0.805155        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -66.418375     -0.805155        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -79.886648     -0.888804        -13.048098
# 2             HV_cw    -68.404484     -0.815721        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -66.418375     -0.805155        -13.048098
# 2             HV_cw    -68.404484     -0.815721        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -65.620158     -0.813258        -13.806937
# 1             HV_dw   -154.796978     -1.519223        -16.022256
# 2             HV_cw    -85.170674     -0.938068        -13.048098
# 3         LSTM_pred    -80.503334     -1.037595        -12.600257
# 4          GRU_pred    -88.948640     -1.017237        -13.026481
# 5     LSTM_GRU_pred    -84.246464     -0.983774        -14.680092
# 6       BiLSTM_pred     69.012468     -0.078050         -6.725953
# 7   BiLSTM_GRU_pred    -82.610613     -0.997018        -15.965874
# 8         QRNN_pred    -56.171001     -0.748296        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -78.885190     -0.945703        -14.430739
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -26.099023     -0.655568        -10.617370
# 1             HV_dw   -113.542965     -1.376181        -13.061609
# 2             HV_cw    -54.010640     -0.795970        -10.459602
# 3         LSTM_pred    -30.154207     -0.788999         -7.500939
# 4          GRU_pred   -134.487175     -1.472373        -15.312492
# 5     LSTM_GRU_pred    -68.569869     -1.007682         -8.342396
# 6       BiLSTM_pred     54.487690     -0.192593         -5.579420
# 7   BiLSTM_GRU_pred   -116.880698     -1.379499        -14.436413
# 8         QRNN_pred    -26.041553     -0.665876         -9.742910
# 9          ESN_pred    -73.536063     -0.932230        -11.448696
# 10         BNN_pred    -79.661949     -1.114871        -13.817928
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     42.290249     -0.387958         -5.018872
# 1             HV_dw   -118.658213     -1.967648        -13.022788
# 2             HV_cw    -60.845351     -1.060639         -8.218248
# 3         LSTM_pred   -118.301563     -1.965928        -12.560795
# 4          GRU_pred   -110.522088     -1.999385        -14.228288
# 5     LSTM_GRU_pred     -2.710247     -0.868455         -8.180309
# 6       BiLSTM_pred     46.257174     -0.398402         -4.058449
# 7   BiLSTM_GRU_pred      1.372355     -0.739252         -7.198336
# 8         QRNN_pred     31.501153     -0.462382         -5.018872
# 9          ESN_pred    -93.315237     -1.479036        -13.124142
# 10         BNN_pred    -67.126416     -1.577542        -11.350192
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -11.566134     -0.709295         -9.967363
# 1             HV_dw    -76.782032     -1.260636        -12.330351
# 2             HV_cw    -26.364275     -0.712966        -10.009150
# 3         LSTM_pred    -80.919735     -1.314283         -8.853589
# 4          GRU_pred   -131.303715     -1.686765        -17.863768
# 5     LSTM_GRU_pred     12.195571     -0.565620         -7.568737
# 6       BiLSTM_pred     40.162126     -0.349584         -4.663775
# 7   BiLSTM_GRU_pred    -53.862772     -1.064078         -9.486337
# 8         QRNN_pred    -35.135379     -0.827926        -11.493259
# 9          ESN_pred    -83.513270     -1.167596        -10.255230
# 10         BNN_pred   -139.923446     -1.855519        -15.652349
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      4.095288     -0.513430         -9.712721
# 1             HV_dw   -125.845255     -1.553419        -14.795317
# 2             HV_cw    -25.442686     -0.632505        -10.459602
# 3         LSTM_pred    -53.915937     -0.982698         -8.824552
# 4          GRU_pred   -153.699545     -1.799735        -18.930534
# 5     LSTM_GRU_pred    -27.131885     -0.773397         -7.593486
# 6       BiLSTM_pred     -9.236946     -0.628839         -8.709218
# 7   BiLSTM_GRU_pred    -89.493354     -1.211939        -12.386828
# 8         QRNN_pred    -18.759767     -0.620436         -9.742910
# 9          ESN_pred    -73.536063     -0.932230        -11.448696
# 10         BNN_pred    -72.613094     -1.092920        -14.079744
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -21.180768     -0.600844        -11.905617
# 1             HV_dw    -71.097435     -1.050282        -11.316727
# 2             HV_cw    -80.170448     -0.997460        -13.048098
# 3         LSTM_pred   -101.570445     -1.376557        -14.407711
# 4          GRU_pred    -51.772956     -0.951793        -11.189433
# 5     LSTM_GRU_pred    -19.766051     -0.877248         -9.277166
# 6       BiLSTM_pred     59.973751     -0.252528         -4.058449
# 7   BiLSTM_GRU_pred    -78.001550     -1.180076        -12.411283
# 8         QRNN_pred    -49.114478     -0.708425        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -25.874954     -0.859568        -13.451680
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -21.180768     -0.600844        -11.905617
# 1             HV_dw   -109.519133     -1.268621        -14.323974
# 2             HV_cw    -51.916866     -0.791879        -13.048098
# 3         LSTM_pred    -76.650059     -1.044377        -11.492873
# 4          GRU_pred    -59.098683     -0.907593        -12.507524
# 5     LSTM_GRU_pred   -131.163715     -1.464123        -16.220600
# 6       BiLSTM_pred     88.240990      0.028731         -4.911786
# 7   BiLSTM_GRU_pred   -112.360757     -1.296449        -15.725033
# 8         QRNN_pred    -49.114478     -0.708425        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred   -110.693309     -1.351673        -15.167920
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -57.610465     -0.798168        -11.989802
# 1             HV_dw   -141.098281     -1.457463        -15.032286
# 2             HV_cw    -69.822255     -0.866186        -13.048098
# 3         LSTM_pred    -85.112078     -1.070344        -12.600257
# 4          GRU_pred    -70.692388     -0.958545        -11.475181
# 5     LSTM_GRU_pred   -110.303914     -1.231772        -15.969369
# 6       BiLSTM_pred     19.579029     -0.397149         -8.090273
# 7   BiLSTM_GRU_pred   -106.589108     -1.195830        -15.177647
# 8         QRNN_pred    -49.114478     -0.708425        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -59.413203     -0.888745        -13.565785
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -79.886648     -0.888804        -13.048098
# 2             HV_cw    -62.007498     -0.806123        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -69.795824     -0.824033        -13.048098
# 5     LSTM_GRU_pred    -76.751689     -0.870300        -13.048098
# 6       BiLSTM_pred    -66.153050     -0.809559        -13.048098
# 7   BiLSTM_GRU_pred    -77.580241     -0.874663        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -66.418375     -0.805155        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -79.886648     -0.888804        -13.048098
# 2             HV_cw    -41.587547     -0.677286        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.404484     -0.815721        -13.048098
# 1             HV_dw    -77.292733     -0.872933        -13.048098
# 2             HV_cw    -68.404484     -0.815721        -13.048098
# 3         LSTM_pred    -68.404484     -0.815721        -13.048098
# 4          GRU_pred    -68.404484     -0.815721        -13.048098
# 5     LSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 6       BiLSTM_pred    -68.404484     -0.815721        -13.048098
# 7   BiLSTM_GRU_pred    -68.404484     -0.815721        -13.048098
# 8         QRNN_pred    -68.404484     -0.815721        -13.048098
# 9          ESN_pred    -68.404484     -0.815721        -13.048098
# 10         BNN_pred    -68.404484     -0.815721        -13.048098
# 11               __    -68.404484     -0.815721        -13.048098

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_2y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_2y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_2y1', file, 'HV')
get_final_results_1('2024_2y1', file, 'HV')

get_final_results('2024_2y1', dw_file, 'HV_dw')
get_final_results_1('2024_2y1', dw_file, 'HV_dw')

get_final_results('2024_2y1', cw_file, 'HV_cw')
get_final_results_1('2024_2y1', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    317.288787      1.171975         -7.217204
# 1             HV_dw    384.141565      1.298066         -7.729145
# 2             HV_cw    247.664605      1.119887         -8.604646
# 3         LSTM_pred    364.562606      1.164094         -8.485144
# 4          GRU_pred    341.580066      1.117541         -8.484837
# 5     LSTM_GRU_pred    325.459288      1.055341         -8.484837
# 6       BiLSTM_pred    227.272914      1.039746         -8.485144
# 7   BiLSTM_GRU_pred    288.828651      1.075173         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    405.406614      1.321044         -7.688132
# 10         BNN_pred    215.385299      0.881286         -8.889622
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    341.167516      1.239442         -6.776091
# 1             HV_dw    466.166126      1.615626         -6.631906
# 2             HV_cw    149.324403      0.315542        -10.505462
# 3         LSTM_pred    279.417832      0.945870         -7.307041
# 4          GRU_pred    320.646118      1.035866         -8.586712
# 5     LSTM_GRU_pred    301.706127      0.986232         -8.573037
# 6       BiLSTM_pred    203.989662      0.581592         -8.340626
# 7   BiLSTM_GRU_pred    293.873146      0.908924         -8.028952
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    335.242774      1.116998         -7.912772
# 10         BNN_pred    230.978526      0.699756        -10.162509
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    163.577077      0.556798         -7.474576
# 1             HV_dw    442.701625      1.630907         -6.857615
# 2             HV_cw     87.660686      0.054792         -7.295024
# 3         LSTM_pred    285.986853      1.009170         -7.307041
# 4          GRU_pred    343.255534      1.238782         -6.501162
# 5     LSTM_GRU_pred    293.784112      1.044406         -7.861297
# 6       BiLSTM_pred    150.682493      0.347631         -8.478361
# 7   BiLSTM_GRU_pred    256.961964      0.834060         -8.028952
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    260.792829      0.890720         -6.636588
# 10         BNN_pred    186.941680      0.524265        -10.022314
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    252.814698      0.946591         -6.769256
# 1             HV_dw    458.627738      1.599636         -6.581321
# 2             HV_cw     47.641987     -0.231152         -9.432684
# 3         LSTM_pred    277.650155      0.968759         -7.307041
# 4          GRU_pred    314.576625      1.032767         -8.162190
# 5     LSTM_GRU_pred    299.666166      0.999330         -8.310378
# 6       BiLSTM_pred    227.882880      0.692487         -8.286555
# 7   BiLSTM_GRU_pred    255.721940      0.828594         -8.028952
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    309.676917      1.047632         -7.373397
# 10         BNN_pred    245.312814      0.763248        -10.022314
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    237.120270      0.792954         -7.614168
# 1             HV_dw    466.166126      1.615626         -6.631906
# 2             HV_cw     77.891156     -0.020727        -12.661472
# 3         LSTM_pred    300.416000      0.978367         -7.307041
# 4          GRU_pred    305.848962      0.974539         -8.586712
# 5     LSTM_GRU_pred    287.121183      0.923313         -8.573037
# 6       BiLSTM_pred    203.989662      0.581592         -8.340626
# 7   BiLSTM_GRU_pred    315.670873      1.000255         -8.028952
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    345.703903      1.160139         -7.154090
# 10         BNN_pred    233.527263      0.710852        -10.162509
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    167.973771      0.519273        -10.323482
# 1             HV_dw    390.857042      1.369665         -7.627178
# 2             HV_cw    184.699103      0.559342         -6.449831
# 3         LSTM_pred    368.163841      1.183912         -8.485144
# 4          GRU_pred    382.237992      1.300512         -6.699473
# 5     LSTM_GRU_pred    373.456507      1.260275         -6.699473
# 6       BiLSTM_pred    227.272914      1.012729         -8.485144
# 7   BiLSTM_GRU_pred    314.705620      1.133915         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    397.137817      1.356581         -6.076435
# 10         BNN_pred    242.383666      1.003177         -8.695715
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    268.108063      1.158123         -9.734706
# 1             HV_dw    388.743132      1.316979         -7.729145
# 2             HV_cw    152.235144      0.334811         -8.065306
# 3         LSTM_pred    368.163841      1.183912         -8.485144
# 4          GRU_pred    348.054057      1.166432         -8.414653
# 5     LSTM_GRU_pred    317.836019      1.050749         -8.562312
# 6       BiLSTM_pred    227.272914      1.039746         -8.485144
# 7   BiLSTM_GRU_pred    298.971360      1.070010         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    405.715353      1.361089         -7.290056
# 10         BNN_pred    239.692711      0.985236         -8.824010
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    311.194821      1.150087         -7.583685
# 1             HV_dw    384.141565      1.298066         -7.729145
# 2             HV_cw    212.829309      0.872790         -9.057168
# 3         LSTM_pred    364.562606      1.164094         -8.485144
# 4          GRU_pred    342.098259      1.119502         -8.484837
# 5     LSTM_GRU_pred    325.971254      1.057297         -8.484837
# 6       BiLSTM_pred    227.272914      1.039746         -8.485144
# 7   BiLSTM_GRU_pred    288.828651      1.075173         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    405.461960      1.321242         -7.688132
# 10         BNN_pred    215.385299      0.881286         -8.889622
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.125963         -8.485144
# 1             HV_dw             0      1.206255         -8.485144
# 2             HV_cw             0      1.071716         -8.485144
# 3         LSTM_pred             0      1.132715         -8.485144
# 4          GRU_pred             0      1.168831         -8.485144
# 5     LSTM_GRU_pred             0      1.168831         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.132715         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.071716         -8.485144
# 10         BNN_pred             0      1.168831         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.132715         -8.485144
# 4          GRU_pred             0      1.132715         -8.485144
# 5     LSTM_GRU_pred             0      1.132715         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.132715         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.071716         -8.485144
# 5     LSTM_GRU_pred             0      1.071716         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.069809         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    225.060989      0.951599         -9.106930
# 1             HV_dw    366.744768      1.188773         -7.814646
# 2             HV_cw    203.733678      0.604574         -9.337443
# 3         LSTM_pred    335.317288      1.055841         -8.937236
# 4          GRU_pred    303.306029      1.061836         -8.603173
# 5     LSTM_GRU_pred    355.469432      1.069801         -8.528839
# 6       BiLSTM_pred      0.000000      1.069809         -8.485144
# 7   BiLSTM_GRU_pred    316.996251      0.990038         -8.734859
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    309.755183      0.965266         -9.488954
# 10         BNN_pred    217.436641      0.901270         -8.958228
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    288.491366      0.990911         -7.029282
# 1             HV_dw    497.111378      1.706565         -7.682955
# 2             HV_cw    255.842447      0.808727         -9.192980
# 3         LSTM_pred    296.030890      0.941656         -6.306695
# 4          GRU_pred    373.132087      1.224415         -7.876931
# 5     LSTM_GRU_pred    345.467751      1.148592         -8.603173
# 6       BiLSTM_pred    249.333590      0.776148         -7.291776
# 7   BiLSTM_GRU_pred    297.509759      0.901074         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    435.271164      1.435876         -7.269949
# 10         BNN_pred    249.927707      0.715139         -9.573458
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     99.956884      0.109773         -9.092647
# 1             HV_dw    533.409702      1.898542         -7.035518
# 2             HV_cw     88.812543      0.013854         -8.890511
# 3         LSTM_pred    265.621839      0.894394         -8.190715
# 4          GRU_pred    471.329073      1.715840         -6.485286
# 5     LSTM_GRU_pred    382.531947      1.400407         -7.853231
# 6       BiLSTM_pred    238.649495      0.753907         -6.639877
# 7   BiLSTM_GRU_pred    237.594746      0.734992         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    363.617845      1.362948         -5.831910
# 10         BNN_pred    201.721932      0.575426         -9.715924
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    204.539022      0.689819         -7.943063
# 1             HV_dw    469.844307      1.625146         -7.682955
# 2             HV_cw    109.652998      0.171652         -8.485144
# 3         LSTM_pred    265.621839      0.894394         -8.190715
# 4          GRU_pred    400.540199      1.358947         -7.043928
# 5     LSTM_GRU_pred    355.527732      1.222490         -6.768915
# 6       BiLSTM_pred    264.930103      0.846641         -7.247608
# 7   BiLSTM_GRU_pred    253.253154      0.798572         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    360.980637      1.237418         -7.487663
# 10         BNN_pred    267.795531      0.846363         -9.364239
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    213.924978      0.642911         -9.657751
# 1             HV_dw    488.796570      1.682885         -7.682955
# 2             HV_cw    142.752037      0.328763         -8.981561
# 3         LSTM_pred    263.190518      0.853681         -7.827949
# 4          GRU_pred    381.699993      1.264317         -7.970489
# 5     LSTM_GRU_pred    360.278942      1.211517         -8.603173
# 6       BiLSTM_pred    249.333590      0.776148         -7.291776
# 7   BiLSTM_GRU_pred    287.758863      0.929043         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    325.972926      1.073364        -10.529296
# 10         BNN_pred    258.702879      0.752786         -9.505459
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    140.389379      0.319082        -12.310496
# 1             HV_dw    386.538643      1.275222         -7.819317
# 2             HV_cw    169.989561      0.415539         -8.485144
# 3         LSTM_pred    345.524643      1.105537         -8.485144
# 4          GRU_pred    359.032416      1.377916         -7.420443
# 5     LSTM_GRU_pred    370.349326      1.338301         -7.508580
# 6       BiLSTM_pred      0.000000      1.069809         -8.485144
# 7   BiLSTM_GRU_pred    298.980297      0.942858         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    402.871532      1.415344         -5.193605
# 10         BNN_pred    198.466474      0.832400         -9.515612
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    158.670453      0.402835        -11.639955
# 1             HV_dw    365.778738      1.187514         -7.814646
# 2             HV_cw    165.997082      0.434801         -8.485144
# 3         LSTM_pred    345.524643      1.105537         -8.485144
# 4          GRU_pred    351.012472      1.314403         -7.418529
# 5     LSTM_GRU_pred    356.411555      1.182658         -7.580144
# 6       BiLSTM_pred      0.000000      1.069809         -8.485144
# 7   BiLSTM_GRU_pred    322.328383      1.020686         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    331.839872      1.065880         -9.282564
# 10         BNN_pred    239.805095      0.998817         -8.906310
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    191.379276      0.818641         -9.657373
# 1             HV_dw    366.744768      1.188773         -7.814646
# 2             HV_cw    170.058861      0.462136         -9.186210
# 3         LSTM_pred    320.078854      1.001083         -8.920548
# 4          GRU_pred    319.887433      1.139355         -8.473850
# 5     LSTM_GRU_pred    356.971305      1.079484         -8.528839
# 6       BiLSTM_pred      0.000000      1.069809         -8.485144
# 7   BiLSTM_GRU_pred    322.328383      1.020686         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    308.690811      0.961226         -9.562508
# 10         BNN_pred    217.436641      0.901270         -8.958228
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.168831         -8.485144
# 3         LSTM_pred             0      1.132715         -8.485144
# 4          GRU_pred             0      1.168831         -8.485144
# 5     LSTM_GRU_pred             0      1.168831         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.132715         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.132715         -8.485144
# 10         BNN_pred             0      1.132715         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.132715         -8.485144
# 4          GRU_pred             0      1.132715         -8.485144
# 5     LSTM_GRU_pred             0      1.132715         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.132715         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.071716         -8.485144
# 5     LSTM_GRU_pred             0      1.069809         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.069809         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    280.707972      0.830439         -8.485144
# 1             HV_dw    472.540521      1.625240         -7.682955
# 2             HV_cw    184.655053      0.448936         -8.956896
# 3         LSTM_pred    305.854942      0.984389         -8.028952
# 4          GRU_pred    315.737876      1.049465        -10.016782
# 5     LSTM_GRU_pred    219.937216      0.986631        -10.016782
# 6       BiLSTM_pred    270.389327      0.866541         -5.963031
# 7   BiLSTM_GRU_pred    371.434140      1.183311         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    396.569057      1.250596         -8.485144
# 10         BNN_pred    227.511222      0.625332         -9.462231
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    268.892303      0.833778         -8.793029
# 1             HV_dw    388.716365      1.390384         -8.401736
# 2             HV_cw    172.481193      0.413685         -9.129517
# 3         LSTM_pred    289.589421      0.944218         -8.241084
# 4          GRU_pred    169.163528      0.468661         -8.895734
# 5     LSTM_GRU_pred    145.319089      0.335427        -10.510498
# 6       BiLSTM_pred    168.785396      0.435673         -7.828041
# 7   BiLSTM_GRU_pred    195.714183      0.518366         -7.687376
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    416.989441      1.382568         -8.485144
# 10         BNN_pred    178.809784      0.508593         -7.468630
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    187.386080      0.547123         -8.778358
# 1             HV_dw    250.795638      1.044495         -7.179901
# 2             HV_cw     44.901056     -0.245126         -8.550712
# 3         LSTM_pred    162.040140      0.523837         -5.730045
# 4          GRU_pred    149.630235      0.471219         -4.378043
# 5     LSTM_GRU_pred    161.663104      0.518014         -4.650774
# 6       BiLSTM_pred    178.779568      0.534724         -6.703378
# 7   BiLSTM_GRU_pred     93.159737      0.062586         -7.706493
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    180.445864      0.578070         -8.485144
# 10         BNN_pred    127.111523      0.290619         -6.642765
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    231.573712      0.711665         -8.826438
# 1             HV_dw    336.763833      1.292518         -7.258375
# 2             HV_cw     48.106730     -0.232611         -8.972604
# 3         LSTM_pred    207.475718      0.704464         -6.671325
# 4          GRU_pred    243.875685      0.885839         -7.369886
# 5     LSTM_GRU_pred    234.347189      0.838628         -6.433413
# 6       BiLSTM_pred    190.931713      0.576763         -7.269984
# 7   BiLSTM_GRU_pred    140.013317      0.333656         -7.706493
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    278.789055      0.948679         -8.485144
# 10         BNN_pred    177.666487      0.533577         -7.123848
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    205.465445      0.578856         -8.793029
# 1             HV_dw    387.314701      1.434141         -8.031695
# 2             HV_cw    104.276579      0.088348         -9.553756
# 3         LSTM_pred    233.910545      0.790603         -7.766655
# 4          GRU_pred    222.616388      0.749094        -11.130113
# 5     LSTM_GRU_pred    169.326913      0.464276         -8.794129
# 6       BiLSTM_pred    145.689065      0.315445         -7.836052
# 7   BiLSTM_GRU_pred    241.525141      0.773612         -7.687376
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    294.338967      0.989600         -8.485144
# 10         BNN_pred    167.486553      0.462567         -7.324231
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    223.299511      0.665434         -8.485144
# 1             HV_dw    398.824266      1.447743         -7.035518
# 2             HV_cw    132.575664      0.270568         -9.345649
# 3         LSTM_pred    264.395857      1.027985         -4.652244
# 4          GRU_pred    239.665725      0.895091         -4.853215
# 5     LSTM_GRU_pred    210.878794      1.060109         -4.793397
# 6       BiLSTM_pred    258.534364      0.858011         -5.885302
# 7   BiLSTM_GRU_pred    137.304380      0.267142         -7.115997
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    218.690284      0.778240         -8.485144
# 10         BNN_pred    107.696482      0.140327        -11.145356
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    275.773018      0.842481         -8.485144
# 1             HV_dw    458.016257      1.629977         -6.976125
# 2             HV_cw    147.475339      0.295644         -9.117423
# 3         LSTM_pred    256.974166      0.805100         -8.028952
# 4          GRU_pred    426.478412      1.555188         -6.443676
# 5     LSTM_GRU_pred    271.812084      1.350839         -6.485881
# 6       BiLSTM_pred    286.131057      0.955861         -5.845325
# 7   BiLSTM_GRU_pred    356.028746      1.180025         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    308.348743      1.033276         -8.485144
# 10         BNN_pred    186.114786      0.504045        -10.761803
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    275.773018      0.858046         -8.485144
# 1             HV_dw    472.139298      1.641956         -7.682955
# 2             HV_cw    156.052825      0.330996         -9.046281
# 3         LSTM_pred    256.974166      0.805100         -8.028952
# 4          GRU_pred    355.610667      1.225962         -8.573957
# 5     LSTM_GRU_pred    234.370687      1.078344         -8.573957
# 6       BiLSTM_pred    265.007067      0.836567         -5.947522
# 7   BiLSTM_GRU_pred    365.181072      1.192299         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    285.947040      0.909083         -8.485144
# 10         BNN_pred    209.041041      0.600399        -10.390733
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.909353         -8.485144
# 1             HV_dw             0      1.206255         -8.485144
# 2             HV_cw             0      1.132715         -8.485144
# 3         LSTM_pred             0      1.132715         -8.485144
# 4          GRU_pred             0      1.124497         -8.485144
# 5     LSTM_GRU_pred             0      1.168831         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.132715         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.124497         -8.485144
# 10         BNN_pred             0      1.168831         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.071716         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.168831         -8.485144
# 5     LSTM_GRU_pred             0      1.168831         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.132715         -8.485144
# 10         BNN_pred             0      1.132715         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.132715         -8.485144
# 5     LSTM_GRU_pred             0      1.132715         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.132715         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    316.163863      0.995382         -9.192980
# 1             HV_dw    399.318470      1.379312         -6.855888
# 2             HV_cw    162.867764      0.362866         -9.124711
# 3         LSTM_pred    274.660974      0.856379         -7.307041
# 4          GRU_pred    315.737876      1.049465        -10.016782
# 5     LSTM_GRU_pred    272.976168      0.902902         -9.973799
# 6       BiLSTM_pred    210.180011      0.618880         -6.940822
# 7   BiLSTM_GRU_pred    253.448364      0.813165         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    326.179591      1.022000         -8.485144
# 10         BNN_pred    209.338208      0.570503         -7.169769
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    200.376312      0.565011         -9.004819
# 1             HV_dw    363.726855      1.343288         -7.382398
# 2             HV_cw    103.190825      0.082689         -8.485144
# 3         LSTM_pred    202.589376      0.622454         -8.265367
# 4          GRU_pred    169.163528      0.468661         -8.895734
# 5     LSTM_GRU_pred    158.557411      0.412141        -11.008310
# 6       BiLSTM_pred    156.218536      0.386177         -7.828041
# 7   BiLSTM_GRU_pred    326.182879      1.124881         -6.425053
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    416.971981      1.415277         -8.485144
# 10         BNN_pred    176.936072      0.492683         -7.749598
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     83.057596      0.001046         -7.305484
# 1             HV_dw    230.423191      1.075386         -6.406805
# 2             HV_cw     46.564060     -0.242063         -8.766865
# 3         LSTM_pred    111.837928      0.227234         -3.860985
# 4          GRU_pred    138.092113      0.433958         -4.156199
# 5     LSTM_GRU_pred    138.007803      0.397883         -4.140184
# 6       BiLSTM_pred    139.034876      0.325943         -5.626936
# 7   BiLSTM_GRU_pred     91.280376      0.048657         -5.952527
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    162.386941      0.495753         -8.485144
# 10         BNN_pred     84.799627     -0.000819         -5.538338
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    142.169725      0.324446         -7.423999
# 1             HV_dw    274.708299      1.070170         -5.997496
# 2             HV_cw     15.367510     -0.413902         -9.274903
# 3         LSTM_pred    130.496162      0.294608         -7.869815
# 4          GRU_pred    243.875685      0.885839         -7.369886
# 5     LSTM_GRU_pred    230.389586      0.883313         -5.930766
# 6       BiLSTM_pred    156.049004      0.411838         -6.373592
# 7   BiLSTM_GRU_pred    137.665951      0.338717         -6.547730
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    242.259259      0.830961         -8.485144
# 10         BNN_pred    115.564217      0.200082         -7.123848
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    134.450928      0.268597         -8.295517
# 1             HV_dw    362.151519      1.416578         -7.188476
# 2             HV_cw     83.603662     -0.024219         -8.485144
# 3         LSTM_pred    130.496162      0.294608         -7.869815
# 4          GRU_pred    222.616388      0.749094        -11.130113
# 5     LSTM_GRU_pred    319.198078      1.260724         -8.049285
# 6       BiLSTM_pred    181.652972      0.541435         -5.643780
# 7   BiLSTM_GRU_pred    221.287481      0.773061         -6.441031
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    245.412535      0.807563         -8.485144
# 10         BNN_pred    112.873301      0.177364         -7.505482
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    184.943142      0.506336         -8.485144
# 1             HV_dw    256.341027      1.084947         -7.445175
# 2             HV_cw     99.238019      0.097326         -9.629084
# 3         LSTM_pred    185.546177      0.718144         -3.965621
# 4          GRU_pred    268.356511      1.063785         -4.698202
# 5     LSTM_GRU_pred    179.065944      0.582060         -5.398885
# 6       BiLSTM_pred    213.407318      0.673494         -6.738711
# 7   BiLSTM_GRU_pred     64.502014     -0.133330         -7.133412
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    173.306090      0.559553         -8.485144
# 10         BNN_pred    122.314872      0.241414         -6.706432
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    243.879357      0.727062         -8.485144
# 1             HV_dw    360.254267      1.350685         -5.426021
# 2             HV_cw     88.373129      0.040001         -9.612529
# 3         LSTM_pred    238.451523      0.782943         -7.591871
# 4          GRU_pred    426.478412      1.555188         -6.443676
# 5     LSTM_GRU_pred    277.033948      1.013693         -6.919311
# 6       BiLSTM_pred    217.246333      0.672575         -6.893445
# 7   BiLSTM_GRU_pred    141.164056      0.321503         -8.557715
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    260.370855      0.878363         -8.485144
# 10         BNN_pred    154.223441      0.379082         -8.160900
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    243.879357      0.727062         -8.485144
# 1             HV_dw    389.613768      1.408424         -5.806331
# 2             HV_cw    111.327809      0.123702         -9.410346
# 3         LSTM_pred    238.451523      0.782943         -7.591871
# 4          GRU_pred    355.610667      1.225962         -8.573957
# 5     LSTM_GRU_pred    337.621697      1.232118         -8.573957
# 6       BiLSTM_pred    232.732570      0.734603         -6.952047
# 7   BiLSTM_GRU_pred    213.852372      0.660918         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    239.511799      0.741462         -8.485144
# 10         BNN_pred    199.377081      0.587015         -8.160900
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.878716         -8.485144
# 1             HV_dw             0      1.206255         -8.485144
# 2             HV_cw             0      1.132715         -8.485144
# 3         LSTM_pred             0      1.125614         -8.485144
# 4          GRU_pred             0      1.122240         -8.485144
# 5     LSTM_GRU_pred             0      1.168831         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.132715         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.279405         -8.485144
# 10         BNN_pred             0      1.168831         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.071716         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.168831         -8.485144
# 5     LSTM_GRU_pred             0      1.168831         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.132715         -8.485144
# 10         BNN_pred             0      1.132715         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.132715         -8.485144
# 5     LSTM_GRU_pred             0      1.132715         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.071716         -8.485144
# 10         BNN_pred             0      1.132715         -8.485144
# 11               __             0      1.069809         -8.485144

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    317.288787      1.171975         -7.217204
# 1             HV_dw    348.035586      1.369314         -7.705191
# 2             HV_cw    255.269331      0.922473         -8.748976
# 3         LSTM_pred    227.272914      1.039746         -8.485144
# 4          GRU_pred    247.731171      1.062744         -8.485144
# 5     LSTM_GRU_pred    346.959080      1.026269         -8.528839
# 6       BiLSTM_pred    227.272914      1.039746         -8.485144
# 7   BiLSTM_GRU_pred     20.016099      1.108262         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    270.755767      0.871240         -8.485144
# 10         BNN_pred    342.595916      1.052014         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    341.167516      1.239442         -6.776091
# 1             HV_dw    457.905307      1.594053         -6.335067
# 2             HV_cw    199.973059      0.568465        -10.240623
# 3         LSTM_pred    189.195540      0.654168         -9.401095
# 4          GRU_pred    213.003812      0.612493         -9.890045
# 5     LSTM_GRU_pred    268.888949      0.851935        -10.732257
# 6       BiLSTM_pred    203.989662      0.581592         -8.340626
# 7   BiLSTM_GRU_pred    298.208167      1.160585         -5.323350
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    220.320566      0.599535         -8.514457
# 10         BNN_pred    332.463214      1.103655         -5.863996
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    163.577077      0.556798         -7.474576
# 1             HV_dw    480.150527      1.766263         -5.071616
# 2             HV_cw    185.445572      0.641328         -4.805632
# 3         LSTM_pred     77.267505      0.032830         -8.485144
# 4          GRU_pred    229.353030      0.718761         -8.406431
# 5     LSTM_GRU_pred    308.425875      1.071942         -8.836041
# 6       BiLSTM_pred    150.682493      0.347631         -8.478361
# 7   BiLSTM_GRU_pred    242.492588      0.881441         -6.133884
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    124.215838      0.175341         -8.485144
# 10         BNN_pred    314.585792      1.074322         -5.257201
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    252.814698      0.946591         -6.769256
# 1             HV_dw    444.768259      1.555842         -6.335067
# 2             HV_cw    206.771180      0.642389         -6.686452
# 3         LSTM_pred    151.374925      0.491353         -9.540495
# 4          GRU_pred    214.579961      0.621904         -9.844672
# 5     LSTM_GRU_pred    259.907592      0.817130        -10.860187
# 6       BiLSTM_pred    227.882880      0.692487         -8.286555
# 7   BiLSTM_GRU_pred    292.054516      1.171341         -5.873562
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred     94.760196      0.014826         -9.310856
# 10         BNN_pred    322.868821      1.064882         -5.906526
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    237.120270      0.792954         -7.614168
# 1             HV_dw    440.773317      1.536718         -6.335067
# 2             HV_cw    208.921663      0.607888         -8.839093
# 3         LSTM_pred    189.195540      0.654168         -9.401095
# 4          GRU_pred    213.003812      0.612493         -9.890045
# 5     LSTM_GRU_pred    237.890809      0.721368        -11.001004
# 6       BiLSTM_pred    203.989662      0.581592         -8.340626
# 7   BiLSTM_GRU_pred    290.602422      1.129425         -5.803644
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    178.796885      0.421997         -9.164577
# 10         BNN_pred    340.919050      1.133159         -5.827018
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    167.973771      0.519273        -10.323482
# 1             HV_dw    326.359526      1.309051         -7.764192
# 2             HV_cw    196.468213      0.631158         -6.106159
# 3         LSTM_pred    227.272914      0.970802         -8.496256
# 4          GRU_pred    248.213114      1.156883         -8.485144
# 5     LSTM_GRU_pred    374.776918      1.218621         -8.821043
# 6       BiLSTM_pred    227.272914      1.012729         -8.485144
# 7   BiLSTM_GRU_pred     20.016099      1.108262         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    287.615035      0.930698         -8.557715
# 10         BNN_pred    303.591808      0.928123         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    268.108063      1.158123         -9.734706
# 1             HV_dw    356.329736      1.402483         -7.705191
# 2             HV_cw    203.037187      0.581951         -6.385831
# 3         LSTM_pred    227.272914      1.012729         -8.485144
# 4          GRU_pred    247.731171      1.111893         -8.485144
# 5     LSTM_GRU_pred    349.770095      1.040043         -8.528839
# 6       BiLSTM_pred    227.272914      1.039746         -8.485144
# 7   BiLSTM_GRU_pred     20.016099      1.108262         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    252.228034      0.736811         -8.485144
# 10         BNN_pred    321.018567      0.975532         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    311.194821      1.150087         -7.583685
# 1             HV_dw    348.035586      1.369314         -7.705191
# 2             HV_cw    239.176967      0.861655         -8.340078
# 3         LSTM_pred    227.272914      1.039746         -8.485144
# 4          GRU_pred    247.731171      1.062744         -8.485144
# 5     LSTM_GRU_pred    346.959080      1.026269         -8.528839
# 6       BiLSTM_pred    227.272914      1.039746         -8.485144
# 7   BiLSTM_GRU_pred     20.016099      1.108262         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    259.608673      0.817715         -8.485144
# 10         BNN_pred    342.595916      1.052014         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.125963         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.071716         -8.485144
# 5     LSTM_GRU_pred             0      1.069809         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.069809         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.069809         -8.485144
# 5     LSTM_GRU_pred             0      1.069809         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.069809         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.069809         -8.485144
# 5     LSTM_GRU_pred             0      1.069809         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.069809         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    225.060989      0.951599         -9.106930
# 1             HV_dw    289.067911      1.124282         -8.293792
# 2             HV_cw    245.505520      0.732019         -8.675171
# 3         LSTM_pred      0.000000      1.069809         -8.485144
# 4          GRU_pred    346.959080      1.026269         -8.528839
# 5     LSTM_GRU_pred    347.863571      1.029588         -8.528839
# 6       BiLSTM_pred      0.000000      1.069809         -8.485144
# 7   BiLSTM_GRU_pred    262.194655      1.079135         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    266.024488      0.831666         -8.469611
# 10         BNN_pred    339.319147      1.036149         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    288.491366      0.990911         -7.029282
# 1             HV_dw    379.589897      1.279595         -7.706922
# 2             HV_cw    270.689366      0.822045         -7.700587
# 3         LSTM_pred    285.326238      0.876788         -8.314064
# 4          GRU_pred    198.777917      0.548779         -9.397213
# 5     LSTM_GRU_pred    303.770283      1.044069         -8.994451
# 6       BiLSTM_pred    249.333590      0.776148         -7.291776
# 7   BiLSTM_GRU_pred    292.363331      1.123992         -7.124640
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    172.785433      0.395975         -8.485144
# 10         BNN_pred    332.157514      1.071606         -7.378233
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     99.956884      0.109773         -9.092647
# 1             HV_dw    337.776426      1.165325         -7.764192
# 2             HV_cw    100.044038      0.039178         -6.808039
# 3         LSTM_pred    267.557996      0.894470         -7.352100
# 4          GRU_pred    278.623801      0.940844         -7.960677
# 5     LSTM_GRU_pred    299.290688      1.059071         -9.223112
# 6       BiLSTM_pred    238.649495      0.753907         -6.639877
# 7   BiLSTM_GRU_pred    234.359579      0.803481         -6.047465
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    169.076379      0.428238         -7.192565
# 10         BNN_pred    303.051677      0.993185         -7.727964
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    204.539022      0.689819         -7.943063
# 1             HV_dw    338.575086      1.135959         -7.764192
# 2             HV_cw    137.023150      0.242207         -6.439521
# 3         LSTM_pred    298.763142      0.932145         -8.314064
# 4          GRU_pred    183.187566      0.481479         -9.588728
# 5     LSTM_GRU_pred    282.683032      0.967295         -9.107449
# 6       BiLSTM_pred    264.930103      0.846641         -7.247608
# 7   BiLSTM_GRU_pred    218.502133      0.804132         -7.842998
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    143.403581      0.270280         -8.485144
# 10         BNN_pred    323.159054      1.040885         -7.428411
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    213.924978      0.642911         -9.657751
# 1             HV_dw    365.269632      1.229870         -7.706922
# 2             HV_cw    214.942277      0.616838         -7.148094
# 3         LSTM_pred    285.326238      0.876788         -8.314064
# 4          GRU_pred    187.972739      0.501909         -9.550105
# 5     LSTM_GRU_pred    302.762638      1.039828         -9.001408
# 6       BiLSTM_pred    249.333590      0.776148         -7.291776
# 7   BiLSTM_GRU_pred    271.855058      1.043444         -7.124640
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    242.375035      0.722270         -8.485144
# 10         BNN_pred    339.682372      1.102524         -7.336791
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    140.389379      0.319082        -12.310496
# 1             HV_dw    270.358644      1.068597         -8.629972
# 2             HV_cw    154.602150      0.368858         -6.769991
# 3         LSTM_pred      0.000000      1.069809         -8.485144
# 4          GRU_pred    386.901667      1.260729         -8.158933
# 5     LSTM_GRU_pred    377.500587      1.228764         -8.803601
# 6       BiLSTM_pred      0.000000      1.069809         -8.485144
# 7   BiLSTM_GRU_pred    211.542250      0.812960         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    181.341360      0.497886         -7.426990
# 10         BNN_pred    329.051386      1.021211         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    158.670453      0.402835        -11.639955
# 1             HV_dw    287.465875      1.118592         -8.273411
# 2             HV_cw    187.238282      0.564193         -6.296862
# 3         LSTM_pred      0.000000      1.069809         -8.485144
# 4          GRU_pred    349.770095      1.040043         -8.528839
# 5     LSTM_GRU_pred    370.619938      1.197054         -8.252667
# 6       BiLSTM_pred      0.000000      1.069809         -8.485144
# 7   BiLSTM_GRU_pred    219.710724      0.948068         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    218.634209      0.643410         -8.485144
# 10         BNN_pred    339.319147      1.036149         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    191.379276      0.818641         -9.657373
# 1             HV_dw    288.590908      1.122413         -8.296862
# 2             HV_cw    204.363845      0.580872         -7.355338
# 3         LSTM_pred      0.000000      1.069809         -8.485144
# 4          GRU_pred    359.818861      1.075361         -8.528839
# 5     LSTM_GRU_pred    360.731988      1.078691         -8.528839
# 6       BiLSTM_pred      0.000000      1.069809         -8.485144
# 7   BiLSTM_GRU_pred    261.044796      1.077232         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    219.849747      0.651944         -8.485144
# 10         BNN_pred    339.319147      1.036149         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.071716         -8.485144
# 5     LSTM_GRU_pred             0      1.069809         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.132715         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.069809         -8.485144
# 5     LSTM_GRU_pred             0      1.069809         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.069809         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.069809         -8.485144
# 5     LSTM_GRU_pred             0      1.069809         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.069809         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    280.707972      0.830439         -8.485144
# 1             HV_dw    411.455470      1.408359         -7.751573
# 2             HV_cw    291.680588      0.883717         -8.418217
# 3         LSTM_pred    237.325446      0.703843         -8.597840
# 4          GRU_pred    213.950780      0.675259         -8.695136
# 5     LSTM_GRU_pred    312.426787      1.032985         -9.514963
# 6       BiLSTM_pred    270.389327      0.866541         -5.963031
# 7   BiLSTM_GRU_pred    239.266632      0.861865         -9.192980
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    314.005208      1.027646         -8.607328
# 10         BNN_pred    339.901890      1.135787         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    268.892303      0.833778         -8.793029
# 1             HV_dw    468.948766      1.707416         -6.354807
# 2             HV_cw    276.560660      0.835295         -8.632916
# 3         LSTM_pred    243.122628      0.797470         -6.430367
# 4          GRU_pred    222.063962      0.691912         -7.832431
# 5     LSTM_GRU_pred    203.746246      0.639827         -7.643877
# 6       BiLSTM_pred    168.785396      0.435673         -7.828041
# 7   BiLSTM_GRU_pred    281.994141      0.951793         -5.762264
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    200.506681      0.560344         -8.754461
# 10         BNN_pred    283.435056      0.978966         -7.160698
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    187.386080      0.547123         -8.778358
# 1             HV_dw    275.873245      1.199888         -3.625419
# 2             HV_cw    105.593047      0.141523        -10.165167
# 3         LSTM_pred    120.162780      0.253764         -7.088261
# 4          GRU_pred    235.904839      0.858817         -6.827040
# 5     LSTM_GRU_pred    164.574374      0.534896         -6.100059
# 6       BiLSTM_pred    178.779568      0.534724         -6.703378
# 7   BiLSTM_GRU_pred    243.887604      0.927789         -5.499954
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred     85.829800      0.006806         -5.277370
# 10         BNN_pred    162.430153      0.518035         -4.325192
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    231.573712      0.711665         -8.826438
# 1             HV_dw    463.009733      1.812098         -6.443794
# 2             HV_cw    201.852266      0.662261         -9.524804
# 3         LSTM_pred    197.066230      0.616000         -7.356561
# 4          GRU_pred    196.227737      0.627241         -6.954122
# 5     LSTM_GRU_pred    203.667083      0.676199         -8.332934
# 6       BiLSTM_pred    190.931713      0.576763         -7.269984
# 7   BiLSTM_GRU_pred    267.463039      0.968697         -5.470520
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    151.546157      0.450944         -7.806967
# 10         BNN_pred    221.977232      0.795547         -5.481347
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    205.465445      0.578856         -8.793029
# 1             HV_dw    455.186413      1.694941         -6.381749
# 2             HV_cw    279.591096      0.953595         -8.601735
# 3         LSTM_pred    226.926022      0.710868         -7.721024
# 4          GRU_pred    249.379377      0.824311         -7.746438
# 5     LSTM_GRU_pred    212.323341      0.692480         -7.377720
# 6       BiLSTM_pred    145.689065      0.315445         -7.836052
# 7   BiLSTM_GRU_pred    318.812438      1.138175         -6.491160
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    185.559791      0.589657         -8.954197
# 10         BNN_pred    283.713651      0.999443         -6.659913
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    223.299511      0.665434         -8.485144
# 1             HV_dw    344.697917      1.285072         -8.036061
# 2             HV_cw    234.702392      0.766421         -8.993947
# 3         LSTM_pred    133.584948      0.285357         -7.991112
# 4          GRU_pred    248.434599      0.870040         -8.236286
# 5     LSTM_GRU_pred    279.134289      1.023763         -7.968810
# 6       BiLSTM_pred    258.534364      0.858011         -5.885302
# 7   BiLSTM_GRU_pred    184.300361      0.507066         -8.485144
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    223.636970      0.731576         -8.975227
# 10         BNN_pred    287.775947      1.011586         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    275.773018      0.842481         -8.485144
# 1             HV_dw    433.847425      1.539939         -7.751573
# 2             HV_cw    260.376352      0.867879         -8.754706
# 3         LSTM_pred    178.673091      0.452568         -8.314064
# 4          GRU_pred    211.756371      0.670088         -8.771674
# 5     LSTM_GRU_pred    316.686196      1.077399        -11.427439
# 6       BiLSTM_pred    286.131057      0.955861         -5.845325
# 7   BiLSTM_GRU_pred    200.664000      0.618995         -9.192980
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    223.164516      0.729280         -8.975227
# 10         BNN_pred    286.659167      0.967729         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    275.773018      0.858046         -8.485144
# 1             HV_dw    400.624819      1.393455         -7.751573
# 2             HV_cw    252.272855      0.804986         -8.547292
# 3         LSTM_pred    238.864947      0.703984         -8.622337
# 4          GRU_pred    211.756371      0.670088         -8.771674
# 5     LSTM_GRU_pred    336.898939      1.143273         -9.929762
# 6       BiLSTM_pred    265.007067      0.836567         -5.947522
# 7   BiLSTM_GRU_pred    269.745991      0.981367         -9.192980
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    251.865716      0.856794         -8.964695
# 10         BNN_pred    327.562634      1.091766         -8.485144
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.909353         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.071716         -8.485144
# 3         LSTM_pred             0      1.071716         -8.485144
# 4          GRU_pred             0      1.071716         -8.485144
# 5     LSTM_GRU_pred             0      1.071716         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.071716         -8.485144
# 10         BNN_pred             0      1.132519         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.069809         -8.485144
# 5     LSTM_GRU_pred             0      1.069809         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.132715         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.069809         -8.485144
# 5     LSTM_GRU_pred             0      1.069809         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.069809         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    316.163863      0.995382         -9.192980
# 1             HV_dw    385.487219      1.353795         -7.706922
# 2             HV_cw    317.925889      1.023438         -8.496076
# 3         LSTM_pred    236.411760      0.705601         -8.314064
# 4          GRU_pred    213.950780      0.675259         -8.695136
# 5     LSTM_GRU_pred    280.058827      0.957085         -6.337501
# 6       BiLSTM_pred    210.180011      0.618880         -6.940822
# 7   BiLSTM_GRU_pred    303.910448      1.018217         -6.498864
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    270.729027      0.891578         -8.855593
# 10         BNN_pred    197.485565      0.574200         -9.019562
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    200.376312      0.565011         -9.004819
# 1             HV_dw    377.754735      1.381786         -6.308330
# 2             HV_cw    217.174073      0.608331         -9.021373
# 3         LSTM_pred    217.847027      0.688097         -6.324071
# 4          GRU_pred    241.186111      0.835708         -5.822420
# 5     LSTM_GRU_pred    199.129613      0.608944         -7.493015
# 6       BiLSTM_pred    156.218536      0.386177         -7.828041
# 7   BiLSTM_GRU_pred    271.704834      0.910667         -5.762264
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    252.631072      0.825304         -6.295937
# 10         BNN_pred    197.880296      0.571944         -7.400688
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     83.057596      0.001046         -7.305484
# 1             HV_dw    256.511279      1.148337         -3.625419
# 2             HV_cw    116.211965      0.229083         -8.547717
# 3         LSTM_pred     82.979538     -0.023191         -6.167358
# 4          GRU_pred    207.826849      0.772921         -4.417052
# 5     LSTM_GRU_pred    140.101075      0.422986         -5.730493
# 6       BiLSTM_pred    139.034876      0.325943         -5.626936
# 7   BiLSTM_GRU_pred    183.637357      0.639952         -3.022463
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred     27.875250     -0.526628         -5.090524
# 10         BNN_pred     27.796147     -0.442496         -8.541535
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    142.169725      0.324446         -7.423999
# 1             HV_dw    251.570921      0.967198         -5.494340
# 2             HV_cw    143.295581      0.375998         -9.544978
# 3         LSTM_pred    193.529859      0.628764         -6.731628
# 4          GRU_pred    206.255974      0.762703         -4.723422
# 5     LSTM_GRU_pred    193.623684      0.685044         -6.928776
# 6       BiLSTM_pred    156.049004      0.411838         -6.373592
# 7   BiLSTM_GRU_pred    250.052985      0.931966         -3.624434
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    123.172279      0.282243         -7.090207
# 10         BNN_pred    117.469040      0.216950         -7.359450
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    134.450928      0.268597         -8.295517
# 1             HV_dw    293.891497      1.062150         -6.456608
# 2             HV_cw    172.223015      0.514297         -9.621040
# 3         LSTM_pred    217.480533      0.690887         -6.324071
# 4          GRU_pred    220.959562      0.734249         -6.622980
# 5     LSTM_GRU_pred    253.943629      0.977223         -5.937352
# 6       BiLSTM_pred    181.652972      0.541435         -5.643780
# 7   BiLSTM_GRU_pred    276.506463      1.031897         -4.407733
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    173.037408      0.574895         -6.726131
# 10         BNN_pred    196.242254      0.596509         -6.407536
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    184.943142      0.506336         -8.485144
# 1             HV_dw    275.503893      1.116296         -6.794612
# 2             HV_cw    140.822227      0.330523         -9.808869
# 3         LSTM_pred    131.744791      0.276466         -7.991112
# 4          GRU_pred    248.434599      0.870040         -8.236286
# 5     LSTM_GRU_pred    222.225244      0.854202         -6.751801
# 6       BiLSTM_pred    213.407318      0.673494         -6.738711
# 7   BiLSTM_GRU_pred    239.645568      0.905847         -5.415461
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    200.989878      0.682945         -9.376047
# 10         BNN_pred    144.827093      0.366626         -6.976644
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    243.879357      0.727062         -8.485144
# 1             HV_dw    295.658321      1.102176         -7.100868
# 2             HV_cw    212.860372      0.695872         -9.238868
# 3         LSTM_pred    214.027745      0.626047         -7.925326
# 4          GRU_pred    255.364261      0.902230         -8.566807
# 5     LSTM_GRU_pred    321.214862      1.213874         -7.656202
# 6       BiLSTM_pred    217.246333      0.672575         -6.893445
# 7   BiLSTM_GRU_pred    301.780516      1.090809         -6.091518
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    200.526168      0.680389         -9.376047
# 10         BNN_pred    182.490318      0.530194         -8.563431
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    243.879357      0.727062         -8.485144
# 1             HV_dw    354.890442      1.281452         -7.764192
# 2             HV_cw    206.418495      0.646435         -9.284614
# 3         LSTM_pred    225.391109      0.663397         -8.314064
# 4          GRU_pred    211.756371      0.670088         -8.771674
# 5     LSTM_GRU_pred    361.557441      1.353575         -6.716266
# 6       BiLSTM_pred    232.732570      0.734603         -6.952047
# 7   BiLSTM_GRU_pred    292.905673      1.017132         -6.105153
# 8         QRNN_pred    113.911672      0.126090         -5.830478
# 9          ESN_pred    204.802765      0.703019         -9.376047
# 10         BNN_pred    194.075293      0.573356         -8.032377
# 11               __      0.000000      1.069809         -8.485144
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.878716         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.071716         -8.485144
# 3         LSTM_pred             0      1.071716         -8.485144
# 4          GRU_pred             0      1.071716         -8.485144
# 5     LSTM_GRU_pred             0      1.071716         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.071716         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.071716         -8.485144
# 10         BNN_pred             0      1.132519         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.071716         -8.485144
# 3         LSTM_pred             0      1.071716         -8.485144
# 4          GRU_pred             0      1.071716         -8.485144
# 5     LSTM_GRU_pred             0      1.071716         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.123931         -8.485144
# 11               __             0      1.069809         -8.485144
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.069809         -8.485144
# 1             HV_dw             0      1.069809         -8.485144
# 2             HV_cw             0      1.069809         -8.485144
# 3         LSTM_pred             0      1.069809         -8.485144
# 4          GRU_pred             0      1.069809         -8.485144
# 5     LSTM_GRU_pred             0      1.069809         -8.485144
# 6       BiLSTM_pred             0      1.069809         -8.485144
# 7   BiLSTM_GRU_pred             0      1.069809         -8.485144
# 8         QRNN_pred             0      1.069809         -8.485144
# 9          ESN_pred             0      1.069809         -8.485144
# 10         BNN_pred             0      1.069809         -8.485144
# 11               __             0      1.069809         -8.485144

# %%
# path_1 = '/content/drive/MyDrive/Strategy/MA/HV/HV/'
# path_2 = '/content/drive/MyDrive/Strategy/MA/HV/DW_HV/'
# path_3 = '/content/drive/MyDrive/Strategy/MA/HV/CW_HV/'

# file_name = 'file_3.csv'
# file.to_csv(path_1 + file_name)

# filename = 'file_3.csv'
# dw_file.to_csv(path_2 + file_name)

# filename = 'file_3.csv'
# cw_file.to_csv(path_3 + file_name)
