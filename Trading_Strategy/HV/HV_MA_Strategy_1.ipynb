# %%
import pandas as pd
import numpy as np
import yfinance as yf
from google.colab import drive
from datetime import datetime
import matplotlib.pyplot as plt
import builtins

# %% [markdown]
# # Loading data

# %%
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Volatility/'
path_1 = '/content/drive/MyDrive/Volatility/Predictions/HV/'
path_2 = '/content/drive/MyDrive/Volatility/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/Not_normal_wc_real/'

def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

filename = 'HV_data.csv'
HV_dw = pd.read_csv(path_2 + filename)

filename = 'HV_data.csv'
HV_cw = pd.read_csv(path_3 + filename)

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path_1 + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path_1 + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path_1 + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path_1 + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path_1 + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(HV_dw)
set_index(HV_cw)

start = datetime(2020, 11, 5)
end = datetime(2022, 12, 23)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")

data_s['Close'] = ticker_historical.Close.values

start = datetime(2020, 10, 1)
end = datetime(2022, 12, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")

data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['HV'] = volatility_proxies['HV'].loc['2020-10-01':'2022-12-30'].values
data_s['HV'] = volatility_proxies['HV'].loc['2020-11-05':'2022-12-22'].values

data_l['HV_dw'] = HV_dw['HV'].loc['2020-10-01':'2022-12-30'].values
data_s['HV_dw'] = HV_dw['HV'].loc['2020-11-05':'2022-12-22'].values

data_l['HV_cw'] = HV_cw['HV'].loc['2020-10-01':'2022-12-30'].values
data_s['HV_cw'] = HV_cw['HV'].loc['2020-11-05':'2022-12-22'].values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2020-11-05':'2022-12-22']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2020-11-05':'2022-12-22']

data_2022_y1 = data_s.head(268)
data_2022_y2 = data_s.tail(269)
data_2022_2y = data_s
# Out:
# Mounted at /content/drive
# <ipython-input-2-ff306df51396>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %%
path_1 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/'
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/HV/'
path_2 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
path_4 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/'

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path_1 + filename)

filename = 'HV_data.csv'
HV_dw = pd.read_csv(path_2 + filename)

filename = 'HV_data.csv'
HV_cw = pd.read_csv(path_3 + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path_4 + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path_4 + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(HV_dw)
set_index(HV_cw)

start = datetime(2022, 7, 14)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")
data_s['Close'] = ticker_historical.Close.values

start = datetime(2022, 5, 31)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")
data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['HV'] = (volatility_proxies['HV'].loc['2022-05-31':'2024-8-30']).values
data_s['HV'] = (volatility_proxies['HV'].loc['2022-07-14':'2024-8-30']).values

data_l['HV_dw'] = (HV_dw['HV'].loc['2022-05-31':'2024-8-30']).values
data_s['HV_dw'] = (HV_dw['HV'].loc['2022-07-14':'2024-8-30']).values

data_l['HV_cw'] = (HV_cw['HV'].loc['2022-05-31':'2024-8-30']).values
data_s['HV_cw'] = (HV_cw['HV'].loc['2022-07-14':'2024-8-30']).values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2022-07-14':'2024-8-30']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2022-07-14':'2024-8-30']

data_2024_y1 = data_s.head(268)
data_2024_y2 = data_s.tail(269)
data_2024_2y1 = data_s
# Out:
# <ipython-input-2-ff306df51396>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %% [markdown]
# # Strategy

# %% [markdown]
# ## Without volatility

# %%
def strategy(data, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0

  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# ## With volatility

# %%
def strategy_with_vol_1(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_2(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_3(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_4(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_5(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_6(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_7(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_8(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_9(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_10(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_11(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_12(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_13(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_14(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_15(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_16(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_17(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_18(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_19(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_20(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_21(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_22(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_23(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_24(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_25(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_26(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_27(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_28(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_29(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_30(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_31(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_32(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_33(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_34(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_35(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_36(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_37(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_38(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_39(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_40(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_41(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_42(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_43(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_44(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# # Backtest

# %%
def backtest_function(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, data_f[vol], short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
def backtest_function_abs(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, abs(data_f[vol]), short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
volatility = ['HV', 'HV_dw', 'HV_cw', 'LSTM_pred', 'GRU_pred', 'LSTM_GRU_pred', 'BiLSTM_pred',
              'BiLSTM_GRU_pred', 'QRNN_pred', 'ESN_pred', 'BNN_pred']

# %%
def backtest(data_s, short_window=10, long_window=50):
  S1_results = backtest_function(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results = backtest_function(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results = backtest_function(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results = backtest_function(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results = backtest_function(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results = backtest_function(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results = backtest_function(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results = backtest_function(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results = backtest_function(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results = backtest_function(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results = backtest_function(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results = backtest_function(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results = backtest_function(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results = backtest_function(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results = backtest_function(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results = backtest_function(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results = backtest_function(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results = backtest_function(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results = backtest_function(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results = backtest_function(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results = backtest_function(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results = backtest_function(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results = backtest_function(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results = backtest_function(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results = backtest_function(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results = backtest_function(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results = backtest_function(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results = backtest_function(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results = backtest_function(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results = backtest_function(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results = backtest_function(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results = backtest_function(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results = backtest_function(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results = backtest_function(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results = backtest_function(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results = backtest_function(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results = backtest_function(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results = backtest_function(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results = backtest_function(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results = backtest_function(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results = backtest_function(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results = backtest_function(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results = backtest_function(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results = backtest_function(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results.loc[len(S1_results)] = new_row
  S2_results.loc[len(S2_results)] = new_row
  S3_results.loc[len(S3_results)] = new_row
  S4_results.loc[len(S4_results)] = new_row
  S5_results.loc[len(S5_results)] = new_row
  S6_results.loc[len(S6_results)] = new_row
  S7_results.loc[len(S7_results)] = new_row
  S8_results.loc[len(S8_results)] = new_row
  S9_results.loc[len(S9_results)] = new_row
  S10_results.loc[len(S10_results)] = new_row
  S11_results.loc[len(S11_results)] = new_row
  S12_results.loc[len(S12_results)] = new_row
  S13_results.loc[len(S13_results)] = new_row
  S14_results.loc[len(S14_results)] = new_row
  S15_results.loc[len(S15_results)] = new_row
  S16_results.loc[len(S16_results)] = new_row
  S17_results.loc[len(S17_results)] = new_row
  S18_results.loc[len(S18_results)] = new_row
  S19_results.loc[len(S19_results)] = new_row
  S20_results.loc[len(S20_results)] = new_row
  S21_results.loc[len(S21_results)] = new_row
  S22_results.loc[len(S22_results)] = new_row

  S23_results.loc[len(S23_results)] = new_row
  S24_results.loc[len(S24_results)] = new_row
  S25_results.loc[len(S25_results)] = new_row
  S26_results.loc[len(S26_results)] = new_row
  S27_results.loc[len(S27_results)] = new_row
  S28_results.loc[len(S28_results)] = new_row
  S29_results.loc[len(S29_results)] = new_row
  S30_results.loc[len(S30_results)] = new_row
  S31_results.loc[len(S31_results)] = new_row
  S32_results.loc[len(S32_results)] = new_row
  S33_results.loc[len(S33_results)] = new_row
  S34_results.loc[len(S34_results)] = new_row
  S35_results.loc[len(S35_results)] = new_row
  S36_results.loc[len(S36_results)] = new_row
  S37_results.loc[len(S37_results)] = new_row
  S38_results.loc[len(S38_results)] = new_row
  S39_results.loc[len(S39_results)] = new_row
  S40_results.loc[len(S40_results)] = new_row
  S41_results.loc[len(S41_results)] = new_row
  S42_results.loc[len(S42_results)] = new_row
  S43_results.loc[len(S43_results)] = new_row
  S44_results.loc[len(S44_results)] = new_row

  return S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results

# %%
def backtest_abs(data_s, short_window=10, long_window=50):
  S1_results_abs = backtest_function_abs(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results_abs = backtest_function_abs(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results_abs = backtest_function_abs(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results_abs = backtest_function_abs(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results_abs = backtest_function_abs(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results_abs = backtest_function_abs(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results_abs = backtest_function_abs(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results_abs = backtest_function_abs(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results_abs = backtest_function_abs(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results_abs = backtest_function_abs(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results_abs = backtest_function_abs(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results_abs = backtest_function_abs(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results_abs = backtest_function_abs(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results_abs = backtest_function_abs(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results_abs = backtest_function_abs(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results_abs = backtest_function_abs(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results_abs = backtest_function_abs(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results_abs = backtest_function_abs(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results_abs = backtest_function_abs(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results_abs = backtest_function_abs(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results_abs = backtest_function_abs(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results_abs = backtest_function_abs(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results_abs = backtest_function_abs(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results_abs = backtest_function_abs(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results_abs = backtest_function_abs(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results_abs = backtest_function_abs(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results_abs = backtest_function_abs(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results_abs = backtest_function_abs(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results_abs = backtest_function_abs(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results_abs = backtest_function_abs(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results_abs = backtest_function_abs(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results_abs = backtest_function_abs(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results_abs = backtest_function_abs(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results_abs = backtest_function_abs(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results_abs = backtest_function_abs(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results_abs = backtest_function_abs(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results_abs = backtest_function_abs(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results_abs = backtest_function_abs(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results_abs = backtest_function_abs(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results_abs = backtest_function_abs(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results_abs = backtest_function_abs(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results_abs = backtest_function_abs(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results_abs = backtest_function_abs(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results_abs = backtest_function_abs(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results_abs.loc[len(S1_results_abs)] = new_row
  S2_results_abs.loc[len(S2_results_abs)] = new_row
  S3_results_abs.loc[len(S3_results_abs)] = new_row
  S4_results_abs.loc[len(S4_results_abs)] = new_row
  S5_results_abs.loc[len(S5_results_abs)] = new_row
  S6_results_abs.loc[len(S6_results_abs)] = new_row
  S7_results_abs.loc[len(S7_results_abs)] = new_row
  S8_results_abs.loc[len(S8_results_abs)] = new_row
  S9_results_abs.loc[len(S9_results_abs)] = new_row
  S10_results_abs.loc[len(S10_results_abs)] = new_row
  S11_results_abs.loc[len(S11_results_abs)] = new_row
  S12_results_abs.loc[len(S12_results_abs)] = new_row
  S13_results_abs.loc[len(S13_results_abs)] = new_row
  S14_results_abs.loc[len(S14_results_abs)] = new_row
  S15_results_abs.loc[len(S15_results_abs)] = new_row
  S16_results_abs.loc[len(S16_results_abs)] = new_row
  S17_results_abs.loc[len(S17_results_abs)] = new_row
  S18_results_abs.loc[len(S18_results_abs)] = new_row
  S19_results_abs.loc[len(S19_results_abs)] = new_row
  S20_results_abs.loc[len(S20_results_abs)] = new_row
  S21_results_abs.loc[len(S21_results_abs)] = new_row
  S22_results_abs.loc[len(S22_results_abs)] = new_row

  S23_results_abs.loc[len(S23_results_abs)] = new_row
  S24_results_abs.loc[len(S24_results_abs)] = new_row
  S25_results_abs.loc[len(S25_results_abs)] = new_row
  S26_results_abs.loc[len(S26_results_abs)] = new_row
  S27_results_abs.loc[len(S27_results_abs)] = new_row
  S28_results_abs.loc[len(S28_results_abs)] = new_row
  S29_results_abs.loc[len(S29_results_abs)] = new_row
  S30_results_abs.loc[len(S30_results_abs)] = new_row
  S31_results_abs.loc[len(S31_results_abs)] = new_row
  S32_results_abs.loc[len(S32_results_abs)] = new_row
  S33_results_abs.loc[len(S33_results_abs)] = new_row
  S34_results_abs.loc[len(S34_results_abs)] = new_row
  S35_results_abs.loc[len(S35_results_abs)] = new_row
  S36_results_abs.loc[len(S36_results_abs)] = new_row
  S37_results_abs.loc[len(S37_results_abs)] = new_row
  S38_results_abs.loc[len(S38_results_abs)] = new_row
  S39_results_abs.loc[len(S39_results_abs)] = new_row
  S40_results_abs.loc[len(S40_results_abs)] = new_row
  S41_results_abs.loc[len(S41_results_abs)] = new_row
  S42_results_abs.loc[len(S42_results_abs)] = new_row
  S43_results_abs.loc[len(S43_results_abs)] = new_row
  S44_results_abs.loc[len(S44_results_abs)] = new_row

  return S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs

# %% [markdown]
# # Final Results

# %%
def check_strategy(data, HV):

    sharpe_ratio_HV = data.loc[data['Volatility'] == HV, 'Sharpe ratio'].values[0]
    sharpe_ratio_pure = data.loc[data['Volatility'] == '__', 'Sharpe ratio'].values[0]

    max_drawdown_HV = data.loc[data['Volatility'] == HV, 'Max drawdown (%)'].values[0]
    max_drawdown_pure = data.loc[data['Volatility'] == '__', 'Max drawdown (%)'].values[0]

    total_profit_HV = data.loc[data['Volatility'] == HV, 'Total profit'].values[0]
    total_profit_pure = data.loc[data['Volatility'] == '__', 'Total profit'].values[0]

    is_HV_sharpe_positive = sharpe_ratio_HV > 0
    is_HV_sharpe_greater_than_pure_sharpe = sharpe_ratio_HV > sharpe_ratio_pure
    is_HV_dd_greater_than_pure_dd = max_drawdown_HV > max_drawdown_pure
    is_pure_tp_greater_than_HV_tp = total_profit_pure > total_profit_HV

    all_sharpes_greater_than_Pure_sharpe = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Sharpe ratio'] > sharpe_ratio_pure)
    all_sharpes_greater_than_Pure_sharpe_percentage = (all_sharpes_greater_than_Pure_sharpe.sum()/8) * 100

    positive_sharpes = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Sharpe ratio'] > 0)
    positive_sharpes_percentage = (positive_sharpes.sum()/8) * 100

    HV_sharpe_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Sharpe ratio'] < sharpe_ratio_HV)
    HV_sharpe_greater_than_all_percentage = (HV_sharpe_greater_than_all.sum()/8) * 100

    HV_dd_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Max drawdown (%)'] < max_drawdown_HV)
    HV_dd_greater_than_all_percentage = (HV_dd_greater_than_all.sum()/8) * 100

    HV_tp_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Total profit'] < total_profit_HV)
    HV_tp_greater_than_all_percentage = (HV_tp_greater_than_all.sum()/8) * 100

    return is_HV_sharpe_positive, is_HV_sharpe_greater_than_pure_sharpe, is_HV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, HV_sharpe_greater_than_all_percentage, HV_dd_greater_than_all_percentage, HV_tp_greater_than_all_percentage

# %%
def get_final_results(year, final_results, HV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results[f'S{i}_results']

    if(HV == 'HV'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV_cw'])]

    elif(HV == 'HV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV', 'HV_cw'])]

    elif(HV == 'HV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV'])]

    is_HV_sharpe_positive, is_HV_sharpe_greater_than_pure_sharpe, is_HV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, HV_sharpe_greater_than_all_percentage, HV_dd_greater_than_all_percentage, HV_tp_greater_than_all_percentage = check_strategy(strategy_result, HV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '-',
                'HV_sharpe > 0': is_HV_sharpe_positive,
                'HV_sharpe > Pure_sharpe': is_HV_sharpe_greater_than_pure_sharpe,
                'HV_dd > Pure_dd': is_HV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'HV_sharpe > Pred_sharpe (%)': HV_sharpe_greater_than_all_percentage,
                'HV_dd > Pred_dd (%)': HV_dd_greater_than_all_percentage,
                'HV_tp > Pred_tp (%)': HV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
def get_final_results_1(year, final_results, HV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results_abs[f'S{i}_results_abs']

    if(HV == 'HV'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV_cw'])]
      # res_combined
      # res_combined = pd.concat(details, strategy_result.drop())

    elif(HV == 'HV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV', 'HV_cw'])]

    elif(HV == 'HV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV'])]

    is_HV_sharpe_positive, is_HV_sharpe_greater_than_pure_sharpe, is_HV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, HV_sharpe_greater_than_all_percentage, HV_dd_greater_than_all_percentage, HV_tp_greater_than_all_percentage = check_strategy(strategy_result, HV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '+',
                'HV_sharpe > 0': is_HV_sharpe_positive,
                'HV_sharpe > Pure_sharpe': is_HV_sharpe_greater_than_pure_sharpe,
                'HV_dd > Pure_dd': is_HV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'HV_sharpe > Pred_sharpe (%)': HV_sharpe_greater_than_all_percentage,
                'HV_dd > Pred_dd (%)': HV_dd_greater_than_all_percentage,
                'HV_tp > Pred_tp (%)': HV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'HV_sharpe > 0', 'HV_sharpe > Pure_sharpe',
                                              'HV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'HV_sharpe > Pred_sharpe (%)',
                                              'HV_dd > Pred_dd (%)', 'HV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

dw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'HV_sharpe > 0', 'HV_sharpe > Pure_sharpe',
                                              'HV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'HV_sharpe > Pred_sharpe (%)',
                                              'HV_dd > Pred_dd (%)', 'HV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

cw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'HV_sharpe > 0', 'HV_sharpe > Pure_sharpe',
                                              'HV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'HV_sharpe > Pred_sharpe (%)',
                                              'HV_dd > Pred_dd (%)', 'HV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

# %%
# details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# dw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# cw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y1', file, 'HV')
get_final_results_1('2022_y1', file, 'HV')

get_final_results('2022_y1', dw_file, 'HV_dw')
get_final_results_1('2022_y1', dw_file, 'HV_dw')

get_final_results('2022_y1', cw_file, 'HV_cw')
get_final_results_1('2022_y1', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-36-d38f2ed52328>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y2', file, 'HV')
get_final_results_1('2022_y2', file, 'HV')

get_final_results('2022_y2', dw_file, 'HV_dw')
get_final_results_1('2022_y2', dw_file, 'HV_dw')

get_final_results('2022_y2', cw_file, 'HV_cw')
get_final_results_1('2022_y2', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-35-b85f21403d3c>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.562776         -9.904078
# 1             HV_dw    -16.909795     -0.093997         -6.984195
# 2             HV_cw      9.412156     -0.646359         -9.358423
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred     18.414117     -0.382152         -9.092906
# 5     LSTM_GRU_pred    -58.222256     -0.433847         -9.165111
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred    -57.423747     -1.053508        -10.785747
# 10         BNN_pred    -54.290084     -0.399780         -8.754749
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      3.675444     -0.494012         -9.048624
# 1             HV_dw     19.647913     -0.138959         -7.045049
# 2             HV_cw     42.352819     -0.212361         -7.004654
# 3         LSTM_pred    -77.632996     -0.604456        -11.156032
# 4          GRU_pred    -62.526450     -0.860327        -10.820362
# 5     LSTM_GRU_pred    -84.114196     -1.504898        -13.468142
# 6       BiLSTM_pred     -3.370510     -0.443676         -9.476473
# 7   BiLSTM_GRU_pred    -63.658141     -0.791114        -13.053323
# 8         QRNN_pred     10.111867     -0.393892         -8.051887
# 9          ESN_pred      7.536425     -0.556834         -9.184324
# 10         BNN_pred    -39.501004     -0.625378         -9.405371
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      8.525677     -0.382149         -7.602717
# 1             HV_dw     26.224920     -0.096042         -6.790444
# 2             HV_cw      2.153261     -0.573956         -7.556758
# 3         LSTM_pred    -95.265436     -0.767754        -11.156032
# 4          GRU_pred    -58.785536     -0.919005         -8.456007
# 5     LSTM_GRU_pred   -124.823562     -2.333187        -17.874803
# 6       BiLSTM_pred    -36.594021     -1.018701         -9.134180
# 7   BiLSTM_GRU_pred    -53.906471     -0.826870         -8.964952
# 8         QRNN_pred      5.607186     -0.517383         -8.064382
# 9          ESN_pred    -28.257979     -1.250951        -10.986631
# 10         BNN_pred      4.384014     -0.282060         -7.770263
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     11.835866     -0.358648         -8.173232
# 1             HV_dw     29.385343     -0.058863         -6.722731
# 2             HV_cw    -10.165170     -0.613900         -8.679832
# 3         LSTM_pred    -77.632996     -0.604456        -11.156032
# 4          GRU_pred    -59.547585     -0.849129         -9.589508
# 5     LSTM_GRU_pred   -115.276752     -1.845272        -15.793462
# 6       BiLSTM_pred    -42.178139     -0.917793         -9.960618
# 7   BiLSTM_GRU_pred    -44.038782     -0.640427        -10.022598
# 8         QRNN_pred      5.607186     -0.433065         -7.987355
# 9          ESN_pred    -34.341374     -0.943841         -9.337145
# 10         BNN_pred    -42.370285     -0.650325         -9.676003
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      3.675444     -0.494012         -9.048624
# 1             HV_dw     19.647913     -0.138959         -7.045049
# 2             HV_cw     -9.974606     -0.688252         -8.391737
# 3         LSTM_pred    -77.632996     -0.604456        -11.156032
# 4          GRU_pred    -66.230348     -0.897913        -10.820362
# 5     LSTM_GRU_pred    -84.114196     -1.504898        -13.468142
# 6       BiLSTM_pred     -3.370510     -0.443676         -9.476473
# 7   BiLSTM_GRU_pred    -63.658141     -0.791114        -13.053323
# 8         QRNN_pred     10.111867     -0.393892         -8.051887
# 9          ESN_pred    -42.398840     -1.126171        -11.011747
# 10         BNN_pred    -39.501004     -0.625378         -9.405371
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.480781         -9.825790
# 1             HV_dw    -27.237526     -0.184088         -6.768211
# 2             HV_cw     -5.656021     -0.642618         -9.135871
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred     42.298562     -0.216677         -8.136556
# 5     LSTM_GRU_pred    -71.381570     -0.754763        -10.306641
# 6       BiLSTM_pred    -95.258931     -0.856673        -12.231137
# 7   BiLSTM_GRU_pred    -85.182102     -0.949842        -10.419008
# 8         QRNN_pred      4.020430     -0.518078         -9.868036
# 9          ESN_pred    -48.448725     -1.436318        -12.836141
# 10         BNN_pred    -60.999202     -0.572830         -8.873977
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.491784         -9.843974
# 1             HV_dw    -14.704840     -0.075130         -6.768211
# 2             HV_cw    -13.566291     -0.615908         -9.683107
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred     11.921578     -0.444716         -7.907640
# 5     LSTM_GRU_pred    -71.381570     -0.672667         -9.444331
# 6       BiLSTM_pred    -71.271091     -0.786997        -10.157965
# 7   BiLSTM_GRU_pred    -64.635364     -0.680710         -9.904078
# 8         QRNN_pred      4.020430     -0.435442         -9.773782
# 9          ESN_pred    -44.401410     -1.065091        -10.906263
# 10         BNN_pred    -54.290084     -0.399780         -8.754749
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.562776         -9.904078
# 1             HV_dw    -16.909795     -0.093997         -6.984195
# 2             HV_cw    -28.189732     -0.980275        -10.730884
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred      4.730963     -0.496632         -9.216740
# 5     LSTM_GRU_pred    -58.222256     -0.433847         -9.165111
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred    -64.110635     -1.210529        -11.602605
# 10         BNN_pred    -54.290084     -0.399780         -8.754749
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -71.271091     -0.545150         -9.841785
# 2             HV_cw    -90.490217     -0.781232        -12.394462
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -64.635364     -0.680710         -9.904078
# 6       BiLSTM_pred    -95.258931     -0.856673        -12.231137
# 7   BiLSTM_GRU_pred    -85.182102     -0.949842        -10.419008
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -55.729010     -0.425844         -9.094755
# 10         BNN_pred    -71.271091     -0.659604         -9.904078
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -64.635364     -0.486499         -9.841785
# 2             HV_cw    -80.086074     -0.631451        -11.392317
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.680710         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.600334         -9.904078
# 6       BiLSTM_pred    -71.271091     -0.786997        -10.157965
# 7   BiLSTM_GRU_pred    -64.635364     -0.680710         -9.904078
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -51.712661     -0.390219         -9.094755
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -64.635364     -0.486499         -9.841785
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.600334         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -71.271091     -0.545150         -9.841785
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.562776         -9.904078
# 1             HV_dw    -44.180771     -0.318871         -7.715239
# 2             HV_cw    -90.884143     -0.730012        -10.826327
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -67.651552     -0.516477        -10.163255
# 5     LSTM_GRU_pred    -19.084381     -0.618153         -9.904078
# 6       BiLSTM_pred    -63.112223     -0.473418         -9.680233
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred     -5.172519     -0.562776         -9.904078
# 10         BNN_pred     17.832648     -0.448261         -8.806530
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      9.394323     -0.447145         -8.485429
# 1             HV_dw     23.981212     -0.046971         -7.266001
# 2             HV_cw     39.679194     -0.389044         -8.986057
# 3         LSTM_pred    -39.129094     -0.620414         -9.849412
# 4          GRU_pred    -57.604861     -0.819362         -9.688431
# 5     LSTM_GRU_pred      8.216444     -0.352019         -9.507399
# 6       BiLSTM_pred    -19.049624     -0.572466        -10.431352
# 7   BiLSTM_GRU_pred    -36.425916     -0.630792        -10.125255
# 8         QRNN_pred     13.791342     -0.355436         -9.317515
# 9          ESN_pred    -44.630181     -1.115727        -11.141403
# 10         BNN_pred    -30.420314     -0.547183         -9.228761
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     14.272193     -0.333911         -7.559643
# 1             HV_dw     44.201356      0.201748         -6.722731
# 2             HV_cw     16.336816     -0.446338         -7.020797
# 3         LSTM_pred    -39.328345     -0.631584         -9.870024
# 4          GRU_pred    -30.701099     -0.647620         -7.494255
# 5     LSTM_GRU_pred    -31.899170     -0.890741        -10.504354
# 6       BiLSTM_pred    -30.350847     -0.953173         -9.134180
# 7   BiLSTM_GRU_pred    -63.292515     -0.908487        -10.562025
# 8         QRNN_pred    -29.909167     -0.888580        -10.242657
# 9          ESN_pred    -26.212842     -1.209284        -12.760449
# 10         BNN_pred    -35.656012     -0.649553         -9.250390
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     17.601243     -0.311596         -7.619571
# 1             HV_dw     33.760024      0.033877         -6.722731
# 2             HV_cw     16.811032     -0.658683         -7.866254
# 3         LSTM_pred    -39.129094     -0.620414         -9.849412
# 4          GRU_pred    -58.481783     -0.842746         -8.982676
# 5     LSTM_GRU_pred    -16.424100     -0.603359         -9.810741
# 6       BiLSTM_pred    -27.114329     -0.777904         -9.740665
# 7   BiLSTM_GRU_pred    -47.776493     -0.752446         -9.725543
# 8         QRNN_pred    -10.008591     -0.526731         -9.504456
# 9          ESN_pred    -61.835922     -1.176417        -11.372929
# 10         BNN_pred    -62.335445     -0.857789         -9.506584
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      9.394323     -0.447145         -8.485429
# 1             HV_dw     23.981212     -0.046971         -7.266001
# 2             HV_cw     24.001020     -0.540956         -9.054779
# 3         LSTM_pred    -39.129094     -0.620414         -9.849412
# 4          GRU_pred    -57.604861     -0.819362         -9.688431
# 5     LSTM_GRU_pred    -33.087730     -0.744924         -9.606051
# 6       BiLSTM_pred    -17.452251     -0.559048        -10.285499
# 7   BiLSTM_GRU_pred    -36.425916     -0.630792        -10.125255
# 8         QRNN_pred     13.791342     -0.355436         -9.317515
# 9          ESN_pred    -53.377678     -1.206751        -11.955005
# 10         BNN_pred    -30.420314     -0.547183         -9.228761
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.480781         -9.825790
# 1             HV_dw    -48.833027     -0.359839         -7.537836
# 2             HV_cw    -59.817370     -0.485516         -9.221644
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred     17.668325     -0.050616         -7.118181
# 5     LSTM_GRU_pred     -2.991289     -0.600313         -9.904078
# 6       BiLSTM_pred    -92.662781     -0.832674        -11.979284
# 7   BiLSTM_GRU_pred    -92.697540     -0.992373        -12.230686
# 8         QRNN_pred    -16.162154     -0.756038         -9.221644
# 9          ESN_pred     27.768547     -0.533695         -9.221644
# 10         BNN_pred     -2.966454     -0.619648         -8.907603
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.491784         -9.843974
# 1             HV_dw    -42.036981     -0.300572         -7.537836
# 2             HV_cw    -54.460268     -0.435624         -9.221644
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -43.494623     -0.511106         -7.824107
# 5     LSTM_GRU_pred    -23.162883     -0.627083         -9.904078
# 6       BiLSTM_pred    -63.112223     -0.713977        -10.011667
# 7   BiLSTM_GRU_pred    -88.794596     -0.954426        -12.478466
# 8         QRNN_pred      4.020430     -0.404028         -9.735824
# 9          ESN_pred     -5.172519     -0.564042         -9.904078
# 10         BNN_pred     17.832648     -0.448261         -8.806530
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.562776         -9.904078
# 1             HV_dw    -44.180771     -0.318871         -7.715239
# 2             HV_cw    -94.252131     -0.773468        -11.156687
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -67.651552     -0.516477        -10.163255
# 5     LSTM_GRU_pred     -3.697289     -0.437763         -9.771449
# 6       BiLSTM_pred    -63.112223     -0.473418         -9.680233
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred     -5.172519     -0.491784         -9.843974
# 10         BNN_pred     17.832648     -0.448261         -8.806530
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -71.271091     -0.545150         -9.841785
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -64.635364     -0.600334         -9.904078
# 6       BiLSTM_pred    -95.258931     -0.856673        -12.231137
# 7   BiLSTM_GRU_pred    -92.697540     -0.992373        -12.230686
# 8         QRNN_pred    -62.023620     -0.671578         -9.221644
# 9          ESN_pred    -33.663253     -0.237747         -9.094755
# 10         BNN_pred    -71.271091     -0.659604         -9.904078
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -64.635364     -0.486499         -9.841785
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.680710         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.727191        -10.157965
# 7   BiLSTM_GRU_pred    -88.794596     -0.954426        -12.478466
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -64.635364     -0.486499         -9.841785
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.486499         -9.841785
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -14.062075     -0.635037         -9.904078
# 1             HV_dw    -21.024029     -0.476675         -9.588352
# 2             HV_cw    -17.197250     -0.330509         -9.808231
# 3         LSTM_pred     -8.903918     -0.382640         -9.091691
# 4          GRU_pred    -17.116244     -0.333420         -6.502787
# 5     LSTM_GRU_pred     -6.873756     -0.589994        -10.155108
# 6       BiLSTM_pred    -48.311401     -0.697648        -11.758406
# 7   BiLSTM_GRU_pred    -47.605838     -0.847565        -13.383195
# 8         QRNN_pred      1.308214     -0.454394         -9.800256
# 9          ESN_pred    -17.771358     -0.101012         -9.094755
# 10         BNN_pred    -21.895640     -0.471250         -9.520480
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -22.566329     -0.775913         -9.904078
# 1             HV_dw     56.520216      0.166803         -8.732659
# 2             HV_cw    -17.097993     -0.501630         -9.221644
# 3         LSTM_pred    -23.371110     -0.437706         -8.451006
# 4          GRU_pred    -58.430285     -0.906416         -8.977697
# 5     LSTM_GRU_pred    -33.922715     -0.671561        -11.941016
# 6       BiLSTM_pred     -4.840291     -0.380818         -8.883241
# 7   BiLSTM_GRU_pred     10.540931     -0.245368         -6.599083
# 8         QRNN_pred    -22.566329     -0.775913         -9.904078
# 9          ESN_pred    -14.367220     -0.074043         -9.094755
# 10         BNN_pred      6.434967     -0.245204         -6.746429
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw    108.986445      0.693915         -2.851301
# 2             HV_cw    -32.051054     -2.143146         -5.055486
# 3         LSTM_pred   -113.408230     -2.017916        -11.340823
# 4          GRU_pred     -2.744190     -0.452021         -7.882013
# 5     LSTM_GRU_pred    -29.912177     -0.563132        -10.628068
# 6       BiLSTM_pred    -44.765015     -0.897832         -7.475255
# 7   BiLSTM_GRU_pred    -40.117327     -1.361026         -8.444143
# 8         QRNN_pred    -75.476863     -1.752951        -10.629292
# 9          ESN_pred    -19.171098     -0.169642         -6.432429
# 10         BNN_pred     12.839227     -0.264166         -5.313410
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -1.452023        -12.226836
# 1             HV_dw    102.064133      0.605173         -3.484599
# 2             HV_cw    -42.573465     -1.107862         -9.221644
# 3         LSTM_pred    -88.160012     -1.387571         -9.514776
# 4          GRU_pred     -1.002547     -0.395532         -6.672035
# 5     LSTM_GRU_pred    -53.560080     -0.963602        -12.173313
# 6       BiLSTM_pred    -77.434901     -1.234756        -10.673048
# 7   BiLSTM_GRU_pred    -14.490708     -0.513162         -7.275017
# 8         QRNN_pred    -64.635364     -1.452023        -12.226836
# 9          ESN_pred      5.012213      0.091299         -9.094755
# 10         BNN_pred    -11.116129     -0.431795         -6.665311
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -13.753450     -0.699121         -9.904078
# 1             HV_dw     70.971165      0.294347         -7.782738
# 2             HV_cw    -13.792273     -0.501012        -11.426129
# 3         LSTM_pred    -20.504036     -0.421134         -8.334655
# 4          GRU_pred    -66.381697     -0.951576        -10.263577
# 5     LSTM_GRU_pred    -35.061068     -0.708471        -12.315869
# 6       BiLSTM_pred    -21.668546     -0.536854         -7.938886
# 7   BiLSTM_GRU_pred      7.964615     -0.277241         -6.599083
# 8         QRNN_pred     -4.717483     -0.618298         -9.844723
# 9          ESN_pred      5.388265      0.094895         -9.094755
# 10         BNN_pred     20.662156     -0.132310         -6.746429
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw     55.477559      0.157835         -7.352992
# 2             HV_cw    -33.318978     -1.954816         -5.179855
# 3         LSTM_pred    -73.831544     -1.170432         -9.104597
# 4          GRU_pred    -40.422011     -0.836648         -8.752953
# 5     LSTM_GRU_pred    -46.491653     -0.654039        -11.300628
# 6       BiLSTM_pred    -60.717166     -0.996735         -9.134180
# 7   BiLSTM_GRU_pred    -27.144263     -1.287152        -10.234634
# 8         QRNN_pred    -75.476863     -1.752951        -10.629292
# 9          ESN_pred    -19.171098     -0.169642         -6.432429
# 10         BNN_pred    -30.681108     -0.618546        -12.857768
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -1.452023        -12.226836
# 1             HV_dw     28.796074     -0.071114         -7.402339
# 2             HV_cw    -43.827605     -1.095758         -9.221644
# 3         LSTM_pred    -60.959162     -0.979874        -10.708065
# 4          GRU_pred     -5.872302     -0.259998         -7.494255
# 5     LSTM_GRU_pred    -40.733810     -0.996757        -12.470870
# 6       BiLSTM_pred    -99.932755     -1.383078        -11.083090
# 7   BiLSTM_GRU_pred    -75.555943     -1.245416        -13.524476
# 8         QRNN_pred    -64.635364     -1.452023        -12.226836
# 9          ESN_pred      5.012213      0.091299         -9.094755
# 10         BNN_pred     -3.514298     -0.334897         -9.304664
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.564042         -9.904078
# 1             HV_dw    -18.686449     -0.459023         -8.715619
# 2             HV_cw    -17.351161     -0.494364         -9.887919
# 3         LSTM_pred     -8.903918     -0.382640         -9.091691
# 4          GRU_pred    -23.762264     -0.379636         -7.453551
# 5     LSTM_GRU_pred    -54.046688     -1.045114        -13.685616
# 6       BiLSTM_pred    -67.768079     -0.888522        -10.888565
# 7   BiLSTM_GRU_pred    -58.236914     -0.956044        -12.529371
# 8         QRNN_pred      1.308214     -0.423157         -9.762195
# 9          ESN_pred      1.915896      0.065458         -9.094755
# 10         BNN_pred      3.103376     -0.273279         -9.520480
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw    -71.271091     -0.545150         -9.841785
# 2             HV_cw    -54.355421     -1.816798         -7.768812
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -82.404587     -0.891050        -11.234981
# 5     LSTM_GRU_pred    -76.705334     -0.597343         -9.216374
# 6       BiLSTM_pred    -95.258931     -0.856673        -12.231137
# 7   BiLSTM_GRU_pred    -73.590337     -1.568726        -12.552512
# 8         QRNN_pred    -75.476863     -1.752951        -10.629292
# 9          ESN_pred    -19.171098     -0.169642         -6.432429
# 10         BNN_pred    -71.271091     -0.659604         -9.904078
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -1.452023        -12.226836
# 1             HV_dw    -71.271091     -0.545150         -9.841785
# 2             HV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -95.258931     -0.856673        -12.231137
# 7   BiLSTM_GRU_pred    -95.258931     -1.015530        -12.478466
# 8         QRNN_pred    -64.635364     -1.452023        -12.226836
# 9          ESN_pred    -32.395781     -0.230243         -9.094755
# 10         BNN_pred    -71.271091     -0.659604         -9.904078
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -71.271091     -0.545150         -9.841785
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.600334         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.727191        -10.157965
# 7   BiLSTM_GRU_pred    -64.635364     -0.727191        -10.157965
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     14.831644     -0.571864         -9.904078
# 1             HV_dw      0.393133     -0.325301         -8.732659
# 2             HV_cw    -23.032878     -0.480321         -9.221644
# 3         LSTM_pred     44.098946      0.058747         -8.160589
# 4          GRU_pred    -44.576542     -0.740782         -7.720227
# 5     LSTM_GRU_pred    -27.643955     -0.712491        -10.932633
# 6       BiLSTM_pred     20.316436     -0.141535         -6.615249
# 7   BiLSTM_GRU_pred    -77.919212     -0.971810        -13.645006
# 8         QRNN_pred    -15.012407     -0.864393         -9.904078
# 9          ESN_pred    -14.367220     -0.074043         -9.094755
# 10         BNN_pred    -70.877350     -0.931936        -10.199053
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -34.401236     -0.890079         -9.904078
# 1             HV_dw     23.484512      0.002670         -7.916121
# 2             HV_cw     -1.842845     -0.359142         -7.069417
# 3         LSTM_pred    -41.304026     -0.607772         -8.334655
# 4          GRU_pred    -58.430285     -0.906416         -8.977697
# 5     LSTM_GRU_pred    -82.320205     -1.447593        -12.934750
# 6       BiLSTM_pred      4.706452     -0.176143         -6.840762
# 7   BiLSTM_GRU_pred      3.308408     -0.332802         -6.825441
# 8         QRNN_pred    -19.826531     -0.780201         -9.221644
# 9          ESN_pred    -48.743109     -0.371656         -9.094755
# 10         BNN_pred    -12.498778     -0.419410         -9.351329
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw    116.015438      0.879670         -2.034192
# 2             HV_cw    -28.731796     -2.054597         -4.729906
# 3         LSTM_pred    -55.511000     -1.299298         -7.681510
# 4          GRU_pred     44.268343      0.044589         -2.500987
# 5     LSTM_GRU_pred     18.458428     -0.058840         -6.178343
# 6       BiLSTM_pred     13.778514     -0.291820         -5.466039
# 7   BiLSTM_GRU_pred    -19.587270     -1.204719         -5.654791
# 8         QRNN_pred   -103.486720     -2.400919        -11.963354
# 9          ESN_pred    -19.171098     -0.169642         -6.432429
# 10         BNN_pred     52.099696      0.139529         -5.207006
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -65.388929     -1.469707        -11.670919
# 1             HV_dw     65.218541      0.271707         -3.156922
# 2             HV_cw    -14.435740     -0.813417         -6.545660
# 3         LSTM_pred    -66.509724     -1.155887         -8.751997
# 4          GRU_pred     -1.002547     -0.395532         -6.672035
# 5     LSTM_GRU_pred    -47.864986     -0.944099        -11.029001
# 6       BiLSTM_pred    -28.905134     -0.744197         -6.879738
# 7   BiLSTM_GRU_pred     33.466693     -0.056734         -5.862415
# 8         QRNN_pred    -60.927090     -1.504800        -11.667360
# 9          ESN_pred    -10.870832     -0.051401         -9.094755
# 10         BNN_pred    -63.969059     -1.001084        -11.952966
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -22.240903     -0.784930         -9.899822
# 1             HV_dw     58.342256      0.197252         -3.656382
# 2             HV_cw     20.376827     -0.256190         -7.194547
# 3         LSTM_pred      8.102895     -0.146121         -8.334655
# 4          GRU_pred     -7.323004     -0.431383         -6.871086
# 5     LSTM_GRU_pred    -58.434360     -1.250202        -13.006230
# 6       BiLSTM_pred     -7.150479     -0.435348         -6.623546
# 7   BiLSTM_GRU_pred     -9.335737     -0.451196         -6.535234
# 8         QRNN_pred    -33.663470     -0.933459         -9.221644
# 9          ESN_pred      7.122156      0.109889         -9.094755
# 10         BNN_pred    -32.446017     -0.641427         -9.094696
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw    110.111921      0.699661         -2.988025
# 2             HV_cw    -33.120895     -1.949510         -5.160425
# 3         LSTM_pred      0.686229     -0.497941         -7.681510
# 4          GRU_pred     10.137818     -0.348752         -4.158081
# 5     LSTM_GRU_pred     10.999594     -0.131565         -6.995124
# 6       BiLSTM_pred    -20.264767     -0.607449         -6.014604
# 7   BiLSTM_GRU_pred    -38.706750     -1.161688         -9.692519
# 8         QRNN_pred   -103.486720     -2.400919        -11.963354
# 9          ESN_pred    -19.171098     -0.169642         -6.432429
# 10         BNN_pred     31.530391     -0.093570         -6.301762
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -71.271091     -1.535049        -12.226836
# 1             HV_dw     56.110092      0.166007         -4.321591
# 2             HV_cw    -43.631675     -1.093096         -9.221644
# 3         LSTM_pred     -0.219956     -0.416603         -7.784085
# 4          GRU_pred    -40.308924     -0.773432         -7.701270
# 5     LSTM_GRU_pred    -29.842273     -0.713670        -10.631102
# 6       BiLSTM_pred    -37.528675     -0.783811         -6.836681
# 7   BiLSTM_GRU_pred    -87.592031     -1.116030        -13.542226
# 8         QRNN_pred    -60.927090     -1.504800        -11.667360
# 9          ESN_pred    -10.870832     -0.051401         -9.094755
# 10         BNN_pred    -72.210623     -1.029532        -11.732050
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     27.611995     -0.473701         -9.825790
# 1             HV_dw     38.982575      0.009560         -4.449495
# 2             HV_cw    -30.766780     -0.856826         -9.221644
# 3         LSTM_pred     59.733134      0.193602         -8.160589
# 4          GRU_pred    -13.725872     -0.485144         -6.790544
# 5     LSTM_GRU_pred    -32.301003     -0.918551        -12.317524
# 6       BiLSTM_pred    -13.760137     -0.470337         -6.156065
# 7   BiLSTM_GRU_pred    -77.451222     -0.983810        -12.793763
# 8         QRNN_pred    -20.463373     -0.934333        -10.099220
# 9          ESN_pred     23.294125      0.249926         -9.094755
# 10         BNN_pred    -40.914420     -0.686120         -8.861790
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw    -71.271091     -0.545150         -9.841785
# 2             HV_cw    -54.355421     -1.816798         -7.768812
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -95.258931     -0.856673        -12.231137
# 5     LSTM_GRU_pred    -76.705334     -0.597343         -9.216374
# 6       BiLSTM_pred    -95.258931     -0.856673        -12.231137
# 7   BiLSTM_GRU_pred    -73.590337     -1.565792        -12.527753
# 8         QRNN_pred   -103.486720     -2.400919        -11.963354
# 9          ESN_pred    -19.171098     -0.169642         -6.432429
# 10         BNN_pred    -71.271091     -0.659604         -9.904078
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -71.271091     -1.535049        -12.226836
# 1             HV_dw    -71.271091     -0.545150         -9.841785
# 2             HV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -76.705334     -0.597343         -9.216374
# 6       BiLSTM_pred    -95.258931     -0.856673        -12.231137
# 7   BiLSTM_GRU_pred    -95.258931     -0.856673        -12.231137
# 8         QRNN_pred    -60.927090     -1.504800        -11.667360
# 9          ESN_pred    -10.870832     -0.051401         -9.094755
# 10         BNN_pred    -71.271091     -0.659604         -9.904078
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -71.271091     -0.545150         -9.841785
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.600334         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.727191        -10.157965
# 7   BiLSTM_GRU_pred    -64.635364     -0.727191        -10.157965
# 8         QRNN_pred    -64.635364     -0.680710         -9.904078
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -71.271091     -0.545150         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.562776         -9.904078
# 1             HV_dw     34.596336     -0.199402         -7.130970
# 2             HV_cw     18.329274     -0.576043         -8.950081
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred     18.414117     -0.382152         -9.092906
# 5     LSTM_GRU_pred    -44.180771     -0.318871         -7.715239
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred    -11.157242     -0.624948        -10.681470
# 10         BNN_pred    -54.290084     -0.399780         -8.754749
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      3.675444     -0.494012         -9.048624
# 1             HV_dw     20.404062     -0.135508         -7.130970
# 2             HV_cw     48.565001     -0.158567         -7.044589
# 3         LSTM_pred    -77.632996     -0.604456        -11.156032
# 4          GRU_pred    -62.526450     -0.860327        -10.820362
# 5     LSTM_GRU_pred     -6.534639     -0.243094         -7.627269
# 6       BiLSTM_pred    -81.419931     -1.102700         -9.951201
# 7   BiLSTM_GRU_pred    -63.658141     -0.791114        -13.053323
# 8         QRNN_pred     10.111867     -0.393892         -8.051887
# 9          ESN_pred     14.680023     -0.181124         -8.753277
# 10         BNN_pred    -37.160452     -0.606184         -9.918649
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      8.525677     -0.382149         -7.602717
# 1             HV_dw     12.114275     -0.210008         -6.443368
# 2             HV_cw     42.770177     -0.134582         -6.457047
# 3         LSTM_pred    -95.265436     -0.767754        -11.156032
# 4          GRU_pred    -58.785536     -0.919005         -8.456007
# 5     LSTM_GRU_pred     48.149286      0.092966         -6.674081
# 6       BiLSTM_pred     -8.060371     -0.464508         -6.813003
# 7   BiLSTM_GRU_pred    -53.906471     -0.826870         -8.964952
# 8         QRNN_pred      5.607186     -0.517383         -8.064382
# 9          ESN_pred     34.660860     -0.047668         -8.176726
# 10         BNN_pred    -18.878461     -0.480594         -8.566435
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     11.835866     -0.358648         -8.173232
# 1             HV_dw      6.694171     -0.253980         -7.130970
# 2             HV_cw      9.295727     -0.421488         -7.149297
# 3         LSTM_pred    -77.632996     -0.604456        -11.156032
# 4          GRU_pred    -59.547585     -0.849129         -9.589508
# 5     LSTM_GRU_pred     34.987777      0.111047         -7.496238
# 6       BiLSTM_pred    -71.450560     -1.005472         -8.973899
# 7   BiLSTM_GRU_pred    -44.038782     -0.640427        -10.022598
# 8         QRNN_pred      5.607186     -0.433065         -7.987355
# 9          ESN_pred     36.926778     -0.009665         -8.911132
# 10         BNN_pred    -40.036725     -0.631153        -10.187747
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      3.675444     -0.494012         -9.048624
# 1             HV_dw     20.404062     -0.135508         -7.130970
# 2             HV_cw      4.723696     -0.551462         -8.391737
# 3         LSTM_pred    -77.632996     -0.604456        -11.156032
# 4          GRU_pred    -66.230348     -0.897913        -10.820362
# 5     LSTM_GRU_pred      9.973402     -0.104661         -7.502601
# 6       BiLSTM_pred    -81.419931     -1.102700         -9.951201
# 7   BiLSTM_GRU_pred    -63.658141     -0.791114        -13.053323
# 8         QRNN_pred     10.111867     -0.393892         -8.051887
# 9          ESN_pred     42.759318      0.049828         -8.697477
# 10         BNN_pred    -37.160452     -0.606184         -9.918649
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.480781         -9.825790
# 1             HV_dw     15.727732     -0.297373         -6.898790
# 2             HV_cw     64.385050      0.086342         -6.397926
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred     42.298562     -0.216677         -8.136556
# 5     LSTM_GRU_pred    -17.273567     -0.113824         -6.432429
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -85.182102     -0.949842        -10.419008
# 8         QRNN_pred      4.020430     -0.518078         -9.868036
# 9          ESN_pred     62.079539      0.227389         -8.848746
# 10         BNN_pred    -51.649453     -0.385760         -8.035879
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.491784         -9.843974
# 1             HV_dw     20.695761     -0.316928         -7.130970
# 2             HV_cw     10.743784     -0.379206         -7.814114
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred     11.921578     -0.444716         -7.907640
# 5     LSTM_GRU_pred    -69.493406     -0.547661        -10.360587
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.680710         -9.904078
# 8         QRNN_pred      4.020430     -0.435442         -9.773782
# 9          ESN_pred     22.415272     -0.134692         -9.192030
# 10         BNN_pred    -54.290084     -0.399780         -8.754749
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.562776         -9.904078
# 1             HV_dw     34.596336     -0.199402         -7.130970
# 2             HV_cw     -8.446147     -0.808055         -9.360431
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred      4.730963     -0.496632         -9.216740
# 5     LSTM_GRU_pred    -44.180771     -0.318871         -7.715239
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred     16.207058     -0.405592        -10.638417
# 10         BNN_pred    -54.290084     -0.399780         -8.754749
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -71.271091     -0.659604         -9.904078
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -73.590337     -0.593507         -9.302939
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -85.182102     -0.949842        -10.419008
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -80.086074     -0.877527        -11.642010
# 10         BNN_pred    -62.023620     -0.474001         -9.094755
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -64.635364     -0.600334         -9.904078
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.680710         -9.904078
# 5     LSTM_GRU_pred    -88.794596     -0.707853        -12.231137
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.680710         -9.904078
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -75.848409     -0.702626        -10.984138
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -64.635364     -0.486499         -9.841785
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.600334         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.562776         -9.904078
# 1             HV_dw      5.186944     -0.427825         -7.758428
# 2             HV_cw    -83.840483     -0.675460        -10.135426
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -67.651552     -0.516477        -10.163255
# 5     LSTM_GRU_pred    -48.881514     -0.576794        -10.732852
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred      4.789901     -0.130625        -10.652155
# 10         BNN_pred     17.832648     -0.448261         -8.806530
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      9.394323     -0.447145         -8.485429
# 1             HV_dw      5.913545     -0.427120         -7.591545
# 2             HV_cw     78.177945     -0.090512         -6.996827
# 3         LSTM_pred    -39.129094     -0.620414         -9.849412
# 4          GRU_pred    -57.604861     -0.819362         -9.688431
# 5     LSTM_GRU_pred     69.774931      0.278963         -5.378559
# 6       BiLSTM_pred    -65.916483     -0.953374         -9.492825
# 7   BiLSTM_GRU_pred    -36.425916     -0.630792        -10.125255
# 8         QRNN_pred     13.791342     -0.355436         -9.317515
# 9          ESN_pred     20.859962     -0.011019         -8.072110
# 10         BNN_pred    -28.098620     -0.527382         -9.749685
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     14.272193     -0.333911         -7.559643
# 1             HV_dw    -44.942437     -0.832007         -7.969498
# 2             HV_cw     84.016581      0.214806         -6.435979
# 3         LSTM_pred    -39.328345     -0.631584         -9.870024
# 4          GRU_pred    -30.701099     -0.647620         -7.494255
# 5     LSTM_GRU_pred     92.240680      0.508981         -4.518508
# 6       BiLSTM_pred    -15.710124     -0.417900         -8.453273
# 7   BiLSTM_GRU_pred    -63.292515     -0.908487        -10.562025
# 8         QRNN_pred    -29.909167     -0.888580        -10.242657
# 9          ESN_pred     -0.364680     -0.433194         -9.728869
# 10         BNN_pred     -0.639605     -0.315516         -8.736656
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     17.601243     -0.311596         -7.619571
# 1             HV_dw     16.112669     -0.344417         -7.515346
# 2             HV_cw     72.120550     -0.156675         -7.194547
# 3         LSTM_pred    -39.129094     -0.620414         -9.849412
# 4          GRU_pred    -58.481783     -0.842746         -8.982676
# 5     LSTM_GRU_pred     61.069742      0.207824         -5.033629
# 6       BiLSTM_pred    -55.778853     -0.854447         -8.510548
# 7   BiLSTM_GRU_pred    -47.776493     -0.752446         -9.725543
# 8         QRNN_pred    -10.008591     -0.526731         -9.504456
# 9          ESN_pred     39.380378      0.004630         -8.159345
# 10         BNN_pred    -31.001963     -0.552263        -10.019288
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      9.394323     -0.447145         -8.485429
# 1             HV_dw      5.913545     -0.427120         -7.591545
# 2             HV_cw     63.009534     -0.225811         -7.125156
# 3         LSTM_pred    -39.129094     -0.620414         -9.849412
# 4          GRU_pred    -57.604861     -0.819362         -9.688431
# 5     LSTM_GRU_pred     48.245166      0.094221         -5.378559
# 6       BiLSTM_pred    -65.916483     -0.953374         -9.492825
# 7   BiLSTM_GRU_pred    -36.425916     -0.630792        -10.125255
# 8         QRNN_pred     13.791342     -0.355436         -9.317515
# 9          ESN_pred     95.581447      0.514674         -7.756776
# 10         BNN_pred    -28.098620     -0.527382         -9.749685
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.480781         -9.825790
# 1             HV_dw    -53.360637     -0.895531         -9.796232
# 2             HV_cw    -38.457368     -0.300820         -9.221644
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred     17.668325     -0.050616         -7.118181
# 5     LSTM_GRU_pred    -26.346675     -0.550827         -7.748066
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -92.697540     -0.992373        -12.230686
# 8         QRNN_pred    -16.162154     -0.756038         -9.221644
# 9          ESN_pred    -10.078053     -0.537840        -10.606026
# 10         BNN_pred     20.674661     -0.435075         -8.083408
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.491784         -9.843974
# 1             HV_dw      7.441459     -0.409484         -7.580032
# 2             HV_cw    -28.865443     -0.212137         -9.221644
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -43.494623     -0.511106         -7.824107
# 5     LSTM_GRU_pred    -63.115540     -0.713803        -12.068786
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -88.794596     -0.954426        -12.478466
# 8         QRNN_pred      4.020430     -0.404028         -9.735824
# 9          ESN_pred     67.274572      0.274093         -8.795154
# 10         BNN_pred     17.832648     -0.448261         -8.806530
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.562776         -9.904078
# 1             HV_dw      5.186944     -0.427825         -7.758428
# 2             HV_cw    -78.773745     -0.645775         -9.638438
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -67.651552     -0.516477        -10.163255
# 5     LSTM_GRU_pred    -48.881514     -0.576794        -10.732852
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred     12.694663     -0.077400        -10.796228
# 10         BNN_pred     17.832648     -0.448261         -8.806530
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw   -100.552815     -1.072525        -11.924143
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -92.697540     -0.744773        -11.982656
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -92.697540     -0.992373        -12.230686
# 8         QRNN_pred    -62.023620     -0.671578         -9.221644
# 9          ESN_pred    -54.355421     -0.780495         -9.170573
# 10         BNN_pred    -62.023620     -0.474001         -9.094755
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -64.635364     -0.486499         -9.841785
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.680710         -9.904078
# 5     LSTM_GRU_pred    -88.794596     -0.707853        -12.231137
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -88.794596     -0.954426        -12.478466
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -75.848409     -0.783815        -10.984138
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -64.635364     -0.486499         -9.841785
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.486499         -9.841785
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -14.062075     -0.635037         -9.904078
# 1             HV_dw      5.913545     -0.427120         -7.591545
# 2             HV_cw    -26.049861     -0.406071         -9.808231
# 3         LSTM_pred     -8.903918     -0.382640         -9.091691
# 4          GRU_pred    -17.116244     -0.333420         -6.502787
# 5     LSTM_GRU_pred    -25.293328     -0.390757         -9.718077
# 6       BiLSTM_pred    -75.179698     -1.008235        -10.151951
# 7   BiLSTM_GRU_pred    -47.605838     -0.847565        -13.383195
# 8         QRNN_pred      1.308214     -0.454394         -9.800256
# 9          ESN_pred      0.149666     -0.301214         -9.695573
# 10         BNN_pred    -41.064018     -0.637315        -10.455174
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -22.566329     -0.775913         -9.904078
# 1             HV_dw     -9.051349     -0.403046         -7.492446
# 2             HV_cw    -29.185000     -0.608464         -9.409946
# 3         LSTM_pred    -23.371110     -0.437706         -8.451006
# 4          GRU_pred    -58.430285     -0.906416         -8.977697
# 5     LSTM_GRU_pred     69.447365      0.282055         -5.378559
# 6       BiLSTM_pred    -31.978415     -0.740997         -8.717939
# 7   BiLSTM_GRU_pred     10.540931     -0.245368         -6.599083
# 8         QRNN_pred    -22.566329     -0.775913         -9.904078
# 9          ESN_pred    -17.532457     -0.564611         -8.278484
# 10         BNN_pred    -41.480810     -0.658993         -8.254235
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw     16.752986     -0.220953         -3.955343
# 2             HV_cw    -31.874627     -0.947753         -9.221644
# 3         LSTM_pred   -113.408230     -2.017916        -11.340823
# 4          GRU_pred     -2.744190     -0.452021         -7.882013
# 5     LSTM_GRU_pred      7.539716     -0.462379         -4.677495
# 6       BiLSTM_pred     -7.936921     -0.418029         -4.609723
# 7   BiLSTM_GRU_pred    -40.117327     -1.361026         -8.444143
# 8         QRNN_pred    -75.476863     -1.752951        -10.629292
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -81.775739     -1.158592        -11.354397
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -1.452023        -12.226836
# 1             HV_dw     15.963484     -0.209903         -5.307463
# 2             HV_cw    -31.874627     -0.947753         -9.221644
# 3         LSTM_pred    -88.160012     -1.387571         -9.514776
# 4          GRU_pred     -1.002547     -0.395532         -6.672035
# 5     LSTM_GRU_pred     38.132752     -0.023238         -4.518508
# 6       BiLSTM_pred      7.950946     -0.257753         -6.557223
# 7   BiLSTM_GRU_pred    -14.490708     -0.513162         -7.275017
# 8         QRNN_pred    -64.635364     -1.452023        -12.226836
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -56.125595     -0.856518         -8.269342
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -13.753450     -0.699121         -9.904078
# 1             HV_dw     -4.294404     -0.362555         -6.539067
# 2             HV_cw     10.327691     -0.265737         -9.286706
# 3         LSTM_pred    -20.504036     -0.421134         -8.334655
# 4          GRU_pred    -66.381697     -0.951576        -10.263577
# 5     LSTM_GRU_pred     62.081460      0.217241         -5.378559
# 6       BiLSTM_pred    -43.031357     -0.769517         -8.140353
# 7   BiLSTM_GRU_pred      7.964615     -0.277241         -6.599083
# 8         QRNN_pred     -4.717483     -0.618298         -9.844723
# 9          ESN_pred    -14.517865     -0.708694         -8.322608
# 10         BNN_pred    -43.100328     -0.674641         -8.254235
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw    -10.763850     -0.775727         -8.428012
# 2             HV_cw    -43.827605     -1.095758         -9.221644
# 3         LSTM_pred    -73.831544     -1.170432         -9.104597
# 4          GRU_pred    -40.422011     -0.836648         -8.752953
# 5     LSTM_GRU_pred    -64.048640     -1.236318        -10.361832
# 6       BiLSTM_pred   -102.434096     -1.493997        -10.880167
# 7   BiLSTM_GRU_pred    -27.144263     -1.287152        -10.234634
# 8         QRNN_pred    -75.476863     -1.752951        -10.629292
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -50.315548     -0.784822        -10.582958
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -1.452023        -12.226836
# 1             HV_dw    -34.269342     -0.738535         -7.696495
# 2             HV_cw    -43.827605     -1.095758         -9.221644
# 3         LSTM_pred    -60.959162     -0.979874        -10.708065
# 4          GRU_pred     -5.872302     -0.259998         -7.494255
# 5     LSTM_GRU_pred    -66.276082     -0.971599         -9.678327
# 6       BiLSTM_pred    -72.022666     -1.002792        -10.445886
# 7   BiLSTM_GRU_pred    -75.555943     -1.245416        -13.524476
# 8         QRNN_pred    -64.635364     -1.452023        -12.226836
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -11.016942     -0.404467         -9.242279
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -5.172519     -0.564042         -9.904078
# 1             HV_dw     16.400355     -0.342061         -7.513219
# 2             HV_cw    -25.192229     -0.564968         -9.887919
# 3         LSTM_pred     -8.903918     -0.382640         -9.091691
# 4          GRU_pred    -23.762264     -0.379636         -7.453551
# 5     LSTM_GRU_pred    -46.037608     -0.578051        -11.351418
# 6       BiLSTM_pred    -65.142601     -0.912970         -9.176828
# 7   BiLSTM_GRU_pred    -58.236914     -0.956044        -12.529371
# 8         QRNN_pred      1.308214     -0.423157         -9.762195
# 9          ESN_pred    -29.803598     -0.717518         -9.904078
# 10         BNN_pred    -41.064018     -0.637315        -10.455174
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw    -91.956667     -0.995107        -11.082389
# 2             HV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -82.404587     -0.891050        -11.234981
# 5     LSTM_GRU_pred    -55.957342     -1.400443        -12.367921
# 6       BiLSTM_pred    -75.848409     -0.587472        -10.984138
# 7   BiLSTM_GRU_pred    -73.590337     -1.568726        -12.552512
# 8         QRNN_pred    -75.476863     -1.752951        -10.629292
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -86.777706     -0.955930        -11.292977
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -1.452023        -12.226836
# 1             HV_dw    -98.006411     -1.049213        -11.674793
# 2             HV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -86.214904     -1.507905        -14.302719
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -95.258931     -1.015530        -12.478466
# 8         QRNN_pred    -64.635364     -1.452023        -12.226836
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -62.023620     -0.474001         -9.094755
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -64.635364     -0.486499         -9.841785
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.600334         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.727191        -10.157965
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -1.165788        -11.468322
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     14.831644     -0.571864         -9.904078
# 1             HV_dw    -19.063381     -0.468567         -8.588307
# 2             HV_cw    -17.408658     -0.487322         -9.221644
# 3         LSTM_pred     44.098946      0.058747         -8.160589
# 4          GRU_pred    -44.576542     -0.740782         -7.720227
# 5     LSTM_GRU_pred     42.501092      0.047150         -8.283349
# 6       BiLSTM_pred    -66.893778     -0.964460         -9.697771
# 7   BiLSTM_GRU_pred    -77.919212     -0.971810        -13.645006
# 8         QRNN_pred    -15.012407     -0.864393         -9.904078
# 9          ESN_pred    -20.342704     -0.510490         -8.563823
# 10         BNN_pred    -37.955613     -0.613721         -9.503545
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -34.401236     -0.890079         -9.904078
# 1             HV_dw     12.935993     -0.240997         -4.803202
# 2             HV_cw    -15.419680     -0.490158         -9.221644
# 3         LSTM_pred    -41.304026     -0.607772         -8.334655
# 4          GRU_pred    -58.430285     -0.906416         -8.977697
# 5     LSTM_GRU_pred     51.218209      0.120908         -5.378559
# 6       BiLSTM_pred    -17.984859     -0.613126         -8.717939
# 7   BiLSTM_GRU_pred      3.308408     -0.332802         -6.825441
# 8         QRNN_pred    -19.826531     -0.780201         -9.221644
# 9          ESN_pred    -17.532457     -0.564611         -8.278484
# 10         BNN_pred    -57.601470     -0.901290         -8.764061
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw     24.160547     -0.160932         -3.955343
# 2             HV_cw    -30.290653     -0.972048         -9.221644
# 3         LSTM_pred    -55.511000     -1.299298         -7.681510
# 4          GRU_pred     44.268343      0.044589         -2.500987
# 5     LSTM_GRU_pred     -3.312586     -0.625525         -4.650507
# 6       BiLSTM_pred    -21.568137     -0.606516         -4.532328
# 7   BiLSTM_GRU_pred    -19.587270     -1.204719         -5.654791
# 8         QRNN_pred   -103.486720     -2.400919        -11.963354
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -85.660650     -1.254858        -10.602486
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -65.388929     -1.469707        -11.670919
# 1             HV_dw     -8.541030     -0.483173         -5.046040
# 2             HV_cw    -38.185342     -1.071097         -9.221644
# 3         LSTM_pred    -66.509724     -1.155887         -8.751997
# 4          GRU_pred     -1.002547     -0.395532         -6.672035
# 5     LSTM_GRU_pred     28.829489     -0.144811         -4.518508
# 6       BiLSTM_pred     -2.492707     -0.414932         -4.847545
# 7   BiLSTM_GRU_pred     33.466693     -0.056734         -5.862415
# 8         QRNN_pred    -60.927090     -1.504800        -11.667360
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -85.559427     -1.226600        -10.618792
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -22.240903     -0.784930         -9.899822
# 1             HV_dw     -8.899603     -0.432533         -6.781826
# 2             HV_cw     32.505007     -0.063523         -9.205517
# 3         LSTM_pred      8.102895     -0.146121         -8.334655
# 4          GRU_pred     -7.323004     -0.431383         -6.871086
# 5     LSTM_GRU_pred     68.287795      0.282786         -5.378559
# 6       BiLSTM_pred    -37.583231     -0.733295         -8.105115
# 7   BiLSTM_GRU_pred     -9.335737     -0.451196         -6.535234
# 8         QRNN_pred    -33.663470     -0.933459         -9.221644
# 9          ESN_pred    -42.446349     -1.363527         -7.768812
# 10         BNN_pred    -47.376620     -0.801466         -8.354610
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw    -25.967462     -0.624414         -7.396619
# 2             HV_cw    -43.631675     -1.093096         -9.221644
# 3         LSTM_pred      0.686229     -0.497941         -7.681510
# 4          GRU_pred     10.137818     -0.348752         -4.158081
# 5     LSTM_GRU_pred    -62.747737     -1.246758        -10.336453
# 6       BiLSTM_pred    -38.809079     -0.828631         -6.237552
# 7   BiLSTM_GRU_pred    -38.706750     -1.161688         -9.692519
# 8         QRNN_pred   -103.486720     -2.400919        -11.963354
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -60.398814     -0.948743         -9.059978
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -71.271091     -1.535049        -12.226836
# 1             HV_dw    -32.865462     -0.668581         -7.140325
# 2             HV_cw    -43.631675     -1.093096         -9.221644
# 3         LSTM_pred     -0.219956     -0.416603         -7.784085
# 4          GRU_pred    -40.308924     -0.773432         -7.701270
# 5     LSTM_GRU_pred    -57.449145     -1.079855        -10.233524
# 6       BiLSTM_pred    -44.491279     -0.872718         -7.544315
# 7   BiLSTM_GRU_pred    -87.592031     -1.116030        -13.542226
# 8         QRNN_pred    -60.927090     -1.504800        -11.667360
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -64.059737     -0.906259        -10.201431
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     27.611995     -0.473701         -9.825790
# 1             HV_dw    -26.723107     -0.546689         -8.841021
# 2             HV_cw     30.419214     -0.076839         -9.221644
# 3         LSTM_pred     59.733134      0.193602         -8.160589
# 4          GRU_pred    -13.725872     -0.485144         -6.790544
# 5     LSTM_GRU_pred    -15.779980     -0.468255         -8.851495
# 6       BiLSTM_pred    -56.766754     -0.865503         -8.717719
# 7   BiLSTM_GRU_pred    -77.451222     -0.983810        -12.793763
# 8         QRNN_pred    -20.463373     -0.934333        -10.099220
# 9          ESN_pred    -40.356110     -0.955584         -7.768812
# 10         BNN_pred      2.321816     -0.287426         -9.112342
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -67.048822     -1.586415        -11.561996
# 1             HV_dw    -91.956667     -0.995107        -11.082389
# 2             HV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -95.258931     -0.856673        -12.231137
# 5     LSTM_GRU_pred    -33.690759     -1.282153        -12.343110
# 6       BiLSTM_pred    -87.773685     -0.699826        -10.414488
# 7   BiLSTM_GRU_pred    -73.590337     -1.565792        -12.527753
# 8         QRNN_pred   -103.486720     -2.400919        -11.963354
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -82.592182     -0.926101        -10.165398
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -71.271091     -1.535049        -12.226836
# 1             HV_dw    -91.956667     -0.995107        -11.082389
# 2             HV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -86.214904     -1.426936        -13.530043
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -95.258931     -0.856673        -12.231137
# 8         QRNN_pred    -60.927090     -1.504800        -11.667360
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -86.777706     -0.955930        -11.292977
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -64.635364     -0.486499         -9.841785
# 1             HV_dw    -88.794596     -0.824747        -12.231137
# 2             HV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.600334         -9.904078
# 5     LSTM_GRU_pred    -88.794596     -0.794942        -12.231137
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.727191        -10.157965
# 8         QRNN_pred    -64.635364     -0.680710         -9.904078
# 9          ESN_pred    -64.635364     -1.239242         -9.904078
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y1', file, 'HV')
get_final_results_1('2024_y1', file, 'HV')

get_final_results('2024_y1', dw_file, 'HV_dw')
get_final_results_1('2024_y1', dw_file, 'HV_dw')

get_final_results('2024_y1', cw_file, 'HV_cw')
get_final_results_1('2024_y1', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-38-f0ec5dbb9c6c>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-38-f0ec5dbb9c6c>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-38-f0ec5dbb9c6c>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     76.910947      0.315397         -7.764436
# 2            CCV_cw     84.701418      0.374014         -7.111357
# 3         LSTM_pred    103.608166      0.515758         -6.951385
# 4          GRU_pred    130.857566      0.760684         -6.681250
# 5     LSTM_GRU_pred     76.910947      0.315397         -7.764436
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred    -43.507228     -0.524640        -15.535370
# 10         BNN_pred     84.701418      0.374014         -7.111357
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    148.434064      0.847559         -3.657049
# 1            CCV_dw    120.639878      0.704200         -4.216181
# 2            CCV_cw     97.118317      0.467625         -6.886716
# 3         LSTM_pred    153.480768      0.931222         -6.650830
# 4          GRU_pred     91.071114      0.455645         -6.584313
# 5     LSTM_GRU_pred    117.209294      0.541542         -6.928723
# 6       BiLSTM_pred     91.071114      0.455645         -6.584313
# 7   BiLSTM_GRU_pred    148.198494      0.890341         -6.681427
# 8         QRNN_pred    106.532521      0.575166         -6.828124
# 9          ESN_pred    111.733550      0.616362         -6.900579
# 10         BNN_pred    109.868909      0.612055         -5.921951
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -69.861162     -1.200247        -10.625852
# 1            CCV_dw     27.846645     -0.156671         -4.685728
# 2            CCV_cw     -4.711844     -0.563163        -10.524210
# 3         LSTM_pred     71.470145      0.384088         -4.580569
# 4          GRU_pred     76.884831      0.341554         -4.998966
# 5     LSTM_GRU_pred     79.391960      0.433426         -4.587788
# 6       BiLSTM_pred    110.212788      0.796671         -2.999966
# 7   BiLSTM_GRU_pred     60.370861      0.268459         -2.970408
# 8         QRNN_pred     -5.242339     -0.516427         -7.712034
# 9          ESN_pred     37.885831     -0.028290         -4.294275
# 10         BNN_pred    135.850525      1.002957         -2.677629
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    184.318093      1.143084         -4.598544
# 1            CCV_dw     77.749741      0.374398         -3.526594
# 2            CCV_cw    173.677572      1.295661         -3.338617
# 3         LSTM_pred    124.865083      0.813199         -6.196504
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred    123.080807      0.686151         -6.142956
# 6       BiLSTM_pred     60.554432      0.127567         -6.279474
# 7   BiLSTM_GRU_pred    123.015334      0.813228         -6.096000
# 8         QRNN_pred     23.640671     -0.173886         -7.494431
# 9          ESN_pred    132.385665      0.914279         -4.552285
# 10         BNN_pred    138.951601      0.935138         -3.356588
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    176.591687      1.120660         -3.322718
# 1            CCV_dw    122.508888      0.723426         -4.209161
# 2            CCV_cw     88.376131      0.385630         -7.759372
# 3         LSTM_pred    101.465973      0.527858         -6.859533
# 4          GRU_pred     68.790056      0.187555         -6.886416
# 5     LSTM_GRU_pred     33.444683     -0.014734         -7.347510
# 6       BiLSTM_pred     91.071114      0.455645         -6.584313
# 7   BiLSTM_GRU_pred    148.198494      0.890341         -6.681427
# 8         QRNN_pred     40.458971      0.028244         -7.261739
# 9          ESN_pred    121.587333      0.692430         -6.736472
# 10         BNN_pred     79.301602      0.361226         -6.001772
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -72.968561     -0.979694        -12.736187
# 1            CCV_dw    -12.261365     -0.524814         -8.575022
# 2            CCV_cw    -15.679380     -0.696767        -10.524210
# 3         LSTM_pred     41.447915      0.024796         -7.317555
# 4          GRU_pred     67.253833      0.341554         -4.998966
# 5     LSTM_GRU_pred     79.391960      0.433426         -4.587788
# 6       BiLSTM_pred    100.283726      0.796671         -2.999966
# 7   BiLSTM_GRU_pred     68.155097      0.372742         -2.948761
# 8         QRNN_pred    -52.717369     -0.898824        -10.825981
# 9          ESN_pred     37.885831     -0.028290         -4.294275
# 10         BNN_pred    133.791890      0.979705         -2.682491
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    246.462950      1.548533         -5.114250
# 1            CCV_dw     77.749741      0.374398         -3.526594
# 2            CCV_cw    173.677572      1.295661         -3.338617
# 3         LSTM_pred     46.074135      0.079908         -7.612810
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred     66.379475      0.233948         -7.244787
# 6       BiLSTM_pred     -3.510753     -0.259401        -14.814772
# 7   BiLSTM_GRU_pred    -51.396969     -0.590149        -15.874250
# 8         QRNN_pred    -25.212808     -0.603856        -10.508152
# 9          ESN_pred     61.907183      0.219177         -7.150553
# 10         BNN_pred    136.887345      0.914751         -3.362682
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    155.821151      1.035093         -3.301464
# 1            CCV_dw     78.707025      0.329908         -7.751508
# 2            CCV_cw     64.200597      0.213594         -7.845829
# 3         LSTM_pred     53.842315      0.140960         -7.169518
# 4          GRU_pred     97.856856      0.491253         -6.987801
# 5     LSTM_GRU_pred     19.359539     -0.124199         -8.202804
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 8         QRNN_pred     -9.197164     -0.359397        -10.385586
# 9          ESN_pred    -30.493765     -0.430577        -15.535370
# 10         BNN_pred     59.456287      0.184333         -7.285950
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV   -135.885771     -1.251585        -18.658743
# 1            CCV_dw    -77.298395     -0.898453        -15.594958
# 2            CCV_cw     -2.020242     -0.495851        -10.524210
# 3         LSTM_pred     62.418278      0.237570         -7.089993
# 4          GRU_pred     46.841575      0.081944         -7.323374
# 5     LSTM_GRU_pred     79.391960      0.433426         -4.587788
# 6       BiLSTM_pred    100.283726      0.796671         -2.999966
# 7   BiLSTM_GRU_pred     68.155097      0.372742         -2.948761
# 8         QRNN_pred   -104.982428     -1.134131        -15.746039
# 9          ESN_pred     37.885831     -0.028290         -4.294275
# 10         BNN_pred    133.791890      0.979705         -2.682491
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    246.462950      1.548533         -5.114250
# 1            CCV_dw     65.262649      0.256156         -3.567933
# 2            CCV_cw    173.677572      1.295661         -3.338617
# 3         LSTM_pred      2.189356     -0.207551        -15.158412
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred    -14.185778     -0.300941        -14.814772
# 6       BiLSTM_pred     -3.510753     -0.259401        -14.814772
# 7   BiLSTM_GRU_pred    -51.396969     -0.590149        -15.874250
# 8         QRNN_pred    -89.743829     -0.990938        -15.535370
# 9          ESN_pred     44.021884      0.062266         -8.172298
# 10         BNN_pred    136.887345      0.914751         -3.362682
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    155.821151      1.035093         -3.301464
# 1            CCV_dw    -68.739212     -0.694059        -15.535370
# 2            CCV_cw    -92.364510     -0.881920        -17.370102
# 3         LSTM_pred    -45.924984     -0.582143        -15.535370
# 4          GRU_pred    -87.009473     -0.788587        -16.680318
# 5     LSTM_GRU_pred   -108.685422     -0.914700        -16.317555
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 8         QRNN_pred    -82.818008     -0.887291        -15.535370
# 9          ESN_pred   -100.041094     -0.856089        -16.317555
# 10         BNN_pred    -70.956775     -0.778386        -15.535370
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     76.910947      0.315397         -7.764436
# 2            CCV_cw    -71.869358     -0.662361        -16.317555
# 3         LSTM_pred    -32.951756     -0.436051        -15.535370
# 4          GRU_pred    130.857566      0.760684         -6.681250
# 5     LSTM_GRU_pred     86.824273      0.388972         -7.811798
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred     14.064510     -0.160187        -13.399868
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred     34.013329     -0.006575        -13.141349
# 10         BNN_pred     84.701418      0.374014         -7.111357
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.545695      0.849282         -3.655821
# 1            CCV_dw     76.910947      0.315397         -7.764436
# 2            CCV_cw     76.910947      0.315397         -7.764436
# 3         LSTM_pred    103.608166      0.515758         -6.951385
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred     86.824273      0.388972         -7.811798
# 6       BiLSTM_pred     97.118317      0.467625         -6.886716
# 7   BiLSTM_GRU_pred     89.391941      0.407726         -7.793386
# 8         QRNN_pred     93.414907      0.440279         -6.910041
# 9          ESN_pred    113.847500      0.632651         -6.783282
# 10         BNN_pred    109.868909      0.612055         -5.921951
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     25.218667     -0.199834         -4.950365
# 1            CCV_dw     95.246175      0.571043         -3.516300
# 2            CCV_cw    101.411983      0.903580         -4.021807
# 3         LSTM_pred     91.999579      0.615586         -4.494455
# 4          GRU_pred    -15.153748     -0.886436         -9.230979
# 5     LSTM_GRU_pred     95.440063      0.595692         -3.001189
# 6       BiLSTM_pred     84.143763      0.579977         -3.698755
# 7   BiLSTM_GRU_pred     27.125270     -0.187109         -4.095000
# 8         QRNN_pred    -58.212568     -0.788504        -10.691454
# 9          ESN_pred    -44.597175     -0.979427         -7.715671
# 10         BNN_pred    118.389815      0.766564         -5.587449
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     80.963094      0.333922         -7.976994
# 1            CCV_dw     93.032453      0.508625         -3.477285
# 2            CCV_cw     51.676374      0.126312         -6.690501
# 3         LSTM_pred     71.436669      0.281057         -6.407079
# 4          GRU_pred    127.034998      0.859600         -3.267053
# 5     LSTM_GRU_pred    195.141675      1.548030         -2.281759
# 6       BiLSTM_pred     38.718552      0.015487         -6.723312
# 7   BiLSTM_GRU_pred    116.913738      0.730326         -3.458887
# 8         QRNN_pred     37.880388      0.029721         -8.202036
# 9          ESN_pred    130.561531      0.823330         -6.767486
# 10         BNN_pred    135.429597      0.906108         -3.330941
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.545695      0.849282         -3.655821
# 1            CCV_dw     92.236002      0.431514         -7.773093
# 2            CCV_cw    -17.901293     -0.352523         -8.480437
# 3         LSTM_pred    103.608166      0.515758         -6.951385
# 4          GRU_pred     63.198114      0.144770         -9.956086
# 5     LSTM_GRU_pred     28.743086     -0.051091         -8.252839
# 6       BiLSTM_pred     97.118317      0.467625         -6.886716
# 7   BiLSTM_GRU_pred     45.606937      0.077830         -7.352028
# 8         QRNN_pred     64.987147      0.228771         -7.203472
# 9          ESN_pred    129.001835      0.749529         -6.692232
# 10         BNN_pred    209.508173      1.487465         -3.171113
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     23.479257     -0.222761         -4.958778
# 1            CCV_dw     95.246175      0.571043         -3.516300
# 2            CCV_cw    101.411983      0.903580         -4.021807
# 3         LSTM_pred     61.402121      0.232053         -7.179987
# 4          GRU_pred    -16.389110     -0.673774        -10.406907
# 5     LSTM_GRU_pred     95.440063      0.595692         -3.001189
# 6       BiLSTM_pred     84.143763      0.579977         -3.698755
# 7   BiLSTM_GRU_pred     41.306573      0.008094         -4.046106
# 8         QRNN_pred    -92.400258     -1.067344        -13.933430
# 9          ESN_pred   -113.074944     -1.473120        -13.939817
# 10         BNN_pred    101.219272      0.538558         -6.827856
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     56.832016      0.158528         -7.907846
# 1            CCV_dw     93.032453      0.508625         -3.477285
# 2            CCV_cw     61.055648      0.208740         -6.631360
# 3         LSTM_pred    -63.647845     -0.692440        -14.814772
# 4          GRU_pred    130.863955      0.902716         -3.255991
# 5     LSTM_GRU_pred    153.934515      1.044803         -5.440681
# 6       BiLSTM_pred    -76.273540     -0.751111        -14.814772
# 7   BiLSTM_GRU_pred    133.719252      0.781995         -6.498170
# 8         QRNN_pred      0.204442     -0.228329        -10.263228
# 9          ESN_pred      4.056133     -0.244102        -13.704528
# 10         BNN_pred    133.371725      0.885732         -3.336989
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     92.236002      0.431514         -7.773093
# 2            CCV_cw   -102.916386     -0.892884        -16.317555
# 3         LSTM_pred     -7.729378     -0.296964        -15.535370
# 4          GRU_pred     26.863189     -0.064127         -9.948296
# 5     LSTM_GRU_pred     12.436271     -0.155289         -9.313715
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred    -62.947904     -0.719234        -13.310014
# 8         QRNN_pred     26.327203     -0.073296        -10.180123
# 9          ESN_pred     48.081489      0.097694        -12.964956
# 10         BNN_pred    207.316039      1.466625         -3.176871
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     23.479257     -0.222761         -4.958778
# 1            CCV_dw     82.556364      0.441713         -3.557518
# 2            CCV_cw    101.411983      0.903580         -4.021807
# 3         LSTM_pred     82.774277      0.431047         -6.956703
# 4          GRU_pred    -10.841735     -0.603834        -10.406907
# 5     LSTM_GRU_pred     95.440063      0.595692         -3.001189
# 6       BiLSTM_pred     84.143763      0.579977         -3.698755
# 7   BiLSTM_GRU_pred     41.306573      0.008094         -4.046106
# 8         QRNN_pred   -142.475867     -1.272267        -18.682039
# 9          ESN_pred   -125.776512     -1.288692        -15.535370
# 10         BNN_pred     34.725804      0.008451        -14.299428
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -80.112423     -0.717560        -17.083763
# 1            CCV_dw     80.368292      0.391426         -3.518046
# 2            CCV_cw     66.270187      0.251101         -6.598930
# 3         LSTM_pred    -31.565571     -0.443706        -14.814772
# 4          GRU_pred    130.863955      0.902716         -3.255991
# 5     LSTM_GRU_pred    156.927543      1.044251         -5.426606
# 6       BiLSTM_pred    -76.273540     -0.751111        -14.814772
# 7   BiLSTM_GRU_pred    113.460044      0.576950         -6.498170
# 8         QRNN_pred    -66.009204     -0.605592        -15.535370
# 9          ESN_pred    -79.030063     -0.717838        -15.694732
# 10         BNN_pred    133.371725      0.885732         -3.336989
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -50.836812     -0.619168        -15.535370
# 1            CCV_dw    -57.059483     -0.610845        -15.535370
# 2            CCV_cw    -98.507685     -0.851001        -16.317555
# 3         LSTM_pred    -16.894289     -0.364161        -15.474381
# 4          GRU_pred   -110.397014     -0.924972        -17.953797
# 5     LSTM_GRU_pred   -100.010133     -0.871264        -16.680318
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred    -87.740133     -0.777321        -15.603630
# 8         QRNN_pred    -35.750620     -0.470773        -15.535370
# 9          ESN_pred   -100.041094     -0.856089        -16.317555
# 10         BNN_pred    207.316039      1.466625         -3.176871
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.722407     -0.082627        -14.680742
# 1            CCV_dw    167.491107      1.134158         -3.301464
# 2            CCV_cw     51.874123      0.125489        -14.273879
# 3         LSTM_pred    103.608166      0.515758         -6.951385
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred    178.238255      1.221024         -3.321602
# 6       BiLSTM_pred    130.857566      0.760684         -6.681250
# 7   BiLSTM_GRU_pred    102.275096      0.505486         -6.959791
# 8         QRNN_pred     14.064510     -0.160187        -13.399868
# 9          ESN_pred     84.701418      0.374014         -7.111357
# 10         BNN_pred    107.346100      0.543095         -6.927920
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.160598      0.766597         -3.633656
# 1            CCV_dw    167.491107      1.134158         -3.301464
# 2            CCV_cw    167.491107      1.134158         -3.301464
# 3         LSTM_pred     96.237232      0.497877         -6.998125
# 4          GRU_pred    183.563727      1.178712         -3.336496
# 5     LSTM_GRU_pred    178.238255      1.221024         -3.321602
# 6       BiLSTM_pred    113.194334      0.638933         -5.904260
# 7   BiLSTM_GRU_pred    178.374934      1.224420         -3.321217
# 8         QRNN_pred     93.414907      0.440279         -6.910041
# 9          ESN_pred    119.082911      0.673756         -6.855260
# 10         BNN_pred    178.374934      1.224420         -3.321217
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw     25.677092     -0.260817         -4.518006
# 2            CCV_cw    -13.863416     -0.972686         -7.501418
# 3         LSTM_pred     92.414351      0.689602         -4.157926
# 4          GRU_pred    121.338387      0.919644         -2.311832
# 5     LSTM_GRU_pred     50.602858      0.161586         -2.276847
# 6       BiLSTM_pred     66.922073      0.403282         -2.117287
# 7   BiLSTM_GRU_pred    -56.489897     -1.685649         -5.648990
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred    -68.506644     -2.178598         -7.235458
# 10         BNN_pred    125.065277      0.979640         -2.757022
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw     35.840452     -0.061270         -4.971830
# 2            CCV_cw     82.667127      0.576572         -6.308350
# 3         LSTM_pred    170.295969      1.494544         -3.124036
# 4          GRU_pred     15.620447     -0.394766         -3.824272
# 5     LSTM_GRU_pred     38.321055     -0.039569         -2.393698
# 6       BiLSTM_pred     73.467361      0.479587         -2.943973
# 7   BiLSTM_GRU_pred     93.868960      0.625371         -3.360452
# 8         QRNN_pred     21.458308     -0.173606         -7.851780
# 9          ESN_pred     17.047251     -0.246332         -6.790988
# 10         BNN_pred    204.865538      1.681850         -1.762886
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    150.843118      0.995000         -3.562038
# 1            CCV_dw    118.993245      0.645128         -4.878309
# 2            CCV_cw     45.657098      0.067672         -3.360174
# 3         LSTM_pred    103.182483      0.611101         -3.515841
# 4          GRU_pred    122.984980      0.868181         -2.902810
# 5     LSTM_GRU_pred    121.311724      0.786409         -2.964054
# 6       BiLSTM_pred     23.329195     -0.151845         -6.445461
# 7   BiLSTM_GRU_pred    120.642866      0.826875         -3.279793
# 8         QRNN_pred     93.167354      0.510119         -6.911606
# 9          ESN_pred     87.356056      0.470853         -7.016974
# 10         BNN_pred    178.128132      1.266612         -3.230977
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw     25.677092     -0.260817         -4.518006
# 2            CCV_cw     21.594260     -0.286549         -5.840415
# 3         LSTM_pred    102.893914      0.803452         -4.118418
# 4          GRU_pred    137.457213      1.070094         -3.165398
# 5     LSTM_GRU_pred     50.602858      0.161586         -2.276847
# 6       BiLSTM_pred     66.922073      0.403282         -2.117287
# 7   BiLSTM_GRU_pred    -73.350127     -1.464764         -8.133216
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred    -68.506644     -2.178598         -7.235458
# 10         BNN_pred     57.249786      0.178181         -8.474128
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw     35.840452     -0.061270         -4.971830
# 2            CCV_cw    121.595669      0.988383         -5.274640
# 3         LSTM_pred    181.522653      1.580489         -3.094352
# 4          GRU_pred     30.219617     -0.154182         -4.695850
# 5     LSTM_GRU_pred     38.321055     -0.039569         -2.393698
# 6       BiLSTM_pred     51.255250      0.135124         -5.718388
# 7   BiLSTM_GRU_pred     57.067226      0.182446         -5.622900
# 8         QRNN_pred    -52.670115     -0.897382        -14.877758
# 9          ESN_pred      5.040325     -0.376987         -6.859425
# 10         BNN_pred    132.239931      0.795683         -6.197170
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.285013      0.062577        -14.391393
# 1            CCV_dw    118.993245      0.645128         -4.878309
# 2            CCV_cw    -57.894629     -0.816465        -15.332532
# 3         LSTM_pred    103.681263      0.615667         -3.514252
# 4          GRU_pred    118.071377      0.750225         -4.649757
# 5     LSTM_GRU_pred    121.311724      0.786409         -2.964054
# 6       BiLSTM_pred     36.963198     -0.000380         -6.934197
# 7   BiLSTM_GRU_pred    101.478326      0.579094         -5.578887
# 8         QRNN_pred     13.834922     -0.214243        -13.402902
# 9          ESN_pred     31.680955     -0.049750         -7.550459
# 10         BNN_pred    178.128132      1.266612         -3.230977
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw     25.677092     -0.260817         -4.518006
# 2            CCV_cw     21.594260     -0.286549         -5.840415
# 3         LSTM_pred     83.185545      0.462420         -6.947002
# 4          GRU_pred    -34.716517     -0.487049        -14.814772
# 5     LSTM_GRU_pred     50.602858      0.161586         -2.276847
# 6       BiLSTM_pred     66.922073      0.403282         -2.117287
# 7   BiLSTM_GRU_pred    -73.350127     -1.464764         -8.133216
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred    -68.506644     -2.178598         -7.235458
# 10         BNN_pred    -19.611999     -0.395136        -15.401605
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw     23.838932     -0.216653         -5.030110
# 2            CCV_cw    121.595669      0.988383         -5.274640
# 3         LSTM_pred    160.409213      1.148447         -5.228548
# 4          GRU_pred     10.515674     -0.348844         -7.063190
# 5     LSTM_GRU_pred     36.559415     -0.065447         -2.393698
# 6       BiLSTM_pred     69.339281      0.334758         -5.621682
# 7   BiLSTM_GRU_pred     57.067226      0.182446         -5.622900
# 8         QRNN_pred    -47.867612     -0.648213        -15.535370
# 9          ESN_pred      0.655058     -0.330401         -8.277173
# 10         BNN_pred     49.926382      0.112291        -14.290174
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     39.697217      0.046288        -14.632099
# 1            CCV_dw   -110.703805     -1.022530        -17.187833
# 2            CCV_cw    -87.154261     -0.961566        -15.833563
# 3         LSTM_pred    113.795554      0.707663         -3.482339
# 4          GRU_pred    -68.561433     -0.690452        -15.571970
# 5     LSTM_GRU_pred    125.121238      0.827482         -2.954018
# 6       BiLSTM_pred    -87.638069     -0.837918        -17.914974
# 7   BiLSTM_GRU_pred    113.717761      0.619109         -6.555487
# 8         QRNN_pred   -104.548831     -0.959003        -17.100504
# 9          ESN_pred    -41.827907     -0.557471        -15.535370
# 10         BNN_pred    175.992873      1.245595         -3.236843
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw    167.491107      1.134158         -3.301464
# 2            CCV_cw     84.295434      0.370128         -7.711557
# 3         LSTM_pred    103.608166      0.515758         -6.951385
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred    178.238255      1.221024         -3.321602
# 6       BiLSTM_pred     91.071114      0.455645         -6.584313
# 7   BiLSTM_GRU_pred    133.463285      0.808977         -3.672213
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred     97.118317      0.467625         -6.886716
# 10         BNN_pred    178.374934      1.224420         -3.321217
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.160598      0.766597         -3.633656
# 1            CCV_dw    189.008699      1.224420         -3.321217
# 2            CCV_cw    167.491107      1.134158         -3.301464
# 3         LSTM_pred    100.744844      0.535069         -6.626702
# 4          GRU_pred    183.563727      1.178712         -3.336496
# 5     LSTM_GRU_pred    178.238255      1.221024         -3.321602
# 6       BiLSTM_pred    189.008699      1.224420         -3.321217
# 7   BiLSTM_GRU_pred    178.374934      1.224420         -3.321217
# 8         QRNN_pred    167.491107      1.134158         -3.301464
# 9          ESN_pred    121.765936      0.616362         -6.900579
# 10         BNN_pred    177.842398      1.220038         -3.322718
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw     19.545949     -0.386092         -4.604004
# 2            CCV_cw    -26.024337     -1.325563         -6.375998
# 3         LSTM_pred     67.334308      0.369973         -4.255629
# 4          GRU_pred    168.255577      1.548413         -1.745478
# 5     LSTM_GRU_pred     17.379825     -0.498803         -2.351199
# 6       BiLSTM_pred     97.280857      0.756763         -1.702662
# 7   BiLSTM_GRU_pred     16.037829     -0.326350         -5.461614
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred    -22.947148     -1.465607         -4.553508
# 10         BNN_pred    115.383631      0.906180         -2.780953
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw     79.060541      0.422428         -5.848694
# 2            CCV_cw     27.826385     -0.141857         -7.939993
# 3         LSTM_pred    147.016262      1.325802         -3.187441
# 4          GRU_pred     15.620447     -0.394766         -3.824272
# 5     LSTM_GRU_pred      8.808531     -0.451873         -2.946138
# 6       BiLSTM_pred    111.998264      0.788082         -2.999966
# 7   BiLSTM_GRU_pred     26.170451     -0.181735         -3.514005
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred     43.096818      0.033965         -5.109295
# 10         BNN_pred    211.919493      1.888492         -1.733900
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.940921      0.371345         -3.827800
# 1            CCV_dw    107.116275      0.570899         -3.498167
# 2            CCV_cw     23.445960     -0.207586         -4.819700
# 3         LSTM_pred    159.930705      1.294749         -3.164465
# 4          GRU_pred      8.693159     -0.473760         -4.290971
# 5     LSTM_GRU_pred    161.989273      1.224197         -2.393698
# 6       BiLSTM_pred     58.943553      0.117607         -4.384055
# 7   BiLSTM_GRU_pred    106.170523      0.742544         -2.460545
# 8         QRNN_pred    108.276609      0.891758         -2.393698
# 9          ESN_pred     55.493579      0.169015         -7.147804
# 10         BNN_pred    117.622266      0.763994         -4.554092
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw     17.698106     -0.415251         -4.604004
# 2            CCV_cw     -3.132697     -0.697455         -5.881854
# 3         LSTM_pred     67.334308      0.369973         -4.255629
# 4          GRU_pred    168.255577      1.548413         -1.745478
# 5     LSTM_GRU_pred     17.379825     -0.498803         -2.351199
# 6       BiLSTM_pred     87.467449      0.756763         -1.702662
# 7   BiLSTM_GRU_pred    -16.573419     -0.628917         -8.859699
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred    -22.947148     -1.465607         -4.553508
# 10         BNN_pred    115.383631      0.906180         -2.780953
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw     77.104833      0.401057         -5.859313
# 2            CCV_cw     57.444219      0.191127         -5.644368
# 3         LSTM_pred    147.016262      1.325802         -3.187441
# 4          GRU_pred     30.219617     -0.154182         -4.695850
# 5     LSTM_GRU_pred    -25.974069     -0.791663         -5.881854
# 6       BiLSTM_pred     79.078797      0.460387         -4.360962
# 7   BiLSTM_GRU_pred    -11.314456     -0.552479         -6.364489
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred     10.405699     -0.353242         -7.073269
# 10         BNN_pred    212.467437      1.894140         -1.733117
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     37.957512     -0.005320         -7.279240
# 1            CCV_dw    106.862221      0.567374         -3.498970
# 2            CCV_cw    -83.859013     -1.025354        -13.534141
# 3         LSTM_pred    160.455143      1.300123         -3.163035
# 4          GRU_pred     23.192751     -0.241253         -4.728099
# 5     LSTM_GRU_pred    161.989273      1.224197         -2.393698
# 6       BiLSTM_pred     49.473011      0.117607         -4.384055
# 7   BiLSTM_GRU_pred     95.161235      0.536792         -5.603032
# 8         QRNN_pred      0.278767     -0.370369        -10.287200
# 9          ESN_pred     19.609895     -0.165278         -7.399360
# 10         BNN_pred    118.127575      0.768716         -4.552034
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw     17.698106     -0.415251         -4.604004
# 2            CCV_cw     -3.132697     -0.697455         -5.881854
# 3         LSTM_pred     58.317380      0.206105         -7.110242
# 4          GRU_pred     10.751582     -0.184171        -15.307552
# 5     LSTM_GRU_pred     17.379825     -0.498803         -2.351199
# 6       BiLSTM_pred     87.467449      0.756763         -1.702662
# 7   BiLSTM_GRU_pred     12.130597     -0.287673         -6.199518
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred    -22.947148     -1.465607         -4.553508
# 10         BNN_pred    -26.283858     -0.454837        -15.401605
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw     64.625213      0.268589         -5.896627
# 2            CCV_cw     66.581773      0.283767         -5.596011
# 3         LSTM_pred    137.326175      0.980767         -5.295821
# 4          GRU_pred     10.515674     -0.348844         -7.063190
# 5     LSTM_GRU_pred     -9.218562     -0.551149         -5.845535
# 6       BiLSTM_pred     97.815225      0.603154         -5.518257
# 7   BiLSTM_GRU_pred     31.592061     -0.075204         -5.702890
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred     23.987537     -0.161323         -8.556941
# 10         BNN_pred     56.550718      0.158001        -14.048858
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -32.488201     -0.519943        -15.535370
# 1            CCV_dw     84.253420      0.443525         -3.539985
# 2            CCV_cw   -131.413532     -1.178362        -18.724675
# 3         LSTM_pred    121.116673      0.768943         -5.355044
# 4          GRU_pred      3.623204     -0.415963         -7.111697
# 5     LSTM_GRU_pred    126.628041      0.896779         -2.393698
# 6       BiLSTM_pred     49.473011      0.117607         -4.384055
# 7   BiLSTM_GRU_pred    104.065480      0.626827         -5.476768
# 8         QRNN_pred    -32.488201     -0.519943        -15.535370
# 9          ESN_pred    -52.798756     -0.643343        -15.535370
# 10         BNN_pred    116.101061      0.748079         -4.560299
# 11               __    -96.091692     -0.830469        -16.317555

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     99.617825      0.528054         -5.886730
# 2            CCV_cw     51.874123      0.125489        -14.273879
# 3         LSTM_pred    -96.091692     -0.830469        -16.317555
# 4          GRU_pred    130.857566      0.760684         -6.681250
# 5     LSTM_GRU_pred     34.274663      0.013758        -14.708813
# 6       BiLSTM_pred    -63.695647     -0.630022        -15.535370
# 7   BiLSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred    108.281287      0.600354         -5.190597
# 10         BNN_pred     84.701418      0.374014         -7.111357
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    148.434064      0.847559         -3.657049
# 1            CCV_dw    120.639878      0.704200         -4.216181
# 2            CCV_cw     86.603115      0.418540         -6.953359
# 3         LSTM_pred    116.848067      0.657532         -6.868978
# 4          GRU_pred     91.071114      0.455645         -6.584313
# 5     LSTM_GRU_pred    108.281287      0.600354         -5.190597
# 6       BiLSTM_pred    128.160598      0.766597         -3.633656
# 7   BiLSTM_GRU_pred     32.634565     -0.088433        -13.481605
# 8         QRNN_pred    106.532521      0.575166         -6.828124
# 9          ESN_pred    177.842398      1.220038         -3.322718
# 10         BNN_pred     99.617825      0.528054         -5.886730
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -69.861162     -1.200247        -10.625852
# 1            CCV_dw    -28.418057     -0.700726         -6.254645
# 2            CCV_cw      6.624526     -0.454321         -9.571897
# 3         LSTM_pred     16.387554     -0.228815         -7.950517
# 4          GRU_pred     76.884831      0.341554         -4.998966
# 5     LSTM_GRU_pred    -25.695210     -0.735423        -10.491741
# 6       BiLSTM_pred     16.926615     -0.251324         -6.190325
# 7   BiLSTM_GRU_pred     89.400942      0.486966         -3.896357
# 8         QRNN_pred     -5.242339     -0.516427         -7.712034
# 9          ESN_pred    154.576028      1.272501         -2.287862
# 10         BNN_pred     76.609376      0.464520         -4.954885
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    184.318093      1.143084         -4.598544
# 1            CCV_dw    155.833210      0.976307         -4.740384
# 2            CCV_cw    171.051157      1.237837         -3.346104
# 3         LSTM_pred     65.478259      0.247511         -7.436354
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred    154.470409      0.965179         -5.059471
# 6       BiLSTM_pred     57.742465      0.185492         -4.480535
# 7   BiLSTM_GRU_pred    -12.934038     -0.558133        -13.141564
# 8         QRNN_pred     23.640671     -0.173886         -7.494431
# 9          ESN_pred    144.586631      1.065520         -3.036751
# 10         BNN_pred    116.275501      0.743845         -3.424774
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    176.591687      1.120660         -3.322718
# 1            CCV_dw    135.148097      0.825628         -4.162294
# 2            CCV_cw     82.215447      0.374377         -6.394089
# 3         LSTM_pred    116.848067      0.657532         -6.868978
# 4          GRU_pred     68.790056      0.187555         -6.886416
# 5     LSTM_GRU_pred    108.281287      0.600354         -5.190597
# 6       BiLSTM_pred    142.309814      0.882371         -3.643774
# 7   BiLSTM_GRU_pred      1.523824     -0.255820        -13.567656
# 8         QRNN_pred     40.458971      0.028244         -7.261739
# 9          ESN_pred    160.383360      1.084731         -3.321686
# 10         BNN_pred    100.394124      0.534445         -5.886730
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -72.968561     -0.979694        -12.736187
# 1            CCV_dw    -46.643937     -0.889347         -8.013211
# 2            CCV_cw      6.624526     -0.454321         -9.571897
# 3         LSTM_pred    -63.825430     -0.724161        -14.814772
# 4          GRU_pred     67.253833      0.341554         -4.998966
# 5     LSTM_GRU_pred    -80.805395     -0.837499        -17.222301
# 6       BiLSTM_pred   -102.919258     -0.958063        -16.154773
# 7   BiLSTM_GRU_pred     75.077961      0.373683         -6.162810
# 8         QRNN_pred    -52.717369     -0.898824        -10.825981
# 9          ESN_pred     96.021202      0.589109         -4.660692
# 10         BNN_pred     49.718607      0.112482         -8.488550
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    246.462950      1.548533         -5.114250
# 1            CCV_dw    110.782773      0.621963         -4.932641
# 2            CCV_cw    171.051157      1.237837         -3.346104
# 3         LSTM_pred     -9.615341     -0.286058        -15.146100
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred     77.379459      0.285528        -14.337236
# 6       BiLSTM_pred    -76.698842     -0.737216        -17.087700
# 7   BiLSTM_GRU_pred    -28.176565     -0.483278        -14.814772
# 8         QRNN_pred    -25.212808     -0.603856        -10.508152
# 9          ESN_pred     86.538421      0.461207         -5.294467
# 10         BNN_pred    116.275501      0.743845         -3.424774
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    155.821151      1.035093         -3.301464
# 1            CCV_dw     70.439658      0.287786         -6.047191
# 2            CCV_cw     47.626689      0.096994        -13.928735
# 3         LSTM_pred    -96.091692     -0.830469        -16.317555
# 4          GRU_pred     97.856856      0.491253         -6.987801
# 5     LSTM_GRU_pred     34.274663      0.013758        -14.708813
# 6       BiLSTM_pred      8.071721     -0.160894        -15.322961
# 7   BiLSTM_GRU_pred   -115.413024     -0.965382        -16.317555
# 8         QRNN_pred     -9.197164     -0.359397        -10.385586
# 9          ESN_pred    101.534013      0.548852         -5.222392
# 10         BNN_pred     85.467187      0.379725         -7.111357
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV   -135.885771     -1.251585        -18.658743
# 1            CCV_dw   -131.434553     -1.213455        -17.930544
# 2            CCV_cw      1.324122     -0.438864        -10.524210
# 3         LSTM_pred    -63.825430     -0.724161        -14.814772
# 4          GRU_pred     46.841575      0.081944         -7.323374
# 5     LSTM_GRU_pred    -94.198022     -0.939488        -18.428368
# 6       BiLSTM_pred   -106.380355     -0.936110        -18.183960
# 7   BiLSTM_GRU_pred     75.077961      0.373683         -6.162810
# 8         QRNN_pred   -104.982428     -1.134131        -15.746039
# 9          ESN_pred     -3.729509     -0.277378        -14.814772
# 10         BNN_pred     49.718607      0.112482         -8.488550
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    246.462950      1.548533         -5.114250
# 1            CCV_dw    130.804346      0.747435         -5.671446
# 2            CCV_cw    171.051157      1.237837         -3.346104
# 3         LSTM_pred     -9.615341     -0.286058        -15.146100
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred     -2.142633     -0.253724        -15.479811
# 6       BiLSTM_pred    -76.698842     -0.737216        -17.087700
# 7   BiLSTM_GRU_pred    -28.176565     -0.483278        -14.814772
# 8         QRNN_pred    -89.743829     -0.990938        -15.535370
# 9          ESN_pred    -28.157867     -0.443466        -15.535370
# 10         BNN_pred    116.275501      0.743845         -3.424774
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    155.821151      1.035093         -3.301464
# 1            CCV_dw    -76.022692     -0.823407        -15.535370
# 2            CCV_cw   -107.047850     -0.993594        -17.370102
# 3         LSTM_pred    -96.091692     -0.830469        -16.317555
# 4          GRU_pred    -87.009473     -0.788587        -16.680318
# 5     LSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 6       BiLSTM_pred      8.071721     -0.160894        -15.322961
# 7   BiLSTM_GRU_pred   -115.413024     -0.965382        -16.317555
# 8         QRNN_pred    -82.818008     -0.887291        -15.535370
# 9          ESN_pred    -49.178904     -0.551670        -15.535370
# 10         BNN_pred     -8.010381     -0.270163        -15.561879
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     76.910947      0.315397         -7.764436
# 2            CCV_cw    106.532521      0.575166         -6.828124
# 3         LSTM_pred    -58.190369     -0.603974        -15.535370
# 4          GRU_pred    130.857566      0.760684         -6.681250
# 5     LSTM_GRU_pred    -80.073633     -0.719933        -16.317555
# 6       BiLSTM_pred     -3.081721     -0.279698        -15.060737
# 7   BiLSTM_GRU_pred     14.064510     -0.160187        -13.399868
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred    108.281287      0.600354         -5.190597
# 10         BNN_pred     97.118317      0.467625         -6.886716
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.545695      0.849282         -3.655821
# 1            CCV_dw     99.617825      0.528054         -5.886730
# 2            CCV_cw    102.912535      0.554937         -5.869144
# 3         LSTM_pred    117.338894      0.543095         -6.927920
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred    102.912535      0.554937         -5.869144
# 6       BiLSTM_pred    128.160598      0.766597         -3.633656
# 7   BiLSTM_GRU_pred     32.634565     -0.088433        -13.481605
# 8         QRNN_pred     93.414907      0.440279         -6.910041
# 9          ESN_pred    108.281287      0.600354         -5.190597
# 10         BNN_pred    109.868909      0.612055         -5.921951
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     25.218667     -0.199834         -4.950365
# 1            CCV_dw     67.592067      0.272362         -8.877427
# 2            CCV_cw     50.801714      0.139765         -3.518644
# 3         LSTM_pred     -8.653106     -0.423071         -8.831917
# 4          GRU_pred    -15.153748     -0.886436         -9.230979
# 5     LSTM_GRU_pred     46.304301      0.075836         -7.301541
# 6       BiLSTM_pred     12.729644     -0.271926         -5.829426
# 7   BiLSTM_GRU_pred    -48.264736     -0.899485        -13.141564
# 8         QRNN_pred    -58.212568     -0.788504        -10.691454
# 9          ESN_pred    150.663464      0.906472         -5.024361
# 10         BNN_pred    129.696785      0.862002         -5.138606
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     80.963094      0.333922         -7.976994
# 1            CCV_dw     51.397241      0.122006         -6.132326
# 2            CCV_cw      9.870188     -0.265366         -7.654117
# 3         LSTM_pred     83.238011      0.297461         -8.114935
# 4          GRU_pred    127.034998      0.859600         -3.267053
# 5     LSTM_GRU_pred     68.283615      0.251357         -8.145707
# 6       BiLSTM_pred    132.274539      0.812226         -3.669688
# 7   BiLSTM_GRU_pred      2.972757     -0.381143        -13.876317
# 8         QRNN_pred     37.880388      0.029721         -8.202036
# 9          ESN_pred    144.227757      0.965560         -5.104762
# 10         BNN_pred    162.338160      1.124898         -3.253829
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.545695      0.849282         -3.655821
# 1            CCV_dw    122.800768      0.721924         -5.853744
# 2            CCV_cw    -15.026590     -0.382433         -8.653081
# 3         LSTM_pred    109.488505      0.562035         -6.142554
# 4          GRU_pred     63.198114      0.144770         -9.956086
# 5     LSTM_GRU_pred    129.344113      0.771255         -5.819828
# 6       BiLSTM_pred    117.015197      0.674113         -3.682912
# 7   BiLSTM_GRU_pred    -68.623858     -0.835113        -14.157592
# 8         QRNN_pred     64.987147      0.228771         -7.203472
# 9          ESN_pred    115.682223      0.657444         -5.156165
# 10         BNN_pred    215.122393      1.539185         -3.156462
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     23.479257     -0.222761         -4.958778
# 1            CCV_dw     67.592067      0.272362         -8.877427
# 2            CCV_cw     50.801714      0.139765         -3.518644
# 3         LSTM_pred    -79.054631     -0.840973        -14.814772
# 4          GRU_pred    -16.389110     -0.673774        -10.406907
# 5     LSTM_GRU_pred     74.475824      0.374566         -7.086127
# 6       BiLSTM_pred   -105.084245     -1.230496        -15.260022
# 7   BiLSTM_GRU_pred    -60.777746     -0.839810        -14.054441
# 8         QRNN_pred    -92.400258     -1.067344        -13.933430
# 9          ESN_pred    150.663464      0.906472         -5.024361
# 10         BNN_pred    125.086078      0.729218         -6.149030
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     56.832016      0.158528         -7.907846
# 1            CCV_dw     17.755895     -0.121177         -8.183184
# 2            CCV_cw     33.401453     -0.036902         -6.808817
# 3         LSTM_pred     -7.256189     -0.267570        -15.146100
# 4          GRU_pred    130.863955      0.902716         -3.255991
# 5     LSTM_GRU_pred     11.118408     -0.124531        -15.276790
# 6       BiLSTM_pred      0.553632     -0.256729        -15.260022
# 7   BiLSTM_GRU_pred     -5.997217     -0.381143        -13.876317
# 8         QRNN_pred      0.204442     -0.228329        -10.263228
# 9          ESN_pred    144.227757      0.965560         -5.104762
# 10         BNN_pred    160.231518      1.104383         -3.259737
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     56.755917      0.163700         -8.034071
# 2            CCV_cw     11.232765     -0.167446         -8.202036
# 3         LSTM_pred    -56.368231     -0.594706        -14.814772
# 4          GRU_pred     26.863189     -0.064127         -9.948296
# 5     LSTM_GRU_pred    -58.027364     -0.571094        -16.317555
# 6       BiLSTM_pred    -12.930544     -0.353718        -15.264894
# 7   BiLSTM_GRU_pred    -96.873944     -0.978851        -15.291346
# 8         QRNN_pred     26.327203     -0.073296        -10.180123
# 9          ESN_pred    115.682223      0.657444         -5.156165
# 10         BNN_pred    207.316039      1.466625         -3.176871
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     23.479257     -0.222761         -4.958778
# 1            CCV_dw     92.684001      0.474879         -6.735746
# 2            CCV_cw     50.801714      0.139765         -3.518644
# 3         LSTM_pred    -79.054631     -0.840973        -14.814772
# 4          GRU_pred    -10.841735     -0.603834        -10.406907
# 5     LSTM_GRU_pred     74.475824      0.374566         -7.086127
# 6       BiLSTM_pred    -99.291583     -0.877827        -18.003574
# 7   BiLSTM_GRU_pred    -66.936712     -0.733009        -14.814772
# 8         QRNN_pred   -142.475867     -1.272267        -18.682039
# 9          ESN_pred     15.071856     -0.095588        -15.061858
# 10         BNN_pred      6.152524     -0.169969        -14.702564
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -80.112423     -0.717560        -17.083763
# 1            CCV_dw    -48.409360     -0.467523        -15.535370
# 2            CCV_cw     38.480086      0.010727         -6.775519
# 3         LSTM_pred      6.450416     -0.174394        -15.139975
# 4          GRU_pred    130.863955      0.902716         -3.255991
# 5     LSTM_GRU_pred      5.874051     -0.156522        -15.356439
# 6       BiLSTM_pred    -15.627309     -0.323179        -15.463034
# 7   BiLSTM_GRU_pred     -2.340666     -0.263956        -15.482884
# 8         QRNN_pred    -66.009204     -0.605592        -15.535370
# 9          ESN_pred     -6.762138     -0.259185        -15.535370
# 10         BNN_pred    116.900566      0.658623         -5.410619
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -50.836812     -0.619168        -15.535370
# 1            CCV_dw    -68.600967     -0.766421        -15.535370
# 2            CCV_cw   -104.598975     -0.893084        -16.317555
# 3         LSTM_pred    -94.342883     -0.822470        -15.603630
# 4          GRU_pred   -110.397014     -0.924972        -17.953797
# 5     LSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 6       BiLSTM_pred   -116.107290     -0.969710        -16.317555
# 7   BiLSTM_GRU_pred   -107.814924     -0.915799        -16.317555
# 8         QRNN_pred    -35.750620     -0.470773        -15.535370
# 9          ESN_pred    -85.169579     -0.749031        -16.317555
# 10         BNN_pred    207.316039      1.466625         -3.176871
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.722407     -0.082627        -14.680742
# 1            CCV_dw     99.617825      0.528054         -5.886730
# 2            CCV_cw     41.097587      0.051462        -14.421630
# 3         LSTM_pred    119.884469      0.612055         -5.921951
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred    -43.507228     -0.524640        -15.535370
# 6       BiLSTM_pred    128.160598      0.766597         -3.633656
# 7   BiLSTM_GRU_pred    -17.138313     -0.400494        -15.535370
# 8         QRNN_pred     14.064510     -0.160187        -13.399868
# 9          ESN_pred    108.281287      0.600354         -5.190597
# 10         BNN_pred    107.346100      0.543095         -6.927920
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.160598      0.766597         -3.633656
# 1            CCV_dw    183.563727      1.178712         -3.336496
# 2            CCV_cw     91.071114      0.455645         -6.584313
# 3         LSTM_pred    189.008699      1.224420         -3.321217
# 4          GRU_pred    183.563727      1.178712         -3.336496
# 5     LSTM_GRU_pred    122.732284      0.634846         -5.906929
# 6       BiLSTM_pred    138.163174      0.847559         -3.657049
# 7   BiLSTM_GRU_pred     32.634565     -0.088433        -13.481605
# 8         QRNN_pred     93.414907      0.440279         -6.910041
# 9          ESN_pred    177.842398      1.220038         -3.322718
# 10         BNN_pred    178.374934      1.224420         -3.321217
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw   -106.170709     -2.511004        -11.695219
# 2            CCV_cw     50.931888      0.187530         -2.711791
# 3         LSTM_pred      3.790985     -0.702601         -5.723910
# 4          GRU_pred    121.338387      0.919644         -2.311832
# 5     LSTM_GRU_pred     62.441333      0.341306         -2.034078
# 6       BiLSTM_pred      1.823266     -0.524172         -4.555649
# 7   BiLSTM_GRU_pred    135.614694      1.365481         -3.825627
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred     47.742849      0.094849         -5.395983
# 10         BNN_pred    106.643083      1.206545         -1.667006
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw     83.539773      0.347043         -4.951094
# 2            CCV_cw     66.858246      0.387291         -2.393698
# 3         LSTM_pred     91.411376      0.538196         -7.914975
# 4          GRU_pred     15.620447     -0.394766         -3.824272
# 5     LSTM_GRU_pred     35.653906     -0.027508         -6.386521
# 6       BiLSTM_pred     21.688206     -0.200535         -4.590651
# 7   BiLSTM_GRU_pred    -35.058281     -0.741412        -13.141564
# 8         QRNN_pred     21.458308     -0.173606         -7.851780
# 9          ESN_pred    124.059111      0.936268         -2.975348
# 10         BNN_pred     85.126740      0.619495         -3.217320
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    150.843118      0.995000         -3.562038
# 1            CCV_dw    129.590873      0.685841         -4.928154
# 2            CCV_cw     26.314171     -0.140868         -7.630398
# 3         LSTM_pred     63.311053      0.158021         -3.783060
# 4          GRU_pred    122.984980      0.868181         -2.902810
# 5     LSTM_GRU_pred    159.902335      0.922620         -5.702325
# 6       BiLSTM_pred    147.474339      0.930304         -3.621078
# 7   BiLSTM_GRU_pred     46.889024      0.017939        -13.298039
# 8         QRNN_pred     93.167354      0.510119         -6.911606
# 9          ESN_pred    241.518925      1.699167         -2.545365
# 10         BNN_pred    162.335419      1.131603         -3.274876
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw   -104.386175     -2.319083        -11.518918
# 2            CCV_cw     43.207981      0.023173         -2.711791
# 3         LSTM_pred      3.790985     -0.702601         -5.723910
# 4          GRU_pred    137.457213      1.070094         -3.165398
# 5     LSTM_GRU_pred     62.441333      0.341306         -2.034078
# 6       BiLSTM_pred      6.052773     -0.434458         -5.000797
# 7   BiLSTM_GRU_pred    130.797272      1.035592         -6.066009
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred     28.402189     -0.152549         -6.286970
# 10         BNN_pred    106.643083      1.206545         -1.667006
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw     11.419939     -0.250297         -6.383785
# 2            CCV_cw     59.017288      0.268422         -2.393698
# 3         LSTM_pred     27.961066     -0.101632         -7.914975
# 4          GRU_pred     30.219617     -0.154182         -4.695850
# 5     LSTM_GRU_pred    -82.883207     -0.932178        -15.535370
# 6       BiLSTM_pred     26.001580     -0.141612         -5.017364
# 7   BiLSTM_GRU_pred    -31.508635     -0.530091        -14.814772
# 8         QRNN_pred    -52.670115     -0.897382        -14.877758
# 9          ESN_pred     67.051964      0.291316         -4.818983
# 10         BNN_pred     41.819036      0.032431         -6.641821
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.285013      0.062577        -14.391393
# 1            CCV_dw    130.544702      0.759172         -4.879959
# 2            CCV_cw    -22.181988     -0.467517        -15.332532
# 3         LSTM_pred      1.494384     -0.478441         -6.161639
# 4          GRU_pred    118.071377      0.750225         -4.649757
# 5     LSTM_GRU_pred      1.277518     -0.214350        -15.385621
# 6       BiLSTM_pred    157.097300      1.007519         -3.590964
# 7   BiLSTM_GRU_pred    -11.058220     -0.386773        -15.535370
# 8         QRNN_pred     13.834922     -0.214243        -13.402902
# 9          ESN_pred    178.554752      1.140147         -4.961041
# 10         BNN_pred    187.526775      1.331592         -3.205405
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw    -83.336297     -1.701597         -9.706410
# 2            CCV_cw     39.196266     -0.019380         -5.743481
# 3         LSTM_pred      3.790985     -0.702601         -5.723910
# 4          GRU_pred    -34.716517     -0.487049        -14.814772
# 5     LSTM_GRU_pred     62.441333      0.341306         -2.034078
# 6       BiLSTM_pred    -94.616255     -0.980159        -14.814772
# 7   BiLSTM_GRU_pred    130.797272      1.035592         -6.066009
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred     42.225935      0.030225         -7.677327
# 10         BNN_pred    104.637385      1.159595         -1.670033
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw    -89.416592     -0.888048        -15.923251
# 2            CCV_cw      2.029529     -0.366125         -8.102058
# 3         LSTM_pred    -47.211341     -0.572256        -14.814772
# 4          GRU_pred     10.515674     -0.348844         -7.063190
# 5     LSTM_GRU_pred    -79.941753     -0.902456        -15.535370
# 6       BiLSTM_pred   -102.408067     -0.925021        -18.756029
# 7   BiLSTM_GRU_pred    -31.508635     -0.530091        -14.814772
# 8         QRNN_pred    -47.867612     -0.648213        -15.535370
# 9          ESN_pred    -29.653575     -0.425560        -14.904722
# 10         BNN_pred    -70.000913     -0.764258        -16.366711
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     39.697217      0.046288        -14.632099
# 1            CCV_dw     89.981708      0.404184         -8.215434
# 2            CCV_cw   -117.201669     -1.018626        -18.441010
# 3         LSTM_pred    -95.074477     -0.896545        -15.847381
# 4          GRU_pred    -68.561433     -0.690452        -15.571970
# 5     LSTM_GRU_pred      4.648978     -0.181869        -15.333989
# 6       BiLSTM_pred      9.624540     -0.150011        -15.463034
# 7   BiLSTM_GRU_pred    -19.902708     -0.386773        -15.535370
# 8         QRNN_pred   -104.548831     -0.959003        -17.100504
# 9          ESN_pred     39.676497      0.053177        -14.872040
# 10         BNN_pred    141.104519      0.845248         -5.330099
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw    188.870786      1.221024         -3.321602
# 2            CCV_cw    130.857566      0.760684         -6.681250
# 3         LSTM_pred    141.293973      0.789060         -4.241407
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred    124.231239      0.714926         -6.823867
# 6       BiLSTM_pred    128.160598      0.766597         -3.633656
# 7   BiLSTM_GRU_pred     22.753503     -0.134495        -15.040316
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred    108.281287      0.600354         -5.190597
# 10         BNN_pred    109.868909      0.612055         -5.921951
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.160598      0.766597         -3.633656
# 1            CCV_dw    183.563727      1.178712         -3.336496
# 2            CCV_cw    177.842398      1.220038         -3.322718
# 3         LSTM_pred    189.008699      1.224420         -3.321217
# 4          GRU_pred    183.563727      1.178712         -3.336496
# 5     LSTM_GRU_pred    122.732284      0.634846         -5.906929
# 6       BiLSTM_pred    138.163174      0.847559         -3.657049
# 7   BiLSTM_GRU_pred    151.566393      0.840075         -6.722004
# 8         QRNN_pred    167.491107      1.134158         -3.301464
# 9          ESN_pred    177.842398      1.220038         -3.322718
# 10         BNN_pred    189.008699      1.224420         -3.321217
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw    -34.312902     -1.944204         -5.974039
# 2            CCV_cw     58.445293      0.466961         -0.822210
# 3         LSTM_pred     43.099406      0.021392         -3.327228
# 4          GRU_pred    168.255577      1.548413         -1.745478
# 5     LSTM_GRU_pred     52.453433      0.182702         -2.049538
# 6       BiLSTM_pred    -53.768829     -1.489295         -7.169825
# 7   BiLSTM_GRU_pred     76.165655      0.579629         -3.944368
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred     84.710481      0.585274         -4.005935
# 10         BNN_pred     61.359663      0.350614         -2.370564
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw     -9.468844     -0.776291         -6.471552
# 2            CCV_cw     62.043614      0.356321         -2.261305
# 3         LSTM_pred     60.440792      0.237259         -8.657475
# 4          GRU_pred     15.620447     -0.394766         -3.824272
# 5     LSTM_GRU_pred    135.546911      1.019548         -3.445250
# 6       BiLSTM_pred      4.018457     -0.382558         -6.069555
# 7   BiLSTM_GRU_pred    131.081120      1.308536         -2.126288
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred    164.911605      1.409703         -2.217784
# 10         BNN_pred    162.102404      1.613483         -3.064139
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.940921      0.371345         -3.827800
# 1            CCV_dw    144.949712      0.870040         -5.559727
# 2            CCV_cw     55.185309      0.199133         -3.380983
# 3         LSTM_pred    103.906806      0.629906         -3.648866
# 4          GRU_pred      8.693159     -0.473760         -4.290971
# 5     LSTM_GRU_pred     75.315447      0.338840         -6.111445
# 6       BiLSTM_pred     43.680432      0.050026         -5.397666
# 7   BiLSTM_GRU_pred     81.148342      0.438965         -6.445494
# 8         QRNN_pred    108.276609      0.891758         -2.393698
# 9          ESN_pred    159.156754      1.258883         -2.545365
# 10         BNN_pred    145.474652      0.977895         -3.322415
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw    -34.312902     -1.944204         -5.974039
# 2            CCV_cw     58.445293      0.466961         -0.822210
# 3         LSTM_pred     43.099406      0.021392         -3.327228
# 4          GRU_pred    168.255577      1.548413         -1.745478
# 5     LSTM_GRU_pred     52.453433      0.182702         -2.049538
# 6       BiLSTM_pred    -54.076717     -1.381708         -7.602780
# 7   BiLSTM_GRU_pred     74.653255      0.427511         -5.416136
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred     64.687422      0.313302         -4.867451
# 10         BNN_pred     61.359663      0.350614         -2.370564
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw    -23.552450     -0.856235         -7.877526
# 2            CCV_cw     62.043614      0.356321         -2.261305
# 3         LSTM_pred     60.440792      0.237259         -8.657475
# 4          GRU_pred     30.219617     -0.154182         -4.695850
# 5     LSTM_GRU_pred    135.546911      1.019548         -3.445250
# 6       BiLSTM_pred      8.257232     -0.319131         -6.107603
# 7   BiLSTM_GRU_pred    131.081120      1.308536         -2.126288
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred    104.327449      0.681259         -4.577038
# 10         BNN_pred     94.542399      0.649851         -5.379155
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     37.957512     -0.005320         -7.279240
# 1            CCV_dw    128.670547      0.690939         -5.559727
# 2            CCV_cw     13.093341     -0.308998         -7.457893
# 3         LSTM_pred     59.607205      0.200143         -6.386414
# 4          GRU_pred     23.192751     -0.241253         -4.728099
# 5     LSTM_GRU_pred    107.725790      0.601303         -6.924642
# 6       BiLSTM_pred     56.274126      0.177773         -5.333311
# 7   BiLSTM_GRU_pred    -39.787666     -0.610309        -14.610204
# 8         QRNN_pred      0.278767     -0.370369        -10.287200
# 9          ESN_pred    100.369614      0.610068         -5.313541
# 10         BNN_pred    145.474652      0.977895         -3.322415
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw    -34.312902     -1.944204         -5.974039
# 2            CCV_cw     46.625770      0.082530         -5.719325
# 3         LSTM_pred     43.099406      0.021392         -3.327228
# 4          GRU_pred     10.751582     -0.184171        -15.307552
# 5     LSTM_GRU_pred     52.453433      0.182702         -2.049538
# 6       BiLSTM_pred   -148.728986     -1.486819        -18.546496
# 7   BiLSTM_GRU_pred     74.653255      0.427511         -5.416136
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred     78.998913      0.443771         -6.270423
# 10         BNN_pred     59.436037      0.314352         -2.374869
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw    -22.102625     -0.652432         -6.908187
# 2            CCV_cw     50.183908      0.123537         -5.576099
# 3         LSTM_pred     60.440792      0.237259         -8.657475
# 4          GRU_pred     10.515674     -0.348844         -7.063190
# 5     LSTM_GRU_pred    135.546911      1.019548         -3.445250
# 6       BiLSTM_pred    -93.420012     -0.894431        -17.347838
# 7   BiLSTM_GRU_pred    131.081120      1.308536         -2.126288
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred     15.569269     -0.133457        -14.538771
# 10         BNN_pred     -4.029543     -0.266510        -14.814772
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -32.488201     -0.519943        -15.535370
# 1            CCV_dw    -47.521783     -0.474367        -15.594958
# 2            CCV_cw    -86.931760     -0.976122        -15.833563
# 3         LSTM_pred    -27.471529     -0.413171        -15.146100
# 4          GRU_pred      3.623204     -0.415963         -7.111697
# 5     LSTM_GRU_pred    -42.024878     -0.515307        -18.915269
# 6       BiLSTM_pred    -91.676871     -0.872176        -19.835581
# 7   BiLSTM_GRU_pred    -25.824214     -0.465540        -14.814772
# 8         QRNN_pred    -32.488201     -0.519943        -15.535370
# 9          ESN_pred      0.223147     -0.240630        -15.458661
# 10         BNN_pred    124.551727      0.712529         -6.426649
# 11               __    -96.091692     -0.830469        -16.317555

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y2', file, 'HV')
get_final_results_1('2024_y2', file, 'HV')

get_final_results('2024_y2', dw_file, 'HV_dw')
get_final_results_1('2024_y2', dw_file, 'HV_dw')

get_final_results('2024_y2', cw_file, 'HV_cw')
get_final_results_1('2024_y2', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:38: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-48-dbce691e5d20>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-48-dbce691e5d20>:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:51: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-48-dbce691e5d20>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-48-dbce691e5d20>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']
# <ipython-input-4-b267510ae310>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
# <ipython-input-4-b267510ae310>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Long_MA'] = data['Close'].rolling(window=long_window).mean()
# <ipython-input-4-b267510ae310>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-4-b267510ae310>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:21: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-4-b267510ae310>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-4-b267510ae310>:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-4-b267510ae310>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-4-b267510ae310>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    137.646971      0.875575         -8.115590
# 1             HV_dw    151.161879      1.013393         -8.588117
# 2             HV_cw    145.024852      1.000371         -6.500563
# 3         LSTM_pred    100.951003      0.586419         -9.302629
# 4          GRU_pred    120.513225      0.731754         -9.345933
# 5     LSTM_GRU_pred    135.460777      0.853998         -9.345933
# 6       BiLSTM_pred    111.371733      0.628605         -9.302629
# 7   BiLSTM_GRU_pred    103.994664      0.563615         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    123.066681      0.788446         -8.588117
# 10         BNN_pred     99.227489      0.528212         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    145.331335      1.089754         -4.297561
# 1             HV_dw    183.607072      1.463227         -7.318989
# 2             HV_cw     55.754899      0.118094         -6.500563
# 3         LSTM_pred     46.834946      0.080059         -8.424766
# 4          GRU_pred     93.439716      0.535257         -9.419603
# 5     LSTM_GRU_pred     77.014760      0.384060         -9.419603
# 6       BiLSTM_pred     96.836428      0.547927         -6.354654
# 7   BiLSTM_GRU_pred     60.528893      0.112865         -9.536885
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     92.115239      0.536771         -8.023967
# 10         BNN_pred     69.882489      0.312688        -10.270987
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    110.447441      1.019685         -4.049900
# 1             HV_dw    196.481888      1.717556         -4.047302
# 2             HV_cw     31.427019     -0.068212         -5.657823
# 3         LSTM_pred     21.915184     -0.209411         -8.424766
# 4          GRU_pred     87.906230      0.562114         -7.143998
# 5     LSTM_GRU_pred     54.250950      0.169664         -8.415522
# 6       BiLSTM_pred    100.803504      0.734041         -4.849539
# 7   BiLSTM_GRU_pred     12.978071     -0.298723         -9.536885
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     93.543972      0.589500         -5.675617
# 10         BNN_pred     30.445478     -0.101265        -10.130962
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    122.659255      0.934505         -3.886098
# 1             HV_dw    192.179673      1.556743         -6.483625
# 2             HV_cw     21.908132     -0.278386         -6.500563
# 3         LSTM_pred     34.436727     -0.058568         -8.424766
# 4          GRU_pred    100.754433      0.638032         -6.850221
# 5     LSTM_GRU_pred     87.981651      0.520110         -6.850221
# 6       BiLSTM_pred    103.993527      0.622962         -6.354654
# 7   BiLSTM_GRU_pred     31.680595     -0.083785         -9.536885
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    111.168225      0.746881         -6.967248
# 10         BNN_pred     57.718238      0.193199        -10.130962
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    117.432511      0.761278         -6.749600
# 1             HV_dw    183.607072      1.463227         -7.318989
# 2             HV_cw     62.875727      0.195643         -6.500563
# 3         LSTM_pred     60.253639      0.110637         -8.424766
# 4          GRU_pred    103.295238      0.631648         -8.603173
# 5     LSTM_GRU_pred     68.084025      0.300857         -8.603173
# 6       BiLSTM_pred     96.836428      0.547927         -6.354654
# 7   BiLSTM_GRU_pred     64.823583      0.157208         -9.536885
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     92.158247      0.537197         -8.023967
# 10         BNN_pred     64.867574      0.262056        -10.270987
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    169.403304      1.615948         -2.455820
# 1             HV_dw    146.829773      1.054537         -7.100868
# 2             HV_cw    105.193092      0.764803         -5.657823
# 3         LSTM_pred     69.149306      0.297193         -9.302629
# 4          GRU_pred    126.237411      0.866092         -7.355253
# 5     LSTM_GRU_pred    141.994273      1.004657         -7.355253
# 6       BiLSTM_pred     99.808030      0.617467         -8.485144
# 7   BiLSTM_GRU_pred     80.542206      0.357223         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    118.779067      0.819319         -6.944894
# 10         BNN_pred     82.575416      0.382051         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    193.355176      1.659697         -3.153872
# 1             HV_dw    145.619585      1.062458         -7.764192
# 2             HV_cw     95.454426      0.533634         -6.500563
# 3         LSTM_pred     89.543348      0.483442         -9.302629
# 4          GRU_pred    115.438740      0.817623         -7.236876
# 5     LSTM_GRU_pred    117.112784      0.822270         -7.236876
# 6       BiLSTM_pred    111.371733      0.628605         -9.302629
# 7   BiLSTM_GRU_pred    101.153567      0.545043         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    127.644198      0.879031         -8.219144
# 10         BNN_pred     84.940019      0.401448         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    139.991371      0.896819         -8.115590
# 1             HV_dw    151.161879      1.013393         -8.588117
# 2             HV_cw    137.594974      0.930686         -6.500563
# 3         LSTM_pred    100.951003      0.586419         -9.302629
# 4          GRU_pred    120.513225      0.828400         -8.528839
# 5     LSTM_GRU_pred    114.207254      0.769564         -8.528839
# 6       BiLSTM_pred    111.371733      0.628605         -9.302629
# 7   BiLSTM_GRU_pred    103.994664      0.563615         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    123.110908      0.788844         -8.588117
# 10         BNN_pred     99.227489      0.528212         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     93.005429      0.561779         -8.485144
# 1             HV_dw    113.008916      0.703108         -8.485144
# 2             HV_cw     93.005429      0.561779         -8.485144
# 3         LSTM_pred     97.459388      0.509485         -9.302629
# 4          GRU_pred     94.406715      0.476962         -9.035617
# 5     LSTM_GRU_pred     94.406715      0.476962         -9.035617
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred     97.459388      0.509485         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     94.406715      0.481149         -9.302629
# 10         BNN_pred     95.709527      0.493258         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     94.406715      0.481149         -9.302629
# 1             HV_dw    113.008916      0.735696         -8.485144
# 2             HV_cw     94.406715      0.481149         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     97.459388      0.603346         -8.485144
# 5     LSTM_GRU_pred     95.709527      0.587046         -8.485144
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.690588         -9.302629
# 10         BNN_pred     95.709527      0.493258         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    118.393445      0.690588         -9.302629
# 1             HV_dw    118.393445      0.690588         -9.302629
# 2             HV_cw    118.393445      0.690588         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.783519         -8.485144
# 5     LSTM_GRU_pred     97.459388      0.603346         -8.485144
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.690588         -9.302629
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    124.622667      0.747319         -8.765729
# 1             HV_dw    113.875261      0.720862         -8.588117
# 2             HV_cw    114.320399      0.654185         -9.302629
# 3         LSTM_pred     96.486979      0.546935         -9.302629
# 4          GRU_pred    130.191977      0.814645         -9.419603
# 5     LSTM_GRU_pred    135.460777      0.853998         -9.345933
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred     96.712930      0.551091         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     81.276958      0.409324        -10.297472
# 10         BNN_pred    109.239508      0.622570         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    184.891600      1.481521         -3.820064
# 1             HV_dw    178.215240      1.356530         -8.588117
# 2             HV_cw     90.042181      0.443235         -9.302629
# 3         LSTM_pred     83.077835      0.346134         -7.143639
# 4          GRU_pred    118.089073      0.764419         -9.222801
# 5     LSTM_GRU_pred     87.799686      0.486733         -9.419603
# 6       BiLSTM_pred     96.364642      0.551183         -6.354654
# 7   BiLSTM_GRU_pred    108.779984      0.573101         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    138.831568      0.870864         -7.431712
# 10         BNN_pred     81.603657      0.320985        -10.313829
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    100.062341      0.842195         -2.960203
# 1             HV_dw    150.784086      1.175889         -7.100868
# 2             HV_cw     11.358825     -0.376725         -8.890511
# 3         LSTM_pred     66.671758      0.293590         -7.143639
# 4          GRU_pred    164.534325      1.364026         -6.582078
# 5     LSTM_GRU_pred    104.703717      0.745298         -7.861297
# 6       BiLSTM_pred    114.592460      0.760072         -4.849539
# 7   BiLSTM_GRU_pred     43.742554      0.048136         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    127.063043      0.993697         -5.319672
# 10         BNN_pred     41.289022      0.020820         -9.364239
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    156.305194      1.322151         -2.354686
# 1             HV_dw    166.309477      1.253487         -8.588117
# 2             HV_cw     64.721016      0.311097         -8.485144
# 3         LSTM_pred     66.671758      0.293590         -7.143639
# 4          GRU_pred    172.911997      1.314316         -7.242169
# 5     LSTM_GRU_pred    104.321390      0.689367         -7.682310
# 6       BiLSTM_pred    103.046067      0.621813         -6.354654
# 7   BiLSTM_GRU_pred     71.792440      0.329829         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    109.142294      0.713556         -8.331495
# 10         BNN_pred     63.606917      0.253729        -10.173871
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    111.630132      0.681428         -9.766839
# 1             HV_dw    166.309477      1.253487         -8.588117
# 2             HV_cw     87.839253      0.432043         -9.302629
# 3         LSTM_pred     69.460128      0.317013         -7.143639
# 4          GRU_pred    161.529643      1.192419         -8.140222
# 5     LSTM_GRU_pred    122.696983      0.833047         -9.419603
# 6       BiLSTM_pred     96.364642      0.551183         -6.354654
# 7   BiLSTM_GRU_pred     78.714424      0.396440         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     75.169617      0.367531        -10.637331
# 10         BNN_pred     63.053231      0.138215        -10.313829
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    152.740335      1.266759         -5.325611
# 1             HV_dw     93.614720      0.556064         -7.100868
# 2             HV_cw     73.242072      0.297392         -8.890511
# 3         LSTM_pred     95.406847      0.544256         -9.302629
# 4          GRU_pred    174.251300      1.486583         -6.582078
# 5     LSTM_GRU_pred    159.087818      1.284288         -6.794612
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred     53.473643      0.146877         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    101.252923      0.668127         -5.579654
# 10         BNN_pred     67.839162      0.334757         -8.485144
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    162.748198      1.280354         -5.325611
# 1             HV_dw    113.875261      0.720862         -8.588117
# 2             HV_cw     89.209174      0.532106         -8.485144
# 3         LSTM_pred     95.406847      0.544256         -9.302629
# 4          GRU_pred    182.283300      1.343353         -7.242169
# 5     LSTM_GRU_pred    135.417939      0.907721         -8.065511
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred     81.785046      0.417172         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     83.742566      0.441428        -10.092926
# 10         BNN_pred     94.821905      0.497703         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    112.286884      0.640166         -9.766462
# 1             HV_dw    113.875261      0.720862         -8.588117
# 2             HV_cw     99.442036      0.528451         -9.302629
# 3         LSTM_pred     87.669824      0.467092         -9.302629
# 4          GRU_pred    153.773913      1.051324         -8.140222
# 5     LSTM_GRU_pred    146.301326      0.955214         -9.345933
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred     81.785046      0.417172         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     80.398259      0.401078        -10.370369
# 10         BNN_pred     88.476794      0.435342         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     84.987072      0.451460         -8.488748
# 1             HV_dw     90.434210      0.503076         -8.485144
# 2             HV_cw     79.763379      0.355471         -8.890511
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     95.709527      0.587046         -8.485144
# 5     LSTM_GRU_pred     94.406715      0.574879         -8.485144
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred     97.459388      0.509485         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     82.140958      0.367370         -9.302629
# 10         BNN_pred     95.709527      0.587046         -8.485144
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     94.406715      0.481149         -9.302629
# 1             HV_dw    118.393445      0.690588         -9.302629
# 2             HV_cw     93.005429      0.561779         -8.485144
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred     97.459388      0.509485         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.690588         -9.302629
# 10         BNN_pred     95.709527      0.493258         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    118.393445      0.690588         -9.302629
# 1             HV_dw    118.393445      0.690588         -9.302629
# 2             HV_cw     95.709527      0.493258         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    118.393445      0.690588         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.690588         -9.302629
# 10         BNN_pred     97.459388      0.509485         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    157.861321      1.055028         -6.066139
# 1             HV_dw    141.531487      1.008004         -8.588117
# 2             HV_cw     93.261889      0.463090        -10.132498
# 3         LSTM_pred     99.068628      0.580132         -9.302629
# 4          GRU_pred     71.228613      0.333833        -10.125437
# 5     LSTM_GRU_pred    127.848525      0.826842         -8.706012
# 6       BiLSTM_pred    109.780104      0.682579         -6.354654
# 7   BiLSTM_GRU_pred    112.967104      0.663373         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     89.704260      0.386970         -9.302629
# 10         BNN_pred     64.601284      0.153039        -10.270987
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    100.860385      0.508864         -9.477214
# 1             HV_dw    149.140621      1.102313         -7.360509
# 2             HV_cw     51.676806      0.063982        -10.132498
# 3         LSTM_pred     79.546209      0.313553         -9.982907
# 4          GRU_pred      2.810499     -0.439308         -9.832867
# 5     LSTM_GRU_pred      5.644781     -0.391956        -12.686699
# 6       BiLSTM_pred     54.657418      0.116194         -8.651395
# 7   BiLSTM_GRU_pred     50.102882      0.115338         -8.850512
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     34.860304     -0.146622         -9.302629
# 10         BNN_pred      8.487224     -0.390222         -8.295194
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     86.574931      0.595487         -4.562087
# 1             HV_dw     58.640306      0.300587         -2.968687
# 2             HV_cw    -23.377376     -1.003142         -8.488748
# 3         LSTM_pred     47.383699      0.090137         -6.183537
# 4          GRU_pred     21.953347     -0.302740         -4.916189
# 5     LSTM_GRU_pred     50.468100      0.138005         -4.684215
# 6       BiLSTM_pred     61.584988      0.190693         -5.156033
# 7   BiLSTM_GRU_pred    -35.583001     -1.080454         -7.990384
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    -11.786724     -0.777355         -9.302629
# 10         BNN_pred     12.963290     -0.481831         -5.915052
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    114.836838      0.847929         -5.144170
# 1             HV_dw    105.087969      0.710633         -5.227756
# 2             HV_cw      6.013260     -0.514170         -9.035617
# 3         LSTM_pred     67.669689      0.327967         -6.935321
# 4          GRU_pred     44.780979      0.054366         -6.099182
# 5     LSTM_GRU_pred     91.313039      0.653726         -6.582078
# 6       BiLSTM_pred     83.263687      0.455132         -5.643780
# 7   BiLSTM_GRU_pred     13.200437     -0.333854         -8.850512
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred      2.009322     -0.412890         -9.302629
# 10         BNN_pred     18.724517     -0.300966         -7.235995
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    123.994890      0.926309         -5.114515
# 1             HV_dw    136.690529      1.003802         -7.360509
# 2             HV_cw     32.645001     -0.151311         -9.035617
# 3         LSTM_pred     56.217309      0.182339        -10.481384
# 4          GRU_pred     72.459049      0.386143         -7.907876
# 5     LSTM_GRU_pred    113.495423      0.854446         -5.954355
# 6       BiLSTM_pred     59.211864      0.149024         -8.651395
# 7   BiLSTM_GRU_pred     33.964469     -0.062825         -8.850512
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     30.915122     -0.087005         -9.302629
# 10         BNN_pred     -2.706675     -0.567001         -8.152086
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    146.522213      1.149923         -5.339951
# 1             HV_dw     55.444930      0.176058         -7.100868
# 2             HV_cw     58.467755      0.215605         -8.488748
# 3         LSTM_pred     33.455447     -0.065933         -9.302629
# 4          GRU_pred     82.439955      0.547779         -5.450334
# 5     LSTM_GRU_pred    116.937407      1.032068         -4.684215
# 6       BiLSTM_pred    127.705476      0.910214         -4.641796
# 7   BiLSTM_GRU_pred     41.915605     -0.046964         -8.086634
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    -11.786724     -0.777355         -9.302629
# 10         BNN_pred     -1.361754     -0.487219         -9.320944
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    148.939611      1.141803         -5.549007
# 1             HV_dw    121.333027      0.848489         -7.100868
# 2             HV_cw     56.726251      0.116976         -9.035617
# 3         LSTM_pred     79.636855      0.401624         -9.302629
# 4          GRU_pred    136.318931      1.084703         -6.582078
# 5     LSTM_GRU_pred    142.172692      1.231406         -6.582078
# 6       BiLSTM_pred    144.335063      1.063345         -4.849539
# 7   BiLSTM_GRU_pred     52.415349      0.082034         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     26.787815     -0.132333         -9.302629
# 10         BNN_pred     25.537757     -0.149069        -10.130962
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    152.241896      1.172739         -5.325611
# 1             HV_dw    136.035560      0.957258         -8.588117
# 2             HV_cw     77.384215      0.319893         -9.035617
# 3         LSTM_pred     79.636855      0.401624         -9.302629
# 4          GRU_pred    137.931829      1.033923         -8.684354
# 5     LSTM_GRU_pred    155.899474      1.164004         -7.242169
# 6       BiLSTM_pred    112.673982      0.694637         -6.354654
# 7   BiLSTM_GRU_pred     84.568301      0.400978         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     42.696463      0.038871         -9.302629
# 10         BNN_pred     39.160591     -0.000347        -10.130962
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     76.769254      0.381037         -8.485144
# 1             HV_dw     80.055020      0.406516         -8.485144
# 2             HV_cw     35.341911     -0.039926        -10.580888
# 3         LSTM_pred     97.459388      0.509485         -9.302629
# 4          GRU_pred     94.406715      0.476962         -9.035617
# 5     LSTM_GRU_pred     93.005429      0.561779         -8.485144
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred     84.987072      0.393913         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     -6.720364     -0.777943         -9.302629
# 10         BNN_pred     95.709527      0.587046         -8.485144
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     79.039580      0.395646         -8.485144
# 1             HV_dw     90.434210      0.538128         -8.485144
# 2             HV_cw     77.603988      0.321095         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     95.709527      0.587046         -8.485144
# 5     LSTM_GRU_pred     94.406715      0.574879         -8.485144
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred     97.459388      0.509485         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     84.224055      0.387153         -9.302629
# 10         BNN_pred     95.709527      0.493258         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     82.140958      0.424998         -8.485144
# 1             HV_dw    113.008916      0.642901         -9.302629
# 2             HV_cw     77.389555      0.317300         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred     97.459388      0.509485         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     87.184197      0.414679         -9.302629
# 10         BNN_pred     95.709527      0.493258         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    107.734604      0.565908         -9.477214
# 1             HV_dw    146.789433      1.012002         -6.344729
# 2             HV_cw     80.967477      0.360738        -10.132498
# 3         LSTM_pred     95.486428      0.470758         -7.143639
# 4          GRU_pred     71.228613      0.333833        -10.125437
# 5     LSTM_GRU_pred    115.078964      0.732099        -10.082505
# 6       BiLSTM_pred     96.554971      0.565009         -6.652189
# 7   BiLSTM_GRU_pred     49.047477     -0.006400         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    105.139922      0.535896         -9.302629
# 10         BNN_pred     15.255821     -0.380303         -9.357572
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     56.934908      0.075467         -9.477214
# 1             HV_dw     76.670981      0.316320         -7.730025
# 2             HV_cw     20.249606     -0.299403        -10.132498
# 3         LSTM_pred     99.807497      0.660002         -9.385831
# 4          GRU_pred      2.810499     -0.439308         -9.832867
# 5     LSTM_GRU_pred    -49.594325     -1.098576        -14.092879
# 6       BiLSTM_pred    -20.801350     -0.849778        -11.520788
# 7   BiLSTM_GRU_pred    103.626137      0.568363         -8.550024
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    110.767490      0.601371         -9.302629
# 10         BNN_pred     39.694042     -0.002852         -8.295194
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     76.881557      0.489859         -4.236136
# 1             HV_dw     44.813987      0.053227         -2.467113
# 2             HV_cw    -45.786814     -1.431019         -8.488748
# 3         LSTM_pred     58.064384      0.315933         -4.033411
# 4          GRU_pred     21.953347     -0.302740         -4.916189
# 5     LSTM_GRU_pred     10.000213     -0.538670         -5.257550
# 6       BiLSTM_pred     -0.420882     -0.733031         -7.441701
# 7   BiLSTM_GRU_pred     -4.001652     -0.673060         -8.550024
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    -25.905422     -1.013446         -9.302629
# 10         BNN_pred     28.785929     -0.256240         -3.685457
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     53.043938      0.160211         -6.915042
# 1             HV_dw     45.564615     -0.094883         -4.737859
# 2             HV_cw    -47.242769     -1.280281         -9.142139
# 3         LSTM_pred     41.428732      0.008129         -7.228822
# 4          GRU_pred     44.780979      0.054366         -6.099182
# 5     LSTM_GRU_pred     24.291911     -0.233828         -6.582078
# 6       BiLSTM_pred     -8.055465     -0.798637         -8.264821
# 7   BiLSTM_GRU_pred     21.980981     -0.251809         -8.550024
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     -9.961542     -0.586524         -9.302629
# 10         BNN_pred     -1.552489     -0.629869         -6.399884
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     93.173471      0.618599         -5.913650
# 1             HV_dw     67.027814      0.207921         -7.620182
# 2             HV_cw      4.021224     -0.534409         -9.076415
# 3         LSTM_pred     56.972117      0.211629         -7.228822
# 4          GRU_pred     72.459049      0.386143         -7.907876
# 5     LSTM_GRU_pred     32.291205     -0.105759         -8.684354
# 6       BiLSTM_pred     -3.371869     -0.691360         -8.223304
# 7   BiLSTM_GRU_pred     74.214368      0.278804         -8.550024
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     29.318549     -0.113833         -9.302629
# 10         BNN_pred     16.637318     -0.334454         -7.235995
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     95.709551      0.667540         -5.339951
# 1             HV_dw     69.653000      0.444952         -3.014907
# 2             HV_cw     23.664513     -0.216497         -8.488748
# 3         LSTM_pred     75.626307      0.496080         -4.728613
# 4          GRU_pred     82.439955      0.547779         -5.450334
# 5     LSTM_GRU_pred    100.505497      0.748633         -5.257550
# 6       BiLSTM_pred    103.569061      0.685004         -4.736304
# 7   BiLSTM_GRU_pred     -4.566563     -0.769259         -8.021596
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    -25.905422     -1.013446         -9.302629
# 10         BNN_pred      2.876807     -0.550196         -5.835999
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     82.109622      0.495907         -6.695987
# 1             HV_dw     86.852247      0.452228         -3.730980
# 2             HV_cw     20.806550     -0.215622         -8.488748
# 3         LSTM_pred     40.013801      0.003449         -7.143639
# 4          GRU_pred    136.318931      1.084703         -6.582078
# 5     LSTM_GRU_pred    120.691141      1.033613         -6.582078
# 6       BiLSTM_pred    103.123392      0.659453         -5.191958
# 7   BiLSTM_GRU_pred     -4.621303     -0.658341         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     -8.981584     -0.571894         -9.302629
# 10         BNN_pred    -12.260317     -0.625940         -7.739090
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    121.351689      0.892137         -5.325611
# 1             HV_dw    121.944378      0.801935         -6.344729
# 2             HV_cw     41.010665     -0.051434         -9.035617
# 3         LSTM_pred     59.852083      0.221195         -7.143639
# 4          GRU_pred    137.931829      1.033923         -8.684354
# 5     LSTM_GRU_pred    137.434968      1.040100         -8.684354
# 6       BiLSTM_pred    115.063301      0.774399         -5.081528
# 7   BiLSTM_GRU_pred     27.079155     -0.252517         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     43.449972      0.045509         -9.302629
# 10         BNN_pred      7.579130     -0.367658         -8.563239
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     77.382144      0.387117         -8.485144
# 1             HV_dw     80.055020      0.406516         -8.485144
# 2             HV_cw     35.341911     -0.039926        -10.580888
# 3         LSTM_pred     97.459388      0.509485         -9.302629
# 4          GRU_pred     94.406715      0.476962         -9.035617
# 5     LSTM_GRU_pred     93.005429      0.463759         -9.035617
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred     69.420670      0.247622         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    -20.911445     -1.014047         -9.302629
# 10         BNN_pred     83.198110      0.471061         -8.485144
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     65.503730      0.265798         -8.485144
# 1             HV_dw     77.806704      0.384680         -8.485144
# 2             HV_cw     77.786008      0.388234         -8.488748
# 3         LSTM_pred     97.459388      0.509485         -9.302629
# 4          GRU_pred     95.709527      0.587046         -8.485144
# 5     LSTM_GRU_pred     94.406715      0.574879         -8.485144
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred     97.459388      0.509485         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     -3.900843     -0.572362         -9.302629
# 10         BNN_pred     95.709527      0.587046         -8.485144
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     82.140958      0.424998         -8.485144
# 1             HV_dw    113.008916      0.642901         -9.302629
# 2             HV_cw     64.599974      0.193326         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred     95.709527      0.493258         -9.302629
# 6       BiLSTM_pred    113.008916      0.642901         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     84.259772      0.387460         -9.302629
# 10         BNN_pred     95.709527      0.493258         -9.302629
# 11               __    118.393445      0.690588         -9.302629

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    137.646971      0.875575         -8.115590
# 1             HV_dw    177.728358      1.265825         -8.588117
# 2             HV_cw     96.316452      0.510043         -9.564104
# 3         LSTM_pred    111.371733      0.628605         -9.302629
# 4          GRU_pred    116.779149      0.676173         -9.302629
# 5     LSTM_GRU_pred    109.688930      0.613476         -9.345933
# 6       BiLSTM_pred    111.371733      0.628605         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     89.856353      0.436140         -9.302629
# 10         BNN_pred    106.164387      0.559959         -9.989142
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    145.331335      1.089754         -4.297561
# 1             HV_dw    182.253772      1.421030         -7.318989
# 2             HV_cw    105.343469      0.604784         -7.080380
# 3         LSTM_pred     72.806055      0.281625         -9.843330
# 4          GRU_pred     78.727364      0.400322         -9.376334
# 5     LSTM_GRU_pred    131.401628      0.934909         -6.576545
# 6       BiLSTM_pred     96.836428      0.547927         -6.354654
# 7   BiLSTM_GRU_pred    104.642150      0.624121         -5.870582
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     32.977849     -0.180538        -10.356511
# 10         BNN_pred    122.441868      0.772527         -6.544894
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    110.447441      1.019685         -4.049900
# 1             HV_dw    226.755922      1.899837         -5.583437
# 2             HV_cw     95.133369      0.755999         -4.779978
# 3         LSTM_pred     16.774329     -0.195093         -8.485144
# 4          GRU_pred     81.699844      0.444945         -9.224618
# 5     LSTM_GRU_pred    165.122946      1.325411         -5.098396
# 6       BiLSTM_pred    100.803504      0.734041         -4.849539
# 7   BiLSTM_GRU_pred     73.843157      0.445024         -5.293872
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     19.008165     -0.397065         -8.890511
# 10         BNN_pred     50.520307      0.068886         -7.380390
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    122.659255      0.934505         -3.886098
# 1             HV_dw    184.867123      1.450724         -7.318989
# 2             HV_cw     87.070333      0.471351         -6.922808
# 3         LSTM_pred     66.779658      0.223336         -9.843330
# 4          GRU_pred     80.129037      0.417490         -9.674880
# 5     LSTM_GRU_pred    112.691044      0.756361         -6.884315
# 6       BiLSTM_pred    103.993527      0.622962         -6.354654
# 7   BiLSTM_GRU_pred    115.717259      0.787001         -5.166056
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred      5.497665     -0.517470        -10.015110
# 10         BNN_pred    114.353229      0.692822         -6.544894
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    117.432511      0.761278         -6.749600
# 1             HV_dw    182.253772      1.421030         -7.318989
# 2             HV_cw    101.304390      0.595336         -6.922808
# 3         LSTM_pred     72.806055      0.281625         -9.843330
# 4          GRU_pred     78.727364      0.400322         -9.376334
# 5     LSTM_GRU_pred    103.762215      0.662274         -6.884315
# 6       BiLSTM_pred     96.836428      0.547927         -6.354654
# 7   BiLSTM_GRU_pred    104.642150      0.624121         -5.870582
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     25.094735     -0.268967        -10.546959
# 10         BNN_pred    129.564905      0.835495         -6.544894
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    169.403304      1.615948         -2.455820
# 1             HV_dw    190.329834      1.389163         -8.588117
# 2             HV_cw     92.424976      0.657874         -6.106159
# 3         LSTM_pred     90.101576      0.529752         -8.485144
# 4          GRU_pred    130.166516      0.810338         -9.302629
# 5     LSTM_GRU_pred    152.709858      1.033096         -8.065511
# 6       BiLSTM_pred     99.808030      0.617467         -8.485144
# 7   BiLSTM_GRU_pred    113.008916      0.735696         -8.485144
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     64.469078      0.220121         -8.962760
# 10         BNN_pred     35.978043     -0.076657         -9.979668
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    193.355176      1.659697         -3.153872
# 1             HV_dw    184.974647      1.334023         -8.588117
# 2             HV_cw     90.823493      0.492114         -6.922808
# 3         LSTM_pred    105.128695      0.572883         -9.302629
# 4          GRU_pred    127.441340      0.774721         -9.302629
# 5     LSTM_GRU_pred    106.651007      0.590433         -9.345933
# 6       BiLSTM_pred    111.371733      0.628605         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     54.698858      0.079155        -10.365655
# 10         BNN_pred     88.386815      0.399708         -9.989142
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    139.991371      0.896819         -8.115590
# 1             HV_dw    177.728358      1.265825         -8.588117
# 2             HV_cw     97.035761      0.518929         -8.913724
# 3         LSTM_pred    111.371733      0.628605         -9.302629
# 4          GRU_pred    116.779149      0.676173         -9.302629
# 5     LSTM_GRU_pred    109.688930      0.613476         -9.345933
# 6       BiLSTM_pred    111.371733      0.628605         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     88.145319      0.420274         -9.302629
# 10         BNN_pred    106.164387      0.559959         -9.989142
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     93.005429      0.561779         -8.485144
# 1             HV_dw    113.008916      0.642901         -9.302629
# 2             HV_cw     93.005429      0.561779         -8.485144
# 3         LSTM_pred    113.008916      0.735696         -8.485144
# 4          GRU_pred    113.008916      0.642901         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred    113.008916      0.735696         -8.485144
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    108.725467      0.626867         -8.890511
# 10         BNN_pred     78.770822      0.336641         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     94.406715      0.481149         -9.302629
# 1             HV_dw    118.393445      0.690588         -9.302629
# 2             HV_cw     94.406715      0.481149         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    100.831256      0.518946         -9.177845
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    118.393445      0.690588         -9.302629
# 1             HV_dw    118.393445      0.690588         -9.302629
# 2             HV_cw    118.393445      0.690588         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    118.393445      0.690588         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.690588         -9.302629
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    124.622667      0.747319         -8.765729
# 1             HV_dw    127.823616      0.798398         -8.588117
# 2             HV_cw    124.782661      0.779183         -8.436466
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    109.688930      0.613476         -9.345933
# 5     LSTM_GRU_pred    110.434092      0.620228         -9.345933
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    109.754647      0.622062         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     94.860453      0.483937         -9.302629
# 10         BNN_pred    117.529078      0.663547         -9.989142
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    184.891600      1.481521         -3.820064
# 1             HV_dw    147.479075      1.060962         -8.588117
# 2             HV_cw    114.384642      0.635448         -8.525080
# 3         LSTM_pred    105.718289      0.591974         -9.133077
# 4          GRU_pred     45.075425      0.062583         -9.376334
# 5     LSTM_GRU_pred    184.255072      1.561765         -5.379925
# 6       BiLSTM_pred     96.364642      0.551183         -6.354654
# 7   BiLSTM_GRU_pred     99.126111      0.570975         -7.954278
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     56.026610      0.065236         -9.989142
# 10         BNN_pred    138.339324      0.909305         -8.303591
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    100.062341      0.842195         -2.960203
# 1             HV_dw    156.703948      1.162895         -8.588117
# 2             HV_cw     92.203664      0.512411         -5.565629
# 3         LSTM_pred    103.874439      0.712170         -6.794612
# 4          GRU_pred    100.488734      0.658491         -7.942483
# 5     LSTM_GRU_pred    198.255885      1.787356         -4.047218
# 6       BiLSTM_pred    114.592460      0.760072         -4.849539
# 7   BiLSTM_GRU_pred     80.480577      0.501883         -5.835194
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     32.937296     -0.265569         -7.750812
# 10         BNN_pred     63.626768      0.214938         -8.013491
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    156.305194      1.322151         -2.354686
# 1             HV_dw    147.054465      1.056991         -8.588117
# 2             HV_cw    104.448110      0.619364         -5.357986
# 3         LSTM_pred    113.781016      0.668818         -9.133077
# 4          GRU_pred     27.792463     -0.115870         -9.674880
# 5     LSTM_GRU_pred    178.242399      1.539349         -4.121465
# 6       BiLSTM_pred    103.046067      0.621813         -6.354654
# 7   BiLSTM_GRU_pred     76.394069      0.342822         -7.954278
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     54.065343      0.040978         -8.890511
# 10         BNN_pred    130.643469      0.844194         -8.303591
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    111.630132      0.681428         -9.766839
# 1             HV_dw    143.812344      1.026113         -8.588117
# 2             HV_cw    162.843240      1.175590         -5.630560
# 3         LSTM_pred    105.718289      0.591974         -9.133077
# 4          GRU_pred     36.941547     -0.020581         -9.674880
# 5     LSTM_GRU_pred    183.339797      1.552647         -5.379925
# 6       BiLSTM_pred     96.364642      0.551183         -6.354654
# 7   BiLSTM_GRU_pred     88.058836      0.461388         -7.954278
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    145.227599      1.009367         -8.485144
# 10         BNN_pred    144.769376      0.972661         -8.303591
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    152.740335      1.266759         -5.325611
# 1             HV_dw    141.705297      0.932367         -8.588117
# 2             HV_cw    101.467287      0.660785         -5.549007
# 3         LSTM_pred     89.137671      0.525947         -8.485144
# 4          GRU_pred    152.709858      1.033096         -8.065511
# 5     LSTM_GRU_pred    154.993574      1.054185         -8.065511
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred     72.001775      0.370792         -8.485144
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     40.372626     -0.086802         -7.983828
# 10         BNN_pred     56.952575      0.134847        -10.084399
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    162.748198      1.280354         -5.325611
# 1             HV_dw    130.601897      0.824292         -8.588117
# 2             HV_cw    108.050579      0.791206         -6.106159
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    106.651007      0.590433         -9.345933
# 5     LSTM_GRU_pred    139.617470      0.906434         -8.065511
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    100.130896      0.541062         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     82.152983      0.405660         -8.890511
# 10         BNN_pred    117.529078      0.663547         -9.989142
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    112.286884      0.640166         -9.766462
# 1             HV_dw    127.406279      0.794560         -8.588117
# 2             HV_cw    110.992843      0.668317         -7.156602
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    120.283428      0.711874         -9.345933
# 5     LSTM_GRU_pred    121.035705      0.718669         -9.345933
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    115.277681      0.674870         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    107.085764      0.692356         -8.485144
# 10         BNN_pred    117.529078      0.663547         -9.989142
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     84.987072      0.451460         -8.488748
# 1             HV_dw    113.008916      0.642901         -9.302629
# 2             HV_cw     79.763379      0.355471         -8.890511
# 3         LSTM_pred     89.137671      0.525947         -8.485144
# 4          GRU_pred    113.008916      0.642901         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred    113.008916      0.735696         -8.485144
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     79.945192      0.346086         -9.035617
# 10         BNN_pred     77.515760      0.324686         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     94.406715      0.481149         -9.302629
# 1             HV_dw    118.393445      0.690588         -9.302629
# 2             HV_cw     93.005429      0.561779         -8.485144
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    113.008916      0.642901         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    100.557435      0.549123         -8.890511
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    118.393445      0.690588         -9.302629
# 1             HV_dw    118.393445      0.690588         -9.302629
# 2             HV_cw     95.709527      0.493258         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    118.393445      0.690588         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.783519         -8.485144
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    157.861321      1.055028         -6.066139
# 1             HV_dw    155.294400      1.101894         -8.588117
# 2             HV_cw    130.469056      0.792436         -8.275088
# 3         LSTM_pred     62.815696      0.195442         -9.133077
# 4          GRU_pred    121.094274      0.927164         -5.334726
# 5     LSTM_GRU_pred    155.166655      1.170637         -6.621151
# 6       BiLSTM_pred    109.780104      0.682579         -6.354654
# 7   BiLSTM_GRU_pred     65.960665      0.214971         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    103.800192      0.654606         -7.324989
# 10         BNN_pred     89.568653      0.507094         -9.985597
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    100.860385      0.508864         -9.477214
# 1             HV_dw    170.794119      1.252115         -7.363240
# 2             HV_cw    121.529515      0.733982         -7.661134
# 3         LSTM_pred     94.603111      0.561443         -7.160860
# 4          GRU_pred    117.934209      0.848659         -7.933985
# 5     LSTM_GRU_pred    107.799629      0.785778         -4.393555
# 6       BiLSTM_pred     54.657418      0.116194         -8.651395
# 7   BiLSTM_GRU_pred     96.232585      0.573028         -6.604071
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    133.050196      0.865869         -7.661134
# 10         BNN_pred    103.209395      0.612297         -5.893851
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     86.574931      0.595487         -4.562087
# 1             HV_dw    118.504234      0.923480         -3.730980
# 2             HV_cw     48.181984      0.125531         -4.954668
# 3         LSTM_pred    113.488261      1.196294         -3.627587
# 4          GRU_pred    170.750239      1.674483         -4.293149
# 5     LSTM_GRU_pred    107.031945      0.938700         -4.349827
# 6       BiLSTM_pred     61.584988      0.190693         -5.156033
# 7   BiLSTM_GRU_pred     49.580517      0.120242         -4.425718
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    161.025124      1.727409         -1.806151
# 10         BNN_pred     39.158920     -0.023803         -5.944967
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    114.836838      0.847929         -5.144170
# 1             HV_dw    163.621796      1.216927         -7.318989
# 2             HV_cw    109.313100      0.961519         -6.348901
# 3         LSTM_pred     90.586155      0.542440         -5.156033
# 4          GRU_pred    118.725087      0.973907         -6.094221
# 5     LSTM_GRU_pred    155.256189      1.441693         -4.349827
# 6       BiLSTM_pred     83.263687      0.455132         -5.643780
# 7   BiLSTM_GRU_pred     65.135604      0.235142         -4.587221
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    180.858414      1.861770         -1.793210
# 10         BNN_pred     57.161923      0.214171         -5.620099
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    123.994890      0.926309         -5.114515
# 1             HV_dw    170.360881      1.247832         -7.363240
# 2             HV_cw    152.094542      1.225760         -4.729253
# 3         LSTM_pred     81.868129      0.400774         -7.160860
# 4          GRU_pred    144.341218      1.147477         -8.008802
# 5     LSTM_GRU_pred    134.414453      1.110306         -6.020586
# 6       BiLSTM_pred     59.211864      0.149024         -8.651395
# 7   BiLSTM_GRU_pred     65.023070      0.237028         -6.604071
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    161.673669      1.470724         -4.126409
# 10         BNN_pred    123.540560      0.839422         -5.596127
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    146.522213      1.149923         -5.339951
# 1             HV_dw     70.677346      0.339263         -8.092734
# 2             HV_cw     99.954778      0.730314         -5.765053
# 3         LSTM_pred     13.901404     -0.324313         -6.798282
# 4          GRU_pred    166.917560      1.523723         -4.047218
# 5     LSTM_GRU_pred    146.173367      1.236616         -4.376446
# 6       BiLSTM_pred    127.705476      0.910214         -4.641796
# 7   BiLSTM_GRU_pred     30.915731     -0.086640         -9.617039
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    101.811288      0.795440         -5.464427
# 10         BNN_pred    -18.092758     -0.689661        -12.044164
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    148.939611      1.141803         -5.549007
# 1             HV_dw    166.208600      1.208615         -8.588117
# 2             HV_cw    123.260542      0.956381         -6.943868
# 3         LSTM_pred     37.157873     -0.091021         -8.314064
# 4          GRU_pred    115.062723      0.878264         -5.723263
# 5     LSTM_GRU_pred    193.147289      1.606091         -4.830185
# 6       BiLSTM_pred    144.335063      1.063345         -4.849539
# 7   BiLSTM_GRU_pred     49.629704      0.149509         -8.485144
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    125.960309      1.062699         -5.464427
# 10         BNN_pred      4.750067     -0.397270        -11.123498
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    152.241896      1.172739         -5.325611
# 1             HV_dw    154.866898      1.098042         -8.588117
# 2             HV_cw    135.974781      0.992976         -6.336290
# 3         LSTM_pred     50.315159      0.051016         -9.133077
# 4          GRU_pred    120.457188      0.937874         -5.723263
# 5     LSTM_GRU_pred    186.625999      1.500090         -6.621151
# 6       BiLSTM_pred    112.673982      0.694637         -6.354654
# 7   BiLSTM_GRU_pred     76.570589      0.319768         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    190.575996      1.634229         -5.391506
# 10         BNN_pred     79.528434      0.411515         -9.700818
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     76.769254      0.381037         -8.485144
# 1             HV_dw     81.949925      0.459228         -8.485144
# 2             HV_cw     36.281298     -0.029654        -10.496231
# 3         LSTM_pred     64.589413      0.259846         -8.544566
# 4          GRU_pred    113.008916      0.642901         -9.302629
# 5     LSTM_GRU_pred    100.119990      0.529315         -9.302629
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred    113.008916      0.702707         -8.488748
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    101.811288      0.795440         -5.464427
# 10         BNN_pred     75.841908      0.310170         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     79.039580      0.395646         -8.485144
# 1             HV_dw    113.008916      0.642901         -9.302629
# 2             HV_cw     64.599974      0.193326         -9.035617
# 3         LSTM_pred    113.008916      0.735696         -8.485144
# 4          GRU_pred    113.008916      0.642901         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred    118.393445      0.783519         -8.485144
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    125.960309      1.062699         -5.464427
# 10         BNN_pred     77.515760      0.324686         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     82.140958      0.424998         -8.485144
# 1             HV_dw    118.393445      0.690588         -9.302629
# 2             HV_cw    113.008916      0.640638         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    118.393445      0.690588         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.751011         -8.488748
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    107.734604      0.565908         -9.477214
# 1             HV_dw    105.773244      0.674078         -8.588117
# 2             HV_cw    142.906474      0.976445         -6.334194
# 3         LSTM_pred     50.472100      0.069736         -9.265691
# 4          GRU_pred    121.094274      0.927164         -5.334726
# 5     LSTM_GRU_pred    134.553409      1.041321         -5.379925
# 6       BiLSTM_pred     96.554971      0.565009         -6.652189
# 7   BiLSTM_GRU_pred     91.824322      0.506194         -7.334092
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    107.151898      0.739561         -7.043580
# 10         BNN_pred     56.917476      0.188270        -10.511597
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     56.934908      0.075467         -9.477214
# 1             HV_dw    106.412605      0.615630         -7.318989
# 2             HV_cw     92.419163      0.476693         -7.661134
# 3         LSTM_pred     69.746241      0.289666         -7.160860
# 4          GRU_pred    159.489744      1.344359         -5.605457
# 5     LSTM_GRU_pred     76.144964      0.285076         -7.013862
# 6       BiLSTM_pred    -20.801350     -0.849778        -11.520788
# 7   BiLSTM_GRU_pred    103.586655      0.591872         -6.604071
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     98.972926      0.547244         -7.661134
# 10         BNN_pred     83.045617      0.381899         -6.767934
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     76.881557      0.489859         -4.236136
# 1             HV_dw    103.597258      0.748785         -3.730980
# 2             HV_cw     61.640359      0.564288         -1.891524
# 3         LSTM_pred     49.853034      0.150985         -3.641992
# 4          GRU_pred    168.847673      1.736941         -4.047218
# 5     LSTM_GRU_pred    107.605495      0.919483         -2.558674
# 6       BiLSTM_pred     -0.420882     -0.733031         -7.441701
# 7   BiLSTM_GRU_pred     54.009693      0.033391         -4.247025
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    100.759108      1.063291         -1.882207
# 10         BNN_pred      0.910468     -0.620458         -6.199114
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     53.043938      0.160211         -6.915042
# 1             HV_dw     90.523145      0.494415         -6.344729
# 2             HV_cw     85.816918      0.787038         -4.356883
# 3         LSTM_pred     74.848682      0.368295         -3.678578
# 4          GRU_pred    171.864299      1.774904         -4.047218
# 5     LSTM_GRU_pred    167.564302      1.540202         -2.558674
# 6       BiLSTM_pred     -8.055465     -0.798637         -8.264821
# 7   BiLSTM_GRU_pred     65.506589      0.191084         -3.262547
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    138.693029      1.594093         -1.882207
# 10         BNN_pred     29.739215     -0.148871         -7.559912
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     93.173471      0.618599         -5.913650
# 1             HV_dw     85.317723      0.397372         -7.363240
# 2             HV_cw    104.704770      0.938249         -4.503990
# 3         LSTM_pred     53.057341      0.078799         -6.324071
# 4          GRU_pred    132.464149      1.052251         -7.457099
# 5     LSTM_GRU_pred    176.242029      1.604537         -2.756959
# 6       BiLSTM_pred     -3.371869     -0.691360         -8.223304
# 7   BiLSTM_GRU_pred     83.249972      0.409554         -3.662597
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    112.489474      1.036518         -5.026374
# 10         BNN_pred    105.050333      0.658574         -6.432988
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     95.709551      0.667540         -5.339951
# 1             HV_dw     46.750494      0.079630         -6.794612
# 2             HV_cw     64.429624      0.324061         -5.892280
# 3         LSTM_pred     15.093846     -0.340925         -6.087572
# 4          GRU_pred    166.917560      1.523723         -4.047218
# 5     LSTM_GRU_pred    117.894345      1.079445         -4.047218
# 6       BiLSTM_pred    103.569061      0.685004         -4.736304
# 7   BiLSTM_GRU_pred     83.109618      0.525695         -4.701004
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     92.327914      0.677950         -5.464427
# 10         BNN_pred    -12.803028     -0.677336        -10.647988
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     82.109622      0.495907         -6.695987
# 1             HV_dw     92.328574      0.560297         -7.930717
# 2             HV_cw    123.422036      1.038617         -5.943960
# 3         LSTM_pred     57.949135      0.131535         -6.794612
# 4          GRU_pred    169.929205      1.557486         -4.047218
# 5     LSTM_GRU_pred    207.320975      1.941825         -4.047218
# 6       BiLSTM_pred    103.123392      0.659453         -5.191958
# 7   BiLSTM_GRU_pred     97.224192      0.600283         -5.364531
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    125.960309      1.062699         -5.464427
# 10         BNN_pred     -3.237637     -0.517435        -11.297206
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    121.351689      0.892137         -5.325611
# 1             HV_dw    108.987532      0.707710         -8.588117
# 2             HV_cw    142.687567      1.205541         -6.605276
# 3         LSTM_pred     39.433735     -0.066493         -8.314064
# 4          GRU_pred    120.457188      0.937874         -5.723263
# 5     LSTM_GRU_pred    209.898598      1.937955         -4.121465
# 6       BiLSTM_pred    115.063301      0.774399         -5.081528
# 7   BiLSTM_GRU_pred    104.460797      0.663555         -5.306636
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    140.733367      1.221458         -5.464427
# 10         BNN_pred     56.042437      0.181654         -9.747798
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     77.382144      0.387117         -8.485144
# 1             HV_dw     81.949925      0.459228         -8.485144
# 2             HV_cw     21.386475     -0.190096        -10.496231
# 3         LSTM_pred     64.589413      0.259846         -8.544566
# 4          GRU_pred    113.008916      0.642901         -9.302629
# 5     LSTM_GRU_pred    100.119990      0.529315         -9.302629
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred    113.008916      0.702707         -8.488748
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     92.327914      0.677950         -5.464427
# 10         BNN_pred     65.148043      0.207272         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     65.503730      0.265798         -8.485144
# 1             HV_dw    113.008916      0.642901         -9.302629
# 2             HV_cw     77.603988      0.321095         -9.035617
# 3         LSTM_pred    113.008916      0.735696         -8.485144
# 4          GRU_pred    113.008916      0.642901         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred    113.008916      0.735696         -8.485144
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    125.960309      1.062699         -5.464427
# 10         BNN_pred     76.756456      0.317618         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     82.140958      0.424998         -8.485144
# 1             HV_dw    118.393445      0.690588         -9.302629
# 2             HV_cw     76.136101      0.305191         -9.035617
# 3         LSTM_pred    113.008916      0.735696         -8.485144
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    113.008916      0.642901         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.783519         -8.485144
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.751011         -8.488748
# 10         BNN_pred    102.414851      0.550459         -9.302629
# 11               __    118.393445      0.690588         -9.302629

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_2y)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_2y)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_2y', file, 'HV')
get_final_results_1('2022_2y', file, 'HV')

get_final_results('2022_2y', dw_file, 'HV_dw')
get_final_results_1('2022_2y', dw_file, 'HV_dw')

get_final_results('2022_2y', cw_file, 'HV_cw')
get_final_results_1('2022_2y', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:21: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-4-b267510ae310>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-4-b267510ae310>:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# ...
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     84.749429     -0.071298        -13.199840
# 1             HV_dw    126.700505      0.364728         -8.607574
# 2             HV_cw    134.543047      0.020574        -12.742088
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred    179.671475      0.260006        -12.612387
# 5     LSTM_GRU_pred     83.426552      0.205238        -12.604715
# 6       BiLSTM_pred     78.242403      0.186086        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred    102.215146      0.027530        -14.411155
# 9          ESN_pred     89.486216     -0.025239        -14.049257
# 10         BNN_pred     90.167935      0.229530        -12.239817
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    150.400139      0.164907        -12.427842
# 1             HV_dw     96.961571      0.088349         -8.806239
# 2             HV_cw    146.313411      0.144558         -7.873878
# 3         LSTM_pred     84.286681      0.208904        -13.134498
# 4          GRU_pred     17.828480     -0.232456        -13.491812
# 5     LSTM_GRU_pred     12.246382     -0.377175        -15.825540
# 6       BiLSTM_pred     96.685649      0.029834        -12.243990
# 7   BiLSTM_GRU_pred     15.321402     -0.197753        -16.436380
# 8         QRNN_pred     47.904594     -0.202073        -14.061548
# 9          ESN_pred     38.584102     -0.297234        -12.599338
# 10         BNN_pred     87.633427      0.054031        -12.664388
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     48.570967     -0.219394        -13.033687
# 1             HV_dw    136.794380      0.241039        -11.109976
# 2             HV_cw     54.050095     -0.197061         -8.397036
# 3         LSTM_pred     49.953161      0.081008        -14.795063
# 4          GRU_pred    -32.885231     -0.494613        -13.333546
# 5     LSTM_GRU_pred   -169.272827     -1.491855        -21.750975
# 6       BiLSTM_pred     75.633485     -0.126107        -12.463967
# 7   BiLSTM_GRU_pred     21.094366     -0.223532        -14.525164
# 8         QRNN_pred     -3.860234     -0.492369        -15.183338
# 9          ESN_pred    -58.550434     -0.936498        -15.620623
# 10         BNN_pred     62.023248     -0.054269        -11.777616
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    118.265451      0.082756        -12.278466
# 1             HV_dw    114.121215      0.152451         -8.458410
# 2             HV_cw     45.293833     -0.215911         -8.850963
# 3         LSTM_pred     84.286681      0.208904        -13.134498
# 4          GRU_pred    -35.375636     -0.472958        -15.125257
# 5     LSTM_GRU_pred    -40.759644     -0.612789        -16.472594
# 6       BiLSTM_pred     55.826217     -0.186630        -13.323831
# 7   BiLSTM_GRU_pred     11.983690     -0.216889        -14.265137
# 8         QRNN_pred    -10.756737     -0.474046        -16.145721
# 9          ESN_pred     -4.522744     -0.473947        -11.273074
# 10         BNN_pred     48.637420     -0.097249        -12.925284
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     76.532932     -0.111856        -13.219381
# 1             HV_dw    104.185937      0.115415         -8.539186
# 2             HV_cw     91.746518     -0.066169         -9.089330
# 3         LSTM_pred     84.286681      0.208904        -13.134498
# 4          GRU_pred     13.807105     -0.250019        -13.491812
# 5     LSTM_GRU_pred     10.461533     -0.385370        -15.825540
# 6       BiLSTM_pred     96.685649      0.029834        -12.243990
# 7   BiLSTM_GRU_pred     15.321402     -0.197753        -16.436380
# 8         QRNN_pred     78.578348     -0.078312        -13.329305
# 9          ESN_pred      2.937622     -0.484792        -12.917280
# 10         BNN_pred     87.633427      0.054031        -12.664388
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      6.316953     -0.383630        -15.627389
# 1             HV_dw    149.302927      0.447560         -9.649484
# 2             HV_cw    101.730773      0.032973        -12.459734
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred    174.837718      0.250581         -8.136556
# 5     LSTM_GRU_pred     11.680934     -0.161613        -14.605856
# 6       BiLSTM_pred     42.941060      0.023319        -16.041652
# 7   BiLSTM_GRU_pred     55.689417     -0.012623        -15.345767
# 8         QRNN_pred     18.317562     -0.375623        -16.842366
# 9          ESN_pred     33.187930     -0.440481        -14.612487
# 10         BNN_pred     82.433992      0.148343        -12.862411
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     85.416819     -0.042203        -13.199840
# 1             HV_dw    128.304216      0.370512         -8.468303
# 2             HV_cw     75.714047     -0.064831        -12.986952
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred    117.688628      0.044753        -11.406266
# 5     LSTM_GRU_pred     55.959470      0.049933        -12.756910
# 6       BiLSTM_pred     70.593064      0.044998        -14.058488
# 7   BiLSTM_GRU_pred     78.242403      0.095226        -13.199840
# 8         QRNN_pred     30.047675     -0.273492        -15.847796
# 9          ESN_pred     63.587911     -0.182450        -12.350711
# 10         BNN_pred     90.167935      0.229530        -12.239817
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     85.715688     -0.069640        -13.199840
# 1             HV_dw    124.204638      0.355812         -8.607574
# 2             HV_cw     77.783244     -0.185790        -13.996401
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred    163.821708      0.206610        -12.612387
# 5     LSTM_GRU_pred     79.523170      0.191017        -12.604715
# 6       BiLSTM_pred     78.242403      0.186086        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     94.612805     -0.000925        -13.681891
# 9          ESN_pred     50.048604     -0.223351        -15.693221
# 10         BNN_pred     90.167935      0.229530        -12.239817
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     47.278164      0.069993        -13.199840
# 1             HV_dw     70.593064      0.158138        -13.815624
# 2             HV_cw     48.438200      0.074423        -15.599124
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     64.038952      0.042621        -13.199840
# 6       BiLSTM_pred     42.941060      0.023319        -16.041652
# 7   BiLSTM_GRU_pred     55.689417     -0.012623        -15.345767
# 8         QRNN_pred     48.489853      0.074657        -13.199840
# 9          ESN_pred     88.509211      0.224790        -12.373346
# 10         BNN_pred     70.593064      0.104900        -13.815624
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.242403      0.186086        -13.199840
# 1             HV_dw     78.242403      0.186086        -13.199840
# 2             HV_cw     60.431584      0.120645        -14.633638
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.095226        -13.199840
# 5     LSTM_GRU_pred     78.242403      0.132971        -13.199840
# 6       BiLSTM_pred     70.593064      0.044998        -14.058488
# 7   BiLSTM_GRU_pred     78.242403      0.095226        -13.199840
# 8         QRNN_pred     40.996859      0.045520        -13.199840
# 9          ESN_pred     93.139061      0.241672        -12.000636
# 10         BNN_pred     78.242403      0.186086        -13.199840
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.242403      0.186086        -13.199840
# 1             HV_dw     78.242403      0.186086        -13.199840
# 2             HV_cw     78.242403      0.186086        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.132971        -13.199840
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     78.242403      0.186086        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     78.242403      0.186086        -13.199840
# 9          ESN_pred     70.593064      0.158138        -13.815624
# 10         BNN_pred     78.242403      0.186086        -13.199840
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    102.829849     -0.006529        -13.199840
# 1             HV_dw     93.879508      0.244011        -11.301691
# 2             HV_cw     27.105591     -0.006864        -14.399940
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     68.074771      0.149162        -13.550624
# 5     LSTM_GRU_pred    107.406680      0.041067        -13.199840
# 6       BiLSTM_pred     79.998206      0.192485        -13.058495
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     80.050661     -0.054580        -14.281789
# 9          ESN_pred    138.710453      0.122193        -13.145154
# 10         BNN_pred    159.884235      0.161094        -12.239817
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     93.530178     -0.046371        -12.470947
# 1             HV_dw    160.802744      0.347116         -9.093340
# 2             HV_cw    188.639544      0.212370        -10.652932
# 3         LSTM_pred    122.742255      0.182122        -11.917184
# 4          GRU_pred     81.121617      0.024898        -11.950255
# 5     LSTM_GRU_pred     56.554652     -0.124819        -15.998036
# 6       BiLSTM_pred    138.812286      0.182444        -13.707826
# 7   BiLSTM_GRU_pred     71.417903     -0.009104        -13.565654
# 8         QRNN_pred      5.871424     -0.366228        -13.677257
# 9          ESN_pred     67.224591     -0.197419        -13.191376
# 10         BNN_pred    133.925537      0.222789        -12.500574
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     26.422505     -0.316229        -12.895011
# 1             HV_dw    155.857959      0.384434         -9.151887
# 2             HV_cw     99.351390     -0.005327         -7.609485
# 3         LSTM_pred    118.580086      0.167780        -11.935449
# 4          GRU_pred     27.712077     -0.217977        -10.119459
# 5     LSTM_GRU_pred     22.675538     -0.356165        -12.342958
# 6       BiLSTM_pred     62.451665     -0.184411        -14.934442
# 7   BiLSTM_GRU_pred     82.224898      0.028070        -14.987556
# 8         QRNN_pred    -52.156799     -0.752619        -16.889725
# 9          ESN_pred     21.179070     -0.515020        -12.760449
# 10         BNN_pred     88.471960      0.053798        -13.135624
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     17.448258     -0.343327        -13.500071
# 1             HV_dw    170.929947      0.382920         -8.515451
# 2             HV_cw    120.789527     -0.033684         -7.866254
# 3         LSTM_pred    122.742255      0.182122        -11.917184
# 4          GRU_pred     63.344571     -0.049420        -10.000686
# 5     LSTM_GRU_pred     64.266127     -0.104036        -14.062644
# 6       BiLSTM_pred     94.725468     -0.037722        -14.534362
# 7   BiLSTM_GRU_pred     76.099854      0.006508        -13.579374
# 8         QRNN_pred    -21.583642     -0.497690        -15.537599
# 9          ESN_pred     17.803259     -0.350292        -13.417560
# 10         BNN_pred     69.252637     -0.017945        -13.760905
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     54.131427     -0.209859        -13.228433
# 1             HV_dw    158.231334      0.338074         -9.093340
# 2             HV_cw    177.717748      0.176978         -9.054779
# 3         LSTM_pred    122.742255      0.182122        -11.917184
# 4          GRU_pred     58.079475     -0.067701        -11.950255
# 5     LSTM_GRU_pred     54.518609     -0.137683        -13.690714
# 6       BiLSTM_pred    140.666721      0.189035        -13.567308
# 7   BiLSTM_GRU_pred     71.417903     -0.009104        -13.565654
# 8         QRNN_pred    -18.988524     -0.479872        -15.745145
# 9          ESN_pred     11.629937     -0.434053        -13.986207
# 10         BNN_pred    123.398647      0.185236        -12.500574
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     28.752568     -0.283540        -13.788415
# 1             HV_dw     78.607322      0.190822        -11.773061
# 2             HV_cw     78.385224      0.192219         -9.221644
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred    127.679754      0.258405         -7.118181
# 5     LSTM_GRU_pred     70.004562     -0.139252        -14.246510
# 6       BiLSTM_pred     45.933775      0.034785        -15.800734
# 7   BiLSTM_GRU_pred     47.016688     -0.043949        -16.041221
# 8         QRNN_pred    -28.407389     -0.610106        -16.654475
# 9          ESN_pred    136.250273      0.021970         -9.221644
# 10         BNN_pred    127.708847      0.050893        -12.862411
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.705130     -0.399586        -14.179676
# 1             HV_dw     98.949997      0.262444        -11.142683
# 2             HV_cw    103.268961      0.287217         -9.221644
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     98.475153      0.170005         -9.649378
# 5     LSTM_GRU_pred     55.091575     -0.129379        -14.089097
# 6       BiLSTM_pred     79.998206      0.079594        -13.303493
# 7   BiLSTM_GRU_pred     50.392827     -0.031003        -15.680055
# 8         QRNN_pred      2.931816     -0.370350        -16.594141
# 9          ESN_pred    132.507482      0.101210        -11.910423
# 10         BNN_pred    158.707685      0.157090        -12.239817
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    105.182720     -0.000446        -13.199840
# 1             HV_dw     91.456346      0.235207        -11.301691
# 2             HV_cw     49.975778      0.080248        -11.864135
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     55.177605      0.100909        -13.550624
# 5     LSTM_GRU_pred    113.632396      0.092321        -13.199840
# 6       BiLSTM_pred     79.998206      0.192485        -13.058495
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     51.649598     -0.167123        -14.633407
# 9          ESN_pred    153.875043      0.211087        -11.910423
# 10         BNN_pred    159.884235      0.161094        -12.239817
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     49.615622      0.079020        -13.199840
# 1             HV_dw     70.593064      0.158138        -13.815624
# 2             HV_cw     78.242403      0.186086        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     63.422940      0.078302        -13.199840
# 6       BiLSTM_pred     42.941060      0.023319        -16.041652
# 7   BiLSTM_GRU_pred     47.016688     -0.043949        -16.041221
# 8         QRNN_pred     80.801655      0.104454        -12.957475
# 9          ESN_pred     97.635138      0.259320        -10.308980
# 10         BNN_pred     70.593064      0.104900        -13.815624
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.242403      0.186086        -13.199840
# 1             HV_dw     78.242403      0.186086        -13.199840
# 2             HV_cw     78.242403      0.186086        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.095226        -13.199840
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     78.242403      0.073171        -13.444439
# 7   BiLSTM_GRU_pred     50.392827     -0.031003        -15.680055
# 8         QRNN_pred     78.242403      0.186086        -13.199840
# 9          ESN_pred     78.242403      0.186086        -13.199840
# 10         BNN_pred     78.242403      0.186086        -13.199840
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.242403      0.186086         -13.19984
# 1             HV_dw     78.242403      0.186086         -13.19984
# 2             HV_cw     78.242403      0.186086         -13.19984
# 3         LSTM_pred     78.242403      0.186086         -13.19984
# 4          GRU_pred     78.242403      0.186086         -13.19984
# 5     LSTM_GRU_pred     78.242403      0.186086         -13.19984
# 6       BiLSTM_pred     78.242403      0.186086         -13.19984
# 7   BiLSTM_GRU_pred     78.242403      0.186086         -13.19984
# 8         QRNN_pred     78.242403      0.186086         -13.19984
# 9          ESN_pred     78.242403      0.186086         -13.19984
# 10         BNN_pred     78.242403      0.186086         -13.19984
# 11               __     78.242403      0.186086         -13.19984
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    123.827005      0.128566        -13.199840
# 1             HV_dw     95.849439      0.084384        -13.392023
# 2             HV_cw    132.199990      0.288119        -10.649745
# 3         LSTM_pred     73.909071     -0.002851        -11.735770
# 4          GRU_pred    104.927832      0.186648        -10.419385
# 5     LSTM_GRU_pred    163.083596      0.270484        -14.569268
# 6       BiLSTM_pred     48.876186     -0.033315        -15.645395
# 7   BiLSTM_GRU_pred    150.483372      0.210449        -13.199840
# 8         QRNN_pred    157.966386      0.248480        -13.199840
# 9          ESN_pred    155.360885      0.474960         -9.094755
# 10         BNN_pred    133.197019      0.219955        -12.459575
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     90.119018      0.061422        -11.118942
# 1             HV_dw     23.376152     -0.165207        -11.766495
# 2             HV_cw     90.790244      0.062420         -8.367100
# 3         LSTM_pred     90.322465      0.125805        -10.319934
# 4          GRU_pred    -41.433184     -0.550863        -13.029871
# 5     LSTM_GRU_pred     21.487171     -0.358144        -16.332159
# 6       BiLSTM_pred     35.368669     -0.167023        -12.657102
# 7   BiLSTM_GRU_pred     60.968509     -0.064476        -11.477048
# 8         QRNN_pred     84.123957      0.037658        -14.573166
# 9          ESN_pred     26.377378     -0.023551         -9.273793
# 10         BNN_pred     77.102675      0.005828        -10.179206
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    108.557790      0.147060         -4.064074
# 1             HV_dw    148.010568      0.347617         -5.933310
# 2             HV_cw    121.811001      0.230276         -5.430055
# 3         LSTM_pred    -43.157430     -0.730178        -12.711762
# 4          GRU_pred   -103.568660     -1.053543        -17.332442
# 5     LSTM_GRU_pred     86.038557      0.115251         -7.874619
# 6       BiLSTM_pred    -49.028837     -0.636914        -15.031542
# 7   BiLSTM_GRU_pred    -30.114063     -0.850471        -11.472801
# 8         QRNN_pred     62.751212     -0.095871         -5.499781
# 9          ESN_pred     -7.359831     -0.264575         -9.094755
# 10         BNN_pred     30.001612     -0.298618         -7.947501
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     21.744035     -0.248436        -14.289880
# 1             HV_dw    129.277814      0.228153         -8.099900
# 2             HV_cw    124.987862      0.218812         -6.545660
# 3         LSTM_pred     46.408313     -0.147407        -10.853240
# 4          GRU_pred    -51.690272     -0.668451        -12.909058
# 5     LSTM_GRU_pred     60.215782     -0.095060        -13.473849
# 6       BiLSTM_pred    -36.485196     -0.540977        -14.925797
# 7   BiLSTM_GRU_pred    112.212060      0.155911         -8.325590
# 8         QRNN_pred     19.217955     -0.274486        -15.577965
# 9          ESN_pred    -12.864538     -0.233337         -9.094755
# 10         BNN_pred     25.884769     -0.240231         -9.407335
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    127.899804      0.203715        -11.118942
# 1             HV_dw     71.550466     -0.022835         -9.988183
# 2             HV_cw    121.012989      0.192920         -7.194547
# 3         LSTM_pred     97.278517      0.086838         -8.807796
# 4          GRU_pred    -97.253101     -0.829102        -16.355621
# 5     LSTM_GRU_pred     95.369484     -0.054870        -14.834838
# 6       BiLSTM_pred     58.688167     -0.073316        -11.861957
# 7   BiLSTM_GRU_pred    134.896800      0.250728        -11.752283
# 8         QRNN_pred     34.324921     -0.119390        -14.573166
# 9          ESN_pred     31.475049     -0.006276         -9.094755
# 10         BNN_pred    104.996438      0.119345         -9.135110
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    152.269586      0.351816         -5.499781
# 1             HV_dw    101.035920      0.103088        -12.973666
# 2             HV_cw    147.444153      0.327310         -8.629713
# 3         LSTM_pred    -18.236372     -0.437829        -14.024384
# 4          GRU_pred    -60.208937     -0.702019        -14.401172
# 5     LSTM_GRU_pred     82.300524      0.096662        -11.131952
# 6       BiLSTM_pred     14.550167     -0.200065        -14.418417
# 7   BiLSTM_GRU_pred    -86.179486     -1.150978        -19.942880
# 8         QRNN_pred    136.787573      0.278958         -5.499781
# 9          ESN_pred     22.570672     -0.084089         -9.094755
# 10         BNN_pred     62.605355     -0.061480        -16.651295
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     75.460287     -0.131404        -15.655820
# 1             HV_dw    151.192526      0.292199        -11.615154
# 2             HV_cw    113.449952      0.156832        -11.250735
# 3         LSTM_pred     59.149165     -0.062415        -11.735770
# 4          GRU_pred     35.881421     -0.105538        -10.053555
# 5     LSTM_GRU_pred     95.182345      0.059887        -14.537378
# 6       BiLSTM_pred      0.038722     -0.251720        -16.627288
# 7   BiLSTM_GRU_pred    117.563022      0.028516        -13.604961
# 8         QRNN_pred     44.406552     -0.152053        -15.923678
# 9          ESN_pred     67.378250      0.151501         -9.094755
# 10         BNN_pred    131.917322      0.219843        -12.834535
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    109.287355      0.076714        -13.199840
# 1             HV_dw    108.741335      0.132361        -12.687677
# 2             HV_cw    117.341534      0.171028        -10.745048
# 3         LSTM_pred     59.149165     -0.062415        -11.735770
# 4          GRU_pred     57.557350     -0.001291        -12.022976
# 5     LSTM_GRU_pred    143.549884      0.142702        -14.515930
# 6       BiLSTM_pred     30.231333     -0.109554        -14.525593
# 7   BiLSTM_GRU_pred    142.315799      0.183494        -13.444439
# 8         QRNN_pred     71.606307     -0.076888        -14.748047
# 9          ESN_pred    154.596536      0.481562         -9.094755
# 10         BNN_pred    152.104023      0.289739        -12.459575
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    152.269586      0.351816         -5.499781
# 1             HV_dw     49.773785      0.080774        -13.815624
# 2             HV_cw     90.092617      0.053755        -11.142683
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred     57.758917     -0.002952        -15.088745
# 5     LSTM_GRU_pred     56.115461      0.050455        -14.981093
# 6       BiLSTM_pred     42.941060      0.023319        -16.041652
# 7   BiLSTM_GRU_pred    -19.852234     -0.656666        -17.816843
# 8         QRNN_pred    136.787573      0.278958         -5.499781
# 9          ESN_pred     70.234371      0.169464         -9.094755
# 10         BNN_pred     54.917437      0.046469        -13.815624
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     75.460287     -0.131404        -15.655820
# 1             HV_dw     66.677769      0.143738        -13.815624
# 2             HV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     64.328735      0.135109        -14.319912
# 6       BiLSTM_pred     70.593064      0.044998        -14.058488
# 7   BiLSTM_GRU_pred     79.400118      0.077408        -13.444439
# 8         QRNN_pred     44.406552     -0.152053        -15.923678
# 9          ESN_pred     62.454774      0.128154        -13.199840
# 10         BNN_pred     70.593064      0.104900        -13.815624
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.242403      0.095226        -13.199840
# 1             HV_dw     70.593064      0.158138        -13.815624
# 2             HV_cw     78.242403      0.186086        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.132971        -13.199840
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     78.242403      0.073171        -13.444439
# 7   BiLSTM_GRU_pred     79.400118      0.077408        -13.444439
# 8         QRNN_pred     78.242403     -0.067701        -14.706863
# 9          ESN_pred     78.242403      0.186086        -13.199840
# 10         BNN_pred     78.242403      0.186086        -13.199840
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    113.094821      0.031455        -14.250829
# 1             HV_dw     54.108409     -0.084778        -12.024311
# 2             HV_cw    176.587579      0.384044        -10.772590
# 3         LSTM_pred    103.882820      0.114855         -9.846970
# 4          GRU_pred     79.859192      0.017306        -10.077672
# 5     LSTM_GRU_pred     35.505684     -0.213577        -15.633437
# 6       BiLSTM_pred    132.010789      0.217775        -14.134931
# 7   BiLSTM_GRU_pred     87.925642     -0.027415        -17.461553
# 8         QRNN_pred    129.895826      0.087885        -13.586460
# 9          ESN_pred      8.172996     -0.096100         -9.094755
# 10         BNN_pred     85.006461      0.041984        -10.497322
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    112.385306      0.148978        -11.675568
# 1             HV_dw     79.671308      0.079259         -9.410765
# 2             HV_cw    108.785050      0.134346         -9.196733
# 3         LSTM_pred     68.633962      0.031886        -11.242691
# 4          GRU_pred    -41.433184     -0.550863        -13.029871
# 5     LSTM_GRU_pred     30.834334     -0.192860        -15.680331
# 6       BiLSTM_pred     31.424995     -0.132283         -9.178619
# 7   BiLSTM_GRU_pred    153.186221      0.318927         -9.486363
# 8         QRNN_pred    154.907056      0.318726        -10.118970
# 9          ESN_pred      8.286031     -0.108495         -9.094755
# 10         BNN_pred     53.446768     -0.119540        -12.088938
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     72.422496     -0.073672         -5.057242
# 1             HV_dw    152.541098      0.398629         -3.527844
# 2             HV_cw     61.241920     -0.147273         -7.154580
# 3         LSTM_pred    -11.824497     -0.514230        -10.540354
# 4          GRU_pred    -35.921155     -0.809484         -9.039405
# 5     LSTM_GRU_pred     80.153709     -0.001686         -6.685026
# 6       BiLSTM_pred    -66.330748     -0.816484        -13.218556
# 7   BiLSTM_GRU_pred     30.567799     -0.452198         -8.523580
# 8         QRNN_pred     61.429163     -0.121551         -6.572252
# 9          ESN_pred    -10.870832     -0.305457         -9.094755
# 10         BNN_pred     96.168587      0.086334         -4.131636
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     28.358979     -0.264076        -12.304719
# 1             HV_dw    121.376512      0.202482         -7.220395
# 2             HV_cw     80.446786     -0.005675         -5.430055
# 3         LSTM_pred    -26.359883     -0.514758        -11.703593
# 4          GRU_pred    -51.690272     -0.668451        -12.909058
# 5     LSTM_GRU_pred     16.443750     -0.289945        -13.783049
# 6       BiLSTM_pred     -3.500514     -0.408374        -11.338380
# 7   BiLSTM_GRU_pred    104.977303      0.124653         -6.750016
# 8         QRNN_pred     82.978416      0.011600         -7.274035
# 9          ESN_pred     34.641743     -0.004634         -9.094755
# 10         BNN_pred    -83.763206     -1.006942        -14.516775
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     50.221516     -0.127637        -15.184132
# 1             HV_dw    137.475891      0.268071         -7.947280
# 2             HV_cw    150.509440      0.332647         -6.311071
# 3         LSTM_pred     62.057195     -0.002952        -10.251773
# 4          GRU_pred    -78.976839     -0.777924        -14.696381
# 5     LSTM_GRU_pred     30.032146     -0.209151        -15.345983
# 6       BiLSTM_pred     -9.180566     -0.395622        -12.117399
# 7   BiLSTM_GRU_pred    142.087172      0.286382         -8.865567
# 8         QRNN_pred    116.826987      0.176010         -9.973424
# 9          ESN_pred     45.595511      0.054718         -9.094755
# 10         BNN_pred    -27.519048     -0.576105        -14.043736
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    138.833878      0.288737         -5.499781
# 1             HV_dw    170.468968      0.434969         -8.069968
# 2             HV_cw    182.881759      0.506065         -8.288896
# 3         LSTM_pred     67.661057     -0.068809         -8.839783
# 4          GRU_pred     13.572443     -0.365071         -7.698788
# 5     LSTM_GRU_pred     51.125000     -0.049852        -12.538182
# 6       BiLSTM_pred     14.362916     -0.293011        -12.068618
# 7   BiLSTM_GRU_pred     33.552887     -0.591826        -11.808160
# 8         QRNN_pred    120.661395      0.201397         -6.572252
# 9          ESN_pred    -10.870832     -0.305457         -9.094755
# 10         BNN_pred    111.649028      0.166936         -6.164757
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     49.836182     -0.127268        -15.486584
# 1             HV_dw    120.839821      0.186432         -8.604748
# 2             HV_cw    156.038933      0.341990        -10.283221
# 3         LSTM_pred     25.718221     -0.252829         -8.587050
# 4          GRU_pred     -1.891092     -0.365756         -9.725342
# 5     LSTM_GRU_pred     39.362875     -0.179301        -16.164947
# 6       BiLSTM_pred     25.103738     -0.229644        -13.169680
# 7   BiLSTM_GRU_pred      7.679723     -0.483607        -17.714406
# 8         QRNN_pred    152.750876      0.353646         -5.499781
# 9          ESN_pred     38.938526      0.023443         -9.094755
# 10         BNN_pred    -22.491231     -0.449342        -13.235770
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     77.373731     -0.119094        -15.505756
# 1             HV_dw    120.600288      0.182035         -8.667811
# 2             HV_cw    140.569056      0.272414        -10.283221
# 3         LSTM_pred     90.422453      0.058691         -9.846970
# 4          GRU_pred     54.817807     -0.096549         -7.595745
# 5     LSTM_GRU_pred     77.729266     -0.114025        -14.905981
# 6       BiLSTM_pred     17.334314     -0.234151        -13.485062
# 7   BiLSTM_GRU_pred     49.836719     -0.199130        -16.922126
# 8         QRNN_pred     82.517120     -0.106488        -15.203527
# 9          ESN_pred     59.984866      0.119948         -9.094755
# 10         BNN_pred     47.849755     -0.111605        -11.159437
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    138.833878      0.288737         -5.499781
# 1             HV_dw     49.773785      0.080774        -13.815624
# 2             HV_cw     82.359209      0.017975        -11.773061
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred     42.941060      0.023319        -16.041652
# 5     LSTM_GRU_pred     56.115461      0.050455        -14.981093
# 6       BiLSTM_pred     42.941060      0.023319        -16.041652
# 7   BiLSTM_GRU_pred    -34.936292     -0.787010        -17.010440
# 8         QRNN_pred    120.661395      0.201397         -6.572252
# 9          ESN_pred    -10.870832     -0.305457         -9.094755
# 10         BNN_pred     54.917437      0.046469        -13.815624
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     49.836182     -0.127268        -15.486584
# 1             HV_dw     66.677769      0.143738        -13.815624
# 2             HV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     64.328735      0.135109        -14.319912
# 6       BiLSTM_pred     42.941060      0.023319        -16.041652
# 7   BiLSTM_GRU_pred     32.493609     -0.017453        -16.041652
# 8         QRNN_pred    152.750876      0.353646         -5.499781
# 9          ESN_pred     56.039339      0.103550        -11.157984
# 10         BNN_pred     70.593064      0.104900        -13.815624
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     70.593064     -0.146850        -16.037538
# 1             HV_dw     70.593064      0.158138        -13.815624
# 2             HV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.132971        -13.199840
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     78.242403      0.073171        -13.444439
# 7   BiLSTM_GRU_pred     79.400118      0.077408        -13.444439
# 8         QRNN_pred     82.517120     -0.106488        -15.203527
# 9          ESN_pred     63.422940      0.131741        -13.199840
# 10         BNN_pred     70.593064      0.158138        -13.815624
# 11               __     78.242403      0.186086        -13.199840

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     84.749429     -0.071298        -13.199840
# 1             HV_dw    180.890392      0.299373         -8.604860
# 2             HV_cw    196.761746      0.237190        -10.699289
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred    179.671475      0.260006        -12.612387
# 5     LSTM_GRU_pred    101.821454      0.272271        -11.301691
# 6       BiLSTM_pred     71.934327      0.163041        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred    102.215146      0.027530        -14.411155
# 9          ESN_pred    124.283176      0.073317        -14.431377
# 10         BNN_pred     87.168090      0.220052        -12.184526
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    150.400139      0.164907        -12.427842
# 1             HV_dw     83.318969      0.036138        -10.262595
# 2             HV_cw    229.236264      0.435797         -8.615351
# 3         LSTM_pred     84.286681      0.208904        -13.134498
# 4          GRU_pred     17.828480     -0.232456        -13.491812
# 5     LSTM_GRU_pred     80.347477      0.084697        -12.483870
# 6       BiLSTM_pred    141.721059      0.299533        -13.420117
# 7   BiLSTM_GRU_pred     15.321402     -0.197753        -16.436380
# 8         QRNN_pred     47.904594     -0.202073        -14.061548
# 9          ESN_pred    148.647025      0.279043        -12.257540
# 10         BNN_pred    117.375197      0.163815        -13.159201
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     48.570967     -0.219394        -13.033687
# 1             HV_dw    109.086197      0.134542         -7.429530
# 2             HV_cw    203.270858      0.462592         -6.457047
# 3         LSTM_pred     49.953161      0.081008        -14.795063
# 4          GRU_pred    -32.885231     -0.494613        -13.333546
# 5     LSTM_GRU_pred     85.989377      0.039002        -13.029508
# 6       BiLSTM_pred    168.524219      0.457701         -6.813003
# 7   BiLSTM_GRU_pred     21.094366     -0.223532        -14.525164
# 8         QRNN_pred     -3.860234     -0.492369        -15.183338
# 9          ESN_pred    212.446495      0.587308        -10.347557
# 10         BNN_pred    111.385157      0.144311        -11.300596
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    118.265451      0.082756        -12.278466
# 1             HV_dw     56.170858     -0.070793         -9.379245
# 2             HV_cw    129.679024      0.147478         -7.551568
# 3         LSTM_pred     84.286681      0.208904        -13.134498
# 4          GRU_pred    -35.375636     -0.472958        -15.125257
# 5     LSTM_GRU_pred    122.077402      0.249888        -11.332643
# 6       BiLSTM_pred    146.744512      0.321374        -12.480464
# 7   BiLSTM_GRU_pred     11.983690     -0.216889        -14.265137
# 8         QRNN_pred    -10.756737     -0.474046        -16.145721
# 9          ESN_pred    192.468327      0.466165        -11.096309
# 10         BNN_pred    101.903439      0.106808        -12.187775
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     76.532932     -0.111856        -13.219381
# 1             HV_dw     71.140199     -0.011408         -9.391376
# 2             HV_cw    112.338423      0.015511         -8.391737
# 3         LSTM_pred     84.286681      0.208904        -13.134498
# 4          GRU_pred     13.807105     -0.250019        -13.491812
# 5     LSTM_GRU_pred     98.299206      0.154810        -12.458492
# 6       BiLSTM_pred    141.721059      0.299533        -13.420117
# 7   BiLSTM_GRU_pred     15.321402     -0.197753        -16.436380
# 8         QRNN_pred     78.578348     -0.078312        -13.329305
# 9          ESN_pred    190.527435      0.433548        -12.477352
# 10         BNN_pred     96.007470      0.084930        -13.159201
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      6.316953     -0.383630        -15.627389
# 1             HV_dw    213.201215      0.446390         -7.509877
# 2             HV_cw    284.390448      0.747150         -6.397926
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred    174.837718      0.250581         -8.136556
# 5     LSTM_GRU_pred    134.055092      0.399510         -9.822579
# 6       BiLSTM_pred     67.123863      0.145702        -13.199840
# 7   BiLSTM_GRU_pred     55.689417     -0.012623        -15.345767
# 8         QRNN_pred     18.317562     -0.375623        -16.842366
# 9          ESN_pred    243.813389      0.667374        -11.033133
# 10         BNN_pred     90.789787      0.235884        -10.687453
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     85.416819     -0.042203        -13.199840
# 1             HV_dw    164.071633      0.241724         -8.722047
# 2             HV_cw    174.816398      0.319664         -7.814114
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred    117.688628      0.044753        -11.406266
# 5     LSTM_GRU_pred     72.642291      0.166256        -13.650658
# 6       BiLSTM_pred     58.336685      0.112840        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.095226        -13.199840
# 8         QRNN_pred     30.047675     -0.273492        -15.847796
# 9          ESN_pred    194.323005      0.459538        -11.247854
# 10         BNN_pred    115.463572      0.324041        -10.936139
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     85.715688     -0.069640        -13.199840
# 1             HV_dw    178.274484      0.290409         -8.604860
# 2             HV_cw    155.877297      0.098690        -10.981177
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred    163.821708      0.206610        -12.612387
# 5     LSTM_GRU_pred    101.821454      0.272271        -11.301691
# 6       BiLSTM_pred     71.934327      0.163041        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     94.612805     -0.000925        -13.681891
# 9          ESN_pred    135.154636      0.112004        -14.377467
# 10         BNN_pred     87.168090      0.220052        -12.184526
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     47.278164      0.069993        -13.199840
# 1             HV_dw     70.593064      0.104900        -13.815624
# 2             HV_cw     87.550160      0.222450        -13.199840
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     69.066182      0.153170        -14.030846
# 6       BiLSTM_pred     59.533867      0.117298        -13.199840
# 7   BiLSTM_GRU_pred     55.689417     -0.012623        -15.345767
# 8         QRNN_pred     48.489853      0.074657        -13.199840
# 9          ESN_pred     60.431584      0.006666        -14.874197
# 10         BNN_pred     81.253093      0.197672        -12.957475
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.242403      0.186086        -13.199840
# 1             HV_dw     78.242403      0.132971        -13.199840
# 2             HV_cw     68.467831      0.150883        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.095226        -13.199840
# 5     LSTM_GRU_pred     50.392827      0.083056        -15.441774
# 6       BiLSTM_pred     64.564742      0.135972        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.095226        -13.199840
# 8         QRNN_pred     40.996859      0.045520        -13.199840
# 9          ESN_pred     65.316557      0.085360        -14.240391
# 10         BNN_pred     78.242403      0.186086        -13.199840
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.242403      0.186086         -13.19984
# 1             HV_dw     78.242403      0.186086         -13.19984
# 2             HV_cw     74.299134      0.171707         -13.19984
# 3         LSTM_pred     78.242403      0.186086         -13.19984
# 4          GRU_pred     78.242403      0.132971         -13.19984
# 5     LSTM_GRU_pred     78.242403      0.186086         -13.19984
# 6       BiLSTM_pred     78.242403      0.186086         -13.19984
# 7   BiLSTM_GRU_pred     78.242403      0.186086         -13.19984
# 8         QRNN_pred     78.242403      0.186086         -13.19984
# 9          ESN_pred     78.242403      0.186086         -13.19984
# 10         BNN_pred     78.242403      0.186086         -13.19984
# 11               __     78.242403      0.186086         -13.19984
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    102.829849     -0.006529        -13.199840
# 1             HV_dw    140.212808      0.157023        -11.374362
# 2             HV_cw     69.627298      0.155926        -12.892697
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     68.074771      0.149162        -13.550624
# 5     LSTM_GRU_pred     93.397911      0.134994        -13.998297
# 6       BiLSTM_pred    123.740118      0.351777        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     80.050661     -0.054580        -14.281789
# 9          ESN_pred    153.941243      0.361212        -12.739148
# 10         BNN_pred    178.786635      0.227446        -10.936139
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     93.530178     -0.046371        -12.470947
# 1             HV_dw    108.714837      0.044417        -11.215485
# 2             HV_cw    306.344872      0.619506         -6.996827
# 3         LSTM_pred    122.742255      0.182122        -11.917184
# 4          GRU_pred     81.121617      0.024898        -11.950255
# 5     LSTM_GRU_pred    281.125240      0.746409         -7.094054
# 6       BiLSTM_pred    187.966798      0.488977        -11.958855
# 7   BiLSTM_GRU_pred     71.417903     -0.009104        -13.565654
# 8         QRNN_pred      5.871424     -0.366228        -13.677257
# 9          ESN_pred    187.860129      0.487199        -11.620442
# 10         BNN_pred    190.166485      0.418873        -12.642499
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     26.422505     -0.316229        -12.895011
# 1             HV_dw    106.025208      0.062511        -11.474425
# 2             HV_cw    211.889696      0.463030         -6.435979
# 3         LSTM_pred    118.580086      0.167780        -11.935449
# 4          GRU_pred     27.712077     -0.217977        -10.119459
# 5     LSTM_GRU_pred    363.352831      1.144039         -5.949456
# 6       BiLSTM_pred    124.591402      0.306839         -8.453273
# 7   BiLSTM_GRU_pred     82.224898      0.028070        -14.987556
# 8         QRNN_pred    -52.156799     -0.752619        -16.889725
# 9          ESN_pred    167.454608      0.404544        -11.811429
# 10         BNN_pred    161.199983      0.330433        -11.527652
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     17.448258     -0.343327        -13.500071
# 1             HV_dw    148.768914      0.188154         -9.422898
# 2             HV_cw    242.993143      0.439940         -7.194547
# 3         LSTM_pred    122.742255      0.182122        -11.917184
# 4          GRU_pred     63.344571     -0.049420        -10.000686
# 5     LSTM_GRU_pred    282.631328      0.774489         -8.568737
# 6       BiLSTM_pred    172.282219      0.430188        -11.076258
# 7   BiLSTM_GRU_pred     76.099854      0.006508        -13.579374
# 8         QRNN_pred    -21.583642     -0.497690        -15.537599
# 9          ESN_pred    245.126808      0.690370        -10.450424
# 10         BNN_pred    152.872076      0.295169        -12.023068
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     54.131427     -0.209859        -13.228433
# 1             HV_dw    106.258812      0.035467        -11.215485
# 2             HV_cw    246.724306      0.430246         -7.125156
# 3         LSTM_pred    122.742255      0.182122        -11.917184
# 4          GRU_pred     58.079475     -0.067701        -11.950255
# 5     LSTM_GRU_pred    230.665711      0.575687         -8.617761
# 6       BiLSTM_pred    187.966798      0.488977        -11.958855
# 7   BiLSTM_GRU_pred     71.417903     -0.009104        -13.565654
# 8         QRNN_pred    -18.988524     -0.479872        -15.745145
# 9          ESN_pred    303.002004      0.855923         -9.954246
# 10         BNN_pred    166.084979      0.340721        -11.759468
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     28.752568     -0.283540        -13.788415
# 1             HV_dw    129.203076      0.148852        -13.231589
# 2             HV_cw    143.336874      0.459881         -9.221644
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred    127.679754      0.258405         -7.118181
# 5     LSTM_GRU_pred    156.252226      0.306028        -11.960660
# 6       BiLSTM_pred     94.543237      0.250275        -13.199840
# 7   BiLSTM_GRU_pred     47.016688     -0.043949        -16.041221
# 8         QRNN_pred    -28.407389     -0.610106        -16.654475
# 9          ESN_pred    166.991035      0.385976        -12.596740
# 10         BNN_pred    151.411546      0.132781        -10.687453
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.705130     -0.399586        -14.179676
# 1             HV_dw    174.772083      0.277466         -9.504003
# 2             HV_cw    189.030737      0.627605         -9.221644
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     98.475153      0.170005         -9.649378
# 5     LSTM_GRU_pred     78.122313      0.078944        -15.285361
# 6       BiLSTM_pred    109.485312      0.301473        -13.199840
# 7   BiLSTM_GRU_pred     50.392827     -0.031003        -15.680055
# 8         QRNN_pred      2.931816     -0.370350        -16.594141
# 9          ESN_pred    285.858336      0.808852        -10.966312
# 10         BNN_pred    167.399730      0.188535        -10.936139
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    105.182720     -0.000446        -13.199840
# 1             HV_dw    140.212808      0.157023        -11.374362
# 2             HV_cw    123.627278      0.366772         -9.638438
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     55.177605      0.100909        -13.550624
# 5     LSTM_GRU_pred     93.397911      0.134994        -13.998297
# 6       BiLSTM_pred    123.740118      0.351777        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     51.649598     -0.167123        -14.633407
# 9          ESN_pred    196.523147      0.514647        -12.881892
# 10         BNN_pred    178.786635      0.227446        -10.936139
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     49.615622      0.079020        -13.199840
# 1             HV_dw     36.838531     -0.083382        -16.768122
# 2             HV_cw     63.310894      0.131316        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     47.016688      0.070287        -15.803960
# 6       BiLSTM_pred     59.533867      0.117298        -13.199840
# 7   BiLSTM_GRU_pred     47.016688     -0.043949        -16.041221
# 8         QRNN_pred     80.801655      0.104454        -12.957475
# 9          ESN_pred     90.092617      0.116418        -12.493167
# 10         BNN_pred     81.253093      0.197672        -12.957475
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.242403      0.186086        -13.199840
# 1             HV_dw     78.242403      0.186086        -13.199840
# 2             HV_cw     65.224936      0.138400        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.095226        -13.199840
# 5     LSTM_GRU_pred     50.392827      0.083056        -15.441774
# 6       BiLSTM_pred     64.564742      0.135972        -13.199840
# 7   BiLSTM_GRU_pred     50.392827     -0.031003        -15.680055
# 8         QRNN_pred     78.242403      0.186086        -13.199840
# 9          ESN_pred     65.316557      0.047457        -14.240391
# 10         BNN_pred     78.242403      0.186086        -13.199840
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.242403      0.186086         -13.19984
# 1             HV_dw     78.242403      0.186086         -13.19984
# 2             HV_cw     78.242403      0.186086         -13.19984
# 3         LSTM_pred     78.242403      0.186086         -13.19984
# 4          GRU_pred     78.242403      0.186086         -13.19984
# 5     LSTM_GRU_pred     78.242403      0.186086         -13.19984
# 6       BiLSTM_pred     78.242403      0.186086         -13.19984
# 7   BiLSTM_GRU_pred     78.242403      0.186086         -13.19984
# 8         QRNN_pred     78.242403      0.186086         -13.19984
# 9          ESN_pred     78.242403      0.186086         -13.19984
# 10         BNN_pred     78.242403      0.186086         -13.19984
# 11               __     78.242403      0.186086         -13.19984
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    123.827005      0.128566        -13.199840
# 1             HV_dw    118.431908      0.079592        -11.159549
# 2             HV_cw    126.737757      0.199089        -10.649745
# 3         LSTM_pred     73.909071     -0.002851        -11.735770
# 4          GRU_pred    104.927832      0.186648        -10.419385
# 5     LSTM_GRU_pred     79.804665      0.083271        -14.485553
# 6       BiLSTM_pred    111.419277      0.172772        -13.752920
# 7   BiLSTM_GRU_pred    150.483372      0.210449        -13.199840
# 8         QRNN_pred    157.966386      0.248480        -13.199840
# 9          ESN_pred    120.996912      0.178152        -11.142683
# 10         BNN_pred     99.385336      0.097783        -13.325374
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     90.119018      0.061422        -11.118942
# 1             HV_dw     34.815855     -0.173724        -11.818755
# 2             HV_cw     92.283537      0.068328        -11.159721
# 3         LSTM_pred     90.322465      0.125805        -10.319934
# 4          GRU_pred    -41.433184     -0.550863        -13.029871
# 5     LSTM_GRU_pred    250.420995      0.696445         -6.432429
# 6       BiLSTM_pred    216.626966      0.574691         -9.647352
# 7   BiLSTM_GRU_pred     60.968509     -0.064476        -11.477048
# 8         QRNN_pred     84.123957      0.037658        -14.573166
# 9          ESN_pred    120.422644      0.181989        -11.702527
# 10         BNN_pred     66.104841     -0.032415        -12.903188
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    108.557790      0.147060         -4.064074
# 1             HV_dw     37.531668     -0.218932         -7.166742
# 2             HV_cw     53.673014     -0.134772         -9.221644
# 3         LSTM_pred    -43.157430     -0.730178        -12.711762
# 4          GRU_pred   -103.568660     -1.053543        -17.332442
# 5     LSTM_GRU_pred     91.732103      0.053777         -7.236821
# 6       BiLSTM_pred     48.427020     -0.122090         -6.858415
# 7   BiLSTM_GRU_pred    -30.114063     -0.850471        -11.472801
# 8         QRNN_pred     62.751212     -0.095871         -5.499781
# 9          ESN_pred    116.665682      0.191022         -6.442252
# 10         BNN_pred      0.154557     -0.390500        -12.962314
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     21.744035     -0.248436        -14.289880
# 1             HV_dw     56.153063     -0.096904         -6.510985
# 2             HV_cw    106.560114      0.130593         -9.221644
# 3         LSTM_pred     46.408313     -0.147407        -10.853240
# 4          GRU_pred    -51.690272     -0.668451        -12.909058
# 5     LSTM_GRU_pred    168.056294      0.420424         -6.432429
# 6       BiLSTM_pred    221.076901      0.712931         -6.976807
# 7   BiLSTM_GRU_pred    112.212060      0.155911         -8.325590
# 8         QRNN_pred     19.217955     -0.274486        -15.577965
# 9          ESN_pred     77.203567     -0.014477        -10.421010
# 10         BNN_pred      0.209473     -0.337538        -11.251734
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    127.899804      0.203715        -11.118942
# 1             HV_dw     49.291372     -0.113446        -10.135343
# 2             HV_cw    139.219997      0.259290        -11.093807
# 3         LSTM_pred     97.278517      0.086838         -8.807796
# 4          GRU_pred    -97.253101     -0.829102        -16.355621
# 5     LSTM_GRU_pred    174.386460      0.412687         -6.627626
# 6       BiLSTM_pred    232.739061      0.705664         -9.040768
# 7   BiLSTM_GRU_pred    134.896800      0.250728        -11.752283
# 8         QRNN_pred     34.324921     -0.119390        -14.573166
# 9          ESN_pred     93.225096      0.067283        -11.169149
# 10         BNN_pred     47.475486     -0.113027        -11.398194
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    152.269586      0.351816         -5.499781
# 1             HV_dw    160.373195      0.176866         -8.428012
# 2             HV_cw     94.189125      0.073644        -11.250735
# 3         LSTM_pred    -18.236372     -0.437829        -14.024384
# 4          GRU_pred    -60.208937     -0.702019        -14.401172
# 5     LSTM_GRU_pred    -53.761041     -0.679232        -15.012005
# 6       BiLSTM_pred    -61.285133     -0.669946        -16.777208
# 7   BiLSTM_GRU_pred    -86.179486     -1.150978        -19.942880
# 8         QRNN_pred    136.787573      0.278958         -5.499781
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred     23.879370     -0.221151        -13.551627
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     75.460287     -0.131404        -15.655820
# 1             HV_dw    107.279230      0.067015        -10.298707
# 2             HV_cw    109.554240      0.140126        -11.250735
# 3         LSTM_pred     59.149165     -0.062415        -11.735770
# 4          GRU_pred     35.881421     -0.105538        -10.053555
# 5     LSTM_GRU_pred     21.710297     -0.167558        -16.406733
# 6       BiLSTM_pred     58.237749     -0.044720        -14.414879
# 7   BiLSTM_GRU_pred    117.563022      0.028516        -13.604961
# 8         QRNN_pred     44.406552     -0.152053        -15.923678
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred    125.370471      0.195729        -11.956231
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    109.287355      0.076714        -13.199840
# 1             HV_dw    151.488386      0.197727         -9.358140
# 2             HV_cw    175.154747      0.384433        -10.745048
# 3         LSTM_pred     59.149165     -0.062415        -11.735770
# 4          GRU_pred     57.557350     -0.001291        -12.022976
# 5     LSTM_GRU_pred     91.118436      0.126585        -14.485553
# 6       BiLSTM_pred    114.481946      0.185084        -12.816879
# 7   BiLSTM_GRU_pred    142.315799      0.183494        -13.444439
# 8         QRNN_pred     71.606307     -0.076888        -14.748047
# 9          ESN_pred     99.317527      0.096195        -11.142683
# 10         BNN_pred     98.838127      0.095446        -12.449247
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    152.269586      0.351816         -5.499781
# 1             HV_dw     42.919659     -0.060300        -15.972663
# 2             HV_cw     63.310894     -0.055144        -13.199840
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred     57.758917     -0.002952        -15.088745
# 5     LSTM_GRU_pred     23.810974     -0.371936        -18.722100
# 6       BiLSTM_pred     26.268086     -0.009554        -15.347035
# 7   BiLSTM_GRU_pred    -19.852234     -0.656666        -17.816843
# 8         QRNN_pred    136.787573      0.278958         -5.499781
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred     53.848108     -0.019135        -15.493419
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     75.460287     -0.131404        -15.655820
# 1             HV_dw     39.773900     -0.072138        -16.532486
# 2             HV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     39.675173      0.010488        -15.202383
# 6       BiLSTM_pred     59.533867      0.117298        -13.199840
# 7   BiLSTM_GRU_pred     79.400118      0.077408        -13.444439
# 8         QRNN_pred     44.406552     -0.152053        -15.923678
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred     81.253093      0.197672        -12.957475
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     78.242403      0.095226        -13.199840
# 1             HV_dw     78.242403      0.186086        -13.199840
# 2             HV_cw     78.242403      0.186086        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.132971        -13.199840
# 5     LSTM_GRU_pred     79.400118      0.190306        -13.199840
# 6       BiLSTM_pred     64.564742      0.135972        -13.199840
# 7   BiLSTM_GRU_pred     79.400118      0.077408        -13.444439
# 8         QRNN_pred     78.242403     -0.067701        -14.706863
# 9          ESN_pred     78.242403      0.008575        -13.199840
# 10         BNN_pred     78.242403      0.186086        -13.199840
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    113.094821      0.031455        -14.250829
# 1             HV_dw     63.286829     -0.040873        -12.945984
# 2             HV_cw     98.966938      0.095582        -12.723784
# 3         LSTM_pred    103.882820      0.114855         -9.846970
# 4          GRU_pred     79.859192      0.017306        -10.077672
# 5     LSTM_GRU_pred    159.022092      0.390739         -9.994778
# 6       BiLSTM_pred    254.354281      0.746578        -12.322672
# 7   BiLSTM_GRU_pred     87.925642     -0.027415        -17.461553
# 8         QRNN_pred    129.895826      0.087885        -13.586460
# 9          ESN_pred    132.540321      0.225312        -11.676221
# 10         BNN_pred    117.955756      0.166426        -12.404248
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    112.385306      0.148978        -11.675568
# 1             HV_dw    142.226161      0.274448         -8.279249
# 2             HV_cw     43.482807     -0.135590        -10.169595
# 3         LSTM_pred     68.633962      0.031886        -11.242691
# 4          GRU_pred    -41.433184     -0.550863        -13.029871
# 5     LSTM_GRU_pred    181.010552      0.432027         -5.725784
# 6       BiLSTM_pred    148.339090      0.296477         -9.742950
# 7   BiLSTM_GRU_pred    153.186221      0.318927         -9.486363
# 8         QRNN_pred    154.907056      0.318726        -10.118970
# 9          ESN_pred    115.167901      0.162074        -13.363793
# 10         BNN_pred      4.820272     -0.311791        -12.838984
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     72.422496     -0.073672         -5.057242
# 1             HV_dw     67.960286     -0.081538         -3.955343
# 2             HV_cw     73.756482     -0.059185         -7.318535
# 3         LSTM_pred    -11.824497     -0.514230        -10.540354
# 4          GRU_pred    -35.921155     -0.809484         -9.039405
# 5     LSTM_GRU_pred     72.431549     -0.088968         -4.677495
# 6       BiLSTM_pred     58.975787     -0.055605         -4.233402
# 7   BiLSTM_GRU_pred     30.567799     -0.452198         -8.523580
# 8         QRNN_pred     61.429163     -0.121551         -6.572252
# 9          ESN_pred    147.273225      0.383332         -5.430376
# 10         BNN_pred    -27.655618     -0.574853        -13.101895
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     28.358979     -0.264076        -12.304719
# 1             HV_dw    167.840377      0.404551         -6.452406
# 2             HV_cw     76.680550     -0.024627         -7.866254
# 3         LSTM_pred    -26.359883     -0.514758        -11.703593
# 4          GRU_pred    -51.690272     -0.668451        -12.909058
# 5     LSTM_GRU_pred    106.012519      0.139374         -4.837541
# 6       BiLSTM_pred    120.562591      0.256223         -5.268715
# 7   BiLSTM_GRU_pred    104.977303      0.124653         -6.750016
# 8         QRNN_pred     82.978416      0.011600         -7.274035
# 9          ESN_pred     64.789740     -0.090302        -10.633274
# 10         BNN_pred    -63.288961     -0.695704        -16.203909
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     50.221516     -0.127637        -15.184132
# 1             HV_dw     94.816698      0.076701         -9.290716
# 2             HV_cw     72.016711     -0.034279         -9.054779
# 3         LSTM_pred     62.057195     -0.002952        -10.251773
# 4          GRU_pred    -78.976839     -0.777924        -14.696381
# 5     LSTM_GRU_pred    231.372456      0.681990         -5.378559
# 6       BiLSTM_pred    102.002594      0.144205        -10.880867
# 7   BiLSTM_GRU_pred    142.087172      0.286382         -8.865567
# 8         QRNN_pred    116.826987      0.176010         -9.973424
# 9          ESN_pred     73.371316     -0.034620        -12.840450
# 10         BNN_pred      7.889496     -0.309760        -12.568212
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    138.833878      0.288737         -5.499781
# 1             HV_dw     33.642257     -0.204635         -9.116263
# 2             HV_cw     59.975651     -0.084551        -12.843931
# 3         LSTM_pred     67.661057     -0.068809         -8.839783
# 4          GRU_pred     13.572443     -0.365071         -7.698788
# 5     LSTM_GRU_pred     17.301213     -0.409746        -10.545257
# 6       BiLSTM_pred     70.189003      0.025804         -6.690127
# 7   BiLSTM_GRU_pred     33.552887     -0.591826        -11.808160
# 8         QRNN_pred    120.661395      0.201397         -6.572252
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred     52.507900     -0.120256        -13.182767
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     49.836182     -0.127268        -15.486584
# 1             HV_dw     70.757993     -0.022143         -9.789127
# 2             HV_cw    103.979569      0.116637        -10.159703
# 3         LSTM_pred     25.718221     -0.252829         -8.587050
# 4          GRU_pred     -1.891092     -0.365756         -9.725342
# 5     LSTM_GRU_pred     -0.176386     -0.352188        -13.287417
# 6       BiLSTM_pred    195.969604      0.600119         -7.985504
# 7   BiLSTM_GRU_pred      7.679723     -0.483607        -17.714406
# 8         QRNN_pred    152.750876      0.353646         -5.499781
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred     39.226713     -0.149863        -13.182767
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     77.373731     -0.119094        -15.505756
# 1             HV_dw     37.437985     -0.149163        -10.956895
# 2             HV_cw    114.308948      0.161457        -10.159703
# 3         LSTM_pred     90.422453      0.058691         -9.846970
# 4          GRU_pred     54.817807     -0.096549         -7.595745
# 5     LSTM_GRU_pred    162.337124      0.420083        -12.102137
# 6       BiLSTM_pred    231.283996      0.669528        -11.443722
# 7   BiLSTM_GRU_pred     49.836719     -0.199130        -16.922126
# 8         QRNN_pred     82.517120     -0.106488        -15.203527
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred    162.035799      0.333898        -10.111831
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    138.833878      0.288737         -5.499781
# 1             HV_dw     42.919659     -0.060300        -15.972663
# 2             HV_cw     53.809010     -0.100298        -13.350980
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred     42.941060      0.023319        -16.041652
# 5     LSTM_GRU_pred     -4.626540     -0.589458        -15.719853
# 6       BiLSTM_pred     29.367111      0.002415        -15.347035
# 7   BiLSTM_GRU_pred    -34.936292     -0.787010        -17.010440
# 8         QRNN_pred    120.661395      0.201397         -6.572252
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred     53.848108     -0.019135        -15.493419
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     49.836182     -0.127268        -15.486584
# 1             HV_dw     46.747748     -0.045610        -15.972663
# 2             HV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     38.126452     -0.270432        -17.437576
# 6       BiLSTM_pred     59.533867      0.117298        -13.199840
# 7   BiLSTM_GRU_pred     32.493609     -0.017453        -16.041652
# 8         QRNN_pred    152.750876      0.353646         -5.499781
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred     53.848108     -0.019135        -15.493419
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     70.593064     -0.146850        -16.037538
# 1             HV_dw     50.392827      0.029339        -15.441774
# 2             HV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.132971        -13.199840
# 5     LSTM_GRU_pred     64.227677      0.134724        -13.199840
# 6       BiLSTM_pred     59.533867      0.117298        -13.199840
# 7   BiLSTM_GRU_pred     79.400118      0.077408        -13.444439
# 8         QRNN_pred     82.517120     -0.106488        -15.203527
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred     78.242403      0.186086        -13.199840
# 11               __     78.242403      0.186086        -13.199840

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_2y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_2y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_2y1', file, 'HV')
get_final_results_1('2024_2y1', file, 'HV')

get_final_results('2024_2y1', dw_file, 'HV_dw')
get_final_results_1('2024_2y1', dw_file, 'HV_dw')

get_final_results('2024_2y1', cw_file, 'HV_cw')
get_final_results_1('2024_2y1', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-37-4662277378c1>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-37-4662277378c1>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-37-4662277378c1>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    262.700213      0.675954         -8.115590
# 1             HV_dw    362.697256      1.033560         -8.588117
# 2             HV_cw    290.565198      0.786687         -6.500563
# 3         LSTM_pred    244.342392      0.634150         -9.302629
# 4          GRU_pred    245.956245      0.627628         -9.345933
# 5     LSTM_GRU_pred    230.493684      0.566057         -9.345933
# 6       BiLSTM_pred    244.935530      0.610543         -9.302629
# 7   BiLSTM_GRU_pred    223.879530      0.538432         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    275.675806      0.741667         -8.588117
# 10         BNN_pred    210.093690      0.492542         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    285.554857      0.791070         -5.632399
# 1             HV_dw    417.129921      1.294667         -7.318989
# 2             HV_cw    226.278383      0.581971         -6.500563
# 3         LSTM_pred    156.123272      0.334475         -8.424766
# 4          GRU_pred    264.892032      0.736746         -9.419603
# 5     LSTM_GRU_pred    272.961564      0.778074         -9.419603
# 6       BiLSTM_pred    171.119937      0.363027         -6.696292
# 7   BiLSTM_GRU_pred    175.914856      0.363757         -9.536885
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    278.332399      0.789007         -8.023967
# 10         BNN_pred    130.332213      0.221487        -10.270987
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    306.272754      0.969914         -5.694421
# 1             HV_dw    360.272624      1.170141         -4.047302
# 2             HV_cw    185.794568      0.529509         -5.657823
# 3         LSTM_pred    138.258924      0.267041         -8.424766
# 4          GRU_pred    211.069382      0.639339         -7.143998
# 5     LSTM_GRU_pred    190.635536      0.550757         -8.415522
# 6       BiLSTM_pred    207.402042      0.565376         -5.972847
# 7   BiLSTM_GRU_pred    110.366315      0.144076         -9.536885
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    220.170061      0.612073         -5.675617
# 10         BNN_pred    151.566125      0.319607        -10.130962
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    305.422414      0.888348         -5.672861
# 1             HV_dw    392.676395      1.224737         -6.483625
# 2             HV_cw    169.452679      0.373407         -6.500563
# 3         LSTM_pred    152.206029      0.324465         -8.424766
# 4          GRU_pred    290.314559      0.850464         -6.850221
# 5     LSTM_GRU_pred    304.577457      0.918365         -6.850221
# 6       BiLSTM_pred    201.202767      0.481073         -6.528590
# 7   BiLSTM_GRU_pred    146.267873      0.295493         -9.536885
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    292.717063      0.857092         -6.967248
# 10         BNN_pred    149.985546      0.302158        -10.130962
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    254.240366      0.669059         -6.749600
# 1             HV_dw    400.490214      1.242283         -7.318989
# 2             HV_cw    229.961129      0.595605         -6.500563
# 3         LSTM_pred    181.462912      0.391379         -8.424766
# 4          GRU_pred    276.292908      0.779062         -8.603173
# 5     LSTM_GRU_pred    262.406015      0.745800         -8.603173
# 6       BiLSTM_pred    171.119937      0.363027         -6.696292
# 7   BiLSTM_GRU_pred    168.463673      0.334156         -9.536885
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    278.382740      0.789188         -8.023967
# 10         BNN_pred    125.033949      0.200195        -10.270987
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    312.073767      0.954962         -5.668320
# 1             HV_dw    312.917966      0.914570         -7.100868
# 2             HV_cw    225.757783      0.633412         -5.671768
# 3         LSTM_pred    192.162999      0.452362         -9.302629
# 4          GRU_pred    231.113588      0.604168         -7.355253
# 5     LSTM_GRU_pred    250.207583      0.662061         -7.355253
# 6       BiLSTM_pred    233.442803      0.611041         -8.485144
# 7   BiLSTM_GRU_pred    181.785908      0.391741         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    251.983421      0.685173         -6.944894
# 10         BNN_pred    153.321900      0.286382         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    336.474453      0.980438         -5.554551
# 1             HV_dw    360.644985      1.070549         -7.764192
# 2             HV_cw    217.934065      0.538587         -6.500563
# 3         LSTM_pred    214.903530      0.532314         -9.302629
# 4          GRU_pred    256.834431      0.722464         -7.236876
# 5     LSTM_GRU_pred    228.171280      0.611226         -7.236876
# 6       BiLSTM_pred    252.067161      0.635561         -9.302629
# 7   BiLSTM_GRU_pred    220.729913      0.529801         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    285.777262      0.792658         -8.219144
# 10         BNN_pred    194.788258      0.439817         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    265.302316      0.684969         -8.115590
# 1             HV_dw    362.697256      1.033560         -8.588117
# 2             HV_cw    271.313166      0.720993         -6.500563
# 3         LSTM_pred    244.342392      0.634150         -9.302629
# 4          GRU_pred    245.956245      0.668377         -8.528839
# 5     LSTM_GRU_pred    207.461338      0.526451         -8.528839
# 6       BiLSTM_pred    244.935530      0.610543         -9.302629
# 7   BiLSTM_GRU_pred    223.879530      0.538432         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    275.726043      0.741838         -8.588117
# 10         BNN_pred    210.093690      0.492542         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    224.361978      0.581165         -8.485144
# 1             HV_dw    187.138510      0.435348         -8.485144
# 2             HV_cw    224.361978      0.581165         -8.485144
# 3         LSTM_pred    212.833959      0.501729         -9.302629
# 4          GRU_pred    209.460362      0.487498         -9.035617
# 5     LSTM_GRU_pred    209.460362      0.487498         -9.035617
# 6       BiLSTM_pred    248.247694      0.661996         -8.485144
# 7   BiLSTM_GRU_pred    212.833959      0.501729         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    212.430594      0.502153         -9.302629
# 10         BNN_pred    192.692854      0.429564         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    225.931670      0.546964         -9.302629
# 1             HV_dw    246.769469      0.656361         -8.485144
# 2             HV_cw    225.931670      0.546964         -9.302629
# 3         LSTM_pred    235.968788      0.580680         -9.302629
# 4          GRU_pred    229.351211      0.598818         -8.485144
# 5     LSTM_GRU_pred    227.391052      0.591895         -8.485144
# 6       BiLSTM_pred    259.977796      0.662362         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    262.444097      0.671101         -9.302629
# 10         BNN_pred    227.391052      0.552122         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    252.801107      0.637340         -9.302629
# 1             HV_dw    252.801107      0.637340         -9.302629
# 2             HV_cw    252.801107      0.637340         -9.302629
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.676986         -8.485144
# 5     LSTM_GRU_pred    229.351211      0.598818         -8.485144
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.637340         -9.302629
# 10         BNN_pred    252.801107      0.637340         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    248.244242      0.622774         -8.765729
# 1             HV_dw    276.048990      0.752251         -8.588117
# 2             HV_cw    234.544518      0.575138         -9.302629
# 3         LSTM_pred    240.927730      0.621594         -9.302629
# 4          GRU_pred    224.783910      0.547523         -9.419603
# 5     LSTM_GRU_pred    227.554140      0.555556         -9.345933
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    225.545183      0.568287         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    238.011854      0.614012        -10.297472
# 10         BNN_pred    221.528020      0.536143         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    330.762718      0.948313         -5.441058
# 1             HV_dw    480.851129      1.480488         -8.588117
# 2             HV_cw    233.280748      0.581706         -9.302629
# 3         LSTM_pred    222.874113      0.542969         -7.143639
# 4          GRU_pred    225.290495      0.581405         -9.222801
# 5     LSTM_GRU_pred    245.650206      0.663958         -9.419603
# 6       BiLSTM_pred    182.697943      0.411434         -6.648852
# 7   BiLSTM_GRU_pred    202.986265      0.455614         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    364.188253      1.037261         -7.431712
# 10         BNN_pred    163.421020      0.304350        -10.313829
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    228.623864      0.654576         -6.053321
# 1             HV_dw    468.189372      1.512948         -7.100868
# 2             HV_cw    153.109334      0.309788         -8.890511
# 3         LSTM_pred    196.272017      0.499016         -7.143639
# 4          GRU_pred    246.557612      0.762298         -6.582078
# 5     LSTM_GRU_pred    236.183305      0.727341         -7.861297
# 6       BiLSTM_pred    234.419798      0.623836         -5.910880
# 7   BiLSTM_GRU_pred     98.681033      0.093063         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    329.091121      1.055390         -5.319672
# 10         BNN_pred    172.650522      0.400858         -9.364239
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    333.613871      0.991516         -5.566466
# 1             HV_dw    448.257066      1.385860         -8.588117
# 2             HV_cw    215.019264      0.579268         -8.485144
# 3         LSTM_pred    187.134473      0.461864         -7.467765
# 4          GRU_pred    293.523363      0.841511         -7.242169
# 5     LSTM_GRU_pred    274.609096      0.792281         -7.682310
# 6       BiLSTM_pred    209.017715      0.513911         -6.529468
# 7   BiLSTM_GRU_pred    140.907526      0.266574         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    337.456731      1.005665         -8.331495
# 10         BNN_pred    186.427645      0.442372        -10.173871
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    248.482085      0.642691         -9.766839
# 1             HV_dw    465.887256      1.435994         -8.588117
# 2             HV_cw    200.439060      0.465413         -9.302629
# 3         LSTM_pred    205.858872      0.524969         -7.143639
# 4          GRU_pred    262.255399      0.721765         -8.140222
# 5     LSTM_GRU_pred    274.864443      0.774335         -9.419603
# 6       BiLSTM_pred    182.697943      0.411434         -6.648852
# 7   BiLSTM_GRU_pred    182.698842      0.427695         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    299.541022      0.864984        -10.637331
# 10         BNN_pred    143.467358      0.228021        -10.313829
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    288.313528      0.834694         -5.748213
# 1             HV_dw    254.175047      0.694555         -7.100868
# 2             HV_cw    211.514015      0.509582         -8.890511
# 3         LSTM_pred    242.628645      0.634910         -9.302629
# 4          GRU_pred    281.304270      0.833087         -6.582078
# 5     LSTM_GRU_pred    252.658407      0.713962         -6.794612
# 6       BiLSTM_pred    253.430484      0.680140         -8.485144
# 7   BiLSTM_GRU_pred    160.549846      0.338759         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    236.226028      0.636735         -5.675087
# 10         BNN_pred    138.006938      0.268380         -8.485144
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    302.196775      0.850405         -5.676423
# 1             HV_dw    276.054982      0.753330         -8.588117
# 2             HV_cw    226.313511      0.594061         -8.485144
# 3         LSTM_pred    233.137012      0.600544         -9.302629
# 4          GRU_pred    289.362382      0.791087         -7.242169
# 5     LSTM_GRU_pred    220.981913      0.544788         -8.065511
# 6       BiLSTM_pred    259.977796      0.662362         -9.302629
# 7   BiLSTM_GRU_pred    230.507057      0.590082         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    250.385745      0.663314        -10.092926
# 10         BNN_pred    206.077965      0.483486         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    234.552476      0.576201         -9.766462
# 1             HV_dw    276.048990      0.752251         -8.588117
# 2             HV_cw    220.703374      0.530008         -9.302629
# 3         LSTM_pred    226.766456      0.572622         -9.302629
# 4          GRU_pred    239.887397      0.606507         -8.140222
# 5     LSTM_GRU_pred    228.914282      0.561879         -9.345933
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    230.507057      0.590082         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    237.005785      0.610470        -10.370369
# 10         BNN_pred    198.663493      0.455752         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    210.621049      0.518046         -8.488748
# 1             HV_dw    194.912371      0.464068         -8.485144
# 2             HV_cw    214.065949      0.511575         -8.890511
# 3         LSTM_pred    245.482218      0.614482         -9.302629
# 4          GRU_pred    220.220609      0.568646         -8.485144
# 5     LSTM_GRU_pred    218.769752      0.563455         -8.485144
# 6       BiLSTM_pred    253.430484      0.680140         -8.485144
# 7   BiLSTM_GRU_pred    217.383799      0.519411         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    198.842063      0.453335         -9.302629
# 10         BNN_pred    192.692854      0.469349         -8.485144
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    225.931670      0.546964         -9.302629
# 1             HV_dw    252.801107      0.637340         -9.302629
# 2             HV_cw    224.361978      0.581165         -8.485144
# 3         LSTM_pred    235.968788      0.580680         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    229.351211      0.559033         -9.302629
# 6       BiLSTM_pred    259.977796      0.662362         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    262.444097      0.671101         -9.302629
# 10         BNN_pred    227.391052      0.552122         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    252.801107      0.637340         -9.302629
# 1             HV_dw    252.801107      0.637340         -9.302629
# 2             HV_cw    227.391052      0.552122         -9.302629
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    252.801107      0.637340         -9.302629
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.637340         -9.302629
# 10         BNN_pred    229.351211      0.559033         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    220.350861      0.545479         -9.302629
# 1             HV_dw    405.314510      1.222961         -8.588117
# 2             HV_cw    210.079945      0.501496        -10.132498
# 3         LSTM_pred    210.847121      0.525097         -8.850512
# 4          GRU_pred    269.235963      0.770853        -10.125437
# 5     LSTM_GRU_pred    248.753355      0.653427        -10.125437
# 6       BiLSTM_pred    208.602520      0.509742         -6.354654
# 7   BiLSTM_GRU_pred    260.006978      0.653409         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    276.314213      0.721778         -9.302629
# 10         BNN_pred    154.653467      0.272793        -10.270987
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    241.520458      0.628410         -8.446027
# 1             HV_dw    400.826214      1.252922         -7.360509
# 2             HV_cw    166.797193      0.356577        -10.132498
# 3         LSTM_pred    184.444305      0.409137         -9.099155
# 4          GRU_pred    132.986115      0.247965         -9.832867
# 5     LSTM_GRU_pred    145.449459      0.297887        -13.165766
# 6       BiLSTM_pred    160.007271      0.339153         -8.651395
# 7   BiLSTM_GRU_pred    150.861805      0.265884         -8.550024
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    254.055470      0.674618         -9.302629
# 10         BNN_pred    101.593216      0.105838         -8.295194
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    182.930588      0.563970         -6.695987
# 1             HV_dw    179.111409      0.598939         -3.027346
# 2             HV_cw     18.674251     -0.458375         -8.488748
# 3         LSTM_pred     83.189422      0.010886         -6.018547
# 4          GRU_pred    114.063516      0.198593         -4.916189
# 5     LSTM_GRU_pred     85.784423      0.019102         -6.150192
# 6       BiLSTM_pred    165.510705      0.423896         -6.317463
# 7   BiLSTM_GRU_pred     36.061742     -0.233800         -8.550024
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred      5.450628     -0.598933         -9.302629
# 10         BNN_pred     88.572932      0.036800         -5.915052
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    217.227851      0.717875         -5.325611
# 1             HV_dw    327.593447      1.072758         -5.227756
# 2             HV_cw     56.826766     -0.169608         -9.035617
# 3         LSTM_pred    148.030173      0.324082         -6.935321
# 4          GRU_pred    131.888374      0.269332         -7.638773
# 5     LSTM_GRU_pred    147.926055      0.351343         -6.582078
# 6       BiLSTM_pred    232.311379      0.668891         -7.472690
# 7   BiLSTM_GRU_pred     70.802448     -0.041369         -8.550024
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    176.713650      0.453294         -9.302629
# 10         BNN_pred     97.753864      0.088351         -7.235995
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    213.366087      0.621019         -6.771430
# 1             HV_dw    383.725413      1.233321         -7.360509
# 2             HV_cw    192.512436      0.470658         -9.035617
# 3         LSTM_pred    141.145341      0.284814         -8.646023
# 4          GRU_pred    178.923742      0.495081         -7.907876
# 5     LSTM_GRU_pred    135.754446      0.277112         -8.904259
# 6       BiLSTM_pred    168.899008      0.372189         -8.651395
# 7   BiLSTM_GRU_pred    197.500917      0.467367         -8.550024
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    211.566000      0.572286         -9.302629
# 10         BNN_pred     80.595749      0.008673         -8.152086
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    126.386770      0.244521         -8.485144
# 1             HV_dw    285.302288      0.869274         -7.100868
# 2             HV_cw    110.826576      0.162569         -8.488748
# 3         LSTM_pred    199.526070      0.545045         -4.728613
# 4          GRU_pred    194.648988      0.620787         -5.450334
# 5     LSTM_GRU_pred    167.710789      0.405778         -5.395219
# 6       BiLSTM_pred    243.651299      0.674644         -5.324724
# 7   BiLSTM_GRU_pred     88.823236     -0.004422         -8.021596
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     28.365316     -0.410160         -9.302629
# 10         BNN_pred    145.490975      0.310086         -9.320944
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    159.841089      0.408131         -8.485144
# 1             HV_dw    400.710934      1.257718         -7.100868
# 2             HV_cw    114.998937      0.138799         -9.035617
# 3         LSTM_pred    144.429899      0.278493         -8.850512
# 4          GRU_pred    262.984503      0.843235         -6.582078
# 5     LSTM_GRU_pred    204.197353      0.600834         -6.582078
# 6       BiLSTM_pred    270.263501      0.756024         -4.940095
# 7   BiLSTM_GRU_pred    185.256001      0.397399         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    217.978972      0.592800         -9.302629
# 10         BNN_pred    194.944782      0.490626        -10.130962
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    167.826597      0.416789         -8.485144
# 1             HV_dw    408.899558      1.243322         -8.588117
# 2             HV_cw    225.888714      0.572170         -9.035617
# 3         LSTM_pred    151.154969      0.304035         -8.850512
# 4          GRU_pred    283.302509      0.895769         -8.684354
# 5     LSTM_GRU_pred    215.904044      0.583303         -8.684354
# 6       BiLSTM_pred    210.376196      0.510296         -6.354654
# 7   BiLSTM_GRU_pred    232.577696      0.565578         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    258.356537      0.716336         -9.302629
# 10         BNN_pred    162.131793      0.351123        -10.130962
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    126.386770      0.244521         -8.485144
# 1             HV_dw    152.393639      0.305926         -8.485144
# 2             HV_cw     78.130481     -0.012618        -10.580888
# 3         LSTM_pred    199.079027      0.454022         -9.302629
# 4          GRU_pred    202.858870      0.464722         -9.035617
# 5     LSTM_GRU_pred    195.423842      0.438217         -9.035617
# 6       BiLSTM_pred    211.289266      0.535941         -8.485144
# 7   BiLSTM_GRU_pred    186.281161      0.407617         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred     56.901835     -0.165362         -9.302629
# 10         BNN_pred    192.692854      0.469349         -8.485144
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    159.841089      0.408131         -8.485144
# 1             HV_dw    190.650837      0.463925         -8.485144
# 2             HV_cw    141.435236      0.255553         -9.035617
# 3         LSTM_pred    245.482218      0.614482         -9.302629
# 4          GRU_pred    210.900137      0.534603         -8.485144
# 5     LSTM_GRU_pred    209.460362      0.529419         -8.485144
# 6       BiLSTM_pred    248.247694      0.661996         -8.485144
# 7   BiLSTM_GRU_pred    212.833959      0.501729         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    201.189376      0.461941         -9.302629
# 10         BNN_pred    227.391052      0.552122         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    167.826597      0.416789         -8.485144
# 1             HV_dw    252.801107      0.637340         -9.302629
# 2             HV_cw    206.869401      0.477964         -9.035617
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    229.351211      0.559033         -9.302629
# 6       BiLSTM_pred    259.977796      0.662362         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    212.430594      0.502153         -9.302629
# 10         BNN_pred    227.391052      0.552122         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    245.869572      0.622688        -10.128959
# 1             HV_dw    382.894827      1.142623         -6.344729
# 2             HV_cw    194.906185      0.454866        -10.132498
# 3         LSTM_pred    215.021791      0.517300         -8.135049
# 4          GRU_pred    269.235963      0.770853        -10.125437
# 5     LSTM_GRU_pred    270.735460      0.770327        -10.082505
# 6       BiLSTM_pred    178.474602      0.401544         -7.381833
# 7   BiLSTM_GRU_pred    156.119229      0.328957         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    227.037993      0.564017         -9.302629
# 10         BNN_pred    169.513185      0.340503         -7.281861
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    209.387730      0.509953         -9.942738
# 1             HV_dw    237.762178      0.670278         -7.730025
# 2             HV_cw    148.647485      0.286738        -10.132498
# 3         LSTM_pred    114.408669      0.166303         -9.385831
# 4          GRU_pred    132.986115      0.247965         -9.832867
# 5     LSTM_GRU_pred     83.194654      0.021646        -12.885814
# 6       BiLSTM_pred    151.861533      0.311863        -11.231734
# 7   BiLSTM_GRU_pred    223.472272      0.564303         -7.374959
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    234.981548      0.624280         -9.302629
# 10         BNN_pred    128.884520      0.227261         -8.295194
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     82.693766     -0.008112         -6.943868
# 1             HV_dw    100.573842      0.125018         -6.689866
# 2             HV_cw     18.352006     -0.479596         -8.488748
# 3         LSTM_pred     70.872072     -0.092903         -4.432685
# 4          GRU_pred    150.951693      0.472630         -4.195281
# 5     LSTM_GRU_pred    110.310505      0.175725         -4.767807
# 6       BiLSTM_pred    141.176473      0.310714         -5.725837
# 7   BiLSTM_GRU_pred     26.474392     -0.302708         -8.245781
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     -8.981584     -0.762256         -9.302629
# 10         BNN_pred     54.118610     -0.186831         -5.270504
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    174.703503      0.540465         -5.325611
# 1             HV_dw     88.861567     -0.033863         -7.106176
# 2             HV_cw     14.760326     -0.412681         -9.278476
# 3         LSTM_pred     48.269183     -0.185030         -7.228822
# 4          GRU_pred    131.888374      0.269332         -7.638773
# 5     LSTM_GRU_pred    106.768770      0.139986         -6.523128
# 6       BiLSTM_pred    138.731256      0.280007         -7.813302
# 7   BiLSTM_GRU_pred     60.225155     -0.105456         -8.385072
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    153.029304      0.362344         -9.302629
# 10         BNN_pred     51.852438     -0.156987         -6.399884
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    153.317015      0.360578         -8.295517
# 1             HV_dw    218.251978      0.622343         -7.620182
# 2             HV_cw     72.834049     -0.081684         -9.035617
# 3         LSTM_pred     60.105155     -0.115306         -7.228822
# 4          GRU_pred    178.923742      0.495081         -7.907876
# 5     LSTM_GRU_pred    174.745498      0.478287         -8.212325
# 6       BiLSTM_pred    168.988651      0.389166         -7.840866
# 7   BiLSTM_GRU_pred    130.576054      0.241089         -7.374959
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    147.835056      0.321894         -9.302629
# 10         BNN_pred    122.974102      0.210978         -6.207199
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    119.914794      0.210224         -8.485144
# 1             HV_dw    213.936601      0.699142         -4.107235
# 2             HV_cw     65.672042     -0.100752         -8.488748
# 3         LSTM_pred    192.447317      0.599156         -3.729801
# 4          GRU_pred    245.549072      0.906516         -4.733476
# 5     LSTM_GRU_pred    169.973518      0.474921         -5.400654
# 6       BiLSTM_pred    162.853884      0.390707         -6.253463
# 7   BiLSTM_GRU_pred     13.815010     -0.329566         -8.021596
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     -8.981584     -0.762256         -9.302629
# 10         BNN_pred    105.519820      0.128840         -6.475643
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    143.547244      0.332633         -8.485144
# 1             HV_dw    291.130978      0.890113         -3.730980
# 2             HV_cw     56.131625     -0.123964         -8.488748
# 3         LSTM_pred    144.324932      0.289649         -8.135049
# 4          GRU_pred    262.984503      0.843235         -6.582078
# 5     LSTM_GRU_pred    190.545218      0.535435         -6.582078
# 6       BiLSTM_pred    241.563190      0.671293         -5.028481
# 7   BiLSTM_GRU_pred     41.695486     -0.170336         -9.374551
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    119.595871      0.192168         -9.302629
# 10         BNN_pred    129.000565      0.228301         -7.445020
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    188.107453      0.493057         -8.485144
# 1             HV_dw    359.099876      1.111178         -6.344729
# 2             HV_cw     90.414947      0.020598         -9.035617
# 3         LSTM_pred    157.245465      0.341419         -8.135049
# 4          GRU_pred    283.302509      0.895769         -8.684354
# 5     LSTM_GRU_pred    240.058117      0.733860         -8.684354
# 6       BiLSTM_pred    203.887731      0.503230         -7.010669
# 7   BiLSTM_GRU_pred    108.815285      0.136306         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    178.076618      0.432773         -9.302629
# 10         BNN_pred    170.730202      0.399401         -8.271795
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    119.914794      0.210224         -8.485144
# 1             HV_dw    145.048482      0.277855         -8.485144
# 2             HV_cw     74.193753     -0.033509        -10.580888
# 3         LSTM_pred    199.079027      0.454022         -9.302629
# 4          GRU_pred    200.123035      0.481345         -8.488748
# 5     LSTM_GRU_pred    195.423842      0.438217         -9.035617
# 6       BiLSTM_pred    165.496630      0.389098         -8.485144
# 7   BiLSTM_GRU_pred    186.281161      0.407617         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred     -3.900843     -0.762587         -9.302629
# 10         BNN_pred    163.194532      0.361294         -8.485144
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    143.547244      0.332633         -8.485144
# 1             HV_dw    149.994738      0.296631         -8.485144
# 2             HV_cw    129.055390      0.232859         -8.488748
# 3         LSTM_pred    222.169316      0.535665         -9.302629
# 4          GRU_pred    210.900137      0.534603         -8.485144
# 5     LSTM_GRU_pred    197.943356      0.488344         -8.485144
# 6       BiLSTM_pred    253.430484      0.680140         -8.485144
# 7   BiLSTM_GRU_pred    208.084995      0.485426         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    201.149807      0.461810         -9.302629
# 10         BNN_pred    192.692854      0.469349         -8.485144
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    167.826597      0.399161         -8.485144
# 1             HV_dw    246.769469      0.616737         -9.302629
# 2             HV_cw    127.660937      0.193974         -9.035617
# 3         LSTM_pred    235.968788      0.580680         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    210.900137      0.494792         -9.302629
# 6       BiLSTM_pred    253.911606      0.641752         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    199.557620      0.455949         -9.302629
# 10         BNN_pred    227.391052      0.552122         -9.302629
# 11               __    252.801107      0.637340         -9.302629

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    262.700213      0.675954         -8.115590
# 1             HV_dw    372.153270      1.075658         -8.588117
# 2             HV_cw    232.044047      0.575465         -9.564104
# 3         LSTM_pred    244.935530      0.610543         -9.302629
# 4          GRU_pred    250.992805      0.631124         -9.302629
# 5     LSTM_GRU_pred    241.508991      0.598681         -9.345933
# 6       BiLSTM_pred    244.935530      0.610543         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    274.826814      0.722860         -9.302629
# 10         BNN_pred    250.093988      0.620689         -9.989142
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    285.554857      0.791070         -5.632399
# 1             HV_dw    416.205076      1.294084         -7.318989
# 2             HV_cw    259.939870      0.688625         -7.080380
# 3         LSTM_pred    207.899762      0.494711         -9.843330
# 4          GRU_pred     92.516243      0.066743         -9.950207
# 5     LSTM_GRU_pred    170.940247      0.393624         -9.023480
# 6       BiLSTM_pred    171.119937      0.363027         -6.696292
# 7   BiLSTM_GRU_pred    261.243122      0.715880         -7.224647
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    181.982064      0.388600        -10.356511
# 10         BNN_pred    294.099258      0.818492         -6.544894
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    306.272754      0.969914         -5.694421
# 1             HV_dw    465.641692      1.505811         -5.583437
# 2             HV_cw    238.035132      0.740895         -5.667774
# 3         LSTM_pred     78.228494      0.017157         -8.485144
# 4          GRU_pred     68.677437     -0.040062        -10.908621
# 5     LSTM_GRU_pred    199.216341      0.520496         -8.814878
# 6       BiLSTM_pred    207.402042      0.565376         -5.972847
# 7   BiLSTM_GRU_pred    136.245646      0.297049         -6.909801
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    165.882340      0.367315         -8.890511
# 10         BNN_pred    218.725975      0.573214         -7.380390
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    305.422414      0.888348         -5.672861
# 1             HV_dw    382.818692      1.189711         -7.318989
# 2             HV_cw    228.250467      0.600147         -6.922808
# 3         LSTM_pred    222.422873      0.551288         -9.843330
# 4          GRU_pred     93.935833      0.072718         -9.904558
# 5     LSTM_GRU_pred    157.054570      0.338136         -9.101687
# 6       BiLSTM_pred    201.202767      0.481073         -6.528590
# 7   BiLSTM_GRU_pred    221.808865      0.627843         -5.336560
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    135.644918      0.204151        -10.015110
# 10         BNN_pred    312.724826      0.888057         -6.544894
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    254.240366      0.669059         -6.749600
# 1             HV_dw    383.129670      1.188780         -7.318989
# 2             HV_cw    280.501115      0.774808         -6.922808
# 3         LSTM_pred    207.899762      0.494711         -9.843330
# 4          GRU_pred     92.516243      0.066743         -9.950207
# 5     LSTM_GRU_pred    142.334931      0.276865         -9.218967
# 6       BiLSTM_pred    171.119937      0.363027         -6.696292
# 7   BiLSTM_GRU_pred    261.243122      0.715880         -7.224647
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    186.822079      0.409343        -10.546959
# 10         BNN_pred    309.771947      0.872428         -6.544894
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    312.073767      0.954962         -5.668320
# 1             HV_dw    378.010181      1.109525         -8.588117
# 2             HV_cw    208.783732      0.576482         -6.106159
# 3         LSTM_pred    186.195708      0.447537         -8.485144
# 4          GRU_pred    251.976820      0.643507         -9.302629
# 5     LSTM_GRU_pred    266.275304      0.698859         -8.065511
# 6       BiLSTM_pred    233.442803      0.611041         -8.485144
# 7   BiLSTM_GRU_pred    232.528829      0.608756         -8.485144
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    277.210583      0.775257         -8.962760
# 10         BNN_pred    159.314379      0.312911         -9.979668
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    336.474453      0.980438         -5.554551
# 1             HV_dw    382.797037      1.111813         -8.588117
# 2             HV_cw    217.558577      0.540133         -6.922808
# 3         LSTM_pred    240.593493      0.596193         -9.302629
# 4          GRU_pred    262.936370      0.673156         -9.302629
# 5     LSTM_GRU_pred    238.110193      0.588434         -9.345933
# 6       BiLSTM_pred    252.067161      0.635561         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    210.959719      0.496255        -10.365655
# 10         BNN_pred    246.571109      0.611294         -9.989142
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    265.302316      0.684969         -8.115590
# 1             HV_dw    372.153270      1.075658         -8.588117
# 2             HV_cw    226.653602      0.558036         -8.913724
# 3         LSTM_pred    244.935530      0.610543         -9.302629
# 4          GRU_pred    250.992805      0.631124         -9.302629
# 5     LSTM_GRU_pred    241.508991      0.598681         -9.345933
# 6       BiLSTM_pred    244.935530      0.610543         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    272.825383      0.715985         -9.302629
# 10         BNN_pred    257.255170      0.645859         -9.989142
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    224.361978      0.581165         -8.485144
# 1             HV_dw    219.650036      0.526433         -9.302629
# 2             HV_cw    224.361978      0.581165         -8.485144
# 3         LSTM_pred    211.122366      0.537800         -8.485144
# 4          GRU_pred    232.969959      0.572957         -9.302629
# 5     LSTM_GRU_pred    222.663009      0.537000         -9.302629
# 6       BiLSTM_pred    248.247694      0.661996         -8.485144
# 7   BiLSTM_GRU_pred    232.528829      0.608756         -8.485144
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    251.530870      0.642598         -8.890511
# 10         BNN_pred    197.668029      0.449971         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    225.931670      0.546964         -9.302629
# 1             HV_dw    252.801107      0.637340         -9.302629
# 2             HV_cw    225.931670      0.546964         -9.302629
# 3         LSTM_pred    255.484213      0.647058         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    246.769469      0.616737         -9.302629
# 6       BiLSTM_pred    259.977796      0.662362         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    233.128307      0.562936         -9.177845
# 10         BNN_pred    269.676026      0.696183         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    252.801107      0.637340         -9.302629
# 1             HV_dw    252.801107      0.637340         -9.302629
# 2             HV_cw    252.801107      0.637340         -9.302629
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    252.801107      0.637340         -9.302629
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.637340         -9.302629
# 10         BNN_pred    259.977796      0.662362         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    248.244242      0.622774         -8.765729
# 1             HV_dw    250.901289      0.643337         -8.588117
# 2             HV_cw    241.349677      0.607414         -8.436466
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    241.508991      0.598681         -9.345933
# 5     LSTM_GRU_pred    242.342672      0.601585         -9.345933
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    241.926265      0.608041         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    230.943502      0.569670         -9.302629
# 10         BNN_pred    262.937407      0.665225         -9.989142
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    330.762718      0.948313         -5.441058
# 1             HV_dw    325.262098      0.947264         -8.588117
# 2             HV_cw    261.008378      0.665134         -8.525080
# 3         LSTM_pred    249.505590      0.644916         -9.133077
# 4          GRU_pred     45.934546     -0.138063        -11.030617
# 5     LSTM_GRU_pred    198.186440      0.518675         -9.718979
# 6       BiLSTM_pred    182.697943      0.411434         -6.648852
# 7   BiLSTM_GRU_pred    221.081626      0.563675         -7.954278
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    190.879819      0.419229         -9.989142
# 10         BNN_pred    289.508037      0.786807         -8.303591
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    228.623864      0.654576         -6.053321
# 1             HV_dw    293.297073      0.849536         -8.588117
# 2             HV_cw    211.953963      0.548021         -5.565629
# 3         LSTM_pred    185.959277      0.498309         -6.794612
# 4          GRU_pred     85.419835      0.033119        -11.271401
# 5     LSTM_GRU_pred    212.466730      0.597762        -10.330999
# 6       BiLSTM_pred    234.419798      0.623836         -5.910880
# 7   BiLSTM_GRU_pred    145.792436      0.335727         -5.898323
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    148.459800      0.286944         -7.750812
# 10         BNN_pred    187.683187      0.439378         -8.013491
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    333.613871      0.991516         -5.566466
# 1             HV_dw    305.003524      0.884612         -8.588117
# 2             HV_cw    239.263491      0.628155         -5.865981
# 3         LSTM_pred    258.616791      0.678077         -9.133077
# 4          GRU_pred     34.529940     -0.190661        -11.115478
# 5     LSTM_GRU_pred    173.131517      0.419029        -10.058575
# 6       BiLSTM_pred    209.017715      0.513911         -6.529468
# 7   BiLSTM_GRU_pred    140.434035      0.260046         -7.954278
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    170.034561      0.345787         -8.890511
# 10         BNN_pred    298.042117      0.821306         -8.303591
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    248.482085      0.642691         -9.766839
# 1             HV_dw    305.503745      0.880841         -8.588117
# 2             HV_cw    287.566486      0.775866         -5.640843
# 3         LSTM_pred    249.505590      0.644916         -9.133077
# 4          GRU_pred     37.793981     -0.175037        -11.080518
# 5     LSTM_GRU_pred    197.260398      0.514898         -9.726497
# 6       BiLSTM_pred    182.697943      0.411434         -6.648852
# 7   BiLSTM_GRU_pred    221.659664      0.569072         -7.954278
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    276.127636      0.748115         -8.485144
# 10         BNN_pred    304.220676      0.839606         -8.303591
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    288.313528      0.834694         -5.748213
# 1             HV_dw    253.269008      0.655952         -8.588117
# 2             HV_cw    222.368550      0.572317         -5.892366
# 3         LSTM_pred    213.003310      0.542913         -8.485144
# 4          GRU_pred    291.169435      0.778472         -8.065511
# 5     LSTM_GRU_pred    282.912614      0.751281         -8.065511
# 6       BiLSTM_pred    253.430484      0.680140         -8.485144
# 7   BiLSTM_GRU_pred    161.597578      0.360044         -8.485144
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    197.067029      0.486054         -7.983828
# 10         BNN_pred    181.319228      0.395751        -10.084399
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    302.196775      0.850405         -5.676423
# 1             HV_dw    261.508794      0.681899         -8.588117
# 2             HV_cw    233.952977      0.643442         -6.106159
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    245.202726      0.613519         -9.345933
# 5     LSTM_GRU_pred    274.992747      0.720702         -8.065511
# 6       BiLSTM_pred    259.977796      0.662362         -9.302629
# 7   BiLSTM_GRU_pred    199.669404      0.459755         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    198.832356      0.472245         -8.890511
# 10         BNN_pred    279.948860      0.724534         -9.989142
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    234.552476      0.576201         -9.766462
# 1             HV_dw    250.438409      0.641702         -8.588117
# 2             HV_cw    228.790703      0.568354         -7.156602
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    253.362011      0.640677         -9.345933
# 5     LSTM_GRU_pred    254.203652      0.643588         -9.345933
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    248.107091      0.630564         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    226.453426      0.596507         -8.485144
# 10         BNN_pred    270.172162      0.690440         -9.989142
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    210.621049      0.518046         -8.488748
# 1             HV_dw    246.769469      0.616737         -9.302629
# 2             HV_cw    209.528509      0.493873         -8.890511
# 3         LSTM_pred    213.003310      0.542913         -8.485144
# 4          GRU_pred    246.699752      0.616975         -9.302629
# 5     LSTM_GRU_pred    236.278028      0.581355         -9.302629
# 6       BiLSTM_pred    253.430484      0.680140         -8.485144
# 7   BiLSTM_GRU_pred    232.528829      0.608756         -8.485144
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    219.043655      0.524747         -9.035617
# 10         BNN_pred    194.791149      0.439415         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    225.931670      0.546964         -9.302629
# 1             HV_dw    252.801107      0.637340         -9.302629
# 2             HV_cw    224.361978      0.581165         -8.485144
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.356640      0.636404         -9.302629
# 5     LSTM_GRU_pred    246.769469      0.616737         -9.302629
# 6       BiLSTM_pred    259.977796      0.662362         -9.302629
# 7   BiLSTM_GRU_pred    248.333119      0.622043         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    232.821579      0.575711         -8.890511
# 10         BNN_pred    269.676026      0.696183         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    252.801107      0.637340         -9.302629
# 1             HV_dw    252.801107      0.637340         -9.302629
# 2             HV_cw    227.391052      0.552122         -9.302629
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    252.801107      0.637340         -9.302629
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.676986         -8.485144
# 10         BNN_pred    259.977796      0.662362         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    220.350861      0.545479         -9.302629
# 1             HV_dw    364.106737      1.076008         -8.588117
# 2             HV_cw    289.243897      0.767577         -8.275088
# 3         LSTM_pred    246.640998      0.654063         -9.133077
# 4          GRU_pred    145.496211      0.305763         -8.213050
# 5     LSTM_GRU_pred    224.248647      0.614763         -7.657780
# 6       BiLSTM_pred    208.602520      0.509742         -6.354654
# 7   BiLSTM_GRU_pred    293.287006      0.806771         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    236.545990      0.619990         -7.664771
# 10         BNN_pred    346.613862      1.021918         -9.985597
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    241.520458      0.628410         -8.446027
# 1             HV_dw    405.426112      1.265375         -7.363240
# 2             HV_cw    301.871173      0.868085         -7.661134
# 3         LSTM_pred    241.468888      0.674276         -7.160860
# 4          GRU_pred    145.814005      0.299808         -7.933985
# 5     LSTM_GRU_pred    324.735342      1.035590         -4.356508
# 6       BiLSTM_pred    160.007271      0.339153         -8.651395
# 7   BiLSTM_GRU_pred    305.141476      0.912825         -6.604071
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    194.625276      0.442864         -7.661134
# 10         BNN_pred    226.973032      0.612809         -5.893851
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    182.930588      0.563970         -6.695987
# 1             HV_dw    313.623963      1.115454         -3.730980
# 2             HV_cw    101.322624      0.116924         -6.874815
# 3         LSTM_pred     57.809135     -0.198303         -7.705405
# 4          GRU_pred    186.017700      0.531260         -7.270496
# 5     LSTM_GRU_pred    161.271556      0.455799         -4.349827
# 6       BiLSTM_pred    165.510705      0.423896         -6.317463
# 7   BiLSTM_GRU_pred    163.410165      0.505527         -7.849094
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     96.774826      0.084884         -7.218944
# 10         BNN_pred    143.094988      0.372014         -5.944967
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    217.227851      0.717875         -5.325611
# 1             HV_dw    368.814889      1.181722         -7.363240
# 2             HV_cw    212.041452      0.716731         -6.983330
# 3         LSTM_pred    185.194860      0.507347         -6.489022
# 4          GRU_pred    180.478406      0.481966         -6.094221
# 5     LSTM_GRU_pred    287.394011      1.018818         -4.349827
# 6       BiLSTM_pred    232.311379      0.668891         -7.472690
# 7   BiLSTM_GRU_pred    203.723935      0.626465         -5.278117
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    150.627237      0.370556         -7.753554
# 10         BNN_pred    140.856669      0.324657         -5.620099
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    213.366087      0.621019         -6.771430
# 1             HV_dw    389.364617      1.225701         -7.363240
# 2             HV_cw    311.352925      0.986379         -5.505330
# 3         LSTM_pred    225.551222      0.606135         -7.370406
# 4          GRU_pred    172.879570      0.417624         -8.008802
# 5     LSTM_GRU_pred    264.146053      0.863355         -6.020586
# 6       BiLSTM_pred    168.899008      0.372189         -8.651395
# 7   BiLSTM_GRU_pred    331.745578      1.038492         -6.604071
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    206.247521      0.566887         -7.532242
# 10         BNN_pred    267.132071      0.784250         -5.596127
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    126.386770      0.244521         -8.485144
# 1             HV_dw    223.233196      0.641432         -8.092734
# 2             HV_cw    173.026387      0.486217         -5.765053
# 3         LSTM_pred     41.195499     -0.232929         -7.229179
# 4          GRU_pred    148.005653      0.330564        -11.038949
# 5     LSTM_GRU_pred    136.593929      0.278091        -11.097696
# 6       BiLSTM_pred    243.651299      0.674644         -5.324724
# 7   BiLSTM_GRU_pred    186.788641      0.475610         -9.617039
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    183.450194      0.452886         -7.121890
# 10         BNN_pred    223.506298      0.640181        -12.044164
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    159.841089      0.408131         -8.485144
# 1             HV_dw    351.736667      1.058442         -8.588117
# 2             HV_cw    212.720108      0.654216         -6.943868
# 3         LSTM_pred    136.819627      0.238502         -8.314064
# 4          GRU_pred    145.860064      0.309242         -8.176743
# 5     LSTM_GRU_pred    274.381831      0.827746         -6.442815
# 6       BiLSTM_pred    270.263501      0.756024         -4.940095
# 7   BiLSTM_GRU_pred    235.843907      0.677621         -8.485144
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    261.277350      0.744452         -5.643936
# 10         BNN_pred    246.815107      0.695450        -11.123498
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    167.826597      0.416789         -8.485144
# 1             HV_dw    355.849190      1.059039         -8.588117
# 2             HV_cw    258.049735      0.737703         -6.336290
# 3         LSTM_pred    249.220353      0.659844         -9.133077
# 4          GRU_pred    144.845258      0.304342         -8.183991
# 5     LSTM_GRU_pred    247.076587      0.709881         -7.517603
# 6       BiLSTM_pred    210.376196      0.510296         -6.354654
# 7   BiLSTM_GRU_pred    333.195719      0.957816         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    261.227682      0.744265         -5.643936
# 10         BNN_pred    340.637173      1.005502         -9.700818
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    126.386770      0.244521         -8.485144
# 1             HV_dw    159.944118      0.350445         -8.485144
# 2             HV_cw     85.576336      0.030761        -10.496231
# 3         LSTM_pred    134.405552      0.240583         -9.350620
# 4          GRU_pred    241.887628      0.600815         -9.302629
# 5     LSTM_GRU_pred    152.957790      0.286474         -9.846310
# 6       BiLSTM_pred    211.289266      0.535941         -8.485144
# 7   BiLSTM_GRU_pred    232.528829      0.593744         -8.488748
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    183.450194      0.452886         -7.121890
# 10         BNN_pred    192.935117      0.433380         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    159.841089      0.408131         -8.485144
# 1             HV_dw    246.769469      0.616737         -9.302629
# 2             HV_cw    127.660937      0.193974         -9.035617
# 3         LSTM_pred    232.528829      0.608756         -8.485144
# 4          GRU_pred    252.356640      0.636404         -9.302629
# 5     LSTM_GRU_pred    241.887628      0.600815         -9.302629
# 6       BiLSTM_pred    248.247694      0.661996         -8.485144
# 7   BiLSTM_GRU_pred    238.491574      0.629478         -8.485144
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    261.277350      0.744452         -5.643936
# 10         BNN_pred    221.751941      0.534335         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    167.826597      0.416789         -8.485144
# 1             HV_dw    252.801107      0.637340         -9.302629
# 2             HV_cw    246.769469      0.615181         -9.035617
# 3         LSTM_pred    248.333119      0.622043         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    252.801107      0.637340         -9.302629
# 6       BiLSTM_pred    259.977796      0.662362         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    261.277350      0.744265         -5.643936
# 10         BNN_pred    259.977796      0.662362         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    245.869572      0.622688        -10.128959
# 1             HV_dw    305.953189      0.892667         -8.588117
# 2             HV_cw    227.525242      0.570745         -6.334194
# 3         LSTM_pred    242.780407      0.643401         -9.265691
# 4          GRU_pred    145.496211      0.305763         -8.213050
# 5     LSTM_GRU_pred    188.744362      0.488670         -8.273986
# 6       BiLSTM_pred    178.474602      0.401544         -7.381833
# 7   BiLSTM_GRU_pred    318.764185      0.943397         -7.334092
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    231.046644      0.569101         -7.661134
# 10         BNN_pred    257.458400      0.740577        -10.511597
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    209.387730      0.509953         -9.942738
# 1             HV_dw    241.338626      0.672343         -7.318989
# 2             HV_cw    231.350106      0.617735         -7.661134
# 3         LSTM_pred    195.644411      0.493383         -7.160860
# 4          GRU_pred     90.000846      0.051363        -11.860692
# 5     LSTM_GRU_pred    256.368188      0.774121         -7.013862
# 6       BiLSTM_pred    151.861533      0.311863        -11.231734
# 7   BiLSTM_GRU_pred    256.778958      0.717167         -6.604071
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    182.363364      0.418083         -7.661134
# 10         BNN_pred    148.692789      0.275072         -6.767934
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     82.693766     -0.008112         -6.943868
# 1             HV_dw    264.352470      0.953438         -3.730980
# 2             HV_cw    100.163865      0.117834         -6.856671
# 3         LSTM_pred     77.049821     -0.081794         -4.327322
# 4          GRU_pred    149.868075      0.368144         -8.944969
# 5     LSTM_GRU_pred    136.666133      0.341371         -5.920395
# 6       BiLSTM_pred    141.176473      0.310714         -5.725837
# 7   BiLSTM_GRU_pred    121.610665      0.186183         -8.114319
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     65.730359     -0.121498         -5.239552
# 10         BNN_pred     51.333388     -0.229418         -6.199114
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    174.703503      0.540465         -5.325611
# 1             HV_dw    203.522227      0.572546         -6.344729
# 2             HV_cw    161.850124      0.487804         -6.272059
# 3         LSTM_pred    196.166348      0.588442         -6.337635
# 4          GRU_pred    162.946928      0.435417         -8.126559
# 5     LSTM_GRU_pred    218.031511      0.749562         -5.748075
# 6       BiLSTM_pred    138.731256      0.280007         -7.813302
# 7   BiLSTM_GRU_pred    152.981003      0.358724         -6.729559
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    159.920684      0.443487         -5.787466
# 10         BNN_pred     88.958547      0.038744         -7.475200
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    153.317015      0.360578         -8.295517
# 1             HV_dw    225.518626      0.621181         -7.363240
# 2             HV_cw    282.589066      0.963643         -6.126737
# 3         LSTM_pred    113.108445      0.133612         -6.625793
# 4          GRU_pred     64.594910     -0.071966        -11.905529
# 5     LSTM_GRU_pred    272.244418      0.955452         -4.201351
# 6       BiLSTM_pred    168.988651      0.389166         -7.840866
# 7   BiLSTM_GRU_pred    227.251136      0.702103         -4.479225
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    174.729365      0.483277         -5.143693
# 10         BNN_pred    160.941748      0.364594         -6.432988
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    119.914794      0.210224         -8.485144
# 1             HV_dw    239.895875      0.752354         -6.794612
# 2             HV_cw    104.190763      0.129343         -6.463150
# 3         LSTM_pred     38.216236     -0.252096         -7.249923
# 4          GRU_pred    148.005653      0.330564        -11.038949
# 5     LSTM_GRU_pred    131.519887      0.270533        -10.447120
# 6       BiLSTM_pred    162.853884      0.390707         -6.253463
# 7   BiLSTM_GRU_pred    240.242156      0.895296         -5.466768
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    197.536395      0.536288         -7.061478
# 10         BNN_pred     56.504581     -0.147904        -10.647988
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    143.547244      0.332633         -8.485144
# 1             HV_dw    248.100079      0.727792         -7.930717
# 2             HV_cw    201.473385      0.641774         -6.187074
# 3         LSTM_pred    177.626500      0.425840         -6.794612
# 4          GRU_pred    187.905592      0.511152         -9.217052
# 5     LSTM_GRU_pred    250.287195      0.797807         -9.131207
# 6       BiLSTM_pred    241.563190      0.671293         -5.028481
# 7   BiLSTM_GRU_pred    282.426610      0.983266         -5.364531
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    253.325905      0.758180         -5.602239
# 10         BNN_pred     96.951200      0.084694        -11.234655
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    188.107453      0.493057         -8.485144
# 1             HV_dw    289.676557      0.851340         -8.588117
# 2             HV_cw    281.660559      0.885633         -6.605276
# 3         LSTM_pred    164.320474      0.361576         -8.314064
# 4          GRU_pred    144.845258      0.304342         -8.183991
# 5     LSTM_GRU_pred    258.341557      0.795409         -7.920321
# 6       BiLSTM_pred    203.887731      0.503230         -7.010669
# 7   BiLSTM_GRU_pred    316.233485      1.051678         -5.306636
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    275.540279      0.838128         -5.895985
# 10         BNN_pred    178.029788      0.464737         -9.747798
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    119.914794      0.210224         -8.485144
# 1             HV_dw    159.944118      0.350445         -8.485144
# 2             HV_cw     88.262720      0.040797        -10.496231
# 3         LSTM_pred    132.998785      0.234863         -9.362230
# 4          GRU_pred    241.887628      0.600815         -9.302629
# 5     LSTM_GRU_pred    165.876547      0.337051         -9.302629
# 6       BiLSTM_pred    165.496630      0.389098         -8.485144
# 7   BiLSTM_GRU_pred    205.719155      0.502395         -8.488748
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    188.363941      0.473149         -6.759605
# 10         BNN_pred     99.475913      0.071649         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    143.547244      0.332633         -8.485144
# 1             HV_dw    246.769469      0.616737         -9.302629
# 2             HV_cw    141.435236      0.255553         -9.035617
# 3         LSTM_pred    239.589389      0.633911         -8.485144
# 4          GRU_pred    241.887628      0.600815         -9.302629
# 5     LSTM_GRU_pred    236.278028      0.581355         -9.302629
# 6       BiLSTM_pred    253.430484      0.680140         -8.485144
# 7   BiLSTM_GRU_pred    232.528829      0.608756         -8.485144
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    243.726135      0.684059         -5.464427
# 10         BNN_pred    194.791149      0.439415         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    167.826597      0.399161         -8.485144
# 1             HV_dw    252.801107      0.637340         -9.302629
# 2             HV_cw    196.621938      0.441023         -9.035617
# 3         LSTM_pred    232.528829      0.608756         -8.485144
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    246.769469      0.616737         -9.302629
# 6       BiLSTM_pred    253.911606      0.641752         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.676986         -8.485144
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    261.277350      0.744452         -5.643936
# 10         BNN_pred    249.984023      0.630273         -9.302629
# 11               __    252.801107      0.637340         -9.302629

# %%
# path_1 = '/content/drive/MyDrive/Strategy/MA/HV/HV/'
# path_2 = '/content/drive/MyDrive/Strategy/MA/HV/DW_HV/'
# path_3 = '/content/drive/MyDrive/Strategy/MA/HV/CW_HV/'

# file_name = 'file_1.csv'
# file.to_csv(path_1 + file_name)

# filename = 'file_1.csv'
# dw_file.to_csv(path_2 + file_name)

# filename = 'file_1.csv'
# cw_file.to_csv(path_3 + file_name)
