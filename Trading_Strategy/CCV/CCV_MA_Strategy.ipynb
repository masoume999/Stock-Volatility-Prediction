# %%
import pandas as pd
import numpy as np
import yfinance as yf
from google.colab import drive
from datetime import datetime
import matplotlib.pyplot as plt
import builtins

# %% [markdown]
# # Loading data

# %%
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Volatility/'
path_1 = '/content/drive/MyDrive/Volatility/Predictions/CCV/'
path_2 = '/content/drive/MyDrive/Volatility/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/Not_normal_wc_real/'

def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

filename = 'CCV_data.csv'
CCV_dw = pd.read_csv(path_2 + filename)

filename = 'CCV_data.csv'
CCV_cw = pd.read_csv(path_3 + filename)

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path_1 + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path_1 + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path_1 + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path_1 + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path_1 + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(CCV_dw)
set_index(CCV_cw)

start = datetime(2020, 11, 5)
end = datetime(2022, 12, 23)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")

data_s['Close'] = ticker_historical.Close.values

start = datetime(2020, 10, 1)
end = datetime(2022, 12, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")

data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['CCV'] = volatility_proxies['CCV'].loc['2020-10-01':'2022-12-30'].values
data_s['CCV'] = volatility_proxies['CCV'].loc['2020-11-05':'2022-12-22'].values

data_l['CCV_dw'] = CCV_dw['CCV'].loc['2020-10-01':'2022-12-30'].values
data_s['CCV_dw'] = CCV_dw['CCV'].loc['2020-11-05':'2022-12-22'].values

data_l['CCV_cw'] = CCV_cw['CCV'].loc['2020-10-01':'2022-12-30'].values
data_s['CCV_cw'] = CCV_cw['CCV'].loc['2020-11-05':'2022-12-22'].values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2020-11-05':'2022-12-22']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2020-11-05':'2022-12-22']

data_2022_y1 = data_s.head(268)
data_2022_y2 = data_s.tail(269)
data_2022_2y = data_s
# Out:
# Mounted at /content/drive
# <ipython-input-2-36c97740868c>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %%
path_1 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/'
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/CCV/'
path_2 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
path_4 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/'

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path_1 + filename)

filename = 'CCV_data.csv'
CCV_dw = pd.read_csv(path_2 + filename)

filename = 'CCV_data.csv'
CCV_cw = pd.read_csv(path_3 + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path_4 + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path_4 + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(CCV_dw)
set_index(CCV_cw)

start = datetime(2022, 7, 14)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")
data_s['Close'] = ticker_historical.Close.values

start = datetime(2022, 5, 31)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")
data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['CCV'] = (volatility_proxies['CCV'].loc['2022-05-31':'2024-8-30']).values
data_s['CCV'] = (volatility_proxies['CCV'].loc['2022-07-14':'2024-8-30']).values

data_l['CCV_dw'] = (CCV_dw['CCV'].loc['2022-05-31':'2024-8-30']).values
data_s['CCV_dw'] = (CCV_dw['CCV'].loc['2022-07-14':'2024-8-30']).values

data_l['CCV_cw'] = (CCV_cw['CCV'].loc['2022-05-31':'2024-8-30']).values
data_s['CCV_cw'] = (CCV_cw['CCV'].loc['2022-07-14':'2024-8-30']).values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2022-07-14':'2024-8-30']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2022-07-14':'2024-8-30']

data_2024_y1 = data_s.head(268)
data_2024_y2 = data_s.tail(269)
data_2024_2y1 = data_s
# Out:
# <ipython-input-2-36c97740868c>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %% [markdown]
# # Strategy

# %% [markdown]
# ## Without volatility

# %%
def strategy(data, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0

  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# ## With volatility

# %%
def strategy_with_vol_1(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_2(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_3(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_4(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_5(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_6(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_7(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_8(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_9(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_10(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_11(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_12(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_13(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_14(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_15(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_16(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_17(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_18(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_19(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_20(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_21(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_22(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_23(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_24(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_25(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_26(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_27(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_28(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_29(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_30(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_31(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_32(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_33(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_34(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_35(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_36(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_37(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_38(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_39(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_40(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_41(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_42(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_43(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_44(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# # Backtest

# %%
def backtest_function(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, data_f[vol], short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
def backtest_function_abs(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, abs(data_f[vol]), short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
volatility = ['CCV', 'CCV_dw', 'CCV_cw', 'LSTM_pred', 'GRU_pred', 'LSTM_GRU_pred', 'BiLSTM_pred',
              'BiLSTM_GRU_pred', 'QRNN_pred', 'ESN_pred', 'BNN_pred']

# %%
def backtest(data_s, short_window=5, long_window=20):
  S1_results = backtest_function(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results = backtest_function(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results = backtest_function(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results = backtest_function(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results = backtest_function(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results = backtest_function(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results = backtest_function(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results = backtest_function(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results = backtest_function(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results = backtest_function(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results = backtest_function(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results = backtest_function(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results = backtest_function(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results = backtest_function(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results = backtest_function(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results = backtest_function(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results = backtest_function(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results = backtest_function(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results = backtest_function(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results = backtest_function(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results = backtest_function(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results = backtest_function(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results = backtest_function(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results = backtest_function(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results = backtest_function(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results = backtest_function(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results = backtest_function(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results = backtest_function(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results = backtest_function(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results = backtest_function(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results = backtest_function(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results = backtest_function(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results = backtest_function(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results = backtest_function(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results = backtest_function(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results = backtest_function(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results = backtest_function(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results = backtest_function(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results = backtest_function(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results = backtest_function(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results = backtest_function(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results = backtest_function(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results = backtest_function(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results = backtest_function(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results.loc[len(S1_results)] = new_row
  S2_results.loc[len(S2_results)] = new_row
  S3_results.loc[len(S3_results)] = new_row
  S4_results.loc[len(S4_results)] = new_row
  S5_results.loc[len(S5_results)] = new_row
  S6_results.loc[len(S6_results)] = new_row
  S7_results.loc[len(S7_results)] = new_row
  S8_results.loc[len(S8_results)] = new_row
  S9_results.loc[len(S9_results)] = new_row
  S10_results.loc[len(S10_results)] = new_row
  S11_results.loc[len(S11_results)] = new_row
  S12_results.loc[len(S12_results)] = new_row
  S13_results.loc[len(S13_results)] = new_row
  S14_results.loc[len(S14_results)] = new_row
  S15_results.loc[len(S15_results)] = new_row
  S16_results.loc[len(S16_results)] = new_row
  S17_results.loc[len(S17_results)] = new_row
  S18_results.loc[len(S18_results)] = new_row
  S19_results.loc[len(S19_results)] = new_row
  S20_results.loc[len(S20_results)] = new_row
  S21_results.loc[len(S21_results)] = new_row
  S22_results.loc[len(S22_results)] = new_row

  S23_results.loc[len(S23_results)] = new_row
  S24_results.loc[len(S24_results)] = new_row
  S25_results.loc[len(S25_results)] = new_row
  S26_results.loc[len(S26_results)] = new_row
  S27_results.loc[len(S27_results)] = new_row
  S28_results.loc[len(S28_results)] = new_row
  S29_results.loc[len(S29_results)] = new_row
  S30_results.loc[len(S30_results)] = new_row
  S31_results.loc[len(S31_results)] = new_row
  S32_results.loc[len(S32_results)] = new_row
  S33_results.loc[len(S33_results)] = new_row
  S34_results.loc[len(S34_results)] = new_row
  S35_results.loc[len(S35_results)] = new_row
  S36_results.loc[len(S36_results)] = new_row
  S37_results.loc[len(S37_results)] = new_row
  S38_results.loc[len(S38_results)] = new_row
  S39_results.loc[len(S39_results)] = new_row
  S40_results.loc[len(S40_results)] = new_row
  S41_results.loc[len(S41_results)] = new_row
  S42_results.loc[len(S42_results)] = new_row
  S43_results.loc[len(S43_results)] = new_row
  S44_results.loc[len(S44_results)] = new_row

  return S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results

# %%
def backtest_abs(data_s, short_window=5, long_window=20):
  S1_results_abs = backtest_function_abs(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results_abs = backtest_function_abs(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results_abs = backtest_function_abs(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results_abs = backtest_function_abs(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results_abs = backtest_function_abs(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results_abs = backtest_function_abs(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results_abs = backtest_function_abs(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results_abs = backtest_function_abs(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results_abs = backtest_function_abs(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results_abs = backtest_function_abs(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results_abs = backtest_function_abs(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results_abs = backtest_function_abs(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results_abs = backtest_function_abs(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results_abs = backtest_function_abs(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results_abs = backtest_function_abs(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results_abs = backtest_function_abs(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results_abs = backtest_function_abs(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results_abs = backtest_function_abs(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results_abs = backtest_function_abs(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results_abs = backtest_function_abs(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results_abs = backtest_function_abs(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results_abs = backtest_function_abs(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results_abs = backtest_function_abs(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results_abs = backtest_function_abs(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results_abs = backtest_function_abs(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results_abs = backtest_function_abs(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results_abs = backtest_function_abs(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results_abs = backtest_function_abs(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results_abs = backtest_function_abs(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results_abs = backtest_function_abs(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results_abs = backtest_function_abs(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results_abs = backtest_function_abs(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results_abs = backtest_function_abs(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results_abs = backtest_function_abs(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results_abs = backtest_function_abs(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results_abs = backtest_function_abs(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results_abs = backtest_function_abs(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results_abs = backtest_function_abs(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results_abs = backtest_function_abs(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results_abs = backtest_function_abs(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results_abs = backtest_function_abs(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results_abs = backtest_function_abs(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results_abs = backtest_function_abs(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results_abs = backtest_function_abs(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results_abs.loc[len(S1_results_abs)] = new_row
  S2_results_abs.loc[len(S2_results_abs)] = new_row
  S3_results_abs.loc[len(S3_results_abs)] = new_row
  S4_results_abs.loc[len(S4_results_abs)] = new_row
  S5_results_abs.loc[len(S5_results_abs)] = new_row
  S6_results_abs.loc[len(S6_results_abs)] = new_row
  S7_results_abs.loc[len(S7_results_abs)] = new_row
  S8_results_abs.loc[len(S8_results_abs)] = new_row
  S9_results_abs.loc[len(S9_results_abs)] = new_row
  S10_results_abs.loc[len(S10_results_abs)] = new_row
  S11_results_abs.loc[len(S11_results_abs)] = new_row
  S12_results_abs.loc[len(S12_results_abs)] = new_row
  S13_results_abs.loc[len(S13_results_abs)] = new_row
  S14_results_abs.loc[len(S14_results_abs)] = new_row
  S15_results_abs.loc[len(S15_results_abs)] = new_row
  S16_results_abs.loc[len(S16_results_abs)] = new_row
  S17_results_abs.loc[len(S17_results_abs)] = new_row
  S18_results_abs.loc[len(S18_results_abs)] = new_row
  S19_results_abs.loc[len(S19_results_abs)] = new_row
  S20_results_abs.loc[len(S20_results_abs)] = new_row
  S21_results_abs.loc[len(S21_results_abs)] = new_row
  S22_results_abs.loc[len(S22_results_abs)] = new_row

  S23_results_abs.loc[len(S23_results_abs)] = new_row
  S24_results_abs.loc[len(S24_results_abs)] = new_row
  S25_results_abs.loc[len(S25_results_abs)] = new_row
  S26_results_abs.loc[len(S26_results_abs)] = new_row
  S27_results_abs.loc[len(S27_results_abs)] = new_row
  S28_results_abs.loc[len(S28_results_abs)] = new_row
  S29_results_abs.loc[len(S29_results_abs)] = new_row
  S30_results_abs.loc[len(S30_results_abs)] = new_row
  S31_results_abs.loc[len(S31_results_abs)] = new_row
  S32_results_abs.loc[len(S32_results_abs)] = new_row
  S33_results_abs.loc[len(S33_results_abs)] = new_row
  S34_results_abs.loc[len(S34_results_abs)] = new_row
  S35_results_abs.loc[len(S35_results_abs)] = new_row
  S36_results_abs.loc[len(S36_results_abs)] = new_row
  S37_results_abs.loc[len(S37_results_abs)] = new_row
  S38_results_abs.loc[len(S38_results_abs)] = new_row
  S39_results_abs.loc[len(S39_results_abs)] = new_row
  S40_results_abs.loc[len(S40_results_abs)] = new_row
  S41_results_abs.loc[len(S41_results_abs)] = new_row
  S42_results_abs.loc[len(S42_results_abs)] = new_row
  S43_results_abs.loc[len(S43_results_abs)] = new_row
  S44_results_abs.loc[len(S44_results_abs)] = new_row

  return S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs

# %% [markdown]
# # Final Results

# %%
def check_strategy(data, CCV):

    sharpe_ratio_CCV = data.loc[data['Volatility'] == CCV, 'Sharpe ratio'].values[0]
    sharpe_ratio_pure = data.loc[data['Volatility'] == '__', 'Sharpe ratio'].values[0]

    max_drawdown_CCV = data.loc[data['Volatility'] == CCV, 'Max drawdown (%)'].values[0]
    max_drawdown_pure = data.loc[data['Volatility'] == '__', 'Max drawdown (%)'].values[0]

    total_profit_CCV = data.loc[data['Volatility'] == CCV, 'Total profit'].values[0]
    total_profit_pure = data.loc[data['Volatility'] == '__', 'Total profit'].values[0]

    is_CCV_sharpe_positive = sharpe_ratio_CCV > 0
    is_CCV_sharpe_greater_than_pure_sharpe = sharpe_ratio_CCV > sharpe_ratio_pure
    is_CCV_dd_greater_than_pure_dd = max_drawdown_CCV > max_drawdown_pure
    is_pure_tp_greater_than_CCV_tp = total_profit_pure > total_profit_CCV

    all_sharpes_greater_than_Pure_sharpe = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'CCV') & (data['Volatility'] != 'CCV_dw') & (data['Volatility'] != 'CCV_cw'), 'Sharpe ratio'] > sharpe_ratio_pure)
    all_sharpes_greater_than_Pure_sharpe_percentage = (all_sharpes_greater_than_Pure_sharpe.sum()/8) * 100

    positive_sharpes = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'CCV') & (data['Volatility'] != 'CCV_dw') & (data['Volatility'] != 'CCV_cw'), 'Sharpe ratio'] > 0)
    positive_sharpes_percentage = (positive_sharpes.sum()/8) * 100

    CCV_sharpe_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'CCV') & (data['Volatility'] != 'CCV_dw') & (data['Volatility'] != 'CCV_cw'), 'Sharpe ratio'] < sharpe_ratio_CCV)
    CCV_sharpe_greater_than_all_percentage = (CCV_sharpe_greater_than_all.sum()/8) * 100

    CCV_dd_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'CCV') & (data['Volatility'] != 'CCV_dw') & (data['Volatility'] != 'CCV_cw'), 'Max drawdown (%)'] < max_drawdown_CCV)
    CCV_dd_greater_than_all_percentage = (CCV_dd_greater_than_all.sum()/8) * 100

    CCV_tp_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'CCV') & (data['Volatility'] != 'CCV_dw') & (data['Volatility'] != 'CCV_cw'), 'Total profit'] < total_profit_CCV)
    CCV_tp_greater_than_all_percentage = (CCV_tp_greater_than_all.sum()/8) * 100

    return is_CCV_sharpe_positive, is_CCV_sharpe_greater_than_pure_sharpe, is_CCV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, CCV_sharpe_greater_than_all_percentage, CCV_dd_greater_than_all_percentage, CCV_tp_greater_than_all_percentage

# %%
def get_final_results(year, final_results, CCV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results[f'S{i}_results']

    if(CCV == 'CCV'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV_dw', 'CCV_cw'])]

    elif(CCV == 'CCV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV', 'CCV_cw'])]

    elif(CCV == 'CCV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV_dw', 'CCV'])]

    is_CCV_sharpe_positive, is_CCV_sharpe_greater_than_pure_sharpe, is_CCV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, CCV_sharpe_greater_than_all_percentage, CCV_dd_greater_than_all_percentage, CCV_tp_greater_than_all_percentage = check_strategy(strategy_result, CCV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '-',
                'CCV_sharpe > 0': is_CCV_sharpe_positive,
                'CCV_sharpe > Pure_sharpe': is_CCV_sharpe_greater_than_pure_sharpe,
                'CCV_dd > Pure_dd': is_CCV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'CCV_sharpe > Pred_sharpe (%)': CCV_sharpe_greater_than_all_percentage,
                'CCV_dd > Pred_dd (%)': CCV_dd_greater_than_all_percentage,
                'CCV_tp > Pred_tp (%)': CCV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
def get_final_results_1(year, final_results, CCV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results_abs[f'S{i}_results_abs']

    if(CCV == 'CCV'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV_dw', 'CCV_cw'])]
      # res_combined
      # res_combined = pd.concat(details, strategy_result.drop())

    elif(CCV == 'CCV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV', 'CCV_cw'])]

    elif(CCV == 'CCV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV_dw', 'CCV'])]

    is_CCV_sharpe_positive, is_CCV_sharpe_greater_than_pure_sharpe, is_CCV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, CCV_sharpe_greater_than_all_percentage, CCV_dd_greater_than_all_percentage, CCV_tp_greater_than_all_percentage = check_strategy(strategy_result, CCV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '+',
                'CCV_sharpe > 0': is_CCV_sharpe_positive,
                'CCV_sharpe > Pure_sharpe': is_CCV_sharpe_greater_than_pure_sharpe,
                'CCV_dd > Pure_dd': is_CCV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'CCV_sharpe > Pred_sharpe (%)': CCV_sharpe_greater_than_all_percentage,
                'CCV_dd > Pred_dd (%)': CCV_dd_greater_than_all_percentage,
                'CCV_tp > Pred_tp (%)': CCV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'CCV_sharpe > 0', 'CCV_sharpe > Pure_sharpe',
                                              'CCV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'CCV_sharpe > Pred_sharpe (%)',
                                              'CCV_dd > Pred_dd (%)', 'CCV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

dw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'CCV_sharpe > 0', 'CCV_sharpe > Pure_sharpe',
                                              'CCV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'CCV_sharpe > Pred_sharpe (%)',
                                              'CCV_dd > Pred_dd (%)', 'CCV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

cw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'CCV_sharpe > 0', 'CCV_sharpe > Pure_sharpe',
                                              'CCV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'CCV_sharpe > Pred_sharpe (%)',
                                              'CCV_dd > Pred_dd (%)', 'CCV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

# %%
# details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# dw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# cw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y1', file, 'CCV')
get_final_results_1('2022_y1', file, 'CCV')

get_final_results('2022_y1', dw_file, 'CCV_dw')
get_final_results_1('2022_y1', dw_file, 'CCV_dw')

get_final_results('2022_y1', cw_file, 'CCV_cw')
get_final_results_1('2022_y1', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:38: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-48-dbce691e5d20>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-48-dbce691e5d20>:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:51: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-48-dbce691e5d20>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-48-dbce691e5d20>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']
# <ipython-input-4-b267510ae310>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
# <ipython-input-4-b267510ae310>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Long_MA'] = data['Close'].rolling(window=long_window).mean()
# <ipython-input-4-b267510ae310>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-4-b267510ae310>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:31: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:37: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-4-b267510ae310>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-4-b267510ae310>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     71.363409      0.318711         -6.991876
# 1            CCV_dw    104.575887      0.489770         -6.448371
# 2            CCV_cw    117.495205      0.608240         -6.226896
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    115.353273      0.586315         -6.542573
# 5     LSTM_GRU_pred    115.353273      0.586315         -6.542573
# 6       BiLSTM_pred    123.809040      0.660325         -6.493346
# 7   BiLSTM_GRU_pred    123.005320      0.651457         -6.329412
# 8         QRNN_pred    132.642753      0.751775         -4.592928
# 9          ESN_pred     99.750134      0.445670         -7.287346
# 10         BNN_pred    147.878720      0.888151         -5.134494
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     87.546230      0.478094         -6.379079
# 1            CCV_dw     71.299498      0.187431         -5.936158
# 2            CCV_cw     78.472464      0.262132         -5.828274
# 3         LSTM_pred     73.914308      0.213969         -6.658890
# 4          GRU_pred    115.782668      0.600651         -5.771678
# 5     LSTM_GRU_pred    120.945303      0.648611         -5.745096
# 6       BiLSTM_pred    105.956078      0.518137         -6.547700
# 7   BiLSTM_GRU_pred     92.386920      0.385057         -6.632484
# 8         QRNN_pred    163.005008      1.065186         -4.456740
# 9          ESN_pred     33.820084     -0.191377         -8.337977
# 10         BNN_pred    143.694435      0.867431         -4.972505
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     85.741018      0.530277         -4.648827
# 1            CCV_dw     54.710797      0.016043         -5.108166
# 2            CCV_cw     42.926310     -0.125654         -6.175396
# 3         LSTM_pred     21.722473     -0.334368         -7.197069
# 4          GRU_pred     21.009257     -0.338026         -8.173571
# 5     LSTM_GRU_pred     30.686159     -0.240781         -8.099164
# 6       BiLSTM_pred     28.260804     -0.256876         -8.512576
# 7   BiLSTM_GRU_pred     89.224281      0.365533         -6.453040
# 8         QRNN_pred     85.969398      0.345513         -4.739544
# 9          ESN_pred    -23.060381     -0.923623         -7.882716
# 10         BNN_pred     89.688914      0.393010         -5.136085
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     68.778600      0.309154         -5.085962
# 1            CCV_dw     57.576962      0.051683         -6.208104
# 2            CCV_cw     47.266904     -0.068820         -6.478467
# 3         LSTM_pred     50.233257     -0.023913         -7.235891
# 4          GRU_pred     78.753889      0.257745         -6.911773
# 5     LSTM_GRU_pred     80.370309      0.273523         -6.885762
# 6       BiLSTM_pred     66.896463      0.144790         -7.773214
# 7   BiLSTM_GRU_pred     76.906073      0.240813         -7.720896
# 8         QRNN_pred    121.120282      0.683961         -4.508920
# 9          ESN_pred     11.893449     -0.447558         -7.328811
# 10         BNN_pred    122.236877      0.674118         -5.538252
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     67.888308      0.290578         -6.496506
# 1            CCV_dw     68.926355      0.164127         -5.949337
# 2            CCV_cw     44.150818     -0.088990         -6.624581
# 3         LSTM_pred     73.914308      0.213969         -6.658890
# 4          GRU_pred    102.357219      0.478504         -6.541575
# 5     LSTM_GRU_pred    107.457736      0.526488         -6.511447
# 6       BiLSTM_pred     93.233546      0.398768         -6.623899
# 7   BiLSTM_GRU_pred     92.723256      0.388865         -7.199573
# 8         QRNN_pred    160.664331      1.043796         -4.465727
# 9          ESN_pred     40.597216     -0.124255         -6.247347
# 10         BNN_pred    133.679402      0.778601         -5.016433
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     49.339019      0.109583         -5.023102
# 1            CCV_dw     97.151721      0.430279         -6.466647
# 2            CCV_cw     72.437624      0.200960         -6.066427
# 3         LSTM_pred     94.787589      0.400546         -7.004445
# 4          GRU_pred     41.901413     -0.102873         -8.629916
# 5     LSTM_GRU_pred     22.550535     -0.297364         -8.735831
# 6       BiLSTM_pred     95.310101      0.407106         -8.143392
# 7   BiLSTM_GRU_pred    124.557473      0.678304         -5.757058
# 8         QRNN_pred     83.634637      0.306267         -5.708379
# 9          ESN_pred     27.417480     -0.282493         -6.080659
# 10         BNN_pred     92.100332      0.386093         -6.287611
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.611710      0.200614         -5.753508
# 1            CCV_dw     95.500039      0.407979         -6.510900
# 2            CCV_cw     78.639529      0.260179         -6.407788
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred     75.491308      0.223617         -7.593307
# 5     LSTM_GRU_pred     73.049432      0.200587         -7.593307
# 6       BiLSTM_pred    104.737631      0.492097         -7.593231
# 7   BiLSTM_GRU_pred    101.427833      0.460804         -7.031268
# 8         QRNN_pred    107.376945      0.525773         -5.786546
# 9          ESN_pred     79.098852      0.267776         -5.686763
# 10         BNN_pred    140.474847      0.823638         -5.515841
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     67.678664      0.283706         -7.016006
# 1            CCV_dw    102.129030      0.467596         -6.462687
# 2            CCV_cw     94.942690      0.405031         -6.927056
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred     99.953307      0.448767         -7.203624
# 5     LSTM_GRU_pred     99.953307      0.448767         -7.203624
# 6       BiLSTM_pred    115.487270      0.587413         -6.541788
# 7   BiLSTM_GRU_pred    115.761882      0.588007         -6.930622
# 8         QRNN_pred    130.363183      0.731326         -4.602191
# 9          ESN_pred    117.615637      0.619164         -5.479186
# 10         BNN_pred    147.878720      0.888151         -5.134494
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     59.150006      0.067279         -6.388245
# 1            CCV_dw     95.432891      0.406901         -6.429126
# 2            CCV_cw     91.388282      0.376361         -5.957188
# 3         LSTM_pred     94.787589      0.400546         -7.004445
# 4          GRU_pred     84.222723      0.304459         -7.848529
# 5     LSTM_GRU_pred     73.274153      0.202424         -7.906555
# 6       BiLSTM_pred     85.837074      0.318344         -8.156639
# 7   BiLSTM_GRU_pred    115.781404      0.595771         -5.754450
# 8         QRNN_pred     73.627497      0.206464         -7.521765
# 9          ESN_pred    122.552940      0.647951         -6.334596
# 10         BNN_pred     75.977637      0.227453         -7.717537
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     91.785189      0.372916         -6.947089
# 1            CCV_dw    111.631510      0.551035         -6.396831
# 2            CCV_cw    112.671529      0.571467         -6.207734
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    102.477207      0.469561         -6.879715
# 5     LSTM_GRU_pred    102.477207      0.469561         -6.879715
# 6       BiLSTM_pred    104.461433      0.487279         -7.004445
# 7   BiLSTM_GRU_pred    100.746667      0.453786         -7.028083
# 8         QRNN_pred     97.150550      0.422197         -7.559013
# 9          ESN_pred    117.262971      0.600203         -6.364589
# 10         BNN_pred    112.700948      0.560311         -6.952577
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    119.924515      0.623770         -6.349463
# 1            CCV_dw    119.924515      0.623770         -6.349463
# 2            CCV_cw    114.450282      0.576060         -6.805803
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    104.461433      0.487279         -7.004445
# 5     LSTM_GRU_pred    104.461433      0.487279         -7.004445
# 6       BiLSTM_pred    111.631510      0.551035         -6.396831
# 7   BiLSTM_GRU_pred    112.700948      0.560311         -6.952577
# 8         QRNN_pred    119.924515      0.623770         -6.349463
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     97.747895      0.430772         -6.913901
# 1            CCV_dw     98.522848      0.438760         -5.861756
# 2            CCV_cw    116.246223      0.605990         -5.534535
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    111.162081      0.548837         -6.544941
# 5     LSTM_GRU_pred    112.449629      0.559803         -6.517684
# 6       BiLSTM_pred    111.572414      0.551567         -6.521688
# 7   BiLSTM_GRU_pred    123.472253      0.655599         -6.329412
# 8         QRNN_pred    146.352030      0.873125         -4.441883
# 9          ESN_pred    135.124968      0.789162         -4.645285
# 10         BNN_pred    135.792356      0.781097         -5.208853
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    156.914296      1.184226         -4.484757
# 1            CCV_dw     75.097049      0.222012         -6.075170
# 2            CCV_cw     99.508889      0.458438         -5.229627
# 3         LSTM_pred     90.458120      0.369547         -6.260875
# 4          GRU_pred    118.058682      0.620650         -5.710876
# 5     LSTM_GRU_pred    118.058682      0.620650         -5.710876
# 6       BiLSTM_pred    153.303428      0.969577         -5.769187
# 7   BiLSTM_GRU_pred     78.895063      0.257615         -7.611602
# 8         QRNN_pred    161.933936      1.053850         -4.475485
# 9          ESN_pred     54.590551      0.021166         -4.790720
# 10         BNN_pred    154.457549      1.008166         -5.220210
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     97.612472      0.654499         -5.239775
# 1            CCV_dw     54.846025      0.016112         -5.060546
# 2            CCV_cw     10.081196     -0.536781         -7.384840
# 3         LSTM_pred     69.190137      0.169547         -6.255898
# 4          GRU_pred     68.169277      0.161003         -7.725561
# 5     LSTM_GRU_pred     50.999169     -0.019782         -7.810268
# 6       BiLSTM_pred     80.802874      0.296313         -5.258380
# 7   BiLSTM_GRU_pred     61.432169      0.090198         -5.973984
# 8         QRNN_pred     98.685964      0.482520         -4.546257
# 9          ESN_pred    -28.472877     -1.022256         -7.024320
# 10         BNN_pred    112.420465      0.621410         -5.536626
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.685565      1.058577         -4.471286
# 1            CCV_dw     66.263416      0.137109         -6.134080
# 2            CCV_cw     43.162725     -0.099473         -6.122419
# 3         LSTM_pred     78.827623      0.261604         -6.314003
# 4          GRU_pred     61.223017      0.088067         -6.948779
# 5     LSTM_GRU_pred     87.329647      0.344067         -6.883505
# 6       BiLSTM_pred    105.879288      0.536125         -7.003855
# 7   BiLSTM_GRU_pred     71.308152      0.186897         -8.718789
# 8         QRNN_pred    113.763556      0.613150         -4.649621
# 9          ESN_pred     23.516953     -0.310222         -5.456923
# 10         BNN_pred    154.457549      1.008166         -5.220210
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.657196      1.017416         -4.512619
# 1            CCV_dw     72.715494      0.199173         -6.088657
# 2            CCV_cw     76.149703      0.236772         -6.032040
# 3         LSTM_pred     90.458120      0.369547         -6.260875
# 4          GRU_pred     86.013624      0.326346         -6.543016
# 5     LSTM_GRU_pred     86.203703      0.328153         -6.541871
# 6       BiLSTM_pred    140.036230      0.849772         -5.836326
# 7   BiLSTM_GRU_pred     74.850775      0.219653         -8.214503
# 8         QRNN_pred    139.912429      0.852055         -4.495194
# 9          ESN_pred     75.303977      0.230174         -4.762411
# 10         BNN_pred    154.457549      1.008166         -5.220210
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.393269      0.026394         -5.370373
# 1            CCV_dw     82.230313      0.303447         -6.103463
# 2            CCV_cw     91.072266      0.408380         -6.330049
# 3         LSTM_pred     91.105360      0.366887         -7.028083
# 4          GRU_pred     62.637173      0.102383         -8.417274
# 5     LSTM_GRU_pred     63.434239      0.110454         -8.519021
# 6       BiLSTM_pred     94.008582      0.402126         -5.694968
# 7   BiLSTM_GRU_pred     80.382686      0.274843         -5.331480
# 8         QRNN_pred     89.831299      0.374634         -5.602502
# 9          ESN_pred     47.581392     -0.061363         -5.234680
# 10         BNN_pred     97.694015      0.436870         -5.730812
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     96.720730      0.443773         -4.580222
# 1            CCV_dw     89.496735      0.355846         -5.918597
# 2            CCV_cw    101.843154      0.487599         -5.904529
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred     64.043888      0.115232         -7.569187
# 5     LSTM_GRU_pred     85.329685      0.319754         -7.536345
# 6       BiLSTM_pred     86.147475      0.322649         -7.688466
# 7   BiLSTM_GRU_pred    100.248005      0.449685         -7.031268
# 8         QRNN_pred    104.787376      0.504279         -5.763384
# 9          ESN_pred     77.617271      0.253094         -4.704214
# 10         BNN_pred    135.792356      0.781097         -5.208853
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    110.214288      0.556527         -5.125476
# 1            CCV_dw     96.089400      0.416313         -5.874770
# 2            CCV_cw    116.409329      0.616372         -6.308863
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred     78.435011      0.251143         -7.270277
# 5     LSTM_GRU_pred     79.684637      0.262635         -7.239999
# 6       BiLSTM_pred    103.341256      0.478296         -6.570342
# 7   BiLSTM_GRU_pred    107.960186      0.519157         -6.982326
# 8         QRNN_pred    135.619734      0.779372         -5.093997
# 9          ESN_pred    121.022166      0.661644         -4.640763
# 10         BNN_pred    135.792356      0.781097         -5.208853
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     66.771012      0.143615         -6.237103
# 1            CCV_dw     95.432891      0.406901         -6.429126
# 2            CCV_cw     66.830424      0.143847         -6.406088
# 3         LSTM_pred     91.105360      0.366887         -7.028083
# 4          GRU_pred     84.222723      0.304459         -7.848529
# 5     LSTM_GRU_pred     73.274153      0.202424         -7.906555
# 6       BiLSTM_pred    104.538024      0.494814         -5.709276
# 7   BiLSTM_GRU_pred     80.382686      0.274843         -5.331480
# 8         QRNN_pred     70.940436      0.184003         -7.467365
# 9          ESN_pred    122.552940      0.647951         -6.334596
# 10         BNN_pred     82.358434      0.286538         -7.147483
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    108.544006      0.538414         -5.749138
# 1            CCV_dw    111.631510      0.551035         -6.396831
# 2            CCV_cw    112.325773      0.568857         -5.845055
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    101.193970      0.457927         -6.887732
# 5     LSTM_GRU_pred    101.193970      0.457927         -6.887732
# 6       BiLSTM_pred    104.461433      0.487279         -7.004445
# 7   BiLSTM_GRU_pred    100.746667      0.453786         -7.028083
# 8         QRNN_pred     85.637268      0.318475         -7.602525
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    119.924515      0.623770         -6.349463
# 1            CCV_dw    119.924515      0.623770         -6.349463
# 2            CCV_cw    120.706071      0.639954         -6.284675
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    104.461433      0.487279         -7.004445
# 5     LSTM_GRU_pred    104.461433      0.487279         -7.004445
# 6       BiLSTM_pred    111.631510      0.551035         -6.396831
# 7   BiLSTM_GRU_pred    104.461433      0.487279         -7.004445
# 8         QRNN_pred    115.935185      0.590387         -6.884238
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    127.062269      0.707022         -4.694455
# 1            CCV_dw     97.543742      0.442983         -6.786957
# 2            CCV_cw    108.536300      0.663294         -6.432012
# 3         LSTM_pred     67.712928      0.151005         -6.711351
# 4          GRU_pred    130.808398      0.729632         -5.719446
# 5     LSTM_GRU_pred    132.229476      0.742301         -5.712268
# 6       BiLSTM_pred    135.065648      0.787633         -5.897793
# 7   BiLSTM_GRU_pred     80.033365      0.275122         -5.974350
# 8         QRNN_pred    129.312005      0.728815         -5.151325
# 9          ESN_pred     61.851506      0.094350         -4.848797
# 10         BNN_pred    139.842340      0.875385         -5.340427
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     86.567883      0.338347         -5.675767
# 1            CCV_dw      3.926617     -0.375216         -7.016380
# 2            CCV_cw     65.098151      0.270057         -5.302194
# 3         LSTM_pred     65.467393      0.131864         -6.737455
# 4          GRU_pred    178.721325      1.507417         -3.437031
# 5     LSTM_GRU_pred    105.774086      0.560341         -3.926942
# 6       BiLSTM_pred    119.533959      0.676899         -5.741259
# 7   BiLSTM_GRU_pred    138.059988      1.124967         -2.743021
# 8         QRNN_pred     84.235848      0.318667         -4.760409
# 9          ESN_pred    -48.150418     -1.136658         -9.947476
# 10         BNN_pred    105.335002      0.688096         -5.617734
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     19.900081     -0.443878         -6.896508
# 1            CCV_dw     11.702658     -0.395237         -5.417430
# 2            CCV_cw     35.733347     -0.063676         -5.592925
# 3         LSTM_pred     57.225608      0.041982         -5.238724
# 4          GRU_pred     96.423654      0.750978         -2.396933
# 5     LSTM_GRU_pred     16.341574     -0.602895         -3.200707
# 6       BiLSTM_pred     57.680050      0.043423         -4.178020
# 7   BiLSTM_GRU_pred     50.252080      0.147393         -2.808481
# 8         QRNN_pred    -23.794975     -1.016356         -8.595999
# 9          ESN_pred    -14.992291     -1.038617         -5.689437
# 10         BNN_pred     85.211382      0.616093         -5.051988
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     73.540021      0.225168         -5.065251
# 1            CCV_dw     -3.215319     -0.534475         -5.915148
# 2            CCV_cw     50.988803      0.129437         -6.820608
# 3         LSTM_pred     66.567544      0.151147         -5.238724
# 4          GRU_pred    132.372422      1.002397         -3.650123
# 5     LSTM_GRU_pred     25.108304     -0.375737         -4.630225
# 6       BiLSTM_pred     56.983770      0.040843         -6.100306
# 7   BiLSTM_GRU_pred     42.267870      0.022439         -2.808481
# 8         QRNN_pred     31.720948     -0.243959         -5.990680
# 9          ESN_pred    -34.780753     -1.158660         -7.430973
# 10         BNN_pred    133.902869      1.070327         -4.860937
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     94.871913      0.431795         -5.512295
# 1            CCV_dw     40.297380      0.007892         -5.407622
# 2            CCV_cw    115.819566      0.809880         -5.206455
# 3         LSTM_pred     53.403815      0.004409         -6.797295
# 4          GRU_pred    144.910604      1.109712         -3.633456
# 5     LSTM_GRU_pred     30.335318     -0.258944         -6.064219
# 6       BiLSTM_pred    107.174957      0.571728         -7.347213
# 7   BiLSTM_GRU_pred     43.161463      0.038023         -4.146564
# 8         QRNN_pred     64.158944      0.118016         -6.447317
# 9          ESN_pred     11.391277     -0.473001         -6.255745
# 10         BNN_pred    120.790693      0.853787         -5.371177
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      9.966926     -0.548231         -7.803275
# 1            CCV_dw     77.802551      0.286769         -5.791020
# 2            CCV_cw    111.832063      0.816774         -4.897376
# 3         LSTM_pred     60.329186      0.078923         -7.352105
# 4          GRU_pred     35.750459     -0.208234         -6.929734
# 5     LSTM_GRU_pred     37.602639     -0.220300         -5.982783
# 6       BiLSTM_pred     95.593926      0.513764         -3.999387
# 7   BiLSTM_GRU_pred     50.939219      0.138012         -4.774172
# 8         QRNN_pred    -23.794975     -1.016356         -8.595999
# 9          ESN_pred      9.295370     -0.622393         -4.717541
# 10         BNN_pred     42.986105     -0.125656         -4.600907
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     63.084448      0.108265         -5.119530
# 1            CCV_dw     54.048586      0.009572         -5.988410
# 2            CCV_cw    109.937102      0.730630         -6.565002
# 3         LSTM_pred     69.698547      0.173791         -7.352105
# 4          GRU_pred     68.077777      0.157685         -7.408200
# 5     LSTM_GRU_pred     37.545788     -0.169675         -8.428315
# 6       BiLSTM_pred     71.072095      0.191337         -6.742808
# 7   BiLSTM_GRU_pred     72.041650      0.207139         -6.018386
# 8         QRNN_pred     31.720948     -0.243959         -5.990680
# 9          ESN_pred     20.679820     -0.358434         -5.287062
# 10         BNN_pred    102.741471      0.523261         -5.042497
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    112.712807      0.580261         -5.406858
# 1            CCV_dw     68.403117      0.160922         -6.917251
# 2            CCV_cw    154.025780      1.109701         -5.704098
# 3         LSTM_pred     74.764620      0.221361         -6.692437
# 4          GRU_pred    106.951538      0.517256         -6.909409
# 5     LSTM_GRU_pred     77.359220      0.243507         -6.863905
# 6       BiLSTM_pred    119.455031      0.647935         -6.970214
# 7   BiLSTM_GRU_pred     61.804137      0.094019         -6.954122
# 8         QRNN_pred    111.680048      0.572446         -5.458510
# 9          ESN_pred     55.808998      0.032090         -4.927717
# 10         BNN_pred    133.783858      0.817204         -5.368964
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      9.966926     -0.548231         -7.803275
# 1            CCV_dw     78.454686      0.251231         -7.202001
# 2            CCV_cw     85.624978      0.347820         -4.963071
# 3         LSTM_pred     91.105360      0.366887         -7.028083
# 4          GRU_pred     91.105162      0.372610         -6.380922
# 5     LSTM_GRU_pred     45.289180     -0.093232         -6.769980
# 6       BiLSTM_pred     77.730214      0.251714         -5.800544
# 7   BiLSTM_GRU_pred     50.939219      0.138012         -4.774172
# 8         QRNN_pred    -23.794975     -1.016356         -8.595999
# 9          ESN_pred     99.613658      0.455460         -6.466743
# 10         BNN_pred     71.611128      0.186525         -7.608525
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     63.084448      0.108265         -5.119530
# 1            CCV_dw    107.892628      0.517635         -6.418419
# 2            CCV_cw     83.774683      0.308636         -6.653067
# 3         LSTM_pred    100.746667      0.453786         -7.028083
# 4          GRU_pred     78.677613      0.252545         -7.866949
# 5     LSTM_GRU_pred     89.591728      0.357798         -6.341967
# 6       BiLSTM_pred    114.298026      0.582334         -5.709276
# 7   BiLSTM_GRU_pred     75.253350      0.242084         -6.000409
# 8         QRNN_pred     31.720948     -0.243959         -5.990680
# 9          ESN_pred    122.762068      0.649812         -6.333416
# 10         BNN_pred     99.465444      0.442154         -7.036273
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    107.427183      0.530142         -5.853144
# 1            CCV_dw    107.892628      0.517635         -6.418419
# 2            CCV_cw    119.924515      0.623770         -6.349463
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    112.700948      0.560311         -6.952577
# 5     LSTM_GRU_pred    104.910246      0.491425         -6.864566
# 6       BiLSTM_pred    100.746667      0.453786         -7.028083
# 7   BiLSTM_GRU_pred     99.652276      0.457487         -5.238054
# 8         QRNN_pred    111.680048      0.572446         -5.458510
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    149.652646      0.941693         -4.425024
# 1            CCV_dw     49.938010     -0.026744         -7.076698
# 2            CCV_cw    156.350833      0.983262         -5.791293
# 3         LSTM_pred     61.397391      0.089819         -6.308450
# 4          GRU_pred     93.724897      0.406926         -5.260730
# 5     LSTM_GRU_pred     93.349360      0.401477         -5.262537
# 6       BiLSTM_pred    107.796684      0.537907         -5.974483
# 7   BiLSTM_GRU_pred     58.472586      0.059863         -5.905066
# 8         QRNN_pred    129.204186      0.737416         -4.436474
# 9          ESN_pred     28.640375     -0.243800         -8.168382
# 10         BNN_pred    141.492530      0.899349         -4.244198
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     60.858419      0.084303         -6.077237
# 1            CCV_dw     13.682821     -0.274439         -7.315701
# 2            CCV_cw    118.744908      0.697909         -6.665779
# 3         LSTM_pred    101.730014      0.685812         -4.585411
# 4          GRU_pred    178.721325      1.507417         -3.437031
# 5     LSTM_GRU_pred    155.443907      1.207927         -3.287605
# 6       BiLSTM_pred    127.522482      0.972548         -3.961931
# 7   BiLSTM_GRU_pred    149.580589      1.256485         -2.733392
# 8         QRNN_pred     84.489766      0.325298         -5.612528
# 9          ESN_pred     36.615579     -0.198955         -6.631300
# 10         BNN_pred    103.934383      0.692171         -5.591413
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -1.233634     -0.735292         -6.896508
# 1            CCV_dw    -11.881504     -0.783709         -5.539493
# 2            CCV_cw     37.490573     -0.058198         -3.593444
# 3         LSTM_pred     83.921992      0.576294         -2.853623
# 4          GRU_pred     75.059044      0.453472         -1.478319
# 5     LSTM_GRU_pred     44.486542     -0.209144         -2.506867
# 6       BiLSTM_pred     62.902930      0.342656         -4.141221
# 7   BiLSTM_GRU_pred     17.137548     -0.495776         -2.808481
# 8         QRNN_pred     28.518609     -0.364667         -4.932598
# 9          ESN_pred      5.635916     -0.898575         -4.350482
# 10         BNN_pred    118.306393      1.151377         -4.979808
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     17.019223     -0.453469         -7.161060
# 1            CCV_dw    -10.786914     -0.660253         -5.412610
# 2            CCV_cw     16.619609     -0.292835         -7.594188
# 3         LSTM_pred     65.206872      0.321865         -3.407217
# 4          GRU_pred    132.372422      1.002397         -3.650123
# 5     LSTM_GRU_pred     78.277304      0.382546         -2.472458
# 6       BiLSTM_pred     61.918835      0.296752         -5.112139
# 7   BiLSTM_GRU_pred     54.200745      0.191370         -2.808481
# 8         QRNN_pred      7.826089     -0.553410         -7.706857
# 9          ESN_pred    -21.386450     -1.094402         -6.460176
# 10         BNN_pred    155.368488      1.386569         -4.014363
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     27.131129     -0.293268         -7.711281
# 1            CCV_dw     44.667134      0.056955         -4.654337
# 2            CCV_cw     83.592378      0.486073         -7.701211
# 3         LSTM_pred     58.031947      0.215129         -4.856252
# 4          GRU_pred    121.025353      0.917500         -4.713196
# 5     LSTM_GRU_pred    108.238255      0.705289         -3.719616
# 6       BiLSTM_pred    104.641481      0.802394         -4.290627
# 7   BiLSTM_GRU_pred     67.350789      0.347223         -2.893068
# 8         QRNN_pred     63.353559      0.110557         -5.918892
# 9          ESN_pred     -0.796006     -0.695474         -4.630010
# 10         BNN_pred    166.569970      1.393115         -4.994507
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -0.798475     -0.689982         -7.803275
# 1            CCV_dw     24.039899     -0.400929         -6.096090
# 2            CCV_cw     75.305278      0.445303         -5.445768
# 3         LSTM_pred     59.044837      0.064050         -6.844978
# 4          GRU_pred    -22.265271     -1.089800         -8.394667
# 5     LSTM_GRU_pred      5.730077     -0.747288         -4.551277
# 6       BiLSTM_pred     75.193774      0.269490         -4.054250
# 7   BiLSTM_GRU_pred     28.793297     -0.255914         -2.808481
# 8         QRNN_pred     28.518609     -0.364667         -4.932598
# 9          ESN_pred     44.551477     -0.165826         -4.681853
# 10         BNN_pred     95.469717      0.765325         -4.221531
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     20.357120     -0.382995         -7.772263
# 1            CCV_dw     20.346036     -0.392915         -6.652584
# 2            CCV_cw     80.546373      0.440283         -6.312727
# 3         LSTM_pred     24.242907     -0.317846         -7.038263
# 4          GRU_pred     28.498413     -0.262998         -7.508034
# 5     LSTM_GRU_pred     19.256060     -0.468775         -5.639417
# 6       BiLSTM_pred     56.557932      0.034557         -6.438742
# 7   BiLSTM_GRU_pred     11.554849     -0.513006         -7.416523
# 8         QRNN_pred      7.826089     -0.553410         -7.706857
# 9          ESN_pred    -14.623641     -0.828888         -6.168478
# 10         BNN_pred    133.111720      0.917510         -3.979543
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     94.973868      0.433172         -4.490995
# 1            CCV_dw     42.649452     -0.107939         -7.070801
# 2            CCV_cw    129.750515      0.908351         -5.670757
# 3         LSTM_pred     37.395912     -0.161646         -6.478722
# 4          GRU_pred     31.335792     -0.216073         -6.997550
# 5     LSTM_GRU_pred     50.466286     -0.024187         -7.402943
# 6       BiLSTM_pred     73.993343      0.217412         -6.984525
# 7   BiLSTM_GRU_pred     43.485717     -0.112303         -7.309052
# 8         QRNN_pred     69.819697      0.175501         -5.385785
# 9          ESN_pred      8.189539     -0.497077         -5.918270
# 10         BNN_pred    166.255680      1.200722         -4.912279
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -0.798475     -0.689982         -7.803275
# 1            CCV_dw     40.556320     -0.113862         -7.426461
# 2            CCV_cw     75.090646      0.252971         -5.428815
# 3         LSTM_pred     91.105360      0.366887         -7.028083
# 4          GRU_pred    100.716380      0.463897         -6.322824
# 5     LSTM_GRU_pred     50.238371     -0.036671         -6.738077
# 6       BiLSTM_pred     76.377941      0.238409         -5.800544
# 7   BiLSTM_GRU_pred     41.734169      0.014960         -4.774172
# 8         QRNN_pred     28.518609     -0.364667         -4.932598
# 9          ESN_pred    104.043977      0.551305         -4.697344
# 10         BNN_pred     84.542847      0.310351         -6.450848
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     20.357120     -0.382995         -7.772263
# 1            CCV_dw     95.578842      0.407381         -6.433709
# 2            CCV_cw     71.532798      0.190387         -6.299161
# 3         LSTM_pred     91.105360      0.366887         -7.028083
# 4          GRU_pred     78.677613      0.252545         -7.866949
# 5     LSTM_GRU_pred     89.206840      0.354354         -6.338845
# 6       BiLSTM_pred    109.173835      0.538113         -6.183795
# 7   BiLSTM_GRU_pred     48.780444     -0.051491         -6.824023
# 8         QRNN_pred      7.826089     -0.553410         -7.706857
# 9          ESN_pred    124.136475      0.663434         -6.325672
# 10         BNN_pred     91.163489      0.367786         -7.610131
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     76.514781      0.238564         -5.764284
# 1            CCV_dw    107.892628      0.517635         -6.418419
# 2            CCV_cw    105.288780      0.494278         -6.950548
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    104.910246      0.491425         -6.864566
# 5     LSTM_GRU_pred     89.129856      0.348542         -7.866949
# 6       BiLSTM_pred    100.746667      0.453786         -7.028083
# 7   BiLSTM_GRU_pred     58.127693      0.056981         -7.566487
# 8         QRNN_pred     59.139481      0.066894         -6.371644
# 9          ESN_pred    117.262971      0.600203         -6.364589
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     71.363409      0.318711         -6.991876
# 1            CCV_dw     89.230021      0.353188         -7.576121
# 2            CCV_cw    144.204170      0.863023         -6.081543
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    115.353273      0.586315         -6.542573
# 5     LSTM_GRU_pred    119.924515      0.623770         -6.349463
# 6       BiLSTM_pred    123.809040      0.660325         -6.493346
# 7   BiLSTM_GRU_pred    106.728875      0.506716         -6.404295
# 8         QRNN_pred    132.642753      0.751775         -4.592928
# 9          ESN_pred    109.598228      0.535112         -7.252982
# 10         BNN_pred    162.384032      1.019140         -4.964738
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     87.546230      0.478094         -6.379079
# 1            CCV_dw     68.124757      0.155529         -6.208449
# 2            CCV_cw     92.132110      0.393151         -6.579484
# 3         LSTM_pred     73.914308      0.213969         -6.658890
# 4          GRU_pred    115.782668      0.600651         -5.771678
# 5     LSTM_GRU_pred     69.404625      0.166343         -8.283967
# 6       BiLSTM_pred    105.956078      0.518137         -6.547700
# 7   BiLSTM_GRU_pred     46.631961     -0.057869         -7.627002
# 8         QRNN_pred    163.005008      1.065186         -4.456740
# 9          ESN_pred     96.414519      0.456318         -6.218951
# 10         BNN_pred    173.509342      1.136149         -4.925523
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     85.741018      0.530277         -4.648827
# 1            CCV_dw     38.230863     -0.152327         -7.323635
# 2            CCV_cw    156.621122      1.217285         -2.863247
# 3         LSTM_pred     21.722473     -0.334368         -7.197069
# 4          GRU_pred     21.009257     -0.338026         -8.173571
# 5     LSTM_GRU_pred    125.813117      0.937470         -3.951916
# 6       BiLSTM_pred     28.260804     -0.256876         -8.512576
# 7   BiLSTM_GRU_pred     30.660524     -0.268496         -6.684700
# 8         QRNN_pred     85.969398      0.345513         -4.739544
# 9          ESN_pred     91.700539      0.456115         -4.658018
# 10         BNN_pred    121.611184      0.687702         -4.951635
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     68.778600      0.309154         -5.085962
# 1            CCV_dw     50.997517     -0.015732         -6.802618
# 2            CCV_cw    123.086780      0.773137         -5.254353
# 3         LSTM_pred     50.233257     -0.023913         -7.235891
# 4          GRU_pred     78.753889      0.257745         -6.911773
# 5     LSTM_GRU_pred     80.381794      0.270997         -7.520758
# 6       BiLSTM_pred     66.896463      0.144790         -7.773214
# 7   BiLSTM_GRU_pred     21.797397     -0.316256         -8.911255
# 8         QRNN_pred    121.120282      0.683961         -4.508920
# 9          ESN_pred    122.033530      0.767341         -5.261455
# 10         BNN_pred    139.605912      0.842875         -4.819230
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     67.888308      0.290578         -6.496506
# 1            CCV_dw     36.098161     -0.163053         -7.594600
# 2            CCV_cw    123.593738      0.717791         -6.987904
# 3         LSTM_pred     73.914308      0.213969         -6.658890
# 4          GRU_pred    102.357219      0.478504         -6.541575
# 5     LSTM_GRU_pred     69.404625      0.166343         -8.283967
# 6       BiLSTM_pred     93.233546      0.398768         -6.623899
# 7   BiLSTM_GRU_pred     43.128120     -0.093325         -7.652621
# 8         QRNN_pred    160.664331      1.043796         -4.465727
# 9          ESN_pred     98.778757      0.490987         -7.027725
# 10         BNN_pred    168.392659      1.095973         -4.793853
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     49.339019      0.109583         -5.023102
# 1            CCV_dw    102.638247      0.489800         -7.336005
# 2            CCV_cw    122.251232      0.714697         -5.643178
# 3         LSTM_pred     94.787589      0.400546         -7.004445
# 4          GRU_pred     41.901413     -0.102873         -8.629916
# 5     LSTM_GRU_pred    116.206879      0.590917         -6.370610
# 6       BiLSTM_pred     95.310101      0.407106         -8.143392
# 7   BiLSTM_GRU_pred     79.644442      0.263992         -7.028855
# 8         QRNN_pred     83.634637      0.306267         -5.708379
# 9          ESN_pred     98.650971      0.473436         -4.712368
# 10         BNN_pred    121.576025      0.663785         -5.253674
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.611710      0.200614         -5.753508
# 1            CCV_dw    102.445867      0.484191         -6.815954
# 2            CCV_cw    115.209024      0.631574         -6.294720
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred     75.491308      0.223617         -7.593307
# 5     LSTM_GRU_pred    119.924515      0.623770         -6.349463
# 6       BiLSTM_pred    104.737631      0.492097         -7.593231
# 7   BiLSTM_GRU_pred     98.997699      0.437515         -6.444357
# 8         QRNN_pred    107.376945      0.525773         -5.786546
# 9          ESN_pred    141.328399      0.856972         -4.430898
# 10         BNN_pred    152.202851      0.932384         -4.964738
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     67.678664      0.283706         -7.016006
# 1            CCV_dw     86.817159      0.330670         -7.592941
# 2            CCV_cw    133.502168      0.775503         -6.691411
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred     99.953307      0.448767         -7.203624
# 5     LSTM_GRU_pred    119.924515      0.623770         -6.349463
# 6       BiLSTM_pred    115.487270      0.587413         -6.541788
# 7   BiLSTM_GRU_pred    106.728875      0.506716         -6.404295
# 8         QRNN_pred    130.363183      0.731326         -4.602191
# 9          ESN_pred    126.776119      0.702289         -5.464772
# 10         BNN_pred    162.384032      1.019140         -4.964738
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     59.150006      0.067279         -6.388245
# 1            CCV_dw     96.279641      0.413408         -6.918608
# 2            CCV_cw    111.396251      0.564283         -5.694564
# 3         LSTM_pred     94.787589      0.400546         -7.004445
# 4          GRU_pred     84.222723      0.304459         -7.848529
# 5     LSTM_GRU_pred    116.206879      0.590917         -6.370610
# 6       BiLSTM_pred     85.837074      0.318344         -8.156639
# 7   BiLSTM_GRU_pred     93.984779      0.393671         -6.954975
# 8         QRNN_pred     73.627497      0.206464         -7.521765
# 9          ESN_pred    115.272434      0.607120         -5.114008
# 10         BNN_pred    102.959667      0.474229         -6.966031
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     91.785189      0.372916         -6.947089
# 1            CCV_dw    111.631510      0.551035         -6.396831
# 2            CCV_cw    117.307591      0.612660         -6.278783
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    102.477207      0.469561         -6.879715
# 5     LSTM_GRU_pred    119.924515      0.623770         -6.349463
# 6       BiLSTM_pred    104.461433      0.487279         -7.004445
# 7   BiLSTM_GRU_pred    114.907661      0.579339         -6.378034
# 8         QRNN_pred     97.150550      0.422197         -7.559013
# 9          ESN_pred    132.833476      0.752546         -5.084629
# 10         BNN_pred    112.268179      0.557395         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    119.924515      0.623770         -6.349463
# 1            CCV_dw    119.924515      0.623770         -6.349463
# 2            CCV_cw    114.450282      0.576060         -6.805803
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    104.461433      0.487279         -7.004445
# 5     LSTM_GRU_pred    119.924515      0.623770         -6.349463
# 6       BiLSTM_pred    111.631510      0.551035         -6.396831
# 7   BiLSTM_GRU_pred    119.924515      0.623770         -6.349463
# 8         QRNN_pred    119.924515      0.623770         -6.349463
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     97.747895      0.430772         -6.913901
# 1            CCV_dw     73.240814      0.203259         -7.172771
# 2            CCV_cw    146.497997      0.897387         -5.400317
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    111.162081      0.548837         -6.544941
# 5     LSTM_GRU_pred    119.924515      0.623770         -6.349463
# 6       BiLSTM_pred    111.572414      0.551567         -6.521688
# 7   BiLSTM_GRU_pred    104.776791      0.493574         -6.415611
# 8         QRNN_pred    146.352030      0.873125         -4.441883
# 9          ESN_pred    159.433007      1.004335         -4.407693
# 10         BNN_pred    145.825023      0.872862         -5.208853
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    156.914296      1.184226         -4.484757
# 1            CCV_dw     63.626532      0.111534         -6.026834
# 2            CCV_cw    156.760110      1.053183         -3.720862
# 3         LSTM_pred     90.458120      0.369547         -6.260875
# 4          GRU_pred    118.058682      0.620650         -5.710876
# 5     LSTM_GRU_pred     93.619650      0.398778         -6.650693
# 6       BiLSTM_pred    153.303428      0.969577         -5.769187
# 7   BiLSTM_GRU_pred     71.271209      0.186976         -7.406965
# 8         QRNN_pred    161.933936      1.053850         -4.475485
# 9          ESN_pred    109.676974      0.558306         -4.814961
# 10         BNN_pred    166.112317      1.102811         -5.169519
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     97.612472      0.654499         -5.239775
# 1            CCV_dw     56.761845      0.042413         -6.539443
# 2            CCV_cw    157.277720      1.231018         -3.182469
# 3         LSTM_pred     69.190137      0.169547         -6.255898
# 4          GRU_pred     68.169277      0.161003         -7.725561
# 5     LSTM_GRU_pred    155.051234      1.233135         -4.095924
# 6       BiLSTM_pred     80.802874      0.296313         -5.258380
# 7   BiLSTM_GRU_pred     72.512026      0.212648         -5.172927
# 8         QRNN_pred     98.685964      0.482520         -4.546257
# 9          ESN_pred     59.748375      0.071961         -4.490053
# 10         BNN_pred    186.492823      1.339947         -4.193553
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.685565      1.058577         -4.471286
# 1            CCV_dw     53.577896      0.012902         -6.586462
# 2            CCV_cw    154.020252      1.103351         -2.842531
# 3         LSTM_pred     78.827623      0.261604         -6.314003
# 4          GRU_pred     61.223017      0.088067         -6.948779
# 5     LSTM_GRU_pred     90.237200      0.367216         -6.671327
# 6       BiLSTM_pred    105.879288      0.536125         -7.003855
# 7   BiLSTM_GRU_pred     50.228453     -0.023435         -7.575082
# 8         QRNN_pred    113.763556      0.613150         -4.649621
# 9          ESN_pred     91.202269      0.391412         -3.816464
# 10         BNN_pred    166.404585      1.105903         -5.177828
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.657196      1.017416         -4.512619
# 1            CCV_dw     44.075838     -0.080677         -7.327571
# 2            CCV_cw    175.973289      1.295489         -3.499539
# 3         LSTM_pred     90.458120      0.369547         -6.260875
# 4          GRU_pred     86.013624      0.326346         -6.543016
# 5     LSTM_GRU_pred     93.619650      0.398778         -6.650693
# 6       BiLSTM_pred    140.036230      0.849772         -5.836326
# 7   BiLSTM_GRU_pred     50.557805     -0.018253         -7.553005
# 8         QRNN_pred    139.912429      0.852055         -4.495194
# 9          ESN_pred    104.473053      0.511582         -4.787291
# 10         BNN_pred    166.112317      1.102811         -5.169519
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.393269      0.026394         -5.370373
# 1            CCV_dw     83.451265      0.303290         -6.499772
# 2            CCV_cw    129.096478      0.815507         -6.111195
# 3         LSTM_pred     91.105360      0.366887         -7.028083
# 4          GRU_pred     62.637173      0.102383         -8.417274
# 5     LSTM_GRU_pred    111.843399      0.552040         -6.395612
# 6       BiLSTM_pred     94.008582      0.402126         -5.694968
# 7   BiLSTM_GRU_pred     63.562797      0.111468         -7.135135
# 8         QRNN_pred     89.831299      0.374634         -5.602502
# 9          ESN_pred    102.426339      0.510685         -4.595311
# 10         BNN_pred    136.047233      0.798037         -4.511902
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     96.720730      0.443773         -4.580222
# 1            CCV_dw     83.008300      0.296616         -6.441467
# 2            CCV_cw    123.895236      0.716844         -5.674325
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred     64.043888      0.115232         -7.569187
# 5     LSTM_GRU_pred    119.924515      0.623770         -6.349463
# 6       BiLSTM_pred     86.147475      0.322649         -7.688466
# 7   BiLSTM_GRU_pred     88.864865      0.350704         -6.504328
# 8         QRNN_pred    104.787376      0.504279         -5.763384
# 9          ESN_pred    145.649333      0.894008         -4.431772
# 10         BNN_pred    147.954359      0.892092         -5.208853
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    110.214288      0.556527         -5.125476
# 1            CCV_dw     73.240814      0.203259         -7.172771
# 2            CCV_cw    134.289570      0.802428         -6.209414
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred     78.435011      0.251143         -7.270277
# 5     LSTM_GRU_pred    119.924515      0.623770         -6.349463
# 6       BiLSTM_pred    103.341256      0.478296         -6.570342
# 7   BiLSTM_GRU_pred    104.776791      0.493574         -6.415611
# 8         QRNN_pred    135.619734      0.779372         -5.093997
# 9          ESN_pred    152.694461      0.946742         -4.407693
# 10         BNN_pred    145.825023      0.872862         -5.208853
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     66.771012      0.143615         -6.237103
# 1            CCV_dw    107.941403      0.518068         -6.418136
# 2            CCV_cw     82.724609      0.297191         -6.306188
# 3         LSTM_pred     91.105360      0.366887         -7.028083
# 4          GRU_pred     84.222723      0.304459         -7.848529
# 5     LSTM_GRU_pred    111.843399      0.552040         -6.395612
# 6       BiLSTM_pred    104.538024      0.494814         -5.709276
# 7   BiLSTM_GRU_pred     84.112673      0.309016         -7.018308
# 8         QRNN_pred     70.940436      0.184003         -7.467365
# 9          ESN_pred     80.756892      0.283042         -6.145487
# 10         BNN_pred    112.268179      0.557395         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    108.544006      0.538414         -5.749138
# 1            CCV_dw    119.924515      0.623770         -6.349463
# 2            CCV_cw    114.955873      0.592951         -5.716076
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    101.193970      0.457927         -6.887732
# 5     LSTM_GRU_pred    119.924515      0.623770         -6.349463
# 6       BiLSTM_pred    104.461433      0.487279         -7.004445
# 7   BiLSTM_GRU_pred    114.907661      0.579339         -6.378034
# 8         QRNN_pred     85.637268      0.318475         -7.602525
# 9          ESN_pred    129.612641      0.724242         -5.099127
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    119.924515      0.623770         -6.349463
# 1            CCV_dw    119.924515      0.623770         -6.349463
# 2            CCV_cw    120.706071      0.639954         -6.284675
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    104.461433      0.487279         -7.004445
# 5     LSTM_GRU_pred    119.924515      0.623770         -6.349463
# 6       BiLSTM_pred    111.631510      0.551035         -6.396831
# 7   BiLSTM_GRU_pred    119.924515      0.623770         -6.349463
# 8         QRNN_pred    115.935185      0.590387         -6.884238
# 9          ESN_pred    127.898964      0.703223         -5.692627
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    127.062269      0.707022         -4.694455
# 1            CCV_dw     33.036231     -0.192603         -7.761844
# 2            CCV_cw    126.115972      0.822140         -6.265152
# 3         LSTM_pred     67.712928      0.151005         -6.711351
# 4          GRU_pred    130.808398      0.729632         -5.719446
# 5     LSTM_GRU_pred    103.851264      0.492384         -6.441918
# 6       BiLSTM_pred    135.065648      0.787633         -5.897793
# 7   BiLSTM_GRU_pred    130.942746      0.741229         -6.299797
# 8         QRNN_pred    129.312005      0.728815         -5.151325
# 9          ESN_pred    133.359379      0.784601         -4.429613
# 10         BNN_pred    167.082395      1.124788         -5.314975
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     86.567883      0.338347         -5.675767
# 1            CCV_dw    118.969162      0.718749         -4.731021
# 2            CCV_cw     53.477254      0.150765         -6.254962
# 3         LSTM_pred     65.467393      0.131864         -6.737455
# 4          GRU_pred    178.721325      1.507417         -3.437031
# 5     LSTM_GRU_pred     40.648187      0.016959         -7.889172
# 6       BiLSTM_pred    119.533959      0.676899         -5.741259
# 7   BiLSTM_GRU_pred     73.229921      0.209370         -7.536905
# 8         QRNN_pred     84.235848      0.318667         -4.760409
# 9          ESN_pred     50.122959     -0.035272         -7.801813
# 10         BNN_pred     67.616328      0.308954         -5.571353
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     19.900081     -0.443878         -6.896508
# 1            CCV_dw    -40.466765     -1.515317         -7.012607
# 2            CCV_cw     10.554483     -0.427672         -8.111702
# 3         LSTM_pred     57.225608      0.041982         -5.238724
# 4          GRU_pred     96.423654      0.750978         -2.396933
# 5     LSTM_GRU_pred    104.212596      0.834155         -4.241817
# 6       BiLSTM_pred     57.680050      0.043423         -4.178020
# 7   BiLSTM_GRU_pred     85.464824      0.411790         -4.278112
# 8         QRNN_pred    -23.794975     -1.016356         -8.595999
# 9          ESN_pred    -28.691134     -1.003327         -8.399985
# 10         BNN_pred     65.840911      0.365958         -3.106983
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     73.540021      0.225168         -5.065251
# 1            CCV_dw     63.460119      0.118651         -5.459376
# 2            CCV_cw     80.035646      0.486499         -6.405319
# 3         LSTM_pred     66.567544      0.151147         -5.238724
# 4          GRU_pred    132.372422      1.002397         -3.650123
# 5     LSTM_GRU_pred     51.062411      0.129458         -7.811004
# 6       BiLSTM_pred     56.983770      0.040843         -6.100306
# 7   BiLSTM_GRU_pred     30.896036     -0.246127         -8.407473
# 8         QRNN_pred     31.720948     -0.243959         -5.990680
# 9          ESN_pred     50.586785     -0.042735         -5.276888
# 10         BNN_pred    123.045886      1.010297         -3.542659
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     94.871913      0.431795         -5.512295
# 1            CCV_dw     79.492420      0.297474         -6.073184
# 2            CCV_cw     87.275527      0.512991         -6.162709
# 3         LSTM_pred     53.403815      0.004409         -6.797295
# 4          GRU_pred    144.910604      1.109712         -3.633456
# 5     LSTM_GRU_pred     15.579892     -0.258579         -8.028020
# 6       BiLSTM_pred    107.174957      0.571728         -7.347213
# 7   BiLSTM_GRU_pred     65.478526      0.132394         -7.591736
# 8         QRNN_pred     64.158944      0.118016         -6.447317
# 9          ESN_pred     85.143280      0.359987         -5.314202
# 10         BNN_pred     79.533598      0.439435         -5.404885
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      9.966926     -0.548231         -7.803275
# 1            CCV_dw    -52.680248     -1.224703         -8.588614
# 2            CCV_cw     89.325765      0.536057         -6.598433
# 3         LSTM_pred     60.329186      0.078923         -7.352105
# 4          GRU_pred     35.750459     -0.208234         -6.929734
# 5     LSTM_GRU_pred    116.907389      0.667443         -6.400180
# 6       BiLSTM_pred     95.593926      0.513764         -3.999387
# 7   BiLSTM_GRU_pred     56.132708      0.033697         -7.271314
# 8         QRNN_pred    -23.794975     -1.016356         -8.595999
# 9          ESN_pred     20.769409     -0.373027         -5.717542
# 10         BNN_pred    142.498653      1.032175         -3.877143
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     63.084448      0.108265         -5.119530
# 1            CCV_dw    -11.521442     -0.686843         -7.451396
# 2            CCV_cw    133.484379      0.925471         -7.028837
# 3         LSTM_pred     69.698547      0.173791         -7.352105
# 4          GRU_pred     68.077777      0.157685         -7.408200
# 5     LSTM_GRU_pred    110.632815      0.571606         -6.402583
# 6       BiLSTM_pred     71.072095      0.191337         -6.742808
# 7   BiLSTM_GRU_pred     70.455875      0.185591         -7.295860
# 8         QRNN_pred     31.720948     -0.243959         -5.990680
# 9          ESN_pred     93.156627      0.411812         -4.656252
# 10         BNN_pred    170.704076      1.219309         -4.373918
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    112.712807      0.580261         -5.406858
# 1            CCV_dw     17.391605     -0.354236         -7.847431
# 2            CCV_cw    148.434431      1.057919         -6.246977
# 3         LSTM_pred     74.764620      0.221361         -6.692437
# 4          GRU_pred    106.951538      0.517256         -6.909409
# 5     LSTM_GRU_pred     87.932662      0.346365         -6.536176
# 6       BiLSTM_pred    119.455031      0.647935         -6.970214
# 7   BiLSTM_GRU_pred    107.517321      0.545297         -6.433046
# 8         QRNN_pred    111.680048      0.572446         -5.458510
# 9          ESN_pred    131.879045      0.778387         -4.445279
# 10         BNN_pred    160.936876      1.067855         -5.343110
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      9.966926     -0.548231         -7.803275
# 1            CCV_dw     77.069151      0.237217         -7.042008
# 2            CCV_cw     60.518903      0.080883         -6.706684
# 3         LSTM_pred     91.105360      0.366887         -7.028083
# 4          GRU_pred     91.105162      0.372610         -6.380922
# 5     LSTM_GRU_pred     92.215667      0.396652         -6.544869
# 6       BiLSTM_pred     77.730214      0.251714         -5.800544
# 7   BiLSTM_GRU_pred     76.408911      0.246771         -7.134345
# 8         QRNN_pred    -23.794975     -1.016356         -8.595999
# 9          ESN_pred     67.514494      0.151755         -5.842399
# 10         BNN_pred     73.853412      0.209135         -7.679938
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     63.084448      0.108265         -5.119530
# 1            CCV_dw    104.214932      0.484639         -6.439796
# 2            CCV_cw    103.509756      0.482399         -7.144149
# 3         LSTM_pred    100.746667      0.453786         -7.028083
# 4          GRU_pred     78.677613      0.252545         -7.866949
# 5     LSTM_GRU_pred    111.843399      0.552040         -6.395612
# 6       BiLSTM_pred    114.298026      0.582334         -5.709276
# 7   BiLSTM_GRU_pred     98.385458      0.450392         -7.110342
# 8         QRNN_pred     31.720948     -0.243959         -5.990680
# 9          ESN_pred    109.950619      0.552149         -5.469073
# 10         BNN_pred    105.093996      0.493562         -6.952577
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    107.427183      0.530142         -5.853144
# 1            CCV_dw    111.631510      0.551035         -6.396831
# 2            CCV_cw    118.064459      0.611351         -6.349463
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    112.700948      0.560311         -6.952577
# 5     LSTM_GRU_pred    116.206879      0.590917         -6.370610
# 6       BiLSTM_pred    100.746667      0.453786         -7.028083
# 7   BiLSTM_GRU_pred    119.924515      0.623770         -6.349463
# 8         QRNN_pred    111.680048      0.572446         -5.458510
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    149.652646      0.941693         -4.425024
# 1            CCV_dw     57.122715      0.046674         -8.686641
# 2            CCV_cw    163.441459      1.060127         -5.101629
# 3         LSTM_pred     61.397391      0.089819         -6.308450
# 4          GRU_pred     93.724897      0.406926         -5.260730
# 5     LSTM_GRU_pred     71.220613      0.328666         -6.826186
# 6       BiLSTM_pred    107.796684      0.537907         -5.974483
# 7   BiLSTM_GRU_pred    110.943788      0.566942         -6.413205
# 8         QRNN_pred    129.204186      0.737416         -4.436474
# 9          ESN_pred     79.119267      0.271575         -6.012344
# 10         BNN_pred    146.075952      0.954731         -5.179320
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     60.858419      0.084303         -6.077237
# 1            CCV_dw    105.243852      0.575660         -4.705655
# 2            CCV_cw    129.411238      1.015035         -2.864471
# 3         LSTM_pred    101.730014      0.685812         -4.585411
# 4          GRU_pred    178.721325      1.507417         -3.437031
# 5     LSTM_GRU_pred     30.705751     -0.089724         -8.576119
# 6       BiLSTM_pred    127.522482      0.972548         -3.961931
# 7   BiLSTM_GRU_pred     79.314475      0.276307         -8.188557
# 8         QRNN_pred     84.489766      0.325298         -5.612528
# 9          ESN_pred    -13.179208     -0.601356         -8.166689
# 10         BNN_pred    113.091364      0.833272         -3.627005
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -1.233634     -0.735292         -6.896508
# 1            CCV_dw    -37.960237     -1.615617         -6.030911
# 2            CCV_cw     14.875232     -0.416829         -4.714927
# 3         LSTM_pred     83.921992      0.576294         -2.853623
# 4          GRU_pred     75.059044      0.453472         -1.478319
# 5     LSTM_GRU_pred     88.221874      0.641808         -4.897020
# 6       BiLSTM_pred     62.902930      0.342656         -4.141221
# 7   BiLSTM_GRU_pred    103.940474      0.951510         -4.291251
# 8         QRNN_pred     28.518609     -0.364667         -4.932598
# 9          ESN_pred    -36.299081     -1.292255         -7.152056
# 10         BNN_pred     74.620857      0.538516         -3.027161
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     17.019223     -0.453469         -7.161060
# 1            CCV_dw     -6.489348     -0.656535         -6.523372
# 2            CCV_cw     56.661129      0.223865         -4.195569
# 3         LSTM_pred     65.206872      0.321865         -3.407217
# 4          GRU_pred    132.372422      1.002397         -3.650123
# 5     LSTM_GRU_pred     38.623841     -0.012212         -8.552219
# 6       BiLSTM_pred     61.918835      0.296752         -5.112139
# 7   BiLSTM_GRU_pred     62.344644      0.103691         -5.216842
# 8         QRNN_pred      7.826089     -0.553410         -7.706857
# 9          ESN_pred    -14.255034     -0.744167         -5.667117
# 10         BNN_pred    107.691822      0.908696         -2.409170
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     27.131129     -0.293268         -7.711281
# 1            CCV_dw     40.435195     -0.170275         -5.206949
# 2            CCV_cw    145.855582      1.259297         -2.842701
# 3         LSTM_pred     58.031947      0.215129         -4.856252
# 4          GRU_pred    121.025353      0.917500         -4.713196
# 5     LSTM_GRU_pred     14.555640     -0.274483         -8.669627
# 6       BiLSTM_pred    104.641481      0.802394         -4.290627
# 7   BiLSTM_GRU_pred     22.702654     -0.336632         -8.549312
# 8         QRNN_pred     63.353559      0.110557         -5.918892
# 9          ESN_pred    -17.841377     -0.704007         -7.458073
# 10         BNN_pred    106.098912      0.766949         -3.506248
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -0.798475     -0.689982         -7.803275
# 1            CCV_dw    -70.751887     -1.723485         -9.479197
# 2            CCV_cw     75.741640      0.406844         -6.281902
# 3         LSTM_pred     59.044837      0.064050         -6.844978
# 4          GRU_pred    -22.265271     -1.089800         -8.394667
# 5     LSTM_GRU_pred    114.303474      0.899867         -4.188678
# 6       BiLSTM_pred     75.193774      0.269490         -4.054250
# 7   BiLSTM_GRU_pred     69.592664      0.178733         -7.179810
# 8         QRNN_pred     28.518609     -0.364667         -4.932598
# 9          ESN_pred     10.622862     -0.569539         -4.699388
# 10         BNN_pred    133.226623      1.045569         -3.550575
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     20.357120     -0.382995         -7.772263
# 1            CCV_dw    -25.112145     -0.887832         -8.120154
# 2            CCV_cw     90.576636      0.545699         -6.399842
# 3         LSTM_pred     24.242907     -0.317846         -7.038263
# 4          GRU_pred     28.498413     -0.262998         -7.508034
# 5     LSTM_GRU_pred     74.741411      0.385236         -6.803824
# 6       BiLSTM_pred     56.557932      0.034557         -6.438742
# 7   BiLSTM_GRU_pred     84.602438      0.337764         -7.101967
# 8         QRNN_pred      7.826089     -0.553410         -7.706857
# 9          ESN_pred     16.928021     -0.429964         -5.669785
# 10         BNN_pred    126.288952      0.872423         -4.139808
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     94.973868      0.433172         -4.490995
# 1            CCV_dw      3.372366     -0.541606         -8.120154
# 2            CCV_cw    139.473391      1.008628         -5.753853
# 3         LSTM_pred     37.395912     -0.161646         -6.478722
# 4          GRU_pred     31.335792     -0.216073         -6.997550
# 5     LSTM_GRU_pred     44.227761      0.054799         -7.002640
# 6       BiLSTM_pred     73.993343      0.217412         -6.984525
# 7   BiLSTM_GRU_pred     95.464116      0.436309         -6.485751
# 8         QRNN_pred     69.819697      0.175501         -5.385785
# 9          ESN_pred     37.268799     -0.174127         -5.058687
# 10         BNN_pred    119.481867      0.701012         -5.269691
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -0.798475     -0.689982         -7.803275
# 1            CCV_dw     77.069151      0.237217         -7.042008
# 2            CCV_cw     61.559126      0.091465         -6.299161
# 3         LSTM_pred     91.105360      0.366887         -7.028083
# 4          GRU_pred    100.716380      0.463897         -6.322824
# 5     LSTM_GRU_pred    102.675507      0.503888         -6.482785
# 6       BiLSTM_pred     76.377941      0.238409         -5.800544
# 7   BiLSTM_GRU_pred     76.408911      0.246771         -7.134345
# 8         QRNN_pred     28.518609     -0.364667         -4.932598
# 9          ESN_pred     10.676350     -0.475751         -9.649829
# 10         BNN_pred     73.853412      0.209135         -7.679938
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     20.357120     -0.382995         -7.772263
# 1            CCV_dw    101.664618      0.461631         -6.454704
# 2            CCV_cw     76.350249      0.232783         -7.646904
# 3         LSTM_pred     91.105360      0.366887         -7.028083
# 4          GRU_pred     78.677613      0.252545         -7.866949
# 5     LSTM_GRU_pred    104.179817      0.487434         -6.440001
# 6       BiLSTM_pred    109.173835      0.538113         -6.183795
# 7   BiLSTM_GRU_pred     95.311302      0.421014         -7.032531
# 8         QRNN_pred      7.826089     -0.553410         -7.706857
# 9          ESN_pred     89.928146      0.372042         -5.479403
# 10         BNN_pred     94.792287      0.400682         -7.017999
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     76.514781      0.238564         -5.764284
# 1            CCV_dw    107.892628      0.517635         -6.418419
# 2            CCV_cw    106.432972      0.507968         -7.076660
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    104.910246      0.491425         -6.864566
# 5     LSTM_GRU_pred    116.206879      0.590917         -6.370610
# 6       BiLSTM_pred    100.746667      0.453786         -7.028083
# 7   BiLSTM_GRU_pred    114.347895      0.575447         -6.381238
# 8         QRNN_pred     59.139481      0.066894         -6.371644
# 9          ESN_pred    112.098476      0.572120         -5.458510
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y2', file, 'CCV')
get_final_results_1('2022_y2', file, 'CCV')

get_final_results('2022_y2', dw_file, 'CCV_dw')
get_final_results_1('2022_y2', dw_file, 'CCV_dw')

get_final_results('2022_y2', cw_file, 'CCV_cw')
get_final_results_1('2022_y2', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-29-32a985079057>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-29-32a985079057>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-29-32a985079057>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -32.006109     -0.450302        -16.035561
# 1            CCV_dw    -29.789652     -0.448006        -18.718334
# 2            CCV_cw    -10.339739     -0.296975        -15.774136
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -63.103049     -0.686641        -16.320926
# 5     LSTM_GRU_pred    -63.103049     -0.686641        -16.320926
# 6       BiLSTM_pred    -22.516559     -0.381649        -16.254849
# 7   BiLSTM_GRU_pred    -31.058994     -0.444259        -17.049531
# 8         QRNN_pred    -10.339739     -0.296975        -15.774136
# 9          ESN_pred    -37.402798     -0.491232        -17.049531
# 10         BNN_pred    -11.228949     -0.302595        -15.554671
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -27.918679     -0.429979        -16.035561
# 1            CCV_dw     35.627665      0.007773        -14.555359
# 2            CCV_cw    -11.251207     -0.317165        -14.950626
# 3         LSTM_pred    -80.654901     -0.900673        -16.456312
# 4          GRU_pred    -42.878550     -0.543755        -16.098501
# 5     LSTM_GRU_pred    -61.083141     -0.721849        -16.384959
# 6       BiLSTM_pred     -9.448779     -0.309406        -14.059806
# 7   BiLSTM_GRU_pred     -7.175204     -0.316398        -13.548522
# 8         QRNN_pred      1.752686     -0.220028        -15.787673
# 9          ESN_pred     24.726070     -0.066338        -14.283370
# 10         BNN_pred    -14.981001     -0.356936        -12.948839
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -66.251387     -0.765919        -16.035561
# 1            CCV_dw     44.082956      0.064243        -14.570470
# 2            CCV_cw   -104.409719     -1.173634        -17.479080
# 3         LSTM_pred   -140.746690     -1.517607        -17.880711
# 4          GRU_pred    -41.931737     -0.573905        -14.195778
# 5     LSTM_GRU_pred    -75.614276     -0.890995        -15.446259
# 6       BiLSTM_pred    -91.717297     -1.016546        -15.196756
# 7   BiLSTM_GRU_pred   -151.930003     -2.109019        -16.773998
# 8         QRNN_pred    -67.498789     -0.826119        -17.243913
# 9          ESN_pred    -77.078650     -1.016082        -14.619813
# 10         BNN_pred    -38.323273     -0.597855        -13.583407
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.811611     -0.344215        -15.971820
# 1            CCV_dw     23.272721     -0.082997        -15.190846
# 2            CCV_cw   -105.083568     -1.144830        -18.786003
# 3         LSTM_pred    -96.192011     -1.039761        -17.753076
# 4          GRU_pred    -78.121591     -0.819503        -16.771894
# 5     LSTM_GRU_pred   -116.614026     -1.215379        -17.056054
# 6       BiLSTM_pred    -72.548726     -0.810806        -14.510618
# 7   BiLSTM_GRU_pred    -73.676335     -0.915233        -13.552742
# 8         QRNN_pred    -32.406889     -0.497613        -16.035561
# 9          ESN_pred    -22.261686     -0.471111        -14.256658
# 10         BNN_pred    -29.179657     -0.468480        -12.871150
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -27.918679     -0.429979        -16.035561
# 1            CCV_dw     26.155250     -0.061724        -14.735117
# 2            CCV_cw     -2.336306     -0.254005        -14.819270
# 3         LSTM_pred    -80.654901     -0.900673        -16.456312
# 4          GRU_pred    -42.878550     -0.543755        -16.098501
# 5     LSTM_GRU_pred    -61.083141     -0.721849        -16.384959
# 6       BiLSTM_pred    -12.815299     -0.334120        -14.059806
# 7   BiLSTM_GRU_pred     -7.175204     -0.316398        -13.548522
# 8         QRNN_pred    -26.964190     -0.435178        -16.035561
# 9          ESN_pred     27.424271     -0.047239        -14.283370
# 10         BNN_pred    -14.981001     -0.356936        -12.948839
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -50.746796     -0.636017        -16.035561
# 1            CCV_dw    -14.827197     -0.363941        -17.440303
# 2            CCV_cw    -67.685460     -0.749000        -16.035561
# 3         LSTM_pred    -76.511966     -0.806456        -16.163149
# 4          GRU_pred    -82.623441     -0.878286        -15.867551
# 5     LSTM_GRU_pred    -88.000414     -0.922490        -15.867551
# 6       BiLSTM_pred    -67.229996     -0.731433        -15.937404
# 7   BiLSTM_GRU_pred   -120.259859     -1.393083        -18.236509
# 8         QRNN_pred    -67.498789     -0.826119        -17.243913
# 9          ESN_pred    -44.695384     -0.613217        -13.584098
# 10         BNN_pred    -18.849728     -0.382683        -16.237555
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -22.853615     -0.386275        -15.983096
# 1            CCV_dw    -32.515029     -0.468419        -19.128046
# 2            CCV_cw    -71.919927     -0.771011        -16.935304
# 3         LSTM_pred    -20.556200     -0.367701        -15.916361
# 4          GRU_pred    -97.601384     -0.961239        -16.992534
# 5     LSTM_GRU_pred   -118.514470     -1.147203        -16.992534
# 6       BiLSTM_pred    -56.381784     -0.638947        -16.320926
# 7   BiLSTM_GRU_pred    -79.600092     -0.824455        -17.049531
# 8         QRNN_pred    -32.406889     -0.497613        -16.035561
# 9          ESN_pred     11.687637     -0.155020        -13.217715
# 10         BNN_pred    -11.228949     -0.302595        -15.554671
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -32.006109     -0.450302        -16.035561
# 1            CCV_dw    -29.789652     -0.448006        -18.718334
# 2            CCV_cw    -18.888280     -0.357889        -15.911578
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -63.103049     -0.686641        -16.320926
# 5     LSTM_GRU_pred    -63.103049     -0.686641        -16.320926
# 6       BiLSTM_pred    -22.516559     -0.381649        -16.254849
# 7   BiLSTM_GRU_pred    -31.058994     -0.444259        -17.049531
# 8         QRNN_pred    -33.275113     -0.467710        -16.035561
# 9          ESN_pred    -43.499581     -0.536051        -17.297533
# 10         BNN_pred    -11.228949     -0.302595        -15.554671
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -46.742956     -0.596940        -16.035561
# 1            CCV_dw    -33.329558     -0.485872        -17.243913
# 2            CCV_cw    -59.935840     -0.678064        -16.035561
# 3         LSTM_pred    -76.511966     -0.806456        -16.163149
# 4          GRU_pred    -41.117418     -0.523493        -15.965790
# 5     LSTM_GRU_pred    -46.737668     -0.565291        -15.965790
# 6       BiLSTM_pred    -68.319167     -0.734292        -16.035561
# 7   BiLSTM_GRU_pred   -109.477282     -1.281051        -17.234371
# 8         QRNN_pred    -59.481408     -0.744582        -17.243913
# 9          ESN_pred    -31.032606     -0.459482        -16.035561
# 10         BNN_pred    -51.075963     -0.612336        -16.719255
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -18.756615     -0.355015        -15.916361
# 1            CCV_dw    -19.183123     -0.358012        -15.916361
# 2            CCV_cw    -78.332658     -0.814097        -16.935304
# 3         LSTM_pred    -20.556200     -0.367701        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -41.913551     -0.529297        -16.035561
# 6       BiLSTM_pred    -53.163836     -0.614775        -16.035561
# 7   BiLSTM_GRU_pred    -68.319167     -0.734292        -16.035561
# 8         QRNN_pred    -42.824507     -0.572646        -16.035561
# 9          ESN_pred     -0.323005     -0.230716        -15.916361
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -19.183123     -0.358012        -15.916361
# 1            CCV_dw    -19.183123     -0.358012        -15.916361
# 2            CCV_cw    -19.183123     -0.358012        -15.916361
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred    -41.913551     -0.529297        -16.035561
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -28.163617     -0.422674        -16.035561
# 1            CCV_dw    -29.789652     -0.448006        -18.718334
# 2            CCV_cw    -19.183123     -0.358012        -15.916361
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -50.380000     -0.588601        -16.320926
# 5     LSTM_GRU_pred    -50.380000     -0.588601        -16.320926
# 6       BiLSTM_pred    -45.387485     -0.550185        -16.320926
# 7   BiLSTM_GRU_pred    -61.047545     -0.700355        -17.049531
# 8         QRNN_pred     -4.811374     -0.263652        -16.035561
# 9          ESN_pred    -59.258257     -0.716232        -16.035561
# 10         BNN_pred    -15.284127     -0.330762        -15.618727
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -7.292106     -0.279432        -16.035561
# 1            CCV_dw    -15.940243     -0.368031        -16.365481
# 2            CCV_cw    -75.920010     -0.802660        -16.851590
# 3         LSTM_pred    -39.436739     -0.582136        -14.010447
# 4          GRU_pred    -34.696487     -0.489624        -16.098501
# 5     LSTM_GRU_pred    -54.859248     -0.670319        -16.098501
# 6       BiLSTM_pred     10.731763     -0.166796        -13.593010
# 7   BiLSTM_GRU_pred    -18.882641     -0.400475        -16.225075
# 8         QRNN_pred    -36.149325     -0.505788        -16.387586
# 9          ESN_pred     26.003197     -0.054792        -15.121049
# 10         BNN_pred    -42.348879     -0.538680        -16.115744
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -75.297334     -0.864333        -16.652624
# 1            CCV_dw     12.227084     -0.180453        -14.599524
# 2            CCV_cw    -43.605369     -0.642308        -16.903792
# 3         LSTM_pred   -119.232887     -1.343315        -16.192625
# 4          GRU_pred    -19.264824     -0.417946        -13.195138
# 5     LSTM_GRU_pred    -54.428870     -0.731483        -14.195778
# 6       BiLSTM_pred    -59.948575     -0.777165        -13.655295
# 7   BiLSTM_GRU_pred   -171.613064     -2.374295        -18.274765
# 8         QRNN_pred    -50.736183     -0.740922        -14.650844
# 9          ESN_pred    -30.856870     -0.561560        -13.792458
# 10         BNN_pred    -44.399943     -0.604951        -16.801477
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -8.774284     -0.300049        -15.919901
# 1            CCV_dw     -2.396384     -0.270591        -15.207178
# 2            CCV_cw   -102.713983     -1.050681        -16.035561
# 3         LSTM_pred    -74.128384     -0.896420        -15.092744
# 4          GRU_pred    -69.088757     -0.758636        -16.771894
# 5     LSTM_GRU_pred   -109.656391     -1.151112        -16.771894
# 6       BiLSTM_pred    -15.850674     -0.384631        -13.802478
# 7   BiLSTM_GRU_pred   -103.018097     -1.211120        -16.320926
# 8         QRNN_pred    -64.295061     -0.771284        -16.652624
# 9          ESN_pred    -21.220972     -0.452701        -15.472089
# 10         BNN_pred    -46.135285     -0.566973        -16.115744
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -7.292106     -0.279432        -16.035561
# 1            CCV_dw    -13.733113     -0.351563        -16.328857
# 2            CCV_cw    -53.451016     -0.631066        -16.035561
# 3         LSTM_pred    -39.436739     -0.582136        -14.010447
# 4          GRU_pred    -38.536316     -0.519195        -16.098501
# 5     LSTM_GRU_pred    -58.618873     -0.701419        -16.098501
# 6       BiLSTM_pred      1.107137     -0.237456        -13.723693
# 7   BiLSTM_GRU_pred    -78.038594     -0.899489        -16.320926
# 8         QRNN_pred    -67.417473     -0.771339        -17.221535
# 9          ESN_pred    -15.918203     -0.401676        -15.616175
# 10         BNN_pred    -42.348879     -0.538680        -16.115744
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -75.297334     -0.864333        -16.652624
# 1            CCV_dw    -14.827197     -0.363941        -17.440303
# 2            CCV_cw    -62.833583     -0.706069        -17.023536
# 3         LSTM_pred    -76.511966     -0.806456        -16.163149
# 4          GRU_pred    -69.794228     -0.786455        -14.886407
# 5     LSTM_GRU_pred    -80.517139     -0.868626        -15.867551
# 6       BiLSTM_pred    -76.587552     -0.831514        -16.324547
# 7   BiLSTM_GRU_pred   -157.202926     -1.918752        -18.200954
# 8         QRNN_pred    -50.736183     -0.740922        -14.650844
# 9          ESN_pred    -75.686574     -0.918468        -16.035561
# 10         BNN_pred    -47.303749     -0.584142        -16.388193
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -8.774284     -0.300049        -15.919901
# 1            CCV_dw    -19.512588     -0.377604        -17.912502
# 2            CCV_cw    -66.880767     -0.729784        -16.035561
# 3         LSTM_pred    -40.909095     -0.526708        -14.985792
# 4          GRU_pred    -83.924987     -0.849616        -16.992534
# 5     LSTM_GRU_pred   -105.155023     -1.032673        -16.992534
# 6       BiLSTM_pred    -64.145219     -0.714088        -16.320926
# 7   BiLSTM_GRU_pred    -98.508600     -1.062981        -18.236509
# 8         QRNN_pred    -64.295061     -0.771284        -16.652624
# 9          ESN_pred    -50.793414     -0.677512        -16.035561
# 10         BNN_pred    -15.284127     -0.330762        -15.618727
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -28.163617     -0.422674        -16.035561
# 1            CCV_dw    -27.613585     -0.432216        -18.718334
# 2            CCV_cw    -18.756615     -0.355015        -15.916361
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -59.422693     -0.657253        -16.320926
# 5     LSTM_GRU_pred    -59.422693     -0.657253        -16.320926
# 6       BiLSTM_pred    -50.701556     -0.589604        -16.320926
# 7   BiLSTM_GRU_pred    -61.047545     -0.700355        -17.049531
# 8         QRNN_pred    -61.982590     -0.717101        -16.035561
# 9          ESN_pred    -63.617166     -0.766906        -16.035561
# 10         BNN_pred    -15.284127     -0.330762        -15.618727
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -76.800227     -0.865859        -16.652624
# 1            CCV_dw    -33.329558     -0.485872        -17.243913
# 2            CCV_cw    -62.833583     -0.706069        -17.023536
# 3         LSTM_pred    -76.511966     -0.806456        -16.163149
# 4          GRU_pred    -29.935032     -0.444330        -14.985792
# 5     LSTM_GRU_pred    -41.117418     -0.523493        -15.965790
# 6       BiLSTM_pred    -81.651030     -0.841916        -17.234371
# 7   BiLSTM_GRU_pred   -109.090039     -1.277373        -17.198380
# 8         QRNN_pred    -42.574682     -0.654575        -14.650844
# 9          ESN_pred      5.190880     -0.192510        -15.916361
# 10         BNN_pred    -51.075963     -0.612336        -16.719255
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -8.553839     -0.296545        -15.916361
# 1            CCV_dw    -19.183123     -0.358012        -15.916361
# 2            CCV_cw    -66.880767     -0.729784        -16.035561
# 3         LSTM_pred    -40.909095     -0.526708        -14.985792
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -41.913551     -0.529297        -16.035561
# 6       BiLSTM_pred    -53.163836     -0.614775        -16.035561
# 7   BiLSTM_GRU_pred    -81.651030     -0.841916        -17.234371
# 8         QRNN_pred    -74.369354     -0.846079        -16.652624
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -19.183123     -0.358012        -15.916361
# 1            CCV_dw    -19.183123     -0.358012        -15.916361
# 2            CCV_cw    -18.756615     -0.355015        -15.916361
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred    -57.802191     -0.680294        -16.035561
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -48.154018     -0.575691        -17.046143
# 1            CCV_dw    -23.904952     -0.428216        -16.513347
# 2            CCV_cw     -2.073248     -0.247314        -15.972075
# 3         LSTM_pred    -33.991777     -0.482480        -15.784374
# 4          GRU_pred    -48.124967     -0.613257        -15.297751
# 5     LSTM_GRU_pred    -56.384144     -0.672990        -16.098501
# 6       BiLSTM_pred     10.898379     -0.175732        -13.599135
# 7   BiLSTM_GRU_pred    -92.522994     -0.968903        -17.331449
# 8         QRNN_pred    -13.990743     -0.329911        -15.745343
# 9          ESN_pred      6.453923     -0.183477        -13.937626
# 10         BNN_pred    -15.523156     -0.364834        -12.967221
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -39.317513     -0.631558        -13.039502
# 1            CCV_dw     -1.800920     -0.284588        -15.179499
# 2            CCV_cw    -33.247781     -0.513268        -15.056377
# 3         LSTM_pred    -22.415563     -0.426246        -17.388073
# 4          GRU_pred    -42.840277     -0.781689        -12.941076
# 5     LSTM_GRU_pred   -106.180076     -1.308743        -15.789194
# 6       BiLSTM_pred      8.708148     -0.196315        -14.798888
# 7   BiLSTM_GRU_pred    -48.277235     -0.791445        -10.625221
# 8         QRNN_pred    -53.371742     -0.726257        -16.267759
# 9          ESN_pred     44.313101      0.072501        -13.145104
# 10         BNN_pred    -34.651865     -0.555528        -10.924474
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     14.046295     -0.358749         -5.313069
# 1            CCV_dw    108.457181      0.660454         -6.869124
# 2            CCV_cw    -78.287011     -1.135282        -14.683943
# 3         LSTM_pred   -147.701180     -1.868110        -17.648499
# 4          GRU_pred    -39.295635     -0.910224        -11.130726
# 5     LSTM_GRU_pred    -70.676633     -1.247753        -12.012360
# 6       BiLSTM_pred   -118.332194     -1.766505        -13.090734
# 7   BiLSTM_GRU_pred     -7.382972     -0.737075         -6.679323
# 8         QRNN_pred    -36.160081     -1.418988         -5.433423
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred     27.421999     -0.099474         -9.091925
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     13.981327     -0.276464         -4.949045
# 1            CCV_dw      0.119619     -0.291132        -13.096536
# 2            CCV_cw    -81.518326     -1.129473        -14.985792
# 3         LSTM_pred   -153.516209     -1.926823        -18.509811
# 4          GRU_pred      2.160423     -0.315339        -11.784109
# 5     LSTM_GRU_pred   -103.617654     -1.420886        -14.960418
# 6       BiLSTM_pred     -8.793193     -0.377675        -12.787444
# 7   BiLSTM_GRU_pred    -57.666331     -0.997293        -11.463370
# 8         QRNN_pred     -0.334017     -0.492156         -6.699652
# 9          ESN_pred     45.687127      0.080001        -12.243861
# 10         BNN_pred    -43.143163     -0.680094        -10.980953
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -53.768072     -0.804800        -11.189346
# 1            CCV_dw     36.586027      0.008372        -13.092117
# 2            CCV_cw    -75.514953     -1.002893        -15.056377
# 3         LSTM_pred    -20.033900     -0.426083        -17.395442
# 4          GRU_pred    -68.108794     -1.072587        -13.887028
# 5     LSTM_GRU_pred    -86.565830     -1.010221        -17.513577
# 6       BiLSTM_pred     25.384733     -0.079171        -12.281431
# 7   BiLSTM_GRU_pred    -53.772761     -0.883477        -10.625221
# 8         QRNN_pred     49.084709      0.101974         -9.552709
# 9          ESN_pred     71.609840      0.258478        -12.243861
# 10         BNN_pred    -38.542613     -0.612484        -10.924474
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     14.046295     -0.358749         -5.313069
# 1            CCV_dw     72.703524      0.309377        -10.266452
# 2            CCV_cw    -78.287011     -1.135282        -14.683943
# 3         LSTM_pred   -115.181200     -1.220509        -17.135990
# 4          GRU_pred    -63.017022     -0.953582        -12.012360
# 5     LSTM_GRU_pred    -82.553381     -1.150367        -11.055563
# 6       BiLSTM_pred   -110.610593     -1.441252        -13.070349
# 7   BiLSTM_GRU_pred     31.176096     -0.071278         -6.307517
# 8         QRNN_pred    -36.160081     -1.418988         -5.433423
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred     -2.008565     -0.329663        -13.402698
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.190859      0.289404         -4.882245
# 1            CCV_dw    -10.980374     -0.353618        -16.053259
# 2            CCV_cw    -81.518326     -1.129473        -14.985792
# 3         LSTM_pred   -104.362180     -1.110030        -16.240202
# 4          GRU_pred    -16.148713     -0.393515        -12.659261
# 5     LSTM_GRU_pred    -71.773596     -0.977270        -14.195778
# 6       BiLSTM_pred    -55.934729     -0.742542        -14.494299
# 7   BiLSTM_GRU_pred    -76.233393     -0.871038        -16.708196
# 8         QRNN_pred     -0.334017     -0.492156         -6.699652
# 9          ESN_pred     59.357098      0.176239        -12.243861
# 10         BNN_pred    -45.825008     -0.651414        -13.807591
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.431863     -0.343941        -14.793338
# 1            CCV_dw     -3.105943     -0.276683        -15.231217
# 2            CCV_cw    -48.631086     -0.636033        -16.035561
# 3         LSTM_pred    -11.777585     -0.327887        -14.786358
# 4          GRU_pred    -97.734921     -1.016320        -17.032197
# 5     LSTM_GRU_pred    -70.949387     -0.809679        -16.771894
# 6       BiLSTM_pred     -7.240893     -0.315127        -13.765197
# 7   BiLSTM_GRU_pred    -65.031991     -0.771131        -17.331449
# 8         QRNN_pred     39.272175      0.036808        -11.007508
# 9          ESN_pred     46.786269      0.089438        -12.243861
# 10         BNN_pred    -34.853584     -0.536524        -13.102131
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     14.046295     -0.358749         -5.313069
# 1            CCV_dw    -69.760099     -0.814851        -16.914561
# 2            CCV_cw    -78.287011     -1.135282        -14.683943
# 3         LSTM_pred    -72.836682     -0.800544        -15.829496
# 4          GRU_pred    -20.657515     -0.379882        -13.446381
# 5     LSTM_GRU_pred    -20.657515     -0.379882        -13.446381
# 6       BiLSTM_pred    -75.254959     -0.793903        -16.541092
# 7   BiLSTM_GRU_pred     -2.140275     -0.334576         -8.525701
# 8         QRNN_pred    -36.160081     -1.418988         -5.433423
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred    -64.780426     -0.708030        -17.438089
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     72.122187      0.287046         -4.734178
# 1            CCV_dw    -65.449416     -0.716028        -18.095539
# 2            CCV_cw    -81.518326     -1.129473        -14.985792
# 3         LSTM_pred    -75.217333     -0.796374        -16.163149
# 4          GRU_pred     -3.529853     -0.251298        -13.865808
# 5     LSTM_GRU_pred    -18.368102     -0.352291        -15.833951
# 6       BiLSTM_pred    -53.163836     -0.614775        -16.035561
# 7   BiLSTM_GRU_pred    -11.788565     -0.306832        -15.173647
# 8         QRNN_pred     -0.334017     -0.492156         -6.699652
# 9          ESN_pred     15.642658     -0.128327        -15.916361
# 10         BNN_pred    -59.085137     -0.659375        -16.935304
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.814904     -0.342571        -15.576671
# 1            CCV_dw    -19.183123     -0.358012        -15.916361
# 2            CCV_cw    -55.640776     -0.640450        -16.035561
# 3         LSTM_pred    -24.507927     -0.396035        -16.010201
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred     30.867562     -0.021425        -11.097252
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -43.254808     -0.539141        -16.035561
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.766883     -0.330226        -11.960494
# 1            CCV_dw     -8.460873     -0.327590        -13.729750
# 2            CCV_cw    -65.252291     -0.747546        -16.035561
# 3         LSTM_pred    -88.562489     -1.006705        -17.441552
# 4          GRU_pred    -41.185262     -0.560660        -15.297751
# 5     LSTM_GRU_pred    -41.185262     -0.560660        -15.297751
# 6       BiLSTM_pred    -23.695377     -0.443355        -13.802478
# 7   BiLSTM_GRU_pred     -1.499296     -0.287464        -15.008848
# 8         QRNN_pred    -38.267517     -0.563786        -12.960752
# 9          ESN_pred     52.701503      0.129698        -13.145104
# 10         BNN_pred      3.281878     -0.230643        -11.354963
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -27.841865     -0.507007        -15.293051
# 1            CCV_dw      1.364828     -0.273485        -13.411246
# 2            CCV_cw    -12.484639     -0.356494        -14.937331
# 3         LSTM_pred    -94.283145     -1.179076        -17.587925
# 4          GRU_pred    -42.840277     -0.781689        -12.941076
# 5     LSTM_GRU_pred    -17.006970     -0.506446        -11.740708
# 6       BiLSTM_pred     61.876178      0.197100        -13.279112
# 7   BiLSTM_GRU_pred    -37.414648     -0.723831        -11.881893
# 8         QRNN_pred    -54.688806     -0.748249        -16.384258
# 9          ESN_pred     26.364901     -0.059428        -12.362259
# 10         BNN_pred     20.126178     -0.127004        -10.532205
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     24.590149     -0.256235         -4.321137
# 1            CCV_dw     89.473036      0.520033         -5.194698
# 2            CCV_cw    -91.250780     -1.399260        -14.683943
# 3         LSTM_pred   -145.933939     -2.398302        -14.709754
# 4          GRU_pred    -71.280402     -1.490622        -11.664602
# 5     LSTM_GRU_pred    -21.917008     -0.791538         -8.385332
# 6       BiLSTM_pred    -96.787369     -1.670940        -12.194972
# 7   BiLSTM_GRU_pred    -73.720966     -3.184168         -7.372097
# 8         QRNN_pred    -51.217406     -1.836417         -6.910764
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred     76.760030      0.379605         -7.223616
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     18.880331     -0.248433         -6.215161
# 1            CCV_dw    -13.654185     -0.441223        -11.861280
# 2            CCV_cw    -92.333945     -1.312485        -14.192599
# 3         LSTM_pred   -167.276247     -2.278675        -19.768170
# 4          GRU_pred      2.160423     -0.315339        -11.784109
# 5     LSTM_GRU_pred    -73.261744     -1.271241        -10.261595
# 6       BiLSTM_pred     -5.183318     -0.366174        -12.624274
# 7   BiLSTM_GRU_pred    -70.219246     -1.325552        -10.307462
# 8         QRNN_pred    -11.180860     -0.681599         -7.772213
# 9          ESN_pred     93.215235      0.447678         -5.518910
# 10         BNN_pred     -4.881098     -0.381706         -9.962289
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.704418     -0.127948         -9.271766
# 1            CCV_dw     -8.848293     -0.385818        -11.987150
# 2            CCV_cw    -16.730797     -0.416422        -15.056377
# 3         LSTM_pred    -98.588488     -1.265746        -17.852857
# 4          GRU_pred      0.186109     -0.330896        -12.157264
# 5     LSTM_GRU_pred      3.952682     -0.284856        -10.876036
# 6       BiLSTM_pred     36.746575      0.003709        -12.269402
# 7   BiLSTM_GRU_pred     27.768997     -0.090129        -10.886311
# 8         QRNN_pred     73.569454      0.322314         -5.785848
# 9          ESN_pred     36.668571      0.012998        -10.454377
# 10         BNN_pred    -33.289013     -0.591951        -11.563348
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     24.590149     -0.256235         -4.321137
# 1            CCV_dw     64.997012      0.252577         -8.366348
# 2            CCV_cw    -78.287011     -1.135282        -14.683943
# 3         LSTM_pred   -151.656160     -2.028923        -15.227519
# 4          GRU_pred    -89.901765     -1.335417        -13.025198
# 5     LSTM_GRU_pred    -77.520943     -1.182526        -13.412837
# 6       BiLSTM_pred   -104.819965     -1.535774        -12.487618
# 7   BiLSTM_GRU_pred    -67.649564     -2.018333         -8.012044
# 8         QRNN_pred    -51.217406     -1.836417         -6.910764
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred     34.300344     -0.029273        -10.209504
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      3.999957     -0.422541         -6.880302
# 1            CCV_dw    -23.941816     -0.479408        -14.447749
# 2            CCV_cw    -72.948777     -1.047668        -14.192599
# 3         LSTM_pred   -184.056260     -2.129459        -18.465165
# 4          GRU_pred      1.701976     -0.257068        -12.659261
# 5     LSTM_GRU_pred    -86.009997     -1.195841        -12.825707
# 6       BiLSTM_pred    -52.564225     -0.755480        -13.655295
# 7   BiLSTM_GRU_pred    -67.333787     -1.065131        -13.061619
# 8         QRNN_pred    -11.180860     -0.681599         -7.772213
# 9          ESN_pred     20.242928     -0.112112        -11.874515
# 10         BNN_pred    -12.599750     -0.403682        -10.416174
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      1.333371     -0.265383         -9.698294
# 1            CCV_dw    -14.493073     -0.394029        -13.518263
# 2            CCV_cw    -69.271557     -0.824525        -16.035561
# 3         LSTM_pred   -103.004050     -1.183626        -16.514695
# 4          GRU_pred    -24.543603     -0.456147        -14.535156
# 5     LSTM_GRU_pred    -24.543603     -0.456147        -14.535156
# 6       BiLSTM_pred    -24.612525     -0.482465        -13.802478
# 7   BiLSTM_GRU_pred    -18.529690     -0.450109        -15.286733
# 8         QRNN_pred     71.930483      0.293813         -4.727487
# 9          ESN_pred     63.269566      0.202267        -12.243861
# 10         BNN_pred    -35.127878     -0.555142        -11.457525
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     24.590149     -0.256235         -4.321137
# 1            CCV_dw    -52.215180     -0.707128        -16.914561
# 2            CCV_cw    -78.287011     -1.135282        -14.683943
# 3         LSTM_pred    -37.246110     -0.574345        -11.192294
# 4          GRU_pred    -56.785334     -0.659322        -16.668866
# 5     LSTM_GRU_pred    -47.357334     -0.583302        -15.875226
# 6       BiLSTM_pred    -69.055952     -0.764532        -15.981627
# 7   BiLSTM_GRU_pred    -41.679367     -0.785921        -10.123956
# 8         QRNN_pred    -51.217406     -1.836417         -6.910764
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred    -68.206538     -0.753407        -17.924030
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      3.999957     -0.422541         -6.880302
# 1            CCV_dw    -84.442486     -0.874660        -18.095539
# 2            CCV_cw    -72.948777     -1.047668        -14.192599
# 3         LSTM_pred    -76.511966     -0.806456        -16.163149
# 4          GRU_pred     -3.529853     -0.251298        -13.865808
# 5     LSTM_GRU_pred    -28.350194     -0.434217        -14.344855
# 6       BiLSTM_pred    -68.319167     -0.734292        -16.035561
# 7   BiLSTM_GRU_pred    -11.788565     -0.306832        -15.173647
# 8         QRNN_pred    -11.180860     -0.681599         -7.772213
# 9          ESN_pred     20.242928     -0.112112        -11.874515
# 10         BNN_pred    -72.549134     -0.765811        -18.123917
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -39.051098     -0.550345        -13.465428
# 1            CCV_dw    -41.913551     -0.529297        -16.035561
# 2            CCV_cw    -67.591911     -0.746941        -16.035561
# 3         LSTM_pred    -12.311793     -0.311772        -14.777338
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -53.163836     -0.614775        -16.035561
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred    112.882049      0.560535         -4.560787
# 9          ESN_pred      9.087479     -0.169787        -15.916361
# 10         BNN_pred    -48.862530     -0.580957        -16.035561
# 11               __    -19.183123     -0.358012        -15.916361

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -32.006109     -0.450302        -16.035561
# 1            CCV_dw    -42.393460     -0.542202        -18.718334
# 2            CCV_cw    -10.339739     -0.296975        -15.774136
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -63.103049     -0.686641        -16.320926
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -22.516559     -0.381649        -16.254849
# 7   BiLSTM_GRU_pred    -39.630012     -0.510798        -16.035561
# 8         QRNN_pred    -10.339739     -0.296975        -15.774136
# 9          ESN_pred     -3.892187     -0.254464        -15.801162
# 10         BNN_pred     -7.871722     -0.280473        -14.730270
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -27.918679     -0.429979        -16.035561
# 1            CCV_dw     32.475605     -0.012482        -14.228108
# 2            CCV_cw    -63.444968     -0.713091        -15.892503
# 3         LSTM_pred    -80.654901     -0.900673        -16.456312
# 4          GRU_pred    -42.878550     -0.543755        -16.098501
# 5     LSTM_GRU_pred    -42.891705     -0.540475        -17.307139
# 6       BiLSTM_pred     -9.448779     -0.309406        -14.059806
# 7   BiLSTM_GRU_pred     27.466954     -0.053734        -12.019427
# 8         QRNN_pred      1.752686     -0.220028        -15.787673
# 9          ESN_pred     57.073033      0.161407        -11.238066
# 10         BNN_pred      1.945142     -0.231286        -11.615906
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -66.251387     -0.765919        -16.035561
# 1            CCV_dw     19.052500     -0.112330        -14.238732
# 2            CCV_cw    -44.055900     -0.613426        -13.584098
# 3         LSTM_pred   -140.746690     -1.517607        -17.880711
# 4          GRU_pred    -41.931737     -0.573905        -14.195778
# 5     LSTM_GRU_pred    -29.628877     -0.465145        -15.964277
# 6       BiLSTM_pred    -91.717297     -1.016546        -15.196756
# 7   BiLSTM_GRU_pred    109.034856      0.551016         -6.246620
# 8         QRNN_pred    -67.498789     -0.826119        -17.243913
# 9          ESN_pred     50.845823      0.119527         -4.941485
# 10         BNN_pred    -17.857604     -0.396788        -11.601620
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.811611     -0.344215        -15.971820
# 1            CCV_dw     14.178862     -0.145357        -14.876833
# 2            CCV_cw    -55.582052     -0.691124        -14.980720
# 3         LSTM_pred    -96.192011     -1.039761        -17.753076
# 4          GRU_pred    -78.121591     -0.819503        -16.771894
# 5     LSTM_GRU_pred    -19.649798     -0.375873        -15.151999
# 6       BiLSTM_pred    -72.548726     -0.810806        -14.510618
# 7   BiLSTM_GRU_pred     77.059123      0.307810         -8.126974
# 8         QRNN_pred    -32.406889     -0.497613        -16.035561
# 9          ESN_pred    108.940839      0.566463         -6.522736
# 10         BNN_pred    -12.497497     -0.341397        -11.554823
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -27.918679     -0.429979        -16.035561
# 1            CCV_dw     17.035774     -0.124386        -14.428892
# 2            CCV_cw    -55.000664     -0.650041        -15.892503
# 3         LSTM_pred    -80.654901     -0.900673        -16.456312
# 4          GRU_pred    -42.878550     -0.543755        -16.098501
# 5     LSTM_GRU_pred    -42.891705     -0.540475        -17.307139
# 6       BiLSTM_pred    -12.815299     -0.334120        -14.059806
# 7   BiLSTM_GRU_pred     27.466954     -0.053734        -12.019427
# 8         QRNN_pred    -26.964190     -0.435178        -16.035561
# 9          ESN_pred     78.341439      0.315277        -11.238066
# 10         BNN_pred      1.945142     -0.231286        -11.615906
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -50.746796     -0.636017        -16.035561
# 1            CCV_dw    -43.953586     -0.561145        -18.554989
# 2            CCV_cw    -67.685460     -0.749000        -16.035561
# 3         LSTM_pred    -76.511966     -0.806456        -16.163149
# 4          GRU_pred    -82.623441     -0.878286        -15.867551
# 5     LSTM_GRU_pred    -20.660040     -0.391442        -16.221339
# 6       BiLSTM_pred    -67.229996     -0.731433        -15.937404
# 7   BiLSTM_GRU_pred    -40.909649     -0.544539        -14.570491
# 8         QRNN_pred    -67.498789     -0.826119        -17.243913
# 9          ESN_pred     87.410758      0.424214         -6.698827
# 10         BNN_pred    -31.947015     -0.459156        -14.997271
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -22.853615     -0.386275        -15.983096
# 1            CCV_dw    -50.680436     -0.605219        -19.128046
# 2            CCV_cw    -71.919927     -0.771011        -16.935304
# 3         LSTM_pred    -20.556200     -0.367701        -15.916361
# 4          GRU_pred    -97.601384     -0.961239        -16.992534
# 5     LSTM_GRU_pred    -13.546826     -0.326288        -15.349239
# 6       BiLSTM_pred    -56.381784     -0.638947        -16.320926
# 7   BiLSTM_GRU_pred    -37.419540     -0.494933        -16.035561
# 8         QRNN_pred    -32.406889     -0.497613        -16.035561
# 9          ESN_pred     80.168802      0.317382        -12.281808
# 10         BNN_pred     -7.871722     -0.280473        -14.730270
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -32.006109     -0.450302        -16.035561
# 1            CCV_dw    -48.006230     -0.584614        -18.718334
# 2            CCV_cw    -18.888280     -0.357889        -15.911578
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -63.103049     -0.686641        -16.320926
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -22.516559     -0.381649        -16.254849
# 7   BiLSTM_GRU_pred    -39.630012     -0.510798        -16.035561
# 8         QRNN_pred    -33.275113     -0.467710        -16.035561
# 9          ESN_pred     16.149593     -0.118079        -15.801162
# 10         BNN_pred     -7.871722     -0.280473        -14.730270
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -46.742956     -0.596940        -16.035561
# 1            CCV_dw    -24.121691     -0.393309        -15.927305
# 2            CCV_cw    -59.935840     -0.678064        -16.035561
# 3         LSTM_pred    -76.511966     -0.806456        -16.163149
# 4          GRU_pred    -41.117418     -0.523493        -15.965790
# 5     LSTM_GRU_pred    -20.660040     -0.391442        -16.221339
# 6       BiLSTM_pred    -68.319167     -0.734292        -16.035561
# 7   BiLSTM_GRU_pred     -4.225559     -0.264553        -14.214163
# 8         QRNN_pred    -59.481408     -0.744582        -17.243913
# 9          ESN_pred     31.201699     -0.043494         -6.868056
# 10         BNN_pred    -43.254808     -0.539141        -16.035561
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -18.756615     -0.355015        -15.916361
# 1            CCV_dw    -24.931935     -0.399035        -16.010201
# 2            CCV_cw    -78.332658     -0.814097        -16.935304
# 3         LSTM_pred    -20.556200     -0.367701        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -13.546826     -0.326288        -15.349239
# 6       BiLSTM_pred    -53.163836     -0.614775        -16.035561
# 7   BiLSTM_GRU_pred    -17.619121     -0.347154        -15.916361
# 8         QRNN_pred    -42.824507     -0.572646        -16.035561
# 9          ESN_pred      7.163103     -0.181172        -12.806757
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -19.183123     -0.358012        -15.916361
# 1            CCV_dw    -24.931935     -0.399035        -16.010201
# 2            CCV_cw    -19.183123     -0.358012        -15.916361
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred    -41.913551     -0.529297        -16.035561
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -28.163617     -0.422674        -16.035561
# 1            CCV_dw    -13.681427     -0.343452        -15.949599
# 2            CCV_cw    -11.583937     -0.308284        -15.153252
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -50.380000     -0.588601        -16.320926
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -45.387485     -0.550185        -16.320926
# 7   BiLSTM_GRU_pred     -3.385600     -0.249520        -15.711040
# 8         QRNN_pred     -4.811374     -0.263652        -16.035561
# 9          ESN_pred     35.516325      0.013432        -14.445255
# 10         BNN_pred    -17.042835     -0.343725        -15.646672
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -7.292106     -0.279432        -16.035561
# 1            CCV_dw     -0.897980     -0.252941        -15.947897
# 2            CCV_cw    -47.745222     -0.585726        -15.671040
# 3         LSTM_pred    -39.436739     -0.582136        -14.010447
# 4          GRU_pred    -34.696487     -0.489624        -16.098501
# 5     LSTM_GRU_pred      5.413841     -0.197547        -11.860218
# 6       BiLSTM_pred     10.731763     -0.166796        -13.593010
# 7   BiLSTM_GRU_pred     31.710002     -0.020314        -11.679562
# 8         QRNN_pred    -36.149325     -0.505788        -16.387586
# 9          ESN_pred     19.632170     -0.113224        -13.729299
# 10         BNN_pred    -34.597417     -0.478949        -14.997271
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -75.297334     -0.864333        -16.652624
# 1            CCV_dw     -7.503567     -0.308768        -16.113233
# 2            CCV_cw    -26.607022     -0.513335        -14.600918
# 3         LSTM_pred   -119.232887     -1.343315        -16.192625
# 4          GRU_pred    -19.264824     -0.417946        -13.195138
# 5     LSTM_GRU_pred     39.204615      0.026187         -7.968030
# 6       BiLSTM_pred    -59.948575     -0.777165        -13.655295
# 7   BiLSTM_GRU_pred    104.042528      0.513378         -5.973688
# 8         QRNN_pred    -50.736183     -0.740922        -14.650844
# 9          ESN_pred     36.660399     -0.026327         -6.079400
# 10         BNN_pred    -43.633902     -0.563943        -14.997271
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -8.774284     -0.300049        -15.919901
# 1            CCV_dw     -9.544051     -0.317398        -16.497756
# 2            CCV_cw    -63.707828     -0.743060        -13.584098
# 3         LSTM_pred    -74.128384     -0.896420        -15.092744
# 4          GRU_pred    -69.088757     -0.758636        -16.771894
# 5     LSTM_GRU_pred      5.413841     -0.197547        -11.860218
# 6       BiLSTM_pred    -15.850674     -0.384631        -13.802478
# 7   BiLSTM_GRU_pred    106.620198      0.518482         -6.846129
# 8         QRNN_pred    -64.295061     -0.771284        -16.652624
# 9          ESN_pred     76.828159      0.339277         -5.239642
# 10         BNN_pred    -38.414471     -0.507082        -14.997271
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -7.292106     -0.279432        -16.035561
# 1            CCV_dw     -4.526232     -0.280036        -16.006023
# 2            CCV_cw    -17.033873     -0.363707        -14.059806
# 3         LSTM_pred    -39.436739     -0.582136        -14.010447
# 4          GRU_pred    -38.536316     -0.519195        -16.098501
# 5     LSTM_GRU_pred      5.413841     -0.197547        -11.860218
# 6       BiLSTM_pred      1.107137     -0.237456        -13.723693
# 7   BiLSTM_GRU_pred     31.710002     -0.020314        -11.679562
# 8         QRNN_pred    -67.417473     -0.771339        -17.221535
# 9          ESN_pred     75.435306      0.292993        -11.914002
# 10         BNN_pred    -34.597417     -0.478949        -14.997271
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -75.297334     -0.864333        -16.652624
# 1            CCV_dw    -21.050144     -0.406768        -16.388064
# 2            CCV_cw    -45.581097     -0.586219        -15.138394
# 3         LSTM_pred    -76.511966     -0.806456        -16.163149
# 4          GRU_pred    -69.794228     -0.786455        -14.886407
# 5     LSTM_GRU_pred    -24.981015     -0.421257        -16.134122
# 6       BiLSTM_pred    -76.587552     -0.831514        -16.324547
# 7   BiLSTM_GRU_pred     58.695842      0.171258        -12.546360
# 8         QRNN_pred    -50.736183     -0.740922        -14.650844
# 9          ESN_pred     36.660399     -0.026327         -6.079400
# 10         BNN_pred    -40.895579     -0.522954        -15.783026
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -8.774284     -0.300049        -15.919901
# 1            CCV_dw    -22.216872     -0.407570        -16.505837
# 2            CCV_cw    -41.622153     -0.549905        -13.762727
# 3         LSTM_pred    -40.909095     -0.526708        -14.985792
# 4          GRU_pred    -83.924987     -0.849616        -16.992534
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -64.145219     -0.714088        -16.320926
# 7   BiLSTM_GRU_pred     39.304783      0.039392        -13.315532
# 8         QRNN_pred    -64.295061     -0.771284        -16.652624
# 9          ESN_pred    146.298224      0.854460         -5.768959
# 10         BNN_pred    -17.042835     -0.343725        -15.646672
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -28.163617     -0.422674        -16.035561
# 1            CCV_dw    -17.263256     -0.370435        -16.007731
# 2            CCV_cw     -1.988082     -0.242768        -14.248657
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -59.422693     -0.657253        -16.320926
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -50.701556     -0.589604        -16.320926
# 7   BiLSTM_GRU_pred     -3.385600     -0.249520        -15.711040
# 8         QRNN_pred    -61.982590     -0.717101        -16.035561
# 9          ESN_pred     41.095197      0.050801        -14.478039
# 10         BNN_pred    -17.042835     -0.343725        -15.646672
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -76.800227     -0.865859        -16.652624
# 1            CCV_dw    -24.121691     -0.393309        -15.927305
# 2            CCV_cw    -66.782850     -0.736044        -17.023536
# 3         LSTM_pred    -76.511966     -0.806456        -16.163149
# 4          GRU_pred    -29.935032     -0.444330        -14.985792
# 5     LSTM_GRU_pred    -24.981015     -0.421257        -16.134122
# 6       BiLSTM_pred    -81.651030     -0.841916        -17.234371
# 7   BiLSTM_GRU_pred     37.782584      0.027668        -12.799193
# 8         QRNN_pred    -42.574682     -0.654575        -14.650844
# 9          ESN_pred    -11.187159     -0.501639         -7.279523
# 10         BNN_pred    -43.254808     -0.539141        -16.035561
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -8.553839     -0.296545        -15.916361
# 1            CCV_dw    -24.931935     -0.399035        -16.010201
# 2            CCV_cw    -66.880767     -0.729784        -16.035561
# 3         LSTM_pred    -40.909095     -0.526708        -14.985792
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -53.163836     -0.614775        -16.035561
# 7   BiLSTM_GRU_pred      3.943472     -0.199226        -13.784537
# 8         QRNN_pred    -74.369354     -0.846079        -16.652624
# 9          ESN_pred     72.331335      0.276314         -6.887506
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -19.183123     -0.358012        -15.916361
# 1            CCV_dw    -24.931935     -0.399035        -16.010201
# 2            CCV_cw    -18.756615     -0.355015        -15.916361
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred    -57.802191     -0.680294        -16.035561
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -48.154018     -0.575691        -17.046143
# 1            CCV_dw      3.546682     -0.220976        -15.625005
# 2            CCV_cw     -2.073248     -0.247314        -15.972075
# 3         LSTM_pred    -33.991777     -0.482480        -15.784374
# 4          GRU_pred    -48.124967     -0.613257        -15.297751
# 5     LSTM_GRU_pred     46.082464      0.081902        -10.417703
# 6       BiLSTM_pred     10.898379     -0.175732        -13.599135
# 7   BiLSTM_GRU_pred      8.232892     -0.171102        -14.998845
# 8         QRNN_pred    -13.990743     -0.329911        -15.745343
# 9          ESN_pred    -14.513600     -0.348645        -15.971464
# 10         BNN_pred    -16.526628     -0.371116        -13.429871
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -39.317513     -0.631558        -13.039502
# 1            CCV_dw      4.870223     -0.232527        -14.206203
# 2            CCV_cw    -33.247781     -0.513268        -15.056377
# 3         LSTM_pred    -22.415563     -0.426246        -17.388073
# 4          GRU_pred    -42.840277     -0.781689        -12.941076
# 5     LSTM_GRU_pred     24.081503     -0.086882        -11.966396
# 6       BiLSTM_pred      8.708148     -0.196315        -14.798888
# 7   BiLSTM_GRU_pred     27.358599     -0.044561        -14.416040
# 8         QRNN_pred    -53.371742     -0.726257        -16.267759
# 9          ESN_pred    -38.273393     -0.572508        -16.035561
# 10         BNN_pred    -55.766039     -0.706330        -14.375375
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     14.046295     -0.358749         -5.313069
# 1            CCV_dw    -43.396345     -0.775600        -13.974467
# 2            CCV_cw    -97.190727     -1.312092        -15.877015
# 3         LSTM_pred   -147.701180     -1.868110        -17.648499
# 4          GRU_pred    -39.295635     -0.910224        -11.130726
# 5     LSTM_GRU_pred     -0.527895     -0.373190         -6.695781
# 6       BiLSTM_pred   -118.332194     -1.766505        -13.090734
# 7   BiLSTM_GRU_pred     -8.936931     -0.378923        -13.834233
# 8         QRNN_pred    -36.160081     -1.418988         -5.433423
# 9          ESN_pred    -68.690170     -2.104286         -7.067256
# 10         BNN_pred    -65.607608     -1.116158         -8.920768
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     13.981327     -0.276464         -4.949045
# 1            CCV_dw    -41.563276     -0.645460        -14.045772
# 2            CCV_cw    -81.518326     -1.129473        -14.985792
# 3         LSTM_pred   -153.516209     -1.926823        -18.509811
# 4          GRU_pred      2.160423     -0.315339        -11.784109
# 5     LSTM_GRU_pred     28.959029     -0.059584        -10.737238
# 6       BiLSTM_pred     -8.793193     -0.377675        -12.787444
# 7   BiLSTM_GRU_pred      7.227089     -0.199505        -13.470993
# 8         QRNN_pred     -0.334017     -0.492156         -6.699652
# 9          ESN_pred   -135.811874     -2.022840        -16.035561
# 10         BNN_pred    -55.239911     -0.763420        -14.446701
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -53.768072     -0.804800        -11.189346
# 1            CCV_dw    -19.008088     -0.425622        -15.706503
# 2            CCV_cw    -75.514953     -1.002893        -15.056377
# 3         LSTM_pred    -20.033900     -0.426083        -17.395442
# 4          GRU_pred    -68.108794     -1.072587        -13.887028
# 5     LSTM_GRU_pred     53.085472      0.133475         -9.356892
# 6       BiLSTM_pred     25.384733     -0.079171        -12.281431
# 7   BiLSTM_GRU_pred     35.427293      0.011135        -13.664430
# 8         QRNN_pred     49.084709      0.101974         -9.552709
# 9          ESN_pred    -82.613152     -1.118140        -16.035561
# 10         BNN_pred    -85.620222     -0.975166        -14.375375
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     14.046295     -0.358749         -5.313069
# 1            CCV_dw     38.621291      0.017501        -14.992723
# 2            CCV_cw    -97.190727     -1.312092        -15.877015
# 3         LSTM_pred   -115.181200     -1.220509        -17.135990
# 4          GRU_pred    -63.017022     -0.953582        -12.012360
# 5     LSTM_GRU_pred    -18.814010     -0.527877         -8.203000
# 6       BiLSTM_pred   -110.610593     -1.441252        -13.070349
# 7   BiLSTM_GRU_pred    -41.120293     -0.627052        -13.943048
# 8         QRNN_pred    -36.160081     -1.418988         -5.433423
# 9          ESN_pred    -68.690170     -2.104286         -7.067256
# 10         BNN_pred    -38.764426     -0.768357         -9.317790
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.190859      0.289404         -4.882245
# 1            CCV_dw      4.621443     -0.219661        -15.918759
# 2            CCV_cw    -81.518326     -1.129473        -14.985792
# 3         LSTM_pred   -104.362180     -1.110030        -16.240202
# 4          GRU_pred    -16.148713     -0.393515        -12.659261
# 5     LSTM_GRU_pred     33.206872     -0.012763        -11.727651
# 6       BiLSTM_pred    -55.934729     -0.742542        -14.494299
# 7   BiLSTM_GRU_pred    -14.989701     -0.355415        -13.530486
# 8         QRNN_pred     -0.334017     -0.492156         -6.699652
# 9          ESN_pred    -92.859886     -1.236901        -16.035561
# 10         BNN_pred    -28.234641     -0.503882        -12.612508
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.431863     -0.343941        -14.793338
# 1            CCV_dw     -4.856183     -0.283391        -16.166932
# 2            CCV_cw    -48.631086     -0.636033        -16.035561
# 3         LSTM_pred    -11.777585     -0.327887        -14.786358
# 4          GRU_pred    -97.734921     -1.016320        -17.032197
# 5     LSTM_GRU_pred     46.082464      0.081902        -10.417703
# 6       BiLSTM_pred     -7.240893     -0.315127        -13.765197
# 7   BiLSTM_GRU_pred      8.232892     -0.171102        -14.998845
# 8         QRNN_pred     39.272175      0.036808        -11.007508
# 9          ESN_pred    -66.151811     -0.898029        -16.035561
# 10         BNN_pred    -56.731542     -0.699311        -13.555763
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     14.046295     -0.358749         -5.313069
# 1            CCV_dw    -75.595800     -0.799345        -18.507123
# 2            CCV_cw    -97.190727     -1.312092        -15.877015
# 3         LSTM_pred    -72.836682     -0.800544        -15.829496
# 4          GRU_pred    -20.657515     -0.379882        -13.446381
# 5     LSTM_GRU_pred    -95.434294     -1.113068        -15.865529
# 6       BiLSTM_pred    -75.254959     -0.793903        -16.541092
# 7   BiLSTM_GRU_pred    -41.120293     -0.627052        -13.943048
# 8         QRNN_pred    -36.160081     -1.418988         -5.433423
# 9          ESN_pred    -68.690170     -2.104286         -7.067256
# 10         BNN_pred    -69.421351     -0.771250        -16.143561
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     72.122187      0.287046         -4.734178
# 1            CCV_dw    -24.121691     -0.393309        -15.927305
# 2            CCV_cw    -81.518326     -1.129473        -14.985792
# 3         LSTM_pred    -75.217333     -0.796374        -16.163149
# 4          GRU_pred     -3.529853     -0.251298        -13.865808
# 5     LSTM_GRU_pred    -24.410278     -0.404208        -16.604061
# 6       BiLSTM_pred    -53.163836     -0.614775        -16.035561
# 7   BiLSTM_GRU_pred    -14.989701     -0.355415        -13.530486
# 8         QRNN_pred     -0.334017     -0.492156         -6.699652
# 9          ESN_pred    -92.859886     -1.236901        -16.035561
# 10         BNN_pred    -48.862530     -0.580957        -16.035561
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.814904     -0.342571        -15.576671
# 1            CCV_dw    -24.931935     -0.399035        -16.010201
# 2            CCV_cw    -55.640776     -0.640450        -16.035561
# 3         LSTM_pred    -24.507927     -0.396035        -16.010201
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred     30.867562     -0.021425        -11.097252
# 9          ESN_pred    -99.543698     -1.179175        -16.035561
# 10         BNN_pred    -43.254808     -0.539141        -16.035561
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.766883     -0.330226        -11.960494
# 1            CCV_dw    -75.058487     -0.864382        -16.239347
# 2            CCV_cw    -69.085907     -0.777489        -16.035561
# 3         LSTM_pred    -88.562489     -1.006705        -17.441552
# 4          GRU_pred    -41.185262     -0.560660        -15.297751
# 5     LSTM_GRU_pred     30.158029     -0.040042         -9.313944
# 6       BiLSTM_pred    -23.695377     -0.443355        -13.802478
# 7   BiLSTM_GRU_pred     25.934979     -0.050390        -14.663051
# 8         QRNN_pred    -38.267517     -0.563786        -12.960752
# 9          ESN_pred    -44.391980     -0.597957        -16.035561
# 10         BNN_pred    -20.224729     -0.401725        -13.870486
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -27.841865     -0.507007        -15.293051
# 1            CCV_dw      1.116127     -0.257253        -14.515066
# 2            CCV_cw    -24.286534     -0.446518        -14.268998
# 3         LSTM_pred    -94.283145     -1.179076        -17.587925
# 4          GRU_pred    -42.840277     -0.781689        -12.941076
# 5     LSTM_GRU_pred     23.649575     -0.092508        -12.107118
# 6       BiLSTM_pred     61.876178      0.197100        -13.279112
# 7   BiLSTM_GRU_pred     38.379458      0.024524        -11.008015
# 8         QRNN_pred    -54.688806     -0.748249        -16.384258
# 9          ESN_pred    -98.350136     -1.152336        -15.779882
# 10         BNN_pred    -93.482735     -1.093057        -14.963574
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     24.590149     -0.256235         -4.321137
# 1            CCV_dw    -23.584715     -0.628134        -10.757109
# 2            CCV_cw    -88.716280     -1.246382        -15.087374
# 3         LSTM_pred   -145.933939     -2.398302        -14.709754
# 4          GRU_pred    -71.280402     -1.490622        -11.664602
# 5     LSTM_GRU_pred     63.085814      0.243355         -4.819998
# 6       BiLSTM_pred    -96.787369     -1.670940        -12.194972
# 7   BiLSTM_GRU_pred     59.555306      0.197352         -5.912652
# 8         QRNN_pred    -51.217406     -1.836417         -6.910764
# 9          ESN_pred    -68.690170     -2.104286         -7.067256
# 10         BNN_pred    -94.298177     -1.693132         -9.429818
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     18.880331     -0.248433         -6.215161
# 1            CCV_dw    -16.059835     -0.462271        -10.831081
# 2            CCV_cw    -71.421667     -1.045237        -14.051250
# 3         LSTM_pred   -167.276247     -2.278675        -19.768170
# 4          GRU_pred      2.160423     -0.315339        -11.784109
# 5     LSTM_GRU_pred     58.353716      0.179288         -7.570683
# 6       BiLSTM_pred     -5.183318     -0.366174        -12.624274
# 7   BiLSTM_GRU_pred     54.890492      0.148826         -8.147233
# 8         QRNN_pred    -11.180860     -0.681599         -7.772213
# 9          ESN_pred   -102.814481     -1.800403        -10.475320
# 10         BNN_pred    -87.284533     -1.137283        -14.124162
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.704418     -0.127948         -9.271766
# 1            CCV_dw    -16.630521     -0.435892        -13.071003
# 2            CCV_cw    -97.708837     -1.264968        -14.268998
# 3         LSTM_pred    -98.588488     -1.265746        -17.852857
# 4          GRU_pred      0.186109     -0.330896        -12.157264
# 5     LSTM_GRU_pred     42.656700      0.049823        -10.661365
# 6       BiLSTM_pred     36.746575      0.003709        -12.269402
# 7   BiLSTM_GRU_pred     51.663804      0.122234        -10.191264
# 8         QRNN_pred     73.569454      0.322314         -5.785848
# 9          ESN_pred   -144.081315     -2.084925        -15.779882
# 10         BNN_pred    -77.839810     -0.989368        -14.061733
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     24.590149     -0.256235         -4.321137
# 1            CCV_dw    -77.302643     -1.091334        -15.190052
# 2            CCV_cw    -97.190727     -1.312092        -15.877015
# 3         LSTM_pred   -151.656160     -2.028923        -15.227519
# 4          GRU_pred    -89.901765     -1.335417        -13.025198
# 5     LSTM_GRU_pred     32.698421     -0.058777         -5.083801
# 6       BiLSTM_pred   -104.819965     -1.535774        -12.487618
# 7   BiLSTM_GRU_pred    -41.120293     -0.627052        -13.943048
# 8         QRNN_pred    -51.217406     -1.836417         -6.910764
# 9          ESN_pred    -68.690170     -2.104286         -7.067256
# 10         BNN_pred    -79.797178     -1.281859        -10.557278
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      3.999957     -0.422541         -6.880302
# 1            CCV_dw   -103.919530     -1.172789        -16.300333
# 2            CCV_cw    -81.518326     -1.129473        -14.985792
# 3         LSTM_pred   -184.056260     -2.129459        -18.465165
# 4          GRU_pred      1.701976     -0.257068        -12.659261
# 5     LSTM_GRU_pred      1.826755     -0.274707        -10.211410
# 6       BiLSTM_pred    -52.564225     -0.755480        -13.655295
# 7   BiLSTM_GRU_pred    -35.838512     -0.523621        -14.328225
# 8         QRNN_pred    -11.180860     -0.681599         -7.772213
# 9          ESN_pred   -133.620026     -2.115944        -13.549217
# 10         BNN_pred    -52.676735     -0.721267        -13.689056
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      1.333371     -0.265383         -9.698294
# 1            CCV_dw    -75.208928     -0.869404        -16.592303
# 2            CCV_cw    -73.088689     -0.855915        -16.035561
# 3         LSTM_pred   -103.004050     -1.183626        -16.514695
# 4          GRU_pred    -24.543603     -0.456147        -14.535156
# 5     LSTM_GRU_pred      2.662334     -0.258271        -11.893742
# 6       BiLSTM_pred    -24.612525     -0.482465        -13.802478
# 7   BiLSTM_GRU_pred     37.863141      0.030228        -13.682701
# 8         QRNN_pred     71.930483      0.293813         -4.727487
# 9          ESN_pred    -92.859886     -1.236901        -16.035561
# 10         BNN_pred    -45.110714     -0.621759        -13.921887
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     24.590149     -0.256235         -4.321137
# 1            CCV_dw    -75.999473     -0.807186        -18.507123
# 2            CCV_cw    -97.190727     -1.312092        -15.877015
# 3         LSTM_pred    -37.246110     -0.574345        -11.192294
# 4          GRU_pred    -56.785334     -0.659322        -16.668866
# 5     LSTM_GRU_pred    -44.744706     -0.708027        -13.374151
# 6       BiLSTM_pred    -69.055952     -0.764532        -15.981627
# 7   BiLSTM_GRU_pred    -41.120293     -0.627052        -13.943048
# 8         QRNN_pred    -51.217406     -1.836417         -6.910764
# 9          ESN_pred    -68.690170     -2.104286         -7.067256
# 10         BNN_pred   -109.905024     -1.338124        -17.158152
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      3.999957     -0.422541         -6.880302
# 1            CCV_dw    -46.737668     -0.565291        -15.965790
# 2            CCV_cw    -81.518326     -1.129473        -14.985792
# 3         LSTM_pred    -76.511966     -0.806456        -16.163149
# 4          GRU_pred     -3.529853     -0.251298        -13.865808
# 5     LSTM_GRU_pred    -17.207424     -0.360702        -15.916361
# 6       BiLSTM_pred    -68.319167     -0.734292        -16.035561
# 7   BiLSTM_GRU_pred    -41.731062     -0.568850        -14.365011
# 8         QRNN_pred    -11.180860     -0.681599         -7.772213
# 9          ESN_pred   -133.620026     -2.115944        -13.549217
# 10         BNN_pred    -70.133785     -0.745776        -16.935304
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -39.051098     -0.550345        -13.465428
# 1            CCV_dw    -24.121691     -0.393309        -15.927305
# 2            CCV_cw    -71.415932     -0.776254        -16.035561
# 3         LSTM_pred    -12.311793     -0.311772        -14.777338
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -15.381009     -0.337827        -15.916361
# 6       BiLSTM_pred    -53.163836     -0.614775        -16.035561
# 7   BiLSTM_GRU_pred      2.345142     -0.210183        -13.784537
# 8         QRNN_pred    112.882049      0.560535         -4.560787
# 9          ESN_pred    -92.859886     -1.236901        -16.035561
# 10         BNN_pred    -43.254808     -0.539141        -16.035561
# 11               __    -19.183123     -0.358012        -15.916361

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y1', file, 'CCV')
get_final_results_1('2024_y1', file, 'CCV')

get_final_results('2024_y1', dw_file, 'CCV_dw')
get_final_results_1('2024_y1', dw_file, 'CCV_dw')

get_final_results('2024_y1', cw_file, 'CCV_cw')
get_final_results_1('2024_y1', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-32-c3063833350a>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-32-c3063833350a>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-32-c3063833350a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-32-c3063833350a>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:38: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-32-c3063833350a>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-32-c3063833350a>:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-32-c3063833350a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-32-c3063833350a>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-32-c3063833350a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-32-c3063833350a>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-32-c3063833350a>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-32-c3063833350a>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-32-c3063833350a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-32-c3063833350a>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-32-c3063833350a>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-32-c3063833350a>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-32-c3063833350a>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-32-c3063833350a>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-32-c3063833350a>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-32-c3063833350a>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-32-c3063833350a>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     76.910947      0.315397         -7.764436
# 2            CCV_cw     84.701418      0.374014         -7.111357
# 3         LSTM_pred    103.608166      0.515758         -6.951385
# 4          GRU_pred    130.857566      0.760684         -6.681250
# 5     LSTM_GRU_pred     76.910947      0.315397         -7.764436
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred    -43.507228     -0.524640        -15.535370
# 10         BNN_pred     84.701418      0.374014         -7.111357
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    148.434064      0.847559         -3.657049
# 1            CCV_dw    120.639878      0.704200         -4.216181
# 2            CCV_cw     97.118317      0.467625         -6.886716
# 3         LSTM_pred    153.480768      0.931222         -6.650830
# 4          GRU_pred     91.071114      0.455645         -6.584313
# 5     LSTM_GRU_pred    117.209294      0.541542         -6.928723
# 6       BiLSTM_pred     91.071114      0.455645         -6.584313
# 7   BiLSTM_GRU_pred    148.198494      0.890341         -6.681427
# 8         QRNN_pred    106.532521      0.575166         -6.828124
# 9          ESN_pred    111.733550      0.616362         -6.900579
# 10         BNN_pred    109.868909      0.612055         -5.921951
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -69.861162     -1.200247        -10.625852
# 1            CCV_dw     27.846645     -0.156671         -4.685728
# 2            CCV_cw     -4.711844     -0.563163        -10.524210
# 3         LSTM_pred     71.470145      0.384088         -4.580569
# 4          GRU_pred     76.884831      0.341554         -4.998966
# 5     LSTM_GRU_pred     79.391960      0.433426         -4.587788
# 6       BiLSTM_pred    110.212788      0.796671         -2.999966
# 7   BiLSTM_GRU_pred     60.370861      0.268459         -2.970408
# 8         QRNN_pred     -5.242339     -0.516427         -7.712034
# 9          ESN_pred     37.885831     -0.028290         -4.294275
# 10         BNN_pred    135.850525      1.002957         -2.677629
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    184.318093      1.143084         -4.598544
# 1            CCV_dw     77.749741      0.374398         -3.526594
# 2            CCV_cw    173.677572      1.295661         -3.338617
# 3         LSTM_pred    124.865083      0.813199         -6.196504
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred    123.080807      0.686151         -6.142956
# 6       BiLSTM_pred     60.554432      0.127567         -6.279474
# 7   BiLSTM_GRU_pred    123.015334      0.813228         -6.096000
# 8         QRNN_pred     23.640671     -0.173886         -7.494431
# 9          ESN_pred    132.385665      0.914279         -4.552285
# 10         BNN_pred    138.951601      0.935138         -3.356588
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    176.591687      1.120660         -3.322718
# 1            CCV_dw    122.508888      0.723426         -4.209161
# 2            CCV_cw     88.376131      0.385630         -7.759372
# 3         LSTM_pred    101.465973      0.527858         -6.859533
# 4          GRU_pred     68.790056      0.187555         -6.886416
# 5     LSTM_GRU_pred     33.444683     -0.014734         -7.347510
# 6       BiLSTM_pred     91.071114      0.455645         -6.584313
# 7   BiLSTM_GRU_pred    148.198494      0.890341         -6.681427
# 8         QRNN_pred     40.458971      0.028244         -7.261739
# 9          ESN_pred    121.587333      0.692430         -6.736472
# 10         BNN_pred     79.301602      0.361226         -6.001772
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -72.968561     -0.979694        -12.736187
# 1            CCV_dw    -12.261365     -0.524814         -8.575022
# 2            CCV_cw    -15.679380     -0.696767        -10.524210
# 3         LSTM_pred     41.447915      0.024796         -7.317555
# 4          GRU_pred     67.253833      0.341554         -4.998966
# 5     LSTM_GRU_pred     79.391960      0.433426         -4.587788
# 6       BiLSTM_pred    100.283726      0.796671         -2.999966
# 7   BiLSTM_GRU_pred     68.155097      0.372742         -2.948761
# 8         QRNN_pred    -52.717369     -0.898824        -10.825981
# 9          ESN_pred     37.885831     -0.028290         -4.294275
# 10         BNN_pred    133.791890      0.979705         -2.682491
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    246.462950      1.548533         -5.114250
# 1            CCV_dw     77.749741      0.374398         -3.526594
# 2            CCV_cw    173.677572      1.295661         -3.338617
# 3         LSTM_pred     46.074135      0.079908         -7.612810
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred     66.379475      0.233948         -7.244787
# 6       BiLSTM_pred     -3.510753     -0.259401        -14.814772
# 7   BiLSTM_GRU_pred    -51.396969     -0.590149        -15.874250
# 8         QRNN_pred    -25.212808     -0.603856        -10.508152
# 9          ESN_pred     61.907183      0.219177         -7.150553
# 10         BNN_pred    136.887345      0.914751         -3.362682
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    155.821151      1.035093         -3.301464
# 1            CCV_dw     78.707025      0.329908         -7.751508
# 2            CCV_cw     64.200597      0.213594         -7.845829
# 3         LSTM_pred     53.842315      0.140960         -7.169518
# 4          GRU_pred     97.856856      0.491253         -6.987801
# 5     LSTM_GRU_pred     19.359539     -0.124199         -8.202804
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 8         QRNN_pred     -9.197164     -0.359397        -10.385586
# 9          ESN_pred    -30.493765     -0.430577        -15.535370
# 10         BNN_pred     59.456287      0.184333         -7.285950
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV   -135.885771     -1.251585        -18.658743
# 1            CCV_dw    -77.298395     -0.898453        -15.594958
# 2            CCV_cw     -2.020242     -0.495851        -10.524210
# 3         LSTM_pred     62.418278      0.237570         -7.089993
# 4          GRU_pred     46.841575      0.081944         -7.323374
# 5     LSTM_GRU_pred     79.391960      0.433426         -4.587788
# 6       BiLSTM_pred    100.283726      0.796671         -2.999966
# 7   BiLSTM_GRU_pred     68.155097      0.372742         -2.948761
# 8         QRNN_pred   -104.982428     -1.134131        -15.746039
# 9          ESN_pred     37.885831     -0.028290         -4.294275
# 10         BNN_pred    133.791890      0.979705         -2.682491
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    246.462950      1.548533         -5.114250
# 1            CCV_dw     65.262649      0.256156         -3.567933
# 2            CCV_cw    173.677572      1.295661         -3.338617
# 3         LSTM_pred      2.189356     -0.207551        -15.158412
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred    -14.185778     -0.300941        -14.814772
# 6       BiLSTM_pred     -3.510753     -0.259401        -14.814772
# 7   BiLSTM_GRU_pred    -51.396969     -0.590149        -15.874250
# 8         QRNN_pred    -89.743829     -0.990938        -15.535370
# 9          ESN_pred     44.021884      0.062266         -8.172298
# 10         BNN_pred    136.887345      0.914751         -3.362682
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    155.821151      1.035093         -3.301464
# 1            CCV_dw    -68.739212     -0.694059        -15.535370
# 2            CCV_cw    -92.364510     -0.881920        -17.370102
# 3         LSTM_pred    -45.924984     -0.582143        -15.535370
# 4          GRU_pred    -87.009473     -0.788587        -16.680318
# 5     LSTM_GRU_pred   -108.685422     -0.914700        -16.317555
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 8         QRNN_pred    -82.818008     -0.887291        -15.535370
# 9          ESN_pred   -100.041094     -0.856089        -16.317555
# 10         BNN_pred    -70.956775     -0.778386        -15.535370
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     76.910947      0.315397         -7.764436
# 2            CCV_cw    -71.869358     -0.662361        -16.317555
# 3         LSTM_pred    -32.951756     -0.436051        -15.535370
# 4          GRU_pred    130.857566      0.760684         -6.681250
# 5     LSTM_GRU_pred     86.824273      0.388972         -7.811798
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred     14.064510     -0.160187        -13.399868
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred     34.013329     -0.006575        -13.141349
# 10         BNN_pred     84.701418      0.374014         -7.111357
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.545695      0.849282         -3.655821
# 1            CCV_dw     76.910947      0.315397         -7.764436
# 2            CCV_cw     76.910947      0.315397         -7.764436
# 3         LSTM_pred    103.608166      0.515758         -6.951385
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred     86.824273      0.388972         -7.811798
# 6       BiLSTM_pred     97.118317      0.467625         -6.886716
# 7   BiLSTM_GRU_pred     89.391941      0.407726         -7.793386
# 8         QRNN_pred     93.414907      0.440279         -6.910041
# 9          ESN_pred    113.847500      0.632651         -6.783282
# 10         BNN_pred    109.868909      0.612055         -5.921951
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     25.218667     -0.199834         -4.950365
# 1            CCV_dw     95.246175      0.571043         -3.516300
# 2            CCV_cw    101.411983      0.903580         -4.021807
# 3         LSTM_pred     91.999579      0.615586         -4.494455
# 4          GRU_pred    -15.153748     -0.886436         -9.230979
# 5     LSTM_GRU_pred     95.440063      0.595692         -3.001189
# 6       BiLSTM_pred     84.143763      0.579977         -3.698755
# 7   BiLSTM_GRU_pred     27.125270     -0.187109         -4.095000
# 8         QRNN_pred    -58.212568     -0.788504        -10.691454
# 9          ESN_pred    -44.597175     -0.979427         -7.715671
# 10         BNN_pred    118.389815      0.766564         -5.587449
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     80.963094      0.333922         -7.976994
# 1            CCV_dw     93.032453      0.508625         -3.477285
# 2            CCV_cw     51.676374      0.126312         -6.690501
# 3         LSTM_pred     71.436669      0.281057         -6.407079
# 4          GRU_pred    127.034998      0.859600         -3.267053
# 5     LSTM_GRU_pred    195.141675      1.548030         -2.281759
# 6       BiLSTM_pred     38.718552      0.015487         -6.723312
# 7   BiLSTM_GRU_pred    116.913738      0.730326         -3.458887
# 8         QRNN_pred     37.880388      0.029721         -8.202036
# 9          ESN_pred    130.561531      0.823330         -6.767486
# 10         BNN_pred    135.429597      0.906108         -3.330941
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.545695      0.849282         -3.655821
# 1            CCV_dw     92.236002      0.431514         -7.773093
# 2            CCV_cw    -17.901293     -0.352523         -8.480437
# 3         LSTM_pred    103.608166      0.515758         -6.951385
# 4          GRU_pred     63.198114      0.144770         -9.956086
# 5     LSTM_GRU_pred     28.743086     -0.051091         -8.252839
# 6       BiLSTM_pred     97.118317      0.467625         -6.886716
# 7   BiLSTM_GRU_pred     45.606937      0.077830         -7.352028
# 8         QRNN_pred     64.987147      0.228771         -7.203472
# 9          ESN_pred    129.001835      0.749529         -6.692232
# 10         BNN_pred    209.508173      1.487465         -3.171113
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     23.479257     -0.222761         -4.958778
# 1            CCV_dw     95.246175      0.571043         -3.516300
# 2            CCV_cw    101.411983      0.903580         -4.021807
# 3         LSTM_pred     61.402121      0.232053         -7.179987
# 4          GRU_pred    -16.389110     -0.673774        -10.406907
# 5     LSTM_GRU_pred     95.440063      0.595692         -3.001189
# 6       BiLSTM_pred     84.143763      0.579977         -3.698755
# 7   BiLSTM_GRU_pred     41.306573      0.008094         -4.046106
# 8         QRNN_pred    -92.400258     -1.067344        -13.933430
# 9          ESN_pred   -113.074944     -1.473120        -13.939817
# 10         BNN_pred    101.219272      0.538558         -6.827856
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     56.832016      0.158528         -7.907846
# 1            CCV_dw     93.032453      0.508625         -3.477285
# 2            CCV_cw     61.055648      0.208740         -6.631360
# 3         LSTM_pred    -63.647845     -0.692440        -14.814772
# 4          GRU_pred    130.863955      0.902716         -3.255991
# 5     LSTM_GRU_pred    153.934515      1.044803         -5.440681
# 6       BiLSTM_pred    -76.273540     -0.751111        -14.814772
# 7   BiLSTM_GRU_pred    133.719252      0.781995         -6.498170
# 8         QRNN_pred      0.204442     -0.228329        -10.263228
# 9          ESN_pred      4.056133     -0.244102        -13.704528
# 10         BNN_pred    133.371725      0.885732         -3.336989
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     92.236002      0.431514         -7.773093
# 2            CCV_cw   -102.916386     -0.892884        -16.317555
# 3         LSTM_pred     -7.729378     -0.296964        -15.535370
# 4          GRU_pred     26.863189     -0.064127         -9.948296
# 5     LSTM_GRU_pred     12.436271     -0.155289         -9.313715
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred    -62.947904     -0.719234        -13.310014
# 8         QRNN_pred     26.327203     -0.073296        -10.180123
# 9          ESN_pred     48.081489      0.097694        -12.964956
# 10         BNN_pred    207.316039      1.466625         -3.176871
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     23.479257     -0.222761         -4.958778
# 1            CCV_dw     82.556364      0.441713         -3.557518
# 2            CCV_cw    101.411983      0.903580         -4.021807
# 3         LSTM_pred     82.774277      0.431047         -6.956703
# 4          GRU_pred    -10.841735     -0.603834        -10.406907
# 5     LSTM_GRU_pred     95.440063      0.595692         -3.001189
# 6       BiLSTM_pred     84.143763      0.579977         -3.698755
# 7   BiLSTM_GRU_pred     41.306573      0.008094         -4.046106
# 8         QRNN_pred   -142.475867     -1.272267        -18.682039
# 9          ESN_pred   -125.776512     -1.288692        -15.535370
# 10         BNN_pred     34.725804      0.008451        -14.299428
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -80.112423     -0.717560        -17.083763
# 1            CCV_dw     80.368292      0.391426         -3.518046
# 2            CCV_cw     66.270187      0.251101         -6.598930
# 3         LSTM_pred    -31.565571     -0.443706        -14.814772
# 4          GRU_pred    130.863955      0.902716         -3.255991
# 5     LSTM_GRU_pred    156.927543      1.044251         -5.426606
# 6       BiLSTM_pred    -76.273540     -0.751111        -14.814772
# 7   BiLSTM_GRU_pred    113.460044      0.576950         -6.498170
# 8         QRNN_pred    -66.009204     -0.605592        -15.535370
# 9          ESN_pred    -79.030063     -0.717838        -15.694732
# 10         BNN_pred    133.371725      0.885732         -3.336989
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -50.836812     -0.619168        -15.535370
# 1            CCV_dw    -57.059483     -0.610845        -15.535370
# 2            CCV_cw    -98.507685     -0.851001        -16.317555
# 3         LSTM_pred    -16.894289     -0.364161        -15.474381
# 4          GRU_pred   -110.397014     -0.924972        -17.953797
# 5     LSTM_GRU_pred   -100.010133     -0.871264        -16.680318
# 6       BiLSTM_pred    -96.091692     -0.830469        -16.317555
# 7   BiLSTM_GRU_pred    -87.740133     -0.777321        -15.603630
# 8         QRNN_pred    -35.750620     -0.470773        -15.535370
# 9          ESN_pred   -100.041094     -0.856089        -16.317555
# 10         BNN_pred    207.316039      1.466625         -3.176871
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.722407     -0.082627        -14.680742
# 1            CCV_dw    167.491107      1.134158         -3.301464
# 2            CCV_cw     51.874123      0.125489        -14.273879
# 3         LSTM_pred    103.608166      0.515758         -6.951385
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred    178.238255      1.221024         -3.321602
# 6       BiLSTM_pred    130.857566      0.760684         -6.681250
# 7   BiLSTM_GRU_pred    102.275096      0.505486         -6.959791
# 8         QRNN_pred     14.064510     -0.160187        -13.399868
# 9          ESN_pred     84.701418      0.374014         -7.111357
# 10         BNN_pred    107.346100      0.543095         -6.927920
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.160598      0.766597         -3.633656
# 1            CCV_dw    167.491107      1.134158         -3.301464
# 2            CCV_cw    167.491107      1.134158         -3.301464
# 3         LSTM_pred     96.237232      0.497877         -6.998125
# 4          GRU_pred    183.563727      1.178712         -3.336496
# 5     LSTM_GRU_pred    178.238255      1.221024         -3.321602
# 6       BiLSTM_pred    113.194334      0.638933         -5.904260
# 7   BiLSTM_GRU_pred    178.374934      1.224420         -3.321217
# 8         QRNN_pred     93.414907      0.440279         -6.910041
# 9          ESN_pred    119.082911      0.673756         -6.855260
# 10         BNN_pred    178.374934      1.224420         -3.321217
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw     25.677092     -0.260817         -4.518006
# 2            CCV_cw    -13.863416     -0.972686         -7.501418
# 3         LSTM_pred     92.414351      0.689602         -4.157926
# 4          GRU_pred    121.338387      0.919644         -2.311832
# 5     LSTM_GRU_pred     50.602858      0.161586         -2.276847
# 6       BiLSTM_pred     66.922073      0.403282         -2.117287
# 7   BiLSTM_GRU_pred    -56.489897     -1.685649         -5.648990
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred    -68.506644     -2.178598         -7.235458
# 10         BNN_pred    125.065277      0.979640         -2.757022
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw     35.840452     -0.061270         -4.971830
# 2            CCV_cw     82.667127      0.576572         -6.308350
# 3         LSTM_pred    170.295969      1.494544         -3.124036
# 4          GRU_pred     15.620447     -0.394766         -3.824272
# 5     LSTM_GRU_pred     38.321055     -0.039569         -2.393698
# 6       BiLSTM_pred     73.467361      0.479587         -2.943973
# 7   BiLSTM_GRU_pred     93.868960      0.625371         -3.360452
# 8         QRNN_pred     21.458308     -0.173606         -7.851780
# 9          ESN_pred     17.047251     -0.246332         -6.790988
# 10         BNN_pred    204.865538      1.681850         -1.762886
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    150.843118      0.995000         -3.562038
# 1            CCV_dw    118.993245      0.645128         -4.878309
# 2            CCV_cw     45.657098      0.067672         -3.360174
# 3         LSTM_pred    103.182483      0.611101         -3.515841
# 4          GRU_pred    122.984980      0.868181         -2.902810
# 5     LSTM_GRU_pred    121.311724      0.786409         -2.964054
# 6       BiLSTM_pred     23.329195     -0.151845         -6.445461
# 7   BiLSTM_GRU_pred    120.642866      0.826875         -3.279793
# 8         QRNN_pred     93.167354      0.510119         -6.911606
# 9          ESN_pred     87.356056      0.470853         -7.016974
# 10         BNN_pred    178.128132      1.266612         -3.230977
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw     25.677092     -0.260817         -4.518006
# 2            CCV_cw     21.594260     -0.286549         -5.840415
# 3         LSTM_pred    102.893914      0.803452         -4.118418
# 4          GRU_pred    137.457213      1.070094         -3.165398
# 5     LSTM_GRU_pred     50.602858      0.161586         -2.276847
# 6       BiLSTM_pred     66.922073      0.403282         -2.117287
# 7   BiLSTM_GRU_pred    -73.350127     -1.464764         -8.133216
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred    -68.506644     -2.178598         -7.235458
# 10         BNN_pred     57.249786      0.178181         -8.474128
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw     35.840452     -0.061270         -4.971830
# 2            CCV_cw    121.595669      0.988383         -5.274640
# 3         LSTM_pred    181.522653      1.580489         -3.094352
# 4          GRU_pred     30.219617     -0.154182         -4.695850
# 5     LSTM_GRU_pred     38.321055     -0.039569         -2.393698
# 6       BiLSTM_pred     51.255250      0.135124         -5.718388
# 7   BiLSTM_GRU_pred     57.067226      0.182446         -5.622900
# 8         QRNN_pred    -52.670115     -0.897382        -14.877758
# 9          ESN_pred      5.040325     -0.376987         -6.859425
# 10         BNN_pred    132.239931      0.795683         -6.197170
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.285013      0.062577        -14.391393
# 1            CCV_dw    118.993245      0.645128         -4.878309
# 2            CCV_cw    -57.894629     -0.816465        -15.332532
# 3         LSTM_pred    103.681263      0.615667         -3.514252
# 4          GRU_pred    118.071377      0.750225         -4.649757
# 5     LSTM_GRU_pred    121.311724      0.786409         -2.964054
# 6       BiLSTM_pred     36.963198     -0.000380         -6.934197
# 7   BiLSTM_GRU_pred    101.478326      0.579094         -5.578887
# 8         QRNN_pred     13.834922     -0.214243        -13.402902
# 9          ESN_pred     31.680955     -0.049750         -7.550459
# 10         BNN_pred    178.128132      1.266612         -3.230977
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw     25.677092     -0.260817         -4.518006
# 2            CCV_cw     21.594260     -0.286549         -5.840415
# 3         LSTM_pred     83.185545      0.462420         -6.947002
# 4          GRU_pred    -34.716517     -0.487049        -14.814772
# 5     LSTM_GRU_pred     50.602858      0.161586         -2.276847
# 6       BiLSTM_pred     66.922073      0.403282         -2.117287
# 7   BiLSTM_GRU_pred    -73.350127     -1.464764         -8.133216
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred    -68.506644     -2.178598         -7.235458
# 10         BNN_pred    -19.611999     -0.395136        -15.401605
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw     23.838932     -0.216653         -5.030110
# 2            CCV_cw    121.595669      0.988383         -5.274640
# 3         LSTM_pred    160.409213      1.148447         -5.228548
# 4          GRU_pred     10.515674     -0.348844         -7.063190
# 5     LSTM_GRU_pred     36.559415     -0.065447         -2.393698
# 6       BiLSTM_pred     69.339281      0.334758         -5.621682
# 7   BiLSTM_GRU_pred     57.067226      0.182446         -5.622900
# 8         QRNN_pred    -47.867612     -0.648213        -15.535370
# 9          ESN_pred      0.655058     -0.330401         -8.277173
# 10         BNN_pred     49.926382      0.112291        -14.290174
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     39.697217      0.046288        -14.632099
# 1            CCV_dw   -110.703805     -1.022530        -17.187833
# 2            CCV_cw    -87.154261     -0.961566        -15.833563
# 3         LSTM_pred    113.795554      0.707663         -3.482339
# 4          GRU_pred    -68.561433     -0.690452        -15.571970
# 5     LSTM_GRU_pred    125.121238      0.827482         -2.954018
# 6       BiLSTM_pred    -87.638069     -0.837918        -17.914974
# 7   BiLSTM_GRU_pred    113.717761      0.619109         -6.555487
# 8         QRNN_pred   -104.548831     -0.959003        -17.100504
# 9          ESN_pred    -41.827907     -0.557471        -15.535370
# 10         BNN_pred    175.992873      1.245595         -3.236843
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw    167.491107      1.134158         -3.301464
# 2            CCV_cw     84.295434      0.370128         -7.711557
# 3         LSTM_pred    103.608166      0.515758         -6.951385
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred    178.238255      1.221024         -3.321602
# 6       BiLSTM_pred     91.071114      0.455645         -6.584313
# 7   BiLSTM_GRU_pred    133.463285      0.808977         -3.672213
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred     97.118317      0.467625         -6.886716
# 10         BNN_pred    178.374934      1.224420         -3.321217
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.160598      0.766597         -3.633656
# 1            CCV_dw    189.008699      1.224420         -3.321217
# 2            CCV_cw    167.491107      1.134158         -3.301464
# 3         LSTM_pred    100.744844      0.535069         -6.626702
# 4          GRU_pred    183.563727      1.178712         -3.336496
# 5     LSTM_GRU_pred    178.238255      1.221024         -3.321602
# 6       BiLSTM_pred    189.008699      1.224420         -3.321217
# 7   BiLSTM_GRU_pred    178.374934      1.224420         -3.321217
# 8         QRNN_pred    167.491107      1.134158         -3.301464
# 9          ESN_pred    121.765936      0.616362         -6.900579
# 10         BNN_pred    177.842398      1.220038         -3.322718
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw     19.545949     -0.386092         -4.604004
# 2            CCV_cw    -26.024337     -1.325563         -6.375998
# 3         LSTM_pred     67.334308      0.369973         -4.255629
# 4          GRU_pred    168.255577      1.548413         -1.745478
# 5     LSTM_GRU_pred     17.379825     -0.498803         -2.351199
# 6       BiLSTM_pred     97.280857      0.756763         -1.702662
# 7   BiLSTM_GRU_pred     16.037829     -0.326350         -5.461614
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred    -22.947148     -1.465607         -4.553508
# 10         BNN_pred    115.383631      0.906180         -2.780953
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw     79.060541      0.422428         -5.848694
# 2            CCV_cw     27.826385     -0.141857         -7.939993
# 3         LSTM_pred    147.016262      1.325802         -3.187441
# 4          GRU_pred     15.620447     -0.394766         -3.824272
# 5     LSTM_GRU_pred      8.808531     -0.451873         -2.946138
# 6       BiLSTM_pred    111.998264      0.788082         -2.999966
# 7   BiLSTM_GRU_pred     26.170451     -0.181735         -3.514005
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred     43.096818      0.033965         -5.109295
# 10         BNN_pred    211.919493      1.888492         -1.733900
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.940921      0.371345         -3.827800
# 1            CCV_dw    107.116275      0.570899         -3.498167
# 2            CCV_cw     23.445960     -0.207586         -4.819700
# 3         LSTM_pred    159.930705      1.294749         -3.164465
# 4          GRU_pred      8.693159     -0.473760         -4.290971
# 5     LSTM_GRU_pred    161.989273      1.224197         -2.393698
# 6       BiLSTM_pred     58.943553      0.117607         -4.384055
# 7   BiLSTM_GRU_pred    106.170523      0.742544         -2.460545
# 8         QRNN_pred    108.276609      0.891758         -2.393698
# 9          ESN_pred     55.493579      0.169015         -7.147804
# 10         BNN_pred    117.622266      0.763994         -4.554092
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw     17.698106     -0.415251         -4.604004
# 2            CCV_cw     -3.132697     -0.697455         -5.881854
# 3         LSTM_pred     67.334308      0.369973         -4.255629
# 4          GRU_pred    168.255577      1.548413         -1.745478
# 5     LSTM_GRU_pred     17.379825     -0.498803         -2.351199
# 6       BiLSTM_pred     87.467449      0.756763         -1.702662
# 7   BiLSTM_GRU_pred    -16.573419     -0.628917         -8.859699
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred    -22.947148     -1.465607         -4.553508
# 10         BNN_pred    115.383631      0.906180         -2.780953
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw     77.104833      0.401057         -5.859313
# 2            CCV_cw     57.444219      0.191127         -5.644368
# 3         LSTM_pred    147.016262      1.325802         -3.187441
# 4          GRU_pred     30.219617     -0.154182         -4.695850
# 5     LSTM_GRU_pred    -25.974069     -0.791663         -5.881854
# 6       BiLSTM_pred     79.078797      0.460387         -4.360962
# 7   BiLSTM_GRU_pred    -11.314456     -0.552479         -6.364489
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred     10.405699     -0.353242         -7.073269
# 10         BNN_pred    212.467437      1.894140         -1.733117
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     37.957512     -0.005320         -7.279240
# 1            CCV_dw    106.862221      0.567374         -3.498970
# 2            CCV_cw    -83.859013     -1.025354        -13.534141
# 3         LSTM_pred    160.455143      1.300123         -3.163035
# 4          GRU_pred     23.192751     -0.241253         -4.728099
# 5     LSTM_GRU_pred    161.989273      1.224197         -2.393698
# 6       BiLSTM_pred     49.473011      0.117607         -4.384055
# 7   BiLSTM_GRU_pred     95.161235      0.536792         -5.603032
# 8         QRNN_pred      0.278767     -0.370369        -10.287200
# 9          ESN_pred     19.609895     -0.165278         -7.399360
# 10         BNN_pred    118.127575      0.768716         -4.552034
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw     17.698106     -0.415251         -4.604004
# 2            CCV_cw     -3.132697     -0.697455         -5.881854
# 3         LSTM_pred     58.317380      0.206105         -7.110242
# 4          GRU_pred     10.751582     -0.184171        -15.307552
# 5     LSTM_GRU_pred     17.379825     -0.498803         -2.351199
# 6       BiLSTM_pred     87.467449      0.756763         -1.702662
# 7   BiLSTM_GRU_pred     12.130597     -0.287673         -6.199518
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred    -22.947148     -1.465607         -4.553508
# 10         BNN_pred    -26.283858     -0.454837        -15.401605
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw     64.625213      0.268589         -5.896627
# 2            CCV_cw     66.581773      0.283767         -5.596011
# 3         LSTM_pred    137.326175      0.980767         -5.295821
# 4          GRU_pred     10.515674     -0.348844         -7.063190
# 5     LSTM_GRU_pred     -9.218562     -0.551149         -5.845535
# 6       BiLSTM_pred     97.815225      0.603154         -5.518257
# 7   BiLSTM_GRU_pred     31.592061     -0.075204         -5.702890
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred     23.987537     -0.161323         -8.556941
# 10         BNN_pred     56.550718      0.158001        -14.048858
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -32.488201     -0.519943        -15.535370
# 1            CCV_dw     84.253420      0.443525         -3.539985
# 2            CCV_cw   -131.413532     -1.178362        -18.724675
# 3         LSTM_pred    121.116673      0.768943         -5.355044
# 4          GRU_pred      3.623204     -0.415963         -7.111697
# 5     LSTM_GRU_pred    126.628041      0.896779         -2.393698
# 6       BiLSTM_pred     49.473011      0.117607         -4.384055
# 7   BiLSTM_GRU_pred    104.065480      0.626827         -5.476768
# 8         QRNN_pred    -32.488201     -0.519943        -15.535370
# 9          ESN_pred    -52.798756     -0.643343        -15.535370
# 10         BNN_pred    116.101061      0.748079         -4.560299
# 11               __    -96.091692     -0.830469        -16.317555

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     99.617825      0.528054         -5.886730
# 2            CCV_cw     51.874123      0.125489        -14.273879
# 3         LSTM_pred    -96.091692     -0.830469        -16.317555
# 4          GRU_pred    130.857566      0.760684         -6.681250
# 5     LSTM_GRU_pred     34.274663      0.013758        -14.708813
# 6       BiLSTM_pred    -63.695647     -0.630022        -15.535370
# 7   BiLSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred    108.281287      0.600354         -5.190597
# 10         BNN_pred     84.701418      0.374014         -7.111357
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    148.434064      0.847559         -3.657049
# 1            CCV_dw    120.639878      0.704200         -4.216181
# 2            CCV_cw     86.603115      0.418540         -6.953359
# 3         LSTM_pred    116.848067      0.657532         -6.868978
# 4          GRU_pred     91.071114      0.455645         -6.584313
# 5     LSTM_GRU_pred    108.281287      0.600354         -5.190597
# 6       BiLSTM_pred    128.160598      0.766597         -3.633656
# 7   BiLSTM_GRU_pred     32.634565     -0.088433        -13.481605
# 8         QRNN_pred    106.532521      0.575166         -6.828124
# 9          ESN_pred    177.842398      1.220038         -3.322718
# 10         BNN_pred     99.617825      0.528054         -5.886730
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -69.861162     -1.200247        -10.625852
# 1            CCV_dw    -28.418057     -0.700726         -6.254645
# 2            CCV_cw      6.624526     -0.454321         -9.571897
# 3         LSTM_pred     16.387554     -0.228815         -7.950517
# 4          GRU_pred     76.884831      0.341554         -4.998966
# 5     LSTM_GRU_pred    -25.695210     -0.735423        -10.491741
# 6       BiLSTM_pred     16.926615     -0.251324         -6.190325
# 7   BiLSTM_GRU_pred     89.400942      0.486966         -3.896357
# 8         QRNN_pred     -5.242339     -0.516427         -7.712034
# 9          ESN_pred    154.576028      1.272501         -2.287862
# 10         BNN_pred     76.609376      0.464520         -4.954885
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    184.318093      1.143084         -4.598544
# 1            CCV_dw    155.833210      0.976307         -4.740384
# 2            CCV_cw    171.051157      1.237837         -3.346104
# 3         LSTM_pred     65.478259      0.247511         -7.436354
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred    154.470409      0.965179         -5.059471
# 6       BiLSTM_pred     57.742465      0.185492         -4.480535
# 7   BiLSTM_GRU_pred    -12.934038     -0.558133        -13.141564
# 8         QRNN_pred     23.640671     -0.173886         -7.494431
# 9          ESN_pred    144.586631      1.065520         -3.036751
# 10         BNN_pred    116.275501      0.743845         -3.424774
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    176.591687      1.120660         -3.322718
# 1            CCV_dw    135.148097      0.825628         -4.162294
# 2            CCV_cw     82.215447      0.374377         -6.394089
# 3         LSTM_pred    116.848067      0.657532         -6.868978
# 4          GRU_pred     68.790056      0.187555         -6.886416
# 5     LSTM_GRU_pred    108.281287      0.600354         -5.190597
# 6       BiLSTM_pred    142.309814      0.882371         -3.643774
# 7   BiLSTM_GRU_pred      1.523824     -0.255820        -13.567656
# 8         QRNN_pred     40.458971      0.028244         -7.261739
# 9          ESN_pred    160.383360      1.084731         -3.321686
# 10         BNN_pred    100.394124      0.534445         -5.886730
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -72.968561     -0.979694        -12.736187
# 1            CCV_dw    -46.643937     -0.889347         -8.013211
# 2            CCV_cw      6.624526     -0.454321         -9.571897
# 3         LSTM_pred    -63.825430     -0.724161        -14.814772
# 4          GRU_pred     67.253833      0.341554         -4.998966
# 5     LSTM_GRU_pred    -80.805395     -0.837499        -17.222301
# 6       BiLSTM_pred   -102.919258     -0.958063        -16.154773
# 7   BiLSTM_GRU_pred     75.077961      0.373683         -6.162810
# 8         QRNN_pred    -52.717369     -0.898824        -10.825981
# 9          ESN_pred     96.021202      0.589109         -4.660692
# 10         BNN_pred     49.718607      0.112482         -8.488550
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    246.462950      1.548533         -5.114250
# 1            CCV_dw    110.782773      0.621963         -4.932641
# 2            CCV_cw    171.051157      1.237837         -3.346104
# 3         LSTM_pred     -9.615341     -0.286058        -15.146100
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred     77.379459      0.285528        -14.337236
# 6       BiLSTM_pred    -76.698842     -0.737216        -17.087700
# 7   BiLSTM_GRU_pred    -28.176565     -0.483278        -14.814772
# 8         QRNN_pred    -25.212808     -0.603856        -10.508152
# 9          ESN_pred     86.538421      0.461207         -5.294467
# 10         BNN_pred    116.275501      0.743845         -3.424774
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    155.821151      1.035093         -3.301464
# 1            CCV_dw     70.439658      0.287786         -6.047191
# 2            CCV_cw     47.626689      0.096994        -13.928735
# 3         LSTM_pred    -96.091692     -0.830469        -16.317555
# 4          GRU_pred     97.856856      0.491253         -6.987801
# 5     LSTM_GRU_pred     34.274663      0.013758        -14.708813
# 6       BiLSTM_pred      8.071721     -0.160894        -15.322961
# 7   BiLSTM_GRU_pred   -115.413024     -0.965382        -16.317555
# 8         QRNN_pred     -9.197164     -0.359397        -10.385586
# 9          ESN_pred    101.534013      0.548852         -5.222392
# 10         BNN_pred     85.467187      0.379725         -7.111357
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV   -135.885771     -1.251585        -18.658743
# 1            CCV_dw   -131.434553     -1.213455        -17.930544
# 2            CCV_cw      1.324122     -0.438864        -10.524210
# 3         LSTM_pred    -63.825430     -0.724161        -14.814772
# 4          GRU_pred     46.841575      0.081944         -7.323374
# 5     LSTM_GRU_pred    -94.198022     -0.939488        -18.428368
# 6       BiLSTM_pred   -106.380355     -0.936110        -18.183960
# 7   BiLSTM_GRU_pred     75.077961      0.373683         -6.162810
# 8         QRNN_pred   -104.982428     -1.134131        -15.746039
# 9          ESN_pred     -3.729509     -0.277378        -14.814772
# 10         BNN_pred     49.718607      0.112482         -8.488550
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    246.462950      1.548533         -5.114250
# 1            CCV_dw    130.804346      0.747435         -5.671446
# 2            CCV_cw    171.051157      1.237837         -3.346104
# 3         LSTM_pred     -9.615341     -0.286058        -15.146100
# 4          GRU_pred    182.226602      1.319985         -2.125536
# 5     LSTM_GRU_pred     -2.142633     -0.253724        -15.479811
# 6       BiLSTM_pred    -76.698842     -0.737216        -17.087700
# 7   BiLSTM_GRU_pred    -28.176565     -0.483278        -14.814772
# 8         QRNN_pred    -89.743829     -0.990938        -15.535370
# 9          ESN_pred    -28.157867     -0.443466        -15.535370
# 10         BNN_pred    116.275501      0.743845         -3.424774
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    155.821151      1.035093         -3.301464
# 1            CCV_dw    -76.022692     -0.823407        -15.535370
# 2            CCV_cw   -107.047850     -0.993594        -17.370102
# 3         LSTM_pred    -96.091692     -0.830469        -16.317555
# 4          GRU_pred    -87.009473     -0.788587        -16.680318
# 5     LSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 6       BiLSTM_pred      8.071721     -0.160894        -15.322961
# 7   BiLSTM_GRU_pred   -115.413024     -0.965382        -16.317555
# 8         QRNN_pred    -82.818008     -0.887291        -15.535370
# 9          ESN_pred    -49.178904     -0.551670        -15.535370
# 10         BNN_pred     -8.010381     -0.270163        -15.561879
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     76.910947      0.315397         -7.764436
# 2            CCV_cw    106.532521      0.575166         -6.828124
# 3         LSTM_pred    -58.190369     -0.603974        -15.535370
# 4          GRU_pred    130.857566      0.760684         -6.681250
# 5     LSTM_GRU_pred    -80.073633     -0.719933        -16.317555
# 6       BiLSTM_pred     -3.081721     -0.279698        -15.060737
# 7   BiLSTM_GRU_pred     14.064510     -0.160187        -13.399868
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred    108.281287      0.600354         -5.190597
# 10         BNN_pred     97.118317      0.467625         -6.886716
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.545695      0.849282         -3.655821
# 1            CCV_dw     99.617825      0.528054         -5.886730
# 2            CCV_cw    102.912535      0.554937         -5.869144
# 3         LSTM_pred    117.338894      0.543095         -6.927920
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred    102.912535      0.554937         -5.869144
# 6       BiLSTM_pred    128.160598      0.766597         -3.633656
# 7   BiLSTM_GRU_pred     32.634565     -0.088433        -13.481605
# 8         QRNN_pred     93.414907      0.440279         -6.910041
# 9          ESN_pred    108.281287      0.600354         -5.190597
# 10         BNN_pred    109.868909      0.612055         -5.921951
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     25.218667     -0.199834         -4.950365
# 1            CCV_dw     67.592067      0.272362         -8.877427
# 2            CCV_cw     50.801714      0.139765         -3.518644
# 3         LSTM_pred     -8.653106     -0.423071         -8.831917
# 4          GRU_pred    -15.153748     -0.886436         -9.230979
# 5     LSTM_GRU_pred     46.304301      0.075836         -7.301541
# 6       BiLSTM_pred     12.729644     -0.271926         -5.829426
# 7   BiLSTM_GRU_pred    -48.264736     -0.899485        -13.141564
# 8         QRNN_pred    -58.212568     -0.788504        -10.691454
# 9          ESN_pred    150.663464      0.906472         -5.024361
# 10         BNN_pred    129.696785      0.862002         -5.138606
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     80.963094      0.333922         -7.976994
# 1            CCV_dw     51.397241      0.122006         -6.132326
# 2            CCV_cw      9.870188     -0.265366         -7.654117
# 3         LSTM_pred     83.238011      0.297461         -8.114935
# 4          GRU_pred    127.034998      0.859600         -3.267053
# 5     LSTM_GRU_pred     68.283615      0.251357         -8.145707
# 6       BiLSTM_pred    132.274539      0.812226         -3.669688
# 7   BiLSTM_GRU_pred      2.972757     -0.381143        -13.876317
# 8         QRNN_pred     37.880388      0.029721         -8.202036
# 9          ESN_pred    144.227757      0.965560         -5.104762
# 10         BNN_pred    162.338160      1.124898         -3.253829
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.545695      0.849282         -3.655821
# 1            CCV_dw    122.800768      0.721924         -5.853744
# 2            CCV_cw    -15.026590     -0.382433         -8.653081
# 3         LSTM_pred    109.488505      0.562035         -6.142554
# 4          GRU_pred     63.198114      0.144770         -9.956086
# 5     LSTM_GRU_pred    129.344113      0.771255         -5.819828
# 6       BiLSTM_pred    117.015197      0.674113         -3.682912
# 7   BiLSTM_GRU_pred    -68.623858     -0.835113        -14.157592
# 8         QRNN_pred     64.987147      0.228771         -7.203472
# 9          ESN_pred    115.682223      0.657444         -5.156165
# 10         BNN_pred    215.122393      1.539185         -3.156462
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     23.479257     -0.222761         -4.958778
# 1            CCV_dw     67.592067      0.272362         -8.877427
# 2            CCV_cw     50.801714      0.139765         -3.518644
# 3         LSTM_pred    -79.054631     -0.840973        -14.814772
# 4          GRU_pred    -16.389110     -0.673774        -10.406907
# 5     LSTM_GRU_pred     74.475824      0.374566         -7.086127
# 6       BiLSTM_pred   -105.084245     -1.230496        -15.260022
# 7   BiLSTM_GRU_pred    -60.777746     -0.839810        -14.054441
# 8         QRNN_pred    -92.400258     -1.067344        -13.933430
# 9          ESN_pred    150.663464      0.906472         -5.024361
# 10         BNN_pred    125.086078      0.729218         -6.149030
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     56.832016      0.158528         -7.907846
# 1            CCV_dw     17.755895     -0.121177         -8.183184
# 2            CCV_cw     33.401453     -0.036902         -6.808817
# 3         LSTM_pred     -7.256189     -0.267570        -15.146100
# 4          GRU_pred    130.863955      0.902716         -3.255991
# 5     LSTM_GRU_pred     11.118408     -0.124531        -15.276790
# 6       BiLSTM_pred      0.553632     -0.256729        -15.260022
# 7   BiLSTM_GRU_pred     -5.997217     -0.381143        -13.876317
# 8         QRNN_pred      0.204442     -0.228329        -10.263228
# 9          ESN_pred    144.227757      0.965560         -5.104762
# 10         BNN_pred    160.231518      1.104383         -3.259737
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw     56.755917      0.163700         -8.034071
# 2            CCV_cw     11.232765     -0.167446         -8.202036
# 3         LSTM_pred    -56.368231     -0.594706        -14.814772
# 4          GRU_pred     26.863189     -0.064127         -9.948296
# 5     LSTM_GRU_pred    -58.027364     -0.571094        -16.317555
# 6       BiLSTM_pred    -12.930544     -0.353718        -15.264894
# 7   BiLSTM_GRU_pred    -96.873944     -0.978851        -15.291346
# 8         QRNN_pred     26.327203     -0.073296        -10.180123
# 9          ESN_pred    115.682223      0.657444         -5.156165
# 10         BNN_pred    207.316039      1.466625         -3.176871
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     23.479257     -0.222761         -4.958778
# 1            CCV_dw     92.684001      0.474879         -6.735746
# 2            CCV_cw     50.801714      0.139765         -3.518644
# 3         LSTM_pred    -79.054631     -0.840973        -14.814772
# 4          GRU_pred    -10.841735     -0.603834        -10.406907
# 5     LSTM_GRU_pred     74.475824      0.374566         -7.086127
# 6       BiLSTM_pred    -99.291583     -0.877827        -18.003574
# 7   BiLSTM_GRU_pred    -66.936712     -0.733009        -14.814772
# 8         QRNN_pred   -142.475867     -1.272267        -18.682039
# 9          ESN_pred     15.071856     -0.095588        -15.061858
# 10         BNN_pred      6.152524     -0.169969        -14.702564
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -80.112423     -0.717560        -17.083763
# 1            CCV_dw    -48.409360     -0.467523        -15.535370
# 2            CCV_cw     38.480086      0.010727         -6.775519
# 3         LSTM_pred      6.450416     -0.174394        -15.139975
# 4          GRU_pred    130.863955      0.902716         -3.255991
# 5     LSTM_GRU_pred      5.874051     -0.156522        -15.356439
# 6       BiLSTM_pred    -15.627309     -0.323179        -15.463034
# 7   BiLSTM_GRU_pred     -2.340666     -0.263956        -15.482884
# 8         QRNN_pred    -66.009204     -0.605592        -15.535370
# 9          ESN_pred     -6.762138     -0.259185        -15.535370
# 10         BNN_pred    116.900566      0.658623         -5.410619
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -50.836812     -0.619168        -15.535370
# 1            CCV_dw    -68.600967     -0.766421        -15.535370
# 2            CCV_cw   -104.598975     -0.893084        -16.317555
# 3         LSTM_pred    -94.342883     -0.822470        -15.603630
# 4          GRU_pred   -110.397014     -0.924972        -17.953797
# 5     LSTM_GRU_pred    -96.091692     -0.830469        -16.317555
# 6       BiLSTM_pred   -116.107290     -0.969710        -16.317555
# 7   BiLSTM_GRU_pred   -107.814924     -0.915799        -16.317555
# 8         QRNN_pred    -35.750620     -0.470773        -15.535370
# 9          ESN_pred    -85.169579     -0.749031        -16.317555
# 10         BNN_pred    207.316039      1.466625         -3.176871
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.722407     -0.082627        -14.680742
# 1            CCV_dw     99.617825      0.528054         -5.886730
# 2            CCV_cw     41.097587      0.051462        -14.421630
# 3         LSTM_pred    119.884469      0.612055         -5.921951
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred    -43.507228     -0.524640        -15.535370
# 6       BiLSTM_pred    128.160598      0.766597         -3.633656
# 7   BiLSTM_GRU_pred    -17.138313     -0.400494        -15.535370
# 8         QRNN_pred     14.064510     -0.160187        -13.399868
# 9          ESN_pred    108.281287      0.600354         -5.190597
# 10         BNN_pred    107.346100      0.543095         -6.927920
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.160598      0.766597         -3.633656
# 1            CCV_dw    183.563727      1.178712         -3.336496
# 2            CCV_cw     91.071114      0.455645         -6.584313
# 3         LSTM_pred    189.008699      1.224420         -3.321217
# 4          GRU_pred    183.563727      1.178712         -3.336496
# 5     LSTM_GRU_pred    122.732284      0.634846         -5.906929
# 6       BiLSTM_pred    138.163174      0.847559         -3.657049
# 7   BiLSTM_GRU_pred     32.634565     -0.088433        -13.481605
# 8         QRNN_pred     93.414907      0.440279         -6.910041
# 9          ESN_pred    177.842398      1.220038         -3.322718
# 10         BNN_pred    178.374934      1.224420         -3.321217
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw   -106.170709     -2.511004        -11.695219
# 2            CCV_cw     50.931888      0.187530         -2.711791
# 3         LSTM_pred      3.790985     -0.702601         -5.723910
# 4          GRU_pred    121.338387      0.919644         -2.311832
# 5     LSTM_GRU_pred     62.441333      0.341306         -2.034078
# 6       BiLSTM_pred      1.823266     -0.524172         -4.555649
# 7   BiLSTM_GRU_pred    135.614694      1.365481         -3.825627
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred     47.742849      0.094849         -5.395983
# 10         BNN_pred    106.643083      1.206545         -1.667006
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw     83.539773      0.347043         -4.951094
# 2            CCV_cw     66.858246      0.387291         -2.393698
# 3         LSTM_pred     91.411376      0.538196         -7.914975
# 4          GRU_pred     15.620447     -0.394766         -3.824272
# 5     LSTM_GRU_pred     35.653906     -0.027508         -6.386521
# 6       BiLSTM_pred     21.688206     -0.200535         -4.590651
# 7   BiLSTM_GRU_pred    -35.058281     -0.741412        -13.141564
# 8         QRNN_pred     21.458308     -0.173606         -7.851780
# 9          ESN_pred    124.059111      0.936268         -2.975348
# 10         BNN_pred     85.126740      0.619495         -3.217320
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    150.843118      0.995000         -3.562038
# 1            CCV_dw    129.590873      0.685841         -4.928154
# 2            CCV_cw     26.314171     -0.140868         -7.630398
# 3         LSTM_pred     63.311053      0.158021         -3.783060
# 4          GRU_pred    122.984980      0.868181         -2.902810
# 5     LSTM_GRU_pred    159.902335      0.922620         -5.702325
# 6       BiLSTM_pred    147.474339      0.930304         -3.621078
# 7   BiLSTM_GRU_pred     46.889024      0.017939        -13.298039
# 8         QRNN_pred     93.167354      0.510119         -6.911606
# 9          ESN_pred    241.518925      1.699167         -2.545365
# 10         BNN_pred    162.335419      1.131603         -3.274876
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw   -104.386175     -2.319083        -11.518918
# 2            CCV_cw     43.207981      0.023173         -2.711791
# 3         LSTM_pred      3.790985     -0.702601         -5.723910
# 4          GRU_pred    137.457213      1.070094         -3.165398
# 5     LSTM_GRU_pred     62.441333      0.341306         -2.034078
# 6       BiLSTM_pred      6.052773     -0.434458         -5.000797
# 7   BiLSTM_GRU_pred    130.797272      1.035592         -6.066009
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred     28.402189     -0.152549         -6.286970
# 10         BNN_pred    106.643083      1.206545         -1.667006
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw     11.419939     -0.250297         -6.383785
# 2            CCV_cw     59.017288      0.268422         -2.393698
# 3         LSTM_pred     27.961066     -0.101632         -7.914975
# 4          GRU_pred     30.219617     -0.154182         -4.695850
# 5     LSTM_GRU_pred    -82.883207     -0.932178        -15.535370
# 6       BiLSTM_pred     26.001580     -0.141612         -5.017364
# 7   BiLSTM_GRU_pred    -31.508635     -0.530091        -14.814772
# 8         QRNN_pred    -52.670115     -0.897382        -14.877758
# 9          ESN_pred     67.051964      0.291316         -4.818983
# 10         BNN_pred     41.819036      0.032431         -6.641821
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.285013      0.062577        -14.391393
# 1            CCV_dw    130.544702      0.759172         -4.879959
# 2            CCV_cw    -22.181988     -0.467517        -15.332532
# 3         LSTM_pred      1.494384     -0.478441         -6.161639
# 4          GRU_pred    118.071377      0.750225         -4.649757
# 5     LSTM_GRU_pred      1.277518     -0.214350        -15.385621
# 6       BiLSTM_pred    157.097300      1.007519         -3.590964
# 7   BiLSTM_GRU_pred    -11.058220     -0.386773        -15.535370
# 8         QRNN_pred     13.834922     -0.214243        -13.402902
# 9          ESN_pred    178.554752      1.140147         -4.961041
# 10         BNN_pred    187.526775      1.331592         -3.205405
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     43.142249      0.022156         -2.600503
# 1            CCV_dw    -83.336297     -1.701597         -9.706410
# 2            CCV_cw     39.196266     -0.019380         -5.743481
# 3         LSTM_pred      3.790985     -0.702601         -5.723910
# 4          GRU_pred    -34.716517     -0.487049        -14.814772
# 5     LSTM_GRU_pred     62.441333      0.341306         -2.034078
# 6       BiLSTM_pred    -94.616255     -0.980159        -14.814772
# 7   BiLSTM_GRU_pred    130.797272      1.035592         -6.066009
# 8         QRNN_pred     44.412174      0.048445         -2.600503
# 9          ESN_pred     42.225935      0.030225         -7.677327
# 10         BNN_pred    104.637385      1.159595         -1.670033
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.917547      0.729973         -2.393698
# 1            CCV_dw    -89.416592     -0.888048        -15.923251
# 2            CCV_cw      2.029529     -0.366125         -8.102058
# 3         LSTM_pred    -47.211341     -0.572256        -14.814772
# 4          GRU_pred     10.515674     -0.348844         -7.063190
# 5     LSTM_GRU_pred    -79.941753     -0.902456        -15.535370
# 6       BiLSTM_pred   -102.408067     -0.925021        -18.756029
# 7   BiLSTM_GRU_pred    -31.508635     -0.530091        -14.814772
# 8         QRNN_pred    -47.867612     -0.648213        -15.535370
# 9          ESN_pred    -29.653575     -0.425560        -14.904722
# 10         BNN_pred    -70.000913     -0.764258        -16.366711
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     39.697217      0.046288        -14.632099
# 1            CCV_dw     89.981708      0.404184         -8.215434
# 2            CCV_cw   -117.201669     -1.018626        -18.441010
# 3         LSTM_pred    -95.074477     -0.896545        -15.847381
# 4          GRU_pred    -68.561433     -0.690452        -15.571970
# 5     LSTM_GRU_pred      4.648978     -0.181869        -15.333989
# 6       BiLSTM_pred      9.624540     -0.150011        -15.463034
# 7   BiLSTM_GRU_pred    -19.902708     -0.386773        -15.535370
# 8         QRNN_pred   -104.548831     -0.959003        -17.100504
# 9          ESN_pred     39.676497      0.053177        -14.872040
# 10         BNN_pred    141.104519      0.845248         -5.330099
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.414907      0.440279         -6.910041
# 1            CCV_dw    188.870786      1.221024         -3.321602
# 2            CCV_cw    130.857566      0.760684         -6.681250
# 3         LSTM_pred    141.293973      0.789060         -4.241407
# 4          GRU_pred    188.870786      1.221024         -3.321602
# 5     LSTM_GRU_pred    124.231239      0.714926         -6.823867
# 6       BiLSTM_pred    128.160598      0.766597         -3.633656
# 7   BiLSTM_GRU_pred     22.753503     -0.134495        -15.040316
# 8         QRNN_pred     53.723011      0.139558         -9.765439
# 9          ESN_pred    108.281287      0.600354         -5.190597
# 10         BNN_pred    109.868909      0.612055         -5.921951
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.160598      0.766597         -3.633656
# 1            CCV_dw    183.563727      1.178712         -3.336496
# 2            CCV_cw    177.842398      1.220038         -3.322718
# 3         LSTM_pred    189.008699      1.224420         -3.321217
# 4          GRU_pred    183.563727      1.178712         -3.336496
# 5     LSTM_GRU_pred    122.732284      0.634846         -5.906929
# 6       BiLSTM_pred    138.163174      0.847559         -3.657049
# 7   BiLSTM_GRU_pred    151.566393      0.840075         -6.722004
# 8         QRNN_pred    167.491107      1.134158         -3.301464
# 9          ESN_pred    177.842398      1.220038         -3.322718
# 10         BNN_pred    189.008699      1.224420         -3.321217
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw    -34.312902     -1.944204         -5.974039
# 2            CCV_cw     58.445293      0.466961         -0.822210
# 3         LSTM_pred     43.099406      0.021392         -3.327228
# 4          GRU_pred    168.255577      1.548413         -1.745478
# 5     LSTM_GRU_pred     52.453433      0.182702         -2.049538
# 6       BiLSTM_pred    -53.768829     -1.489295         -7.169825
# 7   BiLSTM_GRU_pred     76.165655      0.579629         -3.944368
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred     84.710481      0.585274         -4.005935
# 10         BNN_pred     61.359663      0.350614         -2.370564
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw     -9.468844     -0.776291         -6.471552
# 2            CCV_cw     62.043614      0.356321         -2.261305
# 3         LSTM_pred     60.440792      0.237259         -8.657475
# 4          GRU_pred     15.620447     -0.394766         -3.824272
# 5     LSTM_GRU_pred    135.546911      1.019548         -3.445250
# 6       BiLSTM_pred      4.018457     -0.382558         -6.069555
# 7   BiLSTM_GRU_pred    131.081120      1.308536         -2.126288
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred    164.911605      1.409703         -2.217784
# 10         BNN_pred    162.102404      1.613483         -3.064139
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.940921      0.371345         -3.827800
# 1            CCV_dw    144.949712      0.870040         -5.559727
# 2            CCV_cw     55.185309      0.199133         -3.380983
# 3         LSTM_pred    103.906806      0.629906         -3.648866
# 4          GRU_pred      8.693159     -0.473760         -4.290971
# 5     LSTM_GRU_pred     75.315447      0.338840         -6.111445
# 6       BiLSTM_pred     43.680432      0.050026         -5.397666
# 7   BiLSTM_GRU_pred     81.148342      0.438965         -6.445494
# 8         QRNN_pred    108.276609      0.891758         -2.393698
# 9          ESN_pred    159.156754      1.258883         -2.545365
# 10         BNN_pred    145.474652      0.977895         -3.322415
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw    -34.312902     -1.944204         -5.974039
# 2            CCV_cw     58.445293      0.466961         -0.822210
# 3         LSTM_pred     43.099406      0.021392         -3.327228
# 4          GRU_pred    168.255577      1.548413         -1.745478
# 5     LSTM_GRU_pred     52.453433      0.182702         -2.049538
# 6       BiLSTM_pred    -54.076717     -1.381708         -7.602780
# 7   BiLSTM_GRU_pred     74.653255      0.427511         -5.416136
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred     64.687422      0.313302         -4.867451
# 10         BNN_pred     61.359663      0.350614         -2.370564
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw    -23.552450     -0.856235         -7.877526
# 2            CCV_cw     62.043614      0.356321         -2.261305
# 3         LSTM_pred     60.440792      0.237259         -8.657475
# 4          GRU_pred     30.219617     -0.154182         -4.695850
# 5     LSTM_GRU_pred    135.546911      1.019548         -3.445250
# 6       BiLSTM_pred      8.257232     -0.319131         -6.107603
# 7   BiLSTM_GRU_pred    131.081120      1.308536         -2.126288
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred    104.327449      0.681259         -4.577038
# 10         BNN_pred     94.542399      0.649851         -5.379155
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     37.957512     -0.005320         -7.279240
# 1            CCV_dw    128.670547      0.690939         -5.559727
# 2            CCV_cw     13.093341     -0.308998         -7.457893
# 3         LSTM_pred     59.607205      0.200143         -6.386414
# 4          GRU_pred     23.192751     -0.241253         -4.728099
# 5     LSTM_GRU_pred    107.725790      0.601303         -6.924642
# 6       BiLSTM_pred     56.274126      0.177773         -5.333311
# 7   BiLSTM_GRU_pred    -39.787666     -0.610309        -14.610204
# 8         QRNN_pred      0.278767     -0.370369        -10.287200
# 9          ESN_pred    100.369614      0.610068         -5.313541
# 10         BNN_pred    145.474652      0.977895         -3.322415
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.702960     -0.011039         -2.393698
# 1            CCV_dw    -34.312902     -1.944204         -5.974039
# 2            CCV_cw     46.625770      0.082530         -5.719325
# 3         LSTM_pred     43.099406      0.021392         -3.327228
# 4          GRU_pred     10.751582     -0.184171        -15.307552
# 5     LSTM_GRU_pred     52.453433      0.182702         -2.049538
# 6       BiLSTM_pred   -148.728986     -1.486819        -18.546496
# 7   BiLSTM_GRU_pred     74.653255      0.427511         -5.416136
# 8         QRNN_pred     39.527031     -0.063764         -2.393698
# 9          ESN_pred     78.998913      0.443771         -6.270423
# 10         BNN_pred     59.436037      0.314352         -2.374869
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.516479      0.563658         -2.619129
# 1            CCV_dw    -22.102625     -0.652432         -6.908187
# 2            CCV_cw     50.183908      0.123537         -5.576099
# 3         LSTM_pred     60.440792      0.237259         -8.657475
# 4          GRU_pred     10.515674     -0.348844         -7.063190
# 5     LSTM_GRU_pred    135.546911      1.019548         -3.445250
# 6       BiLSTM_pred    -93.420012     -0.894431        -17.347838
# 7   BiLSTM_GRU_pred    131.081120      1.308536         -2.126288
# 8         QRNN_pred     78.712814      0.593247         -2.393698
# 9          ESN_pred     15.569269     -0.133457        -14.538771
# 10         BNN_pred     -4.029543     -0.266510        -14.814772
# 11               __    -96.091692     -0.830469        -16.317555
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -32.488201     -0.519943        -15.535370
# 1            CCV_dw    -47.521783     -0.474367        -15.594958
# 2            CCV_cw    -86.931760     -0.976122        -15.833563
# 3         LSTM_pred    -27.471529     -0.413171        -15.146100
# 4          GRU_pred      3.623204     -0.415963         -7.111697
# 5     LSTM_GRU_pred    -42.024878     -0.515307        -18.915269
# 6       BiLSTM_pred    -91.676871     -0.872176        -19.835581
# 7   BiLSTM_GRU_pred    -25.824214     -0.465540        -14.814772
# 8         QRNN_pred    -32.488201     -0.519943        -15.535370
# 9          ESN_pred      0.223147     -0.240630        -15.458661
# 10         BNN_pred    124.551727      0.712529         -6.426649
# 11               __    -96.091692     -0.830469        -16.317555

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y2', file, 'CCV')
get_final_results_1('2024_y2', file, 'CCV')

get_final_results('2024_y2', dw_file, 'CCV_dw')
get_final_results_1('2024_y2', dw_file, 'CCV_dw')

get_final_results('2024_y2', cw_file, 'CCV_cw')
get_final_results_1('2024_y2', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-40-2b5630d8a11b>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-40-2b5630d8a11b>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-40-2b5630d8a11b>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-40-2b5630d8a11b>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-40-2b5630d8a11b>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-40-2b5630d8a11b>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-40-2b5630d8a11b>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-40-2b5630d8a11b>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-40-2b5630d8a11b>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-40-2b5630d8a11b>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    189.127638      1.536126         -4.607859
# 1            CCV_dw    186.996980      1.543669         -4.580048
# 2            CCV_cw    176.097033      1.418078         -4.699749
# 3         LSTM_pred    170.157147      1.284226         -5.258589
# 4          GRU_pred    197.143673      1.618049         -4.596920
# 5     LSTM_GRU_pred    165.856132      1.304393         -4.713131
# 6       BiLSTM_pred    166.850204      1.336725         -4.659127
# 7   BiLSTM_GRU_pred    176.612233      1.417502         -4.620472
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    179.178475      1.474099         -4.236136
# 10         BNN_pred    155.673662      1.236719         -5.206440
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.629055      1.371830         -4.103840
# 1            CCV_dw    237.067602      1.962730         -3.529376
# 2            CCV_cw     63.010777      0.227487         -5.281301
# 3         LSTM_pred    133.021286      0.885274         -5.258589
# 4          GRU_pred    165.638942      1.314214         -4.746451
# 5     LSTM_GRU_pred    146.131381      1.177425         -4.281859
# 6       BiLSTM_pred    117.536982      0.829019         -4.423508
# 7   BiLSTM_GRU_pred    210.192410      1.684627         -4.297193
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    157.085940      1.150168         -5.662857
# 10         BNN_pred    180.131327      1.446741         -3.201611
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    102.294908      0.706651         -3.567474
# 1            CCV_dw    187.867745      1.675992         -3.253304
# 2            CCV_cw     53.854200      0.230606         -5.292806
# 3         LSTM_pred    142.121873      1.211084         -2.862087
# 4          GRU_pred    128.017520      1.055557         -3.503367
# 5     LSTM_GRU_pred    117.838707      0.970592         -4.032427
# 6       BiLSTM_pred    119.206610      0.884571         -4.236136
# 7   BiLSTM_GRU_pred    158.278028      1.406031         -4.957256
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    134.506524      1.156684         -3.015289
# 10         BNN_pred    212.779230      1.881375         -2.861789
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    143.356318      1.272687         -3.135983
# 1            CCV_dw    228.332190      1.970329         -3.554476
# 2            CCV_cw     55.359792      0.170064         -4.689195
# 3         LSTM_pred     96.841090      0.640094         -5.258589
# 4          GRU_pred    159.990795      1.303030         -5.460231
# 5     LSTM_GRU_pred    135.232865      1.073089         -4.917144
# 6       BiLSTM_pred    122.985894      0.904407         -4.236136
# 7   BiLSTM_GRU_pred    192.004926      1.690600         -4.487243
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    153.378906      1.141263         -4.812687
# 10         BNN_pred    181.076598      1.456369         -3.199048
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.629055      1.371830         -4.103840
# 1            CCV_dw    224.567141      1.855340         -3.565404
# 2            CCV_cw     42.816356     -0.000806         -5.629399
# 3         LSTM_pred    144.360772      1.013256         -5.258589
# 4          GRU_pred    167.297630      1.330681         -4.739706
# 5     LSTM_GRU_pred    144.626496      1.161837         -4.281859
# 6       BiLSTM_pred    117.536982      0.829019         -4.423508
# 7   BiLSTM_GRU_pred    213.858973      1.713820         -4.297193
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    157.317191      1.152499         -5.662857
# 10         BNN_pred    180.131327      1.446741         -3.201611
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    145.931497      1.111013         -5.149231
# 1            CCV_dw    192.438944      1.626197         -4.236136
# 2            CCV_cw    107.465004      0.832039         -5.036589
# 3         LSTM_pred    198.842905      1.702405         -2.862087
# 4          GRU_pred    189.041518      1.565253         -4.421146
# 5     LSTM_GRU_pred    167.295225      1.417153         -4.236136
# 6       BiLSTM_pred    174.871741      1.416817         -4.879497
# 7   BiLSTM_GRU_pred    164.241397      1.185414         -4.960999
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    123.637766      0.830997         -4.960999
# 10         BNN_pred    154.322183      1.212780         -4.680119
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    220.245465      1.898409         -4.565701
# 1            CCV_dw    186.996980      1.543669         -4.580048
# 2            CCV_cw     99.192259      0.639678         -4.689195
# 3         LSTM_pred    151.313348      1.143411         -5.258589
# 4          GRU_pred    190.448869      1.607708         -5.291133
# 5     LSTM_GRU_pred    159.041228      1.265692         -4.387340
# 6       BiLSTM_pred    166.757544      1.335943         -4.659497
# 7   BiLSTM_GRU_pred    164.328136      1.289456         -4.669219
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    166.619792      1.215175         -4.960999
# 10         BNN_pred    155.673662      1.236719         -5.206440
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    189.127638      1.536126         -4.607859
# 1            CCV_dw    186.996980      1.543669         -4.580048
# 2            CCV_cw    171.814807      1.379399         -4.935435
# 3         LSTM_pred    175.079122      1.348221         -5.258589
# 4          GRU_pred    197.947562      1.625675         -4.593835
# 5     LSTM_GRU_pred    166.639011      1.312133         -4.709968
# 6       BiLSTM_pred    166.850204      1.336725         -4.659127
# 7   BiLSTM_GRU_pred    176.612233      1.417502         -4.620472
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    179.414142      1.476306         -4.236136
# 10         BNN_pred    155.673662      1.236719         -5.206440
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    123.416541      0.821235         -5.100973
# 1            CCV_dw    185.210274      1.523803         -4.236136
# 2            CCV_cw    128.297360      0.987942         -4.943596
# 3         LSTM_pred    211.302494      1.766584         -4.236136
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    196.501280      1.632648         -4.236136
# 6       BiLSTM_pred    187.466842      1.522063         -4.827741
# 7   BiLSTM_GRU_pred    188.660789      1.407470         -4.960999
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    147.635078      1.036452         -4.960999
# 10         BNN_pred    194.077051      1.561020         -4.236136
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    180.593544      1.453272         -4.604890
# 1            CCV_dw    179.801301      1.446015         -4.607982
# 2            CCV_cw    146.095379      1.081893         -4.689195
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    179.707613      1.445244         -4.608348
# 5     LSTM_GRU_pred    179.707613      1.445244         -4.608348
# 6       BiLSTM_pred    179.707613      1.445244         -4.608348
# 7   BiLSTM_GRU_pred    179.707613      1.424188         -4.608348
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.294763         -4.960999
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    179.801301      1.446015         -4.607982
# 1            CCV_dw    179.801301      1.446015         -4.607982
# 2            CCV_cw    175.278958      1.405449         -4.920888
# 3         LSTM_pred    179.801301      1.446015         -4.607982
# 4          GRU_pred    180.593544      1.453272         -4.604890
# 5     LSTM_GRU_pred    180.593544      1.453272         -4.604890
# 6       BiLSTM_pred    179.801301      1.446015         -4.607982
# 7   BiLSTM_GRU_pred    179.801301      1.446015         -4.607982
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.446015         -4.607982
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    189.052447      1.535856         -4.615341
# 1            CCV_dw    215.479283      1.754428         -4.575117
# 2            CCV_cw    117.945051      0.925577         -5.011812
# 3         LSTM_pred    190.024403      1.347401         -4.655263
# 4          GRU_pred    191.764408      1.599223         -4.553894
# 5     LSTM_GRU_pred    175.945624      1.374151         -4.655733
# 6       BiLSTM_pred    182.710483      1.477480         -4.596648
# 7   BiLSTM_GRU_pred    168.634516      1.259652         -4.692917
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    172.405194      1.294424         -4.689073
# 10         BNN_pred    161.638421      1.294146         -5.179706
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    135.922442      1.028128         -4.348955
# 1            CCV_dw    226.114905      1.894617         -3.678923
# 2            CCV_cw    131.623900      0.943330         -5.091455
# 3         LSTM_pred    163.189667      1.129050         -4.236136
# 4          GRU_pred    189.679765      1.552311         -3.739143
# 5     LSTM_GRU_pred    158.984655      1.268532         -4.281859
# 6       BiLSTM_pred    144.465924      1.091895         -4.319424
# 7   BiLSTM_GRU_pred    197.614770      1.480079         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    115.534774      0.738443         -5.809844
# 10         BNN_pred    177.133011      1.412099         -3.209766
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    121.313918      1.094986         -2.469209
# 1            CCV_dw    228.536844      2.020593         -2.736503
# 2            CCV_cw     92.245906      0.614322         -4.660324
# 3         LSTM_pred    133.393817      0.979519         -4.236136
# 4          GRU_pred    211.286834      1.909802         -3.265403
# 5     LSTM_GRU_pred    137.787413      1.173110         -3.586564
# 6       BiLSTM_pred    150.899781      1.202933         -4.236136
# 7   BiLSTM_GRU_pred     89.868897      0.588028         -5.091576
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     77.071278      0.386818         -4.812167
# 10         BNN_pred    204.268654      1.781015         -2.861789
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    140.211282      1.151436         -2.379032
# 1            CCV_dw    223.286824      1.888669         -3.703240
# 2            CCV_cw    103.169616      0.766772         -4.328260
# 3         LSTM_pred    133.393817      0.979519         -4.236136
# 4          GRU_pred    194.924828      1.665917         -4.312866
# 5     LSTM_GRU_pred    149.170851      1.213013         -5.010470
# 6       BiLSTM_pred    155.454247      1.231288         -4.236136
# 7   BiLSTM_GRU_pred    146.131322      1.137413         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    138.784359      1.020579         -4.960999
# 10         BNN_pred    188.154817      1.531178         -2.856106
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    109.484923      0.718108         -4.815542
# 1            CCV_dw    223.286824      1.888669         -3.703240
# 2            CCV_cw    135.223602      1.083986         -4.569760
# 3         LSTM_pred    151.754082      1.133987         -4.236136
# 4          GRU_pred    179.105014      1.463410         -5.306942
# 5     LSTM_GRU_pred    136.083560      1.028750         -5.970321
# 6       BiLSTM_pred    139.372056      1.052175         -4.338735
# 7   BiLSTM_GRU_pred    183.788436      1.466797         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    129.158568      1.012950         -4.236136
# 10         BNN_pred    177.133011      1.412099         -3.209766
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    193.415860      1.780143         -2.016241
# 1            CCV_dw    220.815734      1.874198         -3.638188
# 2            CCV_cw     94.552305      0.614863         -4.660324
# 3         LSTM_pred    150.507004      1.115439         -4.991797
# 4          GRU_pred    220.092364      1.979913         -4.249123
# 5     LSTM_GRU_pred    176.581202      1.526229         -3.468309
# 6       BiLSTM_pred    180.577596      1.476555         -4.822060
# 7   BiLSTM_GRU_pred    124.842456      0.903920         -5.091576
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    102.840248      0.646412         -5.244110
# 10         BNN_pred    167.855047      1.334764         -5.016241
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    173.273008      1.418512         -4.028460
# 1            CCV_dw    215.479283      1.754428         -4.575117
# 2            CCV_cw     94.194285      0.651902         -4.363763
# 3         LSTM_pred    150.507004      1.115439         -4.991797
# 4          GRU_pred    225.188783      1.995984         -4.177081
# 5     LSTM_GRU_pred    175.962933      1.429527         -4.369367
# 6       BiLSTM_pred    166.252892      1.337246         -4.661513
# 7   BiLSTM_GRU_pred    151.504454      1.122263         -4.977373
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    152.731146      1.087277         -4.960999
# 10         BNN_pred    161.638421      1.294146         -5.179706
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    189.052447      1.535856         -4.615341
# 1            CCV_dw    215.479283      1.754428         -4.575117
# 2            CCV_cw    114.843360      0.877297         -4.528587
# 3         LSTM_pred    154.449250      1.140611         -4.750768
# 4          GRU_pred    196.751779      1.688494         -5.190575
# 5     LSTM_GRU_pred    166.898420      1.293143         -5.295381
# 6       BiLSTM_pred    183.504680      1.484768         -4.593563
# 7   BiLSTM_GRU_pred    162.293624      1.209865         -4.718519
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    170.310846      1.297247         -4.689195
# 10         BNN_pred    161.638421      1.294146         -5.179706
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.003208      1.314464         -4.239907
# 1            CCV_dw    193.669869      1.608371         -4.236136
# 2            CCV_cw    134.077273      0.981285         -4.660324
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    190.814673      1.550142         -4.565365
# 5     LSTM_GRU_pred    207.545260      1.745481         -4.236136
# 6       BiLSTM_pred    180.772456      1.456759         -4.821264
# 7   BiLSTM_GRU_pred    187.804040      1.408621         -5.091576
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    176.068165      1.278852         -4.917586
# 10         BNN_pred    188.084147      1.504390         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    139.441183      1.018094         -4.689195
# 1            CCV_dw    179.801301      1.446015         -4.607982
# 2            CCV_cw    129.309316      0.980197         -4.236136
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    179.707613      1.445244         -4.608348
# 6       BiLSTM_pred    179.707613      1.445244         -4.608348
# 7   BiLSTM_GRU_pred    176.366592      1.394336         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    180.593544      1.302142         -4.960999
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    179.801301      1.446015         -4.607982
# 1            CCV_dw    179.801301      1.446015         -4.607982
# 2            CCV_cw    142.571955      1.124979         -4.418685
# 3         LSTM_pred    180.593544      1.453272         -4.604890
# 4          GRU_pred    179.707613      1.445244         -4.608348
# 5     LSTM_GRU_pred    179.707613      1.445244         -4.608348
# 6       BiLSTM_pred    180.593544      1.453272         -4.604890
# 7   BiLSTM_GRU_pred    179.801301      1.446015         -4.607982
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.349846         -4.689195
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    115.455615      0.680236         -5.956153
# 1            CCV_dw    209.001362      1.751517         -3.610894
# 2            CCV_cw    130.586413      0.874072         -5.959856
# 3         LSTM_pred    152.710295      1.140077         -4.236136
# 4          GRU_pred    154.028965      1.256640         -3.889398
# 5     LSTM_GRU_pred    148.933663      1.274235         -4.236136
# 6       BiLSTM_pred    149.276437      1.109207         -4.269553
# 7   BiLSTM_GRU_pred    133.938035      1.084081         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    150.774959      1.045988         -5.135747
# 10         BNN_pred    151.614197      1.117107         -4.236136
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    116.246769      0.723511         -5.956153
# 1            CCV_dw    176.970669      1.447718         -3.812654
# 2            CCV_cw     81.016057      0.400850         -5.959856
# 3         LSTM_pred    141.892572      1.017625         -5.258589
# 4          GRU_pred     85.445606      0.535652         -4.557809
# 5     LSTM_GRU_pred    149.849941      1.261726         -4.057113
# 6       BiLSTM_pred     47.129996      0.083644         -5.789546
# 7   BiLSTM_GRU_pred    177.485991      1.519178         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    120.411358      0.786512         -5.701289
# 10         BNN_pred    177.678430      1.428649         -3.401469
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    127.512295      1.162009         -4.236136
# 1            CCV_dw     67.268292      0.406792         -2.467113
# 2            CCV_cw    -27.807890     -1.359253         -5.971125
# 3         LSTM_pred     86.358244      0.585609         -5.258589
# 4          GRU_pred     48.874007      0.118170         -3.607520
# 5     LSTM_GRU_pred     70.304504      0.429146         -3.860590
# 6       BiLSTM_pred     23.651094     -0.250199         -4.615809
# 7   BiLSTM_GRU_pred     32.671742     -0.171868         -3.332465
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     71.758027      0.430024         -5.563997
# 10         BNN_pred    149.526152      1.479737         -2.682638
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    147.843391      1.221269         -4.236136
# 1            CCV_dw    139.353963      1.156437         -3.341273
# 2            CCV_cw     47.556009      0.003537         -4.819470
# 3         LSTM_pred    101.970759      0.766949         -5.258589
# 4          GRU_pred     77.053539      0.505710         -4.106721
# 5     LSTM_GRU_pred    141.572518      1.284906         -3.387949
# 6       BiLSTM_pred     50.934473      0.131383         -4.938351
# 7   BiLSTM_GRU_pred    108.597022      0.861559         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    141.267749      1.206846         -4.924773
# 10         BNN_pred    131.542294      0.981840         -3.171439
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    134.668219      1.055500         -4.236136
# 1            CCV_dw    183.004498      1.578844         -3.217987
# 2            CCV_cw     86.887501      0.479636         -5.155024
# 3         LSTM_pred     96.867767      0.676071         -5.258589
# 4          GRU_pred     96.835020      0.702376         -4.198408
# 5     LSTM_GRU_pred    181.404646      1.638393         -3.558488
# 6       BiLSTM_pred     52.384483      0.148739         -4.682406
# 7   BiLSTM_GRU_pred    137.618233      1.132944         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    139.141365      1.105340         -4.870263
# 10         BNN_pred    142.980578      1.091341         -3.164586
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    180.174131      1.624643         -4.236136
# 1            CCV_dw    171.275882      1.550797         -2.740877
# 2            CCV_cw    -12.422839     -1.002669         -5.878103
# 3         LSTM_pred    124.503361      0.916885         -4.236136
# 4          GRU_pred    124.274356      1.124527         -2.513680
# 5     LSTM_GRU_pred     87.795154      0.763345         -3.444677
# 6       BiLSTM_pred    129.588217      0.973079         -4.236136
# 7   BiLSTM_GRU_pred     59.045528      0.363934         -2.883542
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    113.899832      0.863373         -5.326140
# 10         BNN_pred    182.862583      1.505621         -4.236136
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    148.008607      1.188132         -4.236136
# 1            CCV_dw    206.998531      1.775014         -3.294485
# 2            CCV_cw    105.700409      0.659440         -4.916796
# 3         LSTM_pred    138.892356      1.034553         -4.236136
# 4          GRU_pred    187.938341      1.704961         -3.358436
# 5     LSTM_GRU_pred    124.280753      1.097199         -4.611235
# 6       BiLSTM_pred    159.717627      1.243133         -4.236136
# 7   BiLSTM_GRU_pred     87.016477      0.638281         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    140.071051      1.109732         -4.929942
# 10         BNN_pred    163.356408      1.246266         -4.236136
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    129.766377      0.949999         -4.645223
# 1            CCV_dw    215.074895      1.819256         -3.830083
# 2            CCV_cw    123.238082      0.814227         -4.840028
# 3         LSTM_pred    141.249127      1.057779         -4.236136
# 4          GRU_pred    177.752239      1.531848         -4.413670
# 5     LSTM_GRU_pred    158.818069      1.418410         -4.397465
# 6       BiLSTM_pred    160.508589      1.245837         -4.236136
# 7   BiLSTM_GRU_pred    116.628753      0.924167         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    165.699236      1.319073         -4.816085
# 10         BNN_pred    161.698870      1.222985         -4.236136
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    180.174131      1.624643         -4.236136
# 1            CCV_dw    187.630669      1.554741         -4.236136
# 2            CCV_cw    -12.422839     -1.002669         -5.878103
# 3         LSTM_pred    211.302494      1.766584         -4.236136
# 4          GRU_pred    165.972033      1.321856         -4.271104
# 5     LSTM_GRU_pred    193.181889      1.649450         -4.236136
# 6       BiLSTM_pred    187.466842      1.522063         -4.827741
# 7   BiLSTM_GRU_pred    149.059972      1.193295         -4.393735
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred     90.302301      0.564182         -5.326140
# 10         BNN_pred    190.695335      1.531020         -4.429651
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    148.008607      1.188132         -4.236136
# 1            CCV_dw    184.062087      1.491286         -4.263852
# 2            CCV_cw    160.490196      1.157373         -4.812167
# 3         LSTM_pred    176.366592      1.394336         -4.839321
# 4          GRU_pred    190.814673      1.550142         -4.565365
# 5     LSTM_GRU_pred    190.814673      1.550142         -4.565365
# 6       BiLSTM_pred    180.772456      1.456759         -4.821264
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    164.973633      1.246533         -4.666632
# 10         BNN_pred    184.719403      1.495579         -4.838937
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    129.766377      0.949999         -4.645223
# 1            CCV_dw    176.460014      1.416168         -4.838937
# 2            CCV_cw    151.487285      1.059496         -4.812167
# 3         LSTM_pred    176.460014      1.416168         -4.838937
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    184.125990      1.486637         -4.591153
# 6       BiLSTM_pred    179.707613      1.445244         -4.608348
# 7   BiLSTM_GRU_pred    176.460014      1.416168         -4.838937
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.381438         -4.607982
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    118.260425      0.713171         -5.956153
# 1            CCV_dw    246.400852      2.120500         -3.548521
# 2            CCV_cw     87.275590      0.445085         -5.959856
# 3         LSTM_pred    147.697789      0.998648         -4.236136
# 4          GRU_pred    154.028965      1.256640         -3.889398
# 5     LSTM_GRU_pred    135.062615      1.171713         -4.323207
# 6       BiLSTM_pred     97.883030      0.629003         -4.500546
# 7   BiLSTM_GRU_pred    170.252105      1.481071         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    146.594605      1.024124         -5.135747
# 10         BNN_pred    142.786005      1.032231         -3.444737
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     92.248096      0.469607         -5.956153
# 1            CCV_dw    210.076554      1.997180         -2.437826
# 2            CCV_cw      8.062622     -0.505464         -5.959856
# 3         LSTM_pred    131.639809      0.967647         -3.257141
# 4          GRU_pred     85.445606      0.535652         -4.557809
# 5     LSTM_GRU_pred    100.131758      0.742175         -5.081477
# 6       BiLSTM_pred     76.460576      0.310148         -5.786897
# 7   BiLSTM_GRU_pred    223.520991      2.062234         -2.883542
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     71.683355      0.294580         -5.701289
# 10         BNN_pred    128.579194      0.897399         -3.620545
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     99.616719      0.843390         -4.236136
# 1            CCV_dw     91.622085      1.018484         -0.976881
# 2            CCV_cw    -74.948596     -2.527297         -8.411323
# 3         LSTM_pred     67.740113      0.391581         -3.013438
# 4          GRU_pred     48.874007      0.118170         -3.607520
# 5     LSTM_GRU_pred     44.625939      0.049523         -2.731772
# 6       BiLSTM_pred    118.387000      1.320723         -2.377778
# 7   BiLSTM_GRU_pred     60.589629      0.360853         -2.883542
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     68.212645      0.400666         -5.636624
# 10         BNN_pred     69.267464      0.490589         -2.415447
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    114.976983      0.905614         -4.236136
# 1            CCV_dw     98.399719      0.753761         -2.467113
# 2            CCV_cw    -11.752051     -1.000758         -5.310425
# 3         LSTM_pred    120.816438      1.085305         -3.013438
# 4          GRU_pred     77.053539      0.505710         -4.106721
# 5     LSTM_GRU_pred     82.866042      0.603927         -2.561655
# 6       BiLSTM_pred     61.653443      0.287554         -5.047402
# 7   BiLSTM_GRU_pred    171.012941      1.783791         -2.883542
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     55.442622      0.204558         -5.229155
# 10         BNN_pred    107.843958      0.739715         -3.239280
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    111.315958      0.816725         -4.236136
# 1            CCV_dw    181.465565      1.758775         -2.446366
# 2            CCV_cw    -12.615372     -0.845540         -5.744282
# 3         LSTM_pred     97.230733      0.734295         -3.013438
# 4          GRU_pred     96.835020      0.702376         -4.198408
# 5     LSTM_GRU_pred     95.150057      0.723207         -3.250706
# 6       BiLSTM_pred     65.761408      0.317708         -4.892678
# 7   BiLSTM_GRU_pred    219.076574      2.234424         -2.883542
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     89.184107      0.617906         -5.099382
# 10         BNN_pred     98.963372      0.588092         -3.291339
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.095001      1.122071         -4.236136
# 1            CCV_dw    137.099388      1.389243         -2.844190
# 2            CCV_cw    -59.838923     -2.107587         -6.915325
# 3         LSTM_pred     72.565640      0.382132         -4.236136
# 4          GRU_pred    124.274356      1.124527         -2.513680
# 5     LSTM_GRU_pred     34.096936      0.028094         -3.538163
# 6       BiLSTM_pred    104.938528      0.813835         -2.768674
# 7   BiLSTM_GRU_pred     62.326797      0.443828         -2.883542
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    121.720015      0.955779         -5.326140
# 10         BNN_pred     83.203980      0.470522         -2.862087
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    133.137390      1.092391         -4.236136
# 1            CCV_dw    167.858962      1.461707         -2.467113
# 2            CCV_cw     56.710915      0.125013         -4.966370
# 3         LSTM_pred    116.632133      0.833051         -4.236136
# 4          GRU_pred    187.938341      1.704961         -3.358436
# 5     LSTM_GRU_pred     80.295559      0.644487         -4.513122
# 6       BiLSTM_pred     76.577416      0.417885         -4.281859
# 7   BiLSTM_GRU_pred    125.081133      1.164210         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    117.435630      0.902903         -4.990815
# 10         BNN_pred    130.982460      0.955911         -3.111522
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    141.721852      1.099713         -4.236136
# 1            CCV_dw    191.114582      1.617335         -3.941669
# 2            CCV_cw     66.295733      0.236269         -5.234105
# 3         LSTM_pred    113.238614      0.795892         -4.236136
# 4          GRU_pred    177.752239      1.531848         -4.413670
# 5     LSTM_GRU_pred    152.673442      1.420272         -5.032715
# 6       BiLSTM_pred     96.357614      0.629643         -4.281859
# 7   BiLSTM_GRU_pred    153.688051      1.411210         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    140.096693      1.092903         -4.871662
# 10         BNN_pred    153.010700      1.149748         -3.076763
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    160.726935      1.423980         -4.236136
# 1            CCV_dw    187.630669      1.554741         -4.236136
# 2            CCV_cw    -47.482141     -1.717315         -5.980026
# 3         LSTM_pred    213.347676      1.785820         -4.236136
# 4          GRU_pred    165.972033      1.321856         -4.271104
# 5     LSTM_GRU_pred    129.649881      1.076028         -4.236136
# 6       BiLSTM_pred    194.174397      1.585919         -4.800624
# 7   BiLSTM_GRU_pred    160.231926      1.331983         -4.236136
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred     97.956816      0.649859         -5.326140
# 10         BNN_pred    221.963072      1.772265         -4.878345
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    139.833277      1.117630         -4.236136
# 1            CCV_dw    178.071497      1.438593         -4.285534
# 2            CCV_cw    117.865289      0.777613         -4.812167
# 3         LSTM_pred    182.300391      1.450528         -4.430002
# 4          GRU_pred    190.814673      1.550142         -4.565365
# 5     LSTM_GRU_pred    195.917722      1.603233         -4.236136
# 6       BiLSTM_pred    180.772456      1.456759         -4.821264
# 7   BiLSTM_GRU_pred    184.763064      1.497580         -4.261329
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred     93.763194      0.601658         -4.990815
# 10         BNN_pred    184.719403      1.495579         -4.838937
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.787510      0.943721         -4.236136
# 1            CCV_dw    174.881643      1.401877         -4.845438
# 2            CCV_cw    151.730322      1.062675         -4.812167
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    184.125990      1.486637         -4.591153
# 6       BiLSTM_pred    176.366592      1.415396         -4.839321
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.381438         -4.607982
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    189.127638      1.536126         -4.607859
# 1            CCV_dw    194.261005      1.635228         -4.545705
# 2            CCV_cw    154.674507      1.250059         -4.838401
# 3         LSTM_pred    166.538408      1.329921         -4.660372
# 4          GRU_pred    197.143673      1.618049         -4.596920
# 5     LSTM_GRU_pred    174.121122      1.395982         -4.630275
# 6       BiLSTM_pred    167.329036      1.340470         -4.657216
# 7   BiLSTM_GRU_pred    152.722758      1.216170         -4.723588
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    163.166542      1.344008         -4.236136
# 10         BNN_pred    168.119928      1.251764         -5.211394
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.629055      1.371830         -4.103840
# 1            CCV_dw    218.403848      1.871469         -4.343767
# 2            CCV_cw    127.114483      0.842351         -5.117233
# 3         LSTM_pred     66.820135      0.305177         -4.914031
# 4          GRU_pred    165.638942      1.314214         -4.746451
# 5     LSTM_GRU_pred    150.148305      1.262790         -5.518649
# 6       BiLSTM_pred    148.366220      1.110278         -4.885393
# 7   BiLSTM_GRU_pred    200.608887      1.574287         -3.331090
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    191.291274      1.483806         -5.662857
# 10         BNN_pred    115.116238      0.758979         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    102.294908      0.706651         -3.567474
# 1            CCV_dw    220.268416      1.948185         -4.533724
# 2            CCV_cw    144.457478      1.266883         -5.062006
# 3         LSTM_pred     56.403636      0.196442         -3.781461
# 4          GRU_pred    128.017520      1.055557         -3.503367
# 5     LSTM_GRU_pred    137.075662      1.073862         -4.008836
# 6       BiLSTM_pred    114.605858      0.818767         -4.236136
# 7   BiLSTM_GRU_pred    187.168943      1.565526         -3.315716
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    213.576566      2.036945         -2.862087
# 10         BNN_pred    121.367535      0.834449         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    143.356318      1.272687         -3.135983
# 1            CCV_dw    211.555853      1.816211         -4.533724
# 2            CCV_cw    158.016332      1.298737         -4.139183
# 3         LSTM_pred     54.731946      0.172627         -4.914031
# 4          GRU_pred    159.990795      1.303030         -5.460231
# 5     LSTM_GRU_pred    153.436287      1.301008         -5.047422
# 6       BiLSTM_pred    147.573890      1.108805         -4.879058
# 7   BiLSTM_GRU_pred    211.285900      1.782153         -3.246117
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    206.464662      1.741967         -2.862087
# 10         BNN_pred    112.683983      0.733814         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.629055      1.371830         -4.103840
# 1            CCV_dw    234.102380      2.025855         -4.343767
# 2            CCV_cw    139.293423      1.036896         -4.627424
# 3         LSTM_pred     62.798428      0.260356         -4.914031
# 4          GRU_pred    167.297630      1.330681         -4.739706
# 5     LSTM_GRU_pred    144.610891      1.208709         -5.545347
# 6       BiLSTM_pred    148.366220      1.110278         -4.885393
# 7   BiLSTM_GRU_pred    172.003680      1.317396         -3.331090
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    191.529361      1.486190         -5.662857
# 10         BNN_pred    114.434261      0.751917         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    145.931497      1.111013         -5.149231
# 1            CCV_dw    194.560709      1.551467         -4.878345
# 2            CCV_cw    132.286107      1.179350         -5.045161
# 3         LSTM_pred    155.330371      1.228560         -5.005855
# 4          GRU_pred    189.041518      1.565253         -4.421146
# 5     LSTM_GRU_pred    154.060770      1.121187         -4.878345
# 6       BiLSTM_pred    173.217248      1.375657         -4.244728
# 7   BiLSTM_GRU_pred    144.606173      1.205855         -5.532760
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    145.113104      1.033472         -4.960999
# 10         BNN_pred    171.126552      1.294755         -4.243651
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    220.245465      1.898409         -4.565701
# 1            CCV_dw    189.686438      1.475002         -4.878345
# 2            CCV_cw    131.829029      1.038582         -4.175969
# 3         LSTM_pred    163.234684      1.299962         -4.893953
# 4          GRU_pred    190.448869      1.607708         -5.291133
# 5     LSTM_GRU_pred    167.672837      1.347236         -5.081517
# 6       BiLSTM_pred    167.329036      1.319293         -4.657216
# 7   BiLSTM_GRU_pred    155.667621      1.305724         -4.416013
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    136.927596      0.935137         -4.960999
# 10         BNN_pred    166.196405      1.234053         -5.219989
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    189.127638      1.536126         -4.607859
# 1            CCV_dw    194.261005      1.635228         -4.545705
# 2            CCV_cw    171.505254      1.420127         -4.328033
# 3         LSTM_pred    166.538408      1.329921         -4.660372
# 4          GRU_pred    197.947562      1.625675         -4.593835
# 5     LSTM_GRU_pred    174.121122      1.395982         -4.630275
# 6       BiLSTM_pred    167.329036      1.340470         -4.657216
# 7   BiLSTM_GRU_pred    138.701355      1.092530         -4.781752
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    163.399009      1.346245         -4.236136
# 10         BNN_pred    168.119928      1.251764         -5.211394
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    123.416541      0.821235         -5.100973
# 1            CCV_dw    188.084147      1.407566         -4.878345
# 2            CCV_cw    120.321246      0.902945         -4.952009
# 3         LSTM_pred    167.763995      1.338617         -4.952555
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    159.643900      1.173043         -4.878345
# 6       BiLSTM_pred    185.752425      1.481203         -4.236136
# 7   BiLSTM_GRU_pred    174.403021      1.409527         -5.261938
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    177.250014      1.271714         -4.960999
# 10         BNN_pred    180.593544      1.453272         -4.604890
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    180.593544      1.453272         -4.604890
# 1            CCV_dw    179.801301      1.328100         -4.878345
# 2            CCV_cw    146.095379      1.081893         -4.689195
# 3         LSTM_pred    176.460014      1.416168         -4.838937
# 4          GRU_pred    179.707613      1.445244         -4.608348
# 5     LSTM_GRU_pred    173.321820      1.397688         -5.057052
# 6       BiLSTM_pred    179.801301      1.424961         -4.607982
# 7   BiLSTM_GRU_pred    185.752425      1.502300         -4.236136
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.294763         -4.960999
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    179.801301      1.446015         -4.607982
# 1            CCV_dw    179.801301      1.446015         -4.607982
# 2            CCV_cw    179.801301      1.446015         -4.607982
# 3         LSTM_pred    179.801301      1.446015         -4.607982
# 4          GRU_pred    180.593544      1.453272         -4.604890
# 5     LSTM_GRU_pred    179.801301      1.446015         -4.607982
# 6       BiLSTM_pred    179.801301      1.446015         -4.607982
# 7   BiLSTM_GRU_pred    179.801301      1.446015         -4.607982
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.446015         -4.607982
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    189.052447      1.535856         -4.615341
# 1            CCV_dw    196.877552      1.535849         -4.580597
# 2            CCV_cw    134.293592      1.013663         -5.052088
# 3         LSTM_pred    164.775922      1.334854         -4.236136
# 4          GRU_pred    191.764408      1.599223         -4.553894
# 5     LSTM_GRU_pred    201.228079      1.695171         -4.633038
# 6       BiLSTM_pred    169.901126      1.358613         -4.646977
# 7   BiLSTM_GRU_pred    171.449578      1.379627         -4.640834
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    143.664171      1.028754         -4.763042
# 10         BNN_pred    170.789787      1.384269         -5.179706
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    135.922442      1.028128         -4.348955
# 1            CCV_dw    244.564419      2.113033         -4.343767
# 2            CCV_cw    142.187884      1.033211         -5.238261
# 3         LSTM_pred     93.410913      0.583012         -4.389439
# 4          GRU_pred    189.679765      1.552311         -3.739143
# 5     LSTM_GRU_pred    162.814906      1.248008         -5.572403
# 6       BiLSTM_pred    145.236348      1.010838         -4.875568
# 7   BiLSTM_GRU_pred    158.566028      1.168526         -3.793250
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     98.584154      0.523417         -5.809844
# 10         BNN_pred    140.053112      1.052491         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    121.313918      1.094986         -2.469209
# 1            CCV_dw    240.743180      2.135301         -3.847167
# 2            CCV_cw    117.147248      0.849065         -5.256078
# 3         LSTM_pred     96.041562      0.650558         -3.689440
# 4          GRU_pred    211.286834      1.909802         -3.265403
# 5     LSTM_GRU_pred    156.769649      1.332353         -3.597350
# 6       BiLSTM_pred    115.305108      0.781035         -4.491004
# 7   BiLSTM_GRU_pred    168.825858      1.365203         -4.480812
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     99.870404      0.589014         -5.196690
# 10         BNN_pred    144.385616      1.129687         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    140.211282      1.151436         -2.379032
# 1            CCV_dw    244.745588      2.133051         -4.533724
# 2            CCV_cw    146.197611      1.113778         -4.349343
# 3         LSTM_pred     81.021423      0.463370         -4.389439
# 4          GRU_pred    194.924828      1.665917         -4.312866
# 5     LSTM_GRU_pred    185.011584      1.486035         -5.089116
# 6       BiLSTM_pred    144.010886      1.010651         -4.871099
# 7   BiLSTM_GRU_pred    188.033837      1.522519         -3.344756
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    112.490320      0.690948         -4.960999
# 10         BNN_pred    138.262598      1.034449         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    109.484923      0.718108         -4.815542
# 1            CCV_dw    244.564419      2.113033         -4.343767
# 2            CCV_cw    141.244079      1.021270         -4.568418
# 3         LSTM_pred     84.357874      0.497314         -4.389439
# 4          GRU_pred    179.105014      1.463410         -5.306942
# 5     LSTM_GRU_pred    159.482320      1.217078         -5.588419
# 6       BiLSTM_pred    142.962105      0.988459         -4.875568
# 7   BiLSTM_GRU_pred    144.923534      1.050388         -3.838449
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    124.770452      0.794694         -4.921681
# 10         BNN_pred    140.053112      1.052491         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    193.415860      1.780143         -2.016241
# 1            CCV_dw    218.335603      1.756930         -4.769792
# 2            CCV_cw    100.012049      0.700771         -5.328374
# 3         LSTM_pred    168.111028      1.400062         -4.236136
# 4          GRU_pred    220.092364      1.979913         -4.249123
# 5     LSTM_GRU_pred    214.192946      1.713973         -3.306302
# 6       BiLSTM_pred    180.276172      1.441796         -4.262652
# 7   BiLSTM_GRU_pred    154.682013      1.252484         -5.351808
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     84.598934      0.437859         -5.248775
# 10         BNN_pred    165.210829      1.334792         -5.204506
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    173.273008      1.418512         -4.028460
# 1            CCV_dw    204.614823      1.616498         -4.542138
# 2            CCV_cw    123.400783      1.023970         -4.376512
# 3         LSTM_pred    159.901271      1.312372         -4.236136
# 4          GRU_pred    225.188783      1.995984         -4.177081
# 5     LSTM_GRU_pred    196.969991      1.669980         -5.074614
# 6       BiLSTM_pred    169.901126      1.337524         -4.646977
# 7   BiLSTM_GRU_pred    159.292426      1.283875         -4.295713
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    113.446015      0.714071         -4.960999
# 10         BNN_pred    170.789787      1.384269         -5.179706
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    189.052447      1.535856         -4.615341
# 1            CCV_dw    196.877552      1.535849         -4.580597
# 2            CCV_cw    143.135473      1.119394         -4.547639
# 3         LSTM_pred    150.118931      1.213319         -4.236136
# 4          GRU_pred    196.751779      1.688494         -5.190575
# 5     LSTM_GRU_pred    203.580064      1.717477         -4.623985
# 6       BiLSTM_pred    169.901126      1.337524         -4.646977
# 7   BiLSTM_GRU_pred    158.215494      1.269450         -4.693862
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    141.621166      1.031460         -4.762091
# 10         BNN_pred    170.789787      1.384269         -5.179706
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.003208      1.314464         -4.239907
# 1            CCV_dw    184.719403      1.377465         -4.878345
# 2            CCV_cw    110.103034      0.704733         -5.127690
# 3         LSTM_pred    184.075331      1.494312         -4.934467
# 4          GRU_pred    190.814673      1.550142         -4.565365
# 5     LSTM_GRU_pred    184.474241      1.374210         -4.960999
# 6       BiLSTM_pred    190.264145      1.529729         -4.236136
# 7   BiLSTM_GRU_pred    143.644896      1.142016         -5.403457
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    176.366592      1.281598         -4.839321
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    139.441183      1.018094         -4.689195
# 1            CCV_dw    179.801301      1.328100         -4.878345
# 2            CCV_cw    129.309316      0.980197         -4.236136
# 3         LSTM_pred    176.460014      1.416168         -4.838937
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    173.321820      1.397688         -5.057052
# 6       BiLSTM_pred    179.801301      1.424961         -4.607982
# 7   BiLSTM_GRU_pred    185.752425      1.502300         -4.236136
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    180.593544      1.302142         -4.960999
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    179.801301      1.446015         -4.607982
# 1            CCV_dw    179.801301      1.446015         -4.607982
# 2            CCV_cw    141.108997      1.008651         -4.878345
# 3         LSTM_pred    179.801301      1.446015         -4.607982
# 4          GRU_pred    179.707613      1.445244         -4.608348
# 5     LSTM_GRU_pred    179.801301      1.446015         -4.607982
# 6       BiLSTM_pred    179.801301      1.424961         -4.607982
# 7   BiLSTM_GRU_pred    179.801301      1.446015         -4.607982
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.349846         -4.689195
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    115.455615      0.680236         -5.956153
# 1            CCV_dw    194.509755      1.556630         -4.343767
# 2            CCV_cw    177.605201      1.293234         -4.755415
# 3         LSTM_pred    153.595312      1.172500         -4.689073
# 4          GRU_pred    154.028965      1.256640         -3.889398
# 5     LSTM_GRU_pred    120.322646      0.742811         -5.809844
# 6       BiLSTM_pred    156.377090      1.131268         -4.828596
# 7   BiLSTM_GRU_pred    175.942707      1.305718         -4.706656
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    143.852913      1.045988         -5.135747
# 10         BNN_pred    106.409434      0.657969         -5.522946
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    116.246769      0.723511         -5.956153
# 1            CCV_dw    175.805528      1.580117         -3.338232
# 2            CCV_cw    198.626871      1.678394         -4.264818
# 3         LSTM_pred     70.714381      0.236318         -4.765646
# 4          GRU_pred     85.445606      0.535652         -4.557809
# 5     LSTM_GRU_pred    101.861470      0.719221         -4.645543
# 6       BiLSTM_pred     98.119366      0.692638         -4.306380
# 7   BiLSTM_GRU_pred     98.703675      0.644632         -4.657011
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    134.009359      0.917136         -4.825187
# 10         BNN_pred    123.743633      0.945957         -3.537461
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    127.512295      1.162009         -4.236136
# 1            CCV_dw    117.239469      1.115856         -3.338355
# 2            CCV_cw    -23.349779     -1.304586         -5.447448
# 3         LSTM_pred     26.087098     -0.263799         -3.488619
# 4          GRU_pred     48.874007      0.118170         -3.607520
# 5     LSTM_GRU_pred     75.553087      0.508521         -3.195267
# 6       BiLSTM_pred     83.559348      0.727088         -3.037463
# 7   BiLSTM_GRU_pred    126.716053      1.107385         -2.596530
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     80.201316      0.550623         -5.563997
# 10         BNN_pred    107.413800      0.896290         -4.740882
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    147.843391      1.221269         -4.236136
# 1            CCV_dw    163.300294      1.537256         -3.541469
# 2            CCV_cw     97.111208      0.768380         -4.710098
# 3         LSTM_pred     77.037943      0.469960         -3.737495
# 4          GRU_pred     77.053539      0.505710         -4.106721
# 5     LSTM_GRU_pred    113.804023      0.940807         -3.450591
# 6       BiLSTM_pred    119.618526      1.025839         -5.328204
# 7   BiLSTM_GRU_pred    106.345702      0.807742         -4.554208
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    145.902892      1.265777         -4.954162
# 10         BNN_pred    134.772513      1.120610         -2.967672
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    134.668219      1.055500         -4.236136
# 1            CCV_dw    185.334585      1.701643         -3.530185
# 2            CCV_cw    181.594111      1.667077         -4.342104
# 3         LSTM_pred     49.476066      0.112970         -4.765646
# 4          GRU_pred     96.835020      0.702376         -4.198408
# 5     LSTM_GRU_pred    105.942307      0.782800         -4.203480
# 6       BiLSTM_pred    119.656039      0.954078         -3.783720
# 7   BiLSTM_GRU_pred     87.137056      0.480430         -4.810420
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    143.575089      1.157344         -4.889407
# 10         BNN_pred    111.858287      0.794523         -3.579537
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    180.174131      1.624643         -4.236136
# 1            CCV_dw    186.269362      1.568690         -4.684614
# 2            CCV_cw    -14.530851     -0.936169         -5.369529
# 3         LSTM_pred     46.127434      0.072170         -4.622764
# 4          GRU_pred    124.274356      1.124527         -2.513680
# 5     LSTM_GRU_pred    111.876712      0.893847         -4.236136
# 6       BiLSTM_pred     83.047319      0.481818         -5.511974
# 7   BiLSTM_GRU_pred    220.182008      2.018942         -2.862087
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    122.675114      0.968088         -5.326140
# 10         BNN_pred    131.345665      1.004381         -3.583076
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    148.008607      1.188132         -4.236136
# 1            CCV_dw    216.956125      1.791250         -3.847167
# 2            CCV_cw    169.909088      1.362557         -4.685452
# 3         LSTM_pred    142.300845      1.097256         -4.689073
# 4          GRU_pred    187.938341      1.704961         -3.358436
# 5     LSTM_GRU_pred    145.634652      1.099618         -4.960999
# 6       BiLSTM_pred    119.473845      0.804144         -5.410629
# 7   BiLSTM_GRU_pred    186.577419      1.552315         -5.421996
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    149.052510      1.211087         -4.939595
# 10         BNN_pred     98.046153      0.566014         -5.565012
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    129.766377      0.949999         -4.645223
# 1            CCV_dw    200.062886      1.614586         -4.533724
# 2            CCV_cw    161.024806      1.267588         -4.721306
# 3         LSTM_pred    140.523870      1.073503         -4.689073
# 4          GRU_pred    177.752239      1.531848         -4.413670
# 5     LSTM_GRU_pred    126.702163      0.821049         -5.996889
# 6       BiLSTM_pred    152.794111      1.095906         -4.833985
# 7   BiLSTM_GRU_pred    197.597953      1.559407         -4.721346
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    168.661714      1.348467         -4.803688
# 10         BNN_pred    104.587529      0.621262         -5.532056
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    180.174131      1.624643         -4.236136
# 1            CCV_dw    163.624743      1.182993         -5.091576
# 2            CCV_cw    -22.629913     -1.070680         -5.369529
# 3         LSTM_pred    131.696815      1.063845         -4.506939
# 4          GRU_pred    165.972033      1.321856         -4.271104
# 5     LSTM_GRU_pred    221.283712      1.833564         -4.236136
# 6       BiLSTM_pred    173.488997      1.269768         -5.091576
# 7   BiLSTM_GRU_pred    196.149296      1.626882         -4.236136
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    122.675114      0.968088         -5.326140
# 10         BNN_pred    152.260516      1.205991         -4.718120
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    148.008607      1.188132         -4.236136
# 1            CCV_dw    186.842932      1.397872         -4.878345
# 2            CCV_cw    160.294209      1.148315         -4.812167
# 3         LSTM_pred    177.144077      1.428589         -4.870077
# 4          GRU_pred    190.814673      1.550142         -4.565365
# 5     LSTM_GRU_pred    197.940761      1.496939         -4.960999
# 6       BiLSTM_pred    197.923904      1.522120         -4.689195
# 7   BiLSTM_GRU_pred    178.328677      1.448561         -5.281226
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    164.973633      1.246967         -4.666632
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    129.766377      0.949999         -4.645223
# 1            CCV_dw    188.084147      1.407566         -4.878345
# 2            CCV_cw    151.482942      1.059048         -4.812167
# 3         LSTM_pred    176.460014      1.416168         -4.838937
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    173.321820      1.278679         -5.057052
# 6       BiLSTM_pred    179.801301      1.424961         -4.607982
# 7   BiLSTM_GRU_pred    179.801301      1.446015         -4.607982
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.381438         -4.607982
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    118.260425      0.713171         -5.956153
# 1            CCV_dw    204.442369      1.722811         -4.807700
# 2            CCV_cw    168.098143      1.167613         -5.132012
# 3         LSTM_pred     78.513421      0.442647         -4.914031
# 4          GRU_pred    154.028965      1.256640         -3.889398
# 5     LSTM_GRU_pred    156.345395      1.271255         -4.360585
# 6       BiLSTM_pred    106.684305      0.642072         -4.902513
# 7   BiLSTM_GRU_pred    167.915224      1.235176         -4.739006
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    154.218179      1.042240         -5.132012
# 10         BNN_pred    126.474490      0.892630         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     92.248096      0.469607         -5.956153
# 1            CCV_dw    207.839894      1.887225         -3.338232
# 2            CCV_cw    110.926023      0.704525         -5.222641
# 3         LSTM_pred     83.872526      0.402536         -4.539429
# 4          GRU_pred     85.445606      0.535652         -4.557809
# 5     LSTM_GRU_pred    144.776525      1.223019         -3.727532
# 6       BiLSTM_pred    112.265065      0.889482         -3.878805
# 7   BiLSTM_GRU_pred     66.027264      0.237942         -4.131942
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    106.927663      0.666831         -4.943238
# 10         BNN_pred     88.721148      0.467502         -3.766096
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     99.616719      0.843390         -4.236136
# 1            CCV_dw     90.980818      0.676273         -3.338355
# 2            CCV_cw      1.406975     -0.857289         -5.233126
# 3         LSTM_pred     12.073090     -0.515932         -3.679527
# 4          GRU_pred     48.874007      0.118170         -3.607520
# 5     LSTM_GRU_pred     96.789803      0.848904         -2.862087
# 6       BiLSTM_pred    105.560794      1.309283         -2.165929
# 7   BiLSTM_GRU_pred     80.193372      0.591331         -2.942569
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     69.122185      0.415282         -5.643800
# 10         BNN_pred     82.428074      0.495131         -4.651844
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    114.976983      0.905614         -4.236136
# 1            CCV_dw    124.690149      1.038343         -3.676750
# 2            CCV_cw     62.532787      0.337559         -4.932072
# 3         LSTM_pred     47.516984      0.090552         -3.788444
# 4          GRU_pred     77.053539      0.505710         -4.106721
# 5     LSTM_GRU_pred     99.097087      0.794017         -3.335537
# 6       BiLSTM_pred    121.101985      1.136788         -4.396363
# 7   BiLSTM_GRU_pred     47.121414      0.084817         -3.933871
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    102.704755      0.841451         -5.113563
# 10         BNN_pred     80.535636      0.424012         -4.768993
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    111.315958      0.816725         -4.236136
# 1            CCV_dw    203.104255      1.906534         -3.530185
# 2            CCV_cw    109.216926      0.894620         -5.132023
# 3         LSTM_pred     43.242913      0.035405         -4.765646
# 4          GRU_pred     96.835020      0.702376         -4.198408
# 5     LSTM_GRU_pred    132.196749      1.165039         -3.293211
# 6       BiLSTM_pred    126.781838      1.087328         -3.463936
# 7   BiLSTM_GRU_pred     35.588509     -0.150742         -4.273506
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    129.250554      1.083814         -4.957201
# 10         BNN_pred     81.056924      0.377165         -3.853451
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.095001      1.122071         -4.236136
# 1            CCV_dw    103.498114      0.880891         -4.684614
# 2            CCV_cw    -20.149945     -1.081132         -5.232546
# 3         LSTM_pred     19.231073     -0.381734         -3.564340
# 4          GRU_pred    124.274356      1.124527         -2.513680
# 5     LSTM_GRU_pred    137.551839      1.316482         -2.862087
# 6       BiLSTM_pred     88.067755      0.671273         -4.209346
# 7   BiLSTM_GRU_pred    170.627065      1.538140         -2.862087
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    122.675114      0.968088         -5.326140
# 10         BNN_pred    107.540015      0.844813         -3.313342
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    133.137390      1.092391         -4.236136
# 1            CCV_dw    188.144035      1.692580         -4.008677
# 2            CCV_cw     92.436332      0.624738         -5.053818
# 3         LSTM_pred     83.131205      0.538402         -3.578724
# 4          GRU_pred    187.938341      1.704961         -3.358436
# 5     LSTM_GRU_pred    145.790623      1.315708         -3.377811
# 6       BiLSTM_pred     78.384799      0.366583         -6.145467
# 7   BiLSTM_GRU_pred    180.373376      1.516083         -5.450494
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    138.342827      1.108086         -4.987064
# 10         BNN_pred    105.350596      0.710287         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    141.721852      1.099713         -4.236136
# 1            CCV_dw    228.900829      2.008903         -4.533724
# 2            CCV_cw    130.154085      1.010677         -4.885152
# 3         LSTM_pred     64.862169      0.295376         -4.914031
# 4          GRU_pred    177.752239      1.531848         -4.413670
# 5     LSTM_GRU_pred    187.903277      1.664565         -3.243129
# 6       BiLSTM_pred    111.587227      0.707704         -4.453691
# 7   BiLSTM_GRU_pred    187.696799      1.486285         -4.760705
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    153.604160      1.222369         -4.814620
# 10         BNN_pred    124.213867      0.857650         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    160.726935      1.423980         -4.236136
# 1            CCV_dw    159.891992      1.198962         -5.091576
# 2            CCV_cw    -35.141717     -1.309361         -5.232546
# 3         LSTM_pred    124.228202      0.992044         -4.536880
# 4          GRU_pred    165.972033      1.321856         -4.271104
# 5     LSTM_GRU_pred    213.319084      1.794811         -4.236136
# 6       BiLSTM_pred    173.488997      1.269768         -5.091576
# 7   BiLSTM_GRU_pred    194.544509      1.611298         -4.236136
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    122.675114      0.968088         -5.326140
# 10         BNN_pred    125.439688      0.968674         -4.830559
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    139.833277      1.117630         -4.236136
# 1            CCV_dw    177.334875      1.291439         -5.091576
# 2            CCV_cw    151.940811      1.071257         -4.812167
# 3         LSTM_pred    179.750827      1.453435         -4.952555
# 4          GRU_pred    190.814673      1.550142         -4.565365
# 5     LSTM_GRU_pred    206.350957      1.580601         -4.960999
# 6       BiLSTM_pred    190.264145      1.410017         -5.091576
# 7   BiLSTM_GRU_pred    178.328677      1.448561         -5.281226
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    153.884947      1.151428         -4.711478
# 10         BNN_pred    152.260516      1.205991         -4.718120
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.787510      0.943721         -4.236136
# 1            CCV_dw    190.213707      1.427998         -4.878345
# 2            CCV_cw    151.487285      1.059496         -4.812167
# 3         LSTM_pred    174.881643      1.401877         -4.845438
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    173.321820      1.244526         -5.057052
# 6       BiLSTM_pred    185.752425      1.481203         -4.236136
# 7   BiLSTM_GRU_pred    179.801301      1.446015         -4.607982
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.381871         -4.607982
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_2y)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_2y)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_2y', file, 'CCV')
get_final_results_1('2022_2y', file, 'CCV')

get_final_results('2022_2y', dw_file, 'CCV_dw')
get_final_results_1('2022_2y', dw_file, 'CCV_dw')

get_final_results('2022_2y', cw_file, 'CCV_cw')
get_final_results_1('2022_2y', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:30: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-18-f24360cd4555>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-18-f24360cd4555>:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:40: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-18-f24360cd4555>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-18-f24360cd4555>:46: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:30: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-18-f24360cd4555>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-18-f24360cd4555>:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:40: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-18-f24360cd4555>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-18-f24360cd4555>:46: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:30: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# ...
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:30: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-18-f24360cd4555>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-18-f24360cd4555>:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-18-f24360cd4555>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     53.432617     -0.070375        -16.523421
# 1            CCV_dw     98.177927      0.093731        -18.718334
# 2            CCV_cw    123.386331      0.183160        -15.774136
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred     42.914187     -0.111103        -17.181310
# 5     LSTM_GRU_pred     42.914187     -0.111103        -17.181310
# 6       BiLSTM_pred    115.833164      0.156557        -16.254849
# 7   BiLSTM_GRU_pred    105.290620      0.119452        -17.049531
# 8         QRNN_pred    138.613732      0.236401        -15.774136
# 9          ESN_pred     60.637524     -0.043037        -17.369119
# 10         BNN_pred    164.877096      0.326405        -15.554671
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.014395      0.018279        -16.035561
# 1            CCV_dw    136.909235      0.237564        -14.555359
# 2            CCV_cw     58.004999     -0.061349        -16.785697
# 3         LSTM_pred      9.006058     -0.266349        -16.540704
# 4          GRU_pred     65.837421     -0.026699        -16.098501
# 5     LSTM_GRU_pred     50.402780     -0.091970        -16.639535
# 6       BiLSTM_pred     93.349778      0.075026        -14.059806
# 7   BiLSTM_GRU_pred    101.657110      0.105843        -13.548522
# 8         QRNN_pred    182.789736      0.396167        -15.787673
# 9          ESN_pred     70.519221     -0.012541        -14.283370
# 10         BNN_pred    156.226646      0.305139        -12.948839
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     13.809170     -0.268825        -17.045471
# 1            CCV_dw    128.443055      0.214652        -14.570470
# 2            CCV_cw    -65.965333     -0.677738        -18.115515
# 3         LSTM_pred    -93.236203     -0.767881        -17.963664
# 4          GRU_pred    -30.689164     -0.442577        -14.864757
# 5     LSTM_GRU_pred    -55.903021     -0.581862        -16.802687
# 6       BiLSTM_pred    -74.532313     -0.657786        -16.132538
# 7   BiLSTM_GRU_pred    -45.910699     -0.617698        -16.773998
# 8         QRNN_pred     12.667779     -0.276068        -18.110606
# 9          ESN_pred   -101.319810     -0.881884        -17.809469
# 10         BNN_pred     77.031502      0.003549        -13.583407
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     69.076103     -0.019099        -15.971820
# 1            CCV_dw    108.956800      0.133592        -15.190846
# 2            CCV_cw    -60.662273     -0.622563        -19.229950
# 3         LSTM_pred    -19.603042     -0.394053        -17.836158
# 4          GRU_pred     -8.420602     -0.323333        -16.771894
# 5     LSTM_GRU_pred    -48.399599     -0.518596        -17.975208
# 6       BiLSTM_pred    -12.453210     -0.353484        -14.535799
# 7   BiLSTM_GRU_pred     13.299715     -0.261730        -13.552742
# 8         QRNN_pred     84.788261      0.039063        -16.035561
# 9          ESN_pred    -13.879081     -0.395880        -16.006370
# 10         BNN_pred    118.180109      0.167687        -12.871150
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.528766     -0.056042        -16.035561
# 1            CCV_dw    124.014997      0.190133        -14.735117
# 2            CCV_cw     33.570471     -0.159351        -16.785697
# 3         LSTM_pred      9.006058     -0.266349        -16.540704
# 4          GRU_pred     53.012929     -0.075649        -16.098501
# 5     LSTM_GRU_pred     37.764003     -0.142640        -16.639535
# 6       BiLSTM_pred     77.099117      0.013515        -14.059806
# 7   BiLSTM_GRU_pred    101.996301      0.107131        -13.548522
# 8         QRNN_pred    146.570883      0.271031        -16.035561
# 9          ESN_pred     59.882007     -0.055017        -15.290211
# 10         BNN_pred    146.101872      0.269101        -12.948839
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -3.911574     -0.337561        -17.045471
# 1            CCV_dw    107.618887      0.128312        -17.440303
# 2            CCV_cw     -0.150810     -0.303851        -16.551799
# 3         LSTM_pred     45.705902     -0.102804        -16.163149
# 4          GRU_pred    -52.866495     -0.521409        -18.229915
# 5     LSTM_GRU_pred    -75.905563     -0.624008        -18.537264
# 6       BiLSTM_pred     47.357683     -0.096134        -15.937404
# 7   BiLSTM_GRU_pred     21.823948     -0.229600        -18.236509
# 8         QRNN_pred     10.490611     -0.276807        -18.110606
# 9          ESN_pred    -15.635093     -0.386398        -13.584098
# 10         BNN_pred    101.272604      0.104602        -16.237555
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     68.406043     -0.016596        -15.983096
# 1            CCV_dw     86.095150      0.049548        -19.128046
# 2            CCV_cw     16.855201     -0.219739        -16.935304
# 3         LSTM_pred    126.130683      0.192603        -15.916361
# 4          GRU_pred    -32.308777     -0.415734        -18.508303
# 5     LSTM_GRU_pred    -56.881219     -0.525597        -18.508303
# 6       BiLSTM_pred     58.894759     -0.050427        -16.320926
# 7   BiLSTM_GRU_pred     29.745609     -0.162608        -17.049531
# 8         QRNN_pred     71.490303     -0.012013        -16.035561
# 9          ESN_pred     94.901294      0.080713        -13.217715
# 10         BNN_pred    157.363583      0.301012        -15.554671
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     49.809541     -0.084022        -16.523421
# 1            CCV_dw     95.745243      0.084893        -18.718334
# 2            CCV_cw     91.207110      0.068974        -15.911578
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred     28.514407     -0.166740        -17.181310
# 5     LSTM_GRU_pred     28.514407     -0.166740        -17.181310
# 6       BiLSTM_pred    107.570456      0.127511        -16.254849
# 7   BiLSTM_GRU_pred     98.161442      0.094112        -17.049531
# 8         QRNN_pred    109.987883      0.136314        -16.035561
# 9          ESN_pred     71.040771     -0.005526        -17.892477
# 10         BNN_pred    164.877096      0.326405        -15.554671
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      9.642204     -0.264398        -16.035561
# 1            CCV_dw     75.626643      0.009833        -17.243913
# 2            CCV_cw     25.975009     -0.187851        -16.606433
# 3         LSTM_pred     45.705902     -0.102804        -16.163149
# 4          GRU_pred     65.779330     -0.024782        -15.965790
# 5     LSTM_GRU_pred     48.833285     -0.088614        -15.965790
# 6       BiLSTM_pred     37.086989     -0.134201        -16.035561
# 7   BiLSTM_GRU_pred     26.275909     -0.208595        -17.234371
# 8         QRNN_pred      9.766621     -0.272636        -18.110606
# 9          ESN_pred     79.640093      0.026724        -16.035561
# 10         BNN_pred     38.581153     -0.130184        -16.719255
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    106.506458      0.123762        -15.916361
# 1            CCV_dw    107.506067      0.127275        -15.916361
# 2            CCV_cw     41.690035     -0.117938        -16.935304
# 3         LSTM_pred    126.130683      0.192603        -15.916361
# 4          GRU_pred    108.513301      0.130850        -15.916361
# 5     LSTM_GRU_pred     82.823508      0.038315        -16.035561
# 6       BiLSTM_pred     62.240186     -0.037615        -16.035561
# 7   BiLSTM_GRU_pred     41.722094     -0.115786        -16.035561
# 8         QRNN_pred     50.165618     -0.094493        -16.035561
# 9          ESN_pred    113.116629      0.146997        -15.916361
# 10         BNN_pred    108.571536      0.131030        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    115.768295      0.156283        -15.916361
# 1            CCV_dw    115.768295      0.156283        -15.916361
# 2            CCV_cw    110.314378      0.137167        -15.916361
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred    100.362599      0.101982        -15.916361
# 5     LSTM_GRU_pred    100.362599      0.101982        -15.916361
# 6       BiLSTM_pred    107.506067      0.127275        -15.916361
# 7   BiLSTM_GRU_pred    108.571536      0.131030        -15.916361
# 8         QRNN_pred     89.910368      0.064268        -16.035561
# 9          ESN_pred    115.768295      0.156283        -15.916361
# 10         BNN_pred    115.768295      0.156283        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     83.660147      0.041773        -16.035561
# 1            CCV_dw     92.159949      0.071665        -18.718334
# 2            CCV_cw    112.103654      0.143649        -15.916361
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred     53.104744     -0.071968        -17.181310
# 5     LSTM_GRU_pred     54.325019     -0.067303        -17.181310
# 6       BiLSTM_pred     77.859661      0.020725        -16.320926
# 7   BiLSTM_GRU_pred     71.527416     -0.005523        -17.049531
# 8         QRNN_pred    158.832704      0.307192        -16.035561
# 9          ESN_pred     84.704461      0.041253        -16.035561
# 10         BNN_pred    147.884625      0.268498        -15.618727
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    171.107867      0.356807        -16.035561
# 1            CCV_dw     65.190686     -0.033780        -16.797833
# 2            CCV_cw     32.061663     -0.158464        -16.851590
# 3         LSTM_pred     71.985601     -0.010465        -14.010447
# 4          GRU_pred     79.921435      0.025370        -16.098501
# 5     LSTM_GRU_pred     63.945314     -0.038561        -16.098501
# 6       BiLSTM_pred    156.190132      0.306335        -13.593010
# 7   BiLSTM_GRU_pred     73.779326     -0.001790        -16.225075
# 8         QRNN_pred    139.983787      0.247520        -16.387586
# 9          ESN_pred     99.081568      0.096453        -15.121049
# 10         BNN_pred    134.680648      0.226639        -16.115744
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     14.965179     -0.268935        -18.296292
# 1            CCV_dw     75.041533     -0.005729        -14.735684
# 2            CCV_cw    -22.860106     -0.449512        -16.903792
# 3         LSTM_pred    -25.987669     -0.448768        -16.192625
# 4          GRU_pred     32.936725     -0.179365        -13.810384
# 5     LSTM_GRU_pred     -2.469605     -0.345455        -14.195778
# 6       BiLSTM_pred      6.781062     -0.302039        -14.969540
# 7   BiLSTM_GRU_pred    -99.826169     -0.936534        -18.274765
# 8         QRNN_pred     42.942832     -0.154921        -15.121525
# 9          ESN_pred    -42.257863     -0.557856        -14.417734
# 10         BNN_pred     92.551467      0.069814        -16.801477
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.694415      0.209911        -16.929177
# 1            CCV_dw     70.978475     -0.012126        -15.496577
# 2            CCV_cw    -49.219436     -0.512090        -16.035561
# 3         LSTM_pred     31.674843     -0.180956        -15.092744
# 4          GRU_pred    -21.457344     -0.382305        -17.295984
# 5     LSTM_GRU_pred    -35.109028     -0.461275        -16.781259
# 6       BiLSTM_pred     79.489656      0.018099        -13.802478
# 7   BiLSTM_GRU_pred    -16.217740     -0.405006        -16.320926
# 8         QRNN_pred     42.154060     -0.138653        -16.999813
# 9          ESN_pred     17.599842     -0.245594        -15.472089
# 10         BNN_pred    130.194294      0.210490        -16.115744
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    152.626780      0.292024        -16.035561
# 1            CCV_dw     65.214880     -0.033713        -16.760241
# 2            CCV_cw     34.696830     -0.149786        -16.035561
# 3         LSTM_pred     71.985601     -0.010465        -14.010447
# 4          GRU_pred     40.704724     -0.125964        -16.108842
# 5     LSTM_GRU_pred     29.520467     -0.176442        -16.098501
# 6       BiLSTM_pred    132.006634      0.218948        -13.723693
# 7   BiLSTM_GRU_pred      5.253950     -0.286582        -16.320926
# 8         QRNN_pred     58.965626     -0.062080        -17.984870
# 9          ESN_pred     74.879513     -0.001359        -15.616175
# 10         BNN_pred    134.680648      0.226639        -16.115744
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -24.075030     -0.433990        -17.310984
# 1            CCV_dw     92.555124      0.070680        -17.440303
# 2            CCV_cw     34.269131     -0.158166        -17.023536
# 3         LSTM_pred     42.188755     -0.116361        -16.163149
# 4          GRU_pred    -33.877931     -0.451550        -18.192670
# 5     LSTM_GRU_pred    -37.105070     -0.464747        -18.527043
# 6       BiLSTM_pred     35.618529     -0.148053        -16.324547
# 7   BiLSTM_GRU_pred    -59.539311     -0.638604        -18.200954
# 8         QRNN_pred     34.537419     -0.187776        -15.121525
# 9          ESN_pred    -17.997933     -0.413019        -16.035561
# 10         BNN_pred     74.812033      0.006321        -16.388193
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     87.097791      0.050026        -15.919901
# 1            CCV_dw     94.659890      0.080572        -17.912502
# 2            CCV_cw     44.369677     -0.111066        -16.035561
# 3         LSTM_pred    101.185879      0.104697        -14.985792
# 4          GRU_pred    -42.934878     -0.459091        -19.751401
# 5     LSTM_GRU_pred    -40.477994     -0.455713        -19.251957
# 6       BiLSTM_pred     32.510781     -0.154299        -16.320926
# 7   BiLSTM_GRU_pred     24.453357     -0.198593        -18.236509
# 8         QRNN_pred     33.755004     -0.169575        -16.999813
# 9          ESN_pred     39.016922     -0.147290        -16.035561
# 10         BNN_pred    147.884625      0.268498        -15.618727
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.966555      0.085903        -16.035561
# 1            CCV_dw     92.184755      0.071748        -18.718334
# 2            CCV_cw    112.749823      0.146071        -15.916361
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred      2.152763     -0.270942        -18.599504
# 5     LSTM_GRU_pred     13.527932     -0.225214        -17.770831
# 6       BiLSTM_pred     63.922422     -0.030606        -16.320926
# 7   BiLSTM_GRU_pred     56.732566     -0.061837        -17.049531
# 8         QRNN_pred     92.011440      0.070030        -16.035561
# 9          ESN_pred     66.264570     -0.032251        -16.035561
# 10         BNN_pred    147.884625      0.268498        -15.618727
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.157244     -0.381771        -17.217787
# 1            CCV_dw     75.626643      0.009833        -17.243913
# 2            CCV_cw     11.289362     -0.243454        -17.023536
# 3         LSTM_pred     42.188755     -0.116361        -16.163149
# 4          GRU_pred     78.208335      0.020937        -14.985792
# 5     LSTM_GRU_pred     62.958019     -0.035589        -15.965790
# 6       BiLSTM_pred     39.852578     -0.125392        -17.234371
# 7   BiLSTM_GRU_pred     -5.851085     -0.355186        -17.198380
# 8         QRNN_pred     25.345487     -0.222973        -15.121525
# 9          ESN_pred    118.386966      0.165455        -15.916361
# 10         BNN_pred     44.740180     -0.106262        -16.719255
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     99.061700      0.096268        -15.916361
# 1            CCV_dw    107.506067      0.127275        -15.916361
# 2            CCV_cw     54.305509     -0.070277        -16.035561
# 3         LSTM_pred    101.185879      0.104697        -14.985792
# 4          GRU_pred     97.107262      0.090393        -15.916361
# 5     LSTM_GRU_pred     71.681805     -0.002381        -16.035561
# 6       BiLSTM_pred     62.240186     -0.037615        -16.035561
# 7   BiLSTM_GRU_pred     44.083266     -0.108126        -17.234371
# 8         QRNN_pred      4.899125     -0.286978        -16.999813
# 9          ESN_pred    115.768295      0.156283        -15.916361
# 10         BNN_pred    115.768295      0.156283        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    115.768295      0.156283        -15.916361
# 1            CCV_dw    115.768295      0.156283        -15.916361
# 2            CCV_cw    117.032481      0.160912        -15.916361
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred    100.362599      0.101982        -15.916361
# 5     LSTM_GRU_pred    100.362599      0.101982        -15.916361
# 6       BiLSTM_pred    107.506067      0.127275        -15.916361
# 7   BiLSTM_GRU_pred    100.362599      0.101982        -15.916361
# 8         QRNN_pred     77.865123      0.017594        -16.035561
# 9          ESN_pred    115.768295      0.156283        -15.916361
# 10         BNN_pred    115.768295      0.156283        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    116.948043      0.162487        -13.039502
# 1            CCV_dw     88.405993      0.055322        -16.513347
# 2            CCV_cw     90.056983      0.062559        -16.035561
# 3         LSTM_pred     32.532312     -0.171809        -15.784374
# 4          GRU_pred     41.721699     -0.128173        -15.297751
# 5     LSTM_GRU_pred     86.531740      0.050440        -16.098501
# 6       BiLSTM_pred    152.699952      0.292835        -15.257258
# 7   BiLSTM_GRU_pred     25.706550     -0.191006        -17.331449
# 8         QRNN_pred     98.999810      0.095599        -14.109395
# 9          ESN_pred     48.064063     -0.092718        -15.423058
# 10         BNN_pred    124.587010      0.193007        -13.520172
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     61.880856     -0.055926        -16.461837
# 1            CCV_dw    -11.862721     -0.375596        -17.815093
# 2            CCV_cw     14.858098     -0.246386        -15.942451
# 3         LSTM_pred     57.300184     -0.068722        -17.388073
# 4          GRU_pred    138.557092      0.284078        -12.941076
# 5     LSTM_GRU_pred     76.979250     -0.003485        -15.297751
# 6       BiLSTM_pred    147.560443      0.285415        -14.740267
# 7   BiLSTM_GRU_pred    128.468013      0.228614        -10.476139
# 8         QRNN_pred     17.789463     -0.250541        -16.670417
# 9          ESN_pred     11.408513     -0.247517        -14.906255
# 10         BNN_pred    132.828262      0.232201        -12.525578
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.616417     -0.194015         -5.529777
# 1            CCV_dw     77.751609     -0.016509         -9.221506
# 2            CCV_cw    -32.604469     -0.607051        -14.683943
# 3         LSTM_pred    -74.125933     -0.779834        -17.648499
# 4          GRU_pred     58.367872     -0.158131        -11.130726
# 5     LSTM_GRU_pred     11.744317     -0.439742        -12.061010
# 6       BiLSTM_pred    -49.181534     -0.759964        -14.725076
# 7   BiLSTM_GRU_pred     -2.883391     -0.676844         -9.438680
# 8         QRNN_pred     23.956579     -0.480654         -6.727219
# 9          ESN_pred     78.448773     -0.003121        -12.243861
# 10         BNN_pred    149.944150      0.363182        -11.476311
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    115.112414      0.180092         -6.555827
# 1            CCV_dw     -7.019629     -0.395557        -14.987638
# 2            CCV_cw     11.767113     -0.324856        -14.192599
# 3         LSTM_pred    -73.616183     -0.773478        -18.509811
# 4          GRU_pred    118.944164      0.189418        -11.784109
# 5     LSTM_GRU_pred     43.479635     -0.193673        -14.464138
# 6       BiLSTM_pred     80.871705      0.013458        -14.152543
# 7   BiLSTM_GRU_pred    -12.953146     -0.528266        -11.463370
# 8         QRNN_pred     50.717148     -0.171109         -8.577481
# 9          ESN_pred     52.590074     -0.095601        -12.442334
# 10         BNN_pred     90.434359      0.056105        -13.602754
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    133.609673      0.239178        -10.792980
# 1            CCV_dw     55.686737     -0.088628        -16.767357
# 2            CCV_cw     49.537282     -0.110740        -15.056377
# 3         LSTM_pred     -5.161050     -0.371847        -17.326801
# 4          GRU_pred     43.616782     -0.196855        -13.887028
# 5     LSTM_GRU_pred    -44.983205     -0.618079        -17.032197
# 6       BiLSTM_pred    135.993341      0.247021        -14.918551
# 7   BiLSTM_GRU_pred    -17.965699     -0.493684        -10.476139
# 8         QRNN_pred     43.249453     -0.193210         -8.707776
# 9          ESN_pred     44.640033     -0.121745        -12.980635
# 10         BNN_pred    104.313049      0.116867        -13.454476
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.616417     -0.194015         -5.529777
# 1            CCV_dw    102.939448      0.112358        -10.988177
# 2            CCV_cw     15.953172     -0.301244        -14.683943
# 3         LSTM_pred    -80.035173     -0.727230        -17.135990
# 4          GRU_pred    -58.988644     -0.732430        -12.260597
# 5     LSTM_GRU_pred     -2.031685     -0.407634        -10.895738
# 6       BiLSTM_pred    -15.622144     -0.457505        -15.063855
# 7   BiLSTM_GRU_pred    102.946976      0.116393         -8.236270
# 8         QRNN_pred     23.956579     -0.480654         -6.727219
# 9          ESN_pred     71.227886     -0.036201        -13.333723
# 10         BNN_pred     49.365947     -0.139465        -14.449662
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    165.564368      0.426162         -6.013492
# 1            CCV_dw     21.274301     -0.231935        -16.053259
# 2            CCV_cw     31.797087     -0.203005        -14.192599
# 3         LSTM_pred    -61.873105     -0.628955        -16.240202
# 4          GRU_pred     -2.265551     -0.333367        -12.771075
# 5     LSTM_GRU_pred      0.128300     -0.352403        -15.954474
# 6       BiLSTM_pred     49.009260     -0.109231        -15.937404
# 7   BiLSTM_GRU_pred    -14.924839     -0.399747        -16.708196
# 8         QRNN_pred     64.121393     -0.094037         -7.411183
# 9          ESN_pred     84.443541      0.037647        -13.333723
# 10         BNN_pred     58.052447     -0.076300        -14.406361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    192.988036      0.457383         -6.880188
# 1            CCV_dw     54.657229     -0.079039        -16.855516
# 2            CCV_cw     70.791778     -0.014628        -16.035561
# 3         LSTM_pred     25.296270     -0.206315        -15.024244
# 4          GRU_pred    -78.279887     -0.646924        -17.312039
# 5     LSTM_GRU_pred    -11.249064     -0.337989        -17.429561
# 6       BiLSTM_pred    104.282950      0.115816        -15.257258
# 7   BiLSTM_GRU_pred    -29.353641     -0.438532        -17.331449
# 8         QRNN_pred    132.303285      0.247135         -6.101003
# 9          ESN_pred     48.284949     -0.098100        -15.254706
# 10         BNN_pred     98.182840      0.091916        -13.584936
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.616417     -0.194015         -5.529777
# 1            CCV_dw    -18.329094     -0.378632        -16.914561
# 2            CCV_cw     17.824736     -0.283913        -14.683943
# 3         LSTM_pred     46.336443     -0.103768        -15.829496
# 4          GRU_pred    105.222269      0.119229        -13.446381
# 5     LSTM_GRU_pred     28.543056     -0.188662        -14.385866
# 6       BiLSTM_pred     21.829808     -0.199961        -16.541092
# 7   BiLSTM_GRU_pred     42.897633     -0.171468        -11.621088
# 8         QRNN_pred     23.956579     -0.480654         -6.727219
# 9          ESN_pred     54.559475     -0.103455        -16.297314
# 10         BNN_pred     16.301820     -0.222063        -17.666524
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    165.564368      0.426162         -6.013492
# 1            CCV_dw     51.714400     -0.078256        -18.095539
# 2            CCV_cw     33.697839     -0.188899        -14.192599
# 3         LSTM_pred     51.397822     -0.080809        -16.163149
# 4          GRU_pred    101.892726      0.107309        -13.865808
# 5     LSTM_GRU_pred    107.408351      0.127000        -15.833951
# 6       BiLSTM_pred     81.582263      0.033256        -16.035561
# 7   BiLSTM_GRU_pred     49.698303     -0.096583        -15.173647
# 8         QRNN_pred     64.121393     -0.094037         -7.411183
# 9          ESN_pred    122.032311      0.178213        -15.916361
# 10         BNN_pred     52.295364     -0.074908        -16.935304
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    121.198866      0.178853        -13.300597
# 1            CCV_dw    103.781060      0.114111        -15.916361
# 2            CCV_cw     60.698900     -0.045906        -16.035561
# 3         LSTM_pred    115.264945      0.154645        -14.777338
# 4          GRU_pred    100.809747      0.103569        -15.916361
# 5     LSTM_GRU_pred    107.769967      0.128223        -15.916361
# 6       BiLSTM_pred     96.661619      0.088806        -15.916361
# 7   BiLSTM_GRU_pred     71.929007     -0.002887        -15.916361
# 8         QRNN_pred    138.695593      0.275621         -6.101003
# 9          ESN_pred    113.116629      0.146997        -15.916361
# 10         BNN_pred     89.910368      0.064268        -16.035561
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    105.918189      0.122287        -15.293051
# 1            CCV_dw     70.068019     -0.018725        -13.729750
# 2            CCV_cw     87.469437      0.052117        -15.942451
# 3         LSTM_pred    -50.877728     -0.544965        -18.213755
# 4          GRU_pred     41.721699     -0.128173        -15.297751
# 5     LSTM_GRU_pred     41.465624     -0.130030        -15.297751
# 6       BiLSTM_pred     48.627703     -0.104400        -13.802478
# 7   BiLSTM_GRU_pred     79.760638      0.015761        -14.852788
# 8         QRNN_pred     75.377355      0.001498        -16.384258
# 9          ESN_pred     63.685137     -0.035716        -13.937626
# 10         BNN_pred    147.786182      0.281922        -12.230585
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.947900     -0.093240        -13.635484
# 1            CCV_dw      0.904334     -0.330428        -16.398440
# 2            CCV_cw     52.909333     -0.097457        -13.330843
# 3         LSTM_pred      1.982600     -0.351336        -19.204242
# 4          GRU_pred    138.557092      0.284078        -12.941076
# 5     LSTM_GRU_pred    104.902512      0.122659        -11.740708
# 6       BiLSTM_pred    136.226997      0.245869        -13.966137
# 7   BiLSTM_GRU_pred    220.200206      0.644136        -10.606781
# 8         QRNN_pred     54.769164     -0.096431        -14.900864
# 9          ESN_pred    149.661407      0.288920        -13.145104
# 10         BNN_pred     81.735476      0.021336        -14.457660
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.166004     -0.498597         -7.772263
# 1            CCV_dw    125.275181      0.244987         -7.940829
# 2            CCV_cw     64.028731     -0.112172         -6.268185
# 3         LSTM_pred    -75.239613     -0.967629        -15.633142
# 4          GRU_pred      3.195130     -0.616774        -11.664602
# 5     LSTM_GRU_pred     10.794381     -0.527447         -8.385332
# 6       BiLSTM_pred    -71.662859     -0.984056        -16.074439
# 7   BiLSTM_GRU_pred     11.272028     -0.688555         -8.296263
# 8         QRNN_pred      4.338927     -0.671747         -7.682879
# 9          ESN_pred     20.242928     -0.311710        -11.874515
# 10         BNN_pred    141.278505      0.332116        -10.969061
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     94.421225      0.070836         -5.014099
# 1            CCV_dw    -41.399933     -0.609195        -15.077337
# 2            CCV_cw     72.790539     -0.047107         -6.818904
# 3         LSTM_pred    -99.835475     -1.026052        -20.636794
# 4          GRU_pred    118.944164      0.189418        -11.784109
# 5     LSTM_GRU_pred      5.223243     -0.469045        -10.872088
# 6       BiLSTM_pred     33.660805     -0.226299        -12.858238
# 7   BiLSTM_GRU_pred     30.273204     -0.320540        -11.057612
# 8         QRNN_pred     97.102456      0.087326         -5.807375
# 9          ESN_pred     95.185312      0.078036        -12.243861
# 10         BNN_pred    121.931459      0.203731        -12.948914
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    137.460253      0.300606         -4.648770
# 1            CCV_dw     31.129598     -0.217190        -13.414378
# 2            CCV_cw     30.410290     -0.241451        -12.341625
# 3         LSTM_pred    -39.957718     -0.584604        -18.721402
# 4          GRU_pred     43.616782     -0.196855        -13.887028
# 5     LSTM_GRU_pred     74.677015     -0.019075        -10.876036
# 6       BiLSTM_pred    134.012046      0.246494        -12.524644
# 7   BiLSTM_GRU_pred    188.067774      0.508514        -10.217894
# 8         QRNN_pred    103.314913      0.119967         -6.228119
# 9          ESN_pred     53.174859     -0.094793        -12.844962
# 10         BNN_pred     54.727587     -0.105626        -17.274833
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.166004     -0.498597         -7.772263
# 1            CCV_dw    147.432478      0.337406         -9.148459
# 2            CCV_cw     34.214201     -0.219875        -14.683943
# 3         LSTM_pred   -122.057902     -1.057505        -16.426293
# 4          GRU_pred   -105.917075     -1.087464        -16.561194
# 5     LSTM_GRU_pred    -52.164120     -0.773867        -12.108496
# 6       BiLSTM_pred   -109.235393     -1.063046        -16.681173
# 7   BiLSTM_GRU_pred      9.783043     -0.630614         -9.588682
# 8         QRNN_pred      4.338927     -0.671747         -7.682879
# 9          ESN_pred     20.242928     -0.311710        -11.874515
# 10         BNN_pred    116.527292      0.180725        -12.287449
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    102.249654      0.117694         -5.419056
# 1            CCV_dw    -13.864274     -0.413706        -15.467297
# 2            CCV_cw     51.350628     -0.121699        -14.192599
# 3         LSTM_pred   -153.383984     -1.155792        -19.275180
# 4          GRU_pred     -2.265551     -0.333367        -12.771075
# 5     LSTM_GRU_pred    -57.626386     -0.726330        -13.466628
# 6       BiLSTM_pred    -57.985210     -0.652451        -14.076464
# 7   BiLSTM_GRU_pred    -27.311698     -0.585514        -13.820752
# 8         QRNN_pred    108.936150      0.156578         -6.239249
# 9          ESN_pred     62.081304     -0.060087        -12.243861
# 10         BNN_pred    148.594300      0.305546        -10.039455
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.068932      0.370629         -6.215161
# 1            CCV_dw     37.726338     -0.160981        -13.518263
# 2            CCV_cw     64.231897     -0.056697        -14.985792
# 3         LSTM_pred    -58.652647     -0.604787        -17.695267
# 4          GRU_pred    -78.279887     -0.646924        -17.312039
# 5     LSTM_GRU_pred     -7.910392     -0.356846        -14.644569
# 6       BiLSTM_pred     23.651577     -0.221447        -13.802478
# 7   BiLSTM_GRU_pred     78.408867      0.005020        -14.852788
# 8         QRNN_pred    124.871596      0.219501         -7.772213
# 9          ESN_pred      6.321761     -0.279876        -16.352942
# 10         BNN_pred    110.191061      0.140415        -12.371453
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.166004     -0.498597         -7.772263
# 1            CCV_dw    -11.339083     -0.351184        -16.914561
# 2            CCV_cw     24.910237     -0.257990        -14.683943
# 3         LSTM_pred     86.501656      0.046765        -11.192294
# 4          GRU_pred     73.827188      0.002353        -16.668866
# 5     LSTM_GRU_pred      0.141035     -0.312846        -15.550806
# 6       BiLSTM_pred     12.927008     -0.238048        -18.051486
# 7   BiLSTM_GRU_pred     50.965639     -0.151302         -9.427971
# 8         QRNN_pred      4.338927     -0.671747         -7.682879
# 9          ESN_pred     20.242928     -0.311710        -11.874515
# 10         BNN_pred     25.349159     -0.187267        -17.924030
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    102.249654      0.117694         -5.419056
# 1            CCV_dw     18.888365     -0.207387        -18.095539
# 2            CCV_cw     20.670608     -0.257223        -14.192599
# 3         LSTM_pred     42.188755     -0.116361        -16.163149
# 4          GRU_pred    101.892726      0.107309        -13.865808
# 5     LSTM_GRU_pred     34.304289     -0.149553        -14.985792
# 6       BiLSTM_pred     43.432992     -0.112710        -16.035561
# 7   BiLSTM_GRU_pred     49.698303     -0.096583        -15.173647
# 8         QRNN_pred    108.936150      0.156578         -6.239249
# 9          ESN_pred    106.923950      0.125420        -15.916361
# 10         BNN_pred     37.644211     -0.133618        -17.506638
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    142.141154      0.293626         -6.880302
# 1            CCV_dw     78.200937      0.021620        -16.035561
# 2            CCV_cw     44.856339     -0.138136        -14.985792
# 3         LSTM_pred    134.020040      0.220225        -14.777338
# 4          GRU_pred    100.809747      0.103569        -15.916361
# 5     LSTM_GRU_pred     95.092872      0.083118        -15.916361
# 6       BiLSTM_pred     68.428772     -0.014863        -16.035561
# 7   BiLSTM_GRU_pred     71.929007     -0.002887        -15.916361
# 8         QRNN_pred    124.871596      0.219501         -7.772213
# 9          ESN_pred    118.595317      0.166183        -15.916361
# 10         BNN_pred     83.522131      0.041071        -16.035561
# 11               __    115.768295      0.156283        -15.916361

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     53.432617     -0.070375        -16.523421
# 1            CCV_dw     68.852940     -0.014904        -18.718334
# 2            CCV_cw    150.236098      0.276855        -15.774136
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred     42.914187     -0.111103        -17.181310
# 5     LSTM_GRU_pred    115.768295      0.156283        -15.916361
# 6       BiLSTM_pred    115.833164      0.156557        -16.254849
# 7   BiLSTM_GRU_pred     79.635498      0.027053        -16.035561
# 8         QRNN_pred    138.613732      0.236401        -15.774136
# 9          ESN_pred    122.714769      0.180982        -15.801162
# 10         BNN_pred    183.602360      0.390055        -14.730270
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.014395      0.018279        -16.035561
# 1            CCV_dw    130.089995      0.210979        -14.228108
# 2            CCV_cw     38.976711     -0.133900        -15.892503
# 3         LSTM_pred      9.006058     -0.266349        -16.540704
# 4          GRU_pred     65.837421     -0.026699        -16.098501
# 5     LSTM_GRU_pred     39.681876     -0.124308        -17.307139
# 6       BiLSTM_pred     93.349778      0.075026        -14.059806
# 7   BiLSTM_GRU_pred     55.676792     -0.076166        -13.843102
# 8         QRNN_pred    182.789736      0.396167        -15.787673
# 9          ESN_pred    175.694927      0.389651        -11.238066
# 10         BNN_pred    206.754297      0.480882        -11.615906
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     13.809170     -0.268825        -17.045471
# 1            CCV_dw     84.180878      0.038082        -14.238732
# 2            CCV_cw    123.106527      0.193062        -13.584098
# 3         LSTM_pred    -93.236203     -0.767881        -17.963664
# 4          GRU_pred    -30.689164     -0.442577        -14.864757
# 5     LSTM_GRU_pred    111.245236      0.142716        -15.964277
# 6       BiLSTM_pred    -74.532313     -0.657786        -16.132538
# 7   BiLSTM_GRU_pred    134.115476      0.241583         -6.902884
# 8         QRNN_pred     12.667779     -0.276068        -18.110606
# 9          ESN_pred    169.141586      0.443495         -4.941485
# 10         BNN_pred    132.174992      0.222342        -11.601620
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     69.076103     -0.019099        -15.971820
# 1            CCV_dw     92.263684      0.070095        -14.876833
# 2            CCV_cw     77.394817      0.008094        -14.980720
# 3         LSTM_pred    -19.603042     -0.394053        -17.836158
# 4          GRU_pred     -8.420602     -0.323333        -16.771894
# 5     LSTM_GRU_pred     75.860183      0.011236        -15.151999
# 6       BiLSTM_pred    -12.453210     -0.353484        -14.535799
# 7   BiLSTM_GRU_pred     86.228439      0.044093        -10.202703
# 8         QRNN_pred     84.788261      0.039063        -16.035561
# 9          ESN_pred    253.616347      0.727668         -6.522736
# 10         BNN_pred    154.998067      0.302513        -11.554823
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.528766     -0.056042        -16.035561
# 1            CCV_dw     79.812578      0.022888        -14.428892
# 2            CCV_cw     78.544698      0.018051        -15.892503
# 3         LSTM_pred      9.006058     -0.266349        -16.540704
# 4          GRU_pred     53.012929     -0.075649        -16.098501
# 5     LSTM_GRU_pred     39.681876     -0.124308        -17.307139
# 6       BiLSTM_pred     77.099117      0.013515        -14.059806
# 7   BiLSTM_GRU_pred     52.142671     -0.090513        -13.843102
# 8         QRNN_pred    146.570883      0.271031        -16.035561
# 9          ESN_pred    201.936218      0.491591        -11.238066
# 10         BNN_pred    201.492660      0.463493        -11.615906
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -3.911574     -0.337561        -17.045471
# 1            CCV_dw     80.247523      0.026133        -18.554989
# 2            CCV_cw     62.795930     -0.043773        -16.035561
# 3         LSTM_pred     45.705902     -0.102804        -16.163149
# 4          GRU_pred    -52.866495     -0.521409        -18.229915
# 5     LSTM_GRU_pred    108.622107      0.131556        -16.221339
# 6       BiLSTM_pred     47.357683     -0.096134        -15.937404
# 7   BiLSTM_GRU_pred     53.390767     -0.075520        -14.624280
# 8         QRNN_pred     10.490611     -0.276807        -18.110606
# 9          ESN_pred    217.525177      0.595277         -6.698827
# 10         BNN_pred    115.898293      0.157803        -14.997271
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     68.406043     -0.016596        -15.983096
# 1            CCV_dw     72.459633     -0.002308        -19.128046
# 2            CCV_cw     51.330001     -0.086101        -16.935304
# 3         LSTM_pred    126.130683      0.192603        -15.916361
# 4          GRU_pred    -32.308777     -0.415734        -18.508303
# 5     LSTM_GRU_pred    122.180095      0.179298        -15.349239
# 6       BiLSTM_pred     58.894759     -0.050427        -16.320926
# 7   BiLSTM_GRU_pred     72.850454      0.002170        -16.035561
# 8         QRNN_pred     71.490303     -0.012013        -16.035561
# 9          ESN_pred    277.040202      0.721515        -12.281808
# 10         BNN_pred    173.235330      0.355560        -14.730270
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     49.809541     -0.084022        -16.523421
# 1            CCV_dw     60.234281     -0.047461        -18.718334
# 2            CCV_cw    129.635036      0.205931        -15.911578
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred     28.514407     -0.166740        -17.181310
# 5     LSTM_GRU_pred    115.768295      0.156283        -15.916361
# 6       BiLSTM_pred    107.570456      0.127511        -16.254849
# 7   BiLSTM_GRU_pred     79.635498      0.027053        -16.035561
# 8         QRNN_pred    109.987883      0.136314        -16.035561
# 9          ESN_pred    163.034549      0.322253        -15.801162
# 10         BNN_pred    183.602360      0.390055        -14.730270
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      9.642204     -0.264398        -16.035561
# 1            CCV_dw     86.711715      0.053114        -15.927305
# 2            CCV_cw     61.264796     -0.044419        -16.035561
# 3         LSTM_pred     45.705902     -0.102804        -16.163149
# 4          GRU_pred     65.779330     -0.024782        -15.965790
# 5     LSTM_GRU_pred    108.622107      0.131556        -16.221339
# 6       BiLSTM_pred     37.086989     -0.134201        -16.035561
# 7   BiLSTM_GRU_pred    108.208524      0.129958        -14.275624
# 8         QRNN_pred      9.766621     -0.272636        -18.110606
# 9          ESN_pred    172.058177      0.390896         -6.868056
# 10         BNN_pred     73.400181      0.003916        -16.035561
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    106.506458      0.123762        -15.916361
# 1            CCV_dw    101.014698      0.104300        -16.010201
# 2            CCV_cw     46.030345     -0.101109        -16.935304
# 3         LSTM_pred    126.130683      0.192603        -15.916361
# 4          GRU_pred    108.513301      0.130850        -15.916361
# 5     LSTM_GRU_pred    122.180095      0.179298        -15.349239
# 6       BiLSTM_pred     62.240186     -0.037615        -16.035561
# 7   BiLSTM_GRU_pred    110.770060      0.138760        -15.916361
# 8         QRNN_pred     50.165618     -0.094493        -16.035561
# 9          ESN_pred    181.865886      0.388856        -12.806757
# 10         BNN_pred    108.140374      0.129516        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    115.768295      0.156283        -15.916361
# 1            CCV_dw    109.228499      0.133342        -16.010201
# 2            CCV_cw    110.314378      0.137167        -15.916361
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred    100.362599      0.101982        -15.916361
# 5     LSTM_GRU_pred    115.768295      0.156283        -15.916361
# 6       BiLSTM_pred    107.506067      0.127275        -15.916361
# 7   BiLSTM_GRU_pred    115.768295      0.156283        -15.916361
# 8         QRNN_pred     89.910368      0.064268        -16.035561
# 9          ESN_pred    115.768295      0.156283        -15.916361
# 10         BNN_pred    115.768295      0.156283        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     83.660147      0.041773        -16.035561
# 1            CCV_dw     84.739965      0.043009        -15.949599
# 2            CCV_cw    151.093045      0.281226        -15.153252
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred     53.104744     -0.071968        -17.181310
# 5     LSTM_GRU_pred    115.768295      0.156283        -15.916361
# 6       BiLSTM_pred     77.859661      0.020725        -16.320926
# 7   BiLSTM_GRU_pred    118.404833      0.165819        -15.711040
# 8         QRNN_pred    158.832704      0.307192        -16.035561
# 9          ESN_pred    219.550939      0.514359        -14.445255
# 10         BNN_pred    155.955867      0.296396        -15.646672
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    171.107867      0.356807        -16.035561
# 1            CCV_dw     69.934565     -0.014920        -17.072113
# 2            CCV_cw    118.906507      0.170109        -15.671040
# 3         LSTM_pred     71.985601     -0.010465        -14.010447
# 4          GRU_pred     79.921435      0.025370        -16.098501
# 5     LSTM_GRU_pred    116.885106      0.161540        -11.860218
# 6       BiLSTM_pred    156.190132      0.306335        -13.593010
# 7   BiLSTM_GRU_pred    102.495066      0.109013        -12.616309
# 8         QRNN_pred    139.983787      0.247520        -16.387586
# 9          ESN_pred    122.620054      0.186538        -15.449796
# 10         BNN_pred    155.412863      0.299224        -14.997271
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     14.965179     -0.268935        -18.296292
# 1            CCV_dw     56.000923     -0.073659        -16.792754
# 2            CCV_cw    144.255835      0.285779        -14.600918
# 3         LSTM_pred    -25.987669     -0.448768        -16.192625
# 4          GRU_pred     32.936725     -0.179365        -13.810384
# 5     LSTM_GRU_pred    220.978619      0.573218         -7.968030
# 6       BiLSTM_pred      6.781062     -0.302039        -14.969540
# 7   BiLSTM_GRU_pred    187.559202      0.447248         -5.973688
# 8         QRNN_pred     42.942832     -0.154921        -15.121525
# 9          ESN_pred    112.677503      0.163947         -6.079400
# 10         BNN_pred    166.234960      0.343688        -14.997271
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    128.694415      0.209911        -16.929177
# 1            CCV_dw     50.654764     -0.090583        -17.493754
# 2            CCV_cw     97.544551      0.089482        -13.584098
# 3         LSTM_pred     31.674843     -0.180956        -15.092744
# 4          GRU_pred    -21.457344     -0.382305        -17.295984
# 5     LSTM_GRU_pred    113.430699      0.149067        -11.860218
# 6       BiLSTM_pred     79.489656      0.018099        -13.802478
# 7   BiLSTM_GRU_pred    165.600348      0.349717         -7.001515
# 8         QRNN_pred     42.154060     -0.138653        -16.999813
# 9          ESN_pred    177.696998      0.431034         -5.738954
# 10         BNN_pred    151.132978      0.284241        -14.997271
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    152.626780      0.292024        -16.035561
# 1            CCV_dw     46.453860     -0.106842        -17.134336
# 2            CCV_cw    174.176393      0.374145        -14.059806
# 3         LSTM_pred     71.985601     -0.010465        -14.010447
# 4          GRU_pred     40.704724     -0.125964        -16.108842
# 5     LSTM_GRU_pred    116.885106      0.161540        -11.860218
# 6       BiLSTM_pred    132.006634      0.218948        -13.723693
# 7   BiLSTM_GRU_pred     84.420090      0.039810        -12.329218
# 8         QRNN_pred     58.965626     -0.062080        -17.984870
# 9          ESN_pred    178.506838      0.396030        -13.497995
# 10         BNN_pred    155.412863      0.299224        -14.997271
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -24.075030     -0.433990        -17.310984
# 1            CCV_dw     86.878700      0.050053        -16.388064
# 2            CCV_cw     94.630185      0.078612        -15.138394
# 3         LSTM_pred     42.188755     -0.116361        -16.163149
# 4          GRU_pred    -33.877931     -0.451550        -18.192670
# 5     LSTM_GRU_pred     99.416015      0.098116        -16.134122
# 6       BiLSTM_pred     35.618529     -0.148053        -16.324547
# 7   BiLSTM_GRU_pred    145.354928      0.267034        -12.546360
# 8         QRNN_pred     34.537419     -0.187776        -15.121525
# 9          ESN_pred    157.487018      0.375415         -6.079400
# 10         BNN_pred    119.847923      0.171907        -15.783026
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     87.097791      0.050026        -15.919901
# 1            CCV_dw     85.139503      0.044352        -16.505837
# 2            CCV_cw     94.107341      0.077450        -13.762727
# 3         LSTM_pred    101.185879      0.104697        -14.985792
# 4          GRU_pred    -42.934878     -0.459091        -19.751401
# 5     LSTM_GRU_pred    115.768295      0.156283        -15.916361
# 6       BiLSTM_pred     32.510781     -0.154299        -16.320926
# 7   BiLSTM_GRU_pred    151.125446      0.281723        -13.315532
# 8         QRNN_pred     33.755004     -0.169575        -16.999813
# 9          ESN_pred    333.971839      0.969505         -5.768959
# 10         BNN_pred    158.104030      0.303741        -15.646672
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.966555      0.085903        -16.035561
# 1            CCV_dw     80.800717      0.028125        -16.007731
# 2            CCV_cw    149.891864      0.278670        -14.248657
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred      2.152763     -0.270942        -18.599504
# 5     LSTM_GRU_pred    115.768295      0.156283        -15.916361
# 6       BiLSTM_pred     63.922422     -0.030606        -16.320926
# 7   BiLSTM_GRU_pred    118.404833      0.165819        -15.711040
# 8         QRNN_pred     92.011440      0.070030        -16.035561
# 9          ESN_pred    218.995168      0.514794        -14.478039
# 10         BNN_pred    155.955867      0.296396        -15.646672
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.157244     -0.381771        -17.217787
# 1            CCV_dw     98.271698      0.094545        -15.927305
# 2            CCV_cw     26.356068     -0.181622        -17.023536
# 3         LSTM_pred     42.188755     -0.116361        -16.163149
# 4          GRU_pred     78.208335      0.020937        -14.985792
# 5     LSTM_GRU_pred     99.416015      0.098116        -16.134122
# 6       BiLSTM_pred     39.852578     -0.125392        -17.234371
# 7   BiLSTM_GRU_pred    115.109523      0.154963        -12.799193
# 8         QRNN_pred     25.345487     -0.222973        -15.121525
# 9          ESN_pred     82.361039      0.015609         -7.279523
# 10         BNN_pred     82.459224      0.037141        -16.035561
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     99.061700      0.096268        -15.916361
# 1            CCV_dw    109.228499      0.133342        -16.010201
# 2            CCV_cw     56.798421     -0.060779        -16.035561
# 3         LSTM_pred    101.185879      0.104697        -14.985792
# 4          GRU_pred     97.107262      0.090393        -15.916361
# 5     LSTM_GRU_pred    115.768295      0.156283        -15.916361
# 6       BiLSTM_pred     62.240186     -0.037615        -16.035561
# 7   BiLSTM_GRU_pred    135.150708      0.223915        -13.784537
# 8         QRNN_pred      4.899125     -0.286978        -16.999813
# 9          ESN_pred    230.427066      0.579280         -6.887506
# 10         BNN_pred    115.768295      0.156283        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    115.768295      0.156283        -15.916361
# 1            CCV_dw    109.228499      0.133342        -16.010201
# 2            CCV_cw    117.032481      0.160912        -15.916361
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred    100.362599      0.101982        -15.916361
# 5     LSTM_GRU_pred    115.768295      0.156283        -15.916361
# 6       BiLSTM_pred    107.506067      0.127275        -15.916361
# 7   BiLSTM_GRU_pred    115.768295      0.156283        -15.916361
# 8         QRNN_pred     77.865123      0.017594        -16.035561
# 9          ESN_pred    123.713150      0.184262        -15.916361
# 10         BNN_pred    115.768295      0.156283        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    116.948043      0.162487        -13.039502
# 1            CCV_dw     49.112007     -0.096710        -16.744242
# 2            CCV_cw     49.077917     -0.093236        -16.507129
# 3         LSTM_pred     32.532312     -0.171809        -15.784374
# 4          GRU_pred     41.721699     -0.128173        -15.297751
# 5     LSTM_GRU_pred    165.667072      0.341552        -10.417703
# 6       BiLSTM_pred    152.699952      0.292835        -15.257258
# 7   BiLSTM_GRU_pred    172.306769      0.354065        -14.888038
# 8         QRNN_pred     98.999810      0.095599        -14.109395
# 9          ESN_pred     87.090930      0.051243        -16.035561
# 10         BNN_pred    146.748557      0.274482        -14.378881
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     61.880856     -0.055926        -16.461837
# 1            CCV_dw    142.991107      0.268923        -13.925691
# 2            CCV_cw    159.183685      0.321274        -14.631084
# 3         LSTM_pred     57.300184     -0.068722        -17.388073
# 4          GRU_pred    138.557092      0.284078        -12.941076
# 5     LSTM_GRU_pred    123.963645      0.194581        -11.767154
# 6       BiLSTM_pred    147.560443      0.285415        -14.740267
# 7   BiLSTM_GRU_pred    164.666428      0.342758         -7.900727
# 8         QRNN_pred     17.789463     -0.250541        -16.670417
# 9          ESN_pred     12.294206     -0.291552        -16.060089
# 10         BNN_pred     39.083604     -0.155168        -14.332944
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.616417     -0.194015         -5.529777
# 1            CCV_dw    -81.185537     -0.938161        -17.077804
# 2            CCV_cw     25.343838     -0.260188        -14.491958
# 3         LSTM_pred    -74.125933     -0.779834        -17.648499
# 4          GRU_pred     58.367872     -0.158131        -11.130726
# 5     LSTM_GRU_pred    183.976841      0.506441         -4.898333
# 6       BiLSTM_pred    -49.181534     -0.759964        -14.725076
# 7   BiLSTM_GRU_pred    149.260660      0.326476         -6.792384
# 8         QRNN_pred     23.956579     -0.480654         -6.727219
# 9          ESN_pred     -2.002610     -0.599090         -6.467554
# 10         BNN_pred     43.038190     -0.235051         -8.195174
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    115.112414      0.180092         -6.555827
# 1            CCV_dw     11.671941     -0.301567        -12.953185
# 2            CCV_cw     92.161350      0.064122        -13.616759
# 3         LSTM_pred    -73.616183     -0.773478        -18.509811
# 4          GRU_pred    118.944164      0.189418        -11.784109
# 5     LSTM_GRU_pred    164.523846      0.369221         -8.386916
# 6       BiLSTM_pred     80.871705      0.013458        -14.152543
# 7   BiLSTM_GRU_pred    136.449029      0.245111         -7.110916
# 8         QRNN_pred     50.717148     -0.171109         -8.577481
# 9          ESN_pred     81.444702     -0.005554         -4.447194
# 10         BNN_pred    101.079078      0.103450        -13.253586
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    133.609673      0.239178        -10.792980
# 1            CCV_dw     65.152619     -0.046731        -15.464510
# 2            CCV_cw    138.696764      0.250421        -14.632100
# 3         LSTM_pred     -5.161050     -0.371847        -17.326801
# 4          GRU_pred     43.616782     -0.196855        -13.887028
# 5     LSTM_GRU_pred    117.107563      0.169423         -9.478808
# 6       BiLSTM_pred    135.993341      0.247021        -14.918551
# 7   BiLSTM_GRU_pred    202.585876      0.483907         -7.199889
# 8         QRNN_pred     43.249453     -0.193210         -8.707776
# 9          ESN_pred    -39.048792     -0.637510        -16.060089
# 10         BNN_pred     18.888953     -0.247878        -14.332944
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.616417     -0.194015         -5.529777
# 1            CCV_dw    -21.045403     -0.452270        -20.044793
# 2            CCV_cw     -7.213574     -0.413936        -15.287137
# 3         LSTM_pred    -80.035173     -0.727230        -17.135990
# 4          GRU_pred    -58.988644     -0.732430        -12.260597
# 5     LSTM_GRU_pred    111.375396      0.148336         -6.234346
# 6       BiLSTM_pred    -15.622144     -0.457505        -15.063855
# 7   BiLSTM_GRU_pred     11.011398     -0.277346        -14.713683
# 8         QRNN_pred     23.956579     -0.480654         -6.727219
# 9          ESN_pred     27.049263     -0.338512         -7.067256
# 10         BNN_pred    112.849619      0.163391        -11.267991
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    165.564368      0.426162         -6.013492
# 1            CCV_dw     11.571330     -0.257160        -16.878823
# 2            CCV_cw     45.160438     -0.143692        -14.192599
# 3         LSTM_pred    -61.873105     -0.628955        -16.240202
# 4          GRU_pred     -2.265551     -0.333367        -12.771075
# 5     LSTM_GRU_pred    171.271626      0.366892         -9.581921
# 6       BiLSTM_pred     49.009260     -0.109231        -15.937404
# 7   BiLSTM_GRU_pred     77.544753      0.012780        -13.430526
# 8         QRNN_pred     64.121393     -0.094037         -7.411183
# 9          ESN_pred     67.019251     -0.076274         -6.403255
# 10         BNN_pred    148.246014      0.291636        -13.444607
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    192.988036      0.457383         -6.880188
# 1            CCV_dw     30.422715     -0.171915        -17.158238
# 2            CCV_cw     71.381720     -0.012292        -16.035561
# 3         LSTM_pred     25.296270     -0.206315        -15.024244
# 4          GRU_pred    -78.279887     -0.646924        -17.312039
# 5     LSTM_GRU_pred    149.363668      0.282921        -10.417703
# 6       BiLSTM_pred    104.282950      0.115816        -15.257258
# 7   BiLSTM_GRU_pred    151.268245      0.283073        -14.888038
# 8         QRNN_pred    132.303285      0.247135         -6.101003
# 9          ESN_pred     31.954284     -0.194535        -16.035561
# 10         BNN_pred     95.611057      0.082180        -14.378881
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.616417     -0.194015         -5.529777
# 1            CCV_dw     20.678239     -0.199946        -18.507123
# 2            CCV_cw     -5.932358     -0.397145        -15.287137
# 3         LSTM_pred     46.336443     -0.103768        -15.829496
# 4          GRU_pred    105.222269      0.119229        -13.446381
# 5     LSTM_GRU_pred     31.920899     -0.182312        -13.834389
# 6       BiLSTM_pred     21.829808     -0.199961        -16.541092
# 7   BiLSTM_GRU_pred     24.769052     -0.215428        -15.181513
# 8         QRNN_pred     23.956579     -0.480654         -6.727219
# 9          ESN_pred     27.049263     -0.338512         -7.067256
# 10         BNN_pred      7.115113     -0.304222        -17.158152
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    165.564368      0.426162         -6.013492
# 1            CCV_dw     94.577750      0.081367        -15.927305
# 2            CCV_cw     46.509244     -0.133152        -14.192599
# 3         LSTM_pred     51.397822     -0.080809        -16.163149
# 4          GRU_pred    101.892726      0.107309        -13.865808
# 5     LSTM_GRU_pred    108.181393      0.129870        -15.916361
# 6       BiLSTM_pred     81.582263      0.033256        -16.035561
# 7   BiLSTM_GRU_pred     95.378248      0.082782        -13.573383
# 8         QRNN_pred     64.121393     -0.094037         -7.411183
# 9          ESN_pred     67.019251     -0.076274         -6.403255
# 10         BNN_pred     69.173669     -0.011723        -16.035561
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    121.198866      0.178853        -13.300597
# 1            CCV_dw    101.014698      0.104300        -16.010201
# 2            CCV_cw     60.698900     -0.045906        -16.035561
# 3         LSTM_pred    115.264945      0.154645        -14.777338
# 4          GRU_pred    100.809747      0.103569        -15.916361
# 5     LSTM_GRU_pred    112.064456      0.143307        -15.916361
# 6       BiLSTM_pred     96.661619      0.088806        -15.916361
# 7   BiLSTM_GRU_pred    115.768295      0.156283        -15.916361
# 8         QRNN_pred    138.695593      0.275621         -6.101003
# 9          ESN_pred     31.954284     -0.194535        -16.035561
# 10         BNN_pred     89.910368      0.064268        -16.035561
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    105.918189      0.122287        -15.293051
# 1            CCV_dw     13.503084     -0.251993        -16.239347
# 2            CCV_cw    133.531477      0.224887        -15.056377
# 3         LSTM_pred    -50.877728     -0.544965        -18.213755
# 4          GRU_pred     41.721699     -0.128173        -15.297751
# 5     LSTM_GRU_pred    130.440521      0.217919        -11.023794
# 6       BiLSTM_pred     48.627703     -0.104400        -13.802478
# 7   BiLSTM_GRU_pred    160.578829      0.314802        -14.229004
# 8         QRNN_pred     75.377355      0.001498        -16.384258
# 9          ESN_pred     25.708625     -0.204897        -15.779882
# 10         BNN_pred    131.517320      0.219897        -14.400137
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.947900     -0.093240        -13.635484
# 1            CCV_dw    177.963725      0.406614        -13.842592
# 2            CCV_cw     -1.175502     -0.323894        -16.227585
# 3         LSTM_pred      1.982600     -0.351336        -19.204242
# 4          GRU_pred    138.557092      0.284078        -12.941076
# 5     LSTM_GRU_pred     91.654050      0.064108        -11.793966
# 6       BiLSTM_pred    136.226997      0.245869        -13.966137
# 7   BiLSTM_GRU_pred     89.693685      0.057626        -11.068675
# 8         QRNN_pred     54.769164     -0.096431        -14.900864
# 9          ESN_pred    -44.368779     -0.576365        -17.421217
# 10         BNN_pred    -49.544537     -0.642582        -16.925308
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.166004     -0.498597         -7.772263
# 1            CCV_dw    -84.245927     -1.221862        -12.775161
# 2            CCV_cw    -22.374643     -0.607498        -12.475905
# 3         LSTM_pred    -75.239613     -0.967629        -15.633142
# 4          GRU_pred      3.195130     -0.616774        -11.664602
# 5     LSTM_GRU_pred    159.780472      0.412301         -4.033954
# 6       BiLSTM_pred    -71.662859     -0.984056        -16.074439
# 7   BiLSTM_GRU_pred    152.414222      0.354652         -5.256731
# 8         QRNN_pred      4.338927     -0.671747         -7.682879
# 9          ESN_pred    -42.603482     -0.971887         -6.243304
# 10         BNN_pred    -10.357345     -0.618877        -10.452279
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     94.421225      0.070836         -5.014099
# 1            CCV_dw     19.333959     -0.293621        -10.487299
# 2            CCV_cw     43.184191     -0.194439        -13.407667
# 3         LSTM_pred    -99.835475     -1.026052        -20.636794
# 4          GRU_pred    118.944164      0.189418        -11.784109
# 5     LSTM_GRU_pred    109.970649      0.143398         -7.902445
# 6       BiLSTM_pred     33.660805     -0.226299        -12.858238
# 7   BiLSTM_GRU_pred     82.982932      0.022491         -7.518604
# 8         QRNN_pred     97.102456      0.087326         -5.807375
# 9          ESN_pred     17.126395     -0.456533         -4.561864
# 10         BNN_pred     13.216949     -0.331073        -16.006390
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    137.460253      0.300606         -4.648770
# 1            CCV_dw     65.697941     -0.054625        -12.632269
# 2            CCV_cw    -38.507457     -0.581807        -15.907130
# 3         LSTM_pred    -39.957718     -0.584604        -18.721402
# 4          GRU_pred     43.616782     -0.196855        -13.887028
# 5     LSTM_GRU_pred     73.691456     -0.016232        -11.811906
# 6       BiLSTM_pred    134.012046      0.246494        -12.524644
# 7   BiLSTM_GRU_pred     46.271087     -0.127983        -10.569292
# 8         QRNN_pred    103.314913      0.119967         -6.228119
# 9          ESN_pred    -39.546087     -0.733078        -11.338049
# 10         BNN_pred     20.704370     -0.263403        -15.827601
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.166004     -0.498597         -7.772263
# 1            CCV_dw   -147.830912     -1.389978        -17.457889
# 2            CCV_cw     -9.522736     -0.443181        -15.184252
# 3         LSTM_pred   -122.057902     -1.057505        -16.426293
# 4          GRU_pred   -105.917075     -1.087464        -16.561194
# 5     LSTM_GRU_pred    174.964410      0.456256         -5.083801
# 6       BiLSTM_pred   -109.235393     -1.063046        -16.681173
# 7   BiLSTM_GRU_pred     66.805699     -0.042319        -11.999934
# 8         QRNN_pred      4.338927     -0.671747         -7.682879
# 9          ESN_pred      5.283984     -0.481811         -8.192499
# 10         BNN_pred     86.669192      0.029163         -9.998963
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    102.249654      0.117694         -5.419056
# 1            CCV_dw    -94.284537     -0.788746        -17.084286
# 2            CCV_cw     50.546352     -0.120801        -14.965809
# 3         LSTM_pred   -153.383984     -1.155792        -19.275180
# 4          GRU_pred     -2.265551     -0.333367        -12.771075
# 5     LSTM_GRU_pred     97.906297      0.090029        -10.691084
# 6       BiLSTM_pred    -57.985210     -0.652451        -14.076464
# 7   BiLSTM_GRU_pred     43.278832     -0.129164        -14.328225
# 8         QRNN_pred    108.936150      0.156578         -6.239249
# 9          ESN_pred     52.046092     -0.165397         -7.067256
# 10         BNN_pred     88.126285      0.047289        -13.713281
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.068932      0.370629         -6.215161
# 1            CCV_dw    -39.000936     -0.494903        -16.675845
# 2            CCV_cw     45.150037     -0.142224        -14.985792
# 3         LSTM_pred    -58.652647     -0.604787        -17.695267
# 4          GRU_pred    -78.279887     -0.646924        -17.312039
# 5     LSTM_GRU_pred     83.328419      0.030876        -12.034278
# 6       BiLSTM_pred     23.651577     -0.221447        -13.802478
# 7   BiLSTM_GRU_pred    134.035090      0.224883        -13.567449
# 8         QRNN_pred    124.871596      0.219501         -7.772213
# 9          ESN_pred     20.630028     -0.288783        -10.475320
# 10         BNN_pred     88.212575      0.051404        -13.946046
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     22.166004     -0.498597         -7.772263
# 1            CCV_dw     20.232525     -0.202707        -18.507123
# 2            CCV_cw    -19.303886     -0.480403        -15.184252
# 3         LSTM_pred     86.501656      0.046765        -11.192294
# 4          GRU_pred     73.827188      0.002353        -16.668866
# 5     LSTM_GRU_pred     68.249124     -0.036018        -13.374151
# 6       BiLSTM_pred     12.927008     -0.238048        -18.051486
# 7   BiLSTM_GRU_pred     46.104758     -0.127864        -13.266363
# 8         QRNN_pred      4.338927     -0.671747         -7.682879
# 9          ESN_pred      5.283984     -0.481811         -8.192499
# 10         BNN_pred     -2.032284     -0.352700        -16.617638
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    102.249654      0.117694         -5.419056
# 1            CCV_dw     76.577235      0.015446        -15.965790
# 2            CCV_cw     40.172009     -0.162682        -14.965809
# 3         LSTM_pred     42.188755     -0.116361        -16.163149
# 4          GRU_pred    101.892726      0.107309        -13.865808
# 5     LSTM_GRU_pred    111.698445      0.142936        -15.446480
# 6       BiLSTM_pred     43.432992     -0.112710        -16.035561
# 7   BiLSTM_GRU_pred     55.116034     -0.076184        -14.365011
# 8         QRNN_pred    108.936150      0.156578         -6.239249
# 9          ESN_pred     52.046092     -0.165397         -7.067256
# 10         BNN_pred     35.518689     -0.139378        -16.935304
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    142.141154      0.293626         -6.880302
# 1            CCV_dw     98.223348      0.094373        -15.927305
# 2            CCV_cw     34.828984     -0.183182        -14.985792
# 3         LSTM_pred    134.020040      0.220225        -14.777338
# 4          GRU_pred    100.809747      0.103569        -15.916361
# 5     LSTM_GRU_pred    116.375348      0.158750        -15.916361
# 6       BiLSTM_pred     68.428772     -0.014863        -16.035561
# 7   BiLSTM_GRU_pred    113.248512      0.147866        -13.668427
# 8         QRNN_pred    124.871596      0.219501         -7.772213
# 9          ESN_pred    -14.414078     -0.459210        -13.549217
# 10         BNN_pred     89.910368      0.064268        -16.035561
# 11               __    115.768295      0.156283        -15.916361

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_2y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_2y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_2y1', file, 'CCV')
get_final_results_1('2024_2y1', file, 'CCV')

get_final_results('2024_2y1', dw_file, 'CCV_dw')
get_final_results_1('2024_2y1', dw_file, 'CCV_dw')

get_final_results('2024_2y1', cw_file, 'CCV_cw')
get_final_results_1('2024_2y1', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:31: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:37: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# ...
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-4-b267510ae310>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-4-b267510ae310>:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    444.530623      1.315696         -5.923910
# 1            CCV_dw    437.508362      1.325888         -5.888156
# 2            CCV_cw    482.104752      1.439347         -6.019980
# 3         LSTM_pred    470.337035      1.372400         -5.300894
# 4          GRU_pred    487.028545      1.462926         -6.012203
# 5     LSTM_GRU_pred    451.635450      1.336770         -5.938658
# 6       BiLSTM_pred    436.245563      1.289689         -5.989821
# 7   BiLSTM_GRU_pred    448.261390      1.323210         -5.940125
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    450.971505      1.343040         -4.948949
# 10         BNN_pred    429.658350      1.272424         -6.702396
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    424.647551      1.289089         -5.470599
# 1            CCV_dw    462.541105      1.375961         -4.765138
# 2            CCV_cw    281.526937      0.795861         -5.495482
# 3         LSTM_pred    390.661461      1.136650         -5.258589
# 4          GRU_pred    516.631831      1.584056         -5.982664
# 5     LSTM_GRU_pred    502.156681      1.567239         -5.021878
# 6       BiLSTM_pred    467.710449      1.432960         -5.995738
# 7   BiLSTM_GRU_pred    501.177474      1.496238         -4.297193
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    315.223036      0.931961         -5.662857
# 10         BNN_pred    391.340880      1.170281         -4.494197
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    285.971501      0.837881         -4.805567
# 1            CCV_dw    313.855871      0.956395         -4.538843
# 2            CCV_cw    167.063395      0.443744         -5.292806
# 3         LSTM_pred    387.767685      1.223858         -3.838064
# 4          GRU_pred    386.593789      1.406453         -3.870419
# 5     LSTM_GRU_pred    406.098415      1.393065         -5.105317
# 6       BiLSTM_pred    357.105197      1.218856         -5.304436
# 7   BiLSTM_GRU_pred    375.150319      1.226486         -4.957256
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    249.176612      0.735839         -4.492211
# 10         BNN_pred    330.904555      1.022189         -5.400687
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    418.321338      1.290172         -4.527687
# 1            CCV_dw    428.477096      1.305145         -4.799025
# 2            CCV_cw    263.591221      0.777901         -4.689195
# 3         LSTM_pred    354.484064      1.079410         -5.258589
# 4          GRU_pred    534.651310      1.663932         -6.770996
# 5     LSTM_GRU_pred    515.242505      1.656559         -5.871203
# 6       BiLSTM_pred    416.973872      1.396828         -4.954029
# 7   BiLSTM_GRU_pred    471.294032      1.491790         -4.487243
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    272.484114      0.783834         -4.909203
# 10         BNN_pred    355.198347      1.063333         -4.529501
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    424.647551      1.289089         -5.470599
# 1            CCV_dw    429.744874      1.277639         -4.813780
# 2            CCV_cw    316.663948      0.931672         -5.847729
# 3         LSTM_pred    404.579458      1.187124         -5.258589
# 4          GRU_pred    518.789977      1.590708         -5.974163
# 5     LSTM_GRU_pred    532.990426      1.681635         -5.028481
# 6       BiLSTM_pred    467.710449      1.432960         -5.995738
# 7   BiLSTM_GRU_pred    505.725645      1.508522         -4.297193
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    307.394892      0.903544         -5.662857
# 10         BNN_pred    380.568223      1.137388         -4.573424
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    324.106827      0.945890         -6.333972
# 1            CCV_dw    416.692088      1.282412         -5.462123
# 2            CCV_cw    237.456749      0.723771         -5.506994
# 3         LSTM_pred    482.207878      1.453607         -3.889161
# 4          GRU_pred    437.963718      1.361825         -5.922719
# 5     LSTM_GRU_pred    422.255217      1.295135         -4.832722
# 6       BiLSTM_pred    392.813479      1.173376         -6.210383
# 7   BiLSTM_GRU_pred    385.575576      1.085085         -5.212088
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    378.160321      1.072140         -4.960999
# 10         BNN_pred    346.590457      1.037529         -6.362422
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    496.753130      1.493266         -5.869712
# 1            CCV_dw    437.607625      1.328220         -5.888156
# 2            CCV_cw    354.873818      1.073137         -4.689195
# 3         LSTM_pred    446.659244      1.313924         -5.258589
# 4          GRU_pred    503.567157      1.533851         -6.783814
# 5     LSTM_GRU_pred    456.920895      1.365794         -5.669966
# 6       BiLSTM_pred    436.131511      1.289367         -5.990296
# 7   BiLSTM_GRU_pred    433.141216      1.270845         -6.002795
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    435.518127      1.236476         -5.002225
# 10         BNN_pred    386.390930      1.153271         -6.702396
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    444.530623      1.315696         -5.923910
# 1            CCV_dw    437.508362      1.325888         -5.888156
# 2            CCV_cw    495.481851      1.494318         -6.260491
# 3         LSTM_pred    476.521641      1.397092         -5.258589
# 4          GRU_pred    488.027094      1.465970         -6.008168
# 5     LSTM_GRU_pred    452.610232      1.339804         -5.934673
# 6       BiLSTM_pred    436.245563      1.289689         -5.989821
# 7   BiLSTM_GRU_pred    448.261390      1.323210         -5.940125
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    451.261491      1.343919         -4.947960
# 10         BNN_pred    413.476015      1.225669         -6.702396
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    295.981379      0.823978         -6.274611
# 1            CCV_dw    461.034771      1.376191         -5.495436
# 2            CCV_cw    250.765539      0.709791         -6.016307
# 3         LSTM_pred    467.034537      1.389215         -4.236136
# 4          GRU_pred    411.605829      1.230558         -5.902432
# 5     LSTM_GRU_pred    433.470962      1.299374         -4.855103
# 6       BiLSTM_pred    407.745004      1.217719         -6.144512
# 7   BiLSTM_GRU_pred    414.637344      1.174224         -5.105013
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    408.028616      1.151894         -5.505509
# 10         BNN_pred    417.203792      1.246078         -5.509336
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    454.187775      1.340820         -5.920093
# 1            CCV_dw    462.421201      1.366582         -5.924068
# 2            CCV_cw    380.411191      1.093673         -5.512906
# 3         LSTM_pred    447.959037      1.322343         -6.159250
# 4          GRU_pred    449.683850      1.327393         -5.924539
# 5     LSTM_GRU_pred    449.683850      1.327393         -5.924539
# 6       BiLSTM_pred    452.071413      1.334486         -5.924539
# 7   BiLSTM_GRU_pred    452.071413      1.325935         -5.924539
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    452.186731      1.271366         -5.924068
# 10         BNN_pred    418.532308      1.245618         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    452.186731      1.334807         -5.924068
# 1            CCV_dw    452.186731      1.334807         -5.924068
# 2            CCV_cw    446.620297      1.318320         -6.242038
# 3         LSTM_pred    452.186731      1.334807         -5.924068
# 4          GRU_pred    453.161883      1.337738         -5.920093
# 5     LSTM_GRU_pred    453.161883      1.337738         -5.920093
# 6       BiLSTM_pred    452.186731      1.334807         -5.924068
# 7   BiLSTM_GRU_pred    452.186731      1.334807         -5.924068
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    452.186731      1.334807         -5.924068
# 10         BNN_pred    452.186731      1.334807         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    450.173044      1.332437         -5.933529
# 1            CCV_dw    467.013102      1.370381         -5.881817
# 2            CCV_cw    383.790642      1.152667         -6.602322
# 3         LSTM_pred    499.358242      1.406330         -5.984853
# 4          GRU_pred    462.250597      1.401196         -5.955930
# 5     LSTM_GRU_pred    453.333494      1.338525         -6.089122
# 6       BiLSTM_pred    455.767568      1.346974         -5.909497
# 7   BiLSTM_GRU_pred    452.656352      1.309219         -6.033261
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    442.637026      1.270256         -5.973302
# 10         BNN_pred    428.613751      1.268882         -6.667981
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    369.396257      1.071237         -5.747015
# 1            CCV_dw    467.874598      1.409910         -4.924228
# 2            CCV_cw    370.803713      1.074154         -6.302499
# 3         LSTM_pred    484.419217      1.406148         -5.444600
# 4          GRU_pred    466.951230      1.431182         -4.886157
# 5     LSTM_GRU_pred    441.183394      1.326958         -5.386154
# 6       BiLSTM_pred    407.043693      1.299753         -5.854660
# 7   BiLSTM_GRU_pred    405.255833      1.162537         -4.236136
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    398.818694      1.141899         -5.809844
# 10         BNN_pred    382.486815      1.133142         -4.505645
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    251.016749      0.754096         -5.597615
# 1            CCV_dw    399.133146      1.238907         -3.984682
# 2            CCV_cw    236.369524      0.699912         -4.880291
# 3         LSTM_pred    444.018759      1.356151         -4.729388
# 4          GRU_pred    436.755913      1.552956         -3.607523
# 5     LSTM_GRU_pred    364.867286      1.171931         -4.930435
# 6       BiLSTM_pred    373.060522      1.267029         -5.122402
# 7   BiLSTM_GRU_pred    204.727584      0.543656         -6.275427
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    280.813118      0.805811         -5.522359
# 10         BNN_pred    324.444149      0.984716         -6.612710
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    404.646647      1.215749         -3.840497
# 1            CCV_dw    453.329729      1.371881         -4.956776
# 2            CCV_cw    282.652833      0.852896         -5.489594
# 3         LSTM_pred    436.775203      1.331261         -4.729388
# 4          GRU_pred    476.364340      1.512494         -5.575961
# 5     LSTM_GRU_pred    476.047572      1.462916         -6.184972
# 6       BiLSTM_pred    450.081483      1.488425         -4.814820
# 7   BiLSTM_GRU_pred    329.013139      0.985584         -4.917923
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    425.310416      1.241687         -5.278520
# 10         BNN_pred    400.633746      1.202362         -4.514985
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    337.524855      0.955145         -5.756720
# 1            CCV_dw    459.074557      1.387374         -4.956776
# 2            CCV_cw    372.166037      1.132653         -4.772722
# 3         LSTM_pred    469.825550      1.408200         -5.443715
# 4          GRU_pred    494.013787      1.503492         -6.580909
# 5     LSTM_GRU_pred    412.706159      1.233630         -7.141806
# 6       BiLSTM_pred    400.781126      1.282865         -5.880834
# 7   BiLSTM_GRU_pred    410.158345      1.240689         -4.236136
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    407.193557      1.219863         -5.190091
# 10         BNN_pred    366.838416      1.083196         -4.626619
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    331.458751      1.039058         -5.259427
# 1            CCV_dw    423.306799      1.272408         -4.948532
# 2            CCV_cw    237.461741      0.679747         -4.660324
# 3         LSTM_pred    416.652380      1.218069         -6.353314
# 4          GRU_pred    461.739781      1.493782         -5.692271
# 5     LSTM_GRU_pred    405.521954      1.277522         -4.767870
# 6       BiLSTM_pred    424.021867      1.281155         -6.137281
# 7   BiLSTM_GRU_pred    339.985611      1.019561         -5.425052
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    307.412493      0.873641         -6.811084
# 10         BNN_pred    390.393240      1.165362         -5.892405
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    443.741997      1.310472         -5.391163
# 1            CCV_dw    470.136044      1.383218         -5.881817
# 2            CCV_cw    285.220977      0.844048         -6.068967
# 3         LSTM_pred    426.306772      1.243779         -6.353314
# 4          GRU_pred    472.381280      1.502180         -5.614226
# 5     LSTM_GRU_pred    497.417236      1.498369         -5.872669
# 6       BiLSTM_pred    435.510347      1.289318         -5.992889
# 7   BiLSTM_GRU_pred    448.238127      1.321568         -6.130157
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    415.880885      1.178119         -6.215348
# 10         BNN_pred    433.939802      1.291541         -6.667981
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    450.173044      1.332437         -5.933529
# 1            CCV_dw    461.589439      1.354232         -5.881817
# 2            CCV_cw    379.946857      1.143572         -4.732405
# 3         LSTM_pred    454.535716      1.321756         -6.107636
# 4          GRU_pred    474.926960      1.452671         -6.654887
# 5     LSTM_GRU_pred    442.152190      1.305670         -6.789261
# 6       BiLSTM_pred    456.745125      1.349909         -5.905531
# 7   BiLSTM_GRU_pred    482.079115      1.413973         -6.066176
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    440.059945      1.271316         -5.972109
# 10         BNN_pred    412.443240      1.222134         -6.667981
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    290.963990      0.864397         -5.259427
# 1            CCV_dw    446.261791      1.342440         -4.912472
# 2            CCV_cw    294.290425      0.842794         -4.660324
# 3         LSTM_pred    415.079242      1.230750         -6.159250
# 4          GRU_pred    419.579460      1.256176         -5.869279
# 5     LSTM_GRU_pred    457.314310      1.386624         -4.540982
# 6       BiLSTM_pred    424.256908      1.275684         -6.136268
# 7   BiLSTM_GRU_pred    410.854910      1.169013         -5.164030
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    394.654943      1.131811         -6.386992
# 10         BNN_pred    429.577078      1.272746         -5.150817
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    402.422908      1.159135         -5.391163
# 1            CCV_dw    462.421201      1.366582         -5.924068
# 2            CCV_cw    291.932630      0.838873         -5.995406
# 3         LSTM_pred    424.722914      1.256032         -6.159250
# 4          GRU_pred    423.631698      1.261848         -5.902432
# 5     LSTM_GRU_pred    454.271580      1.341260         -5.924539
# 6       BiLSTM_pred    452.071413      1.334486         -5.924539
# 7   BiLSTM_GRU_pred    428.154189      1.258419         -5.960133
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    450.552152      1.266526         -6.068664
# 10         BNN_pred    452.186731      1.334807         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    452.186731      1.334807         -5.924068
# 1            CCV_dw    452.186731      1.334807         -5.924068
# 2            CCV_cw    386.522635      1.143788         -5.777654
# 3         LSTM_pred    453.161883      1.337738         -5.920093
# 4          GRU_pred    449.683850      1.327393         -5.924539
# 5     LSTM_GRU_pred    452.071413      1.334486         -5.924539
# 6       BiLSTM_pred    453.161883      1.337738         -5.920093
# 7   BiLSTM_GRU_pred    452.186731      1.334807         -5.924068
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    452.186731      1.295132         -5.924068
# 10         BNN_pred    452.186731      1.334807         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    414.864577      1.236278         -5.924068
# 1            CCV_dw    468.125754      1.415318         -3.589291
# 2            CCV_cw    313.163345      0.886494         -6.164654
# 3         LSTM_pred    434.697020      1.247340         -5.508678
# 4          GRU_pred    476.427333      1.516790         -5.082504
# 5     LSTM_GRU_pred    399.622835      1.261951         -5.773974
# 6       BiLSTM_pred    346.818082      1.076325         -5.928193
# 7   BiLSTM_GRU_pred    290.673215      0.869357         -6.812198
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    448.519532      1.280192         -6.025888
# 10         BNN_pred    265.244126      0.723785         -4.718294
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    400.046501      1.227445         -5.960278
# 1            CCV_dw    485.275137      1.559092         -4.125624
# 2            CCV_cw    339.745132      1.046755         -5.959856
# 3         LSTM_pred    370.138379      1.128105         -5.258589
# 4          GRU_pred    319.271551      1.026781         -4.557809
# 5     LSTM_GRU_pred    392.134258      1.248471         -5.081477
# 6       BiLSTM_pred    290.559020      0.912871         -7.429655
# 7   BiLSTM_GRU_pred    411.133506      1.291417         -4.236136
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    235.730557      0.645841         -5.701289
# 10         BNN_pred    373.737375      1.137709         -4.704211
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    182.884195      0.658404         -4.236136
# 1            CCV_dw    135.225898      0.304654         -6.994049
# 2            CCV_cw     47.783799     -0.383899         -7.161075
# 3         LSTM_pred    254.345764      0.807250         -5.258589
# 4          GRU_pred    189.398531      0.662057         -3.607520
# 5     LSTM_GRU_pred    119.824923      0.221466         -5.355557
# 6       BiLSTM_pred    163.894498      0.507557         -6.958960
# 7   BiLSTM_GRU_pred     93.815608      0.067242         -5.017352
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred     77.950302     -0.018651         -7.719476
# 10         BNN_pred    321.531092      1.160603         -3.321034
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    233.932207      0.847992         -6.126143
# 1            CCV_dw    304.309815      0.996768         -5.800776
# 2            CCV_cw    215.394949      0.729874         -5.039386
# 3         LSTM_pred    329.927641      1.085788         -5.258589
# 4          GRU_pred    207.611973      0.692623         -4.634846
# 5     LSTM_GRU_pred    275.875881      0.972489         -4.727624
# 6       BiLSTM_pred    260.523147      0.916908         -6.742518
# 7   BiLSTM_GRU_pred    262.603020      0.822516         -4.275690
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    179.521612      0.485727         -5.485049
# 10         BNN_pred    250.541071      0.730693         -5.294743
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    357.315518      1.308742         -5.960278
# 1            CCV_dw    439.603748      1.429100         -4.674390
# 2            CCV_cw    204.641682      0.600190         -6.437775
# 3         LSTM_pred    344.177560      1.111170         -5.258589
# 4          GRU_pred    298.013906      1.054421         -4.715083
# 5     LSTM_GRU_pred    351.244427      1.116707         -4.884764
# 6       BiLSTM_pred    252.523150      0.853168         -6.578149
# 7   BiLSTM_GRU_pred    286.783566      0.887452         -4.238899
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    284.642242      0.899936         -5.232507
# 10         BNN_pred    276.011730      0.812815         -4.857154
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    182.884195      0.658404         -4.236136
# 1            CCV_dw    277.814880      0.898538         -3.674054
# 2            CCV_cw     28.481872     -0.465407         -6.436079
# 3         LSTM_pred    299.830117      0.891106         -4.236136
# 4          GRU_pred    333.375293      1.336266         -2.690777
# 5     LSTM_GRU_pred    172.325274      0.553780         -4.781017
# 6       BiLSTM_pred    229.807107      0.701392         -5.235109
# 7   BiLSTM_GRU_pred    105.496367      0.165348         -6.636622
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    282.593216      0.827671         -7.060304
# 10         BNN_pred    265.844089      0.810914         -5.226012
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    276.022558      1.047575         -5.924068
# 1            CCV_dw    373.098584      1.143434         -3.468142
# 2            CCV_cw    210.545602      0.612378         -6.324855
# 3         LSTM_pred    421.945676      1.275625         -4.737782
# 4          GRU_pred    455.095670      1.663326         -4.639968
# 5     LSTM_GRU_pred    275.795081      0.972187         -6.669811
# 6       BiLSTM_pred    368.232993      1.193780         -5.242906
# 7   BiLSTM_GRU_pred    240.913368      0.724333         -4.923949
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    331.922746      0.997802         -6.808013
# 10         BNN_pred    195.333483      0.473139         -6.141562
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    343.101721      1.184270         -5.924068
# 1            CCV_dw    452.812722      1.370326         -3.820778
# 2            CCV_cw    261.404870      0.734776         -6.300949
# 3         LSTM_pred    440.862839      1.330345         -4.737406
# 4          GRU_pred    450.816831      1.557380         -5.706286
# 5     LSTM_GRU_pred    405.404750      1.305139         -6.584508
# 6       BiLSTM_pred    376.816576      1.216137         -5.148928
# 7   BiLSTM_GRU_pred    307.252459      0.942793         -4.992747
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    423.976634      1.259197         -6.288371
# 10         BNN_pred    237.349908      0.630143         -4.712850
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    182.884195      0.658404         -4.236136
# 1            CCV_dw    401.451739      1.272540         -5.085143
# 2            CCV_cw     24.531280     -0.495174         -6.436079
# 3         LSTM_pred    434.243188      1.300576         -4.236136
# 4          GRU_pred    360.442129      1.077212         -5.602800
# 5     LSTM_GRU_pred    249.928831      0.832730         -4.762712
# 6       BiLSTM_pred    349.775064      1.061420         -6.109999
# 7   BiLSTM_GRU_pred    290.168662      0.869817         -5.444006
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    262.792137      0.727116         -6.917625
# 10         BNN_pred    432.719022      1.283199         -4.971295
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    276.022558      1.047575         -5.924068
# 1            CCV_dw    425.792700      1.276158         -5.575202
# 2            CCV_cw    266.405777      0.843395         -6.022648
# 3         LSTM_pred    415.079242      1.222144         -6.159250
# 4          GRU_pred    428.691201      1.285445         -5.869279
# 5     LSTM_GRU_pred    401.799082      1.200107         -6.101801
# 6       BiLSTM_pred    443.079576      1.313370         -6.136268
# 7   BiLSTM_GRU_pred    366.659544      1.097256         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    311.360102      0.891636         -6.670433
# 10         BNN_pred    412.189106      1.226182         -6.158761
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    343.101721      1.184270         -5.924068
# 1            CCV_dw    458.279513      1.354426         -6.158761
# 2            CCV_cw    300.634332      0.834093         -6.064179
# 3         LSTM_pred    448.074028      1.322664         -6.158761
# 4          GRU_pred    457.407104      1.350912         -5.902432
# 5     LSTM_GRU_pred    436.948876      1.294169         -5.902432
# 6       BiLSTM_pred    447.959037      1.322343         -6.159250
# 7   BiLSTM_GRU_pred    447.959037      1.322343         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    450.238437      1.299751         -5.932027
# 10         BNN_pred    418.532308      1.245618         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    375.384104      1.092416         -5.956153
# 1            CCV_dw    481.771537      1.506809         -3.584427
# 2            CCV_cw    229.845423      0.625514         -6.520940
# 3         LSTM_pred    362.489166      1.045619         -6.183303
# 4          GRU_pred    476.427333      1.516790         -5.082504
# 5     LSTM_GRU_pred    407.866489      1.312253         -5.395315
# 6       BiLSTM_pred    274.641428      0.833986         -6.079244
# 7   BiLSTM_GRU_pred    413.991826      1.305483         -4.236136
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    370.587757      1.059681         -6.262580
# 10         BNN_pred    331.768432      0.988603         -4.679602
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    336.634459      1.026268         -5.956153
# 1            CCV_dw    509.044630      1.727828         -4.039044
# 2            CCV_cw    178.636062      0.419381         -8.228814
# 3         LSTM_pred    368.702077      1.187418         -4.433838
# 4          GRU_pred    319.271551      1.026781         -4.557809
# 5     LSTM_GRU_pred    206.672723      0.586783         -5.405205
# 6       BiLSTM_pred    302.119452      0.929669         -7.449136
# 7   BiLSTM_GRU_pred    405.802291      1.324965         -3.353621
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    177.356192      0.420528         -5.701289
# 10         BNN_pred    286.706687      0.841939         -5.006226
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    141.392071      0.430210         -4.236136
# 1            CCV_dw    116.592466      0.251456         -7.466535
# 2            CCV_cw     60.337132     -0.315456         -4.815044
# 3         LSTM_pred    247.469171      0.841174         -3.966045
# 4          GRU_pred    250.604415      1.163574         -3.528210
# 5     LSTM_GRU_pred    150.688926      0.423833         -3.706685
# 6       BiLSTM_pred    230.693320      1.002738         -3.579627
# 7   BiLSTM_GRU_pred     65.775830     -0.100066         -4.919381
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    -52.149055     -1.000106        -13.176824
# 10         BNN_pred    154.665678      0.429755         -4.293905
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    205.781713      0.742310         -4.236136
# 1            CCV_dw    224.370539      0.699209         -6.543185
# 2            CCV_cw    130.084485      0.270780         -6.063349
# 3         LSTM_pred    345.320281      1.234358         -3.666758
# 4          GRU_pred    207.611973      0.692623         -4.634846
# 5     LSTM_GRU_pred    177.610486      0.537696         -4.984716
# 6       BiLSTM_pred    207.307713      0.714261         -6.710199
# 7   BiLSTM_GRU_pred    180.129350      0.510303         -4.453514
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred     42.287811     -0.236279         -8.809046
# 10         BNN_pred    115.000762      0.120173         -6.932208
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    262.741680      0.927273         -5.661832
# 1            CCV_dw    361.238954      1.238561         -5.936609
# 2            CCV_cw     71.935267     -0.102907         -8.230448
# 3         LSTM_pred    310.054504      1.023858         -3.787934
# 4          GRU_pred    298.013906      1.054421         -4.715083
# 5     LSTM_GRU_pred    338.685895      1.140391         -4.081963
# 6       BiLSTM_pred    222.704289      0.736347         -6.529718
# 7   BiLSTM_GRU_pred    308.139198      1.024210         -3.563875
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    188.749797      0.524652         -5.425791
# 10         BNN_pred    169.596123      0.378306         -5.650796
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    174.408643      0.641221         -4.236136
# 1            CCV_dw    231.653167      0.748843         -5.348658
# 2            CCV_cw     64.738331     -0.217153         -4.812167
# 3         LSTM_pred    222.057931      0.627402         -4.236136
# 4          GRU_pred    434.236578      1.934304         -2.516992
# 5     LSTM_GRU_pred    118.764019      0.270672         -5.285346
# 6       BiLSTM_pred    147.722589      0.361370         -4.889476
# 7   BiLSTM_GRU_pred    133.003192      0.243532         -4.729803
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    161.211798      0.380956         -7.320884
# 10         BNN_pred    231.083870      0.725382         -3.521377
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    203.087313      0.699559         -5.981982
# 1            CCV_dw    309.819571      1.001813         -4.130754
# 2            CCV_cw    183.493069      0.507167         -6.403650
# 3         LSTM_pred    338.649694      1.039871         -4.481966
# 4          GRU_pred    455.095670      1.663326         -4.639968
# 5     LSTM_GRU_pred    200.352208      0.675597         -5.101916
# 6       BiLSTM_pred    245.791804      0.771215         -5.593173
# 7   BiLSTM_GRU_pred    209.388649      0.639457         -4.264102
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    261.057103      0.768451         -7.320884
# 10         BNN_pred    244.155193      0.688610         -7.123870
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    300.947231      1.013793         -5.924068
# 1            CCV_dw    343.576708      1.073041         -4.044735
# 2            CCV_cw    198.718514      0.567876         -6.681840
# 3         LSTM_pred    327.886858      0.999186         -4.935845
# 4          GRU_pred    450.816831      1.557380         -5.706286
# 5     LSTM_GRU_pred    391.248830      1.299294         -6.309562
# 6       BiLSTM_pred    281.265058      0.890916         -5.453715
# 7   BiLSTM_GRU_pred    340.632053      1.100445         -4.236136
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    383.195850      1.172659         -6.485704
# 10         BNN_pred    294.980944      0.873088         -4.711809
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    174.408643      0.641221         -4.236136
# 1            CCV_dw    355.693955      1.128599         -5.085143
# 2            CCV_cw     58.499308     -0.252090         -4.812167
# 3         LSTM_pred    447.806015      1.385346         -4.886879
# 4          GRU_pred    344.455439      1.026940         -5.602800
# 5     LSTM_GRU_pred    250.230517      0.834033         -4.761563
# 6       BiLSTM_pred    353.155505      1.072901         -6.109963
# 7   BiLSTM_GRU_pred    354.973762      1.060903         -5.091576
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    191.985282      0.482345         -6.917625
# 10         BNN_pred    463.999927      1.365816         -4.878345
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    203.087313      0.699559         -5.981982
# 1            CCV_dw    377.911220      1.136623         -5.603552
# 2            CCV_cw    226.950769      0.684449         -6.060982
# 3         LSTM_pred    422.217150      1.244730         -5.743307
# 4          GRU_pred    428.691201      1.285445         -5.869279
# 5     LSTM_GRU_pred    387.151489      1.216982         -4.950331
# 6       BiLSTM_pred    409.636210      1.223602         -6.136268
# 7   BiLSTM_GRU_pred    312.768568      0.930571         -5.731697
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    310.644188      0.889284         -6.917625
# 10         BNN_pred    412.189106      1.226182         -6.158761
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    301.821170      1.017076         -5.924068
# 1            CCV_dw    450.248132      1.335661         -6.158761
# 2            CCV_cw    341.880721      0.989947         -6.068455
# 3         LSTM_pred    424.722914      1.256032         -6.159250
# 4          GRU_pred    457.407104      1.350912         -5.902432
# 5     LSTM_GRU_pred    436.853656      1.295398         -5.869279
# 6       BiLSTM_pred    447.959037      1.322343         -6.159250
# 7   BiLSTM_GRU_pred    447.959037      1.322343         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    420.286966      1.212711         -6.057123
# 10         BNN_pred    418.532308      1.245618         -5.924068
# 11               __    452.186731      1.334807         -5.924068

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    444.530623      1.315696         -5.923910
# 1            CCV_dw    436.174440      1.340212         -5.960300
# 2            CCV_cw    448.282849      1.346950         -6.179249
# 3         LSTM_pred    435.861782      1.287314         -5.991422
# 4          GRU_pred    487.028545      1.462926         -6.012203
# 5     LSTM_GRU_pred    445.195147      1.314374         -5.952728
# 6       BiLSTM_pred    425.602514      1.261974         -5.987364
# 7   BiLSTM_GRU_pred    408.418340      1.209185         -6.072692
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    403.213368      1.210158         -4.782014
# 10         BNN_pred    447.333226      1.285139         -6.708773
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    424.647551      1.289089         -5.470599
# 1            CCV_dw    423.643534      1.297109         -4.844483
# 2            CCV_cw    300.981222      0.825192         -6.741198
# 3         LSTM_pred    317.017945      0.965164         -4.914031
# 4          GRU_pred    516.631831      1.584056         -5.982664
# 5     LSTM_GRU_pred    458.609072      1.423445         -6.885903
# 6       BiLSTM_pred    288.899007      0.809912         -6.423101
# 7   BiLSTM_GRU_pred    597.489093      1.822556         -3.665677
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    469.706626      1.373039         -5.662857
# 10         BNN_pred    409.226879      1.214761         -5.330235
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    285.971501      0.837881         -4.805567
# 1            CCV_dw    374.992695      1.161570         -4.861366
# 2            CCV_cw    268.718304      0.818473         -6.755056
# 3         LSTM_pred    254.490952      0.794643         -4.804785
# 4          GRU_pred    386.593789      1.406453         -3.870419
# 5     LSTM_GRU_pred    331.295356      1.031380         -5.393967
# 6       BiLSTM_pred    147.526575      0.296942         -7.980773
# 7   BiLSTM_GRU_pred    463.755748      1.649783         -3.514783
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    450.166279      1.388046         -3.391065
# 10         BNN_pred    314.718007      0.931404         -4.512218
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    418.321338      1.290172         -4.527687
# 1            CCV_dw    373.696098      1.140030         -4.862190
# 2            CCV_cw    401.390711      1.248431         -4.817433
# 3         LSTM_pred    297.913529      0.919751         -4.914031
# 4          GRU_pred    534.651310      1.663932         -6.770996
# 5     LSTM_GRU_pred    403.607797      1.263304         -6.412906
# 6       BiLSTM_pred    247.292460      0.666171         -6.414771
# 7   BiLSTM_GRU_pred    527.605127      1.841961         -3.560226
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    460.218153      1.379642         -3.528759
# 10         BNN_pred    373.114875      1.107881         -5.341887
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    424.647551      1.289089         -5.470599
# 1            CCV_dw    424.040978      1.302360         -4.782858
# 2            CCV_cw    399.478906      1.197293         -4.835690
# 3         LSTM_pred    312.053040      0.947198         -4.914031
# 4          GRU_pred    518.789977      1.590708         -5.974163
# 5     LSTM_GRU_pred    451.586568      1.401927         -6.919216
# 6       BiLSTM_pred    288.899007      0.809912         -6.423101
# 7   BiLSTM_GRU_pred    559.427983      1.716022         -3.755146
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    443.804662      1.296076         -5.662857
# 10         BNN_pred    391.817480      1.160462         -5.333497
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    324.106827      0.945890         -6.333972
# 1            CCV_dw    442.395982      1.323234         -6.000639
# 2            CCV_cw    290.387194      0.938382         -5.437906
# 3         LSTM_pred    383.449123      1.141998         -6.349817
# 4          GRU_pred    437.963718      1.361825         -5.922719
# 5     LSTM_GRU_pred    327.300936      0.924872         -6.152675
# 6       BiLSTM_pred    391.717583      1.159886         -5.368548
# 7   BiLSTM_GRU_pred    352.923449      1.068420         -6.922944
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    375.745615      1.064908         -4.960999
# 10         BNN_pred    367.288526      1.071731         -5.737186
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    496.753130      1.493266         -5.869712
# 1            CCV_dw    423.024309      1.249870         -5.983219
# 2            CCV_cw    400.889048      1.249272         -4.721409
# 3         LSTM_pred    398.613461      1.185275         -6.228783
# 4          GRU_pred    503.567157      1.533851         -6.783814
# 5     LSTM_GRU_pred    437.258120      1.293644         -6.411273
# 6       BiLSTM_pred    426.608950      1.256471         -5.987364
# 7   BiLSTM_GRU_pred    388.680024      1.176476         -5.792891
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    371.536626      1.045956         -4.960999
# 10         BNN_pred    418.696919      1.211584         -6.719839
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    444.530623      1.315696         -5.923910
# 1            CCV_dw    436.174440      1.340212         -5.960300
# 2            CCV_cw    482.575139      1.469678         -5.833450
# 3         LSTM_pred    435.861782      1.287314         -5.991422
# 4          GRU_pred    488.027094      1.465970         -6.008168
# 5     LSTM_GRU_pred    445.195147      1.314374         -5.952728
# 6       BiLSTM_pred    425.602514      1.261974         -5.987364
# 7   BiLSTM_GRU_pred    391.286727      1.158926         -6.147468
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    403.493810      1.211045         -4.781059
# 10         BNN_pred    430.950829      1.238358         -6.708773
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    295.981379      0.823978         -6.274611
# 1            CCV_dw    462.421201      1.318152         -5.924068
# 2            CCV_cw    245.136508      0.680942         -6.337969
# 3         LSTM_pred    398.337753      1.187647         -6.282208
# 4          GRU_pred    411.605829      1.230558         -5.902432
# 5     LSTM_GRU_pred    333.722170      0.946111         -6.123053
# 6       BiLSTM_pred    461.652456      1.355736         -5.311794
# 7   BiLSTM_GRU_pred    414.262964      1.240447         -6.584074
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    448.737876      1.261297         -6.303621
# 10         BNN_pred    419.023216      1.253651         -5.920093
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    454.187775      1.340820         -5.920093
# 1            CCV_dw    452.186731      1.286388         -5.924068
# 2            CCV_cw    382.894729      1.101562         -5.359862
# 3         LSTM_pred    414.514917      1.233347         -6.158761
# 4          GRU_pred    449.683850      1.327393         -5.924539
# 5     LSTM_GRU_pred    444.211307      1.314132         -6.380406
# 6       BiLSTM_pred    453.211934      1.329337         -5.924068
# 7   BiLSTM_GRU_pred    451.640688      1.344927         -5.509336
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    452.186731      1.271366         -5.924068
# 10         BNN_pred    456.673370      1.354861         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    452.186731      1.334807         -5.924068
# 1            CCV_dw    452.186731      1.334807         -5.924068
# 2            CCV_cw    452.186731      1.334807         -5.924068
# 3         LSTM_pred    452.186731      1.334807         -5.924068
# 4          GRU_pred    453.161883      1.337738         -5.920093
# 5     LSTM_GRU_pred    452.186731      1.334807         -5.924068
# 6       BiLSTM_pred    452.186731      1.334807         -5.924068
# 7   BiLSTM_GRU_pred    452.186731      1.334807         -5.924068
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    452.186731      1.334807         -5.924068
# 10         BNN_pred    452.186731      1.334807         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    450.173044      1.332437         -5.933529
# 1            CCV_dw    408.730454      1.180233         -6.006050
# 2            CCV_cw    432.434021      1.277245         -5.256974
# 3         LSTM_pred    461.702682      1.383875         -5.010143
# 4          GRU_pred    462.250597      1.401196         -5.955930
# 5     LSTM_GRU_pred    472.881873      1.411258         -5.956281
# 6       BiLSTM_pred    411.130030      1.214516         -6.403072
# 7   BiLSTM_GRU_pred    355.709004      1.108911         -5.966303
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    388.759362      1.109894         -6.123415
# 10         BNN_pred    441.246502      1.310820         -6.667981
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    369.396257      1.071237         -5.747015
# 1            CCV_dw    480.717170      1.453348         -4.867854
# 2            CCV_cw    360.990773      1.033374         -6.611499
# 3         LSTM_pred    348.019275      1.064798         -4.565984
# 4          GRU_pred    466.951230      1.431182         -4.886157
# 5     LSTM_GRU_pred    385.377353      1.129723         -6.927454
# 6       BiLSTM_pred    347.840719      0.991522         -5.217752
# 7   BiLSTM_GRU_pred    566.059184      1.730247         -3.994494
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    337.213173      0.929620         -6.320637
# 10         BNN_pred    375.123819      1.102562         -4.512218
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    251.016749      0.754096         -5.597615
# 1            CCV_dw    384.885035      1.184328         -5.323248
# 2            CCV_cw    252.380568      0.724694         -5.498867
# 3         LSTM_pred    252.646218      0.771836         -4.821430
# 4          GRU_pred    436.755913      1.552956         -3.607523
# 5     LSTM_GRU_pred    236.416970      0.681517         -4.800285
# 6       BiLSTM_pred    223.737781      0.587778         -6.186762
# 7   BiLSTM_GRU_pred    423.101730      1.469868         -4.683004
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    334.620784      0.947345         -6.536597
# 10         BNN_pred    312.971830      0.930263         -4.512218
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    404.646647      1.215749         -3.840497
# 1            CCV_dw    478.534688      1.459587         -4.857481
# 2            CCV_cw    313.622117      0.916122         -6.713244
# 3         LSTM_pred    328.465159      1.022599         -4.573026
# 4          GRU_pred    476.364340      1.512494         -5.575961
# 5     LSTM_GRU_pred    401.808277      1.205580         -6.420861
# 6       BiLSTM_pred    287.173464      0.803092         -5.212968
# 7   BiLSTM_GRU_pred    471.419716      1.593446         -3.543679
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    353.586194      0.994997         -6.297879
# 10         BNN_pred    326.240502      0.947810         -4.721657
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    337.524855      0.955145         -5.756720
# 1            CCV_dw    457.362454      1.384844         -4.867854
# 2            CCV_cw    356.901313      1.032337         -5.971502
# 3         LSTM_pred    354.306532      1.099585         -4.558956
# 4          GRU_pred    494.013787      1.503492         -6.580909
# 5     LSTM_GRU_pred    385.895606      1.131235         -6.947365
# 6       BiLSTM_pred    345.164139      0.982479         -5.217752
# 7   BiLSTM_GRU_pred    453.536518      1.492301         -4.042091
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    360.644257      1.007497         -6.327363
# 10         BNN_pred    359.348016      1.052860         -4.512218
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    331.458751      1.039058         -5.259427
# 1            CCV_dw    355.273382      1.035019         -6.187291
# 2            CCV_cw    242.148259      0.689086         -5.990699
# 3         LSTM_pred    438.828092      1.347613         -5.350978
# 4          GRU_pred    461.739781      1.493782         -5.692271
# 5     LSTM_GRU_pred    365.616944      1.052591         -4.699705
# 6       BiLSTM_pred    425.732404      1.253914         -4.969448
# 7   BiLSTM_GRU_pred    248.879720      0.754204         -6.696524
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    309.535967      0.858367         -6.842104
# 10         BNN_pred    355.808266      1.075200         -6.699907
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    443.741997      1.310472         -5.391163
# 1            CCV_dw    418.989470      1.221276         -5.955622
# 2            CCV_cw    310.610503      0.950447         -6.128103
# 3         LSTM_pred    449.286935      1.374127         -5.254994
# 4          GRU_pred    472.381280      1.502180         -5.614226
# 5     LSTM_GRU_pred    457.288905      1.369288         -6.402564
# 6       BiLSTM_pred    412.126248      1.209027         -6.403072
# 7   BiLSTM_GRU_pred    311.582974      0.962877         -5.635082
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    351.604748      0.984660         -6.277110
# 10         BNN_pred    392.414997      1.171023         -6.667981
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    450.173044      1.332437         -5.933529
# 1            CCV_dw    386.511155      1.112908         -6.006050
# 2            CCV_cw    405.405892      1.201779         -5.087684
# 3         LSTM_pred    471.158068      1.424425         -5.073992
# 4          GRU_pred    474.926960      1.452671         -6.654887
# 5     LSTM_GRU_pred    475.765751      1.419979         -5.944641
# 6       BiLSTM_pred    411.130030      1.205941         -6.403072
# 7   BiLSTM_GRU_pred    328.695959      1.020443         -6.034476
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    386.255510      1.110862         -6.122192
# 10         BNN_pred    424.933001      1.264019         -6.667981
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    290.963990      0.864397         -5.259427
# 1            CCV_dw    423.941173      1.214494         -6.158761
# 2            CCV_cw    274.023838      0.748277         -6.526407
# 3         LSTM_pred    403.463511      1.204109         -6.259264
# 4          GRU_pred    419.579460      1.256176         -5.869279
# 5     LSTM_GRU_pred    356.893635      1.006840         -4.960999
# 6       BiLSTM_pred    467.213960      1.374455         -4.507226
# 7   BiLSTM_GRU_pred    377.222804      1.129532         -6.761151
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    445.358650      1.258169         -6.308355
# 10         BNN_pred    422.914969      1.265464         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    402.422908      1.159135         -5.391163
# 1            CCV_dw    462.421201      1.318152         -5.924068
# 2            CCV_cw    291.932630      0.838873         -5.995406
# 3         LSTM_pred    414.514917      1.233347         -6.158761
# 4          GRU_pred    423.631698      1.261848         -5.902432
# 5     LSTM_GRU_pred    444.211307      1.314132         -6.380406
# 6       BiLSTM_pred    453.211934      1.329337         -5.924068
# 7   BiLSTM_GRU_pred    457.514766      1.351635         -5.509336
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    453.161883      1.274312         -5.920093
# 10         BNN_pred    433.763692      1.283132         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    452.186731      1.334807         -5.924068
# 1            CCV_dw    452.186731      1.334807         -5.924068
# 2            CCV_cw    384.747321      1.097393         -5.785061
# 3         LSTM_pred    452.186731      1.334807         -5.924068
# 4          GRU_pred    449.683850      1.327393         -5.924539
# 5     LSTM_GRU_pred    452.186731      1.334807         -5.924068
# 6       BiLSTM_pred    452.186731      1.326256         -5.924068
# 7   BiLSTM_GRU_pred    452.186731      1.334807         -5.924068
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    452.186731      1.295132         -5.924068
# 10         BNN_pred    452.186731      1.334807         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    414.864577      1.236278         -5.924068
# 1            CCV_dw    421.244718      1.259405         -4.343767
# 2            CCV_cw    431.944685      1.221926         -5.962512
# 3         LSTM_pred    412.752338      1.223232         -5.501893
# 4          GRU_pred    476.427333      1.516790         -5.082504
# 5     LSTM_GRU_pred    422.212587      1.226894         -5.804540
# 6       BiLSTM_pred    365.370792      1.045411         -4.747870
# 7   BiLSTM_GRU_pred    491.275178      1.452274         -4.876803
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    420.690988      1.173672         -6.074438
# 10         BNN_pred    417.073160      1.216836         -4.598806
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    400.046501      1.227445         -5.960278
# 1            CCV_dw    361.540885      1.155895         -4.080235
# 2            CCV_cw    406.369514      1.260147         -5.570439
# 3         LSTM_pred    317.052239      0.958695         -4.765646
# 4          GRU_pred    319.271551      1.026781         -4.557809
# 5     LSTM_GRU_pred    285.611571      0.867918         -4.754252
# 6       BiLSTM_pred    212.008397      0.590569         -5.478388
# 7   BiLSTM_GRU_pred    345.126569      1.079990         -4.657011
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    320.433731      0.918388         -4.577363
# 10         BNN_pred    318.241493      0.985938         -3.906254
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    182.884195      0.658404         -4.236136
# 1            CCV_dw    321.610399      1.284386         -3.338355
# 2            CCV_cw     74.631768     -0.059715         -6.953342
# 3         LSTM_pred     45.926829     -0.285120         -7.250704
# 4          GRU_pred    189.398531      0.662057         -3.607520
# 5     LSTM_GRU_pred    219.415633      0.709195         -3.903567
# 6       BiLSTM_pred    217.498662      0.756788         -3.275817
# 7   BiLSTM_GRU_pred    355.375911      1.475649         -2.780741
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    136.725275      0.303192         -4.298950
# 10         BNN_pred    203.582715      0.684019         -6.164591
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    233.932207      0.847992         -6.126143
# 1            CCV_dw    284.161632      0.909449         -4.300435
# 2            CCV_cw    222.749294      0.771507         -6.111848
# 3         LSTM_pred    295.506483      0.988031         -5.924181
# 4          GRU_pred    207.611973      0.692623         -4.634846
# 5     LSTM_GRU_pred    243.531511      0.763636         -4.936658
# 6       BiLSTM_pred    241.163407      0.753631         -5.328204
# 7   BiLSTM_GRU_pred    293.941036      1.113666         -4.600025
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    351.623146      1.130194         -4.366856
# 10         BNN_pred    247.925073      0.760942         -6.009167
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    357.315518      1.308742         -5.960278
# 1            CCV_dw    307.785056      0.975587         -4.239092
# 2            CCV_cw    309.390433      1.070827         -5.671384
# 3         LSTM_pred    286.782286      0.919700         -4.765646
# 4          GRU_pred    298.013906      1.054421         -4.715083
# 5     LSTM_GRU_pred    286.564327      0.880032         -4.943924
# 6       BiLSTM_pred    275.019031      0.857878         -3.766557
# 7   BiLSTM_GRU_pred    386.574662      1.265859         -4.784351
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    363.374231      1.136738         -4.001204
# 10         BNN_pred    271.509003      0.809074         -4.774518
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    182.884195      0.658404         -4.236136
# 1            CCV_dw    409.190255      1.417045         -4.684614
# 2            CCV_cw    112.229227      0.178846         -6.975637
# 3         LSTM_pred    131.936585      0.259281         -6.822336
# 4          GRU_pred    333.375293      1.336266         -2.690777
# 5     LSTM_GRU_pred    322.371022      1.109952         -4.236136
# 6       BiLSTM_pred    171.467334      0.409926         -5.511974
# 7   BiLSTM_GRU_pred    484.859153      1.614863         -3.350588
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    283.983075      0.842581         -7.075542
# 10         BNN_pred    253.053201      0.736714         -5.022474
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    276.022558      1.047575         -5.924068
# 1            CCV_dw    369.366730      1.121677         -4.017440
# 2            CCV_cw    296.919473      1.022038         -6.387126
# 3         LSTM_pred    386.420190      1.176949         -4.783592
# 4          GRU_pred    455.095670      1.663326         -4.639968
# 5     LSTM_GRU_pred    374.506022      1.181653         -4.960999
# 6       BiLSTM_pred    212.900144      0.533697         -7.079021
# 7   BiLSTM_GRU_pred    459.155458      1.479153         -5.710968
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    362.997916      1.094773         -6.822706
# 10         BNN_pred    294.936859      0.836292         -4.617984
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    343.101721      1.184270         -5.924068
# 1            CCV_dw    398.991057      1.197589         -4.343767
# 2            CCV_cw    368.888175      1.132433         -6.069759
# 3         LSTM_pred    391.030858      1.187864         -4.757644
# 4          GRU_pred    450.816831      1.557380         -5.706286
# 5     LSTM_GRU_pred    410.193387      1.237858         -5.981876
# 6       BiLSTM_pred    298.326451      0.833693         -5.328641
# 7   BiLSTM_GRU_pred    522.234239      1.578601         -4.892024
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    422.751655      1.251394         -6.280404
# 10         BNN_pred    366.806274      1.057042         -4.606392
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    182.884195      0.658404         -4.236136
# 1            CCV_dw    353.531949      1.001410         -6.239697
# 2            CCV_cw     91.310922      0.012677         -6.975637
# 3         LSTM_pred    261.681794      0.773573         -5.095282
# 4          GRU_pred    360.442129      1.077212         -5.602800
# 5     LSTM_GRU_pred    440.797700      1.309082         -4.236136
# 6       BiLSTM_pred    391.940874      1.120719         -5.372909
# 7   BiLSTM_GRU_pred    426.726288      1.268266         -4.236136
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    314.773154      0.931603         -6.917625
# 10         BNN_pred    274.769466      0.802230         -6.210216
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    276.022558      1.047575         -5.924068
# 1            CCV_dw    442.237998      1.266851         -6.158761
# 2            CCV_cw    291.985836      0.945991         -6.023665
# 3         LSTM_pred    415.375462      1.237768         -6.198395
# 4          GRU_pred    428.691201      1.285445         -5.869279
# 5     LSTM_GRU_pred    476.495028      1.353750         -4.960999
# 6       BiLSTM_pred    479.087971      1.377795         -4.689195
# 7   BiLSTM_GRU_pred    409.097764      1.223926         -6.608208
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    382.332014      1.135597         -6.670433
# 10         BNN_pred    419.023216      1.253651         -5.920093
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    343.101721      1.184270         -5.924068
# 1            CCV_dw    462.421201      1.366582         -5.924068
# 2            CCV_cw    364.647233      1.030471         -6.069759
# 3         LSTM_pred    414.514917      1.233347         -6.158761
# 4          GRU_pred    457.407104      1.350912         -5.902432
# 5     LSTM_GRU_pred    444.211307      1.314132         -6.380406
# 6       BiLSTM_pred    450.602113      1.321596         -6.072739
# 7   BiLSTM_GRU_pred    450.199705      1.329122         -5.924068
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    450.238437      1.299924         -5.932027
# 10         BNN_pred    433.763692      1.283132         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    375.384104      1.092416         -5.956153
# 1            CCV_dw    427.715388      1.317808         -4.817850
# 2            CCV_cw    363.510506      1.044590         -5.987272
# 3         LSTM_pred    278.611028      0.824988         -4.914031
# 4          GRU_pred    476.427333      1.516790         -5.082504
# 5     LSTM_GRU_pred    330.626627      0.987923         -5.039918
# 6       BiLSTM_pred    235.767322      0.619665         -7.046623
# 7   BiLSTM_GRU_pred    412.371973      1.306556         -4.939024
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    417.331052      1.196167         -6.088200
# 10         BNN_pred    393.672042      1.189707         -5.000954
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    336.634459      1.026268         -5.956153
# 1            CCV_dw    411.594278      1.342371         -3.984036
# 2            CCV_cw    341.599813      1.039989         -6.499469
# 3         LSTM_pred    334.847066      1.043520         -5.333878
# 4          GRU_pred    319.271551      1.026781         -4.557809
# 5     LSTM_GRU_pred    400.913650      1.303217         -4.533797
# 6       BiLSTM_pred    227.700285      0.670750         -5.850527
# 7   BiLSTM_GRU_pred    267.279511      0.831160         -4.434998
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    319.487452      0.933505         -4.577363
# 10         BNN_pred    335.011656      1.081991         -3.766096
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    141.392071      0.430210         -4.236136
# 1            CCV_dw    255.909272      0.954299         -3.338355
# 2            CCV_cw    113.132584      0.211976         -5.887033
# 3         LSTM_pred     56.685095     -0.215571         -5.757810
# 4          GRU_pred    250.604415      1.163574         -3.528210
# 5     LSTM_GRU_pred    136.359641      0.315549         -4.506101
# 6       BiLSTM_pred    143.947455      0.399267         -4.140001
# 7   BiLSTM_GRU_pred    217.798001      0.858825         -4.715182
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    164.239374      0.515592         -4.004381
# 10         BNN_pred    213.127705      0.811927         -4.651844
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    205.781713      0.742310         -4.236136
# 1            CCV_dw    231.605496      0.685173         -4.548389
# 2            CCV_cw    208.162775      0.777689         -5.151704
# 3         LSTM_pred    192.683146      0.569323         -8.412256
# 4          GRU_pred    207.611973      0.692623         -4.634846
# 5     LSTM_GRU_pred    244.006705      0.817216         -3.622650
# 6       BiLSTM_pred    213.454544      0.659033         -4.396363
# 7   BiLSTM_GRU_pred    225.788033      0.823216         -4.110399
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    231.518461      0.762409         -4.274409
# 10         BNN_pred    240.984111      0.773275         -4.768993
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    262.741680      0.927273         -5.661832
# 1            CCV_dw    361.105260      1.183258         -4.107311
# 2            CCV_cw    205.161295      0.670795         -6.419827
# 3         LSTM_pred    280.514260      0.897304         -4.765646
# 4          GRU_pred    298.013906      1.054421         -4.715083
# 5     LSTM_GRU_pred    246.584535      0.787784         -3.528380
# 6       BiLSTM_pred    256.327007      0.810104         -3.674586
# 7   BiLSTM_GRU_pred    209.746760      0.655837         -4.225890
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    342.591020      1.084392         -4.092601
# 10         BNN_pred    254.939224      0.774723         -3.964206
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    174.408643      0.641221         -4.236136
# 1            CCV_dw    340.549381      1.257451         -4.684614
# 2            CCV_cw     88.147406      0.030638         -6.546628
# 3         LSTM_pred     37.293604     -0.340000         -6.016388
# 4          GRU_pred    434.236578      1.934304         -2.516992
# 5     LSTM_GRU_pred    216.806835      0.711622         -4.450625
# 6       BiLSTM_pred    243.264118      0.841407         -5.275264
# 7   BiLSTM_GRU_pred    370.774587      1.429104         -3.581107
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    223.785230      0.644548         -6.841835
# 10         BNN_pred    175.059974      0.487632         -7.124531
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    203.087313      0.699559         -5.981982
# 1            CCV_dw    318.355904      1.006685         -5.158134
# 2            CCV_cw    214.709776      0.696018         -6.497240
# 3         LSTM_pred    173.471877      0.445229         -7.927136
# 4          GRU_pred    455.095670      1.663326         -4.639968
# 5     LSTM_GRU_pred    281.267767      0.929373         -5.407627
# 6       BiLSTM_pred    195.856716      0.487510         -6.145467
# 7   BiLSTM_GRU_pred    398.694166      1.440099         -5.670458
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    303.946472      0.921300         -6.972650
# 10         BNN_pred    269.451460      0.795693         -4.618430
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    300.947231      1.013793         -5.924068
# 1            CCV_dw    387.521243      1.203546         -4.533724
# 2            CCV_cw    278.288183      0.859089         -6.345115
# 3         LSTM_pred    260.140153      0.775526         -4.914031
# 4          GRU_pred    450.816831      1.557380         -5.706286
# 5     LSTM_GRU_pred    275.790993      0.845544         -4.674181
# 6       BiLSTM_pred    257.704944      0.717928         -4.993136
# 7   BiLSTM_GRU_pred    388.630188      1.327773         -5.621871
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    430.294772      1.311987         -6.259244
# 10         BNN_pred    353.315516      1.059221         -4.600768
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    174.408643      0.641221         -4.236136
# 1            CCV_dw    343.354902      0.973296         -5.728036
# 2            CCV_cw     71.498678     -0.112452         -6.546628
# 3         LSTM_pred    253.355347      0.743730         -5.129131
# 4          GRU_pred    344.455439      1.026940         -5.602800
# 5     LSTM_GRU_pred    327.520921      0.980749         -4.236136
# 6       BiLSTM_pred    361.329571      1.026821         -5.675303
# 7   BiLSTM_GRU_pred    406.736400      1.208313         -4.236136
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    321.399671      0.955603         -6.545288
# 10         BNN_pred    309.977953      0.931782         -6.210216
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    203.087313      0.699559         -5.981982
# 1            CCV_dw    422.030775      1.199230         -6.167035
# 2            CCV_cw    262.100462      0.822874         -6.067346
# 3         LSTM_pred    414.952770      1.236489         -6.282208
# 4          GRU_pred    428.691201      1.285445         -5.869279
# 5     LSTM_GRU_pred    438.873007      1.257855         -4.960999
# 6       BiLSTM_pred    467.213960      1.325266         -5.091576
# 7   BiLSTM_GRU_pred    409.097764      1.223926         -6.608208
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    360.772849      1.076977         -6.670433
# 10         BNN_pred    346.797311      1.034821         -6.065663
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    301.821170      1.017076         -5.924068
# 1            CCV_dw    462.421201      1.318152         -5.924068
# 2            CCV_cw    299.443535      0.829921         -6.069736
# 3         LSTM_pred    412.617165      1.227493         -6.167035
# 4          GRU_pred    457.407104      1.350912         -5.902432
# 5     LSTM_GRU_pred    444.211307      1.265567         -6.380406
# 6       BiLSTM_pred    457.919204      1.344100         -5.657260
# 7   BiLSTM_GRU_pred    426.512923      1.264408         -5.924068
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    433.935741      1.251622         -5.999469
# 10         BNN_pred    443.868323      1.314934         -5.924068
# 11               __    452.186731      1.334807         -5.924068

# %%
# path_1 = '/content/drive/MyDrive/Strategy/MA/CCV/CCV/'
# path_2 = '/content/drive/MyDrive/Strategy/MA/CCV/DW_CCV/'
# path_3 = '/content/drive/MyDrive/Strategy/MA/CCV/CW_CCV/'

# file_name = 'file.csv'
# file.to_csv(path_1 + file_name)

# filename = 'file.csv'
# dw_file.to_csv(path_2 + file_name)

# filename = 'file.csv'
# cw_file.to_csv(path_3 + file_name)
