# %%
# !pip install pyswarm
# Out:
# Requirement already satisfied: pyswarm in /usr/local/lib/python3.10/dist-packages (0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyswarm) (1.26.4)

# %%
# from collections import Iterable, OrderedDict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from collections.abc import Iterable
from collections import OrderedDict
from google.colab import drive
from torch.nn import Parameter
from datetime import datetime
from functools import partial
import torch.optim as optim
from pyswarm import pso
import torch.nn as nn
from math import sqrt
import pandas as pd
import numpy as np
import inspect
import torch
import time

# %% [markdown]
# # Load data

# %%
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

# %%
filename = 'RSV_data.csv'
RSV_data = pd.read_csv(path + filename)

# %%
RSV_data
# Out:
#             Date       RSV  log_returns  ('GARCH', 'normal', 0)  \
# 0     2000-02-02 -0.001329     0.000077               -0.001864
# 1     2000-02-03 -0.001195     0.000020               -0.001554
# 2     2000-02-04 -0.000892     0.000152               -0.001080
# 3     2000-02-07 -0.000587     0.000090               -0.000627
# 4     2000-02-08 -0.000294    -0.000335               -0.000202
# ...          ...       ...          ...                     ...
# 6179  2024-08-26  0.000235    -0.000161               -0.000358
# 6180  2024-08-27 -0.000003    -0.000193               -0.000694
# 6181  2024-08-28 -0.000249    -0.000154               -0.000954
# 6182  2024-08-29 -0.000508    -0.000150               -0.001147
# 6183  2024-08-30 -0.000760    -0.000129               -0.001232
#
#       ('GARCH', 'normal', 1)  ('GARCH', 'gaussian', 0)  \
# 0                  -0.001725                 -0.001864
# 1                  -0.001557                 -0.001554
# 2                  -0.001163                 -0.001080
# 3                  -0.000738                 -0.000627
# 4                  -0.000335                 -0.000202
# ...                      ...                       ...
# 6179               -0.000493                 -0.000358
# 6180               -0.000707                 -0.000694
# 6181               -0.000846                 -0.000954
# 6182               -0.000937                 -0.001147
# 6183               -0.000923                 -0.001232
#
#       ('GARCH', 'gaussian', 1)  ('GARCH', 'ged', 0)  ('GARCH', 'ged', 1)  \
# 0                    -0.001725            -0.001971            -0.001822
# 1                    -0.001557            -0.001745            -0.001612
# 2                    -0.001163            -0.001302            -0.001217
# 3                    -0.000738            -0.000863            -0.000784
# 4                    -0.000335            -0.000364            -0.000368
# ...                        ...                  ...                  ...
# 6179                 -0.000493            -0.001023            -0.000502
# 6180                 -0.000707            -0.001244            -0.000717
# 6181                 -0.000846            -0.001311            -0.000852
# 6182                 -0.000937            -0.001324            -0.000933
# 6183                 -0.000923            -0.001267            -0.000919
#
#       ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# 0                    -0.001782                 -0.001782
# 1                    -0.001519                 -0.001519
# 2                    -0.001076                 -0.001076
# 3                    -0.000678                 -0.000678
# 4                    -0.000311                 -0.000311
# ...                        ...                       ...
# 6179                 -0.000690                 -0.000690
# 6180                 -0.000899                 -0.000899
# 6181                 -0.001012                 -0.001012
# 6182                 -0.001067                 -0.001067
# 6183                 -0.001030                 -0.001030
#
#       ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)  \
# 0                      -0.001782                   -0.001782
# 1                      -0.001519                   -0.001519
# 2                      -0.001076                   -0.001076
# 3                      -0.000678                   -0.000678
# 4                      -0.000311                   -0.000311
# ...                          ...                         ...
# 6179                   -0.000690                   -0.000690
# 6180                   -0.000899                   -0.000899
# 6181                   -0.001012                   -0.001012
# 6182                   -0.001067                   -0.001067
# 6183                   -0.001030                   -0.001030
#
#       ('APARCH', 'normal', 0)  ('APARCH', 'gaussian', 0)          vix  \
# 0                   -0.002629                  -0.002629 -5074.430765
# 1                   -0.002632                  -0.002632 -4871.204473
# 2                   -0.001695                  -0.001695 -3989.985998
# 3                   22.959341                  22.959341 -2979.521889
# 4                    0.002296                   0.002296 -1886.674367
# ...                       ...                        ...          ...
# 6179                -0.000912                  -0.000912  -118.886061
# 6180                -0.001074                  -0.001074  -381.296847
# 6181                -0.001116                  -0.001116  -746.562442
# 6182                -0.001080                  -0.001080 -1297.880813
('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)  \
# Date
# 2000-02-02                   -0.001782                   -0.001782
# 2000-02-03                   -0.001519                   -0.001519
# 2000-02-04                   -0.001076                   -0.001076
# 2000-02-07                   -0.000678                   -0.000678
# 2000-02-08                   -0.000311                   -0.000311
# ...                                ...                         ...
# 2024-08-26                   -0.000690                   -0.000690
# 2024-08-27                   -0.000899                   -0.000899
# 2024-08-28                   -0.001012                   -0.001012
# 2024-08-29                   -0.001067                   -0.001067
# 2024-08-30                   -0.001030                   -0.001030
#
#             ('APARCH', 'normal', 0)  ('APARCH', 'gaussian', 0)       RSV
# Date
# 2000-02-02                -0.002629                  -0.002629 -0.001329
# 2000-02-03                -0.002632                  -0.002632 -0.001195
# 2000-02-04                -0.001695                  -0.001695 -0.000892
# 2000-02-07                22.959341                  22.959341 -0.000587
# 2000-02-08                 0.002296                   0.002296 -0.000294
# ...                             ...                        ...       ...
# 2024-08-26                -0.000912                  -0.000912  0.000235
# 2024-08-27                -0.001074                  -0.001074 -0.000003
# 2024-08-28                -0.001116                  -0.001116 -0.000249
# 2024-08-29                -0.001080                  -0.001080 -0.000508
# 2024-08-30                -0.000941                  -0.000941 -0.000760
#
# [6184 rows x 14 columns]

# %% [markdown]
# # Split train, validation and test data

# %%
# train_end = datetime(2020, 6, 30)
# test_start = datetime(2020, 10, 1)
# val_size = 0.1

# %%
# target = ['RSV', 'CCV', 'PV', 'GKV', 'RSV', 'YZV', 'GKYZV']
# test_data = data.loc[test_start:]

# train_val = data.loc[:train_end]
# train_data, val_data = train_test_split(train_val, test_size=val_size, shuffle=False)

# X_train = train_data.drop(columns=target)
# y_train = train_data[target]

# X_val = val_data.drop(columns=target)
# y_val = val_data[target]

# X_test = test_data.drop(columns=target)
# y_test = test_data[target]

# X_train = np.array(X_train)
# y_train = np.array(y_train)

# X_val = np.array(X_val)
# y_val = np.array(y_val)

# X_test = np.array(X_test)
# y_test = np.array(y_test)

# %%
def split_data(data, target, train_end =datetime(2022, 5, 30), test_start=datetime(2022, 5, 31), test_size=0.1):
  test_data = data.loc[test_start:]

  train_val = data.loc[:train_end]
  train_data, val_data = train_test_split(train_val, test_size=test_size, shuffle=False)

  X_train = train_data.drop(columns=[target])
  y_train = train_data[target]

  X_val = val_data.drop(columns=[target])
  y_val = val_data[target]

  X_test = test_data.drop(columns=[target])
  y_test = test_data[target]

  return np.array(X_train), np.array(y_train), np.array(X_val), np.array(y_val), np.array(X_test), np.array(y_test)

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(RSV_data, 'RSV')

# %% [markdown]
# # Model

# %%
class BDropout(torch.nn.Dropout):

    """Binary dropout with regularization and resampling.

    See: Gal Y., Ghahramani Z., "Dropout as a Bayesian Approximation:
    Representing Model Uncertainty in Deep Learning", 2016.
    """

    # def __init__(self, rate=0.1, reg=1.0, **kwargs):
    #     """Constructs a BDropout.

    #     Args:
    #         rate (float): Dropout probability.
    #         reg (float): Regularization scale.
    #     """
    #     super(BDropout, self).__init__(**kwargs)
    #     self.register_buffer("rate", torch.tensor(rate))
    #     self.p = 1 - self.rate
    #     self.register_buffer("reg", torch.tensor(reg))
    #     self.register_buffer("noise", torch.bernoulli(self.p))


    def __init__(self, rate=0.1, reg=1.0, **kwargs):
        """Constructs a BDropout.

        Args:
            rate (float): Dropout probability.
            reg (float): Regularization scale.
        """
        super(BDropout, self).__init__(p=rate, **kwargs)
        self.register_buffer("rate", torch.tensor(rate))
        self.p = 1 - self.rate
        self.register_buffer("reg", torch.tensor(reg))
        self.register_buffer("noise", torch.bernoulli(self.p))

    def regularization(self, weight, bias):
        """Computes the regularization cost.

        Args:
            weight (Tensor): Weight tensor.
            bias (Tensor): Bias tensor.

        Returns:
            Regularization cost (Tensor).
        """
        self.p = 1 - self.rate
        weight_reg = self.p * (weight**2).sum()
        bias_reg = (bias**2).sum() if bias is not None else 0
        return self.reg * (weight_reg + bias_reg)

    def resample(self):
        """Resamples the dropout noise."""
        self._update_noise(self.noise)

    def _update_noise(self, x):
        """Updates the dropout noise.

        Args:
            x (Tensor): Input.
        """
        self.p = 1 - self.rate
        self.noise.data = torch.bernoulli(self.p.expand(x.shape))

    def forward(self, x, resample=False, mask_dims=0, **kwargs):
        """Computes the binary dropout.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.
            mask_dims (int): Number of dimensions to sample noise for
                (0 for all).

        Returns:
            Output (Tensor).
        """
        sample_shape = x.shape[-mask_dims:]
        if sample_shape != self.noise.shape:
            sample = x.view(-1, *sample_shape)[0]
            self._update_noise(sample)
        elif resample:
            return x * torch.bernoulli(self.p.expand(x.shape))

        return x * self.noise

    def extra_repr(self):
        """Formats module representation.

        Returns:
            Module representation (str).
        """
        return "rate={}".format(self.rate)

# %%
class CDropout(BDropout):

    """Concrete dropout with regularization and resampling.

    See: Gal Y., Hron, J., Kendall, A. "Concrete Dropout", 2017.
    """

    # def __init__(self, temperature=0.1, rate=0.5, reg=1.0, **kwargs):
    #     """Constructs a CDropout.

    #     Args:
    #         temperature (float): Temperature.
    #         rate (float): Initial dropout rate.
    #         reg (float): Regularization scale.
    #     """
    #     super(CDropout, self).__init__(rate, reg, **kwargs)
    #     self.temperature = Parameter(
    #         torch.tensor(temperature), requires_grad=False)

    #     # We need to constrain p to [0, 1], so we train logit(p).
    #     self.logit_p = Parameter(-torch.log(self.p.reciprocal() - 1.0))

    def __init__(self, temperature=0.1, rate=0.5, reg=1.0, **kwargs):
        """Constructs a CDropout.

        Args:
            temperature (float): Temperature.
            rate (float): Initial dropout rate.
            reg (float): Regularization scale.
        """
        super(CDropout, self).__init__(rate, reg, **kwargs)
        self.temperature = torch.nn.Parameter(
            torch.tensor(temperature), requires_grad=False)

        # We need to constrain p to [0, 1], so we train logit(p).
        self.logit_p = torch.nn.Parameter(-torch.log(self.p.reciprocal() - 1.0))

    def regularization(self, weight, bias):
        """Computes the regularization cost.

        Args:
            weight (Tensor): Weight tensor.
            bias (Tensor): Bias tensor.

        Returns:
            Regularization cost (Tensor).
        """
        self.p.data = self.logit_p.sigmoid()
        reg = super(CDropout, self).regularization(weight, bias)
        reg -= -(1 - self.p) * (1 - self.p).log() - self.p * self.p.log()
        return reg

    def _update_noise(self, x):
        """Updates the dropout noise.

        Args:
            x (Tensor): Input.
        """
        self.noise.data = torch.rand_like(x)

    def forward(self, x, resample=False, mask_dims=0, **kwargs):
        """Computes the concrete dropout.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.
            mask_dims (int): Number of dimensions to sample noise for
                (0 for all).

        Returns:
            Output (Tensor).
        """
        sample_shape = x.shape[-mask_dims:]
        noise = self.noise
        if sample_shape != noise.shape:
            sample = x.view(-1, *sample_shape)[0]
            self._update_noise(sample)
            noise = self.noise
        elif resample:
            noise = torch.rand_like(x)

        self.p.data = self.logit_p.sigmoid()
        concrete_p = self.logit_p + noise.log() - (1 - noise).log()
        concrete_noise = (concrete_p / self.temperature).sigmoid()

        return x * concrete_noise

    def extra_repr(self):
        """Formats module representation.

        Returns:
            Module representation (str).
        """
        return "temperature={}".format(self.temperature)

# %%
class BSequential(torch.nn.Sequential):

    """Extension of Sequential module with regularization and resampling."""

    def resample(self):
        """Resample all child modules."""
        for child in self.children():
            if isinstance(child, BDropout):
                child.resample()

    def regularization(self):
        """Computes the total regularization cost of all child modules.

        Returns:
            Total regularization cost (Tensor).
        """
        reg = torch.tensor(0.0)
        children = list(self._modules.values())
        for i, child in enumerate(children):
            if isinstance(child, BSequential):
                reg += child.regularization()
            elif isinstance(child, BDropout):
                for next_child in children[i:]:
                    if hasattr(next_child, "weight") and hasattr(
                            next_child, "bias"):
                        reg += child.regularization(next_child.weight,
                                                    next_child.bias)
                        break
        return reg

    def forward(self, x, resample=False, **kwargs):
        """Computes the model.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.

        Returns:
            Output (Tensor).
        """
        for module in self._modules.values():
            if isinstance(module, (BDropout, BSequential)):
                x = module(x, resample=resample, **kwargs)
            else:
                x = module(x)
        return x

# %%
def bayesian_model(in_features,
                   out_features,
                   hidden_features,
                   nonlin=nn.ReLU,
                   output_nonlin=None,
                   weight_initializer=partial(
                       nn.init.xavier_normal_,
                       gain=nn.init.calculate_gain("relu")),
                   bias_initializer=partial(
                       nn.init.uniform_, a=-1.0, b=1.0),
                   dropout_layers=CDropout,
                   input_dropout=None):
    """Constructs and initializes a Bayesian neural network with dropout."""
    dims = [in_features] + hidden_features
    if not isinstance(dropout_layers, Iterable):
        dropout_layers = [dropout_layers] * len(hidden_features)

    modules = OrderedDict()

    if inspect.isclass(input_dropout):
        input_dropout = input_dropout()
    if input_dropout is not None:
        modules["drop_in"] = input_dropout

    for i, (din, dout) in enumerate(zip(dims[:-1], dims[1:])):
        drop_i = dropout_layers[i]
        if inspect.isclass(drop_i):
            drop_i = drop_i()

        modules["fc_{}".format(i)] = nn.Linear(din, dout)
        if drop_i is not None:
            modules["drop_{}".format(i)] = drop_i
        modules["nonlin_{}".format(i)] = nonlin()

    modules["fc_out"] = nn.Linear(dims[-1], out_features)
    if output_nonlin is not None:
        modules["nonlin_out"] = output_nonlin()

    def init(module):
        if callable(weight_initializer) and hasattr(module, "weight"):
            weight_initializer(module.weight)
        if callable(bias_initializer) and hasattr(module, "bias"):
            if module.bias is not None:
                bias_initializer(module.bias)

    net = BSequential(modules)
    net.apply(init)

    return net

# %%
# Convert NumPy arrays to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# Early stopping implementation
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_val_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_val_loss is None:
            self.best_val_loss = val_loss
        elif val_loss < self.best_val_loss - self.min_delta:
            self.best_val_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# Define parameter bounds
def parameter_bounds():
    # Number of layers: 1 to 5
    num_layers_bounds = (1, 5)

    # Number of neurons per layer: 10 to 200
    num_neurons_bounds = (10, 200)

    # Dropout rate: 0 to 0.5
    dropout_rate_bounds = (0.0, 0.5)

    # Learning rate: 0.0001 to 0.01
    learning_rate_bounds = (0.0001, 0.01)

    # Number of epochs: 50 to 500
    num_epochs_bounds = (150, 500)

    return num_layers_bounds, num_neurons_bounds, dropout_rate_bounds, learning_rate_bounds, num_epochs_bounds

# %%
def objective_function(params):
    # Unpack parameters from PSO
    num_layers, num_neurons, dropout_rate, learning_rate, num_epochs = params

    # Define the model with the given parameters
    model = bayesian_model(
        in_features=X_train.shape[1],
        out_features=1,
        hidden_features=[int(num_neurons)] * int(num_layers),
        nonlin=nn.ReLU,
        output_nonlin=None,
        dropout_layers=CDropout,
        input_dropout=CDropout(temperature=0.1, rate=dropout_rate, reg=1.0)
    )

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Initialize early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=0.01)

    # Track the best validation loss
    best_val_loss = float('inf')

    # Training loop with the number of epochs specified in the params
    for epoch in range(int(num_epochs)):
        model.train()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Validation phase (after each epoch)
        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val)
            val_loss = criterion(val_outputs, y_val)

        # Check and update the best validation loss
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()

        # Early stopping condition
        early_stopping(val_loss.item())
        if early_stopping.early_stop:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    # Return the best validation loss for PSO optimization
    return best_val_loss

# %%
# Define the bounds for each parameter
def get_bounds():
    num_layers_bounds, num_neurons_bounds, dropout_rate_bounds, learning_rate_bounds, num_epochs_bounds = parameter_bounds()
    return [
        [num_layers_bounds[0], num_neurons_bounds[0], dropout_rate_bounds[0], learning_rate_bounds[0], num_epochs_bounds[0]],
        [num_layers_bounds[1], num_neurons_bounds[1], dropout_rate_bounds[1], learning_rate_bounds[1], num_epochs_bounds[1]]
    ]

# %%
bounds = get_bounds()

# %%
lower_bounds = bounds[0]
upper_bounds = bounds[1]

swarmsize = 20
maxiter = 50

# %%
start_time = time.time()

best_params, best_val = pso(objective_function, lb=lower_bounds, ub=upper_bounds, swarmsize=swarmsize, maxiter=maxiter, debug=True)

end_time = time.time()
execution_time = end_time - start_time
# Out:
# No constraints given.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([5055])) that is different to the input size (torch.Size([5055, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([562])) that is different to the input size (torch.Size([562, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 16
# Early stopping triggered at epoch 91
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 19
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 199
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 69
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 70
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Best after iteration 1: [4.29909478e+00 1.17302335e+02 1.71090139e-01 5.68011191e-03
#  4.62411109e+02] 0.004214318469166756
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 111
# Early stopping triggered at epoch 81
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 11
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 16
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 66
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 40
# Best after iteration 2: [4.29909478e+00 1.17302335e+02 1.71090139e-01 5.68011191e-03
#  4.62411109e+02] 0.004214318469166756
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 84
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 17
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 59
# Best after iteration 3: [4.29909478e+00 1.17302335e+02 1.71090139e-01 5.68011191e-03
#  4.62411109e+02] 0.004214318469166756
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 47
# Best after iteration 4: [4.29909478e+00 1.17302335e+02 1.71090139e-01 5.68011191e-03
#  4.62411109e+02] 0.004214318469166756
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 28
# Best after iteration 5: [4.29909478e+00 1.17302335e+02 1.71090139e-01 5.68011191e-03
#  4.62411109e+02] 0.004214318469166756
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 38
# Best after iteration 6: [4.29909478e+00 1.17302335e+02 1.71090139e-01 5.68011191e-03
#  4.62411109e+02] 0.004214318469166756
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 31
# Best after iteration 7: [4.29909478e+00 1.17302335e+02 1.71090139e-01 5.68011191e-03
#  4.62411109e+02] 0.004214318469166756
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 44
# Best after iteration 8: [4.29909478e+00 1.17302335e+02 1.71090139e-01 5.68011191e-03
#  4.62411109e+02] 0.004214318469166756
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 37
# New best for swarm at iteration 9: [4.30111055e+00 1.13834692e+02 1.99144726e-01 6.13481119e-03
#  4.65601297e+02] 0.003317725844681263
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 32
# Best after iteration 9: [4.30111055e+00 1.13834692e+02 1.99144726e-01 6.13481119e-03
#  4.65601297e+02] 0.003317725844681263
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Best after iteration 10: [4.30111055e+00 1.13834692e+02 1.99144726e-01 6.13481119e-03
#  4.65601297e+02] 0.003317725844681263
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 37
# New best for swarm at iteration 11: [4.04351042e+00 1.14726429e+02 2.72364749e-01 6.57470144e-03
#  4.64133531e+02] 0.0020570603664964437
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 54
# Best after iteration 11: [4.04351042e+00 1.14726429e+02 2.72364749e-01 6.57470144e-03
#  4.64133531e+02] 0.0020570603664964437
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Best after iteration 12: [4.04351042e+00 1.14726429e+02 2.72364749e-01 6.57470144e-03
#  4.64133531e+02] 0.0020570603664964437
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 34
# Best after iteration 13: [4.04351042e+00 1.14726429e+02 2.72364749e-01 6.57470144e-03
#  4.64133531e+02] 0.0020570603664964437
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 63
# Best after iteration 14: [4.04351042e+00 1.14726429e+02 2.72364749e-01 6.57470144e-03
#  4.64133531e+02] 0.0020570603664964437
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 29
# Best after iteration 15: [4.04351042e+00 1.14726429e+02 2.72364749e-01 6.57470144e-03
#  4.64133531e+02] 0.0020570603664964437
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 45
# Best after iteration 16: [4.04351042e+00 1.14726429e+02 2.72364749e-01 6.57470144e-03
#  4.64133531e+02] 0.0020570603664964437
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 33
# New best for swarm at iteration 17: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Best after iteration 17: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 30
# Best after iteration 18: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 36
# Best after iteration 19: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 39
# Best after iteration 20: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 39
# Best after iteration 21: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Best after iteration 22: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 33
# Best after iteration 23: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 27
# Best after iteration 24: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 30
# Best after iteration 25: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 32
# Best after iteration 26: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 41
# Best after iteration 27: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Best after iteration 28: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 49
# Best after iteration 29: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 43
# Best after iteration 30: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Best after iteration 31: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 34
# Best after iteration 32: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 32
# Best after iteration 33: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 31
# Best after iteration 34: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 32
# Best after iteration 35: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 30
# Best after iteration 36: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 52
# Best after iteration 37: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 43
# Best after iteration 38: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 48
# Best after iteration 39: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Best after iteration 40: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 25
# Best after iteration 41: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Best after iteration 42: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 34
# Best after iteration 43: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 34
# Best after iteration 44: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 32
# Best after iteration 45: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Best after iteration 46: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 33
# Best after iteration 47: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 31
# Best after iteration 48: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 49
# Best after iteration 49: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Best after iteration 50: [4.37867129e+00 1.09651456e+02 1.83033473e-01 6.85028804e-03
#  4.70017989e+02] 0.0015411465428769588
# Stopping search: maximum iterations reached --> 50

# %%
execution_time
# Out:
# 11852.970267534256

# %%
best_params
# Out:
# array([4.37867129e+00, 1.09651456e+02, 1.83033473e-01, 6.85028804e-03,
#        4.70017989e+02])

# %%
# Function to train and evaluate the model with given hyperparameters
def train_and_evaluate_model(params):
    n_layers, n_neurons, drop_rate, learning_rate, epochs = params

    # Define the model
    hidden_features = [int(n_neurons)] * int(n_layers)
    model = bayesian_model(
        in_features=X_train.shape[1],
        out_features=1,
        hidden_features=hidden_features,
        dropout_layers=CDropout(rate=drop_rate),  # Dropout layer without partial
    )

    # Define optimizer and loss function
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()

    # Early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

    # Training loop
    for epoch in range(int(epochs)):
        model.train()
        optimizer.zero_grad()

        output = model(X_train)
        loss = criterion(output, y_train)

        loss.backward()
        optimizer.step()

        model.eval()
        val_output = model(X_val)
        val_loss = criterion(val_output, y_val)

        print(f'Epoch {epoch+1}/{int(epochs)}, Loss: {loss.item()}, Val Loss: {val_loss.item()}')

        early_stopping(val_loss.item())
        if early_stopping.early_stop:
            print("Early stopping triggered")
            break

    # Test the model
    model.eval()
    test_output = model(X_test)
    mse = criterion(test_output, y_test)
    rmse = mse ** 0.5
    mae = nn.L1Loss()(y_test, test_output).item()
    mape = torch.mean(torch.abs((y_test - test_output) / y_test)) * 100

    print(f'Test Loss: {mse.item()}')
    print(f'RMSE: {rmse}')
    print(f'MAE: {mae}')
    print(f'MAPE: {mape.item()}%')

    return mse, rmse, mae, mape, test_output

# %%
# best_params = [3.62253629e+00, 1.12321717e+02, 2.77934900e-01, 5.49072091e-03, 2.22486413e+02]

# %%
mse, rmse, mae, mape, test_output = train_and_evaluate_model(best_params)
# Out:
# Epoch 1/470, Loss: 1.3761072158813477, Val Loss: 4.908101558685303
# Epoch 2/470, Loss: 10.054695129394531, Val Loss: 0.444622278213501
# Epoch 3/470, Loss: 0.8301581740379333, Val Loss: 0.7798404097557068
# Epoch 4/470, Loss: 2.3547563552856445, Val Loss: 0.9825190305709839
# Epoch 5/470, Loss: 4.884798049926758, Val Loss: 0.5544611215591431
# Epoch 6/470, Loss: 1.7209726572036743, Val Loss: 0.1862001121044159
# Epoch 7/470, Loss: 1.2061703205108643, Val Loss: 0.1308445781469345
# Epoch 8/470, Loss: 1.6482752561569214, Val Loss: 0.15431243181228638
# Epoch 9/470, Loss: 0.49016156792640686, Val Loss: 0.16888275742530823
# Epoch 10/470, Loss: 0.36672070622444153, Val Loss: 0.12860684096813202
# Epoch 11/470, Loss: 0.33486098051071167, Val Loss: 0.09816625714302063
# Epoch 12/470, Loss: 0.3161258399486542, Val Loss: 0.08292319625616074
# Epoch 13/470, Loss: 0.5548864006996155, Val Loss: 0.07754238694906235
# Epoch 14/470, Loss: 0.5025709867477417, Val Loss: 0.0694836676120758
# Epoch 15/470, Loss: 0.20711730420589447, Val Loss: 0.061650343239307404
# Epoch 16/470, Loss: 0.43140143156051636, Val Loss: 0.06161048263311386
# Epoch 17/470, Loss: 0.09475601464509964, Val Loss: 0.06270384043455124
# Epoch 18/470, Loss: 0.08974280208349228, Val Loss: 0.059773433953523636
# Epoch 19/470, Loss: 0.10114844143390656, Val Loss: 0.056299518793821335
# Epoch 20/470, Loss: 0.10204863548278809, Val Loss: 0.05397086963057518
# Epoch 21/470, Loss: 0.108583003282547, Val Loss: 0.05504553020000458
# Epoch 22/470, Loss: 0.1777772307395935, Val Loss: 0.05136636272072792
