# %%
# !pip install pyswarm
# Out:
# Requirement already satisfied: pyswarm in /usr/local/lib/python3.10/dist-packages (0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyswarm) (1.26.4)

# %%
# from collections import Iterable, OrderedDict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from collections.abc import Iterable
from collections import OrderedDict
from google.colab import drive
from torch.nn import Parameter
from datetime import datetime
from functools import partial
import torch.optim as optim
from pyswarm import pso
import torch.nn as nn
from math import sqrt
import pandas as pd
import numpy as np
import inspect
import torch
import time

# %% [markdown]
# # Load data

# %%
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

# %%
filename = 'YZV_data.csv'
YZV_data = pd.read_csv(path + filename)

# %%
YZV_data.drop(columns=['djia', 'inflation_rate', 'interest_rate', 'gdp_growth', 'usd_eur', 'usd_jpy', 'usd_gbp', 'usd_cny', 'usd_cad','usd_mxn', 'gold', 'vix', 'unemployment_rate'], inplace=True)

# %%
YZV_data
# Out:
#             Date       YZV  ('GARCH', 'normal', 0)  ('GARCH', 'normal', 1)  \
# 0     2000-02-02 -0.098637               -0.001864               -0.001725
# 1     2000-02-03 -0.089867               -0.001554               -0.001557
# 2     2000-02-04 -0.068001               -0.001080               -0.001163
# 3     2000-02-07 -0.045380               -0.000627               -0.000738
# 4     2000-02-08 -0.024180               -0.000202               -0.000335
# ...          ...       ...                     ...                     ...
# 6179  2024-08-26  0.026248               -0.000358               -0.000493
# 6180  2024-08-27  0.006282               -0.000694               -0.000707
# 6181  2024-08-28 -0.015856               -0.000954               -0.000846
# 6182  2024-08-29 -0.040485               -0.001147               -0.000937
# 6183  2024-08-30 -0.065823               -0.001232               -0.000923
#
#       ('GARCH', 'gaussian', 0)  ('GARCH', 'gaussian', 1)  ('GARCH', 'ged', 0)  \
# 0                    -0.001864                 -0.001725            -0.001971
# 1                    -0.001554                 -0.001557            -0.001745
# 2                    -0.001080                 -0.001163            -0.001302
# 3                    -0.000627                 -0.000738            -0.000863
# 4                    -0.000202                 -0.000335            -0.000364
# ...                        ...                       ...                  ...
# 6179                 -0.000358                 -0.000493            -0.001023
# 6180                 -0.000694                 -0.000707            -0.001244
# 6181                 -0.000954                 -0.000846            -0.001311
# 6182                 -0.001147                 -0.000937            -0.001324
# 6183                 -0.001232                 -0.000923            -0.001267
#
#       ('GARCH', 'ged', 1)  ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# 0               -0.001822                 -0.001782                 -0.001782
# 1               -0.001612                 -0.001519                 -0.001519
# 2               -0.001217                 -0.001076                 -0.001076
# 3               -0.000784                 -0.000678                 -0.000678
# 4               -0.000368                 -0.000311                 -0.000311
# ...                   ...                       ...                       ...
# 6179            -0.000502                 -0.000690                 -0.000690
# 6180            -0.000717                 -0.000899                 -0.000899
# 6181            -0.000852                 -0.001012                 -0.001012
# 6182            -0.000933                 -0.001067                 -0.001067
# 6183            -0.000919                 -0.001030                 -0.001030
#
#       ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)
# 0                      -0.001782                   -0.001782
# 1                      -0.001519                   -0.001519
# 2                      -0.001076                   -0.001076
# 3                      -0.000678                   -0.000678
# 4                      -0.000311                   -0.000311
# ...                          ...                         ...
# 6179                   -0.000690                   -0.000690
# 6180                   -0.000899                   -0.000899
# 6181                   -0.001012                   -0.001012
# 6182                   -0.001067                   -0.001067
# 6183                   -0.001030                   -0.001030
#
# [6184 rows x 12 columns]

# %%
set_index(YZV_data)

# %%
tm_data = YZV_data

# %%
YZV_data = YZV_data.drop(columns=['YZV'])

# %%
YZV_data['YZV'] = tm_data['YZV']

# %%
YZV_data
# Out:
#             ('GARCH', 'normal', 0)  ('GARCH', 'normal', 1)  \
# Date
# 2000-02-02               -0.001864               -0.001725
# 2000-02-03               -0.001554               -0.001557
# 2000-02-04               -0.001080               -0.001163
# 2000-02-07               -0.000627               -0.000738
# 2000-02-08               -0.000202               -0.000335
# ...                            ...                     ...
# 2024-08-26               -0.000358               -0.000493
# 2024-08-27               -0.000694               -0.000707
# 2024-08-28               -0.000954               -0.000846
# 2024-08-29               -0.001147               -0.000937
# 2024-08-30               -0.001232               -0.000923
#
#             ('GARCH', 'gaussian', 0)  ('GARCH', 'gaussian', 1)  \
# Date
# 2000-02-02                 -0.001864                 -0.001725
# 2000-02-03                 -0.001554                 -0.001557
# 2000-02-04                 -0.001080                 -0.001163
# 2000-02-07                 -0.000627                 -0.000738
# 2000-02-08                 -0.000202                 -0.000335
# ...                              ...                       ...
# 2024-08-26                 -0.000358                 -0.000493
# 2024-08-27                 -0.000694                 -0.000707
# 2024-08-28                 -0.000954                 -0.000846
# 2024-08-29                 -0.001147                 -0.000937
# 2024-08-30                 -0.001232                 -0.000923
#
#             ('GARCH', 'ged', 0)  ('GARCH', 'ged', 1)  \
# Date
# 2000-02-02            -0.001971            -0.001822
# 2000-02-03            -0.001745            -0.001612
# 2000-02-04            -0.001302            -0.001217
# 2000-02-07            -0.000863            -0.000784
# 2000-02-08            -0.000364            -0.000368
# ...                         ...                  ...
# 2024-08-26            -0.001023            -0.000502
# 2024-08-27            -0.001244            -0.000717
# 2024-08-28            -0.001311            -0.000852
# 2024-08-29            -0.001324            -0.000933
# 2024-08-30            -0.001267            -0.000919
#
#             ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# Date
# 2000-02-02                 -0.001782                 -0.001782
# 2000-02-03                 -0.001519                 -0.001519
# 2000-02-04                 -0.001076                 -0.001076
# 2000-02-07                 -0.000678                 -0.000678
# 2000-02-08                 -0.000311                 -0.000311
# ...                              ...                       ...
# 2024-08-26                 -0.000690                 -0.000690
# 2024-08-27                 -0.000899                 -0.000899
# 2024-08-28                 -0.001012                 -0.001012
# 2024-08-29                 -0.001067                 -0.001067
# 2024-08-30                 -0.001030                 -0.001030
#
#             ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)       YZV
# Date
# 2000-02-02                   -0.001782                   -0.001782 -0.098637
# 2000-02-03                   -0.001519                   -0.001519 -0.089867
# 2000-02-04                   -0.001076                   -0.001076 -0.068001
# 2000-02-07                   -0.000678                   -0.000678 -0.045380
# 2000-02-08                   -0.000311                   -0.000311 -0.024180
# ...                                ...                         ...       ...
# 2024-08-26                   -0.000690                   -0.000690  0.026248
# 2024-08-27                   -0.000899                   -0.000899  0.006282
# 2024-08-28                   -0.001012                   -0.001012 -0.015856
# 2024-08-29                   -0.001067                   -0.001067 -0.040485
# 2024-08-30                   -0.001030                   -0.001030 -0.065823
#
# [6184 rows x 11 columns]

# %% [markdown]
# # Split train, validation and test data

# %%
# train_end = datetime(2020, 6, 30)
# test_start = datetime(2020, 10, 1)
# val_size = 0.1

# %%
# target = ['YZV', 'CCV', 'PV', 'GKV', 'RSV', 'YZV', 'GKYZV']
# test_data = data.loc[test_start:]

# train_val = data.loc[:train_end]
# train_data, val_data = train_test_split(train_val, test_size=val_size, shuffle=False)

# X_train = train_data.drop(columns=target)
# y_train = train_data[target]

# X_val = val_data.drop(columns=target)
# y_val = val_data[target]

# X_test = test_data.drop(columns=target)
# y_test = test_data[target]

# X_train = np.array(X_train)
# y_train = np.array(y_train)

# X_val = np.array(X_val)
# y_val = np.array(y_val)

# X_test = np.array(X_test)
# y_test = np.array(y_test)

# %%
def split_data(data, target, train_end =datetime(2022, 5, 30), test_start=datetime(2022, 5, 31), test_size=0.1):
  test_data = data.loc[test_start:]

  train_val = data.loc[:train_end]
  train_data, val_data = train_test_split(train_val, test_size=test_size, shuffle=False)

  X_train = train_data.drop(columns=[target])
  y_train = train_data[target]

  X_val = val_data.drop(columns=[target])
  y_val = val_data[target]

  X_test = test_data.drop(columns=[target])
  y_test = test_data[target]

  return np.array(X_train), np.array(y_train), np.array(X_val), np.array(y_val), np.array(X_test), np.array(y_test)

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(YZV_data, 'YZV')

# %% [markdown]
# # Model

# %%
class BDropout(torch.nn.Dropout):

    """Binary dropout with regularization and resampling.

    See: Gal Y., Ghahramani Z., "Dropout as a Bayesian Approximation:
    Representing Model Uncertainty in Deep Learning", 2016.
    """

    # def __init__(self, rate=0.1, reg=1.0, **kwargs):
    #     """Constructs a BDropout.

    #     Args:
    #         rate (float): Dropout probability.
    #         reg (float): Regularization scale.
    #     """
    #     super(BDropout, self).__init__(**kwargs)
    #     self.register_buffer("rate", torch.tensor(rate))
    #     self.p = 1 - self.rate
    #     self.register_buffer("reg", torch.tensor(reg))
    #     self.register_buffer("noise", torch.bernoulli(self.p))


    def __init__(self, rate=0.1, reg=1.0, **kwargs):
        """Constructs a BDropout.

        Args:
            rate (float): Dropout probability.
            reg (float): Regularization scale.
        """
        super(BDropout, self).__init__(p=rate, **kwargs)
        self.register_buffer("rate", torch.tensor(rate))
        self.p = 1 - self.rate
        self.register_buffer("reg", torch.tensor(reg))
        self.register_buffer("noise", torch.bernoulli(self.p))

    def regularization(self, weight, bias):
        """Computes the regularization cost.

        Args:
            weight (Tensor): Weight tensor.
            bias (Tensor): Bias tensor.

        Returns:
            Regularization cost (Tensor).
        """
        self.p = 1 - self.rate
        weight_reg = self.p * (weight**2).sum()
        bias_reg = (bias**2).sum() if bias is not None else 0
        return self.reg * (weight_reg + bias_reg)

    def resample(self):
        """Resamples the dropout noise."""
        self._update_noise(self.noise)

    def _update_noise(self, x):
        """Updates the dropout noise.

        Args:
            x (Tensor): Input.
        """
        self.p = 1 - self.rate
        self.noise.data = torch.bernoulli(self.p.expand(x.shape))

    def forward(self, x, resample=False, mask_dims=0, **kwargs):
        """Computes the binary dropout.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.
            mask_dims (int): Number of dimensions to sample noise for
                (0 for all).

        Returns:
            Output (Tensor).
        """
        sample_shape = x.shape[-mask_dims:]
        if sample_shape != self.noise.shape:
            sample = x.view(-1, *sample_shape)[0]
            self._update_noise(sample)
        elif resample:
            return x * torch.bernoulli(self.p.expand(x.shape))

        return x * self.noise

    def extra_repr(self):
        """Formats module representation.

        Returns:
            Module representation (str).
        """
        return "rate={}".format(self.rate)

# %%
class CDropout(BDropout):

    """Concrete dropout with regularization and resampling.

    See: Gal Y., Hron, J., Kendall, A. "Concrete Dropout", 2017.
    """

    # def __init__(self, temperature=0.1, rate=0.5, reg=1.0, **kwargs):
    #     """Constructs a CDropout.

    #     Args:
    #         temperature (float): Temperature.
    #         rate (float): Initial dropout rate.
    #         reg (float): Regularization scale.
    #     """
    #     super(CDropout, self).__init__(rate, reg, **kwargs)
    #     self.temperature = Parameter(
    #         torch.tensor(temperature), requires_grad=False)

    #     # We need to constrain p to [0, 1], so we train logit(p).
    #     self.logit_p = Parameter(-torch.log(self.p.reciprocal() - 1.0))

    def __init__(self, temperature=0.1, rate=0.5, reg=1.0, **kwargs):
        """Constructs a CDropout.

        Args:
            temperature (float): Temperature.
            rate (float): Initial dropout rate.
            reg (float): Regularization scale.
        """
        super(CDropout, self).__init__(rate, reg, **kwargs)
        self.temperature = torch.nn.Parameter(
            torch.tensor(temperature), requires_grad=False)

        # We need to constrain p to [0, 1], so we train logit(p).
        self.logit_p = torch.nn.Parameter(-torch.log(self.p.reciprocal() - 1.0))

    def regularization(self, weight, bias):
        """Computes the regularization cost.

        Args:
            weight (Tensor): Weight tensor.
            bias (Tensor): Bias tensor.

        Returns:
            Regularization cost (Tensor).
        """
        self.p.data = self.logit_p.sigmoid()
        reg = super(CDropout, self).regularization(weight, bias)
        reg -= -(1 - self.p) * (1 - self.p).log() - self.p * self.p.log()
        return reg

    def _update_noise(self, x):
        """Updates the dropout noise.

        Args:
            x (Tensor): Input.
        """
        self.noise.data = torch.rand_like(x)

    def forward(self, x, resample=False, mask_dims=0, **kwargs):
        """Computes the concrete dropout.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.
            mask_dims (int): Number of dimensions to sample noise for
                (0 for all).

        Returns:
            Output (Tensor).
        """
        sample_shape = x.shape[-mask_dims:]
        noise = self.noise
        if sample_shape != noise.shape:
            sample = x.view(-1, *sample_shape)[0]
            self._update_noise(sample)
            noise = self.noise
        elif resample:
            noise = torch.rand_like(x)

        self.p.data = self.logit_p.sigmoid()
        concrete_p = self.logit_p + noise.log() - (1 - noise).log()
        concrete_noise = (concrete_p / self.temperature).sigmoid()

        return x * concrete_noise

    def extra_repr(self):
        """Formats module representation.

        Returns:
            Module representation (str).
        """
        return "temperature={}".format(self.temperature)

# %%
class BSequential(torch.nn.Sequential):

    """Extension of Sequential module with regularization and resampling."""

    def resample(self):
        """Resample all child modules."""
        for child in self.children():
            if isinstance(child, BDropout):
                child.resample()

    def regularization(self):
        """Computes the total regularization cost of all child modules.

        Returns:
            Total regularization cost (Tensor).
        """
        reg = torch.tensor(0.0)
        children = list(self._modules.values())
        for i, child in enumerate(children):
            if isinstance(child, BSequential):
                reg += child.regularization()
            elif isinstance(child, BDropout):
                for next_child in children[i:]:
                    if hasattr(next_child, "weight") and hasattr(
                            next_child, "bias"):
                        reg += child.regularization(next_child.weight,
                                                    next_child.bias)
                        break
        return reg

    def forward(self, x, resample=False, **kwargs):
        """Computes the model.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.

        Returns:
            Output (Tensor).
        """
        for module in self._modules.values():
            if isinstance(module, (BDropout, BSequential)):
                x = module(x, resample=resample, **kwargs)
            else:
                x = module(x)
        return x

# %%
def bayesian_model(in_features,
                   out_features,
                   hidden_features,
                   nonlin=nn.ReLU,
                   output_nonlin=None,
                   weight_initializer=partial(
                       nn.init.xavier_normal_,
                       gain=nn.init.calculate_gain("relu")),
                   bias_initializer=partial(
                       nn.init.uniform_, a=-1.0, b=1.0),
                   dropout_layers=CDropout,
                   input_dropout=None):
    """Constructs and initializes a Bayesian neural network with dropout."""
    dims = [in_features] + hidden_features
    if not isinstance(dropout_layers, Iterable):
        dropout_layers = [dropout_layers] * len(hidden_features)

    modules = OrderedDict()

    if inspect.isclass(input_dropout):
        input_dropout = input_dropout()
    if input_dropout is not None:
        modules["drop_in"] = input_dropout

    for i, (din, dout) in enumerate(zip(dims[:-1], dims[1:])):
        drop_i = dropout_layers[i]
        if inspect.isclass(drop_i):
            drop_i = drop_i()

        modules["fc_{}".format(i)] = nn.Linear(din, dout)
        if drop_i is not None:
            modules["drop_{}".format(i)] = drop_i
        modules["nonlin_{}".format(i)] = nonlin()

    modules["fc_out"] = nn.Linear(dims[-1], out_features)
    if output_nonlin is not None:
        modules["nonlin_out"] = output_nonlin()

    def init(module):
        if callable(weight_initializer) and hasattr(module, "weight"):
            weight_initializer(module.weight)
        if callable(bias_initializer) and hasattr(module, "bias"):
            if module.bias is not None:
                bias_initializer(module.bias)

    net = BSequential(modules)
    net.apply(init)

    return net

# %%
# Convert NumPy arrays to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# Early stopping implementation
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_val_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_val_loss is None:
            self.best_val_loss = val_loss
        elif val_loss < self.best_val_loss - self.min_delta:
            self.best_val_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# Define parameter bounds
def parameter_bounds():
    # Number of layers: 1 to 5
    num_layers_bounds = (1, 5)

    # Number of neurons per layer: 10 to 200
    num_neurons_bounds = (10, 200)

    # Dropout rate: 0 to 0.5
    dropout_rate_bounds = (0.0, 0.5)

    # Learning rate: 0.0001 to 0.01
    learning_rate_bounds = (0.0001, 0.01)

    # Number of epochs: 50 to 500
    num_epochs_bounds = (150, 500)

    return num_layers_bounds, num_neurons_bounds, dropout_rate_bounds, learning_rate_bounds, num_epochs_bounds

# %%
def objective_function(params):
    # Unpack parameters from PSO
    num_layers, num_neurons, dropout_rate, learning_rate, num_epochs = params

    # Define the model with the given parameters
    model = bayesian_model(
        in_features=X_train.shape[1],
        out_features=1,
        hidden_features=[int(num_neurons)] * int(num_layers),
        nonlin=nn.ReLU,
        output_nonlin=None,
        dropout_layers=CDropout,
        input_dropout=CDropout(temperature=0.1, rate=dropout_rate, reg=1.0)
    )

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Initialize early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=0.01)

    # Track the best validation loss
    best_val_loss = float('inf')

    # Training loop with the number of epochs specified in the params
    for epoch in range(int(num_epochs)):
        model.train()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Validation phase (after each epoch)
        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val)
            val_loss = criterion(val_outputs, y_val)

        # Check and update the best validation loss
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()

        # Early stopping condition
        early_stopping(val_loss.item())
        if early_stopping.early_stop:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    # Return the best validation loss for PSO optimization
    return best_val_loss

# %%
# Define the bounds for each parameter
def get_bounds():
    num_layers_bounds, num_neurons_bounds, dropout_rate_bounds, learning_rate_bounds, num_epochs_bounds = parameter_bounds()
    return [
        [num_layers_bounds[0], num_neurons_bounds[0], dropout_rate_bounds[0], learning_rate_bounds[0], num_epochs_bounds[0]],
        [num_layers_bounds[1], num_neurons_bounds[1], dropout_rate_bounds[1], learning_rate_bounds[1], num_epochs_bounds[1]]
    ]

# %%
bounds = get_bounds()

# %%
lower_bounds = bounds[0]
upper_bounds = bounds[1]

swarmsize = 20
maxiter = 50

# %%
start_time = time.time()

best_params, best_val = pso(objective_function, lb=lower_bounds, ub=upper_bounds, swarmsize=swarmsize, maxiter=maxiter, debug=True)

end_time = time.time()
execution_time = end_time - start_time
# Out:
# No constraints given.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([5055])) that is different to the input size (torch.Size([5055, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([562])) that is different to the input size (torch.Size([562, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Early stopping triggered at epoch 71
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 68
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 94
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 77
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 18
# Early stopping triggered at epoch 88
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 41
# Best after iteration 1: [4.90706675e+00 1.69776022e+02 3.38068097e-01 1.80313388e-03
#  2.53900504e+02] 0.0013772944221273065
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 82
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 83
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 18
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 27
# Best after iteration 2: [4.90706675e+00 1.69776022e+02 3.38068097e-01 1.80313388e-03
#  2.53900504e+02] 0.0013772944221273065
# Early stopping triggered at epoch 67
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 68
# Early stopping triggered at epoch 68
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 15
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 25
# Best after iteration 3: [4.90706675e+00 1.69776022e+02 3.38068097e-01 1.80313388e-03
#  2.53900504e+02] 0.0013772944221273065
# Early stopping triggered at epoch 92
# Early stopping triggered at epoch 69
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 66
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 24
# New best for swarm at iteration 4: [4.07231636e+00 1.37963976e+02 3.49444526e-01 4.94778122e-03
#  3.50475559e+02] 0.0010150272864848375
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 32
# Best after iteration 4: [4.07231636e+00 1.37963976e+02 3.49444526e-01 4.94778122e-03
#  3.50475559e+02] 0.0010150272864848375
# Early stopping triggered at epoch 73
# Early stopping triggered at epoch 68
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 22
# New best for swarm at iteration 5: [3.97006891e+00 1.61138611e+02 4.00609692e-01 3.18853724e-03
#  2.32509520e+02] 0.0007910430431365967
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 67
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 43
# Best after iteration 5: [3.97006891e+00 1.61138611e+02 4.00609692e-01 3.18853724e-03
#  2.32509520e+02] 0.0007910430431365967
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 84
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 41
# Best after iteration 6: [3.97006891e+00 1.61138611e+02 4.00609692e-01 3.18853724e-03
#  2.32509520e+02] 0.0007910430431365967
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 49
# Best after iteration 7: [3.97006891e+00 1.61138611e+02 4.00609692e-01 3.18853724e-03
#  2.32509520e+02] 0.0007910430431365967
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 49
# Best after iteration 8: [3.97006891e+00 1.61138611e+02 4.00609692e-01 3.18853724e-03
#  2.32509520e+02] 0.0007910430431365967
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 48
# Best after iteration 9: [3.97006891e+00 1.61138611e+02 4.00609692e-01 3.18853724e-03
#  2.32509520e+02] 0.0007910430431365967
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 25
# New best for swarm at iteration 10: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Best after iteration 10: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 45
# Best after iteration 11: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Best after iteration 12: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 42
# Best after iteration 13: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Best after iteration 14: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Best after iteration 15: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 47
# Best after iteration 16: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 39
# Best after iteration 17: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 33
# Best after iteration 18: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 43
# Best after iteration 19: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 73
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 49
# Best after iteration 20: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 47
# Best after iteration 21: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 43
# Best after iteration 22: [3.90334089e+00 1.47309950e+02 3.44963177e-01 6.10180099e-03
#  2.86032822e+02] 0.0007267010514624417
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 26
# New best for swarm at iteration 23: [3.71654729e+00 1.20860440e+02 2.87507204e-01 5.21619010e-03
#  3.18780009e+02] 0.0006119838799349964
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 35
# Best after iteration 23: [3.71654729e+00 1.20860440e+02 2.87507204e-01 5.21619010e-03
#  3.18780009e+02] 0.0006119838799349964
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 46
# Best after iteration 24: [3.71654729e+00 1.20860440e+02 2.87507204e-01 5.21619010e-03
#  3.18780009e+02] 0.0006119838799349964
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 34
# Best after iteration 25: [3.71654729e+00 1.20860440e+02 2.87507204e-01 5.21619010e-03
#  3.18780009e+02] 0.0006119838799349964
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 68
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 43
# Best after iteration 26: [3.71654729e+00 1.20860440e+02 2.87507204e-01 5.21619010e-03
#  3.18780009e+02] 0.0006119838799349964
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 35
# Best after iteration 27: [3.71654729e+00 1.20860440e+02 2.87507204e-01 5.21619010e-03
#  3.18780009e+02] 0.0006119838799349964
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 74
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 47
# Best after iteration 28: [3.71654729e+00 1.20860440e+02 2.87507204e-01 5.21619010e-03
#  3.18780009e+02] 0.0006119838799349964
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 23
# Best after iteration 29: [3.71654729e+00 1.20860440e+02 2.87507204e-01 5.21619010e-03
#  3.18780009e+02] 0.0006119838799349964
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 21
# New best for swarm at iteration 30: [3.86526036e+00 1.31219639e+02 3.14766861e-01 5.15110965e-03
#  3.28994071e+02] 0.0005108754266984761
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 51
# Best after iteration 30: [3.86526036e+00 1.31219639e+02 3.14766861e-01 5.15110965e-03
#  3.28994071e+02] 0.0005108754266984761
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 50
# Best after iteration 31: [3.86526036e+00 1.31219639e+02 3.14766861e-01 5.15110965e-03
#  3.28994071e+02] 0.0005108754266984761
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 43
# Best after iteration 32: [3.86526036e+00 1.31219639e+02 3.14766861e-01 5.15110965e-03
#  3.28994071e+02] 0.0005108754266984761
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Best after iteration 33: [3.86526036e+00 1.31219639e+02 3.14766861e-01 5.15110965e-03
#  3.28994071e+02] 0.0005108754266984761
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 50
# Best after iteration 34: [3.86526036e+00 1.31219639e+02 3.14766861e-01 5.15110965e-03
#  3.28994071e+02] 0.0005108754266984761
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 33
# Best after iteration 35: [3.86526036e+00 1.31219639e+02 3.14766861e-01 5.15110965e-03
#  3.28994071e+02] 0.0005108754266984761
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 39
# Best after iteration 36: [3.86526036e+00 1.31219639e+02 3.14766861e-01 5.15110965e-03
#  3.28994071e+02] 0.0005108754266984761
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Best after iteration 37: [3.86526036e+00 1.31219639e+02 3.14766861e-01 5.15110965e-03
#  3.28994071e+02] 0.0005108754266984761
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 28
# New best for swarm at iteration 38: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Best after iteration 38: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 45
# Best after iteration 39: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Best after iteration 40: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 80
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 41
# Best after iteration 41: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 51
# Best after iteration 42: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Best after iteration 43: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 46
# Best after iteration 44: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 37
# Best after iteration 45: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 23
# Best after iteration 46: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 42
# Best after iteration 47: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Best after iteration 48: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 53
# Best after iteration 49: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 42
# Best after iteration 50: [4.44799288e+00 1.51696719e+02 3.24122973e-01 3.88300486e-03
#  2.83091172e+02] 0.000285623682430014
# Stopping search: maximum iterations reached --> 50

# %%
execution_time
# Out:
# 17292.44191622734

# %%
best_params
# Out:
# array([4.44799288e+00, 1.51696719e+02, 3.24122973e-01, 3.88300486e-03,
#        2.83091172e+02])

# %%
# Function to train and evaluate the model with given hyperparameters
def train_and_evaluate_model(params):
    n_layers, n_neurons, drop_rate, learning_rate, epochs = params

    # Define the model
    hidden_features = [int(n_neurons)] * int(n_layers)
    model = bayesian_model(
        in_features=X_train.shape[1],
        out_features=1,
        hidden_features=hidden_features,
        dropout_layers=CDropout(rate=drop_rate),  # Dropout layer without partial
    )

    # Define optimizer and loss function
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()

    # Early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

    # Training loop
    for epoch in range(int(epochs)):
        model.train()
        optimizer.zero_grad()

        output = model(X_train)
        loss = criterion(output, y_train)

        loss.backward()
        optimizer.step()

        model.eval()
        val_output = model(X_val)
        val_loss = criterion(val_output, y_val)

        print(f'Epoch {epoch+1}/{int(epochs)}, Loss: {loss.item()}, Val Loss: {val_loss.item()}')

        early_stopping(val_loss.item())
        if early_stopping.early_stop:
            print("Early stopping triggered")
            break

    # Test the model
    model.eval()
    test_output = model(X_test)
    mse = criterion(test_output, y_test)
    rmse = mse ** 0.5
    mae = nn.L1Loss()(y_test, test_output).item()
    mape = torch.mean(torch.abs((y_test - test_output) / y_test)) * 100

    print(f'Test Loss: {mse.item()}')
    print(f'RMSE: {rmse}')
    print(f'MAE: {mae}')
    print(f'MAPE: {mape.item()}%')

    return mse, rmse, mae, mape, test_output

# %%
# best_params = [3.62253629e+00, 1.12321717e+02, 2.77934900e-01, 5.49072091e-03, 2.22486413e+02]

# %%
mse, rmse, mae, mape, test_output = train_and_evaluate_model(best_params)
# Out:
# Epoch 1/283, Loss: 0.6641771793365479, Val Loss: 2.04860520362854
# Epoch 2/283, Loss: 1.9479018449783325, Val Loss: 0.6375886797904968
# Epoch 3/283, Loss: 0.6662852168083191, Val Loss: 0.32929855585098267
# Epoch 4/283, Loss: 0.28505536913871765, Val Loss: 0.6101438999176025
# Epoch 5/283, Loss: 0.5792056322097778, Val Loss: 0.6350454092025757
# Epoch 6/283, Loss: 0.6176449656486511, Val Loss: 0.4290148913860321
# Epoch 7/283, Loss: 0.4216378927230835, Val Loss: 0.21576237678527832
# Epoch 8/283, Loss: 0.237169086933136, Val Loss: 0.13177143037319183
# Epoch 9/283, Loss: 0.1315271258354187, Val Loss: 0.13917145133018494
# Epoch 10/283, Loss: 0.13490962982177734, Val Loss: 0.1815287321805954
# Epoch 11/283, Loss: 0.16703735291957855, Val Loss: 0.2017950564622879
# Epoch 12/283, Loss: 0.1995099037885666, Val Loss: 0.207916721701622
# Epoch 13/283, Loss: 0.1977408081293106, Val Loss: 0.1520969569683075
# Epoch 14/283, Loss: 0.16329161822795868, Val Loss: 0.1284564584493637
# Epoch 15/283, Loss: 0.13011421263217926, Val Loss: 0.09503966569900513
# Epoch 16/283, Loss: 0.09749734401702881, Val Loss: 0.0790090337395668
# Epoch 17/283, Loss: 0.08481718599796295, Val Loss: 0.07365597784519196
# Epoch 18/283, Loss: 0.07467126101255417, Val Loss: 0.07782388478517532
# Epoch 19/283, Loss: 0.08085497468709946, Val Loss: 0.09170610457658768
# Epoch 20/283, Loss: 0.08773244172334671, Val Loss: 0.09313894808292389
# Epoch 21/283, Loss: 0.09163228422403336, Val Loss: 0.09973131120204926
# Epoch 22/283, Loss: 0.0880926176905632, Val Loss: 0.09178739041090012
# Epoch 23/283, Loss: 0.08154517412185669, Val Loss: 0.07152580469846725
# Epoch 24/283, Loss: 0.07187860459089279, Val Loss: 0.061155758798122406
# Epoch 25/283, Loss: 0.06254376471042633, Val Loss: 0.05359844118356705
# Epoch 26/283, Loss: 0.05334936082363129, Val Loss: 0.04999741166830063
# Epoch 27/283, Loss: 0.050894010812044144, Val Loss: 0.05043390020728111
# Epoch 28/283, Loss: 0.04967709630727768, Val Loss: 0.049377065151929855
# Epoch 29/283, Loss: 0.04879172146320343, Val Loss: 0.049791865050792694
# Epoch 30/283, Loss: 0.05052842199802399, Val Loss: 0.05489322543144226
# Epoch 31/283, Loss: 0.051071904599666595, Val Loss: 0.0519588440656662
# Epoch 32/283, Loss: 0.04677267372608185, Val Loss: 0.04301438480615616
# Epoch 33/283, Loss: 0.0435250885784626, Val Loss: 0.0376310832798481
# Epoch 34/283, Loss: 0.03935560956597328, Val Loss: 0.03829771652817726
# Epoch 35/283, Loss: 0.037650901824235916, Val Loss: 0.03276413306593895
# Epoch 36/283, Loss: 0.03565575182437897, Val Loss: 0.03702741116285324
# Epoch 37/283, Loss: 0.035653915256261826, Val Loss: 0.035458728671073914
# Epoch 38/283, Loss: 0.03697165474295616, Val Loss: 0.03523189201951027
# Epoch 39/283, Loss: 0.034643612802028656, Val Loss: 0.03324296325445175
# Epoch 40/283, Loss: 0.03281833976507187, Val Loss: 0.031189732253551483
# Epoch 41/283, Loss: 0.030068693682551384, Val Loss: 0.028277285397052765
# Epoch 42/283, Loss: 0.028430534526705742, Val Loss: 0.027313850820064545
# Epoch 43/283, Loss: 0.026914382353425026, Val Loss: 0.023455385118722916
# Epoch 44/283, Loss: 0.026220055297017097, Val Loss: 0.025235742330551147
# Epoch 45/283, Loss: 0.025400234386324883, Val Loss: 0.02554178796708584
# Epoch 46/283, Loss: 0.02513931132853031, Val Loss: 0.024050725623965263
# Epoch 47/283, Loss: 0.024113710969686508, Val Loss: 0.02038046531379223
# Epoch 48/283, Loss: 0.022463317960500717, Val Loss: 0.02191944606602192
# Epoch 49/283, Loss: 0.020719004794955254, Val Loss: 0.02095797471702099
# Epoch 50/283, Loss: 0.020633822306990623, Val Loss: 0.01760730892419815
# Epoch 51/283, Loss: 0.019292734563350677, Val Loss: 0.02075992152094841
# Epoch 52/283, Loss: 0.018400395289063454, Val Loss: 0.016559479758143425
# Epoch 53/283, Loss: 0.01741854101419449, Val Loss: 0.015093175694346428
# Epoch 54/283, Loss: 0.016704345121979713, Val Loss: 0.016580816358327866
# Epoch 55/283, Loss: 0.015462761744856834, Val Loss: 0.014547458849847317
# Epoch 56/283, Loss: 0.01432744599878788, Val Loss: 0.013861587271094322
# Epoch 57/283, Loss: 0.013942078687250614, Val Loss: 0.014178137294948101
# Epoch 58/283, Loss: 0.012724150903522968, Val Loss: 0.011834817007184029
# Epoch 59/283, Loss: 0.011962086893618107, Val Loss: 0.011557447724044323
# Epoch 60/283, Loss: 0.011548931710422039, Val Loss: 0.011560467071831226
# Epoch 61/283, Loss: 0.010690517723560333, Val Loss: 0.009812124073505402
# Epoch 62/283, Loss: 0.010534645989537239, Val Loss: 0.010005059652030468
# Epoch 63/283, Loss: 0.010009288787841797, Val Loss: 0.00968227069824934
# Epoch 64/283, Loss: 0.009747087955474854, Val Loss: 0.009261511266231537
# Epoch 65/283, Loss: 0.009186254814267159, Val Loss: 0.008655195124447346
# Epoch 66/283, Loss: 0.008906575851142406, Val Loss: 0.007702802773565054
# Epoch 67/283, Loss: 0.007788489107042551, Val Loss: 0.006968683563172817
# Epoch 68/283, Loss: 0.007122057490050793, Val Loss: 0.007532360963523388
# Epoch 69/283, Loss: 0.007054625079035759, Val Loss: 0.007279848214238882
# Epoch 70/283, Loss: 0.006766425911337137, Val Loss: 0.006893897894769907
# Epoch 71/283, Loss: 0.006395832635462284, Val Loss: 0.0062529887072741985
# Epoch 72/283, Loss: 0.0064299507066607475, Val Loss: 0.0058874101378023624
# Epoch 73/283, Loss: 0.006139469798654318, Val Loss: 0.005488977767527103
# Epoch 74/283, Loss: 0.005567642860114574, Val Loss: 0.005757107865065336
# Epoch 75/283, Loss: 0.005274378694593906, Val Loss: 0.0049174074083566666
# Epoch 76/283, Loss: 0.005027791950851679, Val Loss: 0.005039651412516832
# Epoch 77/283, Loss: 0.005048819817602634, Val Loss: 0.004465529695153236
# Epoch 78/283, Loss: 0.004637047182768583, Val Loss: 0.004359042271971703
# Epoch 79/283, Loss: 0.004229279700666666, Val Loss: 0.003773618023842573
# Epoch 80/283, Loss: 0.0041926088742911816, Val Loss: 0.0037982328794896603
# Epoch 81/283, Loss: 0.0040312702767550945, Val Loss: 0.0035511506721377373
# Epoch 82/283, Loss: 0.003971095196902752, Val Loss: 0.0045454660430550575
# Epoch 83/283, Loss: 0.0034796379040926695, Val Loss: 0.003994856495410204
# Epoch 84/283, Loss: 0.0034567315597087145, Val Loss: 0.0029229214414954185
# Epoch 85/283, Loss: 0.0034397311974316835, Val Loss: 0.0032402081415057182
# Epoch 86/283, Loss: 0.0031844775658100843, Val Loss: 0.002896876074373722
# Epoch 87/283, Loss: 0.0027186491061002016, Val Loss: 0.002769083483144641
# Epoch 88/283, Loss: 0.0027922193985432386, Val Loss: 0.00228310190141201
# Epoch 89/283, Loss: 0.002704250393435359, Val Loss: 0.002499206457287073
# Epoch 90/283, Loss: 0.002395523712038994, Val Loss: 0.002563030691817403
# Epoch 91/283, Loss: 0.002312376396730542, Val Loss: 0.002569196280092001
# Epoch 92/283, Loss: 0.0022145372349768877, Val Loss: 0.0018821373814716935
# Epoch 93/283, Loss: 0.002099159173667431, Val Loss: 0.001865060767158866
# Epoch 94/283, Loss: 0.002028913237154484, Val Loss: 0.0015730777522549033
# Epoch 95/283, Loss: 0.0018545257626101375, Val Loss: 0.001966888550668955
# Epoch 96/283, Loss: 0.0016782990423962474, Val Loss: 0.0015538380248472095
# Epoch 97/283, Loss: 0.001642747432924807, Val Loss: 0.0016944087110459805
# Epoch 98/283, Loss: 0.0016320452559739351, Val Loss: 0.0015208275290206075
# Epoch 99/283, Loss: 0.0014795945025980473, Val Loss: 0.0012817136012017727
# Epoch 100/283, Loss: 0.0014448161236941814, Val Loss: 0.0013892860151827335
# Epoch 101/283, Loss: 0.0013938163174316287, Val Loss: 0.001270972192287445
# Epoch 102/283, Loss: 0.001272994326427579, Val Loss: 0.0013296966208145022
# Epoch 103/283, Loss: 0.0011292984709143639, Val Loss: 0.0012070504017174244
# Epoch 104/283, Loss: 0.0011092845816165209, Val Loss: 0.0011355363531038165
# Epoch 105/283, Loss: 0.0011127564357593656, Val Loss: 0.0010541389929130673
# Epoch 106/283, Loss: 0.0011136187240481377, Val Loss: 0.0008772233850322664
# Epoch 107/283, Loss: 0.0010736266849562526, Val Loss: 0.0009789739269763231
# Epoch 108/283, Loss: 0.0009603466605767608, Val Loss: 0.0008301816997118294
# Epoch 109/283, Loss: 0.000966799387242645, Val Loss: 0.0008143599261529744
# Epoch 110/283, Loss: 0.0009039498399943113, Val Loss: 0.0009008444030769169
# Epoch 111/283, Loss: 0.0009331534383818507, Val Loss: 0.0007957792840898037
# Epoch 112/283, Loss: 0.0008663877961225808, Val Loss: 0.0008986546890810132
# Epoch 113/283, Loss: 0.0008241800824180245, Val Loss: 0.0009334280621260405
# Epoch 114/283, Loss: 0.0008757411851547658, Val Loss: 0.0007974116015248001
# Epoch 115/283, Loss: 0.0008621534216217697, Val Loss: 0.000841714849229902
# Epoch 116/283, Loss: 0.0008283525821752846, Val Loss: 0.0007481701904907823
# Epoch 117/283, Loss: 0.0007632721099071205, Val Loss: 0.0008006580173969269
# Epoch 118/283, Loss: 0.0007380451424978673, Val Loss: 0.0006853388622403145
# Epoch 119/283, Loss: 0.0006947824731469154, Val Loss: 0.0007057754555717111
# Epoch 120/283, Loss: 0.0007516609621234238, Val Loss: 0.0006996550946496427
# Epoch 121/283, Loss: 0.0006652684533037245, Val Loss: 0.0006153635331429541
# Epoch 122/283, Loss: 0.0006992139387875795, Val Loss: 0.0006447487976402044
# Epoch 123/283, Loss: 0.0006694422336295247, Val Loss: 0.0006861762376502156
# Epoch 124/283, Loss: 0.0006333726341836154, Val Loss: 0.0006446038605645299
# Epoch 125/283, Loss: 0.0006445139297284186, Val Loss: 0.0006403242005035281
# Epoch 126/283, Loss: 0.0006249086000025272, Val Loss: 0.0007741157314740121
# Epoch 127/283, Loss: 0.0005835323827341199, Val Loss: 0.0006113930139690638
# Epoch 128/283, Loss: 0.0006213011220097542, Val Loss: 0.0006039857398718596
# Epoch 129/283, Loss: 0.0006099200691096485, Val Loss: 0.0005634153494611382
# Epoch 130/283, Loss: 0.0005807899287901819, Val Loss: 0.0007459907210431993
# Epoch 131/283, Loss: 0.0005933309439569712, Val Loss: 0.0006083865300752223
# Early stopping triggered
# Test Loss: 0.000589794828556478
# RMSE: 0.0242856927216053
# MAE: 0.018326422199606895
# MAPE: 16601.193359375%

# %%
print(f'Final Test Metrics -> MSE: {mse}, RMSE: {rmse}, MAE: {mae}, MAPE: {mape.item()}%')
# Out:
# Final Test Metrics -> MSE: 0.000589794828556478, RMSE: 0.0242856927216053, MAE: 0.018326422199606895, MAPE: 16601.193359375%

# %%
# path_1 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/YZV/'

# df_pred = pd.DataFrame(test_output.detach().numpy().flatten(), columns=['bnn_pred'])
# filename = 'BNN_pred.csv'
# df_pred.to_csv(path_1 + filename)
