# %%
# !pip install pyswarm
# Out:
# Requirement already satisfied: pyswarm in /usr/local/lib/python3.10/dist-packages (0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyswarm) (1.26.4)

# %%
# from collections import Iterable, OrderedDict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from collections.abc import Iterable
from collections import OrderedDict
from google.colab import drive
from torch.nn import Parameter
from datetime import datetime
from functools import partial
import torch.optim as optim
from pyswarm import pso
import torch.nn as nn
from math import sqrt
import pandas as pd
import numpy as np
import inspect
import torch
import time

# %% [markdown]
# # Load data

# %%
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

# %%
filename = 'HV_data.csv'
HV_data = pd.read_csv(path + filename)

# %%
HV_data.drop(columns=['vix', 'unemployment_rate', 'usd_eur', 'usd_jpy', 'usd_gbp', 'usd_cny', 'usd_cad', 'gt_data'], inplace=True)

# %%
HV_data
# Out:
#             Date        HV  ('GARCH', 'normal', 0)  ('GARCH', 'gaussian', 0)  \
# 0     2000-02-02 -0.001870               -0.001864                 -0.001864
# 1     2000-02-03 -0.001609               -0.001554                 -0.001554
# 2     2000-02-04 -0.001164               -0.001080                 -0.001080
# 3     2000-02-07 -0.000746               -0.000627                 -0.000627
# 4     2000-02-08 -0.000358               -0.000202                 -0.000202
# ...          ...       ...                     ...                       ...
# 6179  2024-08-26  0.000494               -0.000358                 -0.000358
# 6180  2024-08-27  0.000014               -0.000694                 -0.000694
# 6181  2024-08-28 -0.000477               -0.000954                 -0.000954
# 6182  2024-08-29 -0.000990               -0.001147                 -0.001147
# 6183  2024-08-30 -0.001491               -0.001232                 -0.001232
#
#       ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# 0                    -0.001782                 -0.001782
# 1                    -0.001519                 -0.001519
# 2                    -0.001076                 -0.001076
# 3                    -0.000678                 -0.000678
# 4                    -0.000311                 -0.000311
# ...                        ...                       ...
# 6179                 -0.000690                 -0.000690
# 6180                 -0.000899                 -0.000899
# 6181                 -0.001012                 -0.001012
# 6182                 -0.001067                 -0.001067
# 6183                 -0.001030                 -0.001030
#
#       ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)  log_returns  \
# 0                      -0.001782                   -0.001782     0.000077
# 1                      -0.001519                   -0.001519     0.000020
# 2                      -0.001076                   -0.001076     0.000152
# 3                      -0.000678                   -0.000678     0.000090
# 4                      -0.000311                   -0.000311    -0.000335
# ...                          ...                         ...          ...
# 6179                   -0.000690                   -0.000690    -0.000161
# 6180                   -0.000899                   -0.000899    -0.000193
# 6181                   -0.001012                   -0.001012    -0.000154
# 6182                   -0.001067                   -0.001067    -0.000150
# 6183                   -0.001030                   -0.001030    -0.000129
#
#       ('GARCH', 'normal', 1)  ('GARCH', 'gaussian', 1)  ('GARCH', 'ged', 0)  \
# 0                  -0.001725                 -0.001725            -0.001971
# 1                  -0.001557                 -0.001557            -0.001745
# 2                  -0.001163                 -0.001163            -0.001302
# 3                  -0.000738                 -0.000738            -0.000863
# 4                  -0.000335                 -0.000335            -0.000364
# ...                      ...                       ...                  ...
# 6179               -0.000493                 -0.000493            -0.001023
# 6180               -0.000707                 -0.000707            -0.001244
# 6181               -0.000846                 -0.000846            -0.001311
# 6182               -0.000937                 -0.000937            -0.001324
# 6183               -0.000923                 -0.000923            -0.001267
#
#       ('GARCH', 'ged', 1)
# 0               -0.001822
# 1               -0.001612
# 2               -0.001217
# 3               -0.000784
# 4               -0.000368
# ...                   ...
# 6179            -0.000502
# 6180            -0.000717
# 6181            -0.000852
# 6182            -0.000933
# 6183            -0.000919
#
# [6184 rows x 13 columns]

# %%
set_index(HV_data)

# %%
tm_data = HV_data

# %%
HV_data = HV_data.drop(columns=['HV'])

# %%
HV_data['HV'] = tm_data['HV']

# %%
HV_data
# Out:
#             ('GARCH', 'normal', 0)  ('GARCH', 'gaussian', 0)  \
# Date
# 2000-02-02               -0.001864                 -0.001864
# 2000-02-03               -0.001554                 -0.001554
# 2000-02-04               -0.001080                 -0.001080
# 2000-02-07               -0.000627                 -0.000627
# 2000-02-08               -0.000202                 -0.000202
# ...                            ...                       ...
# 2024-08-26               -0.000358                 -0.000358
# 2024-08-27               -0.000694                 -0.000694
# 2024-08-28               -0.000954                 -0.000954
# 2024-08-29               -0.001147                 -0.001147
# 2024-08-30               -0.001232                 -0.001232
#
#             ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# Date
# 2000-02-02                 -0.001782                 -0.001782
# 2000-02-03                 -0.001519                 -0.001519
# 2000-02-04                 -0.001076                 -0.001076
# 2000-02-07                 -0.000678                 -0.000678
# 2000-02-08                 -0.000311                 -0.000311
# ...                              ...                       ...
# 2024-08-26                 -0.000690                 -0.000690
# 2024-08-27                 -0.000899                 -0.000899
# 2024-08-28                 -0.001012                 -0.001012
# 2024-08-29                 -0.001067                 -0.001067
# 2024-08-30                 -0.001030                 -0.001030
#
#             ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)  \
# Date
# 2000-02-02                   -0.001782                   -0.001782
# 2000-02-03                   -0.001519                   -0.001519
# 2000-02-04                   -0.001076                   -0.001076
# 2000-02-07                   -0.000678                   -0.000678
# 2000-02-08                   -0.000311                   -0.000311
# ...                                ...                         ...
# 2024-08-26                   -0.000690                   -0.000690
# 2024-08-27                   -0.000899                   -0.000899
# 2024-08-28                   -0.001012                   -0.001012
# 2024-08-29                   -0.001067                   -0.001067
# 2024-08-30                   -0.001030                   -0.001030
#
#             log_returns  ('GARCH', 'normal', 1)  ('GARCH', 'gaussian', 1)  \
# Date
# 2000-02-02     0.000077               -0.001725                 -0.001725
# 2000-02-03     0.000020               -0.001557                 -0.001557
# 2000-02-04     0.000152               -0.001163                 -0.001163
# 2000-02-07     0.000090               -0.000738                 -0.000738
# 2000-02-08    -0.000335               -0.000335                 -0.000335
# ...                 ...                     ...                       ...
# 2024-08-26    -0.000161               -0.000493                 -0.000493
# 2024-08-27    -0.000193               -0.000707                 -0.000707
# 2024-08-28    -0.000154               -0.000846                 -0.000846
# 2024-08-29    -0.000150               -0.000937                 -0.000937
# 2024-08-30    -0.000129               -0.000923                 -0.000923
#
#             ('GARCH', 'ged', 0)  ('GARCH', 'ged', 1)        HV
# Date
# 2000-02-02            -0.001971            -0.001822 -0.001870
# 2000-02-03            -0.001745            -0.001612 -0.001609
# 2000-02-04            -0.001302            -0.001217 -0.001164
# 2000-02-07            -0.000863            -0.000784 -0.000746
# 2000-02-08            -0.000364            -0.000368 -0.000358
# ...                         ...                  ...       ...
# 2024-08-26            -0.001023            -0.000502  0.000494
# 2024-08-27            -0.001244            -0.000717  0.000014
# 2024-08-28            -0.001311            -0.000852 -0.000477
# 2024-08-29            -0.001324            -0.000933 -0.000990
# 2024-08-30            -0.001267            -0.000919 -0.001491
#
# [6184 rows x 12 columns]

# %% [markdown]
# # Split train, validation and test data

# %%
# train_end = datetime(2020, 6, 30)
# test_start = datetime(2020, 10, 1)
# val_size = 0.1

# %%
# target = ['HV', 'CCV', 'PV', 'GKV', 'RSV', 'YZV', 'GKYZV']
# test_data = data.loc[test_start:]

# train_val = data.loc[:train_end]
# train_data, val_data = train_test_split(train_val, test_size=val_size, shuffle=False)

# X_train = train_data.drop(columns=target)
# y_train = train_data[target]

# X_val = val_data.drop(columns=target)
# y_val = val_data[target]

# X_test = test_data.drop(columns=target)
# y_test = test_data[target]

# X_train = np.array(X_train)
# y_train = np.array(y_train)

# X_val = np.array(X_val)
# y_val = np.array(y_val)

# X_test = np.array(X_test)
# y_test = np.array(y_test)

# %%
def split_data(data, target, train_end =datetime(2022, 5, 30), test_start=datetime(2022, 5, 31), test_size=0.1):
  test_data = data.loc[test_start:]

  train_val = data.loc[:train_end]
  train_data, val_data = train_test_split(train_val, test_size=test_size, shuffle=False)

  X_train = train_data.drop(columns=[target])
  y_train = train_data[target]

  X_val = val_data.drop(columns=[target])
  y_val = val_data[target]

  X_test = test_data.drop(columns=[target])
  y_test = test_data[target]

  return np.array(X_train), np.array(y_train), np.array(X_val), np.array(y_val), np.array(X_test), np.array(y_test)

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(HV_data, 'HV')

# %% [markdown]
# # Model

# %%
class BDropout(torch.nn.Dropout):

    """Binary dropout with regularization and resampling.

    See: Gal Y., Ghahramani Z., "Dropout as a Bayesian Approximation:
    Representing Model Uncertainty in Deep Learning", 2016.
    """

    # def __init__(self, rate=0.1, reg=1.0, **kwargs):
    #     """Constructs a BDropout.

    #     Args:
    #         rate (float): Dropout probability.
    #         reg (float): Regularization scale.
    #     """
    #     super(BDropout, self).__init__(**kwargs)
    #     self.register_buffer("rate", torch.tensor(rate))
    #     self.p = 1 - self.rate
    #     self.register_buffer("reg", torch.tensor(reg))
    #     self.register_buffer("noise", torch.bernoulli(self.p))


    def __init__(self, rate=0.1, reg=1.0, **kwargs):
        """Constructs a BDropout.

        Args:
            rate (float): Dropout probability.
            reg (float): Regularization scale.
        """
        super(BDropout, self).__init__(p=rate, **kwargs)
        self.register_buffer("rate", torch.tensor(rate))
        self.p = 1 - self.rate
        self.register_buffer("reg", torch.tensor(reg))
        self.register_buffer("noise", torch.bernoulli(self.p))

    def regularization(self, weight, bias):
        """Computes the regularization cost.

        Args:
            weight (Tensor): Weight tensor.
            bias (Tensor): Bias tensor.

        Returns:
            Regularization cost (Tensor).
        """
        self.p = 1 - self.rate
        weight_reg = self.p * (weight**2).sum()
        bias_reg = (bias**2).sum() if bias is not None else 0
        return self.reg * (weight_reg + bias_reg)

    def resample(self):
        """Resamples the dropout noise."""
        self._update_noise(self.noise)

    def _update_noise(self, x):
        """Updates the dropout noise.

        Args:
            x (Tensor): Input.
        """
        self.p = 1 - self.rate
        self.noise.data = torch.bernoulli(self.p.expand(x.shape))

    def forward(self, x, resample=False, mask_dims=0, **kwargs):
        """Computes the binary dropout.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.
            mask_dims (int): Number of dimensions to sample noise for
                (0 for all).

        Returns:
            Output (Tensor).
        """
        sample_shape = x.shape[-mask_dims:]
        if sample_shape != self.noise.shape:
            sample = x.view(-1, *sample_shape)[0]
            self._update_noise(sample)
        elif resample:
            return x * torch.bernoulli(self.p.expand(x.shape))

        return x * self.noise

    def extra_repr(self):
        """Formats module representation.

        Returns:
            Module representation (str).
        """
        return "rate={}".format(self.rate)

# %%
class CDropout(BDropout):

    """Concrete dropout with regularization and resampling.

    See: Gal Y., Hron, J., Kendall, A. "Concrete Dropout", 2017.
    """

    # def __init__(self, temperature=0.1, rate=0.5, reg=1.0, **kwargs):
    #     """Constructs a CDropout.

    #     Args:
    #         temperature (float): Temperature.
    #         rate (float): Initial dropout rate.
    #         reg (float): Regularization scale.
    #     """
    #     super(CDropout, self).__init__(rate, reg, **kwargs)
    #     self.temperature = Parameter(
    #         torch.tensor(temperature), requires_grad=False)

    #     # We need to constrain p to [0, 1], so we train logit(p).
    #     self.logit_p = Parameter(-torch.log(self.p.reciprocal() - 1.0))

    def __init__(self, temperature=0.1, rate=0.5, reg=1.0, **kwargs):
        """Constructs a CDropout.

        Args:
            temperature (float): Temperature.
            rate (float): Initial dropout rate.
            reg (float): Regularization scale.
        """
        super(CDropout, self).__init__(rate, reg, **kwargs)
        self.temperature = torch.nn.Parameter(
            torch.tensor(temperature), requires_grad=False)

        # We need to constrain p to [0, 1], so we train logit(p).
        self.logit_p = torch.nn.Parameter(-torch.log(self.p.reciprocal() - 1.0))

    def regularization(self, weight, bias):
        """Computes the regularization cost.

        Args:
            weight (Tensor): Weight tensor.
            bias (Tensor): Bias tensor.

        Returns:
            Regularization cost (Tensor).
        """
        self.p.data = self.logit_p.sigmoid()
        reg = super(CDropout, self).regularization(weight, bias)
        reg -= -(1 - self.p) * (1 - self.p).log() - self.p * self.p.log()
        return reg

    def _update_noise(self, x):
        """Updates the dropout noise.

        Args:
            x (Tensor): Input.
        """
        self.noise.data = torch.rand_like(x)

    def forward(self, x, resample=False, mask_dims=0, **kwargs):
        """Computes the concrete dropout.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.
            mask_dims (int): Number of dimensions to sample noise for
                (0 for all).

        Returns:
            Output (Tensor).
        """
        sample_shape = x.shape[-mask_dims:]
        noise = self.noise
        if sample_shape != noise.shape:
            sample = x.view(-1, *sample_shape)[0]
            self._update_noise(sample)
            noise = self.noise
        elif resample:
            noise = torch.rand_like(x)

        self.p.data = self.logit_p.sigmoid()
        concrete_p = self.logit_p + noise.log() - (1 - noise).log()
        concrete_noise = (concrete_p / self.temperature).sigmoid()

        return x * concrete_noise

    def extra_repr(self):
        """Formats module representation.

        Returns:
            Module representation (str).
        """
        return "temperature={}".format(self.temperature)

# %%
class BSequential(torch.nn.Sequential):

    """Extension of Sequential module with regularization and resampling."""

    def resample(self):
        """Resample all child modules."""
        for child in self.children():
            if isinstance(child, BDropout):
                child.resample()

    def regularization(self):
        """Computes the total regularization cost of all child modules.

        Returns:
            Total regularization cost (Tensor).
        """
        reg = torch.tensor(0.0)
        children = list(self._modules.values())
        for i, child in enumerate(children):
            if isinstance(child, BSequential):
                reg += child.regularization()
            elif isinstance(child, BDropout):
                for next_child in children[i:]:
                    if hasattr(next_child, "weight") and hasattr(
                            next_child, "bias"):
                        reg += child.regularization(next_child.weight,
                                                    next_child.bias)
                        break
        return reg

    def forward(self, x, resample=False, **kwargs):
        """Computes the model.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.

        Returns:
            Output (Tensor).
        """
        for module in self._modules.values():
            if isinstance(module, (BDropout, BSequential)):
                x = module(x, resample=resample, **kwargs)
            else:
                x = module(x)
        return x

# %%
def bayesian_model(in_features,
                   out_features,
                   hidden_features,
                   nonlin=nn.ReLU,
                   output_nonlin=None,
                   weight_initializer=partial(
                       nn.init.xavier_normal_,
                       gain=nn.init.calculate_gain("relu")),
                   bias_initializer=partial(
                       nn.init.uniform_, a=-1.0, b=1.0),
                   dropout_layers=CDropout,
                   input_dropout=None):
    """Constructs and initializes a Bayesian neural network with dropout."""
    dims = [in_features] + hidden_features
    if not isinstance(dropout_layers, Iterable):
        dropout_layers = [dropout_layers] * len(hidden_features)

    modules = OrderedDict()

    if inspect.isclass(input_dropout):
        input_dropout = input_dropout()
    if input_dropout is not None:
        modules["drop_in"] = input_dropout

    for i, (din, dout) in enumerate(zip(dims[:-1], dims[1:])):
        drop_i = dropout_layers[i]
        if inspect.isclass(drop_i):
            drop_i = drop_i()

        modules["fc_{}".format(i)] = nn.Linear(din, dout)
        if drop_i is not None:
            modules["drop_{}".format(i)] = drop_i
        modules["nonlin_{}".format(i)] = nonlin()

    modules["fc_out"] = nn.Linear(dims[-1], out_features)
    if output_nonlin is not None:
        modules["nonlin_out"] = output_nonlin()

    def init(module):
        if callable(weight_initializer) and hasattr(module, "weight"):
            weight_initializer(module.weight)
        if callable(bias_initializer) and hasattr(module, "bias"):
            if module.bias is not None:
                bias_initializer(module.bias)

    net = BSequential(modules)
    net.apply(init)

    return net

# %%
# Convert NumPy arrays to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# Early stopping implementation
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_val_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_val_loss is None:
            self.best_val_loss = val_loss
        elif val_loss < self.best_val_loss - self.min_delta:
            self.best_val_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# Define parameter bounds
def parameter_bounds():
    # Number of layers: 1 to 5
    num_layers_bounds = (1, 5)

    # Number of neurons per layer: 10 to 200
    num_neurons_bounds = (10, 200)

    # Dropout rate: 0 to 0.5
    dropout_rate_bounds = (0.0, 0.5)

    # Learning rate: 0.0001 to 0.01
    learning_rate_bounds = (0.0001, 0.01)

    # Number of epochs: 50 to 500
    num_epochs_bounds = (150, 500)

    return num_layers_bounds, num_neurons_bounds, dropout_rate_bounds, learning_rate_bounds, num_epochs_bounds

# %%
def objective_function(params):
    # Unpack parameters from PSO
    num_layers, num_neurons, dropout_rate, learning_rate, num_epochs = params

    # Define the model with the given parameters
    model = bayesian_model(
        in_features=X_train.shape[1],
        out_features=1,
        hidden_features=[int(num_neurons)] * int(num_layers),
        nonlin=nn.ReLU,
        output_nonlin=None,
        dropout_layers=CDropout,
        input_dropout=CDropout(temperature=0.1, rate=dropout_rate, reg=1.0)
    )

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Initialize early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=0.01)

    # Track the best validation loss
    best_val_loss = float('inf')

    # Training loop with the number of epochs specified in the params
    for epoch in range(int(num_epochs)):
        model.train()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Validation phase (after each epoch)
        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val)
            val_loss = criterion(val_outputs, y_val)

        # Check and update the best validation loss
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()

        # Early stopping condition
        early_stopping(val_loss.item())
        if early_stopping.early_stop:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    # Return the best validation loss for PSO optimization
    return best_val_loss

# %%
# Define the bounds for each parameter
def get_bounds():
    num_layers_bounds, num_neurons_bounds, dropout_rate_bounds, learning_rate_bounds, num_epochs_bounds = parameter_bounds()
    return [
        [num_layers_bounds[0], num_neurons_bounds[0], dropout_rate_bounds[0], learning_rate_bounds[0], num_epochs_bounds[0]],
        [num_layers_bounds[1], num_neurons_bounds[1], dropout_rate_bounds[1], learning_rate_bounds[1], num_epochs_bounds[1]]
    ]

# %%
bounds = get_bounds()

# %%
lower_bounds = bounds[0]
upper_bounds = bounds[1]

swarmsize = 20
maxiter = 50

# %%
start_time = time.time()

best_params, best_val = pso(objective_function, lb=lower_bounds, ub=upper_bounds, swarmsize=swarmsize, maxiter=maxiter, debug=True)

end_time = time.time()
execution_time = end_time - start_time
# Out:
# No constraints given.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([5055])) that is different to the input size (torch.Size([5055, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([562])) that is different to the input size (torch.Size([562, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 16
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 65
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 68
# Early stopping triggered at epoch 14
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 100
# Early stopping triggered at epoch 16
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 12
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 19
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 44
# Best after iteration 1: [4.08150195e+00 1.22440681e+02 1.89586384e-01 9.09702636e-03
#  3.72337350e+02] 0.004846616182476282
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 51
# New best for swarm at iteration 2: [4.89711598e+00 2.00000000e+02 2.31075336e-01 4.33622143e-03
#  4.21191129e+02] 0.00432576984167099
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 11
# Early stopping triggered at epoch 65
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 17
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 66
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 54
# Best after iteration 2: [4.89711598e+00 2.00000000e+02 2.31075336e-01 4.33622143e-03
#  4.21191129e+02] 0.00432576984167099
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 22
# New best for swarm at iteration 3: [5.00000000e+00 6.95198511e+01 4.04634352e-01 9.49580490e-03
#  4.21581103e+02] 0.001663828850723803
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 72
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 90
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 35
# Best after iteration 3: [5.00000000e+00 6.95198511e+01 4.04634352e-01 9.49580490e-03
#  4.21581103e+02] 0.001663828850723803
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 21
# New best for swarm at iteration 4: [5.00000000e+00 7.79971421e+01 4.75680110e-01 6.11915801e-03
#  3.30017718e+02] 0.0006396587705239654
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 42
# Best after iteration 4: [5.00000000e+00 7.79971421e+01 4.75680110e-01 6.11915801e-03
#  3.30017718e+02] 0.0006396587705239654
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 40
# Best after iteration 5: [5.00000000e+00 7.79971421e+01 4.75680110e-01 6.11915801e-03
#  3.30017718e+02] 0.0006396587705239654
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 36
# Best after iteration 6: [5.00000000e+00 7.79971421e+01 4.75680110e-01 6.11915801e-03
#  3.30017718e+02] 0.0006396587705239654
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 42
# Best after iteration 7: [5.00000000e+00 7.79971421e+01 4.75680110e-01 6.11915801e-03
#  3.30017718e+02] 0.0006396587705239654
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 42
# Best after iteration 8: [5.00000000e+00 7.79971421e+01 4.75680110e-01 6.11915801e-03
#  3.30017718e+02] 0.0006396587705239654
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 36
# Best after iteration 9: [5.00000000e+00 7.79971421e+01 4.75680110e-01 6.11915801e-03
#  3.30017718e+02] 0.0006396587705239654
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 39
# Best after iteration 10: [5.00000000e+00 7.79971421e+01 4.75680110e-01 6.11915801e-03
#  3.30017718e+02] 0.0006396587705239654
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 42
# Best after iteration 11: [5.00000000e+00 7.79971421e+01 4.75680110e-01 6.11915801e-03
#  3.30017718e+02] 0.0006396587705239654
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 27
# New best for swarm at iteration 12: [4.83835401e+00 7.68627423e+01 4.22286892e-01 5.88013189e-03
#  3.16624649e+02] 0.0005906930891796947
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 38
# Best after iteration 12: [4.83835401e+00 7.68627423e+01 4.22286892e-01 5.88013189e-03
#  3.16624649e+02] 0.0005906930891796947
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 39
# Best after iteration 13: [4.83835401e+00 7.68627423e+01 4.22286892e-01 5.88013189e-03
#  3.16624649e+02] 0.0005906930891796947
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 26
# Best after iteration 14: [4.83835401e+00 7.68627423e+01 4.22286892e-01 5.88013189e-03
#  3.16624649e+02] 0.0005906930891796947
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 46
# Best after iteration 15: [4.83835401e+00 7.68627423e+01 4.22286892e-01 5.88013189e-03
#  3.16624649e+02] 0.0005906930891796947
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 35
# Best after iteration 16: [4.83835401e+00 7.68627423e+01 4.22286892e-01 5.88013189e-03
#  3.16624649e+02] 0.0005906930891796947
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 30
# Best after iteration 17: [4.83835401e+00 7.68627423e+01 4.22286892e-01 5.88013189e-03
#  3.16624649e+02] 0.0005906930891796947
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 27
# Best after iteration 18: [4.83835401e+00 7.68627423e+01 4.22286892e-01 5.88013189e-03
#  3.16624649e+02] 0.0005906930891796947
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 31
# Best after iteration 19: [4.83835401e+00 7.68627423e+01 4.22286892e-01 5.88013189e-03
#  3.16624649e+02] 0.0005906930891796947
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 31
# Best after iteration 20: [4.83835401e+00 7.68627423e+01 4.22286892e-01 5.88013189e-03
#  3.16624649e+02] 0.0005906930891796947
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 28
# New best for swarm at iteration 21: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 37
# Best after iteration 21: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 34
# Best after iteration 22: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 41
# Best after iteration 23: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Best after iteration 24: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 54
# Best after iteration 25: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 26
# Best after iteration 26: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 33
# Best after iteration 27: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 42
# Best after iteration 28: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 38
# Best after iteration 29: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Best after iteration 30: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 20
# Best after iteration 31: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Best after iteration 32: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 39
# Best after iteration 33: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 29
# Best after iteration 34: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Best after iteration 35: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 36
# Best after iteration 36: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 35
# Best after iteration 37: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 54
# Best after iteration 38: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 38
# Best after iteration 39: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 38
# Best after iteration 40: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 24
# Best after iteration 41: [4.94348686e+00 6.92955143e+01 4.04448060e-01 7.14261170e-03
#  3.39912356e+02] 0.0004606124712154269
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 34
# New best for swarm at iteration 42: [4.95894469e+00 8.22486135e+01 3.51523875e-01 6.91371347e-03
#  3.10711128e+02] 0.00014782417565584183
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Best after iteration 42: [4.95894469e+00 8.22486135e+01 3.51523875e-01 6.91371347e-03
#  3.10711128e+02] 0.00014782417565584183
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 24
# Best after iteration 43: [4.95894469e+00 8.22486135e+01 3.51523875e-01 6.91371347e-03
#  3.10711128e+02] 0.00014782417565584183
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 34
# Best after iteration 44: [4.95894469e+00 8.22486135e+01 3.51523875e-01 6.91371347e-03
#  3.10711128e+02] 0.00014782417565584183
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 36
# Best after iteration 45: [4.95894469e+00 8.22486135e+01 3.51523875e-01 6.91371347e-03
#  3.10711128e+02] 0.00014782417565584183
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 36
# Best after iteration 46: [4.95894469e+00 8.22486135e+01 3.51523875e-01 6.91371347e-03
#  3.10711128e+02] 0.00014782417565584183
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 31
# Best after iteration 47: [4.95894469e+00 8.22486135e+01 3.51523875e-01 6.91371347e-03
#  3.10711128e+02] 0.00014782417565584183
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 42
# Best after iteration 48: [4.95894469e+00 8.22486135e+01 3.51523875e-01 6.91371347e-03
#  3.10711128e+02] 0.00014782417565584183
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 36
# Best after iteration 49: [4.95894469e+00 8.22486135e+01 3.51523875e-01 6.91371347e-03
#  3.10711128e+02] 0.00014782417565584183
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 45
# Best after iteration 50: [4.95894469e+00 8.22486135e+01 3.51523875e-01 6.91371347e-03
#  3.10711128e+02] 0.00014782417565584183
# Stopping search: maximum iterations reached --> 50

# %%
execution_time
# Out:
# 11415.95533156395

# %%
best_params
# Out:
# array([4.95894469e+00, 8.22486135e+01, 3.51523875e-01, 6.91371347e-03,
#        3.10711128e+02])

# %%
# Function to train and evaluate the model with given hyperparameters
def train_and_evaluate_model(params):
    n_layers, n_neurons, drop_rate, learning_rate, epochs = params

    # Define the model
    hidden_features = [int(n_neurons)] * int(n_layers)
    model = bayesian_model(
        in_features=X_train.shape[1],
        out_features=1,
        hidden_features=hidden_features,
        dropout_layers=CDropout(rate=drop_rate),  # Dropout layer without partial
    )

    # Define optimizer and loss function
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()

    # Early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

    # Training loop
    for epoch in range(int(epochs)):
        model.train()
        optimizer.zero_grad()

        output = model(X_train)
        loss = criterion(output, y_train)

        loss.backward()
        optimizer.step()

        model.eval()
        val_output = model(X_val)
        val_loss = criterion(val_output, y_val)

        print(f'Epoch {epoch+1}/{int(epochs)}, Loss: {loss.item()}, Val Loss: {val_loss.item()}')

        early_stopping(val_loss.item())
        if early_stopping.early_stop:
            print("Early stopping triggered")
            break

    # Test the model
    model.eval()
    test_output = model(X_test)
    mse = criterion(test_output, y_test)
    rmse = mse ** 0.5
    mae = nn.L1Loss()(y_test, test_output).item()
    mape = torch.mean(torch.abs((y_test - test_output) / y_test)) * 100

    print(f'Test Loss: {mse.item()}')
    print(f'RMSE: {rmse}')
    print(f'MAE: {mae}')
    print(f'MAPE: {mape.item()}%')

    return mse, rmse, mae, mape, test_output

# %%
# best_params = [3.62253629e+00, 1.12321717e+02, 2.77934900e-01, 5.49072091e-03, 2.22486413e+02]

# %%
mse, rmse, mae, mape, test_output = train_and_evaluate_model(best_params)
# Out:
# Epoch 1/310, Loss: 0.609625518321991, Val Loss: 0.4038904011249542
# Epoch 2/310, Loss: 0.39621391892433167, Val Loss: 0.22470469772815704
# Epoch 3/310, Loss: 0.2357361763715744, Val Loss: 0.17758160829544067
# Epoch 4/310, Loss: 0.16109837591648102, Val Loss: 0.10784007608890533
# Epoch 5/310, Loss: 0.10831379145383835, Val Loss: 0.10226865857839584
# Epoch 6/310, Loss: 0.09209242463111877, Val Loss: 0.08325027674436569
# Epoch 7/310, Loss: 0.08501698076725006, Val Loss: 0.06282906979322433
# Epoch 8/310, Loss: 0.06567732244729996, Val Loss: 0.047657303512096405
# Epoch 9/310, Loss: 0.048411935567855835, Val Loss: 0.045902710407972336
# Epoch 10/310, Loss: 0.04467667266726494, Val Loss: 0.040863584727048874
# Epoch 11/310, Loss: 0.03995676338672638, Val Loss: 0.030794795602560043
# Epoch 12/310, Loss: 0.03336181119084358, Val Loss: 0.027844693511724472
# Epoch 13/310, Loss: 0.028475439175963402, Val Loss: 0.023394599556922913
# Epoch 14/310, Loss: 0.02508859895169735, Val Loss: 0.02571592666208744
# Epoch 15/310, Loss: 0.024857325479388237, Val Loss: 0.02393646351993084
# Epoch 16/310, Loss: 0.02312511019408703, Val Loss: 0.018702039495110512
# Epoch 17/310, Loss: 0.019712530076503754, Val Loss: 0.018687764182686806
# Epoch 18/310, Loss: 0.017881132662296295, Val Loss: 0.01621212624013424
# Epoch 19/310, Loss: 0.01722630299627781, Val Loss: 0.015570719726383686
# Epoch 20/310, Loss: 0.01640176773071289, Val Loss: 0.014240988530218601
# Epoch 21/310, Loss: 0.015110411681234837, Val Loss: 0.012464307248592377
# Epoch 22/310, Loss: 0.01357617974281311, Val Loss: 0.011689988896250725
# Epoch 23/310, Loss: 0.01226181909441948, Val Loss: 0.011197862215340137
# Epoch 24/310, Loss: 0.011467518284916878, Val Loss: 0.010809378698468208
# Epoch 25/310, Loss: 0.010546955280005932, Val Loss: 0.009896071627736092
# Epoch 26/310, Loss: 0.010164880193769932, Val Loss: 0.008433223702013493
# Epoch 27/310, Loss: 0.009512734599411488, Val Loss: 0.009563883766531944
# Epoch 28/310, Loss: 0.008632419630885124, Val Loss: 0.008357618004083633
# Epoch 29/310, Loss: 0.00777479587122798, Val Loss: 0.00792653113603592
# Epoch 30/310, Loss: 0.0073102060705423355, Val Loss: 0.0075479187071323395
# Epoch 31/310, Loss: 0.007011222653090954, Val Loss: 0.006283928640186787
# Epoch 32/310, Loss: 0.0066230082884430885, Val Loss: 0.006753225810825825
# Epoch 33/310, Loss: 0.006495812442153692, Val Loss: 0.006158888805657625
# Epoch 34/310, Loss: 0.006047853734344244, Val Loss: 0.006100638769567013
# Epoch 35/310, Loss: 0.0056504374369978905, Val Loss: 0.005559227894991636
# Epoch 36/310, Loss: 0.005208634305745363, Val Loss: 0.005045637488365173
# Epoch 37/310, Loss: 0.005146883428096771, Val Loss: 0.00466121407225728
# Epoch 38/310, Loss: 0.004896362777799368, Val Loss: 0.004538544453680515
# Epoch 39/310, Loss: 0.004457033239305019, Val Loss: 0.004015279468148947
# Epoch 40/310, Loss: 0.004271820653229952, Val Loss: 0.0038805510848760605
# Epoch 41/310, Loss: 0.004063115920871496, Val Loss: 0.004160085693001747
# Epoch 42/310, Loss: 0.003989948891103268, Val Loss: 0.0035166197922080755
# Epoch 43/310, Loss: 0.00357675738632679, Val Loss: 0.0033584069460630417
# Epoch 44/310, Loss: 0.0035555693320930004, Val Loss: 0.003410917706787586
# Epoch 45/310, Loss: 0.0032550045289099216, Val Loss: 0.0028229800518602133
# Epoch 46/310, Loss: 0.003084462368860841, Val Loss: 0.0029016733169555664
# Epoch 47/310, Loss: 0.003111034631729126, Val Loss: 0.002779340138658881
# Epoch 48/310, Loss: 0.0029017850756645203, Val Loss: 0.002851904137060046
# Epoch 49/310, Loss: 0.0027470265049487352, Val Loss: 0.002635845448821783
# Epoch 50/310, Loss: 0.0025564790703356266, Val Loss: 0.0023988261818885803
# Epoch 51/310, Loss: 0.002488161902874708, Val Loss: 0.002350317779928446
# Epoch 52/310, Loss: 0.0022938898764550686, Val Loss: 0.0025239193346351385
# Epoch 53/310, Loss: 0.0022995255421847105, Val Loss: 0.0021479367278516293
# Epoch 54/310, Loss: 0.002213000087067485, Val Loss: 0.0019292073557153344
# Epoch 55/310, Loss: 0.0020144577138125896, Val Loss: 0.0021037172991782427
# Epoch 56/310, Loss: 0.0018342416733503342, Val Loss: 0.0016757163684815168
# Epoch 57/310, Loss: 0.001897225040011108, Val Loss: 0.0017610860522836447
# Epoch 58/310, Loss: 0.0017207220662385225, Val Loss: 0.0014262888580560684
# Epoch 59/310, Loss: 0.0016021464252844453, Val Loss: 0.0016691249329596758
# Epoch 60/310, Loss: 0.0015080271987244487, Val Loss: 0.0014984854497015476
# Epoch 61/310, Loss: 0.0014221438905224204, Val Loss: 0.0015332669718191028
# Epoch 62/310, Loss: 0.0013735629618167877, Val Loss: 0.0010691850911825895
# Epoch 63/310, Loss: 0.0012332350015640259, Val Loss: 0.0011690015671774745
# Epoch 64/310, Loss: 0.001187430345453322, Val Loss: 0.0012562040938064456
# Epoch 65/310, Loss: 0.0010070663411170244, Val Loss: 0.000874294142704457
# Epoch 66/310, Loss: 0.0010353137040510774, Val Loss: 0.0009996178559958935
# Epoch 67/310, Loss: 0.0009022133308462799, Val Loss: 0.000940552621614188
# Epoch 68/310, Loss: 0.0007997138309292495, Val Loss: 0.0006599095067940652
# Epoch 69/310, Loss: 0.0007982320967130363, Val Loss: 0.0006895138067193329
# Epoch 70/310, Loss: 0.0007322915480472147, Val Loss: 0.0006037323619239032
# Epoch 71/310, Loss: 0.0006678524077869952, Val Loss: 0.0005611462402157485
# Epoch 72/310, Loss: 0.000617830257397145, Val Loss: 0.0005575430113822222
# Epoch 73/310, Loss: 0.0005898738745599985, Val Loss: 0.0005894558853469789
# Epoch 74/310, Loss: 0.0005238574231043458, Val Loss: 0.0004910338902845979
# Epoch 75/310, Loss: 0.000523281516507268, Val Loss: 0.0006082330364733934
# Epoch 76/310, Loss: 0.00042560562724247575, Val Loss: 0.00036655672010965645
# Epoch 77/310, Loss: 0.0004472777363844216, Val Loss: 0.0004325709887780249
# Epoch 78/310, Loss: 0.0003844921011477709, Val Loss: 0.00035109114833176136
# Epoch 79/310, Loss: 0.00037132963188923895, Val Loss: 0.00036379878292791545
# Epoch 80/310, Loss: 0.00034559701452963054, Val Loss: 0.0003431319200899452
# Epoch 81/310, Loss: 0.0003301527176517993, Val Loss: 0.0003277741780038923
# Epoch 82/310, Loss: 0.0003008822095580399, Val Loss: 0.00029345101211220026
# Epoch 83/310, Loss: 0.0002803582465276122, Val Loss: 0.00029500460368581116
# Epoch 84/310, Loss: 0.0002493966312613338, Val Loss: 0.0002214380947407335
# Epoch 85/310, Loss: 0.00028807122725993395, Val Loss: 0.0002662463521119207
# Epoch 86/310, Loss: 0.0002831759047694504, Val Loss: 0.00021722215751651675
# Epoch 87/310, Loss: 0.0002371365699218586, Val Loss: 0.00023416864860337228
# Epoch 88/310, Loss: 0.00020234004477970302, Val Loss: 0.00020370667334645987
# Epoch 89/310, Loss: 0.00023774847795721143, Val Loss: 0.0002729195693973452
# Epoch 90/310, Loss: 0.00022453581914305687, Val Loss: 0.00024458367261104286
# Epoch 91/310, Loss: 0.00019941365462727845, Val Loss: 0.0002078549296129495
# Epoch 92/310, Loss: 0.00021125329658389091, Val Loss: 0.00015759040252305567
# Epoch 93/310, Loss: 0.00018971945974044502, Val Loss: 0.00019744002202060074
# Epoch 94/310, Loss: 0.00019719880947377533, Val Loss: 0.00014915424981154501
# Early stopping triggered
# Test Loss: 0.00017889875744003803
# RMSE: 0.013375303708016872
# MAE: 0.00955329928547144
# MAPE: 190398.75%
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([567])) that is different to the input size (torch.Size([567, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:128: UserWarning: Using a target size (torch.Size([567, 1])) that is different to the input size (torch.Size([567])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)

# %%
print(f'Final Test Metrics -> MSE: {mse}, RMSE: {rmse}, MAE: {mae}, MAPE: {mape.item()}%')
# Out:
# Final Test Metrics -> MSE: 0.00017889875744003803, RMSE: 0.013375303708016872, MAE: 0.00955329928547144, MAPE: 190398.75%

# %%
# path_1 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/HV/'

# df_pred = pd.DataFrame(test_output.detach().numpy().flatten(), columns=['bnn_pred'])
# filename = 'BNN_pred.csv'
# df_pred.to_csv(path_1 + filename)
