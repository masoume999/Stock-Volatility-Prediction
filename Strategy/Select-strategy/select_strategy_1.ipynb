# %%
import pandas as pd
import numpy as np
import builtins
import yfinance as yf
from google.colab import drive
from datetime import datetime
import matplotlib.pyplot as plt
from functools import reduce

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Functions

# %%
def final_select_strategy(Filtered_2y_2022, Filtered_2y_2024):
  final_common_rows = pd.merge(Filtered_2y_2022, Filtered_2y_2024, on=['Strategy'])
  return final_common_rows['Strategy']

# %%
def select_strategy_2022():
    path = '/content/drive/MyDrive/Strategy/MA/HV/HV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_HV = pd.DataFrame()
    y2_2022_HV = pd.DataFrame()
    F_2022_2y_HV = pd.DataFrame()

    y1_2022_HV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_HV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_HV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_HV = y1_2022_HV.loc[(y1_2022_HV['HV_sharpe > 0'] == True) & (y1_2022_HV['HV_sharpe > Pure_sharpe'] == True) & (y1_2022_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_HV = y2_2022_HV.loc[(y2_2022_HV['HV_sharpe > 0'] == True) & (y2_2022_HV['HV_sharpe > Pure_sharpe'] == True) & (y2_2022_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_HV = F_2022_2y_HV.loc[(F_2022_2y_HV['HV_sharpe > 0'] == True) & (F_2022_2y_HV['HV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_HV = pd.merge(Filtered_y1_2022_HV, Filtered_y2_2022_HV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/PV/PV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_PV = pd.DataFrame()
    y2_2022_PV = pd.DataFrame()
    F_2022_2y_PV = pd.DataFrame()

    y1_2022_PV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_PV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_PV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_PV = y1_2022_PV.loc[(y1_2022_PV['PV_sharpe > 0'] == True) & (y1_2022_PV['PV_sharpe > Pure_sharpe'] == True) & (y1_2022_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_PV = y2_2022_PV.loc[(y2_2022_PV['PV_sharpe > 0'] == True) & (y2_2022_PV['PV_sharpe > Pure_sharpe'] == True) & (y2_2022_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_PV = F_2022_2y_PV.loc[(F_2022_2y_PV['PV_sharpe > 0'] == True) & (F_2022_2y_PV['PV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_PV = pd.merge(Filtered_y1_2022_PV, Filtered_y2_2022_PV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/CCV/CCV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_CCV = pd.DataFrame()
    y2_2022_CCV = pd.DataFrame()
    F_2022_2y_CCV = pd.DataFrame()

    y1_2022_CCV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_CCV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_CCV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_CCV = y1_2022_CCV.loc[(y1_2022_CCV['CCV_sharpe > 0'] == True) & (y1_2022_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y1_2022_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_CCV = y2_2022_CCV.loc[(y2_2022_CCV['CCV_sharpe > 0'] == True) & (y2_2022_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y2_2022_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_CCV = F_2022_2y_CCV.loc[(F_2022_2y_CCV['CCV_sharpe > 0'] == True) & (F_2022_2y_CCV['CCV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_CCV = pd.merge(Filtered_y1_2022_CCV, Filtered_y2_2022_CCV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKV/GKV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_GKV = pd.DataFrame()
    y2_2022_GKV = pd.DataFrame()
    F_2022_2y_GKV = pd.DataFrame()

    y1_2022_GKV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_GKV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_GKV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_GKV = y1_2022_GKV.loc[(y1_2022_GKV['GKV_sharpe > 0'] == True) & (y1_2022_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y1_2022_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_GKV = y2_2022_GKV.loc[(y2_2022_GKV['GKV_sharpe > 0'] == True) & (y2_2022_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y2_2022_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_GKV = F_2022_2y_GKV.loc[(F_2022_2y_GKV['GKV_sharpe > 0'] == True) & (F_2022_2y_GKV['GKV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKV = pd.merge(Filtered_y1_2022_GKV, Filtered_y2_2022_GKV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/YZV/YZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_YZV = pd.DataFrame()
    y2_2022_YZV = pd.DataFrame()
    F_2022_2y_YZV = pd.DataFrame()

    y1_2022_YZV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_YZV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_YZV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_YZV = y1_2022_YZV.loc[(y1_2022_YZV['YZV_sharpe > 0'] == True) & (y1_2022_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y1_2022_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_YZV = y2_2022_YZV.loc[(y2_2022_YZV['YZV_sharpe > 0'] == True) & (y2_2022_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y2_2022_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_YZV = F_2022_2y_YZV.loc[(F_2022_2y_YZV['YZV_sharpe > 0'] == True) & (F_2022_2y_YZV['YZV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_YZV = pd.merge(Filtered_y1_2022_YZV, Filtered_y2_2022_YZV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKYZV/GKYZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_GKYZV = pd.DataFrame()
    y2_2022_GKYZV = pd.DataFrame()
    F_2022_2y_GKYZV = pd.DataFrame()

    y1_2022_GKYZV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_GKYZV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_GKYZV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_GKYZV = y1_2022_GKYZV.loc[(y1_2022_GKYZV['GKYZV_sharpe > 0'] == True) & (y1_2022_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y1_2022_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_GKYZV = y2_2022_GKYZV.loc[(y2_2022_GKYZV['GKYZV_sharpe > 0'] == True) & (y2_2022_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y2_2022_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_GKYZV = F_2022_2y_GKYZV.loc[(F_2022_2y_GKYZV['GKYZV_sharpe > 0'] == True) & (F_2022_2y_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKYZV = pd.merge(Filtered_y1_2022_GKYZV, Filtered_y2_2022_GKYZV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/RSV/RSV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_RSV = pd.DataFrame()
    y2_2022_RSV = pd.DataFrame()
    F_2022_2y_RSV = pd.DataFrame()

    y1_2022_RSV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_RSV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_RSV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_RSV = y1_2022_RSV.loc[(y1_2022_RSV['RSV_sharpe > 0'] == True) & (y1_2022_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y1_2022_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_RSV = y2_2022_RSV.loc[(y2_2022_RSV['RSV_sharpe > 0'] == True) & (y2_2022_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y2_2022_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_RSV = F_2022_2y_RSV.loc[(F_2022_2y_RSV['RSV_sharpe > 0'] == True) & (F_2022_2y_RSV['RSV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_RSV = pd.merge(Filtered_y1_2022_RSV, Filtered_y2_2022_RSV, on=['Strategy'])

    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [common_rows_HV['Strategy'], common_rows_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_1['Strategy'], common_rows_CCV['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_2['Strategy'], common_rows_GKV['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_3['Strategy'], common_rows_YZV['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_4['Strategy'], common_rows_GKYZV['Strategy']])
    Filtered_y1_y2_2022 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_5['Strategy'], common_rows_RSV['Strategy']])


    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_HV['Strategy'], Filtered_2022_2y_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_CCV['Strategy'], common_rows_2y_1['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_GKV['Strategy'], common_rows_2y_2['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_YZV['Strategy'], common_rows_2y_3['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_GKYZV['Strategy'], common_rows_2y_4['Strategy']])
    Filtered_2y_2022 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_RSV['Strategy'], common_rows_2y_5['Strategy']])


    return Filtered_2y_2022, Filtered_2022_2y_HV, Filtered_2022_2y_PV, Filtered_2022_2y_CCV, Filtered_2022_2y_GKV, Filtered_2022_2y_YZV, Filtered_2022_2y_GKYZV, Filtered_2022_2y_RSV

# %%
def select_strategy_dw_2022():
    path = '/content/drive/MyDrive/Strategy/MA/HV/DW_HV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_HV = pd.DataFrame()
    y2_2022_HV = pd.DataFrame()
    F_2022_2y_HV = pd.DataFrame()

    y1_2022_HV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_HV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_HV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_HV = y1_2022_HV.loc[(y1_2022_HV['HV_sharpe > 0'] == True) & (y1_2022_HV['HV_sharpe > Pure_sharpe'] == True) & (y1_2022_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_HV = y2_2022_HV.loc[(y2_2022_HV['HV_sharpe > 0'] == True) & (y2_2022_HV['HV_sharpe > Pure_sharpe'] == True) & (y2_2022_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_HV = F_2022_2y_HV.loc[(F_2022_2y_HV['HV_sharpe > 0'] == True) & (F_2022_2y_HV['HV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_HV = pd.merge(Filtered_y1_2022_HV, Filtered_y2_2022_HV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/PV/DW_PV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_PV = pd.DataFrame()
    y2_2022_PV = pd.DataFrame()
    F_2022_2y_PV = pd.DataFrame()

    y1_2022_PV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_PV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_PV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_PV = y1_2022_PV.loc[(y1_2022_PV['PV_sharpe > 0'] == True) & (y1_2022_PV['PV_sharpe > Pure_sharpe'] == True) & (y1_2022_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_PV = y2_2022_PV.loc[(y2_2022_PV['PV_sharpe > 0'] == True) & (y2_2022_PV['PV_sharpe > Pure_sharpe'] == True) & (y2_2022_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_PV = F_2022_2y_PV.loc[(F_2022_2y_PV['PV_sharpe > 0'] == True) & (F_2022_2y_PV['PV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_PV = pd.merge(Filtered_y1_2022_PV, Filtered_y2_2022_PV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/CCV/DW_CCV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_CCV = pd.DataFrame()
    y2_2022_CCV = pd.DataFrame()
    F_2022_2y_CCV = pd.DataFrame()

    y1_2022_CCV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_CCV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_CCV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_CCV = y1_2022_CCV.loc[(y1_2022_CCV['CCV_sharpe > 0'] == True) & (y1_2022_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y1_2022_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_CCV = y2_2022_CCV.loc[(y2_2022_CCV['CCV_sharpe > 0'] == True) & (y2_2022_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y2_2022_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_CCV = F_2022_2y_CCV.loc[(F_2022_2y_CCV['CCV_sharpe > 0'] == True) & (F_2022_2y_CCV['CCV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_CCV = pd.merge(Filtered_y1_2022_CCV, Filtered_y2_2022_CCV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKV/DW_GKV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_GKV = pd.DataFrame()
    y2_2022_GKV = pd.DataFrame()
    F_2022_2y_GKV = pd.DataFrame()

    y1_2022_GKV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_GKV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_GKV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_GKV = y1_2022_GKV.loc[(y1_2022_GKV['GKV_sharpe > 0'] == True) & (y1_2022_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y1_2022_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_GKV = y2_2022_GKV.loc[(y2_2022_GKV['GKV_sharpe > 0'] == True) & (y2_2022_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y2_2022_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_GKV = F_2022_2y_GKV.loc[(F_2022_2y_GKV['GKV_sharpe > 0'] == True) & (F_2022_2y_GKV['GKV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKV = pd.merge(Filtered_y1_2022_GKV, Filtered_y2_2022_GKV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/YZV/DW_YZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_YZV = pd.DataFrame()
    y2_2022_YZV = pd.DataFrame()
    F_2022_2y_YZV = pd.DataFrame()

    y1_2022_YZV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_YZV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_YZV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_YZV = y1_2022_YZV.loc[(y1_2022_YZV['YZV_sharpe > 0'] == True) & (y1_2022_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y1_2022_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_YZV = y2_2022_YZV.loc[(y2_2022_YZV['YZV_sharpe > 0'] == True) & (y2_2022_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y2_2022_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_YZV = F_2022_2y_YZV.loc[(F_2022_2y_YZV['YZV_sharpe > 0'] == True) & (F_2022_2y_YZV['YZV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_YZV = pd.merge(Filtered_y1_2022_YZV, Filtered_y2_2022_YZV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKYZV/DW_GKYZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_GKYZV = pd.DataFrame()
    y2_2022_GKYZV = pd.DataFrame()
    F_2022_2y_GKYZV = pd.DataFrame()

    y1_2022_GKYZV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_GKYZV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_GKYZV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_GKYZV = y1_2022_GKYZV.loc[(y1_2022_GKYZV['GKYZV_sharpe > 0'] == True) & (y1_2022_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y1_2022_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_GKYZV = y2_2022_GKYZV.loc[(y2_2022_GKYZV['GKYZV_sharpe > 0'] == True) & (y2_2022_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y2_2022_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_GKYZV = F_2022_2y_GKYZV.loc[(F_2022_2y_GKYZV['GKYZV_sharpe > 0'] == True) & (F_2022_2y_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKYZV = pd.merge(Filtered_y1_2022_GKYZV, Filtered_y2_2022_GKYZV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/RSV/DW_RSV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_RSV = pd.DataFrame()
    y2_2022_RSV = pd.DataFrame()
    F_2022_2y_RSV = pd.DataFrame()

    y1_2022_RSV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_RSV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_RSV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_RSV = y1_2022_RSV.loc[(y1_2022_RSV['RSV_sharpe > 0'] == True) & (y1_2022_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y1_2022_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_RSV = y2_2022_RSV.loc[(y2_2022_RSV['RSV_sharpe > 0'] == True) & (y2_2022_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y2_2022_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_RSV = F_2022_2y_RSV.loc[(F_2022_2y_RSV['RSV_sharpe > 0'] == True) & (F_2022_2y_RSV['RSV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_RSV = pd.merge(Filtered_y1_2022_RSV, Filtered_y2_2022_RSV, on=['Strategy'])

    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [common_rows_HV['Strategy'], common_rows_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_1['Strategy'], common_rows_CCV['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_2['Strategy'], common_rows_GKV['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_3['Strategy'], common_rows_YZV['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_4['Strategy'], common_rows_GKYZV['Strategy']])
    Filtered_y1_y2_2022 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_5['Strategy'], common_rows_RSV['Strategy']])


    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_HV['Strategy'], Filtered_2022_2y_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_CCV['Strategy'], common_rows_2y_1['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_GKV['Strategy'], common_rows_2y_2['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_YZV['Strategy'], common_rows_2y_3['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_GKYZV['Strategy'], common_rows_2y_4['Strategy']])
    Filtered_2y_2022 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_RSV['Strategy'], common_rows_2y_5['Strategy']])


    return Filtered_2y_2022, Filtered_2022_2y_HV, Filtered_2022_2y_PV, Filtered_2022_2y_CCV, Filtered_2022_2y_GKV, Filtered_2022_2y_YZV, Filtered_2022_2y_GKYZV, Filtered_2022_2y_RSV

# %%
def select_strategy_cw_2022():
    path = '/content/drive/MyDrive/Strategy/MA/HV/CW_HV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_HV = pd.DataFrame()
    y2_2022_HV = pd.DataFrame()
    F_2022_2y_HV = pd.DataFrame()

    y1_2022_HV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_HV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_HV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_HV = y1_2022_HV.loc[(y1_2022_HV['HV_sharpe > 0'] == True) & (y1_2022_HV['HV_sharpe > Pure_sharpe'] == True) & (y1_2022_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_HV = y2_2022_HV.loc[(y2_2022_HV['HV_sharpe > 0'] == True) & (y2_2022_HV['HV_sharpe > Pure_sharpe'] == True) & (y2_2022_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_HV = F_2022_2y_HV.loc[(F_2022_2y_HV['HV_sharpe > 0'] == True) & (F_2022_2y_HV['HV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_HV = pd.merge(Filtered_y1_2022_HV, Filtered_y2_2022_HV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/PV/CW_PV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_PV = pd.DataFrame()
    y2_2022_PV = pd.DataFrame()
    F_2022_2y_PV = pd.DataFrame()

    y1_2022_PV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_PV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_PV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_PV = y1_2022_PV.loc[(y1_2022_PV['PV_sharpe > 0'] == True) & (y1_2022_PV['PV_sharpe > Pure_sharpe'] == True) & (y1_2022_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_PV = y2_2022_PV.loc[(y2_2022_PV['PV_sharpe > 0'] == True) & (y2_2022_PV['PV_sharpe > Pure_sharpe'] == True) & (y2_2022_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_PV = F_2022_2y_PV.loc[(F_2022_2y_PV['PV_sharpe > 0'] == True) & (F_2022_2y_PV['PV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_PV = pd.merge(Filtered_y1_2022_PV, Filtered_y2_2022_PV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/CCV/CW_CCV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_CCV = pd.DataFrame()
    y2_2022_CCV = pd.DataFrame()
    F_2022_2y_CCV = pd.DataFrame()

    y1_2022_CCV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_CCV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_CCV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_CCV = y1_2022_CCV.loc[(y1_2022_CCV['CCV_sharpe > 0'] == True) & (y1_2022_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y1_2022_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_CCV = y2_2022_CCV.loc[(y2_2022_CCV['CCV_sharpe > 0'] == True) & (y2_2022_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y2_2022_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_CCV = F_2022_2y_CCV.loc[(F_2022_2y_CCV['CCV_sharpe > 0'] == True) & (F_2022_2y_CCV['CCV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_CCV = pd.merge(Filtered_y1_2022_CCV, Filtered_y2_2022_CCV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKV/CW_GKV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_GKV = pd.DataFrame()
    y2_2022_GKV = pd.DataFrame()
    F_2022_2y_GKV = pd.DataFrame()

    y1_2022_GKV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_GKV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_GKV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_GKV = y1_2022_GKV.loc[(y1_2022_GKV['GKV_sharpe > 0'] == True) & (y1_2022_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y1_2022_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_GKV = y2_2022_GKV.loc[(y2_2022_GKV['GKV_sharpe > 0'] == True) & (y2_2022_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y2_2022_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_GKV = F_2022_2y_GKV.loc[(F_2022_2y_GKV['GKV_sharpe > 0'] == True) & (F_2022_2y_GKV['GKV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKV = pd.merge(Filtered_y1_2022_GKV, Filtered_y2_2022_GKV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/YZV/CW_YZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_YZV = pd.DataFrame()
    y2_2022_YZV = pd.DataFrame()
    F_2022_2y_YZV = pd.DataFrame()

    y1_2022_YZV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_YZV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_YZV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_YZV = y1_2022_YZV.loc[(y1_2022_YZV['YZV_sharpe > 0'] == True) & (y1_2022_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y1_2022_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_YZV = y2_2022_YZV.loc[(y2_2022_YZV['YZV_sharpe > 0'] == True) & (y2_2022_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y2_2022_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_YZV = F_2022_2y_YZV.loc[(F_2022_2y_YZV['YZV_sharpe > 0'] == True) & (F_2022_2y_YZV['YZV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_YZV = pd.merge(Filtered_y1_2022_YZV, Filtered_y2_2022_YZV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKYZV/CW_GKYZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_GKYZV = pd.DataFrame()
    y2_2022_GKYZV = pd.DataFrame()
    F_2022_2y_GKYZV = pd.DataFrame()

    y1_2022_GKYZV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_GKYZV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_GKYZV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_GKYZV = y1_2022_GKYZV.loc[(y1_2022_GKYZV['GKYZV_sharpe > 0'] == True) & (y1_2022_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y1_2022_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_GKYZV = y2_2022_GKYZV.loc[(y2_2022_GKYZV['GKYZV_sharpe > 0'] == True) & (y2_2022_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y2_2022_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_GKYZV = F_2022_2y_GKYZV.loc[(F_2022_2y_GKYZV['GKYZV_sharpe > 0'] == True) & (F_2022_2y_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKYZV = pd.merge(Filtered_y1_2022_GKYZV, Filtered_y2_2022_GKYZV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/RSV/CW_RSV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2022_RSV = pd.DataFrame()
    y2_2022_RSV = pd.DataFrame()
    F_2022_2y_RSV = pd.DataFrame()

    y1_2022_RSV = file_1.loc[file_1['Year'] == '2022_y1']
    y2_2022_RSV = file_1.loc[file_1['Year'] == '2022_y2']
    F_2022_2y_RSV = file_1.loc[file_1['Year'] == '2022_2y']

    Filtered_y1_2022_RSV = y1_2022_RSV.loc[(y1_2022_RSV['RSV_sharpe > 0'] == True) & (y1_2022_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y1_2022_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2022_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2022_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2022_RSV = y2_2022_RSV.loc[(y2_2022_RSV['RSV_sharpe > 0'] == True) & (y2_2022_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y2_2022_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2022_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2022_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2022_2y_RSV = F_2022_2y_RSV.loc[(F_2022_2y_RSV['RSV_sharpe > 0'] == True) & (F_2022_2y_RSV['RSV_sharpe > Pure_sharpe'] == True) & (F_2022_2y_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2022_2y_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2022_2y_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_RSV = pd.merge(Filtered_y1_2022_RSV, Filtered_y2_2022_RSV, on=['Strategy'])

    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [common_rows_HV['Strategy'], common_rows_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_1['Strategy'], common_rows_CCV['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_2['Strategy'], common_rows_GKV['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_3['Strategy'], common_rows_YZV['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_4['Strategy'], common_rows_GKYZV['Strategy']])
    Filtered_y1_y2_2022 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_5['Strategy'], common_rows_RSV['Strategy']])


    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_HV['Strategy'], Filtered_2022_2y_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_CCV['Strategy'], common_rows_2y_1['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_GKV['Strategy'], common_rows_2y_2['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_YZV['Strategy'], common_rows_2y_3['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_GKYZV['Strategy'], common_rows_2y_4['Strategy']])
    Filtered_2y_2022 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2022_2y_RSV['Strategy'], common_rows_2y_5['Strategy']])


    return Filtered_2y_2022, Filtered_2022_2y_HV, Filtered_2022_2y_PV, Filtered_2022_2y_CCV, Filtered_2022_2y_GKV, Filtered_2022_2y_YZV, Filtered_2022_2y_GKYZV, Filtered_2022_2y_RSV

# %%
def select_strategy_2024():
    path = '/content/drive/MyDrive/Strategy/MA/HV/HV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_HV = pd.DataFrame()
    y2_2024_HV = pd.DataFrame()
    F_2024_2y1_HV = pd.DataFrame()

    y1_2024_HV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_HV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_HV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_HV = y1_2024_HV.loc[(y1_2024_HV['HV_sharpe > 0'] == True) & (y1_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y1_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_HV = y2_2024_HV.loc[(y2_2024_HV['HV_sharpe > 0'] == True) & (y2_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y2_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_HV = F_2024_2y1_HV.loc[(F_2024_2y1_HV['HV_sharpe > 0'] == True) & (F_2024_2y1_HV['HV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_HV = pd.merge(Filtered_y1_2024_HV, Filtered_y2_2024_HV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/PV/PV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_PV = pd.DataFrame()
    y2_2024_PV = pd.DataFrame()
    F_2024_2y1_PV = pd.DataFrame()

    y1_2024_PV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_PV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_PV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_PV = y1_2024_PV.loc[(y1_2024_PV['PV_sharpe > 0'] == True) & (y1_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y1_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_PV = y2_2024_PV.loc[(y2_2024_PV['PV_sharpe > 0'] == True) & (y2_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y2_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_PV = F_2024_2y1_PV.loc[(F_2024_2y1_PV['PV_sharpe > 0'] == True) & (F_2024_2y1_PV['PV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_PV = pd.merge(Filtered_y1_2024_PV, Filtered_y2_2024_PV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/CCV/CCV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_CCV = pd.DataFrame()
    y2_2024_CCV = pd.DataFrame()
    F_2024_2y1_CCV = pd.DataFrame()

    y1_2024_CCV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_CCV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_CCV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_CCV = y1_2024_CCV.loc[(y1_2024_CCV['CCV_sharpe > 0'] == True) & (y1_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y1_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_CCV = y2_2024_CCV.loc[(y2_2024_CCV['CCV_sharpe > 0'] == True) & (y2_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y2_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_CCV = F_2024_2y1_CCV.loc[(F_2024_2y1_CCV['CCV_sharpe > 0'] == True) & (F_2024_2y1_CCV['CCV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_CCV = pd.merge(Filtered_y1_2024_CCV, Filtered_y2_2024_CCV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKV/GKV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_GKV = pd.DataFrame()
    y2_2024_GKV = pd.DataFrame()
    F_2024_2y1_GKV = pd.DataFrame()

    y1_2024_GKV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_GKV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_GKV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_GKV = y1_2024_GKV.loc[(y1_2024_GKV['GKV_sharpe > 0'] == True) & (y1_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_GKV = y2_2024_GKV.loc[(y2_2024_GKV['GKV_sharpe > 0'] == True) & (y2_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_GKV = F_2024_2y1_GKV.loc[(F_2024_2y1_GKV['GKV_sharpe > 0'] == True) & (F_2024_2y1_GKV['GKV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKV = pd.merge(Filtered_y1_2024_GKV, Filtered_y2_2024_GKV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/YZV/YZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_YZV = pd.DataFrame()
    y2_2024_YZV = pd.DataFrame()
    F_2024_2y1_YZV = pd.DataFrame()

    y1_2024_YZV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_YZV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_YZV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_YZV = y1_2024_YZV.loc[(y1_2024_YZV['YZV_sharpe > 0'] == True) & (y1_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y1_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_YZV = y2_2024_YZV.loc[(y2_2024_YZV['YZV_sharpe > 0'] == True) & (y2_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y2_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_YZV = F_2024_2y1_YZV.loc[(F_2024_2y1_YZV['YZV_sharpe > 0'] == True) & (F_2024_2y1_YZV['YZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_YZV = pd.merge(Filtered_y1_2024_YZV, Filtered_y2_2024_YZV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKYZV/GKYZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_GKYZV = pd.DataFrame()
    y2_2024_GKYZV = pd.DataFrame()
    F_2024_2y1_GKYZV = pd.DataFrame()

    y1_2024_GKYZV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_GKYZV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_GKYZV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_GKYZV = y1_2024_GKYZV.loc[(y1_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y1_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_GKYZV = y2_2024_GKYZV.loc[(y2_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y2_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_GKYZV = F_2024_2y1_GKYZV.loc[(F_2024_2y1_GKYZV['GKYZV_sharpe > 0'] == True) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKYZV = pd.merge(Filtered_y1_2024_GKYZV, Filtered_y2_2024_GKYZV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/RSV/RSV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_RSV = pd.DataFrame()
    y2_2024_RSV = pd.DataFrame()
    F_2024_2y1_RSV = pd.DataFrame()

    y1_2024_RSV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_RSV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_RSV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_RSV = y1_2024_RSV.loc[(y1_2024_RSV['RSV_sharpe > 0'] == True) & (y1_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y1_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_RSV = y2_2024_RSV.loc[(y2_2024_RSV['RSV_sharpe > 0'] == True) & (y2_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y2_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_RSV = F_2024_2y1_RSV.loc[(F_2024_2y1_RSV['RSV_sharpe > 0'] == True) & (F_2024_2y1_RSV['RSV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_RSV = pd.merge(Filtered_y1_2024_RSV, Filtered_y2_2024_RSV, on=['Strategy'])

    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [common_rows_HV['Strategy'], common_rows_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_1['Strategy'], common_rows_CCV['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_2['Strategy'], common_rows_GKV['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_3['Strategy'], common_rows_YZV['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_4['Strategy'], common_rows_GKYZV['Strategy']])
    Filtered_y1_y2_2024 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_5['Strategy'], common_rows_RSV['Strategy']])


    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_HV['Strategy'], Filtered_2024_2y1_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_CCV['Strategy'], common_rows_2y_1['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKV['Strategy'], common_rows_2y_2['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_YZV['Strategy'], common_rows_2y_3['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKYZV['Strategy'], common_rows_2y_4['Strategy']])
    Filtered_2y_2024 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_RSV['Strategy'], common_rows_2y_5['Strategy']])


    return Filtered_2y_2024, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV

# %%
def select_strategy_dw_2024():
    path = '/content/drive/MyDrive/Strategy/MA/HV/DW_HV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_HV = pd.DataFrame()
    y2_2024_HV = pd.DataFrame()
    F_2024_2y1_HV = pd.DataFrame()

    y1_2024_HV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_HV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_HV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_HV = y1_2024_HV.loc[(y1_2024_HV['HV_sharpe > 0'] == True) & (y1_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y1_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_HV = y2_2024_HV.loc[(y2_2024_HV['HV_sharpe > 0'] == True) & (y2_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y2_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_HV = F_2024_2y1_HV.loc[(F_2024_2y1_HV['HV_sharpe > 0'] == True) & (F_2024_2y1_HV['HV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_HV = pd.merge(Filtered_y1_2024_HV, Filtered_y2_2024_HV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/PV/DW_PV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_PV = pd.DataFrame()
    y2_2024_PV = pd.DataFrame()
    F_2024_2y1_PV = pd.DataFrame()

    y1_2024_PV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_PV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_PV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_PV = y1_2024_PV.loc[(y1_2024_PV['PV_sharpe > 0'] == True) & (y1_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y1_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_PV = y2_2024_PV.loc[(y2_2024_PV['PV_sharpe > 0'] == True) & (y2_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y2_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_PV = F_2024_2y1_PV.loc[(F_2024_2y1_PV['PV_sharpe > 0'] == True) & (F_2024_2y1_PV['PV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_PV = pd.merge(Filtered_y1_2024_PV, Filtered_y2_2024_PV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/CCV/DW_CCV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_CCV = pd.DataFrame()
    y2_2024_CCV = pd.DataFrame()
    F_2024_2y1_CCV = pd.DataFrame()

    y1_2024_CCV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_CCV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_CCV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_CCV = y1_2024_CCV.loc[(y1_2024_CCV['CCV_sharpe > 0'] == True) & (y1_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y1_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_CCV = y2_2024_CCV.loc[(y2_2024_CCV['CCV_sharpe > 0'] == True) & (y2_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y2_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_CCV = F_2024_2y1_CCV.loc[(F_2024_2y1_CCV['CCV_sharpe > 0'] == True) & (F_2024_2y1_CCV['CCV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_CCV = pd.merge(Filtered_y1_2024_CCV, Filtered_y2_2024_CCV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKV/DW_GKV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_GKV = pd.DataFrame()
    y2_2024_GKV = pd.DataFrame()
    F_2024_2y1_GKV = pd.DataFrame()

    y1_2024_GKV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_GKV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_GKV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_GKV = y1_2024_GKV.loc[(y1_2024_GKV['GKV_sharpe > 0'] == True) & (y1_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_GKV = y2_2024_GKV.loc[(y2_2024_GKV['GKV_sharpe > 0'] == True) & (y2_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_GKV = F_2024_2y1_GKV.loc[(F_2024_2y1_GKV['GKV_sharpe > 0'] == True) & (F_2024_2y1_GKV['GKV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKV = pd.merge(Filtered_y1_2024_GKV, Filtered_y2_2024_GKV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/YZV/DW_YZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_YZV = pd.DataFrame()
    y2_2024_YZV = pd.DataFrame()
    F_2024_2y1_YZV = pd.DataFrame()

    y1_2024_YZV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_YZV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_YZV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_YZV = y1_2024_YZV.loc[(y1_2024_YZV['YZV_sharpe > 0'] == True) & (y1_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y1_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_YZV = y2_2024_YZV.loc[(y2_2024_YZV['YZV_sharpe > 0'] == True) & (y2_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y2_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_YZV = F_2024_2y1_YZV.loc[(F_2024_2y1_YZV['YZV_sharpe > 0'] == True) & (F_2024_2y1_YZV['YZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_YZV = pd.merge(Filtered_y1_2024_YZV, Filtered_y2_2024_YZV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKYZV/DW_GKYZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_GKYZV = pd.DataFrame()
    y2_2024_GKYZV = pd.DataFrame()
    F_2024_2y1_GKYZV = pd.DataFrame()

    y1_2024_GKYZV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_GKYZV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_GKYZV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_GKYZV = y1_2024_GKYZV.loc[(y1_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y1_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_GKYZV = y2_2024_GKYZV.loc[(y2_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y2_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_GKYZV = F_2024_2y1_GKYZV.loc[(F_2024_2y1_GKYZV['GKYZV_sharpe > 0'] == True) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKYZV = pd.merge(Filtered_y1_2024_GKYZV, Filtered_y2_2024_GKYZV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/RSV/DW_RSV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_RSV = pd.DataFrame()
    y2_2024_RSV = pd.DataFrame()
    F_2024_2y1_RSV = pd.DataFrame()

    y1_2024_RSV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_RSV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_RSV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_RSV = y1_2024_RSV.loc[(y1_2024_RSV['RSV_sharpe > 0'] == True) & (y1_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y1_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_RSV = y2_2024_RSV.loc[(y2_2024_RSV['RSV_sharpe > 0'] == True) & (y2_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y2_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_RSV = F_2024_2y1_RSV.loc[(F_2024_2y1_RSV['RSV_sharpe > 0'] == True) & (F_2024_2y1_RSV['RSV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_RSV = pd.merge(Filtered_y1_2024_RSV, Filtered_y2_2024_RSV, on=['Strategy'])

    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [common_rows_HV['Strategy'], common_rows_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_1['Strategy'], common_rows_CCV['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_2['Strategy'], common_rows_GKV['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_3['Strategy'], common_rows_YZV['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_4['Strategy'], common_rows_GKYZV['Strategy']])
    Filtered_y1_y2_2024 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_5['Strategy'], common_rows_RSV['Strategy']])


    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_HV['Strategy'], Filtered_2024_2y1_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_CCV['Strategy'], common_rows_2y_1['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKV['Strategy'], common_rows_2y_2['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_YZV['Strategy'], common_rows_2y_3['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKYZV['Strategy'], common_rows_2y_4['Strategy']])
    Filtered_2y_2024 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_RSV['Strategy'], common_rows_2y_5['Strategy']])


    return Filtered_2y_2024, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV

# %%
def select_strategy_cw_2024():
    path = '/content/drive/MyDrive/Strategy/MA/HV/CW_HV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_HV = pd.DataFrame()
    y2_2024_HV = pd.DataFrame()
    F_2024_2y1_HV = pd.DataFrame()

    y1_2024_HV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_HV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_HV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_HV = y1_2024_HV.loc[(y1_2024_HV['HV_sharpe > 0'] == True) & (y1_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y1_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_HV = y2_2024_HV.loc[(y2_2024_HV['HV_sharpe > 0'] == True) & (y2_2024_HV['HV_sharpe > Pure_sharpe'] == True) & (y2_2024_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_HV = F_2024_2y1_HV.loc[(F_2024_2y1_HV['HV_sharpe > 0'] == True) & (F_2024_2y1_HV['HV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_HV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_HV['HV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_HV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_HV = pd.merge(Filtered_y1_2024_HV, Filtered_y2_2024_HV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/PV/CW_PV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_PV = pd.DataFrame()
    y2_2024_PV = pd.DataFrame()
    F_2024_2y1_PV = pd.DataFrame()

    y1_2024_PV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_PV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_PV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_PV = y1_2024_PV.loc[(y1_2024_PV['PV_sharpe > 0'] == True) & (y1_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y1_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_PV = y2_2024_PV.loc[(y2_2024_PV['PV_sharpe > 0'] == True) & (y2_2024_PV['PV_sharpe > Pure_sharpe'] == True) & (y2_2024_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_PV = F_2024_2y1_PV.loc[(F_2024_2y1_PV['PV_sharpe > 0'] == True) & (F_2024_2y1_PV['PV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_PV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_PV['PV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_PV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_PV = pd.merge(Filtered_y1_2024_PV, Filtered_y2_2024_PV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/CCV/CW_CCV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_CCV = pd.DataFrame()
    y2_2024_CCV = pd.DataFrame()
    F_2024_2y1_CCV = pd.DataFrame()

    y1_2024_CCV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_CCV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_CCV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_CCV = y1_2024_CCV.loc[(y1_2024_CCV['CCV_sharpe > 0'] == True) & (y1_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y1_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_CCV = y2_2024_CCV.loc[(y2_2024_CCV['CCV_sharpe > 0'] == True) & (y2_2024_CCV['CCV_sharpe > Pure_sharpe'] == True) & (y2_2024_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_CCV = F_2024_2y1_CCV.loc[(F_2024_2y1_CCV['CCV_sharpe > 0'] == True) & (F_2024_2y1_CCV['CCV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_CCV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_CCV['CCV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_CCV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_CCV = pd.merge(Filtered_y1_2024_CCV, Filtered_y2_2024_CCV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKV/CW_GKV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_GKV = pd.DataFrame()
    y2_2024_GKV = pd.DataFrame()
    F_2024_2y1_GKV = pd.DataFrame()

    y1_2024_GKV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_GKV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_GKV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_GKV = y1_2024_GKV.loc[(y1_2024_GKV['GKV_sharpe > 0'] == True) & (y1_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_GKV = y2_2024_GKV.loc[(y2_2024_GKV['GKV_sharpe > 0'] == True) & (y2_2024_GKV['GKV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_GKV = F_2024_2y1_GKV.loc[(F_2024_2y1_GKV['GKV_sharpe > 0'] == True) & (F_2024_2y1_GKV['GKV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKV['GKV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_GKV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKV = pd.merge(Filtered_y1_2024_GKV, Filtered_y2_2024_GKV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/YZV/CW_YZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_YZV = pd.DataFrame()
    y2_2024_YZV = pd.DataFrame()
    F_2024_2y1_YZV = pd.DataFrame()

    y1_2024_YZV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_YZV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_YZV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_YZV = y1_2024_YZV.loc[(y1_2024_YZV['YZV_sharpe > 0'] == True) & (y1_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y1_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_YZV = y2_2024_YZV.loc[(y2_2024_YZV['YZV_sharpe > 0'] == True) & (y2_2024_YZV['YZV_sharpe > Pure_sharpe'] == True) & (y2_2024_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_YZV = F_2024_2y1_YZV.loc[(F_2024_2y1_YZV['YZV_sharpe > 0'] == True) & (F_2024_2y1_YZV['YZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_YZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_YZV['YZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_YZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_YZV = pd.merge(Filtered_y1_2024_YZV, Filtered_y2_2024_YZV, on=['Strategy'])


    path = '/content/drive/MyDrive/Strategy/MA/GKYZV/CW_GKYZV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_GKYZV = pd.DataFrame()
    y2_2024_GKYZV = pd.DataFrame()
    F_2024_2y1_GKYZV = pd.DataFrame()

    y1_2024_GKYZV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_GKYZV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_GKYZV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_GKYZV = y1_2024_GKYZV.loc[(y1_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y1_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y1_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_GKYZV = y2_2024_GKYZV.loc[(y2_2024_GKYZV['GKYZV_sharpe > 0'] == True) & (y2_2024_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (y2_2024_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_GKYZV = F_2024_2y1_GKYZV.loc[(F_2024_2y1_GKYZV['GKYZV_sharpe > 0'] == True) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_GKYZV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_GKYZV['GKYZV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_GKYZV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_GKYZV = pd.merge(Filtered_y1_2024_GKYZV, Filtered_y2_2024_GKYZV, on=['Strategy'])

    path = '/content/drive/MyDrive/Strategy/MA/RSV/CW_RSV/'

    file_1name = 'file_1.csv'
    file_1 = pd.read_csv(path + file_1name)

    y1_2024_RSV = pd.DataFrame()
    y2_2024_RSV = pd.DataFrame()
    F_2024_2y1_RSV = pd.DataFrame()

    y1_2024_RSV = file_1.loc[file_1['Year'] == '2024_y1']
    y2_2024_RSV = file_1.loc[file_1['Year'] == '2024_y2']
    F_2024_2y1_RSV = file_1.loc[file_1['Year'] == '2024_2y1']

    Filtered_y1_2024_RSV = y1_2024_RSV.loc[(y1_2024_RSV['RSV_sharpe > 0'] == True) & (y1_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y1_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y1_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y1_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_y2_2024_RSV = y2_2024_RSV.loc[(y2_2024_RSV['RSV_sharpe > 0'] == True) & (y2_2024_RSV['RSV_sharpe > Pure_sharpe'] == True) & (y2_2024_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (y2_2024_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (y2_2024_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]
    Filtered_2024_2y1_RSV = F_2024_2y1_RSV.loc[(F_2024_2y1_RSV['RSV_sharpe > 0'] == True) & (F_2024_2y1_RSV['RSV_sharpe > Pure_sharpe'] == True) & (F_2024_2y1_RSV['Pred_sharpes > 0 (%)'] >= 62.5) & (F_2024_2y1_RSV['RSV_sharpe > Pred_sharpe (%)'] >= 62.5) & (F_2024_2y1_RSV['Pred_sharpe > Pure_sharpe (%)'] >= 62.5)]

    common_rows_RSV = pd.merge(Filtered_y1_2024_RSV, Filtered_y2_2024_RSV, on=['Strategy'])

    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [common_rows_HV['Strategy'], common_rows_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_1['Strategy'], common_rows_CCV['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_2['Strategy'], common_rows_GKV['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_3['Strategy'], common_rows_YZV['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_4['Strategy'], common_rows_GKYZV['Strategy']])
    Filtered_y1_y2_2024 = reduce(lambda left, right: pd.merge(left, right), [common_rows_2y_5['Strategy'], common_rows_RSV['Strategy']])


    common_rows_2y_1 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_HV['Strategy'], Filtered_2024_2y1_PV['Strategy']])
    common_rows_2y_2 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_CCV['Strategy'], common_rows_2y_1['Strategy']])
    common_rows_2y_3 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKV['Strategy'], common_rows_2y_2['Strategy']])
    common_rows_2y_4 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_YZV['Strategy'], common_rows_2y_3['Strategy']])
    common_rows_2y_5 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_GKYZV['Strategy'], common_rows_2y_4['Strategy']])
    Filtered_2y_2024 = reduce(lambda left, right: pd.merge(left, right), [Filtered_2024_2y1_RSV['Strategy'], common_rows_2y_5['Strategy']])


    return Filtered_2y_2024, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV

# %% [markdown]
# # Results

# %%
Filtered_2y_2022, Filtered_2022_2y_HV, Filtered_2022_2y_PV, Filtered_2022_2y_CCV, Filtered_2022_2y_GKV, Filtered_2022_2y_YZV, Filtered_2022_2y_GKYZV, Filtered_2022_2y_RSV = select_strategy_2022()

# %%
Filtered_2y_2024, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV = select_strategy_2024()

# %%
final_common_rows = final_select_strategy(Filtered_2y_2022, Filtered_2y_2024)

# %%
final_common_rows
# Out:
# Series([], Name: Strategy, dtype: object)

# %%
Filtered_2y_2022
# Out:
# Empty DataFrame
# Columns: [Strategy]
# Index: []

# %%
Filtered_2y_2024
# Out:
# Empty DataFrame
# Columns: [Strategy]
# Index: []

# %%
Filtered_2y_2022_dw, Filtered_2022_2y_HV, Filtered_2022_2y_PV, Filtered_2022_2y_CCV, Filtered_2022_2y_GKV, Filtered_2022_2y_YZV, Filtered_2022_2y_GKYZV, Filtered_2022_2y_RSV = select_strategy_dw_2022()

# %%
Filtered_2y_2024_dw, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV = select_strategy_dw_2024()

# %%
final_common_rows_dw = final_select_strategy(Filtered_2y_2022_dw, Filtered_2y_2022_dw)

# %%
final_common_rows_dw
# Out:
# Series([], Name: Strategy, dtype: object)

# %%
Filtered_2y_2022_dw
# Out:
# Empty DataFrame
# Columns: [Strategy]
# Index: []

# %%
Filtered_2022_2y_HV
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Year, Strategy, Abs, HV_sharpe > 0, HV_sharpe > Pure_sharpe, HV_dd > Pure_dd, Pred_sharpes > 0 (%), HV_sharpe > Pred_sharpe (%), HV_dd > Pred_dd (%), HV_tp > Pred_tp (%), Pred_sharpe > Pure_sharpe (%)]
# Index: []

# %%
Filtered_2y_2024_dw
# Out:
#        Strategy
# 0    Strategy_1
# 1    Strategy_1
# 2    Strategy_8
# 3    Strategy_8
# 4    Strategy_8
# ..          ...
# 87  Strategy_34
# 88  Strategy_34
# 89  Strategy_34
# 90  Strategy_34
# 91  Strategy_34
#
# [92 rows x 1 columns]

# %%
Filtered_2y_2022_cw, Filtered_2022_2y_HV, Filtered_2022_2y_PV, Filtered_2022_2y_CCV, Filtered_2022_2y_GKV, Filtered_2022_2y_YZV, Filtered_2022_2y_GKYZV, Filtered_2022_2y_RSV = select_strategy_cw_2022()

# %%
Filtered_2y_2024_cw, Filtered_2024_2y1_HV, Filtered_2024_2y1_PV, Filtered_2024_2y1_CCV, Filtered_2024_2y1_GKV, Filtered_2024_2y1_YZV, Filtered_2024_2y1_GKYZV, Filtered_2024_2y1_RSV = select_strategy_cw_2024()

# %%
final_common_rows_cw = final_select_strategy(Filtered_2y_2022_cw, Filtered_2y_2022_cw)

# %%
final_common_rows_cw
# Out:
# Series([], Name: Strategy, dtype: object)

# %%
Filtered_2y_2022_cw
# Out:
# Empty DataFrame
# Columns: [Strategy]
# Index: []

# %%
Filtered_2y_2024_cw
# Out:
# Empty DataFrame
# Columns: [Strategy]
# Index: []
