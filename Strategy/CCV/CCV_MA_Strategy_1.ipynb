# %%
import pandas as pd
import numpy as np
import yfinance as yf
from google.colab import drive
from datetime import datetime
import matplotlib.pyplot as plt
import builtins

# %% [markdown]
# # Loading data

# %%
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Volatility/'
path_1 = '/content/drive/MyDrive/Volatility/Predictions/CCV/'
path_2 = '/content/drive/MyDrive/Volatility/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/Not_normal_wc_real/'

def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

filename = 'CCV_data.csv'
CCV_dw = pd.read_csv(path_2 + filename)

filename = 'CCV_data.csv'
CCV_cw = pd.read_csv(path_3 + filename)

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path_1 + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path_1 + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path_1 + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path_1 + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path_1 + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(CCV_dw)
set_index(CCV_cw)

start = datetime(2020, 11, 5)
end = datetime(2022, 12, 23)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")

data_s['Close'] = ticker_historical.Close.values

start = datetime(2020, 10, 1)
end = datetime(2022, 12, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")

data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['CCV'] = volatility_proxies['CCV'].loc['2020-10-01':'2022-12-30'].values
data_s['CCV'] = volatility_proxies['CCV'].loc['2020-11-05':'2022-12-22'].values

data_l['CCV_dw'] = CCV_dw['CCV'].loc['2020-10-01':'2022-12-30'].values
data_s['CCV_dw'] = CCV_dw['CCV'].loc['2020-11-05':'2022-12-22'].values

data_l['CCV_cw'] = CCV_cw['CCV'].loc['2020-10-01':'2022-12-30'].values
data_s['CCV_cw'] = CCV_cw['CCV'].loc['2020-11-05':'2022-12-22'].values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2020-11-05':'2022-12-22']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2020-11-05':'2022-12-22']

data_2022_y1 = data_s.head(268)
data_2022_y2 = data_s.tail(269)
data_2022_2y = data_s
# Out:
# Mounted at /content/drive
# <ipython-input-2-36c97740868c>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %%
path_1 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/'
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/CCV/'
path_2 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
path_4 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/'

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path_1 + filename)

filename = 'CCV_data.csv'
CCV_dw = pd.read_csv(path_2 + filename)

filename = 'CCV_data.csv'
CCV_cw = pd.read_csv(path_3 + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path_4 + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path_4 + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(CCV_dw)
set_index(CCV_cw)

start = datetime(2022, 7, 14)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")
data_s['Close'] = ticker_historical.Close.values

start = datetime(2022, 5, 31)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")
data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['CCV'] = (volatility_proxies['CCV'].loc['2022-05-31':'2024-8-30']).values
data_s['CCV'] = (volatility_proxies['CCV'].loc['2022-07-14':'2024-8-30']).values

data_l['CCV_dw'] = (CCV_dw['CCV'].loc['2022-05-31':'2024-8-30']).values
data_s['CCV_dw'] = (CCV_dw['CCV'].loc['2022-07-14':'2024-8-30']).values

data_l['CCV_cw'] = (CCV_cw['CCV'].loc['2022-05-31':'2024-8-30']).values
data_s['CCV_cw'] = (CCV_cw['CCV'].loc['2022-07-14':'2024-8-30']).values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2022-07-14':'2024-8-30']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2022-07-14':'2024-8-30']

data_2024_y1 = data_s.head(268)
data_2024_y2 = data_s.tail(269)
data_2024_2y1 = data_s
# Out:
# <ipython-input-2-36c97740868c>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %% [markdown]
# # Strategy

# %% [markdown]
# ## Without volatility

# %%
def strategy(data, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0

  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# ## With volatility

# %%
def strategy_with_vol_1(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_2(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_3(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_4(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_5(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_6(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_7(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_8(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_9(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_10(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_11(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_12(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_13(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_14(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_15(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_16(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_17(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_18(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_19(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_20(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_21(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_22(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_23(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_24(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_25(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_26(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_27(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_28(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_29(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_30(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_31(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_32(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_33(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_34(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_35(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_36(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_37(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_38(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_39(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_40(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_41(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_42(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_43(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_44(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# # Backtest

# %%
def backtest_function(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, data_f[vol], short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
def backtest_function_abs(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, abs(data_f[vol]), short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
volatility = ['CCV', 'CCV_dw', 'CCV_cw', 'LSTM_pred', 'GRU_pred', 'LSTM_GRU_pred', 'BiLSTM_pred',
              'BiLSTM_GRU_pred', 'QRNN_pred', 'ESN_pred', 'BNN_pred']

# %%
def backtest(data_s, short_window=10, long_window=50):
  S1_results = backtest_function(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results = backtest_function(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results = backtest_function(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results = backtest_function(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results = backtest_function(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results = backtest_function(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results = backtest_function(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results = backtest_function(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results = backtest_function(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results = backtest_function(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results = backtest_function(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results = backtest_function(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results = backtest_function(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results = backtest_function(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results = backtest_function(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results = backtest_function(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results = backtest_function(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results = backtest_function(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results = backtest_function(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results = backtest_function(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results = backtest_function(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results = backtest_function(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results = backtest_function(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results = backtest_function(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results = backtest_function(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results = backtest_function(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results = backtest_function(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results = backtest_function(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results = backtest_function(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results = backtest_function(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results = backtest_function(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results = backtest_function(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results = backtest_function(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results = backtest_function(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results = backtest_function(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results = backtest_function(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results = backtest_function(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results = backtest_function(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results = backtest_function(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results = backtest_function(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results = backtest_function(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results = backtest_function(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results = backtest_function(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results = backtest_function(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results.loc[len(S1_results)] = new_row
  S2_results.loc[len(S2_results)] = new_row
  S3_results.loc[len(S3_results)] = new_row
  S4_results.loc[len(S4_results)] = new_row
  S5_results.loc[len(S5_results)] = new_row
  S6_results.loc[len(S6_results)] = new_row
  S7_results.loc[len(S7_results)] = new_row
  S8_results.loc[len(S8_results)] = new_row
  S9_results.loc[len(S9_results)] = new_row
  S10_results.loc[len(S10_results)] = new_row
  S11_results.loc[len(S11_results)] = new_row
  S12_results.loc[len(S12_results)] = new_row
  S13_results.loc[len(S13_results)] = new_row
  S14_results.loc[len(S14_results)] = new_row
  S15_results.loc[len(S15_results)] = new_row
  S16_results.loc[len(S16_results)] = new_row
  S17_results.loc[len(S17_results)] = new_row
  S18_results.loc[len(S18_results)] = new_row
  S19_results.loc[len(S19_results)] = new_row
  S20_results.loc[len(S20_results)] = new_row
  S21_results.loc[len(S21_results)] = new_row
  S22_results.loc[len(S22_results)] = new_row

  S23_results.loc[len(S23_results)] = new_row
  S24_results.loc[len(S24_results)] = new_row
  S25_results.loc[len(S25_results)] = new_row
  S26_results.loc[len(S26_results)] = new_row
  S27_results.loc[len(S27_results)] = new_row
  S28_results.loc[len(S28_results)] = new_row
  S29_results.loc[len(S29_results)] = new_row
  S30_results.loc[len(S30_results)] = new_row
  S31_results.loc[len(S31_results)] = new_row
  S32_results.loc[len(S32_results)] = new_row
  S33_results.loc[len(S33_results)] = new_row
  S34_results.loc[len(S34_results)] = new_row
  S35_results.loc[len(S35_results)] = new_row
  S36_results.loc[len(S36_results)] = new_row
  S37_results.loc[len(S37_results)] = new_row
  S38_results.loc[len(S38_results)] = new_row
  S39_results.loc[len(S39_results)] = new_row
  S40_results.loc[len(S40_results)] = new_row
  S41_results.loc[len(S41_results)] = new_row
  S42_results.loc[len(S42_results)] = new_row
  S43_results.loc[len(S43_results)] = new_row
  S44_results.loc[len(S44_results)] = new_row

  return S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results

# %%
def backtest_abs(data_s, short_window=10, long_window=50):
  S1_results_abs = backtest_function_abs(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results_abs = backtest_function_abs(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results_abs = backtest_function_abs(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results_abs = backtest_function_abs(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results_abs = backtest_function_abs(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results_abs = backtest_function_abs(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results_abs = backtest_function_abs(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results_abs = backtest_function_abs(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results_abs = backtest_function_abs(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results_abs = backtest_function_abs(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results_abs = backtest_function_abs(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results_abs = backtest_function_abs(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results_abs = backtest_function_abs(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results_abs = backtest_function_abs(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results_abs = backtest_function_abs(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results_abs = backtest_function_abs(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results_abs = backtest_function_abs(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results_abs = backtest_function_abs(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results_abs = backtest_function_abs(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results_abs = backtest_function_abs(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results_abs = backtest_function_abs(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results_abs = backtest_function_abs(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results_abs = backtest_function_abs(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results_abs = backtest_function_abs(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results_abs = backtest_function_abs(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results_abs = backtest_function_abs(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results_abs = backtest_function_abs(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results_abs = backtest_function_abs(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results_abs = backtest_function_abs(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results_abs = backtest_function_abs(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results_abs = backtest_function_abs(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results_abs = backtest_function_abs(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results_abs = backtest_function_abs(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results_abs = backtest_function_abs(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results_abs = backtest_function_abs(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results_abs = backtest_function_abs(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results_abs = backtest_function_abs(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results_abs = backtest_function_abs(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results_abs = backtest_function_abs(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results_abs = backtest_function_abs(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results_abs = backtest_function_abs(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results_abs = backtest_function_abs(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results_abs = backtest_function_abs(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results_abs = backtest_function_abs(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results_abs.loc[len(S1_results_abs)] = new_row
  S2_results_abs.loc[len(S2_results_abs)] = new_row
  S3_results_abs.loc[len(S3_results_abs)] = new_row
  S4_results_abs.loc[len(S4_results_abs)] = new_row
  S5_results_abs.loc[len(S5_results_abs)] = new_row
  S6_results_abs.loc[len(S6_results_abs)] = new_row
  S7_results_abs.loc[len(S7_results_abs)] = new_row
  S8_results_abs.loc[len(S8_results_abs)] = new_row
  S9_results_abs.loc[len(S9_results_abs)] = new_row
  S10_results_abs.loc[len(S10_results_abs)] = new_row
  S11_results_abs.loc[len(S11_results_abs)] = new_row
  S12_results_abs.loc[len(S12_results_abs)] = new_row
  S13_results_abs.loc[len(S13_results_abs)] = new_row
  S14_results_abs.loc[len(S14_results_abs)] = new_row
  S15_results_abs.loc[len(S15_results_abs)] = new_row
  S16_results_abs.loc[len(S16_results_abs)] = new_row
  S17_results_abs.loc[len(S17_results_abs)] = new_row
  S18_results_abs.loc[len(S18_results_abs)] = new_row
  S19_results_abs.loc[len(S19_results_abs)] = new_row
  S20_results_abs.loc[len(S20_results_abs)] = new_row
  S21_results_abs.loc[len(S21_results_abs)] = new_row
  S22_results_abs.loc[len(S22_results_abs)] = new_row

  S23_results_abs.loc[len(S23_results_abs)] = new_row
  S24_results_abs.loc[len(S24_results_abs)] = new_row
  S25_results_abs.loc[len(S25_results_abs)] = new_row
  S26_results_abs.loc[len(S26_results_abs)] = new_row
  S27_results_abs.loc[len(S27_results_abs)] = new_row
  S28_results_abs.loc[len(S28_results_abs)] = new_row
  S29_results_abs.loc[len(S29_results_abs)] = new_row
  S30_results_abs.loc[len(S30_results_abs)] = new_row
  S31_results_abs.loc[len(S31_results_abs)] = new_row
  S32_results_abs.loc[len(S32_results_abs)] = new_row
  S33_results_abs.loc[len(S33_results_abs)] = new_row
  S34_results_abs.loc[len(S34_results_abs)] = new_row
  S35_results_abs.loc[len(S35_results_abs)] = new_row
  S36_results_abs.loc[len(S36_results_abs)] = new_row
  S37_results_abs.loc[len(S37_results_abs)] = new_row
  S38_results_abs.loc[len(S38_results_abs)] = new_row
  S39_results_abs.loc[len(S39_results_abs)] = new_row
  S40_results_abs.loc[len(S40_results_abs)] = new_row
  S41_results_abs.loc[len(S41_results_abs)] = new_row
  S42_results_abs.loc[len(S42_results_abs)] = new_row
  S43_results_abs.loc[len(S43_results_abs)] = new_row
  S44_results_abs.loc[len(S44_results_abs)] = new_row

  return S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs

# %% [markdown]
# # Final Results

# %%
def check_strategy(data, CCV):

    sharpe_ratio_CCV = data.loc[data['Volatility'] == CCV, 'Sharpe ratio'].values[0]
    sharpe_ratio_pure = data.loc[data['Volatility'] == '__', 'Sharpe ratio'].values[0]

    max_drawdown_CCV = data.loc[data['Volatility'] == CCV, 'Max drawdown (%)'].values[0]
    max_drawdown_pure = data.loc[data['Volatility'] == '__', 'Max drawdown (%)'].values[0]

    total_profit_CCV = data.loc[data['Volatility'] == CCV, 'Total profit'].values[0]
    total_profit_pure = data.loc[data['Volatility'] == '__', 'Total profit'].values[0]

    is_CCV_sharpe_positive = sharpe_ratio_CCV > 0
    is_CCV_sharpe_greater_than_pure_sharpe = sharpe_ratio_CCV > sharpe_ratio_pure
    is_CCV_dd_greater_than_pure_dd = max_drawdown_CCV > max_drawdown_pure
    is_pure_tp_greater_than_CCV_tp = total_profit_pure > total_profit_CCV

    all_sharpes_greater_than_Pure_sharpe = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'CCV') & (data['Volatility'] != 'CCV_dw') & (data['Volatility'] != 'CCV_cw'), 'Sharpe ratio'] > sharpe_ratio_pure)
    all_sharpes_greater_than_Pure_sharpe_percentage = (all_sharpes_greater_than_Pure_sharpe.sum()/8) * 100

    positive_sharpes = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'CCV') & (data['Volatility'] != 'CCV_dw') & (data['Volatility'] != 'CCV_cw'), 'Sharpe ratio'] > 0)
    positive_sharpes_percentage = (positive_sharpes.sum()/8) * 100

    CCV_sharpe_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'CCV') & (data['Volatility'] != 'CCV_dw') & (data['Volatility'] != 'CCV_cw'), 'Sharpe ratio'] < sharpe_ratio_CCV)
    CCV_sharpe_greater_than_all_percentage = (CCV_sharpe_greater_than_all.sum()/8) * 100

    CCV_dd_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'CCV') & (data['Volatility'] != 'CCV_dw') & (data['Volatility'] != 'CCV_cw'), 'Max drawdown (%)'] < max_drawdown_CCV)
    CCV_dd_greater_than_all_percentage = (CCV_dd_greater_than_all.sum()/8) * 100

    CCV_tp_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'CCV') & (data['Volatility'] != 'CCV_dw') & (data['Volatility'] != 'CCV_cw'), 'Total profit'] < total_profit_CCV)
    CCV_tp_greater_than_all_percentage = (CCV_tp_greater_than_all.sum()/8) * 100

    return is_CCV_sharpe_positive, is_CCV_sharpe_greater_than_pure_sharpe, is_CCV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, CCV_sharpe_greater_than_all_percentage, CCV_dd_greater_than_all_percentage, CCV_tp_greater_than_all_percentage

# %%
def get_final_results(year, final_results, CCV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results[f'S{i}_results']

    if(CCV == 'CCV'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV_dw', 'CCV_cw'])]

    elif(CCV == 'CCV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV', 'CCV_cw'])]

    elif(CCV == 'CCV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV_dw', 'CCV'])]

    is_CCV_sharpe_positive, is_CCV_sharpe_greater_than_pure_sharpe, is_CCV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, CCV_sharpe_greater_than_all_percentage, CCV_dd_greater_than_all_percentage, CCV_tp_greater_than_all_percentage = check_strategy(strategy_result, CCV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '-',
                'CCV_sharpe > 0': is_CCV_sharpe_positive,
                'CCV_sharpe > Pure_sharpe': is_CCV_sharpe_greater_than_pure_sharpe,
                'CCV_dd > Pure_dd': is_CCV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'CCV_sharpe > Pred_sharpe (%)': CCV_sharpe_greater_than_all_percentage,
                'CCV_dd > Pred_dd (%)': CCV_dd_greater_than_all_percentage,
                'CCV_tp > Pred_tp (%)': CCV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
def get_final_results_1(year, final_results, CCV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results_abs[f'S{i}_results_abs']

    if(CCV == 'CCV'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV_dw', 'CCV_cw'])]
      # res_combined
      # res_combined = pd.concat(details, strategy_result.drop())

    elif(CCV == 'CCV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV', 'CCV_cw'])]

    elif(CCV == 'CCV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['CCV_dw', 'CCV'])]

    is_CCV_sharpe_positive, is_CCV_sharpe_greater_than_pure_sharpe, is_CCV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, CCV_sharpe_greater_than_all_percentage, CCV_dd_greater_than_all_percentage, CCV_tp_greater_than_all_percentage = check_strategy(strategy_result, CCV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '+',
                'CCV_sharpe > 0': is_CCV_sharpe_positive,
                'CCV_sharpe > Pure_sharpe': is_CCV_sharpe_greater_than_pure_sharpe,
                'CCV_dd > Pure_dd': is_CCV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'CCV_sharpe > Pred_sharpe (%)': CCV_sharpe_greater_than_all_percentage,
                'CCV_dd > Pred_dd (%)': CCV_dd_greater_than_all_percentage,
                'CCV_tp > Pred_tp (%)': CCV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'CCV_sharpe > 0', 'CCV_sharpe > Pure_sharpe',
                                              'CCV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'CCV_sharpe > Pred_sharpe (%)',
                                              'CCV_dd > Pred_dd (%)', 'CCV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

dw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'CCV_sharpe > 0', 'CCV_sharpe > Pure_sharpe',
                                              'CCV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'CCV_sharpe > Pred_sharpe (%)',
                                              'CCV_dd > Pred_dd (%)', 'CCV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

cw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'CCV_sharpe > 0', 'CCV_sharpe > Pure_sharpe',
                                              'CCV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'CCV_sharpe > Pred_sharpe (%)',
                                              'CCV_dd > Pred_dd (%)', 'CCV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

# %%
# details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# dw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# cw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y1', file, 'CCV')
get_final_results_1('2022_y1', file, 'CCV')

get_final_results('2022_y1', dw_file, 'CCV_dw')
get_final_results_1('2022_y1', dw_file, 'CCV_dw')

get_final_results('2022_y1', cw_file, 'CCV_cw')
get_final_results_1('2022_y1', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:51: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-4-b267510ae310>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-4-b267510ae310>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    121.600012      0.718771         -4.057562
# 1            CCV_dw    177.800691      0.933226         -4.023417
# 2            CCV_cw    159.970330      0.889011         -4.028262
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    148.737326      0.822346         -3.985167
# 5     LSTM_GRU_pred    148.737326      0.822346         -3.985167
# 6       BiLSTM_pred    157.038060      1.072543         -3.724506
# 7   BiLSTM_GRU_pred    153.257909      1.042925         -4.020988
# 8         QRNN_pred    142.146039      0.982212         -4.131197
# 9          ESN_pred    154.870568      1.065089         -4.020988
# 10         BNN_pred    186.949626      1.319946         -3.686139
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    139.741094      0.896828         -4.238904
# 1            CCV_dw    119.872651      0.495746         -6.061774
# 2            CCV_cw     76.246050      0.122959         -5.229675
# 3         LSTM_pred    139.939522      0.670459         -4.004621
# 4          GRU_pred    187.208155      1.139119         -3.944907
# 5     LSTM_GRU_pred    192.701270      1.183177         -3.926738
# 6       BiLSTM_pred    182.233463      1.040483         -3.984177
# 7   BiLSTM_GRU_pred    126.945096      0.661394         -4.671342
# 8         QRNN_pred     84.156695      0.546364         -4.131197
# 9          ESN_pred     39.878839     -0.176261         -5.633454
# 10         BNN_pred    222.968000      1.342270         -3.827974
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     75.505588      0.416057         -4.383277
# 1            CCV_dw    134.837954      0.685761         -4.414708
# 2            CCV_cw     64.536147      0.040784         -5.510792
# 3         LSTM_pred     86.874856      0.224629         -4.755476
# 4          GRU_pred    136.974172      0.675117         -3.841191
# 5     LSTM_GRU_pred    175.226740      1.026233         -3.766703
# 6       BiLSTM_pred    154.498925      0.867050         -4.768917
# 7   BiLSTM_GRU_pred    106.046855      0.510125         -4.131197
# 8         QRNN_pred     41.532159      0.093836         -4.339303
# 9          ESN_pred    -14.696066     -0.887540         -7.328235
# 10         BNN_pred    174.309364      1.032982         -4.252573
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    100.777294      0.596641         -3.880104
# 1            CCV_dw    112.217602      0.444785         -6.103495
# 2            CCV_cw     68.173613      0.060757         -5.359764
# 3         LSTM_pred    119.171233      0.501300         -4.004621
# 4          GRU_pred    177.106444      0.999249         -3.794133
# 5     LSTM_GRU_pred    197.195749      1.167319         -3.776659
# 6       BiLSTM_pred    149.339443      0.787780         -4.284651
# 7   BiLSTM_GRU_pred    125.608694      0.654422         -4.785322
# 8         QRNN_pred     70.511849      0.427969         -4.131197
# 9          ESN_pred     45.739655     -0.178850         -5.951729
# 10         BNN_pred    207.813597      1.230092         -3.876003
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    110.666185      0.650881         -4.609357
# 1            CCV_dw    117.391909      0.474942         -6.075231
# 2            CCV_cw     46.214579     -0.156610         -5.301520
# 3         LSTM_pred    139.939522      0.670459         -4.004621
# 4          GRU_pred    187.208155      1.139119         -3.944907
# 5     LSTM_GRU_pred    192.701270      1.183177         -3.926738
# 6       BiLSTM_pred    177.351715      1.002408         -4.000696
# 7   BiLSTM_GRU_pred    134.610363      0.726103         -4.639783
# 8         QRNN_pred    110.856259      0.783618         -4.131197
# 9          ESN_pred    126.479502      0.628622         -4.766163
# 10         BNN_pred    212.258789      1.263933         -3.861790
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     98.283211      0.617791         -4.353894
# 1            CCV_dw    189.207549      1.057819         -4.023417
# 2            CCV_cw    142.108003      0.719555         -3.976413
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    118.247670      0.485911         -4.304918
# 5     LSTM_GRU_pred    108.674323      0.404638         -4.304918
# 6       BiLSTM_pred    174.828953      1.233538         -3.659522
# 7   BiLSTM_GRU_pred    148.781439      1.025100         -4.020988
# 8         QRNN_pred     66.403246      0.337664         -4.339303
# 9          ESN_pred     57.054060      0.159263         -4.028262
# 10         BNN_pred    160.799469      1.039895         -4.284651
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    101.199058      0.581035         -3.894946
# 1            CCV_dw    175.191627      0.926068         -4.029453
# 2            CCV_cw    129.680928      0.595331         -4.405217
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    137.999917      0.674972         -3.909532
# 5     LSTM_GRU_pred    137.999917      0.674972         -3.909532
# 6       BiLSTM_pred    141.936011      0.957277         -4.284651
# 7   BiLSTM_GRU_pred    149.095312      1.010759         -4.020988
# 8         QRNN_pred     72.461452      0.412617         -5.373286
# 9          ESN_pred    118.264367      0.827048         -4.022668
# 10         BNN_pred    186.949626      1.319946         -3.686139
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    117.742488      0.687300         -4.071565
# 1            CCV_dw    175.191627      0.913335         -4.029453
# 2            CCV_cw    149.361867      0.769720         -4.028262
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    148.737326      0.822346         -3.985167
# 5     LSTM_GRU_pred    148.737326      0.822346         -3.985167
# 6       BiLSTM_pred    157.038060      1.072543         -3.724506
# 7   BiLSTM_GRU_pred    153.257909      1.042925         -4.020988
# 8         QRNN_pred    124.685344      0.848043         -4.131197
# 9          ESN_pred    191.188418      1.392146         -4.016676
# 10         BNN_pred    186.949626      1.319946         -3.686139
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    123.851105      0.876750         -4.020988
# 1            CCV_dw    157.079330      1.070681         -4.020988
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    141.176324      0.952978         -4.020988
# 8         QRNN_pred    125.151388      0.854817         -4.028262
# 9          ESN_pred    157.079330      0.966813         -4.028262
# 10         BNN_pred    141.176324      0.952978         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     157.07933      1.070681         -4.020988
# 1            CCV_dw     157.07933      1.070681         -4.020988
# 2            CCV_cw     157.07933      1.070681         -4.020988
# 3         LSTM_pred     157.07933      1.070681         -4.020988
# 4          GRU_pred     157.07933      1.070681         -4.020988
# 5     LSTM_GRU_pred     157.07933      1.070681         -4.020988
# 6       BiLSTM_pred     157.07933      1.070681         -4.020988
# 7   BiLSTM_GRU_pred     157.07933      1.070681         -4.020988
# 8         QRNN_pred     157.07933      1.070681         -4.020988
# 9          ESN_pred     157.07933      1.069071         -4.022668
# 10         BNN_pred     157.07933      1.070681         -4.020988
# 11               __     157.07933      1.070681         -4.020988
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     157.07933      1.070681         -4.020988
# 1            CCV_dw     157.07933      1.070681         -4.020988
# 2            CCV_cw     157.07933      1.070681         -4.020988
# 3         LSTM_pred     157.07933      1.070681         -4.020988
# 4          GRU_pred     157.07933      1.070681         -4.020988
# 5     LSTM_GRU_pred     157.07933      1.070681         -4.020988
# 6       BiLSTM_pred     157.07933      1.070681         -4.020988
# 7   BiLSTM_GRU_pred     157.07933      1.070681         -4.020988
# 8         QRNN_pred     157.07933      1.070681         -4.020988
# 9          ESN_pred     157.07933      1.080411         -4.016676
# 10         BNN_pred     157.07933      1.070681         -4.020988
# 11               __     157.07933      1.070681         -4.020988
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    107.122741      0.693061         -4.070503
# 1            CCV_dw    186.481641      1.001946         -4.023417
# 2            CCV_cw    157.549482      0.793480         -4.028262
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    166.781943      0.955639         -4.028262
# 5     LSTM_GRU_pred    181.087047      1.068279         -3.693035
# 6       BiLSTM_pred    177.911775      0.974785         -4.023417
# 7   BiLSTM_GRU_pred    179.997103      1.042925         -4.020988
# 8         QRNN_pred    132.864077      0.912370         -4.131197
# 9          ESN_pred    149.929159      1.063402         -4.020988
# 10         BNN_pred    173.961523      1.223912         -3.914511
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    191.780406      1.386672         -3.790815
# 1            CCV_dw    166.309531      0.854927         -4.084933
# 2            CCV_cw    162.901813      0.873253         -3.869343
# 3         LSTM_pred    151.723670      0.756574         -4.097542
# 4          GRU_pred    192.087407      1.105656         -3.927353
# 5     LSTM_GRU_pred    192.087407      1.105656         -3.927353
# 6       BiLSTM_pred    205.715871      1.217310         -3.894374
# 7   BiLSTM_GRU_pred     98.400314      0.414134         -5.949051
# 8         QRNN_pred    119.735795      0.860008         -4.228733
# 9          ESN_pred    151.225364      0.775873         -4.028262
# 10         BNN_pred    234.632914      1.485099         -3.923046
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     75.935261      0.414860         -5.171329
# 1            CCV_dw    151.743634      0.846649         -4.023417
# 2            CCV_cw     75.706329      0.367770         -4.137018
# 3         LSTM_pred    100.238238      0.348510         -5.306173
# 4          GRU_pred    164.911926      0.940271         -3.709825
# 5     LSTM_GRU_pred    160.796875      0.900703         -3.719282
# 6       BiLSTM_pred    191.930201      1.179760         -3.702712
# 7   BiLSTM_GRU_pred    100.821453      0.468260         -4.339303
# 8         QRNN_pred     35.670127      0.067003         -4.028262
# 9          ESN_pred     14.249832     -0.508796         -5.126589
# 10         BNN_pred    192.000032      1.176947         -4.103825
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    104.886552      0.690437         -4.543411
# 1            CCV_dw    163.725922      0.847657         -4.094002
# 2            CCV_cw     97.307046      0.339576         -4.145419
# 3         LSTM_pred    150.552493      0.754962         -4.004621
# 4          GRU_pred    149.361135      0.778628         -3.999914
# 5     LSTM_GRU_pred    160.260192      0.864036         -3.999214
# 6       BiLSTM_pred    172.555002      0.971449         -4.002136
# 7   BiLSTM_GRU_pred     97.097762      0.405269         -6.062346
# 8         QRNN_pred     46.309982      0.182248         -4.194473
# 9          ESN_pred    127.583098      0.595574         -4.028262
# 10         BNN_pred    224.258550      1.407865         -4.251221
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    130.620597      0.883796         -4.732401
# 1            CCV_dw    163.725922      0.834766         -4.094002
# 2            CCV_cw    125.975265      0.581035         -3.869343
# 3         LSTM_pred    151.723670      0.756574         -4.097542
# 4          GRU_pred    172.035320      0.953503         -3.966154
# 5     LSTM_GRU_pred    172.240455      0.955129         -3.965460
# 6       BiLSTM_pred    200.737158      1.179524         -3.910522
# 7   BiLSTM_GRU_pred    105.871425      0.478233         -5.908860
# 8         QRNN_pred     90.930837      0.609069         -4.131197
# 9          ESN_pred    173.817942      0.969002         -4.028262
# 10         BNN_pred    234.632914      1.485099         -3.923046
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     64.369434      0.382498         -5.306195
# 1            CCV_dw    165.368244      0.920532         -4.023417
# 2            CCV_cw    152.306130      1.044175         -3.778218
# 3         LSTM_pred    141.176324      0.952978         -4.020988
# 4          GRU_pred    137.426734      0.669158         -4.028262
# 5     LSTM_GRU_pred    187.167629      1.083809         -3.674560
# 6       BiLSTM_pred    171.291206      0.929238         -4.023417
# 7   BiLSTM_GRU_pred    154.712258      0.877861         -4.028262
# 8         QRNN_pred     48.714161      0.196660         -5.285716
# 9          ESN_pred     66.967816      0.069313         -5.058067
# 10         BNN_pred    149.881139      1.044220         -4.133122
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     49.795167      0.209625         -5.437908
# 1            CCV_dw    183.853346      0.994784         -4.029453
# 2            CCV_cw    165.660916      0.909362         -3.826700
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    145.196287      0.728670         -4.028262
# 5     LSTM_GRU_pred    164.987984      0.886566         -3.771334
# 6       BiLSTM_pred    162.920616      0.862044         -4.023417
# 7   BiLSTM_GRU_pred    175.737994      1.010759         -4.020988
# 8         QRNN_pred     59.488023      0.297654         -4.978120
# 9          ESN_pred    138.887469      1.001778         -4.020988
# 10         BNN_pred    164.096969      1.149428         -4.284651
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     77.853936      0.460514         -4.993705
# 1            CCV_dw    183.853346      0.982001         -4.029453
# 2            CCV_cw    171.330929      0.946145         -4.028262
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    156.564740      0.814945         -4.028262
# 5     LSTM_GRU_pred    170.744578      0.927684         -3.725858
# 6       BiLSTM_pred    177.911775      0.974785         -4.023417
# 7   BiLSTM_GRU_pred    179.997103      1.042925         -4.020988
# 8         QRNN_pred     87.440174      0.546045         -4.761539
# 9          ESN_pred    166.703654      1.210677         -4.020988
# 10         BNN_pred    173.961523      1.223912         -3.914511
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    125.151388      0.900789         -4.016676
# 1            CCV_dw    157.079330      1.070681         -4.020988
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    141.176324      0.952978         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    157.079330      1.080411         -4.016676
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    141.176324      0.920551         -4.028262
# 8         QRNN_pred    157.079330      1.069071         -4.022668
# 9          ESN_pred    144.259924      0.715664         -5.058067
# 10         BNN_pred    141.176324      0.952978         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     157.07933      1.070681         -4.020988
# 1            CCV_dw     157.07933      1.070681         -4.020988
# 2            CCV_cw     157.07933      1.070681         -4.020988
# 3         LSTM_pred     157.07933      1.070681         -4.020988
# 4          GRU_pred     157.07933      1.070681         -4.020988
# 5     LSTM_GRU_pred     157.07933      1.070681         -4.020988
# 6       BiLSTM_pred     157.07933      1.070681         -4.020988
# 7   BiLSTM_GRU_pred     157.07933      1.070681         -4.020988
# 8         QRNN_pred     157.07933      1.070681         -4.020988
# 9          ESN_pred     157.07933      1.070681         -4.020988
# 10         BNN_pred     157.07933      1.070681         -4.020988
# 11               __     157.07933      1.070681         -4.020988
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     157.07933      1.070681         -4.020988
# 1            CCV_dw     157.07933      1.070681         -4.020988
# 2            CCV_cw     157.07933      1.070681         -4.020988
# 3         LSTM_pred     157.07933      1.070681         -4.020988
# 4          GRU_pred     157.07933      1.070681         -4.020988
# 5     LSTM_GRU_pred     157.07933      1.070681         -4.020988
# 6       BiLSTM_pred     157.07933      1.070681         -4.020988
# 7   BiLSTM_GRU_pred     157.07933      1.070681         -4.020988
# 8         QRNN_pred     157.07933      1.070681         -4.020988
# 9          ESN_pred     157.07933      1.070681         -4.020988
# 10         BNN_pred     157.07933      1.070681         -4.020988
# 11               __     157.07933      1.070681         -4.020988
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    151.447674      1.066376         -4.020988
# 1            CCV_dw    182.648392      0.990298         -3.989872
# 2            CCV_cw    173.688847      1.126470         -3.691147
# 3         LSTM_pred    130.108556      0.581388         -4.154093
# 4          GRU_pred    181.526080      1.021874         -4.028262
# 5     LSTM_GRU_pred    183.010895      1.033415         -4.028262
# 6       BiLSTM_pred    190.943449      1.104431         -3.696466
# 7   BiLSTM_GRU_pred    118.348006      0.580938         -4.020988
# 8         QRNN_pred    101.587206      0.648082         -5.122932
# 9          ESN_pred    152.755104      0.801953         -4.086024
# 10         BNN_pred    230.056482      1.502733         -3.880979
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    143.907514      1.042138         -4.019672
# 1            CCV_dw     55.307201      0.164732         -5.356167
# 2            CCV_cw    100.156168      0.550573         -4.244093
# 3         LSTM_pred    142.555517      0.740209         -4.468715
# 4          GRU_pred    273.596514      2.157225         -3.459492
# 5     LSTM_GRU_pred    206.162588      1.318781         -3.574887
# 6       BiLSTM_pred    187.496778      1.098649         -3.933003
# 7   BiLSTM_GRU_pred    176.482431      1.420414         -4.028262
# 8         QRNN_pred     55.273145      0.141319         -4.120935
# 9          ESN_pred     13.314826     -0.488508         -5.021959
# 10         BNN_pred    168.431560      1.173903         -4.119965
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      9.639697     -0.557563         -5.692045
# 1            CCV_dw     31.139749     -0.118003         -4.893882
# 2            CCV_cw     97.249296      0.687651         -3.919491
# 3         LSTM_pred     83.654392      0.215959         -4.721130
# 4          GRU_pred    238.036508      2.482726         -2.420267
# 5     LSTM_GRU_pred    116.873969      0.684577         -2.989918
# 6       BiLSTM_pred    135.544044      0.889484         -2.517214
# 7   BiLSTM_GRU_pred     67.589729      0.418739         -4.028262
# 8         QRNN_pred     34.095728     -0.210665         -4.253489
# 9          ESN_pred     -8.679976     -0.964805         -4.885189
# 10         BNN_pred    121.171912      0.957463         -4.892511
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     24.268273     -0.070707         -5.044642
# 1            CCV_dw     42.922809      0.040110         -4.210749
# 2            CCV_cw    107.804981      0.680824         -4.484660
# 3         LSTM_pred     98.755794      0.372179         -4.721130
# 4          GRU_pred    259.810651      2.073426         -2.918200
# 5     LSTM_GRU_pred    138.069076      0.826259         -3.060950
# 6       BiLSTM_pred    134.954343      0.728788         -4.284651
# 7   BiLSTM_GRU_pred     72.685714      0.406085         -4.258705
# 8         QRNN_pred     63.020268      0.208741         -4.028262
# 9          ESN_pred     16.146486     -0.540401         -5.245811
# 10         BNN_pred    185.986151      1.427400         -4.035793
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    125.153056      0.918395         -4.124774
# 1            CCV_dw     98.535569      0.590098         -3.973480
# 2            CCV_cw    127.378823      0.825984         -3.865307
# 3         LSTM_pred    140.369447      0.713449         -4.507924
# 4          GRU_pred    269.380254      2.140117         -2.898751
# 5     LSTM_GRU_pred    160.837518      0.946100         -4.945930
# 6       BiLSTM_pred    167.196160      0.977945         -3.988615
# 7   BiLSTM_GRU_pred     71.944410      0.360265         -4.028262
# 8         QRNN_pred     51.875786      0.108683         -4.027508
# 9          ESN_pred     63.862485      0.002266         -5.208015
# 10         BNN_pred    166.566953      1.175317         -4.063642
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.461904      0.088269         -4.028262
# 1            CCV_dw    169.728436      1.107942         -3.793203
# 2            CCV_cw    207.667200      1.482417         -3.641904
# 3         LSTM_pred    116.453718      0.482676         -4.131197
# 4          GRU_pred    135.677480      0.701573         -4.598127
# 5     LSTM_GRU_pred    131.707186      0.721229         -4.223091
# 6       BiLSTM_pred    219.858901      1.637486         -3.140601
# 7   BiLSTM_GRU_pred     77.547994      0.452622         -4.028262
# 8         QRNN_pred     37.794610     -0.129311         -7.142721
# 9          ESN_pred     52.632502     -0.100164         -4.176815
# 10         BNN_pred    101.472184      0.488161         -4.174533
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.271836      0.431444         -4.022668
# 1            CCV_dw    143.642983      0.743784         -4.046888
# 2            CCV_cw    207.667200      1.482417         -3.641904
# 3         LSTM_pred    132.012199      0.611568         -4.131197
# 4          GRU_pred    156.370282      0.847254         -4.028262
# 5     LSTM_GRU_pred    127.522777      0.634119         -4.028262
# 6       BiLSTM_pred    164.931723      0.953803         -4.284651
# 7   BiLSTM_GRU_pred    106.717903      0.532865         -4.020988
# 8         QRNN_pred     57.158298      0.138955         -5.371545
# 9          ESN_pred     86.802487      0.237168         -5.245811
# 10         BNN_pred    171.699925      1.063806         -3.976645
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    123.958051      0.849936         -4.020988
# 1            CCV_dw    169.028524      0.899271         -4.040537
# 2            CCV_cw    211.584935      1.462376         -3.706620
# 3         LSTM_pred    141.757191      0.683749         -4.131197
# 4          GRU_pred    165.937925      0.903104         -4.028262
# 5     LSTM_GRU_pred    153.182451      0.771126         -4.028262
# 6       BiLSTM_pred    191.244523      1.108612         -3.696466
# 7   BiLSTM_GRU_pred    111.424773      0.545255         -4.020988
# 8         QRNN_pred     98.040743      0.633951         -4.132857
# 9          ESN_pred    137.967633      0.668202         -4.859146
# 10         BNN_pred    196.562674      1.251962         -3.934780
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.461904      0.088269         -4.028262
# 1            CCV_dw    141.837377      0.804302         -4.028262
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    141.176324      0.952978         -4.020988
# 4          GRU_pred    141.176324      0.962767         -4.016676
# 5     LSTM_GRU_pred    171.930061      1.195498         -4.028262
# 6       BiLSTM_pred    141.176324      0.952978         -4.020988
# 7   BiLSTM_GRU_pred    183.456144      1.310241         -4.028262
# 8         QRNN_pred    157.079330      0.886643         -4.253489
# 9          ESN_pred    135.313876      0.686944         -5.099161
# 10         BNN_pred    140.815002      0.950106         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    157.079330      1.069071         -4.022668
# 1            CCV_dw    157.079330      1.038576         -4.028262
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    141.176324      0.962767         -4.016676
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    141.176324      0.952978         -4.020988
# 8         QRNN_pred    157.079330      0.950627         -4.028262
# 9          ESN_pred    157.079330      0.794286         -5.245811
# 10         BNN_pred    141.176324      0.952978         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    157.079330      1.070681         -4.020988
# 1            CCV_dw    157.079330      1.070681         -4.020988
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    157.079330      1.070681         -4.020988
# 8         QRNN_pred    157.079330      1.070681         -4.020988
# 9          ESN_pred    157.079330      0.966813         -4.028262
# 10         BNN_pred    141.176324      0.952978         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     94.097440      0.625911         -4.020988
# 1            CCV_dw     86.675350      0.260226         -6.012940
# 2            CCV_cw    233.454900      1.514356         -3.609157
# 3         LSTM_pred    138.919592      0.673720         -4.093420
# 4          GRU_pred    201.865294      1.209824         -4.095234
# 5     LSTM_GRU_pred    190.506345      1.110768         -4.124785
# 6       BiLSTM_pred    176.586307      0.965636         -3.718621
# 7   BiLSTM_GRU_pred     49.425366     -0.021612         -6.739277
# 8         QRNN_pred    182.717799      1.295290         -4.028262
# 9          ESN_pred     38.776027     -0.225095         -5.043068
# 10         BNN_pred    227.026355      1.520372         -3.947527
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    146.087159      0.954919         -4.027508
# 1            CCV_dw     58.492731      0.195904         -5.806813
# 2            CCV_cw    178.111079      1.133074         -3.745731
# 3         LSTM_pred    146.186178      1.046834         -4.631572
# 4          GRU_pred    273.596514      2.157225         -3.459492
# 5     LSTM_GRU_pred    255.452793      1.963221         -2.503324
# 6       BiLSTM_pred    249.677704      1.938372         -3.531165
# 7   BiLSTM_GRU_pred     58.046368      0.198063         -6.396782
# 8         QRNN_pred    142.462505      0.774827         -5.233858
# 9          ESN_pred    102.609610      0.388451         -4.819543
# 10         BNN_pred     75.070751      0.363952         -6.195227
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -18.737754     -1.138066         -5.836452
# 1            CCV_dw    -15.115358     -0.816903         -5.355490
# 2            CCV_cw     62.147587      0.309013         -3.488194
# 3         LSTM_pred     79.304618      0.474855         -5.086107
# 4          GRU_pred    170.183697      1.917671         -1.487248
# 5     LSTM_GRU_pred     59.911872      0.079052         -2.469892
# 6       BiLSTM_pred    119.213676      1.094888         -2.272482
# 7   BiLSTM_GRU_pred     28.606109     -0.230083         -4.028262
# 8         QRNN_pred     40.708368     -0.204412         -4.253489
# 9          ESN_pred    -11.439585     -1.349550         -5.118789
# 10         BNN_pred     90.711295      0.695237         -4.892228
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.761372     -0.752648         -7.153869
# 1            CCV_dw     60.690854      0.236267         -4.362595
# 2            CCV_cw     64.266802      0.265373         -5.296127
# 3         LSTM_pred     75.450311      0.414678         -5.086107
# 4          GRU_pred    259.810651      2.073426         -2.918200
# 5     LSTM_GRU_pred    189.989567      1.706010         -2.546656
# 6       BiLSTM_pred    164.552894      1.378883         -3.401540
# 7   BiLSTM_GRU_pred     69.434992      0.393353         -4.028262
# 8         QRNN_pred      0.198355     -0.717013         -6.471806
# 9          ESN_pred      9.064176     -0.695831         -5.748421
# 10         BNN_pred    139.014367      1.093010         -4.299950
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     37.331499     -0.051142         -5.338611
# 1            CCV_dw     93.589949      0.548551         -4.335426
# 2            CCV_cw    115.135905      0.743392         -6.754224
# 3         LSTM_pred    106.707246      0.686956         -5.804481
# 4          GRU_pred    251.847393      2.104881         -4.704517
# 5     LSTM_GRU_pred    219.094081      1.710165         -2.537753
# 6       BiLSTM_pred    191.797046      1.535610         -3.060533
# 7   BiLSTM_GRU_pred     51.324293      0.136800         -4.028262
# 8         QRNN_pred     81.269634      0.232013         -5.233858
# 9          ESN_pred     26.982214     -0.408064         -6.929421
# 10         BNN_pred    130.510030      0.944435         -5.579074
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.461904      0.001446         -4.485631
# 1            CCV_dw     79.750081      0.184802         -4.094973
# 2            CCV_cw    118.863817      0.980396         -3.901731
# 3         LSTM_pred     96.718799      0.336971         -5.267190
# 4          GRU_pred    104.743626      0.490841         -4.257953
# 5     LSTM_GRU_pred     28.850065     -0.441186         -4.783941
# 6       BiLSTM_pred    187.557136      1.350189         -2.786684
# 7   BiLSTM_GRU_pred     41.732019      0.002191         -4.028262
# 8         QRNN_pred     40.708368     -0.204412         -4.253489
# 9          ESN_pred     16.498652     -0.735083         -4.006050
# 10         BNN_pred    123.856219      1.000157         -4.122666
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     32.284931     -0.106527         -5.695457
# 1            CCV_dw     91.049715      0.279795         -4.923614
# 2            CCV_cw    153.660217      1.075379         -3.819072
# 3         LSTM_pred     75.460065      0.123796         -5.446160
# 4          GRU_pred    163.458375      0.929833         -3.835756
# 5     LSTM_GRU_pred    123.036803      0.668948         -4.028262
# 6       BiLSTM_pred    156.994716      0.945848         -4.284651
# 7   BiLSTM_GRU_pred     18.128791     -0.422433         -4.432821
# 8         QRNN_pred     83.843107      0.267608         -4.883403
# 9          ESN_pred    -18.619850     -0.888268         -6.018942
# 10         BNN_pred    218.124984      1.601002         -3.954244
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     73.384171      0.463275         -4.028130
# 1            CCV_dw     95.944999      0.344844         -6.040168
# 2            CCV_cw    208.231357      1.497137         -3.707883
# 3         LSTM_pred    109.678230      0.428980         -4.678639
# 4          GRU_pred    150.427935      0.794243         -4.294833
# 5     LSTM_GRU_pred    166.182200      0.941689         -4.028262
# 6       BiLSTM_pred    161.910825      0.897473         -3.463870
# 7   BiLSTM_GRU_pred     38.541266     -0.151416         -6.343316
# 8         QRNN_pred    119.368763      0.816269         -4.028262
# 9          ESN_pred     31.529341     -0.300465         -5.316521
# 10         BNN_pred    217.210338      1.517257         -4.008860
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.461904      0.001446         -4.485631
# 1            CCV_dw    141.837377      0.804302         -4.028262
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    141.176324      0.952978         -4.020988
# 4          GRU_pred    141.176324      0.920551         -4.028262
# 5     LSTM_GRU_pred    125.151388      0.854817         -4.028262
# 6       BiLSTM_pred    141.176324      0.952978         -4.020988
# 7   BiLSTM_GRU_pred     41.732019      0.002191         -4.028262
# 8         QRNN_pred     40.708368     -0.204412         -4.253489
# 9          ESN_pred    115.831596      0.590329         -5.099161
# 10         BNN_pred    144.259924      0.977834         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    157.079330      0.966813         -4.028262
# 1            CCV_dw    157.079330      1.038576         -4.028262
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    141.176324      0.962767         -4.016676
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    141.176324      0.920551         -4.028262
# 8         QRNN_pred    157.079330      0.823470         -4.883403
# 9          ESN_pred    144.259924      0.697780         -5.245811
# 10         BNN_pred    140.815002      0.950106         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    157.079330      1.070681         -4.020988
# 1            CCV_dw    157.079330      1.070681         -4.020988
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    141.176324      0.952978         -4.020988
# 8         QRNN_pred    157.079330      1.038576         -4.028262
# 9          ESN_pred    157.079330      0.794286         -5.245811
# 10         BNN_pred    141.176324      0.952978         -4.020988
# 11               __    157.079330      1.070681         -4.020988

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    121.600012      0.718771         -4.057562
# 1            CCV_dw    161.437514      0.815241         -4.028262
# 2            CCV_cw    188.264389      1.078955         -4.028262
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    148.737326      0.822346         -3.985167
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    157.038060      1.072543         -3.724506
# 7   BiLSTM_GRU_pred    184.912946      0.992527         -4.023417
# 8         QRNN_pred    142.146039      0.982212         -4.131197
# 9          ESN_pred    160.754968      1.113851         -3.882427
# 10         BNN_pred    194.392662      1.378979         -3.679416
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    139.741094      0.896828         -4.238904
# 1            CCV_dw    135.718200      0.629096         -5.746994
# 2            CCV_cw    179.899288      1.018244         -3.758628
# 3         LSTM_pred    139.939522      0.670459         -4.004621
# 4          GRU_pred    187.208155      1.139119         -3.944907
# 5     LSTM_GRU_pred    153.201737      0.757072         -4.521195
# 6       BiLSTM_pred    182.233463      1.040483         -3.984177
# 7   BiLSTM_GRU_pred     92.284733      0.262913         -4.881483
# 8         QRNN_pred     84.156695      0.546364         -4.131197
# 9          ESN_pred    156.499348      0.924234         -5.305299
# 10         BNN_pred    227.006327      1.392715         -3.848471
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     75.505588      0.416057         -4.383277
# 1            CCV_dw    128.723435      0.626134         -5.782609
# 2            CCV_cw    162.600235      1.020004         -3.787402
# 3         LSTM_pred     86.874856      0.224629         -4.755476
# 4          GRU_pred    136.974172      0.675117         -3.841191
# 5     LSTM_GRU_pred    101.376150      0.643370         -4.484368
# 6       BiLSTM_pred    154.498925      0.867050         -4.768917
# 7   BiLSTM_GRU_pred     68.259913      0.061262         -4.343380
# 8         QRNN_pred     41.532159      0.093836         -4.339303
# 9          ESN_pred    163.268384      1.125442         -3.192401
# 10         BNN_pred    168.737970      0.952936         -4.252573
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    100.777294      0.596641         -3.880104
# 1            CCV_dw    125.843946      0.556323         -5.797399
# 2            CCV_cw    135.456347      0.716903         -3.794258
# 3         LSTM_pred    119.171233      0.501300         -4.004621
# 4          GRU_pred    177.106444      0.999249         -3.794133
# 5     LSTM_GRU_pred    165.039063      0.852660         -4.087687
# 6       BiLSTM_pred    149.339443      0.787780         -4.284651
# 7   BiLSTM_GRU_pred     59.977557     -0.024560         -5.043387
# 8         QRNN_pred     70.511849      0.427969         -4.131197
# 9          ESN_pred    180.706818      1.195433         -4.427138
# 10         BNN_pred    202.086263      1.211133         -3.903021
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    110.666185      0.650881         -4.609357
# 1            CCV_dw    101.664885      0.343353         -5.924638
# 2            CCV_cw    199.719775      1.235116         -3.714411
# 3         LSTM_pred    139.939522      0.670459         -4.004621
# 4          GRU_pred    187.208155      1.139119         -3.944907
# 5     LSTM_GRU_pred    153.201737      0.757072         -4.521195
# 6       BiLSTM_pred    177.351715      1.002408         -4.000696
# 7   BiLSTM_GRU_pred     88.628059      0.231070         -4.897880
# 8         QRNN_pred    110.856259      0.783618         -4.131197
# 9          ESN_pred    184.159533      1.190787         -5.441220
# 10         BNN_pred    221.656388      1.357117         -3.882469
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     98.283211      0.617791         -4.353894
# 1            CCV_dw    184.550437      1.052380         -4.028262
# 2            CCV_cw    199.067694      1.324302         -3.723898
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    118.247670      0.485911         -4.304918
# 5     LSTM_GRU_pred    140.815002      0.862454         -4.028262
# 6       BiLSTM_pred    174.828953      1.233538         -3.659522
# 7   BiLSTM_GRU_pred    150.333830      0.748890         -4.028262
# 8         QRNN_pred     66.403246      0.337664         -4.339303
# 9          ESN_pred    122.511293      0.768291         -3.813969
# 10         BNN_pred    157.896262      1.023008         -4.284651
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    101.199058      0.581035         -3.894946
# 1            CCV_dw    184.299164      1.006404         -4.028262
# 2            CCV_cw    160.907297      0.928020         -4.028262
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    137.999917      0.674972         -3.909532
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    141.936011      0.957277         -4.284651
# 7   BiLSTM_GRU_pred    170.491217      0.879692         -4.023417
# 8         QRNN_pred     72.461452      0.412617         -5.373286
# 9          ESN_pred    148.067563      1.086369         -3.716784
# 10         BNN_pred    194.392662      1.378979         -3.679416
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    117.742488      0.687300         -4.071565
# 1            CCV_dw    158.864697      0.795119         -4.028262
# 2            CCV_cw    178.018652      1.012170         -4.028262
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    148.737326      0.822346         -3.985167
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    157.038060      1.072543         -3.724506
# 7   BiLSTM_GRU_pred    184.912946      0.992527         -4.023417
# 8         QRNN_pred    124.685344      0.848043         -4.131197
# 9          ESN_pred    156.183900      1.122649         -3.744348
# 10         BNN_pred    194.392662      1.378979         -3.679416
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    123.851105      0.876750         -4.020988
# 1            CCV_dw    157.079330      1.070681         -4.020988
# 2            CCV_cw    183.456144      1.239638         -4.028262
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    140.815002      0.862454         -4.028262
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    157.079330      0.984328         -4.028262
# 8         QRNN_pred    125.151388      0.854817         -4.028262
# 9          ESN_pred    157.079330      0.966813         -4.028262
# 10         BNN_pred    141.176324      0.952978         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     157.07933      1.070681         -4.020988
# 1            CCV_dw     157.07933      1.070681         -4.020988
# 2            CCV_cw     160.60186      1.052570         -4.028262
# 3         LSTM_pred     157.07933      1.070681         -4.020988
# 4          GRU_pred     157.07933      1.070681         -4.020988
# 5     LSTM_GRU_pred     157.07933      1.070681         -4.020988
# 6       BiLSTM_pred     157.07933      1.070681         -4.020988
# 7   BiLSTM_GRU_pred     157.07933      1.070681         -4.020988
# 8         QRNN_pred     157.07933      1.070681         -4.020988
# 9          ESN_pred     157.07933      1.069071         -4.022668
# 10         BNN_pred     157.07933      1.070681         -4.020988
# 11               __     157.07933      1.070681         -4.020988
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     157.07933      1.070681         -4.020988
# 1            CCV_dw     157.07933      1.070681         -4.020988
# 2            CCV_cw     157.07933      1.038576         -4.028262
# 3         LSTM_pred     157.07933      1.070681         -4.020988
# 4          GRU_pred     157.07933      1.070681         -4.020988
# 5     LSTM_GRU_pred     157.07933      1.070681         -4.020988
# 6       BiLSTM_pred     157.07933      1.070681         -4.020988
# 7   BiLSTM_GRU_pred     157.07933      1.070681         -4.020988
# 8         QRNN_pred     157.07933      1.070681         -4.020988
# 9          ESN_pred     157.07933      1.080411         -4.016676
# 10         BNN_pred     157.07933      1.070681         -4.020988
# 11               __     157.07933      1.070681         -4.020988
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    107.122741      0.693061         -4.070503
# 1            CCV_dw    159.175273      0.795239         -4.429063
# 2            CCV_cw    181.078395      1.021175         -4.013581
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    166.781943      0.955639         -4.028262
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    177.911775      0.974785         -4.023417
# 7   BiLSTM_GRU_pred    179.341424      0.957411         -4.023417
# 8         QRNN_pred    132.864077      0.912370         -4.131197
# 9          ESN_pred    238.083495      1.766945         -3.659510
# 10         BNN_pred    179.168537      1.265777         -3.914511
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    191.780406      1.386672         -3.790815
# 1            CCV_dw    158.155159      0.793750         -4.439948
# 2            CCV_cw    188.169867      1.161734         -3.711120
# 3         LSTM_pred    151.723670      0.756574         -4.097542
# 4          GRU_pred    192.087407      1.105656         -3.927353
# 5     LSTM_GRU_pred    160.769337      0.829911         -4.002628
# 6       BiLSTM_pred    205.715871      1.217310         -3.894374
# 7   BiLSTM_GRU_pred    120.494481      0.504368         -4.768756
# 8         QRNN_pred    119.735795      0.860008         -4.228733
# 9          ESN_pred    203.655531      1.197408         -4.099914
# 10         BNN_pred    248.093618      1.590581         -3.932243
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     75.935261      0.414860         -5.171329
# 1            CCV_dw    166.325521      0.912893         -4.460448
# 2            CCV_cw    135.590387      1.035458         -3.788943
# 3         LSTM_pred    100.238238      0.348510         -5.306173
# 4          GRU_pred    164.911926      0.940271         -3.709825
# 5     LSTM_GRU_pred    105.270721      0.686733         -4.683834
# 6       BiLSTM_pred    191.930201      1.179760         -3.702712
# 7   BiLSTM_GRU_pred    113.007924      0.491401         -4.214153
# 8         QRNN_pred     35.670127      0.067003         -4.028262
# 9          ESN_pred    135.802808      0.762206         -2.876303
# 10         BNN_pred    254.851330      1.720096         -4.248880
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    104.886552      0.690437         -4.543411
# 1            CCV_dw    145.608893      0.708078         -4.457260
# 2            CCV_cw    175.696327      1.110377         -3.748440
# 3         LSTM_pred    150.552493      0.754962         -4.004621
# 4          GRU_pred    149.361135      0.778628         -3.999914
# 5     LSTM_GRU_pred    157.179201      0.802009         -4.015046
# 6       BiLSTM_pred    172.555002      0.971449         -4.002136
# 7   BiLSTM_GRU_pred     91.903043      0.262450         -4.906390
# 8         QRNN_pred     46.309982      0.182248         -4.194473
# 9          ESN_pred    179.678231      1.074352         -3.046969
# 10         BNN_pred    237.916333      1.516400         -4.248880
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    130.620597      0.883796         -4.732401
# 1            CCV_dw    136.866919      0.623261         -4.457260
# 2            CCV_cw    187.138996      1.207721         -3.869343
# 3         LSTM_pred    151.723670      0.756574         -4.097542
# 4          GRU_pred    172.035320      0.953503         -3.966154
# 5     LSTM_GRU_pred    160.769337      0.829911         -4.002628
# 6       BiLSTM_pred    200.737158      1.179524         -3.910522
# 7   BiLSTM_GRU_pred     98.829328      0.319553         -4.862779
# 8         QRNN_pred     90.930837      0.609069         -4.131197
# 9          ESN_pred    161.325565      0.896556         -4.031674
# 10         BNN_pred    248.093618      1.590581         -3.932243
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     64.369434      0.382498         -5.306195
# 1            CCV_dw    168.760794      0.915133         -4.504505
# 2            CCV_cw    155.528156      1.115264         -3.740369
# 3         LSTM_pred    141.176324      0.952978         -4.020988
# 4          GRU_pred    137.426734      0.669158         -4.028262
# 5     LSTM_GRU_pred    140.815002      0.950106         -4.020988
# 6       BiLSTM_pred    171.291206      0.929238         -4.023417
# 7   BiLSTM_GRU_pred    155.372672      0.798417         -4.023417
# 8         QRNN_pred     48.714161      0.196660         -5.285716
# 9          ESN_pred    147.320761      1.010761         -3.734548
# 10         BNN_pred    151.219455      1.066908         -4.284651
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     49.795167      0.209625         -5.437908
# 1            CCV_dw    168.088788      0.879867         -4.429063
# 2            CCV_cw    183.678646      1.087733         -3.691147
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    145.196287      0.728670         -4.028262
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    162.920616      0.862044         -4.023417
# 7   BiLSTM_GRU_pred    168.490033      0.874212         -4.023417
# 8         QRNN_pred     59.488023      0.297654         -4.978120
# 9          ESN_pred    176.426983      1.350660         -3.708861
# 10         BNN_pred    171.433117      1.208679         -4.284651
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     77.853936      0.460514         -4.993705
# 1            CCV_dw    159.175273      0.795239         -4.429063
# 2            CCV_cw    179.612510      1.011511         -4.028262
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    156.564740      0.814945         -4.028262
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    177.911775      0.974785         -4.023417
# 7   BiLSTM_GRU_pred    179.341424      0.957411         -4.023417
# 8         QRNN_pred     87.440174      0.546045         -4.761539
# 9          ESN_pred    184.949445      1.399939         -3.656896
# 10         BNN_pred    179.168537      1.265777         -3.914511
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    125.151388      0.900789         -4.016676
# 1            CCV_dw    157.079330      1.070681         -4.020988
# 2            CCV_cw    157.079330      0.950627         -4.028262
# 3         LSTM_pred    141.176324      0.952978         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    140.815002      0.950106         -4.020988
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    157.079330      1.070681         -4.020988
# 8         QRNN_pred    157.079330      1.069071         -4.022668
# 9          ESN_pred    157.079330      0.966813         -4.028262
# 10         BNN_pred    141.176324      0.952978         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     157.07933      1.070681         -4.020988
# 1            CCV_dw     157.07933      1.070681         -4.020988
# 2            CCV_cw     157.07933      1.070681         -4.020988
# 3         LSTM_pred     157.07933      1.070681         -4.020988
# 4          GRU_pred     157.07933      1.070681         -4.020988
# 5     LSTM_GRU_pred     157.07933      1.070681         -4.020988
# 6       BiLSTM_pred     157.07933      1.070681         -4.020988
# 7   BiLSTM_GRU_pred     157.07933      1.070681         -4.020988
# 8         QRNN_pred     157.07933      1.070681         -4.020988
# 9          ESN_pred     157.07933      1.070681         -4.020988
# 10         BNN_pred     157.07933      1.070681         -4.020988
# 11               __     157.07933      1.070681         -4.020988
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     157.07933      1.070681         -4.020988
# 1            CCV_dw     157.07933      1.070681         -4.020988
# 2            CCV_cw     157.07933      1.070681         -4.020988
# 3         LSTM_pred     157.07933      1.070681         -4.020988
# 4          GRU_pred     157.07933      1.070681         -4.020988
# 5     LSTM_GRU_pred     157.07933      1.070681         -4.020988
# 6       BiLSTM_pred     157.07933      1.070681         -4.020988
# 7   BiLSTM_GRU_pred     157.07933      1.070681         -4.020988
# 8         QRNN_pred     157.07933      1.070681         -4.020988
# 9          ESN_pred     157.07933      1.070681         -4.020988
# 10         BNN_pred     157.07933      1.070681         -4.020988
# 11               __     157.07933      1.070681         -4.020988
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    151.447674      1.066376         -4.020988
# 1            CCV_dw    103.378919      0.352587         -4.577031
# 2            CCV_cw    180.534372      1.175227         -3.675319
# 3         LSTM_pred    130.108556      0.581388         -4.154093
# 4          GRU_pred    181.526080      1.021874         -4.028262
# 5     LSTM_GRU_pred    125.153208      0.842132         -3.836420
# 6       BiLSTM_pred    190.943449      1.104431         -3.696466
# 7   BiLSTM_GRU_pred    176.924189      1.256905         -3.667662
# 8         QRNN_pred    101.587206      0.648082         -5.122932
# 9          ESN_pred    234.321291      1.467399         -3.672640
# 10         BNN_pred    241.532646      1.549852         -3.909501
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    143.907514      1.042138         -4.019672
# 1            CCV_dw    128.533429      0.894700         -6.040998
# 2            CCV_cw     64.288674      0.244931         -4.418476
# 3         LSTM_pred    142.555517      0.740209         -4.468715
# 4          GRU_pred    273.596514      2.157225         -3.459492
# 5     LSTM_GRU_pred     18.099368     -0.205389         -8.180717
# 6       BiLSTM_pred    187.496778      1.098649         -3.933003
# 7   BiLSTM_GRU_pred     55.770475     -0.056824         -6.109138
# 8         QRNN_pred     55.273145      0.141319         -4.120935
# 9          ESN_pred     70.820017      0.318891         -4.900022
# 10         BNN_pred     96.264012      0.557506         -4.965820
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      9.639697     -0.557563         -5.692045
# 1            CCV_dw     10.166957     -0.432230         -6.389490
# 2            CCV_cw     43.182729      0.038448         -5.491023
# 3         LSTM_pred     83.654392      0.215959         -4.721130
# 4          GRU_pred    238.036508      2.482726         -2.420267
# 5     LSTM_GRU_pred     34.451398     -0.073588         -5.464183
# 6       BiLSTM_pred    135.544044      0.889484         -2.517214
# 7   BiLSTM_GRU_pred    139.689500      0.832787         -3.909972
# 8         QRNN_pred     34.095728     -0.210665         -4.253489
# 9          ESN_pred     24.324621     -0.186690         -4.121439
# 10         BNN_pred     84.904824      0.558311         -4.533584
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     24.268273     -0.070707         -5.044642
# 1            CCV_dw     99.683619      0.648931         -6.184532
# 2            CCV_cw    122.000048      0.871610         -4.457385
# 3         LSTM_pred     98.755794      0.372179         -4.721130
# 4          GRU_pred    259.810651      2.073426         -2.918200
# 5     LSTM_GRU_pred     29.403071     -0.101932         -8.204161
# 6       BiLSTM_pred    134.954343      0.728788         -4.284651
# 7   BiLSTM_GRU_pred     75.387555      0.152122         -6.033297
# 8         QRNN_pred     63.020268      0.208741         -4.028262
# 9          ESN_pred     80.770676      0.453238         -4.396045
# 10         BNN_pred    138.725420      1.061681         -3.585344
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    125.153056      0.918395         -4.124774
# 1            CCV_dw    102.301060      0.644131         -6.230068
# 2            CCV_cw    120.949608      0.784067         -4.315556
# 3         LSTM_pred    140.369447      0.713449         -4.507924
# 4          GRU_pred    269.380254      2.140117         -2.898751
# 5     LSTM_GRU_pred     -6.425745     -0.468278         -8.444423
# 6       BiLSTM_pred    167.196160      0.977945         -3.988615
# 7   BiLSTM_GRU_pred     77.223570      0.140427         -6.023014
# 8         QRNN_pred     51.875786      0.108683         -4.027508
# 9          ESN_pred     93.057378      0.559587         -4.407041
# 10         BNN_pred     91.283376      0.513052         -4.814852
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.461904      0.088269         -4.028262
# 1            CCV_dw     49.352511     -0.092726         -6.196737
# 2            CCV_cw    220.205848      1.693880         -3.682177
# 3         LSTM_pred    116.453718      0.482676         -4.131197
# 4          GRU_pred    135.677480      0.701573         -4.598127
# 5     LSTM_GRU_pred    107.242327      0.646900         -3.871351
# 6       BiLSTM_pred    219.858901      1.637486         -3.140601
# 7   BiLSTM_GRU_pred     96.748881      0.601463         -3.957413
# 8         QRNN_pred     37.794610     -0.129311         -7.142721
# 9          ESN_pred    133.412194      0.676724         -3.776964
# 10         BNN_pred    225.545717      1.574330         -4.252687
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.271836      0.431444         -4.022668
# 1            CCV_dw     78.404908      0.184124         -5.780625
# 2            CCV_cw    240.882925      1.706992         -3.596945
# 3         LSTM_pred    132.012199      0.611568         -4.131197
# 4          GRU_pred    156.370282      0.847254         -4.028262
# 5     LSTM_GRU_pred    133.293306      0.931852         -3.808864
# 6       BiLSTM_pred    164.931723      0.953803         -4.284651
# 7   BiLSTM_GRU_pred    120.433083      0.868737         -3.852582
# 8         QRNN_pred     57.158298      0.138955         -5.371545
# 9          ESN_pred    174.444780      1.012989         -3.710614
# 10         BNN_pred    236.323415      1.554808         -3.908617
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    123.958051      0.849936         -4.020988
# 1            CCV_dw     99.486810      0.332908         -4.598006
# 2            CCV_cw    207.720581      1.422159         -3.695712
# 3         LSTM_pred    141.757191      0.683749         -4.131197
# 4          GRU_pred    165.937925      0.903104         -4.028262
# 5     LSTM_GRU_pred    108.927412      0.713631         -4.048760
# 6       BiLSTM_pred    191.244523      1.108612         -3.696466
# 7   BiLSTM_GRU_pred    152.546342      1.096404         -3.745238
# 8         QRNN_pred     98.040743      0.633951         -4.132857
# 9          ESN_pred    209.660052      1.305130         -3.688905
# 10         BNN_pred    224.617687      1.421498         -4.236986
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.461904      0.088269         -4.028262
# 1            CCV_dw    157.079330      1.038576         -4.028262
# 2            CCV_cw    164.759692      1.080858         -4.028262
# 3         LSTM_pred    141.176324      0.952978         -4.020988
# 4          GRU_pred    141.176324      0.962767         -4.016676
# 5     LSTM_GRU_pred    140.815002      0.862454         -4.028262
# 6       BiLSTM_pred    141.176324      0.952978         -4.020988
# 7   BiLSTM_GRU_pred    157.079330      1.022296         -4.028262
# 8         QRNN_pred    157.079330      0.886643         -4.253489
# 9          ESN_pred    157.079330      0.794286         -5.245811
# 10         BNN_pred    140.815002      0.959894         -4.016676
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    157.079330      1.069071         -4.022668
# 1            CCV_dw    157.079330      1.070681         -4.020988
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    157.079330      1.070681         -4.020988
# 8         QRNN_pred    157.079330      0.950627         -4.028262
# 9          ESN_pred    157.079330      0.950627         -4.028262
# 10         BNN_pred    141.176324      0.952978         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     157.07933      1.070681         -4.020988
# 1            CCV_dw     157.07933      1.070681         -4.020988
# 2            CCV_cw     157.07933      1.070681         -4.020988
# 3         LSTM_pred     157.07933      1.070681         -4.020988
# 4          GRU_pred     157.07933      1.070681         -4.020988
# 5     LSTM_GRU_pred     157.07933      1.070681         -4.020988
# 6       BiLSTM_pred     157.07933      1.070681         -4.020988
# 7   BiLSTM_GRU_pred     157.07933      1.070681         -4.020988
# 8         QRNN_pred     157.07933      1.070681         -4.020988
# 9          ESN_pred     157.07933      0.984328         -4.028262
# 10         BNN_pred     157.07933      1.070681         -4.020988
# 11               __     157.07933      1.070681         -4.020988
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     94.097440      0.625911         -4.020988
# 1            CCV_dw    116.967635      0.470539         -4.451046
# 2            CCV_cw    189.666565      1.295366         -3.738122
# 3         LSTM_pred    138.919592      0.673720         -4.093420
# 4          GRU_pred    201.865294      1.209824         -4.095234
# 5     LSTM_GRU_pred    122.708104      0.750519         -4.109353
# 6       BiLSTM_pred    176.586307      0.965636         -3.718621
# 7   BiLSTM_GRU_pred    160.140531      1.148604         -3.720722
# 8         QRNN_pred    182.717799      1.295290         -4.028262
# 9          ESN_pred    173.473933      0.985740         -5.190031
# 10         BNN_pred    215.581729      1.427221         -4.374408
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    146.087159      0.954919         -4.027508
# 1            CCV_dw    116.397828      0.801206         -4.524204
# 2            CCV_cw    167.638748      1.273940         -3.717138
# 3         LSTM_pred    146.186178      1.046834         -4.631572
# 4          GRU_pred    273.596514      2.157225         -3.459492
# 5     LSTM_GRU_pred     -4.468992     -0.452698         -8.517462
# 6       BiLSTM_pred    249.677704      1.938372         -3.531165
# 7   BiLSTM_GRU_pred    130.699933      0.619129         -6.375987
# 8         QRNN_pred    142.462505      0.774827         -5.233858
# 9          ESN_pred     -4.127835     -0.438794         -5.118365
# 10         BNN_pred    148.667532      1.078323         -3.036446
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -18.737754     -1.138066         -5.836452
# 1            CCV_dw     10.973999     -0.467562         -5.335411
# 2            CCV_cw     74.402839      0.431106         -3.763603
# 3         LSTM_pred     79.304618      0.474855         -5.086107
# 4          GRU_pred    170.183697      1.917671         -1.487248
# 5     LSTM_GRU_pred     48.750347      0.108922         -5.988256
# 6       BiLSTM_pred    119.213676      1.094888         -2.272482
# 7   BiLSTM_GRU_pred    158.573886      1.408670         -3.921980
# 8         QRNN_pred     40.708368     -0.204412         -4.253489
# 9          ESN_pred     -0.949805     -0.570917         -4.209528
# 10         BNN_pred    127.137791      1.185253         -2.409170
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.761372     -0.752648         -7.153869
# 1            CCV_dw     55.926779      0.187478         -4.783375
# 2            CCV_cw     89.599250      0.580334         -4.022771
# 3         LSTM_pred     75.450311      0.414678         -5.086107
# 4          GRU_pred    259.810651      2.073426         -2.918200
# 5     LSTM_GRU_pred     -5.111339     -0.509493         -9.900822
# 6       BiLSTM_pred    164.552894      1.378883         -3.401540
# 7   BiLSTM_GRU_pred    117.191646      0.569325         -4.299818
# 8         QRNN_pred      0.198355     -0.717013         -6.471806
# 9          ESN_pred     21.193458     -0.217672         -4.587690
# 10         BNN_pred    124.432438      0.983432         -4.202088
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     37.331499     -0.051142         -5.338611
# 1            CCV_dw     79.195276      0.437997         -4.675312
# 2            CCV_cw    206.517111      1.707156         -3.686253
# 3         LSTM_pred    106.707246      0.686956         -5.804481
# 4          GRU_pred    251.847393      2.104881         -4.704517
# 5     LSTM_GRU_pred     -2.855704     -0.447321         -8.639511
# 6       BiLSTM_pred    191.797046      1.535610         -3.060533
# 7   BiLSTM_GRU_pred    113.711375      0.476625         -6.473246
# 8         QRNN_pred     81.269634      0.232013         -5.233858
# 9          ESN_pred      6.286008     -0.358722         -4.757396
# 10         BNN_pred    117.386101      0.810305         -3.904420
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.461904      0.001446         -4.485631
# 1            CCV_dw     15.195592     -0.476470         -7.160284
# 2            CCV_cw    154.169313      1.224799         -3.853791
# 3         LSTM_pred     96.718799      0.336971         -5.267190
# 4          GRU_pred    104.743626      0.490841         -4.257953
# 5     LSTM_GRU_pred    138.988272      1.092030         -3.862511
# 6       BiLSTM_pred    187.557136      1.350189         -2.786684
# 7   BiLSTM_GRU_pred    110.726472      0.694622         -3.926087
# 8         QRNN_pred     40.708368     -0.204412         -4.253489
# 9          ESN_pred    109.342277      0.498983         -3.848606
# 10         BNN_pred    220.222162      1.855207         -4.110250
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     32.284931     -0.106527         -5.695457
# 1            CCV_dw     69.191495      0.087525         -5.929789
# 2            CCV_cw    165.117968      1.161156         -3.769025
# 3         LSTM_pred     75.460065      0.123796         -5.446160
# 4          GRU_pred    163.458375      0.929833         -3.835756
# 5     LSTM_GRU_pred    116.986382      0.740948         -4.119650
# 6       BiLSTM_pred    156.994716      0.945848         -4.284651
# 7   BiLSTM_GRU_pred    124.900310      0.922638         -3.837282
# 8         QRNN_pred     83.843107      0.267608         -4.883403
# 9          ESN_pred    138.387422      0.737267         -3.750411
# 10         BNN_pred    189.142152      1.376522         -3.664590
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     73.384171      0.463275         -4.028130
# 1            CCV_dw     84.788740      0.211093         -4.599166
# 2            CCV_cw    215.239236      1.551990         -3.691725
# 3         LSTM_pred    109.678230      0.428980         -4.678639
# 4          GRU_pred    150.427935      0.794243         -4.294833
# 5     LSTM_GRU_pred     94.417858      0.515468         -4.215578
# 6       BiLSTM_pred    161.910825      0.897473         -3.463870
# 7   BiLSTM_GRU_pred    155.882422      1.163289         -3.734428
# 8         QRNN_pred    119.368763      0.816269         -4.028262
# 9          ESN_pred    147.260527      0.817451         -4.231935
# 10         BNN_pred    173.968135      1.119448         -4.488450
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     55.461904      0.001446         -4.485631
# 1            CCV_dw    157.079330      1.038576         -4.028262
# 2            CCV_cw    164.759692      1.080858         -4.028262
# 3         LSTM_pred    141.176324      0.952978         -4.020988
# 4          GRU_pred    141.176324      0.920551         -4.028262
# 5     LSTM_GRU_pred    140.815002      0.862454         -4.028262
# 6       BiLSTM_pred    141.176324      0.952978         -4.020988
# 7   BiLSTM_GRU_pred    157.079330      0.984328         -4.028262
# 8         QRNN_pred     40.708368     -0.204412         -4.253489
# 9          ESN_pred    157.079330      0.794286         -5.245811
# 10         BNN_pred    140.815002      0.862454         -4.028262
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    157.079330      0.966813         -4.028262
# 1            CCV_dw    157.079330      1.070681         -4.020988
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    157.079330      1.070681         -4.020988
# 8         QRNN_pred    157.079330      0.823470         -4.883403
# 9          ESN_pred    157.079330      0.794286         -5.245811
# 10         BNN_pred    141.176324      0.952978         -4.020988
# 11               __    157.079330      1.070681         -4.020988
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    157.079330      1.070681         -4.020988
# 1            CCV_dw    157.079330      1.070681         -4.020988
# 2            CCV_cw    157.079330      1.070681         -4.020988
# 3         LSTM_pred    157.079330      1.070681         -4.020988
# 4          GRU_pred    157.079330      1.070681         -4.020988
# 5     LSTM_GRU_pred    157.079330      1.070681         -4.020988
# 6       BiLSTM_pred    157.079330      1.070681         -4.020988
# 7   BiLSTM_GRU_pred    157.079330      1.070681         -4.020988
# 8         QRNN_pred    157.079330      1.038576         -4.028262
# 9          ESN_pred    157.079330      0.984328         -4.028262
# 10         BNN_pred    141.176324      0.952978         -4.020988
# 11               __    157.079330      1.070681         -4.020988

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y2', file, 'CCV')
get_final_results_1('2022_y2', file, 'CCV')

get_final_results('2022_y2', dw_file, 'CCV_dw')
get_final_results_1('2022_y2', dw_file, 'CCV_dw')

get_final_results('2022_y2', cw_file, 'CCV_cw')
get_final_results_1('2022_y2', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:52: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-9-5a649d29e1cf>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-9-5a649d29e1cf>:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:30: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-9-5a649d29e1cf>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-9-5a649d29e1cf>:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:52: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-9-5a649d29e1cf>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-9-5a649d29e1cf>:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-9-5a649d29e1cf>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-9-5a649d29e1cf>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-9-5a649d29e1cf>:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-9-5a649d29e1cf>:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']
# <ipython-input-9-5a649d29e1cf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vol_Mean'] = volatility.rolling(window=10).mean()
# <ipython-input-9-5a649d29e1cf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vol_Std'] = volatility.rolling(window=10).std()
# <ipython-input-9-5a649d29e1cf>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
# <ipython-input-9-5a649d29e1cf>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
# <ipython-input-9-5a649d29e1cf>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vol_Low_Threshold'] = data['Vol_Mean']
# <ipython-input-9-5a649d29e1cf>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
# <ipython-input-9-5a649d29e1cf>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Long_MA'] = data['Close'].rolling(window=long_window).mean()
# <ipython-input-9-5a649d29e1cf>:13: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-9-5a649d29e1cf>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:52: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-9-5a649d29e1cf>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-9-5a649d29e1cf>:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:30: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-9-5a649d29e1cf>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-9-5a649d29e1cf>:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-9-5a649d29e1cf>:65: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-9-5a649d29e1cf>:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-9-5a649d29e1cf>:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-9-5a649d29e1cf>:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-9-5a649d29e1cf>:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']
# <ipython-input-9-5a649d29e1cf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Vol_Mean'] = volatility.rolling(window=10).mean()

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.105914     -0.595255        -10.260304
# 1            CCV_dw    -16.909795     -0.093997         -6.984195
# 2            CCV_cw      7.463384     -0.388017         -9.417281
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -69.584589     -0.888776        -11.581798
# 5     LSTM_GRU_pred    -69.584589     -0.888776        -11.581798
# 6       BiLSTM_pred    -67.814325     -0.514238        -10.180663
# 7   BiLSTM_GRU_pred    -50.690601     -0.714826         -9.841785
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred    -17.218032     -0.665558         -9.904078
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      0.412830     -0.520869         -9.372811
# 1            CCV_dw     24.246730     -0.107743         -6.695927
# 2            CCV_cw    -24.636646     -0.507638         -9.974771
# 3         LSTM_pred    -52.184565     -0.997769        -10.143821
# 4          GRU_pred    -69.153516     -0.890547        -11.346776
# 5     LSTM_GRU_pred    -82.862158     -1.020005        -11.581798
# 6       BiLSTM_pred    -72.563028     -0.820530        -10.314616
# 7   BiLSTM_GRU_pred    -89.376885     -0.945022        -11.468121
# 8         QRNN_pred     10.111867     -0.393892         -8.051887
# 9          ESN_pred      2.781491     -0.473146         -9.527381
# 10         BNN_pred      9.492727     -0.536449         -9.221644
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -13.719411     -0.577728         -9.039868
# 1            CCV_dw     28.149789     -0.079198         -6.612262
# 2            CCV_cw    -19.548058     -0.553568        -10.884448
# 3         LSTM_pred    -70.248119     -1.289281        -12.167618
# 4          GRU_pred    -36.272010     -0.687806         -7.597881
# 5     LSTM_GRU_pred    -60.578039     -0.920969         -7.776714
# 6       BiLSTM_pred    -65.207737     -0.983389         -8.127295
# 7   BiLSTM_GRU_pred   -145.537812     -1.995149        -15.788624
# 8         QRNN_pred     -1.526860     -0.628687         -8.106628
# 9          ESN_pred    -43.615227     -1.445334        -10.986631
# 10         BNN_pred    -44.180226     -1.063742        -12.109612
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      8.546725     -0.385620         -8.491931
# 1            CCV_dw     26.543994     -0.088193         -6.695927
# 2            CCV_cw    -28.450098     -0.595741        -13.026686
# 3         LSTM_pred    -83.964700     -1.351534        -13.156688
# 4          GRU_pred   -106.971356     -1.260796        -13.280326
# 5     LSTM_GRU_pred   -120.123053     -1.395281        -13.510222
# 6       BiLSTM_pred   -117.915203     -1.277100        -11.945292
# 7   BiLSTM_GRU_pred    -97.222038     -1.152697        -11.658071
# 8         QRNN_pred      5.607186     -0.401041         -7.956335
# 9          ESN_pred    -45.897043     -1.081662         -9.221644
# 10         BNN_pred    -35.688066     -0.949725        -11.957791
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      0.412830     -0.520869         -9.372811
# 1            CCV_dw     24.246730     -0.107743         -6.695927
# 2            CCV_cw    -12.467593     -0.405614         -9.628298
# 3         LSTM_pred    -52.184565     -0.997769        -10.143821
# 4          GRU_pred    -72.831231     -0.927037        -11.346776
# 5     LSTM_GRU_pred    -86.485711     -1.057194        -11.581798
# 6       BiLSTM_pred    -75.715045     -0.849904        -10.314616
# 7   BiLSTM_GRU_pred    -89.376885     -1.076881        -11.468121
# 8         QRNN_pred     10.111867     -0.393892         -8.051887
# 9          ESN_pred      2.781491     -0.473146         -9.527381
# 10         BNN_pred      9.492727     -0.536449         -9.221644
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -10.961034     -0.528927        -10.406430
# 1            CCV_dw    -27.237526     -0.184088         -6.768211
# 2            CCV_cw    -23.665473     -0.912327        -12.388477
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -48.599801     -0.785499         -8.377576
# 5     LSTM_GRU_pred    -48.599801     -0.785499         -8.377576
# 6       BiLSTM_pred    -81.443700     -0.730153         -9.798753
# 7   BiLSTM_GRU_pred   -138.692517     -1.862101        -15.113987
# 8         QRNN_pred     -3.102359     -0.627177         -9.904078
# 9          ESN_pred      4.300029     -0.739267         -9.221644
# 10         BNN_pred    -92.697540     -0.833132        -11.982656
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.105914     -0.524306        -10.238519
# 1            CCV_dw    -14.704840     -0.075130         -6.768211
# 2            CCV_cw    -17.711457     -0.643916        -11.854192
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred   -115.884783     -1.342746        -13.510222
# 5     LSTM_GRU_pred   -115.884783     -1.342746        -13.510222
# 6       BiLSTM_pred    -85.634464     -0.675725        -10.180663
# 7   BiLSTM_GRU_pred    -50.690601     -0.714826         -9.841785
# 8         QRNN_pred      4.020430     -0.404028         -9.735824
# 9          ESN_pred      8.571705     -0.469328         -9.176039
# 10         BNN_pred    -75.848409     -0.702626        -10.984138
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.105914     -0.595255        -10.260304
# 1            CCV_dw    -16.909795     -0.093997         -6.984195
# 2            CCV_cw     -3.670181     -0.552958        -10.594196
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -82.085415     -1.008303        -11.581798
# 5     LSTM_GRU_pred    -82.085415     -1.008303        -11.581798
# 6       BiLSTM_pred    -67.814325     -0.514238        -10.180663
# 7   BiLSTM_GRU_pred    -50.690601     -0.714826         -9.841785
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred    -17.218032     -0.665558         -9.904078
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -71.271091     -0.545150         -9.841785
# 2            CCV_cw   -119.441426     -1.035689        -15.183092
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.566240         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.566240         -9.904078
# 6       BiLSTM_pred    -82.516274     -0.732555         -9.904078
# 7   BiLSTM_GRU_pred   -108.322888     -1.692972        -13.958506
# 8         QRNN_pred    -71.271091     -0.545150         -9.841785
# 9          ESN_pred    -55.729010     -0.425844         -9.094755
# 10         BNN_pred    -92.697540     -0.833132        -11.982656
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.486499         -9.841785
# 2            CCV_cw    -88.794596     -0.707853        -12.231137
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.680710         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.680710         -9.904078
# 6       BiLSTM_pred    -82.516274     -0.647705         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -51.712661     -0.390219         -9.094755
# 10         BNN_pred    -75.848409     -0.702626        -10.984138
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.486499         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.600334         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.600334         -9.904078
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.562776         -9.904078
# 1            CCV_dw    -44.180771     -0.318871         -7.715239
# 2            CCV_cw    -74.210034     -0.572567        -10.826327
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -65.929694     -0.853130        -11.581798
# 5     LSTM_GRU_pred    -65.929694     -0.853130        -11.581798
# 6       BiLSTM_pred    -68.355723     -0.714047        -11.468121
# 7   BiLSTM_GRU_pred    -63.409489     -0.831517         -9.904078
# 8         QRNN_pred      1.308214     -0.454394         -9.800256
# 9          ESN_pred    -48.713639     -0.975393         -9.981361
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      1.503863     -0.509580         -9.264167
# 1            CCV_dw      9.531543     -0.173025         -6.722731
# 2            CCV_cw    -16.586803     -0.727916        -11.902284
# 3         LSTM_pred    -47.846015     -1.002317        -10.051322
# 4          GRU_pred    -55.940744     -0.784470        -11.697297
# 5     LSTM_GRU_pred    -72.833941     -0.924110        -11.697297
# 6       BiLSTM_pred    -35.651456     -0.497717         -9.421154
# 7   BiLSTM_GRU_pred    -84.763412     -1.091695        -11.289464
# 8         QRNN_pred     -8.544493     -0.543865         -9.897647
# 9          ESN_pred      5.569215     -0.441587        -10.721506
# 10         BNN_pred     27.290777     -0.389450         -9.061378
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     14.272193     -0.333911         -7.559643
# 1            CCV_dw      8.748449     -0.106928         -6.722731
# 2            CCV_cw     35.337011     -0.175265         -6.836313
# 3         LSTM_pred    -74.651465     -1.337498        -12.583596
# 4          GRU_pred    -24.843367     -0.612071         -8.426633
# 5     LSTM_GRU_pred    -56.083236     -0.904031         -8.477867
# 6       BiLSTM_pred    -34.216219     -0.685769         -6.432429
# 7   BiLSTM_GRU_pred   -154.320660     -2.284457        -16.654216
# 8         QRNN_pred    -39.259865     -0.974772        -11.107827
# 9          ESN_pred    -34.777578     -1.330915        -11.336034
# 10         BNN_pred     -5.853123     -0.695494        -11.033914
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      1.503863     -0.438343         -9.181384
# 1            CCV_dw     11.795803     -0.153644         -6.722731
# 2            CCV_cw      4.400222     -0.627878         -9.869997
# 3         LSTM_pred    -75.922252     -1.322272        -12.703645
# 4          GRU_pred    -98.221201     -1.196438        -13.759882
# 5     LSTM_GRU_pred   -114.357822     -1.334122        -13.759882
# 6       BiLSTM_pred    -77.839932     -0.907604        -10.743720
# 7   BiLSTM_GRU_pred   -111.357474     -1.375695        -13.041303
# 8         QRNN_pred    -14.062663     -0.560195         -9.904078
# 9          ESN_pred    -46.278228     -1.046934        -10.732875
# 10         BNN_pred      3.761809     -0.590862         -9.785562
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      1.503863     -0.509580         -9.264167
# 1            CCV_dw     11.795803     -0.153644         -6.722731
# 2            CCV_cw    -13.651690     -0.724809        -11.639346
# 3         LSTM_pred    -47.846015     -1.002317        -10.051322
# 4          GRU_pred    -68.624885     -0.905481        -11.697297
# 5     LSTM_GRU_pred    -85.291109     -1.044702        -11.697297
# 6       BiLSTM_pred    -60.945309     -0.713744         -9.653883
# 7   BiLSTM_GRU_pred    -91.427813     -1.163585        -11.289464
# 8         QRNN_pred    -22.198663     -0.658362         -9.904078
# 9          ESN_pred    -38.655844     -0.959393        -10.885039
# 10         BNN_pred     27.290777     -0.389450         -9.061378
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.480781         -9.825790
# 1            CCV_dw    -48.833027     -0.359839         -7.537836
# 2            CCV_cw    -42.573465     -0.322456         -9.094755
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -46.415380     -0.774374         -9.904823
# 5     LSTM_GRU_pred    -46.415380     -0.774374         -9.904823
# 6       BiLSTM_pred    -82.835420     -0.752910         -9.935418
# 7   BiLSTM_GRU_pred   -138.072451     -1.905763        -15.052877
# 8         QRNN_pred    -21.638914     -0.806747         -9.477454
# 9          ESN_pred    -57.423747     -1.454060        -13.416279
# 10         BNN_pred    -82.404587     -0.731444        -10.984138
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.491784         -9.843974
# 1            CCV_dw    -42.036981     -0.300572         -7.537836
# 2            CCV_cw    -37.118108     -0.273443         -9.094755
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred   -102.485482     -1.205845        -13.647081
# 5     LSTM_GRU_pred   -102.485482     -1.205845        -13.647081
# 6       BiLSTM_pred    -80.873060     -0.717973        -11.468121
# 7   BiLSTM_GRU_pred    -75.778649     -0.972025         -9.904078
# 8         QRNN_pred      4.020430     -0.404028         -9.735824
# 9          ESN_pred    -57.423747     -1.100523        -10.814145
# 10         BNN_pred    -64.635364     -0.600334         -9.904078
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.562776         -9.904078
# 1            CCV_dw    -42.036981     -0.300572         -7.537836
# 2            CCV_cw    -77.639794     -0.613056        -11.156687
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -78.479626     -0.971960        -11.581798
# 5     LSTM_GRU_pred    -78.479626     -0.971960        -11.581798
# 6       BiLSTM_pred    -68.355723     -0.760622        -11.468121
# 7   BiLSTM_GRU_pred    -63.409489     -0.831517         -9.904078
# 8         QRNN_pred     -7.340940     -0.526383         -9.885647
# 9          ESN_pred    -57.423747     -1.148151        -11.576032
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -71.271091     -0.545150         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.566240         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.566240         -9.904078
# 6       BiLSTM_pred    -82.516274     -0.732555         -9.904078
# 7   BiLSTM_GRU_pred   -104.518262     -1.652349        -13.591382
# 8         QRNN_pred    -62.023620     -0.718879         -9.477454
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -82.404587     -0.731444        -10.984138
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.486499         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -64.635364     -0.727191        -10.157965
# 6       BiLSTM_pred    -64.635364     -0.566240         -9.904078
# 7   BiLSTM_GRU_pred    -64.635364     -0.566240         -9.904078
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -64.635364     -0.600334         -9.904078
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.486499         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.680710         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.680710         -9.904078
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -14.062075     -0.635037         -9.904078
# 1            CCV_dw      3.425849     -0.269654         -8.165969
# 2            CCV_cw    -26.049861     -0.406071         -9.808231
# 3         LSTM_pred    -29.056474     -0.792726        -13.038481
# 4          GRU_pred    -26.224785     -0.463528         -7.379452
# 5     LSTM_GRU_pred    -74.443940     -0.881008        -11.346776
# 6       BiLSTM_pred    -71.272552     -0.879634        -11.382423
# 7   BiLSTM_GRU_pred    -80.458710     -0.915673        -11.047576
# 8         QRNN_pred      1.308214     -0.454394         -9.800256
# 9          ESN_pred    -46.627039     -0.347003         -9.094755
# 10         BNN_pred     40.316564     -0.386883         -9.156058
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -44.205725     -0.913365         -9.904078
# 1            CCV_dw     11.004256     -0.112495         -7.916121
# 2            CCV_cw    -17.097993     -0.501630         -9.221644
# 3         LSTM_pred     -6.866653     -0.248977         -8.488536
# 4          GRU_pred      5.821038     -0.175493         -7.359087
# 5     LSTM_GRU_pred    -15.871208     -0.386017         -6.857556
# 6       BiLSTM_pred     10.836550     -0.253751         -6.854974
# 7   BiLSTM_GRU_pred    -10.587855     -0.333943         -9.537396
# 8         QRNN_pred     -8.609264     -0.709588         -9.904078
# 9          ESN_pred    -48.743109     -0.371656         -9.094755
# 10         BNN_pred    -59.207126     -0.748157        -11.688032
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw     92.663866      0.599197         -2.613741
# 2            CCV_cw    -32.051054     -2.143146         -5.055486
# 3         LSTM_pred    -88.133783     -1.489168        -10.715722
# 4          GRU_pred    -53.162513     -1.468160         -6.085384
# 5     LSTM_GRU_pred    -25.775977     -1.433208         -3.555401
# 6       BiLSTM_pred    -14.287572     -0.835283         -6.100851
# 7   BiLSTM_GRU_pred    -17.340388     -1.455084         -4.570263
# 8         QRNN_pred    -74.634597     -1.739508        -10.566199
# 9          ESN_pred    -19.171098     -0.169642         -6.432429
# 10         BNN_pred    -33.966806     -0.769030         -9.572672
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -78.942989     -1.572938        -13.569441
# 1            CCV_dw     52.873857      0.141460         -3.682685
# 2            CCV_cw    -42.573465     -1.107862         -9.221644
# 3         LSTM_pred    -68.252484     -1.224474        -10.513085
# 4          GRU_pred    -39.323954     -0.879495         -6.807022
# 5     LSTM_GRU_pred    -87.958381     -1.893474         -9.536706
# 6       BiLSTM_pred    -27.075102     -0.691733         -6.542611
# 7   BiLSTM_GRU_pred   -103.019316     -2.130615        -12.185406
# 8         QRNN_pred    -51.279016     -1.362879        -11.617773
# 9          ESN_pred    -10.870832     -0.051401         -9.094755
# 10         BNN_pred    -74.714262     -0.968967         -9.910815
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -84.969797     -1.562095        -14.134987
# 1            CCV_dw     49.667038      0.107045         -6.985153
# 2            CCV_cw    -12.769242     -0.490865        -11.426129
# 3         LSTM_pred    -42.426328     -0.580495        -11.833281
# 4          GRU_pred   -110.246666     -1.805991        -11.747429
# 5     LSTM_GRU_pred    -90.989919     -1.262701        -11.437706
# 6       BiLSTM_pred    -48.491543     -0.689078         -9.589484
# 7   BiLSTM_GRU_pred    -28.663652     -0.541262         -9.838156
# 8         QRNN_pred      9.494451     -0.552759         -9.844723
# 9          ESN_pred    -53.057507     -0.418872         -9.094755
# 10         BNN_pred    -37.049601     -0.563340         -9.494371
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw     86.271125      0.444149         -7.239473
# 2            CCV_cw    -33.318978     -1.954816         -5.179855
# 3         LSTM_pred    -42.896951     -0.753080        -11.613002
# 4          GRU_pred    -52.501381     -1.312083         -7.157734
# 5     LSTM_GRU_pred   -107.952025     -2.180002        -12.591160
# 6       BiLSTM_pred    -55.306471     -1.260911         -7.746011
# 7   BiLSTM_GRU_pred    -16.899544     -1.258027         -4.861656
# 8         QRNN_pred    -74.634597     -1.739508        -10.566199
# 9          ESN_pred    -19.171098     -0.169642         -6.432429
# 10         BNN_pred      2.646429     -0.481384        -10.759197
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -27.884668     -0.843764         -9.904078
# 1            CCV_dw     36.257554     -0.008481         -7.392832
# 2            CCV_cw    -43.827605     -1.095758         -9.221644
# 3         LSTM_pred    -24.243897     -0.575739        -11.613002
# 4          GRU_pred    -39.681643     -0.784297         -7.025586
# 5     LSTM_GRU_pred    -85.331834     -1.672396        -10.374682
# 6       BiLSTM_pred    -55.863261     -0.953341         -8.972734
# 7   BiLSTM_GRU_pred   -110.351670     -1.903407        -12.873433
# 8         QRNN_pred    -64.635364     -1.279932        -10.973497
# 9          ESN_pred    -10.870832     -0.051401         -9.094755
# 10         BNN_pred    -14.995238     -0.892719        -12.109612
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.564042         -9.904078
# 1            CCV_dw      5.676415     -0.251002         -7.945595
# 2            CCV_cw    -25.192229     -0.564968         -9.887919
# 3         LSTM_pred    -19.820540     -0.722753        -12.916971
# 4          GRU_pred   -119.491102     -1.466429        -13.721836
# 5     LSTM_GRU_pred   -104.041721     -1.331766        -13.280326
# 6       BiLSTM_pred    -88.252497     -1.060052        -11.327581
# 7   BiLSTM_GRU_pred    -77.257566     -0.926659        -11.650892
# 8         QRNN_pred      1.308214     -0.423157         -9.762195
# 9          ESN_pred    -25.416803     -0.168664         -9.094755
# 10         BNN_pred     12.152129     -0.638977        -11.181895
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw    -71.271091     -0.545150         -9.841785
# 2            CCV_cw    -54.355421     -1.816798         -7.768812
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -64.635364     -1.165788        -11.468322
# 5     LSTM_GRU_pred    -94.250615     -1.618266        -15.056330
# 6       BiLSTM_pred    -82.516274     -1.362393        -11.468322
# 7   BiLSTM_GRU_pred    -16.899544     -1.258027         -4.861656
# 8         QRNN_pred    -74.634597     -1.739508        -10.566199
# 9          ESN_pred    -19.171098     -0.169642         -6.432429
# 10         BNN_pred    -98.511026     -0.898493        -12.546622
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.680710         -9.904078
# 1            CCV_dw    -71.271091     -0.545150         -9.841785
# 2            CCV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.566240         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -1.165788        -11.468322
# 6       BiLSTM_pred    -71.271091     -0.626653         -9.904078
# 7   BiLSTM_GRU_pred    -87.066151     -1.445104        -13.591382
# 8         QRNN_pred    -64.635364     -1.279932        -10.973497
# 9          ESN_pred    -10.870832     -0.051401         -9.094755
# 10         BNN_pred    -92.697540     -0.833132        -11.982656
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.486499         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -64.635364     -0.566240         -9.904078
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -75.848409     -0.702626        -10.984138
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -17.545130     -0.578901         -9.904078
# 1            CCV_dw     28.507849     -0.077686         -7.634862
# 2            CCV_cw    -28.414894     -0.477055         -9.221644
# 3         LSTM_pred    -29.144595     -0.913602        -10.021060
# 4          GRU_pred    -19.125416     -0.396255         -7.379452
# 5     LSTM_GRU_pred    -19.125416     -0.396255         -7.379452
# 6       BiLSTM_pred    -33.825905     -0.506770         -8.697166
# 7   BiLSTM_GRU_pred     -0.228824     -0.338851        -10.938599
# 8         QRNN_pred    -15.012407     -0.864393         -9.904078
# 9          ESN_pred    -44.241965     -0.328354         -9.094755
# 10         BNN_pred    -50.457801     -0.604307        -11.016773
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -34.401236     -0.890079         -9.904078
# 1            CCV_dw     -8.051211     -0.302545         -7.916121
# 2            CCV_cw     -4.934014     -0.388260         -7.473455
# 3         LSTM_pred    -57.045181     -0.871651         -8.081695
# 4          GRU_pred      5.821038     -0.175493         -7.359087
# 5     LSTM_GRU_pred     29.573937      0.059391         -6.271451
# 6       BiLSTM_pred     23.456086     -0.002161         -6.782015
# 7   BiLSTM_GRU_pred    -12.682355     -0.476245         -9.623644
# 8         QRNN_pred    -19.826531     -0.780201         -9.221644
# 9          ESN_pred    -48.743109     -0.371656         -9.094755
# 10         BNN_pred    -40.620573     -0.592871        -12.228647
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw    108.187889      0.790521         -2.351021
# 2            CCV_cw    -28.731796     -2.054597         -4.729906
# 3         LSTM_pred    -82.437826     -1.585725         -9.569816
# 4          GRU_pred    -24.160966     -1.522288         -5.352963
# 5     LSTM_GRU_pred     -5.743571     -1.099747         -2.636597
# 6       BiLSTM_pred     -0.804346     -0.710977         -3.018181
# 7   BiLSTM_GRU_pred      4.970128     -1.312112         -2.403605
# 8         QRNN_pred   -102.931906     -2.390966        -11.908871
# 9          ESN_pred      0.000000      0.034446         -6.432429
# 10         BNN_pred     24.658915     -0.163161         -5.732023
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -65.388929     -1.469707        -11.670919
# 1            CCV_dw     41.409716      0.021140         -3.504824
# 2            CCV_cw    -59.379276     -1.504912         -9.397803
# 3         LSTM_pred    -58.249417     -1.158227         -7.559908
# 4          GRU_pred    -39.323954     -0.879495         -6.807022
# 5     LSTM_GRU_pred    -74.504477     -1.831607         -8.202244
# 6       BiLSTM_pred     31.046534     -0.093749         -5.693140
# 7   BiLSTM_GRU_pred    -91.874451     -2.058579        -11.330883
# 8         QRNN_pred    -60.927090     -1.274410         -9.409698
# 9          ESN_pred    -10.870832     -0.051401         -9.094755
# 10         BNN_pred    -57.648762     -0.837728         -9.369196
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -22.240903     -0.784930         -9.899822
# 1            CCV_dw     25.732492     -0.139339         -4.689721
# 2            CCV_cw     81.431963      0.421560         -7.426598
# 3         LSTM_pred    -89.438993     -1.222623         -9.589876
# 4          GRU_pred    -41.679657     -0.905488         -6.880622
# 5     LSTM_GRU_pred    -27.192751     -0.732124         -5.789090
# 6       BiLSTM_pred    -27.039995     -0.513672         -6.930841
# 7   BiLSTM_GRU_pred     -9.689808     -0.514579        -11.325903
# 8         QRNN_pred    -33.663470     -0.933459         -9.221644
# 9          ESN_pred    -20.815467     -0.132290         -9.094755
# 10         BNN_pred    -31.842843     -0.546734        -10.607875
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw    125.934876      0.865023         -2.650948
# 2            CCV_cw    -33.120895     -1.949510         -5.160425
# 3         LSTM_pred   -103.764127     -1.698103        -12.277624
# 4          GRU_pred    -54.643080     -1.585705         -7.367592
# 5     LSTM_GRU_pred    -57.039166     -1.552865         -7.602376
# 6       BiLSTM_pred    -46.609395     -1.259169         -5.485890
# 7   BiLSTM_GRU_pred    -16.899544     -1.258027         -4.861656
# 8         QRNN_pred   -102.931906     -2.390966        -11.908871
# 9          ESN_pred      0.000000      0.034446         -6.432429
# 10         BNN_pred    -22.102803     -0.592852         -9.430518
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -71.271091     -1.535049        -12.226836
# 1            CCV_dw     62.757461      0.229404         -3.938631
# 2            CCV_cw    -43.631675     -1.093096         -9.221644
# 3         LSTM_pred    -84.046125     -1.363499        -10.347652
# 4          GRU_pred    -22.257928     -0.612423         -6.640311
# 5     LSTM_GRU_pred    -77.209357     -1.669617         -9.578787
# 6       BiLSTM_pred    -18.826650     -0.596490         -5.511672
# 7   BiLSTM_GRU_pred    -97.239791     -1.892420        -11.404102
# 8         QRNN_pred    -60.927090     -1.274410         -9.409698
# 9          ESN_pred    -10.870832     -0.051401         -9.094755
# 10         BNN_pred    -82.483998     -0.991664        -10.793554
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.480781         -9.825790
# 1            CCV_dw     68.181796      0.274749         -3.955343
# 2            CCV_cw     24.182371     -0.136847         -9.221644
# 3         LSTM_pred    -67.477430     -1.341420        -12.597785
# 4          GRU_pred    -32.680382     -0.713672         -6.640311
# 5     LSTM_GRU_pred    -32.680382     -0.713672         -6.640311
# 6       BiLSTM_pred    -82.134420     -1.025149        -10.870568
# 7   BiLSTM_GRU_pred    -52.987757     -0.897874        -14.135759
# 8         QRNN_pred    -20.463373     -0.934333        -10.099220
# 9          ESN_pred    -20.851144     -0.129810         -9.094755
# 10         BNN_pred    -53.309317     -0.692569        -10.793554
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw    -71.271091     -0.545150         -9.841785
# 2            CCV_cw    -54.355421     -1.816798         -7.768812
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -64.635364     -1.258263        -12.278930
# 5     LSTM_GRU_pred   -105.466827     -1.787402        -16.108217
# 6       BiLSTM_pred    -82.516274     -1.362393        -11.468322
# 7   BiLSTM_GRU_pred    -16.899544     -1.258027         -4.861656
# 8         QRNN_pred   -102.931906     -2.390966        -11.908871
# 9          ESN_pred      0.000000      0.034446         -6.432429
# 10         BNN_pred    -98.511026     -0.898493        -12.546622
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -71.271091     -1.535049        -12.226836
# 1            CCV_dw    -71.271091     -0.545150         -9.841785
# 2            CCV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -64.635364     -0.566240         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -1.165788        -11.468322
# 6       BiLSTM_pred    -82.516274     -0.732555         -9.904078
# 7   BiLSTM_GRU_pred   -104.518262     -1.652349        -13.591382
# 8         QRNN_pred    -60.927090     -1.274410         -9.409698
# 9          ESN_pred    -10.870832     -0.051401         -9.094755
# 10         BNN_pred    -92.697540     -0.833132        -11.982656
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -71.271091     -0.545150         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.566240         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.566240         -9.904078
# 6       BiLSTM_pred    -64.635364     -0.566240         -9.904078
# 7   BiLSTM_GRU_pred    -87.066151     -0.701663        -12.064650
# 8         QRNN_pred    -64.635364     -0.680710         -9.904078
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -86.214904     -0.801715        -11.982656
# 11               __    -64.635364     -0.486499         -9.841785

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.105914     -0.595255        -10.260304
# 1            CCV_dw     33.866455     -0.205369         -7.130970
# 2            CCV_cw     16.363286     -0.318877         -9.013487
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -69.584589     -0.888776        -11.581798
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -67.814325     -0.514238        -10.180663
# 7   BiLSTM_GRU_pred    -94.256026     -0.764200        -12.757191
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred      4.721204     -0.487060         -9.122558
# 10         BNN_pred      7.818186     -0.526489         -9.788933
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      0.412830     -0.520869         -9.372811
# 1            CCV_dw     44.657930     -0.119682         -7.130970
# 2            CCV_cw    -53.641881     -0.775705        -12.651931
# 3         LSTM_pred    -52.184565     -0.997769        -10.143821
# 4          GRU_pred    -69.153516     -0.890547        -11.346776
# 5     LSTM_GRU_pred     -5.312685     -0.382436        -10.204092
# 6       BiLSTM_pred    -72.563028     -0.820530        -10.314616
# 7   BiLSTM_GRU_pred     38.878285     -0.407346         -8.616568
# 8         QRNN_pred     10.111867     -0.393892         -8.051887
# 9          ESN_pred     12.950402     -0.193747         -8.918040
# 10         BNN_pred     20.916330     -0.442598         -9.007698
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -13.719411     -0.577728         -9.039868
# 1            CCV_dw     28.264556     -0.259424         -7.130970
# 2            CCV_cw     20.982962     -0.157332         -8.591541
# 3         LSTM_pred    -70.248119     -1.289281        -12.167618
# 4          GRU_pred    -36.272010     -0.687806         -7.597881
# 5     LSTM_GRU_pred    -24.208867     -0.389827        -11.307511
# 6       BiLSTM_pred    -65.207737     -0.983389         -8.127295
# 7   BiLSTM_GRU_pred     83.395220     -0.052493         -7.190473
# 8         QRNN_pred     -1.526860     -0.628687         -8.106628
# 9          ESN_pred     11.453384     -0.293542         -9.226418
# 10         BNN_pred    -13.256603     -0.779863        -11.041959
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      8.546725     -0.385620         -8.491931
# 1            CCV_dw     55.249889     -0.033822         -7.130970
# 2            CCV_cw      0.897139     -0.323044        -10.220570
# 3         LSTM_pred    -83.964700     -1.351534        -13.156688
# 4          GRU_pred   -106.971356     -1.260796        -13.280326
# 5     LSTM_GRU_pred     -5.312685     -0.382436        -10.204092
# 6       BiLSTM_pred   -117.915203     -1.277100        -11.945292
# 7   BiLSTM_GRU_pred     71.569536     -0.140458         -7.287811
# 8         QRNN_pred      5.607186     -0.401041         -7.956335
# 9          ESN_pred     49.173020      0.102494         -8.957599
# 10         BNN_pred    -24.775738     -0.852005        -11.831992
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      0.412830     -0.520869         -9.372811
# 1            CCV_dw     44.657930     -0.119682         -7.130970
# 2            CCV_cw    -33.370306     -0.601298        -11.578123
# 3         LSTM_pred    -52.184565     -0.997769        -10.143821
# 4          GRU_pred    -72.831231     -0.927037        -11.346776
# 5     LSTM_GRU_pred     -5.312685     -0.382436        -10.204092
# 6       BiLSTM_pred    -75.715045     -0.849904        -10.314616
# 7   BiLSTM_GRU_pred     38.878285     -0.407346         -8.616568
# 8         QRNN_pred     10.111867     -0.393892         -8.051887
# 9          ESN_pred     40.981834      0.035585         -8.861189
# 10         BNN_pred     20.916330     -0.442598         -9.007698
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -10.961034     -0.528927        -10.406430
# 1            CCV_dw     15.011163     -0.365565         -7.130970
# 2            CCV_cw     45.107022     -0.254447         -9.170353
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -48.599801     -0.785499         -8.377576
# 5     LSTM_GRU_pred    -82.404587     -0.646634        -10.984138
# 6       BiLSTM_pred    -81.443700     -0.730153         -9.798753
# 7   BiLSTM_GRU_pred    -97.912320     -0.812672        -13.109371
# 8         QRNN_pred     -3.102359     -0.627177         -9.904078
# 9          ESN_pred     65.630129      0.261842         -7.425979
# 10         BNN_pred    -24.865293     -0.816871        -10.443080
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.105914     -0.524306        -10.238519
# 1            CCV_dw     36.185296     -0.186462         -7.130970
# 2            CCV_cw     16.115696     -0.348206         -9.031914
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred   -115.884783     -1.342746        -13.510222
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -85.634464     -0.675725        -10.180663
# 7   BiLSTM_GRU_pred    -82.474035     -0.661765        -11.622329
# 8         QRNN_pred      4.020430     -0.404028         -9.735824
# 9          ESN_pred     56.051049      0.161282         -7.493338
# 10         BNN_pred    -17.641888     -0.743605        -10.885123
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.105914     -0.595255        -10.260304
# 1            CCV_dw     33.866455     -0.205369         -7.130970
# 2            CCV_cw     16.571549     -0.389132         -9.092022
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -82.085415     -1.008303        -11.581798
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -67.814325     -0.514238        -10.180663
# 7   BiLSTM_GRU_pred    -94.256026     -0.764200        -12.757191
# 8         QRNN_pred      4.020430     -0.415519         -9.753841
# 9          ESN_pred     32.524909     -0.267887         -9.064404
# 10         BNN_pred      7.818186     -0.526489         -9.788933
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -71.271091     -0.659604         -9.904078
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.566240         -9.904078
# 5     LSTM_GRU_pred    -82.404587     -0.646634        -10.984138
# 6       BiLSTM_pred    -82.516274     -0.732555         -9.904078
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -71.271091     -0.545150         -9.841785
# 9          ESN_pred    -80.086074     -0.830144        -11.392317
# 10         BNN_pred    -75.848409     -0.702626        -10.984138
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.486499         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.680710         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -82.516274     -0.647705         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -75.848409     -0.587472        -10.984138
# 10         BNN_pred    -75.848409     -0.702626        -10.984138
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.486499         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.600334         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.562776         -9.904078
# 1            CCV_dw     16.395916     -0.338572         -7.513251
# 2            CCV_cw    -67.037187     -0.516882        -10.097606
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -65.929694     -0.853130        -11.581798
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -68.355723     -0.714047        -11.468121
# 7   BiLSTM_GRU_pred    -62.883354     -0.477411         -9.656004
# 8         QRNN_pred      1.308214     -0.454394         -9.800256
# 9          ESN_pred     20.924420      0.005930         -9.076109
# 10         BNN_pred     35.421041     -0.319367         -9.148548
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      1.503863     -0.509580         -9.264167
# 1            CCV_dw     19.135947     -0.318607         -7.493051
# 2            CCV_cw     18.181904     -0.432334         -9.103615
# 3         LSTM_pred    -47.846015     -1.002317        -10.051322
# 4          GRU_pred    -55.940744     -0.784470        -11.697297
# 5     LSTM_GRU_pred     -6.704535     -0.394169        -10.224529
# 6       BiLSTM_pred    -35.651456     -0.497717         -9.421154
# 7   BiLSTM_GRU_pred     -4.140183      0.008542         -6.432429
# 8         QRNN_pred     -8.544493     -0.543865         -9.897647
# 9          ESN_pred     37.048860      0.128165         -7.405686
# 10         BNN_pred     22.386367     -0.433390         -9.007698
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     14.272193     -0.333911         -7.559643
# 1            CCV_dw     -2.726581     -0.510455         -7.130970
# 2            CCV_cw     56.103270      0.023556         -6.664929
# 3         LSTM_pred    -74.651465     -1.337498        -12.583596
# 4          GRU_pred    -24.843367     -0.612071         -8.426633
# 5     LSTM_GRU_pred    -25.574276     -0.401741        -11.325681
# 6       BiLSTM_pred    -34.216219     -0.685769         -6.432429
# 7   BiLSTM_GRU_pred     -2.016755      0.021687         -6.432429
# 8         QRNN_pred    -39.259865     -0.974772        -11.107827
# 9          ESN_pred     11.448182     -0.293263         -8.662120
# 10         BNN_pred    -12.069679     -0.759390        -10.934954
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      1.503863     -0.438343         -9.181384
# 1            CCV_dw     29.469135     -0.235653         -7.417841
# 2            CCV_cw     45.988368     -0.267774         -9.172950
# 3         LSTM_pred    -75.922252     -1.322272        -12.703645
# 4          GRU_pred    -98.221201     -1.196438        -13.759882
# 5     LSTM_GRU_pred     -6.704535     -0.394169        -10.224529
# 6       BiLSTM_pred    -77.839932     -0.907604        -10.743720
# 7   BiLSTM_GRU_pred     27.104274      0.296599         -6.432429
# 8         QRNN_pred    -14.062663     -0.560195         -9.904078
# 9          ESN_pred     70.242481      0.304908         -7.385143
# 10         BNN_pred     -1.030272     -0.635705         -9.685214
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      1.503863     -0.509580         -9.264167
# 1            CCV_dw     29.469135     -0.235653         -7.417841
# 2            CCV_cw     22.269318     -0.412688         -9.103615
# 3         LSTM_pred    -47.846015     -1.002317        -10.051322
# 4          GRU_pred    -68.624885     -0.905481        -11.697297
# 5     LSTM_GRU_pred     -6.704535     -0.394169        -10.224529
# 6       BiLSTM_pred    -60.945309     -0.713744         -9.653883
# 7   BiLSTM_GRU_pred     -4.140183      0.008542         -6.432429
# 8         QRNN_pred    -22.198663     -0.658362         -9.904078
# 9          ESN_pred    112.955286      0.653137         -7.116386
# 10         BNN_pred     22.386367     -0.433390         -9.007698
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.480781         -9.825790
# 1            CCV_dw     -3.150545     -0.510506         -7.130970
# 2            CCV_cw    -20.821699     -0.136290         -9.094755
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -46.415380     -0.774374         -9.904823
# 5     LSTM_GRU_pred    -82.404587     -0.646634        -10.984138
# 6       BiLSTM_pred    -82.835420     -0.752910         -9.935418
# 7   BiLSTM_GRU_pred      8.101899      0.118743         -7.051396
# 8         QRNN_pred    -21.638914     -0.806747         -9.477454
# 9          ESN_pred     11.448182     -0.293263         -8.662120
# 10         BNN_pred      3.545509     -0.586176         -9.221644
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.491784         -9.843974
# 1            CCV_dw     26.701322     -0.256102         -7.437838
# 2            CCV_cw    -11.053849     -0.049157         -9.094755
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred   -102.485482     -1.205845        -13.647081
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -80.873060     -0.717973        -11.468121
# 7   BiLSTM_GRU_pred    -30.618140     -0.208425         -7.351191
# 8         QRNN_pred      4.020430     -0.404028         -9.735824
# 9          ESN_pred    109.748263      0.650210         -7.122240
# 10         BNN_pred     15.721866     -0.483690         -9.221644
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.562776         -9.904078
# 1            CCV_dw     26.701322     -0.256102         -7.437838
# 2            CCV_cw    -61.877519     -0.484060         -9.549659
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -78.479626     -0.971960        -11.581798
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -68.355723     -0.760622        -11.468121
# 7   BiLSTM_GRU_pred    -62.883354     -0.477411         -9.656004
# 8         QRNN_pred     -7.340940     -0.526383         -9.885647
# 9          ESN_pred     28.956113      0.062054         -9.228550
# 10         BNN_pred     35.421041     -0.319367         -9.148548
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -76.705334     -0.712965         -9.333450
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.566240         -9.904078
# 5     LSTM_GRU_pred    -82.404587     -0.646634        -10.984138
# 6       BiLSTM_pred    -82.516274     -0.732555         -9.904078
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -62.023620     -0.718879         -9.477454
# 9          ESN_pred    -54.355421     -0.724874         -8.662120
# 10         BNN_pred    -75.848409     -0.702626        -10.984138
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.486499         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.566240         -9.904078
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -75.848409     -0.587472        -10.984138
# 10         BNN_pred    -64.635364     -0.600334         -9.904078
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.486499         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.680710         -9.904078
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -0.486499         -9.841785
# 10         BNN_pred    -64.635364     -0.486499         -9.841785
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -14.062075     -0.635037         -9.904078
# 1            CCV_dw     -4.454701     -0.278764         -7.539472
# 2            CCV_cw      2.924791     -0.277299         -9.808231
# 3         LSTM_pred    -29.056474     -0.792726        -13.038481
# 4          GRU_pred    -26.224785     -0.463528         -7.379452
# 5     LSTM_GRU_pred    -74.983542     -0.588014         -9.266663
# 6       BiLSTM_pred    -71.272552     -0.879634        -11.382423
# 7   BiLSTM_GRU_pred    -64.932810     -0.494163         -9.873395
# 8         QRNN_pred      1.308214     -0.454394         -9.800256
# 9          ESN_pred     -4.292125     -0.339864         -9.738825
# 10         BNN_pred     50.320425     -0.304145         -9.007698
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -44.205725     -0.913365         -9.904078
# 1            CCV_dw     21.670803     -0.141925         -6.871498
# 2            CCV_cw    -17.097993     -0.501630         -9.221644
# 3         LSTM_pred     -6.866653     -0.248977         -8.488536
# 4          GRU_pred      5.821038     -0.175493         -7.359087
# 5     LSTM_GRU_pred     34.485926      0.108374         -7.252277
# 6       BiLSTM_pred     10.836550     -0.253751         -6.854974
# 7   BiLSTM_GRU_pred     81.615335      0.190933         -6.432429
# 8         QRNN_pred     -8.609264     -0.709588         -9.904078
# 9          ESN_pred    -17.532457     -0.564611         -8.278484
# 10         BNN_pred    -70.673843     -0.842831        -15.496811
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw     36.392748     -0.038985         -3.955343
# 2            CCV_cw    -42.573465     -1.107862         -9.221644
# 3         LSTM_pred    -88.133783     -1.489168        -10.715722
# 4          GRU_pred    -53.162513     -1.468160         -6.085384
# 5     LSTM_GRU_pred    -30.179786     -0.476372        -11.078722
# 6       BiLSTM_pred    -14.287572     -0.835283         -6.100851
# 7   BiLSTM_GRU_pred    103.246165      0.393346         -6.432429
# 8         QRNN_pred    -74.634597     -1.739508        -10.566199
# 9          ESN_pred    -61.064076     -1.970786         -7.768812
# 10         BNN_pred   -116.003362     -1.932418        -12.670692
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -78.942989     -1.572938        -13.569441
# 1            CCV_dw     49.128187      0.102382         -3.955343
# 2            CCV_cw    -42.573465     -1.107862         -9.221644
# 3         LSTM_pred    -68.252484     -1.224474        -10.513085
# 4          GRU_pred    -39.323954     -0.879495         -6.807022
# 5     LSTM_GRU_pred    -20.212202     -0.368880         -9.556775
# 6       BiLSTM_pred    -27.075102     -0.691733         -6.542611
# 7   BiLSTM_GRU_pred     94.155097      0.298949         -6.432429
# 8         QRNN_pred    -51.279016     -1.362879        -11.617773
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred   -118.649864     -1.445684        -14.887485
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -84.969797     -1.562095        -14.134987
# 1            CCV_dw     26.491821     -0.100652         -4.972473
# 2            CCV_cw    -12.769242     -0.490865        -11.426129
# 3         LSTM_pred    -42.426328     -0.580495        -11.833281
# 4          GRU_pred   -110.246666     -1.805991        -11.747429
# 5     LSTM_GRU_pred     16.062288     -0.046418         -7.385291
# 6       BiLSTM_pred    -48.491543     -0.689078         -9.589484
# 7   BiLSTM_GRU_pred     69.265371      0.088430         -6.432429
# 8         QRNN_pred      9.494451     -0.552759         -9.844723
# 9          ESN_pred    -43.589451     -1.108176         -9.003419
# 10         BNN_pred    -75.133654     -0.905427        -12.781729
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw     36.962757      0.051757         -6.714999
# 2            CCV_cw    -43.827605     -1.095758         -9.221644
# 3         LSTM_pred    -42.896951     -0.753080        -11.613002
# 4          GRU_pred    -52.501381     -1.312083         -7.157734
# 5     LSTM_GRU_pred    -98.004533     -0.825542        -10.828490
# 6       BiLSTM_pred    -55.306471     -1.260911         -7.746011
# 7   BiLSTM_GRU_pred    -52.475674     -0.422062         -8.048757
# 8         QRNN_pred    -74.634597     -1.739508        -10.566199
# 9          ESN_pred    -61.064076     -1.970786         -7.768812
# 10         BNN_pred    -51.908326     -1.514612        -12.182472
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -27.884668     -0.843764         -9.904078
# 1            CCV_dw    -29.604508     -0.520782         -7.160013
# 2            CCV_cw    -43.827605     -1.095758         -9.221644
# 3         LSTM_pred    -24.243897     -0.575739        -11.613002
# 4          GRU_pred    -39.681643     -0.784297         -7.025586
# 5     LSTM_GRU_pred    -92.556179     -0.751757        -10.354364
# 6       BiLSTM_pred    -55.863261     -0.953341         -8.972734
# 7   BiLSTM_GRU_pred    -66.472545     -0.518839         -8.667644
# 8         QRNN_pred    -64.635364     -1.279932        -10.973497
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -25.747614     -0.999019        -11.871853
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.564042         -9.904078
# 1            CCV_dw      5.924018     -0.192945         -7.461683
# 2            CCV_cw    -10.698793     -0.425836         -9.887919
# 3         LSTM_pred    -19.820540     -0.722753        -12.916971
# 4          GRU_pred   -119.491102     -1.466429        -13.721836
# 5     LSTM_GRU_pred    -74.983542     -0.588014         -9.266663
# 6       BiLSTM_pred    -88.252497     -1.060052        -11.327581
# 7   BiLSTM_GRU_pred    -64.932810     -0.494163         -9.873395
# 8         QRNN_pred      1.308214     -0.423157         -9.762195
# 9          ESN_pred    -37.096301     -0.799564         -9.904078
# 10         BNN_pred      0.935851     -0.727514        -10.704902
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw    -91.956667     -0.834631        -10.831115
# 2            CCV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -64.635364     -1.165788        -11.468322
# 5     LSTM_GRU_pred    -73.267974     -0.576707         -9.984306
# 6       BiLSTM_pred    -82.516274     -1.362393        -11.468322
# 7   BiLSTM_GRU_pred    -71.271091     -0.545150         -9.841785
# 8         QRNN_pred    -74.634597     -1.739508        -10.566199
# 9          ESN_pred    -61.064076     -1.970786         -7.768812
# 10         BNN_pred    -92.697540     -1.485070        -13.510812
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.680710         -9.904078
# 1            CCV_dw    -98.006411     -1.049213        -11.674793
# 2            CCV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.566240         -9.904078
# 5     LSTM_GRU_pred    -82.404587     -0.646634        -10.984138
# 6       BiLSTM_pred    -71.271091     -0.626653         -9.904078
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -1.279932        -10.973497
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -92.697540     -0.833132        -11.982656
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.486499         -9.841785
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.727191        -10.157965
# 5     LSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.486499         -9.841785
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.486499         -9.841785
# 9          ESN_pred    -64.635364     -1.258263        -12.278930
# 10         BNN_pred    -75.848409     -0.702626        -10.984138
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -17.545130     -0.578901         -9.904078
# 1            CCV_dw    -19.063381     -0.468567         -8.588307
# 2            CCV_cw    -28.414894     -0.477055         -9.221644
# 3         LSTM_pred    -29.144595     -0.913602        -10.021060
# 4          GRU_pred    -19.125416     -0.396255         -7.379452
# 5     LSTM_GRU_pred     -7.920372     -0.416068         -9.519410
# 6       BiLSTM_pred    -33.825905     -0.506770         -8.697166
# 7   BiLSTM_GRU_pred    -73.943223     -0.570838        -10.800627
# 8         QRNN_pred    -15.012407     -0.864393         -9.904078
# 9          ESN_pred    -34.480403     -0.637219         -9.904078
# 10         BNN_pred    -44.558057     -0.568749         -9.045738
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -34.401236     -0.890079         -9.904078
# 1            CCV_dw     26.555601     -0.107608         -4.290772
# 2            CCV_cw     -7.987046     -0.420237         -9.221644
# 3         LSTM_pred    -57.045181     -0.871651         -8.081695
# 4          GRU_pred      5.821038     -0.175493         -7.359087
# 5     LSTM_GRU_pred     46.431942      0.216605         -6.230037
# 6       BiLSTM_pred     23.456086     -0.002161         -6.782015
# 7   BiLSTM_GRU_pred     66.434351      0.064308         -6.432429
# 8         QRNN_pred    -19.826531     -0.780201         -9.221644
# 9          ESN_pred    -17.532457     -0.564611         -8.278484
# 10         BNN_pred    -37.618353     -0.557298        -13.970673
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw     -6.640596     -0.588482         -3.955343
# 2            CCV_cw    -33.586339     -1.020245         -9.221644
# 3         LSTM_pred    -82.437826     -1.585725         -9.569816
# 4          GRU_pred    -24.160966     -1.522288         -5.352963
# 5     LSTM_GRU_pred     41.346336      0.174986         -4.218165
# 6       BiLSTM_pred     -0.804346     -0.710977         -3.018181
# 7   BiLSTM_GRU_pred     80.125738      0.191340         -6.432429
# 8         QRNN_pred   -102.931906     -2.390966        -11.908871
# 9          ESN_pred    -61.064076     -1.970786         -7.768812
# 10         BNN_pred   -118.561506     -2.073755        -13.075207
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -65.388929     -1.469707        -11.670919
# 1            CCV_dw     48.962838      0.100904         -3.955343
# 2            CCV_cw    -32.048694     -0.995612         -9.221644
# 3         LSTM_pred    -58.249417     -1.158227         -7.559908
# 4          GRU_pred    -39.323954     -0.879495         -6.807022
# 5     LSTM_GRU_pred     38.302867      0.143535         -5.173730
# 6       BiLSTM_pred     31.046534     -0.093749         -5.693140
# 7   BiLSTM_GRU_pred     96.143557      0.325676         -6.432429
# 8         QRNN_pred    -60.927090     -1.274410         -9.409698
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -80.872175     -1.097347        -12.972404
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -22.240903     -0.784930         -9.899822
# 1            CCV_dw     -0.696842     -0.352381         -5.968771
# 2            CCV_cw     40.299426      0.014753         -9.205517
# 3         LSTM_pred    -89.438993     -1.222623         -9.589876
# 4          GRU_pred    -41.679657     -0.905488         -6.880622
# 5     LSTM_GRU_pred     51.971344      0.272680         -5.008726
# 6       BiLSTM_pred    -27.039995     -0.513672         -6.930841
# 7   BiLSTM_GRU_pred     58.592722     -0.004897         -6.432429
# 8         QRNN_pred    -33.663470     -0.933459         -9.221644
# 9          ESN_pred    -48.216734     -1.359897         -8.322608
# 10         BNN_pred    -46.674021     -0.667350        -11.547620
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw    -19.904764     -0.650591         -7.152716
# 2            CCV_cw    -43.631675     -1.093096         -9.221644
# 3         LSTM_pred   -103.764127     -1.698103        -12.277624
# 4          GRU_pred    -54.643080     -1.585705         -7.367592
# 5     LSTM_GRU_pred      6.855137     -0.148215         -7.846300
# 6       BiLSTM_pred    -46.609395     -1.259169         -5.485890
# 7   BiLSTM_GRU_pred    -55.306196     -0.571490         -8.669873
# 8         QRNN_pred   -102.931906     -2.390966        -11.908871
# 9          ESN_pred    -61.064076     -1.970786         -7.768812
# 10         BNN_pred   -103.384992     -1.680612        -11.424133
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -71.271091     -1.535049        -12.226836
# 1            CCV_dw      1.355772     -0.330860         -6.985611
# 2            CCV_cw    -43.631675     -1.093096         -9.221644
# 3         LSTM_pred    -84.046125     -1.363499        -10.347652
# 4          GRU_pred    -22.257928     -0.612423         -6.640311
# 5     LSTM_GRU_pred    -26.567590     -0.584475        -10.597439
# 6       BiLSTM_pred    -18.826650     -0.596490         -5.511672
# 7   BiLSTM_GRU_pred    -69.261255     -0.543855         -8.693615
# 8         QRNN_pred    -60.927090     -1.274410         -9.409698
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -90.271856     -1.116031        -12.349820
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -5.172519     -0.480781         -9.825790
# 1            CCV_dw    -14.914009     -0.439177         -7.727903
# 2            CCV_cw     24.182371     -0.136847         -9.221644
# 3         LSTM_pred    -67.477430     -1.341420        -12.597785
# 4          GRU_pred    -32.680382     -0.713672         -6.640311
# 5     LSTM_GRU_pred    -14.756605     -0.476631         -9.498949
# 6       BiLSTM_pred    -82.134420     -1.025149        -10.870568
# 7   BiLSTM_GRU_pred    -80.752638     -0.642825         -9.832544
# 8         QRNN_pred    -20.463373     -0.934333        -10.099220
# 9          ESN_pred    -64.635364     -1.239242         -9.904078
# 10         BNN_pred    -74.785189     -0.887486        -11.816779
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -67.048822     -1.586415        -11.561996
# 1            CCV_dw    -91.956667     -0.834631        -10.831115
# 2            CCV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -64.635364     -1.258263        -12.278930
# 5     LSTM_GRU_pred    -73.267974     -0.576707         -9.984306
# 6       BiLSTM_pred    -82.516274     -1.362393        -11.468322
# 7   BiLSTM_GRU_pred    -71.271091     -0.659604         -9.904078
# 8         QRNN_pred   -102.931906     -2.390966        -11.908871
# 9          ESN_pred    -61.064076     -1.970786         -7.768812
# 10         BNN_pred    -92.697540     -1.485070        -13.510812
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -71.271091     -1.535049        -12.226836
# 1            CCV_dw    -98.006411     -1.049213        -11.674793
# 2            CCV_cw    -64.635364     -1.239242         -9.904078
# 3         LSTM_pred    -82.516274     -0.647705         -9.841785
# 4          GRU_pred    -64.635364     -0.566240         -9.904078
# 5     LSTM_GRU_pred    -82.404587     -0.646634        -10.984138
# 6       BiLSTM_pred    -82.516274     -0.732555         -9.904078
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -60.927090     -1.274410         -9.409698
# 9          ESN_pred    -54.355421     -1.816798         -7.768812
# 10         BNN_pred    -92.697540     -0.833132        -11.982656
# 11               __    -64.635364     -0.486499         -9.841785
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -64.635364     -0.486499         -9.841785
# 1            CCV_dw    -64.635364     -0.600334         -9.904078
# 2            CCV_cw    -64.635364     -0.486499         -9.841785
# 3         LSTM_pred    -64.635364     -0.486499         -9.841785
# 4          GRU_pred    -64.635364     -0.566240         -9.904078
# 5     LSTM_GRU_pred    -71.271091     -0.545150         -9.841785
# 6       BiLSTM_pred    -64.635364     -0.566240         -9.904078
# 7   BiLSTM_GRU_pred    -64.635364     -0.486499         -9.841785
# 8         QRNN_pred    -64.635364     -0.680710         -9.904078
# 9          ESN_pred    -64.635364     -1.239242         -9.904078
# 10         BNN_pred    -75.848409     -0.702626        -10.984138
# 11               __    -64.635364     -0.486499         -9.841785

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y1', file, 'CCV')
get_final_results_1('2024_y1', file, 'CCV')

get_final_results('2024_y1', dw_file, 'CCV_dw')
get_final_results_1('2024_y1', dw_file, 'CCV_dw')

get_final_results('2024_y1', cw_file, 'CCV_cw')
get_final_results_1('2024_y1', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-44-3cbff3a033da>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-44-3cbff3a033da>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-44-3cbff3a033da>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-44-3cbff3a033da>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-45-e6d9a494c045>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     34.903636      0.708918         -6.426168
# 1            CCV_dw    172.504536      1.214951         -5.724544
# 2            CCV_cw    178.661499      0.871338         -6.416039
# 3         LSTM_pred    152.039247      1.093637         -6.212724
# 4          GRU_pred    151.532694      0.745763         -6.465690
# 5     LSTM_GRU_pred    169.658089      0.792560         -6.437814
# 6       BiLSTM_pred     44.466919      0.779573         -6.426168
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    156.408749      0.770809         -6.525284
# 10         BNN_pred    181.250948      0.941007         -5.927286
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.421245      0.822937         -5.986781
# 1            CCV_dw    189.381306      1.031803         -5.882078
# 2            CCV_cw    167.027252      0.923528         -5.964144
# 3         LSTM_pred    124.460354      0.861054         -7.556079
# 4          GRU_pred    187.937807      1.072946         -6.859770
# 5     LSTM_GRU_pred    179.072119      1.019482         -5.711801
# 6       BiLSTM_pred    233.465888      1.419475         -5.074789
# 7   BiLSTM_GRU_pred    174.694555      0.876750         -7.479621
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     39.654557     -0.028321         -8.837755
# 10         BNN_pred    151.636928      0.677120         -6.223405
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    175.865780      0.951199         -5.967303
# 1            CCV_dw    126.613486      0.572447         -5.972105
# 2            CCV_cw     96.442618      0.509833         -6.437533
# 3         LSTM_pred    109.812302      0.761716         -8.173380
# 4          GRU_pred    152.811698      1.003705         -5.071159
# 5     LSTM_GRU_pred    225.181198      1.517289         -4.457078
# 6       BiLSTM_pred    153.241958      0.977609         -5.262139
# 7   BiLSTM_GRU_pred     87.838787      0.225184         -8.764794
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     14.064970     -0.274839         -8.008016
# 10         BNN_pred     99.515095      0.313230         -7.174312
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    177.254342      0.946794         -5.949254
# 1            CCV_dw    179.323445      0.934657         -5.956175
# 2            CCV_cw    150.961104      0.837346         -6.133056
# 3         LSTM_pred    109.812302      0.761716         -8.173380
# 4          GRU_pred    213.908544      1.267293         -6.713010
# 5     LSTM_GRU_pred    193.463925      1.155506         -4.970310
# 6       BiLSTM_pred    153.813152      0.959537         -5.071118
# 7   BiLSTM_GRU_pred    129.002980      0.559392         -9.669853
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred      2.965338     -0.366306         -8.909097
# 10         BNN_pred    131.998321      0.544031         -6.270659
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.421245      0.822937         -5.986781
# 1            CCV_dw    174.579473      0.932247         -5.956203
# 2            CCV_cw    185.560280      1.059477         -5.923845
# 3         LSTM_pred    124.460354      0.861054         -7.556079
# 4          GRU_pred    187.937807      1.072946         -6.859770
# 5     LSTM_GRU_pred    179.072119      1.019482         -5.711801
# 6       BiLSTM_pred    233.465888      1.419475         -5.074789
# 7   BiLSTM_GRU_pred    174.694555      0.876750         -7.479621
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     33.260080     -0.085418         -8.892448
# 10         BNN_pred    142.720213      0.617156         -6.296420
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     46.167224      0.800298         -6.426168
# 1            CCV_dw    142.622144      1.000349         -5.761445
# 2            CCV_cw    129.798194      0.733754         -6.779199
# 3         LSTM_pred    139.267881      1.014227         -6.197962
# 4          GRU_pred    152.851076      0.698676         -6.434461
# 5     LSTM_GRU_pred    177.047869      0.865972         -6.311443
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     38.365122      0.738442         -5.975049
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    132.759367      0.619218         -7.354025
# 10         BNN_pred    126.053006      0.576979         -7.301035
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.234684      0.781386         -6.426168
# 1            CCV_dw    181.608628      1.250483         -5.701516
# 2            CCV_cw    156.129734      0.840362         -6.576675
# 3         LSTM_pred    139.267881      1.014227         -6.197962
# 4          GRU_pred    176.707541      0.927068         -6.327361
# 5     LSTM_GRU_pred    196.628423      0.981091         -6.292715
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    156.408749      0.770809         -6.525284
# 10         BNN_pred    156.922378      0.783083         -5.994245
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     34.903636      0.708918         -6.426168
# 1            CCV_dw    172.504536      1.214951         -5.724544
# 2            CCV_cw    168.101818      0.801429         -6.418118
# 3         LSTM_pred    152.039247      1.093637         -6.212724
# 4          GRU_pred    151.532694      0.745763         -6.465690
# 5     LSTM_GRU_pred    169.658089      0.792560         -6.437814
# 6       BiLSTM_pred     44.466919      0.779573         -6.426168
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    156.408749      0.770809         -6.525284
# 10         BNN_pred    167.880343      0.853768         -6.043723
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     -1.578828      0.434431         -7.332713
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     30.433725      0.676651         -6.426168
# 4          GRU_pred     30.433725      0.676651         -6.426168
# 5     LSTM_GRU_pred     30.433725      0.676651         -6.426168
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     38.365122      0.738442         -5.975049
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     32.964298      0.621325         -7.259176
# 10         BNN_pred     22.752102      0.584483         -6.002409
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     30.433725      0.676651         -6.426168
# 4          GRU_pred     44.466919      0.779573         -6.426168
# 5     LSTM_GRU_pred     44.466919      0.779573         -6.426168
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.779573         -6.426168
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.779573         -6.426168
# 4          GRU_pred     44.466919      0.779573         -6.426168
# 5     LSTM_GRU_pred     44.466919      0.779573         -6.426168
# 6       BiLSTM_pred     44.466919      0.779573         -6.426168
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.779573         -6.426168
# 10         BNN_pred     44.466919      0.779573         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     34.903636      0.708918         -6.426168
# 1            CCV_dw    176.284060      0.911258         -6.328146
# 2            CCV_cw    173.379845      0.816641         -6.438662
# 3         LSTM_pred     94.287192      1.109878         -6.195912
# 4          GRU_pred     98.539680      0.518867         -6.647593
# 5     LSTM_GRU_pred    110.663710      0.604758         -6.575028
# 6       BiLSTM_pred     44.466919      0.779573         -6.426168
# 7   BiLSTM_GRU_pred     55.050732      0.643458         -7.182932
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    156.408749      0.770809         -6.525284
# 10         BNN_pred    174.326819      0.893324         -5.962235
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     40.660403      0.707688         -6.429460
# 1            CCV_dw    197.400197      1.082582         -5.808332
# 2            CCV_cw    157.109378      0.846850         -6.381295
# 3         LSTM_pred    143.937553      0.943365         -7.486362
# 4          GRU_pred    135.989179      0.680125         -8.678233
# 5     LSTM_GRU_pred     90.979685      0.473512         -8.671533
# 6       BiLSTM_pred    128.698226      0.946765         -5.001854
# 7   BiLSTM_GRU_pred     76.597603      0.590622         -6.777712
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    192.616638      0.930849         -6.119789
# 10         BNN_pred    177.992137      0.861470         -6.136955
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.254642      0.684677         -6.531484
# 1            CCV_dw    168.103736      0.881244         -5.894554
# 2            CCV_cw    163.858415      0.999370         -6.154232
# 3         LSTM_pred    111.094120      0.715653         -8.228731
# 4          GRU_pred    106.058099      0.534658         -7.108913
# 5     LSTM_GRU_pred    153.851635      1.008084         -4.271866
# 6       BiLSTM_pred    102.113752      0.736238         -5.241449
# 7   BiLSTM_GRU_pred     19.194012      0.064695         -9.176085
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    153.745815      0.700606         -5.979317
# 10         BNN_pred    115.554109      0.436686         -7.104464
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     65.184901      0.897693         -6.338066
# 1            CCV_dw    202.236338      1.085372         -5.808304
# 2            CCV_cw    181.951665      1.089447         -6.360053
# 3         LSTM_pred    126.225805      0.825449         -8.228731
# 4          GRU_pred    152.832215      0.808164         -8.551442
# 5     LSTM_GRU_pred    124.713395      0.728726         -7.886738
# 6       BiLSTM_pred    114.132559      0.829297         -5.085615
# 7   BiLSTM_GRU_pred     36.798973      0.275484         -8.937969
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    188.246298      0.903796         -5.612522
# 10         BNN_pred    166.497628      0.792961         -6.114161
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     40.660403      0.707688         -6.429460
# 1            CCV_dw    192.973313      1.052484         -5.829885
# 2            CCV_cw    172.517271      1.004129         -6.360286
# 3         LSTM_pred    158.916945      1.055140         -7.389598
# 4          GRU_pred    135.989179      0.680125         -8.678233
# 5     LSTM_GRU_pred     90.979685      0.473512         -8.671533
# 6       BiLSTM_pred    128.698226      0.946765         -5.001854
# 7   BiLSTM_GRU_pred     64.251547      0.495599         -7.511931
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    185.281356      0.882483         -6.157662
# 10         BNN_pred    164.658417      0.772494         -6.207215
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     46.167224      0.800298         -6.426168
# 1            CCV_dw    182.289185      0.936068         -6.202901
# 2            CCV_cw    142.946045      0.823213         -6.293176
# 3         LSTM_pred     87.008408      1.031027         -6.181189
# 4          GRU_pred    104.409792      0.579629         -6.518201
# 5     LSTM_GRU_pred    128.776921      0.756072         -6.377492
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred    107.119879      0.909568         -4.479565
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    138.460276      0.655166         -6.874865
# 10         BNN_pred    145.109696      0.709340         -6.279725
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.234684      0.781386         -6.426168
# 1            CCV_dw    181.034916      0.913412         -6.328116
# 2            CCV_cw    174.017120      1.017561         -6.401113
# 3         LSTM_pred    101.812077      1.134620         -6.181189
# 4          GRU_pred    116.132565      0.641243         -6.550471
# 5     LSTM_GRU_pred    148.214153      0.877365         -6.360003
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     55.050732      0.692532         -7.139055
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    152.284534      0.742907         -6.548639
# 10         BNN_pred    162.868076      0.826328         -6.279725
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     34.903636      0.708918         -6.426168
# 1            CCV_dw    171.935244      0.882044         -6.351628
# 2            CCV_cw    175.544373      0.948503         -6.451659
# 3         LSTM_pred     96.011828      1.087291         -6.213901
# 4          GRU_pred     98.539680      0.518867         -6.647593
# 5     LSTM_GRU_pred    110.663710      0.604758         -6.575028
# 6       BiLSTM_pred     44.466919      0.779573         -6.426168
# 7   BiLSTM_GRU_pred     55.050732      0.692532         -7.139055
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    156.408749      0.770809         -6.525284
# 10         BNN_pred    161.034588      0.806036         -6.375299
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     21.747922      0.615924         -7.332713
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     30.433725      0.676651         -6.426168
# 4          GRU_pred     30.433725      0.676651         -6.426168
# 5     LSTM_GRU_pred     30.433725      0.676651         -6.426168
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     52.506331      0.841252         -5.975049
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     32.964298      0.664345         -6.694353
# 10         BNN_pred     28.477359      0.664345         -5.975049
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.779573         -6.426168
# 4          GRU_pred     44.466919      0.779573         -6.426168
# 5     LSTM_GRU_pred     44.466919      0.779573         -6.426168
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.751749         -6.449168
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.779573         -6.426168
# 4          GRU_pred     44.466919      0.779573         -6.426168
# 5     LSTM_GRU_pred     44.466919      0.779573         -6.426168
# 6       BiLSTM_pred     44.466919      0.779573         -6.426168
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.779573         -6.426168
# 10         BNN_pred     44.466919      0.779573         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.431188      0.774312         -5.691626
# 1            CCV_dw    194.369315      1.086124         -5.863321
# 2            CCV_cw     27.888118      0.684721         -5.141173
# 3         LSTM_pred     97.566228      0.710055         -7.161285
# 4          GRU_pred    218.800873      1.305378         -6.679968
# 5     LSTM_GRU_pred    149.088205      0.892090         -6.490014
# 6       BiLSTM_pred    144.534716      0.726792         -6.204369
# 7   BiLSTM_GRU_pred     72.478058      0.468516         -6.696646
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    137.946081      0.708536         -5.787397
# 10         BNN_pred    146.200565      0.662458         -6.965917
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     47.117901      0.870760         -5.608409
# 1            CCV_dw    175.673935      1.036154         -7.244081
# 2            CCV_cw    155.501428      0.870272         -6.583719
# 3         LSTM_pred    188.883465      1.026642         -7.046033
# 4          GRU_pred    125.601014      0.675002         -9.231261
# 5     LSTM_GRU_pred    100.565230      0.521472         -6.746969
# 6       BiLSTM_pred    195.796078      1.128239         -4.659000
# 7   BiLSTM_GRU_pred     53.041025      0.188925         -7.558846
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     28.507267     -0.088861         -8.867491
# 10         BNN_pred     88.653029      0.233985         -7.031103
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.326919      0.319826         -3.372620
# 1            CCV_dw    106.364403      0.662376         -5.716782
# 2            CCV_cw     97.924612      0.742517         -4.676617
# 3         LSTM_pred    127.538151      0.609836         -6.673679
# 4          GRU_pred     74.595505      0.319619         -5.574050
# 5     LSTM_GRU_pred     38.750118     -0.074542         -6.218852
# 6       BiLSTM_pred     54.581461     -0.066195         -5.729217
# 7   BiLSTM_GRU_pred      3.636706     -0.188087         -7.747533
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    -50.763248     -1.091808        -10.962813
# 10         BNN_pred     46.709133      0.023130         -6.410483
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.468523      0.458280         -5.106350
# 1            CCV_dw    113.191227      0.649496         -8.563743
# 2            CCV_cw    117.519560      0.738829         -5.762777
# 3         LSTM_pred    156.093235      0.825882         -6.597232
# 4          GRU_pred     60.228153      0.124511         -8.482077
# 5     LSTM_GRU_pred     69.964127      0.315089         -6.487081
# 6       BiLSTM_pred    123.704525      0.636503         -4.747540
# 7   BiLSTM_GRU_pred     12.443441     -0.167649         -7.539246
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     -7.326195     -0.466372        -10.309106
# 10         BNN_pred     99.576966      0.341464         -6.431409
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     92.188015      1.213480         -5.106350
# 1            CCV_dw    135.185574      0.733615         -8.014328
# 2            CCV_cw    178.639946      1.068617         -6.583719
# 3         LSTM_pred    178.198127      0.970394         -7.733636
# 4          GRU_pred    114.467886      0.665905         -8.988797
# 5     LSTM_GRU_pred    113.424529      0.631320         -6.579442
# 6       BiLSTM_pred    134.294920      0.725158         -4.595941
# 7   BiLSTM_GRU_pred     37.536577      0.059730         -7.539246
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred      6.777927     -0.300081         -8.898401
# 10         BNN_pred     94.887777      0.291733         -7.592013
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.326919      0.319826         -3.372620
# 1            CCV_dw    124.686161      0.705146         -6.079366
# 2            CCV_cw    -17.989933      0.360545         -4.692337
# 3         LSTM_pred     68.327908      0.504747         -6.844755
# 4          GRU_pred    142.539175      1.018648         -4.752387
# 5     LSTM_GRU_pred     71.958011      0.249650         -6.026200
# 6       BiLSTM_pred     78.766755      0.185964         -6.494181
# 7   BiLSTM_GRU_pred     10.175066     -0.101950         -8.380620
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     94.139182      0.426566         -5.130636
# 10         BNN_pred     75.327088      0.293649         -5.515163
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -26.376780      0.267321         -5.106350
# 1            CCV_dw    186.457598      1.056273         -5.902420
# 2            CCV_cw    -12.358662      0.408466         -5.106350
# 3         LSTM_pred     82.090721      0.605465         -6.757698
# 4          GRU_pred    158.777530      1.009183         -6.567517
# 5     LSTM_GRU_pred     98.470073      0.618129         -6.282934
# 6       BiLSTM_pred    133.188155      0.641641         -6.182298
# 7   BiLSTM_GRU_pred     24.184524      0.093715         -6.927373
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    140.307628      0.736659         -5.591233
# 10         BNN_pred    105.178340      0.366976         -6.412873
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     39.154942      0.770304         -5.106350
# 1            CCV_dw    194.374923      1.088875         -5.863294
# 2            CCV_cw     48.471224      0.868402         -5.106350
# 3         LSTM_pred     88.449465      0.649519         -7.221267
# 4          GRU_pred    169.852406      1.078727         -6.654870
# 5     LSTM_GRU_pred    137.862358      0.830176         -6.786285
# 6       BiLSTM_pred    130.936630      0.620330         -6.194606
# 7   BiLSTM_GRU_pred     51.930318      0.313399         -6.827454
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    144.111235      0.753598         -5.808111
# 10         BNN_pred    122.279087      0.490267         -7.018809
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.326919      0.319826         -3.372620
# 1            CCV_dw     -1.578828      0.405774         -7.642435
# 2            CCV_cw    -17.989933      0.360545         -4.692337
# 3         LSTM_pred     38.365122      0.738442         -5.975049
# 4          GRU_pred     28.477359      0.636203         -5.996435
# 5     LSTM_GRU_pred    -19.464972      0.312086         -5.975049
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     19.085651      0.559416         -6.694353
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred      9.381476      0.483991         -6.694353
# 10         BNN_pred     22.752102      0.584483         -6.002409
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -26.376780      0.267321         -5.106350
# 1            CCV_dw     21.747922      0.615924         -7.332713
# 2            CCV_cw    -12.358662      0.408466         -5.106350
# 3         LSTM_pred     38.365122      0.738442         -5.975049
# 4          GRU_pred     30.433725      0.676651         -6.426168
# 5     LSTM_GRU_pred     30.433725      0.676651         -6.426168
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     30.433725      0.676651         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     32.964298      0.664345         -6.694353
# 10         BNN_pred     28.477359      0.664345         -5.975049
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     20.621489      0.602553         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.779573         -6.426168
# 4          GRU_pred     44.466919      0.779573         -6.426168
# 5     LSTM_GRU_pred     30.433725      0.676651         -6.426168
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.751749         -6.449168
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     17.412976      0.614178         -7.163752
# 1            CCV_dw    210.681558      1.229372         -5.811249
# 2            CCV_cw     54.288953      0.750497         -5.448947
# 3         LSTM_pred    141.361693      0.666802         -7.747136
# 4          GRU_pred    218.800873      1.305378         -6.679968
# 5     LSTM_GRU_pred    170.049444      1.052770         -6.373746
# 6       BiLSTM_pred    241.273139      1.396152         -5.411600
# 7   BiLSTM_GRU_pred    104.655508      0.588438         -6.610790
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     78.354617      0.306724         -7.000545
# 10         BNN_pred    158.801010      0.767265         -5.768310
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     54.337580      0.931731         -5.570005
# 1            CCV_dw    177.753107      1.081177         -7.924190
# 2            CCV_cw    102.757667      0.554232         -5.863371
# 3         LSTM_pred    212.969225      1.206612         -5.871020
# 4          GRU_pred    125.601014      0.675002         -9.231261
# 5     LSTM_GRU_pred    101.963097      0.534325         -7.294788
# 6       BiLSTM_pred    207.338986      1.299587         -4.579078
# 7   BiLSTM_GRU_pred     20.766571     -0.074491         -9.881905
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     89.614197      0.489319         -4.716764
# 10         BNN_pred     50.063166     -0.083013         -9.137531
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      0.000000      0.546862         -2.417327
# 1            CCV_dw     73.917079      0.458308         -5.698579
# 2            CCV_cw     60.543792      0.284242         -5.282927
# 3         LSTM_pred    134.346523      0.728009         -4.015020
# 4          GRU_pred     96.292620      0.656428         -2.723289
# 5     LSTM_GRU_pred    102.489125      0.596403         -3.248304
# 6       BiLSTM_pred     78.007909      0.346910         -5.930042
# 7   BiLSTM_GRU_pred    -14.994603     -0.468272        -10.365128
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     -9.375410     -0.722683         -7.978581
# 10         BNN_pred     61.842661      0.184197         -4.506281
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.856808      0.456122         -4.753962
# 1            CCV_dw     89.025484      0.465930        -10.155289
# 2            CCV_cw     86.682644      0.534129         -5.104279
# 3         LSTM_pred    139.012590      0.724413         -6.859218
# 4          GRU_pred     60.228153      0.124511         -8.482077
# 5     LSTM_GRU_pred     74.133219      0.368560         -6.956508
# 6       BiLSTM_pred    104.995091      0.584489         -5.420208
# 7   BiLSTM_GRU_pred      0.897327     -0.209194         -9.647202
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     26.676408     -0.133259         -6.536478
# 10         BNN_pred     12.838113     -0.475473         -7.938393
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      8.958577      0.645451         -4.753962
# 1            CCV_dw    130.959370      0.727946         -8.792705
# 2            CCV_cw     68.243682      0.307908         -5.623161
# 3         LSTM_pred    163.011447      0.877264         -6.706986
# 4          GRU_pred     41.557396     -0.075388         -9.646425
# 5     LSTM_GRU_pred    135.769001      0.804882         -7.010453
# 6       BiLSTM_pred    122.608822      0.749234         -4.621286
# 7   BiLSTM_GRU_pred     27.160518     -0.028823         -9.521646
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     36.627477     -0.019509         -7.380327
# 10         BNN_pred     30.486123     -0.280268         -7.787362
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      0.000000      0.546862         -2.417327
# 1            CCV_dw     88.191630      0.439205         -7.584634
# 2            CCV_cw    -19.849035      0.323608         -5.085678
# 3         LSTM_pred    155.533203      0.838518         -5.055980
# 4          GRU_pred    149.387377      1.144153         -5.012870
# 5     LSTM_GRU_pred     49.938684      0.040254         -6.152582
# 6       BiLSTM_pred     54.799166     -0.055341         -7.349291
# 7   BiLSTM_GRU_pred     26.038983     -0.023827         -7.180713
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     22.608653     -0.199302         -7.669389
# 10         BNN_pred    103.166521      0.579754         -5.033773
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -33.422804      0.193179         -5.106350
# 1            CCV_dw    174.426575      1.075450         -5.945285
# 2            CCV_cw     -1.942275      0.459805         -5.089129
# 3         LSTM_pred    118.963762      0.511051         -8.028185
# 4          GRU_pred    158.777530      1.009183         -6.567517
# 5     LSTM_GRU_pred     69.119111      0.438759         -6.307983
# 6       BiLSTM_pred    137.433046      0.714908         -5.615506
# 7   BiLSTM_GRU_pred     73.219125      0.364272         -6.289797
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     28.117857     -0.151088         -9.264409
# 10         BNN_pred    103.770898      0.368031         -6.773220
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -26.376780      0.267321         -5.106350
# 1            CCV_dw    171.964427      0.973254         -6.003230
# 2            CCV_cw     11.649998      0.468450         -5.772688
# 3         LSTM_pred    110.416724      0.444333         -8.501373
# 4          GRU_pred    152.964814      0.956252         -6.600627
# 5     LSTM_GRU_pred    165.686424      1.036896         -6.319035
# 6       BiLSTM_pred    140.684540      0.739317         -5.510335
# 7   BiLSTM_GRU_pred     99.280143      0.554251         -6.643116
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     57.235332      0.126126         -6.996628
# 10         BNN_pred    143.417718      0.669835         -5.491991
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      0.000000      0.546862         -2.417327
# 1            CCV_dw     -1.578828      0.405774         -7.642435
# 2            CCV_cw    -26.607029      0.262072         -5.516324
# 3         LSTM_pred     38.365122      0.738442         -5.975049
# 4          GRU_pred     28.477359      0.628313         -6.002409
# 5     LSTM_GRU_pred    -19.464972      0.270710         -6.002409
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     19.085651      0.593199         -6.297292
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred      9.381476      0.483991         -6.694353
# 10         BNN_pred     22.752102      0.584483         -6.002409
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -33.422804      0.193179         -5.106350
# 1            CCV_dw     21.747922      0.587567         -7.642435
# 2            CCV_cw    -12.358662      0.408466         -5.106350
# 3         LSTM_pred     38.365122      0.738442         -5.975049
# 4          GRU_pred     30.433725      0.676651         -6.426168
# 5     LSTM_GRU_pred    -26.954642      0.242132         -6.426168
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     38.365122      0.738442         -5.975049
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     32.964298      0.664345         -6.694353
# 10         BNN_pred     28.477359      0.664345         -5.975049
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -26.376780      0.267321         -5.106350
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     30.433725      0.676651         -6.426168
# 4          GRU_pred     30.433725      0.676651         -6.426168
# 5     LSTM_GRU_pred     30.433725      0.676651         -6.426168
# 6       BiLSTM_pred     30.433725      0.676651         -6.426168
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.751749         -6.449168
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     34.903636      0.708918         -6.426168
# 1            CCV_dw    119.316452      0.844673         -7.721031
# 2            CCV_cw    173.132758      0.832684         -6.446276
# 3         LSTM_pred     44.466919      0.779573         -6.426168
# 4          GRU_pred    151.532694      0.745763         -6.465690
# 5     LSTM_GRU_pred     44.466919      0.779573         -6.426168
# 6       BiLSTM_pred    114.766562      0.750738         -6.450014
# 7   BiLSTM_GRU_pred    133.552409      0.722613         -6.473794
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    119.118127      0.520068         -8.011323
# 10         BNN_pred    180.026861      0.932795         -5.933435
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.421245      0.822937         -5.986781
# 1            CCV_dw    136.841742      0.668912         -7.899159
# 2            CCV_cw    112.146381      0.399430         -7.760323
# 3         LSTM_pred    192.629394      1.145205         -5.726421
# 4          GRU_pred    187.937807      1.072946         -6.859770
# 5     LSTM_GRU_pred    213.982022      1.116955         -6.101833
# 6       BiLSTM_pred     66.455713      0.049236        -10.147234
# 7   BiLSTM_GRU_pred    179.733980      1.010466         -6.606456
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    127.249839      0.647394         -7.681089
# 10         BNN_pred    224.867539      1.183684         -5.994678
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    175.865780      0.951199         -5.967303
# 1            CCV_dw    150.254300      0.751728         -6.191811
# 2            CCV_cw    118.006538      0.655833         -8.121824
# 3         LSTM_pred    161.991894      1.056842         -6.562577
# 4          GRU_pred    152.811698      1.003705         -5.071159
# 5     LSTM_GRU_pred    215.927494      1.180180         -4.594059
# 6       BiLSTM_pred    -15.673227     -0.668264        -14.539849
# 7   BiLSTM_GRU_pred     72.416449      0.233226         -7.788496
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     93.927017      0.414504         -8.000209
# 10         BNN_pred    211.476647      1.155599         -5.815080
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    177.254342      0.946794         -5.949254
# 1            CCV_dw    123.776284      0.580883         -6.711456
# 2            CCV_cw    146.502858      0.780227         -7.229998
# 3         LSTM_pred    197.535130      1.187251         -5.702963
# 4          GRU_pred    213.908544      1.267293         -6.713010
# 5     LSTM_GRU_pred    179.011364      0.884418         -6.263458
# 6       BiLSTM_pred     39.957328     -0.162655        -10.079971
# 7   BiLSTM_GRU_pred     90.540173      0.397024         -8.021633
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     75.219131      0.264830        -10.852920
# 10         BNN_pred    207.837413      1.082424         -5.997523
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.421245      0.822937         -5.986781
# 1            CCV_dw    139.156511      0.693635         -6.673753
# 2            CCV_cw    132.147238      0.660623         -7.709742
# 3         LSTM_pred    192.629394      1.145205         -5.726421
# 4          GRU_pred    187.937807      1.072946         -6.859770
# 5     LSTM_GRU_pred    213.982022      1.116955         -6.101833
# 6       BiLSTM_pred     74.664376      0.112739         -9.455624
# 7   BiLSTM_GRU_pred    179.733980      1.010466         -6.606456
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     90.941909      0.383572         -9.335102
# 10         BNN_pred    210.475987      1.091699         -6.065950
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     46.167224      0.800298         -6.426168
# 1            CCV_dw    132.690310      0.933797         -6.049338
# 2            CCV_cw    149.324500      0.873480         -6.664025
# 3         LSTM_pred     44.466919      0.751749         -6.449168
# 4          GRU_pred    152.851076      0.698676         -6.434461
# 5     LSTM_GRU_pred     21.353733      0.494496         -8.846084
# 6       BiLSTM_pred     85.658734      0.551007         -7.756952
# 7   BiLSTM_GRU_pred    120.604938      0.547936         -6.622729
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     94.867275      0.350068         -9.516069
# 10         BNN_pred    122.656815      0.551222         -6.548894
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.234684      0.781386         -6.426168
# 1            CCV_dw    138.350427      0.960054         -6.384256
# 2            CCV_cw    158.840442      0.857167         -6.524248
# 3         LSTM_pred     44.466919      0.751749         -6.449168
# 4          GRU_pred    176.707541      0.927068         -6.327361
# 5     LSTM_GRU_pred     20.835400      0.572800         -7.820054
# 6       BiLSTM_pred    119.340778      0.784483         -6.018686
# 7   BiLSTM_GRU_pred    120.604938      0.547936         -6.622729
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     94.724369      0.345822        -10.168042
# 10         BNN_pred    155.723502      0.774791         -5.994245
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     34.903636      0.708918         -6.426168
# 1            CCV_dw    135.729676      0.971176         -6.365182
# 2            CCV_cw    158.326541      0.733696         -6.458809
# 3         LSTM_pred     44.466919      0.779573         -6.426168
# 4          GRU_pred    151.532694      0.745763         -6.465690
# 5     LSTM_GRU_pred     44.466919      0.779573         -6.426168
# 6       BiLSTM_pred    123.347081      0.812368         -5.997221
# 7   BiLSTM_GRU_pred    133.552409      0.722613         -6.473794
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    102.722851      0.404081         -9.451344
# 10         BNN_pred    166.670111      0.845526         -6.043723
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     21.747922      0.615924         -7.332713
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.751749         -6.449168
# 4          GRU_pred     30.433725      0.676651         -6.426168
# 5     LSTM_GRU_pred     21.353733      0.494496         -8.846084
# 6       BiLSTM_pred     20.835400      0.580415         -7.728274
# 7   BiLSTM_GRU_pred     44.466919      0.693246         -6.500416
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     20.835400      0.580415         -7.728274
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.751749         -6.449168
# 4          GRU_pred     44.466919      0.779573         -6.426168
# 5     LSTM_GRU_pred     20.835400      0.572800         -7.820054
# 6       BiLSTM_pred     52.506331      0.813380         -5.996435
# 7   BiLSTM_GRU_pred     44.466919      0.693246         -6.500416
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.779573         -6.426168
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.779573         -6.426168
# 4          GRU_pred     44.466919      0.779573         -6.426168
# 5     LSTM_GRU_pred     44.466919      0.779573         -6.426168
# 6       BiLSTM_pred     52.506331      0.841252         -5.975049
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.779573         -6.426168
# 10         BNN_pred     44.466919      0.779573         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     34.903636      0.708918         -6.426168
# 1            CCV_dw     98.849707      0.620111         -6.505058
# 2            CCV_cw    180.552828      0.977745         -6.414335
# 3         LSTM_pred     63.388930      0.703428         -6.489492
# 4          GRU_pred     98.539680      0.518867         -6.647593
# 5     LSTM_GRU_pred    150.446217      0.749628         -6.450943
# 6       BiLSTM_pred    132.923198      0.534421         -6.891686
# 7   BiLSTM_GRU_pred     81.672048      0.320687         -6.534159
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    126.477709      0.569836         -7.958983
# 10         BNN_pred    165.253522      0.832904         -6.008660
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     40.660403      0.707688         -6.429460
# 1            CCV_dw    148.076398      0.733912         -6.525034
# 2            CCV_cw    138.200795      0.718280         -6.487305
# 3         LSTM_pred    199.163499      1.176605         -5.710438
# 4          GRU_pred    135.989179      0.680125         -8.678233
# 5     LSTM_GRU_pred    168.837739      0.812781         -5.107447
# 6       BiLSTM_pred     93.117197      0.381590         -6.865804
# 7   BiLSTM_GRU_pred    218.022680      1.275588         -5.013503
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    150.833728      0.654975         -7.452676
# 10         BNN_pred    211.017929      1.088426         -6.063235
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     58.254642      0.684677         -6.531484
# 1            CCV_dw    122.562973      0.506584         -7.137599
# 2            CCV_cw    146.233276      0.872941         -6.248863
# 3         LSTM_pred    125.856438      0.756585         -6.925391
# 4          GRU_pred    106.058099      0.534658         -7.108913
# 5     LSTM_GRU_pred     73.059739      0.085732         -9.560210
# 6       BiLSTM_pred     22.928974     -0.124561        -11.239832
# 7   BiLSTM_GRU_pred     72.042230      0.230812         -6.271260
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    114.718675      0.422631         -9.098134
# 10         BNN_pred    159.086294      0.754803         -6.640751
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     65.184901      0.897693         -6.338066
# 1            CCV_dw    150.841371      0.727431         -6.605059
# 2            CCV_cw    165.048048      0.975763         -6.452331
# 3         LSTM_pred    204.096112      1.218559         -5.687045
# 4          GRU_pred    152.832215      0.808164         -8.551442
# 5     LSTM_GRU_pred    131.636367      0.566596         -6.453047
# 6       BiLSTM_pred     48.581277      0.030018         -8.565491
# 7   BiLSTM_GRU_pred     91.825849      0.406766         -6.513900
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    118.462162      0.427237         -8.859782
# 10         BNN_pred    185.559894      0.925161         -6.110220
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     40.660403      0.707688         -6.429460
# 1            CCV_dw    129.968282      0.606796         -6.629600
# 2            CCV_cw    153.356904      0.875185         -6.465948
# 3         LSTM_pred    206.504274      1.235301         -5.675693
# 4          GRU_pred    135.989179      0.680125         -8.678233
# 5     LSTM_GRU_pred    172.635719      0.838027         -5.090904
# 6       BiLSTM_pred     93.117197      0.381590         -6.865804
# 7   BiLSTM_GRU_pred    126.667479      0.700647         -6.028970
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    110.693722      0.367909         -9.581053
# 10         BNN_pred    197.124794      0.998656         -6.133602
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     46.167224      0.800298         -6.426168
# 1            CCV_dw     87.543719      0.435058         -7.034872
# 2            CCV_cw    135.223277      0.764992         -6.293176
# 3         LSTM_pred     72.700894      0.824093         -6.393860
# 4          GRU_pred    104.409792      0.579629         -6.518201
# 5     LSTM_GRU_pred     86.367877      0.191781        -11.276145
# 6       BiLSTM_pred    103.341280      0.327089         -8.908347
# 7   BiLSTM_GRU_pred     36.850178     -0.093737         -7.412262
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    114.339499      0.488096         -8.692535
# 10         BNN_pred    108.290852      0.446134         -6.633782
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.234684      0.781386         -6.426168
# 1            CCV_dw    105.444678      0.574292         -6.604601
# 2            CCV_cw    166.084408      0.960905         -6.444659
# 3         LSTM_pred     70.880924      0.810577         -6.404726
# 4          GRU_pred    116.132565      0.641243         -6.550471
# 5     LSTM_GRU_pred    133.558064      0.581844         -6.685923
# 6       BiLSTM_pred    137.571916      0.568258         -7.237933
# 7   BiLSTM_GRU_pred     62.562863      0.128877         -6.619637
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    118.081713      0.514145         -8.682882
# 10         BNN_pred    140.934404      0.671696         -6.393816
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     34.903636      0.708918         -6.426168
# 1            CCV_dw     94.787172      0.495308         -6.609304
# 2            CCV_cw    167.601342      0.893065         -6.458877
# 3         LSTM_pred     74.713782      0.838573         -6.381884
# 4          GRU_pred     98.539680      0.518867         -6.647593
# 5     LSTM_GRU_pred    150.446217      0.749628         -6.450943
# 6       BiLSTM_pred    132.923198      0.534421         -6.891686
# 7   BiLSTM_GRU_pred     72.232509      0.243475         -6.591683
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    109.956184      0.454724         -9.389752
# 10         BNN_pred    152.063991      0.745288         -6.418283
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.751749         -6.449168
# 4          GRU_pred     30.433725      0.676651         -6.426168
# 5     LSTM_GRU_pred    -18.229602      0.344531        -11.177548
# 6       BiLSTM_pred     20.835400      0.580415         -7.728274
# 7   BiLSTM_GRU_pred     44.466919      0.693246         -6.500416
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.751749         -6.449168
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.751749         -6.449168
# 4          GRU_pred     44.466919      0.779573         -6.426168
# 5     LSTM_GRU_pred     44.466919      0.667340         -6.613178
# 6       BiLSTM_pred     52.506331      0.813380         -5.996435
# 7   BiLSTM_GRU_pred     44.466919      0.693246         -6.500416
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.779573         -6.426168
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     44.466919      0.779573         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.779573         -6.426168
# 4          GRU_pred     44.466919      0.779573         -6.426168
# 5     LSTM_GRU_pred     44.466919      0.779573         -6.426168
# 6       BiLSTM_pred     44.466919      0.779573         -6.426168
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.779573         -6.426168
# 10         BNN_pred     44.466919      0.779573         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     41.431188      0.774312         -5.691626
# 1            CCV_dw    166.212163      0.857759         -6.349387
# 2            CCV_cw     54.997599      0.765892         -6.626210
# 3         LSTM_pred    155.158936      0.823599         -6.773621
# 4          GRU_pred    218.800873      1.305378         -6.679968
# 5     LSTM_GRU_pred    187.719032      1.134621         -5.313156
# 6       BiLSTM_pred     99.822348      0.504753         -7.260060
# 7   BiLSTM_GRU_pred    174.227450      0.955858         -6.971440
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    149.683144      0.807119         -7.358022
# 10         BNN_pred    232.652514      1.226916         -5.319173
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     47.117901      0.870760         -5.608409
# 1            CCV_dw    129.278089      0.673119         -7.865935
# 2            CCV_cw     63.820784      0.853353         -6.997691
# 3         LSTM_pred    154.518150      0.869741         -7.081895
# 4          GRU_pred    125.601014      0.675002         -9.231261
# 5     LSTM_GRU_pred    150.865756      0.843515         -5.729463
# 6       BiLSTM_pred     50.010882      0.112174         -7.753864
# 7   BiLSTM_GRU_pred    129.497868      0.682952         -5.079752
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    106.412535      0.560985         -5.520436
# 10         BNN_pred     87.507472      0.429224         -7.685186
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.326919      0.319826         -3.372620
# 1            CCV_dw     87.712776      0.497200         -6.095246
# 2            CCV_cw     31.987084      0.915363         -5.626812
# 3         LSTM_pred      9.005071     -0.459502         -6.206996
# 4          GRU_pred     74.595505      0.319619         -5.574050
# 5     LSTM_GRU_pred     77.154618      0.439832         -4.138529
# 6       BiLSTM_pred     96.229755      0.607416         -4.845962
# 7   BiLSTM_GRU_pred     88.667598      0.644531         -6.376499
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     66.126210      0.247224         -6.367203
# 10         BNN_pred     93.661259      0.625347         -4.969913
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.468523      0.458280         -5.106350
# 1            CCV_dw     95.043603      0.424634         -7.901753
# 2            CCV_cw     15.630278      0.554787         -6.777700
# 3         LSTM_pred    105.763672      0.583474         -9.840108
# 4          GRU_pred     60.228153      0.124511         -8.482077
# 5     LSTM_GRU_pred     42.767501      0.040488         -9.452415
# 6       BiLSTM_pred     92.939174      0.541906         -4.158748
# 7   BiLSTM_GRU_pred     68.064155      0.331313         -6.661231
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     72.550486      0.274764         -6.994521
# 10         BNN_pred    113.266849      0.681368         -5.000888
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     92.188015      1.213480         -5.106350
# 1            CCV_dw     88.876599      0.359287         -9.224164
# 2            CCV_cw     50.200466      0.745619         -6.800071
# 3         LSTM_pred    159.267120      0.911027         -6.416804
# 4          GRU_pred    114.467886      0.665905         -8.988797
# 5     LSTM_GRU_pred    133.545401      0.725827         -6.392745
# 6       BiLSTM_pred     87.600776      0.461007         -6.622376
# 7   BiLSTM_GRU_pred    159.218346      0.939864         -6.397413
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    111.923780      0.563414         -8.894971
# 10         BNN_pred    101.199100      0.541954         -5.730014
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.326919      0.319826         -3.372620
# 1            CCV_dw    111.338988      0.581784         -6.436867
# 2            CCV_cw     24.402414      0.822990         -5.626812
# 3         LSTM_pred     58.463661      0.193333         -8.234723
# 4          GRU_pred    142.539175      1.018648         -4.752387
# 5     LSTM_GRU_pred    119.257781      0.889281         -3.929350
# 6       BiLSTM_pred     74.180665      0.339661         -7.644034
# 7   BiLSTM_GRU_pred    105.092636      0.598821         -6.880841
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     78.396685      0.348928         -8.500998
# 10         BNN_pred    155.832278      0.929928         -5.645115
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -26.376780      0.267321         -5.106350
# 1            CCV_dw    134.484925      0.557803         -6.862425
# 2            CCV_cw      9.056170      0.495638         -6.502686
# 3         LSTM_pred    124.087884      0.675979         -6.957396
# 4          GRU_pred    158.777530      1.009183         -6.567517
# 5     LSTM_GRU_pred     60.811471      0.211329        -10.204545
# 6       BiLSTM_pred     30.620316     -0.060220        -10.288527
# 7   BiLSTM_GRU_pred    147.527592      0.898929         -6.762519
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     69.148452      0.232023         -8.532681
# 10         BNN_pred    207.372293      1.118046         -5.326849
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     39.154942      0.770304         -5.106350
# 1            CCV_dw    164.323752      0.852638         -6.427258
# 2            CCV_cw     27.409849      0.572927         -6.429595
# 3         LSTM_pred    139.807450      0.714344         -6.864852
# 4          GRU_pred    169.852406      1.078727         -6.654870
# 5     LSTM_GRU_pred    205.183436      1.281285         -4.508175
# 6       BiLSTM_pred     68.850941      0.268633         -8.784065
# 7   BiLSTM_GRU_pred    175.711501      0.982354         -6.721599
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    123.774129      0.628145         -9.520417
# 10         BNN_pred    206.926763      1.066940         -5.376491
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -15.326919      0.319826         -3.372620
# 1            CCV_dw      8.108061      0.510225         -8.627356
# 2            CCV_cw     -4.756645      0.436513         -5.626812
# 3         LSTM_pred     44.466919      0.743940         -6.455594
# 4          GRU_pred     28.477359      0.636203         -5.996435
# 5     LSTM_GRU_pred     -1.828149      0.288549        -11.340102
# 6       BiLSTM_pred     20.835400      0.580415         -7.728274
# 7   BiLSTM_GRU_pred     21.747922      0.527048         -8.405513
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     -3.471574      0.318495        -11.060838
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -26.376780      0.267321         -5.106350
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw    -12.358662      0.408466         -5.106350
# 3         LSTM_pred     44.466919      0.751749         -6.449168
# 4          GRU_pred     30.433725      0.676651         -6.426168
# 5     LSTM_GRU_pred    -18.229602      0.344531        -11.177548
# 6       BiLSTM_pred     20.835400      0.580415         -7.728274
# 7   BiLSTM_GRU_pred     44.466919      0.693246         -6.500416
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.751749         -6.449168
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     20.621489      0.602553         -6.426168
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.751749         -6.449168
# 4          GRU_pred     44.466919      0.779573         -6.426168
# 5     LSTM_GRU_pred     44.466919      0.779573         -6.426168
# 6       BiLSTM_pred     52.506331      0.841252         -5.975049
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.751749         -6.449168
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     17.412976      0.614178         -7.163752
# 1            CCV_dw    153.397226      0.833216         -6.068881
# 2            CCV_cw     48.924296      0.926627         -5.120121
# 3         LSTM_pred    173.118418      1.003987         -6.351222
# 4          GRU_pred    218.800873      1.305378         -6.679968
# 5     LSTM_GRU_pred    168.032826      1.015117         -6.498560
# 6       BiLSTM_pred     84.627970      0.406437         -6.188875
# 7   BiLSTM_GRU_pred    177.212511      1.113262         -4.889832
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    193.391380      1.128017         -6.085124
# 10         BNN_pred    202.778228      1.245489         -6.063994
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     54.337580      0.931731         -5.570005
# 1            CCV_dw    106.193486      0.513785         -7.268362
# 2            CCV_cw    205.551166      1.151386         -5.113571
# 3         LSTM_pred    173.534191      1.034440         -5.993155
# 4          GRU_pred    125.601014      0.675002         -9.231261
# 5     LSTM_GRU_pred    168.779336      1.018295         -5.216771
# 6       BiLSTM_pred     13.174255     -0.241501         -8.668161
# 7   BiLSTM_GRU_pred    106.465015      0.514138         -7.241049
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    131.085284      0.713893         -5.643565
# 10         BNN_pred    107.914482      0.534321         -7.604652
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      0.000000      0.546862         -2.417327
# 1            CCV_dw     66.748480      0.292976         -6.170176
# 2            CCV_cw    105.717387      0.826913         -6.194329
# 3         LSTM_pred     22.648846     -0.293531         -5.124405
# 4          GRU_pred     96.292620      0.656428         -2.723289
# 5     LSTM_GRU_pred     53.658999      0.164984         -4.860947
# 6       BiLSTM_pred     25.368455     -0.179386         -4.422082
# 7   BiLSTM_GRU_pred     76.152361      0.489040         -8.390874
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     51.313792      0.141720         -5.453341
# 10         BNN_pred    102.603986      0.839619         -3.662596
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -9.856808      0.456122         -4.753962
# 1            CCV_dw     88.982478      0.391297         -7.167973
# 2            CCV_cw    137.748618      0.998776         -6.468886
# 3         LSTM_pred     94.673991      0.531414         -7.570871
# 4          GRU_pred     60.228153      0.124511         -8.482077
# 5     LSTM_GRU_pred     63.139478      0.260948         -7.720127
# 6       BiLSTM_pred     44.141148      0.053091         -5.178778
# 7   BiLSTM_GRU_pred    100.113687      0.757979         -8.662215
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     43.304877     -0.012014         -6.355426
# 10         BNN_pred    152.839685      1.080316         -4.413001
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      8.958577      0.645451         -4.753962
# 1            CCV_dw     98.317538      0.458550         -7.159214
# 2            CCV_cw    219.155972      1.324803         -5.116116
# 3         LSTM_pred    164.602519      1.068489         -6.041563
# 4          GRU_pred     41.557396     -0.075388         -9.646425
# 5     LSTM_GRU_pred     78.555637      0.373072         -6.293682
# 6       BiLSTM_pred     87.814706      0.479723         -4.167142
# 7   BiLSTM_GRU_pred     85.521665      0.502905         -7.078474
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     47.954735      0.038127         -6.978232
# 10         BNN_pred     99.083177      0.551533         -6.715165
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      0.000000      0.546862         -2.417327
# 1            CCV_dw     95.753159      0.456890         -5.398048
# 2            CCV_cw     12.826035      0.706255         -5.626812
# 3         LSTM_pred     29.066287     -0.185468         -5.788373
# 4          GRU_pred    149.387377      1.144153         -5.012870
# 5     LSTM_GRU_pred    100.255185      0.697713         -4.594191
# 6       BiLSTM_pred    105.696708      0.677934         -5.549003
# 7   BiLSTM_GRU_pred    131.582853      1.101585         -4.620500
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred     92.041777      0.587564         -5.487719
# 10         BNN_pred     92.740029      0.593941         -6.212394
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -33.422804      0.193179         -5.106350
# 1            CCV_dw    119.724217      0.615084         -5.628409
# 2            CCV_cw     30.807488      0.729488         -6.129972
# 3         LSTM_pred    105.751241      0.595484         -9.507997
# 4          GRU_pred    158.777530      1.009183         -6.567517
# 5     LSTM_GRU_pred     47.811226      0.091605        -11.504517
# 6       BiLSTM_pred     70.280499      0.299680         -7.981854
# 7   BiLSTM_GRU_pred    171.634547      1.388564         -4.892474
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    105.821251      0.569493         -5.815222
# 10         BNN_pred    210.765034      1.392613         -4.896383
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -26.376780      0.267321         -5.106350
# 1            CCV_dw    140.424531      0.746799         -6.170268
# 2            CCV_cw     66.993506      1.149536         -5.062061
# 3         LSTM_pred    167.409090      1.045761         -5.835227
# 4          GRU_pred    152.964814      0.956252         -6.600627
# 5     LSTM_GRU_pred    128.751956      0.782882         -5.989711
# 6       BiLSTM_pred     98.302745      0.534851         -6.217070
# 7   BiLSTM_GRU_pred    133.613751      0.920060         -4.841600
# 8         QRNN_pred     97.884264      0.557115         -5.310109
# 9          ESN_pred    107.415602      0.572594         -6.780319
# 10         BNN_pred    160.422801      0.962018         -6.717771
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      0.000000      0.546862         -2.417327
# 1            CCV_dw      8.108061      0.510225         -8.627356
# 2            CCV_cw    -23.235468      0.237838         -5.626812
# 3         LSTM_pred     44.466919      0.693246         -6.500416
# 4          GRU_pred     28.477359      0.628313         -6.002409
# 5     LSTM_GRU_pred     -1.828149      0.288549        -11.340102
# 6       BiLSTM_pred     20.835400      0.580415         -7.728274
# 7   BiLSTM_GRU_pred     21.747922      0.527048         -8.405513
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred      5.405956      0.411373         -9.978769
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -33.422804      0.193179         -5.106350
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw    -12.358662      0.408466         -5.106350
# 3         LSTM_pred     44.466919      0.751749         -6.449168
# 4          GRU_pred     30.433725      0.676651         -6.426168
# 5     LSTM_GRU_pred    -18.229602      0.146657        -12.814803
# 6       BiLSTM_pred     20.835400      0.580415         -7.728274
# 7   BiLSTM_GRU_pred     44.466919      0.693246         -6.500416
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     21.747922      0.587567         -7.642435
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    -26.376780      0.267321         -5.106350
# 1            CCV_dw     44.466919      0.779573         -6.426168
# 2            CCV_cw     44.466919      0.779573         -6.426168
# 3         LSTM_pred     44.466919      0.751749         -6.449168
# 4          GRU_pred     30.433725      0.676651         -6.426168
# 5     LSTM_GRU_pred     44.466919      0.779573         -6.426168
# 6       BiLSTM_pred     52.506331      0.813380         -5.996435
# 7   BiLSTM_GRU_pred     44.466919      0.779573         -6.426168
# 8         QRNN_pred     44.466919      0.779573         -6.426168
# 9          ESN_pred     44.466919      0.751749         -6.449168
# 10         BNN_pred     30.433725      0.676651         -6.426168
# 11               __     44.466919      0.779573         -6.426168

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y2', file, 'CCV')
get_final_results_1('2024_y2', file, 'CCV')

get_final_results('2024_y2', dw_file, 'CCV_dw')
get_final_results_1('2024_y2', dw_file, 'CCV_dw')

get_final_results('2024_y2', cw_file, 'CCV_cw')
get_final_results_1('2024_y2', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-41-f5c2e4eea568>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-41-f5c2e4eea568>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-41-f5c2e4eea568>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-41-f5c2e4eea568>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-41-f5c2e4eea568>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-41-f5c2e4eea568>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-41-f5c2e4eea568>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-41-f5c2e4eea568>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-41-f5c2e4eea568>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-41-f5c2e4eea568>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-41-f5c2e4eea568>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-41-f5c2e4eea568>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-41-f5c2e4eea568>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-41-f5c2e4eea568>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-41-f5c2e4eea568>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    148.545359      0.968725         -8.115590
# 1            CCV_dw    137.496191      0.879357         -9.302629
# 2            CCV_cw    116.002345      0.671354         -9.302629
# 3         LSTM_pred     90.058556      0.490147         -9.823698
# 4          GRU_pred    119.683459      0.724077         -9.345933
# 5     LSTM_GRU_pred    111.220141      0.700613         -9.302629
# 6       BiLSTM_pred    111.630322      0.634060         -8.850512
# 7   BiLSTM_GRU_pred    115.370366      0.663679         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    103.735169      0.564501         -9.302629
# 10         BNN_pred    118.199061      0.697000         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    136.865345      1.003520         -4.297561
# 1            CCV_dw    171.057357      1.233138         -8.588117
# 2            CCV_cw     84.096989      0.415869         -6.500563
# 3         LSTM_pred     81.235781      0.329379         -8.135049
# 4          GRU_pred     92.770039      0.529295         -9.419603
# 5     LSTM_GRU_pred     66.092681      0.276852         -9.345933
# 6       BiLSTM_pred     53.039697      0.143320         -8.850512
# 7   BiLSTM_GRU_pred    127.907259      0.781607        -10.058747
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     78.869872      0.320054         -9.848677
# 10         BNN_pred     69.874801      0.271452         -9.599462
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    114.462161      0.882063         -3.178694
# 1            CCV_dw    137.678782      1.041406         -7.100868
# 2            CCV_cw     52.231896      0.199500         -5.657823
# 3         LSTM_pred     58.307181      0.216267         -6.306587
# 4          GRU_pred     76.833989      0.432503         -7.143998
# 5     LSTM_GRU_pred     62.927056      0.270599         -7.196219
# 6       BiLSTM_pred     53.459133      0.151781         -9.458904
# 7   BiLSTM_GRU_pred     83.797105      0.479776         -8.795689
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    109.796606      0.762464         -7.425819
# 10         BNN_pred     80.361469      0.397075         -8.719271
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    121.258355      0.919868         -3.886098
# 1            CCV_dw    167.619923      1.285759         -7.764192
# 2            CCV_cw     43.078610     -0.025401         -6.500563
# 3         LSTM_pred     49.082855      0.104649         -8.135049
# 4          GRU_pred    100.080277      0.631838         -6.850221
# 5     LSTM_GRU_pred     64.413111      0.266894         -8.528839
# 6       BiLSTM_pred     75.963536      0.381710         -8.028952
# 7   BiLSTM_GRU_pred    114.941104      0.784884         -9.610399
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    117.909606      0.729594         -9.036114
# 10         BNN_pred     70.731758      0.280300         -9.599462
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    109.172742      0.678501         -6.749600
# 1            CCV_dw    159.223923      1.128840         -8.588117
# 2            CCV_cw     66.522457      0.232656         -6.500563
# 3         LSTM_pred     78.313141      0.299194         -8.135049
# 4          GRU_pred    102.619525      0.625753         -8.603173
# 5     LSTM_GRU_pred     43.279424      0.042703         -9.470059
# 6       BiLSTM_pred     53.039697      0.143320         -8.850512
# 7   BiLSTM_GRU_pred    131.324521      0.811892        -10.058747
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     79.085491      0.322181         -9.848677
# 10         BNN_pred     69.874801      0.271452         -9.599462
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    192.195875      1.659606         -2.455820
# 1            CCV_dw    132.019691      0.895547         -8.485144
# 2            CCV_cw     67.110934      0.332049         -8.485144
# 3         LSTM_pred     71.437680      0.336496         -8.383588
# 4          GRU_pred    115.855093      0.763703         -7.355253
# 5     LSTM_GRU_pred    107.250062      0.731865         -8.488748
# 6       BiLSTM_pred     98.300297      0.615545         -9.458904
# 7   BiLSTM_GRU_pred     95.417599      0.465356         -9.177845
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     54.901176      0.081278        -10.134016
# 10         BNN_pred    103.538445      0.578008         -8.890511
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    205.979757      1.772826         -3.153872
# 1            CCV_dw    132.019691      0.926887         -8.485144
# 2            CCV_cw     48.274976      0.040492         -9.302629
# 3         LSTM_pred     62.098907      0.230026         -9.823698
# 4          GRU_pred    103.349667      0.701978         -7.236876
# 5     LSTM_GRU_pred     91.166786      0.529579         -8.485144
# 6       BiLSTM_pred    111.630322      0.727451         -8.028952
# 7   BiLSTM_GRU_pred    103.813303      0.561251         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     91.979985      0.439080         -9.252686
# 10         BNN_pred    118.199061      0.697000         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    150.912218      0.989912         -8.115590
# 1            CCV_dw    137.496191      0.879357         -9.302629
# 2            CCV_cw    115.096966      0.663208         -9.302629
# 3         LSTM_pred     80.867214      0.405634         -9.823698
# 4          GRU_pred    119.683459      0.820682         -8.528839
# 5     LSTM_GRU_pred     90.420353      0.512922         -9.302629
# 6       BiLSTM_pred    111.630322      0.634060         -8.850512
# 7   BiLSTM_GRU_pred    115.370366      0.663679         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    103.955758      0.566529         -9.302629
# 10         BNN_pred    118.199061      0.697000         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     84.987072      0.393913         -9.302629
# 1            CCV_dw    113.008916      0.703108         -8.485144
# 2            CCV_cw     87.184197      0.508378         -8.485144
# 3         LSTM_pred    100.119990      0.509424         -9.177845
# 4          GRU_pred     94.406715      0.476962         -9.035617
# 5     LSTM_GRU_pred     95.709527      0.552106         -8.488748
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred    118.393445      0.672626         -9.177845
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     93.005429      0.447341         -9.177845
# 10         BNN_pred    118.393445      0.704983         -8.890511
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     94.406715      0.481149         -9.302629
# 1            CCV_dw    113.008916      0.735696         -8.485144
# 2            CCV_cw     93.005429      0.468110         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     97.459388      0.603346         -8.485144
# 5     LSTM_GRU_pred     97.459388      0.603346         -8.485144
# 6       BiLSTM_pred    118.393445      0.783519         -8.485144
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.672626         -9.177845
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    118.393445      0.690588         -9.302629
# 1            CCV_dw    118.393445      0.690588         -9.302629
# 2            CCV_cw    118.393445      0.690588         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.783519         -8.485144
# 5     LSTM_GRU_pred     97.459388      0.509485         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.690588         -9.302629
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    132.068888      0.816104         -8.046987
# 1            CCV_dw    148.703718      1.056690         -8.588117
# 2            CCV_cw     97.493500      0.512139         -9.302629
# 3         LSTM_pred    118.800902      0.650128         -8.850512
# 4          GRU_pred    130.191977      0.814645         -9.419603
# 5     LSTM_GRU_pred    100.682979      0.602324         -9.345933
# 6       BiLSTM_pred    121.904067      0.724018         -9.302629
# 7   BiLSTM_GRU_pred     92.507887      0.510712         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    130.368368      0.824541         -9.302629
# 10         BNN_pred    106.495084      0.597690        -10.712777
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    153.171900      1.138871         -4.910420
# 1            CCV_dw    144.552573      1.028714         -8.021596
# 2            CCV_cw    119.534759      0.732973         -9.302629
# 3         LSTM_pred    123.688918      0.730504         -7.143639
# 4          GRU_pred     94.960352      0.559072         -9.222801
# 5     LSTM_GRU_pred     91.275882      0.518282         -9.345933
# 6       BiLSTM_pred     69.051581      0.302335         -8.850512
# 7   BiLSTM_GRU_pred    112.283045      0.608790         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     48.633050      0.014579        -11.388617
# 10         BNN_pred     67.162837      0.242988         -9.599462
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    116.517755      1.003398         -3.504390
# 1            CCV_dw    136.212723      0.985399         -6.794612
# 2            CCV_cw     37.826570     -0.072694         -8.890511
# 3         LSTM_pred     97.387829      0.597840         -7.143639
# 4          GRU_pred    144.381652      1.192307         -6.582078
# 5     LSTM_GRU_pred     80.284241      0.459358         -8.021596
# 6       BiLSTM_pred     85.054066      0.485659         -9.458904
# 7   BiLSTM_GRU_pred     16.814789     -0.244627         -9.687645
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     75.316961      0.410373         -4.728613
# 10         BNN_pred     78.197706      0.372632         -8.719271
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    137.030510      1.084901         -3.504390
# 1            CCV_dw    141.912618      1.013254         -7.627198
# 2            CCV_cw     59.873283      0.257452         -8.485144
# 3         LSTM_pred     97.387829      0.597840         -7.143639
# 4          GRU_pred    135.966287      0.996759         -7.242169
# 5     LSTM_GRU_pred     95.357413      0.592467         -8.065511
# 6       BiLSTM_pred     99.287590      0.614850         -8.028952
# 7   BiLSTM_GRU_pred     70.694309      0.319422         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     90.211486      0.468110        -10.589934
# 10         BNN_pred     68.017621      0.251810         -9.599462
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     81.871651      0.379207         -9.766839
# 1            CCV_dw    141.912618      1.013254         -7.627198
# 2            CCV_cw     74.114264      0.300552         -9.302629
# 3         LSTM_pred    112.641674      0.734073         -7.143639
# 4          GRU_pred    137.502314      0.992451         -8.140222
# 5     LSTM_GRU_pred    125.439519      0.855230         -9.345933
# 6       BiLSTM_pred     64.293372      0.256876         -8.850512
# 7   BiLSTM_GRU_pred     99.441856      0.593800         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     45.462512     -0.019176        -11.388617
# 10         BNN_pred     67.162837      0.242988         -9.599462
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    166.702707      1.431744         -5.325611
# 1            CCV_dw    142.969924      1.030027         -7.100868
# 2            CCV_cw     40.018056     -0.043384         -8.890511
# 3         LSTM_pred     83.992740      0.439463         -8.850512
# 4          GRU_pred    174.251300      1.486583         -6.582078
# 5     LSTM_GRU_pred     94.459375      0.603165         -8.021596
# 6       BiLSTM_pred    116.904420      0.781017         -8.485144
# 7   BiLSTM_GRU_pred     59.111088      0.201724         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     72.785755      0.301034         -9.035617
# 10         BNN_pred    104.661282      0.594340        -10.307067
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    177.713214      1.448231         -5.325611
# 1            CCV_dw    148.703718      1.056690         -8.588117
# 2            CCV_cw     51.250209      0.166419         -8.485144
# 3         LSTM_pred     83.992740      0.439463         -8.850512
# 4          GRU_pred    181.164566      1.332927         -7.242169
# 5     LSTM_GRU_pred     92.568164      0.556200         -8.065511
# 6       BiLSTM_pred    105.550222      0.673518         -8.485144
# 7   BiLSTM_GRU_pred     81.785046      0.417172         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    142.964661      0.951087         -9.177845
# 10         BNN_pred    106.495084      0.597690        -10.712777
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    119.651429      0.708967         -9.055603
# 1            CCV_dw    148.703718      1.056690         -8.588117
# 2            CCV_cw     67.847022      0.234687         -9.302629
# 3         LSTM_pred     84.626604      0.441956         -8.850512
# 4          GRU_pred    153.773913      1.051324         -8.140222
# 5     LSTM_GRU_pred    110.357644      0.696739         -9.345933
# 6       BiLSTM_pred    121.904067      0.724018         -9.302629
# 7   BiLSTM_GRU_pred     86.580049      0.458460         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    137.167794      0.888634         -9.302629
# 10         BNN_pred    106.495084      0.597690        -10.712777
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     82.786859      0.430784         -8.488748
# 1            CCV_dw    113.008916      0.703108         -8.485144
# 2            CCV_cw     77.573759      0.334715         -8.890511
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     95.709527      0.587046         -8.485144
# 5     LSTM_GRU_pred     95.709527      0.493258         -9.302629
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     93.005429      0.463759         -9.035617
# 10         BNN_pred    118.393445      0.704983         -8.890511
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.005429      0.468110         -9.302629
# 1            CCV_dw    118.393445      0.690588         -9.302629
# 2            CCV_cw     84.987072      0.487480         -8.485144
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred     97.459388      0.509485         -9.302629
# 6       BiLSTM_pred    118.393445      0.783519         -8.485144
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.672626         -9.177845
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    118.393445      0.690588         -9.302629
# 1            CCV_dw    118.393445      0.690588         -9.302629
# 2            CCV_cw     94.406715      0.481149         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    118.393445      0.690588         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.690588         -9.302629
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    157.861321      1.055028         -6.066139
# 1            CCV_dw    133.287276      0.928812         -8.021596
# 2            CCV_cw     92.386918      0.454940        -10.132498
# 3         LSTM_pred     99.289461      0.591716         -8.850512
# 4          GRU_pred     49.069245      0.104270        -10.125437
# 5     LSTM_GRU_pred    106.125518      0.614781         -9.376334
# 6       BiLSTM_pred     90.908955      0.506784         -8.850512
# 7   BiLSTM_GRU_pred     63.964526      0.196892         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    112.816806      0.680432         -7.521653
# 10         BNN_pred     43.149316     -0.004772        -11.692153
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    110.450899      0.600376         -9.477214
# 1            CCV_dw    118.389155      0.755772         -6.881637
# 2            CCV_cw     77.252121      0.326822        -10.132498
# 3         LSTM_pred    104.989212      0.589936         -8.664998
# 4          GRU_pred     -3.103592     -0.512013        -10.172832
# 5     LSTM_GRU_pred     58.205941      0.202861        -10.618557
# 6       BiLSTM_pred    -12.468841     -0.593662         -9.848431
# 7   BiLSTM_GRU_pred     54.865597      0.164484         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    107.787527      0.647376         -9.231893
# 10         BNN_pred     79.341772      0.322415         -6.605864
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     77.097532      0.465911         -5.470767
# 1            CCV_dw     27.529493     -0.213470         -4.737859
# 2            CCV_cw     -7.962133     -0.808731         -9.035617
# 3         LSTM_pred     32.366478     -0.104109         -8.079796
# 4          GRU_pred     19.322624     -0.344524         -4.916189
# 5     LSTM_GRU_pred     67.888738      0.377605         -5.774263
# 6       BiLSTM_pred    -40.853882     -1.122745        -10.425934
# 7   BiLSTM_GRU_pred    -11.576332     -0.797828         -8.446767
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     92.155130      0.899238         -1.882207
# 10         BNN_pred     57.826770      0.225667         -7.746749
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    124.196201      0.947530         -5.345147
# 1            CCV_dw    106.713626      0.706406         -5.588817
# 2            CCV_cw     17.321193     -0.360616         -9.035617
# 3         LSTM_pred     69.167673      0.344733         -8.209703
# 4          GRU_pred     40.398008     -0.005632         -6.099182
# 5     LSTM_GRU_pred     70.946456      0.375497         -8.684354
# 6       BiLSTM_pred     -2.783958     -0.520362        -10.284630
# 7   BiLSTM_GRU_pred     23.126217     -0.198380         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    196.729839      2.088503         -1.823429
# 10         BNN_pred     38.415329     -0.144292         -7.294682
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    133.786947      1.027919         -5.314525
# 1            CCV_dw    124.940060      0.856462         -6.881637
# 2            CCV_cw     65.009839      0.207701         -9.035617
# 3         LSTM_pred     73.571498      0.386768         -8.209703
# 4          GRU_pred     47.187319      0.084980         -8.054547
# 5     LSTM_GRU_pred    123.308480      0.918602         -7.242169
# 6       BiLSTM_pred      5.475682     -0.401441         -9.681786
# 7   BiLSTM_GRU_pred     35.638093     -0.043993         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    155.032043      1.357203         -4.044394
# 10         BNN_pred     38.655072     -0.137273         -7.445391
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    147.174806      1.156691         -5.339951
# 1            CCV_dw     87.769250      0.530229         -6.794612
# 2            CCV_cw     58.813254      0.145713         -9.035617
# 3         LSTM_pred     28.731060     -0.117553         -8.725106
# 4          GRU_pred     61.895988      0.291330         -5.450334
# 5     LSTM_GRU_pred    100.539525      0.702294         -5.535652
# 6       BiLSTM_pred     54.682897      0.164937         -9.458904
# 7   BiLSTM_GRU_pred     41.261177     -0.061713         -8.021596
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     83.789838      0.563865         -6.207049
# 10         BNN_pred     51.063820      0.075414        -11.290893
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    144.074709      1.098698         -5.549007
# 1            CCV_dw    130.931263      0.923913         -7.627198
# 2            CCV_cw     56.379629      0.113558         -9.035617
# 3         LSTM_pred     90.827526      0.521575         -8.850512
# 4          GRU_pred    113.426925      0.864021         -6.582078
# 5     LSTM_GRU_pred     89.316761      0.502789         -8.684354
# 6       BiLSTM_pred    108.673446      0.706905         -9.458904
# 7   BiLSTM_GRU_pred     31.351237     -0.144128         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    139.789173      1.164323         -5.666234
# 10         BNN_pred     48.117814      0.045754        -10.896206
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    152.241896      1.172739         -5.325611
# 1            CCV_dw    136.716072      0.965815         -7.627198
# 2            CCV_cw     73.135017      0.278608         -9.035617
# 3         LSTM_pred     90.827526      0.521575         -8.850512
# 4          GRU_pred    114.392642      0.817118         -8.684354
# 5     LSTM_GRU_pred    133.102371      0.928869         -7.638211
# 6       BiLSTM_pred    110.352018      0.706205         -8.850512
# 7   BiLSTM_GRU_pred     63.483545      0.194651         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    114.885641      0.810478         -6.397942
# 10         BNN_pred     43.357797     -0.002637        -11.692153
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     77.382144      0.387117         -8.485144
# 1            CCV_dw     80.055020      0.406516         -8.485144
# 2            CCV_cw     32.003587     -0.140045        -10.988946
# 3         LSTM_pred     79.527975      0.321357         -9.177845
# 4          GRU_pred     94.406715      0.476962         -9.035617
# 5     LSTM_GRU_pred     82.786859      0.373473         -9.302629
# 6       BiLSTM_pred    102.414851      0.643492         -8.485144
# 7   BiLSTM_GRU_pred     97.459388      0.509485         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     13.761521     -0.281699        -12.267414
# 10         BNN_pred    118.393445      0.704983         -8.890511
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     74.470652      0.352698         -8.485144
# 1            CCV_dw    113.008916      0.642901         -9.302629
# 2            CCV_cw     73.426683      0.281687         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     94.406715      0.574879         -8.485144
# 5     LSTM_GRU_pred     95.709527      0.493258         -9.302629
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    113.008916      0.702707         -8.488748
# 10         BNN_pred    118.393445      0.783519         -8.485144
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     82.140958      0.424998         -8.485144
# 1            CCV_dw    113.008916      0.642901         -9.302629
# 2            CCV_cw     69.424703      0.240552         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred     97.459388      0.509485         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.751011         -8.488748
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    100.958875      0.501160         -9.942738
# 1            CCV_dw    151.607470      1.060487         -9.063396
# 2            CCV_cw     65.712852      0.202529        -10.132498
# 3         LSTM_pred    102.605289      0.530523         -7.143639
# 4          GRU_pred     49.069245      0.104270        -10.125437
# 5     LSTM_GRU_pred     98.357977      0.552496         -8.706012
# 6       BiLSTM_pred     29.346637     -0.100351         -8.894031
# 7   BiLSTM_GRU_pred    103.851387      0.590665         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     99.479977      0.541784         -8.687525
# 10         BNN_pred     56.041386      0.064957         -7.906615
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     74.723891      0.255973         -9.477214
# 1            CCV_dw     94.195706      0.525292         -7.730025
# 2            CCV_cw      4.820200     -0.466193        -12.035094
# 3         LSTM_pred     64.229051      0.159626         -7.783947
# 4          GRU_pred     -3.103592     -0.512013        -10.172832
# 5     LSTM_GRU_pred     10.532543     -0.337608        -11.808376
# 6       BiLSTM_pred      9.603083     -0.465424        -10.335645
# 7   BiLSTM_GRU_pred    140.692810      1.067562         -7.563093
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     92.730880      0.538053         -7.664771
# 10         BNN_pred     51.410188      0.013770         -8.966721
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.452727      0.404019         -4.236136
# 1            CCV_dw     78.177228      0.846547         -0.868096
# 2            CCV_cw    -65.502299     -1.902923         -9.035617
# 3         LSTM_pred      0.613170     -0.602103         -6.452571
# 4          GRU_pred     19.322624     -0.344524         -4.916189
# 5     LSTM_GRU_pred     24.010633     -0.263099         -5.774263
# 6       BiLSTM_pred     26.617514     -0.227220         -6.566848
# 7   BiLSTM_GRU_pred      0.352704     -0.630556         -7.563093
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     83.142350      0.808347         -1.906775
# 10         BNN_pred      3.051565     -0.586242         -8.292983
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     96.725184      0.677382         -5.949009
# 1            CCV_dw     52.695880      0.012619         -4.737859
# 2            CCV_cw    -40.820784     -1.254476         -9.184157
# 3         LSTM_pred     61.469570      0.269965         -6.584778
# 4          GRU_pred     40.398008     -0.005632         -6.099182
# 5     LSTM_GRU_pred     24.873788     -0.220049         -7.506307
# 6       BiLSTM_pred      0.663988     -0.539605         -9.215320
# 7   BiLSTM_GRU_pred     83.311855      0.531861         -7.563093
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    105.136409      1.069507         -2.785495
# 10         BNN_pred     32.069721     -0.231415         -8.162735
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    111.717982      0.819706         -6.159574
# 1            CCV_dw     91.906278      0.523660         -7.616544
# 2            CCV_cw    -38.245338     -1.059747        -12.386778
# 3         LSTM_pred     35.426943     -0.061901         -7.164415
# 4          GRU_pred     47.187319      0.084980         -8.054547
# 5     LSTM_GRU_pred     56.846380      0.204949         -6.625866
# 6       BiLSTM_pred     18.080443     -0.259414         -9.540841
# 7   BiLSTM_GRU_pred    112.138152      0.824801         -7.563093
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    113.884197      1.027542         -4.515972
# 10         BNN_pred     12.576368     -0.443508        -10.368269
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     84.002444      0.528289         -5.339951
# 1            CCV_dw    114.059837      1.125619         -4.264433
# 2            CCV_cw     -7.975494     -0.735944         -9.441268
# 3         LSTM_pred     -3.286506     -0.520462         -7.012223
# 4          GRU_pred     61.895988      0.291330         -5.450334
# 5     LSTM_GRU_pred     40.986716     -0.080453         -5.774263
# 6       BiLSTM_pred     10.394833     -0.362483         -7.786359
# 7   BiLSTM_GRU_pred     24.316349     -0.291172         -8.021596
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    106.664697      0.866387         -4.420971
# 10         BNN_pred      2.229128     -0.697929         -8.686128
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    108.548140      0.786493         -6.943868
# 1            CCV_dw     98.133893      0.584938         -5.227756
# 2            CCV_cw     20.193791     -0.292314         -9.035617
# 3         LSTM_pred     71.925312      0.343555         -7.143639
# 4          GRU_pred    113.426925      0.864021         -6.582078
# 5     LSTM_GRU_pred     60.083130      0.180518         -7.506307
# 6       BiLSTM_pred     13.782459     -0.290271         -9.502133
# 7   BiLSTM_GRU_pred     52.960145      0.088125         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    138.433163      1.218307         -4.420971
# 10         BNN_pred     50.392924     -0.001498         -7.431299
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    130.128657      0.975219         -5.325611
# 1            CCV_dw    115.082927      0.722702         -7.800867
# 2            CCV_cw     33.776819     -0.130020         -9.035617
# 3         LSTM_pred     71.925312      0.343555         -7.143639
# 4          GRU_pred    114.392642      0.817118         -8.684354
# 5     LSTM_GRU_pred    135.483864      0.990499         -7.242169
# 6       BiLSTM_pred     46.329215      0.074794         -8.894031
# 7   BiLSTM_GRU_pred     83.144587      0.407948         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    152.470731      1.299284         -3.664207
# 10         BNN_pred     54.670851      0.049766         -8.018665
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     59.628779      0.210857         -8.485144
# 1            CCV_dw     80.055020      0.406516         -8.485144
# 2            CCV_cw      3.390409     -0.455843        -13.456853
# 3         LSTM_pred     79.527975      0.321357         -9.177845
# 4          GRU_pred     94.406715      0.476962         -9.035617
# 5     LSTM_GRU_pred     82.786859      0.373473         -9.302629
# 6       BiLSTM_pred    100.831256      0.632418         -8.485144
# 7   BiLSTM_GRU_pred     97.459388      0.509485         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     15.814412     -0.259030        -12.267414
# 10         BNN_pred     80.136739      0.359324         -8.890511
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     59.381575      0.205972         -8.485144
# 1            CCV_dw     77.806704      0.384680         -8.485144
# 2            CCV_cw     79.234832      0.339256         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     94.406715      0.574879         -8.485144
# 5     LSTM_GRU_pred     95.709527      0.493258         -9.302629
# 6       BiLSTM_pred    113.008916      0.735696         -8.485144
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred     44.974884      0.060294        -12.267414
# 10         BNN_pred    118.393445      0.783519         -8.485144
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     84.224055      0.445104         -8.485144
# 1            CCV_dw    113.008916      0.642901         -9.302629
# 2            CCV_cw     65.324001      0.200608         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred     95.709527      0.493258         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.751011         -8.488748
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    148.545359      0.968725         -8.115590
# 1            CCV_dw    146.089996      0.968971         -9.302629
# 2            CCV_cw    114.431995      0.662690         -9.564104
# 3         LSTM_pred    105.820878      0.579166         -9.302629
# 4          GRU_pred    119.683459      0.724077         -9.345933
# 5     LSTM_GRU_pred    118.393445      0.690588         -9.302629
# 6       BiLSTM_pred    106.570354      0.587107         -9.302629
# 7   BiLSTM_GRU_pred     94.526661      0.480367         -9.161092
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     85.509568      0.399632         -9.302629
# 10         BNN_pred    122.823436      0.739794         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    136.865345      1.003520         -4.297561
# 1            CCV_dw    164.570100      1.230371         -8.588117
# 2            CCV_cw     99.993913      0.508740         -8.525080
# 3         LSTM_pred     43.847254      0.049023         -8.680115
# 4          GRU_pred     92.770039      0.529295         -9.419603
# 5     LSTM_GRU_pred    106.563220      0.612150         -9.152164
# 6       BiLSTM_pred     96.547835      0.519039         -7.568079
# 7   BiLSTM_GRU_pred    119.706131      0.737270         -7.972201
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     81.304651      0.322435        -10.791571
# 10         BNN_pred     53.498384      0.100771         -9.113290
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    114.462161      0.882063         -3.178694
# 1            CCV_dw    156.843127      1.184309         -8.588117
# 2            CCV_cw    112.335089      0.766239         -4.779978
# 3         LSTM_pred     25.904854     -0.157711         -8.610086
# 4          GRU_pred     76.833989      0.432503         -7.143998
# 5     LSTM_GRU_pred     89.305513      0.466511         -8.540049
# 6       BiLSTM_pred    131.567428      0.959156         -4.842541
# 7   BiLSTM_GRU_pred    121.083259      0.795039         -7.156602
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    137.972389      1.057777         -8.865148
# 10         BNN_pred     33.383099     -0.131085        -10.526383
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    121.258355      0.919868         -3.886098
# 1            CCV_dw    154.742461      1.145832         -8.588117
# 2            CCV_cw     86.500029      0.413564         -6.922808
# 3         LSTM_pred     34.359691     -0.054436         -8.680115
# 4          GRU_pred    100.080277      0.631838         -6.850221
# 5     LSTM_GRU_pred    118.735485      0.733312         -8.540049
# 6       BiLSTM_pred    107.673250      0.632062         -7.568079
# 7   BiLSTM_GRU_pred    127.047381      0.848251         -6.922808
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    138.350364      0.952012         -7.854420
# 10         BNN_pred     36.563515     -0.075088        -10.526383
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    109.172742      0.678501         -6.749600
# 1            CCV_dw    179.575010      1.370008         -8.588117
# 2            CCV_cw    108.719310      0.617592         -6.922808
# 3         LSTM_pred     39.912151      0.007716         -8.680115
# 4          GRU_pred    102.619525      0.625753         -8.603173
# 5     LSTM_GRU_pred    101.235648      0.561720         -9.152164
# 6       BiLSTM_pred     96.547835      0.519039         -7.568079
# 7   BiLSTM_GRU_pred    100.393437      0.560108         -7.972201
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     81.520757      0.324602        -10.791571
# 10         BNN_pred     52.854090      0.094224         -9.113290
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    192.195875      1.659606         -2.455820
# 1            CCV_dw    132.904744      0.862997         -9.302629
# 2            CCV_cw     90.866512      0.630198         -6.106159
# 3         LSTM_pred    106.485488      0.585214         -9.302629
# 4          GRU_pred    115.855093      0.763703         -7.355253
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred     85.857601      0.403051         -9.302629
# 7   BiLSTM_GRU_pred     86.765740      0.425398         -7.553010
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     60.915784      0.141237        -10.134016
# 10         BNN_pred    115.405782      0.674055         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    205.979757      1.772826         -3.153872
# 1            CCV_dw    136.203207      0.881730         -9.302629
# 2            CCV_cw     57.091833      0.132736         -8.219144
# 3         LSTM_pred    105.820878      0.579166         -9.302629
# 4          GRU_pred    103.349667      0.701978         -7.236876
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    106.570354      0.587107         -9.302629
# 7   BiLSTM_GRU_pred     85.159608      0.409528         -7.553010
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     61.022424      0.141853         -9.252686
# 10         BNN_pred    122.823436      0.739794         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    150.912218      0.989912         -8.115590
# 1            CCV_dw    146.089996      0.968971         -9.302629
# 2            CCV_cw    121.535955      0.729060         -8.913724
# 3         LSTM_pred    105.820878      0.579166         -9.302629
# 4          GRU_pred    119.683459      0.820682         -8.528839
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    106.570354      0.587107         -9.302629
# 7   BiLSTM_GRU_pred     81.213140      0.358373         -9.161092
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     85.726515      0.401682         -9.302629
# 10         BNN_pred    122.823436      0.739794         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     84.987072      0.393913         -9.302629
# 1            CCV_dw    113.008916      0.642901         -9.302629
# 2            CCV_cw     87.184197      0.508378         -8.485144
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     94.406715      0.476962         -9.035617
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred     97.459388      0.509485         -9.302629
# 7   BiLSTM_GRU_pred    113.008916      0.642901         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.672626         -9.177845
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     94.406715      0.481149         -9.302629
# 1            CCV_dw    113.008916      0.642901         -9.302629
# 2            CCV_cw     93.005429      0.468110         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     97.459388      0.603346         -8.485144
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    113.008916      0.642901         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.672626         -9.177845
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    118.393445      0.690588         -9.302629
# 1            CCV_dw    118.393445      0.690588         -9.302629
# 2            CCV_cw    118.393445      0.690588         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.783519         -8.485144
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.690588         -9.302629
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    132.068888      0.816104         -8.046987
# 1            CCV_dw    146.320079      0.969906         -8.588117
# 2            CCV_cw     97.734312      0.536686         -8.436466
# 3         LSTM_pred     90.254085      0.438999         -9.302629
# 4          GRU_pred    130.191977      0.814645         -9.419603
# 5     LSTM_GRU_pred    131.663142      0.835389         -8.171731
# 6       BiLSTM_pred    109.008568      0.607269         -9.302629
# 7   BiLSTM_GRU_pred    110.476425      0.622998         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    102.657860      0.570278         -9.302629
# 10         BNN_pred    138.472037      0.884506         -8.132438
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    153.171900      1.138871         -4.910420
# 1            CCV_dw    179.839888      1.368806         -8.588117
# 2            CCV_cw    138.755913      0.902945         -6.702461
# 3         LSTM_pred     61.721287      0.230288         -8.176300
# 4          GRU_pred     94.960352      0.559072         -9.222801
# 5     LSTM_GRU_pred    133.259545      0.913856         -6.345449
# 6       BiLSTM_pred     83.342413      0.365421         -8.739466
# 7   BiLSTM_GRU_pred    128.973828      0.869024         -5.129032
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     45.861469     -0.042013        -11.388617
# 10         BNN_pred     44.478224      0.001220        -11.042537
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    116.517755      1.003398         -3.504390
# 1            CCV_dw    168.014627      1.285441         -7.930717
# 2            CCV_cw    134.760472      1.091492         -5.531077
# 3         LSTM_pred     45.010222      0.060855         -7.166729
# 4          GRU_pred    144.381652      1.192307         -6.582078
# 5     LSTM_GRU_pred    113.995308      0.783265         -5.584703
# 6       BiLSTM_pred    121.046964      0.848622         -4.728613
# 7   BiLSTM_GRU_pred    139.483967      1.044259         -4.237156
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    138.682659      1.144621         -4.728613
# 10         BNN_pred     63.174013      0.194785         -9.357885
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    137.030510      1.084901         -3.504390
# 1            CCV_dw    182.359597      1.401528         -8.588117
# 2            CCV_cw     97.259861      0.519246         -6.106159
# 3         LSTM_pred     39.423944      0.003661         -8.176300
# 4          GRU_pred    135.966287      0.996759         -7.242169
# 5     LSTM_GRU_pred    155.035718      1.143589         -5.714423
# 6       BiLSTM_pred     84.336487      0.378509         -8.739466
# 7   BiLSTM_GRU_pred    133.485445      0.954562         -4.192685
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     78.613632      0.312085        -10.589934
# 10         BNN_pred     49.764885      0.055130        -10.599093
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     81.871651      0.379207         -9.766839
# 1            CCV_dw    179.839888      1.368806         -8.588117
# 2            CCV_cw     72.853355      0.244803         -8.674393
# 3         LSTM_pred     39.679196      0.006726         -8.176300
# 4          GRU_pred    137.502314      0.992451         -8.140222
# 5     LSTM_GRU_pred    130.011664      0.882905         -6.345449
# 6       BiLSTM_pred     83.342413      0.365421         -8.739466
# 7   BiLSTM_GRU_pred    115.679792      0.747621         -5.129032
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     42.699311     -0.075730        -11.388617
# 10         BNN_pred     66.262932      0.220127         -9.187149
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    166.702707      1.431744         -5.325611
# 1            CCV_dw    158.734145      1.091157         -7.930717
# 2            CCV_cw    117.355115      0.935162         -5.549007
# 3         LSTM_pred     89.429170      0.436895         -9.302629
# 4          GRU_pred    174.251300      1.486583         -6.582078
# 5     LSTM_GRU_pred    134.252868      0.845276         -7.570059
# 6       BiLSTM_pred     88.250177      0.424279         -9.302629
# 7   BiLSTM_GRU_pred     88.172185      0.516037         -8.485144
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     79.273889      0.363080         -9.035617
# 10         BNN_pred    133.247381      0.857795         -8.305157
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    177.713214      1.448231         -5.325611
# 1            CCV_dw    156.026189      1.062268         -8.588117
# 2            CCV_cw     75.436361      0.442110         -6.106159
# 3         LSTM_pred     88.774804      0.430719         -9.302629
# 4          GRU_pred    181.164566      1.332927         -7.242169
# 5     LSTM_GRU_pred    134.252868      0.861567         -7.697052
# 6       BiLSTM_pred    109.008568      0.607269         -9.302629
# 7   BiLSTM_GRU_pred     88.172185      0.422670         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    104.012372      0.589681         -9.177845
# 10         BNN_pred    120.771250      0.732999         -9.560780
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    119.651429      0.708967         -9.055603
# 1            CCV_dw    146.320079      0.969906         -8.588117
# 2            CCV_cw     87.649529      0.447222         -7.232052
# 3         LSTM_pred     76.534842      0.314033         -9.302629
# 4          GRU_pred    153.773913      1.051324         -8.140222
# 5     LSTM_GRU_pred    128.419836      0.806621         -8.171731
# 6       BiLSTM_pred    109.008568      0.607269         -9.302629
# 7   BiLSTM_GRU_pred     97.931165      0.512431         -9.302629
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    109.290602      0.634247         -9.302629
# 10         BNN_pred    138.472037      0.884506         -8.132438
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     82.786859      0.430784         -8.488748
# 1            CCV_dw    113.008916      0.642901         -9.302629
# 2            CCV_cw     77.573759      0.334715         -8.890511
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     95.709527      0.587046         -8.485144
# 5     LSTM_GRU_pred    113.008916      0.624390         -9.177845
# 6       BiLSTM_pred     97.459388      0.509485         -9.302629
# 7   BiLSTM_GRU_pred    113.008916      0.735696         -8.485144
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.688894         -9.035617
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     93.005429      0.468110         -9.302629
# 1            CCV_dw    118.393445      0.690588         -9.302629
# 2            CCV_cw     84.987072      0.487480         -8.485144
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    113.008916      0.642901         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.672626         -9.177845
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    118.393445      0.690588         -9.302629
# 1            CCV_dw    118.393445      0.690588         -9.302629
# 2            CCV_cw     93.005429      0.468110         -9.302629
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.690588         -9.302629
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    157.861321      1.055028         -6.066139
# 1            CCV_dw    133.258171      0.899580         -8.588117
# 2            CCV_cw    153.738561      1.074425         -6.219346
# 3         LSTM_pred    101.100023      0.614067         -8.850512
# 4          GRU_pred     49.069245      0.104270        -10.125437
# 5     LSTM_GRU_pred     84.027554      0.359280         -9.523858
# 6       BiLSTM_pred     82.000111      0.350943         -9.989142
# 7   BiLSTM_GRU_pred    139.162040      0.949732         -5.870582
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    106.123083      0.680432         -7.521653
# 10         BNN_pred     64.295107      0.209360         -9.113290
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    110.450899      0.600376         -9.477214
# 1            CCV_dw    119.002637      0.838655         -7.627198
# 2            CCV_cw    163.713416      1.317506         -5.030146
# 3         LSTM_pred     78.645424      0.322868         -5.711906
# 4          GRU_pred     -3.103592     -0.512013        -10.172832
# 5     LSTM_GRU_pred     69.043265      0.318147         -7.304448
# 6       BiLSTM_pred     77.967584      0.408989         -7.196945
# 7   BiLSTM_GRU_pred     80.519367      0.447706         -6.604071
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    145.915031      1.071573         -5.302177
# 10         BNN_pred     51.740192      0.082825         -6.702461
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     77.097532      0.465911         -5.470767
# 1            CCV_dw     59.085738      0.230351         -7.627198
# 2            CCV_cw      4.795201     -0.769181         -5.625380
# 3         LSTM_pred     43.322293      0.026087         -2.817267
# 4          GRU_pred     19.322624     -0.344524         -4.916189
# 5     LSTM_GRU_pred     45.928986      0.069035         -4.878877
# 6       BiLSTM_pred     72.348007      0.499679         -4.278046
# 7   BiLSTM_GRU_pred     71.351711      0.431230         -3.898195
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    111.637431      1.241990         -1.882207
# 10         BNN_pred     62.151167      0.228778         -4.452117
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    124.196201      0.947530         -5.345147
# 1            CCV_dw    111.933251      0.796843         -7.627198
# 2            CCV_cw    104.039973      0.895334         -5.127657
# 3         LSTM_pred     69.952525      0.375599         -5.639601
# 4          GRU_pred     40.398008     -0.005632         -6.099182
# 5     LSTM_GRU_pred    105.155534      0.800731         -4.878877
# 6       BiLSTM_pred     71.204405      0.366422         -6.468503
# 7   BiLSTM_GRU_pred     88.574442      0.610986         -3.909208
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    190.226820      1.995867         -1.841424
# 10         BNN_pred     64.577277      0.225042         -6.509140
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    133.786947      1.027919         -5.314525
# 1            CCV_dw    127.658354      0.930585         -7.627198
# 2            CCV_cw    170.773115      1.632595         -5.502319
# 3         LSTM_pred     59.647324      0.233864         -5.711906
# 4          GRU_pred     47.187319      0.084980         -8.054547
# 5     LSTM_GRU_pred     75.271343      0.390263         -6.825286
# 6       BiLSTM_pred     94.069098      0.582935         -7.196945
# 7   BiLSTM_GRU_pred     57.416934      0.131073         -5.439525
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    154.998798      1.346020         -3.873437
# 10         BNN_pred     45.004960     -0.018444         -7.714362
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    147.174806      1.156691         -5.339951
# 1            CCV_dw    141.888975      1.004098         -8.913724
# 2            CCV_cw     87.322939      0.577428         -5.850477
# 3         LSTM_pred     71.533189      0.433063         -4.728613
# 4          GRU_pred     61.895988      0.291330         -5.450334
# 5     LSTM_GRU_pred     12.240803     -0.314138        -10.085953
# 6       BiLSTM_pred     25.481832     -0.216025         -9.704374
# 7   BiLSTM_GRU_pred    111.392597      0.803367         -5.407386
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    103.122915      0.812007         -5.464427
# 10         BNN_pred    110.123451      0.817662         -5.621095
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    144.074709      1.098698         -5.549007
# 1            CCV_dw    145.530784      1.019422         -7.930717
# 2            CCV_cw    132.382339      1.064318         -5.943960
# 3         LSTM_pred     75.176313      0.373875        -10.267690
# 4          GRU_pred    113.426925      0.864021         -6.582078
# 5     LSTM_GRU_pred     63.296954      0.169067        -10.169230
# 6       BiLSTM_pred     53.962274      0.071410         -9.989142
# 7   BiLSTM_GRU_pred    143.006651      1.103615         -5.407386
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    148.768411      1.272086         -5.666234
# 10         BNN_pred     77.734808      0.344848         -7.585413
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    152.241896      1.172739         -5.325611
# 1            CCV_dw    132.838823      0.895746         -8.588117
# 2            CCV_cw    160.737747      1.323954         -6.696361
# 3         LSTM_pred     91.092087      0.528642         -8.850512
# 4          GRU_pred    114.392642      0.817118         -8.684354
# 5     LSTM_GRU_pred     69.789891      0.227818        -10.516274
# 6       BiLSTM_pred     80.793855      0.339090         -9.989142
# 7   BiLSTM_GRU_pred    147.414597      1.064154         -5.338495
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    130.115010      0.961073         -5.464427
# 10         BNN_pred     47.747612      0.024479        -10.526383
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     77.382144      0.387117         -8.485144
# 1            CCV_dw    113.008916      0.642901         -9.302629
# 2            CCV_cw     30.539158     -0.155090        -11.115254
# 3         LSTM_pred     94.406715      0.476962         -9.035617
# 4          GRU_pred     94.406715      0.476962         -9.035617
# 5     LSTM_GRU_pred     77.212642      0.381330         -9.557279
# 6       BiLSTM_pred     78.798464      0.336904         -9.302629
# 7   BiLSTM_GRU_pred     89.137671      0.490773         -8.485144
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    103.122915      0.812007         -5.464427
# 10         BNN_pred     77.810769      0.321361         -9.035617
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     74.470652      0.352698         -8.485144
# 1            CCV_dw    113.008916      0.642901         -9.302629
# 2            CCV_cw     73.245400      0.278746         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     94.406715      0.574879         -8.485144
# 5     LSTM_GRU_pred    113.008916      0.624390         -9.177845
# 6       BiLSTM_pred     97.459388      0.509485         -9.302629
# 7   BiLSTM_GRU_pred    113.008916      0.735696         -8.485144
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    113.008916      0.703108         -8.485144
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     82.140958      0.424998         -8.485144
# 1            CCV_dw    118.393445      0.690588         -9.302629
# 2            CCV_cw    100.119990      0.525700         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.642901         -9.302629
# 6       BiLSTM_pred    118.393445      0.690588         -9.302629
# 7   BiLSTM_GRU_pred    118.393445      0.690588         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.751011         -8.488748
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    100.958875      0.501160         -9.942738
# 1            CCV_dw    169.528063      1.275185         -8.588117
# 2            CCV_cw    106.056557      0.557660         -8.683929
# 3         LSTM_pred     55.288738      0.169518         -8.680115
# 4          GRU_pred     49.069245      0.104270        -10.125437
# 5     LSTM_GRU_pred    112.186571      0.781048         -6.197208
# 6       BiLSTM_pred     70.044873      0.234965         -7.608018
# 7   BiLSTM_GRU_pred    127.075237      0.856117         -7.334092
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    118.277411      0.678142         -8.683929
# 10         BNN_pred     49.434340      0.058668         -8.862215
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     74.723891      0.255973         -9.477214
# 1            CCV_dw    143.366531      1.043781        -10.060863
# 2            CCV_cw    115.086336      0.698046         -7.661134
# 3         LSTM_pred     89.893358      0.464658         -4.149330
# 4          GRU_pred     -3.103592     -0.512013        -10.172832
# 5     LSTM_GRU_pred    107.513255      0.727627         -7.304448
# 6       BiLSTM_pred    136.526277      1.097527         -5.478137
# 7   BiLSTM_GRU_pred      2.041053     -0.527446         -9.012328
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    101.701942      0.631412         -6.807509
# 10         BNN_pred     37.928956     -0.167082         -5.546025
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.452727      0.404019         -4.236136
# 1            CCV_dw     99.154427      0.819215         -4.234618
# 2            CCV_cw     50.790181      0.196458         -2.159080
# 3         LSTM_pred     24.118398     -0.327002         -2.817267
# 4          GRU_pred     19.322624     -0.344524         -4.916189
# 5     LSTM_GRU_pred     55.005418      0.198055         -3.988153
# 6       BiLSTM_pred     92.277590      0.941466         -3.557238
# 7   BiLSTM_GRU_pred     30.006879     -0.199925         -4.676849
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred     97.520604      1.088670         -1.909203
# 10         BNN_pred     34.249017     -0.318086         -4.292877
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     96.725184      0.677382         -5.949009
# 1            CCV_dw     83.449528      0.418110         -8.812182
# 2            CCV_cw     79.774933      0.652030         -5.074980
# 3         LSTM_pred     41.541371      0.010214         -5.639601
# 4          GRU_pred     40.398008     -0.005632         -6.099182
# 5     LSTM_GRU_pred     85.641102      0.591577         -3.982057
# 6       BiLSTM_pred    111.950603      0.958757         -3.928638
# 7   BiLSTM_GRU_pred     41.364608      0.002072         -4.676849
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    154.623802      1.799823         -1.846057
# 10         BNN_pred     32.703429     -0.305476         -4.435989
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    111.717982      0.819706         -6.159574
# 1            CCV_dw    131.131286      0.934530        -10.060863
# 2            CCV_cw    136.403134      1.304210         -6.565980
# 3         LSTM_pred     56.740420      0.199647         -5.711906
# 4          GRU_pred     47.187319      0.084980         -8.054547
# 5     LSTM_GRU_pred    132.105704      1.126532         -3.882461
# 6       BiLSTM_pred    114.259422      0.896649         -6.264087
# 7   BiLSTM_GRU_pred      8.690420     -0.524279         -6.063866
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    135.499652      1.292688         -4.199621
# 10         BNN_pred     22.863820     -0.379710         -5.392400
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     84.002444      0.528289         -5.339951
# 1            CCV_dw     98.307754      0.672594         -8.913724
# 2            CCV_cw     49.030463      0.111770         -5.592060
# 3         LSTM_pred     17.361629     -0.433919         -3.148385
# 4          GRU_pred     61.895988      0.291330         -5.450334
# 5     LSTM_GRU_pred     74.358998      0.424742         -5.464427
# 6       BiLSTM_pred     89.026420      0.682730         -4.246765
# 7   BiLSTM_GRU_pred     94.260960      0.684018         -4.314153
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    119.049126      1.025034         -3.862322
# 10         BNN_pred     65.289233      0.251349         -5.678806
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    108.548140      0.786493         -6.943868
# 1            CCV_dw    139.649684      1.044879         -7.930717
# 2            CCV_cw     91.253357      0.644895         -6.656980
# 3         LSTM_pred     39.418410     -0.006711         -8.610086
# 4          GRU_pred    113.426925      0.864021         -6.582078
# 5     LSTM_GRU_pred     86.556207      0.561855         -5.516782
# 6       BiLSTM_pred     92.063248      0.524729         -5.183292
# 7   BiLSTM_GRU_pred    162.243387      1.430731         -4.218191
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    157.348224      1.398606         -4.980673
# 10         BNN_pred     43.998904     -0.034962         -6.467412
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    130.128657      0.975219         -5.325611
# 1            CCV_dw    166.383007      1.256074         -8.588117
# 2            CCV_cw    128.930266      1.049611         -6.695987
# 3         LSTM_pred     45.697183      0.067601         -8.680115
# 4          GRU_pred    114.392642      0.817118         -8.684354
# 5     LSTM_GRU_pred    132.989697      1.028514         -5.516782
# 6       BiLSTM_pred     56.815403      0.101309         -7.608018
# 7   BiLSTM_GRU_pred    133.593006      0.964132         -6.178648
# 8         QRNN_pred     86.112981      0.434203         -7.661134
# 9          ESN_pred    164.673128      1.418201         -3.862322
# 10         BNN_pred     26.667897     -0.205136        -10.352122
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     59.628779      0.210857         -8.485144
# 1            CCV_dw    100.119990      0.529315         -9.302629
# 2            CCV_cw     20.639390     -0.264310        -10.750791
# 3         LSTM_pred     81.949925      0.423288         -8.485144
# 4          GRU_pred     94.406715      0.476962         -9.035617
# 5     LSTM_GRU_pred     77.212642      0.381330         -9.557279
# 6       BiLSTM_pred     78.798464      0.336904         -9.302629
# 7   BiLSTM_GRU_pred     89.137671      0.490773         -8.485144
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    100.400521      0.777606         -5.464427
# 10         BNN_pred     77.810769      0.321361         -9.035617
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     59.381575      0.205972         -8.485144
# 1            CCV_dw    113.008916      0.642901         -9.302629
# 2            CCV_cw     65.518699      0.203206         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred     94.406715      0.574879         -8.485144
# 5     LSTM_GRU_pred    113.008916      0.624390         -9.177845
# 6       BiLSTM_pred     97.459388      0.509485         -9.302629
# 7   BiLSTM_GRU_pred    113.008916      0.702707         -8.488748
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    102.414851      0.609823         -8.485144
# 10         BNN_pred     79.532046      0.343872         -9.302629
# 11               __    118.393445      0.690588         -9.302629
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     84.224055      0.445104         -8.485144
# 1            CCV_dw    113.008916      0.642901         -9.302629
# 2            CCV_cw     69.424703      0.240552         -9.035617
# 3         LSTM_pred    118.393445      0.690588         -9.302629
# 4          GRU_pred    118.393445      0.690588         -9.302629
# 5     LSTM_GRU_pred    113.008916      0.624390         -9.177845
# 6       BiLSTM_pred     97.459388      0.509485         -9.302629
# 7   BiLSTM_GRU_pred    113.008916      0.642901         -9.302629
# 8         QRNN_pred    118.393445      0.690588         -9.302629
# 9          ESN_pred    118.393445      0.751412         -8.485144
# 10         BNN_pred    118.393445      0.690588         -9.302629
# 11               __    118.393445      0.690588         -9.302629

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_2y)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_2y)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_2y', file, 'CCV')
get_final_results_1('2022_2y', file, 'CCV')

get_final_results('2022_2y', dw_file, 'CCV_dw')
get_final_results_1('2022_2y', dw_file, 'CCV_dw')

get_final_results('2022_2y', cw_file, 'CCV_cw')
get_final_results_1('2022_2y', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.077593     -0.033939        -13.543035
# 1            CCV_dw    125.445896      0.360233         -8.607574
# 2            CCV_cw    136.579543      0.150309        -12.902188
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     14.133421     -0.226699        -15.474193
# 5     LSTM_GRU_pred     14.133421     -0.226699        -15.474193
# 6       BiLSTM_pred     74.539526      0.172622        -13.494842
# 7   BiLSTM_GRU_pred     90.703101      0.066869        -14.250829
# 8         QRNN_pred    113.397617      0.068125        -14.411155
# 9          ESN_pred    118.242227      0.050088        -14.250829
# 10         BNN_pred    118.185826      0.330991        -13.116104
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    124.307118      0.069686        -12.712510
# 1            CCV_dw    111.462496      0.142793         -9.736115
# 2            CCV_cw     15.808753     -0.238500        -11.728141
# 3         LSTM_pred     54.077611     -0.162120        -13.103786
# 4          GRU_pred     69.319051     -0.015595        -13.573469
# 5     LSTM_GRU_pred     36.973213     -0.143700        -16.573792
# 6       BiLSTM_pred     56.083460     -0.008736        -12.941421
# 7   BiLSTM_GRU_pred     -2.803647     -0.242631        -15.739413
# 8         QRNN_pred     52.569606     -0.183324        -13.678971
# 9          ESN_pred     -5.396071     -0.427587        -13.717875
# 10         BNN_pred    217.379173      0.360966        -11.304918
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      3.143326     -0.431367        -14.352256
# 1            CCV_dw    133.943260      0.230525        -10.923708
# 2            CCV_cw     11.676657     -0.299971        -12.396094
# 3         LSTM_pred     -6.723266     -0.454745        -15.060917
# 4          GRU_pred     46.369709     -0.123726        -10.091614
# 5     LSTM_GRU_pred     29.730255     -0.200096        -14.401244
# 6       BiLSTM_pred     37.273256     -0.164184        -12.173827
# 7   BiLSTM_GRU_pred    -85.155719     -0.768250        -20.420065
# 8         QRNN_pred    -28.753393     -0.636842        -16.624474
# 9          ESN_pred   -119.107211     -1.323848        -20.423436
# 10         BNN_pred     71.766023     -0.177302        -16.018125
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     68.553724     -0.116158        -12.868181
# 1            CCV_dw    107.890343      0.129394         -9.513033
# 2            CCV_cw     23.563781     -0.230526        -13.245631
# 3         LSTM_pred      7.702657     -0.363605        -16.017406
# 4          GRU_pred      8.893174     -0.258575        -16.139991
# 5     LSTM_GRU_pred     -9.510136     -0.341212        -19.051217
# 6       BiLSTM_pred    -23.506772     -0.340624        -15.894356
# 7   BiLSTM_GRU_pred    -12.566990     -0.347471        -15.920198
# 8         QRNN_pred     12.858710     -0.350307        -15.406081
# 9          ESN_pred    -54.315590     -0.735394        -15.148429
# 10         BNN_pred    135.167720      0.075260        -15.096600
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    116.801960      0.041335        -12.712510
# 1            CCV_dw    109.000384      0.133557         -9.736115
# 2            CCV_cw     -0.216259     -0.307829        -12.501781
# 3         LSTM_pred     54.077611     -0.162120        -13.103786
# 4          GRU_pred     65.094240     -0.031997        -13.573469
# 5     LSTM_GRU_pred     32.876198     -0.160491        -16.573792
# 6       BiLSTM_pred     48.148199     -0.040043        -13.237301
# 7   BiLSTM_GRU_pred      3.979094     -0.276935        -15.739413
# 8         QRNN_pred     87.680613     -0.042367        -12.943468
# 9          ESN_pred     59.780877     -0.155107        -15.131566
# 10         BNN_pred    206.718903      0.325369        -11.304918
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     27.253378     -0.294432        -15.659609
# 1            CCV_dw    127.725516      0.369905         -9.649484
# 2            CCV_cw     77.533669     -0.149956        -15.593358
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     -8.722832     -0.344145        -14.788300
# 5     LSTM_GRU_pred    -17.209180     -0.380084        -14.788300
# 6       BiLSTM_pred     75.109616      0.145223        -14.759624
# 7   BiLSTM_GRU_pred    -14.247344     -0.375068        -19.782532
# 8         QRNN_pred     -7.129811     -0.514394        -18.255314
# 9          ESN_pred     55.752707     -0.306128        -11.071652
# 10         BNN_pred     50.417815      0.050892        -15.722736
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     67.311823     -0.112496        -13.543035
# 1            CCV_dw    127.047821      0.366016         -8.468303
# 2            CCV_cw     70.651837     -0.102543        -15.078618
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred    -53.086629     -0.512574        -17.984272
# 5     LSTM_GRU_pred    -53.086629     -0.512574        -17.984272
# 6       BiLSTM_pred     40.240942      0.044668        -15.148519
# 7   BiLSTM_GRU_pred     86.766291      0.052550        -14.250829
# 8         QRNN_pred     13.102207     -0.327476        -17.060753
# 9          ESN_pred    130.274574      0.092637        -10.693405
# 10         BNN_pred    104.781142      0.230097        -14.157658
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    112.403923      0.028226        -13.543035
# 1            CCV_dw    122.952808      0.351318         -8.607574
# 2            CCV_cw    109.101234      0.018578        -13.864713
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred      0.507781     -0.282360        -15.474193
# 5     LSTM_GRU_pred      0.507781     -0.282360        -15.474193
# 6       BiLSTM_pred     74.539526      0.172622        -13.494842
# 7   BiLSTM_GRU_pred     90.703101      0.066869        -14.250829
# 8         QRNN_pred    105.718147      0.039954        -13.681891
# 9          ESN_pred    147.333462      0.152563        -14.507198
# 10         BNN_pred    118.185826      0.330991        -13.116104
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     47.278164      0.069993        -13.199840
# 1            CCV_dw     70.593064      0.158138        -13.815624
# 2            CCV_cw     15.064668     -0.055401        -18.285744
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.156352        -13.199840
# 5     LSTM_GRU_pred     78.242403      0.156352        -13.199840
# 6       BiLSTM_pred     57.630169      0.079444        -14.859156
# 7   BiLSTM_GRU_pred     13.754272     -0.335417        -18.690599
# 8         QRNN_pred     37.244329      0.030696        -13.815624
# 9          ESN_pred     75.367794      0.176533        -12.373346
# 10         BNN_pred     31.518846     -0.021242        -15.803960
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.242403      0.186086        -13.199840
# 1            CCV_dw     78.242403      0.186086        -13.199840
# 2            CCV_cw     50.392827      0.083056        -15.441774
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.095226        -13.199840
# 5     LSTM_GRU_pred     78.242403      0.095226        -13.199840
# 6       BiLSTM_pred     57.630169      0.110208        -14.859156
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     78.242403      0.186086        -13.199840
# 9          ESN_pred     92.682660      0.240116        -12.000636
# 10         BNN_pred     65.316557      0.085360        -14.240391
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.242403      0.186086         -13.19984
# 1            CCV_dw     78.242403      0.186086         -13.19984
# 2            CCV_cw     78.242403      0.186086         -13.19984
# 3         LSTM_pred     78.242403      0.186086         -13.19984
# 4          GRU_pred     78.242403      0.132971         -13.19984
# 5     LSTM_GRU_pred     78.242403      0.132971         -13.19984
# 6       BiLSTM_pred     78.242403      0.186086         -13.19984
# 7   BiLSTM_GRU_pred     78.242403      0.186086         -13.19984
# 8         QRNN_pred     78.242403      0.186086         -13.19984
# 9          ESN_pred     79.400118      0.190306         -13.19984
# 10         BNN_pred     78.242403      0.186086         -13.19984
# 11               __     78.242403      0.186086         -13.19984
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    119.856688      0.055468        -13.199840
# 1            CCV_dw    102.290930      0.274608        -11.301691
# 2            CCV_cw     58.191405      0.112188        -12.020286
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     43.984780     -0.108385        -14.915577
# 5     LSTM_GRU_pred     56.784353     -0.059902        -14.816188
# 6       BiLSTM_pred     62.222093      0.035997        -14.706669
# 7   BiLSTM_GRU_pred     73.915099      0.004032        -14.250829
# 8         QRNN_pred    115.970246      0.069227        -13.276240
# 9          ESN_pred     93.377784     -0.011267        -13.219657
# 10         BNN_pred    106.412108      0.289077        -13.116104
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    147.804347      0.156323        -13.155164
# 1            CCV_dw    124.449963      0.218172         -9.766844
# 2            CCV_cw    113.476465      0.019058        -14.482110
# 3         LSTM_pred     78.177645     -0.079779        -12.435306
# 4          GRU_pred     83.947570      0.039412        -13.693020
# 5     LSTM_GRU_pred     71.176629     -0.008482        -13.663709
# 6       BiLSTM_pred    112.999713      0.209120        -12.306309
# 7   BiLSTM_GRU_pred    -24.787094     -0.415329        -15.569376
# 8         QRNN_pred     85.029001     -0.051023        -13.844378
# 9          ESN_pred    139.101510      0.154231        -12.869539
# 10         BNN_pred    226.822579      0.398001        -12.158792
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     35.120406     -0.275574        -12.895011
# 1            CCV_dw    112.819200      0.218467         -9.836838
# 2            CCV_cw    133.694368      0.173880         -7.409884
# 3         LSTM_pred      8.517807     -0.390519        -14.900465
# 4          GRU_pred     82.240671      0.024293        -12.147177
# 5     LSTM_GRU_pred     58.355153     -0.075832        -10.928074
# 6       BiLSTM_pred    101.926714      0.106704        -11.586152
# 7   BiLSTM_GRU_pred    -99.157132     -0.891055        -21.246296
# 8         QRNN_pred    -43.307103     -0.720862        -16.772202
# 9          ESN_pred    -27.147934     -0.762850        -13.034149
# 10         BNN_pred    132.954159      0.065549        -14.973685
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     47.921031     -0.212251        -14.476937
# 1            CCV_dw    126.050471      0.224059         -9.551115
# 2            CCV_cw     98.923417     -0.067888        -10.403260
# 3         LSTM_pred     53.189317     -0.185588        -15.017333
# 4          GRU_pred    -11.768714     -0.348325        -17.151505
# 5     LSTM_GRU_pred    -14.151237     -0.354554        -16.635881
# 6       BiLSTM_pred     35.036301     -0.096728        -13.363219
# 7   BiLSTM_GRU_pred    -56.593507     -0.567603        -17.236696
# 8         QRNN_pred    -21.372963     -0.497908        -16.374525
# 9          ESN_pred     62.660867     -0.149483        -12.720763
# 10         BNN_pred    174.868694      0.218860        -13.001813
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     73.661286     -0.130133        -14.823449
# 1            CCV_dw    124.475503      0.218284         -9.551115
# 2            CCV_cw     96.637215     -0.048691        -13.013249
# 3         LSTM_pred     78.177645     -0.079779        -12.435306
# 4          GRU_pred     47.266660     -0.103492        -14.642997
# 5     LSTM_GRU_pred     39.179103     -0.133643        -13.774046
# 6       BiLSTM_pred     79.331577      0.081510        -12.306309
# 7   BiLSTM_GRU_pred    -16.655670     -0.378470        -15.569376
# 8         QRNN_pred     27.651767     -0.284690        -15.076244
# 9          ESN_pred    114.000297      0.058554        -12.869539
# 10         BNN_pred    226.822579      0.398001        -12.158792
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      9.246071     -0.365805        -15.423100
# 1            CCV_dw     80.584871      0.197635        -11.773061
# 2            CCV_cw    121.418135      0.359747         -9.094755
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     -0.275531     -0.310170        -16.887843
# 5     LSTM_GRU_pred     43.443495     -0.128220        -16.329492
# 6       BiLSTM_pred     39.815462      0.010239        -14.888773
# 7   BiLSTM_GRU_pred    -36.558517     -0.500013        -19.724783
# 8         QRNN_pred     18.749946     -0.402028        -12.475877
# 9          ESN_pred     -3.581245     -0.598581        -15.267305
# 10         BNN_pred     63.129808      0.099898        -14.766647
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -7.224118     -0.428925        -15.557751
# 1            CCV_dw    103.859897      0.280300        -11.142683
# 2            CCV_cw    117.510032      0.340260         -9.094755
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred    -38.316643     -0.444569        -18.834552
# 5     LSTM_GRU_pred    -15.607815     -0.349979        -18.086504
# 6       BiLSTM_pred     34.624304     -0.008705        -14.706669
# 7   BiLSTM_GRU_pred     51.882800     -0.083702        -14.250829
# 8         QRNN_pred     42.106871     -0.204494        -13.641573
# 9          ESN_pred     92.727795     -0.018835        -12.800224
# 10         BNN_pred     97.115157      0.202262        -13.116104
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     74.992328     -0.112493        -13.199840
# 1            CCV_dw    102.315966      0.274724        -11.142683
# 2            CCV_cw     65.726405      0.141036        -12.664130
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred      3.403136     -0.269388        -16.377004
# 5     LSTM_GRU_pred     26.045245     -0.179427        -15.274468
# 6       BiLSTM_pred     62.222093      0.013874        -14.706669
# 7   BiLSTM_GRU_pred     73.915099      0.004032        -14.250829
# 8         QRNN_pred     79.514534     -0.066808        -13.199840
# 9          ESN_pred    113.808206      0.029250        -13.545144
# 10         BNN_pred    106.412108      0.289077        -13.116104
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     49.615622      0.079020        -13.199840
# 1            CCV_dw     70.593064      0.158138        -13.815624
# 2            CCV_cw     78.242403      0.186086        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.156352        -13.199840
# 5     LSTM_GRU_pred     79.400118      0.160622        -13.199840
# 6       BiLSTM_pred     57.630169      0.079444        -14.859156
# 7   BiLSTM_GRU_pred     14.356533     -0.333235        -18.343667
# 8         QRNN_pred     80.801655      0.082204        -13.202757
# 9          ESN_pred     34.710071      0.023220        -13.968228
# 10         BNN_pred     43.220980      0.024405        -14.848792
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.242403      0.186086        -13.199840
# 1            CCV_dw     78.242403      0.186086        -13.199840
# 2            CCV_cw     78.242403      0.186086        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     78.242403      0.073171        -13.444439
# 6       BiLSTM_pred     78.242403      0.156352        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.156352        -13.199840
# 8         QRNN_pred     78.242403      0.186086        -13.199840
# 9          ESN_pred     78.242403      0.186086        -13.199840
# 10         BNN_pred     78.242403      0.132971        -13.199840
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.242403      0.186086         -13.19984
# 1            CCV_dw     78.242403      0.186086         -13.19984
# 2            CCV_cw     78.242403      0.186086         -13.19984
# 3         LSTM_pred     78.242403      0.186086         -13.19984
# 4          GRU_pred     78.242403      0.095226         -13.19984
# 5     LSTM_GRU_pred     78.242403      0.095226         -13.19984
# 6       BiLSTM_pred     78.242403      0.186086         -13.19984
# 7   BiLSTM_GRU_pred     78.242403      0.186086         -13.19984
# 8         QRNN_pred     78.242403      0.186086         -13.19984
# 9          ESN_pred     78.242403      0.186086         -13.19984
# 10         BNN_pred     78.242403      0.186086         -13.19984
# 11               __     78.242403      0.186086         -13.19984
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    131.732976      0.149449        -13.199840
# 1            CCV_dw    157.251975      0.306560        -11.647121
# 2            CCV_cw    161.119984      0.324924        -10.649745
# 3         LSTM_pred     52.518759     -0.218163        -16.219584
# 4          GRU_pred    131.579356      0.286918         -8.732784
# 5     LSTM_GRU_pred     69.842301     -0.014271        -13.140478
# 6       BiLSTM_pred     92.018915      0.130039        -14.923582
# 7   BiLSTM_GRU_pred    -14.923898     -0.368666        -15.339158
# 8         QRNN_pred    120.823031      0.118497        -13.199840
# 9          ESN_pred    -50.446078     -0.330497        -13.883854
# 10         BNN_pred    239.281827      0.391021        -11.329812
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    102.067221      0.107419        -11.212864
# 1            CCV_dw     16.148256     -0.202280        -12.055088
# 2            CCV_cw     41.744797     -0.140937        -12.589933
# 3         LSTM_pred    104.837503      0.181829        -11.410281
# 4          GRU_pred    264.984689      0.858061         -9.334142
# 5     LSTM_GRU_pred    232.757840      0.696737         -8.492315
# 6       BiLSTM_pred    176.812677      0.396420        -11.161812
# 7   BiLSTM_GRU_pred     -8.347346     -0.329713        -15.659162
# 8         QRNN_pred     78.082531      0.013644        -15.923238
# 9          ESN_pred     39.343917      0.032193         -9.094755
# 10         BNN_pred     91.428634      0.129872        -12.102538
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    181.877396      0.510495         -4.064074
# 1            CCV_dw     76.099161     -0.028602         -6.345438
# 2            CCV_cw    133.743092      0.300061         -5.430055
# 3         LSTM_pred    -44.056909     -0.630438        -15.783860
# 4          GRU_pred    152.972961      0.439005         -8.599540
# 5     LSTM_GRU_pred     39.442389     -0.369029         -4.816899
# 6       BiLSTM_pred      8.983842     -0.468953        -12.425634
# 7   BiLSTM_GRU_pred   -103.885853     -1.447128        -19.559948
# 8         QRNN_pred    132.619124      0.259017         -5.555543
# 9          ESN_pred     -7.812966     -0.273779         -9.094755
# 10         BNN_pred    133.510604      0.272697         -8.762566
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     36.521870     -0.181080        -13.503490
# 1            CCV_dw     53.185935     -0.125458        -10.031101
# 2            CCV_cw    118.268680      0.189471         -8.044812
# 3         LSTM_pred     -9.602493     -0.440233        -13.947706
# 4          GRU_pred    158.822757      0.376760        -11.485394
# 5     LSTM_GRU_pred    115.147808      0.183338         -9.893045
# 6       BiLSTM_pred     79.492834      0.006509        -12.196614
# 7   BiLSTM_GRU_pred    -98.950971     -1.173041        -18.377828
# 8         QRNN_pred     13.538226     -0.303370        -16.912156
# 9          ESN_pred     -6.759223     -0.193550         -9.094755
# 10         BNN_pred     69.032593      0.032236        -12.294441
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    155.791017      0.304461        -11.212864
# 1            CCV_dw    108.467977      0.135117         -8.938027
# 2            CCV_cw    198.633738      0.505086         -9.197401
# 3         LSTM_pred     12.655230     -0.220747        -14.170037
# 4          GRU_pred     87.019515      0.035726        -14.827343
# 5     LSTM_GRU_pred     26.634739     -0.250293        -17.481947
# 6       BiLSTM_pred     90.315504      0.125014        -13.780763
# 7   BiLSTM_GRU_pred     -9.851757     -0.356857        -14.347428
# 8         QRNN_pred      9.352912     -0.297124        -18.467485
# 9          ESN_pred     -2.361900     -0.157551         -9.094755
# 10         BNN_pred    103.580777      0.181831        -10.372374
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    152.269586      0.351816         -5.499781
# 1            CCV_dw    180.177774      0.431795        -11.483612
# 2            CCV_cw    134.023853      0.263422         -8.629713
# 3         LSTM_pred     -6.589964     -0.378926        -16.474093
# 4          GRU_pred     59.339286     -0.115870         -8.710895
# 5     LSTM_GRU_pred    -22.488755     -0.566137        -10.621736
# 6       BiLSTM_pred     90.851800      0.054406        -10.964564
# 7   BiLSTM_GRU_pred    -76.575716     -1.013845        -18.334999
# 8         QRNN_pred    132.619124      0.259017         -5.555543
# 9          ESN_pred      7.556544     -0.178277         -9.094755
# 10         BNN_pred     57.226592     -0.170076        -15.834940
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     75.460287     -0.131404        -15.655820
# 1            CCV_dw    117.698220      0.168051        -11.711761
# 2            CCV_cw    121.696070      0.192610        -11.250735
# 3         LSTM_pred     26.884271     -0.227203        -14.846250
# 4          GRU_pred     65.549315     -0.047671        -10.536883
# 5     LSTM_GRU_pred     36.249073     -0.202259        -10.589593
# 6       BiLSTM_pred     60.762030     -0.062453        -15.699423
# 7   BiLSTM_GRU_pred   -112.405214     -1.055659        -18.233260
# 8         QRNN_pred     27.900926     -0.231261        -17.252406
# 9          ESN_pred     -3.720353     -0.160563         -9.094755
# 10         BNN_pred    108.315484     -0.081922        -15.867917
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    132.304397      0.159087        -13.199840
# 1            CCV_dw    137.592324      0.237598        -11.448956
# 2            CCV_cw    201.283094      0.482383        -10.745048
# 3         LSTM_pred     34.301899     -0.295987        -16.633486
# 4          GRU_pred    -33.457345     -0.454421        -17.104631
# 5     LSTM_GRU_pred    -13.090958     -0.354341        -16.204631
# 6       BiLSTM_pred     54.816093     -0.016146        -14.870932
# 7   BiLSTM_GRU_pred    -28.421436     -0.444844        -15.913366
# 8         QRNN_pred     62.716581     -0.146716        -16.086451
# 9          ESN_pred    -42.864593     -0.310655        -13.743019
# 10         BNN_pred    159.299786      0.115929        -14.372405
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    152.269586      0.351816         -5.499781
# 1            CCV_dw     38.039725      0.036189        -13.815624
# 2            CCV_cw     90.092617      0.053755        -11.142683
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred     64.564742     -0.122152        -14.706863
# 5     LSTM_GRU_pred     88.087408     -0.071588        -15.487819
# 6       BiLSTM_pred     43.094002     -0.209209        -16.337371
# 7   BiLSTM_GRU_pred     15.835201     -0.399643        -19.752866
# 8         QRNN_pred    132.619124      0.259017         -5.555543
# 9          ESN_pred    111.102645      0.365580         -9.094755
# 10         BNN_pred     24.584940     -0.049164        -16.343441
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     75.460287     -0.131404        -15.655820
# 1            CCV_dw     66.677769      0.143738        -13.815624
# 2            CCV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.156352        -13.199840
# 5     LSTM_GRU_pred     64.564742     -0.122152        -14.706863
# 6       BiLSTM_pred     78.242403      0.156352        -13.199840
# 7   BiLSTM_GRU_pred     34.125404     -0.249099        -16.752260
# 8         QRNN_pred     27.900926     -0.231261        -17.252406
# 9          ESN_pred     39.032541      0.037558        -13.862960
# 10         BNN_pred     31.518846     -0.021242        -15.803960
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.242403      0.186086        -13.199840
# 1            CCV_dw     78.242403      0.186086        -13.199840
# 2            CCV_cw     78.242403      0.186086        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     78.242403      0.073171        -13.444439
# 6       BiLSTM_pred     78.242403      0.186086        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     78.242403     -0.121785        -15.612725
# 9          ESN_pred     44.233142      0.059752        -14.138352
# 10         BNN_pred     50.674747      0.030413        -14.240391
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    113.094821      0.031455        -14.250829
# 1            CCV_dw    109.880744      0.137938         -9.374288
# 2            CCV_cw    157.849193      0.317104         -9.221644
# 3         LSTM_pred     59.120255     -0.196894        -12.032098
# 4          GRU_pred    131.579356      0.286918         -8.732784
# 5     LSTM_GRU_pred    134.488921      0.298870         -8.732784
# 6       BiLSTM_pred     42.621438     -0.071524        -13.431183
# 7   BiLSTM_GRU_pred     43.510352     -0.073981        -16.450370
# 8         QRNN_pred    129.895826      0.087885        -13.586460
# 9          ESN_pred    -32.059833     -0.260052        -14.480809
# 10         BNN_pred    163.083466      0.403274        -12.420813
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    113.031342      0.151290        -11.960503
# 1            CCV_dw     -1.365441     -0.287765        -12.925752
# 2            CCV_cw     72.460775     -0.015539        -10.348570
# 3         LSTM_pred     -7.630644     -0.325018        -18.287313
# 4          GRU_pred    264.984689      0.858061         -9.334142
# 5     LSTM_GRU_pred    211.649483      0.643614         -9.688748
# 6       BiLSTM_pred    144.822220      0.356512        -11.022382
# 7   BiLSTM_GRU_pred     12.769605     -0.295126        -14.600311
# 8         QRNN_pred    141.754908      0.266548        -10.554888
# 9          ESN_pred    -26.241559     -0.270896        -12.329835
# 10         BNN_pred     21.380995     -0.180382        -15.933261
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     87.555454      0.026768         -5.057242
# 1            CCV_dw    119.629958      0.221994         -3.721460
# 2            CCV_cw    103.173175      0.126147         -5.293580
# 3         LSTM_pred    -87.619746     -0.986245        -19.668329
# 4          GRU_pred    124.717598      0.328640         -5.352963
# 5     LSTM_GRU_pred      0.759952     -0.814003         -5.550701
# 6       BiLSTM_pred    112.982849      0.193964         -4.857656
# 7   BiLSTM_GRU_pred      0.812829     -0.871332         -8.286746
# 8         QRNN_pred     50.875471     -0.181031         -6.919703
# 9          ESN_pred    -10.870832     -0.305457         -9.094755
# 10         BNN_pred    170.337050      0.516091         -4.623598
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     57.164722     -0.112371        -11.194806
# 1            CCV_dw     43.571705     -0.184484        -11.228140
# 2            CCV_cw     96.372056      0.081775         -5.632987
# 3         LSTM_pred    -38.548450     -0.646485        -16.710298
# 4          GRU_pred    158.822757      0.376760        -11.485394
# 5     LSTM_GRU_pred     25.854162     -0.367057        -12.647469
# 6       BiLSTM_pred    107.000193      0.134948         -6.291509
# 7   BiLSTM_GRU_pred    -78.967564     -1.137510        -18.121056
# 8         QRNN_pred    111.899201      0.161784         -4.855180
# 9          ESN_pred     13.106263     -0.117785         -9.094755
# 10         BNN_pred     57.104227     -0.030744        -14.358419
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     50.831450     -0.123196        -15.457749
# 1            CCV_dw     74.180494     -0.020481        -11.572790
# 2            CCV_cw    125.912941      0.225521         -5.556345
# 3         LSTM_pred    -56.649715     -0.585057        -19.168513
# 4          GRU_pred     87.019515      0.035726        -14.827343
# 5     LSTM_GRU_pred     85.013652      0.028101        -10.805110
# 6       BiLSTM_pred    148.035929      0.380978         -8.603671
# 7   BiLSTM_GRU_pred     18.782745     -0.243946        -15.264077
# 8         QRNN_pred     98.389368      0.166783         -9.548988
# 9          ESN_pred    -24.760271     -0.285724         -9.795911
# 10         BNN_pred     48.030424     -0.068552        -14.691794
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.833878      0.288737         -5.499781
# 1            CCV_dw    138.432724      0.288551         -6.731296
# 2            CCV_cw    234.769758      0.757405         -5.055486
# 3         LSTM_pred    -84.985626     -0.821637        -17.914166
# 4          GRU_pred     39.741303     -0.251270         -7.367592
# 5     LSTM_GRU_pred    -53.245401     -0.898543        -10.479821
# 6       BiLSTM_pred     43.493540     -0.228313        -10.406738
# 7   BiLSTM_GRU_pred    -31.490820     -0.997564        -11.546991
# 8         QRNN_pred    116.493747      0.181103         -6.919703
# 9          ESN_pred    -10.870832     -0.305457         -9.094755
# 10         BNN_pred     84.776032      0.024384        -12.689373
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     68.567164     -0.044545        -13.978712
# 1            CCV_dw    104.864638      0.119782         -7.475389
# 2            CCV_cw    221.346783      0.623315         -9.221644
# 3         LSTM_pred    -28.743763     -0.508848        -14.026926
# 4          GRU_pred     65.549315     -0.047671        -10.536883
# 5     LSTM_GRU_pred     15.840374     -0.352211        -11.365187
# 6       BiLSTM_pred     46.860325     -0.152407        -11.670308
# 7   BiLSTM_GRU_pred   -114.910379     -1.229070        -19.020628
# 8         QRNN_pred    152.750876      0.353646         -5.499781
# 9          ESN_pred    -34.049862     -0.337635         -9.094755
# 10         BNN_pred     92.403120      0.135274        -13.641566
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     77.373731     -0.119094        -15.505756
# 1            CCV_dw    142.220082      0.268316         -7.309345
# 2            CCV_cw    172.151631      0.408899         -9.221644
# 3         LSTM_pred     20.286983     -0.371037        -14.551233
# 4          GRU_pred    -33.457345     -0.454421        -17.104631
# 5     LSTM_GRU_pred     69.103782     -0.032845        -10.284798
# 6       BiLSTM_pred     35.326924     -0.106545        -12.619168
# 7   BiLSTM_GRU_pred     -3.047310     -0.313416        -17.345144
# 8         QRNN_pred     82.517120      0.005690        -13.036245
# 9          ESN_pred    -78.088883     -0.506296        -13.242343
# 10         BNN_pred    119.087981      0.245313        -12.273051
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.833878      0.288737         -5.499781
# 1            CCV_dw     38.039725      0.036189        -13.815624
# 2            CCV_cw     90.092617      0.053755        -11.142683
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred     59.533867     -0.181463        -15.487819
# 5     LSTM_GRU_pred    -14.791464     -0.527176        -19.177028
# 6       BiLSTM_pred     43.094002     -0.209209        -16.337371
# 7   BiLSTM_GRU_pred    -31.490820     -0.997564        -11.546991
# 8         QRNN_pred    116.493747      0.181103         -6.919703
# 9          ESN_pred    -10.870832     -0.305457         -9.094755
# 10         BNN_pred     24.584940     -0.049164        -16.343441
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     68.567164     -0.044545        -13.978712
# 1            CCV_dw     66.677769      0.143738        -13.815624
# 2            CCV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     57.630169      0.110208        -14.859156
# 4          GRU_pred     78.242403      0.156352        -13.199840
# 5     LSTM_GRU_pred     64.564742     -0.122152        -14.706863
# 6       BiLSTM_pred     70.593064      0.128037        -13.815624
# 7   BiLSTM_GRU_pred     14.356533     -0.333235        -18.343667
# 8         QRNN_pred    152.750876      0.353646         -5.499781
# 9          ESN_pred     26.176154     -0.013503        -14.005465
# 10         BNN_pred     31.518846     -0.021242        -15.803960
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.593064     -0.146850        -16.037538
# 1            CCV_dw     70.593064      0.158138        -13.815624
# 2            CCV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     78.242403      0.156352        -13.199840
# 6       BiLSTM_pred     78.242403      0.186086        -13.199840
# 7   BiLSTM_GRU_pred     63.422940      0.131741        -13.199840
# 8         QRNN_pred     82.517120      0.005690        -13.036245
# 9          ESN_pred     44.233142      0.059752        -14.138352
# 10         BNN_pred     38.889002      0.007454        -15.202383
# 11               __     78.242403      0.186086        -13.199840

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     95.077593     -0.033939        -13.543035
# 1            CCV_dw    166.175128      0.248747         -8.736679
# 2            CCV_cw    165.118154      0.249743        -12.379661
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     14.133421     -0.226699        -15.474193
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     74.539526      0.172622        -13.494842
# 7   BiLSTM_GRU_pred     34.840927      0.023678        -15.948584
# 8         QRNN_pred    113.397617      0.068125        -14.411155
# 9          ESN_pred    161.872424      0.204846        -12.567018
# 10         BNN_pred    212.355722      0.337114        -13.019461
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    124.307118      0.069686        -12.712510
# 1            CCV_dw    136.105957      0.143533         -9.103270
# 2            CCV_cw     98.038151      0.091952        -14.047767
# 3         LSTM_pred     54.077611     -0.162120        -13.103786
# 4          GRU_pred     69.319051     -0.015595        -13.573469
# 5     LSTM_GRU_pred    110.617079      0.120888        -13.407135
# 6       BiLSTM_pred     56.083460     -0.008736        -12.941421
# 7   BiLSTM_GRU_pred     84.093630     -0.168835        -12.350647
# 8         QRNN_pred     52.569606     -0.183324        -13.678971
# 9          ESN_pred    136.648701      0.240938        -11.197302
# 10         BNN_pred    211.642440      0.342532        -12.187527
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      3.143326     -0.431367        -14.352256
# 1            CCV_dw    137.431503      0.149106         -7.604456
# 2            CCV_cw    181.711846      0.434750         -8.591541
# 3         LSTM_pred     -6.723266     -0.454745        -15.060917
# 4          GRU_pred     46.369709     -0.123726        -10.091614
# 5     LSTM_GRU_pred     71.190581      0.047030        -15.052149
# 6       BiLSTM_pred     37.273256     -0.164184        -12.173827
# 7   BiLSTM_GRU_pred    125.835756     -0.020554         -9.533571
# 8         QRNN_pred    -28.753393     -0.636842        -16.624474
# 9          ESN_pred    151.964170      0.342963        -11.247854
# 10         BNN_pred    100.714827     -0.059083        -14.258118
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     68.553724     -0.116158        -12.868181
# 1            CCV_dw    137.647347      0.149477         -9.011897
# 2            CCV_cw    128.957039      0.216020        -10.948181
# 3         LSTM_pred      7.702657     -0.363605        -16.017406
# 4          GRU_pred      8.893174     -0.258575        -16.139991
# 5     LSTM_GRU_pred    122.017283      0.162249        -13.407135
# 6       BiLSTM_pred    -23.506772     -0.340624        -15.894356
# 7   BiLSTM_GRU_pred     89.488360     -0.151042        -10.756115
# 8         QRNN_pred     12.858710     -0.350307        -15.406081
# 9          ESN_pred    191.061837      0.478746        -11.314465
# 10         BNN_pred    120.760079      0.020127        -14.975286
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    116.801960      0.041335        -12.712510
# 1            CCV_dw    102.041016      0.017436         -9.103270
# 2            CCV_cw    111.795523      0.144680        -15.292139
# 3         LSTM_pred     54.077611     -0.162120        -13.103786
# 4          GRU_pred     65.094240     -0.031997        -13.573469
# 5     LSTM_GRU_pred    110.617079      0.120888        -13.407135
# 6       BiLSTM_pred     48.148199     -0.040043        -13.237301
# 7   BiLSTM_GRU_pred     80.464377     -0.183127        -12.350647
# 8         QRNN_pred     87.680613     -0.042367        -12.943468
# 9          ESN_pred    196.040960      0.466174        -11.125921
# 10         BNN_pred    206.359490      0.324917        -12.187527
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     27.253378     -0.294432        -15.659609
# 1            CCV_dw    195.051318      0.351735         -7.577355
# 2            CCV_cw    259.130273      0.529401         -9.170353
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     -8.722832     -0.344145        -14.788300
# 5     LSTM_GRU_pred     32.308400      0.014107        -14.848792
# 6       BiLSTM_pred     75.109616      0.145223        -14.759624
# 7   BiLSTM_GRU_pred      1.211974     -0.111629        -16.287882
# 8         QRNN_pred     -7.129811     -0.514394        -18.255314
# 9          ESN_pred    177.319813      0.410078        -11.055376
# 10         BNN_pred    126.126180      0.043642        -13.635889
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     67.311823     -0.112496        -13.543035
# 1            CCV_dw    191.797112      0.338089         -8.596447
# 2            CCV_cw    183.410079      0.316548         -9.031914
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred    -53.086629     -0.512574        -17.984272
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     40.240942      0.044668        -15.148519
# 7   BiLSTM_GRU_pred     34.741948      0.022835        -14.855237
# 8         QRNN_pred     13.102207     -0.327476        -17.060753
# 9          ESN_pred    207.378179      0.498906        -11.142683
# 10         BNN_pred    181.728505      0.236110        -14.062173
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    112.403923      0.028226        -13.543035
# 1            CCV_dw    163.591817      0.239772         -8.736679
# 2            CCV_cw    155.308680      0.181703        -12.361707
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred      0.507781     -0.282360        -15.474193
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     74.539526      0.172622        -13.494842
# 7   BiLSTM_GRU_pred     34.840927      0.023678        -15.948584
# 8         QRNN_pred    105.718147      0.039954        -13.681891
# 9          ESN_pred    190.599880      0.305961        -12.567018
# 10         BNN_pred    212.355722      0.337114        -13.019461
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     47.278164      0.069993        -13.199840
# 1            CCV_dw     70.593064      0.104900        -13.815624
# 2            CCV_cw     89.507834      0.229695        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.156352        -13.199840
# 5     LSTM_GRU_pred     32.308400      0.014107        -14.848792
# 6       BiLSTM_pred     57.630169      0.079444        -14.859156
# 7   BiLSTM_GRU_pred     67.301416      0.146071        -13.199840
# 8         QRNN_pred     37.244329      0.030696        -13.815624
# 9          ESN_pred     47.629144     -0.019702        -14.633638
# 10         BNN_pred     50.674747      0.030413        -14.240391
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.242403      0.186086        -13.199840
# 1            CCV_dw     78.242403      0.186086        -13.199840
# 2            CCV_cw     70.550632      0.158679        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.095226        -13.199840
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     57.630169      0.110208        -14.859156
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     78.242403      0.186086        -13.199840
# 9          ESN_pred     64.871772      0.137109        -14.240391
# 10         BNN_pred     65.316557      0.085360        -14.240391
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.242403      0.186086         -13.19984
# 1            CCV_dw     78.242403      0.186086         -13.19984
# 2            CCV_cw     74.299134      0.171707         -13.19984
# 3         LSTM_pred     78.242403      0.186086         -13.19984
# 4          GRU_pred     78.242403      0.132971         -13.19984
# 5     LSTM_GRU_pred     78.242403      0.186086         -13.19984
# 6       BiLSTM_pred     78.242403      0.186086         -13.19984
# 7   BiLSTM_GRU_pred     78.242403      0.186086         -13.19984
# 8         QRNN_pred     78.242403      0.186086         -13.19984
# 9          ESN_pred     79.400118      0.190306         -13.19984
# 10         BNN_pred     78.242403      0.186086         -13.19984
# 11               __     78.242403      0.186086         -13.19984
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    119.856688      0.055468        -13.199840
# 1            CCV_dw    144.235719      0.171155        -11.215485
# 2            CCV_cw     90.904161      0.235856        -11.338636
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     43.984780     -0.108385        -14.915577
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     62.222093      0.035997        -14.706669
# 7   BiLSTM_GRU_pred     68.846362      0.151992        -13.037257
# 8         QRNN_pred    115.970246      0.069227        -13.276240
# 9          ESN_pred    276.031292      0.777512        -11.337948
# 10         BNN_pred    230.197895      0.398834        -10.637174
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    147.804347      0.156323        -13.155164
# 1            CCV_dw    126.997217      0.110365        -11.574159
# 2            CCV_cw    199.163826      0.333296         -9.967160
# 3         LSTM_pred     78.177645     -0.079779        -12.435306
# 4          GRU_pred     83.947570      0.039412        -13.693020
# 5     LSTM_GRU_pred    116.340960      0.141863        -13.424876
# 6       BiLSTM_pred    112.999713      0.209120        -12.306309
# 7   BiLSTM_GRU_pred    102.565749      0.289125         -6.663204
# 8         QRNN_pred     85.029001     -0.051023        -13.844378
# 9          ESN_pred    191.307739      0.501100        -10.870033
# 10         BNN_pred    234.277274      0.422398        -12.061084
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     35.120406     -0.275574        -12.895011
# 1            CCV_dw    136.623675      0.145405        -10.670011
# 2            CCV_cw    219.052299      0.540186         -6.664929
# 3         LSTM_pred      8.517807     -0.390519        -14.900465
# 4          GRU_pred     82.240671      0.024293        -12.147177
# 5     LSTM_GRU_pred     81.572092      0.089011        -12.546751
# 6       BiLSTM_pred    101.926714      0.106704        -11.586152
# 7   BiLSTM_GRU_pred    114.877676      0.359980         -6.432429
# 8         QRNN_pred    -43.307103     -0.720862        -16.772202
# 9          ESN_pred    111.414987      0.150988        -10.696122
# 10         BNN_pred    185.234018      0.260998        -14.110229
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     47.921031     -0.212251        -14.476937
# 1            CCV_dw    148.792678      0.188466         -9.558844
# 2            CCV_cw    224.413735      0.413093         -9.172950
# 3         LSTM_pred     53.189317     -0.185588        -15.017333
# 4          GRU_pred    -11.768714     -0.348325        -17.151505
# 5     LSTM_GRU_pred    112.888236      0.129252        -13.424876
# 6       BiLSTM_pred     35.036301     -0.096728        -13.363219
# 7   BiLSTM_GRU_pred    121.014994      0.369435         -6.432429
# 8         QRNN_pred    -21.372963     -0.497908        -16.374525
# 9          ESN_pred    219.129331      0.586613         -9.550280
# 10         BNN_pred    182.303947      0.244291        -12.905042
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     73.661286     -0.130133        -14.823449
# 1            CCV_dw    117.498469      0.076073        -11.526857
# 2            CCV_cw    198.570342      0.338611         -9.930027
# 3         LSTM_pred     78.177645     -0.079779        -12.435306
# 4          GRU_pred     47.266660     -0.103492        -14.642997
# 5     LSTM_GRU_pred    116.340960      0.141863        -13.424876
# 6       BiLSTM_pred     79.331577      0.081510        -12.306309
# 7   BiLSTM_GRU_pred     84.489613      0.217981         -6.636769
# 8         QRNN_pred     27.651767     -0.284690        -15.076244
# 9          ESN_pred    234.319980      0.616825         -9.980415
# 10         BNN_pred    234.277274      0.422398        -12.061084
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV      9.246071     -0.365805        -15.423100
# 1            CCV_dw    158.023545      0.220716        -10.719477
# 2            CCV_cw    150.102521      0.477565         -9.094755
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     -0.275531     -0.310170        -16.887843
# 5     LSTM_GRU_pred     42.890672      0.054688        -14.848792
# 6       BiLSTM_pred     39.815462      0.010239        -14.888773
# 7   BiLSTM_GRU_pred    188.310908      0.612258         -7.051396
# 8         QRNN_pred     18.749946     -0.402028        -12.475877
# 9          ESN_pred    165.607509      0.375861        -10.696122
# 10         BNN_pred    164.065191      0.178475        -12.208675
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     -7.224118     -0.428925        -15.557751
# 1            CCV_dw    188.205156      0.323695         -9.325717
# 2            CCV_cw    165.500955      0.526050         -9.094755
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred    -38.316643     -0.444569        -18.834552
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     34.624304     -0.008705        -14.706669
# 7   BiLSTM_GRU_pred     94.626135      0.248385        -10.991860
# 8         QRNN_pred     42.106871     -0.204494        -13.641573
# 9          ESN_pred    320.077833      0.922018         -9.210301
# 10         BNN_pred    198.876398      0.295875        -11.143473
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     74.992328     -0.112493        -13.199840
# 1            CCV_dw    155.837314      0.211622        -11.154516
# 2            CCV_cw     87.920002      0.227472        -11.171641
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred      3.403136     -0.269388        -16.377004
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     62.222093      0.013874        -14.706669
# 7   BiLSTM_GRU_pred     68.846362      0.151992        -13.037257
# 8         QRNN_pred     79.514534     -0.066808        -13.199840
# 9          ESN_pred    231.651951      0.641129        -11.467784
# 10         BNN_pred    230.197895      0.398834        -10.637174
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     49.615622      0.079020        -13.199840
# 1            CCV_dw     64.328735      0.081638        -14.319912
# 2            CCV_cw     63.310894      0.131316        -13.199840
# 3         LSTM_pred     63.422940      0.131741        -13.199840
# 4          GRU_pred     78.242403      0.156352        -13.199840
# 5     LSTM_GRU_pred     42.890672      0.054688        -14.848792
# 6       BiLSTM_pred     57.630169      0.079444        -14.859156
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     80.801655      0.082204        -13.202757
# 9          ESN_pred     76.932084      0.088441        -12.003313
# 10         BNN_pred     50.674747      0.030413        -14.240391
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.242403      0.186086        -13.199840
# 1            CCV_dw     78.242403      0.186086        -13.199840
# 2            CCV_cw     78.242403      0.186086        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     78.242403      0.156352        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     78.242403      0.186086        -13.199840
# 9          ESN_pred     65.316557      0.138738        -14.240391
# 10         BNN_pred     78.242403      0.132971        -13.199840
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.242403      0.186086         -13.19984
# 1            CCV_dw     78.242403      0.186086         -13.19984
# 2            CCV_cw     78.242403      0.186086         -13.19984
# 3         LSTM_pred     78.242403      0.186086         -13.19984
# 4          GRU_pred     78.242403      0.095226         -13.19984
# 5     LSTM_GRU_pred     78.242403      0.186086         -13.19984
# 6       BiLSTM_pred     78.242403      0.186086         -13.19984
# 7   BiLSTM_GRU_pred     78.242403      0.186086         -13.19984
# 8         QRNN_pred     78.242403      0.186086         -13.19984
# 9          ESN_pred     78.242403      0.186086         -13.19984
# 10         BNN_pred     78.242403      0.186086         -13.19984
# 11               __     78.242403      0.186086         -13.19984
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    131.732976      0.149449        -13.199840
# 1            CCV_dw     49.611306     -0.063684        -11.185067
# 2            CCV_cw    104.952375      0.179363        -10.649745
# 3         LSTM_pred     52.518759     -0.218163        -16.219584
# 4          GRU_pred    131.579356      0.286918         -8.732784
# 5     LSTM_GRU_pred    108.368387      0.043192        -11.756572
# 6       BiLSTM_pred     92.018915      0.130039        -14.923582
# 7   BiLSTM_GRU_pred    108.246551      0.297498        -12.341182
# 8         QRNN_pred    120.823031      0.118497        -13.199840
# 9          ESN_pred    120.996912      0.178152        -11.142683
# 10         BNN_pred    267.008711      0.484136        -10.586510
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    102.067221      0.107419        -11.212864
# 1            CCV_dw    145.937899      0.282729        -10.484108
# 2            CCV_cw    169.248586      0.363475        -11.448260
# 3         LSTM_pred    104.837503      0.181829        -11.410281
# 4          GRU_pred    264.984689      0.858061         -9.334142
# 5     LSTM_GRU_pred     57.085092     -0.007145         -7.659336
# 6       BiLSTM_pred    176.812677      0.396420        -11.161812
# 7   BiLSTM_GRU_pred    157.562304      0.230954         -6.432429
# 8         QRNN_pred     78.082531      0.013644        -15.923238
# 9          ESN_pred    132.915557      0.232813        -11.630125
# 10         BNN_pred     24.294833     -0.154849        -15.474228
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    181.877396      0.510495         -4.064074
# 1            CCV_dw      2.803044     -0.463408         -9.103313
# 2            CCV_cw    145.676376      0.354948         -4.973798
# 3         LSTM_pred    -44.056909     -0.630438        -15.783860
# 4          GRU_pred    152.972961      0.439005         -8.599540
# 5     LSTM_GRU_pred    128.419566      0.303252         -7.943292
# 6       BiLSTM_pred      8.983842     -0.468953        -12.425634
# 7   BiLSTM_GRU_pred    247.738367      0.621240         -6.432429
# 8         QRNN_pred    132.619124      0.259017         -5.555543
# 9          ESN_pred    -10.073323     -0.507941        -12.992825
# 10         BNN_pred      5.817451     -0.354653        -12.055379
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     36.521870     -0.181080        -13.503490
# 1            CCV_dw    140.597447      0.274863         -5.888711
# 2            CCV_cw    166.954659      0.407341         -9.221644
# 3         LSTM_pred     -9.602493     -0.440233        -13.947706
# 4          GRU_pred    158.822757      0.376760        -11.485394
# 5     LSTM_GRU_pred     35.126798     -0.108992        -10.039592
# 6       BiLSTM_pred     79.492834      0.006509        -12.196614
# 7   BiLSTM_GRU_pred    211.983460      0.444132         -6.432429
# 8         QRNN_pred     13.538226     -0.303370        -16.912156
# 9          ESN_pred     84.204763      0.020072         -9.966231
# 10         BNN_pred     21.262638     -0.197847        -15.283437
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    155.791017      0.304461        -11.212864
# 1            CCV_dw     99.467827      0.096566         -8.789615
# 2            CCV_cw    253.664776      0.695894         -9.205517
# 3         LSTM_pred     12.655230     -0.220747        -14.170037
# 4          GRU_pred     87.019515      0.035726        -14.827343
# 5     LSTM_GRU_pred     16.070083     -0.181868         -7.968516
# 6       BiLSTM_pred     90.315504      0.125014        -13.780763
# 7   BiLSTM_GRU_pred    169.205076      0.277284         -6.766805
# 8         QRNN_pred      9.352912     -0.297124        -18.467485
# 9          ESN_pred    105.414751      0.125047        -11.096309
# 10         BNN_pred     10.288053     -0.223197        -13.520163
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    152.269586      0.351816         -5.499781
# 1            CCV_dw     51.121569     -0.083029        -11.377210
# 2            CCV_cw    125.972184      0.223756         -9.711141
# 3         LSTM_pred     -6.589964     -0.378926        -16.474093
# 4          GRU_pred     59.339286     -0.115870         -8.710895
# 5     LSTM_GRU_pred     88.036539     -0.040304         -9.751605
# 6       BiLSTM_pred     90.851800      0.054406        -10.964564
# 7   BiLSTM_GRU_pred     66.741266      0.088243         -8.396227
# 8         QRNN_pred    132.619124      0.259017         -5.555543
# 9          ESN_pred     48.220098     -0.145442        -12.727000
# 10         BNN_pred    137.070991      0.021619        -16.591030
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     75.460287     -0.131404        -15.655820
# 1            CCV_dw     37.398087     -0.119495        -11.731000
# 2            CCV_cw    101.033513      0.103415        -11.250735
# 3         LSTM_pred     26.884271     -0.227203        -14.846250
# 4          GRU_pred     65.549315     -0.047671        -10.536883
# 5     LSTM_GRU_pred     94.507749     -0.009317        -12.585940
# 6       BiLSTM_pred     60.762030     -0.062453        -15.699423
# 7   BiLSTM_GRU_pred     75.885059      0.181919         -8.854579
# 8         QRNN_pred     27.900926     -0.231261        -17.252406
# 9          ESN_pred     79.031385      0.002284        -11.142683
# 10         BNN_pred    176.250450      0.181357        -15.387563
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    132.304397      0.159087        -13.199840
# 1            CCV_dw     78.117185      0.044998         -9.321795
# 2            CCV_cw    194.669887      0.458072        -10.745048
# 3         LSTM_pred     34.301899     -0.295987        -16.633486
# 4          GRU_pred    -33.457345     -0.454421        -17.104631
# 5     LSTM_GRU_pred    103.559366      0.025418        -10.893168
# 6       BiLSTM_pred     54.816093     -0.016146        -14.870932
# 7   BiLSTM_GRU_pred    108.745215      0.301758        -10.699123
# 8         QRNN_pred     62.716581     -0.146716        -16.086451
# 9          ESN_pred     99.317527      0.096195        -11.142683
# 10         BNN_pred    177.176046      0.176108        -13.654608
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    152.269586      0.351816         -5.499781
# 1            CCV_dw     42.919659      0.022810        -15.735208
# 2            CCV_cw     81.756880      0.015950        -11.694058
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred     64.564742     -0.122152        -14.706863
# 5     LSTM_GRU_pred     42.587225      0.052897        -14.000931
# 6       BiLSTM_pred     43.094002     -0.209209        -16.337371
# 7   BiLSTM_GRU_pred     64.740160      0.083262        -13.815624
# 8         QRNN_pred    132.619124      0.259017         -5.555543
# 9          ESN_pred     48.220098     -0.145442        -12.727000
# 10         BNN_pred     32.299440     -0.254650        -17.265770
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     75.460287     -0.131404        -15.655820
# 1            CCV_dw     39.773900     -0.072138        -16.532486
# 2            CCV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.156352        -13.199840
# 5     LSTM_GRU_pred     57.758917      0.110689        -14.848792
# 6       BiLSTM_pred     78.242403      0.156352        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     27.900926     -0.231261        -17.252406
# 9          ESN_pred     79.031385      0.002284        -11.142683
# 10         BNN_pred     31.518846     -0.021242        -15.803960
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     78.242403      0.186086        -13.199840
# 1            CCV_dw     78.242403      0.186086        -13.199840
# 2            CCV_cw     78.242403      0.186086        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     78.242403      0.186086        -13.199840
# 6       BiLSTM_pred     78.242403      0.186086        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     78.242403     -0.121785        -15.612725
# 9          ESN_pred     78.242403      0.008575        -13.199840
# 10         BNN_pred     65.316557      0.085360        -14.240391
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    113.094821      0.031455        -14.250829
# 1            CCV_dw     89.919738      0.061762        -12.018994
# 2            CCV_cw    141.919331      0.258399        -11.637162
# 3         LSTM_pred     59.120255     -0.196894        -12.032098
# 4          GRU_pred    131.579356      0.286918         -8.732784
# 5     LSTM_GRU_pred    147.231115      0.257135        -11.065199
# 6       BiLSTM_pred     42.621438     -0.071524        -13.431183
# 7   BiLSTM_GRU_pred    102.333369      0.278254        -11.581371
# 8         QRNN_pred    129.895826      0.087885        -13.586460
# 9          ESN_pred    132.540321      0.225312        -11.676221
# 10         BNN_pred    152.197732      0.362231         -9.812345
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    113.031342      0.151290        -11.960503
# 1            CCV_dw    169.486317      0.390525         -8.397174
# 2            CCV_cw      2.942157     -0.316957        -14.031967
# 3         LSTM_pred     -7.630644     -0.325018        -18.287313
# 4          GRU_pred    264.984689      0.858061         -9.334142
# 5     LSTM_GRU_pred     75.528080      0.069053         -7.596420
# 6       BiLSTM_pred    144.822220      0.356512        -11.022382
# 7   BiLSTM_GRU_pred    157.236863      0.231264         -7.600775
# 8         QRNN_pred    141.754908      0.266548        -10.554888
# 9          ESN_pred    136.978252      0.248889        -11.238195
# 10         BNN_pred     87.794944      0.115472        -14.981892
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     87.555454      0.026768         -5.057242
# 1            CCV_dw    -38.061184     -0.986542         -9.532108
# 2            CCV_cw     38.902839     -0.315432         -4.130944
# 3         LSTM_pred    -87.619746     -0.986245        -19.668329
# 4          GRU_pred    124.717598      0.328640         -5.352963
# 5     LSTM_GRU_pred     76.623954      0.062865         -6.032207
# 6       BiLSTM_pred    112.982849      0.193964         -4.857656
# 7   BiLSTM_GRU_pred    252.229690      0.657013         -6.432429
# 8         QRNN_pred     50.875471     -0.181031         -6.919703
# 9          ESN_pred     -6.065877     -0.537320        -11.544595
# 10         BNN_pred    -15.184375     -0.532798        -15.433210
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     57.164722     -0.112371        -11.194806
# 1            CCV_dw    103.485542      0.115143         -5.855822
# 2            CCV_cw    126.289320      0.246399         -6.928360
# 3         LSTM_pred    -38.548450     -0.646485        -16.710298
# 4          GRU_pred    158.822757      0.376760        -11.485394
# 5     LSTM_GRU_pred     79.812154      0.080548         -7.759666
# 6       BiLSTM_pred    107.000193      0.134948         -6.291509
# 7   BiLSTM_GRU_pred    245.873263      0.593078         -6.432429
# 8         QRNN_pred    111.899201      0.161784         -4.855180
# 9          ESN_pred     55.171426     -0.146267        -11.608510
# 10         BNN_pred     30.602169     -0.167052        -15.707082
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     50.831450     -0.123196        -15.457749
# 1            CCV_dw     86.264230      0.038639         -9.776494
# 2            CCV_cw     17.503092     -0.313401         -9.972127
# 3         LSTM_pred    -56.649715     -0.585057        -19.168513
# 4          GRU_pred     87.019515      0.035726        -14.827343
# 5     LSTM_GRU_pred     82.727257      0.098574         -7.738774
# 6       BiLSTM_pred    148.035929      0.380978         -8.603671
# 7   BiLSTM_GRU_pred    178.040748      0.316528         -6.432429
# 8         QRNN_pred     98.389368      0.166783         -9.548988
# 9          ESN_pred     94.364214      0.072161        -10.702011
# 10         BNN_pred     48.642771     -0.061534        -13.093137
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.833878      0.288737         -5.499781
# 1            CCV_dw    -19.475656     -0.577610        -12.996004
# 2            CCV_cw    111.712434      0.164739         -8.528613
# 3         LSTM_pred    -84.985626     -0.821637        -17.914166
# 4          GRU_pred     39.741303     -0.251270         -7.367592
# 5     LSTM_GRU_pred    128.187929      0.295763         -8.886812
# 6       BiLSTM_pred     43.493540     -0.228313        -10.406738
# 7   BiLSTM_GRU_pred     86.180904      0.167979         -8.669873
# 8         QRNN_pred    116.493747      0.181103         -6.919703
# 9          ESN_pred     35.528099     -0.208459        -13.783714
# 10         BNN_pred    116.184351      0.275800        -11.395140
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     68.567164     -0.044545        -13.978712
# 1            CCV_dw     79.622919      0.016636        -10.114657
# 2            CCV_cw    125.825428      0.213345        -11.152535
# 3         LSTM_pred    -28.743763     -0.508848        -14.026926
# 4          GRU_pred     65.549315     -0.047671        -10.536883
# 5     LSTM_GRU_pred    114.832840      0.137613        -11.883012
# 6       BiLSTM_pred     46.860325     -0.152407        -11.670308
# 7   BiLSTM_GRU_pred     77.366689      0.188032         -8.818114
# 8         QRNN_pred    152.750876      0.353646         -5.499781
# 9          ESN_pred     69.292040     -0.043527        -11.773061
# 10         BNN_pred     97.318651      0.158464        -13.067421
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     77.373731     -0.119094        -15.505756
# 1            CCV_dw     83.507872      0.035551         -9.495355
# 2            CCV_cw     92.068424      0.063925        -11.152535
# 3         LSTM_pred     20.286983     -0.371037        -14.551233
# 4          GRU_pred    -33.457345     -0.454421        -17.104631
# 5     LSTM_GRU_pred    114.242977      0.135036        -10.813859
# 6       BiLSTM_pred     35.326924     -0.106545        -12.619168
# 7   BiLSTM_GRU_pred     98.468806      0.268135         -9.944814
# 8         QRNN_pred     82.517120      0.005690        -13.036245
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred     87.296957      0.113001        -12.912217
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    138.833878      0.288737         -5.499781
# 1            CCV_dw     42.919659     -0.202949        -16.992390
# 2            CCV_cw     82.132529      0.013228        -11.142683
# 3         LSTM_pred     43.094002      0.055456        -14.859156
# 4          GRU_pred     59.533867     -0.181463        -15.487819
# 5     LSTM_GRU_pred     42.587225      0.052897        -14.000931
# 6       BiLSTM_pred     43.094002     -0.209209        -16.337371
# 7   BiLSTM_GRU_pred     51.976177      0.035477        -14.848792
# 8         QRNN_pred    116.493747      0.181103         -6.919703
# 9          ESN_pred     35.528099     -0.208459        -13.783714
# 10         BNN_pred     39.034835     -0.229964        -16.725958
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     68.567164     -0.044545        -13.978712
# 1            CCV_dw     39.773900     -0.072138        -16.532486
# 2            CCV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     57.630169      0.110208        -14.859156
# 4          GRU_pred     78.242403      0.156352        -13.199840
# 5     LSTM_GRU_pred     57.758917      0.110689        -14.848792
# 6       BiLSTM_pred     70.593064      0.128037        -13.815624
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred    152.750876      0.353646         -5.499781
# 9          ESN_pred     69.292040     -0.043527        -11.773061
# 10         BNN_pred     31.518846     -0.021242        -15.803960
# 11               __     78.242403      0.186086        -13.199840
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     70.593064     -0.146850        -16.037538
# 1            CCV_dw     78.242403      0.132971        -13.199840
# 2            CCV_cw     78.242403      0.008575        -13.199840
# 3         LSTM_pred     78.242403      0.186086        -13.199840
# 4          GRU_pred     78.242403      0.073171        -13.444439
# 5     LSTM_GRU_pred     70.593064      0.158138        -13.815624
# 6       BiLSTM_pred     78.242403      0.186086        -13.199840
# 7   BiLSTM_GRU_pred     78.242403      0.186086        -13.199840
# 8         QRNN_pred     82.517120      0.005690        -13.036245
# 9          ESN_pred     90.092617      0.053755        -11.142683
# 10         BNN_pred     50.674747      0.030413        -14.240391
# 11               __     78.242403      0.186086        -13.199840

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_2y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_2y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_2y1', file, 'CCV')
get_final_results_1('2024_2y1', file, 'CCV')

get_final_results('2024_2y1', dw_file, 'CCV_dw')
get_final_results_1('2024_2y1', dw_file, 'CCV_dw')

get_final_results('2024_2y1', cw_file, 'CCV_cw')
get_final_results_1('2024_2y1', cw_file, 'CCV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-30-cf8b11d79c0f>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-30-cf8b11d79c0f>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:38: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-30-cf8b11d79c0f>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-30-cf8b11d79c0f>:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-30-cf8b11d79c0f>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-30-cf8b11d79c0f>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-30-cf8b11d79c0f>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-30-cf8b11d79c0f>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:50: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-30-cf8b11d79c0f>:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-30-cf8b11d79c0f>:56: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-30-cf8b11d79c0f>:60: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    274.796582      0.716368         -8.115590
# 1            CCV_dw    349.695360      0.986408         -9.302629
# 2            CCV_cw    263.385609      0.678503         -9.302629
# 3         LSTM_pred    266.607918      0.718700         -9.823698
# 4          GRU_pred    245.033585      0.624347         -9.345933
# 5     LSTM_GRU_pred    258.829775      0.693337         -9.302629
# 6       BiLSTM_pred    245.225196      0.612624         -8.850512
# 7   BiLSTM_GRU_pred    249.414716      0.625728         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    234.718248      0.577618         -9.302629
# 10         BNN_pred    275.657683      0.723319         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    294.802508      0.825133         -5.283701
# 1            CCV_dw    372.345766      1.088705         -8.588117
# 2            CCV_cw    229.710073      0.594033         -6.500563
# 3         LSTM_pred    211.321062      0.497372         -8.135049
# 4          GRU_pred    278.889689      0.789483         -9.419603
# 5     LSTM_GRU_pred    226.012359      0.604335         -9.345933
# 6       BiLSTM_pred    270.184463      0.772619         -8.850512
# 7   BiLSTM_GRU_pred    278.239877      0.744806        -10.058747
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     92.998849      0.031156         -9.848677
# 10         BNN_pred    179.428693      0.394952         -9.599462
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    307.890816      0.918788         -5.400918
# 1            CCV_dw    263.433108      0.769798         -7.100868
# 2            CCV_cw    130.230083      0.261676         -5.944919
# 3         LSTM_pred    185.131367      0.459486         -7.518746
# 4          GRU_pred    221.984605      0.692752         -7.143998
# 5     LSTM_GRU_pred    282.947387      0.924163         -7.196219
# 6       BiLSTM_pred    206.162575      0.591276         -9.458904
# 7   BiLSTM_GRU_pred    132.161840      0.243935         -8.795689
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     96.656836      0.041977         -7.425819
# 10         BNN_pred    137.086310      0.234912         -8.719271
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    316.011226      0.927369         -5.316812
# 1            CCV_dw    351.295139      1.055098         -7.764192
# 2            CCV_cw    166.893663      0.362195         -6.500563
# 3         LSTM_pred    174.801627      0.408613         -8.135049
# 4          GRU_pred    304.593548      0.905407         -6.850221
# 5     LSTM_GRU_pred    243.022528      0.691298         -8.528839
# 6       BiLSTM_pred    215.325913      0.613070         -8.028952
# 7   BiLSTM_GRU_pred    207.454522      0.539846         -9.610399
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     92.582374      0.027356         -9.036114
# 10         BNN_pred    160.244757      0.322162         -9.599462
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    263.262756      0.702387         -6.749600
# 1            CCV_dw    341.572088      0.988710         -8.588117
# 2            CCV_cw    228.986861      0.593775         -6.500563
# 3         LSTM_pred    230.508188      0.571214         -8.135049
# 4          GRU_pred    290.416731      0.832068         -8.603173
# 5     LSTM_GRU_pred    204.626735      0.526564         -9.470059
# 6       BiLSTM_pred    270.184463      0.772619         -8.850512
# 7   BiLSTM_GRU_pred    282.112606      0.757915        -10.058747
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     86.493372      0.002134         -9.848677
# 10         BNN_pred    170.296796      0.360479         -9.599462
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    337.647095      0.990354         -5.559952
# 1            CCV_dw    309.969420      0.895578         -8.485144
# 2            CCV_cw    181.081694      0.449446         -8.485144
# 3         LSTM_pred    239.761435      0.647010         -8.383588
# 4          GRU_pred    219.764459      0.561602         -7.355253
# 5     LSTM_GRU_pred    268.459421      0.767165         -8.488748
# 6       BiLSTM_pred    209.010669      0.529926         -9.458904
# 7   BiLSTM_GRU_pred    215.118894      0.500497         -9.177845
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    155.955340      0.286650        -10.134016
# 10         BNN_pred    200.104758      0.469144         -8.890511
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    350.613102      1.026492         -5.496404
# 1            CCV_dw    348.622220      1.026225         -8.485144
# 2            CCV_cw    177.973129      0.386181         -9.302629
# 3         LSTM_pred    228.955533      0.594780         -9.823698
# 4          GRU_pred    243.212918      0.674080         -7.236876
# 5     LSTM_GRU_pred    263.590722      0.724247         -8.485144
# 6       BiLSTM_pred    228.494665      0.595480         -8.028952
# 7   BiLSTM_GRU_pred    236.468734      0.581490         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    221.568046      0.523949         -9.252686
# 10         BNN_pred    249.384750      0.635812         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    277.423613      0.725374         -8.115590
# 1            CCV_dw    349.695360      0.986408         -9.302629
# 2            CCV_cw    251.051117      0.636583         -9.302629
# 3         LSTM_pred    257.272814      0.686984         -9.823698
# 4          GRU_pred    245.033585      0.665090         -8.528839
# 5     LSTM_GRU_pred    235.267035      0.613715         -9.302629
# 6       BiLSTM_pred    245.225196      0.612624         -8.850512
# 7   BiLSTM_GRU_pred    249.414716      0.625728         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    234.965015      0.578486         -9.302629
# 10         BNN_pred    261.218486      0.675004         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    215.379981      0.509857         -9.302629
# 1            CCV_dw    197.145991      0.471901         -8.485144
# 2            CCV_cw    217.841155      0.558446         -8.485144
# 3         LSTM_pred    215.774266      0.501687         -9.177845
# 4          GRU_pred    209.460362      0.487498         -9.035617
# 5     LSTM_GRU_pred    206.158745      0.502899         -8.488748
# 6       BiLSTM_pred    225.201940      0.583616         -8.485144
# 7   BiLSTM_GRU_pred    240.605417      0.589908         -9.177845
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    198.240666      0.443134         -9.177845
# 10         BNN_pred    221.163208      0.535138         -8.890511
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    225.931670      0.546964         -9.302629
# 1            CCV_dw    246.769469      0.656361         -8.485144
# 2            CCV_cw    224.361978      0.541410         -9.302629
# 3         LSTM_pred    235.968788      0.580680         -9.302629
# 4          GRU_pred    229.351211      0.598818         -8.485144
# 5     LSTM_GRU_pred    229.351211      0.598818         -8.485144
# 6       BiLSTM_pred    235.968788      0.620363         -8.485144
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.628959         -9.177845
# 10         BNN_pred    235.968788      0.580680         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    252.801107      0.637340         -9.302629
# 1            CCV_dw    252.801107      0.637340         -9.302629
# 2            CCV_cw    252.801107      0.637340         -9.302629
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.676986         -8.485144
# 5     LSTM_GRU_pred    229.351211      0.559033         -9.302629
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.637340         -9.302629
# 10         BNN_pred    252.801107      0.637340         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    256.508972      0.652017         -8.046987
# 1            CCV_dw    315.948267      0.893135         -8.588117
# 2            CCV_cw    234.359773      0.579880         -9.302629
# 3         LSTM_pred    296.079882      0.773057         -8.850512
# 4          GRU_pred    222.329955      0.538679         -9.419603
# 5     LSTM_GRU_pred    196.671844      0.469597         -9.345933
# 6       BiLSTM_pred    256.733632      0.651514         -9.302629
# 7   BiLSTM_GRU_pred    202.360469      0.484487         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    264.512076      0.686366         -9.302629
# 10         BNN_pred    254.906371      0.654146        -10.712777
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    289.207047      0.798031         -5.616443
# 1            CCV_dw    350.328217      1.031661         -8.021596
# 2            CCV_cw    262.331946      0.688430         -9.302629
# 3         LSTM_pred    270.605234      0.711183         -7.143639
# 4          GRU_pred    211.260337      0.534474         -9.222801
# 5     LSTM_GRU_pred    173.995184      0.392194         -9.345933
# 6       BiLSTM_pred    204.014712      0.546077         -8.850512
# 7   BiLSTM_GRU_pred    224.656068      0.546884         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    195.546870      0.440887        -11.388617
# 10         BNN_pred    203.361832      0.486624         -9.599462
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    246.857741      0.718244         -5.964798
# 1            CCV_dw    312.352708      0.938422         -6.794612
# 2            CCV_cw    181.388058      0.424075         -8.890511
# 3         LSTM_pred    220.629095      0.586582         -7.262846
# 4          GRU_pred    230.936651      0.704457         -6.582078
# 5     LSTM_GRU_pred    252.343451      0.749761         -8.021596
# 6       BiLSTM_pred    211.451143      0.601052         -9.458904
# 7   BiLSTM_GRU_pred     43.730972     -0.159997         -9.687645
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    189.180596      0.460272         -5.564933
# 10         BNN_pred    151.362796      0.294984         -8.719271
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    311.231487      0.906718         -5.661484
# 1            CCV_dw    347.219959      1.026101         -7.627198
# 2            CCV_cw    227.222060      0.619372         -8.485144
# 3         LSTM_pred    237.252506      0.647790         -7.262846
# 4          GRU_pred    264.592881      0.746364         -7.352433
# 5     LSTM_GRU_pred    220.049906      0.583101         -8.065511
# 6       BiLSTM_pred    223.399482      0.635741         -8.028952
# 7   BiLSTM_GRU_pred    119.359261      0.180952         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    238.395670      0.609636        -10.589934
# 10         BNN_pred    192.574246      0.449152         -9.599462
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    209.495788      0.498117         -9.766839
# 1            CCV_dw    342.232878      1.007722         -7.627198
# 2            CCV_cw    233.784257      0.592336         -9.302629
# 3         LSTM_pred    290.863628      0.834327         -7.143639
# 4          GRU_pred    247.801976      0.675862         -8.140222
# 5     LSTM_GRU_pred    205.480435      0.515135         -9.345933
# 6       BiLSTM_pred    198.655800      0.525855         -8.850512
# 7   BiLSTM_GRU_pred    196.635740      0.488615         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    184.601066      0.399529        -11.388617
# 10         BNN_pred    189.740952      0.435799         -9.599462
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    303.918008      0.893539         -5.703774
# 1            CCV_dw    310.776394      0.893252         -7.100868
# 2            CCV_cw    162.610521      0.338916         -8.890511
# 3         LSTM_pred    257.692347      0.695528         -8.850512
# 4          GRU_pred    267.107943      0.779278         -6.582078
# 5     LSTM_GRU_pred    240.187258      0.663085         -8.021596
# 6       BiLSTM_pred    229.490117      0.601494         -8.485144
# 7   BiLSTM_GRU_pred    193.256468      0.470515         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    181.469451      0.401239         -9.035617
# 10         BNN_pred    221.656416      0.548601        -10.307067
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    318.956548      0.911579         -5.628325
# 1            CCV_dw    315.954446      0.894465         -8.588117
# 2            CCV_cw    209.066024      0.542696         -8.485144
# 3         LSTM_pred    274.820512      0.753424         -8.850512
# 4          GRU_pred    285.561426      0.777673         -7.242169
# 5     LSTM_GRU_pred    241.353216      0.650810         -8.065511
# 6       BiLSTM_pred    221.775373      0.572125         -8.485144
# 7   BiLSTM_GRU_pred    197.876817      0.470959         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    274.043196      0.717777         -9.177845
# 10         BNN_pred    242.661356      0.615831        -10.712777
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    242.726552      0.605445         -9.055603
# 1            CCV_dw    311.083102      0.876875         -8.588117
# 2            CCV_cw    220.117517      0.534685         -9.302629
# 3         LSTM_pred    268.851025      0.728391         -8.850512
# 4          GRU_pred    237.403181      0.597561         -8.140222
# 5     LSTM_GRU_pred    211.087943      0.524907         -9.345933
# 6       BiLSTM_pred    256.733632      0.651514         -9.302629
# 7   BiLSTM_GRU_pred    203.186396      0.488740         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    272.118408      0.713094         -9.302629
# 10         BNN_pred    240.702058      0.605459        -10.712777
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    208.166066      0.509320         -8.488748
# 1            CCV_dw    219.650036      0.551252         -8.485144
# 2            CCV_cw    202.349325      0.468780         -8.890511
# 3         LSTM_pred    235.968788      0.580680         -9.302629
# 4          GRU_pred    210.900137      0.534603         -8.485144
# 5     LSTM_GRU_pred    206.158745      0.478474         -9.302629
# 6       BiLSTM_pred    225.201940      0.583616         -8.485144
# 7   BiLSTM_GRU_pred    257.500880      0.655272         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    205.358812      0.474469         -9.035617
# 10         BNN_pred    233.622196      0.579034         -8.890511
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    224.361978      0.541410         -9.302629
# 1            CCV_dw    252.801107      0.637340         -9.302629
# 2            CCV_cw    215.379981      0.549594         -8.485144
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    229.351211      0.559033         -9.302629
# 6       BiLSTM_pred    235.968788      0.620363         -8.485144
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    248.333119      0.613598         -9.177845
# 10         BNN_pred    235.968788      0.580680         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    252.801107      0.637340         -9.302629
# 1            CCV_dw    252.801107      0.637340         -9.302629
# 2            CCV_cw    225.931670      0.546964         -9.302629
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    252.801107      0.637340         -9.302629
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.637340         -9.302629
# 10         BNN_pred    252.801107      0.637340         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    220.350861      0.545479         -9.302629
# 1            CCV_dw    354.890786      1.048385         -8.588117
# 2            CCV_cw    194.148921      0.440011        -10.132498
# 3         LSTM_pred    220.419441      0.518859         -8.850512
# 4          GRU_pred    245.093082      0.686616        -10.125437
# 5     LSTM_GRU_pred    256.911628      0.680904         -9.376334
# 6       BiLSTM_pred    186.396278      0.467728         -8.850512
# 7   BiLSTM_GRU_pred    131.775767      0.203311         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    281.418945      0.751906         -7.664771
# 10         BNN_pred    125.416218      0.183632        -11.692153
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    236.498876      0.609226         -8.446027
# 1            CCV_dw    305.101320      0.904656         -6.881637
# 2            CCV_cw    209.155895      0.516700        -10.132498
# 3         LSTM_pred    229.038069      0.593385         -8.192869
# 4          GRU_pred     94.719599      0.074160        -10.172832
# 5     LSTM_GRU_pred    150.804995      0.312027        -11.572865
# 6       BiLSTM_pred    155.560693      0.343919        -10.394517
# 7   BiLSTM_GRU_pred    138.041893      0.258025         -8.850512
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    154.814769      0.315682         -7.664771
# 10         BNN_pred    156.322171      0.293029         -6.605864
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    181.823534      0.557592         -6.943868
# 1            CCV_dw    152.826290      0.391304         -5.229502
# 2            CCV_cw     29.839822     -0.405386         -9.035617
# 3         LSTM_pred     71.486026     -0.043594         -8.618110
# 4          GRU_pred     79.674221     -0.028144         -5.275089
# 5     LSTM_GRU_pred     72.659862     -0.048688         -5.795911
# 6       BiLSTM_pred     58.681146     -0.144895         -8.160141
# 7   BiLSTM_GRU_pred      5.129090     -0.409086         -7.990384
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    110.235231      0.158570         -6.135392
# 10         BNN_pred    156.996690      0.348050         -7.750382
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    212.304526      0.693544         -5.325611
# 1            CCV_dw    240.883015      0.693508         -7.433755
# 2            CCV_cw    107.173446      0.103397         -9.035617
# 3         LSTM_pred    173.762168      0.434963         -7.735220
# 4          GRU_pred     79.610755     -0.013878         -7.923209
# 5     LSTM_GRU_pred    131.611376      0.256028         -8.915011
# 6       BiLSTM_pred    111.029793      0.158063        -10.144626
# 7   BiLSTM_GRU_pred     83.859958      0.024599         -8.850512
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    156.401294      0.392759         -5.810509
# 10         BNN_pred    125.796437      0.168711         -7.294682
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    208.458381      0.599676         -6.771430
# 1            CCV_dw    269.018000      0.781459         -6.881637
# 2            CCV_cw    214.212685      0.550998         -9.035617
# 3         LSTM_pred    184.264097      0.473553         -7.735220
# 4          GRU_pred    129.053697      0.253475         -8.219467
# 5     LSTM_GRU_pred    213.165096      0.572794         -7.242169
# 6       BiLSTM_pred    145.156788      0.324393         -9.540841
# 7   BiLSTM_GRU_pred     90.818725      0.057965         -8.850512
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    226.840776      0.696708         -5.248582
# 10         BNN_pred    102.759315      0.060619         -7.445391
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    125.332632      0.238748         -8.485144
# 1            CCV_dw    226.277087      0.643340         -7.100868
# 2            CCV_cw     62.731520     -0.147398         -9.035617
# 3         LSTM_pred     78.081681      0.002909         -8.721512
# 4          GRU_pred    179.885751      0.553093         -5.450334
# 5     LSTM_GRU_pred    168.194000      0.416348         -5.774263
# 6       BiLSTM_pred    101.085317      0.104853         -9.458904
# 7   BiLSTM_GRU_pred     56.348238     -0.137308         -8.086634
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    240.662764      0.703844         -6.246893
# 10         BNN_pred    108.897481      0.118063        -11.304580
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.841089      0.408131         -8.485144
# 1            CCV_dw    363.645466      1.104073         -7.930717
# 2            CCV_cw     92.463857      0.031957         -9.035617
# 3         LSTM_pred    186.866398      0.446906         -8.850512
# 4          GRU_pred    245.893644      0.780849         -6.582078
# 5     LSTM_GRU_pred    179.335642      0.444439         -8.915011
# 6       BiLSTM_pred    187.556889      0.486200         -9.458904
# 7   BiLSTM_GRU_pred     73.387580     -0.039813         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    272.744066      0.823016         -5.939841
# 10         BNN_pred     90.306347      0.035791        -11.008635
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    167.826597      0.416789         -8.485144
# 1            CCV_dw    368.269905      1.098048         -8.588117
# 2            CCV_cw    196.261980      0.457260         -9.035617
# 3         LSTM_pred    193.840840      0.471780         -8.850512
# 4          GRU_pred    258.892060      0.805316         -8.684354
# 5     LSTM_GRU_pred    264.340105      0.728195         -7.638211
# 6       BiLSTM_pred    187.999123      0.481023         -8.850512
# 7   BiLSTM_GRU_pred    121.888799      0.165135         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    329.730066      0.992680         -5.683714
# 10         BNN_pred    102.148742      0.087172        -11.692153
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    125.332632      0.238748         -8.485144
# 1            CCV_dw    157.557881      0.325990         -8.485144
# 2            CCV_cw     48.021170     -0.207362        -13.456853
# 3         LSTM_pred    202.200264      0.455721         -9.177845
# 4          GRU_pred    202.858870      0.464722         -9.035617
# 5     LSTM_GRU_pred    134.214139      0.219737         -9.302629
# 6       BiLSTM_pred    213.539977      0.543263         -8.485144
# 7   BiLSTM_GRU_pred    213.042123      0.503885         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    115.702083      0.162799        -12.267414
# 10         BNN_pred    221.163208      0.535138         -8.890511
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.841089      0.408131         -8.485144
# 1            CCV_dw    219.650036      0.526433         -9.302629
# 2            CCV_cw    136.332244      0.233350         -9.035617
# 3         LSTM_pred    245.482218      0.614482         -9.302629
# 4          GRU_pred    209.460362      0.529419         -8.485144
# 5     LSTM_GRU_pred    206.158745      0.478474         -9.302629
# 6       BiLSTM_pred    230.018190      0.599649         -8.485144
# 7   BiLSTM_GRU_pred    235.968788      0.580680         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    144.552127      0.276600        -12.267414
# 10         BNN_pred    233.622196      0.613636         -8.485144
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    167.826597      0.416789         -8.485144
# 1            CCV_dw    246.769469      0.616737         -9.302629
# 2            CCV_cw    196.621938      0.441023         -9.035617
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    212.833959      0.501729         -9.302629
# 6       BiLSTM_pred    235.968788      0.580680         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.662267         -8.488748
# 10         BNN_pred    235.968788      0.580680         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    245.869572      0.622688        -10.128959
# 1            CCV_dw    326.972811      0.993036         -9.063396
# 2            CCV_cw    174.845860      0.374612        -10.132498
# 3         LSTM_pred    205.414074      0.478164         -7.143639
# 4          GRU_pred    245.093082      0.686616        -10.125437
# 5     LSTM_GRU_pred    297.933458      0.839192         -8.662402
# 6       BiLSTM_pred    153.259678      0.335118         -8.894031
# 7   BiLSTM_GRU_pred    188.698757      0.429911         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    193.496724      0.444652        -10.530121
# 10         BNN_pred    188.408597      0.425292         -8.133188
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    200.498007      0.473731         -9.942738
# 1            CCV_dw    279.126973      0.836823         -7.730025
# 2            CCV_cw     73.675089     -0.048984        -12.577965
# 3         LSTM_pred    227.709049      0.647406         -7.783947
# 4          GRU_pred     94.719599      0.074160        -10.172832
# 5     LSTM_GRU_pred     55.271149     -0.112584        -11.572865
# 6       BiLSTM_pred    180.409202      0.402949        -10.335645
# 7   BiLSTM_GRU_pred    156.238817      0.339264         -8.096342
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     95.295860      0.044949         -7.664771
# 10         BNN_pred    117.577617      0.127711         -7.898023
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     85.631619      0.011767         -6.675080
# 1            CCV_dw    174.173529      0.697266         -5.189190
# 2            CCV_cw     -9.883753     -0.727195         -9.140502
# 3         LSTM_pred     85.681340      0.023475         -6.749072
# 4          GRU_pred    112.292979      0.204050         -4.195281
# 5     LSTM_GRU_pred     93.502514      0.065518         -5.754832
# 6       BiLSTM_pred    103.453318      0.128195         -6.566848
# 7   BiLSTM_GRU_pred    -34.612285     -0.670523        -11.125812
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred      0.710055     -0.580040         -9.766445
# 10         BNN_pred     65.016169     -0.106485         -7.707033
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    185.741820      0.598116         -5.325611
# 1            CCV_dw    154.693639      0.324841         -9.245010
# 2            CCV_cw     13.539244     -0.451612         -9.682441
# 3         LSTM_pred    164.120376      0.417217         -6.584778
# 4          GRU_pred     79.610755     -0.013878         -7.923209
# 5     LSTM_GRU_pred     93.646857      0.067218         -7.506307
# 6       BiLSTM_pred     97.366293      0.087303         -8.843067
# 7   BiLSTM_GRU_pred     44.885629     -0.183676         -7.638211
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred     67.895162     -0.086259         -8.628833
# 10         BNN_pred     17.609877     -0.390354         -7.575952
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    144.839446      0.319629         -8.295517
# 1            CCV_dw    234.228338      0.672604         -7.616544
# 2            CCV_cw     -6.317479     -0.514156        -13.663070
# 3         LSTM_pred    170.282933      0.425831         -7.164415
# 4          GRU_pred    129.053697      0.253475         -8.219467
# 5     LSTM_GRU_pred    180.002793      0.457416         -6.625866
# 6       BiLSTM_pred    137.185627      0.290675         -8.725504
# 7   BiLSTM_GRU_pred    114.240257      0.165347         -8.096342
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    135.660597      0.286641         -6.938335
# 10         BNN_pred     39.400921     -0.255195         -8.521508
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    122.953644      0.226653         -8.485144
# 1            CCV_dw    274.562721      0.968038         -4.261275
# 2            CCV_cw     41.817041     -0.289036         -9.326783
# 3         LSTM_pred    110.339520      0.146059         -7.577012
# 4          GRU_pred    217.720296      0.781094         -4.733476
# 5     LSTM_GRU_pred     98.245335      0.114562         -5.690131
# 6       BiLSTM_pred     45.092185     -0.195329         -7.786359
# 7   BiLSTM_GRU_pred      9.097441     -0.399975         -8.021596
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    162.112312      0.388796         -6.160174
# 10         BNN_pred     97.708428      0.028661         -8.686128
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    144.664384      0.338500         -8.485144
# 1            CCV_dw    266.510718      0.821856         -6.404108
# 2            CCV_cw     73.073125     -0.067251         -9.035617
# 3         LSTM_pred    178.442662      0.427908         -7.158803
# 4          GRU_pred    245.893644      0.780849         -6.582078
# 5     LSTM_GRU_pred    171.130605      0.420176         -7.506307
# 6       BiLSTM_pred    107.705270      0.135975         -9.502133
# 7   BiLSTM_GRU_pred     64.613329     -0.092258         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    200.477176      0.550325         -6.448191
# 10         BNN_pred    127.049817      0.172253         -7.562655
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    188.107453      0.493057         -8.485144
# 1            CCV_dw    274.982914      0.824796         -7.800867
# 2            CCV_cw    101.743102      0.075918         -9.035617
# 3         LSTM_pred    169.441304      0.390806         -7.580749
# 4          GRU_pred    258.892060      0.805316         -8.684354
# 5     LSTM_GRU_pred    276.334360      0.795849         -7.242169
# 6       BiLSTM_pred    145.260591      0.306177         -8.072864
# 7   BiLSTM_GRU_pred    122.703789      0.170729         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    299.028009      0.923883         -5.792934
# 10         BNN_pred    171.110412      0.359284         -8.394285
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    122.953644      0.226653         -8.485144
# 1            CCV_dw    157.557881      0.325990         -8.485144
# 2            CCV_cw     48.873752     -0.204010        -13.456853
# 3         LSTM_pred    202.200264      0.455721         -9.177845
# 4          GRU_pred    200.123035      0.481345         -8.488748
# 5     LSTM_GRU_pred    134.214139      0.262629         -8.485144
# 6       BiLSTM_pred    211.796752      0.538029         -8.485144
# 7   BiLSTM_GRU_pred    187.438110      0.412838         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred     89.579996      0.055226        -12.267414
# 10         BNN_pred    179.391073      0.385919         -8.890511
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    144.664384      0.338500         -8.485144
# 1            CCV_dw    176.862798      0.397762         -8.485144
# 2            CCV_cw    143.162682      0.263928         -9.035617
# 3         LSTM_pred    245.482218      0.614482         -9.302629
# 4          GRU_pred    209.460362      0.529419         -8.485144
# 5     LSTM_GRU_pred    204.724608      0.473288         -9.302629
# 6       BiLSTM_pred    230.018190      0.599649         -8.485144
# 7   BiLSTM_GRU_pred    208.084995      0.485426         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    127.353351      0.209685        -12.267414
# 10         BNN_pred    233.622196      0.613636         -8.485144
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    167.826597      0.399161         -8.485144
# 1            CCV_dw    246.769469      0.616737         -9.302629
# 2            CCV_cw    193.353818      0.429272         -9.035617
# 3         LSTM_pred    235.968788      0.580680         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    210.900137      0.494792         -9.302629
# 6       BiLSTM_pred    235.968788      0.620363         -8.485144
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    234.902217      0.601440         -8.488748
# 10         BNN_pred    235.968788      0.580680         -9.302629
# 11               __    252.801107      0.637340         -9.302629

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    274.796582      0.716368         -8.115590
# 1            CCV_dw    298.203815      0.821548         -9.302629
# 2            CCV_cw    255.690056      0.653296         -9.564104
# 3         LSTM_pred    238.717578      0.589213         -9.302629
# 4          GRU_pred    245.033585      0.624347         -9.345933
# 5     LSTM_GRU_pred    252.801107      0.637340         -9.302629
# 6       BiLSTM_pred    234.974384      0.576658         -9.302629
# 7   BiLSTM_GRU_pred    217.046216      0.515079         -9.161092
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    175.171372      0.367227         -9.302629
# 10         BNN_pred    279.605854      0.737166         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    294.802508      0.825133         -5.283701
# 1            CCV_dw    304.457454      0.889403         -8.588117
# 2            CCV_cw    172.609516      0.342379         -8.525080
# 3         LSTM_pred    210.029773      0.548951         -8.680115
# 4          GRU_pred    278.889689      0.789483         -9.419603
# 5     LSTM_GRU_pred    284.194151      0.781818         -9.152164
# 6       BiLSTM_pred    127.670638      0.188619         -9.090814
# 7   BiLSTM_GRU_pred    287.929090      0.797289         -7.972201
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    187.763105      0.402266        -10.791571
# 10         BNN_pred    228.162691      0.576998         -9.113290
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    307.890816      0.918788         -5.400918
# 1            CCV_dw    305.822423      0.915580         -8.588117
# 2            CCV_cw    218.286614      0.566818         -7.261036
# 3         LSTM_pred    162.288634      0.379476         -8.610086
# 4          GRU_pred    221.984605      0.692752         -7.143998
# 5     LSTM_GRU_pred    266.192048      0.748457         -8.540049
# 6       BiLSTM_pred     74.067563     -0.045988        -14.140620
# 7   BiLSTM_GRU_pred    180.518596      0.436716         -7.156602
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    213.058236      0.536690         -8.865148
# 10         BNN_pred    196.881533      0.472127        -10.526383
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    316.011226      0.927369         -5.316812
# 1            CCV_dw    278.584013      0.806395         -8.588117
# 2            CCV_cw    210.761154      0.512058         -6.922808
# 3         LSTM_pred    203.963843      0.531036         -8.680115
# 4          GRU_pred    304.593548      0.905407         -6.850221
# 5     LSTM_GRU_pred    260.920212      0.705701         -8.540049
# 6       BiLSTM_pred    110.808138      0.120058         -9.063003
# 7   BiLSTM_GRU_pred    198.360955      0.510702         -6.922808
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    192.709041      0.435561         -9.287379
# 10         BNN_pred    191.618666      0.444989        -10.526383
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    263.262756      0.702387         -6.749600
# 1            CCV_dw    323.955025      0.965538         -8.588117
# 2            CCV_cw    220.051371      0.530296         -6.922808
# 3         LSTM_pred    205.468194      0.531227         -8.680115
# 4          GRU_pred    290.416731      0.832068         -8.603173
# 5     LSTM_GRU_pred    278.011371      0.760062         -9.152164
# 6       BiLSTM_pred    136.350481      0.223782         -8.406502
# 7   BiLSTM_GRU_pred    265.714886      0.720257         -7.972201
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    149.735821      0.255534        -10.791571
# 10         BNN_pred    212.990134      0.521901         -9.113290
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    337.647095      0.990354         -5.559952
# 1            CCV_dw    293.800328      0.822864         -9.302629
# 2            CCV_cw    228.241498      0.650208         -6.106159
# 3         LSTM_pred    235.041645      0.576491         -9.302629
# 4          GRU_pred    219.764459      0.561602         -7.355253
# 5     LSTM_GRU_pred    200.255879      0.460218         -9.302629
# 6       BiLSTM_pred    180.215168      0.385825         -9.302629
# 7   BiLSTM_GRU_pred    181.241003      0.392531         -7.553010
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    123.293571      0.159423        -10.134016
# 10         BNN_pred    214.771596      0.518281         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    350.613102      1.026492         -5.496404
# 1            CCV_dw    304.051255      0.846622         -9.302629
# 2            CCV_cw    190.666007      0.443395         -8.219144
# 3         LSTM_pred    234.299817      0.573891         -9.302629
# 4          GRU_pred    243.212918      0.674080         -7.236876
# 5     LSTM_GRU_pred    213.056535      0.502888         -9.302629
# 6       BiLSTM_pred    240.041848      0.595060         -9.302629
# 7   BiLSTM_GRU_pred    179.495246      0.385942         -7.553010
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    123.623892      0.159731         -9.252686
# 10         BNN_pred    253.251606      0.649697         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    277.423613      0.725374         -8.115590
# 1            CCV_dw    317.240175      0.890902         -9.302629
# 2            CCV_cw    247.745262      0.627091         -8.913724
# 3         LSTM_pred    238.717578      0.589213         -9.302629
# 4          GRU_pred    245.033585      0.665090         -8.528839
# 5     LSTM_GRU_pred    246.769469      0.616737         -9.302629
# 6       BiLSTM_pred    244.480160      0.610415         -9.302629
# 7   BiLSTM_GRU_pred    202.242401      0.463037         -9.161092
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    158.186331      0.304015         -9.302629
# 10         BNN_pred    265.121967      0.688856         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    215.379981      0.509857         -9.302629
# 1            CCV_dw    219.650036      0.526433         -9.302629
# 2            CCV_cw    217.841155      0.558446         -8.485144
# 3         LSTM_pred    248.333119      0.622043         -9.302629
# 4          GRU_pred    209.460362      0.487498         -9.035617
# 5     LSTM_GRU_pred    200.255879      0.460218         -9.302629
# 6       BiLSTM_pred    197.251447      0.448020         -9.302629
# 7   BiLSTM_GRU_pred    232.528829      0.569057         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    220.089039      0.519002         -9.177845
# 10         BNN_pred    231.129238      0.564640         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    225.931670      0.546964         -9.302629
# 1            CCV_dw    246.769469      0.616737         -9.302629
# 2            CCV_cw    224.361978      0.541410         -9.302629
# 3         LSTM_pred    248.333119      0.622043         -9.302629
# 4          GRU_pred    229.351211      0.598818         -8.485144
# 5     LSTM_GRU_pred    213.056535      0.502888         -9.302629
# 6       BiLSTM_pred    257.941718      0.655790         -9.302629
# 7   BiLSTM_GRU_pred    232.528829      0.569057         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.628959         -9.177845
# 10         BNN_pred    235.968788      0.580680         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    252.801107      0.637340         -9.302629
# 1            CCV_dw    252.801107      0.637340         -9.302629
# 2            CCV_cw    252.801107      0.637340         -9.302629
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.676986         -8.485144
# 5     LSTM_GRU_pred    246.769469      0.616737         -9.302629
# 6       BiLSTM_pred    262.444097      0.671101         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.637340         -9.302629
# 10         BNN_pred    252.801107      0.637340         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    256.508972      0.652017         -8.046987
# 1            CCV_dw    265.806182      0.696551         -8.588117
# 2            CCV_cw    259.610463      0.679661         -8.436466
# 3         LSTM_pred    209.362848      0.486875         -9.302629
# 4          GRU_pred    222.329955      0.538679         -9.419603
# 5     LSTM_GRU_pred    262.796980      0.679287         -8.171731
# 6       BiLSTM_pred    202.859656      0.466348         -9.302629
# 7   BiLSTM_GRU_pred    169.569797      0.359404         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    201.586379      0.466528         -9.302629
# 10         BNN_pred    281.196219      0.743798         -8.132438
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    289.207047      0.798031         -5.616443
# 1            CCV_dw    334.621557      0.979625         -8.588117
# 2            CCV_cw    263.022558      0.681735         -6.702461
# 3         LSTM_pred    241.345669      0.661922         -8.176300
# 4          GRU_pred    211.260337      0.534474         -9.222801
# 5     LSTM_GRU_pred    272.229120      0.737844         -6.345449
# 6       BiLSTM_pred    159.187683      0.304746         -8.739466
# 7   BiLSTM_GRU_pred    350.942242      1.035494         -5.129032
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    150.612126      0.258227        -11.388617
# 10         BNN_pred    203.879070      0.482594        -11.042537
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    246.857741      0.718244         -5.964798
# 1            CCV_dw    283.081078      0.818950         -7.930717
# 2            CCV_cw    277.170004      0.820893         -5.561188
# 3         LSTM_pred    161.865393      0.370298         -7.166729
# 4          GRU_pred    230.936651      0.704457         -6.582078
# 5     LSTM_GRU_pred    142.745353      0.259965         -8.540515
# 6       BiLSTM_pred    121.256396      0.158036        -10.324261
# 7   BiLSTM_GRU_pred    218.001985      0.618347         -5.391873
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    216.659813      0.548288         -8.028523
# 10         BNN_pred    179.597349      0.401051         -9.357885
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    311.231487      0.906718         -5.661484
# 1            CCV_dw    335.306098      0.990420         -8.588117
# 2            CCV_cw    252.341640      0.666438         -6.106159
# 3         LSTM_pred    220.274902      0.586768         -8.176300
# 4          GRU_pred    264.592881      0.746364         -7.352433
# 5     LSTM_GRU_pred    255.405512      0.691378         -5.714423
# 6       BiLSTM_pred    112.980245      0.118357         -8.739466
# 7   BiLSTM_GRU_pred    225.263546      0.636316         -5.633538
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    153.265772      0.272560        -10.589934
# 10         BNN_pred    184.536485      0.411834        -10.599093
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    209.495788      0.498117         -9.766839
# 1            CCV_dw    313.571145      0.909783         -8.588117
# 2            CCV_cw    212.198034      0.500278         -8.674393
# 3         LSTM_pred    223.015683      0.596191         -8.176300
# 4          GRU_pred    247.801976      0.675862         -8.140222
# 5     LSTM_GRU_pred    272.705046      0.739433         -6.345449
# 6       BiLSTM_pred    159.187683      0.304746         -8.739466
# 7   BiLSTM_GRU_pred    234.903035      0.664769         -5.278349
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    107.122317      0.082358        -11.388617
# 10         BNN_pred    214.889109      0.522873         -9.187149
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    303.918008      0.893539         -5.703774
# 1            CCV_dw    249.538048      0.645269         -7.930717
# 2            CCV_cw    245.500790      0.700965         -5.694563
# 3         LSTM_pred    233.548554      0.577303         -9.302629
# 4          GRU_pred    267.107943      0.779278         -6.582078
# 5     LSTM_GRU_pred    177.955821      0.378379         -9.778808
# 6       BiLSTM_pred    149.524418      0.271647         -9.302629
# 7   BiLSTM_GRU_pred     94.368717      0.092680         -8.485144
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    163.054544      0.328672         -9.035617
# 10         BNN_pred    219.922080      0.541919         -8.305157
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    318.956548      0.911579         -5.628325
# 1            CCV_dw    268.620611      0.710437         -8.588117
# 2            CCV_cw    228.525559      0.630446         -6.106159
# 3         LSTM_pred    223.705995      0.541916         -9.302629
# 4          GRU_pred    285.561426      0.777673         -7.242169
# 5     LSTM_GRU_pred    238.293673      0.596780         -7.697052
# 6       BiLSTM_pred    207.795343      0.484769         -9.302629
# 7   BiLSTM_GRU_pred    121.507795      0.165433         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    193.708735      0.437471         -9.177845
# 10         BNN_pred    234.953240      0.588302         -9.560780
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    242.726552      0.605445         -9.055603
# 1            CCV_dw    245.841165      0.627923         -8.588117
# 2            CCV_cw    234.346687      0.595137         -7.232052
# 3         LSTM_pred    214.279747      0.507555         -9.302629
# 4          GRU_pred    237.403181      0.597561         -8.140222
# 5     LSTM_GRU_pred    259.177849      0.667030         -8.171731
# 6       BiLSTM_pred    202.859656      0.466348         -9.302629
# 7   BiLSTM_GRU_pred    146.265651      0.267006         -9.302629
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    191.085083      0.429406         -9.302629
# 10         BNN_pred    266.694330      0.695415         -8.132438
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    208.166066      0.509320         -8.488748
# 1            CCV_dw    246.769469      0.616737         -9.302629
# 2            CCV_cw    207.075742      0.485160         -8.890511
# 3         LSTM_pred    255.484213      0.647058         -9.302629
# 4          GRU_pred    210.900137      0.534603         -8.485144
# 5     LSTM_GRU_pred    177.326050      0.370186         -9.613849
# 6       BiLSTM_pred    197.251447      0.448020         -9.302629
# 7   BiLSTM_GRU_pred    232.528829      0.608756         -8.485144
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    248.333119      0.620511         -9.035617
# 10         BNN_pred    243.049053      0.605744         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    224.361978      0.541410         -9.302629
# 1            CCV_dw    252.801107      0.637340         -9.302629
# 2            CCV_cw    215.379981      0.549594         -8.485144
# 3         LSTM_pred    248.333119      0.622043         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    228.467324      0.554846         -9.302629
# 6       BiLSTM_pred    257.941718      0.655790         -9.302629
# 7   BiLSTM_GRU_pred    232.528829      0.569057         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.628959         -9.177845
# 10         BNN_pred    235.968788      0.580680         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    252.801107      0.637340         -9.302629
# 1            CCV_dw    252.801107      0.637340         -9.302629
# 2            CCV_cw    224.361978      0.541410         -9.302629
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    246.769469      0.616737         -9.302629
# 6       BiLSTM_pred    252.801107      0.637340         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.637340         -9.302629
# 10         BNN_pred    252.801107      0.637340         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    220.350861      0.545479         -9.302629
# 1            CCV_dw    305.738391      0.870769         -8.588117
# 2            CCV_cw    233.282795      0.566912         -9.335950
# 3         LSTM_pred    240.851219      0.642450         -8.850512
# 4          GRU_pred    245.093082      0.686616        -10.125437
# 5     LSTM_GRU_pred    243.858432      0.628289        -10.297472
# 6       BiLSTM_pred    202.720759      0.477641         -9.989142
# 7   BiLSTM_GRU_pred    281.683858      0.764353         -8.691528
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    253.668277      0.634622         -8.683929
# 10         BNN_pred    237.565433      0.607809         -9.113290
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    236.498876      0.609226         -8.446027
# 1            CCV_dw    242.396732      0.687900         -7.627198
# 2            CCV_cw    303.943325      0.905993         -6.048781
# 3         LSTM_pred    228.369350      0.600387         -6.383919
# 4          GRU_pred     94.719599      0.074160        -10.172832
# 5     LSTM_GRU_pred    225.871136      0.654360         -6.197208
# 6       BiLSTM_pred     63.126511     -0.076957         -7.292958
# 7   BiLSTM_GRU_pred    198.867593      0.523867         -6.604071
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    192.116916      0.435092         -7.661134
# 10         BNN_pred    160.310489      0.353315         -7.123871
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    181.823534      0.557592         -6.943868
# 1            CCV_dw    205.642799      0.633989         -7.627198
# 2            CCV_cw     92.249784      0.056642         -5.881940
# 3         LSTM_pred     45.536199     -0.297463         -5.890003
# 4          GRU_pred     79.674221     -0.028144         -5.275089
# 5     LSTM_GRU_pred     93.702375      0.066098         -4.878877
# 6       BiLSTM_pred    130.189017      0.283977         -4.613947
# 7   BiLSTM_GRU_pred    170.930783      0.563428         -5.874971
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    121.453893      0.234462         -7.354812
# 10         BNN_pred    172.713865      0.517605         -4.525902
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    212.304526      0.693544         -5.325611
# 1            CCV_dw    212.075156      0.598431         -7.627198
# 2            CCV_cw    189.265008      0.592967         -6.246621
# 3         LSTM_pred    182.019882      0.480588         -8.753960
# 4          GRU_pred     79.610755     -0.013878         -7.923209
# 5     LSTM_GRU_pred    154.359845      0.382420         -5.747538
# 6       BiLSTM_pred    110.495994      0.153345         -6.468503
# 7   BiLSTM_GRU_pred    159.148491      0.437833         -6.091023
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    227.516451      0.686711         -8.450006
# 10         BNN_pred    153.974711      0.332949         -6.939035
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    208.458381      0.599676         -6.771430
# 1            CCV_dw    206.362526      0.555755         -8.042946
# 2            CCV_cw    295.057798      0.944491         -5.906395
# 3         LSTM_pred    216.034793      0.607819         -5.808460
# 4          GRU_pred    129.053697      0.253475         -8.219467
# 5     LSTM_GRU_pred    165.728095      0.406889         -6.365624
# 6       BiLSTM_pred    162.747017      0.390585         -7.196945
# 7   BiLSTM_GRU_pred    228.851307      0.643707         -5.772164
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    201.581208      0.547566         -9.210607
# 10         BNN_pred    132.409231      0.217456         -7.714362
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    125.332632      0.238748         -8.485144
# 1            CCV_dw    276.952158      0.852994         -8.913724
# 2            CCV_cw    189.773929      0.577955         -5.850477
# 3         LSTM_pred    143.608789      0.321134         -8.699995
# 4          GRU_pred    179.885751      0.553093         -5.450334
# 5     LSTM_GRU_pred    123.843695      0.224806         -9.950567
# 6       BiLSTM_pred     87.585891      0.015484        -10.416420
# 7   BiLSTM_GRU_pred    202.584749      0.556118         -6.795560
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    208.380256      0.588316         -9.525832
# 10         BNN_pred    221.618229      0.622916         -6.513143
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.841089      0.408131         -8.485144
# 1            CCV_dw    278.383019      0.797481         -7.930717
# 2            CCV_cw    219.567535      0.683555         -5.943960
# 3         LSTM_pred    196.502065      0.485283        -10.267690
# 4          GRU_pred    245.893644      0.780849         -6.582078
# 5     LSTM_GRU_pred    128.298474      0.191349        -10.632176
# 6       BiLSTM_pred     86.263562     -0.000540         -9.989142
# 7   BiLSTM_GRU_pred    275.384529      0.813125         -6.719755
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    294.504997      0.907463         -6.043165
# 10         BNN_pred    213.718008      0.545183         -6.439477
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    167.826597      0.416789         -8.485144
# 1            CCV_dw    299.542467      0.856759         -8.588117
# 2            CCV_cw    273.825447      0.809137         -6.696361
# 3         LSTM_pred    217.575025      0.561528         -8.850512
# 4          GRU_pred    258.892060      0.805316         -8.684354
# 5     LSTM_GRU_pred    221.248350      0.565924        -10.297472
# 6       BiLSTM_pred    164.871844      0.336247         -9.989142
# 7   BiLSTM_GRU_pred    311.881686      0.886879         -7.553010
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    305.859325      0.908004         -6.937612
# 10         BNN_pred    192.897247      0.439650        -10.526383
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    125.332632      0.238748         -8.485144
# 1            CCV_dw    203.368274      0.468735         -9.302629
# 2            CCV_cw     83.845249     -0.010834        -11.115254
# 3         LSTM_pred    225.812425      0.545099         -9.035617
# 4          GRU_pred    202.858870      0.464722         -9.035617
# 5     LSTM_GRU_pred    175.599255      0.402260         -9.698106
# 6       BiLSTM_pred    182.167718      0.393543         -9.302629
# 7   BiLSTM_GRU_pred    179.859508      0.409419         -8.485144
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    171.974160      0.409744         -9.044627
# 10         BNN_pred    186.455765      0.405074         -9.035617
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    159.841089      0.408131         -8.485144
# 1            CCV_dw    246.769469      0.616737         -9.302629
# 2            CCV_cw    136.818469      0.235118         -9.035617
# 3         LSTM_pred    255.484213      0.647058         -9.302629
# 4          GRU_pred    209.460362      0.529419         -8.485144
# 5     LSTM_GRU_pred    149.696353      0.264959        -11.188250
# 6       BiLSTM_pred    197.251447      0.448020         -9.302629
# 7   BiLSTM_GRU_pred    232.528829      0.608756         -8.485144
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    256.779132      0.727726         -5.664136
# 10         BNN_pred    215.778852      0.510705         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    167.826597      0.416789         -8.485144
# 1            CCV_dw    252.801107      0.637340         -9.302629
# 2            CCV_cw    232.331561      0.565917         -9.035617
# 3         LSTM_pred    252.801107      0.637340         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    246.769469      0.616737         -9.302629
# 6       BiLSTM_pred    257.941718      0.655790         -9.302629
# 7   BiLSTM_GRU_pred    252.801107      0.637340         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    252.801107      0.662438         -8.485144
# 10         BNN_pred    235.968788      0.580680         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    245.869572      0.622688        -10.128959
# 1            CCV_dw    329.773565      0.986586         -8.588117
# 2            CCV_cw    249.998974      0.649711         -8.683929
# 3         LSTM_pred    198.699711      0.509995         -8.680115
# 4          GRU_pred    245.093082      0.686616        -10.125437
# 5     LSTM_GRU_pred    248.743540      0.706119         -6.197208
# 6       BiLSTM_pred    127.820980      0.183614         -7.608018
# 7   BiLSTM_GRU_pred    291.466405      0.881022         -5.870582
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    315.957065      0.890431         -5.328365
# 10         BNN_pred    225.571460      0.581954         -8.862215
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    200.498007      0.473731         -9.942738
# 1            CCV_dw    225.648835      0.607069        -10.060863
# 2            CCV_cw    278.275616      0.790238         -7.661134
# 3         LSTM_pred    278.332875      0.818737         -5.364283
# 4          GRU_pred     94.719599      0.074160        -10.172832
# 5     LSTM_GRU_pred    242.676925      0.712105         -7.304448
# 6       BiLSTM_pred    124.008728      0.215339         -7.891879
# 7   BiLSTM_GRU_pred    139.104275      0.274983         -7.706509
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    212.730967      0.528918         -7.661134
# 10         BNN_pred    122.047361      0.151975         -7.389437
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV     85.631619      0.011767         -6.675080
# 1            CCV_dw    164.633051      0.421198         -5.556356
# 2            CCV_cw    140.572177      0.409601         -5.969150
# 3         LSTM_pred     69.126759     -0.122339         -4.209052
# 4          GRU_pred    112.292979      0.204050         -4.195281
# 5     LSTM_GRU_pred     75.864460     -0.045994         -4.878877
# 6       BiLSTM_pred    119.801614      0.243525         -4.182610
# 7   BiLSTM_GRU_pred    133.025509      0.347218         -6.867003
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    143.437238      0.424346         -6.053712
# 10         BNN_pred    138.977848      0.312171         -4.292877
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    185.741820      0.598116         -5.325611
# 1            CCV_dw    139.223605      0.242893         -8.812182
# 2            CCV_cw    194.623105      0.678105         -6.130945
# 3         LSTM_pred    139.144556      0.301001         -6.913364
# 4          GRU_pred     79.610755     -0.013878         -7.923209
# 5     LSTM_GRU_pred    139.638386      0.328776         -4.878877
# 6       BiLSTM_pred    135.820400      0.296663         -4.737363
# 7   BiLSTM_GRU_pred    186.594984      0.636089         -7.077206
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    162.361337      0.453323         -5.882317
# 10         BNN_pred    166.768219      0.401614         -5.565170
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    144.839446      0.319629         -8.295517
# 1            CCV_dw    233.469021      0.655887        -10.060863
# 2            CCV_cw    309.908225      1.066768         -7.277381
# 3         LSTM_pred    230.281368      0.683087         -5.711906
# 4          GRU_pred    129.053697      0.253475         -8.219467
# 5     LSTM_GRU_pred    139.383436      0.302777         -7.828286
# 6       BiLSTM_pred    199.653356      0.584051         -6.196210
# 7   BiLSTM_GRU_pred    139.995475      0.288052         -5.459576
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    250.987974      0.782645         -6.145006
# 10         BNN_pred     97.611029      0.032004         -6.567878
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    122.953644      0.226653         -8.485144
# 1            CCV_dw    248.735003      0.795287         -8.913724
# 2            CCV_cw    131.426840      0.285890         -5.592060
# 3         LSTM_pred     54.627412     -0.225679         -4.971213
# 4          GRU_pred    217.720296      0.781094         -4.733476
# 5     LSTM_GRU_pred    156.095078      0.415411         -5.464427
# 6       BiLSTM_pred    184.688878      0.556703         -5.295011
# 7   BiLSTM_GRU_pred    207.865381      0.697958         -5.464427
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    171.344038      0.445500        -10.731477
# 10         BNN_pred    169.134176      0.465352         -5.700132
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    144.664384      0.338500         -8.485144
# 1            CCV_dw    248.480345      0.733401         -7.930717
# 2            CCV_cw    183.982956      0.547686         -6.656980
# 3         LSTM_pred     86.324925      0.034143        -10.636807
# 4          GRU_pred    245.893644      0.780849         -6.582078
# 5     LSTM_GRU_pred    158.914294      0.410242         -6.016982
# 6       BiLSTM_pred    143.225427      0.268803         -6.270186
# 7   BiLSTM_GRU_pred    315.450057      1.141828         -5.410019
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    235.284415      0.700688         -6.548242
# 10         BNN_pred    237.937852      0.682946         -5.885756
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    188.107453      0.493057         -8.485144
# 1            CCV_dw    305.196695      0.912302         -8.588117
# 2            CCV_cw    289.544581      0.916942         -6.695987
# 3         LSTM_pred    173.665055      0.412584         -8.680115
# 4          GRU_pred    258.892060      0.805316         -8.684354
# 5     LSTM_GRU_pred    138.002580      0.277460         -9.306489
# 6       BiLSTM_pred    163.260882      0.341634         -7.608018
# 7   BiLSTM_GRU_pred    267.047681      0.847136         -5.366934
# 8         QRNN_pred    188.506267      0.475696         -7.661134
# 9          ESN_pred    349.951528      1.112547         -6.112563
# 10         BNN_pred    154.254364      0.298701        -10.352122
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    122.953644      0.226653         -8.485144
# 1            CCV_dw    184.775628      0.402121         -9.302629
# 2            CCV_cw     61.611775     -0.124619        -10.750791
# 3         LSTM_pred    211.859945      0.522448         -8.485144
# 4          GRU_pred    200.123035      0.481345         -8.488748
# 5     LSTM_GRU_pred    137.789968      0.255130         -9.902986
# 6       BiLSTM_pred    182.167718      0.393543         -9.302629
# 7   BiLSTM_GRU_pred    179.859508      0.409419         -8.485144
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    155.688325      0.346636         -9.979164
# 10         BNN_pred    186.455765      0.405074         -9.035617
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    144.664384      0.338500         -8.485144
# 1            CCV_dw    246.769469      0.616737         -9.302629
# 2            CCV_cw    128.634082      0.198705         -9.035617
# 3         LSTM_pred    253.927297      0.641711         -9.302629
# 4          GRU_pred    209.460362      0.529419         -8.485144
# 5     LSTM_GRU_pred    149.696353      0.264959        -11.188250
# 6       BiLSTM_pred    202.616711      0.467910         -9.302629
# 7   BiLSTM_GRU_pred    232.528829      0.608756         -8.485144
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    233.254776      0.643002         -5.772180
# 10         BNN_pred    188.350549      0.414541         -9.302629
# 11               __    252.801107      0.637340         -9.302629
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0               CCV    167.826597      0.399161         -8.485144
# 1            CCV_dw    252.801107      0.637340         -9.302629
# 2            CCV_cw    197.947339      0.445907         -9.035617
# 3         LSTM_pred    248.333119      0.622043         -9.302629
# 4          GRU_pred    252.801107      0.637340         -9.302629
# 5     LSTM_GRU_pred    234.871678      0.577729         -9.302629
# 6       BiLSTM_pred    257.941718      0.655790         -9.302629
# 7   BiLSTM_GRU_pred    246.769469      0.616737         -9.302629
# 8         QRNN_pred    252.801107      0.637340         -9.302629
# 9          ESN_pred    246.769469      0.641737         -8.485144
# 10         BNN_pred    235.968788      0.580680         -9.302629
# 11               __    252.801107      0.637340         -9.302629

# %%
# path_1 = '/content/drive/MyDrive/Strategy/MA/CCV/CCV/'
# path_2 = '/content/drive/MyDrive/Strategy/MA/CCV/DW_CCV/'
# path_3 = '/content/drive/MyDrive/Strategy/MA/CCV/CW_CCV/'

# file_name = 'file_1.csv'
# file.to_csv(path_1 + file_name)

# filename = 'file_1.csv'
# dw_file.to_csv(path_2 + file_name)

# filename = 'file_1.csv'
# cw_file.to_csv(path_3 + file_name)
