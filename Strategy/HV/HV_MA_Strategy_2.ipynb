# %%
import pandas as pd
import numpy as np
import yfinance as yf
from google.colab import drive
from datetime import datetime
import matplotlib.pyplot as plt
import builtins

# %% [markdown]
# # Loading data

# %%
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Volatility/'
path_1 = '/content/drive/MyDrive/Volatility/Predictions/HV/'
path_2 = '/content/drive/MyDrive/Volatility/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/Not_normal_wc_real/'

def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

filename = 'HV_data.csv'
HV_dw = pd.read_csv(path_2 + filename)

filename = 'HV_data.csv'
HV_cw = pd.read_csv(path_3 + filename)

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path_1 + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path_1 + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path_1 + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path_1 + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path_1 + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(HV_dw)
set_index(HV_cw)

start = datetime(2020, 11, 5)
end = datetime(2022, 12, 23)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")

data_s['Close'] = ticker_historical.Close.values

start = datetime(2020, 10, 1)
end = datetime(2022, 12, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")

data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['HV'] = volatility_proxies['HV'].loc['2020-10-01':'2022-12-30'].values
data_s['HV'] = volatility_proxies['HV'].loc['2020-11-05':'2022-12-22'].values

data_l['HV_dw'] = HV_dw['HV'].loc['2020-10-01':'2022-12-30'].values
data_s['HV_dw'] = HV_dw['HV'].loc['2020-11-05':'2022-12-22'].values

data_l['HV_cw'] = HV_cw['HV'].loc['2020-10-01':'2022-12-30'].values
data_s['HV_cw'] = HV_cw['HV'].loc['2020-11-05':'2022-12-22'].values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2020-11-05':'2022-12-22']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2020-11-05':'2022-12-22']

data_2022_y1 = data_s.head(268)
data_2022_y2 = data_s.tail(269)
data_2022_2y = data_s
# Out:
# Mounted at /content/drive
# <ipython-input-2-ff306df51396>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %%
path_1 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/'
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/HV/'
path_2 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
path_4 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/'

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path_1 + filename)

filename = 'HV_data.csv'
HV_dw = pd.read_csv(path_2 + filename)

filename = 'HV_data.csv'
HV_cw = pd.read_csv(path_3 + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path_4 + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path_4 + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(HV_dw)
set_index(HV_cw)

start = datetime(2022, 7, 14)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")
data_s['Close'] = ticker_historical.Close.values

start = datetime(2022, 5, 31)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")
data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['HV'] = (volatility_proxies['HV'].loc['2022-05-31':'2024-8-30']).values
data_s['HV'] = (volatility_proxies['HV'].loc['2022-07-14':'2024-8-30']).values

data_l['HV_dw'] = (HV_dw['HV'].loc['2022-05-31':'2024-8-30']).values
data_s['HV_dw'] = (HV_dw['HV'].loc['2022-07-14':'2024-8-30']).values

data_l['HV_cw'] = (HV_cw['HV'].loc['2022-05-31':'2024-8-30']).values
data_s['HV_cw'] = (HV_cw['HV'].loc['2022-07-14':'2024-8-30']).values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2022-07-14':'2024-8-30']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2022-07-14':'2024-8-30']

data_2024_y1 = data_s.head(268)
data_2024_y2 = data_s.tail(269)
data_2024_2y1 = data_s
# Out:
# <ipython-input-2-ff306df51396>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %% [markdown]
# # Strategy

# %% [markdown]
# ## Without volatility

# %%
def strategy(data, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0

  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# ## With volatility

# %%
def strategy_with_vol_1(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_2(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_3(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_4(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_5(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_6(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_7(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_8(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_9(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_10(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_11(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_12(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_13(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_14(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_15(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_16(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_17(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_18(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_19(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_20(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_21(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_22(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_23(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_24(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_25(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_26(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_27(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_28(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_29(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_30(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_31(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_32(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_33(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_34(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_35(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_36(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_37(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_38(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_39(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_40(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_41(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_42(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_43(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_44(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# # Backtest

# %%
def backtest_function(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, data_f[vol], short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
def backtest_function_abs(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, abs(data_f[vol]), short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
volatility = ['HV', 'HV_dw', 'HV_cw', 'LSTM_pred', 'GRU_pred', 'LSTM_GRU_pred', 'BiLSTM_pred',
              'BiLSTM_GRU_pred', 'QRNN_pred', 'ESN_pred', 'BNN_pred']

# %%
def backtest(data_s, short_window=20, long_window=100):
  S1_results = backtest_function(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results = backtest_function(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results = backtest_function(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results = backtest_function(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results = backtest_function(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results = backtest_function(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results = backtest_function(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results = backtest_function(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results = backtest_function(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results = backtest_function(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results = backtest_function(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results = backtest_function(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results = backtest_function(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results = backtest_function(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results = backtest_function(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results = backtest_function(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results = backtest_function(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results = backtest_function(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results = backtest_function(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results = backtest_function(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results = backtest_function(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results = backtest_function(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results = backtest_function(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results = backtest_function(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results = backtest_function(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results = backtest_function(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results = backtest_function(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results = backtest_function(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results = backtest_function(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results = backtest_function(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results = backtest_function(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results = backtest_function(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results = backtest_function(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results = backtest_function(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results = backtest_function(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results = backtest_function(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results = backtest_function(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results = backtest_function(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results = backtest_function(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results = backtest_function(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results = backtest_function(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results = backtest_function(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results = backtest_function(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results = backtest_function(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results.loc[len(S1_results)] = new_row
  S2_results.loc[len(S2_results)] = new_row
  S3_results.loc[len(S3_results)] = new_row
  S4_results.loc[len(S4_results)] = new_row
  S5_results.loc[len(S5_results)] = new_row
  S6_results.loc[len(S6_results)] = new_row
  S7_results.loc[len(S7_results)] = new_row
  S8_results.loc[len(S8_results)] = new_row
  S9_results.loc[len(S9_results)] = new_row
  S10_results.loc[len(S10_results)] = new_row
  S11_results.loc[len(S11_results)] = new_row
  S12_results.loc[len(S12_results)] = new_row
  S13_results.loc[len(S13_results)] = new_row
  S14_results.loc[len(S14_results)] = new_row
  S15_results.loc[len(S15_results)] = new_row
  S16_results.loc[len(S16_results)] = new_row
  S17_results.loc[len(S17_results)] = new_row
  S18_results.loc[len(S18_results)] = new_row
  S19_results.loc[len(S19_results)] = new_row
  S20_results.loc[len(S20_results)] = new_row
  S21_results.loc[len(S21_results)] = new_row
  S22_results.loc[len(S22_results)] = new_row

  S23_results.loc[len(S23_results)] = new_row
  S24_results.loc[len(S24_results)] = new_row
  S25_results.loc[len(S25_results)] = new_row
  S26_results.loc[len(S26_results)] = new_row
  S27_results.loc[len(S27_results)] = new_row
  S28_results.loc[len(S28_results)] = new_row
  S29_results.loc[len(S29_results)] = new_row
  S30_results.loc[len(S30_results)] = new_row
  S31_results.loc[len(S31_results)] = new_row
  S32_results.loc[len(S32_results)] = new_row
  S33_results.loc[len(S33_results)] = new_row
  S34_results.loc[len(S34_results)] = new_row
  S35_results.loc[len(S35_results)] = new_row
  S36_results.loc[len(S36_results)] = new_row
  S37_results.loc[len(S37_results)] = new_row
  S38_results.loc[len(S38_results)] = new_row
  S39_results.loc[len(S39_results)] = new_row
  S40_results.loc[len(S40_results)] = new_row
  S41_results.loc[len(S41_results)] = new_row
  S42_results.loc[len(S42_results)] = new_row
  S43_results.loc[len(S43_results)] = new_row
  S44_results.loc[len(S44_results)] = new_row

  return S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results

# %%
def backtest_abs(data_s, short_window=20, long_window=100):
  S1_results_abs = backtest_function_abs(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results_abs = backtest_function_abs(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results_abs = backtest_function_abs(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results_abs = backtest_function_abs(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results_abs = backtest_function_abs(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results_abs = backtest_function_abs(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results_abs = backtest_function_abs(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results_abs = backtest_function_abs(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results_abs = backtest_function_abs(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results_abs = backtest_function_abs(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results_abs = backtest_function_abs(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results_abs = backtest_function_abs(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results_abs = backtest_function_abs(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results_abs = backtest_function_abs(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results_abs = backtest_function_abs(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results_abs = backtest_function_abs(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results_abs = backtest_function_abs(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results_abs = backtest_function_abs(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results_abs = backtest_function_abs(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results_abs = backtest_function_abs(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results_abs = backtest_function_abs(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results_abs = backtest_function_abs(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results_abs = backtest_function_abs(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results_abs = backtest_function_abs(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results_abs = backtest_function_abs(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results_abs = backtest_function_abs(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results_abs = backtest_function_abs(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results_abs = backtest_function_abs(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results_abs = backtest_function_abs(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results_abs = backtest_function_abs(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results_abs = backtest_function_abs(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results_abs = backtest_function_abs(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results_abs = backtest_function_abs(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results_abs = backtest_function_abs(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results_abs = backtest_function_abs(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results_abs = backtest_function_abs(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results_abs = backtest_function_abs(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results_abs = backtest_function_abs(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results_abs = backtest_function_abs(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results_abs = backtest_function_abs(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results_abs = backtest_function_abs(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results_abs = backtest_function_abs(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results_abs = backtest_function_abs(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results_abs = backtest_function_abs(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results_abs.loc[len(S1_results_abs)] = new_row
  S2_results_abs.loc[len(S2_results_abs)] = new_row
  S3_results_abs.loc[len(S3_results_abs)] = new_row
  S4_results_abs.loc[len(S4_results_abs)] = new_row
  S5_results_abs.loc[len(S5_results_abs)] = new_row
  S6_results_abs.loc[len(S6_results_abs)] = new_row
  S7_results_abs.loc[len(S7_results_abs)] = new_row
  S8_results_abs.loc[len(S8_results_abs)] = new_row
  S9_results_abs.loc[len(S9_results_abs)] = new_row
  S10_results_abs.loc[len(S10_results_abs)] = new_row
  S11_results_abs.loc[len(S11_results_abs)] = new_row
  S12_results_abs.loc[len(S12_results_abs)] = new_row
  S13_results_abs.loc[len(S13_results_abs)] = new_row
  S14_results_abs.loc[len(S14_results_abs)] = new_row
  S15_results_abs.loc[len(S15_results_abs)] = new_row
  S16_results_abs.loc[len(S16_results_abs)] = new_row
  S17_results_abs.loc[len(S17_results_abs)] = new_row
  S18_results_abs.loc[len(S18_results_abs)] = new_row
  S19_results_abs.loc[len(S19_results_abs)] = new_row
  S20_results_abs.loc[len(S20_results_abs)] = new_row
  S21_results_abs.loc[len(S21_results_abs)] = new_row
  S22_results_abs.loc[len(S22_results_abs)] = new_row

  S23_results_abs.loc[len(S23_results_abs)] = new_row
  S24_results_abs.loc[len(S24_results_abs)] = new_row
  S25_results_abs.loc[len(S25_results_abs)] = new_row
  S26_results_abs.loc[len(S26_results_abs)] = new_row
  S27_results_abs.loc[len(S27_results_abs)] = new_row
  S28_results_abs.loc[len(S28_results_abs)] = new_row
  S29_results_abs.loc[len(S29_results_abs)] = new_row
  S30_results_abs.loc[len(S30_results_abs)] = new_row
  S31_results_abs.loc[len(S31_results_abs)] = new_row
  S32_results_abs.loc[len(S32_results_abs)] = new_row
  S33_results_abs.loc[len(S33_results_abs)] = new_row
  S34_results_abs.loc[len(S34_results_abs)] = new_row
  S35_results_abs.loc[len(S35_results_abs)] = new_row
  S36_results_abs.loc[len(S36_results_abs)] = new_row
  S37_results_abs.loc[len(S37_results_abs)] = new_row
  S38_results_abs.loc[len(S38_results_abs)] = new_row
  S39_results_abs.loc[len(S39_results_abs)] = new_row
  S40_results_abs.loc[len(S40_results_abs)] = new_row
  S41_results_abs.loc[len(S41_results_abs)] = new_row
  S42_results_abs.loc[len(S42_results_abs)] = new_row
  S43_results_abs.loc[len(S43_results_abs)] = new_row
  S44_results_abs.loc[len(S44_results_abs)] = new_row

  return S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs

# %% [markdown]
# # Final Results

# %%
def check_strategy(data, HV):

    sharpe_ratio_HV = data.loc[data['Volatility'] == HV, 'Sharpe ratio'].values[0]
    sharpe_ratio_pure = data.loc[data['Volatility'] == '__', 'Sharpe ratio'].values[0]

    max_drawdown_HV = data.loc[data['Volatility'] == HV, 'Max drawdown (%)'].values[0]
    max_drawdown_pure = data.loc[data['Volatility'] == '__', 'Max drawdown (%)'].values[0]

    total_profit_HV = data.loc[data['Volatility'] == HV, 'Total profit'].values[0]
    total_profit_pure = data.loc[data['Volatility'] == '__', 'Total profit'].values[0]

    is_HV_sharpe_positive = sharpe_ratio_HV > 0
    is_HV_sharpe_greater_than_pure_sharpe = sharpe_ratio_HV > sharpe_ratio_pure
    is_HV_dd_greater_than_pure_dd = max_drawdown_HV > max_drawdown_pure
    is_pure_tp_greater_than_HV_tp = total_profit_pure > total_profit_HV

    all_sharpes_greater_than_Pure_sharpe = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Sharpe ratio'] > sharpe_ratio_pure)
    all_sharpes_greater_than_Pure_sharpe_percentage = (all_sharpes_greater_than_Pure_sharpe.sum()/8) * 100

    positive_sharpes = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Sharpe ratio'] > 0)
    positive_sharpes_percentage = (positive_sharpes.sum()/8) * 100

    HV_sharpe_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Sharpe ratio'] < sharpe_ratio_HV)
    HV_sharpe_greater_than_all_percentage = (HV_sharpe_greater_than_all.sum()/8) * 100

    HV_dd_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Max drawdown (%)'] < max_drawdown_HV)
    HV_dd_greater_than_all_percentage = (HV_dd_greater_than_all.sum()/8) * 100

    HV_tp_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'HV') & (data['Volatility'] != 'HV_dw') & (data['Volatility'] != 'HV_cw'), 'Total profit'] < total_profit_HV)
    HV_tp_greater_than_all_percentage = (HV_tp_greater_than_all.sum()/8) * 100

    return is_HV_sharpe_positive, is_HV_sharpe_greater_than_pure_sharpe, is_HV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, HV_sharpe_greater_than_all_percentage, HV_dd_greater_than_all_percentage, HV_tp_greater_than_all_percentage

# %%
def get_final_results(year, final_results, HV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results[f'S{i}_results']

    if(HV == 'HV'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV_cw'])]

    elif(HV == 'HV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV', 'HV_cw'])]

    elif(HV == 'HV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV'])]

    is_HV_sharpe_positive, is_HV_sharpe_greater_than_pure_sharpe, is_HV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, HV_sharpe_greater_than_all_percentage, HV_dd_greater_than_all_percentage, HV_tp_greater_than_all_percentage = check_strategy(strategy_result, HV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '-',
                'HV_sharpe > 0': is_HV_sharpe_positive,
                'HV_sharpe > Pure_sharpe': is_HV_sharpe_greater_than_pure_sharpe,
                'HV_dd > Pure_dd': is_HV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'HV_sharpe > Pred_sharpe (%)': HV_sharpe_greater_than_all_percentage,
                'HV_dd > Pred_dd (%)': HV_dd_greater_than_all_percentage,
                'HV_tp > Pred_tp (%)': HV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
def get_final_results_1(year, final_results, HV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results_abs[f'S{i}_results_abs']

    if(HV == 'HV'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV_cw'])]
      # res_combined
      # res_combined = pd.concat(details, strategy_result.drop())

    elif(HV == 'HV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV', 'HV_cw'])]

    elif(HV == 'HV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['HV_dw', 'HV'])]

    is_HV_sharpe_positive, is_HV_sharpe_greater_than_pure_sharpe, is_HV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, HV_sharpe_greater_than_all_percentage, HV_dd_greater_than_all_percentage, HV_tp_greater_than_all_percentage = check_strategy(strategy_result, HV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '+',
                'HV_sharpe > 0': is_HV_sharpe_positive,
                'HV_sharpe > Pure_sharpe': is_HV_sharpe_greater_than_pure_sharpe,
                'HV_dd > Pure_dd': is_HV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'HV_sharpe > Pred_sharpe (%)': HV_sharpe_greater_than_all_percentage,
                'HV_dd > Pred_dd (%)': HV_dd_greater_than_all_percentage,
                'HV_tp > Pred_tp (%)': HV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'HV_sharpe > 0', 'HV_sharpe > Pure_sharpe',
                                              'HV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'HV_sharpe > Pred_sharpe (%)',
                                              'HV_dd > Pred_dd (%)', 'HV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

dw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'HV_sharpe > 0', 'HV_sharpe > Pure_sharpe',
                                              'HV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'HV_sharpe > Pred_sharpe (%)',
                                              'HV_dd > Pred_dd (%)', 'HV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

cw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'HV_sharpe > 0', 'HV_sharpe > Pure_sharpe',
                                              'HV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'HV_sharpe > Pred_sharpe (%)',
                                              'HV_dd > Pred_dd (%)', 'HV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

# %%
# details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# dw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# cw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y1', file, 'HV')
get_final_results_1('2022_y1', file, 'HV')

get_final_results('2022_y1', dw_file, 'HV_dw')
get_final_results_1('2022_y1', dw_file, 'HV_dw')

get_final_results('2022_y1', cw_file, 'HV_cw')
get_final_results_1('2022_y1', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:30: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-20-6378cba2b518>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-20-6378cba2b518>:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-20-6378cba2b518>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y2', file, 'HV')
get_final_results_1('2022_y2', file, 'HV')

get_final_results('2022_y2', dw_file, 'HV_dw')
get_final_results_1('2022_y2', dw_file, 'HV_dw')

get_final_results('2022_y2', cw_file, 'HV_cw')
get_final_results_1('2022_y2', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:51: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-48-dbce691e5d20>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-48-dbce691e5d20>:70: SettingWithCopyWarning:
# ...
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-4-b267510ae310>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-4-b267510ae310>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -107.378574     -2.303740        -16.407054
# 1             HV_dw    -91.002346     -2.171562        -14.873439
# 2             HV_cw   -108.601701     -2.328682        -16.521598
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred   -107.276197     -2.090825        -14.697300
# 5     LSTM_GRU_pred    -94.634801     -2.155830        -15.213614
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred    -94.102544     -2.150998        -15.163769
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -52.109463     -1.941418        -11.231166
# 1             HV_dw   -135.181599     -2.171562        -14.873439
# 2             HV_cw   -105.531039     -2.164577        -14.605780
# 3         LSTM_pred   -116.800948     -2.460071        -17.289448
# 4          GRU_pred   -133.912403     -2.155351        -14.642884
# 5     LSTM_GRU_pred   -121.546391     -2.305495        -15.387192
# 6       BiLSTM_pred   -137.640477     -2.308270        -16.322382
# 7   BiLSTM_GRU_pred   -102.501390     -1.919016        -11.058562
# 8         QRNN_pred    -73.324909     -2.401885        -13.217968
# 9          ESN_pred    -83.774758     -2.038133        -14.196584
# 10         BNN_pred   -138.989284     -2.192862        -15.248240
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -57.497973     -2.280541        -11.630222
# 1             HV_dw    -97.312305     -1.742999        -11.493591
# 2             HV_cw    -51.650732     -1.902325         -9.476439
# 3         LSTM_pred   -112.376446     -2.411438        -16.875098
# 4          GRU_pred   -128.546320     -2.179109        -12.944938
# 5     LSTM_GRU_pred   -115.006034     -2.530320        -15.335042
# 6       BiLSTM_pred    -79.387503     -2.072324        -11.927515
# 7   BiLSTM_GRU_pred    -67.696642     -1.660221         -8.067621
# 8         QRNN_pred    -74.105795     -2.523625        -13.291097
# 9          ESN_pred    -83.431703     -2.048763        -14.164457
# 10         BNN_pred   -104.174700     -1.842416        -12.907413
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -44.396046     -1.942387        -10.508814
# 1             HV_dw   -126.922759     -2.067122        -14.590668
# 2             HV_cw    -71.945468     -2.126833        -10.104977
# 3         LSTM_pred   -116.800948     -2.460071        -17.289448
# 4          GRU_pred   -124.010912     -2.030338        -13.667044
# 5     LSTM_GRU_pred   -115.741223     -2.163716        -14.197424
# 6       BiLSTM_pred   -137.640477     -2.511454        -17.500418
# 7   BiLSTM_GRU_pred    -82.874852     -1.704151         -9.725523
# 8         QRNN_pred    -74.105795     -2.523625        -13.291097
# 9          ESN_pred    -77.146702     -1.961249        -13.575874
# 10         BNN_pred   -141.561365     -2.229698        -15.501418
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -41.994682     -1.798852        -10.283929
# 1             HV_dw   -135.181599     -2.171562        -14.873439
# 2             HV_cw    -95.834108     -2.542070        -13.680022
# 3         LSTM_pred   -116.800948     -2.460071        -17.289448
# 4          GRU_pred   -125.618168     -2.048889        -14.020583
# 5     LSTM_GRU_pred   -121.546391     -2.305495        -15.387192
# 6       BiLSTM_pred   -137.640477     -2.308270        -16.322382
# 7   BiLSTM_GRU_pred   -102.501390     -1.919016        -11.058562
# 8         QRNN_pred    -73.324909     -2.401885        -13.217968
# 9          ESN_pred    -83.774758     -2.038133        -14.196584
# 10         BNN_pred   -138.989284     -2.192862        -15.248240
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -2.076583        -14.351882
# 1             HV_dw    -84.399615     -1.742999        -11.493591
# 2             HV_cw    -51.650732     -1.902325         -9.476439
# 3         LSTM_pred    -99.868405     -2.214056        -15.703735
# 4          GRU_pred   -103.779110     -2.137079        -14.363142
# 5     LSTM_GRU_pred   -131.306373     -2.735984        -16.894451
# 6       BiLSTM_pred   -104.355255     -1.948908        -13.244317
# 7   BiLSTM_GRU_pred    -97.825501     -2.173316        -15.602909
# 8         QRNN_pred    -83.431703     -2.048763        -14.164457
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -90.099255     -2.092827        -14.686945
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -2.090490        -14.454202
# 1             HV_dw    -82.321604     -2.067122        -14.590668
# 2             HV_cw    -71.945468     -2.126833        -10.104977
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -99.114804     -1.995805        -13.917452
# 5     LSTM_GRU_pred   -113.148060     -2.468907        -16.947359
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred    -83.431703     -2.048763        -14.164457
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -107.378574     -2.303740        -16.407054
# 1             HV_dw    -91.002346     -2.171562        -14.873439
# 2             HV_cw   -137.823084     -2.837482        -19.258146
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred   -100.767738     -2.014013        -14.269965
# 5     LSTM_GRU_pred    -94.634801     -2.155830        -15.213614
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred    -94.102544     -2.150998        -15.163769
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.249109        -16.023600
# 1             HV_dw    -99.868405     -1.875965        -12.647019
# 2             HV_cw    -68.163598     -1.562937        -11.052656
# 3         LSTM_pred    -99.868405     -2.214056        -15.703735
# 4          GRU_pred    -88.104957     -2.088855        -14.602102
# 5     LSTM_GRU_pred    -99.868405     -2.099128        -13.886867
# 6       BiLSTM_pred   -104.355255     -1.948908        -13.244317
# 7   BiLSTM_GRU_pred    -97.825501     -2.173316        -15.602909
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -99.868405     -2.200414        -15.602909
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -97.825501     -2.186948        -15.703735
# 2             HV_cw    -88.104957     -1.765602        -11.670249
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -99.868405     -2.214056        -15.703735
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -104.355255     -2.262708        -16.123923
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw   -104.355255     -2.262708        -16.123923
# 2             HV_cw   -104.355255     -2.262708        -16.123923
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -97.825501     -2.186948        -15.703735
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -104.355255     -2.262708        -16.123923
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -107.378574     -2.303740        -16.407054
# 1             HV_dw    -84.769258     -2.082384        -14.289718
# 2             HV_cw    -90.440225     -2.624542        -14.820797
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred   -104.355255     -2.262708        -16.123923
# 5     LSTM_GRU_pred   -135.696272     -2.359061        -16.750111
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -100.272069     -2.238301        -15.741538
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -52.109463     -1.941418        -11.231166
# 1             HV_dw   -126.871714     -2.005232        -13.473643
# 2             HV_cw   -104.461175     -2.325965        -16.133843
# 3         LSTM_pred   -162.803759     -2.568736        -17.490267
# 4          GRU_pred   -130.436287     -2.119539        -14.300296
# 5     LSTM_GRU_pred   -119.685994     -2.188547        -14.580198
# 6       BiLSTM_pred   -137.640477     -2.308270        -16.322382
# 7   BiLSTM_GRU_pred   -120.742734     -2.078095        -13.452180
# 8         QRNN_pred   -102.428694     -2.298137        -15.943503
# 9          ESN_pred    -94.144357     -2.151374        -15.167685
# 10         BNN_pred   -144.643806     -2.278175        -15.804831
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -57.497973     -2.280541        -11.630222
# 1             HV_dw    -65.457063     -1.272555         -8.798286
# 2             HV_cw    -52.287379     -2.037167         -9.984613
# 3         LSTM_pred   -151.980726     -2.435883        -16.423605
# 4          GRU_pred    -99.447303     -1.863383        -11.347698
# 5     LSTM_GRU_pred   -124.158423     -2.682470        -16.210626
# 6       BiLSTM_pred    -79.387503     -2.072324        -11.927515
# 7   BiLSTM_GRU_pred   -119.726674     -2.117278        -13.548374
# 8         QRNN_pred    -88.483733     -2.703439        -14.637574
# 9          ESN_pred    -94.144357     -2.151374        -15.167685
# 10         BNN_pred   -110.057860     -1.931738        -13.479377
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -44.396046     -1.942387        -10.508814
# 1             HV_dw   -118.533517     -1.899129        -12.989193
# 2             HV_cw    -78.662536     -2.577237        -13.614629
# 3         LSTM_pred   -162.803759     -2.568736        -17.490267
# 4          GRU_pred   -112.649860     -1.909454        -12.547358
# 5     LSTM_GRU_pred   -106.476977     -2.076058        -13.298483
# 6       BiLSTM_pred   -137.640477     -2.511454        -17.500418
# 7   BiLSTM_GRU_pred   -114.841956     -2.001857        -12.871350
# 8         QRNN_pred    -88.483733     -2.703439        -14.637574
# 9          ESN_pred    -94.144357     -2.151374        -15.167685
# 10         BNN_pred   -146.178969     -2.301298        -15.955942
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -55.309142     -1.990103        -11.530812
# 1             HV_dw   -126.871714     -2.005232        -13.473643
# 2             HV_cw   -100.799230     -2.868345        -15.790906
# 3         LSTM_pred   -162.803759     -2.568736        -17.490267
# 4          GRU_pred   -110.635965     -1.881096        -12.547358
# 5     LSTM_GRU_pred   -126.258090     -2.291105        -15.217911
# 6       BiLSTM_pred   -137.640477     -2.308270        -16.322382
# 7   BiLSTM_GRU_pred   -120.742734     -2.078095        -13.452180
# 8         QRNN_pred    -98.336725     -2.274264        -15.560295
# 9          ESN_pred    -94.144357     -2.151374        -15.167685
# 10         BNN_pred   -144.643806     -2.278175        -15.804831
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -2.076583        -14.351882
# 1             HV_dw    -66.073599     -1.512792        -10.886694
# 2             HV_cw    -56.168316     -2.103986        -10.353231
# 3         LSTM_pred    -99.868405     -2.214056        -15.703735
# 4          GRU_pred    -68.163598     -1.901626        -14.005008
# 5     LSTM_GRU_pred    -99.868405     -2.099128        -13.886867
# 6       BiLSTM_pred   -104.355255     -1.948908        -13.244317
# 7   BiLSTM_GRU_pred    -97.825501     -2.173316        -15.602909
# 8         QRNN_pred    -83.431703     -2.048763        -14.164457
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -90.099255     -2.092827        -14.686945
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -2.090490        -14.454202
# 1             HV_dw    -78.121251     -2.005923        -14.005008
# 2             HV_cw    -92.216444     -2.742455        -14.885455
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -88.104957     -2.088855        -14.602102
# 5     LSTM_GRU_pred   -131.366429     -2.233275        -15.713590
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred    -83.431703     -2.048763        -14.164457
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -94.634801     -2.142147        -15.112202
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -97.160472     -2.192214        -15.450140
# 1             HV_dw    -84.769258     -2.082384        -14.289718
# 2             HV_cw   -102.449074     -2.888540        -15.945412
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -97.825501     -2.186948        -15.703735
# 5     LSTM_GRU_pred   -135.696272     -2.282173        -16.133729
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred    -83.431703     -2.048763        -14.164457
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.249109        -16.023600
# 1             HV_dw    -66.073599     -1.512792        -10.886694
# 2             HV_cw    -68.789159     -1.652133        -11.551980
# 3         LSTM_pred    -99.868405     -2.214056        -15.703735
# 4          GRU_pred    -68.163598     -1.901626        -14.005008
# 5     LSTM_GRU_pred    -99.868405     -2.099128        -13.886867
# 6       BiLSTM_pred   -104.355255     -1.948908        -13.244317
# 7   BiLSTM_GRU_pred    -97.825501     -2.173316        -15.602909
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -99.868405     -2.200414        -15.602909
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -99.868405     -2.214056        -15.703735
# 2             HV_cw   -104.355255     -2.249109        -16.023600
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -88.104957     -2.088855        -14.602102
# 5     LSTM_GRU_pred    -99.868405     -2.214056        -15.703735
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -104.355255     -2.249109        -16.023600
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw   -104.355255     -2.262708        -16.123923
# 2             HV_cw   -104.355255     -2.262708        -16.123923
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -97.825501     -2.186948        -15.703735
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -104.355255     -2.262708        -16.123923
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw   -133.175727     -2.209392        -14.675995
# 2             HV_cw   -141.874303     -2.119003        -14.187430
# 3         LSTM_pred   -160.926026     -2.542600        -17.305207
# 4          GRU_pred   -137.458147     -2.144091        -13.745815
# 5     LSTM_GRU_pred   -132.901550     -2.534739        -17.047057
# 6       BiLSTM_pred   -150.782634     -2.320552        -16.322382
# 7   BiLSTM_GRU_pred   -106.959504     -2.297812        -16.367808
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -140.186035     -2.190287        -15.278246
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -101.547041     -1.887225        -12.820115
# 1             HV_dw   -108.964505     -2.066290        -12.292815
# 2             HV_cw    -82.665134     -1.735306         -9.221644
# 3         LSTM_pred   -119.305376     -1.959047        -11.948274
# 4          GRU_pred   -126.221518     -2.341553        -13.884910
# 5     LSTM_GRU_pred   -113.035463     -2.173706        -13.081462
# 6       BiLSTM_pred   -123.936057     -2.258831        -13.677055
# 7   BiLSTM_GRU_pred   -121.208854     -2.292168        -13.408330
# 8         QRNN_pred    -95.047551     -1.808744        -12.189448
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -142.123494     -2.294281        -15.469153
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -94.144357     -2.032715        -13.339263
# 1             HV_dw    -37.853542     -1.300700         -7.120377
# 2             HV_cw      0.000000          -inf          0.000000
# 3         LSTM_pred   -119.399162     -2.198673        -11.939916
# 4          GRU_pred    -43.752716     -1.775553         -5.349595
# 5     LSTM_GRU_pred    -55.313974     -2.012452         -5.813602
# 6       BiLSTM_pred    -96.621543     -2.061441        -10.018514
# 7   BiLSTM_GRU_pred   -110.325103     -2.376846        -11.233970
# 8         QRNN_pred    -93.805184     -1.878090         -9.380518
# 9          ESN_pred    -49.715842     -1.875558        -12.149083
# 10         BNN_pred    -22.666309     -1.214839         -5.997994
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -94.144357     -2.032715        -13.339263
# 1             HV_dw    -45.166606     -1.354099         -7.120377
# 2             HV_cw    -45.245292     -1.513418         -9.221644
# 3         LSTM_pred   -132.207706     -2.196621        -13.220771
# 4          GRU_pred    -98.009828     -2.010249         -9.894453
# 5     LSTM_GRU_pred   -107.867408     -2.340979        -12.575016
# 6       BiLSTM_pred   -118.963223     -2.371955        -11.896322
# 7   BiLSTM_GRU_pred   -120.663107     -2.306752        -13.354555
# 8         QRNN_pred    -93.805184     -2.044736        -13.306815
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -75.396927     -1.794414        -10.220137
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -101.547041     -1.887225        -12.820115
# 1             HV_dw    -90.323548     -1.820271        -11.042738
# 2             HV_cw    -62.517086     -1.683798         -9.221644
# 3         LSTM_pred   -132.207706     -2.196621        -13.220771
# 4          GRU_pred   -121.434064     -2.198723        -13.413084
# 5     LSTM_GRU_pred    -94.317865     -1.999556        -11.247221
# 6       BiLSTM_pred   -117.449685     -2.171667        -13.037920
# 7   BiLSTM_GRU_pred   -121.208854     -2.292168        -13.408330
# 8         QRNN_pred    -95.047551     -1.808744        -12.189448
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -129.996360     -2.212110        -14.376413
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -40.464844     -1.298854         -8.342583
# 2             HV_cw      0.000000          -inf          0.000000
# 3         LSTM_pred   -154.315288     -2.459340        -16.653687
# 4          GRU_pred    -54.187787     -1.903633         -6.393414
# 5     LSTM_GRU_pred    -65.456596     -2.197824         -6.545660
# 6       BiLSTM_pred    -89.826527     -1.938562         -9.341692
# 7   BiLSTM_GRU_pred    -75.863256     -1.941592        -11.973203
# 8         QRNN_pred   -104.355255     -1.993642        -10.435525
# 9          ESN_pred    -49.715842     -1.875558        -12.149083
# 10         BNN_pred    -56.727962     -1.269157        -10.561836
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -64.720995     -1.502170         -9.383516
# 2             HV_cw   -104.355255     -1.993642        -10.435525
# 3         LSTM_pred   -160.926026     -2.542600        -17.305207
# 4          GRU_pred   -109.802605     -1.790302        -12.276191
# 5     LSTM_GRU_pred   -109.063978     -2.609169        -15.383409
# 6       BiLSTM_pred   -119.275146     -2.346663        -11.927515
# 7   BiLSTM_GRU_pred   -106.959504     -2.284197        -16.267777
# 8         QRNN_pred   -104.355255     -2.150617        -14.316111
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -100.703084     -1.774716        -12.687599
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw   -124.897732     -2.102269        -13.861168
# 2             HV_cw   -123.026706     -2.076260        -12.302671
# 3         LSTM_pred   -160.926026     -2.542600        -17.305207
# 4          GRU_pred   -119.246613     -1.794878        -11.924661
# 5     LSTM_GRU_pred   -128.086113     -2.570554        -16.586378
# 6       BiLSTM_pred   -162.738144     -2.523991        -17.500418
# 7   BiLSTM_GRU_pred   -106.959504     -2.297812        -16.367808
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -118.210360     -1.988449        -13.226610
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -66.073599     -1.687243        -12.333426
# 2             HV_cw      0.000000          -inf          0.000000
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -81.729071     -1.929077        -12.333426
# 5     LSTM_GRU_pred    -81.729071     -1.553585         -8.172907
# 6       BiLSTM_pred    -97.825501     -1.869890        -12.809703
# 7   BiLSTM_GRU_pred    -97.825501     -2.011454        -14.065173
# 8         QRNN_pred   -104.355255     -1.993642        -10.435525
# 9          ESN_pred    -49.715842     -1.875558        -12.149083
# 10         BNN_pred    -66.073599     -1.861172        -13.902150
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -66.073599     -1.687243        -12.333426
# 2             HV_cw   -104.355255     -1.993642        -10.435525
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -68.163598     -1.901626        -14.005008
# 5     LSTM_GRU_pred    -88.104957     -2.065995        -13.392827
# 6       BiLSTM_pred   -104.355255     -1.948908        -13.244317
# 7   BiLSTM_GRU_pred   -104.355255     -2.249109        -16.023600
# 8         QRNN_pred   -104.355255     -2.150617        -14.316111
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -97.825501     -2.173316        -15.602909
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -99.868405     -2.214056        -15.703735
# 2             HV_cw   -104.355255     -1.945234        -13.092606
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -88.104957     -2.088855        -14.602102
# 5     LSTM_GRU_pred    -99.868405     -2.214056        -15.703735
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -104.355255     -2.262708        -16.123923
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw   -117.381973     -2.041186        -13.121371
# 2             HV_cw   -126.310680     -2.011372        -12.631068
# 3         LSTM_pred   -119.280777     -2.144987        -13.200867
# 4          GRU_pred   -139.073998     -2.416994        -15.151584
# 5     LSTM_GRU_pred   -125.448772     -2.321094        -15.139380
# 6       BiLSTM_pred    -98.114345     -1.837146        -11.132713
# 7   BiLSTM_GRU_pred   -150.363205     -2.297812        -16.367808
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -166.639893     -2.558854        -17.884876
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -98.102290     -1.850717        -12.485860
# 1             HV_dw   -145.964259     -2.610940        -14.596426
# 2             HV_cw   -107.310387     -1.878504        -10.731039
# 3         LSTM_pred   -140.052654     -2.213823        -14.005265
# 4          GRU_pred   -126.221518     -2.341553        -13.884910
# 5     LSTM_GRU_pred    -88.360744     -2.337536        -10.663450
# 6       BiLSTM_pred    -82.619616     -2.071207         -9.295330
# 7   BiLSTM_GRU_pred    -90.099357     -2.221003        -10.342956
# 8         QRNN_pred    -94.882186     -2.070751        -14.036494
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -129.613464     -2.156101        -14.236478
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -1.968260        -12.610402
# 1             HV_dw    -68.863916     -2.273394         -7.945758
# 2             HV_cw      0.000000          -inf          0.000000
# 3         LSTM_pred    -92.798375     -1.812684         -9.399733
# 4          GRU_pred      9.080235     -1.467519         -1.113775
# 5     LSTM_GRU_pred    -17.620994     -2.173907         -1.762099
# 6       BiLSTM_pred    -25.137177     -2.045800         -2.734468
# 7   BiLSTM_GRU_pred    -40.987057     -1.948815         -4.455205
# 8         QRNN_pred    -76.749405     -1.653615         -8.766878
# 9          ESN_pred    -49.715842     -1.875558        -12.149083
# 10         BNN_pred     12.313039     -1.271442         -1.311348
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -1.968260        -12.610402
# 1             HV_dw    -60.765611     -1.808966         -7.894890
# 2             HV_cw    -58.514690     -2.367883         -6.545660
# 3         LSTM_pred   -101.881653     -1.793218        -10.188165
# 4          GRU_pred    -98.009828     -2.010249         -9.894453
# 5     LSTM_GRU_pred    -67.620852     -2.398789         -8.631034
# 6       BiLSTM_pred    -48.821494     -1.889542         -4.882149
# 7   BiLSTM_GRU_pred    -54.323025     -1.772217         -8.558542
# 8         QRNN_pred    -83.431703     -1.953845        -12.418881
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -61.913853     -1.619075         -8.704186
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -98.102290     -1.850717        -12.485860
# 1             HV_dw    -91.631136     -2.262334         -9.849892
# 2             HV_cw    -84.877494     -1.860751         -9.110984
# 3         LSTM_pred   -118.073571     -2.003733        -11.807357
# 4          GRU_pred    -92.022003     -1.865766        -11.559940
# 5     LSTM_GRU_pred    -94.385234     -2.279707        -13.465526
# 6       BiLSTM_pred    -48.425001     -1.750312         -5.914387
# 7   BiLSTM_GRU_pred    -90.099357     -2.221003        -10.342956
# 8         QRNN_pred    -94.882186     -2.070751        -14.036494
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -116.253709     -2.053750        -13.023896
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -24.629956     -1.070771         -6.829991
# 2             HV_cw      0.000000          -inf          0.000000
# 3         LSTM_pred    -93.100392     -1.952476        -10.620663
# 4          GRU_pred      4.407007     -1.163918         -2.490871
# 5     LSTM_GRU_pred    -22.379849     -2.219519         -2.530028
# 6       BiLSTM_pred    -89.826527     -1.938562         -9.341692
# 7   BiLSTM_GRU_pred    -90.593147     -1.785969        -10.687171
# 8         QRNN_pred    -97.825501     -1.905765         -9.986840
# 9          ESN_pred    -49.715842     -1.875558        -12.149083
# 10         BNN_pred     12.313039     -1.271442         -1.311348
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -56.219880     -1.386840         -8.559867
# 2             HV_cw   -104.355255     -1.993642        -10.435525
# 3         LSTM_pred   -102.180646     -1.928097        -11.515566
# 4          GRU_pred   -123.817088     -2.290643        -12.472504
# 5     LSTM_GRU_pred    -61.873270     -2.143597         -8.067797
# 6       BiLSTM_pred   -112.336256     -2.249593        -11.233626
# 7   BiLSTM_GRU_pred   -143.145224     -2.208430        -15.848309
# 8         QRNN_pred   -104.355255     -2.181082        -14.418195
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -120.907064     -2.077097        -14.445485
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -76.786095     -1.655959         -9.383516
# 2             HV_cw   -104.355255     -1.993642        -10.435525
# 3         LSTM_pred   -119.280777     -2.144987        -13.200867
# 4          GRU_pred   -111.470264     -2.061992        -13.454265
# 5     LSTM_GRU_pred    -92.332990     -2.166304        -13.165974
# 6       BiLSTM_pred   -109.974484     -2.136501        -10.997448
# 7   BiLSTM_GRU_pred   -150.363205     -2.297812        -16.367808
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -135.031357     -2.246142        -14.871945
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -66.073599     -1.512792        -10.886694
# 2             HV_cw      0.000000          -inf          0.000000
# 3         LSTM_pred    -99.868405     -2.214056        -15.703735
# 4          GRU_pred    -49.715842     -1.502791         -9.133014
# 5     LSTM_GRU_pred    -49.715842     -1.233972         -6.191115
# 6       BiLSTM_pred    -97.825501     -1.869890        -12.809703
# 7   BiLSTM_GRU_pred    -97.825501     -1.869890        -12.809703
# 8         QRNN_pred    -97.825501     -1.905765         -9.986840
# 9          ESN_pred    -49.715842     -1.875558        -12.149083
# 10         BNN_pred    -13.371922     -1.016985         -9.133014
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -66.073599     -1.687243        -12.333426
# 2             HV_cw   -104.355255     -1.993642        -10.435525
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -68.163598     -1.901626        -14.005008
# 5     LSTM_GRU_pred    -88.104957     -1.776982        -10.638384
# 6       BiLSTM_pred   -104.355255     -1.948908        -13.244317
# 7   BiLSTM_GRU_pred    -97.825501     -2.173316        -15.602909
# 8         QRNN_pred   -104.355255     -2.181082        -14.418195
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred    -99.868405     -2.200414        -15.602909
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -99.868405     -2.039028        -14.065173
# 2             HV_cw   -104.355255     -1.993642        -10.435525
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -68.163598     -1.901626        -14.005008
# 5     LSTM_GRU_pred    -99.868405     -2.214056        -15.703735
# 6       BiLSTM_pred   -104.355255     -1.948908        -13.244317
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -2.262708        -16.123923
# 10         BNN_pred   -104.355255     -2.249109        -16.023600
# 11               __   -104.355255     -2.262708        -16.123923

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -107.378574     -2.303740        -16.407054
# 1             HV_dw   -116.795642     -2.181056        -14.929599
# 2             HV_cw   -108.601701     -2.328682        -16.521598
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred   -107.276197     -2.090825        -14.697300
# 5     LSTM_GRU_pred    -84.769258     -2.082384        -14.289718
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred    -94.102544     -2.150998        -15.163769
# 9          ESN_pred   -111.674496     -2.002780        -13.802816
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -52.109463     -1.941418        -11.231166
# 1             HV_dw   -128.497450     -2.111341        -14.215499
# 2             HV_cw   -105.531039     -2.164577        -14.605780
# 3         LSTM_pred   -116.800948     -2.460071        -17.289448
# 4          GRU_pred   -133.912403     -2.155351        -14.642884
# 5     LSTM_GRU_pred   -115.027276     -1.869764        -11.802531
# 6       BiLSTM_pred   -154.099334     -2.302655        -16.171880
# 7   BiLSTM_GRU_pred   -102.501390     -1.919016        -11.058562
# 8         QRNN_pred    -73.324909     -2.401885        -13.217968
# 9          ESN_pred    -99.350793     -1.953187        -11.236670
# 10         BNN_pred   -138.989284     -2.192862        -15.248240
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -57.497973     -2.280541        -11.630222
# 1             HV_dw   -101.231847     -1.784113        -11.877893
# 2             HV_cw    -51.650732     -1.902325         -9.476439
# 3         LSTM_pred   -112.376446     -2.411438        -16.875098
# 4          GRU_pred   -128.546320     -2.179109        -12.944938
# 5     LSTM_GRU_pred    -57.799930     -1.520753         -9.473740
# 6       BiLSTM_pred   -114.267705     -1.970750        -12.683937
# 7   BiLSTM_GRU_pred    -67.696642     -1.660221         -8.067621
# 8         QRNN_pred    -74.105795     -2.523625        -13.291097
# 9          ESN_pred      5.065150     -1.312768         -2.282814
# 10         BNN_pred   -102.019566     -1.812146        -11.914504
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -44.396046     -1.942387        -10.508814
# 1             HV_dw   -122.143707     -2.031798        -13.930543
# 2             HV_cw    -71.945468     -2.126833        -10.104977
# 3         LSTM_pred   -116.800948     -2.460071        -17.289448
# 4          GRU_pred   -124.010912     -2.030338        -13.667044
# 5     LSTM_GRU_pred    -78.423865     -1.434952        -10.458902
# 6       BiLSTM_pred   -144.918753     -2.194758        -15.262091
# 7   BiLSTM_GRU_pred    -82.874852     -1.704151         -9.725523
# 8         QRNN_pred    -74.105795     -2.523625        -13.291097
# 9          ESN_pred    -58.988337     -1.513935         -7.206444
# 10         BNN_pred   -141.561365     -2.229698        -15.501418
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -41.994682     -1.798852        -10.283929
# 1             HV_dw   -128.497450     -2.111341        -14.215499
# 2             HV_cw    -95.834108     -2.542070        -13.680022
# 3         LSTM_pred   -116.800948     -2.460071        -17.289448
# 4          GRU_pred   -125.618168     -2.048889        -14.020583
# 5     LSTM_GRU_pred   -100.322016     -1.731487        -11.802531
# 6       BiLSTM_pred   -154.099334     -2.302655        -16.171880
# 7   BiLSTM_GRU_pred   -102.501390     -1.919016        -11.058562
# 8         QRNN_pred    -73.324909     -2.401885        -13.217968
# 9          ESN_pred    -95.711341     -1.793314        -11.097702
# 10         BNN_pred   -138.989284     -2.192862        -15.248240
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -2.076583        -14.351882
# 1             HV_dw   -110.380266     -2.024607        -14.015061
# 2             HV_cw    -51.650732     -1.902325         -9.476439
# 3         LSTM_pred    -99.868405     -2.214056        -15.703735
# 4          GRU_pred   -103.779110     -2.137079        -14.363142
# 5     LSTM_GRU_pred    -49.908695     -1.867684        -12.149083
# 6       BiLSTM_pred    -88.104957     -2.088855        -14.602102
# 7   BiLSTM_GRU_pred    -97.825501     -2.173316        -15.602909
# 8         QRNN_pred    -83.431703     -2.048763        -14.164457
# 9          ESN_pred    -13.371922     -0.968565         -6.191115
# 10         BNN_pred    -88.034179     -2.065608        -14.686945
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -2.090490        -14.454202
# 1             HV_dw   -110.356585     -2.102638        -14.647014
# 2             HV_cw    -71.945468     -2.126833        -10.104977
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -99.114804     -1.995805        -13.917452
# 5     LSTM_GRU_pred    -85.383671     -2.092531        -14.347257
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred    -83.431703     -2.048763        -14.164457
# 9          ESN_pred    -68.789159     -1.583484         -8.172907
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -107.378574     -2.303740        -16.407054
# 1             HV_dw   -116.795642     -2.181056        -14.929599
# 2             HV_cw   -137.823084     -2.837482        -19.258146
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred   -100.767738     -2.014013        -14.269965
# 5     LSTM_GRU_pred    -84.769258     -2.082384        -14.289718
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred    -94.102544     -2.150998        -15.163769
# 9          ESN_pred    -97.825501     -2.070369        -13.886867
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.249109        -16.023600
# 1             HV_dw    -99.868405     -2.214056        -15.703735
# 2             HV_cw    -68.163598     -1.562937        -11.052656
# 3         LSTM_pred    -99.868405     -2.214056        -15.703735
# 4          GRU_pred    -88.104957     -2.088855        -14.602102
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred    -88.104957     -2.088855        -14.602102
# 7   BiLSTM_GRU_pred    -97.825501     -2.173316        -15.602909
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred    -13.371922     -0.968565         -6.191115
# 10         BNN_pred    -97.825501     -2.173316        -15.602909
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -97.825501     -2.186948        -15.703735
# 2             HV_cw    -88.104957     -1.765602        -11.670249
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -99.868405     -2.214056        -15.703735
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred    -68.789159     -1.583484         -8.172907
# 10         BNN_pred   -104.355255     -2.262708        -16.123923
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw   -104.355255     -2.262708        -16.123923
# 2             HV_cw   -104.355255     -2.262708        -16.123923
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -97.825501     -2.186948        -15.703735
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred    -97.825501     -2.070369        -13.886867
# 10         BNN_pred   -104.355255     -2.262708        -16.123923
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -107.378574     -2.303740        -16.407054
# 1             HV_dw   -116.795642     -2.181056        -14.929599
# 2             HV_cw    -90.440225     -2.624542        -14.820797
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred   -104.355255     -2.262708        -16.123923
# 5     LSTM_GRU_pred   -155.610230     -2.204550        -15.561023
# 6       BiLSTM_pred   -107.378574     -2.303740        -16.407054
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -100.272069     -2.238301        -15.741538
# 9          ESN_pred   -116.423217     -1.818464        -12.030293
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -52.109463     -1.941418        -11.231166
# 1             HV_dw   -112.042358     -2.149138        -14.471762
# 2             HV_cw   -104.461175     -2.325965        -16.133843
# 3         LSTM_pred   -162.803759     -2.568736        -17.490267
# 4          GRU_pred   -130.436287     -2.119539        -14.300296
# 5     LSTM_GRU_pred    -84.957050     -1.685278        -11.159601
# 6       BiLSTM_pred   -154.099334     -2.302655        -16.171880
# 7   BiLSTM_GRU_pred   -120.742734     -2.078095        -13.452180
# 8         QRNN_pred   -102.428694     -2.298137        -15.943503
# 9          ESN_pred    -87.317076     -1.796938         -8.731708
# 10         BNN_pred   -138.210003     -2.180086        -15.171534
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -57.497973     -2.280541        -11.630222
# 1             HV_dw    -98.545766     -1.904191        -12.871214
# 2             HV_cw    -52.287379     -2.037167         -9.984613
# 3         LSTM_pred   -151.980726     -2.435883        -16.423605
# 4          GRU_pred    -99.447303     -1.863383        -11.347698
# 5     LSTM_GRU_pred    -87.631170     -1.833825        -10.352096
# 6       BiLSTM_pred   -104.128465     -1.740310        -11.684405
# 7   BiLSTM_GRU_pred   -119.726674     -2.117278        -13.548374
# 8         QRNN_pred    -88.483733     -2.703439        -14.637574
# 9          ESN_pred    -22.828142     -3.375786         -2.282814
# 10         BNN_pred   -107.712105     -1.881082        -12.284510
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -44.396046     -1.942387        -10.508814
# 1             HV_dw   -103.039209     -2.037520        -13.604577
# 2             HV_cw    -71.945468     -2.481778        -12.984831
# 3         LSTM_pred   -162.803759     -2.568736        -17.490267
# 4          GRU_pred   -112.649860     -1.909454        -12.547358
# 5     LSTM_GRU_pred    -70.443111     -1.495575        -10.352096
# 6       BiLSTM_pred   -144.918753     -2.194758        -15.262091
# 7   BiLSTM_GRU_pred   -114.841956     -2.001857        -12.871350
# 8         QRNN_pred    -88.483733     -2.703439        -14.637574
# 9          ESN_pred    -33.348252     -1.387245         -6.303185
# 10         BNN_pred   -140.784412     -2.216868        -15.424940
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -55.309142     -1.990103        -11.530812
# 1             HV_dw   -112.042358     -2.149138        -14.471762
# 2             HV_cw   -100.799230     -2.868345        -15.790906
# 3         LSTM_pred   -162.803759     -2.568736        -17.490267
# 4          GRU_pred   -110.635965     -1.881096        -12.547358
# 5     LSTM_GRU_pred    -88.975069     -1.730790        -11.159601
# 6       BiLSTM_pred   -154.099334     -2.302655        -16.171880
# 7   BiLSTM_GRU_pred   -120.742734     -2.078095        -13.452180
# 8         QRNN_pred    -98.336725     -2.274264        -15.560295
# 9          ESN_pred    -44.691028     -1.404551         -6.303185
# 10         BNN_pred   -138.210003     -2.180086        -15.171534
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -2.076583        -14.351882
# 1             HV_dw   -110.380266     -2.024607        -14.015061
# 2             HV_cw    -56.168316     -2.103986        -10.353231
# 3         LSTM_pred    -99.868405     -2.214056        -15.703735
# 4          GRU_pred    -68.163598     -1.901626        -14.005008
# 5     LSTM_GRU_pred   -142.038177     -2.258764        -14.203818
# 6       BiLSTM_pred    -80.779635     -2.016154        -13.916094
# 7   BiLSTM_GRU_pred    -97.825501     -2.173316        -15.602909
# 8         QRNN_pred    -83.431703     -2.048763        -14.164457
# 9          ESN_pred    -22.828142     -3.375786         -2.282814
# 10         BNN_pred    -94.634801     -2.142147        -15.112202
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -2.090490        -14.454202
# 1             HV_dw   -114.814719     -2.155068        -14.738796
# 2             HV_cw    -75.745904     -2.539872        -13.341163
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -88.104957     -2.088855        -14.602102
# 5     LSTM_GRU_pred   -146.194328     -2.094605        -14.619433
# 6       BiLSTM_pred   -107.378574     -2.303740        -16.407054
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred    -83.431703     -2.048763        -14.164457
# 9          ESN_pred    -18.586079     -1.059704         -6.303185
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -97.160472     -2.192214        -15.450140
# 1             HV_dw   -116.795642     -2.181056        -14.929599
# 2             HV_cw   -102.449074     -2.888540        -15.945412
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -97.825501     -2.186948        -15.703735
# 5     LSTM_GRU_pred   -155.610230     -2.204550        -15.561023
# 6       BiLSTM_pred   -107.378574     -2.303740        -16.407054
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred    -83.431703     -2.048763        -14.164457
# 9          ESN_pred   -100.943756     -1.717039        -10.094376
# 10         BNN_pred    -94.634801     -2.155830        -15.213614
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.249109        -16.023600
# 1             HV_dw    -99.868405     -2.214056        -15.703735
# 2             HV_cw    -68.789159     -1.652133        -11.551980
# 3         LSTM_pred    -99.868405     -2.214056        -15.703735
# 4          GRU_pred    -68.163598     -1.901626        -14.005008
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred    -88.104957     -2.088855        -14.602102
# 7   BiLSTM_GRU_pred    -97.825501     -2.173316        -15.602909
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred    -22.828142     -3.375786         -2.282814
# 10         BNN_pred   -104.355255     -2.249109        -16.023600
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw   -104.355255     -2.262708        -16.123923
# 2             HV_cw    -88.104957     -2.075083        -14.499959
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -88.104957     -2.088855        -14.602102
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred    -17.412220     -1.478847        -12.149083
# 10         BNN_pred   -104.355255     -2.262708        -16.123923
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw   -104.355255     -2.262708        -16.123923
# 2             HV_cw   -104.355255     -2.262708        -16.123923
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -97.825501     -2.186948        -15.703735
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred    -99.868405     -2.214056        -15.703735
# 10         BNN_pred   -104.355255     -2.262708        -16.123923
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -71.915111     -1.921728        -10.606698
# 2             HV_cw   -149.603884     -2.214555        -14.960388
# 3         LSTM_pred   -160.926026     -2.542600        -17.305207
# 4          GRU_pred   -137.458147     -2.144091        -13.745815
# 5     LSTM_GRU_pred   -155.440148     -2.204550        -15.561023
# 6       BiLSTM_pred   -149.519866     -2.230047        -15.718058
# 7   BiLSTM_GRU_pred   -106.959504     -2.297812        -16.367808
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -126.310680     -2.011372        -12.631068
# 10         BNN_pred   -133.392170     -2.090825        -14.697300
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -101.547041     -1.887225        -12.820115
# 1             HV_dw    -74.154595     -1.737550         -8.771839
# 2             HV_cw   -122.327587     -1.984062        -12.232759
# 3         LSTM_pred   -119.305376     -1.959047        -11.948274
# 4          GRU_pred   -126.221518     -2.341553        -13.884910
# 5     LSTM_GRU_pred    -82.288637     -1.645440        -11.159601
# 6       BiLSTM_pred   -138.212647     -2.357540        -15.548713
# 7   BiLSTM_GRU_pred   -121.208854     -2.292168        -13.408330
# 8         QRNN_pred    -95.047551     -1.808744        -12.189448
# 9          ESN_pred    -71.385894     -1.556236         -7.138589
# 10         BNN_pred   -140.408191     -2.212861        -15.300136
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -94.144357     -2.032715        -13.339263
# 1             HV_dw    -13.525726     -1.148453         -5.042351
# 2             HV_cw    -44.255733     -1.262217         -6.928360
# 3         LSTM_pred   -119.399162     -2.198673        -11.939916
# 4          GRU_pred    -43.752716     -1.775553         -5.349595
# 5     LSTM_GRU_pred    -86.539896     -1.817299        -10.244869
# 6       BiLSTM_pred    -47.984387     -1.404866         -7.722904
# 7   BiLSTM_GRU_pred   -110.325103     -2.376846        -11.233970
# 8         QRNN_pred    -93.805184     -1.878090         -9.380518
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred   -102.207851     -1.844379        -12.625652
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -94.144357     -2.032715        -13.339263
# 1             HV_dw    -24.577127     -1.175128         -6.379168
# 2             HV_cw    -83.431703     -1.745110         -9.221644
# 3         LSTM_pred   -132.207706     -2.196621        -13.220771
# 4          GRU_pred    -98.009828     -2.010249         -9.894453
# 5     LSTM_GRU_pred    -67.732374     -1.455519        -10.352096
# 6       BiLSTM_pred   -132.629862     -2.334410        -14.044271
# 7   BiLSTM_GRU_pred   -120.663107     -2.306752        -13.354555
# 8         QRNN_pred    -93.805184     -2.044736        -13.306815
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred   -116.632582     -2.018135        -13.061184
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -101.547041     -1.887225        -12.820115
# 1             HV_dw    -81.606849     -1.855214         -9.506147
# 2             HV_cw   -102.120232     -1.924661        -10.305067
# 3         LSTM_pred   -132.207706     -2.196621        -13.220771
# 4          GRU_pred   -121.434064     -2.198723        -13.413084
# 5     LSTM_GRU_pred    -86.318374     -1.691174        -11.159601
# 6       BiLSTM_pred   -148.052598     -2.477757        -15.572653
# 7   BiLSTM_GRU_pred   -121.208854     -2.292168        -13.408330
# 8         QRNN_pred    -95.047551     -1.808744        -12.189448
# 9          ESN_pred    -48.050234     -1.530600         -5.453339
# 10         BNN_pred   -140.408191     -2.212861        -15.300136
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw      4.783698     -1.452247         -6.774368
# 2             HV_cw    -66.073599     -1.540334         -8.172907
# 3         LSTM_pred   -154.315288     -2.459340        -16.653687
# 4          GRU_pred    -54.187787     -1.903633         -6.393414
# 5     LSTM_GRU_pred   -141.011978     -2.244731        -14.101198
# 6       BiLSTM_pred    -88.680213     -1.928098        -10.395673
# 7   BiLSTM_GRU_pred    -75.863256     -1.941592        -11.973203
# 8         QRNN_pred   -104.355255     -1.993642        -10.435525
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred    -95.649721     -1.699670        -12.088889
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -47.067042     -1.493119         -8.086802
# 2             HV_cw   -104.355255     -1.993642        -10.435525
# 3         LSTM_pred   -160.926026     -2.542600        -17.305207
# 4          GRU_pred   -109.802605     -1.790302        -12.276191
# 5     LSTM_GRU_pred   -146.022349     -2.094605        -14.619433
# 6       BiLSTM_pred   -142.598337     -2.234618        -15.032140
# 7   BiLSTM_GRU_pred   -106.959504     -2.284197        -16.267777
# 8         QRNN_pred   -104.355255     -2.150617        -14.316111
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred   -110.179821     -1.870935        -12.527096
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -62.505105     -1.791257         -9.790766
# 2             HV_cw   -130.024533     -2.160725        -13.092606
# 3         LSTM_pred   -160.926026     -2.542600        -17.305207
# 4          GRU_pred   -119.246613     -1.794878        -11.924661
# 5     LSTM_GRU_pred   -155.440148     -2.204550        -15.561023
# 6       BiLSTM_pred   -140.289585     -2.122093        -14.803344
# 7   BiLSTM_GRU_pred   -106.959504     -2.297812        -16.367808
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -1.993642        -10.435525
# 10         BNN_pred   -133.392170     -2.090825        -14.697300
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -99.868405     -2.198117        -14.510060
# 2             HV_cw    -66.073599     -1.540334         -8.172907
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -81.729071     -1.929077        -12.333426
# 5     LSTM_GRU_pred   -104.355255     -2.249109        -16.023600
# 6       BiLSTM_pred    -66.073599     -1.875368        -14.005008
# 7   BiLSTM_GRU_pred    -97.825501     -2.011454        -14.065173
# 8         QRNN_pred   -104.355255     -1.993642        -10.435525
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred    -99.868405     -2.200414        -15.602909
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -99.868405     -2.214056        -15.703735
# 2             HV_cw   -104.355255     -1.993642        -10.435525
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -68.163598     -1.901626        -14.005008
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.249109        -16.023600
# 8         QRNN_pred   -104.355255     -2.150617        -14.316111
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred   -104.355255     -2.249109        -16.023600
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw   -104.355255     -2.262708        -16.123923
# 2             HV_cw   -104.355255     -1.945234        -13.092606
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -88.104957     -2.088855        -14.602102
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -1.993642        -10.435525
# 10         BNN_pred   -104.355255     -2.262708        -16.123923
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -81.561499     -1.828333         -9.595458
# 2             HV_cw   -126.310680     -2.011372        -12.631068
# 3         LSTM_pred   -119.280777     -2.144987        -13.200867
# 4          GRU_pred   -139.073998     -2.416994        -15.151584
# 5     LSTM_GRU_pred   -143.055848     -2.204550        -15.561023
# 6       BiLSTM_pred   -156.014810     -2.330165        -16.361702
# 7   BiLSTM_GRU_pred   -150.363205     -2.297812        -16.367808
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -126.851851     -2.081684        -12.685185
# 10         BNN_pred   -152.209592     -2.373057        -16.462987
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -98.102290     -1.850717        -12.485860
# 1             HV_dw    -13.549228     -0.958878         -4.725124
# 2             HV_cw   -122.252411     -2.005997        -12.225241
# 3         LSTM_pred   -140.052654     -2.213823        -14.005265
# 4          GRU_pred   -126.221518     -2.341553        -13.884910
# 5     LSTM_GRU_pred    -84.957050     -1.685278        -11.159601
# 6       BiLSTM_pred    -85.871388     -1.981634        -10.419504
# 7   BiLSTM_GRU_pred    -90.099357     -2.221003        -10.342956
# 8         QRNN_pred    -94.882186     -2.070751        -14.036494
# 9          ESN_pred    -71.385894     -1.556236         -7.138589
# 10         BNN_pred   -140.135437     -2.379878        -15.273260
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -1.968260        -12.610402
# 1             HV_dw     -0.633903     -0.914676         -5.042351
# 2             HV_cw    -31.378004     -1.544065         -6.928360
# 3         LSTM_pred    -92.798375     -1.812684         -9.399733
# 4          GRU_pred      9.080235     -1.467519         -1.113775
# 5     LSTM_GRU_pred    -86.539896     -1.817299        -10.244869
# 6       BiLSTM_pred    -55.091781     -1.564314         -8.401102
# 7   BiLSTM_GRU_pred    -40.987057     -1.948815         -4.455205
# 8         QRNN_pred    -76.749405     -1.653615         -8.766878
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred   -124.757922     -2.244302        -14.199324
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -86.525652     -1.968260        -12.610402
# 1             HV_dw     -8.508078     -0.940149         -4.559354
# 2             HV_cw    -55.244838     -1.729826         -9.221644
# 3         LSTM_pred   -101.881653     -1.793218        -10.188165
# 4          GRU_pred    -98.009828     -2.010249         -9.894453
# 5     LSTM_GRU_pred    -82.006940     -1.700720        -10.352096
# 6       BiLSTM_pred   -110.172713     -2.034642        -11.818785
# 7   BiLSTM_GRU_pred    -54.323025     -1.772217         -8.558542
# 8         QRNN_pred    -83.431703     -1.953845        -12.418881
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred   -132.541858     -2.334447        -14.718579
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -98.102290     -1.850717        -12.485860
# 1             HV_dw    -48.928122     -1.408840         -6.498357
# 2             HV_cw    -93.635728     -1.879993        -10.632304
# 3         LSTM_pred   -118.073571     -2.003733        -11.807357
# 4          GRU_pred    -92.022003     -1.865766        -11.559940
# 5     LSTM_GRU_pred    -88.975069     -1.730790        -11.159601
# 6       BiLSTM_pred   -103.111095     -2.233770        -11.118984
# 7   BiLSTM_GRU_pred    -90.099357     -2.221003        -10.342956
# 8         QRNN_pred    -94.882186     -2.070751        -14.036494
# 9          ESN_pred    -50.448637     -1.791133         -5.691546
# 10         BNN_pred   -145.976440     -2.496536        -15.848803
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw      0.402778     -0.891856         -5.042351
# 2             HV_cw    -81.729071     -1.825059         -8.172907
# 3         LSTM_pred    -93.100392     -1.952476        -10.620663
# 4          GRU_pred      4.407007     -1.163918         -2.490871
# 5     LSTM_GRU_pred   -141.011978     -2.244731        -14.101198
# 6       BiLSTM_pred    -71.742003     -1.845849        -10.015166
# 7   BiLSTM_GRU_pred    -90.593147     -1.785969        -10.687171
# 8         QRNN_pred    -97.825501     -1.905765         -9.986840
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred   -105.200405     -1.872846        -12.916891
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw     -7.479566     -0.920294         -4.559354
# 2             HV_cw   -104.355255     -1.993642        -10.435525
# 3         LSTM_pred   -102.180646     -1.928097        -11.515566
# 4          GRU_pred   -123.817088     -2.290643        -12.472504
# 5     LSTM_GRU_pred   -146.194328     -2.304534        -14.619433
# 6       BiLSTM_pred   -125.461357     -2.048695        -13.333878
# 7   BiLSTM_GRU_pred   -143.145224     -2.208430        -15.848309
# 8         QRNN_pred   -104.355255     -2.181082        -14.418195
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred   -113.158276     -1.963647        -12.916891
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -64.977875     -1.607331         -8.171495
# 2             HV_cw    -97.826305     -1.886263        -10.435525
# 3         LSTM_pred   -119.280777     -2.144987        -13.200867
# 4          GRU_pred   -111.470264     -2.061992        -13.454265
# 5     LSTM_GRU_pred   -143.055848     -2.204550        -15.561023
# 6       BiLSTM_pred   -146.855018     -2.222390        -15.453974
# 7   BiLSTM_GRU_pred   -150.363205     -2.297812        -16.367808
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.407950     -2.115467        -10.440795
# 10         BNN_pred   -129.501273     -2.163677        -14.327688
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -49.715842     -1.857942        -10.905072
# 2             HV_cw    -81.729071     -1.825059         -8.172907
# 3         LSTM_pred    -99.868405     -2.214056        -15.703735
# 4          GRU_pred    -49.715842     -1.502791         -9.133014
# 5     LSTM_GRU_pred   -104.355255     -2.249109        -16.023600
# 6       BiLSTM_pred    -66.073599     -1.875368        -14.005008
# 7   BiLSTM_GRU_pred    -97.825501     -1.869890        -12.809703
# 8         QRNN_pred    -97.825501     -1.905765         -9.986840
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred    -99.868405     -2.200414        -15.602909
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.150617        -14.316111
# 1             HV_dw    -99.868405     -2.039028        -14.065173
# 2             HV_cw   -104.355255     -1.993642        -10.435525
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -68.163598     -1.901626        -14.005008
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred    -88.104957     -2.088855        -14.602102
# 7   BiLSTM_GRU_pred    -97.825501     -2.173316        -15.602909
# 8         QRNN_pred   -104.355255     -2.181082        -14.418195
# 9          ESN_pred      0.000000          -inf          0.000000
# 10         BNN_pred    -97.825501     -2.173316        -15.602909
# 11               __   -104.355255     -2.262708        -16.123923
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV   -104.355255     -2.262708        -16.123923
# 1             HV_dw    -97.825501     -2.186948        -15.703735
# 2             HV_cw   -104.355255     -2.150617        -14.316111
# 3         LSTM_pred   -104.355255     -2.262708        -16.123923
# 4          GRU_pred    -68.163598     -1.901626        -14.005008
# 5     LSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 6       BiLSTM_pred   -104.355255     -2.262708        -16.123923
# 7   BiLSTM_GRU_pred   -104.355255     -2.262708        -16.123923
# 8         QRNN_pred   -104.355255     -2.262708        -16.123923
# 9          ESN_pred   -104.355255     -1.993642        -10.435525
# 10         BNN_pred   -104.355255     -2.249109        -16.023600
# 11               __   -104.355255     -2.262708        -16.123923

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y1', file, 'HV')
get_final_results_1('2024_y1', file, 'HV')

get_final_results('2024_y1', dw_file, 'HV_dw')
get_final_results_1('2024_y1', dw_file, 'HV_dw')

get_final_results('2024_y1', cw_file, 'HV_cw')
get_final_results_1('2024_y1', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:51: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-48-dbce691e5d20>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-48-dbce691e5d20>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']
# <ipython-input-4-b267510ae310>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
# <ipython-input-4-b267510ae310>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Long_MA'] = data['Close'].rolling(window=long_window).mean()
# <ipython-input-4-b267510ae310>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-4-b267510ae310>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-4-b267510ae310>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.196048     -0.042808         -8.541342
# 1             HV_dw     81.293115      0.202697         -6.351203
# 2             HV_cw     45.176971     -0.103861         -8.820072
# 3         LSTM_pred     -9.776428     -0.146882         -9.761087
# 4          GRU_pred     17.821439     -0.286611         -8.763174
# 5     LSTM_GRU_pred    -27.068897     -0.510332        -10.381609
# 6       BiLSTM_pred    -73.508058     -0.221840         -8.942539
# 7   BiLSTM_GRU_pred    -83.091861     -0.314479         -9.951725
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     32.943348     -0.101930         -9.033432
# 10         BNN_pred    -15.352400     -0.377210         -9.036014
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     27.350350     -0.162392         -8.945192
# 1             HV_dw     82.015740      0.280097         -5.105717
# 2             HV_cw     42.994999     -0.180223         -7.793067
# 3         LSTM_pred      7.810708     -0.334317         -8.934538
# 4          GRU_pred     15.886000     -0.274972         -9.977753
# 5     LSTM_GRU_pred     25.969155     -0.187601         -9.879692
# 6       BiLSTM_pred    -13.366256     -0.691589        -12.120795
# 7   BiLSTM_GRU_pred     25.466804     -0.301907        -11.460576
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     61.446686      0.140343         -5.903597
# 10         BNN_pred    -34.916033     -0.690514        -11.704222
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     38.069634      0.006046         -8.820397
# 1             HV_dw    114.153393      0.581649         -5.874749
# 2             HV_cw     70.957967      0.272692         -6.441097
# 3         LSTM_pred     17.286708     -0.252620         -9.485322
# 4          GRU_pred     99.294954      0.491506         -5.433704
# 5     LSTM_GRU_pred     95.781551      0.460867         -5.381699
# 6       BiLSTM_pred     -4.862201     -0.659736        -10.069221
# 7   BiLSTM_GRU_pred     14.608716     -0.417487        -11.525564
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     20.084910     -0.272691         -7.293186
# 10         BNN_pred     29.901072     -0.084126         -7.366763
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     37.262754     -0.083134         -8.906916
# 1             HV_dw     59.957495      0.037721         -6.043053
# 2             HV_cw     59.176666     -0.018795         -6.861839
# 3         LSTM_pred     17.286708     -0.252620         -9.485322
# 4          GRU_pred     57.009690      0.090007         -8.062485
# 5     LSTM_GRU_pred     68.750718      0.195758         -7.973913
# 6       BiLSTM_pred     -9.007527     -0.651337        -12.120795
# 7   BiLSTM_GRU_pred     14.608716     -0.417487        -11.525564
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     52.814923      0.061988         -5.952000
# 10         BNN_pred      3.222454     -0.329977         -9.763743
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     27.350350     -0.162392         -8.945192
# 1             HV_dw     69.310888      0.164814         -5.966126
# 2             HV_cw     45.029325     -0.140705         -7.717994
# 3         LSTM_pred     16.865138     -0.253355         -9.387110
# 4          GRU_pred     15.886000     -0.274972         -9.977753
# 5     LSTM_GRU_pred     25.969155     -0.187601         -9.879692
# 6       BiLSTM_pred    -13.366256     -0.691589        -12.120795
# 7   BiLSTM_GRU_pred     14.859188     -0.404093        -12.474916
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     61.446686      0.140343         -5.903597
# 10         BNN_pred    -34.916033     -0.690514        -11.704222
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -75.319323     -0.253811         -8.736460
# 1             HV_dw    153.489675      0.886645         -4.980198
# 2             HV_cw     45.176971      0.022645         -8.829132
# 3         LSTM_pred     -9.776428     -0.146882         -9.761087
# 4          GRU_pred     82.384906      0.184246         -5.534116
# 5     LSTM_GRU_pred     55.538506      0.208385         -6.725466
# 6       BiLSTM_pred    -41.713719      0.063417         -7.368823
# 7   BiLSTM_GRU_pred    -83.091861     -0.314479         -9.951725
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     28.976251     -0.135940         -9.068260
# 10         BNN_pred    -16.258279     -0.386077         -9.044335
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -75.319323     -0.253811         -8.736460
# 1             HV_dw     84.887865      0.233357         -6.330158
# 2             HV_cw     45.176971     -0.123174         -8.840085
# 3         LSTM_pred     -9.776428     -0.146882         -9.761087
# 4          GRU_pred     59.023477      0.069191         -6.625742
# 5     LSTM_GRU_pred     13.501049     -0.153987         -7.924109
# 6       BiLSTM_pred    -73.508058     -0.230547         -8.951449
# 7   BiLSTM_GRU_pred    -83.091861     -0.314479         -9.951725
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     28.976251     -0.135940         -9.068260
# 10         BNN_pred    -15.984014     -0.382875         -9.041814
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.196048     -0.042808         -8.541342
# 1             HV_dw     81.293115      0.202697         -6.351203
# 2             HV_cw     45.176971     -0.102488         -8.818701
# 3         LSTM_pred     -9.776428     -0.146882         -9.761087
# 4          GRU_pred     17.821439     -0.286611         -8.763174
# 5     LSTM_GRU_pred    -27.068897     -0.510332        -10.381609
# 6       BiLSTM_pred    -73.508058     -0.221840         -8.942539
# 7   BiLSTM_GRU_pred    -83.091861     -0.314479         -9.951725
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     32.943348     -0.101930         -9.033432
# 10         BNN_pred    -15.352400     -0.377210         -9.036014
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -26.913371      0.218999         -7.361793
# 2             HV_cw    -73.508058     -0.221840         -8.942539
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -27.713578      0.202514         -7.361793
# 5     LSTM_GRU_pred    -27.713578      0.202514         -7.361793
# 6       BiLSTM_pred    -41.713719      0.063417         -7.368823
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -73.508058     -0.221840         -8.942539
# 10         BNN_pred    -73.508058     -0.194222         -8.914067
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -73.508058     -0.221840         -8.942539
# 2             HV_cw    -73.508058     -0.221840         -8.942539
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -56.627144     -0.066479         -7.708285
# 5     LSTM_GRU_pred    -56.627144     -0.066479         -7.708285
# 6       BiLSTM_pred    -73.508058     -0.230547         -8.951449
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -73.508058     -0.221840         -8.942539
# 10         BNN_pred    -73.508058     -0.230547         -8.951449
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058      -0.22184         -8.942539
# 1             HV_dw    -73.508058      -0.22184         -8.942539
# 2             HV_cw    -73.508058      -0.22184         -8.942539
# 3         LSTM_pred    -73.508058      -0.22184         -8.942539
# 4          GRU_pred    -73.508058      -0.22184         -8.942539
# 5     LSTM_GRU_pred    -73.508058      -0.22184         -8.942539
# 6       BiLSTM_pred    -73.508058      -0.22184         -8.942539
# 7   BiLSTM_GRU_pred    -73.508058      -0.22184         -8.942539
# 8         QRNN_pred    -73.508058      -0.22184         -8.942539
# 9          ESN_pred    -73.508058      -0.22184         -8.942539
# 10         BNN_pred    -73.508058      -0.22184         -8.942539
# 11               __    -73.508058      -0.22184         -8.942539
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -47.503704      0.018412         -8.698396
# 1             HV_dw     39.698778     -0.090990         -8.911137
# 2             HV_cw     38.724113     -0.177782         -8.840085
# 3         LSTM_pred    -55.089474     -0.081217         -8.798451
# 4          GRU_pred    -27.068897     -0.510332        -10.381609
# 5     LSTM_GRU_pred    -29.393146     -0.531463        -10.406469
# 6       BiLSTM_pred    -73.508058     -0.221840         -8.942539
# 7   BiLSTM_GRU_pred    -47.675041     -0.194928         -8.621677
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     31.885193     -0.110940         -9.042696
# 10         BNN_pred    -15.019769     -0.379185        -10.003955
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -62.555975     -0.146173         -8.860068
# 1             HV_dw    135.447961      0.786591         -4.372934
# 2             HV_cw      7.613596     -0.327015        -10.544642
# 3         LSTM_pred      3.807717     -0.305548         -9.297371
# 4          GRU_pred     -4.708224     -0.456884        -10.985179
# 5     LSTM_GRU_pred     27.990818     -0.165675         -9.212051
# 6       BiLSTM_pred     -3.465508     -0.598268        -12.120795
# 7   BiLSTM_GRU_pred    -32.446707     -0.235189         -9.037998
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     90.632828      0.397658         -5.705436
# 10         BNN_pred    -28.391043     -0.599363        -11.463140
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -70.231644     -0.442166         -9.129037
# 1             HV_dw    166.804189      1.195071         -4.289413
# 2             HV_cw     93.196423      0.504989         -5.371873
# 3         LSTM_pred      8.953864     -0.268031        -10.141905
# 4          GRU_pred     68.364057      0.196428         -5.809321
# 5     LSTM_GRU_pred     93.382039      0.429264         -5.355832
# 6       BiLSTM_pred     17.575794     -0.435865         -8.918495
# 7   BiLSTM_GRU_pred    -73.684241     -0.648942        -10.026686
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     76.749060      0.300811         -5.779003
# 10         BNN_pred     30.259390     -0.073043         -7.116364
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.944896      0.008352         -8.705805
# 1             HV_dw    121.791956      0.676755         -4.429319
# 2             HV_cw     41.689624     -0.036047         -7.864296
# 3         LSTM_pred      8.953864     -0.268031        -10.141905
# 4          GRU_pred     26.016204     -0.187387         -8.784901
# 5     LSTM_GRU_pred     61.405188      0.129199         -7.856236
# 6       BiLSTM_pred      1.865319     -0.549643        -12.098228
# 7   BiLSTM_GRU_pred    -64.555905     -0.550862         -9.982481
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     95.624513      0.445392         -5.679442
# 10         BNN_pred     17.800439     -0.179599         -9.413344
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -43.025183      0.037129         -8.679244
# 1             HV_dw    135.447961      0.786591         -4.372934
# 2             HV_cw     13.240580     -0.406146        -10.085763
# 3         LSTM_pred     20.246568     -0.156715         -9.147566
# 4          GRU_pred     -4.708224     -0.456884        -10.985179
# 5     LSTM_GRU_pred     27.990818     -0.165675         -9.212051
# 6       BiLSTM_pred     -3.465508     -0.598268        -12.120795
# 7   BiLSTM_GRU_pred    -33.545093     -0.247277         -9.681570
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     90.632828      0.397658         -5.705436
# 10         BNN_pred    -28.391043     -0.599363        -11.463140
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.022474     -0.177769         -8.889904
# 1             HV_dw    130.991095      0.689925         -5.784257
# 2             HV_cw     84.988157      0.414601         -7.277449
# 3         LSTM_pred    -55.089474     -0.120714         -8.837903
# 4          GRU_pred     34.885923      0.041575         -6.799538
# 5     LSTM_GRU_pred     24.985146     -0.046108         -6.865218
# 6       BiLSTM_pred    -41.713719      0.100461         -7.338353
# 7   BiLSTM_GRU_pred    -47.675041     -0.342918         -8.761636
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     31.885193     -0.110940         -9.042696
# 10         BNN_pred    -20.035511     -0.425012        -10.055158
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.022474     -0.177769         -8.889904
# 1             HV_dw     43.897984     -0.091607         -8.849743
# 2             HV_cw     40.977508     -0.036361         -8.840085
# 3         LSTM_pred    -55.089474     -0.120714         -8.837903
# 4          GRU_pred      4.139412     -0.248625         -7.715402
# 5     LSTM_GRU_pred     -9.865821     -0.373383         -7.824535
# 6       BiLSTM_pred    -73.508058     -0.230547         -8.951449
# 7   BiLSTM_GRU_pred    -47.675041     -0.141457         -8.569010
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     31.885193     -0.110940         -9.042696
# 10         BNN_pred    -15.651596     -0.384908        -10.010376
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -55.923361     -0.060936         -8.775972
# 1             HV_dw     39.698778     -0.090990         -8.911137
# 2             HV_cw     40.977508     -0.159126         -8.840085
# 3         LSTM_pred    -55.089474     -0.120714         -8.837903
# 4          GRU_pred    -27.068897     -0.510332        -10.381609
# 5     LSTM_GRU_pred    -29.393146     -0.531463        -10.406469
# 6       BiLSTM_pred    -73.508058     -0.221840         -8.942539
# 7   BiLSTM_GRU_pred    -47.675041     -0.141457         -8.569010
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     31.885193     -0.110940         -9.042696
# 10         BNN_pred    -15.019769     -0.379185        -10.003955
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -19.086148      0.298181         -7.361793
# 2             HV_cw    -34.337652      0.140602         -7.361793
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -34.337652      0.140602         -7.361793
# 5     LSTM_GRU_pred    -34.337652      0.140602         -7.361793
# 6       BiLSTM_pred    -41.713719      0.100461         -7.338353
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -73.508058     -0.221840         -8.942539
# 10         BNN_pred    -73.508058     -0.230547         -8.951449
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -73.508058     -0.221840         -8.942539
# 2             HV_cw    -73.508058     -0.221840         -8.942539
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -58.861497     -0.086826         -7.439946
# 5     LSTM_GRU_pred    -58.861497     -0.086826         -7.439946
# 6       BiLSTM_pred    -73.508058     -0.230547         -8.951449
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -73.508058     -0.221840         -8.942539
# 10         BNN_pred    -73.508058     -0.230547         -8.951449
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058      -0.22184         -8.942539
# 1             HV_dw    -73.508058      -0.22184         -8.942539
# 2             HV_cw    -73.508058      -0.22184         -8.942539
# 3         LSTM_pred    -73.508058      -0.22184         -8.942539
# 4          GRU_pred    -73.508058      -0.22184         -8.942539
# 5     LSTM_GRU_pred    -73.508058      -0.22184         -8.942539
# 6       BiLSTM_pred    -73.508058      -0.22184         -8.942539
# 7   BiLSTM_GRU_pred    -73.508058      -0.22184         -8.942539
# 8         QRNN_pred    -73.508058      -0.22184         -8.942539
# 9          ESN_pred    -73.508058      -0.22184         -8.942539
# 10         BNN_pred    -73.508058      -0.22184         -8.942539
# 11               __    -73.508058      -0.22184         -8.942539
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -66.990313     -0.163553         -8.268057
# 1             HV_dw     91.269711      0.381790         -6.320156
# 2             HV_cw    -52.640005      0.042735         -7.586410
# 3         LSTM_pred    -16.661597     -0.224132         -8.587661
# 4          GRU_pred     41.460149     -0.047358         -9.732738
# 5     LSTM_GRU_pred     19.446388     -0.100557         -7.846230
# 6       BiLSTM_pred     -7.469529     -0.636092        -12.120795
# 7   BiLSTM_GRU_pred    -35.161848     -0.468859         -8.456635
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     43.908656     -0.015804         -7.296724
# 10         BNN_pred      8.280191     -0.266877        -10.505230
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -69.515826     -0.198417         -8.528286
# 1             HV_dw     71.754501      0.225204         -6.920952
# 2             HV_cw     81.915091      0.190522         -6.502511
# 3         LSTM_pred      6.166558     -0.542627         -8.411212
# 4          GRU_pred     39.532671     -0.082093         -8.325698
# 5     LSTM_GRU_pred      7.497205     -0.375104        -10.060831
# 6       BiLSTM_pred    -14.384002     -0.617589        -12.118929
# 7   BiLSTM_GRU_pred    -43.589895     -0.698772        -10.435405
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred    101.204536      0.504968         -5.650663
# 10         BNN_pred    -51.915389     -0.950049        -11.257723
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.689150         -2.417327
# 1             HV_dw     55.013867      0.177893         -5.970702
# 2             HV_cw     58.411983      0.213543         -6.821532
# 3         LSTM_pred     60.132647     -0.010750         -4.742587
# 4          GRU_pred     42.416508     -0.091059         -4.433259
# 5     LSTM_GRU_pred     35.662029     -0.168927         -7.124775
# 6       BiLSTM_pred     49.413938      0.004496         -6.977757
# 7   BiLSTM_GRU_pred    -83.780201     -1.467656        -10.194250
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred    -10.871165     -0.695960         -6.455602
# 10         BNN_pred     -1.906567     -0.539122         -7.080138
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -40.820321      0.078837         -7.361793
# 1             HV_dw     49.269728      0.108277         -6.456619
# 2             HV_cw    114.281092      0.635648         -5.358157
# 3         LSTM_pred     29.847344     -0.331657         -8.096849
# 4          GRU_pred     65.089228      0.170504         -6.697657
# 5     LSTM_GRU_pred     20.701250     -0.277519         -7.229205
# 6       BiLSTM_pred    -21.299579     -0.716349        -10.929474
# 7   BiLSTM_GRU_pred    -61.226317     -0.998618        -10.194250
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     97.748133      0.508266         -5.668455
# 10         BNN_pred    -44.019604     -0.964060        -11.454396
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -47.467524      0.016576         -7.361793
# 1             HV_dw     70.703863      0.217505         -5.824543
# 2             HV_cw    117.852258      0.505489         -6.408134
# 3         LSTM_pred      7.312591     -0.579331         -8.277985
# 4          GRU_pred     57.113084      0.090517         -8.180319
# 5     LSTM_GRU_pred     15.896944     -0.297048         -9.977645
# 6       BiLSTM_pred    -17.857137     -0.664772        -12.232963
# 7   BiLSTM_GRU_pred    -54.350053     -0.881243        -10.311529
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     91.284627      0.422524         -5.702029
# 10         BNN_pred    -43.062809     -0.876516        -11.817326
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.689150         -2.417327
# 1             HV_dw     64.711639      0.161647         -6.818664
# 2             HV_cw    -31.185848      0.147509         -6.734441
# 3         LSTM_pred     54.888277      0.490313         -2.978956
# 4          GRU_pred     60.895679      0.131967         -5.672065
# 5     LSTM_GRU_pred     96.551875      0.747378         -5.183464
# 6       BiLSTM_pred     21.232743     -0.421101        -10.644542
# 7   BiLSTM_GRU_pred    -50.748780     -0.935723         -8.247885
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred    -22.129175     -0.679066         -8.902959
# 10         BNN_pred     87.378489      0.483703         -6.717627
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.669736     -0.051603         -7.708285
# 1             HV_dw     72.932590      0.235920         -6.837408
# 2             HV_cw    -18.301252      0.153950         -7.416654
# 3         LSTM_pred    -24.829545     -0.308946         -8.659591
# 4          GRU_pred     90.148050      0.388901         -6.768676
# 5     LSTM_GRU_pred     59.613362      0.269814         -5.406999
# 6       BiLSTM_pred    -36.405932     -0.922836        -11.988246
# 7   BiLSTM_GRU_pred    -47.278620     -0.603019         -8.460609
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     61.267564      0.139779         -7.177373
# 10         BNN_pred     68.481883      0.283858         -6.655894
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -58.328573     -0.082450         -7.708285
# 1             HV_dw     78.145037      0.272924         -6.335711
# 2             HV_cw    -35.378870      0.239662         -7.557269
# 3         LSTM_pred    -24.829545     -0.308946         -8.659591
# 4          GRU_pred     45.387917     -0.013092         -9.696170
# 5     LSTM_GRU_pred     44.607027      0.110602         -7.666208
# 6       BiLSTM_pred    -15.226185     -0.711596        -12.120795
# 7   BiLSTM_GRU_pred    -45.602277     -0.574102         -9.717647
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     53.966420      0.073371         -7.227093
# 10         BNN_pred     39.655059      0.018288         -8.786220
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.689150         -2.417327
# 1             HV_dw    -79.332919     -0.289903         -9.553400
# 2             HV_cw    -38.684313      0.100507         -6.762984
# 3         LSTM_pred    -18.401649      0.289059         -7.361793
# 4          GRU_pred    -20.229749      0.272156         -7.361793
# 5     LSTM_GRU_pred    -34.337652      0.131675         -7.369127
# 6       BiLSTM_pred    -27.713578      0.131328         -7.420293
# 7   BiLSTM_GRU_pred    -73.508058     -0.230186         -8.951078
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -73.508058     -0.221840         -8.942539
# 10         BNN_pred    -56.627144     -0.038375         -7.683742
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.669736     -0.051603         -7.708285
# 1             HV_dw    -79.332919     -0.289903         -9.553400
# 2             HV_cw    -25.899441      0.219357         -7.361793
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -41.713719      0.071952         -7.361793
# 5     LSTM_GRU_pred    -41.713719      0.071952         -7.361793
# 6       BiLSTM_pred    -73.508058     -0.230186         -8.951078
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -73.508058     -0.221840         -8.942539
# 10         BNN_pred    -73.508058     -0.230547         -8.951449
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -73.508058     -0.221840         -8.942539
# 2             HV_cw    -42.844881      0.061460         -7.708285
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.230547         -8.951449
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -73.508058     -0.221840         -8.942539
# 10         BNN_pred    -73.508058     -0.221840         -8.942539
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -80.125474     -0.292028         -9.637114
# 1             HV_dw     71.698544      0.311255         -5.556165
# 2             HV_cw    -57.130581     -0.141700         -7.741833
# 3         LSTM_pred     14.430653     -0.074847         -9.040418
# 4          GRU_pred     43.230118     -0.031615         -9.716226
# 5     LSTM_GRU_pred     27.944826      0.057838         -8.966450
# 6       BiLSTM_pred    -26.020088     -0.692088        -11.149144
# 7   BiLSTM_GRU_pred    -84.077572     -1.027534        -10.544547
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     97.852704      0.461208         -5.707828
# 10         BNN_pred      9.136975     -0.281832         -7.782069
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -43.676006      0.051661         -7.372988
# 1             HV_dw     69.330200      0.208669         -8.064055
# 2             HV_cw     57.262769      0.178636         -7.157515
# 3         LSTM_pred    -50.320272     -1.049432         -7.876028
# 4          GRU_pred     39.532671     -0.082093         -8.325698
# 5     LSTM_GRU_pred    -11.787473     -0.576381        -11.912709
# 6       BiLSTM_pred     22.299529     -0.259011        -10.524821
# 7   BiLSTM_GRU_pred    -54.674062     -0.816818         -9.745111
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     90.330543      0.424746         -6.880092
# 10         BNN_pred    -34.475213     -0.764294        -10.041067
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.597076         -2.417327
# 1             HV_dw     60.475623      0.268185         -3.597310
# 2             HV_cw     66.281382      0.316526         -6.697001
# 3         LSTM_pred      2.145656     -0.777051         -4.118997
# 4          GRU_pred     73.389194      0.339121         -2.860917
# 5     LSTM_GRU_pred     25.607738     -0.346632         -5.778999
# 6       BiLSTM_pred     33.212782     -0.203024         -5.763475
# 7   BiLSTM_GRU_pred    -71.654825     -1.319135         -9.503002
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred    -56.475749     -1.449634         -7.559154
# 10         BNN_pred    -21.758522     -0.934341         -4.797532
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     19.562950      0.699309         -7.240594
# 1             HV_dw     66.049772      0.300697         -4.752209
# 2             HV_cw     88.834299      0.523375         -4.673487
# 3         LSTM_pred    -23.041834     -0.877135         -6.749677
# 4          GRU_pred     65.089228      0.170504         -6.697657
# 5     LSTM_GRU_pred     10.506128     -0.416593         -8.153627
# 6       BiLSTM_pred     44.660833     -0.046675         -6.819852
# 7   BiLSTM_GRU_pred    -36.517478     -0.756914         -9.481954
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     70.079744      0.253062         -7.045277
# 10         BNN_pred    -44.056079     -1.041138         -9.480998
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -17.211600      0.309161         -7.240594
# 1             HV_dw     59.852583      0.222247         -5.260465
# 2             HV_cw     72.503340      0.320961         -7.695500
# 3         LSTM_pred    -23.041834     -0.877135         -6.749677
# 4          GRU_pred     47.476164     -0.006127         -7.736986
# 5     LSTM_GRU_pred     33.888039     -0.136936         -8.718014
# 6       BiLSTM_pred     -3.191393     -0.535080        -11.271780
# 7   BiLSTM_GRU_pred    -54.084819     -0.928555         -9.503002
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     71.916682      0.262758         -6.998281
# 10         BNN_pred      2.426967     -0.415324         -7.043867
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.597076         -2.417327
# 1             HV_dw     47.134363      0.085189         -6.861224
# 2             HV_cw    -32.883657      0.128286         -6.746264
# 3         LSTM_pred     43.291654      0.152095         -3.365272
# 4          GRU_pred     82.210592      0.378025         -6.077638
# 5     LSTM_GRU_pred     97.720381      0.569575         -5.388142
# 6       BiLSTM_pred     -1.897923     -0.547992         -8.678207
# 7   BiLSTM_GRU_pred    -49.960207     -0.971069         -8.911887
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     -8.887637     -0.598252         -7.201592
# 10         BNN_pred     22.411464     -0.191390         -7.998376
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      2.064177      0.516451         -7.361793
# 1             HV_dw     74.881625      0.367996         -5.093600
# 2             HV_cw    -30.814054      0.033180         -7.429675
# 3         LSTM_pred      5.480283     -0.165901         -9.746812
# 4          GRU_pred     90.506581      0.392298         -6.766450
# 5     LSTM_GRU_pred     60.232700      0.369745         -6.614691
# 6       BiLSTM_pred     10.261841     -0.377118         -6.643238
# 7   BiLSTM_GRU_pred    -29.605681     -0.490254         -8.759308
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred    104.188668      0.552932         -5.675075
# 10         BNN_pred     21.759682     -0.171299         -6.600326
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.669736     -0.051603         -7.708285
# 1             HV_dw     63.941233      0.249976         -5.495618
# 2             HV_cw    -35.272650     -0.010816         -7.782366
# 3         LSTM_pred      5.480283     -0.165901         -9.746812
# 4          GRU_pred     92.000765      0.405417         -6.757192
# 5     LSTM_GRU_pred     63.192884      0.378860         -7.633583
# 6       BiLSTM_pred    -45.421537     -0.895911        -10.998956
# 7   BiLSTM_GRU_pred    -54.866127     -0.734432         -8.911887
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred    110.567326      0.596765         -5.642480
# 10         BNN_pred     52.604512      0.138471         -6.467214
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.597076         -2.417327
# 1             HV_dw    -79.332919     -0.289903         -9.553400
# 2             HV_cw    -38.684313      0.100507         -6.762984
# 3         LSTM_pred    -18.401649      0.289059         -7.361793
# 4          GRU_pred    -20.229749      0.263149         -7.369127
# 5     LSTM_GRU_pred    -20.229749      0.263149         -7.369127
# 6       BiLSTM_pred    -27.713578      0.131328         -7.420293
# 7   BiLSTM_GRU_pred    -73.508058     -0.194222         -8.914067
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -73.508058     -0.221840         -8.942539
# 10         BNN_pred    -41.713719     -0.018332         -7.538186
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      2.064177      0.516451         -7.361793
# 1             HV_dw    -79.332919     -0.289903         -9.553400
# 2             HV_cw    -36.627123      0.119717         -7.361793
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -41.713719      0.071952         -7.361793
# 5     LSTM_GRU_pred    -34.337652      0.140602         -7.361793
# 6       BiLSTM_pred    -41.713719      0.063417         -7.368823
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -73.508058     -0.221840         -8.942539
# 10         BNN_pred    -73.508058     -0.230547         -8.951449
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.669736     -0.051603         -7.708285
# 1             HV_dw    -73.508058     -0.221840         -8.942539
# 2             HV_cw    -41.058977      0.078098         -7.708285
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -41.713719      0.071952         -7.361793
# 5     LSTM_GRU_pred    -58.861497     -0.086826         -7.439946
# 6       BiLSTM_pred    -73.508058     -0.230186         -8.951078
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -73.508058     -0.221840         -8.942539
# 10         BNN_pred    -73.508058     -0.230547         -8.951449
# 11               __    -73.508058     -0.221840         -8.942539

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.196048     -0.042808         -8.541342
# 1             HV_dw     18.260851      0.063343         -6.448875
# 2             HV_cw     29.826379     -0.261487         -8.771498
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.221840         -8.942539
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     35.341746     -0.081581         -8.770195
# 10         BNN_pred     10.816692     -0.146383         -8.027931
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     27.350350     -0.162392         -8.945192
# 1             HV_dw     81.831713      0.282080         -4.757186
# 2             HV_cw     49.432275     -0.099509         -7.791900
# 3         LSTM_pred      6.062632     -0.264610         -8.579665
# 4          GRU_pred    -21.413112     -0.611131        -10.282634
# 5     LSTM_GRU_pred    -28.204147     -0.615787        -11.979320
# 6       BiLSTM_pred    -13.366256     -0.691589        -12.120795
# 7   BiLSTM_GRU_pred      1.056130     -0.420499        -11.489407
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     24.623849     -0.120861         -7.138743
# 10         BNN_pred     40.509735     -0.179602         -6.854150
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     38.069634      0.006046         -8.820397
# 1             HV_dw     60.907929      0.016259         -5.642540
# 2             HV_cw     65.799609      0.212144         -7.688885
# 3         LSTM_pred     52.438455      0.035814         -4.799436
# 4          GRU_pred    -49.121444     -0.897190        -10.915738
# 5     LSTM_GRU_pred    -29.198126     -0.638926        -12.142065
# 6       BiLSTM_pred     -4.862201     -0.659736        -10.069221
# 7   BiLSTM_GRU_pred     44.779743     -0.029085         -8.888099
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     96.624728      0.578553         -4.748520
# 10         BNN_pred     59.699080     -0.014520         -5.412844
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     37.262754     -0.083134         -8.906916
# 1             HV_dw     63.993194      0.075296         -4.174225
# 2             HV_cw     50.905526     -0.091470         -7.797856
# 3         LSTM_pred     39.443826      0.030230         -6.028043
# 4          GRU_pred    -21.413112     -0.611131        -10.282634
# 5     LSTM_GRU_pred    -23.580697     -0.571844        -11.979320
# 6       BiLSTM_pred     -9.007527     -0.651337        -12.120795
# 7   BiLSTM_GRU_pred     38.343843     -0.083023         -7.630433
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     33.897119     -0.044559         -7.267036
# 10         BNN_pred     49.016813     -0.103111         -6.074765
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     27.350350     -0.162392         -8.945192
# 1             HV_dw     63.993194      0.116263         -4.157454
# 2             HV_cw     63.269892      0.024124         -7.718498
# 3         LSTM_pred      6.062632     -0.264610         -8.579665
# 4          GRU_pred    -21.413112     -0.611131        -10.282634
# 5     LSTM_GRU_pred    -28.204147     -0.615787        -11.979320
# 6       BiLSTM_pred    -13.366256     -0.691589        -12.120795
# 7   BiLSTM_GRU_pred      1.056130     -0.420499        -11.489407
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     62.726768      0.230660         -4.960397
# 10         BNN_pred     40.509735     -0.179602         -6.854150
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -75.319323     -0.253811         -8.736460
# 1             HV_dw     15.079441      0.000757         -6.493092
# 2             HV_cw     11.168314     -0.284086         -9.574432
# 3         LSTM_pred    -48.862521     -0.073057         -8.377382
# 4          GRU_pred    -73.508058     -0.230186         -8.951078
# 5     LSTM_GRU_pred    -73.508058     -0.230186         -8.951078
# 6       BiLSTM_pred    -41.713719      0.063417         -7.368823
# 7   BiLSTM_GRU_pred    -27.713578      0.131328         -7.420293
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     97.368287      0.452903         -5.479897
# 10         BNN_pred     14.571945     -0.119968         -7.594518
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -75.319323     -0.253811         -8.736460
# 1             HV_dw     18.260851      0.063343         -6.448875
# 2             HV_cw      6.298047     -0.470619        -10.602757
# 3         LSTM_pred    -58.861497     -0.086826         -7.439946
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.230547         -8.951449
# 7   BiLSTM_GRU_pred    -58.861497     -0.086826         -7.439946
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     51.130509      0.049803         -7.479451
# 10         BNN_pred     10.816692     -0.146383         -8.027931
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.196048     -0.042808         -8.541342
# 1             HV_dw     18.260851      0.063343         -6.448875
# 2             HV_cw     16.822440     -0.379658         -9.580826
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.221840         -8.942539
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     70.871474      0.218189         -7.094904
# 10         BNN_pred     10.816692     -0.146383         -8.027931
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -73.508058     -0.230186         -8.951078
# 2             HV_cw    -73.508058     -0.221840         -8.942539
# 3         LSTM_pred    -48.862521     -0.073057         -8.377382
# 4          GRU_pred    -73.508058     -0.230186         -8.951078
# 5     LSTM_GRU_pred    -73.508058     -0.230186         -8.951078
# 6       BiLSTM_pred    -41.713719      0.063417         -7.368823
# 7   BiLSTM_GRU_pred    -27.713578      0.131328         -7.420293
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -34.337652      0.131675         -7.369127
# 10         BNN_pred    -69.226172     -0.189564         -8.498368
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -73.508058     -0.221840         -8.942539
# 2             HV_cw    -73.508058     -0.221840         -8.942539
# 3         LSTM_pred    -58.861497     -0.086826         -7.439946
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.230547         -8.951449
# 7   BiLSTM_GRU_pred    -58.861497     -0.086826         -7.439946
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -41.713719      0.071952         -7.361793
# 10         BNN_pred    -73.508058     -0.221840         -8.942539
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -73.508058     -0.221840         -8.942539
# 2             HV_cw    -73.508058     -0.221840         -8.942539
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.221840         -8.942539
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -41.713719      0.071952         -7.361793
# 10         BNN_pred    -73.508058     -0.221840         -8.942539
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -47.503704      0.018412         -8.698396
# 1             HV_dw    -22.311107     -0.296676         -9.119841
# 2             HV_cw     34.734814     -0.212117         -8.874167
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.221840         -8.942539
# 7   BiLSTM_GRU_pred     -0.628781     -0.316106         -9.510623
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     13.264615     -0.276384         -8.961281
# 10         BNN_pred     10.816692     -0.146383         -8.027931
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -62.555975     -0.146173         -8.860068
# 1             HV_dw     52.221896      0.011592         -6.505483
# 2             HV_cw      3.485591     -0.379393        -11.823837
# 3         LSTM_pred     46.845304     -0.092451         -8.201808
# 4          GRU_pred    -46.094174     -0.822205        -12.482333
# 5     LSTM_GRU_pred    -31.110916     -0.647525        -12.133375
# 6       BiLSTM_pred     -3.465508     -0.598268        -12.120795
# 7   BiLSTM_GRU_pred    -21.321327     -0.628363        -13.320715
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     30.848240     -0.053917         -7.708083
# 10         BNN_pred     20.862299     -0.066689         -6.712556
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -70.231644     -0.442166         -9.129037
# 1             HV_dw      0.699512     -0.535113         -9.011118
# 2             HV_cw     40.394115      0.020905         -6.774918
# 3         LSTM_pred     67.022983      0.079277         -5.817153
# 4          GRU_pred    -56.389414     -0.952929        -12.482333
# 5     LSTM_GRU_pred    -40.384707     -0.753923        -12.133375
# 6       BiLSTM_pred     17.575794     -0.435865         -8.918495
# 7   BiLSTM_GRU_pred     39.334733     -0.078414         -7.818966
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     76.822053      0.360256         -5.391916
# 10         BNN_pred     25.817177     -0.026709         -6.740773
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.944896      0.008352         -8.705805
# 1             HV_dw     31.402695     -0.216077         -6.599800
# 2             HV_cw     10.171824     -0.338305         -8.109665
# 3         LSTM_pred     37.591643     -0.174303         -8.274955
# 4          GRU_pred    -46.094174     -0.822205        -12.482333
# 5     LSTM_GRU_pred    -46.530134     -0.806360        -12.133375
# 6       BiLSTM_pred      1.865319     -0.549643        -12.098228
# 7   BiLSTM_GRU_pred     -4.401221     -0.481129        -10.946523
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred      2.988891     -0.315109         -9.396696
# 10         BNN_pred     20.862299     -0.066689         -6.712556
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -43.025183      0.037129         -8.679244
# 1             HV_dw     39.857133     -0.099142         -6.582838
# 2             HV_cw     -4.298426     -0.576817        -11.867382
# 3         LSTM_pred     46.845304     -0.092451         -8.201808
# 4          GRU_pred    -46.094174     -0.822205        -12.482333
# 5     LSTM_GRU_pred    -31.110916     -0.647525        -12.133375
# 6       BiLSTM_pred     -3.465508     -0.598268        -12.120795
# 7   BiLSTM_GRU_pred    -10.898620     -0.532722        -12.397601
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     25.457489     -0.105590         -7.666349
# 10         BNN_pred     20.862299     -0.066689         -6.712556
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.022474     -0.177769         -8.889904
# 1             HV_dw    -38.376671     -0.480503        -10.700851
# 2             HV_cw     45.945501      0.076329         -7.714046
# 3         LSTM_pred    -27.713578      0.131328         -7.420293
# 4          GRU_pred    -73.508058     -0.230186         -8.951078
# 5     LSTM_GRU_pred    -73.508058     -0.230186         -8.951078
# 6       BiLSTM_pred    -41.713719      0.100461         -7.338353
# 7   BiLSTM_GRU_pred     31.051746     -0.150901         -8.141207
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     80.841215      0.313346         -5.563690
# 10         BNN_pred     14.571945     -0.119968         -7.594518
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -68.022474     -0.177769         -8.889904
# 1             HV_dw    -21.614983     -0.323510         -9.084193
# 2             HV_cw     29.651244     -0.135099         -8.937326
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.230547         -8.951449
# 7   BiLSTM_GRU_pred     -3.026529     -0.439653         -9.641426
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     13.194309     -0.284704         -8.878975
# 10         BNN_pred     10.816692     -0.146383         -8.027931
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -55.923361     -0.060936         -8.775972
# 1             HV_dw    -22.311107     -0.296676         -9.119841
# 2             HV_cw     36.979555     -0.193524         -8.874167
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.221840         -8.942539
# 7   BiLSTM_GRU_pred     -0.628781     -0.316106         -9.510623
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     14.203757     -0.275626         -8.870138
# 10         BNN_pred     10.816692     -0.146383         -8.027931
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -73.508058     -0.230186         -8.951078
# 2             HV_cw    -56.627144     -0.066479         -7.708285
# 3         LSTM_pred    -27.713578      0.131328         -7.420293
# 4          GRU_pred    -73.508058     -0.230186         -8.951078
# 5     LSTM_GRU_pred    -73.508058     -0.230186         -8.951078
# 6       BiLSTM_pred    -41.713719      0.100461         -7.338353
# 7   BiLSTM_GRU_pred    -27.713578      0.131328         -7.420293
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -34.337652      0.131675         -7.369127
# 10         BNN_pred    -69.226172     -0.189564         -8.498368
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -73.508058     -0.221840         -8.942539
# 2             HV_cw    -73.508058     -0.221840         -8.942539
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.230547         -8.951449
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -58.861497     -0.095615         -7.447358
# 10         BNN_pred    -73.508058     -0.221840         -8.942539
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -73.508058     -0.221840         -8.942539
# 2             HV_cw    -73.508058     -0.221840         -8.942539
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.221840         -8.942539
# 7   BiLSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -58.861497     -0.086826         -7.439946
# 10         BNN_pred    -73.508058     -0.221840         -8.942539
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -66.990313     -0.163553         -8.268057
# 1             HV_dw     30.372792     -0.136787         -7.724371
# 2             HV_cw    -54.293761     -0.116007         -8.275310
# 3         LSTM_pred     29.640824     -0.157257        -10.653178
# 4          GRU_pred    -19.435525     -0.590823         -9.247605
# 5     LSTM_GRU_pred     20.437146     -0.160588         -8.619030
# 6       BiLSTM_pred     -7.469529     -0.636092        -12.120795
# 7   BiLSTM_GRU_pred     57.469686      0.094164         -7.825855
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred    -20.490762     -0.522935        -10.550651
# 10         BNN_pred    124.781328      0.549919         -5.444301
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -69.515826     -0.198417         -8.528286
# 1             HV_dw     34.884409     -0.135412         -6.717041
# 2             HV_cw    -10.968770      0.170094         -7.396476
# 3         LSTM_pred    -16.933899     -0.661500        -11.145370
# 4          GRU_pred    -12.612330     -0.522980        -10.004012
# 5     LSTM_GRU_pred      7.299047     -0.323573         -6.962384
# 6       BiLSTM_pred    -14.384002     -0.617589        -12.118929
# 7   BiLSTM_GRU_pred     20.621206     -0.256288         -8.354647
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     63.055551      0.235198         -6.311232
# 10         BNN_pred     11.557935     -0.276000         -7.645781
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.689150         -2.417327
# 1             HV_dw     24.773098     -0.217810         -6.212504
# 2             HV_cw     15.114404      0.432240         -7.421731
# 3         LSTM_pred    -41.914636     -1.260653        -10.769287
# 4          GRU_pred    -45.467778     -1.022653         -9.899206
# 5     LSTM_GRU_pred    -51.748461     -1.288566         -8.058971
# 6       BiLSTM_pred     49.413938      0.004496         -6.977757
# 7   BiLSTM_GRU_pred     72.917603      0.388197         -8.114200
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     61.578521      0.255933         -4.971471
# 10         BNN_pred     97.982199      0.774527         -4.719603
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -40.820321      0.078837         -7.361793
# 1             HV_dw    -18.107928     -0.755888         -6.664534
# 2             HV_cw     11.188512      0.510336         -7.319748
# 3         LSTM_pred     46.498126     -0.024373         -6.546029
# 4          GRU_pred      7.868536     -0.350994         -7.070838
# 5     LSTM_GRU_pred     16.669598     -0.264635         -6.391331
# 6       BiLSTM_pred    -21.299579     -0.716349        -10.929474
# 7   BiLSTM_GRU_pred     66.364245      0.289385         -6.713237
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     82.219798      0.459515         -6.117582
# 10         BNN_pred     60.314048      0.229084         -4.853075
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -47.467524      0.016576         -7.361793
# 1             HV_dw      7.761398     -0.428935         -5.932169
# 2             HV_cw    -17.790747      0.103733         -7.350650
# 3         LSTM_pred     -5.342847     -0.546030         -9.977897
# 4          GRU_pred    -12.612330     -0.522980        -10.004012
# 5     LSTM_GRU_pred     26.623931     -0.140475         -5.317006
# 6       BiLSTM_pred    -17.857137     -0.664772        -12.232963
# 7   BiLSTM_GRU_pred     48.067280      0.003187         -8.259149
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     -2.574437     -0.413296        -10.671739
# 10         BNN_pred     27.833051     -0.109838         -6.746776
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.689150         -2.417327
# 1             HV_dw     10.238728     -0.301939         -8.347192
# 2             HV_cw     -8.401819      0.290763         -7.730204
# 3         LSTM_pred     18.873020     -0.252469         -7.936952
# 4          GRU_pred    -73.933485     -1.230703        -12.636829
# 5     LSTM_GRU_pred    -46.431646     -0.956290        -12.122783
# 6       BiLSTM_pred     21.232743     -0.421101        -10.644542
# 7   BiLSTM_GRU_pred     57.662649      0.189370         -8.497573
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred      9.080510     -0.303059         -7.534407
# 10         BNN_pred    133.513941      1.000987         -6.347195
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.669736     -0.051603         -7.708285
# 1             HV_dw      3.576236     -0.395336         -9.132762
# 2             HV_cw    -11.740606      0.248433         -7.730204
# 3         LSTM_pred     65.747705      0.175534         -6.711110
# 4          GRU_pred    -19.435525     -0.590823         -9.247605
# 5     LSTM_GRU_pred     24.303271     -0.129966         -8.737801
# 6       BiLSTM_pred    -36.405932     -0.922836        -11.988246
# 7   BiLSTM_GRU_pred     92.811848      0.516282         -8.047794
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred      5.151710     -0.323899         -9.307661
# 10         BNN_pred    121.752573      0.711306         -4.484494
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -58.328573     -0.082450         -7.708285
# 1             HV_dw      6.084213     -0.366597         -7.816145
# 2             HV_cw    -56.544209     -0.173216         -8.040420
# 3         LSTM_pred     47.274275      0.001924         -9.356819
# 4          GRU_pred    -19.435525     -0.590823         -9.247605
# 5     LSTM_GRU_pred     20.437146     -0.160588         -8.619030
# 6       BiLSTM_pred    -15.226185     -0.711596        -12.120795
# 7   BiLSTM_GRU_pred     76.244950      0.262705         -7.849376
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred    -22.081825     -0.553832        -10.695948
# 10         BNN_pred    123.766354      0.541506         -5.449218
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.689150         -2.417327
# 1             HV_dw    -75.072549     -0.264048         -9.618330
# 2             HV_cw    -36.627123      0.008714         -7.730204
# 3         LSTM_pred    -61.311555     -0.289366        -10.353328
# 4          GRU_pred    -73.508058     -0.230186         -8.951078
# 5     LSTM_GRU_pred    -73.508058     -0.230186         -8.951078
# 6       BiLSTM_pred    -27.713578      0.131328         -7.420293
# 7   BiLSTM_GRU_pred    -26.013321      0.147450         -7.420293
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -63.395363     -0.109343         -8.370344
# 10         BNN_pred    -38.421281      0.102586         -7.361793
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.669736     -0.051603         -7.708285
# 1             HV_dw    -73.508058     -0.230186         -8.951078
# 2             HV_cw    -41.058977     -0.030107         -8.080874
# 3         LSTM_pred    -27.713578      0.131328         -7.420293
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.230186         -8.951078
# 7   BiLSTM_GRU_pred    -27.713578      0.202514         -7.361793
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -63.395363     -0.147493         -8.405445
# 10         BNN_pred    -51.617419     -0.019513         -7.361793
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -73.508058     -0.221840         -8.942539
# 1             HV_dw    -73.508058     -0.221840         -8.942539
# 2             HV_cw    -42.844881      0.061460         -7.708285
# 3         LSTM_pred    -73.508058     -0.221840         -8.942539
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.230547         -8.951449
# 7   BiLSTM_GRU_pred    -42.844881      0.061460         -7.708285
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -58.861497     -0.086826         -7.439946
# 10         BNN_pred    -73.508058     -0.221840         -8.942539
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -80.125474     -0.292028         -9.637114
# 1             HV_dw     16.509542     -0.284760         -6.748162
# 2             HV_cw    -90.996712     -0.293961         -8.847954
# 3         LSTM_pred     13.953021     -0.310434        -10.755484
# 4          GRU_pred    -19.435525     -0.590823         -9.247605
# 5     LSTM_GRU_pred    -31.436941     -0.698345        -12.123937
# 6       BiLSTM_pred    -26.020088     -0.692088        -11.149144
# 7   BiLSTM_GRU_pred     64.341069      0.157535         -6.359323
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     -2.363564     -0.360458         -9.226786
# 10         BNN_pred     75.231214      0.340465         -4.913693
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -43.676006      0.051661         -7.372988
# 1             HV_dw      5.557352     -0.368004         -7.808653
# 2             HV_cw     94.622394      0.278944         -7.314730
# 3         LSTM_pred    -22.611612     -0.728374        -10.835025
# 4          GRU_pred    -83.079644     -1.407083        -14.445366
# 5     LSTM_GRU_pred     32.057417     -0.084419         -7.182547
# 6       BiLSTM_pred     22.299529     -0.259011        -10.524821
# 7   BiLSTM_GRU_pred     -5.726598     -0.539895         -9.267540
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred    106.538771      0.648142         -5.413389
# 10         BNN_pred      6.914931     -0.349247         -6.813028
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.597076         -2.417327
# 1             HV_dw     22.859855     -0.302168         -3.602357
# 2             HV_cw     65.199538      0.291421         -7.570193
# 3         LSTM_pred     -9.742964     -0.970731         -5.937113
# 4          GRU_pred    -76.602062     -1.524165         -9.861833
# 5     LSTM_GRU_pred    -45.345511     -1.465424         -7.891779
# 6       BiLSTM_pred     33.212782     -0.203024         -5.763475
# 7   BiLSTM_GRU_pred     53.029198      0.163759         -8.474536
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     50.124229      0.124805         -6.023706
# 10         BNN_pred     81.769802      0.656508         -2.066886
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     19.562950      0.699309         -7.240594
# 1             HV_dw      9.782060     -0.419639         -4.082849
# 2             HV_cw     88.080935      0.261421         -7.522215
# 3         LSTM_pred     40.028623      0.004496         -7.004069
# 4          GRU_pred    -68.503188     -1.404294         -9.178388
# 5     LSTM_GRU_pred    -15.096985     -0.762634         -8.609871
# 6       BiLSTM_pred     44.660833     -0.046675         -6.819852
# 7   BiLSTM_GRU_pred     62.017821      0.254347         -7.468084
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     90.981898      0.585189         -4.844124
# 10         BNN_pred     69.966651      0.365016         -3.880261
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -17.211600      0.309161         -7.240594
# 1             HV_dw    -15.449346     -0.638399         -7.572114
# 2             HV_cw    116.831709      0.486213         -7.254463
# 3         LSTM_pred    -21.722812     -0.755502         -9.594438
# 4          GRU_pred    -83.079644     -1.407083        -14.445366
# 5     LSTM_GRU_pred     12.044585     -0.337029         -6.779926
# 6       BiLSTM_pred     -3.191393     -0.535080        -11.271780
# 7   BiLSTM_GRU_pred     32.672411     -0.168575         -6.690703
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     64.601865      0.266967         -6.183121
# 10         BNN_pred      9.240303     -0.339397         -5.998302
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.597076         -2.417327
# 1             HV_dw    -17.402911     -0.723181         -8.633567
# 2             HV_cw    -25.112401      0.088233         -8.414972
# 3         LSTM_pred     17.474108     -0.273138         -7.936952
# 4          GRU_pred    -73.933485     -1.230703        -12.636829
# 5     LSTM_GRU_pred    -50.222248     -1.093440        -12.246021
# 6       BiLSTM_pred     -1.897923     -0.547992         -8.678207
# 7   BiLSTM_GRU_pred    121.338872      0.909970         -5.381836
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred      3.389777     -0.380120         -7.520793
# 10         BNN_pred     98.524597      0.662375         -6.560814
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      2.064177      0.516451         -7.361793
# 1             HV_dw    -19.192115     -0.725193         -7.180076
# 2             HV_cw    -17.754917      0.162375         -8.414972
# 3         LSTM_pred     64.003326      0.252853         -6.687115
# 4          GRU_pred    -44.213979     -0.871850        -10.476514
# 5     LSTM_GRU_pred     -9.107200     -0.504199         -9.907262
# 6       BiLSTM_pred     10.261841     -0.377118         -6.643238
# 7   BiLSTM_GRU_pred    140.253344      1.003275         -5.380481
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred      0.345532     -0.397542         -9.308390
# 10         BNN_pred     62.948973      0.243037         -4.631499
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.669736     -0.051603         -7.708285
# 1             HV_dw    -23.514887     -0.691358         -6.858343
# 2             HV_cw    -35.566747      0.060110         -7.571177
# 3         LSTM_pred     14.875071     -0.316867         -9.387503
# 4          GRU_pred    -19.435525     -0.590823         -9.247605
# 5     LSTM_GRU_pred    -18.986678     -0.573307        -11.900098
# 6       BiLSTM_pred    -45.421537     -0.895911        -10.998956
# 7   BiLSTM_GRU_pred     99.789608      0.493347         -5.401523
# 8         QRNN_pred      7.109653     -0.513538         -6.158769
# 9          ESN_pred     14.815355     -0.225756         -7.708340
# 10         BNN_pred     49.892193      0.111529         -5.032284
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      0.000000      0.597076         -2.417327
# 1             HV_dw    -61.559765     -0.132721         -9.618330
# 2             HV_cw    -20.159567      0.172329         -7.730204
# 3         LSTM_pred    -61.311555     -0.289366        -10.353328
# 4          GRU_pred    -73.508058     -0.230186         -8.951078
# 5     LSTM_GRU_pred    -73.508058     -0.230186         -8.951078
# 6       BiLSTM_pred    -27.713578      0.131328         -7.420293
# 7   BiLSTM_GRU_pred    -47.199248     -0.057599         -8.377382
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -62.919798     -0.107476         -8.321776
# 10         BNN_pred    -36.739750      0.109908         -7.368823
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      2.064177      0.516451         -7.361793
# 1             HV_dw    -56.627144     -0.074931         -7.715645
# 2             HV_cw    -41.058977     -0.030107         -8.080874
# 3         LSTM_pred    -27.713578      0.131328         -7.420293
# 4          GRU_pred    -73.508058     -0.230186         -8.951078
# 5     LSTM_GRU_pred    -73.508058     -0.230186         -8.951078
# 6       BiLSTM_pred    -41.713719      0.063417         -7.368823
# 7   BiLSTM_GRU_pred    -27.713578      0.131328         -7.420293
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -63.395363     -0.147493         -8.405445
# 10         BNN_pred    -69.226172     -0.189564         -8.498368
# 11               __    -73.508058     -0.221840         -8.942539
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -54.669736     -0.051603         -7.708285
# 1             HV_dw    -73.508058     -0.230186         -8.951078
# 2             HV_cw    -41.058977      0.078098         -7.708285
# 3         LSTM_pred    -73.508058     -0.294162         -9.013600
# 4          GRU_pred    -73.508058     -0.221840         -8.942539
# 5     LSTM_GRU_pred    -73.508058     -0.221840         -8.942539
# 6       BiLSTM_pred    -73.508058     -0.230186         -8.951078
# 7   BiLSTM_GRU_pred    -42.844881      0.061460         -7.708285
# 8         QRNN_pred    -73.508058     -0.221840         -8.942539
# 9          ESN_pred    -34.337652      0.131675         -7.369127
# 10         BNN_pred    -73.508058     -0.221840         -8.942539
# 11               __    -73.508058     -0.221840         -8.942539

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y2', file, 'HV')
get_final_results_1('2024_y2', file, 'HV')

get_final_results('2024_y2', dw_file, 'HV_dw')
get_final_results_1('2024_y2', dw_file, 'HV_dw')

get_final_results('2024_y2', cw_file, 'HV_cw')
get_final_results_1('2024_y2', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-4-b267510ae310>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-4-b267510ae310>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    148.184750      1.309034         -7.217204
# 1             HV_dw    177.267775      1.300625         -7.729145
# 2             HV_cw    108.298069      1.421958         -5.463941
# 3         LSTM_pred    157.188072      1.032980         -8.485144
# 4          GRU_pred    174.934459      1.251670         -8.484837
# 5     LSTM_GRU_pred    193.018995      1.379698         -8.484837
# 6       BiLSTM_pred     69.771131      1.069047         -8.485144
# 7   BiLSTM_GRU_pred    109.288478      1.008762         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    194.579708      1.342753         -7.688132
# 10         BNN_pred     81.963631      0.949403         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    176.408487      1.501154         -3.932779
# 1             HV_dw    242.194318      1.865390         -6.271406
# 2             HV_cw     72.946630      0.301694         -5.657823
# 3         LSTM_pred     83.551813      0.458036         -7.307041
# 4          GRU_pred    164.693791      1.134408         -8.586712
# 5     LSTM_GRU_pred    150.674231      1.033707         -8.573037
# 6       BiLSTM_pred     96.722583      0.544300         -5.510598
# 7   BiLSTM_GRU_pred    126.378837      0.732888         -8.028952
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    147.753190      1.015407         -7.912772
# 10         BNN_pred    102.055462      0.599904        -10.162509
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     53.998428      0.261936         -4.050878
# 1             HV_dw    269.200547      2.214591         -3.891944
# 2             HV_cw      4.990603     -0.434355         -5.657823
# 3         LSTM_pred     82.164931      0.453537         -7.307041
# 4          GRU_pred    181.059456      1.433879         -6.501162
# 5     LSTM_GRU_pred    144.522403      1.088734         -7.861297
# 6       BiLSTM_pred     50.799066      0.090036         -6.116624
# 7   BiLSTM_GRU_pred     97.417338      0.576552         -8.028952
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    156.939386      1.185315         -5.108172
# 10         BNN_pred     86.115027      0.461723        -10.022314
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    129.636246      1.170744         -3.659320
# 1             HV_dw    251.742075      1.949961         -6.271406
# 2             HV_cw     16.072275     -0.366237         -6.500563
# 3         LSTM_pred     70.227198      0.327736         -7.307041
# 4          GRU_pred    184.176982      1.336140         -6.708450
# 5     LSTM_GRU_pred    173.982327      1.274185         -6.697765
# 6       BiLSTM_pred    107.007869      0.645451         -5.510598
# 7   BiLSTM_GRU_pred     96.758174      0.570213         -8.028952
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    176.879582      1.313902         -6.024685
# 10         BNN_pred    113.407369      0.704577        -10.022314
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    106.915021      0.791256         -6.636864
# 1             HV_dw    242.194318      1.865390         -6.271406
# 2             HV_cw     78.253283      0.410785         -5.657823
# 3         LSTM_pred     97.847400      0.490140         -7.307041
# 4          GRU_pred    164.693791      1.134408         -8.586712
# 5     LSTM_GRU_pred    150.674231      1.033707         -8.573037
# 6       BiLSTM_pred     96.722583      0.544300         -5.510598
# 7   BiLSTM_GRU_pred    130.940192      0.771556         -8.028952
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    156.745408      1.098446         -7.154090
# 10         BNN_pred     96.889741      0.551212        -10.162509
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    107.881136      1.000084         -2.478650
# 1             HV_dw    184.112660      1.432968         -7.018341
# 2             HV_cw     42.712703      0.078547         -5.657823
# 3         LSTM_pred    145.197708      0.936783         -8.485144
# 4          GRU_pred    211.720965      1.574391         -6.699473
# 5     LSTM_GRU_pred    226.182213      1.668789         -6.699473
# 6       BiLSTM_pred     72.803383      1.044123         -8.485144
# 7   BiLSTM_GRU_pred    118.018258      0.997238         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    188.710402      1.419801         -6.076435
# 10         BNN_pred     90.715988      1.040275         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    182.276227      2.059097         -2.878946
# 1             HV_dw    177.267775      1.300625         -7.729145
# 2             HV_cw     39.167326     -0.069619         -6.500563
# 3         LSTM_pred    145.197708      0.936783         -8.485144
# 4          GRU_pred    191.923914      1.427534         -7.099268
# 5     LSTM_GRU_pred    198.040277      1.461130         -7.099268
# 6       BiLSTM_pred     72.803383      1.096429         -8.485144
# 7   BiLSTM_GRU_pred    118.018258      0.997238         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    199.448706      1.458753         -7.290056
# 10         BNN_pred     93.098372      1.051908         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    150.550866      1.329284         -7.217204
# 1             HV_dw    177.267775      1.300625         -7.729145
# 2             HV_cw     80.159159      0.955227         -5.647722
# 3         LSTM_pred    157.188072      1.032980         -8.485144
# 4          GRU_pred    174.934459      1.251670         -8.484837
# 5     LSTM_GRU_pred    193.018995      1.379698         -8.484837
# 6       BiLSTM_pred     69.771131      1.069047         -8.485144
# 7   BiLSTM_GRU_pred    109.288478      1.008762         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    194.626751      1.343133         -7.688132
# 10         BNN_pred     81.963631      0.949403         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.180995         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.127186         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.127186         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     93.810948      1.119976         -8.655431
# 1             HV_dw    160.112413      1.071576         -7.682955
# 2             HV_cw    101.041562      0.668247         -8.485144
# 3         LSTM_pred    152.069556      0.993044         -8.485144
# 4          GRU_pred    155.380464      1.263728         -8.603173
# 5     LSTM_GRU_pred    202.856750      1.287698         -8.528839
# 6       BiLSTM_pred      0.000000      1.127186         -8.485144
# 7   BiLSTM_GRU_pred    162.100270      1.078192         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    141.233117      0.908824         -9.488954
# 10         BNN_pred     91.818408      1.039572         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    165.593536      1.308211         -2.906038
# 1             HV_dw    233.021799      1.716440         -7.682955
# 2             HV_cw     86.717402      0.508468         -9.192980
# 3         LSTM_pred    119.878942      0.694188         -6.306695
# 4          GRU_pred    178.347891      1.239355         -7.876931
# 5     LSTM_GRU_pred    149.971845      1.015631         -8.603173
# 6       BiLSTM_pred     98.577242      0.543880         -5.510598
# 7   BiLSTM_GRU_pred    172.845491      1.094987         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    191.363000      1.281494         -7.269949
# 10         BNN_pred    122.045547      0.675452         -9.505459
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     63.252565      0.356914         -2.619379
# 1             HV_dw    260.069118      1.973599         -7.035518
# 2             HV_cw    -25.896293     -0.847033         -8.890511
# 3         LSTM_pred    106.833893      0.691545         -6.306695
# 4          GRU_pred    250.264084      2.004679         -6.485286
# 5     LSTM_GRU_pred    191.554341      1.509804         -7.853231
# 6       BiLSTM_pred     90.223994      0.474567         -4.488139
# 7   BiLSTM_GRU_pred    121.495605      0.772389         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    194.807360      1.616926         -4.941255
# 10         BNN_pred     94.087726      0.531722         -9.364239
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    100.864224      0.781803         -2.331024
# 1             HV_dw    226.173719      1.670522         -7.682955
# 2             HV_cw      0.016419     -0.405793         -8.485144
# 3         LSTM_pred    106.833893      0.691545         -6.306695
# 4          GRU_pred    234.955786      1.763697         -6.300042
# 5     LSTM_GRU_pred    189.706729      1.411830         -6.768915
# 6       BiLSTM_pred    109.724505      0.653008         -5.510598
# 7   BiLSTM_GRU_pred    130.078781      0.846330         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    169.348736      1.226484         -7.487663
# 10         BNN_pred    127.609974      0.829097         -9.364239
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     98.375413      0.603268         -9.657751
# 1             HV_dw    226.173719      1.670522         -7.682955
# 2             HV_cw     52.227045      0.179496         -8.485144
# 3         LSTM_pred    105.798529      0.665832         -6.306695
# 4          GRU_pred    224.129668      1.653913         -7.261488
# 5     LSTM_GRU_pred    186.863663      1.348574         -8.603173
# 6       BiLSTM_pred     98.577242      0.543880         -5.510598
# 7   BiLSTM_GRU_pred    150.985433      1.019347         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    124.764484      0.808861        -10.529296
# 10         BNN_pred    122.045547      0.675452         -9.505459
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     99.983995      0.760283         -5.217094
# 1             HV_dw    188.257435      1.314898         -7.035518
# 2             HV_cw     39.862301     -0.042378         -8.485144
# 3         LSTM_pred    150.934671      0.996512         -8.485144
# 4          GRU_pred    220.336566      2.006226         -6.469453
# 5     LSTM_GRU_pred    218.885041      1.821926         -6.693578
# 6       BiLSTM_pred      0.000000      1.154564         -8.485144
# 7   BiLSTM_GRU_pred    142.040534      0.924178         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    165.778277      1.261296         -5.043688
# 10         BNN_pred     75.868922      0.910295         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    120.243073      0.924381         -5.209760
# 1             HV_dw    160.112413      1.071576         -7.682955
# 2             HV_cw     47.338022      0.126770         -8.485144
# 3         LSTM_pred    150.934671      0.996512         -8.485144
# 4          GRU_pred    201.499722      1.771304         -6.284661
# 5     LSTM_GRU_pred    208.683262      1.528281         -7.163256
# 6       BiLSTM_pred      0.000000      1.154564         -8.485144
# 7   BiLSTM_GRU_pred    150.780946      0.995173         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    143.835440      0.950198         -9.282564
# 10         BNN_pred    103.054566      1.142734         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     81.813133      1.019720         -9.657373
# 1             HV_dw    160.112413      1.071576         -7.682955
# 2             HV_cw     63.105617      0.313994         -8.485144
# 3         LSTM_pred    142.805446      0.918742         -8.485144
# 4          GRU_pred    179.487969      1.496534         -7.243760
# 5     LSTM_GRU_pred    214.340747      1.385465         -8.528839
# 6       BiLSTM_pred      0.000000      1.127186         -8.485144
# 7   BiLSTM_GRU_pred    150.780946      0.995173         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    140.305694      0.901027         -9.562508
# 10         BNN_pred     91.818408      1.039572         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.994690         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.127186         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.127186         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    154.522460      1.007044         -5.118664
# 1             HV_dw    188.856437      1.344841         -7.682955
# 2             HV_cw     95.903035      0.488488         -8.485144
# 3         LSTM_pred    158.884824      1.067522         -8.485144
# 4          GRU_pred    122.994730      0.809739        -10.016782
# 5     LSTM_GRU_pred    155.121133      1.309416         -7.857700
# 6       BiLSTM_pred    112.104575      0.668506         -5.510598
# 7   BiLSTM_GRU_pred    141.683890      1.032858         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    156.963069      0.944616         -8.485144
# 10         BNN_pred     91.138084      0.401461         -9.462231
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    117.127580      0.775587         -8.534447
# 1             HV_dw    185.479454      1.394774         -6.439893
# 2             HV_cw     62.960748      0.182807         -8.485144
# 3         LSTM_pred    131.319192      0.798306         -8.241084
# 4          GRU_pred     56.567735      0.190109         -8.841681
# 5     LSTM_GRU_pred     46.144787      0.072884        -10.016782
# 6       BiLSTM_pred     43.173478     -0.013563         -7.828041
# 7   BiLSTM_GRU_pred    107.444418      0.674244         -8.028952
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    147.354942      0.873118         -8.485144
# 10         BNN_pred     63.488805      0.261989         -7.468630
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     38.060784     -0.043301         -4.562087
# 1             HV_dw    108.853050      0.979538         -2.982694
# 2             HV_cw    -37.418861     -1.252188         -8.485144
# 3         LSTM_pred     87.329006      0.607390         -6.000133
# 4          GRU_pred     73.313378      0.467835         -4.310938
# 5     LSTM_GRU_pred     62.196472      0.300878         -4.597974
# 6       BiLSTM_pred     37.424180     -0.123404         -5.889618
# 7   BiLSTM_GRU_pred     56.595389      0.195840         -7.099768
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    102.639645      0.711710         -8.485144
# 10         BNN_pred     19.763416     -0.316284         -6.642765
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     82.610866      0.509835         -5.034539
# 1             HV_dw    187.383676      1.520353         -5.096428
# 2             HV_cw    -14.265417     -0.790114         -8.485144
# 3         LSTM_pred     92.593291      0.603016         -6.078530
# 4          GRU_pred    144.219699      1.173846         -5.953708
# 5     LSTM_GRU_pred    156.320323      1.317931         -6.433413
# 6       BiLSTM_pred     77.399114      0.372390         -5.643780
# 7   BiLSTM_GRU_pred     75.479017      0.383216         -8.028952
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    137.228317      0.896080         -8.485144
# 10         BNN_pred     55.864507      0.189100         -7.123848
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    103.502888      0.725554         -4.965525
# 1             HV_dw    191.906815      1.500075         -6.439893
# 2             HV_cw     21.155439     -0.293066         -8.485144
# 3         LSTM_pred     98.077362      0.599857         -9.078810
# 4          GRU_pred    129.949906      1.032281         -7.093304
# 5     LSTM_GRU_pred    179.955015      1.448036         -5.663788
# 6       BiLSTM_pred     44.858300     -0.013660         -7.828041
# 7   BiLSTM_GRU_pred     72.372661      0.342310         -8.028952
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    128.411858      0.815438         -8.485144
# 10         BNN_pred     46.399341      0.074913         -7.324231
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    130.736844      0.977397         -5.172748
# 1             HV_dw    138.466361      0.948895         -7.035518
# 2             HV_cw     14.616066     -0.328591         -8.485144
# 3         LSTM_pred    114.148654      0.724715         -8.485144
# 4          GRU_pred    138.065954      1.163027         -4.853215
# 5     LSTM_GRU_pred    150.681611      1.786261         -4.512391
# 6       BiLSTM_pred    102.422827      0.607062         -4.581673
# 7   BiLSTM_GRU_pred    120.552187      0.885594         -7.186004
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    102.639645      0.711710         -8.485144
# 10         BNN_pred     11.105538     -0.313706         -9.320944
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    128.323037      0.931205         -5.183814
# 1             HV_dw    209.905256      1.529481         -6.976125
# 2             HV_cw     29.503441     -0.175022         -8.485144
# 3         LSTM_pred    129.350910      0.830762         -8.485144
# 4          GRU_pred    228.605302      1.864903         -6.443676
# 5     LSTM_GRU_pred    205.658395      1.970929         -6.469453
# 6       BiLSTM_pred    145.400573      1.006237         -4.367059
# 7   BiLSTM_GRU_pred     99.298423      0.604572         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    151.575440      1.010628         -8.485144
# 10         BNN_pred     73.138412      0.338196         -9.320944
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    142.684219      1.072047         -5.118664
# 1             HV_dw    194.322169      1.392279         -7.682955
# 2             HV_cw     44.039011     -0.014396         -8.485144
# 3         LSTM_pred    129.350910      0.830762         -8.485144
# 4          GRU_pred    192.921317      1.484242         -8.573957
# 5     LSTM_GRU_pred    200.448239      1.818549         -6.284661
# 6       BiLSTM_pred    119.496074      0.722373         -5.510598
# 7   BiLSTM_GRU_pred    109.726960      0.714205         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    137.861352      0.888100         -8.485144
# 10         BNN_pred     88.455836      0.479417         -9.320944
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.154564         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.291093         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      0.711229         -8.485144
# 10         BNN_pred             0      1.183332         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.324778         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    129.881383      0.865272         -8.534447
# 1             HV_dw    175.411077      1.217850         -5.435068
# 2             HV_cw     54.788384      0.096714         -8.485144
# 3         LSTM_pred    132.709158      0.813212         -6.306695
# 4          GRU_pred    122.994730      0.809739        -10.016782
# 5     LSTM_GRU_pred     83.302752      1.125083         -9.973799
# 6       BiLSTM_pred     75.796681      0.331378         -5.810815
# 7   BiLSTM_GRU_pred    115.815478      0.630287         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    166.022965      1.018494         -8.485144
# 10         BNN_pred     42.219536     -0.075284         -9.247989
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     88.718416      0.505657         -8.534447
# 1             HV_dw    127.851585      0.884939         -6.714697
# 2             HV_cw     31.196350     -0.165299         -8.485144
# 3         LSTM_pred    175.537780      1.351708         -8.265367
# 4          GRU_pred     56.567735      0.190109         -8.841681
# 5     LSTM_GRU_pred     -2.872717     -0.489781        -11.465961
# 6       BiLSTM_pred    -25.244346     -0.877200         -7.828041
# 7   BiLSTM_GRU_pred    167.879568      1.140709         -7.687376
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    140.684356      0.835970         -8.485144
# 10         BNN_pred    102.673614      0.661566         -7.468630
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     28.214953     -0.198539         -4.236136
# 1             HV_dw    105.004290      1.047729         -2.480682
# 2             HV_cw    -59.506106     -1.701535         -8.485144
# 3         LSTM_pred    110.681012      1.165093         -2.801501
# 4          GRU_pred     73.313378      0.467835         -4.310938
# 5     LSTM_GRU_pred     31.003458     -0.165839         -4.650774
# 6       BiLSTM_pred    -41.168153     -1.386185         -7.344600
# 7   BiLSTM_GRU_pred     89.406760      0.602625         -7.706493
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     55.705966      0.191353         -8.485144
# 10         BNN_pred     46.273873      0.075788         -4.430416
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     23.606453     -0.238578         -5.518323
# 1             HV_dw    118.139253      0.864361         -5.426282
# 2             HV_cw    -66.447939     -1.604078         -9.138561
# 3         LSTM_pred    106.229842      0.803345         -6.081318
# 4          GRU_pred    144.219699      1.173846         -5.953708
# 5     LSTM_GRU_pred     93.642818      0.668959         -6.433413
# 6       BiLSTM_pred    -24.957639     -1.024690         -6.373592
# 7   BiLSTM_GRU_pred     77.170744      0.427027         -7.706493
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    127.893953      0.846696         -8.485144
# 10         BNN_pred     50.050273      0.121612         -7.123848
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     63.190848      0.282272         -4.879282
# 1             HV_dw    141.008453      1.073434         -7.188476
# 2             HV_cw    -15.757216     -0.804636         -8.485144
# 3         LSTM_pred    111.781991      0.859792         -6.081318
# 4          GRU_pred    129.949906      1.032281         -7.093304
# 5     LSTM_GRU_pred    122.820930      0.941059         -8.562883
# 6       BiLSTM_pred     -3.858008     -0.668316         -5.647848
# 7   BiLSTM_GRU_pred    137.678205      0.931601         -7.687376
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    128.318350      0.841167         -8.485144
# 10         BNN_pred     65.025746      0.301174         -7.123848
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     60.611026      0.250131         -5.267355
# 1             HV_dw    138.028481      1.236837         -2.845950
# 2             HV_cw     -4.640650     -0.608070         -8.485144
# 3         LSTM_pred    146.677555      1.334911         -4.652244
# 4          GRU_pred    138.065954      1.163027         -4.853215
# 5     LSTM_GRU_pred     87.163595      1.282503         -4.628090
# 6       BiLSTM_pred     72.001048      0.297740         -4.384347
# 7   BiLSTM_GRU_pred    105.828344      0.629084         -7.115997
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     55.705966      0.191353         -8.485144
# 10         BNN_pred     29.107126     -0.142606         -6.225377
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     44.628115      0.053282         -5.349025
# 1             HV_dw    169.960787      1.265758         -3.618634
# 2             HV_cw     -4.624615     -0.522806         -8.485144
# 3         LSTM_pred     99.757444      0.623160         -6.306695
# 4          GRU_pred    228.605302      1.864903         -6.443676
# 5     LSTM_GRU_pred    115.193701      1.693650         -6.485881
# 6       BiLSTM_pred     87.391553      0.457712         -4.563987
# 7   BiLSTM_GRU_pred     46.914280     -0.029469         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    129.010364      0.854468         -8.485144
# 10         BNN_pred     38.138213     -0.012997         -8.452696
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     83.568451      0.492850         -5.253209
# 1             HV_dw    177.217630      1.286750         -5.435068
# 2             HV_cw      6.760599     -0.443568         -8.485144
# 3         LSTM_pred     99.757444      0.623160         -6.306695
# 4          GRU_pred    192.921317      1.484242         -8.573957
# 5     LSTM_GRU_pred    139.250149      1.748870         -8.573957
# 6       BiLSTM_pred    108.940483      0.672641         -4.505300
# 7   BiLSTM_GRU_pred     89.342615      0.398487         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    134.343637      0.859174         -8.485144
# 10         BNN_pred     54.875108      0.163276         -8.452696
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.210422         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.154564         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.307438         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      0.190835         -8.485144
# 10         BNN_pred             0      1.144714         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      0.854063         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    148.184750      1.309034         -7.217204
# 1             HV_dw    164.506838      1.575484         -7.705191
# 2             HV_cw     77.253303      0.657600         -8.748976
# 3         LSTM_pred     69.771131      1.069047         -8.485144
# 4          GRU_pred     87.603882      1.113525         -8.485144
# 5     LSTM_GRU_pred    175.555198      1.054733         -8.528839
# 6       BiLSTM_pred     69.771131      1.069047         -8.485144
# 7   BiLSTM_GRU_pred      0.000000      1.127186         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     97.893680      0.633859         -8.485144
# 10         BNN_pred    165.223467      1.029696         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    176.408487      1.501154         -3.932779
# 1             HV_dw    245.914032      1.856514         -6.335067
# 2             HV_cw    107.697320      0.673063         -6.242866
# 3         LSTM_pred     74.072812      0.621781         -9.030719
# 4          GRU_pred    150.512204      1.026111         -8.559514
# 5     LSTM_GRU_pred    191.348643      1.421003         -5.706103
# 6       BiLSTM_pred     96.722583      0.544300         -5.510598
# 7   BiLSTM_GRU_pred     91.452183      0.830759         -4.987287
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    101.891968      0.509722         -8.469975
# 10         BNN_pred    172.087509      1.187970         -5.011305
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     53.998428      0.261936         -4.050878
# 1             HV_dw    273.538348      2.214491         -4.643589
# 2             HV_cw     31.271134     -0.079201         -4.779978
# 3         LSTM_pred     27.028366     -0.028233         -8.485144
# 4          GRU_pred    166.182597      1.236093         -8.406431
# 5     LSTM_GRU_pred    211.971068      1.700803         -4.239639
# 6       BiLSTM_pred     50.799066      0.090036         -6.116624
# 7   BiLSTM_GRU_pred     42.523407      0.135855         -6.133884
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     -4.893708     -0.729112         -8.485144
# 10         BNN_pred    151.664498      1.075021         -4.811390
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    129.636246      1.170744         -3.659320
# 1             HV_dw    254.873168      1.938915         -6.335067
# 2             HV_cw     44.606543     -0.011790         -6.686452
# 3         LSTM_pred     57.245725      0.466877         -9.030719
# 4          GRU_pred    152.007153      1.047610         -8.860751
# 5     LSTM_GRU_pred    177.314891      1.304439         -6.034990
# 6       BiLSTM_pred    107.007869      0.645451         -5.510598
# 7   BiLSTM_GRU_pred     86.824818      0.801975         -5.873562
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     10.079186     -0.463476         -8.485144
# 10         BNN_pred    172.094349      1.188032         -5.011275
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    106.915021      0.791256         -6.636864
# 1             HV_dw    245.914032      1.856514         -6.335067
# 2             HV_cw     44.458781     -0.008797         -6.329527
# 3         LSTM_pred     74.072812      0.621781         -9.030719
# 4          GRU_pred    150.512204      1.026111         -8.559514
# 5     LSTM_GRU_pred    162.244763      1.163221         -6.034990
# 6       BiLSTM_pred     96.722583      0.544300         -5.510598
# 7   BiLSTM_GRU_pred     91.452183      0.830759         -4.987287
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     72.131735      0.230017         -8.485144
# 10         BNN_pred    172.087509      1.187970         -5.011305
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    107.881136      1.000084         -2.478650
# 1             HV_dw    156.450933      1.555414         -7.764192
# 2             HV_cw     57.093192      0.251320         -6.106159
# 3         LSTM_pred     72.803383      0.962788         -8.485144
# 4          GRU_pred     96.895746      1.379060         -8.485144
# 5     LSTM_GRU_pred    220.284742      1.600822         -7.163256
# 6       BiLSTM_pred     72.803383      1.044123         -8.485144
# 7   BiLSTM_GRU_pred      0.000000      1.127186         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     85.974273      0.433505         -8.557715
# 10         BNN_pred    159.675619      1.022863         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    182.276227      2.059097         -2.878946
# 1             HV_dw    172.105501      1.643653         -7.705191
# 2             HV_cw     61.306450      0.179127         -6.083873
# 3         LSTM_pred     69.771131      1.016741         -8.485144
# 4          GRU_pred     87.603882      1.208858         -8.485144
# 5     LSTM_GRU_pred    178.008505      1.081438         -8.528839
# 6       BiLSTM_pred     72.803383      1.096429         -8.485144
# 7   BiLSTM_GRU_pred      0.000000      1.127186         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     76.006668      0.285411         -8.485144
# 10         BNN_pred    165.223467      1.029696         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    150.550866      1.329284         -7.217204
# 1             HV_dw    164.506838      1.575484         -7.705191
# 2             HV_cw     68.356078      0.577955         -8.092734
# 3         LSTM_pred     69.771131      1.069047         -8.485144
# 4          GRU_pred     87.603882      1.113525         -8.485144
# 5     LSTM_GRU_pred    175.555198      1.054733         -8.528839
# 6       BiLSTM_pred     69.771131      1.069047         -8.485144
# 7   BiLSTM_GRU_pred      0.000000      1.127186         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     96.170028      0.599066         -8.485144
# 10         BNN_pred    165.223467      1.029696         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.180995         -8.485144
# 1             HV_dw             0      1.154564         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.154564         -8.485144
# 4          GRU_pred             0      1.210422         -8.485144
# 5     LSTM_GRU_pred             0      1.210422         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.210422         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.127186         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.127186         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.127186         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     93.810948      1.119976         -8.655431
# 1             HV_dw    116.739767      1.148912         -7.705191
# 2             HV_cw    104.977319      0.611996         -7.611175
# 3         LSTM_pred      0.000000      1.127186         -8.485144
# 4          GRU_pred    175.555198      1.054733         -8.528839
# 5     LSTM_GRU_pred    176.344591      1.061156         -8.528839
# 6       BiLSTM_pred      0.000000      1.127186         -8.485144
# 7   BiLSTM_GRU_pred     96.649775      1.103477         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    141.202465      0.953059         -8.469611
# 10         BNN_pred    171.805378      1.085155         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    165.593536      1.308211         -2.906038
# 1             HV_dw    197.787901      1.419809         -7.706922
# 2             HV_cw    126.086492      0.750675         -7.700587
# 3         LSTM_pred    124.374264      0.740362         -8.314064
# 4          GRU_pred    145.953312      0.964524         -8.559514
# 5     LSTM_GRU_pred    215.573896      1.781350         -4.527084
# 6       BiLSTM_pred     98.577242      0.543880         -5.510598
# 7   BiLSTM_GRU_pred     93.336438      0.852546         -7.124640
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     43.490313     -0.068221         -8.485144
# 10         BNN_pred    170.418807      1.161741         -6.649942
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     63.252565      0.356914         -2.619379
# 1             HV_dw    185.958161      1.380756         -7.764192
# 2             HV_cw     40.960202     -0.141445         -5.565629
# 3         LSTM_pred    146.362412      1.078397         -6.794612
# 4          GRU_pred    208.261150      1.565774         -7.030697
# 5     LSTM_GRU_pred    234.624146      2.046292         -3.182365
# 6       BiLSTM_pred     90.223994      0.474567         -4.488139
# 7   BiLSTM_GRU_pred     66.606024      0.398816         -5.835194
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred      7.741251     -0.644585         -7.192565
# 10         BNN_pred    135.750230      0.913339         -6.649942
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    100.864224      0.781803         -2.331024
# 1             HV_dw    195.086447      1.405666         -7.764192
# 2             HV_cw     44.655868     -0.078943         -5.381653
# 3         LSTM_pred    132.573027      0.814849         -8.314064
# 4          GRU_pred    132.454304      0.852435         -8.860751
# 5     LSTM_GRU_pred    215.253074      1.817477         -3.677935
# 6       BiLSTM_pred    109.724505      0.653008         -5.510598
# 7   BiLSTM_GRU_pred     51.331631      0.404233         -7.842998
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     24.672630     -0.321809         -8.485144
# 10         BNN_pred    162.512859      1.101775         -6.649942
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     98.375413      0.603268         -9.657751
# 1             HV_dw    203.294695      1.467395         -7.706922
# 2             HV_cw    103.463804      0.595269         -5.578679
# 3         LSTM_pred    124.374264      0.740362         -8.314064
# 4          GRU_pred    137.034296      0.889633         -8.860751
# 5     LSTM_GRU_pred    214.634416      1.772706         -4.527084
# 6       BiLSTM_pred     98.577242      0.543880         -5.510598
# 7   BiLSTM_GRU_pred     86.575048      0.792850         -7.124640
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    127.584361      0.818847         -8.485144
# 10         BNN_pred    177.030063      1.222799         -6.649942
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     99.983995      0.760283         -5.217094
# 1             HV_dw    110.779343      1.130849         -7.764192
# 2             HV_cw     83.356261      0.454807         -5.305055
# 3         LSTM_pred      0.000000      1.154564         -8.485144
# 4          GRU_pred    220.284742      1.600822         -7.163256
# 5     LSTM_GRU_pred    222.702335      1.621017         -7.163256
# 6       BiLSTM_pred      0.000000      1.154564         -8.485144
# 7   BiLSTM_GRU_pred     85.614239      0.879721         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     32.095427     -0.192870         -7.426990
# 10         BNN_pred    153.592432      0.973208         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    120.243073      0.924381         -5.209760
# 1             HV_dw    119.905151      1.177012         -7.705191
# 2             HV_cw     81.575185      0.510467         -6.106159
# 3         LSTM_pred      0.000000      1.127186         -8.485144
# 4          GRU_pred    178.008505      1.081438         -8.528839
# 5     LSTM_GRU_pred    196.205154      1.389887         -7.163256
# 6       BiLSTM_pred      0.000000      1.154564         -8.485144
# 7   BiLSTM_GRU_pred     85.614239      1.077681         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     87.464381      0.459259         -8.485144
# 10         BNN_pred    171.805378      1.085155         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     81.813133      1.019720         -9.657373
# 1             HV_dw    116.739767      1.148912         -7.705191
# 2             HV_cw     90.528165      0.492560         -6.319775
# 3         LSTM_pred      0.000000      1.127186         -8.485144
# 4          GRU_pred    186.778540      1.149917         -8.528839
# 5     LSTM_GRU_pred    187.575469      1.156379         -8.528839
# 6       BiLSTM_pred      0.000000      1.127186         -8.485144
# 7   BiLSTM_GRU_pred    107.176574      1.198442         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    106.699996      0.671553         -8.485144
# 10         BNN_pred    171.805378      1.085155         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      0.994690         -8.485144
# 1             HV_dw             0      1.154564         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.154564         -8.485144
# 4          GRU_pred             0      1.210422         -8.485144
# 5     LSTM_GRU_pred             0      1.210422         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.154564         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.127186         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.127186         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.127186         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.127186         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    154.522460      1.007044         -5.118664
# 1             HV_dw    177.532348      1.228226         -7.764192
# 2             HV_cw    127.711158      0.768842         -6.597365
# 3         LSTM_pred     80.747807      0.364020         -8.314064
# 4          GRU_pred    152.814499      1.208714         -4.481478
# 5     LSTM_GRU_pred    157.560849      1.159510         -5.779497
# 6       BiLSTM_pred    112.104575      0.668506         -5.510598
# 7   BiLSTM_GRU_pred     40.759851      0.309389         -9.192980
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    191.823089      1.403599         -5.223683
# 10         BNN_pred    145.589404      0.984260         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    117.127580      0.775587         -8.534447
# 1             HV_dw    205.190701      1.476693         -6.354807
# 2             HV_cw     90.017038      0.410004         -5.972181
# 3         LSTM_pred     63.478567      0.213419         -6.324071
# 4          GRU_pred     98.557807      0.617320         -7.104164
# 5     LSTM_GRU_pred    137.870218      1.065443         -4.338431
# 6       BiLSTM_pred     43.173478     -0.013563         -7.828041
# 7   BiLSTM_GRU_pred     93.182807      0.530483         -5.762264
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    141.996656      1.063056         -6.699453
# 10         BNN_pred    154.394452      1.101975         -4.138990
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     38.060784     -0.043301         -4.562087
# 1             HV_dw    164.913187      1.375410         -3.625419
# 2             HV_cw     34.493817     -0.172105         -4.626700
# 3         LSTM_pred    110.789563      1.076581         -3.504363
# 4          GRU_pred    166.659819      1.503759         -3.706694
# 5     LSTM_GRU_pred    135.369943      1.330000         -4.106938
# 6       BiLSTM_pred     37.424180     -0.123404         -5.889618
# 7   BiLSTM_GRU_pred     23.358289     -0.251187         -4.336712
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     94.249860      0.885009         -1.806151
# 10         BNN_pred     82.405365      0.550868         -4.325192
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     82.610866      0.509835         -5.034539
# 1             HV_dw    201.046329      1.479421         -6.396666
# 2             HV_cw     79.636496      0.561875         -5.435954
# 3         LSTM_pred     53.162826      0.080208         -5.889618
# 4          GRU_pred    114.816435      0.866937         -5.247819
# 5     LSTM_GRU_pred    157.769049      1.440354         -4.106815
# 6       BiLSTM_pred     77.399114      0.372390         -5.643780
# 7   BiLSTM_GRU_pred     39.537405     -0.096523         -4.587221
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     89.072637      0.771078         -1.793210
# 10         BNN_pred    136.462785      1.074162         -4.138990
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    103.502888      0.725554         -4.965525
# 1             HV_dw    195.019681      1.396245         -6.456608
# 2             HV_cw     92.604637      0.614979         -4.552018
# 3         LSTM_pred     52.356964      0.070834         -6.324071
# 4          GRU_pred    124.507121      0.895064         -7.179656
# 5     LSTM_GRU_pred    126.804916      1.010618         -5.417484
# 6       BiLSTM_pred     44.858300     -0.013660         -7.828041
# 7   BiLSTM_GRU_pred     47.447514      0.033888         -6.491160
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    134.553570      1.152111         -4.002775
# 10         BNN_pred    168.261962      1.251690         -4.138990
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    130.736844      0.977397         -5.172748
# 1             HV_dw    131.524360      0.912037         -8.092734
# 2             HV_cw     85.999499      0.579467         -5.424556
# 3         LSTM_pred     60.276667      0.230526         -6.794612
# 4          GRU_pred    209.157019      1.880368         -3.176751
# 5     LSTM_GRU_pred    182.544326      1.572514         -3.514561
# 6       BiLSTM_pred    102.422827      0.607062         -4.581673
# 7   BiLSTM_GRU_pred     23.722783     -0.159838         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    144.212698      1.228179         -5.232706
# 10         BNN_pred     83.111190      0.446186         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    128.323037      0.931205         -5.183814
# 1             HV_dw    206.138558      1.474622         -7.750985
# 2             HV_cw    111.255350      0.845799         -5.269590
# 3         LSTM_pred     41.051223     -0.045604         -8.314064
# 4          GRU_pred    155.425168      1.257860         -4.873516
# 5     LSTM_GRU_pred    196.776541      1.587886         -3.972389
# 6       BiLSTM_pred    145.400573      1.006237         -4.367059
# 7   BiLSTM_GRU_pred     37.287978      0.076327         -8.485144
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    144.212698      1.228179         -5.232706
# 10         BNN_pred     97.408717      0.573868         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    142.684219      1.072047         -5.118664
# 1             HV_dw    186.299063      1.302921         -7.764192
# 2             HV_cw     93.305949      0.591461         -5.773193
# 3         LSTM_pred     69.307778      0.238203         -8.314064
# 4          GRU_pred    152.159387      1.223109         -4.873516
# 5     LSTM_GRU_pred    189.085395      1.477374         -5.779497
# 6       BiLSTM_pred    119.496074      0.722373         -5.510598
# 7   BiLSTM_GRU_pred     55.728532      0.417071         -9.192980
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    189.350352      1.569629         -5.046666
# 10         BNN_pred    135.039586      0.898300         -8.485144
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.154564         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.197776         -8.485144
# 4          GRU_pred             0      1.210422         -8.485144
# 5     LSTM_GRU_pred             0      1.291093         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.210422         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.154564         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.154564         -8.485144
# 4          GRU_pred             0      1.210422         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.154564         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.127186         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    129.881383      0.865272         -8.534447
# 1             HV_dw    163.689429      1.142584         -7.706922
# 2             HV_cw    149.740587      1.044938         -5.112631
# 3         LSTM_pred     51.489823      0.080410         -8.314064
# 4          GRU_pred    152.814499      1.208714         -4.481478
# 5     LSTM_GRU_pred    156.324344      1.211433         -4.863804
# 6       BiLSTM_pred     75.796681      0.331378         -5.810815
# 7   BiLSTM_GRU_pred    100.170188      0.575640         -6.498864
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    105.127620      0.697438         -5.297689
# 10         BNN_pred     93.333933      0.546285         -6.990566
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     88.718416      0.505657         -8.534447
# 1             HV_dw    153.167749      1.016577         -6.356378
# 2             HV_cw     99.750353      0.543033         -5.972181
# 3         LSTM_pred     72.883903      0.316861         -6.324071
# 4          GRU_pred    133.179983      1.008126         -4.754648
# 5     LSTM_GRU_pred    132.400296      0.837451         -5.878916
# 6       BiLSTM_pred    -25.244346     -0.877200         -7.828041
# 7   BiLSTM_GRU_pred    112.606866      0.670605         -5.762264
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    107.650314      0.758870         -6.699453
# 10         BNN_pred    109.979704      0.654167         -4.139168
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     28.214953     -0.198539         -4.236136
# 1             HV_dw    166.219525      1.408020         -3.631203
# 2             HV_cw     66.193980      0.696148         -1.070838
# 3         LSTM_pred     63.046047      0.369598         -3.435213
# 4          GRU_pred    150.218166      1.393219         -3.162804
# 5     LSTM_GRU_pred    117.818216      1.057419         -2.311236
# 6       BiLSTM_pred    -41.168153     -1.386185         -7.344600
# 7   BiLSTM_GRU_pred     37.780512     -0.228290         -3.433739
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     46.456923      0.091254         -1.882207
# 10         BNN_pred     40.976995     -0.001193         -4.325192
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     23.606453     -0.238578         -5.518323
# 1             HV_dw    128.502970      0.886022         -5.500584
# 2             HV_cw     70.693771      0.517342         -4.312233
# 3         LSTM_pred     63.179846      0.209673         -4.407733
# 4          GRU_pred    153.186712      1.428596         -3.162804
# 5     LSTM_GRU_pred    170.969273      1.545814         -2.311236
# 6       BiLSTM_pred    -24.957639     -1.024690         -6.373592
# 7   BiLSTM_GRU_pred     63.043181      0.155459         -3.624434
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     50.184684      0.173698         -1.882207
# 10         BNN_pred     80.638176      0.477945         -6.257181
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     63.190848      0.282272         -4.879282
# 1             HV_dw    135.716180      0.874928         -6.466907
# 2             HV_cw    103.669866      0.950224         -3.682683
# 3         LSTM_pred     73.129318      0.304444         -6.324071
# 4          GRU_pred    106.767621      0.731879         -6.622980
# 5     LSTM_GRU_pred    180.409219      1.626053         -2.132913
# 6       BiLSTM_pred     -3.858008     -0.668316         -5.647848
# 7   BiLSTM_GRU_pred     65.033712      0.175854         -4.407733
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred     86.517615      0.664514         -4.985007
# 10         BNN_pred    132.538261      0.922222         -4.139168
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     60.611026      0.250131         -5.267355
# 1             HV_dw    102.906833      0.708652         -6.794612
# 2             HV_cw     61.119804      0.286953         -5.592060
# 3         LSTM_pred     28.258430     -0.153942         -6.083873
# 4          GRU_pred    209.157019      1.880368         -3.176751
# 5     LSTM_GRU_pred    183.174231      1.815313         -3.182365
# 6       BiLSTM_pred     72.001048      0.297740         -4.384347
# 7   BiLSTM_GRU_pred     48.030986      0.097093         -4.489265
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    107.403805      0.844928         -5.409043
# 10         BNN_pred     33.495566     -0.079215         -6.976644
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     44.628115      0.053282         -5.349025
# 1             HV_dw    130.365884      0.900152         -7.100868
# 2             HV_cw    100.782424      0.783596         -5.286548
# 3         LSTM_pred     61.920533      0.171622         -6.794612
# 4          GRU_pred    212.277677      1.912129         -3.176751
# 5     LSTM_GRU_pred    231.676737      2.083886         -3.182365
# 6       BiLSTM_pred     87.391553      0.457712         -4.563987
# 7   BiLSTM_GRU_pred     95.107156      0.566161         -6.117344
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    107.403805      0.844928         -5.409043
# 10         BNN_pred     65.971084      0.280818         -8.627865
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     83.568451      0.492850         -5.253209
# 1             HV_dw    164.870938      1.162955         -7.764192
# 2             HV_cw    109.225386      0.853460         -5.322104
# 3         LSTM_pred     57.171482      0.120894         -8.314064
# 4          GRU_pred    152.159387      1.223109         -4.873516
# 5     LSTM_GRU_pred    239.080912      2.124125         -3.254053
# 6       BiLSTM_pred    108.940483      0.672641         -4.505300
# 7   BiLSTM_GRU_pred     88.584369      0.477126         -6.108930
# 8         QRNN_pred     77.623524      0.349410         -3.521232
# 9          ESN_pred    134.260137      1.103967         -5.291779
# 10         BNN_pred     92.435119      0.548898         -6.663166
# 11               __      0.000000      1.127186         -8.485144
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.154564         -8.485144
# 2             HV_cw             0      1.210422         -8.485144
# 3         LSTM_pred             0      1.144714         -8.485144
# 4          GRU_pred             0      1.210422         -8.485144
# 5     LSTM_GRU_pred             0      1.291093         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.210422         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.154564         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.154564         -8.485144
# 4          GRU_pred             0      1.210422         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.154564         -8.485144
# 11               __             0      1.127186         -8.485144
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV             0      1.127186         -8.485144
# 1             HV_dw             0      1.154564         -8.485144
# 2             HV_cw             0      1.127186         -8.485144
# 3         LSTM_pred             0      1.127186         -8.485144
# 4          GRU_pred             0      1.127186         -8.485144
# 5     LSTM_GRU_pred             0      1.127186         -8.485144
# 6       BiLSTM_pred             0      1.154564         -8.485144
# 7   BiLSTM_GRU_pred             0      1.127186         -8.485144
# 8         QRNN_pred             0      1.127186         -8.485144
# 9          ESN_pred             0      1.127186         -8.485144
# 10         BNN_pred             0      1.127186         -8.485144
# 11               __             0      1.127186         -8.485144

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_2y)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_2y)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_2y', file, 'HV')
get_final_results_1('2022_2y', file, 'HV')

get_final_results('2022_2y', dw_file, 'HV_dw')
get_final_results_1('2022_2y', dw_file, 'HV_dw')

get_final_results('2022_2y', cw_file, 'HV_cw')
get_final_results_1('2022_2y', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -28.956874     -0.731561        -20.764324
# 1             HV_dw     28.127722     -0.463870        -19.310649
# 2             HV_cw     12.518234     -0.526571        -20.872898
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     29.622979     -0.355099        -19.209938
# 5     LSTM_GRU_pred     30.871219     -0.440394        -19.633093
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred    -31.782365     -0.750774        -20.097753
# 9          ESN_pred     15.861053     -0.507597        -20.495952
# 10         BNN_pred     61.500700     -0.304799        -18.642821
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     23.022283     -0.564987        -17.417871
# 1             HV_dw    -68.302273     -0.710563        -19.528301
# 2             HV_cw     13.450108     -0.469122        -15.842508
# 3         LSTM_pred     30.713559     -0.446100        -20.436102
# 4          GRU_pred    -40.948546     -0.597751        -18.237949
# 5     LSTM_GRU_pred    -29.105826     -0.651278        -18.021671
# 6       BiLSTM_pred    -60.088307     -0.738155        -20.826997
# 7   BiLSTM_GRU_pred    -15.240028     -0.435738        -15.676882
# 8         QRNN_pred      2.713362     -0.673478        -19.447030
# 9          ESN_pred     36.242535     -0.436867        -18.539326
# 10         BNN_pred    -51.132710     -0.633809        -20.559012
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -30.261755     -1.085216        -20.087116
# 1             HV_dw    -34.700732     -0.561932        -15.777365
# 2             HV_cw     49.567777     -0.295547         -9.476439
# 3         LSTM_pred     36.876364     -0.418535        -20.037516
# 4          GRU_pred    -80.493023     -0.864151        -18.067378
# 5     LSTM_GRU_pred   -114.279387     -1.297084        -17.854223
# 6       BiLSTM_pred     -6.535944     -0.586985        -16.329836
# 7   BiLSTM_GRU_pred    -48.108125     -0.708528        -11.931730
# 8         QRNN_pred    -67.577996     -1.176293        -20.734550
# 9          ESN_pred    -77.479676     -1.092415        -18.408408
# 10         BNN_pred    -73.158650     -0.823021        -20.424176
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     25.819984     -0.647159        -17.749993
# 1             HV_dw    -60.734947     -0.675005        -18.540082
# 2             HV_cw     10.428976     -0.498922        -10.735887
# 3         LSTM_pred     30.713559     -0.446100        -20.436102
# 4          GRU_pred    -82.070142     -0.836010        -19.575515
# 5     LSTM_GRU_pred    -34.842626     -0.668489        -15.230005
# 6       BiLSTM_pred    -76.093914     -0.902622        -21.941616
# 7   BiLSTM_GRU_pred    -18.691694     -0.463901        -14.446256
# 8         QRNN_pred    -63.598445     -1.137333        -21.554087
# 9          ESN_pred    -16.313935     -0.721589        -16.863808
# 10         BNN_pred    -60.269954     -0.689940        -20.796325
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -32.450439     -0.878273        -18.391307
# 1             HV_dw    -62.166300     -0.680132        -19.310649
# 2             HV_cw     29.739424     -0.423641        -14.930157
# 3         LSTM_pred     30.713559     -0.446100        -20.436102
# 4          GRU_pred    -31.764026     -0.550119        -17.454941
# 5     LSTM_GRU_pred    -27.313354     -0.641894        -18.021671
# 6       BiLSTM_pred    -60.088307     -0.738155        -20.826997
# 7   BiLSTM_GRU_pred    -15.240028     -0.435738        -15.676882
# 8         QRNN_pred    -11.720415     -0.743051        -18.760675
# 9          ESN_pred    -16.372176     -0.700507        -17.460904
# 10         BNN_pred    -51.132710     -0.633809        -20.559012
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -85.827586     -1.230639        -20.560331
# 1             HV_dw     47.296044     -0.213645        -15.777365
# 2             HV_cw     70.636857     -0.130529        -12.927383
# 3         LSTM_pred     30.102633     -0.442237        -20.097666
# 4          GRU_pred      9.054275     -0.472513        -17.374137
# 5     LSTM_GRU_pred    -86.706736     -0.974406        -21.226316
# 6       BiLSTM_pred     24.967921     -0.312003        -17.766445
# 7   BiLSTM_GRU_pred      5.851667     -0.553613        -19.820536
# 8         QRNN_pred    -76.969654     -1.116073        -21.532937
# 9          ESN_pred    -19.846259     -0.718141        -19.314919
# 10         BNN_pred     66.818428     -0.276061        -18.137453
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     13.516879     -0.599172        -18.913265
# 1             HV_dw     29.417753     -0.459493        -18.540082
# 2             HV_cw     30.094552     -0.329536        -14.790743
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     -7.586289     -0.537155        -18.471345
# 5     LSTM_GRU_pred      1.747215     -0.582846        -21.276466
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred    -23.536495     -0.754574        -20.513548
# 9          ESN_pred     -0.009066     -0.606479        -19.314919
# 10         BNN_pred     61.500700     -0.304799        -18.642821
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -28.091901     -0.739399        -20.764324
# 1             HV_dw     25.850213     -0.474574        -19.310649
# 2             HV_cw    -34.208328     -0.763080        -23.466804
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     37.129509     -0.321194        -18.620933
# 5     LSTM_GRU_pred     30.871219     -0.440394        -19.633093
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred    -34.739237     -0.770306        -19.585846
# 9          ESN_pred      1.912488     -0.573969        -20.733650
# 10         BNN_pred     61.500700     -0.304799        -18.642821
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.459326        -20.400858
# 1             HV_dw     18.063823     -0.337299        -17.200281
# 2             HV_cw     66.385333     -0.127978        -14.443511
# 3         LSTM_pred     30.102633     -0.442237        -20.097666
# 4          GRU_pred     43.564618     -0.383257        -19.053455
# 5     LSTM_GRU_pred    -11.856680     -0.557273        -18.375502
# 6       BiLSTM_pred     24.967921     -0.312003        -17.766445
# 7   BiLSTM_GRU_pred      5.851667     -0.553613        -19.820536
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred    -16.782239     -0.667574        -20.495952
# 10         BNN_pred     30.102633     -0.436651        -20.002096
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.464904        -20.495952
# 1             HV_dw     32.440514     -0.431545        -19.916323
# 2             HV_cw     43.564618     -0.228538        -16.274425
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     30.102633     -0.442237        -20.097666
# 5     LSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred     -0.455394     -0.588142        -20.495952
# 10         BNN_pred     24.967921     -0.464904        -20.495952
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.464904        -20.495952
# 1             HV_dw     24.967921     -0.464904        -20.495952
# 2             HV_cw     24.967921     -0.464904        -20.495952
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     32.440514     -0.431545        -19.916323
# 5     LSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred     24.967921     -0.464904        -20.495952
# 10         BNN_pred     24.967921     -0.464904        -20.495952
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      7.308684     -0.564809        -21.304412
# 1             HV_dw     45.612482     -0.378536        -18.757354
# 2             HV_cw     40.282865     -0.433803        -19.553580
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     24.229138     -0.472672        -20.561090
# 5     LSTM_GRU_pred    -31.318725     -0.604590        -21.089500
# 6       BiLSTM_pred     46.274368     -0.373192        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     28.057380     -0.465320        -20.521972
# 9          ESN_pred      5.295195     -0.559077        -20.445863
# 10         BNN_pred     34.885955     -0.421240        -19.633093
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -43.215665     -0.932287        -19.078211
# 1             HV_dw    -33.939258     -0.500129        -17.983817
# 2             HV_cw     38.219636     -0.423655        -17.353070
# 3         LSTM_pred    -28.861159     -0.499372        -20.629281
# 4          GRU_pred     16.857589     -0.302705        -17.794708
# 5     LSTM_GRU_pred    -82.028536     -0.881797        -19.822236
# 6       BiLSTM_pred    -23.786060     -0.547939        -20.903301
# 7   BiLSTM_GRU_pred    -29.284953     -0.530057        -18.108174
# 8         QRNN_pred    -23.997943     -0.770336        -20.480276
# 9          ESN_pred    -16.174504     -0.687741        -18.461919
# 10         BNN_pred     -8.115886     -0.402800        -19.159227
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -63.461550     -1.286010        -19.959688
# 1             HV_dw      9.882439     -0.277052        -12.078326
# 2             HV_cw     74.219266     -0.166881         -9.984613
# 3         LSTM_pred     -6.089583     -0.390011        -19.603199
# 4          GRU_pred    -21.877377     -0.549335        -15.539301
# 5     LSTM_GRU_pred    -13.646612     -0.661242        -16.560988
# 6       BiLSTM_pred    -13.999486     -0.644493        -19.214720
# 7   BiLSTM_GRU_pred    -69.795878     -0.796487        -18.389512
# 8         QRNN_pred    -90.552177     -1.318601        -21.863592
# 9          ESN_pred    -46.181764     -0.906497        -18.461919
# 10         BNN_pred      2.742040     -0.377753        -16.926420
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -57.145455     -1.190789        -19.073025
# 1             HV_dw    -32.727105     -0.495816        -17.200579
# 2             HV_cw     65.381655     -0.340324        -13.614629
# 3         LSTM_pred    -28.861159     -0.499372        -20.629281
# 4          GRU_pred     24.860254     -0.270519        -14.852242
# 5     LSTM_GRU_pred    -34.462836     -0.650530        -16.003030
# 6       BiLSTM_pred    -46.523980     -0.756195        -23.381662
# 7   BiLSTM_GRU_pred    -23.463223     -0.516610        -17.936648
# 8         QRNN_pred    -71.472524     -1.182715        -21.065625
# 9          ESN_pred    -21.305080     -0.725866        -18.461919
# 10         BNN_pred    -24.552325     -0.491026        -19.836868
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -61.529589     -1.084192        -18.398951
# 1             HV_dw    -36.079276     -0.511002        -17.983817
# 2             HV_cw     46.630533     -0.422412        -16.877719
# 3         LSTM_pred    -28.861159     -0.499372        -20.629281
# 4          GRU_pred     17.845891     -0.300244        -15.922860
# 5     LSTM_GRU_pred    -51.791764     -0.716332        -19.372922
# 6       BiLSTM_pred     -3.493083     -0.454087        -20.903301
# 7   BiLSTM_GRU_pred    -29.284953     -0.530057        -18.108174
# 8         QRNN_pred    -60.407978     -0.976894        -22.031355
# 9          ESN_pred    -30.306421     -0.758976        -18.461919
# 10         BNN_pred     -8.115886     -0.402800        -19.159227
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -79.032758     -1.184345        -19.916383
# 1             HV_dw     62.242402     -0.150734        -14.091624
# 2             HV_cw    132.126661      0.141063        -10.353231
# 3         LSTM_pred     30.102633     -0.442237        -20.097666
# 4          GRU_pred     33.184284     -0.453481        -15.802871
# 5     LSTM_GRU_pred    -57.102144     -0.826014        -18.375502
# 6       BiLSTM_pred     44.635143     -0.225175        -17.766445
# 7   BiLSTM_GRU_pred      5.851667     -0.553613        -19.820536
# 8         QRNN_pred    -72.125825     -1.076955        -22.094325
# 9          ESN_pred    -24.632400     -0.767595        -19.329476
# 10         BNN_pred     40.070352     -0.392853        -19.133876
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -85.533871     -1.212577        -20.139401
# 1             HV_dw     55.721650     -0.333656        -18.167228
# 2             HV_cw    108.939765     -0.116416        -14.885455
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     48.203103     -0.372404        -17.604695
# 5     LSTM_GRU_pred    -68.584112     -0.770449        -20.107007
# 6       BiLSTM_pred     46.274368     -0.373192        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred    -52.659599     -0.957093        -21.298714
# 9          ESN_pred     24.657872     -0.485027        -19.314919
# 10         BNN_pred     34.885955     -0.415646        -19.536967
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     18.038752     -0.526186        -20.403561
# 1             HV_dw     43.296241     -0.389129        -18.757354
# 2             HV_cw     47.477321     -0.410972        -17.960105
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     19.238454     -0.497726        -19.981936
# 5     LSTM_GRU_pred    -40.917514     -0.619138        -20.505247
# 6       BiLSTM_pred     46.274368     -0.373192        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     24.884912     -0.498354        -19.366490
# 9          ESN_pred     32.085608     -0.442822        -19.314919
# 10         BNN_pred     34.885955     -0.421240        -19.633093
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.459326        -20.400858
# 1             HV_dw     56.286311     -0.165816        -14.091624
# 2             HV_cw     65.669446     -0.158811        -14.980913
# 3         LSTM_pred     30.102633     -0.442237        -20.097666
# 4          GRU_pred     66.385333     -0.285652        -17.283313
# 5     LSTM_GRU_pred     -7.800841     -0.537724        -18.375502
# 6       BiLSTM_pred     24.967921     -0.312003        -17.766445
# 7   BiLSTM_GRU_pred      5.851667     -0.553613        -19.820536
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred    -15.210542     -0.667318        -20.495952
# 10         BNN_pred     30.102633     -0.436651        -20.002096
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.464904        -20.495952
# 1             HV_dw     30.102633     -0.442237        -20.097666
# 2             HV_cw     24.967921     -0.459326        -20.400858
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     43.564618     -0.383257        -19.053455
# 5     LSTM_GRU_pred     30.102633     -0.442237        -20.097666
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred     24.967921     -0.464904        -20.495952
# 10         BNN_pred     24.967921     -0.459326        -20.400858
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.464904        -20.495952
# 1             HV_dw     24.967921     -0.464904        -20.495952
# 2             HV_cw     24.967921     -0.464904        -20.495952
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     32.440514     -0.431545        -19.916323
# 5     LSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred     24.967921     -0.464904        -20.495952
# 10         BNN_pred     24.967921     -0.464904        -20.495952
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -1.599263     -0.422341        -19.757864
# 1             HV_dw    -55.886935     -0.665128        -19.584368
# 2             HV_cw      5.169392     -0.266799        -17.185161
# 3         LSTM_pred    -78.782944     -0.775425        -22.135968
# 4          GRU_pred    -14.456910     -0.385627        -18.980918
# 5     LSTM_GRU_pred     68.957766     -0.112888        -14.944621
# 6       BiLSTM_pred    -73.448861     -0.665254        -21.516491
# 7   BiLSTM_GRU_pred    -23.343409     -0.728761        -20.495952
# 8         QRNN_pred      9.002351     -0.375253        -18.896323
# 9          ESN_pred     -8.838260     -0.654031        -19.187998
# 10         BNN_pred     -8.174710     -0.411161        -20.264190
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     30.692802     -0.235607        -14.371352
# 1             HV_dw    -93.044553     -0.889272        -18.347270
# 2             HV_cw    -26.524155     -0.466989        -14.571409
# 3         LSTM_pred    -51.547304     -0.645445        -15.928865
# 4          GRU_pred   -109.552152     -1.150961        -20.817589
# 5     LSTM_GRU_pred     -8.272208     -0.520790        -15.382208
# 6       BiLSTM_pred    -78.087979     -0.867929        -18.686666
# 7   BiLSTM_GRU_pred    -13.002123     -0.474524        -18.614389
# 8         QRNN_pred      1.993020     -0.285351        -17.007024
# 9          ESN_pred   -112.588474     -1.263355        -23.728941
# 10         BNN_pred    -84.744258     -0.875397        -20.391941
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    121.278194      0.235037         -5.018872
# 1             HV_dw     10.138098     -0.507692         -8.721517
# 2             HV_cw    148.047706      0.420784         -4.281736
# 3         LSTM_pred    -88.402282     -1.126845        -17.204776
# 4          GRU_pred    -80.873762     -1.318199        -13.830563
# 5     LSTM_GRU_pred     57.816640     -0.072649         -4.904173
# 6       BiLSTM_pred   -109.076940     -1.187209        -18.010211
# 7   BiLSTM_GRU_pred    -15.015157     -0.632652        -11.983244
# 8         QRNN_pred     90.187589      0.048346         -9.799737
# 9          ESN_pred   -120.591322     -1.957137        -18.060115
# 10         BNN_pred     -8.207480     -0.767484         -7.989073
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      3.527180     -0.394793        -15.388666
# 1             HV_dw     28.558137     -0.310415        -10.151489
# 2             HV_cw    125.452040      0.247544         -6.545660
# 3         LSTM_pred    -94.766522     -1.024331        -18.128314
# 4          GRU_pred   -125.494546     -1.416498        -19.644351
# 5     LSTM_GRU_pred     38.301505     -0.296100         -9.561859
# 6       BiLSTM_pred    -85.988191     -1.017547        -17.138303
# 7   BiLSTM_GRU_pred     -8.010331     -0.508702        -16.015761
# 8         QRNN_pred     43.131150     -0.183871        -13.599639
# 9          ESN_pred   -142.302985     -1.657102        -22.361227
# 10         BNN_pred    -47.653566     -0.800917        -17.127123
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     28.266314     -0.246669        -14.572941
# 1             HV_dw    -47.443936     -0.712549        -15.197135
# 2             HV_cw      3.255784     -0.394419        -13.021050
# 3         LSTM_pred    -58.341478     -0.775391        -17.143836
# 4          GRU_pred   -148.215685     -1.423673        -22.331047
# 5     LSTM_GRU_pred     65.357208     -0.244835        -13.603573
# 6       BiLSTM_pred    -66.091199     -0.826020        -17.482108
# 7   BiLSTM_GRU_pred    -29.007765     -0.582201        -18.638159
# 8         QRNN_pred      3.191493     -0.279531        -16.907757
# 9          ESN_pred    -98.469583     -1.261115        -21.829287
# 10         BNN_pred    -48.114299     -0.691963        -19.413506
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    116.005661      0.185564         -9.799737
# 1             HV_dw      9.021456     -0.403441        -12.632536
# 2             HV_cw    178.144099      0.517481         -9.799737
# 3         LSTM_pred    -73.250743     -0.767394        -20.308594
# 4          GRU_pred     -7.618695     -0.566733        -11.725051
# 5     LSTM_GRU_pred    113.342056      0.281709         -4.962772
# 6       BiLSTM_pred    -56.338312     -0.641115        -17.840789
# 7   BiLSTM_GRU_pred   -107.847004     -1.206342        -21.223743
# 8         QRNN_pred     90.187589      0.048346         -9.799737
# 9          ESN_pred   -129.701309     -2.018497        -18.908948
# 10         BNN_pred     42.217104     -0.237567        -13.212091
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.374531        -18.782372
# 1             HV_dw     25.224612     -0.279615        -12.736529
# 2             HV_cw     77.021120     -0.008877        -11.673544
# 3         LSTM_pred    -78.782944     -0.775425        -22.135968
# 4          GRU_pred    -32.655239     -0.520721        -17.623924
# 5     LSTM_GRU_pred     89.074470      0.017928         -8.654166
# 6       BiLSTM_pred    -50.026211     -0.598293        -18.273830
# 7   BiLSTM_GRU_pred    -57.901329     -0.941241        -20.679531
# 8         QRNN_pred     24.967921     -0.248106        -15.104061
# 9          ESN_pred   -105.788160     -1.304241        -22.580563
# 10         BNN_pred     -2.788099     -0.419718        -19.898906
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -0.405087     -0.416755        -19.661887
# 1             HV_dw    -45.079019     -0.612841        -18.351143
# 2             HV_cw     25.020295     -0.249504        -15.104061
# 3         LSTM_pred    -78.782944     -0.775425        -22.135968
# 4          GRU_pred    -25.666769     -0.439055        -17.570783
# 5     LSTM_GRU_pred     59.839511     -0.232179        -14.533785
# 6       BiLSTM_pred    -99.957987     -0.815607        -22.306728
# 7   BiLSTM_GRU_pred    -39.725126     -0.825037        -20.495952
# 8         QRNN_pred     10.209208     -0.369630        -18.799316
# 9          ESN_pred    -26.679562     -0.776757        -20.139863
# 10         BNN_pred     12.026387     -0.322751        -18.333295
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    116.005661      0.185564         -9.799737
# 1             HV_dw     28.620112     -0.374265        -15.486325
# 2             HV_cw    144.391152      0.329506         -9.799737
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     50.861126     -0.268579        -16.903034
# 5     LSTM_GRU_pred     87.496781      0.121888         -9.924927
# 6       BiLSTM_pred     32.440514     -0.278045        -17.166916
# 7   BiLSTM_GRU_pred      1.123351     -0.495377        -18.359646
# 8         QRNN_pred     90.187589      0.048346         -9.799737
# 9          ESN_pred    -81.413565     -1.138186        -20.495952
# 10         BNN_pred    100.010583     -0.144620        -12.314845
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.374531        -18.782372
# 1             HV_dw     56.286311     -0.243198        -15.486325
# 2             HV_cw     66.385333     -0.056120        -11.673544
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     66.385333     -0.285652        -17.283313
# 5     LSTM_GRU_pred     43.564618     -0.180198        -15.296346
# 6       BiLSTM_pred     24.967921     -0.312003        -17.766445
# 7   BiLSTM_GRU_pred     -1.927783     -0.589517        -20.400858
# 8         QRNN_pred     24.967921     -0.248106        -15.104061
# 9          ESN_pred    -12.746617     -0.648481        -20.495952
# 10         BNN_pred     30.102633     -0.436651        -20.002096
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.459326        -20.400858
# 1             HV_dw     30.102633     -0.442237        -20.097666
# 2             HV_cw     24.967921     -0.248106        -15.104061
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     43.564618     -0.383257        -19.053455
# 5     LSTM_GRU_pred     30.102633     -0.442237        -20.097666
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     -1.428481     -0.592726        -20.495952
# 8         QRNN_pred     24.967921     -0.378384        -18.950542
# 9          ESN_pred     24.967921     -0.464904        -20.495952
# 10         BNN_pred     24.967921     -0.464904        -20.495952
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     32.123759     -0.271088        -17.047522
# 1             HV_dw    -44.330918     -0.622626        -16.088769
# 2             HV_cw    124.845513      0.294392        -10.345108
# 3         LSTM_pred    -60.279661     -0.753242        -17.964817
# 4          GRU_pred     -8.131117     -0.447817        -18.725224
# 5     LSTM_GRU_pred    -47.593398     -0.701881        -19.771641
# 6       BiLSTM_pred    -42.096126     -0.596745        -21.380825
# 7   BiLSTM_GRU_pred     15.924789     -0.558118        -21.463783
# 8         QRNN_pred     35.808818     -0.356317        -18.517329
# 9          ESN_pred   -118.316571     -1.288717        -22.413392
# 10         BNN_pred    -45.367806     -0.619822        -20.423422
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     60.271708     -0.020125        -12.625785
# 1             HV_dw    -74.395109     -0.829679        -20.869699
# 2             HV_cw     43.818183     -0.109918        -11.888351
# 3         LSTM_pred    -37.770788     -0.566536        -17.062600
# 4          GRU_pred   -109.552152     -1.150961        -20.817589
# 5     LSTM_GRU_pred    -53.917293     -0.817818        -15.166450
# 6       BiLSTM_pred    -89.820549     -0.899516        -16.977455
# 7   BiLSTM_GRU_pred    -26.085979     -0.584869        -18.692231
# 8         QRNN_pred     51.533839     -0.058503        -11.923522
# 9          ESN_pred    -62.667459     -1.027764        -22.305712
# 10         BNN_pred    -29.070072     -0.599857        -18.708226
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    131.051662      0.302227         -5.018872
# 1             HV_dw      4.917278     -0.619010         -9.852587
# 2             HV_cw    125.959995      0.288386         -4.516652
# 3         LSTM_pred    -61.381556     -0.896926        -15.022602
# 4          GRU_pred    -48.136484     -1.391469        -10.145658
# 5     LSTM_GRU_pred     74.545198     -0.091981         -4.481169
# 6       BiLSTM_pred    -99.445571     -1.320733        -12.219809
# 7   BiLSTM_GRU_pred    -16.585805     -0.724414        -11.233970
# 8         QRNN_pred    117.451634      0.216399         -5.018872
# 9          ESN_pred   -104.355255     -1.936423        -16.123923
# 10         BNN_pred     43.646212     -0.396395         -3.958368
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     65.458542     -0.083663        -10.166989
# 1             HV_dw     10.335812     -0.474422        -12.316945
# 2             HV_cw    130.030119      0.302360         -3.702639
# 3         LSTM_pred    -72.342025     -0.842343        -15.679263
# 4          GRU_pred   -125.494546     -1.416498        -19.644351
# 5     LSTM_GRU_pred    -50.356670     -0.928809        -12.822171
# 6       BiLSTM_pred    -57.334035     -0.872821        -13.380674
# 7   BiLSTM_GRU_pred    -46.456885     -0.808229        -15.204778
# 8         QRNN_pred    103.113700      0.118267        -11.493259
# 9          ESN_pred    -96.924289     -1.461799        -18.618686
# 10         BNN_pred    -42.555557     -0.873559        -13.049018
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     90.071233      0.051037        -11.486108
# 1             HV_dw     -0.500841     -0.483272        -12.363898
# 2             HV_cw    219.720270      0.762888         -3.605379
# 3         LSTM_pred    -44.922008     -0.635777        -16.172053
# 4          GRU_pred   -141.401015     -1.471526        -21.233661
# 5     LSTM_GRU_pred    -77.412528     -0.945708        -18.899554
# 6       BiLSTM_pred    -75.683743     -0.937097        -16.182177
# 7   BiLSTM_GRU_pred    -47.028121     -0.738745        -16.744589
# 8         QRNN_pred     61.932344     -0.082315        -12.355640
# 9          ESN_pred    -75.842368     -1.199865        -20.231250
# 10         BNN_pred    -71.862455     -0.911012        -19.801221
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    101.393119      0.108515         -9.799737
# 1             HV_dw     67.913706     -0.088163         -9.814129
# 2             HV_cw    213.408518      0.769867         -4.575158
# 3         LSTM_pred    -18.279207     -0.613808        -14.418789
# 4          GRU_pred     64.556520     -0.137789         -8.202035
# 5     LSTM_GRU_pred     22.688365     -0.307942         -7.295721
# 6       BiLSTM_pred   -127.080923     -1.242944        -17.211598
# 7   BiLSTM_GRU_pred      7.498551     -0.654617        -15.129928
# 8         QRNN_pred     99.531330      0.098882         -9.799737
# 9          ESN_pred   -104.355255     -1.936423        -16.123923
# 10         BNN_pred     50.584981     -0.290588         -5.092098
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.993311     -0.117848        -13.326126
# 1             HV_dw     16.206112     -0.355676        -12.148223
# 2             HV_cw    203.256167      0.697173         -4.575158
# 3         LSTM_pred    -60.443575     -0.781569        -16.592461
# 4          GRU_pred    -44.447739     -0.706548        -17.323335
# 5     LSTM_GRU_pred     21.001389     -0.378772        -11.458045
# 6       BiLSTM_pred   -120.871563     -1.158405        -19.619058
# 7   BiLSTM_GRU_pred    -53.042030     -0.997039        -21.144493
# 8         QRNN_pred    144.391152      0.329506         -9.799737
# 9          ESN_pred   -126.593648     -1.543308        -21.284007
# 10         BNN_pred    -80.450402     -0.925921        -19.724387
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     45.371961     -0.283786        -17.165572
# 1             HV_dw     16.909574     -0.325375        -11.726261
# 2             HV_cw    176.596034      0.468163         -9.459582
# 3         LSTM_pred    -62.782245     -0.772808        -17.964817
# 4          GRU_pred    -27.648208     -0.582723        -16.308246
# 5     LSTM_GRU_pred    -20.425446     -0.667657        -18.450435
# 6       BiLSTM_pred   -136.774418     -1.164638        -22.306789
# 7   BiLSTM_GRU_pred    -31.403868     -0.837819        -20.727124
# 8         QRNN_pred     48.912648     -0.273956        -16.984034
# 9          ESN_pred    -97.888522     -1.219552        -22.354545
# 10         BNN_pred    -59.764547     -0.735472        -20.245184
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    101.393119      0.108515         -9.799737
# 1             HV_dw     28.620112     -0.297027        -14.091624
# 2             HV_cw    144.391152      0.329506         -9.799737
# 3         LSTM_pred     30.102633     -0.442237        -20.097666
# 4          GRU_pred     87.496781     -0.038082        -12.749731
# 5     LSTM_GRU_pred     87.496781      0.121888         -9.924927
# 6       BiLSTM_pred      5.348725     -0.408524        -17.166916
# 7   BiLSTM_GRU_pred    -23.861638     -0.656708        -18.359646
# 8         QRNN_pred     99.531330      0.098882         -9.799737
# 9          ESN_pred   -104.355255     -1.936423        -16.123923
# 10         BNN_pred    100.010583      0.017559         -9.799737
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     32.440514     -0.212827        -14.485122
# 1             HV_dw     56.286311     -0.243198        -15.486325
# 2             HV_cw    144.391152      0.329506         -9.799737
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     66.385333     -0.285652        -17.283313
# 5     LSTM_GRU_pred     43.564618     -0.180198        -15.296346
# 6       BiLSTM_pred     24.967921     -0.312003        -17.766445
# 7   BiLSTM_GRU_pred     -6.122574     -0.609709        -20.400858
# 8         QRNN_pred    144.391152      0.329506         -9.799737
# 9          ESN_pred    -26.089642     -0.724842        -20.495952
# 10         BNN_pred      3.573994     -0.564413        -20.002096
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.374531        -18.782372
# 1             HV_dw     18.063823     -0.412659        -18.544514
# 2             HV_cw     24.967921     -0.248106        -15.104061
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     66.385333     -0.285652        -17.283313
# 5     LSTM_GRU_pred     43.564618     -0.383257        -19.053455
# 6       BiLSTM_pred     24.967921     -0.459326        -20.400858
# 7   BiLSTM_GRU_pred     -1.428481     -0.592726        -20.495952
# 8         QRNN_pred     24.967921     -0.381271        -18.879134
# 9          ESN_pred     24.967921     -0.464904        -20.495952
# 10         BNN_pred     24.967921     -0.459326        -20.400858
# 11               __     24.967921     -0.464904        -20.495952

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -28.956874     -0.731561        -20.764324
# 1             HV_dw    -23.917284     -0.589242        -20.873565
# 2             HV_cw     60.585824     -0.313890        -19.729557
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     29.622979     -0.355099        -19.209938
# 5     LSTM_GRU_pred     47.381963     -0.368674        -18.757354
# 6       BiLSTM_pred     18.971519     -0.492662        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred    -31.782365     -0.750774        -20.097753
# 9          ESN_pred    -21.816959     -0.527430        -18.754036
# 10         BNN_pred     64.284538     -0.295394        -18.591564
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     23.022283     -0.564987        -17.417871
# 1             HV_dw    -89.993031     -0.846613        -20.995212
# 2             HV_cw     41.575086     -0.323414        -16.403481
# 3         LSTM_pred     30.713559     -0.446100        -20.436102
# 4          GRU_pred    -40.948546     -0.597751        -18.237949
# 5     LSTM_GRU_pred    -43.538488     -0.543591        -16.823273
# 6       BiLSTM_pred     42.870095     -0.134914        -17.833672
# 7   BiLSTM_GRU_pred    -15.240028     -0.435738        -15.676882
# 8         QRNN_pred      2.713362     -0.673478        -19.447030
# 9          ESN_pred      6.860532     -0.352169        -15.729221
# 10         BNN_pred     16.683383     -0.284916        -18.624811
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -30.261755     -1.085216        -20.087116
# 1             HV_dw    -45.687566     -0.641020        -16.743012
# 2             HV_cw    122.498201      0.126035         -9.476439
# 3         LSTM_pred     36.876364     -0.418535        -20.037516
# 4          GRU_pred    -80.493023     -0.864151        -18.067378
# 5     LSTM_GRU_pred    -62.687000     -0.828987        -14.735810
# 6       BiLSTM_pred     66.296083     -0.035478        -12.883093
# 7   BiLSTM_GRU_pred    -48.108125     -0.708528        -11.931730
# 8         QRNN_pred    -67.577996     -1.176293        -20.734550
# 9          ESN_pred    139.279419      0.328092         -8.459812
# 10         BNN_pred     46.880511     -0.158168        -14.026877
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     25.819984     -0.647159        -17.749993
# 1             HV_dw   -100.722023     -0.915583        -20.408595
# 2             HV_cw     52.646785     -0.240223        -11.225537
# 3         LSTM_pred     30.713559     -0.446100        -20.436102
# 4          GRU_pred    -82.070142     -0.836010        -19.575515
# 5     LSTM_GRU_pred    -26.914329     -0.473254        -12.718274
# 6       BiLSTM_pred     40.409544     -0.148457        -16.941919
# 7   BiLSTM_GRU_pred    -18.691694     -0.463901        -14.446256
# 8         QRNN_pred    -63.598445     -1.137333        -21.554087
# 9          ESN_pred     41.469571     -0.197144         -9.478834
# 10         BNN_pred     24.102337     -0.258012        -17.714525
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -32.450439     -0.878273        -18.391307
# 1             HV_dw    -93.902375     -0.873276        -20.298347
# 2             HV_cw     39.482624     -0.372784        -15.497212
# 3         LSTM_pred     30.713559     -0.446100        -20.436102
# 4          GRU_pred    -31.764026     -0.550119        -17.454941
# 5     LSTM_GRU_pred    -27.645326     -0.466267        -15.441156
# 6       BiLSTM_pred     42.870095     -0.134914        -17.833672
# 7   BiLSTM_GRU_pred    -15.240028     -0.435738        -15.676882
# 8         QRNN_pred    -11.720415     -0.743051        -18.760675
# 9          ESN_pred    -22.825412     -0.496164        -15.658646
# 10         BNN_pred      5.132920     -0.342079        -18.624811
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -85.827586     -1.230639        -20.560331
# 1             HV_dw      6.518281     -0.419420        -18.762190
# 2             HV_cw    160.615567      0.316286         -9.476439
# 3         LSTM_pred     30.102633     -0.442237        -20.097666
# 4          GRU_pred      9.054275     -0.472513        -17.374137
# 5     LSTM_GRU_pred     87.276083     -0.202878        -15.662873
# 6       BiLSTM_pred     38.756709     -0.414046        -19.053455
# 7   BiLSTM_GRU_pred      5.851667     -0.553613        -19.820536
# 8         QRNN_pred    -76.969654     -1.116073        -21.532937
# 9          ESN_pred    122.070554      0.211511         -8.361729
# 10         BNN_pred     88.328792     -0.190113        -16.732833
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     13.516879     -0.599172        -18.913265
# 1             HV_dw    -31.526274     -0.630390        -20.839964
# 2             HV_cw     82.789108     -0.075907        -10.159929
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     -7.586289     -0.537155        -18.471345
# 5     LSTM_GRU_pred     46.678834     -0.372003        -18.811894
# 6       BiLSTM_pred      7.062798     -0.549860        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred    -23.536495     -0.754574        -20.513548
# 9          ESN_pred     72.365208     -0.033731        -10.421630
# 10         BNN_pred     88.536131     -0.190815        -17.434259
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -28.091901     -0.739399        -20.764324
# 1             HV_dw    -26.079502     -0.600144        -20.873565
# 2             HV_cw     11.070859     -0.553277        -22.360943
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     37.129509     -0.321194        -18.620933
# 5     LSTM_GRU_pred     47.381963     -0.368674        -18.757354
# 6       BiLSTM_pred     18.971519     -0.492662        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred    -34.739237     -0.770306        -19.585846
# 9          ESN_pred     -8.303623     -0.537741        -18.597793
# 10         BNN_pred     64.284538     -0.295394        -18.591564
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.459326        -20.400858
# 1             HV_dw     30.102633     -0.442237        -20.097666
# 2             HV_cw     66.385333     -0.127978        -14.443511
# 3         LSTM_pred     30.102633     -0.442237        -20.097666
# 4          GRU_pred     43.564618     -0.383257        -19.053455
# 5     LSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 6       BiLSTM_pred     31.368477     -0.440361        -19.053455
# 7   BiLSTM_GRU_pred      5.851667     -0.553613        -19.820536
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred    129.088443      0.236646         -9.799737
# 10         BNN_pred     32.440514     -0.425959        -19.820536
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.464904        -20.495952
# 1             HV_dw     32.440514     -0.431545        -19.916323
# 2             HV_cw     43.564618     -0.228538        -16.274425
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     30.102633     -0.442237        -20.097666
# 5     LSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 6       BiLSTM_pred     12.989120     -0.521979        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred     65.669446     -0.059535        -11.732839
# 10         BNN_pred     24.967921     -0.464904        -20.495952
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.464904        -20.495952
# 1             HV_dw     24.967921     -0.464904        -20.495952
# 2             HV_cw     24.967921     -0.464904        -20.495952
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     32.440514     -0.431545        -19.916323
# 5     LSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred     32.440514     -0.340393        -18.190250
# 10         BNN_pred     24.967921     -0.464904        -20.495952
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      7.308684     -0.564809        -21.304412
# 1             HV_dw     -4.941309     -0.486222        -19.429947
# 2             HV_cw     36.170881     -0.458417        -18.766464
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     24.229138     -0.472672        -20.561090
# 5     LSTM_GRU_pred    -36.336055     -0.451975        -19.962393
# 6       BiLSTM_pred     44.052578     -0.383844        -20.764324
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     28.057380     -0.465320        -20.521972
# 9          ESN_pred     29.385940     -0.149028        -15.443545
# 10         BNN_pred     59.154214     -0.323834        -18.439242
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -43.215665     -0.932287        -19.078211
# 1             HV_dw    -42.953087     -0.689177        -20.497805
# 2             HV_cw     38.345891     -0.427902        -17.787685
# 3         LSTM_pred    -28.861159     -0.499372        -20.629281
# 4          GRU_pred     16.857589     -0.302705        -17.794708
# 5     LSTM_GRU_pred     74.748111     -0.019049        -14.073395
# 6       BiLSTM_pred     25.750906     -0.217180        -17.833672
# 7   BiLSTM_GRU_pred    -29.284953     -0.530057        -18.108174
# 8         QRNN_pred    -23.997943     -0.770336        -20.480276
# 9          ESN_pred     24.908683     -0.195559        -13.422034
# 10         BNN_pred     32.800310     -0.206288        -18.219933
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -63.461550     -1.286010        -19.959688
# 1             HV_dw     -5.606419     -0.485778        -17.733323
# 2             HV_cw     61.672873     -0.244172         -9.984613
# 3         LSTM_pred     -6.089583     -0.390011        -19.603199
# 4          GRU_pred    -21.877377     -0.549335        -15.539301
# 5     LSTM_GRU_pred     66.628533     -0.078524        -15.117376
# 6       BiLSTM_pred     20.830562     -0.235478        -11.885840
# 7   BiLSTM_GRU_pred    -69.795878     -0.796487        -18.389512
# 8         QRNN_pred    -90.552177     -1.318601        -21.863592
# 9          ESN_pred    122.774034      0.239597         -8.534812
# 10         BNN_pred     67.383965     -0.055106        -14.581871
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -57.145455     -1.190789        -19.073025
# 1             HV_dw    -15.945174     -0.559698        -18.187353
# 2             HV_cw     90.651125     -0.219086        -12.984831
# 3         LSTM_pred    -28.861159     -0.499372        -20.629281
# 4          GRU_pred     24.860254     -0.270519        -14.852242
# 5     LSTM_GRU_pred     51.748969     -0.135651        -12.710471
# 6       BiLSTM_pred     13.231354     -0.282401        -17.009969
# 7   BiLSTM_GRU_pred    -23.463223     -0.516610        -17.936648
# 8         QRNN_pred    -71.472524     -1.182715        -21.065625
# 9          ESN_pred    118.690556      0.197478         -8.534812
# 10         BNN_pred     27.290032     -0.241876        -17.640050
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -61.529589     -1.084192        -18.398951
# 1             HV_dw    -45.073137     -0.700150        -20.497805
# 2             HV_cw     86.924338     -0.235068        -15.790906
# 3         LSTM_pred    -28.861159     -0.499372        -20.629281
# 4          GRU_pred     17.845891     -0.300244        -15.922860
# 5     LSTM_GRU_pred     48.995280     -0.141076        -14.450705
# 6       BiLSTM_pred     25.750906     -0.217180        -17.833672
# 7   BiLSTM_GRU_pred    -29.284953     -0.530057        -18.108174
# 8         QRNN_pred    -60.407978     -0.976894        -22.031355
# 9          ESN_pred     85.849088      0.029434         -9.523985
# 10         BNN_pred     42.355241     -0.166161        -17.393281
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -79.032758     -1.184345        -19.916383
# 1             HV_dw     33.732283     -0.279401        -16.712344
# 2             HV_cw    100.399356     -0.026298        -10.353231
# 3         LSTM_pred     30.102633     -0.442237        -20.097666
# 4          GRU_pred     33.184284     -0.453481        -15.802871
# 5     LSTM_GRU_pred     10.390304     -0.311121        -18.675932
# 6       BiLSTM_pred     70.172149     -0.281005        -18.403206
# 7   BiLSTM_GRU_pred      5.851667     -0.553613        -19.820536
# 8         QRNN_pred    -72.125825     -1.076955        -22.094325
# 9          ESN_pred    170.458734      0.498248         -8.459812
# 10         BNN_pred     53.581419     -0.349494        -18.341688
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -85.533871     -1.212577        -20.139401
# 1             HV_dw     17.395126     -0.383779        -17.736583
# 2             HV_cw    123.898209     -0.050292        -13.341163
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     48.203103     -0.372404        -17.604695
# 5     LSTM_GRU_pred    -24.606035     -0.399918        -19.069883
# 6       BiLSTM_pred     31.850735     -0.441290        -20.764324
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred    -52.659599     -0.957093        -21.298714
# 9          ESN_pred    180.187284      0.491879         -8.396111
# 10         BNN_pred     45.610617     -0.388796        -18.439242
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     18.038752     -0.526186        -20.403561
# 1             HV_dw     -4.941309     -0.486222        -19.429947
# 2             HV_cw     68.494070     -0.318979        -17.157398
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     19.238454     -0.497726        -19.981936
# 5     LSTM_GRU_pred    -36.336055     -0.451975        -19.962393
# 6       BiLSTM_pred     44.052578     -0.383844        -20.764324
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     24.884912     -0.498354        -19.366490
# 9          ESN_pred     60.021086     -0.013058        -13.528297
# 10         BNN_pred     59.154214     -0.323834        -18.439242
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.459326        -20.400858
# 1             HV_dw     18.063823     -0.499313        -20.097666
# 2             HV_cw     37.705713     -0.290571        -14.980913
# 3         LSTM_pred     30.102633     -0.442237        -20.097666
# 4          GRU_pred     66.385333     -0.285652        -17.283313
# 5     LSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 6       BiLSTM_pred     31.368477     -0.440361        -19.053455
# 7   BiLSTM_GRU_pred      5.851667     -0.553613        -19.820536
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred    118.266827      0.194550         -9.799737
# 10         BNN_pred     24.967921     -0.459326        -20.400858
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.464904        -20.495952
# 1             HV_dw     24.967921     -0.464904        -20.495952
# 2             HV_cw     43.564618     -0.377647        -18.956636
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     43.564618     -0.383257        -19.053455
# 5     LSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 6       BiLSTM_pred     12.989120     -0.521979        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred    124.464761     -0.039078        -12.778246
# 10         BNN_pred     24.967921     -0.464904        -20.495952
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.464904        -20.495952
# 1             HV_dw     24.967921     -0.464904        -20.495952
# 2             HV_cw     24.967921     -0.464904        -20.495952
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     32.440514     -0.431545        -19.916323
# 5     LSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 8         QRNN_pred     24.967921     -0.464904        -20.495952
# 9          ESN_pred     30.102633     -0.442237        -20.097666
# 10         BNN_pred     24.967921     -0.464904        -20.495952
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -1.599263     -0.422341        -19.757864
# 1             HV_dw     -3.539346     -0.527292        -16.852710
# 2             HV_cw     -5.405686     -0.319408        -17.185161
# 3         LSTM_pred    -78.782944     -0.775425        -22.135968
# 4          GRU_pred    -14.456910     -0.385627        -18.980918
# 5     LSTM_GRU_pred    -31.419195     -0.456849        -19.962393
# 6       BiLSTM_pred     32.048087     -0.178192        -18.565528
# 7   BiLSTM_GRU_pred    -23.343409     -0.728761        -20.495952
# 8         QRNN_pred      9.002351     -0.375253        -18.896323
# 9          ESN_pred     41.425195     -0.110264        -13.740940
# 10         BNN_pred     20.672483     -0.261287        -17.762742
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     30.692802     -0.235607        -14.371352
# 1             HV_dw      5.432627     -0.420051        -12.191096
# 2             HV_cw    -35.472854     -0.549859        -15.889323
# 3         LSTM_pred    -51.547304     -0.645445        -15.928865
# 4          GRU_pred   -109.552152     -1.150961        -20.817589
# 5     LSTM_GRU_pred      7.605957     -0.366108        -16.553994
# 6       BiLSTM_pred     36.290429     -0.247411        -15.793666
# 7   BiLSTM_GRU_pred    -13.002123     -0.474524        -18.614389
# 8         QRNN_pred      1.993020     -0.285351        -17.007024
# 9          ESN_pred     88.198482      0.119553        -10.261452
# 10         BNN_pred    -68.096125     -0.768603        -21.266373
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    121.278194      0.235037         -5.018872
# 1             HV_dw     45.872638     -0.298978         -5.042351
# 2             HV_cw     83.650540     -0.005309         -5.974593
# 3         LSTM_pred    -88.402282     -1.126845        -17.204776
# 4          GRU_pred    -80.873762     -1.318199        -13.830563
# 5     LSTM_GRU_pred    -28.998794     -0.718003        -15.027694
# 6       BiLSTM_pred     63.087330     -0.035628         -7.722904
# 7   BiLSTM_GRU_pred    -15.015157     -0.632652        -11.983244
# 8         QRNN_pred     90.187589      0.048346         -9.799737
# 9          ESN_pred     87.747493      0.028447         -8.297742
# 10         BNN_pred    -50.452255     -0.822215        -18.159879
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV      3.527180     -0.394793        -15.388666
# 1             HV_dw     29.078621     -0.325067         -6.286557
# 2             HV_cw     74.604760     -0.042632         -9.221644
# 3         LSTM_pred    -94.766522     -1.024331        -18.128314
# 4          GRU_pred   -125.494546     -1.416498        -19.644351
# 5     LSTM_GRU_pred     22.032474     -0.324084        -15.719719
# 6       BiLSTM_pred     29.999287     -0.248671        -14.363809
# 7   BiLSTM_GRU_pred     -8.010331     -0.508702        -16.015761
# 8         QRNN_pred     43.131150     -0.183871        -13.599639
# 9          ESN_pred    148.470461      0.370653         -8.039689
# 10         BNN_pred    -72.665293     -0.880517        -18.983387
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     28.266314     -0.246669        -14.572941
# 1             HV_dw     -4.454174     -0.484347        -12.725008
# 2             HV_cw     -9.444568     -0.495089        -15.340970
# 3         LSTM_pred    -58.341478     -0.775391        -17.143836
# 4          GRU_pred   -148.215685     -1.423673        -22.331047
# 5     LSTM_GRU_pred     19.676779     -0.316079        -15.993980
# 6       BiLSTM_pred     67.701782     -0.026422        -15.817537
# 7   BiLSTM_GRU_pred    -29.007765     -0.582201        -18.638159
# 8         QRNN_pred      3.191493     -0.279531        -16.907757
# 9          ESN_pred    140.590643      0.315374         -8.039689
# 10         BNN_pred    -78.356197     -0.852286        -20.027736
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    116.005661      0.185564         -9.799737
# 1             HV_dw    145.957460      0.135048         -6.774368
# 2             HV_cw    108.486100      0.148404         -9.799737
# 3         LSTM_pred    -73.250743     -0.767394        -20.308594
# 4          GRU_pred     -7.618695     -0.566733        -11.725051
# 5     LSTM_GRU_pred    -90.958110     -0.873544        -18.675932
# 6       BiLSTM_pred     -3.881246     -0.446830        -12.521962
# 7   BiLSTM_GRU_pred   -107.847004     -1.206342        -21.223743
# 8         QRNN_pred     90.187589      0.048346         -9.799737
# 9          ESN_pred    144.391152      0.329506         -9.799737
# 10         BNN_pred     24.632056     -0.280759        -14.391374
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.374531        -18.782372
# 1             HV_dw     14.852725     -0.419651        -12.024058
# 2             HV_cw     31.568724     -0.223724        -15.104061
# 3         LSTM_pred    -78.782944     -0.775425        -22.135968
# 4          GRU_pred    -32.655239     -0.520721        -17.623924
# 5     LSTM_GRU_pred    -83.584885     -0.762700        -19.962393
# 6       BiLSTM_pred     15.374392     -0.276331        -17.902783
# 7   BiLSTM_GRU_pred    -57.901329     -0.941241        -20.679531
# 8         QRNN_pred     24.967921     -0.248106        -15.104061
# 9          ESN_pred    144.391152      0.329506         -9.799737
# 10         BNN_pred     51.613586     -0.128553        -14.818104
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     -0.405087     -0.416755        -19.661887
# 1             HV_dw     11.087963     -0.459792        -15.019547
# 2             HV_cw     21.433979     -0.266695        -15.104061
# 3         LSTM_pred    -78.782944     -0.775425        -22.135968
# 4          GRU_pred    -25.666769     -0.439055        -17.570783
# 5     LSTM_GRU_pred    -58.265576     -0.602075        -19.962393
# 6       BiLSTM_pred     48.188460     -0.103429        -17.681718
# 7   BiLSTM_GRU_pred    -39.725126     -0.825037        -20.495952
# 8         QRNN_pred     10.209208     -0.369630        -18.799316
# 9          ESN_pred     58.773727     -0.105412        -12.303997
# 10         BNN_pred     16.942944     -0.287690        -16.931468
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    116.005661      0.185564         -9.799737
# 1             HV_dw     74.787206     -0.198949        -14.451257
# 2             HV_cw    101.393119      0.108515         -9.799737
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     50.861126     -0.268579        -16.903034
# 5     LSTM_GRU_pred     -6.122574     -0.615333        -20.495952
# 6       BiLSTM_pred     56.286311     -0.332422        -17.097789
# 7   BiLSTM_GRU_pred      1.123351     -0.495377        -18.359646
# 8         QRNN_pred     90.187589      0.048346         -9.799737
# 9          ESN_pred    144.391152      0.329506         -9.799737
# 10         BNN_pred     30.102633     -0.436651        -20.002096
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.374531        -18.782372
# 1             HV_dw     18.063823     -0.493710        -20.002096
# 2             HV_cw     24.967921     -0.248106        -15.104061
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     66.385333     -0.285652        -17.283313
# 5     LSTM_GRU_pred     -1.428481     -0.592726        -20.495952
# 6       BiLSTM_pred     12.989120     -0.521979        -20.495952
# 7   BiLSTM_GRU_pred     -1.927783     -0.589517        -20.400858
# 8         QRNN_pred     24.967921     -0.248106        -15.104061
# 9          ESN_pred    144.391152      0.329506         -9.799737
# 10         BNN_pred     24.967921     -0.459326        -20.400858
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.459326        -20.400858
# 1             HV_dw     24.967921     -0.464904        -20.495952
# 2             HV_cw     24.967921     -0.248106        -15.104061
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     43.564618     -0.383257        -19.053455
# 5     LSTM_GRU_pred     24.967921     -0.464904        -20.495952
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     -1.428481     -0.592726        -20.495952
# 8         QRNN_pred     24.967921     -0.378384        -18.950542
# 9          ESN_pred     24.967921     -0.248106        -15.104061
# 10         BNN_pred     24.967921     -0.464904        -20.495952
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     32.123759     -0.271088        -17.047522
# 1             HV_dw    -29.575624     -0.576268        -15.912127
# 2             HV_cw    -13.675940     -0.367875        -16.807614
# 3         LSTM_pred    -60.279661     -0.753242        -17.964817
# 4          GRU_pred     -8.131117     -0.447817        -18.725224
# 5     LSTM_GRU_pred    -80.822291     -0.717647        -19.911968
# 6       BiLSTM_pred     72.036359      0.002302        -19.431288
# 7   BiLSTM_GRU_pred     15.924789     -0.558118        -21.463783
# 8         QRNN_pred     35.808818     -0.356317        -18.517329
# 9          ESN_pred     62.697766     -0.002696        -11.978977
# 10         BNN_pred      2.977043     -0.362462        -20.264190
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     60.271708     -0.020125        -12.625785
# 1             HV_dw     60.439668     -0.122443         -7.311682
# 2             HV_cw    -29.014797     -0.480872        -13.570110
# 3         LSTM_pred    -37.770788     -0.566536        -17.062600
# 4          GRU_pred   -109.552152     -1.150961        -20.817589
# 5     LSTM_GRU_pred      4.551051     -0.399250        -12.878632
# 6       BiLSTM_pred     73.212249     -0.069571        -10.479000
# 7   BiLSTM_GRU_pred    -26.085979     -0.584869        -18.692231
# 8         QRNN_pred     51.533839     -0.058503        -11.923522
# 9          ESN_pred     16.186395     -0.250479        -12.579522
# 10         BNN_pred    -71.011303     -0.818910        -21.167136
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    131.051662      0.302227         -5.018872
# 1             HV_dw     20.179710     -0.562630         -5.042351
# 2             HV_cw      3.779160     -0.652039         -6.741115
# 3         LSTM_pred    -61.381556     -0.896926        -15.022602
# 4          GRU_pred    -48.136484     -1.391469        -10.145658
# 5     LSTM_GRU_pred    -39.495834     -0.885142        -12.578878
# 6       BiLSTM_pred     91.843194      0.187161         -7.679430
# 7   BiLSTM_GRU_pred    -16.585805     -0.724414        -11.233970
# 8         QRNN_pred    117.451634      0.216399         -5.018872
# 9          ESN_pred    113.619592      0.213353         -6.850416
# 10         BNN_pred   -119.138213     -1.380545        -20.059018
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     65.458542     -0.083663        -10.166989
# 1             HV_dw     89.328528      0.038531         -5.394122
# 2             HV_cw     12.962387     -0.447343         -7.866254
# 3         LSTM_pred    -72.342025     -0.842343        -15.679263
# 4          GRU_pred   -125.494546     -1.416498        -19.644351
# 5     LSTM_GRU_pred     26.861592     -0.328316        -10.773622
# 6       BiLSTM_pred     27.506107     -0.321794        -10.157949
# 7   BiLSTM_GRU_pred    -46.456885     -0.808229        -15.204778
# 8         QRNN_pred    103.113700      0.118267        -11.493259
# 9          ESN_pred    112.277227      0.179416         -8.051161
# 10         BNN_pred   -143.054209     -1.409725        -22.664162
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     90.071233      0.051037        -11.486108
# 1             HV_dw      5.331966     -0.450693         -9.971422
# 2             HV_cw     30.120241     -0.259883        -10.994235
# 3         LSTM_pred    -44.922008     -0.635777        -16.172053
# 4          GRU_pred   -141.401015     -1.471526        -21.233661
# 5     LSTM_GRU_pred     11.129646     -0.385544        -12.552469
# 6       BiLSTM_pred    -15.980861     -0.486350        -17.522326
# 7   BiLSTM_GRU_pred    -47.028121     -0.738745        -16.744589
# 8         QRNN_pred     61.932344     -0.082315        -12.355640
# 9          ESN_pred     94.304284      0.070169        -10.415150
# 10         BNN_pred    -87.358138     -0.963823        -20.928024
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    101.393119      0.108515         -9.799737
# 1             HV_dw     71.504873     -0.073749         -5.086333
# 2             HV_cw     76.519558     -0.034312         -9.799737
# 3         LSTM_pred    -18.279207     -0.613808        -14.418789
# 4          GRU_pred     64.556520     -0.137789         -8.202035
# 5     LSTM_GRU_pred    -60.301726     -0.860321        -17.369146
# 6       BiLSTM_pred     94.681774      0.200739        -10.015166
# 7   BiLSTM_GRU_pred      7.498551     -0.654617        -15.129928
# 8         QRNN_pred     99.531330      0.098882         -9.799737
# 9          ESN_pred    144.391152      0.329506         -9.799737
# 10         BNN_pred    -25.489074     -0.626363        -18.166793
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     52.993311     -0.117848        -13.326126
# 1             HV_dw     62.878585     -0.109840         -7.821472
# 2             HV_cw      6.134054     -0.369593        -13.953453
# 3         LSTM_pred    -60.443575     -0.781569        -16.592461
# 4          GRU_pred    -44.447739     -0.706548        -17.323335
# 5     LSTM_GRU_pred   -105.612629     -0.952608        -19.261009
# 6       BiLSTM_pred     70.733881     -0.023841        -11.180116
# 7   BiLSTM_GRU_pred    -53.042030     -0.997039        -21.144493
# 8         QRNN_pred    144.391152      0.329506         -9.799737
# 9          ESN_pred    144.391152      0.329506         -9.799737
# 10         BNN_pred    -45.316873     -0.680411        -18.015882
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     45.371961     -0.283786        -17.165572
# 1             HV_dw    -42.251539     -0.675953        -13.384641
# 2             HV_cw     47.316335     -0.153101        -13.953453
# 3         LSTM_pred    -62.782245     -0.772808        -17.964817
# 4          GRU_pred    -27.648208     -0.582723        -16.308246
# 5     LSTM_GRU_pred    -66.311270     -0.675146        -19.911968
# 6       BiLSTM_pred     60.802723     -0.053853        -18.623601
# 7   BiLSTM_GRU_pred    -31.403868     -0.837819        -20.727124
# 8         QRNN_pred     48.912648     -0.273956        -16.984034
# 9          ESN_pred    144.391152      0.329506         -9.799737
# 10         BNN_pred     11.343020     -0.343785        -17.507788
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    101.393119      0.108515         -9.799737
# 1             HV_dw     74.787206     -0.198949        -14.451257
# 2             HV_cw     97.776509      0.089220         -9.799737
# 3         LSTM_pred     30.102633     -0.442237        -20.097666
# 4          GRU_pred     87.496781     -0.038082        -12.749731
# 5     LSTM_GRU_pred     -6.122574     -0.609709        -20.400858
# 6       BiLSTM_pred     56.286311     -0.332422        -17.097789
# 7   BiLSTM_GRU_pred    -23.861638     -0.656708        -18.359646
# 8         QRNN_pred     99.531330      0.098882         -9.799737
# 9          ESN_pred    144.391152      0.329506         -9.799737
# 10         BNN_pred     30.102633     -0.436651        -20.002096
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     32.440514     -0.212827        -14.485122
# 1             HV_dw     18.063823     -0.412659        -18.544514
# 2             HV_cw     -6.122574     -0.404219        -15.104061
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     66.385333     -0.285652        -17.283313
# 5     LSTM_GRU_pred     -6.122574     -0.615333        -20.495952
# 6       BiLSTM_pred     31.368477     -0.440361        -19.053455
# 7   BiLSTM_GRU_pred     -6.122574     -0.609709        -20.400858
# 8         QRNN_pred    144.391152      0.329506         -9.799737
# 9          ESN_pred    144.391152      0.329506         -9.799737
# 10         BNN_pred     24.967921     -0.459326        -20.400858
# 11               __     24.967921     -0.464904        -20.495952
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     24.967921     -0.374531        -18.782372
# 1             HV_dw     32.440514     -0.431545        -19.916323
# 2             HV_cw     24.967921     -0.248106        -15.104061
# 3         LSTM_pred     24.967921     -0.464904        -20.495952
# 4          GRU_pred     66.385333     -0.285652        -17.283313
# 5     LSTM_GRU_pred     -1.428481     -0.592726        -20.495952
# 6       BiLSTM_pred     24.967921     -0.464904        -20.495952
# 7   BiLSTM_GRU_pred     -1.428481     -0.592726        -20.495952
# 8         QRNN_pred     24.967921     -0.381271        -18.879134
# 9          ESN_pred    144.391152      0.329506         -9.799737
# 10         BNN_pred     24.967921     -0.464904        -20.495952
# 11               __     24.967921     -0.464904        -20.495952

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_2y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_2y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_2y1', file, 'HV')
get_final_results_1('2024_2y1', file, 'HV')

get_final_results('2024_2y1', dw_file, 'HV_dw')
get_final_results_1('2024_2y1', dw_file, 'HV_dw')

get_final_results('2024_2y1', cw_file, 'HV_cw')
get_final_results_1('2024_2y1', cw_file, 'HV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    194.933591      0.607452         -7.224172
# 1             HV_dw    265.157241      0.752923         -7.729145
# 2             HV_cw    123.153912      0.512936         -7.590989
# 3         LSTM_pred    171.163689      0.367774         -8.594452
# 4          GRU_pred    173.492396      0.398684         -8.484837
# 5     LSTM_GRU_pred    161.275985      0.349748         -8.845210
# 6       BiLSTM_pred     73.447650      0.346248         -8.485144
# 7   BiLSTM_GRU_pred    101.586689      0.274247         -8.782947
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    227.980405      0.573358         -7.688132
# 10         BNN_pred     74.200405      0.241602         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    208.245843      0.565867         -7.576536
# 1             HV_dw    337.711204      1.022181         -6.271406
# 2             HV_cw     37.414746     -0.205640         -9.850786
# 3         LSTM_pred     70.717975     -0.030116         -8.327056
# 4          GRU_pred    164.157606      0.350582         -8.752516
# 5     LSTM_GRU_pred    159.356906      0.337614         -8.802522
# 6       BiLSTM_pred     85.805397      0.024762        -11.057259
# 7   BiLSTM_GRU_pred     99.878566      0.051812        -10.633214
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    199.971951      0.497817         -7.912772
# 10         BNN_pred     71.895226     -0.019662        -10.501304
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     74.596581     -0.004809         -8.543980
# 1             HV_dw    409.027546      1.372869         -4.680314
# 2             HV_cw     45.561888     -0.166433         -6.266613
# 3         LSTM_pred     62.537295     -0.072174         -8.992571
# 4          GRU_pred    286.294751      0.875432         -6.501162
# 5     LSTM_GRU_pred    251.390120      0.751172         -7.861297
# 6       BiLSTM_pred     55.063592     -0.124701         -9.439082
# 7   BiLSTM_GRU_pred     41.841284     -0.160187        -11.058063
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    136.122208      0.261213         -6.938479
# 10         BNN_pred    119.966970      0.186164        -10.022314
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    150.641048      0.356108         -7.955842
# 1             HV_dw    315.206849      0.949777         -6.271406
# 2             HV_cw      7.582864     -0.386595         -9.519739
# 3         LSTM_pred     56.683821     -0.099075         -9.042385
# 4          GRU_pred    219.958302      0.570510         -7.022147
# 5     LSTM_GRU_pred    220.570301      0.584631         -7.052129
# 6       BiLSTM_pred    106.251083      0.111824        -10.852899
# 7   BiLSTM_GRU_pred     42.236017     -0.158372        -11.053875
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    202.964618      0.521686         -6.073185
# 10         BNN_pred    130.172176      0.224437        -10.022314
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    126.200875      0.239722         -8.011545
# 1             HV_dw    322.004018      0.969062         -6.271406
# 2             HV_cw     35.472775     -0.198244        -11.480571
# 3         LSTM_pred     94.185721      0.025118         -8.725659
# 4          GRU_pred    164.157606      0.350582         -8.752516
# 5     LSTM_GRU_pred    159.356906      0.337614         -8.802522
# 6       BiLSTM_pred     85.805397      0.024762        -11.057259
# 7   BiLSTM_GRU_pred     92.909187      0.022250        -11.527645
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    209.373283      0.534237         -7.154090
# 10         BNN_pred     74.114581     -0.010184        -10.479606
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     95.745562      0.098820         -8.126908
# 1             HV_dw    341.408973      1.100763         -7.018341
# 2             HV_cw    101.013014      0.121623         -7.936242
# 3         LSTM_pred    154.621165      0.307214         -8.717587
# 4          GRU_pred    296.064189      0.847185         -6.699473
# 5     LSTM_GRU_pred    315.354852      0.896214         -6.699473
# 6       BiLSTM_pred    109.225844      0.465946         -8.485144
# 7   BiLSTM_GRU_pred    106.033972      0.247837         -8.839221
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    220.284164      0.563680         -7.655045
# 10         BNN_pred     80.769494      0.268835         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    163.201192      0.580189         -7.968136
# 1             HV_dw    269.363246      0.768447         -7.729145
# 2             HV_cw     69.884255     -0.055306         -8.167151
# 3         LSTM_pred    159.028515      0.323490         -8.684437
# 4          GRU_pred    226.997066      0.605601         -7.394022
# 5     LSTM_GRU_pred    203.361131      0.513622         -7.356273
# 6       BiLSTM_pred     72.379236      0.342014         -8.485144
# 7   BiLSTM_GRU_pred    110.255858      0.264151         -8.805608
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    228.250166      0.585183         -7.605397
# 10         BNN_pred     81.493623      0.270921         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    189.405658      0.587891         -7.257747
# 1             HV_dw    265.157241      0.752923         -7.729145
# 2             HV_cw     94.807998      0.302155         -7.966974
# 3         LSTM_pred    171.163689      0.367774         -8.594452
# 4          GRU_pred    173.492396      0.398684         -8.484837
# 5     LSTM_GRU_pred    161.275985      0.349748         -8.845210
# 6       BiLSTM_pred     73.447650      0.346248         -8.485144
# 7   BiLSTM_GRU_pred    101.586689      0.274247         -8.782947
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    228.028764      0.573528         -7.688132
# 10         BNN_pred     74.200405      0.241602         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw      2.582548      0.606052         -8.485144
# 2             HV_cw    -45.424503      0.372853         -8.485144
# 3         LSTM_pred    -45.424503      0.356725         -8.485144
# 4          GRU_pred      1.758086      0.585176         -8.485144
# 5     LSTM_GRU_pred      1.758086      0.585176         -8.485144
# 6       BiLSTM_pred    -13.608338      0.516799         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.356725         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -42.375500      0.386514         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -45.424503      0.372853         -8.485144
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    -28.031900      0.447586         -8.485144
# 5     LSTM_GRU_pred    -28.031900      0.447586         -8.485144
# 6       BiLSTM_pred    -46.374603      0.368622         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -46.374603      0.368622         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -45.424503      0.372853         -8.485144
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    -45.424503      0.372853         -8.485144
# 5     LSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 6       BiLSTM_pred    -45.424503      0.372853         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -45.424503      0.372853         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    119.135459      0.453192         -8.655431
# 1             HV_dw    206.527238      0.500435         -7.690736
# 2             HV_cw    110.995410      0.180892         -8.485144
# 3         LSTM_pred    167.949841      0.355722         -8.485144
# 4          GRU_pred    121.591613      0.283854         -8.940757
# 5     LSTM_GRU_pred    164.889978      0.288655         -8.936586
# 6       BiLSTM_pred    -45.424503      0.372853         -8.485144
# 7   BiLSTM_GRU_pred    142.092085      0.260389         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    152.719538      0.300258         -9.488954
# 10         BNN_pred     84.599318      0.284101         -8.755451
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    197.719890      0.483139         -7.678001
# 1             HV_dw    427.782168      1.299756         -7.682955
# 2             HV_cw     78.657679      0.028758         -9.440405
# 3         LSTM_pred    110.215172      0.095246         -8.570774
# 4          GRU_pred    171.180176      0.375575         -9.384277
# 5     LSTM_GRU_pred    190.369084      0.453029         -8.603173
# 6       BiLSTM_pred    113.541962      0.135365        -10.786784
# 7   BiLSTM_GRU_pred    129.830074      0.174072         -9.677844
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    283.054760      0.755709         -7.269949
# 10         BNN_pred     88.415687      0.007044        -10.379941
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     10.871198     -0.359650         -9.290298
# 1             HV_dw    489.104344      1.604057         -7.035518
# 2             HV_cw     60.676936     -0.106586         -8.890511
# 3         LSTM_pred     59.983375     -0.078834         -9.744217
# 4          GRU_pred    343.009320      1.064708         -6.485286
# 5     LSTM_GRU_pred    322.286800      1.003943         -7.853231
# 6       BiLSTM_pred    134.599659      0.223134         -7.944563
# 7   BiLSTM_GRU_pred     40.842104     -0.158359         -9.505724
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    252.540017      0.769419         -6.073076
# 10         BNN_pred    130.974696      0.227924         -9.364239
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    130.103543      0.230869         -8.081502
# 1             HV_dw    402.775877      1.226746         -7.682955
# 2             HV_cw     42.169923     -0.141034         -8.485144
# 3         LSTM_pred     61.022284     -0.074131         -9.734675
# 4          GRU_pred    253.429050      0.691398         -7.228668
# 5     LSTM_GRU_pred    259.565274      0.725920         -6.768915
# 6       BiLSTM_pred    127.661916      0.194457        -10.651718
# 7   BiLSTM_GRU_pred     54.452993     -0.096971         -9.383024
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    247.017941      0.684265         -7.487663
# 10         BNN_pred    150.597454      0.302461         -9.364239
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    153.204590      0.312755         -9.657751
# 1             HV_dw    419.852408      1.277219         -7.682955
# 2             HV_cw     35.720610     -0.159744         -9.218369
# 3         LSTM_pred     94.767483      0.076762         -8.604863
# 4          GRU_pred    189.548261      0.446963         -9.239372
# 5     LSTM_GRU_pred    203.472916      0.503617         -8.603173
# 6       BiLSTM_pred    113.541962      0.135365        -10.786784
# 7   BiLSTM_GRU_pred    100.052025      0.099242         -9.669981
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    211.330573      0.540432        -10.529296
# 10         BNN_pred     96.056957      0.038201        -10.307577
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     94.997663      0.076584         -9.943686
# 1             HV_dw    317.484459      0.933320         -7.035518
# 2             HV_cw    110.135386      0.120915         -8.485144
# 3         LSTM_pred    171.949919      0.372749         -8.485144
# 4          GRU_pred    264.990766      0.868763         -6.469453
# 5     LSTM_GRU_pred    251.398326      0.755881         -6.693578
# 6       BiLSTM_pred     -9.512788      0.534782         -8.485144
# 7   BiLSTM_GRU_pred    108.755014      0.133837         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    182.471238      0.425187         -7.852318
# 10         BNN_pred     61.167977      0.190112         -8.948778
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    102.975270      0.107420         -9.385339
# 1             HV_dw    206.532903      0.501081         -7.682955
# 2             HV_cw     73.962135      0.007845         -8.485144
# 3         LSTM_pred    176.423416      0.389112         -8.485144
# 4          GRU_pred    206.953130      0.640697         -6.362977
# 5     LSTM_GRU_pred    196.101768      0.473602         -7.163256
# 6       BiLSTM_pred    -46.374603      0.368622         -8.485144
# 7   BiLSTM_GRU_pred    146.716082      0.279162         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    155.348054      0.311877         -9.282564
# 10         BNN_pred     91.963139      0.313646         -8.696408
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     91.989563      0.348645         -9.657373
# 1             HV_dw    206.527238      0.500435         -7.690736
# 2             HV_cw     75.043647      0.026833         -8.485144
# 3         LSTM_pred    154.621379      0.306986         -8.485144
# 4          GRU_pred    134.310820      0.334908         -8.881382
# 5     LSTM_GRU_pred    166.180688      0.294011         -8.926695
# 6       BiLSTM_pred    -45.424503      0.372853         -8.485144
# 7   BiLSTM_GRU_pred    146.716082      0.279162         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    151.782781      0.296771         -9.562508
# 10         BNN_pred     84.599318      0.284101         -8.755451
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw     10.647028      0.642896         -8.485144
# 2             HV_cw     -5.066775      0.554427         -8.485144
# 3         LSTM_pred    -45.424503      0.356725         -8.485144
# 4          GRU_pred     -5.066775      0.554301         -8.485144
# 5     LSTM_GRU_pred     -5.066775      0.554301         -8.485144
# 6       BiLSTM_pred     -9.512788      0.534782         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.356725         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -46.374603      0.364460         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -45.424503      0.372853         -8.485144
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    -30.333980      0.440992         -8.485144
# 5     LSTM_GRU_pred    -30.333980      0.436939         -8.485144
# 6       BiLSTM_pred    -46.374603      0.368622         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -46.374603      0.368622         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -45.424503      0.372853         -8.485144
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    -45.424503      0.368691         -8.485144
# 5     LSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 6       BiLSTM_pred    -45.424503      0.372853         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -45.424503      0.372853         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    115.017321      0.135857         -8.485144
# 1             HV_dw    376.885178      1.125171         -7.682955
# 2             HV_cw    106.890295      0.100162         -8.485144
# 3         LSTM_pred    119.301001      0.176045         -8.418220
# 4          GRU_pred    188.681272      0.454411        -10.016782
# 5     LSTM_GRU_pred     92.379223      0.359896        -10.016782
# 6       BiLSTM_pred    128.421923      0.197257         -9.760987
# 7   BiLSTM_GRU_pred    184.816495      0.383013         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    246.654939      0.609901         -8.485144
# 10         BNN_pred    105.641683      0.076641         -9.551330
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    185.919332      0.453682         -7.492520
# 1             HV_dw    287.146636      0.830920         -6.439893
# 2             HV_cw     62.869781     -0.091764         -8.485144
# 3         LSTM_pred    123.370607      0.152671         -8.241084
# 4          GRU_pred     77.818454     -0.006293         -8.841681
# 5     LSTM_GRU_pred     65.827160     -0.054331        -10.510498
# 6       BiLSTM_pred     56.311607     -0.128870        -10.914522
# 7   BiLSTM_GRU_pred     54.596742     -0.154829        -10.509708
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    222.816503      0.549055         -8.485144
# 10         BNN_pred     50.316027     -0.136644        -10.303479
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    223.539060      0.702262         -6.929753
# 1             HV_dw    183.272932      0.572412         -5.340240
# 2             HV_cw    -12.041605     -0.555417         -8.776004
# 3         LSTM_pred    102.960530      0.120429         -5.730045
# 4          GRU_pred    122.177544      0.235971         -4.310938
# 5     LSTM_GRU_pred    125.476580      0.242149         -6.600841
# 6       BiLSTM_pred    147.929666      0.317235         -6.212361
# 7   BiLSTM_GRU_pred     34.635657     -0.275289         -8.548690
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    117.032128      0.209529         -8.485144
# 10         BNN_pred     78.404831     -0.025041         -6.642765
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    210.014984      0.619922         -6.844365
# 1             HV_dw    291.215063      0.940734         -5.096428
# 2             HV_cw     25.881882     -0.293632         -8.485144
# 3         LSTM_pred     59.041831     -0.107994         -7.852359
# 4          GRU_pred    195.884183      0.548205         -6.216506
# 5     LSTM_GRU_pred    175.744042      0.452715         -6.433413
# 6       BiLSTM_pred    135.850894      0.242480         -7.328284
# 7   BiLSTM_GRU_pred     16.642820     -0.326180         -8.699987
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    163.798511      0.388662         -8.485144
# 10         BNN_pred     39.658666     -0.217371        -10.757714
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    156.123035      0.339602         -7.492520
# 1             HV_dw    318.533277      0.984889         -6.439893
# 2             HV_cw     71.755774     -0.056452         -8.485144
# 3         LSTM_pred     49.004696     -0.145652         -9.642790
# 4          GRU_pred    139.785967      0.287517         -7.554159
# 5     LSTM_GRU_pred    108.103144      0.135170         -9.199374
# 6       BiLSTM_pred     65.765649     -0.094929        -10.022570
# 7   BiLSTM_GRU_pred     96.256273      0.029858         -8.524255
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    157.138707      0.346484         -8.485144
# 10         BNN_pred     61.967915     -0.085355        -10.869506
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    194.926711      0.539342         -8.485144
# 1             HV_dw    324.923110      1.010098         -7.035518
# 2             HV_cw     59.595714     -0.100139         -8.485144
# 3         LSTM_pred    217.449897      0.658006         -4.652244
# 4          GRU_pred    209.111742      0.625208         -4.946832
# 5     LSTM_GRU_pred    215.109078      0.881141         -4.926820
# 6       BiLSTM_pred    145.148588      0.274078         -8.504465
# 7   BiLSTM_GRU_pred    101.584098      0.052842         -7.487295
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    142.489810      0.357845         -8.485144
# 10         BNN_pred     95.309354      0.077519         -9.320944
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    189.840387      0.487287         -8.485144
# 1             HV_dw    421.388657      1.319055         -6.976125
# 2             HV_cw     92.977222      0.040918         -8.485144
# 3         LSTM_pred     40.368516     -0.152470        -10.877680
# 4          GRU_pred    342.218075      1.057791         -6.443676
# 5     LSTM_GRU_pred    227.428842      0.979996         -6.485881
# 6       BiLSTM_pred    171.927049      0.377705         -7.196963
# 7   BiLSTM_GRU_pred    151.344024      0.263012         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    181.851349      0.437916         -8.485144
# 10         BNN_pred    122.253904      0.193174         -9.320944
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    141.457861      0.278356         -8.485144
# 1             HV_dw    377.490106      1.136427         -7.682955
# 2             HV_cw    106.343005      0.097763         -8.485144
# 3         LSTM_pred     41.388200     -0.148045        -10.867029
# 4          GRU_pred    237.106706      0.644203         -8.573957
# 5     LSTM_GRU_pred    142.808815      0.574310         -8.573957
# 6       BiLSTM_pred    123.859046      0.171054         -9.800616
# 7   BiLSTM_GRU_pred    159.153043      0.291166         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    215.768940      0.555280         -8.485144
# 10         BNN_pred    121.640914      0.188432         -9.320944
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     23.207865      0.785982         -8.485144
# 1             HV_dw    -51.425925      0.333364         -8.485144
# 2             HV_cw    -14.225352      0.541221         -8.485144
# 3         LSTM_pred     11.352275      0.472463         -8.485144
# 4          GRU_pred      9.468762      0.602719         -8.485144
# 5     LSTM_GRU_pred     -6.057043      0.533852         -8.485144
# 6       BiLSTM_pred     -6.139523      0.552819         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.355181         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred      8.697112      0.323267         -8.485144
# 10         BNN_pred    -24.927343      0.461367         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     17.854862      0.719770         -8.485144
# 1             HV_dw    -51.425925      0.349748         -8.485144
# 2             HV_cw      3.627212      0.593398         -8.485144
# 3         LSTM_pred    -45.424503      0.356725         -8.485144
# 4          GRU_pred    -12.666424      0.520773         -8.485144
# 5     LSTM_GRU_pred    -12.666424      0.520773         -8.485144
# 6       BiLSTM_pred    -28.959156      0.447694         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.356725         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -46.374603      0.364460         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -26.015159      0.464294         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -13.831873      0.515539         -8.485144
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    -45.424503      0.368691         -8.485144
# 5     LSTM_GRU_pred    -45.424503      0.368691         -8.485144
# 6       BiLSTM_pred    -46.374603      0.368622         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -45.424503      0.372853         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    156.157570      0.318988         -9.192980
# 1             HV_dw    286.036686      0.807287         -5.435068
# 2             HV_cw     72.723177     -0.040588         -8.485144
# 3         LSTM_pred    120.862575      0.140523         -8.398719
# 4          GRU_pred    188.681272      0.454411        -10.016782
# 5     LSTM_GRU_pred    220.617589      0.578720         -9.973799
# 6       BiLSTM_pred     91.450499      0.039907         -9.852905
# 7   BiLSTM_GRU_pred     88.411096      0.049380         -8.635054
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    218.961977      0.516303         -8.485144
# 10         BNN_pred    108.602708      0.088047         -7.185535
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    154.036826      0.331053         -9.004819
# 1             HV_dw    201.252918      0.509071         -8.034931
# 2             HV_cw     58.489702     -0.116913         -8.485144
# 3         LSTM_pred     80.521323      0.007645        -10.468792
# 4          GRU_pred     77.818454     -0.006293         -8.841681
# 5     LSTM_GRU_pred     48.455893     -0.142528        -11.008310
# 6       BiLSTM_pred     44.027200     -0.200956         -9.804232
# 7   BiLSTM_GRU_pred    142.646538      0.237601         -9.131879
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    289.207928      0.822329         -8.485144
# 10         BNN_pred     37.536594     -0.202628        -10.090727
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     62.384323     -0.121741         -7.844723
# 1             HV_dw    152.577532      0.471756         -5.387549
# 2             HV_cw    -15.478711     -0.609106        -10.869216
# 3         LSTM_pred     74.395799     -0.080266         -5.831255
# 4          GRU_pred    149.578638      0.445758         -4.156199
# 5     LSTM_GRU_pred    135.324833      0.327822         -5.268336
# 6       BiLSTM_pred     84.846579     -0.024368         -5.626936
# 7   BiLSTM_GRU_pred     10.077403     -0.453586        -10.016545
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    129.010364      0.295826         -8.485144
# 10         BNN_pred     41.573261     -0.302952         -5.254480
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    150.402807      0.370366         -7.166628
# 1             HV_dw    191.813378      0.535149         -5.426282
# 2             HV_cw    -30.172995     -0.610870        -11.708235
# 3         LSTM_pred     15.374220     -0.381838         -9.156622
# 4          GRU_pred    195.884183      0.548205         -6.216506
# 5     LSTM_GRU_pred    199.642113      0.596653         -6.623616
# 6       BiLSTM_pred     97.612368      0.052577         -6.373592
# 7   BiLSTM_GRU_pred     15.989674     -0.367099         -9.958256
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    160.756232      0.398204         -8.485144
# 10         BNN_pred    -17.244787     -0.581052         -9.874180
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    119.793761      0.189365         -8.295517
# 1             HV_dw    246.374887      0.759497         -7.188476
# 2             HV_cw     48.294818     -0.177812         -8.485144
# 3         LSTM_pred     16.369408     -0.375905         -9.061200
# 4          GRU_pred    139.785967      0.287517         -7.554159
# 5     LSTM_GRU_pred    260.272646      0.810535         -8.049285
# 6       BiLSTM_pred     68.757188     -0.092621        -10.271117
# 7   BiLSTM_GRU_pred     48.167766     -0.161611         -9.387711
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    179.317292      0.454523         -8.485144
# 10         BNN_pred     52.871364     -0.148695         -7.134225
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    161.258086      0.394559         -8.485144
# 1             HV_dw    169.057779      0.485802         -6.188116
# 2             HV_cw     25.092900     -0.287108         -8.485144
# 3         LSTM_pred    163.434277      0.480566         -4.305988
# 4          GRU_pred    272.607345      0.936478         -5.168150
# 5     LSTM_GRU_pred    251.419766      0.835762         -5.176153
# 6       BiLSTM_pred    117.952296      0.155188         -7.817419
# 7   BiLSTM_GRU_pred     -0.912883     -0.447446         -8.192934
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    129.010364      0.295826         -8.485144
# 10         BNN_pred     92.644614      0.061900         -7.445242
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    161.195704      0.393142         -8.485144
# 1             HV_dw    281.130633      0.866185         -4.327160
# 2             HV_cw     17.132851     -0.283022         -8.485144
# 3         LSTM_pred     61.751391     -0.074484         -9.380079
# 4          GRU_pred    342.218075      1.057791         -6.443676
# 5     LSTM_GRU_pred    306.597748      0.969053         -6.501754
# 6       BiLSTM_pred    150.331108      0.299500         -5.861922
# 7   BiLSTM_GRU_pred     -0.014415     -0.387801         -8.557715
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     94.737986      0.074431         -8.485144
# 10         BNN_pred     84.534893      0.027656         -8.160900
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    126.357626      0.207472         -8.485144
# 1             HV_dw    290.649133      0.870640         -5.435068
# 2             HV_cw     35.900643     -0.214197         -8.485144
# 3         LSTM_pred     62.792033     -0.069679         -9.370894
# 4          GRU_pred    237.106706      0.644203         -8.573957
# 5     LSTM_GRU_pred    326.962043      0.998015         -8.573957
# 6       BiLSTM_pred    103.100086      0.083075         -9.845438
# 7   BiLSTM_GRU_pred     37.330316     -0.184810         -8.562864
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    164.899760      0.368436         -8.485144
# 10         BNN_pred    141.586924      0.281938         -8.160900
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     23.207865      0.770570         -8.485144
# 1             HV_dw    -51.425925      0.333364         -8.485144
# 2             HV_cw     -9.545191      0.563203         -8.485144
# 3         LSTM_pred     11.352275      0.427608         -8.558172
# 4          GRU_pred      8.464027      0.598414         -8.485144
# 5     LSTM_GRU_pred      8.464027      0.598414         -8.485144
# 6       BiLSTM_pred     -6.139523      0.552819         -8.485144
# 7   BiLSTM_GRU_pred    -46.335167      0.157268         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred      0.000000      0.295541         -8.485144
# 10         BNN_pred    -22.477368      0.475103         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     18.820610      0.768034         -8.485144
# 1             HV_dw    -51.425925      0.349748         -8.485144
# 2             HV_cw     -7.425644      0.549156         -8.485144
# 3         LSTM_pred    -45.424503      0.356725         -8.485144
# 4          GRU_pred    -12.666424      0.520773         -8.485144
# 5     LSTM_GRU_pred    -12.666424      0.504624         -8.485144
# 6       BiLSTM_pred     -9.512788      0.534782         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.356725         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372722         -8.485144
# 10         BNN_pred    -46.374603      0.364460         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -26.015159      0.464294         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -11.991835      0.523587         -8.485144
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    -45.424503      0.368691         -8.485144
# 5     LSTM_GRU_pred    -30.333980      0.440992         -8.485144
# 6       BiLSTM_pred    -46.335167      0.368798         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -46.374603      0.368622         -8.485144
# 11               __    -45.424503      0.372853         -8.485144

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    194.933591      0.607452         -7.224172
# 1             HV_dw    230.733934      0.798580         -7.705191
# 2             HV_cw     76.301946      0.129004         -8.748976
# 3         LSTM_pred     73.447650      0.346248         -8.485144
# 4          GRU_pred     91.341688      0.366720         -8.485144
# 5     LSTM_GRU_pred    178.132462      0.334538         -8.528839
# 6       BiLSTM_pred     73.447650      0.346248         -8.485144
# 7   BiLSTM_GRU_pred    -51.017025      0.348021         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    123.210910      0.227915         -8.485144
# 10         BNN_pred    189.216416      0.400931         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    208.245843      0.565867         -7.576536
# 1             HV_dw    343.495630      1.043716         -6.335067
# 2             HV_cw     99.502269      0.092577         -9.875030
# 3         LSTM_pred     94.287212      0.203931         -9.030719
# 4          GRU_pred     78.445695      0.008605         -9.245060
# 5     LSTM_GRU_pred    106.814908      0.127312        -10.715089
# 6       BiLSTM_pred     85.805397      0.024762        -11.057259
# 7   BiLSTM_GRU_pred     63.845307      0.076400        -10.401743
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    102.376743      0.062491         -8.469975
# 10         BNN_pred    183.864452      0.404116         -5.970365
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     74.596581     -0.004809         -8.543980
# 1             HV_dw    357.258419      1.149182         -4.643589
# 2             HV_cw    100.490062      0.123622         -7.154614
# 3         LSTM_pred     93.236791      0.111577         -8.485144
# 4          GRU_pred     51.702347     -0.112964        -10.404302
# 5     LSTM_GRU_pred    112.266765      0.151606        -10.807425
# 6       BiLSTM_pred     55.063592     -0.124701         -9.439082
# 7   BiLSTM_GRU_pred     72.074796      0.012417         -8.455762
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     84.177444     -0.033649         -8.485144
# 10         BNN_pred    175.253103      0.399638         -5.565819
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    150.641048      0.356108         -7.955842
# 1             HV_dw    325.006274      0.986909         -6.335067
# 2             HV_cw     79.807054     -0.021430         -7.191808
# 3         LSTM_pred    115.282075      0.291738         -9.030719
# 4          GRU_pred     79.847003      0.014210         -9.202646
# 5     LSTM_GRU_pred     98.980732      0.094683        -10.791472
# 6       BiLSTM_pred    106.251083      0.111824        -10.852899
# 7   BiLSTM_GRU_pred     88.085860      0.166601         -7.032557
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     21.846346     -0.327519         -8.485144
# 10         BNN_pred    184.949477      0.408848         -5.422479
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    126.200875      0.239722         -8.011545
# 1             HV_dw    321.342487      0.971627         -6.335067
# 2             HV_cw     50.401735     -0.150325         -9.696725
# 3         LSTM_pred     94.287212      0.203931         -9.030719
# 4          GRU_pred     78.445695      0.008605         -9.245060
# 5     LSTM_GRU_pred     79.776132      0.013778        -10.983406
# 6       BiLSTM_pred     85.805397      0.024762        -11.057259
# 7   BiLSTM_GRU_pred     57.612612      0.049039        -10.463042
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    112.490563      0.104882         -8.485144
# 10         BNN_pred    191.377278      0.432259         -5.932715
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     95.745562      0.098820         -8.126908
# 1             HV_dw    213.447514      0.744613         -7.764192
# 2             HV_cw     66.315396     -0.033646         -8.800083
# 3         LSTM_pred     93.314434      0.370973         -8.485144
# 4          GRU_pred     90.300550      0.436129         -8.485144
# 5     LSTM_GRU_pred    201.316489      0.482778         -7.627742
# 6       BiLSTM_pred    109.225844      0.465946         -8.485144
# 7   BiLSTM_GRU_pred    -11.962202      0.527604         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    202.254678      0.496376         -8.557715
# 10         BNN_pred    158.957847      0.307961         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    163.201192      0.580189         -7.968136
# 1             HV_dw    238.306354      0.826531         -7.705191
# 2             HV_cw     51.844832     -0.134542         -9.834058
# 3         LSTM_pred     90.417378      0.390509         -8.485144
# 4          GRU_pred     91.341688      0.407651         -8.485144
# 5     LSTM_GRU_pred    180.591147      0.344061         -8.528839
# 6       BiLSTM_pred     72.379236      0.342014         -8.485144
# 7   BiLSTM_GRU_pred    -36.014912      0.416207         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    136.241897      0.211307         -8.485144
# 10         BNN_pred    170.104085      0.332332         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    189.405658      0.587891         -7.257747
# 1             HV_dw    230.733934      0.798580         -7.705191
# 2             HV_cw     53.934026      0.036516         -8.769672
# 3         LSTM_pred     73.447650      0.346248         -8.485144
# 4          GRU_pred     91.341688      0.366720         -8.485144
# 5     LSTM_GRU_pred    178.132462      0.334538         -8.528839
# 6       BiLSTM_pred     73.447650      0.346248         -8.485144
# 7   BiLSTM_GRU_pred    -51.017025      0.348021         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    159.932122      0.361847         -8.485144
# 10         BNN_pred    189.216416      0.400931         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw    -46.335167      0.368798         -8.485144
# 2             HV_cw    -45.424503      0.357607         -8.485144
# 3         LSTM_pred    -27.757740      0.461353         -8.485144
# 4          GRU_pred    -46.335167      0.368798         -8.485144
# 5     LSTM_GRU_pred    -46.335167      0.368798         -8.485144
# 6       BiLSTM_pred    -13.608338      0.516799         -8.485144
# 7   BiLSTM_GRU_pred     -6.139523      0.552819         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred     -6.057043      0.550142         -8.485144
# 10         BNN_pred    -41.012825      0.396110         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -45.424503      0.372853         -8.485144
# 3         LSTM_pred    -30.333980      0.441121         -8.485144
# 4          GRU_pred    -45.424503      0.372853         -8.485144
# 5     LSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 6       BiLSTM_pred    -46.374603      0.368622         -8.485144
# 7   BiLSTM_GRU_pred    -30.333980      0.441121         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -12.666424      0.520900         -8.485144
# 10         BNN_pred    -45.424503      0.372853         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -45.424503      0.372853         -8.485144
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    -45.424503      0.372853         -8.485144
# 5     LSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 6       BiLSTM_pred    -45.424503      0.372853         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -12.666424      0.520900         -8.485144
# 10         BNN_pred    -45.424503      0.372853         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    119.135459      0.453192         -8.655431
# 1             HV_dw    133.223959      0.426088         -7.825059
# 2             HV_cw    110.684634      0.129169         -7.948126
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    178.132462      0.334538         -8.528839
# 5     LSTM_GRU_pred    178.923585      0.337396         -8.528839
# 6       BiLSTM_pred    -45.424503      0.372853         -8.485144
# 7   BiLSTM_GRU_pred     85.026746      0.298505         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    142.622785      0.280934         -8.469611
# 10         BNN_pred    201.434381      0.444827         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    197.719890      0.483139         -7.678001
# 1             HV_dw    255.206847      0.693955         -7.706922
# 2             HV_cw    113.124247      0.107325        -10.555422
# 3         LSTM_pred    191.536546      0.433956         -8.314064
# 4          GRU_pred     30.779795     -0.198859        -11.939590
# 5     LSTM_GRU_pred    130.462591      0.229106        -10.496793
# 6       BiLSTM_pred    113.541962      0.135365        -10.786784
# 7   BiLSTM_GRU_pred     47.942416      0.007197        -12.108894
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     61.465661     -0.111799         -8.485144
# 10         BNN_pred    207.936771      0.488195         -6.649942
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     10.871198     -0.359650         -9.290298
# 1             HV_dw    187.925769      0.459135         -7.764192
# 2             HV_cw     61.119536     -0.142420         -7.186398
# 3         LSTM_pred    228.642138      0.660543         -6.794612
# 4          GRU_pred     77.576808      0.000593        -11.467960
# 5     LSTM_GRU_pred    124.495472      0.206681        -10.659903
# 6       BiLSTM_pred    134.599659      0.223134         -7.944563
# 7   BiLSTM_GRU_pred     82.723903      0.064167         -7.230829
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    105.672594      0.073421         -7.192565
# 10         BNN_pred    173.060430      0.378600         -6.649942
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    130.103543      0.230869         -8.081502
# 1             HV_dw    218.757058      0.565721         -7.764192
# 2             HV_cw     39.511390     -0.235547         -7.680039
# 3         LSTM_pred    192.352737      0.438001         -8.314064
# 4          GRU_pred     17.374294     -0.259705        -12.057061
# 5     LSTM_GRU_pred    112.178428      0.152000        -10.800547
# 6       BiLSTM_pred    127.661916      0.194457        -10.651718
# 7   BiLSTM_GRU_pred     15.113602     -0.164273        -10.167222
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     31.064762     -0.270299         -8.760386
# 10         BNN_pred    199.777397      0.458944         -6.649942
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    153.204590      0.312755         -9.657751
# 1             HV_dw    242.177688      0.648620         -7.706922
# 2             HV_cw     67.322400     -0.092422        -10.671447
# 3         LSTM_pred    191.536546      0.433956         -8.314064
# 4          GRU_pred     21.488867     -0.240683        -12.008495
# 5     LSTM_GRU_pred    129.588890      0.225427        -10.504912
# 6       BiLSTM_pred    113.541962      0.135365        -10.786784
# 7   BiLSTM_GRU_pred     42.296061     -0.018587        -11.330808
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    141.010126      0.223926         -8.485144
# 10         BNN_pred    214.759953      0.514002         -6.649942
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     94.997663      0.076584         -9.943686
# 1             HV_dw    104.146091      0.316294         -9.095419
# 2             HV_cw    110.229214      0.122118         -7.183186
# 3         LSTM_pred     -6.139523      0.552819         -8.485144
# 4          GRU_pred    211.443490      0.518513         -7.563978
# 5     LSTM_GRU_pred    203.696503      0.491378         -7.612660
# 6       BiLSTM_pred     -9.512788      0.534782         -8.485144
# 7   BiLSTM_GRU_pred     84.345818      0.234994         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    125.398377      0.184452         -7.426990
# 10         BNN_pred    182.331475      0.394361         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    102.975270      0.107420         -9.385339
# 1             HV_dw    132.621468      0.423913         -7.775318
# 2             HV_cw     97.002498      0.104020         -8.130666
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    180.591147      0.344061         -8.528839
# 5     LSTM_GRU_pred    198.827690      0.472258         -7.643577
# 6       BiLSTM_pred    -46.374603      0.368622         -8.485144
# 7   BiLSTM_GRU_pred     48.506070      0.177284         -8.593097
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    106.896406      0.107391         -8.485144
# 10         BNN_pred    201.434381      0.444827         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     91.989563      0.348645         -9.657373
# 1             HV_dw    132.804624      0.424476         -7.827955
# 2             HV_cw     98.538846      0.079892         -8.100823
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    189.380410      0.375438         -8.528839
# 5     LSTM_GRU_pred    190.179086      0.378303         -8.528839
# 6       BiLSTM_pred    -45.424503      0.372853         -8.485144
# 7   BiLSTM_GRU_pred     84.038287      0.294951         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    109.104394      0.152624         -8.485144
# 10         BNN_pred    201.434381      0.444827         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw    -46.335167      0.368798         -8.485144
# 2             HV_cw    -28.031900      0.434109         -8.485144
# 3         LSTM_pred     -6.139523      0.552819         -8.485144
# 4          GRU_pred    -46.335167      0.368798         -8.485144
# 5     LSTM_GRU_pred    -46.335167      0.368798         -8.485144
# 6       BiLSTM_pred     -9.512788      0.534782         -8.485144
# 7   BiLSTM_GRU_pred     -6.139523      0.552819         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred     -6.057043      0.550142         -8.485144
# 10         BNN_pred    -41.012825      0.396110         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -45.424503      0.372853         -8.485144
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    -45.424503      0.372853         -8.485144
# 5     LSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 6       BiLSTM_pred    -46.374603      0.368622         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -31.299100      0.436870         -8.485144
# 10         BNN_pred    -45.424503      0.372853         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -45.424503      0.372853         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -45.424503      0.372853         -8.485144
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    -45.424503      0.372853         -8.485144
# 5     LSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 6       BiLSTM_pred    -45.424503      0.372853         -8.485144
# 7   BiLSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -30.333980      0.441121         -8.485144
# 10         BNN_pred    -45.424503      0.372853         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    115.017321      0.135857         -8.485144
# 1             HV_dw    264.559389      0.722975         -7.751573
# 2             HV_cw    145.948353      0.237898         -7.281649
# 3         LSTM_pred    120.824489      0.165286         -9.454500
# 4          GRU_pred     77.179612     -0.008049         -8.419285
# 5     LSTM_GRU_pred    154.188002      0.324337         -8.346302
# 6       BiLSTM_pred    128.421923      0.197257         -9.760987
# 7   BiLSTM_GRU_pred     86.310669      0.171768         -9.192980
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    149.308998      0.294609         -8.058377
# 10         BNN_pred    258.817320      0.705440         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    185.919332      0.453682         -7.492520
# 1             HV_dw    345.052005      1.063565         -6.354807
# 2             HV_cw    145.177313      0.241649         -7.608249
# 3         LSTM_pred     97.314353      0.063899         -9.820309
# 4          GRU_pred     68.589558     -0.046637         -9.045252
# 5     LSTM_GRU_pred    110.133674      0.146885         -6.235617
# 6       BiLSTM_pred     56.311607     -0.128870        -10.914522
# 7   BiLSTM_GRU_pred     96.204261      0.059783         -7.312273
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     58.190191     -0.140568        -10.126945
# 10         BNN_pred    147.815161      0.266672         -7.194709
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    223.539060      0.702262         -6.929753
# 1             HV_dw    275.768291      1.035583         -3.625419
# 2             HV_cw     76.944252     -0.026760         -7.834232
# 3         LSTM_pred     74.565230     -0.058919         -9.154980
# 4          GRU_pred     88.120061      0.037513         -9.006627
# 5     LSTM_GRU_pred     49.130989     -0.210396        -10.271074
# 6       BiLSTM_pred    147.929666      0.317235         -6.212361
# 7   BiLSTM_GRU_pred    122.519694      0.226130         -8.310209
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     45.874558     -0.215186         -8.067842
# 10         BNN_pred    173.741547      0.531202         -4.376693
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    210.014984      0.619922         -6.844365
# 1             HV_dw    324.380213      1.047053         -6.443794
# 2             HV_cw    169.130007      0.430583         -7.510722
# 3         LSTM_pred    151.524920      0.325463         -6.578982
# 4          GRU_pred     98.395612      0.091969         -6.634861
# 5     LSTM_GRU_pred    127.314581      0.242227         -9.020668
# 6       BiLSTM_pred    135.850894      0.242480         -7.328284
# 7   BiLSTM_GRU_pred    145.682318      0.295588         -6.104834
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     20.144449     -0.334898        -10.752927
# 10         BNN_pred    176.035722      0.467897         -5.788123
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    156.123035      0.339602         -7.492520
# 1             HV_dw    323.662915      1.003482         -6.381749
# 2             HV_cw    139.978090      0.276147         -7.580769
# 3         LSTM_pred    116.906292      0.146513         -8.546131
# 4          GRU_pred     92.474533      0.064124         -8.840304
# 5     LSTM_GRU_pred    132.186639      0.257555         -6.006330
# 6       BiLSTM_pred     65.765649     -0.094929        -10.022570
# 7   BiLSTM_GRU_pred    126.856280      0.200078         -6.991119
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     45.015211     -0.167866        -10.357994
# 10         BNN_pred    185.390267      0.434772         -6.532817
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    194.926711      0.539342         -8.485144
# 1             HV_dw    201.078314      0.541333         -8.036061
# 2             HV_cw    138.912468      0.279627         -7.394309
# 3         LSTM_pred     68.979598     -0.060737         -7.285767
# 4          GRU_pred     61.126676     -0.092673        -12.356723
# 5     LSTM_GRU_pred     74.077210     -0.029854        -12.116562
# 6       BiLSTM_pred    145.148588      0.274078         -8.504465
# 7   BiLSTM_GRU_pred     78.387061      0.000957         -8.485144
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     80.499915      0.009306         -7.897808
# 10         BNN_pred    240.595162      0.716711         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    189.840387      0.487287         -8.485144
# 1             HV_dw    270.039629      0.759668         -7.751573
# 2             HV_cw    166.231686      0.388326         -7.153774
# 3         LSTM_pred    119.167605      0.155209         -8.314064
# 4          GRU_pred     74.162247     -0.023199         -8.490204
# 5     LSTM_GRU_pred    179.017458      0.437008         -9.489780
# 6       BiLSTM_pred    171.927049      0.377705         -7.196963
# 7   BiLSTM_GRU_pred    117.397922      0.216546         -9.192980
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     85.685444      0.034711         -7.382148
# 10         BNN_pred    217.652435      0.575605         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    141.457861      0.278356         -8.485144
# 1             HV_dw    262.289331      0.723478         -7.751573
# 2             HV_cw    104.690709      0.118940         -7.183443
# 3         LSTM_pred    136.984545      0.224799         -8.326171
# 4          GRU_pred     75.232438     -0.018070         -8.399914
# 5     LSTM_GRU_pred    175.709556      0.413837         -8.193521
# 6       BiLSTM_pred    123.859046      0.171054         -9.800616
# 7   BiLSTM_GRU_pred    136.194553      0.362856         -9.192980
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     94.958013      0.076710         -8.392952
# 10         BNN_pred    246.099314      0.661672         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     23.207865      0.785982         -8.485144
# 1             HV_dw    -47.945542      0.367877         -8.485144
# 2             HV_cw    -19.251904      0.448212         -8.485144
# 3         LSTM_pred    -47.442479      0.375107         -9.028584
# 4          GRU_pred    -46.335167      0.368798         -8.485144
# 5     LSTM_GRU_pred    -46.335167      0.368798         -8.485144
# 6       BiLSTM_pred     -6.139523      0.552819         -8.485144
# 7   BiLSTM_GRU_pred     -4.401540      0.561437         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -35.925879      0.421766         -8.485144
# 10         BNN_pred     -9.274186      0.540998         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     17.854862      0.719770         -8.485144
# 1             HV_dw    -46.335167      0.368798         -8.485144
# 2             HV_cw    -23.763689      0.441340         -8.485144
# 3         LSTM_pred     -6.139523      0.552819         -8.485144
# 4          GRU_pred    -46.335167      0.368798         -8.485144
# 5     LSTM_GRU_pred    -46.335167      0.368798         -8.485144
# 6       BiLSTM_pred    -28.959156      0.447694         -8.485144
# 7   BiLSTM_GRU_pred     -6.139523      0.552819         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -31.299100      0.436870         -8.485144
# 10         BNN_pred    -22.870321      0.474321         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -26.015159      0.464294         -8.485144
# 1             HV_dw    -45.424503      0.372853         -8.485144
# 2             HV_cw    -13.831873      0.515539         -8.485144
# 3         LSTM_pred    -45.424503      0.372853         -8.485144
# 4          GRU_pred    -45.424503      0.372853         -8.485144
# 5     LSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 6       BiLSTM_pred    -46.374603      0.368622         -8.485144
# 7   BiLSTM_GRU_pred    -13.831873      0.515539         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -45.424503      0.372853         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    156.157570      0.318988         -9.192980
# 1             HV_dw    248.837647      0.684898         -7.706922
# 2             HV_cw    135.493564      0.199513         -7.933555
# 3         LSTM_pred     83.235427      0.005926         -9.726043
# 4          GRU_pred     77.179612     -0.008049         -8.419285
# 5     LSTM_GRU_pred    107.617652      0.133219        -10.704959
# 6       BiLSTM_pred     91.450499      0.039907         -9.852905
# 7   BiLSTM_GRU_pred    156.557961      0.319190         -6.498864
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    111.457014      0.146870         -8.290808
# 10         BNN_pred    130.471364      0.227398         -9.289400
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    154.036826      0.331053         -9.004819
# 1             HV_dw    202.015937      0.511179         -8.436628
# 2             HV_cw     53.937432     -0.164588         -9.093543
# 3         LSTM_pred     71.591874     -0.060063         -9.776023
# 4          GRU_pred     44.832451     -0.175656        -13.467422
# 5     LSTM_GRU_pred     86.982563      0.036173         -6.706498
# 6       BiLSTM_pred     44.027200     -0.200956         -9.804232
# 7   BiLSTM_GRU_pred     76.185148     -0.065230         -8.488708
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred    119.956859      0.139032         -6.918385
# 10         BNN_pred    123.507339      0.158906         -6.216250
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     62.384323     -0.121741         -7.844723
# 1             HV_dw    192.971208      0.630913         -3.625419
# 2             HV_cw     54.185577     -0.192047         -8.518686
# 3         LSTM_pred    103.800771      0.145096         -5.390104
# 4          GRU_pred     60.623834     -0.124834         -9.680467
# 5     LSTM_GRU_pred     12.870886     -0.549827         -9.881191
# 6       BiLSTM_pred     84.846579     -0.024368         -5.626936
# 7   BiLSTM_GRU_pred     92.765679     -0.011611         -8.339711
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     15.706411     -0.464343         -5.637134
# 10         BNN_pred     83.315098     -0.004788         -6.154841
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    150.402807      0.370366         -7.166628
# 1             HV_dw    171.450872      0.440825         -5.494340
# 2             HV_cw     79.507093     -0.010829         -8.978207
# 3         LSTM_pred    162.293926      0.394589         -6.232197
# 4          GRU_pred     68.188561     -0.079994         -9.234798
# 5     LSTM_GRU_pred     68.472093     -0.086762         -9.141621
# 6       BiLSTM_pred     97.612368      0.052577         -6.373592
# 7   BiLSTM_GRU_pred    133.621895      0.224698         -7.045061
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     79.308776     -0.018283         -6.151277
# 10         BNN_pred    124.215529      0.231275         -6.167625
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    119.793761      0.189365         -8.295517
# 1             HV_dw    147.796803      0.276588         -8.523405
# 2             HV_cw    111.410628      0.157049         -8.791899
# 3         LSTM_pred    108.635319      0.109276         -7.730123
# 4          GRU_pred     27.805710     -0.262997        -13.421971
# 5     LSTM_GRU_pred    130.029217      0.264435         -6.166271
# 6       BiLSTM_pred     68.757188     -0.092621        -10.271117
# 7   BiLSTM_GRU_pred    104.494157      0.066430         -6.213074
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     48.793471     -0.170983         -7.391110
# 10         BNN_pred    152.100872      0.300271         -5.894448
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    161.258086      0.394559         -8.485144
# 1             HV_dw    163.830113      0.431701         -7.462968
# 2             HV_cw     73.264551     -0.036786         -8.323139
# 3         LSTM_pred     67.244316     -0.070545         -7.297613
# 4          GRU_pred     61.126676     -0.092673        -12.356723
# 5     LSTM_GRU_pred     51.084464     -0.178416        -11.510287
# 6       BiLSTM_pred    117.952296      0.155188         -7.817419
# 7   BiLSTM_GRU_pred    165.677994      0.449592         -5.887829
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     64.905266     -0.075706         -8.216397
# 10         BNN_pred     99.978900      0.100388         -6.976644
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    161.195704      0.393142         -8.485144
# 1             HV_dw    176.593747      0.445040         -7.100868
# 2             HV_cw    144.315129      0.305652         -7.876011
# 3         LSTM_pred    152.737374      0.305422         -6.794612
# 4          GRU_pred     93.401823      0.067603         -9.811108
# 5     LSTM_GRU_pred    160.192358      0.385639         -9.525777
# 6       BiLSTM_pred    150.331108      0.299500         -5.861922
# 7   BiLSTM_GRU_pred    240.239178      0.709952         -6.091518
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     93.358359      0.067261         -7.711823
# 10         BNN_pred     71.579666     -0.031766         -8.563431
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    126.357626      0.207472         -8.485144
# 1             HV_dw    211.541784      0.559951         -7.764192
# 2             HV_cw    151.194531      0.327434         -7.691825
# 3         LSTM_pred    109.875307      0.113040         -8.314064
# 4          GRU_pred     75.232438     -0.018070         -8.399914
# 5     LSTM_GRU_pred    181.138272      0.462749         -9.974437
# 6       BiLSTM_pred    103.100086      0.083075         -9.845438
# 7   BiLSTM_GRU_pred    193.887390      0.487486         -6.105153
# 8         QRNN_pred     49.727822     -0.245713         -5.849527
# 9          ESN_pred     53.793890     -0.124818         -8.778069
# 10         BNN_pred    109.241216      0.139009         -8.779665
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     23.207865      0.770570         -8.485144
# 1             HV_dw    -34.036444      0.364729         -8.512022
# 2             HV_cw     -2.487341      0.538927         -8.485144
# 3         LSTM_pred    -47.442479      0.375107         -9.028584
# 4          GRU_pred    -46.335167      0.368798         -8.485144
# 5     LSTM_GRU_pred    -46.335167      0.364636         -8.485144
# 6       BiLSTM_pred     -6.139523      0.552819         -8.485144
# 7   BiLSTM_GRU_pred    -26.057561      0.469863         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -31.922992      0.439903         -8.485144
# 10         BNN_pred     -8.488488      0.545468         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV     18.820610      0.768034         -8.485144
# 1             HV_dw    -28.959156      0.447694         -8.485144
# 2             HV_cw    -23.763689      0.441340         -8.485144
# 3         LSTM_pred     -6.139523      0.552819         -8.485144
# 4          GRU_pred    -46.335167      0.368798         -8.485144
# 5     LSTM_GRU_pred    -46.335167      0.368798         -8.485144
# 6       BiLSTM_pred     -9.512788      0.534782         -8.485144
# 7   BiLSTM_GRU_pred     -6.139523      0.552819         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred     -6.057043      0.550142         -8.485144
# 10         BNN_pred    -41.012825      0.396110         -8.485144
# 11               __    -45.424503      0.372853         -8.485144
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                HV    -26.015159      0.464294         -8.485144
# 1             HV_dw    -46.335167      0.368798         -8.485144
# 2             HV_cw    -11.991835      0.508407         -8.485144
# 3         LSTM_pred    -52.950137      0.340069         -8.485144
# 4          GRU_pred    -45.424503      0.372853         -8.485144
# 5     LSTM_GRU_pred    -45.424503      0.372853         -8.485144
# 6       BiLSTM_pred    -46.335167      0.368798         -8.485144
# 7   BiLSTM_GRU_pred    -13.831873      0.515539         -8.485144
# 8         QRNN_pred    -45.424503      0.372853         -8.485144
# 9          ESN_pred    -45.424503      0.372853         -8.485144
# 10         BNN_pred    -45.424503      0.372853         -8.485144
# 11               __    -45.424503      0.372853         -8.485144

# %%
# path_1 = '/content/drive/MyDrive/Strategy/MA/HV/HV/'
# path_2 = '/content/drive/MyDrive/Strategy/MA/HV/DW_HV/'
# path_3 = '/content/drive/MyDrive/Strategy/MA/HV/CW_HV/'

# file_name = 'file_2.csv'
# file.to_csv(path_1 + file_name)

# filename = 'file_2.csv'
# dw_file.to_csv(path_2 + file_name)

# filename = 'file_2.csv'
# cw_file.to_csv(path_3 + file_name)
