# %%
import pandas as pd
import numpy as np
import yfinance as yf
from google.colab import drive
from datetime import datetime
import matplotlib.pyplot as plt
import builtins

# %% [markdown]
# # Loading data

# %%
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Volatility/'
path_1 = '/content/drive/MyDrive/Volatility/Predictions/PV/'
path_2 = '/content/drive/MyDrive/Volatility/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/Not_normal_wc_real/'

def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

filename = 'PV_data.csv'
PV_dw = pd.read_csv(path_2 + filename)

filename = 'PV_data.csv'
PV_cw = pd.read_csv(path_3 + filename)

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path_1 + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path_1 + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path_1 + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path_1 + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path_1 + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path_1 + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path_1 + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(PV_dw)
set_index(PV_cw)

start = datetime(2020, 11, 5)
end = datetime(2022, 12, 23)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")

data_s['Close'] = ticker_historical.Close.values

start = datetime(2020, 10, 1)
end = datetime(2022, 12, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")

data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['PV'] = volatility_proxies['PV'].loc['2020-10-01':'2022-12-30'].values
data_s['PV'] = volatility_proxies['PV'].loc['2020-11-05':'2022-12-22'].values

data_l['PV_dw'] = PV_dw['PV'].loc['2020-10-01':'2022-12-30'].values
data_s['PV_dw'] = PV_dw['PV'].loc['2020-11-05':'2022-12-22'].values

data_l['PV_cw'] = PV_cw['PV'].loc['2020-10-01':'2022-12-30'].values
data_s['PV_cw'] = PV_cw['PV'].loc['2020-11-05':'2022-12-22'].values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2020-11-05':'2022-12-22']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2020-11-05':'2022-12-22']

data_2022_y1 = data_s.head(268)
data_2022_y2 = data_s.tail(269)
data_2022_2y = data_s
# Out:
# Mounted at /content/drive
# <ipython-input-2-ab3c3496e876>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %%
path_1 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/'
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/PV/'
path_2 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wd/'
path_3 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
path_4 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/'

filename = 'daily_volatility_proxies.csv'
volatility_proxies = pd.read_csv(path_1 + filename)

filename = 'PV_data.csv'
PV_dw = pd.read_csv(path_2 + filename)

filename = 'PV_data.csv'
PV_cw = pd.read_csv(path_3 + filename)

filename = 'test_set_date.csv'
test_set_date = pd.read_csv(path_4 + filename)

filename = 'test_set_date_1.csv'
test_set_date_1 = pd.read_csv(path_4 + filename)

filename = 'LSTM_pred.csv'
LSTM_pred = pd.read_csv(path + filename)

filename = 'GRU_pred.csv'
GRU_pred = pd.read_csv(path + filename)

filename = 'LSTM_GRU_pred.csv'
LSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_pred.csv'
BiLSTM_pred = pd.read_csv(path + filename)

filename = 'BiLSTM_GRU_pred.csv'
BiLSTM_GRU_pred = pd.read_csv(path + filename)

filename = 'ESN_pred.csv'
ESN_pred = pd.read_csv(path + filename)

filename = 'BNN_pred.csv'
BNN_pred = pd.read_csv(path + filename)

filename = 'QRNN_pred.csv'
QRNN_pred = pd.read_csv(path + filename)

data_s = pd.DataFrame(index=test_set_date['Date'], columns=['equity', 'position'])
data_l = pd.DataFrame(index=test_set_date_1['Date'], columns=['equity', 'position'])

data_s['LSTM_pred'] = LSTM_pred['lstm_pred'].values
data_s['LSTM_GRU_pred'] = LSTM_GRU_pred['lstm_gru_pred'].values
data_s['GRU_pred'] = GRU_pred['gru_pred'].values
data_s['BiLSTM_pred'] = BiLSTM_pred['bilstm_pred'].values
data_s['BiLSTM_GRU_pred'] = BiLSTM_GRU_pred['bilstm_gru_pred'].values
data_s['QRNN_pred'] = QRNN_pred['qrnn_pred'].values
data_l['ESN_pred'] = ESN_pred['esn_pred'].values
data_l['BNN_pred'] = BNN_pred['bnn_pred'].values

set_index(volatility_proxies)
set_index(PV_dw)
set_index(PV_cw)

start = datetime(2022, 7, 14)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical = ticker.history(start=start, end=end, interval="1d")
data_s['Close'] = ticker_historical.Close.values

start = datetime(2022, 5, 31)
end = datetime(2024, 8, 31)
tckr = '^GSPC'
ticker = yf.Ticker(tckr)
ticker_historical_1 = ticker.history(start=start, end=end, interval="1d")
data_l['Close'] = ticker_historical_1.Close.values

volatility_proxies.index = pd.to_datetime(volatility_proxies.index, utc=True).tz_localize(None)

data_l['PV'] = (volatility_proxies['PV'].loc['2022-05-31':'2024-8-30']).values
data_s['PV'] = (volatility_proxies['PV'].loc['2022-07-14':'2024-8-30']).values

data_l['PV_dw'] = (PV_dw['PV'].loc['2022-05-31':'2024-8-30']).values
data_s['PV_dw'] = (PV_dw['PV'].loc['2022-07-14':'2024-8-30']).values

data_l['PV_cw'] = (PV_cw['PV'].loc['2022-05-31':'2024-8-30']).values
data_s['PV_cw'] = (PV_cw['PV'].loc['2022-07-14':'2024-8-30']).values

data_s['ESN_pred'] = data_l['ESN_pred'].loc['2022-07-14':'2024-8-30']
data_s['BNN_pred'] = data_l['BNN_pred'].loc['2022-07-14':'2024-8-30']

data_2024_y1 = data_s.head(268)
data_2024_y2 = data_s.tail(269)
data_2024_2y1 = data_s
# Out:
# <ipython-input-2-ab3c3496e876>:9: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df.index = pd.to_datetime(df['Date'])

# %% [markdown]
# # Strategy

# %% [markdown]
# ## Without volatility

# %%
def strategy(data, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0

  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# ## With volatility

# %%
def strategy_with_vol_1(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_2(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_3(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_4(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_5(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_6(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_7(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_8(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_9(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_10(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_11(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=10).mean()
  data['Vol_Std'] = volatility.rolling(window=10).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_12(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_13(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_14(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_15(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_16(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_17(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_18(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_19(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_20(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_21(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_22(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_Mean'] = volatility.rolling(window=20).mean()
  data['Vol_Std'] = volatility.rolling(window=20).std()
  data['Vol_High_Threshold'] = data['Vol_Mean'] + 2 * data['Vol_Std']
  data['Vol_Mid_Threshold'] = data['Vol_Mean'] + 1 * data['Vol_Std']
  data['Vol_Low_Threshold'] = data['Vol_Mean']

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_23(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_24(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_25(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_26(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_27(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_28(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_29(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_30(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_31(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_32(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_33(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.85)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.60)
  data['Vol_Low_Threshold'] = volatility.quantile(0.30)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_34(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_35(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none'):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_36(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_37(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_38(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_Mid_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_39(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_40(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_41(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif(volatility.iloc[i]>=data['Vol_High_Threshold'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_42(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Low_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_43(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_Mid_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %%
def strategy_with_vol_44(data, volatility, short_window, long_window, risk_free_rate=0.04, initial_capital=1000):

  # Calculate quantile-based volatility thresholds
  data['Vol_High_Threshold'] = volatility.quantile(0.75)
  data['Vol_Mid_Threshold'] = volatility.quantile(0.50)
  data['Vol_Low_Threshold'] = volatility.quantile(0.25)

  data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
  data['Long_MA'] = data['Close'].rolling(window=long_window).mean()

  data['equity'].iloc[0] = initial_capital
  account_balance = initial_capital
  # profit_loss = []
  total_shares = 0
  trades = []
  position = 'none'
  buy = 0
  sell = 0
  last_close = 0



  for i in range(1, len(data)):
    if (data['Short_MA'].iloc[i] >= data['Long_MA'].iloc[i] and position == 'none' and volatility.iloc[i]<=data['Vol_High_Threshold'].iloc[i]):
      # buy
      buy_shares = (account_balance) / data['Close'].iloc[i]
      account_balance -= buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'buy'
      total_shares += buy_shares
      position = 'buy'
      buy = 1
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    elif (data['Short_MA'].iloc[i] <= data['Long_MA'].iloc[i] and buy == 1):
      # close buy
      account_balance += buy_shares * data['Close'].iloc[i]
      data['position'].iloc[i] = 'close buy'
      total_shares -= buy_shares
      buy_shares = 0
      position = 'none'
      buy = 0
      last_close = i
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
      trades.append(('close buy', data.index[i], data['Close'].iloc[i], data['equity'].iloc[i]))

    else:
      data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

  # Calculate returns
  data['Daily Return'] = data['equity'].pct_change()
  data['Strategy Return'] = data['Daily Return'].shift(1)


  # Calculate Sharpe Ratio
  excess_returns = data['Strategy Return']
  sharpe_ratio = ((excess_returns.mean() - (risk_free_rate / 252)) / excess_returns.std()) * np.sqrt(252)

  # Calculate total profit
  total_profit = data['equity'].iloc[last_close] - initial_capital

  # profit_loss = []
  # for i in range(1, len(data)):
  #   pl = data['Daily Return'].iloc[i] * data['equity'].iloc[i-1]
  #   profit_loss.append(pl)
  # total_profit = builtins.sum(profit_loss)

  # Calculate drawdown
  data['Cumulative Max'] = data['equity'].cummax()
  data['Drawdown'] = data['equity'] - data['Cumulative Max']
  max_drawdown = data['Drawdown'].min()
  max_drawdown_percentage = (max_drawdown / data['Cumulative Max'].max()) * 100

  return total_profit, sharpe_ratio, max_drawdown_percentage, trades

# %% [markdown]
# # Backtest

# %%
def backtest_function(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, data_f[vol], short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
def backtest_function_abs(strategy, data, volatility, short_window, long_window):
  results = pd.DataFrame(columns=['Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

  for vol in volatility:
    data_f = data
    total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, abs(data_f[vol]), short_window, long_window)
    new_row = {'Volatility': vol, 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}
    results.loc[len(results)] = new_row

  return results

# %%
volatility = ['PV', 'PV_dw', 'PV_cw', 'LSTM_pred', 'GRU_pred', 'LSTM_GRU_pred', 'BiLSTM_pred',
              'BiLSTM_GRU_pred', 'QRNN_pred', 'ESN_pred', 'BNN_pred']

# %%
def backtest(data_s, short_window=5, long_window=20):
  S1_results = backtest_function(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results = backtest_function(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results = backtest_function(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results = backtest_function(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results = backtest_function(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results = backtest_function(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results = backtest_function(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results = backtest_function(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results = backtest_function(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results = backtest_function(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results = backtest_function(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results = backtest_function(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results = backtest_function(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results = backtest_function(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results = backtest_function(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results = backtest_function(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results = backtest_function(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results = backtest_function(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results = backtest_function(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results = backtest_function(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results = backtest_function(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results = backtest_function(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results = backtest_function(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results = backtest_function(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results = backtest_function(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results = backtest_function(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results = backtest_function(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results = backtest_function(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results = backtest_function(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results = backtest_function(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results = backtest_function(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results = backtest_function(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results = backtest_function(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results = backtest_function(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results = backtest_function(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results = backtest_function(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results = backtest_function(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results = backtest_function(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results = backtest_function(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results = backtest_function(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results = backtest_function(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results = backtest_function(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results = backtest_function(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results = backtest_function(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results.loc[len(S1_results)] = new_row
  S2_results.loc[len(S2_results)] = new_row
  S3_results.loc[len(S3_results)] = new_row
  S4_results.loc[len(S4_results)] = new_row
  S5_results.loc[len(S5_results)] = new_row
  S6_results.loc[len(S6_results)] = new_row
  S7_results.loc[len(S7_results)] = new_row
  S8_results.loc[len(S8_results)] = new_row
  S9_results.loc[len(S9_results)] = new_row
  S10_results.loc[len(S10_results)] = new_row
  S11_results.loc[len(S11_results)] = new_row
  S12_results.loc[len(S12_results)] = new_row
  S13_results.loc[len(S13_results)] = new_row
  S14_results.loc[len(S14_results)] = new_row
  S15_results.loc[len(S15_results)] = new_row
  S16_results.loc[len(S16_results)] = new_row
  S17_results.loc[len(S17_results)] = new_row
  S18_results.loc[len(S18_results)] = new_row
  S19_results.loc[len(S19_results)] = new_row
  S20_results.loc[len(S20_results)] = new_row
  S21_results.loc[len(S21_results)] = new_row
  S22_results.loc[len(S22_results)] = new_row

  S23_results.loc[len(S23_results)] = new_row
  S24_results.loc[len(S24_results)] = new_row
  S25_results.loc[len(S25_results)] = new_row
  S26_results.loc[len(S26_results)] = new_row
  S27_results.loc[len(S27_results)] = new_row
  S28_results.loc[len(S28_results)] = new_row
  S29_results.loc[len(S29_results)] = new_row
  S30_results.loc[len(S30_results)] = new_row
  S31_results.loc[len(S31_results)] = new_row
  S32_results.loc[len(S32_results)] = new_row
  S33_results.loc[len(S33_results)] = new_row
  S34_results.loc[len(S34_results)] = new_row
  S35_results.loc[len(S35_results)] = new_row
  S36_results.loc[len(S36_results)] = new_row
  S37_results.loc[len(S37_results)] = new_row
  S38_results.loc[len(S38_results)] = new_row
  S39_results.loc[len(S39_results)] = new_row
  S40_results.loc[len(S40_results)] = new_row
  S41_results.loc[len(S41_results)] = new_row
  S42_results.loc[len(S42_results)] = new_row
  S43_results.loc[len(S43_results)] = new_row
  S44_results.loc[len(S44_results)] = new_row

  return S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results

# %%
def backtest_abs(data_s, short_window=5, long_window=20):
  S1_results_abs = backtest_function_abs(strategy_with_vol_1, data_s, volatility, short_window, long_window)
  S2_results_abs = backtest_function_abs(strategy_with_vol_2, data_s, volatility, short_window, long_window)
  S3_results_abs = backtest_function_abs(strategy_with_vol_3, data_s, volatility, short_window, long_window)
  S4_results_abs = backtest_function_abs(strategy_with_vol_4, data_s, volatility, short_window, long_window)
  S5_results_abs = backtest_function_abs(strategy_with_vol_5, data_s, volatility, short_window, long_window)
  S6_results_abs = backtest_function_abs(strategy_with_vol_6, data_s, volatility, short_window, long_window)
  S7_results_abs = backtest_function_abs(strategy_with_vol_7, data_s, volatility, short_window, long_window)
  S8_results_abs = backtest_function_abs(strategy_with_vol_8, data_s, volatility, short_window, long_window)
  S9_results_abs = backtest_function_abs(strategy_with_vol_9, data_s, volatility, short_window, long_window)
  S10_results_abs = backtest_function_abs(strategy_with_vol_10, data_s, volatility, short_window, long_window)
  S11_results_abs = backtest_function_abs(strategy_with_vol_11, data_s, volatility, short_window, long_window)
  S12_results_abs = backtest_function_abs(strategy_with_vol_12, data_s, volatility, short_window, long_window)
  S13_results_abs = backtest_function_abs(strategy_with_vol_13, data_s, volatility, short_window, long_window)
  S14_results_abs = backtest_function_abs(strategy_with_vol_14, data_s, volatility, short_window, long_window)
  S15_results_abs = backtest_function_abs(strategy_with_vol_15, data_s, volatility, short_window, long_window)
  S16_results_abs = backtest_function_abs(strategy_with_vol_16, data_s, volatility, short_window, long_window)
  S17_results_abs = backtest_function_abs(strategy_with_vol_17, data_s, volatility, short_window, long_window)
  S18_results_abs = backtest_function_abs(strategy_with_vol_18, data_s, volatility, short_window, long_window)
  S19_results_abs = backtest_function_abs(strategy_with_vol_19, data_s, volatility, short_window, long_window)
  S20_results_abs = backtest_function_abs(strategy_with_vol_20, data_s, volatility, short_window, long_window)
  S21_results_abs = backtest_function_abs(strategy_with_vol_21, data_s, volatility, short_window, long_window)
  S22_results_abs = backtest_function_abs(strategy_with_vol_22, data_s, volatility, short_window, long_window)

  S23_results_abs = backtest_function_abs(strategy_with_vol_23, data_s, volatility, short_window, long_window)
  S24_results_abs = backtest_function_abs(strategy_with_vol_24, data_s, volatility, short_window, long_window)
  S25_results_abs = backtest_function_abs(strategy_with_vol_25, data_s, volatility, short_window, long_window)
  S26_results_abs = backtest_function_abs(strategy_with_vol_26, data_s, volatility, short_window, long_window)
  S27_results_abs = backtest_function_abs(strategy_with_vol_27, data_s, volatility, short_window, long_window)
  S28_results_abs = backtest_function_abs(strategy_with_vol_28, data_s, volatility, short_window, long_window)
  S29_results_abs = backtest_function_abs(strategy_with_vol_29, data_s, volatility, short_window, long_window)
  S30_results_abs = backtest_function_abs(strategy_with_vol_30, data_s, volatility, short_window, long_window)
  S31_results_abs = backtest_function_abs(strategy_with_vol_31, data_s, volatility, short_window, long_window)
  S32_results_abs = backtest_function_abs(strategy_with_vol_32, data_s, volatility, short_window, long_window)
  S33_results_abs = backtest_function_abs(strategy_with_vol_33, data_s, volatility, short_window, long_window)
  S34_results_abs = backtest_function_abs(strategy_with_vol_34, data_s, volatility, short_window, long_window)
  S35_results_abs = backtest_function_abs(strategy_with_vol_35, data_s, volatility, short_window, long_window)
  S36_results_abs = backtest_function_abs(strategy_with_vol_36, data_s, volatility, short_window, long_window)
  S37_results_abs = backtest_function_abs(strategy_with_vol_37, data_s, volatility, short_window, long_window)
  S38_results_abs = backtest_function_abs(strategy_with_vol_38, data_s, volatility, short_window, long_window)
  S39_results_abs = backtest_function_abs(strategy_with_vol_39, data_s, volatility, short_window, long_window)
  S40_results_abs = backtest_function_abs(strategy_with_vol_40, data_s, volatility, short_window, long_window)
  S41_results_abs = backtest_function_abs(strategy_with_vol_41, data_s, volatility, short_window, long_window)
  S42_results_abs = backtest_function_abs(strategy_with_vol_42, data_s, volatility, short_window, long_window)
  S43_results_abs = backtest_function_abs(strategy_with_vol_43, data_s, volatility, short_window, long_window)
  S44_results_abs = backtest_function_abs(strategy_with_vol_44, data_s, volatility, short_window, long_window)


  data_f = data_s
  total_profit, sharpe_ratio, max_drawdown_percentage, trades = strategy(data_f, short_window, long_window)


  new_row = {'Volatility': '__', 'Total profit': total_profit, 'Sharpe ratio': sharpe_ratio, 'Max drawdown (%)': max_drawdown_percentage}

  S1_results_abs.loc[len(S1_results_abs)] = new_row
  S2_results_abs.loc[len(S2_results_abs)] = new_row
  S3_results_abs.loc[len(S3_results_abs)] = new_row
  S4_results_abs.loc[len(S4_results_abs)] = new_row
  S5_results_abs.loc[len(S5_results_abs)] = new_row
  S6_results_abs.loc[len(S6_results_abs)] = new_row
  S7_results_abs.loc[len(S7_results_abs)] = new_row
  S8_results_abs.loc[len(S8_results_abs)] = new_row
  S9_results_abs.loc[len(S9_results_abs)] = new_row
  S10_results_abs.loc[len(S10_results_abs)] = new_row
  S11_results_abs.loc[len(S11_results_abs)] = new_row
  S12_results_abs.loc[len(S12_results_abs)] = new_row
  S13_results_abs.loc[len(S13_results_abs)] = new_row
  S14_results_abs.loc[len(S14_results_abs)] = new_row
  S15_results_abs.loc[len(S15_results_abs)] = new_row
  S16_results_abs.loc[len(S16_results_abs)] = new_row
  S17_results_abs.loc[len(S17_results_abs)] = new_row
  S18_results_abs.loc[len(S18_results_abs)] = new_row
  S19_results_abs.loc[len(S19_results_abs)] = new_row
  S20_results_abs.loc[len(S20_results_abs)] = new_row
  S21_results_abs.loc[len(S21_results_abs)] = new_row
  S22_results_abs.loc[len(S22_results_abs)] = new_row

  S23_results_abs.loc[len(S23_results_abs)] = new_row
  S24_results_abs.loc[len(S24_results_abs)] = new_row
  S25_results_abs.loc[len(S25_results_abs)] = new_row
  S26_results_abs.loc[len(S26_results_abs)] = new_row
  S27_results_abs.loc[len(S27_results_abs)] = new_row
  S28_results_abs.loc[len(S28_results_abs)] = new_row
  S29_results_abs.loc[len(S29_results_abs)] = new_row
  S30_results_abs.loc[len(S30_results_abs)] = new_row
  S31_results_abs.loc[len(S31_results_abs)] = new_row
  S32_results_abs.loc[len(S32_results_abs)] = new_row
  S33_results_abs.loc[len(S33_results_abs)] = new_row
  S34_results_abs.loc[len(S34_results_abs)] = new_row
  S35_results_abs.loc[len(S35_results_abs)] = new_row
  S36_results_abs.loc[len(S36_results_abs)] = new_row
  S37_results_abs.loc[len(S37_results_abs)] = new_row
  S38_results_abs.loc[len(S38_results_abs)] = new_row
  S39_results_abs.loc[len(S39_results_abs)] = new_row
  S40_results_abs.loc[len(S40_results_abs)] = new_row
  S41_results_abs.loc[len(S41_results_abs)] = new_row
  S42_results_abs.loc[len(S42_results_abs)] = new_row
  S43_results_abs.loc[len(S43_results_abs)] = new_row
  S44_results_abs.loc[len(S44_results_abs)] = new_row

  return S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs

# %% [markdown]
# # Final Results

# %%
def check_strategy(data, PV):

    sharpe_ratio_PV = data.loc[data['Volatility'] == PV, 'Sharpe ratio'].values[0]
    sharpe_ratio_pure = data.loc[data['Volatility'] == '__', 'Sharpe ratio'].values[0]

    max_drawdown_PV = data.loc[data['Volatility'] == PV, 'Max drawdown (%)'].values[0]
    max_drawdown_pure = data.loc[data['Volatility'] == '__', 'Max drawdown (%)'].values[0]

    total_profit_PV = data.loc[data['Volatility'] == PV, 'Total profit'].values[0]
    total_profit_pure = data.loc[data['Volatility'] == '__', 'Total profit'].values[0]

    is_PV_sharpe_positive = sharpe_ratio_PV > 0
    is_PV_sharpe_greater_than_pure_sharpe = sharpe_ratio_PV > sharpe_ratio_pure
    is_PV_dd_greater_than_pure_dd = max_drawdown_PV > max_drawdown_pure
    is_pure_tp_greater_than_PV_tp = total_profit_pure > total_profit_PV

    all_sharpes_greater_than_Pure_sharpe = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'PV') & (data['Volatility'] != 'PV_dw') & (data['Volatility'] != 'PV_cw'), 'Sharpe ratio'] > sharpe_ratio_pure)
    all_sharpes_greater_than_Pure_sharpe_percentage = (all_sharpes_greater_than_Pure_sharpe.sum()/8) * 100

    positive_sharpes = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'PV') & (data['Volatility'] != 'PV_dw') & (data['Volatility'] != 'PV_cw'), 'Sharpe ratio'] > 0)
    positive_sharpes_percentage = (positive_sharpes.sum()/8) * 100

    PV_sharpe_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'PV') & (data['Volatility'] != 'PV_dw') & (data['Volatility'] != 'PV_cw'), 'Sharpe ratio'] < sharpe_ratio_PV)
    PV_sharpe_greater_than_all_percentage = (PV_sharpe_greater_than_all.sum()/8) * 100

    PV_dd_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'PV') & (data['Volatility'] != 'PV_dw') & (data['Volatility'] != 'PV_cw'), 'Max drawdown (%)'] < max_drawdown_PV)
    PV_dd_greater_than_all_percentage = (PV_dd_greater_than_all.sum()/8) * 100

    PV_tp_greater_than_all = (data.loc[(data['Volatility'] != '__') & (data['Volatility'] != 'PV') & (data['Volatility'] != 'PV_dw') & (data['Volatility'] != 'PV_cw'), 'Total profit'] < total_profit_PV)
    PV_tp_greater_than_all_percentage = (PV_tp_greater_than_all.sum()/8) * 100

    return is_PV_sharpe_positive, is_PV_sharpe_greater_than_pure_sharpe, is_PV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, PV_sharpe_greater_than_all_percentage, PV_dd_greater_than_all_percentage, PV_tp_greater_than_all_percentage

# %%
def get_final_results(year, final_results, PV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results[f'S{i}_results']

    if(PV == 'PV'):
      strategy_result[~strategy_result['Volatility'].isin(['PV_dw', 'PV_cw'])]

    elif(PV == 'PV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['PV', 'PV_cw'])]

    elif(PV == 'PV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['PV_dw', 'PV'])]

    is_PV_sharpe_positive, is_PV_sharpe_greater_than_pure_sharpe, is_PV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, PV_sharpe_greater_than_all_percentage, PV_dd_greater_than_all_percentage, PV_tp_greater_than_all_percentage = check_strategy(strategy_result, PV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '-',
                'PV_sharpe > 0': is_PV_sharpe_positive,
                'PV_sharpe > Pure_sharpe': is_PV_sharpe_greater_than_pure_sharpe,
                'PV_dd > Pure_dd': is_PV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'PV_sharpe > Pred_sharpe (%)': PV_sharpe_greater_than_all_percentage,
                'PV_dd > Pred_dd (%)': PV_dd_greater_than_all_percentage,
                'PV_tp > Pred_tp (%)': PV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
def get_final_results_1(year, final_results, PV):
  for i in range(1, len(strategy_results)+1):
    strategy_result = strategy_results_abs[f'S{i}_results_abs']

    if(PV == 'PV'):
      strategy_result[~strategy_result['Volatility'].isin(['PV_dw', 'PV_cw'])]
      # res_combined
      # res_combined = pd.concat(details, strategy_result.drop())

    elif(PV == 'PV_dw'):
      strategy_result[~strategy_result['Volatility'].isin(['PV', 'PV_cw'])]

    elif(PV == 'PV_cw'):
      strategy_result[~strategy_result['Volatility'].isin(['PV_dw', 'PV'])]

    is_PV_sharpe_positive, is_PV_sharpe_greater_than_pure_sharpe, is_PV_dd_greater_than_pure_dd, all_sharpes_greater_than_Pure_sharpe_percentage, positive_sharpes_percentage, PV_sharpe_greater_than_all_percentage, PV_dd_greater_than_all_percentage, PV_tp_greater_than_all_percentage = check_strategy(strategy_result, PV)

    new_row = {'Year': year, 'Strategy': f'Strategy_{i}', 'Abs': '+',
                'PV_sharpe > 0': is_PV_sharpe_positive,
                'PV_sharpe > Pure_sharpe': is_PV_sharpe_greater_than_pure_sharpe,
                'PV_dd > Pure_dd': is_PV_dd_greater_than_pure_dd,
                'Pred_sharpes > 0 (%)': positive_sharpes_percentage,
                'PV_sharpe > Pred_sharpe (%)': PV_sharpe_greater_than_all_percentage,
                'PV_dd > Pred_dd (%)': PV_dd_greater_than_all_percentage,
                'PV_tp > Pred_tp (%)': PV_tp_greater_than_all_percentage,
                'Pred_sharpe > Pure_sharpe (%)': all_sharpes_greater_than_Pure_sharpe_percentage}

    final_results.loc[len(final_results)] = new_row

# %%
file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'PV_sharpe > 0', 'PV_sharpe > Pure_sharpe',
                                              'PV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'PV_sharpe > Pred_sharpe (%)',
                                              'PV_dd > Pred_dd (%)', 'PV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

dw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'PV_sharpe > 0', 'PV_sharpe > Pure_sharpe',
                                              'PV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'PV_sharpe > Pred_sharpe (%)',
                                              'PV_dd > Pred_dd (%)', 'PV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

cw_file = pd.DataFrame(columns=['Year', 'Strategy', 'Abs',
                                              'PV_sharpe > 0', 'PV_sharpe > Pure_sharpe',
                                              'PV_dd > Pure_dd', 'Pred_sharpes > 0 (%)',
                                              'PV_sharpe > Pred_sharpe (%)',
                                              'PV_dd > Pred_dd (%)', 'PV_tp > Pred_tp (%)',
                                              'Pred_sharpe > Pure_sharpe (%)'])

# %%
# details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# dw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# cw_details = pd.DataFrame(columns=['Year', 'Strategy', 'Abs', 'Volatility', 'Total profit', 'Sharpe ratio', 'Max drawdown (%)'])

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y1', file, 'PV')
get_final_results_1('2022_y1', file, 'PV')

get_final_results('2022_y1', dw_file, 'PV_dw')
get_final_results_1('2022_y1', dw_file, 'PV_dw')

get_final_results('2022_y1', cw_file, 'PV_cw')
get_final_results_1('2022_y1', cw_file, 'PV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:38: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-48-dbce691e5d20>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-48-dbce691e5d20>:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:51: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-48-dbce691e5d20>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-48-dbce691e5d20>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']
# <ipython-input-4-b267510ae310>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
# <ipython-input-4-b267510ae310>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Long_MA'] = data['Close'].rolling(window=long_window).mean()
# <ipython-input-4-b267510ae310>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-4-b267510ae310>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:31: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:37: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-4-b267510ae310>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-4-b267510ae310>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     67.369392      0.279613         -7.962712
# 1             PV_dw    113.601883      0.570892         -6.413932
# 2             PV_cw    120.108269      0.631974         -6.348421
# 3         LSTM_pred    114.608431      0.577650         -6.368100
# 4          GRU_pred    115.817024      0.590481         -6.542573
# 5     LSTM_GRU_pred    127.174816      0.691981         -6.493630
# 6       BiLSTM_pred    122.946472      0.652730         -6.315137
# 7   BiLSTM_GRU_pred    121.044993      0.636179         -6.474783
# 8         QRNN_pred    132.642753      0.751775         -4.592928
# 9          ESN_pred    113.675438      0.570802         -7.242561
# 10         BNN_pred    116.651270      0.595515         -6.775106
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    111.111787      0.738735         -7.006324
# 1             PV_dw     98.621369      0.452254         -6.033875
# 2             PV_cw    135.433880      0.868865         -4.615342
# 3         LSTM_pred    115.194824      0.605607         -6.645710
# 4          GRU_pred    112.423479      0.569526         -5.771678
# 5     LSTM_GRU_pred    132.004923      0.748621         -5.742481
# 6       BiLSTM_pred     92.145904      0.384767         -6.203801
# 7   BiLSTM_GRU_pred    110.605058      0.571721         -4.895499
# 8         QRNN_pred    144.103626      0.888511         -4.461494
# 9          ESN_pred     49.230478     -0.032661         -7.663735
# 10         BNN_pred     54.462365      0.158426         -6.662717
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    179.671971      1.698212         -2.593268
# 1             PV_dw     71.224342      0.205377         -5.317387
# 2             PV_cw     63.374665      0.117406         -5.717248
# 3         LSTM_pred     94.839965      0.426122         -6.980157
# 4          GRU_pred     19.803305     -0.349990         -8.173571
# 5     LSTM_GRU_pred     34.352358     -0.191433         -7.985870
# 6       BiLSTM_pred     66.536141      0.145118         -5.615289
# 7   BiLSTM_GRU_pred     82.994302      0.312814         -5.062156
# 8         QRNN_pred     78.526555      0.267871         -5.426028
# 9          ESN_pred    -43.213875     -1.144053         -9.770026
# 10         BNN_pred     50.903589      0.123580         -7.341299
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    176.569517      1.595193         -3.094874
# 1             PV_dw     87.107292      0.353697         -6.031209
# 2             PV_cw     92.512576      0.453076         -4.857484
# 3         LSTM_pred    102.935960      0.500119         -6.928920
# 4          GRU_pred     77.740436      0.247965         -6.911773
# 5     LSTM_GRU_pred     78.398647      0.255987         -6.945088
# 6       BiLSTM_pred     61.204330      0.087874         -6.897372
# 7   BiLSTM_GRU_pred     95.964673      0.443951         -5.002247
# 8         QRNN_pred    103.507524      0.510896         -4.547949
# 9          ESN_pred     -5.594560     -0.651270         -7.156694
# 10         BNN_pred     61.408144      0.228521         -6.602688
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     94.155962      0.581770         -5.438987
# 1             PV_dw     98.633507      0.452646         -6.033809
# 2             PV_cw    158.755730      1.101357         -3.963536
# 3         LSTM_pred    112.799799      0.583200         -6.682342
# 4          GRU_pred     99.038450      0.447331         -6.541575
# 5     LSTM_GRU_pred    122.511099      0.665365         -6.496489
# 6       BiLSTM_pred     92.145904      0.384767         -6.203801
# 7   BiLSTM_GRU_pred    111.250831      0.578406         -5.058008
# 8         QRNN_pred    144.103626      0.888511         -4.461494
# 9          ESN_pred     75.676848      0.235255         -5.732253
# 10         BNN_pred     54.462365      0.158426         -6.662717
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    117.820851      0.869589         -4.465830
# 1             PV_dw     78.899815      0.262209         -6.384072
# 2             PV_cw     66.411229      0.142048         -5.758329
# 3         LSTM_pred    106.524233      0.507087         -6.437227
# 4          GRU_pred     31.106148     -0.209482         -8.704435
# 5     LSTM_GRU_pred     30.080305     -0.222983         -8.723089
# 6       BiLSTM_pred    102.532923      0.471594         -7.653886
# 7   BiLSTM_GRU_pred     98.941185      0.438999         -6.628287
# 8         QRNN_pred     84.001799      0.309647         -5.706446
# 9          ESN_pred     34.231200     -0.199628         -6.116038
# 10         BNN_pred    100.935391      0.455472         -7.515484
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    107.688695      0.724534         -4.408052
# 1             PV_dw     97.371931      0.425772         -6.508793
# 2             PV_cw     63.357425      0.109736         -6.623618
# 3         LSTM_pred    109.160195      0.530838         -6.421928
# 4          GRU_pred     78.173639      0.248927         -7.593307
# 5     LSTM_GRU_pred     81.799813      0.284262         -7.604865
# 6       BiLSTM_pred    117.457468      0.604898         -6.769011
# 7   BiLSTM_GRU_pred    112.957618      0.565665         -6.544812
# 8         QRNN_pred     93.865880      0.399975         -5.858019
# 9          ESN_pred     64.867265      0.125168         -5.678455
# 10         BNN_pred    110.374024      0.539630         -6.813407
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     88.387766      0.485555         -6.117887
# 1             PV_dw    105.463229      0.498737         -6.461153
# 2             PV_cw    110.837593      0.548974         -6.401403
# 3         LSTM_pred    118.535742      0.613134         -6.368100
# 4          GRU_pred    100.410655      0.452951         -7.203624
# 5     LSTM_GRU_pred    118.031236      0.613451         -7.136560
# 6       BiLSTM_pred    122.946472      0.652730         -6.315137
# 7   BiLSTM_GRU_pred    124.994984      0.671789         -6.474783
# 8         QRNN_pred    132.642753      0.751775         -4.592928
# 9          ESN_pred    129.990840      0.729881         -5.454073
# 10         BNN_pred    116.651270      0.595515         -6.775106
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    120.840739      0.651873         -5.139034
# 1             PV_dw     96.017382      0.422997         -6.235096
# 2             PV_cw     90.069367      0.364104         -5.284103
# 3         LSTM_pred    103.173595      0.475133         -6.445875
# 4          GRU_pred     84.222723      0.304459         -7.848529
# 5     LSTM_GRU_pred     71.584401      0.186335         -7.919023
# 6       BiLSTM_pred     99.565901      0.443179         -7.695488
# 7   BiLSTM_GRU_pred    103.173595      0.475133         -6.445875
# 8         QRNN_pred     73.991268      0.209833         -7.519218
# 9          ESN_pred     97.443908      0.423752         -6.479529
# 10         BNN_pred    104.162567      0.484051         -7.084907
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    119.924515      0.623770         -6.349463
# 1             PV_dw    119.924515      0.623770         -6.349463
# 2             PV_cw    105.551496      0.503013         -6.370823
# 3         LSTM_pred    105.801575      0.498792         -6.430556
# 4          GRU_pred    102.477207      0.469561         -6.879715
# 5     LSTM_GRU_pred     92.820743      0.382705         -6.879715
# 6       BiLSTM_pred    114.450282      0.576060         -6.805803
# 7   BiLSTM_GRU_pred    107.941403      0.518068         -6.418136
# 8         QRNN_pred     83.764257      0.299329         -7.652379
# 9          ESN_pred    106.067925      0.500703         -6.429008
# 10         BNN_pred    113.628868      0.567995         -6.385358
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    119.924515      0.623770         -6.349463
# 1             PV_dw    119.924515      0.623770         -6.349463
# 2             PV_cw    119.924515      0.623770         -6.349463
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    104.461433      0.487279         -7.004445
# 5     LSTM_GRU_pred    104.461433      0.487279         -7.004445
# 6       BiLSTM_pred    119.924515      0.623770         -6.349463
# 7   BiLSTM_GRU_pred    119.924515      0.623770         -6.349463
# 8         QRNN_pred    119.924515      0.623770         -6.349463
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     94.229592      0.400683         -6.445737
# 1             PV_dw    100.564407      0.453923         -6.367277
# 2             PV_cw    126.622016      0.698962         -5.112663
# 3         LSTM_pred    138.632032      0.802030         -6.233742
# 4          GRU_pred    107.816803      0.518380         -6.544941
# 5     LSTM_GRU_pred    105.834930      0.502939         -6.403214
# 6       BiLSTM_pred    116.875769      0.597712         -6.349463
# 7   BiLSTM_GRU_pred    103.273745      0.484321         -6.583387
# 8         QRNN_pred    143.250829      0.844375         -4.453932
# 9          ESN_pred    150.955163      0.924369         -4.555384
# 10         BNN_pred    100.091964      0.450961         -6.892441
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    106.259089      0.527189         -5.547716
# 1             PV_dw     72.014518      0.195404         -6.092395
# 2             PV_cw    159.016905      1.076449         -5.278466
# 3         LSTM_pred     85.409245      0.325068         -6.558180
# 4          GRU_pred     94.427211      0.406254         -5.988323
# 5     LSTM_GRU_pred    118.706118      0.626820         -5.612554
# 6       BiLSTM_pred    105.851771      0.509196         -5.913702
# 7   BiLSTM_GRU_pred    135.826826      0.840111         -3.673249
# 8         QRNN_pred     99.804460      0.447959         -6.928455
# 9          ESN_pred     70.608001      0.181758         -4.734426
# 10         BNN_pred     55.480323      0.168488         -6.055673
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     70.661000      0.201854         -5.222896
# 1             PV_dw     40.196579     -0.164184         -4.512677
# 2             PV_cw     27.639227     -0.324996         -7.145460
# 3         LSTM_pred     99.208061      0.475377         -6.489577
# 4          GRU_pred     36.995507     -0.175968         -7.654766
# 5     LSTM_GRU_pred    -33.537026     -0.972143         -7.547125
# 6       BiLSTM_pred     51.845394     -0.012313         -5.694489
# 7   BiLSTM_GRU_pred    128.238640      0.795331         -4.092862
# 8         QRNN_pred     77.886035      0.256681         -5.965352
# 9          ESN_pred    -39.848165     -1.129946         -8.062996
# 10         BNN_pred     78.852381      0.404784         -6.025699
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    112.673093      0.624797         -4.452532
# 1             PV_dw     47.751326     -0.050737         -6.154513
# 2             PV_cw    104.727967      0.561865         -6.548255
# 3         LSTM_pred    105.496335      0.537828         -6.452664
# 4          GRU_pred     58.161938      0.057083         -7.237905
# 5     LSTM_GRU_pred     50.920401     -0.014630         -6.427082
# 6       BiLSTM_pred     82.930448      0.297702         -7.206526
# 7   BiLSTM_GRU_pred    134.692990      0.860558         -4.069581
# 8         QRNN_pred     78.630092      0.258492         -6.752860
# 9          ESN_pred     40.029897     -0.133868         -5.637842
# 10         BNN_pred     87.747691      0.491224         -5.976423
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     93.423821      0.405497         -5.582182
# 1             PV_dw     73.602152      0.211321         -6.106305
# 2             PV_cw    152.407670      1.029645         -4.910091
# 3         LSTM_pred    113.282800      0.601267         -6.416510
# 4          GRU_pred     57.472504      0.051054         -7.324306
# 5     LSTM_GRU_pred     98.987218      0.448446         -6.441217
# 6       BiLSTM_pred    105.851771      0.509196         -5.913702
# 7   BiLSTM_GRU_pred    129.687789      0.787047         -4.037479
# 8         QRNN_pred    107.105601      0.524832         -6.304575
# 9          ESN_pred     89.064037      0.364873         -4.734426
# 10         BNN_pred     55.480323      0.168488         -6.055673
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     50.443449     -0.036271         -5.366122
# 1             PV_dw    104.638743      0.523819         -6.419846
# 2             PV_cw     53.435716      0.005586         -6.529999
# 3         LSTM_pred    110.887350      0.559437         -6.411944
# 4          GRU_pred     49.163018     -0.036175         -8.199659
# 5     LSTM_GRU_pred    -29.142214     -0.881265         -8.245137
# 6       BiLSTM_pred     87.500742      0.334822         -7.759683
# 7   BiLSTM_GRU_pred     91.068942      0.373489         -6.680485
# 8         QRNN_pred     99.590379      0.468863         -4.981128
# 9          ESN_pred     51.364999     -0.013062         -5.043344
# 10         BNN_pred     92.634543      0.382573         -6.939483
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     81.030146      0.285429         -5.261745
# 1             PV_dw     75.958648      0.229216         -6.548446
# 2             PV_cw    102.044157      0.489730         -5.230110
# 3         LSTM_pred    117.242438      0.617860         -6.375472
# 4          GRU_pred     80.620665      0.275062         -7.569187
# 5     LSTM_GRU_pred     44.733758     -0.073686         -7.050983
# 6       BiLSTM_pred    103.253085      0.477212         -7.496596
# 7   BiLSTM_GRU_pred     97.310654      0.431934         -6.642486
# 8         QRNN_pred    100.349418      0.464009         -5.761264
# 9          ESN_pred    112.824348      0.586014         -4.555384
# 10         BNN_pred    100.091964      0.450961         -6.892441
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     79.357188      0.261889         -6.498862
# 1             PV_dw     97.120686      0.424587         -6.433520
# 2             PV_cw    117.196473      0.622192         -5.694464
# 3         LSTM_pred    125.577301      0.692735         -6.328261
# 4          GRU_pred     70.146765      0.173033         -7.721588
# 5     LSTM_GRU_pred     85.255895      0.315896         -7.126142
# 6       BiLSTM_pred    116.875769      0.597712         -6.349463
# 7   BiLSTM_GRU_pred     97.310654      0.431934         -6.642486
# 8         QRNN_pred    135.245521      0.774799         -5.095676
# 9          ESN_pred    135.549118      0.788607         -4.555384
# 10         BNN_pred    100.091964      0.450961         -6.892441
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     67.584142      0.151517         -6.337777
# 1             PV_dw     78.491473      0.253197         -6.517514
# 2             PV_cw     58.442483      0.060106         -6.494855
# 3         LSTM_pred    105.308338      0.494413         -6.433426
# 4          GRU_pred     84.222723      0.304459         -7.848529
# 5     LSTM_GRU_pred     79.513428      0.260345         -7.212718
# 6       BiLSTM_pred     90.469303      0.361723         -7.759683
# 7   BiLSTM_GRU_pred    105.308338      0.494413         -6.433426
# 8         QRNN_pred     78.355667      0.255905         -6.844366
# 9          ESN_pred     50.943927     -0.010444         -6.701287
# 10         BNN_pred    112.332651      0.556415         -6.392799
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    122.718445      0.669093         -5.130439
# 1             PV_dw    111.631510      0.551035         -6.396831
# 2             PV_cw    115.388973      0.597059         -5.164152
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    101.193970      0.457927         -6.887732
# 5     LSTM_GRU_pred     92.820743      0.382705         -6.879715
# 6       BiLSTM_pred    106.264645      0.503638         -7.496596
# 7   BiLSTM_GRU_pred    111.631510      0.551035         -6.396831
# 8         QRNN_pred     79.100048      0.257934         -7.623217
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    119.924515      0.623770         -6.349463
# 1             PV_dw    119.924515      0.623770         -6.349463
# 2             PV_cw    124.832798      0.676032         -5.655805
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    104.461433      0.487279         -7.004445
# 5     LSTM_GRU_pred    104.461433      0.487279         -7.004445
# 6       BiLSTM_pred    119.924515      0.623770         -6.349463
# 7   BiLSTM_GRU_pred    111.631510      0.551035         -6.396831
# 8         QRNN_pred    113.322255      0.566232         -6.900395
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    113.890291      0.589792         -4.749967
# 1             PV_dw     52.889542      0.004873         -6.642547
# 2             PV_cw     91.892335      0.521726         -5.182353
# 3         LSTM_pred    138.991326      0.829926         -5.481430
# 4          GRU_pred    123.342149      0.662671         -5.997310
# 5     LSTM_GRU_pred    101.352758      0.472449         -6.402115
# 6       BiLSTM_pred    110.601002      0.551309         -5.912923
# 7   BiLSTM_GRU_pred     78.008711      0.249935         -6.629445
# 8         QRNN_pred    129.312005      0.728815         -5.151325
# 9          ESN_pred     92.934508      0.400930         -4.657176
# 10         BNN_pred     24.858286     -0.138734         -8.326630
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    136.303415      0.871509         -4.488234
# 1             PV_dw     -3.605210     -0.468975         -7.570641
# 2             PV_cw     92.357973      0.546863         -5.209195
# 3         LSTM_pred    137.926256      1.143406         -4.292778
# 4          GRU_pred    157.079740      1.209832         -3.501316
# 5     LSTM_GRU_pred     62.617367      0.102824         -3.886593
# 6       BiLSTM_pred    177.251569      1.338186         -3.689639
# 7   BiLSTM_GRU_pred    208.021962      1.760020         -3.129609
# 8         QRNN_pred     87.759199      0.353487         -4.744990
# 9          ESN_pred    -31.010237     -0.922959        -10.491033
# 10         BNN_pred    107.024223      0.775605         -4.592659
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     -5.064642     -0.915737         -5.776942
# 1             PV_dw     28.123997     -0.219678         -2.543324
# 2             PV_cw     37.201461     -0.036308         -6.248930
# 3         LSTM_pred     90.999882      0.689825         -3.068062
# 4          GRU_pred     73.522839      0.305207         -4.052100
# 5     LSTM_GRU_pred    -11.347119     -1.061949         -4.544492
# 6       BiLSTM_pred     64.964934      0.150336         -3.927064
# 7   BiLSTM_GRU_pred     92.076164      0.774469         -3.276557
# 8         QRNN_pred    -21.719226     -0.986079         -8.779875
# 9          ESN_pred    -39.087594     -1.423959         -8.546114
# 10         BNN_pred     58.432788      0.256625         -4.203924
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     65.702911      0.146163         -4.576202
# 1             PV_dw    -45.065603     -1.144239         -8.173961
# 2             PV_cw    107.082520      0.762779         -5.590035
# 3         LSTM_pred    120.248829      1.061688         -2.940035
# 4          GRU_pred    108.286322      0.680744         -3.229583
# 5     LSTM_GRU_pred     13.501485     -0.498591         -6.398683
# 6       BiLSTM_pred    148.947088      1.186565         -3.894393
# 7   BiLSTM_GRU_pred    148.388562      1.502249         -2.766850
# 8         QRNN_pred     38.720717     -0.164402         -5.845086
# 9          ESN_pred    -71.364482     -1.612217        -11.820391
# 10         BNN_pred    120.849095      1.002564         -3.839161
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    107.316930      0.587459         -4.488234
# 1             PV_dw    -30.737947     -0.811817         -8.231546
# 2             PV_cw    135.828013      1.020161         -5.153638
# 3         LSTM_pred    128.149191      1.127493         -3.435088
# 4          GRU_pred    149.000211      1.189552         -2.933796
# 5     LSTM_GRU_pred     42.566444     -0.119743         -5.986773
# 6       BiLSTM_pred    141.607900      0.968911         -3.760497
# 7   BiLSTM_GRU_pred    205.836275      1.855181         -2.301587
# 8         QRNN_pred     95.207586      0.428096         -4.853814
# 9          ESN_pred      6.759034     -0.531837         -6.512171
# 10         BNN_pred    103.439411      0.777242         -4.585253
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     -5.064642     -0.915737         -5.776942
# 1             PV_dw     68.088012      0.173155         -5.369690
# 2             PV_cw     65.027252      0.295543         -6.169247
# 3         LSTM_pred     73.283441      0.211511         -6.451448
# 4          GRU_pred     -1.296258     -0.677831         -5.846655
# 5     LSTM_GRU_pred     33.156584     -0.295937         -5.256639
# 6       BiLSTM_pred     26.685540     -0.326282         -5.249823
# 7   BiLSTM_GRU_pred     42.167618      0.025721         -6.674233
# 8         QRNN_pred    -21.719226     -0.986079         -8.779875
# 9          ESN_pred    -33.626623     -1.263256         -6.890553
# 10         BNN_pred     35.873426     -0.044075         -6.899567
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     62.094164      0.097666         -4.630814
# 1             PV_dw      9.687746     -0.481779         -9.188164
# 2             PV_cw    114.227159      0.807048         -5.505743
# 3         LSTM_pred     98.843375      0.464935         -5.837463
# 4          GRU_pred     67.203331      0.149153         -7.701440
# 5     LSTM_GRU_pred     -9.122913     -0.697064         -8.144854
# 6       BiLSTM_pred     71.087704      0.192036         -5.726235
# 7   BiLSTM_GRU_pred     91.306913      0.386748         -5.354779
# 8         QRNN_pred     38.720717     -0.164402         -5.845086
# 9          ESN_pred     14.446036     -0.422482         -5.671501
# 10         BNN_pred     55.768212      0.173071         -8.263310
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     88.136216      0.352662         -5.829902
# 1             PV_dw     25.162876     -0.285845         -6.831132
# 2             PV_cw    135.343845      0.968960         -5.127082
# 3         LSTM_pred     98.843375      0.464935         -5.837463
# 4          GRU_pred     97.146094      0.426811         -7.191243
# 5     LSTM_GRU_pred     66.679663      0.143025         -7.505999
# 6       BiLSTM_pred     73.798400      0.209495         -6.596038
# 7   BiLSTM_GRU_pred     98.789617      0.458826         -4.975257
# 8         QRNN_pred    110.715095      0.563352         -5.539789
# 9          ESN_pred     63.757816      0.113907         -4.890895
# 10         BNN_pred     57.591049      0.190994         -8.189756
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     -5.064642     -0.915737         -5.776942
# 1             PV_dw     69.010963      0.163856         -7.844592
# 2             PV_cw     55.446089      0.024401         -6.160054
# 3         LSTM_pred     94.849948      0.400421         -7.162893
# 4          GRU_pred     91.105162      0.372610         -6.380922
# 5     LSTM_GRU_pred      8.719278     -0.481072        -10.495720
# 6       BiLSTM_pred    103.914110      0.496877         -6.367996
# 7   BiLSTM_GRU_pred     30.741319     -0.259683         -7.117551
# 8         QRNN_pred    -21.719226     -0.986079         -8.779875
# 9          ESN_pred     10.132987     -0.470428         -6.740659
# 10         BNN_pred     85.513397      0.315572         -7.576328
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     62.094164      0.097666         -4.630814
# 1             PV_dw     80.096208      0.265431         -7.112665
# 2             PV_cw     97.546003      0.454711         -5.530885
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred     81.684047      0.280521         -7.866949
# 5     LSTM_GRU_pred     80.122079      0.265929         -7.863076
# 6       BiLSTM_pred     98.341507      0.432001         -7.800970
# 7   BiLSTM_GRU_pred    118.058525      0.616203         -5.690074
# 8         QRNN_pred     38.720717     -0.164402         -5.845086
# 9          ESN_pred    117.262971      0.600203         -6.364589
# 10         BNN_pred    112.332651      0.556415         -6.392799
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     82.967336      0.302035         -6.286267
# 1             PV_dw    111.631510      0.551035         -6.396831
# 2             PV_cw    119.924515      0.623770         -6.349463
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    112.700948      0.560311         -6.952577
# 5     LSTM_GRU_pred    112.700948      0.560311         -6.952577
# 6       BiLSTM_pred    113.153109      0.564462         -6.813734
# 7   BiLSTM_GRU_pred    111.631510      0.551035         -6.396831
# 8         QRNN_pred    110.715095      0.563352         -5.539789
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     89.345167      0.362457         -6.641989
# 1             PV_dw     46.719727     -0.065023         -5.427751
# 2             PV_cw    124.552595      0.717947         -5.198725
# 3         LSTM_pred    124.704933      0.897825         -4.993024
# 4          GRU_pred     93.724897      0.406926         -5.260730
# 5     LSTM_GRU_pred     65.537031      0.131137         -5.854234
# 6       BiLSTM_pred    105.436333      0.510576         -5.957738
# 7   BiLSTM_GRU_pred    111.392244      0.764020         -4.323280
# 8         QRNN_pred     95.701399      0.424153         -5.443051
# 9          ESN_pred     75.426532      0.230330         -5.419714
# 10         BNN_pred     41.009878      0.019633         -6.376284
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     58.092132      0.055238         -5.697039
# 1             PV_dw    -27.713069     -0.750211         -8.195383
# 2             PV_cw     80.793024      0.451849         -5.406019
# 3         LSTM_pred    121.120638      0.770879         -6.412343
# 4          GRU_pred    157.079740      1.209832         -3.501316
# 5     LSTM_GRU_pred     98.431003      0.508454         -5.541159
# 6       BiLSTM_pred    122.408109      0.784923         -4.333397
# 7   BiLSTM_GRU_pred    244.640674      2.202615         -1.887421
# 8         QRNN_pred     84.489766      0.325298         -5.612528
# 9          ESN_pred     13.890988     -0.461009         -8.580982
# 10         BNN_pred    120.643393      0.822588         -4.727414
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -18.531676     -1.167231         -6.007068
# 1             PV_dw     60.994866      0.334183         -2.543324
# 2             PV_cw     24.847921     -0.218774         -5.601284
# 3         LSTM_pred     97.081297      0.905538         -2.166842
# 4          GRU_pred     61.801698      0.142454         -1.478319
# 5     LSTM_GRU_pred     17.961117     -0.770019         -2.573257
# 6       BiLSTM_pred     29.662245     -0.205154         -3.939813
# 7   BiLSTM_GRU_pred    101.561107      1.079335         -1.733776
# 8         QRNN_pred    -16.458511     -0.960494         -8.308155
# 9          ESN_pred    -47.140005     -1.669731         -8.688244
# 10         BNN_pred     38.952206     -0.061585         -3.994100
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     22.238231     -0.427000         -5.651303
# 1             PV_dw      6.913633     -0.503301         -3.369145
# 2             PV_cw     59.984835      0.248594         -5.307494
# 3         LSTM_pred    124.021335      1.278160         -2.662361
# 4          GRU_pred    108.286322      0.680744         -3.229583
# 5     LSTM_GRU_pred     -8.577570     -0.931114         -4.376907
# 6       BiLSTM_pred     92.674385      0.522970         -4.133102
# 7   BiLSTM_GRU_pred    123.022033      1.211556         -1.965419
# 8         QRNN_pred     17.104857     -0.435067         -6.508957
# 9          ESN_pred    -20.842363     -1.068051         -8.779423
# 10         BNN_pred    122.004970      1.186234         -2.588326
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     68.823778      0.177100         -5.578592
# 1             PV_dw    -13.209978     -0.683495         -5.862891
# 2             PV_cw     87.175382      0.554895         -5.481186
# 3         LSTM_pred    130.888897      1.344199         -3.332321
# 4          GRU_pred    124.120084      0.929843         -4.801350
# 5     LSTM_GRU_pred     36.996484     -0.214376         -4.319635
# 6       BiLSTM_pred     89.566517      0.423365         -3.926415
# 7   BiLSTM_GRU_pred    135.583047      1.314543         -1.989069
# 8         QRNN_pred      8.353326     -0.515576         -7.643378
# 9          ESN_pred     25.528146     -0.349867         -6.274324
# 10         BNN_pred    110.398236      0.949157         -4.939127
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -18.531676     -1.167231         -6.007068
# 1             PV_dw     64.768161      0.151673         -2.834278
# 2             PV_cw     57.387681      0.208694         -5.445768
# 3         LSTM_pred    121.476483      1.004670         -2.272482
# 4          GRU_pred    -53.722629     -1.647100         -8.461012
# 5     LSTM_GRU_pred     -6.802683     -1.024814         -4.208586
# 6       BiLSTM_pred     53.431483     -0.013818         -3.950539
# 7   BiLSTM_GRU_pred     64.217794      0.335549         -4.337747
# 8         QRNN_pred    -16.458511     -0.960494         -8.308155
# 9          ESN_pred    -57.798485     -1.795515         -8.594605
# 10         BNN_pred     19.094434     -0.307046         -5.715400
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     36.083015     -0.204243         -6.900875
# 1             PV_dw      7.257819     -0.639536         -4.382269
# 2             PV_cw     75.413409      0.403252         -6.091177
# 3         LSTM_pred    127.129329      1.004068         -4.208080
# 4          GRU_pred     25.129716     -0.302989         -7.508034
# 5     LSTM_GRU_pred    -58.182310     -1.405907         -9.930191
# 6       BiLSTM_pred     42.879202     -0.117123         -5.929786
# 7   BiLSTM_GRU_pred     81.347458      0.492051         -4.596214
# 8         QRNN_pred     17.104857     -0.435067         -6.508957
# 9          ESN_pred    -50.953522     -1.301197         -9.287588
# 10         BNN_pred     70.666948      0.361316         -4.539612
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     87.952443      0.375401         -4.490995
# 1             PV_dw     -5.332383     -0.683017         -7.655105
# 2             PV_cw     86.104197      0.497929         -5.648306
# 3         LSTM_pred    130.883343      1.044914         -4.194111
# 4          GRU_pred     52.907482      0.003050         -6.997550
# 5     LSTM_GRU_pred     12.161603     -0.442353         -7.753268
# 6       BiLSTM_pred     42.809544     -0.098862         -6.378985
# 7   BiLSTM_GRU_pred     83.023452      0.484759         -4.589102
# 8         QRNN_pred     47.227451     -0.056552         -6.391228
# 9          ESN_pred    -13.334686     -0.739937         -7.127124
# 10         BNN_pred     71.948783      0.355657         -6.417036
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -18.531676     -1.167231         -6.007068
# 1             PV_dw     85.680884      0.327281         -6.357779
# 2             PV_cw     51.786752     -0.017717         -5.445768
# 3         LSTM_pred     87.545078      0.337951         -6.527418
# 4          GRU_pred    100.716380      0.463897         -6.322824
# 5     LSTM_GRU_pred     26.653019     -0.351928         -5.421778
# 6       BiLSTM_pred    103.914110      0.496877         -6.367996
# 7   BiLSTM_GRU_pred     20.226255     -0.386488         -8.065087
# 8         QRNN_pred    -16.458511     -0.960494         -8.308155
# 9          ESN_pred     -8.691573     -0.718885         -7.594659
# 10         BNN_pred     85.513397      0.315572         -7.576328
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     25.992249     -0.309642         -7.807600
# 1             PV_dw     80.096208      0.265431         -7.112665
# 2             PV_cw     78.761205      0.268625         -6.008680
# 3         LSTM_pred    107.941403      0.518068         -6.418136
# 4          GRU_pred     81.684047      0.280521         -7.866949
# 5     LSTM_GRU_pred     29.007956     -0.253454         -9.442206
# 6       BiLSTM_pred     86.376734      0.323952         -7.788915
# 7   BiLSTM_GRU_pred    111.698794      0.558777         -5.722625
# 8         QRNN_pred     17.104857     -0.435067         -6.508957
# 9          ESN_pred     33.380501     -0.190086         -6.740659
# 10         BNN_pred     94.491341      0.397420         -7.084907
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     57.865394      0.054281         -6.919837
# 1             PV_dw    107.892628      0.517635         -6.418419
# 2             PV_cw    112.098476      0.572120         -5.458510
# 3         LSTM_pred    111.631510      0.551035         -6.396831
# 4          GRU_pred    104.910246      0.491425         -6.864566
# 5     LSTM_GRU_pred    101.193970      0.457927         -6.887732
# 6       BiLSTM_pred    112.297883      0.556801         -6.818973
# 7   BiLSTM_GRU_pred    111.631510      0.551035         -6.396831
# 8         QRNN_pred     47.920758     -0.048904         -6.493492
# 9          ESN_pred    117.262971      0.600203         -6.364589
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     67.369392      0.279613         -7.962712
# 1             PV_dw    122.867680      0.660549         -6.361005
# 2             PV_cw    112.130239      0.558703         -6.824788
# 3         LSTM_pred    123.870558      0.659206         -6.349463
# 4          GRU_pred    119.924515      0.623770         -6.349463
# 5     LSTM_GRU_pred    127.174816      0.691981         -6.493630
# 6       BiLSTM_pred    125.448180      0.674283         -6.318300
# 7   BiLSTM_GRU_pred    119.924515      0.623770         -6.349463
# 8         QRNN_pred    113.349991      0.570955         -6.496200
# 9          ESN_pred     93.604176      0.389679         -7.359058
# 10         BNN_pred     93.996370      0.397496         -6.802175
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    111.111787      0.738735         -7.006324
# 1             PV_dw     89.791814      0.366189         -6.881013
# 2             PV_cw    113.775421      0.608014         -4.587005
# 3         LSTM_pred    122.783995      0.690583         -6.584284
# 4          GRU_pred    101.896389      0.471842         -8.160211
# 5     LSTM_GRU_pred    132.004923      0.748621         -5.742481
# 6       BiLSTM_pred     99.730136      0.464306         -5.273121
# 7   BiLSTM_GRU_pred    147.886427      0.897282         -6.153614
# 8         QRNN_pred    118.598678      0.706268         -6.247083
# 9          ESN_pred    111.857977      0.613404         -4.573344
# 10         BNN_pred     11.601793     -0.287738         -7.883376
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    179.671971      1.698212         -2.593268
# 1             PV_dw     37.469821     -0.166093         -8.289047
# 2             PV_cw    128.356363      0.874857         -6.122198
# 3         LSTM_pred     82.689070      0.336935         -8.855659
# 4          GRU_pred    218.200442      1.931053         -2.933925
# 5     LSTM_GRU_pred     34.352358     -0.191433         -7.985870
# 6       BiLSTM_pred    106.216493      0.557733         -5.857015
# 7   BiLSTM_GRU_pred     73.787059      0.233249         -8.578417
# 8         QRNN_pred     19.316233     -0.375675         -4.477283
# 9          ESN_pred     22.135731     -0.251810         -6.096242
# 10         BNN_pred     39.654815      0.004118         -5.681716
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    176.569517      1.595193         -3.094874
# 1             PV_dw     50.637547     -0.020294         -7.525661
# 2             PV_cw    106.701628      0.604348         -5.346529
# 3         LSTM_pred    106.100628      0.534327         -7.203904
# 4          GRU_pred    114.238546      0.588873         -7.401545
# 5     LSTM_GRU_pred     78.398647      0.255987         -6.945088
# 6       BiLSTM_pred     89.866491      0.373485         -5.294417
# 7   BiLSTM_GRU_pred    149.381457      0.940944         -6.077840
# 8         QRNN_pred     63.750885      0.125104         -4.608343
# 9          ESN_pred     89.557432      0.408249         -4.644630
# 10         BNN_pred     37.536307     -0.018333         -5.683643
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     94.155962      0.581770         -5.438987
# 1             PV_dw     67.063353      0.146047         -7.027579
# 2             PV_cw    139.991753      0.886561         -4.589835
# 3         LSTM_pred    127.187102      0.733131         -6.584284
# 4          GRU_pred    101.896389      0.471842         -8.160211
# 5     LSTM_GRU_pred    122.511099      0.665365         -6.496489
# 6       BiLSTM_pred     99.730136      0.464306         -5.273121
# 7   BiLSTM_GRU_pred    147.886427      0.897282         -6.153614
# 8         QRNN_pred    107.859403      0.603232         -4.672472
# 9          ESN_pred    117.732780      0.689875         -4.638890
# 10         BNN_pred     17.990450     -0.220760         -7.641870
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    117.820851      0.869589         -4.465830
# 1             PV_dw     86.226756      0.333700         -7.233946
# 2             PV_cw    108.862125      0.590981         -5.112769
# 3         LSTM_pred    104.754256      0.492195         -7.496596
# 4          GRU_pred    116.206879      0.590917         -6.370610
# 5     LSTM_GRU_pred     30.080305     -0.222983         -8.723089
# 6       BiLSTM_pred    106.908534      0.518547         -6.421708
# 7   BiLSTM_GRU_pred     96.977081      0.420657         -7.644456
# 8         QRNN_pred    101.607257      0.762116         -4.973334
# 9          ESN_pred     70.918467      0.190720         -4.818226
# 10         BNN_pred     84.365025      0.309199         -6.838444
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    107.688695      0.724534         -4.408052
# 1             PV_dw    101.382987      0.467163         -6.485089
# 2             PV_cw     83.518126      0.320622         -4.817748
# 3         LSTM_pred    111.181771      0.549205         -6.952577
# 4          GRU_pred    116.206879      0.590917         -6.370610
# 5     LSTM_GRU_pred     81.799813      0.284262         -7.604865
# 6       BiLSTM_pred    109.259358      0.536757         -6.354362
# 7   BiLSTM_GRU_pred    110.115231      0.537924         -6.349463
# 8         QRNN_pred    114.258277      0.673434         -4.941832
# 9          ESN_pred    122.046972      0.677731         -4.507039
# 10         BNN_pred     86.513885      0.328366         -6.799270
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     88.387766      0.485555         -6.117887
# 1             PV_dw    110.919303      0.553872         -6.429420
# 2             PV_cw    121.680048      0.665997         -5.177485
# 3         LSTM_pred    128.277926      0.698757         -6.349463
# 4          GRU_pred    119.924515      0.623770         -6.349463
# 5     LSTM_GRU_pred    118.031236      0.613451         -7.136560
# 6       BiLSTM_pred    125.448180      0.674283         -6.318300
# 7   BiLSTM_GRU_pred    119.924515      0.623770         -6.349463
# 8         QRNN_pred    109.789258      0.538774         -6.517043
# 9          ESN_pred    115.139158      0.595695         -5.521799
# 10         BNN_pred     94.619507      0.403300         -6.748921
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    120.840739      0.651873         -5.139034
# 1             PV_dw     99.803573      0.445436         -7.112987
# 2             PV_cw    108.210806      0.535023         -5.188969
# 3         LSTM_pred     96.575006      0.416953         -7.496596
# 4          GRU_pred    116.206879      0.590917         -6.370610
# 5     LSTM_GRU_pred     71.584401      0.186335         -7.919023
# 6       BiLSTM_pred    107.524539      0.517768         -6.418136
# 7   BiLSTM_GRU_pred     96.977081      0.420657         -7.644456
# 8         QRNN_pred    119.924515      0.623770         -6.349463
# 9          ESN_pred     81.956721      0.293994         -5.653269
# 10         BNN_pred    103.247596      0.475797         -6.445443
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    119.924515      0.623770         -6.349463
# 1             PV_dw    116.206879      0.590917         -6.370610
# 2             PV_cw     99.272929      0.446752         -6.363408
# 3         LSTM_pred    102.954935      0.474072         -6.952577
# 4          GRU_pred    116.206879      0.590917         -6.370610
# 5     LSTM_GRU_pred     92.820743      0.382705         -6.879715
# 6       BiLSTM_pred    110.115231      0.537924         -6.349463
# 7   BiLSTM_GRU_pred    110.115231      0.537924         -6.349463
# 8         QRNN_pred    119.924515      0.623770         -6.349463
# 9          ESN_pred    121.482412      0.651033         -5.136093
# 10         BNN_pred    111.631510      0.551035         -6.396831
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    119.924515      0.623770         -6.349463
# 1             PV_dw    116.206879      0.590917         -6.370610
# 2             PV_cw    114.450282      0.576060         -6.805803
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    119.924515      0.623770         -6.349463
# 5     LSTM_GRU_pred    104.461433      0.487279         -7.004445
# 6       BiLSTM_pred    119.924515      0.623770         -6.349463
# 7   BiLSTM_GRU_pred    119.924515      0.623770         -6.349463
# 8         QRNN_pred    119.924515      0.623770         -6.349463
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    119.924515      0.623770         -6.349463
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     94.229592      0.400683         -6.445737
# 1             PV_dw    132.700633      0.744716         -6.301497
# 2             PV_cw    119.692083      0.636392         -5.133048
# 3         LSTM_pred    123.870558      0.659206         -6.349463
# 4          GRU_pred    119.924515      0.623770         -6.349463
# 5     LSTM_GRU_pred    105.834930      0.502939         -6.403214
# 6       BiLSTM_pred    121.743045      0.642873         -6.343322
# 7   BiLSTM_GRU_pred    119.924515      0.623770         -6.349463
# 8         QRNN_pred    112.269854      0.557707         -6.393160
# 9          ESN_pred    147.282043      0.882677         -4.790033
# 10         BNN_pred     72.103298      0.192867         -6.968907
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    106.259089      0.527189         -5.547716
# 1             PV_dw    102.785081      0.482503         -6.429391
# 2             PV_cw     90.014875      0.368213         -5.271870
# 3         LSTM_pred    159.579688      1.042918         -4.399002
# 4          GRU_pred     98.811914      0.449340         -6.597814
# 5     LSTM_GRU_pred    118.706118      0.626820         -5.612554
# 6       BiLSTM_pred     83.966957      0.313885         -6.585431
# 7   BiLSTM_GRU_pred    139.128281      0.819149         -6.144351
# 8         QRNN_pred    122.737063      0.878239         -6.053581
# 9          ESN_pred    171.779553      1.191841         -3.253950
# 10         BNN_pred     65.592033      0.273809         -5.133526
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     70.661000      0.201854         -5.222896
# 1             PV_dw     65.510523      0.131646         -6.667559
# 2             PV_cw     34.385082     -0.201953         -6.586443
# 3         LSTM_pred    112.697286      0.656682         -5.924137
# 4          GRU_pred    183.490710      1.610196         -3.123366
# 5     LSTM_GRU_pred    -33.537026     -0.972143         -7.547125
# 6       BiLSTM_pred     51.814274     -0.012870         -7.362371
# 7   BiLSTM_GRU_pred     52.315332     -0.009973         -8.761149
# 8         QRNN_pred     25.138159     -0.241263         -7.120301
# 9          ESN_pred     63.321640      0.273287         -5.142539
# 10         BNN_pred     81.041521      0.439765         -5.067104
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    112.673093      0.624797         -4.452532
# 1             PV_dw     96.230660      0.424699         -6.492201
# 2             PV_cw     71.978177      0.196645         -6.166485
# 3         LSTM_pred    142.349577      0.888221         -4.996597
# 4          GRU_pred     98.811914      0.449340         -6.597814
# 5     LSTM_GRU_pred     50.920401     -0.014630         -6.427082
# 6       BiLSTM_pred     62.657640      0.102902         -6.693863
# 7   BiLSTM_GRU_pred    129.777770      0.740268         -6.153699
# 8         QRNN_pred     77.973497      0.487964         -6.440208
# 9          ESN_pred    128.686450      0.796169         -3.433541
# 10         BNN_pred     69.255866      0.312163         -5.075860
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     93.423821      0.405497         -5.582182
# 1             PV_dw     97.070467      0.430877         -6.487231
# 2             PV_cw     88.445046      0.355609         -5.295150
# 3         LSTM_pred    164.127094      1.086283         -4.399002
# 4          GRU_pred     98.811914      0.449340         -6.597814
# 5     LSTM_GRU_pred     98.987218      0.448446         -6.441217
# 6       BiLSTM_pred    101.733021      0.490803         -6.467568
# 7   BiLSTM_GRU_pred    139.128281      0.819149         -6.144351
# 8         QRNN_pred    138.512603      0.916054         -6.141061
# 9          ESN_pred    152.421447      1.010131         -4.133199
# 10         BNN_pred     58.303821      0.200145         -5.117756
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     50.443449     -0.036271         -5.366122
# 1             PV_dw     95.260282      0.419949         -6.564104
# 2             PV_cw     59.608599      0.071097         -6.429655
# 3         LSTM_pred    103.468368      0.480502         -7.505332
# 4          GRU_pred    111.843399      0.552040         -6.395612
# 5     LSTM_GRU_pred    -29.142214     -0.881265         -8.245137
# 6       BiLSTM_pred    110.333142      0.550599         -6.406096
# 7   BiLSTM_GRU_pred     92.654854      0.381151         -7.653364
# 8         QRNN_pred    107.295488      0.831063         -6.489848
# 9          ESN_pred    125.931503      0.720045         -4.396089
# 10         BNN_pred     50.374840     -0.018213         -7.032312
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     81.030146      0.285429         -5.261745
# 1             PV_dw    121.906578      0.653308         -6.408200
# 2             PV_cw     98.354810      0.454238         -5.247678
# 3         LSTM_pred    111.181771      0.549205         -6.952577
# 4          GRU_pred    119.924515      0.623770         -6.349463
# 5     LSTM_GRU_pred     44.733758     -0.073686         -7.050983
# 6       BiLSTM_pred    107.520192      0.522709         -6.380861
# 7   BiLSTM_GRU_pred    110.115231      0.537924         -6.349463
# 8         QRNN_pred    112.840176      0.819869         -6.457512
# 9          ESN_pred    159.961643      1.020151         -4.384797
# 10         BNN_pred     66.716101      0.141301         -6.953226
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     79.357188      0.261889         -6.498862
# 1             PV_dw    131.620597      0.739216         -6.353191
# 2             PV_cw    110.016669      0.555601         -5.731297
# 3         LSTM_pred    128.277926      0.698757         -6.349463
# 4          GRU_pred    119.924515      0.623770         -6.349463
# 5     LSTM_GRU_pred     85.255895      0.315896         -7.126142
# 6       BiLSTM_pred    132.775742      0.744820         -6.281541
# 7   BiLSTM_GRU_pred    119.924515      0.623770         -6.349463
# 8         QRNN_pred    113.644956      0.575681         -6.385266
# 9          ESN_pred    150.336124      0.923386         -4.384797
# 10         BNN_pred     64.770552      0.122490         -6.965931
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     67.584142      0.151517         -6.337777
# 1             PV_dw    104.214932      0.484639         -6.439796
# 2             PV_cw     64.644704      0.122217         -6.395051
# 3         LSTM_pred     95.298639      0.405280         -7.505332
# 4          GRU_pred    111.843399      0.552040         -6.395612
# 5     LSTM_GRU_pred     79.513428      0.260345         -7.212718
# 6       BiLSTM_pred    107.524539      0.517768         -6.418136
# 7   BiLSTM_GRU_pred     92.654854      0.381151         -7.653364
# 8         QRNN_pred    105.269633      0.512631         -6.433651
# 9          ESN_pred    100.350632      0.463442         -6.247491
# 10         BNN_pred    109.484555      0.531768         -6.409210
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    122.718445      0.669093         -5.130439
# 1             PV_dw    119.924515      0.623770         -6.349463
# 2             PV_cw    111.654952      0.563001         -5.181498
# 3         LSTM_pred    102.954935      0.474072         -6.952577
# 4          GRU_pred    119.924515      0.623770         -6.349463
# 5     LSTM_GRU_pred     92.820743      0.382705         -6.879715
# 6       BiLSTM_pred    100.366990      0.451078         -6.418136
# 7   BiLSTM_GRU_pred    110.115231      0.537924         -6.349463
# 8         QRNN_pred    119.924515      0.623770         -6.349463
# 9          ESN_pred    129.612641      0.724242         -5.099127
# 10         BNN_pred    111.631510      0.551035         -6.396831
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    119.924515      0.623770         -6.349463
# 1             PV_dw    119.924515      0.623770         -6.349463
# 2             PV_cw    121.923715      0.649978         -5.670470
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    119.924515      0.623770         -6.349463
# 5     LSTM_GRU_pred    104.461433      0.487279         -7.004445
# 6       BiLSTM_pred    119.924515      0.623770         -6.349463
# 7   BiLSTM_GRU_pred    119.924515      0.623770         -6.349463
# 8         QRNN_pred    119.924515      0.623770         -6.349463
# 9          ESN_pred    112.700948      0.560311         -6.952577
# 10         BNN_pred    111.631510      0.551035         -6.396831
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    113.890291      0.589792         -4.749967
# 1             PV_dw     90.654675      0.371629         -6.389039
# 2             PV_cw     98.545020      0.584416         -5.150969
# 3         LSTM_pred    120.628126      0.662198         -6.468541
# 4          GRU_pred     54.537067      0.160531         -8.482557
# 5     LSTM_GRU_pred    101.352758      0.472449         -6.402115
# 6       BiLSTM_pred     92.390704      0.394958         -6.907823
# 7   BiLSTM_GRU_pred    139.872025      0.828055         -5.521796
# 8         QRNN_pred    102.284328      0.614366         -6.355171
# 9          ESN_pred    106.481359      0.539773         -4.273394
# 10         BNN_pred     38.715709     -0.138265         -8.295842
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    136.303415      0.871509         -4.488234
# 1             PV_dw     26.309523     -0.302392         -6.627598
# 2             PV_cw     76.579468      0.388363         -5.308456
# 3         LSTM_pred    117.963278      0.674736         -4.899932
# 4          GRU_pred     66.056798      0.298138         -7.140082
# 5     LSTM_GRU_pred     62.617367      0.102824         -3.886593
# 6       BiLSTM_pred    108.946828      0.761991         -7.246357
# 7   BiLSTM_GRU_pred    100.972933      0.493729         -4.940367
# 8         QRNN_pred     97.325452      0.476427         -7.082299
# 9          ESN_pred     72.727722      0.361590         -4.646328
# 10         BNN_pred     29.625796     -0.116429         -5.217856
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     -5.064642     -0.915737         -5.776942
# 1             PV_dw    -87.027762     -2.265841         -9.892217
# 2             PV_cw     18.349420     -0.274879         -9.718950
# 3         LSTM_pred      8.431351     -0.686223         -7.789864
# 4          GRU_pred    130.220936      1.315356         -4.707432
# 5     LSTM_GRU_pred    -11.347119     -1.061949         -4.544492
# 6       BiLSTM_pred     56.207334      0.220809         -6.645908
# 7   BiLSTM_GRU_pred     29.603074     -0.337778         -8.024828
# 8         QRNN_pred    123.507185      1.206060         -4.055617
# 9          ESN_pred    -11.219836     -0.792644         -6.747361
# 10         BNN_pred     56.532232      0.230954         -3.128870
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     65.702911      0.146163         -4.576202
# 1             PV_dw    -61.900860     -1.514709         -7.841885
# 2             PV_cw     44.618311      0.056548         -7.980064
# 3         LSTM_pred     66.999191      0.151613         -5.716759
# 4          GRU_pred     40.396693      0.004913         -8.034503
# 5     LSTM_GRU_pred     13.501485     -0.498591         -6.398683
# 6       BiLSTM_pred     27.736326     -0.150742         -8.360301
# 7   BiLSTM_GRU_pred     20.977728     -0.371602         -7.043028
# 8         QRNN_pred    106.059192      0.903507         -4.775804
# 9          ESN_pred     14.605948     -0.323156         -7.432072
# 10         BNN_pred     72.736219      0.406037         -3.809453
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    107.316930      0.587459         -4.488234
# 1             PV_dw     -8.508674     -0.709751         -7.449918
# 2             PV_cw     86.158300      0.504399         -6.127339
# 3         LSTM_pred    122.347481      0.719604         -4.899932
# 4          GRU_pred     66.056798      0.298138         -7.140082
# 5     LSTM_GRU_pred     42.566444     -0.119743         -5.986773
# 6       BiLSTM_pred     46.496188      0.078263         -7.629219
# 7   BiLSTM_GRU_pred     84.757439      0.336251         -5.870449
# 8         QRNN_pred     81.620446      0.474030         -7.180031
# 9          ESN_pred     55.151975      0.018416         -6.196828
# 10         BNN_pred     59.846015      0.237759         -3.276248
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     -5.064642     -0.915737         -5.776942
# 1             PV_dw     -7.481783     -0.760117         -8.473224
# 2             PV_cw     50.037583      0.120013         -9.718950
# 3         LSTM_pred     16.587785     -0.413225         -8.297699
# 4          GRU_pred    186.644215      1.750946         -3.740640
# 5     LSTM_GRU_pred     33.156584     -0.295937         -5.256639
# 6       BiLSTM_pred     80.033069      0.476983         -6.016405
# 7   BiLSTM_GRU_pred     63.731236      0.116085         -8.169966
# 8         QRNN_pred     94.125203      0.587312         -6.549765
# 9          ESN_pred    112.330712      0.862046         -4.330187
# 10         BNN_pred     32.615942     -0.248536         -5.373241
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     62.094164      0.097666         -4.630814
# 1             PV_dw     53.821234      0.012649         -6.641519
# 2             PV_cw    101.463052      0.658399         -5.567450
# 3         LSTM_pred     57.447952      0.049229         -7.717080
# 4          GRU_pred     51.036488      0.125071         -8.510809
# 5     LSTM_GRU_pred     -9.122913     -0.697064         -8.144854
# 6       BiLSTM_pred     46.989580     -0.059954         -7.803474
# 7   BiLSTM_GRU_pred     71.776226      0.196466         -6.966198
# 8         QRNN_pred     91.268235      0.544720         -6.566913
# 9          ESN_pred    119.160734      0.866055         -3.872510
# 10         BNN_pred     55.307942      0.025981         -6.479084
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     88.136216      0.352662         -5.829902
# 1             PV_dw     82.918338      0.300083         -6.458926
# 2             PV_cw    123.208366      0.849503         -5.182476
# 3         LSTM_pred    125.022779      0.704126         -6.468541
# 4          GRU_pred     54.537067      0.160531         -8.482557
# 5     LSTM_GRU_pred     66.679663      0.143025         -7.505999
# 6       BiLSTM_pred     60.628381      0.082008         -7.068351
# 7   BiLSTM_GRU_pred    114.902899      0.610668         -6.143115
# 8         QRNN_pred    131.813061      0.940212         -6.331667
# 9          ESN_pred    130.885449      0.807492         -4.222111
# 10         BNN_pred     75.560432      0.234909         -6.243438
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     -5.064642     -0.915737         -5.776942
# 1             PV_dw     60.315543      0.079533         -7.753102
# 2             PV_cw     25.287061     -0.310251         -9.718950
# 3         LSTM_pred     77.148376      0.242642         -7.548183
# 4          GRU_pred    104.179817      0.487434         -6.440001
# 5     LSTM_GRU_pred      8.719278     -0.481072        -10.495720
# 6       BiLSTM_pred     91.754135      0.375680         -6.547636
# 7   BiLSTM_GRU_pred     65.594385      0.130615         -7.748667
# 8         QRNN_pred     86.331164      0.345655         -6.545812
# 9          ESN_pred     78.981290      0.265093         -6.177347
# 10         BNN_pred     81.900840      0.282134         -7.167357
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     62.094164      0.097666         -4.630814
# 1             PV_dw     94.543247      0.397986         -6.439796
# 2             PV_cw     87.830199      0.351457         -5.578184
# 3         LSTM_pred    102.954935      0.474072         -6.952577
# 4          GRU_pred    116.206879      0.590917         -6.370610
# 5     LSTM_GRU_pred     80.122079      0.265929         -7.863076
# 6       BiLSTM_pred    107.524539      0.517768         -6.418136
# 7   BiLSTM_GRU_pred    112.268179      0.557395         -6.349463
# 8         QRNN_pred     94.028370      0.407096         -6.499758
# 9          ESN_pred    109.455531      0.547625         -5.471514
# 10         BNN_pred    105.752894      0.498359         -6.430839
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     82.967336      0.302035         -6.286267
# 1             PV_dw    119.924515      0.623770         -6.349463
# 2             PV_cw    119.924515      0.623770         -6.349463
# 3         LSTM_pred    119.924515      0.623770         -6.349463
# 4          GRU_pred    119.924515      0.623770         -6.349463
# 5     LSTM_GRU_pred    112.700948      0.560311         -6.952577
# 6       BiLSTM_pred    111.213257      0.551004         -6.396831
# 7   BiLSTM_GRU_pred    110.115231      0.537924         -6.349463
# 8         QRNN_pred    119.924515      0.623770         -6.349463
# 9          ESN_pred    119.924515      0.623770         -6.349463
# 10         BNN_pred    111.631510      0.551035         -6.396831
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     89.345167      0.362457         -6.641989
# 1             PV_dw     55.608436      0.031100         -7.010882
# 2             PV_cw     94.923488      0.429874         -5.529318
# 3         LSTM_pred    119.640874      0.681205         -5.114024
# 4          GRU_pred     58.252718      0.198156         -8.482557
# 5     LSTM_GRU_pred     65.537031      0.131137         -5.854234
# 6       BiLSTM_pred     83.413324      0.313774         -6.528370
# 7   BiLSTM_GRU_pred    103.773224      0.501814         -5.665694
# 8         QRNN_pred    100.865065      0.500144         -6.597181
# 9          ESN_pred     81.026308      0.433716         -4.056158
# 10         BNN_pred     13.662799     -0.271039         -7.716423
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     58.092132      0.055238         -5.697039
# 1             PV_dw     20.095482     -0.384479         -5.556244
# 2             PV_cw    103.401223      0.673687         -5.215061
# 3         LSTM_pred    124.622599      0.744187         -4.853752
# 4          GRU_pred    131.214589      0.959214         -4.121627
# 5     LSTM_GRU_pred     98.431003      0.508454         -5.541159
# 6       BiLSTM_pred     85.289181      0.496375         -7.407261
# 7   BiLSTM_GRU_pred     95.871253      0.459900         -6.000512
# 8         QRNN_pred    173.518007      1.357292         -4.509278
# 9          ESN_pred     36.360609     -0.032057         -6.258440
# 10         BNN_pred     28.093171     -0.132011         -6.183469
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -18.531676     -1.167231         -6.007068
# 1             PV_dw    -99.457586     -2.626718        -11.326599
# 2             PV_cw     -0.075973     -0.541539         -9.532345
# 3         LSTM_pred      4.902138     -0.802646         -6.840766
# 4          GRU_pred     88.953868      0.939187         -1.526791
# 5     LSTM_GRU_pred     17.961117     -0.770019         -2.573257
# 6       BiLSTM_pred     64.642014      0.406615         -4.719291
# 7   BiLSTM_GRU_pred     25.958501     -0.454147         -5.574219
# 8         QRNN_pred    101.090519      0.935992         -4.154642
# 9          ESN_pred    -49.498346     -1.547199         -8.155331
# 10         BNN_pred     53.556271      0.203608         -3.033515
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     22.238231     -0.427000         -5.651303
# 1             PV_dw    -86.642896     -2.017611         -9.854232
# 2             PV_cw     62.617216      0.273866         -8.267959
# 3         LSTM_pred      0.155731     -0.644919         -6.655342
# 4          GRU_pred     12.908286     -0.395147         -4.631290
# 5     LSTM_GRU_pred     -8.577570     -0.931114         -4.376907
# 6       BiLSTM_pred     24.938930     -0.201234         -7.189556
# 7   BiLSTM_GRU_pred     -0.337967     -0.670436         -7.804494
# 8         QRNN_pred    103.052960      0.965636         -4.147251
# 9          ESN_pred    -44.799697     -1.228002        -10.448600
# 10         BNN_pred     96.104789      0.729842         -3.222366
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     68.823778      0.177100         -5.578592
# 1             PV_dw    -62.725209     -1.473613         -8.303876
# 2             PV_cw     54.634526      0.173172         -6.105467
# 3         LSTM_pred    119.143854      0.692668         -4.853752
# 4          GRU_pred     29.999062     -0.131629         -4.068999
# 5     LSTM_GRU_pred     36.996484     -0.214376         -4.319635
# 6       BiLSTM_pred     31.521252     -0.106650         -7.116556
# 7   BiLSTM_GRU_pred     60.701529      0.082688         -6.725563
# 8         QRNN_pred     29.408038     -0.130728         -7.489653
# 9          ESN_pred      2.613873     -0.472964         -8.977942
# 10         BNN_pred     61.482779      0.263714         -4.938545
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -18.531676     -1.167231         -6.007068
# 1             PV_dw    -32.204208     -1.132615         -8.633751
# 2             PV_cw     20.313911     -0.252256         -9.788312
# 3         LSTM_pred    -12.363356     -0.963409         -7.283384
# 4          GRU_pred    188.847531      1.803050         -3.740640
# 5     LSTM_GRU_pred     -6.802683     -1.024814         -4.208586
# 6       BiLSTM_pred     46.372178      0.077347         -6.953331
# 7   BiLSTM_GRU_pred     28.422251     -0.328024         -6.620543
# 8         QRNN_pred    122.409065      1.110211         -4.291963
# 9          ESN_pred      9.118633     -0.451456         -5.767250
# 10         BNN_pred     58.057527      0.258021         -3.033515
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     36.083015     -0.204243         -6.900875
# 1             PV_dw    -31.214487     -1.002503         -7.895805
# 2             PV_cw     80.310320      0.460855         -7.300077
# 3         LSTM_pred     -1.904438     -0.654693         -7.366600
# 4          GRU_pred     54.739804      0.162688         -8.510809
# 5     LSTM_GRU_pred    -58.182310     -1.405907         -9.930191
# 6       BiLSTM_pred     84.051479      0.343408         -7.153706
# 7   BiLSTM_GRU_pred     13.488518     -0.447422         -8.556517
# 8         QRNN_pred    122.409065      1.110211         -4.291963
# 9          ESN_pred     31.754281     -0.100042         -7.016278
# 10         BNN_pred     40.402767      0.009489         -5.910664
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     87.952443      0.375401         -4.490995
# 1             PV_dw      4.926336     -0.517961         -7.699365
# 2             PV_cw     62.037318      0.245724         -6.495107
# 3         LSTM_pred    114.186398      0.630324         -5.114024
# 4          GRU_pred     54.739804      0.162688         -8.510809
# 5     LSTM_GRU_pred     12.161603     -0.442353         -7.753268
# 6       BiLSTM_pred     39.441762     -0.143375         -7.410158
# 7   BiLSTM_GRU_pred     65.480462      0.131875         -6.599248
# 8         QRNN_pred     68.838349      0.330690         -7.951909
# 9          ESN_pred     90.684348      0.562702         -4.439770
# 10         BNN_pred     54.939517      0.171951         -5.194378
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -18.531676     -1.167231         -6.007068
# 1             PV_dw     60.919495      0.085290         -7.697731
# 2             PV_cw     14.909360     -0.459126         -9.788312
# 3         LSTM_pred     74.154548      0.213805         -7.548183
# 4          GRU_pred    110.001178      0.544685         -6.440001
# 5     LSTM_GRU_pred     26.653019     -0.351928         -5.421778
# 6       BiLSTM_pred     83.516650      0.299518         -7.275974
# 7   BiLSTM_GRU_pred     60.059152      0.076709         -7.789128
# 8         QRNN_pred     86.331164      0.345655         -6.545812
# 9          ESN_pred      6.644422     -0.529666        -10.201131
# 10         BNN_pred     81.900840      0.282134         -7.167357
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     25.992249     -0.309642         -7.807600
# 1             PV_dw     80.469220      0.268972         -6.523680
# 2             PV_cw    115.179148      0.626239         -5.448275
# 3         LSTM_pred     99.718812      0.447162         -7.610637
# 4          GRU_pred    116.206879      0.590917         -6.370610
# 5     LSTM_GRU_pred     29.007956     -0.253454         -9.442206
# 6       BiLSTM_pred    107.524539      0.517768         -6.418136
# 7   BiLSTM_GRU_pred    104.098569      0.484793         -7.036879
# 8         QRNN_pred     86.331164      0.345655         -6.545812
# 9          ESN_pred    101.306580      0.472474         -6.165416
# 10         BNN_pred    105.752894      0.498359         -6.430839
# 11               __    119.924515      0.623770         -6.349463
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     57.865394      0.054281         -6.919837
# 1             PV_dw    111.631510      0.551035         -6.396831
# 2             PV_cw    100.469755      0.465188         -5.539789
# 3         LSTM_pred    110.115231      0.537924         -6.349463
# 4          GRU_pred    116.206879      0.590917         -6.370610
# 5     LSTM_GRU_pred    101.193970      0.457927         -6.887732
# 6       BiLSTM_pred    111.213257      0.551004         -6.396831
# 7   BiLSTM_GRU_pred    110.115231      0.537924         -6.349463
# 8         QRNN_pred    119.924515      0.623770         -6.349463
# 9          ESN_pred    112.098476      0.572120         -5.458510
# 10         BNN_pred    111.631510      0.551035         -6.396831
# 11               __    119.924515      0.623770         -6.349463

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_y2', file, 'PV')
get_final_results_1('2022_y2', file, 'PV')

get_final_results('2022_y2', dw_file, 'PV_dw')
get_final_results_1('2022_y2', dw_file, 'PV_dw')

get_final_results('2022_y2', cw_file, 'PV_cw')
get_final_results_1('2022_y2', cw_file, 'PV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:38: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-48-dbce691e5d20>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-48-dbce691e5d20>:44: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:51: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-48-dbce691e5d20>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-48-dbce691e5d20>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-48-dbce691e5d20>:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']
# <ipython-input-4-b267510ae310>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Short_MA'] = data['Close'].rolling(window=short_window).mean()
# <ipython-input-4-b267510ae310>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Long_MA'] = data['Close'].rolling(window=long_window).mean()
# <ipython-input-4-b267510ae310>:6: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-4-b267510ae310>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[0] = initial_capital
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# ...
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:37: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Daily Return'] = data['equity'].pct_change()
# <ipython-input-4-b267510ae310>:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Strategy Return'] = data['Daily Return'].shift(1)
# <ipython-input-4-b267510ae310>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Cumulative Max'] = data['equity'].cummax()
# <ipython-input-4-b267510ae310>:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Drawdown'] = data['equity'] - data['Cumulative Max']

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -15.401678     -0.331643        -15.916361
# 1             PV_dw    -41.405275     -0.520821        -17.220231
# 2             PV_cw    -15.627332     -0.333144        -15.653229
# 3         LSTM_pred    -19.041322     -0.358310        -16.502003
# 4          GRU_pred    -63.103049     -0.686641        -16.320926
# 5     LSTM_GRU_pred    -48.570184     -0.574796        -16.320926
# 6       BiLSTM_pred    -50.590970     -0.592855        -17.068592
# 7   BiLSTM_GRU_pred    -25.408812     -0.402312        -16.437575
# 8         QRNN_pred    -10.339739     -0.296975        -15.774136
# 9          ESN_pred    -29.776167     -0.435693        -16.035561
# 10         BNN_pred    -14.690128     -0.327238        -15.843783
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -25.275730     -0.402372        -16.035561
# 1             PV_dw    -49.946646     -0.607938        -19.668101
# 2             PV_cw     33.078953     -0.004639        -13.333204
# 3         LSTM_pred     67.696761      0.232359        -10.578829
# 4          GRU_pred    -42.878550     -0.543755        -16.098501
# 5     LSTM_GRU_pred    -33.981658     -0.494188        -16.320926
# 6       BiLSTM_pred    -63.956682     -0.699959        -17.130757
# 7   BiLSTM_GRU_pred      6.275336     -0.200563        -11.957792
# 8         QRNN_pred    -17.671583     -0.365788        -16.035561
# 9          ESN_pred    -21.126884     -0.384592        -14.699898
# 10         BNN_pred    -34.741932     -0.482689        -16.587065
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -59.394668     -0.702669        -15.965790
# 1             PV_dw      3.949191     -0.225828        -17.160264
# 2             PV_cw     -6.680283     -0.335307        -13.284966
# 3         LSTM_pred     36.799924      0.017044        -11.472676
# 4          GRU_pred    -42.727194     -0.580099        -14.267019
# 5     LSTM_GRU_pred    -38.703565     -0.578095        -14.886407
# 6       BiLSTM_pred   -101.489719     -1.201610        -14.490924
# 7   BiLSTM_GRU_pred     49.297322      0.103861         -7.361510
# 8         QRNN_pred    -54.849830     -0.717178        -16.652624
# 9          ESN_pred    -39.650236     -0.587143        -12.809510
# 10         BNN_pred     19.549746     -0.115636        -14.216517
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -39.988111     -0.511680        -17.054487
# 1             PV_dw    -39.852121     -0.537323        -19.402160
# 2             PV_cw    -11.002548     -0.336026        -13.404050
# 3         LSTM_pred     36.799924      0.017044        -11.472676
# 4          GRU_pred    -78.121591     -0.819503        -16.771894
# 5     LSTM_GRU_pred    -79.855381     -0.864892        -16.320926
# 6       BiLSTM_pred    -80.311238     -0.828708        -17.795866
# 7   BiLSTM_GRU_pred     -5.003427     -0.293733        -12.306207
# 8         QRNN_pred    -50.697134     -0.653930        -16.035561
# 9          ESN_pred      0.328602     -0.239779        -13.543012
# 10         BNN_pred    -34.395394     -0.484979        -16.911642
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -25.275730     -0.402372        -16.035561
# 1             PV_dw    -49.946646     -0.607938        -19.668101
# 2             PV_cw     36.824211      0.021171        -13.075299
# 3         LSTM_pred     67.851122      0.233711        -11.139071
# 4          GRU_pred    -42.878550     -0.543755        -16.098501
# 5     LSTM_GRU_pred    -33.981658     -0.494188        -16.320926
# 6       BiLSTM_pred    -63.956682     -0.699959        -17.130757
# 7   BiLSTM_GRU_pred    -12.421847     -0.344224        -12.784505
# 8         QRNN_pred    -17.671583     -0.365788        -16.035561
# 9          ESN_pred    -18.549418     -0.366082        -14.699898
# 10         BNN_pred    -34.741932     -0.482689        -16.587065
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -50.702773     -0.632718        -15.965790
# 1             PV_dw    -26.801480     -0.438733        -16.652624
# 2             PV_cw    -32.715292     -0.522697        -12.916133
# 3         LSTM_pred    -53.026948     -0.615796        -16.628530
# 4          GRU_pred    -83.385112     -0.884364        -15.937404
# 5     LSTM_GRU_pred    -44.849243     -0.581199        -14.886407
# 6       BiLSTM_pred   -116.151310     -1.254788        -17.068592
# 7   BiLSTM_GRU_pred    -50.429153     -0.616440        -16.124881
# 8         QRNN_pred    -54.849830     -0.717178        -16.652624
# 9          ESN_pred    -58.309802     -0.707797        -16.035561
# 10         BNN_pred      5.249232     -0.205777        -15.452123
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -31.116884     -0.446364        -17.054487
# 1             PV_dw    -39.925323     -0.514761        -17.092429
# 2             PV_cw    -38.020619     -0.520155        -13.942706
# 3         LSTM_pred    -53.026948     -0.615796        -16.628530
# 4          GRU_pred    -97.601384     -0.961239        -16.992534
# 5     LSTM_GRU_pred    -68.662150     -0.727244        -16.320926
# 6       BiLSTM_pred    -59.631654     -0.661782        -17.068592
# 7   BiLSTM_GRU_pred    -54.939279     -0.632240        -17.048775
# 8         QRNN_pred    -50.697134     -0.653930        -16.035561
# 9          ESN_pred     -3.853704     -0.260092        -15.972775
# 10         BNN_pred    -21.467260     -0.378412        -16.524862
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -15.401678     -0.331643        -15.916361
# 1             PV_dw    -41.405275     -0.520821        -17.220231
# 2             PV_cw      5.343274     -0.190227        -13.982487
# 3         LSTM_pred    -19.041322     -0.358310        -16.502003
# 4          GRU_pred    -63.103049     -0.686641        -16.320926
# 5     LSTM_GRU_pred    -48.570184     -0.574796        -16.320926
# 6       BiLSTM_pred    -50.590970     -0.592855        -17.068592
# 7   BiLSTM_GRU_pred    -54.748738     -0.625307        -17.048775
# 8         QRNN_pred    -10.339739     -0.296975        -15.774136
# 9          ESN_pred    -35.921255     -0.480387        -16.283886
# 10         BNN_pred    -14.690128     -0.327238        -15.843783
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -50.702773     -0.632718        -15.965790
# 1             PV_dw    -26.422741     -0.433659        -16.651209
# 2             PV_cw    -57.673093     -0.716260        -14.612838
# 3         LSTM_pred    -53.163836     -0.614775        -16.035561
# 4          GRU_pred    -41.913551     -0.529297        -16.035561
# 5     LSTM_GRU_pred    -35.201465     -0.483137        -14.985792
# 6       BiLSTM_pred    -41.913551     -0.529297        -16.035561
# 7   BiLSTM_GRU_pred    -49.387191     -0.593578        -16.035561
# 8         QRNN_pred    -46.723697     -0.637682        -16.652624
# 9          ESN_pred    -27.276426     -0.440317        -16.035561
# 10         BNN_pred      0.665313     -0.238349        -15.522907
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -18.756615     -0.355015        -15.916361
# 1             PV_dw    -31.560081     -0.452872        -17.092429
# 2             PV_cw    -62.841533     -0.701672        -16.163149
# 3         LSTM_pred    -53.163836     -0.614775        -16.035561
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -24.931935     -0.399035        -16.010201
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -53.163836     -0.614775        -16.035561
# 8         QRNN_pred    -58.813755     -0.713383        -16.035561
# 9          ESN_pred     -0.323005     -0.230716        -15.916361
# 10         BNN_pred    -25.929351     -0.409310        -16.600561
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -19.183123     -0.358012        -15.916361
# 1             PV_dw    -19.183123     -0.358012        -15.916361
# 2             PV_cw    -19.183123     -0.358012        -15.916361
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -41.913551     -0.529297        -16.035561
# 8         QRNN_pred    -19.183123     -0.358012        -15.916361
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -19.183123     -0.358012        -15.916361
# 1             PV_dw    -33.052927     -0.459367        -17.220231
# 2             PV_cw    -28.365080     -0.424945        -16.035561
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -50.380000     -0.588601        -16.320926
# 5     LSTM_GRU_pred    -47.020882     -0.563502        -16.320926
# 6       BiLSTM_pred    -30.785433     -0.442862        -16.035561
# 7   BiLSTM_GRU_pred    -20.471367     -0.367100        -15.937294
# 8         QRNN_pred     19.326090     -0.095292        -15.643967
# 9          ESN_pred    -19.159663     -0.365534        -16.035561
# 10         BNN_pred    -11.726658     -0.306591        -15.547506
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -23.486112     -0.390956        -15.986496
# 1             PV_dw    -77.107660     -0.822186        -21.121904
# 2             PV_cw    -17.367701     -0.373487        -14.279117
# 3         LSTM_pred     61.249235      0.188573        -12.697586
# 4          GRU_pred    -34.696487     -0.489624        -16.098501
# 5     LSTM_GRU_pred     -5.843293     -0.291081        -16.098501
# 6       BiLSTM_pred    -20.437480     -0.394262        -17.130757
# 7   BiLSTM_GRU_pred    -18.663590     -0.378233        -15.706902
# 8         QRNN_pred    -32.180072     -0.476441        -16.387586
# 9          ESN_pred    -27.324914     -0.436348        -15.668627
# 10         BNN_pred    -22.526750     -0.396261        -16.321243
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -46.617092     -0.647158        -15.598818
# 1             PV_dw    -21.426910     -0.431130        -17.755542
# 2             PV_cw      2.640791     -0.268871        -13.128052
# 3         LSTM_pred     39.329636      0.035040        -12.965380
# 4          GRU_pred     -9.930433     -0.336183        -14.195778
# 5     LSTM_GRU_pred    -46.698283     -0.788631        -13.195138
# 6       BiLSTM_pred    -69.683438     -0.936745        -13.882232
# 7   BiLSTM_GRU_pred    -77.782180     -0.882142        -15.550297
# 8         QRNN_pred    -48.407832     -0.719567        -14.917781
# 9          ESN_pred      9.603320     -0.183703        -13.289114
# 10         BNN_pred     40.211081      0.036613        -12.192060
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -74.413717     -0.787316        -17.198380
# 1             PV_dw    -67.450000     -0.757644        -20.967887
# 2             PV_cw    -27.182349     -0.464131        -13.146995
# 3         LSTM_pred     39.329636      0.035040        -12.965380
# 4          GRU_pred    -69.088757     -0.758636        -16.771894
# 5     LSTM_GRU_pred    -36.266412     -0.529922        -16.771894
# 6       BiLSTM_pred    -69.516687     -0.872632        -16.384666
# 7   BiLSTM_GRU_pred    -35.984271     -0.522282        -14.763563
# 8         QRNN_pred    -55.681754     -0.700880        -16.230372
# 9          ESN_pred      3.384152     -0.224391        -13.289114
# 10         BNN_pred    -29.249980     -0.449395        -16.963047
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -23.486112     -0.390956        -15.986496
# 1             PV_dw    -77.107660     -0.822186        -21.121904
# 2             PV_cw    -26.528071     -0.449116        -14.279117
# 3         LSTM_pred     61.249235      0.188573        -12.697586
# 4          GRU_pred    -38.536316     -0.519195        -16.098501
# 5     LSTM_GRU_pred     -9.797896     -0.321175        -16.098501
# 6       BiLSTM_pred    -20.437480     -0.394262        -17.130757
# 7   BiLSTM_GRU_pred    -19.952516     -0.387768        -15.727559
# 8         QRNN_pred    -42.676693     -0.571146        -17.294416
# 9          ESN_pred    -24.287258     -0.423416        -15.668627
# 10         BNN_pred    -22.526750     -0.396261        -16.321243
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -46.617092     -0.647158        -15.598818
# 1             PV_dw    -39.958131     -0.550093        -17.811381
# 2             PV_cw    -33.396877     -0.553420        -14.594215
# 3         LSTM_pred    -53.163836     -0.614775        -16.035561
# 4          GRU_pred    -60.940763     -0.702151        -15.867551
# 5     LSTM_GRU_pred    -88.547206     -1.030169        -14.886407
# 6       BiLSTM_pred    -85.900754     -0.976688        -15.402538
# 7   BiLSTM_GRU_pred    -89.256732     -0.921256        -16.035561
# 8         QRNN_pred    -48.407832     -0.719567        -14.917781
# 9          ESN_pred    -26.377969     -0.444840        -16.035561
# 10         BNN_pred     21.941868     -0.092389        -13.291966
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -74.413717     -0.787316        -17.198380
# 1             PV_dw    -37.926953     -0.494834        -17.637493
# 2             PV_cw    -62.148091     -0.723077        -14.979967
# 3         LSTM_pred    -53.163836     -0.614775        -16.035561
# 4          GRU_pred    -83.924987     -0.849616        -16.992534
# 5     LSTM_GRU_pred    -78.243051     -0.802172        -16.992534
# 6       BiLSTM_pred    -34.724051     -0.472834        -16.035561
# 7   BiLSTM_GRU_pred    -43.364815     -0.544811        -16.035561
# 8         QRNN_pred    -55.681754     -0.700880        -16.230372
# 9          ESN_pred    -32.375492     -0.480875        -16.035561
# 10         BNN_pred    -18.524173     -0.357634        -16.226543
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -19.183123     -0.358012        -15.916361
# 1             PV_dw    -33.052927     -0.459367        -17.220231
# 2             PV_cw    -46.608552     -0.566634        -16.035561
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -59.422693     -0.657253        -16.320926
# 5     LSTM_GRU_pred    -56.095563     -0.632038        -16.320926
# 6       BiLSTM_pred    -30.785433     -0.442862        -16.035561
# 7   BiLSTM_GRU_pred     -9.032427     -0.288448        -15.753327
# 8         QRNN_pred      8.270852     -0.178147        -15.643967
# 9          ESN_pred     -9.007524     -0.296494        -15.972775
# 10         BNN_pred    -11.726658     -0.306591        -15.547506
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -46.617092     -0.647158        -15.598818
# 1             PV_dw    -39.958131     -0.550093        -17.811381
# 2             PV_cw    -39.625565     -0.604780        -14.594215
# 3         LSTM_pred    -53.163836     -0.614775        -16.035561
# 4          GRU_pred    -41.117418     -0.523493        -15.965790
# 5     LSTM_GRU_pred    -35.201465     -0.483137        -14.985792
# 6       BiLSTM_pred    -34.690362     -0.477605        -15.402538
# 7   BiLSTM_GRU_pred    -53.163836     -0.614775        -16.035561
# 8         QRNN_pred    -40.226312     -0.633692        -14.917781
# 9          ESN_pred    -15.381009     -0.337827        -15.916361
# 10         BNN_pred     25.060412     -0.066659        -13.170092
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -74.413717     -0.787316        -17.198380
# 1             PV_dw    -19.183123     -0.358012        -15.916361
# 2             PV_cw    -68.191510     -0.770365        -15.527827
# 3         LSTM_pred    -53.163836     -0.614775        -16.035561
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -24.507927     -0.396035        -16.010201
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -53.163836     -0.614775        -16.035561
# 8         QRNN_pred    -65.848782     -0.776207        -16.230372
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -25.929351     -0.409310        -16.600561
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -19.183123     -0.358012        -15.916361
# 1             PV_dw    -19.183123     -0.358012        -15.916361
# 2             PV_cw    -52.752105     -0.611722        -16.035561
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred     -8.984781     -0.299634        -15.916361
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -47.494664     -0.596124        -17.812958
# 1             PV_dw    -47.680843     -0.588699        -18.972550
# 2             PV_cw    -30.632853     -0.462720        -16.035561
# 3         LSTM_pred      7.056532     -0.187256        -15.713550
# 4          GRU_pred    -48.124967     -0.613257        -15.297751
# 5     LSTM_GRU_pred    -54.750822     -0.656033        -16.582639
# 6       BiLSTM_pred    -58.567387     -0.731784        -16.360910
# 7   BiLSTM_GRU_pred      7.773038     -0.185603        -13.742303
# 8         QRNN_pred      2.839316     -0.211597        -15.481098
# 9          ESN_pred     14.720849     -0.127126        -13.145104
# 10         BNN_pred    -13.520463     -0.337084        -16.734989
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     -0.284917     -0.265099        -13.052525
# 1             PV_dw   -105.622959     -1.150750        -19.019269
# 2             PV_cw    -20.596246     -0.407267        -15.685142
# 3         LSTM_pred     13.595961     -0.153813        -13.050069
# 4          GRU_pred    -61.482352     -0.960653        -12.941076
# 5     LSTM_GRU_pred    -57.539147     -0.890716        -12.392345
# 6       BiLSTM_pred   -112.934478     -1.316359        -16.339859
# 7   BiLSTM_GRU_pred     -0.489333     -0.272204        -10.662336
# 8         QRNN_pred    -62.615638     -0.808642        -17.085411
# 9          ESN_pred     25.379833     -0.058382        -13.937626
# 10         BNN_pred     14.423271     -0.163165        -11.837714
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -20.962679     -1.206301         -4.804020
# 1             PV_dw     -0.807475     -0.404170         -8.940707
# 2             PV_cw   -129.304611     -2.270889        -16.128391
# 3         LSTM_pred     78.903632      0.328555         -8.584818
# 4          GRU_pred    -47.675287     -1.007132        -11.130726
# 5     LSTM_GRU_pred    -60.960188     -1.200001        -11.688635
# 6       BiLSTM_pred   -158.711942     -2.300129        -16.961589
# 7   BiLSTM_GRU_pred      2.780993     -0.373750         -5.461641
# 8         QRNN_pred    -36.840045     -1.431779         -5.500138
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred    124.358839      0.770920         -8.832633
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     20.235179     -0.206473         -5.451873
# 1             PV_dw    -31.298358     -0.584361        -14.414329
# 2             PV_cw    -66.203218     -0.976433        -14.356016
# 3         LSTM_pred     71.397718      0.271362         -9.670923
# 4          GRU_pred      0.148271     -0.319227        -12.084270
# 5     LSTM_GRU_pred    -48.775958     -0.904529        -11.704025
# 6       BiLSTM_pred    -82.193173     -1.109413        -15.752561
# 7   BiLSTM_GRU_pred    -14.288504     -0.440317         -8.983570
# 8         QRNN_pred    -10.095831     -0.619479         -7.663865
# 9          ESN_pred     40.416201      0.042366        -12.243861
# 10         BNN_pred     55.601775      0.154843        -13.599588
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -86.174993     -1.158332        -12.601072
# 1             PV_dw    -84.551447     -0.983216        -18.281413
# 2             PV_cw    -69.198845     -0.953457        -15.685142
# 3         LSTM_pred     15.774923     -0.146559        -12.271329
# 4          GRU_pred    -86.258728     -1.253622        -13.887028
# 5     LSTM_GRU_pred    -67.117271     -1.028201        -12.392345
# 6       BiLSTM_pred    -90.734997     -1.141847        -16.339859
# 7   BiLSTM_GRU_pred     40.942109      0.040815         -9.523287
# 8         QRNN_pred      4.029132     -0.256158        -12.916597
# 9          ESN_pred     60.824216      0.185474        -12.243861
# 10         BNN_pred      3.502343     -0.249614        -14.482203
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -20.962679     -1.206301         -4.804020
# 1             PV_dw    -44.136132     -0.689714        -17.043652
# 2             PV_cw   -134.915279     -2.350709        -16.128391
# 3         LSTM_pred    -26.894923     -0.449450        -15.336973
# 4          GRU_pred    -61.703470     -0.940370        -12.012360
# 5     LSTM_GRU_pred    -63.706218     -0.991626        -13.156926
# 6       BiLSTM_pred   -121.768068     -1.611700        -14.924360
# 7   BiLSTM_GRU_pred    -89.991291     -1.130154        -14.960142
# 8         QRNN_pred    -36.840045     -1.431779         -5.500138
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred    166.395644      1.029950         -8.004398
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     20.235179     -0.206473         -5.451873
# 1             PV_dw    -31.301814     -0.486793        -19.265837
# 2             PV_cw    -76.032052     -1.063656        -15.233286
# 3         LSTM_pred    -22.226868     -0.406843        -16.184157
# 4          GRU_pred    -19.496338     -0.417834        -13.466628
# 5     LSTM_GRU_pred    -77.547301     -1.023578        -15.944589
# 6       BiLSTM_pred    -28.962350     -0.527603        -14.703137
# 7   BiLSTM_GRU_pred    -70.894692     -0.829446        -15.203790
# 8         QRNN_pred    -10.095831     -0.619479         -7.663865
# 9          ESN_pred     66.066602      0.222988        -12.243861
# 10         BNN_pred     40.047356      0.037743        -16.177882
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV   -130.095303     -1.489221        -16.801644
# 1             PV_dw    -37.715245     -0.521886        -18.814336
# 2             PV_cw    -91.424873     -1.107244        -16.035561
# 3         LSTM_pred    -22.226868     -0.406843        -16.184157
# 4          GRU_pred    -97.734921     -1.016320        -17.032197
# 5     LSTM_GRU_pred    -52.088522     -0.652800        -16.582639
# 6       BiLSTM_pred    -66.368307     -0.798817        -16.360910
# 7   BiLSTM_GRU_pred      4.748888     -0.207774        -13.783665
# 8         QRNN_pred     27.848474     -0.040634        -13.119064
# 9          ESN_pred     53.416154      0.134553        -12.243861
# 10         BNN_pred    -26.198459     -0.436203        -17.642421
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -20.962679     -1.206301         -4.804020
# 1             PV_dw    -55.194345     -0.747049        -17.043652
# 2             PV_cw   -134.915279     -2.350709        -16.128391
# 3         LSTM_pred    -34.660685     -0.490657        -14.732060
# 4          GRU_pred    -19.284579     -0.369971        -13.446381
# 5     LSTM_GRU_pred    -19.438884     -0.374814        -15.291177
# 6       BiLSTM_pred    -65.226205     -0.730973        -18.075977
# 7   BiLSTM_GRU_pred   -121.322702     -1.237390        -17.711328
# 8         QRNN_pred    -36.840045     -1.431779         -5.500138
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred     57.478483      0.164023        -10.360646
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     20.235179     -0.206473         -5.451873
# 1             PV_dw    -43.277372     -0.539264        -18.095539
# 2             PV_cw    -76.032052     -1.063656        -15.233286
# 3         LSTM_pred    -53.163836     -0.614775        -16.035561
# 4          GRU_pred     -6.920415     -0.273698        -14.690724
# 5     LSTM_GRU_pred    -22.874843     -0.391592        -15.843334
# 6       BiLSTM_pred    -11.788565     -0.306832        -15.173647
# 7   BiLSTM_GRU_pred    -53.163836     -0.614775        -16.035561
# 8         QRNN_pred    -10.095831     -0.619479         -7.663865
# 9          ESN_pred     15.642658     -0.128327        -15.916361
# 10         BNN_pred    -18.620028     -0.363256        -15.856201
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -65.166744     -0.744618        -15.817172
# 1             PV_dw    -19.183123     -0.358012        -15.916361
# 2             PV_cw    -91.424873     -1.107244        -16.035561
# 3         LSTM_pred    -53.163836     -0.614775        -16.035561
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred      6.334261     -0.190012        -13.399534
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -25.505777     -0.406293        -16.557120
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -31.151128     -0.482508        -16.916156
# 1             PV_dw    -43.999474     -0.592926        -18.583515
# 2             PV_cw    -17.295640     -0.370365        -16.035561
# 3         LSTM_pred     44.948794      0.076358        -12.929615
# 4          GRU_pred    -41.185262     -0.560660        -15.297751
# 5     LSTM_GRU_pred   -101.230492     -1.160484        -15.448263
# 6       BiLSTM_pred    -29.645157     -0.466927        -17.389938
# 7   BiLSTM_GRU_pred     37.006759      0.019853        -14.669031
# 8         QRNN_pred     -5.735289     -0.296086        -12.782791
# 9          ESN_pred     27.521223     -0.043268        -13.937626
# 10         BNN_pred     15.859636     -0.135024        -14.445885
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -20.775367     -0.431586        -14.384824
# 1             PV_dw    -76.685505     -0.883461        -16.663495
# 2             PV_cw    -63.511440     -0.804449        -15.227678
# 3         LSTM_pred     36.160203      0.003944         -9.496712
# 4          GRU_pred    -61.482352     -0.960653        -12.941076
# 5     LSTM_GRU_pred   -118.620048     -1.633858        -14.480610
# 6       BiLSTM_pred   -116.774203     -1.555866        -15.927163
# 7   BiLSTM_GRU_pred    -88.554076     -1.040975        -15.060858
# 8         QRNN_pred    -54.688806     -0.748249        -16.384258
# 9          ESN_pred     36.677466      0.012908        -11.410238
# 10         BNN_pred      2.148698     -0.268390        -10.542282
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -41.727580     -1.834624         -5.979675
# 1             PV_dw      5.262454     -0.358105         -6.570439
# 2             PV_cw   -130.333479     -2.397147        -15.025873
# 3         LSTM_pred     63.113638      0.222443         -5.300846
# 4          GRU_pred    -71.280402     -1.490622        -11.664602
# 5     LSTM_GRU_pred    -69.697771     -1.570805         -9.810117
# 6       BiLSTM_pred   -134.599996     -2.339349        -14.771332
# 7   BiLSTM_GRU_pred    -40.074639     -1.319209         -6.069760
# 8         QRNN_pred    -51.217406     -1.836417         -6.910764
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred     87.438246      0.473149         -9.017862
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     10.427525     -0.331232         -5.593556
# 1             PV_dw    -42.961201     -0.737035        -11.644802
# 2             PV_cw    -74.631267     -1.263683        -11.402158
# 3         LSTM_pred     87.478731      0.411644         -6.231172
# 4          GRU_pred      0.148271     -0.319227        -12.084270
# 5     LSTM_GRU_pred   -111.735305     -1.861676        -14.482676
# 6       BiLSTM_pred   -108.473136     -1.630089        -15.306958
# 7   BiLSTM_GRU_pred      7.148100     -0.314314         -8.534650
# 8         QRNN_pred     -1.865806     -0.561514         -6.849705
# 9          ESN_pred     61.391407      0.197216         -8.183186
# 10         BNN_pred     68.123119      0.265223         -9.550577
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -55.034798     -1.008684        -11.145347
# 1             PV_dw    -50.311500     -0.698911        -16.892735
# 2             PV_cw   -118.671973     -1.608577        -15.227678
# 3         LSTM_pred     87.478731      0.411644         -6.231172
# 4          GRU_pred      1.585889     -0.306469        -12.157264
# 5     LSTM_GRU_pred    -45.863648     -0.754367        -15.100870
# 6       BiLSTM_pred   -112.486418     -1.589040        -15.600436
# 7   BiLSTM_GRU_pred    -15.472133     -0.446397        -11.986249
# 8         QRNN_pred     73.569454      0.322314         -5.785848
# 9          ESN_pred     36.416878      0.006010        -10.520025
# 10         BNN_pred     14.719886     -0.188929        -12.777898
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -41.727580     -1.834624         -5.979675
# 1             PV_dw     70.866647      0.302104         -7.344760
# 2             PV_cw   -145.835105     -2.571384        -16.460006
# 3         LSTM_pred     -6.340925     -0.327255        -12.668963
# 4          GRU_pred    -89.901765     -1.335417        -13.025198
# 5     LSTM_GRU_pred    -44.665584     -0.936556         -7.517588
# 6       BiLSTM_pred   -135.761712     -1.932701        -14.885744
# 7   BiLSTM_GRU_pred    -40.333851     -1.276077         -6.405995
# 8         QRNN_pred    -51.217406     -1.836417         -6.910764
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred    156.086504      0.999907         -8.643653
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     10.427525     -0.331232         -5.593556
# 1             PV_dw      5.612561     -0.258722        -12.334009
# 2             PV_cw    -89.775396     -1.292413        -12.897449
# 3         LSTM_pred     26.535454     -0.059743        -13.161538
# 4          GRU_pred    -14.584376     -0.380217        -13.466628
# 5     LSTM_GRU_pred   -104.262229     -1.402763        -12.966226
# 6       BiLSTM_pred    -81.033506     -1.059479        -16.819328
# 7   BiLSTM_GRU_pred    -67.021479     -0.828030        -15.901935
# 8         QRNN_pred     -1.865806     -0.561514         -6.849705
# 9          ESN_pred     20.242928     -0.112112        -11.874515
# 10         BNN_pred    132.198800      0.731859        -10.154726
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -74.348183     -1.074856        -13.683374
# 1             PV_dw    -16.999973     -0.399735        -17.265595
# 2             PV_cw    -77.594864     -0.997568        -16.035561
# 3         LSTM_pred     26.535454     -0.059743        -13.161538
# 4          GRU_pred    -24.543603     -0.456147        -14.535156
# 5     LSTM_GRU_pred    -48.366580     -0.662177        -15.491828
# 6       BiLSTM_pred    -85.802907     -1.044099        -16.646180
# 7   BiLSTM_GRU_pred    -28.634170     -0.484305        -15.118477
# 8         QRNN_pred    106.426255      0.558826         -4.592885
# 9          ESN_pred     68.089158      0.236636        -12.243861
# 10         BNN_pred     47.760084      0.093101        -15.919167
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -41.727580     -1.834624         -5.979675
# 1             PV_dw    -18.770518     -0.451176        -13.736404
# 2             PV_cw   -150.520551     -2.640137        -16.653832
# 3         LSTM_pred    -83.564657     -0.892616        -14.732060
# 4          GRU_pred    -56.785334     -0.659322        -16.668866
# 5     LSTM_GRU_pred     20.035751     -0.107864         -9.462320
# 6       BiLSTM_pred    -16.585896     -0.373173        -14.865188
# 7   BiLSTM_GRU_pred    -10.567113     -0.459002         -7.217827
# 8         QRNN_pred    -51.217406     -1.836417         -6.910764
# 9          ESN_pred     81.218725      0.417238         -4.440325
# 10         BNN_pred     40.147726      0.038260        -10.400896
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     10.427525     -0.331232         -5.593556
# 1             PV_dw    -78.839425     -0.831656        -18.095539
# 2             PV_cw    -94.768353     -1.345354        -12.897449
# 3         LSTM_pred    -53.163836     -0.614775        -16.035561
# 4          GRU_pred     -6.920415     -0.273698        -14.690724
# 5     LSTM_GRU_pred     -8.381006     -0.293981        -14.386451
# 6       BiLSTM_pred    -29.672685     -0.437947        -16.933538
# 7   BiLSTM_GRU_pred    -53.163836     -0.614775        -16.035561
# 8         QRNN_pred     -1.865806     -0.561514         -6.849705
# 9          ESN_pred     20.242928     -0.112112        -11.874515
# 10         BNN_pred      4.212960     -0.204993        -15.173647
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -74.348183     -1.074856        -13.683374
# 1             PV_dw    -19.183123     -0.358012        -15.916361
# 2             PV_cw    -99.273012     -1.184227        -16.035561
# 3         LSTM_pred    -53.163836     -0.614775        -16.035561
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -24.507927     -0.396035        -16.010201
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -53.163836     -0.614775        -16.035561
# 8         QRNN_pred    112.882049      0.560535         -4.560787
# 9          ESN_pred      3.657832     -0.207115        -15.916361
# 10         BNN_pred    -18.620028     -0.363256        -15.856201
# 11               __    -19.183123     -0.358012        -15.916361

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -15.401678     -0.331643        -15.916361
# 1             PV_dw    -46.156601     -0.563282        -18.187175
# 2             PV_cw    -12.241290     -0.309650        -15.916361
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -48.570184     -0.574796        -16.320926
# 6       BiLSTM_pred    -30.700319     -0.441563        -16.035561
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred    -10.339739     -0.296975        -15.774136
# 9          ESN_pred     17.088335     -0.110982        -14.965803
# 10         BNN_pred    -15.912362     -0.336138        -15.966497
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -25.275730     -0.402372        -16.035561
# 1             PV_dw    -43.764529     -0.560800        -19.354676
# 2             PV_cw      5.132901     -0.197788        -13.991512
# 3         LSTM_pred     91.038566      0.414566        -10.259727
# 4          GRU_pred    -38.251024     -0.526916        -16.532926
# 5     LSTM_GRU_pred    -33.981658     -0.494188        -16.320926
# 6       BiLSTM_pred     84.907572      0.353925         -9.839228
# 7   BiLSTM_GRU_pred    -22.859673     -0.391525        -17.014683
# 8         QRNN_pred    -33.500822     -0.487030        -17.251467
# 9          ESN_pred     45.188851      0.075654        -10.747997
# 10         BNN_pred    -61.020502     -0.697010        -16.565170
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -59.394668     -0.702669        -15.965790
# 1             PV_dw    -45.798634     -0.604608        -18.315540
# 2             PV_cw    -16.982535     -0.415164        -12.603605
# 3         LSTM_pred    -49.117408     -0.927501        -11.662443
# 4          GRU_pred    -14.644258     -0.375516        -12.777708
# 5     LSTM_GRU_pred    -38.703565     -0.578095        -14.886407
# 6       BiLSTM_pred    171.643618      1.039286         -4.368071
# 7   BiLSTM_GRU_pred     49.366827      0.105827        -12.633702
# 8         QRNN_pred    -59.604789     -0.741811        -17.860957
# 9          ESN_pred     12.572955     -0.380361         -4.166183
# 10         BNN_pred   -121.638427     -1.300816        -17.339636
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -39.988111     -0.511680        -17.054487
# 1             PV_dw    -44.796314     -0.571663        -19.441693
# 2             PV_cw    -20.721348     -0.402960        -13.819093
# 3         LSTM_pred     99.264105      0.475011         -9.555603
# 4          GRU_pred    -14.896426     -0.356966        -14.270753
# 5     LSTM_GRU_pred    -79.855381     -0.864892        -16.320926
# 6       BiLSTM_pred     95.698170      0.435031         -7.649068
# 7   BiLSTM_GRU_pred    -20.221511     -0.373669        -16.607628
# 8         QRNN_pred    -52.985956     -0.659655        -16.260662
# 9          ESN_pred     99.174499      0.518358         -6.518963
# 10         BNN_pred    -89.891639     -0.949788        -17.139049
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -25.275730     -0.402372        -16.035561
# 1             PV_dw    -35.699533     -0.501649        -18.674504
# 2             PV_cw      7.807622     -0.179120        -13.594821
# 3         LSTM_pred     91.038566      0.414566        -10.259727
# 4          GRU_pred    -38.251024     -0.526916        -16.532926
# 5     LSTM_GRU_pred    -33.981658     -0.494188        -16.320926
# 6       BiLSTM_pred     84.907572      0.353925         -9.839228
# 7   BiLSTM_GRU_pred    -24.227604     -0.401358        -17.014683
# 8         QRNN_pred    -33.500822     -0.487030        -17.251467
# 9          ESN_pred     66.218146      0.227186        -10.747997
# 10         BNN_pred    -61.020502     -0.697010        -16.565170
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -50.702773     -0.632718        -15.965790
# 1             PV_dw    -43.335728     -0.555193        -17.370508
# 2             PV_cw    -39.584878     -0.567230        -14.612838
# 3         LSTM_pred    -34.474438     -0.484603        -16.738028
# 4          GRU_pred      1.992169     -0.231173        -13.442550
# 5     LSTM_GRU_pred    -44.849243     -0.581199        -14.886407
# 6       BiLSTM_pred     -7.897024     -0.301044        -13.416015
# 7   BiLSTM_GRU_pred     21.554508     -0.089194        -13.229595
# 8         QRNN_pred    -68.518106     -0.796852        -17.510336
# 9          ESN_pred     82.369978      0.396068         -4.460570
# 10         BNN_pred    -24.680719     -0.425899        -14.669280
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -31.116884     -0.446364        -17.054487
# 1             PV_dw    -38.111780     -0.505404        -17.497157
# 2             PV_cw    -39.946801     -0.525842        -14.985792
# 3         LSTM_pred    -11.788565     -0.306832        -15.173647
# 4          GRU_pred    -13.546826     -0.326288        -15.349239
# 5     LSTM_GRU_pred    -68.662150     -0.727244        -16.320926
# 6       BiLSTM_pred    -25.391224     -0.411459        -16.035561
# 7   BiLSTM_GRU_pred    -30.225902     -0.441962        -16.864513
# 8         QRNN_pred    -61.962008     -0.714855        -16.035561
# 9          ESN_pred    181.322246      1.082000         -4.440325
# 10         BNN_pred    -22.681087     -0.387411        -16.648423
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -15.401678     -0.331643        -15.916361
# 1             PV_dw    -38.111780     -0.505404        -17.497157
# 2             PV_cw    -12.200635     -0.309411        -15.916361
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -48.570184     -0.574796        -16.320926
# 6       BiLSTM_pred    -30.700319     -0.441563        -16.035561
# 7   BiLSTM_GRU_pred    -20.556200     -0.367701        -15.916361
# 8         QRNN_pred    -10.339739     -0.296975        -15.774136
# 9          ESN_pred     24.243414     -0.063313        -14.965803
# 10         BNN_pred    -15.912362     -0.336138        -15.966497
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -50.702773     -0.632718        -15.965790
# 1             PV_dw    -25.487855     -0.403009        -15.927305
# 2             PV_cw    -44.853151     -0.608636        -14.612838
# 3         LSTM_pred    -34.474438     -0.484603        -16.738028
# 4          GRU_pred      1.992169     -0.231173        -13.442550
# 5     LSTM_GRU_pred    -35.201465     -0.483137        -14.985792
# 6       BiLSTM_pred      3.891120     -0.213881        -13.258478
# 7   BiLSTM_GRU_pred     21.554508     -0.089194        -13.229595
# 8         QRNN_pred    -60.509489     -0.719374        -17.510336
# 9          ESN_pred     33.902558     -0.029540         -4.909184
# 10         BNN_pred    -31.571524     -0.475706        -14.561053
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -18.756615     -0.355015        -15.916361
# 1             PV_dw    -19.183123     -0.358012        -15.916361
# 2             PV_cw    -45.213088     -0.564660        -14.985792
# 3         LSTM_pred    -11.788565     -0.306832        -15.173647
# 4          GRU_pred    -13.546826     -0.326288        -15.349239
# 5     LSTM_GRU_pred    -24.931935     -0.399035        -16.010201
# 6       BiLSTM_pred    -13.810945     -0.326814        -15.916361
# 7   BiLSTM_GRU_pred    -30.225902     -0.441962        -16.864513
# 8         QRNN_pred    -69.982313     -0.772094        -16.035561
# 9          ESN_pred      0.566593     -0.222230        -13.957181
# 10         BNN_pred    -25.929351     -0.409310        -16.600561
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -19.183123     -0.358012        -15.916361
# 1             PV_dw    -19.183123     -0.358012        -15.916361
# 2             PV_cw    -17.619121     -0.347154        -15.916361
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -20.556200     -0.367701        -15.916361
# 8         QRNN_pred    -19.183123     -0.358012        -15.916361
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -19.183123     -0.358012        -15.916361
# 1             PV_dw    -19.642325     -0.366645        -17.047889
# 2             PV_cw    -24.866458     -0.405535        -15.501378
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -47.020882     -0.563502        -16.320926
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred     -2.105064     -0.240359        -15.643967
# 9          ESN_pred     35.516325      0.013432        -14.445255
# 10         BNN_pred    -10.741621     -0.301843        -15.374428
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -23.486112     -0.390956        -15.986496
# 1             PV_dw    -65.208727     -0.730783        -20.814152
# 2             PV_cw    -58.223607     -0.670979        -16.815361
# 3         LSTM_pred     41.303412      0.043724        -12.026156
# 4          GRU_pred    -30.305515     -0.455092        -16.035561
# 5     LSTM_GRU_pred     -5.843293     -0.291081        -16.098501
# 6       BiLSTM_pred     65.976840      0.221601        -10.638323
# 7   BiLSTM_GRU_pred     -9.660661     -0.304888        -16.342784
# 8         QRNN_pred    -56.192717     -0.650136        -18.217590
# 9          ESN_pred     -2.715674     -0.289178        -14.434207
# 10         BNN_pred    -51.330196     -0.626139        -16.565170
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -46.617092     -0.647158        -15.598818
# 1             PV_dw    -26.344413     -0.455974        -18.493148
# 2             PV_cw    -39.433498     -0.595279        -13.368470
# 3         LSTM_pred    -50.098052     -0.934939        -10.883045
# 4          GRU_pred    -37.303766     -0.535281        -16.134122
# 5     LSTM_GRU_pred    -46.698283     -0.788631        -13.195138
# 6       BiLSTM_pred    159.916680      0.910960         -5.072506
# 7   BiLSTM_GRU_pred    -10.309704     -0.331647        -14.167823
# 8         QRNN_pred    -75.891587     -0.906998        -17.137873
# 9          ESN_pred     -2.699711     -0.715162         -4.177000
# 10         BNN_pred    -77.795263     -0.919892        -16.643091
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -74.413717     -0.787316        -17.198380
# 1             PV_dw    -50.698849     -0.628208        -19.585025
# 2             PV_cw    -70.248281     -0.802503        -15.714282
# 3         LSTM_pred     47.685243      0.092228        -11.296459
# 4          GRU_pred    -30.305515     -0.455092        -16.035561
# 5     LSTM_GRU_pred    -36.266412     -0.529922        -16.771894
# 6       BiLSTM_pred     73.901443      0.279449         -8.442480
# 7   BiLSTM_GRU_pred     -9.270453     -0.302127        -16.268582
# 8         QRNN_pred    -70.157384     -0.786293        -17.165423
# 9          ESN_pred     68.476223      0.279978         -4.908195
# 10         BNN_pred    -74.258504     -0.828461        -16.918798
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -23.486112     -0.390956        -15.986496
# 1             PV_dw    -57.324594     -0.671445        -20.146290
# 2             PV_cw    -66.450174     -0.756344        -15.585690
# 3         LSTM_pred     41.303412      0.043724        -12.026156
# 4          GRU_pred    -30.305515     -0.455092        -16.035561
# 5     LSTM_GRU_pred     -9.797896     -0.321175        -16.098501
# 6       BiLSTM_pred     65.976840      0.221601        -10.638323
# 7   BiLSTM_GRU_pred     -9.660661     -0.304888        -16.342784
# 8         QRNN_pred    -56.192717     -0.650136        -18.217590
# 9          ESN_pred     71.892496      0.276097         -9.520506
# 10         BNN_pred    -51.330196     -0.626139        -16.565170
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -46.617092     -0.647158        -15.598818
# 1             PV_dw    -10.983869     -0.313718        -16.340172
# 2             PV_cw    -32.570294     -0.537738        -12.758400
# 3         LSTM_pred    -23.938888     -0.409157        -15.765770
# 4          GRU_pred    -14.890323     -0.349036        -15.969312
# 5     LSTM_GRU_pred    -88.547206     -1.030169        -14.886407
# 6       BiLSTM_pred     -1.844812     -0.248404        -13.816620
# 7   BiLSTM_GRU_pred    -10.139029     -0.307612        -14.671762
# 8         QRNN_pred    -75.077255     -0.899944        -17.064854
# 9          ESN_pred    -11.310326     -0.782059         -5.004328
# 10         BNN_pred    -30.858081     -0.472838        -15.175165
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -74.413717     -0.787316        -17.198380
# 1             PV_dw    -19.642325     -0.366645        -17.047889
# 2             PV_cw    -63.605246     -0.747646        -15.112064
# 3         LSTM_pred    -13.171995     -0.316531        -15.173647
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -78.243051     -0.802172        -16.992534
# 6       BiLSTM_pred    -15.381009     -0.337827        -15.916361
# 7   BiLSTM_GRU_pred     -5.336860     -0.262782        -14.690724
# 8         QRNN_pred    -69.338000     -0.779761        -17.092429
# 9          ESN_pred    157.096792      0.937199         -4.951461
# 10         BNN_pred    -10.877859     -0.306092        -15.728212
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -19.183123     -0.358012        -15.916361
# 1             PV_dw    -19.642325     -0.366645        -17.047889
# 2             PV_cw    -37.115513     -0.504292        -15.138503
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -56.095563     -0.632038        -16.320926
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred     -2.105064     -0.240359        -15.643967
# 9          ESN_pred     68.896364      0.240046        -12.132442
# 10         BNN_pred    -10.741621     -0.301843        -15.374428
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -46.617092     -0.647158        -15.598818
# 1             PV_dw    -43.430298     -0.540132        -17.510336
# 2             PV_cw    -58.628973     -0.731914        -15.233286
# 3         LSTM_pred    -23.938888     -0.409157        -15.765770
# 4          GRU_pred    -14.890323     -0.349036        -15.969312
# 5     LSTM_GRU_pred    -35.201465     -0.483137        -14.985792
# 6       BiLSTM_pred     -1.844812     -0.248404        -13.816620
# 7   BiLSTM_GRU_pred    -10.139029     -0.307612        -14.671762
# 8         QRNN_pred    -67.125032     -0.816327        -17.064854
# 9          ESN_pred    -55.582838     -1.314381         -6.462878
# 10         BNN_pred    -31.571524     -0.475706        -14.561053
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -74.413717     -0.787316        -17.198380
# 1             PV_dw    -19.183123     -0.358012        -15.916361
# 2             PV_cw    -68.191510     -0.770365        -15.527827
# 3         LSTM_pred    -13.171995     -0.316531        -15.173647
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -24.507927     -0.396035        -16.010201
# 6       BiLSTM_pred    -15.381009     -0.337827        -15.916361
# 7   BiLSTM_GRU_pred     -5.336860     -0.262782        -14.690724
# 8         QRNN_pred    -79.357998     -0.852134        -17.092429
# 9          ESN_pred     82.433107      0.351295         -6.040277
# 10         BNN_pred    -25.929351     -0.409310        -16.600561
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -19.183123     -0.358012        -15.916361
# 1             PV_dw    -19.183123     -0.358012        -15.916361
# 2             PV_cw    -52.752105     -0.611722        -16.035561
# 3         LSTM_pred    -19.183123     -0.358012        -15.916361
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 8         QRNN_pred    -19.183123     -0.358012        -15.916361
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -19.183123     -0.358012        -15.916361
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -47.494664     -0.596124        -17.812958
# 1             PV_dw    -42.110133     -0.564036        -18.443052
# 2             PV_cw    -30.632853     -0.462720        -16.035561
# 3         LSTM_pred     66.331482      0.227981        -11.585714
# 4          GRU_pred     56.095811      0.156527         -9.523670
# 5     LSTM_GRU_pred    -54.750822     -0.656033        -16.582639
# 6       BiLSTM_pred     39.823263      0.037724        -11.810607
# 7   BiLSTM_GRU_pred    -50.596262     -0.601621        -16.060869
# 8         QRNN_pred      2.839316     -0.211597        -15.481098
# 9          ESN_pred    -47.764599     -0.662236        -16.035561
# 10         BNN_pred    -43.193969     -0.560864        -16.827811
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     -0.284917     -0.265099        -13.052525
# 1             PV_dw    -74.489879     -0.848083        -21.315928
# 2             PV_cw     21.554695     -0.091449        -13.606516
# 3         LSTM_pred    -10.585654     -0.391719        -12.812843
# 4          GRU_pred    -21.256250     -0.459670        -12.787216
# 5     LSTM_GRU_pred    -57.539147     -0.890716        -12.392345
# 6       BiLSTM_pred     50.579365      0.114156         -8.951205
# 7   BiLSTM_GRU_pred     23.434015     -0.082474        -15.521917
# 8         QRNN_pred    -62.615638     -0.808642        -17.085411
# 9          ESN_pred    -38.273393     -0.572508        -16.035561
# 10         BNN_pred   -124.491910     -1.479728        -17.776280
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -20.962679     -1.206301         -4.804020
# 1             PV_dw   -101.818613     -1.440093        -18.817998
# 2             PV_cw   -101.449833     -1.538609        -12.531885
# 3         LSTM_pred    -63.984786     -1.631810         -8.840791
# 4          GRU_pred     31.990585     -0.044719         -9.519579
# 5     LSTM_GRU_pred    -60.960188     -1.200001        -11.688635
# 6       BiLSTM_pred     82.182484      0.437952         -4.474907
# 7   BiLSTM_GRU_pred    -23.066389     -0.563348        -14.806254
# 8         QRNN_pred    -20.513051     -1.037174         -5.202919
# 9          ESN_pred    -57.284117     -1.846948         -5.929078
# 10         BNN_pred    -44.533617     -1.005650        -11.556369
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     20.235179     -0.206473         -5.451873
# 1             PV_dw    -83.502781     -0.989004        -19.613654
# 2             PV_cw    -40.438770     -0.710713        -13.360593
# 3         LSTM_pred    -84.828260     -1.347532        -12.167950
# 4          GRU_pred     38.075001      0.007797         -9.463783
# 5     LSTM_GRU_pred    -48.775958     -0.904529        -11.704025
# 6       BiLSTM_pred    149.498597      0.887365         -5.094537
# 7   BiLSTM_GRU_pred    -35.277105     -0.651062        -14.107981
# 8         QRNN_pred    -10.095831     -0.619479         -7.663865
# 9          ESN_pred   -135.811874     -2.022840        -16.035561
# 10         BNN_pred    -72.122331     -1.129555        -15.740804
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -86.174993     -1.158332        -12.601072
# 1             PV_dw    -62.731073     -0.767821        -20.947054
# 2             PV_cw    -26.131036     -0.544485        -13.890647
# 3         LSTM_pred     30.674603     -0.047093         -9.378621
# 4          GRU_pred    -21.256250     -0.459670        -12.787216
# 5     LSTM_GRU_pred    -67.117271     -1.028201        -12.392345
# 6       BiLSTM_pred     71.814702      0.273946         -8.528140
# 7   BiLSTM_GRU_pred     13.647396     -0.155716        -16.391537
# 8         QRNN_pred      4.029132     -0.256158        -12.916597
# 9          ESN_pred    -49.444024     -0.776297        -16.035561
# 10         BNN_pred   -128.574148     -1.487320        -19.294592
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -20.962679     -1.206301         -4.804020
# 1             PV_dw   -109.542780     -1.381564        -18.763777
# 2             PV_cw   -129.930666     -1.816677        -14.873726
# 3         LSTM_pred     59.712547      0.195599         -4.460133
# 4          GRU_pred     23.786849     -0.098206        -10.987991
# 5     LSTM_GRU_pred    -63.706218     -0.991626        -13.156926
# 6       BiLSTM_pred     49.953909      0.109379         -9.088819
# 7   BiLSTM_GRU_pred     -2.681386     -0.294716        -14.560498
# 8         QRNN_pred    -20.513051     -1.037174         -5.202919
# 9          ESN_pred    -57.284117     -1.846948         -5.929078
# 10         BNN_pred    -25.622542     -0.575357        -14.907334
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     20.235179     -0.206473         -5.451873
# 1             PV_dw    -62.712000     -0.754542        -18.405991
# 2             PV_cw    -50.228858     -0.776584        -14.192599
# 3         LSTM_pred     37.063748      0.009724        -11.321232
# 4          GRU_pred     39.978365      0.031071        -10.816918
# 5     LSTM_GRU_pred    -77.547301     -1.023578        -15.944589
# 6       BiLSTM_pred    114.654507      0.585557         -9.343516
# 7   BiLSTM_GRU_pred     -0.385396     -0.263458        -14.497255
# 8         QRNN_pred    -10.095831     -0.619479         -7.663865
# 9          ESN_pred    -92.859886     -1.236901        -16.035561
# 10         BNN_pred    -20.567136     -0.477555        -16.274232
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV   -130.095303     -1.489221        -16.801644
# 1             PV_dw    -29.939936     -0.481281        -18.060710
# 2             PV_cw    -91.424873     -1.107244        -16.035561
# 3         LSTM_pred     72.866703      0.274881        -10.865276
# 4          GRU_pred     56.095811      0.156527         -9.523670
# 5     LSTM_GRU_pred    -52.088522     -0.652800        -16.582639
# 6       BiLSTM_pred     39.823263      0.037724        -11.810607
# 7   BiLSTM_GRU_pred    -64.715272     -0.712652        -17.193242
# 8         QRNN_pred     27.848474     -0.040634        -13.119064
# 9          ESN_pred    -33.944815     -0.592137        -16.035561
# 10         BNN_pred    -81.310093     -0.881258        -17.800047
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -20.962679     -1.206301         -4.804020
# 1             PV_dw    -53.918340     -0.625343        -18.623154
# 2             PV_cw   -129.930666     -1.816677        -14.873726
# 3         LSTM_pred     54.660905      0.144827         -8.555727
# 4          GRU_pred    -30.551980     -0.451915        -16.613306
# 5     LSTM_GRU_pred    -19.438884     -0.374814        -15.291177
# 6       BiLSTM_pred    -37.528219     -0.631501        -13.319575
# 7   BiLSTM_GRU_pred    -10.087937     -0.329337        -14.602839
# 8         QRNN_pred    -20.513051     -1.037174         -5.202919
# 9          ESN_pred    -57.284117     -1.846948         -5.929078
# 10         BNN_pred    -48.704239     -0.619088        -16.072575
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     20.235179     -0.206473         -5.451873
# 1             PV_dw    -25.487855     -0.403009        -15.927305
# 2             PV_cw    -50.228858     -0.776584        -14.192599
# 3         LSTM_pred    -29.023659     -0.440455        -16.758755
# 4          GRU_pred    -24.410278     -0.404208        -16.604061
# 5     LSTM_GRU_pred    -22.874843     -0.391592        -15.843334
# 6       BiLSTM_pred     -1.408743     -0.243443        -13.810586
# 7   BiLSTM_GRU_pred     12.111382     -0.156173        -14.130604
# 8         QRNN_pred    -10.095831     -0.619479         -7.663865
# 9          ESN_pred    -92.859886     -1.236901        -16.035561
# 10         BNN_pred    -41.363506     -0.538041        -15.984639
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -65.166744     -0.744618        -15.817172
# 1             PV_dw    -24.931935     -0.399035        -16.010201
# 2             PV_cw    -91.424873     -1.107244        -16.035561
# 3         LSTM_pred    -13.171995     -0.316531        -15.173647
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -19.183123     -0.358012        -15.916361
# 6       BiLSTM_pred    -19.183123     -0.358012        -15.916361
# 7   BiLSTM_GRU_pred    -33.769292     -0.464625        -17.165596
# 8         QRNN_pred      6.334261     -0.190012        -13.399534
# 9          ESN_pred    -19.183123     -0.358012        -15.916361
# 10         BNN_pred    -33.218097     -0.460628        -17.234371
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -31.151128     -0.482508        -16.916156
# 1             PV_dw    -56.451501     -0.680739        -17.243302
# 2             PV_cw    -37.619284     -0.516084        -16.035561
# 3         LSTM_pred     50.249103      0.111619        -10.753024
# 4          GRU_pred     56.095811      0.156527         -9.523670
# 5     LSTM_GRU_pred   -101.230492     -1.160484        -15.448263
# 6       BiLSTM_pred     73.601363      0.280748         -9.663178
# 7   BiLSTM_GRU_pred     -7.410325     -0.300896        -14.782948
# 8         QRNN_pred     -5.735289     -0.296086        -12.782791
# 9          ESN_pred    -44.391980     -0.597957        -16.035561
# 10         BNN_pred    -74.482100     -0.839660        -16.822338
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -20.775367     -0.431586        -14.384824
# 1             PV_dw    -33.114566     -0.599441        -17.610605
# 2             PV_cw    -24.958649     -0.448330        -15.031886
# 3         LSTM_pred    -13.711998     -0.435640        -11.112495
# 4          GRU_pred    -27.169433     -0.610683        -11.498583
# 5     LSTM_GRU_pred   -118.620048     -1.633858        -14.480610
# 6       BiLSTM_pred     19.729727     -0.126646        -10.322117
# 7   BiLSTM_GRU_pred    -24.126663     -0.455688        -14.071680
# 8         QRNN_pred    -66.554089     -0.846217        -17.433779
# 9          ESN_pred    -71.315859     -0.940029        -13.254700
# 10         BNN_pred   -132.654988     -1.566376        -17.776280
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -41.727580     -1.834624         -5.979675
# 1             PV_dw    -42.069125     -1.120962         -9.024499
# 2             PV_cw    -93.985720     -1.727489        -11.976723
# 3         LSTM_pred    -44.536773     -1.488774         -6.102010
# 4          GRU_pred     -4.666809     -0.690584         -5.341521
# 5     LSTM_GRU_pred    -69.697771     -1.570805         -9.810117
# 6       BiLSTM_pred     55.889764      0.178346         -4.985438
# 7   BiLSTM_GRU_pred     51.274874      0.140137         -4.278512
# 8         QRNN_pred    -16.333756     -0.968038         -5.180814
# 9          ESN_pred    -57.284117     -1.846948         -5.929078
# 10         BNN_pred    -35.139331     -0.921201         -9.846200
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     10.427525     -0.331232         -5.593556
# 1             PV_dw    -25.164401     -0.663576        -12.731053
# 2             PV_cw    -55.802772     -0.904806        -12.340740
# 3         LSTM_pred    -98.081784     -1.641808        -11.971625
# 4          GRU_pred     -3.574508     -0.445739         -9.928239
# 5     LSTM_GRU_pred   -111.735305     -1.861676        -14.482676
# 6       BiLSTM_pred    100.154035      0.533453         -6.539672
# 7   BiLSTM_GRU_pred    -26.144341     -0.594198        -12.335184
# 8         QRNN_pred    -14.394107     -0.719842         -8.094479
# 9          ESN_pred    -75.914059     -1.550458         -7.791090
# 10         BNN_pred    -69.054620     -1.131822        -13.464112
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -55.034798     -1.008684        -11.145347
# 1             PV_dw    -80.307127     -1.107448        -16.331752
# 2             PV_cw    -86.106517     -1.140685        -15.031886
# 3         LSTM_pred     -4.552168     -0.358168         -8.667740
# 4          GRU_pred    -27.169433     -0.610683        -11.498583
# 5     LSTM_GRU_pred    -45.863648     -0.754367        -15.100870
# 6       BiLSTM_pred     48.976903      0.101446         -9.673443
# 7   BiLSTM_GRU_pred    -32.353310     -0.532493        -15.377302
# 8         QRNN_pred     60.094310      0.200656         -6.946131
# 9          ESN_pred   -118.418201     -1.868258        -13.254700
# 10         BNN_pred   -130.970373     -1.566921        -16.777345
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -41.727580     -1.834624         -5.979675
# 1             PV_dw    -82.878984     -1.226843        -15.641516
# 2             PV_cw   -117.117853     -1.927793        -14.473784
# 3         LSTM_pred    -17.636617     -0.856530         -5.089369
# 4          GRU_pred      9.608455     -0.284814         -7.433682
# 5     LSTM_GRU_pred    -44.665584     -0.936556         -7.517588
# 6       BiLSTM_pred    122.709075      0.792262         -4.345820
# 7   BiLSTM_GRU_pred     94.776371      0.487741         -5.972069
# 8         QRNN_pred    -16.333756     -0.968038         -5.180814
# 9          ESN_pred    -57.284117     -1.846948         -5.929078
# 10         BNN_pred     26.049184     -0.118684         -9.235164
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     10.427525     -0.331232         -5.593556
# 1             PV_dw    -43.979645     -0.724336        -16.678625
# 2             PV_cw    -74.698664     -1.050486        -15.233286
# 3         LSTM_pred    -70.947666     -1.197648        -11.383856
# 4          GRU_pred     23.786849     -0.098206        -10.987991
# 5     LSTM_GRU_pred   -104.262229     -1.402763        -12.966226
# 6       BiLSTM_pred    126.045934      0.707037         -5.802655
# 7   BiLSTM_GRU_pred     22.056309     -0.100269        -14.075439
# 8         QRNN_pred    -14.394107     -0.719842         -8.094479
# 9          ESN_pred   -133.620026     -2.115944        -13.549217
# 10         BNN_pred    -13.075286     -0.436486        -13.176740
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -74.348183     -1.074856        -13.683374
# 1             PV_dw    -28.605556     -0.485899        -16.326035
# 2             PV_cw    -97.973163     -1.172109        -16.035561
# 3         LSTM_pred     41.565143      0.043935        -10.034987
# 4          GRU_pred     56.095811      0.156527         -9.523670
# 5     LSTM_GRU_pred    -48.366580     -0.662177        -15.491828
# 6       BiLSTM_pred     53.746260      0.137541         -9.704375
# 7   BiLSTM_GRU_pred    -17.454703     -0.378699        -14.700022
# 8         QRNN_pred    106.426255      0.558826         -4.592885
# 9          ESN_pred    -92.859886     -1.236901        -16.035561
# 10         BNN_pred    -89.666512     -1.003943        -17.308572
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -41.727580     -1.834624         -5.979675
# 1             PV_dw    -43.825779     -0.564017        -17.728358
# 2             PV_cw   -118.390114     -1.944675        -14.473784
# 3         LSTM_pred     81.096992      0.349407         -6.295015
# 4          GRU_pred    -62.312056     -0.843068        -15.865529
# 5     LSTM_GRU_pred     20.035751     -0.107864         -9.462320
# 6       BiLSTM_pred    -37.528219     -0.631501        -13.319575
# 7   BiLSTM_GRU_pred     83.156164      0.369182         -6.123556
# 8         QRNN_pred    -16.333756     -0.968038         -5.180814
# 9          ESN_pred    -57.284117     -1.846948         -5.929078
# 10         BNN_pred    -26.571197     -0.455365        -14.119902
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     10.427525     -0.331232         -5.593556
# 1             PV_dw    -25.487855     -0.403009        -15.927305
# 2             PV_cw    -76.032052     -1.063656        -15.233286
# 3         LSTM_pred    -23.938888     -0.409157        -15.765770
# 4          GRU_pred    -30.551980     -0.451915        -16.613306
# 5     LSTM_GRU_pred     -8.381006     -0.293981        -14.386451
# 6       BiLSTM_pred    -36.426217     -0.511236        -14.144070
# 7   BiLSTM_GRU_pred     15.566923     -0.132284        -13.307594
# 8         QRNN_pred    -14.394107     -0.719842         -8.094479
# 9          ESN_pred   -133.620026     -2.115944        -13.549217
# 10         BNN_pred    -30.164365     -0.472827        -14.436907
# 11               __    -19.183123     -0.358012        -15.916361
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    -74.348183     -1.074856        -13.683374
# 1             PV_dw    -26.296965     -0.408735        -16.010201
# 2             PV_cw    -99.273012     -1.184227        -16.035561
# 3         LSTM_pred    -27.292984     -0.419069        -16.600561
# 4          GRU_pred    -19.183123     -0.358012        -15.916361
# 5     LSTM_GRU_pred    -24.507927     -0.396035        -16.010201
# 6       BiLSTM_pred    -21.152107     -0.379406        -16.010201
# 7   BiLSTM_GRU_pred    -22.501213     -0.385976        -16.110643
# 8         QRNN_pred    112.882049      0.560535         -4.560787
# 9          ESN_pred    -92.859886     -1.236901        -16.035561
# 10         BNN_pred    -48.089678     -0.579557        -16.574123
# 11               __    -19.183123     -0.358012        -15.916361

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y1', file, 'PV')
get_final_results_1('2024_y1', file, 'PV')

get_final_results('2024_y1', dw_file, 'PV_dw')
get_final_results_1('2024_y1', dw_file, 'PV_dw')

get_final_results('2024_y1', cw_file, 'PV_cw')
get_final_results_1('2024_y1', cw_file, 'PV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:38: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# ...
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:28: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-48-dbce691e5d20>:32: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-48-dbce691e5d20>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    220.877285      1.176116         -4.000427
# 2             PV_cw    225.465054      1.207268         -3.944088
# 3         LSTM_pred    230.499510      1.236259         -3.974758
# 4          GRU_pred    245.138666      1.356102         -5.234619
# 5     LSTM_GRU_pred    247.507144      1.362851         -5.224681
# 6       BiLSTM_pred    255.664578      1.405153         -3.865203
# 7   BiLSTM_GRU_pred    218.290092      1.159186         -4.005501
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    184.870774      1.037458         -4.096142
# 10         BNN_pred    229.276802      1.223692         -4.020298
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    193.473928      1.089440         -4.051338
# 1             PV_dw    271.127006      1.573573         -3.835246
# 2             PV_cw    268.367687      1.539439         -3.827015
# 3         LSTM_pred    258.670034      1.506738         -4.019705
# 4          GRU_pred    304.249886      1.774748         -5.227577
# 5     LSTM_GRU_pred    314.801143      1.844855         -5.198558
# 6       BiLSTM_pred    239.687610      1.430797         -4.322631
# 7   BiLSTM_GRU_pred    214.175257      1.168951         -4.024477
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    235.663934      1.446631         -3.493153
# 10         BNN_pred    199.592487      1.186736         -4.086829
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    121.213457      0.654614         -5.823368
# 1             PV_dw    172.760466      0.960718         -4.122825
# 2             PV_cw    144.171808      0.902079         -4.895143
# 3         LSTM_pred    244.865219      1.452100         -4.330154
# 4          GRU_pred    233.879493      1.660013         -3.953557
# 5     LSTM_GRU_pred    241.040068      1.734383         -3.922496
# 6       BiLSTM_pred    209.708867      1.288247         -4.549300
# 7   BiLSTM_GRU_pred    155.343972      0.825256         -5.041229
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    132.656096      0.845529         -5.532559
# 10         BNN_pred    133.916424      0.776488         -6.518609
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    203.559294      1.155786         -4.038795
# 1             PV_dw    262.601252      1.538605         -3.861144
# 2             PV_cw    182.822699      1.127851         -4.971506
# 3         LSTM_pred    262.937601      1.564425         -4.088065
# 4          GRU_pred    326.172019      1.920668         -4.336616
# 5     LSTM_GRU_pred    338.465705      2.001397         -4.311731
# 6       BiLSTM_pred    238.803579      1.438046         -4.357253
# 7   BiLSTM_GRU_pred    207.894658      1.154278         -4.442371
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    199.598238      1.205786         -4.142632
# 10         BNN_pred    212.977156      1.346732         -4.141652
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    193.473928      1.089440         -4.051338
# 1             PV_dw    256.201641      1.484323         -3.880814
# 2             PV_cw    233.636368      1.336749         -5.522870
# 3         LSTM_pred    255.263947      1.492600         -4.030613
# 4          GRU_pred    304.249886      1.774748         -5.227577
# 5     LSTM_GRU_pred    314.801143      1.844855         -5.198558
# 6       BiLSTM_pred    239.687610      1.430797         -4.322631
# 7   BiLSTM_GRU_pred    201.901007      1.101190         -4.091604
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    224.350025      1.370352         -3.493153
# 10         BNN_pred    199.592487      1.186736         -4.086829
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    108.096596      0.468510         -6.280401
# 1             PV_dw    168.946689      0.883358         -4.051911
# 2             PV_cw    179.818281      1.069376         -4.363072
# 3         LSTM_pred    186.889655      0.974383         -5.201790
# 4          GRU_pred    213.920511      1.234482         -3.956806
# 5     LSTM_GRU_pred    231.638512      1.342876         -3.899885
# 6       BiLSTM_pred    227.460819      1.242169         -4.375968
# 7   BiLSTM_GRU_pred    208.130722      1.163843         -4.595079
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    111.050976      0.516128         -5.915491
# 10         BNN_pred    144.490625      0.717069         -5.836062
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.751398      1.250782         -4.005717
# 1             PV_dw    238.421404      1.287524         -3.943755
# 2             PV_cw    162.035125      0.884335         -5.840156
# 3         LSTM_pred    230.499510      1.236259         -3.974758
# 4          GRU_pred    266.067244      1.493160         -4.346723
# 5     LSTM_GRU_pred    269.960509      1.508083         -4.333398
# 6       BiLSTM_pred    255.664578      1.405153         -3.865203
# 7   BiLSTM_GRU_pred    268.952764      1.494818         -3.981033
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    160.724839      0.872272         -4.181351
# 10         BNN_pred    220.516376      1.191310         -3.955315
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    220.877285      1.176116         -4.000427
# 2             PV_cw    240.799456      1.318939         -3.975023
# 3         LSTM_pred    230.499510      1.236259         -3.974758
# 4          GRU_pred    245.138666      1.356102         -5.234619
# 5     LSTM_GRU_pred    247.507144      1.362851         -5.224681
# 6       BiLSTM_pred    255.664578      1.405153         -3.865203
# 7   BiLSTM_GRU_pred    218.290092      1.159186         -4.005501
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    174.021934      0.963573         -4.133993
# 10         BNN_pred    229.276802      1.223692         -4.020298
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    108.096596      0.468510         -6.280401
# 1             PV_dw    177.347324      0.939180         -4.031391
# 2             PV_cw    181.735994      1.008195         -5.049621
# 3         LSTM_pred    190.110213      0.990638         -5.241937
# 4          GRU_pred    196.616178      1.043345         -4.058440
# 5     LSTM_GRU_pred    202.648964      1.083604         -4.038082
# 6       BiLSTM_pred    214.038378      1.134682         -4.424349
# 7   BiLSTM_GRU_pred    190.110213      0.990638         -5.241937
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    209.939759      1.114508         -4.145916
# 10         BNN_pred    147.418884      0.732726         -5.821169
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.751398      1.250782         -4.005717
# 1             PV_dw    251.568772      1.362429         -3.948692
# 2             PV_cw    147.988295      0.738063         -6.593505
# 3         LSTM_pred    233.838400      1.251141         -4.005435
# 4          GRU_pred    231.809666      1.238835         -4.150396
# 5     LSTM_GRU_pred    231.809666      1.238835         -4.150396
# 6       BiLSTM_pred    233.838400      1.251141         -4.005435
# 7   BiLSTM_GRU_pred    233.838400      1.251141         -4.005435
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    233.838400      1.251141         -4.005435
# 10         BNN_pred    215.663077      1.158406         -3.971106
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV      233.8384      1.251141         -4.005435
# 1             PV_dw      233.8384      1.251141         -4.005435
# 2             PV_cw      233.8384      1.251141         -4.005435
# 3         LSTM_pred      233.8384      1.251141         -4.005435
# 4          GRU_pred      233.8384      1.251141         -4.005435
# 5     LSTM_GRU_pred      233.8384      1.251141         -4.005435
# 6       BiLSTM_pred      233.8384      1.251141         -4.005435
# 7   BiLSTM_GRU_pred      233.8384      1.251141         -4.005435
# 8         QRNN_pred      233.8384      1.251141         -4.005435
# 9          ESN_pred      233.8384      1.251141         -4.005435
# 10         BNN_pred      233.8384      1.251141         -4.005435
# 11               __      233.8384      1.251141         -4.005435
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    220.877285      1.176116         -4.000427
# 2             PV_cw    230.613473      1.253511         -4.034615
# 3         LSTM_pred    233.838400      1.251141         -4.005435
# 4          GRU_pred    232.386983      1.274104         -5.288782
# 5     LSTM_GRU_pred    229.917795      1.258421         -5.299400
# 6       BiLSTM_pred    226.449779      1.212472         -4.022021
# 7   BiLSTM_GRU_pred    250.795483      1.372481         -4.028394
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    222.520909      1.184440         -4.005501
# 10         BNN_pred    217.945326      1.158770         -4.057702
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    232.389241      1.251803         -3.992552
# 1             PV_dw    240.064944      1.345187         -3.897461
# 2             PV_cw    207.441981      1.136836         -4.104594
# 3         LSTM_pred    273.033702      1.568088         -4.028236
# 4          GRU_pred    226.567092      1.279738         -5.245695
# 5     LSTM_GRU_pred    266.824365      1.510355         -5.232967
# 6       BiLSTM_pred    205.878351      1.208415         -3.913642
# 7   BiLSTM_GRU_pred    260.050873      1.443002         -3.919713
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    146.549934      0.848608         -4.195552
# 10         BNN_pred    243.705967      1.358576         -4.282101
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    109.252077      0.498410         -6.684034
# 1             PV_dw    178.431331      1.002563         -4.182363
# 2             PV_cw    177.572821      1.090394         -4.548171
# 3         LSTM_pred    264.567027      1.542650         -4.320486
# 4          GRU_pred    183.637561      1.198244         -3.697867
# 5     LSTM_GRU_pred    174.020679      1.097622         -4.079385
# 6       BiLSTM_pred    173.478010      1.036532         -4.705482
# 7   BiLSTM_GRU_pred    197.138059      1.090518         -4.665998
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    105.249340      0.571647         -5.064083
# 10         BNN_pred    257.932922      1.527035         -4.190061
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.417658      0.748146         -6.545250
# 1             PV_dw    250.122991      1.439843         -3.926836
# 2             PV_cw    193.075567      1.137746         -6.049583
# 3         LSTM_pred    264.567027      1.542650         -4.320486
# 4          GRU_pred    229.019205      1.338658         -4.240031
# 5     LSTM_GRU_pred    278.595143      1.635831         -4.199182
# 6       BiLSTM_pred    199.260081      1.172142         -3.963930
# 7   BiLSTM_GRU_pred    267.753790      1.508645         -4.390083
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    125.961973      0.711038         -4.355306
# 10         BNN_pred    269.541209      1.575851         -4.187351
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    232.389241      1.251803         -3.992552
# 1             PV_dw    240.064944      1.345187         -3.897461
# 2             PV_cw    219.161520      1.273098         -4.889992
# 3         LSTM_pred    273.033702      1.568088         -4.028236
# 4          GRU_pred    260.398353      1.473182         -5.403480
# 5     LSTM_GRU_pred    262.750889      1.484895         -5.390370
# 6       BiLSTM_pred    205.878351      1.208415         -3.913642
# 7   BiLSTM_GRU_pred    276.496762      1.551094         -3.919778
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    136.051965      0.773363         -4.234322
# 10         BNN_pred    243.705967      1.358576         -4.282101
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    125.271802      0.614012         -6.588878
# 1             PV_dw    198.887590      1.092123         -4.841279
# 2             PV_cw    140.629706      0.774992         -6.261510
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    214.397058      1.242663         -3.526169
# 5     LSTM_GRU_pred    209.326453      1.198233         -3.960289
# 6       BiLSTM_pred    251.845749      1.413022         -4.798972
# 7   BiLSTM_GRU_pred    189.174804      1.017642         -5.339660
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    218.475430      1.177290         -4.020008
# 10         BNN_pred    184.780373      0.970312         -4.135835
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    141.005530      0.689606         -6.593505
# 1             PV_dw    230.859254      1.241865         -3.962544
# 2             PV_cw    171.803796      0.966563         -6.424740
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    207.071459      1.168366         -4.273180
# 5     LSTM_GRU_pred    237.723919      1.347487         -4.269981
# 6       BiLSTM_pred    219.718606      1.177678         -4.134905
# 7   BiLSTM_GRU_pred    274.929678      1.527889         -4.003786
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    233.543579      1.254871         -4.005501
# 10         BNN_pred    200.004119      1.064081         -4.022925
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    220.877285      1.176116         -4.000427
# 2             PV_cw    161.261916      0.841454         -5.268619
# 3         LSTM_pred    233.838400      1.251141         -4.005435
# 4          GRU_pred    237.890240      1.310120         -5.438577
# 5     LSTM_GRU_pred    227.895507      1.245770         -5.449496
# 6       BiLSTM_pred    226.449779      1.212472         -4.022021
# 7   BiLSTM_GRU_pred    274.929678      1.527889         -4.003786
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    233.543579      1.254871         -4.005501
# 10         BNN_pred    217.945326      1.158770         -4.057702
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    125.271802      0.614012         -6.588878
# 1             PV_dw    220.569173      1.229209         -4.816761
# 2             PV_cw    112.485679      0.528570         -6.229800
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    194.978849      1.033126         -4.064001
# 5     LSTM_GRU_pred    202.648964      1.083604         -4.038082
# 6       BiLSTM_pred    209.484824      1.113939         -4.783090
# 7   BiLSTM_GRU_pred    190.110213      0.990638         -5.241937
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    229.385905      1.237496         -4.019941
# 10         BNN_pred    200.240675      1.065446         -4.082561
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    141.005530      0.689606         -6.593505
# 1             PV_dw    251.568772      1.362429         -3.948692
# 2             PV_cw    164.994909      0.887704         -6.392203
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    205.159212      1.090590         -4.005717
# 5     LSTM_GRU_pred    207.070375      1.102775         -3.999375
# 6       BiLSTM_pred    218.185419      1.160101         -4.117853
# 7   BiLSTM_GRU_pred    233.838400      1.251141         -4.005435
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    233.838400      1.251141         -4.005435
# 10         BNN_pred    215.663077      1.158406         -3.971106
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    233.838400      1.251141         -4.005435
# 2             PV_cw    148.926588      0.738509         -5.242812
# 3         LSTM_pred    233.838400      1.251141         -4.005435
# 4          GRU_pred    231.809666      1.238835         -4.150396
# 5     LSTM_GRU_pred    231.809666      1.238835         -4.150396
# 6       BiLSTM_pred    233.838400      1.251141         -4.005435
# 7   BiLSTM_GRU_pred    233.838400      1.251141         -4.005435
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    233.838400      1.251141         -4.005435
# 10         BNN_pred    233.838400      1.251141         -4.005435
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    212.647941      1.172455         -4.005435
# 1             PV_dw    201.473657      1.087365         -4.048036
# 2             PV_cw    235.885373      1.340333         -4.026802
# 3         LSTM_pred    205.768455      1.116612         -4.745694
# 4          GRU_pred    282.448861      1.697310         -4.339425
# 5     LSTM_GRU_pred    235.497195      1.336772         -5.232967
# 6       BiLSTM_pred    202.460907      1.111262         -3.960182
# 7   BiLSTM_GRU_pred    205.469812      1.109312         -4.491038
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    189.962609      1.076497         -4.005435
# 10         BNN_pred    239.486221      1.335426         -4.236340
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    199.445398      1.138039         -4.030814
# 1             PV_dw    217.912795      1.346760         -4.065711
# 2             PV_cw    281.404438      1.729445         -3.136138
# 3         LSTM_pred    211.593721      1.216307         -3.000737
# 4          GRU_pred    228.274516      1.413925         -4.103982
# 5     LSTM_GRU_pred    218.251468      1.309929         -4.523553
# 6       BiLSTM_pred    210.538526      1.263795         -3.110944
# 7   BiLSTM_GRU_pred    214.188964      1.201327         -3.902397
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    203.467428      1.378260         -3.550810
# 10         BNN_pred    268.572850      1.622203         -3.698165
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     73.094009      0.352238         -3.455562
# 1             PV_dw     46.241165      0.075737         -7.218106
# 2             PV_cw     35.639117     -0.092524         -4.019605
# 3         LSTM_pred    145.555979      0.825136         -3.918075
# 4          GRU_pred    131.940047      0.954048         -3.212193
# 5     LSTM_GRU_pred     97.606829      0.592017         -5.031067
# 6       BiLSTM_pred    110.688276      0.644970         -4.713177
# 7   BiLSTM_GRU_pred    -10.501255     -0.679209         -8.158648
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     91.629714      0.561632         -4.621713
# 10         BNN_pred    176.133702      1.454713         -3.434310
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     88.910002      0.418256         -6.588878
# 1             PV_dw    211.927379      1.406682         -3.391928
# 2             PV_cw    107.322072      0.712401         -3.972604
# 3         LSTM_pred    173.248475      1.008047         -3.880415
# 4          GRU_pred    163.560125      1.115872         -3.841087
# 5     LSTM_GRU_pred    158.274527      1.067589         -3.520823
# 6       BiLSTM_pred    205.420691      1.341541         -4.646875
# 7   BiLSTM_GRU_pred    135.749247      0.709273         -3.879113
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     82.997683      0.437120         -3.861801
# 10         BNN_pred    196.060088      1.420338         -2.445643
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    140.000968      0.832124         -4.030814
# 1             PV_dw    228.848171      1.453207         -4.049990
# 2             PV_cw    145.204361      0.976479         -3.198623
# 3         LSTM_pred    173.001978      0.995215         -3.673433
# 4          GRU_pred    195.934367      1.358459         -3.707125
# 5     LSTM_GRU_pred    179.612984      1.197306         -4.065894
# 6       BiLSTM_pred    222.237475      1.404836         -4.267146
# 7   BiLSTM_GRU_pred    195.739921      1.111794         -4.184786
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    135.115725      0.848393         -3.772420
# 10         BNN_pred    297.681454      1.878529         -3.269996
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     73.094009      0.352238         -3.455562
# 1             PV_dw     61.098477      0.124683         -6.714999
# 2             PV_cw     16.965876     -0.500619         -4.388284
# 3         LSTM_pred    173.725646      0.952736         -6.331991
# 4          GRU_pred    188.843773      1.460180         -3.077551
# 5     LSTM_GRU_pred    110.486411      0.618174         -5.954565
# 6       BiLSTM_pred    135.130587      0.694639         -4.957414
# 7   BiLSTM_GRU_pred     38.250625     -0.098316         -6.080494
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     90.576391      0.378431         -7.150154
# 10         BNN_pred    197.184753      1.187048         -4.048053
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     88.910002      0.418256         -6.588878
# 1             PV_dw    171.025431      0.924576         -4.433037
# 2             PV_cw     86.141113      0.435866         -4.313072
# 3         LSTM_pred    207.813185      1.143744         -5.289226
# 4          GRU_pred    220.010798      1.532830         -3.616055
# 5     LSTM_GRU_pred    179.631980      1.151014         -3.652768
# 6       BiLSTM_pred    174.698384      0.957567         -4.962354
# 7   BiLSTM_GRU_pred    143.105541      0.734247         -4.692914
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    122.024805      0.622336         -4.972375
# 10         BNN_pred    217.324370      1.262964         -4.250357
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    140.628563      0.816599         -4.005435
# 1             PV_dw    211.218694      1.174473         -4.081450
# 2             PV_cw    103.424158      0.518785         -6.494355
# 3         LSTM_pred    207.898358      1.144129         -5.282565
# 4          GRU_pred    234.819092      1.553262         -4.136346
# 5     LSTM_GRU_pred    176.609588      1.080585         -4.150951
# 6       BiLSTM_pred    215.068099      1.220282         -4.169398
# 7   BiLSTM_GRU_pred    219.236985      1.222446         -4.527154
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    141.793688      0.749054         -4.005435
# 10         BNN_pred    288.688983      1.685116         -4.110876
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     73.094009      0.352238         -3.455562
# 1             PV_dw     97.122394      0.413029         -6.507047
# 2             PV_cw      9.904715     -0.557629         -4.388284
# 3         LSTM_pred    199.109354      1.109259         -6.197950
# 4          GRU_pred    169.598028      0.882556         -4.081922
# 5     LSTM_GRU_pred    163.671895      0.885580         -5.964635
# 6       BiLSTM_pred     99.833271      0.406992         -6.170739
# 7   BiLSTM_GRU_pred    116.436510      0.532521         -6.494355
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    155.938231      0.797331         -4.601523
# 10         BNN_pred    182.648437      0.955882         -4.094638
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     88.910002      0.418256         -6.588878
# 1             PV_dw    238.697925      1.335384         -4.117604
# 2             PV_cw     78.599643      0.333140         -4.313072
# 3         LSTM_pred    190.110213      0.990638         -5.241937
# 4          GRU_pred    194.978849      1.033126         -4.064001
# 5     LSTM_GRU_pred    202.648964      1.083604         -4.038082
# 6       BiLSTM_pred    211.122934      1.117060         -4.776620
# 7   BiLSTM_GRU_pred    164.561277      0.845546         -5.241937
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    165.770288      0.851019         -4.562714
# 10         BNN_pred    200.240675      1.065446         -4.082561
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    140.628563      0.816599         -4.005435
# 1             PV_dw    251.568772      1.362429         -3.948692
# 2             PV_cw     95.762685      0.437255         -6.494355
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    233.751398      1.250782         -4.005717
# 5     LSTM_GRU_pred    207.070375      1.102775         -3.999375
# 6       BiLSTM_pred    218.185419      1.160101         -4.117853
# 7   BiLSTM_GRU_pred    233.838400      1.251141         -4.005435
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    205.244199      1.090976         -4.005435
# 10         BNN_pred    228.716169      1.226887         -4.082561
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    211.268725      1.165190         -4.005435
# 1             PV_dw    241.602908      1.460437         -3.438004
# 2             PV_cw    245.038662      1.411685         -3.455562
# 3         LSTM_pred    225.523963      1.282256         -4.094989
# 4          GRU_pred    282.448861      1.697310         -4.339425
# 5     LSTM_GRU_pred    218.110511      1.251779         -4.530742
# 6       BiLSTM_pred    191.798134      1.050280         -4.623287
# 7   BiLSTM_GRU_pred    198.542859      1.071738         -4.248311
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    218.901960      1.298527         -3.987463
# 10         BNN_pred    191.278358      1.154231         -4.145981
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    175.637382      0.987846         -3.884565
# 1             PV_dw    169.916258      1.023377         -3.723503
# 2             PV_cw    246.318145      1.510929         -3.180571
# 3         LSTM_pred    153.037120      0.838847         -3.371082
# 4          GRU_pred    228.274516      1.413925         -4.103982
# 5     LSTM_GRU_pred    254.420414      1.610482         -4.048283
# 6       BiLSTM_pred    147.833228      0.853985         -3.874850
# 7   BiLSTM_GRU_pred    174.451356      0.979168         -4.708975
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    152.793386      1.023254         -4.647560
# 10         BNN_pred    280.503864      1.734249         -3.676421
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     77.714977      0.426402         -3.061465
# 1             PV_dw      3.615313     -0.415579         -7.115795
# 2             PV_cw     36.185371     -0.085929         -3.743821
# 3         LSTM_pred     74.871266      0.260034         -3.436989
# 4          GRU_pred    168.255577      1.548413         -1.745478
# 5     LSTM_GRU_pred    147.573475      1.235569         -3.182675
# 6       BiLSTM_pred     76.295426      0.356006         -4.863959
# 7   BiLSTM_GRU_pred     63.168084      0.168040         -4.315792
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     10.302229     -0.382980         -8.663032
# 10         BNN_pred    140.098503      1.221202         -4.002576
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     66.267334      0.191599         -6.438495
# 1             PV_dw    122.736615      0.773409         -5.214042
# 2             PV_cw    107.199904      0.769968         -3.995600
# 3         LSTM_pred    127.469781      0.711052         -3.873159
# 4          GRU_pred    163.560125      1.115872         -3.841087
# 5     LSTM_GRU_pred    179.983131      1.362510         -3.282442
# 6       BiLSTM_pred    155.325615      0.992557         -4.789329
# 7   BiLSTM_GRU_pred    111.082438      0.567377         -3.688925
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     32.636716     -0.078255         -6.849440
# 10         BNN_pred    187.221055      1.387649         -2.395811
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    110.436469      0.584910         -3.884565
# 1             PV_dw    205.200669      1.358324         -3.418634
# 2             PV_cw    104.917389      0.655280         -3.509394
# 3         LSTM_pred    129.326672      0.726870         -3.866790
# 4          GRU_pred    156.505412      1.049166         -3.864518
# 5     LSTM_GRU_pred    212.453674      1.602358         -3.978119
# 6       BiLSTM_pred    184.160902      1.164681         -4.337044
# 7   BiLSTM_GRU_pred    243.165588      1.487578         -3.457058
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    135.883580      0.910903         -4.607589
# 10         BNN_pred    174.619352      1.220325         -4.038222
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     77.714977      0.426402         -3.061465
# 1             PV_dw    117.380852      0.729065         -5.524754
# 2             PV_cw     23.834592     -0.410319         -4.113559
# 3         LSTM_pred    135.070592      0.712477         -4.550707
# 4          GRU_pred    234.393790      2.096135         -2.959842
# 5     LSTM_GRU_pred    111.345211      0.682076         -3.374364
# 6       BiLSTM_pred    169.275266      1.003436         -4.859620
# 7   BiLSTM_GRU_pred     34.524800     -0.163217         -6.106701
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     29.464686     -0.178626         -9.829570
# 10         BNN_pred    164.357099      1.280681         -2.432495
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     83.744140      0.366750         -6.588878
# 1             PV_dw    184.199592      1.162317         -3.665476
# 2             PV_cw    100.335441      0.608637         -4.313072
# 3         LSTM_pred    200.889133      1.146125         -4.390500
# 4          GRU_pred    220.010798      1.532830         -3.616055
# 5     LSTM_GRU_pred    116.787681      0.645474         -3.754196
# 6       BiLSTM_pred    224.894033      1.368865         -4.870703
# 7   BiLSTM_GRU_pred     64.372051      0.152101         -4.852514
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     47.734753      0.003998         -7.833543
# 10         BNN_pred    175.703879      1.125570         -4.604655
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    125.729565      0.697612         -4.025445
# 1             PV_dw    221.815061      1.394550         -3.719018
# 2             PV_cw    114.563322      0.654575         -4.873955
# 3         LSTM_pred    202.866942      1.159708         -4.383281
# 4          GRU_pred    221.682425      1.545895         -3.611107
# 5     LSTM_GRU_pred    162.515678      1.024458         -3.494620
# 6       BiLSTM_pred    201.688715      1.158488         -4.679023
# 7   BiLSTM_GRU_pred    174.268043      0.943141         -4.993216
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    162.471108      0.925390         -3.987463
# 10         BNN_pred    169.180973      1.059915         -4.328773
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     77.714977      0.426402         -3.061465
# 1             PV_dw     97.482101      0.424128         -6.475947
# 2             PV_cw      3.609975     -0.651558         -4.113559
# 3         LSTM_pred    199.109354      1.109259         -6.197950
# 4          GRU_pred    155.853966      0.793127         -4.963745
# 5     LSTM_GRU_pred    163.671895      0.885580         -5.964635
# 6       BiLSTM_pred     99.833271      0.406992         -6.170739
# 7   BiLSTM_GRU_pred    146.978727      0.764072         -5.190956
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    158.382492      0.815228         -4.808463
# 10         BNN_pred    169.638947      0.879986         -4.140181
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     83.744140      0.366750         -6.588878
# 1             PV_dw    221.485237      1.232153         -4.117604
# 2             PV_cw     78.599643      0.333140         -4.313072
# 3         LSTM_pred    190.110213      0.990638         -5.241937
# 4          GRU_pred    194.978849      1.033126         -4.064001
# 5     LSTM_GRU_pred    181.772765      0.953183         -4.563739
# 6       BiLSTM_pred    201.020480      1.059104         -4.816799
# 7   BiLSTM_GRU_pred    131.371629      0.634827         -5.258852
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    160.211991      0.814423         -4.584573
# 10         BNN_pred    200.240675      1.065446         -4.082561
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    123.409147      0.677584         -4.210182
# 1             PV_dw    235.690856      1.271503         -4.059518
# 2             PV_cw     80.378227      0.303184         -5.924261
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    196.616178      1.043345         -4.058440
# 5     LSTM_GRU_pred    186.616023      0.977795         -4.716361
# 6       BiLSTM_pred    214.038378      1.134682         -4.424349
# 7   BiLSTM_GRU_pred    209.519985      1.108381         -5.241937
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    191.091675      1.004588         -4.005435
# 10         BNN_pred    200.240675      1.065446         -4.082561
# 11               __    233.838400      1.251141         -4.005435

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    261.052317      1.437126         -3.523261
# 2             PV_cw    238.568096      1.287693         -3.927345
# 3         LSTM_pred    230.499510      1.236259         -3.974758
# 4          GRU_pred    212.349712      1.130001         -5.250460
# 5     LSTM_GRU_pred    232.386983      1.274104         -5.288782
# 6       BiLSTM_pred    255.664578      1.405153         -3.865203
# 7   BiLSTM_GRU_pred    218.290092      1.159186         -4.005501
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    163.499618      0.892698         -4.180735
# 10         BNN_pred    221.639780      1.199529         -3.900413
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    193.473928      1.089440         -4.051338
# 1             PV_dw    275.556540      1.563248         -3.498762
# 2             PV_cw    233.150951      1.302580         -3.923330
# 3         LSTM_pred    258.670034      1.506738         -4.019705
# 4          GRU_pred    229.989412      1.414534         -4.702795
# 5     LSTM_GRU_pred    224.445208      1.353001         -5.239043
# 6       BiLSTM_pred    239.687610      1.430797         -4.322631
# 7   BiLSTM_GRU_pred    214.175257      1.168951         -4.024477
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    153.022327      0.840995         -5.302129
# 10         BNN_pred    264.998144      1.519063         -3.766724
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    121.213457      0.654614         -5.823368
# 1             PV_dw    247.898884      1.499852         -3.454721
# 2             PV_cw     66.493129      0.174144         -7.240553
# 3         LSTM_pred    244.865219      1.452100         -4.330154
# 4          GRU_pred    104.873172      0.617179         -5.946327
# 5     LSTM_GRU_pred    135.659847      0.902784         -4.872223
# 6       BiLSTM_pred    209.708867      1.288247         -4.549300
# 7   BiLSTM_GRU_pred    155.343972      0.825256         -5.041229
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     77.240201      0.263981         -6.223322
# 10         BNN_pred    268.090284      1.634439         -3.737678
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    203.559294      1.155786         -4.038795
# 1             PV_dw    300.862265      1.731886         -3.430701
# 2             PV_cw    140.952406      0.746818         -6.846487
# 3         LSTM_pred    262.937601      1.564425         -4.088065
# 4          GRU_pred    181.120355      1.100214         -5.907240
# 5     LSTM_GRU_pred    246.483490      1.506675         -4.786370
# 6       BiLSTM_pred    238.803579      1.438046         -4.357253
# 7   BiLSTM_GRU_pred    207.894658      1.154278         -4.442371
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    129.150614      0.667230         -5.324599
# 10         BNN_pred    272.758243      1.570973         -3.743758
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    193.473928      1.089440         -4.051338
# 1             PV_dw    297.620034      1.711591         -3.439273
# 2             PV_cw    194.256176      1.062818         -5.583397
# 3         LSTM_pred    255.263947      1.492600         -4.030613
# 4          GRU_pred    199.639202      1.219733         -4.821773
# 5     LSTM_GRU_pred    224.445208      1.353001         -5.239043
# 6       BiLSTM_pred    239.687610      1.430797         -4.322631
# 7   BiLSTM_GRU_pred    201.901007      1.101190         -4.091604
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    134.932986      0.707867         -5.297470
# 10         BNN_pred    245.485423      1.387635         -3.825737
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    108.096596      0.468510         -6.280401
# 1             PV_dw    289.016159      1.668582         -3.383991
# 2             PV_cw    109.952320      0.512805         -5.663018
# 3         LSTM_pred    186.889655      0.974383         -5.201790
# 4          GRU_pred    187.046189      0.994904         -4.213010
# 5     LSTM_GRU_pred    199.086536      1.124514         -4.158634
# 6       BiLSTM_pred    227.460819      1.242169         -4.375968
# 7   BiLSTM_GRU_pred    208.130722      1.163843         -4.595079
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     86.423108      0.330837         -5.589365
# 10         BNN_pred    235.500320      1.362926         -3.942967
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.751398      1.250782         -4.005717
# 1             PV_dw    263.052116      1.449404         -3.517683
# 2             PV_cw    115.468365      0.529243         -5.862770
# 3         LSTM_pred    230.499510      1.236259         -3.974758
# 4          GRU_pred    202.314442      1.072732         -5.399169
# 5     LSTM_GRU_pred    254.568206      1.419343         -4.386564
# 6       BiLSTM_pred    255.664578      1.405153         -3.865203
# 7   BiLSTM_GRU_pred    268.952764      1.494818         -3.981033
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    154.857538      0.838412         -4.509982
# 10         BNN_pred    248.390444      1.374911         -3.816834
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    263.052116      1.449404         -3.517683
# 2             PV_cw    218.618654      1.171493         -3.991638
# 3         LSTM_pred    230.499510      1.236259         -3.974758
# 4          GRU_pred    212.349712      1.130001         -5.250460
# 5     LSTM_GRU_pred    232.386983      1.274104         -5.288782
# 6       BiLSTM_pred    255.664578      1.405153         -3.865203
# 7   BiLSTM_GRU_pred    218.290092      1.159186         -4.005501
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    160.952011      0.878134         -4.486307
# 10         BNN_pred    221.639780      1.199529         -3.900413
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    108.096596      0.468510         -6.280401
# 1             PV_dw    220.547830      1.189819         -4.049050
# 2             PV_cw    145.966508      0.759457         -6.392203
# 3         LSTM_pred    190.110213      0.990638         -5.241937
# 4          GRU_pred    218.099520      1.159728         -4.118144
# 5     LSTM_GRU_pred    186.616023      0.977795         -4.716361
# 6       BiLSTM_pred    214.038378      1.134682         -4.424349
# 7   BiLSTM_GRU_pred    190.110213      0.990638         -5.241937
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    229.733327      1.240756         -4.021643
# 10         BNN_pred    180.636589      0.946640         -4.082561
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.751398      1.250782         -4.005717
# 1             PV_dw    232.150140      1.241198         -4.010923
# 2             PV_cw    148.798743      0.743602         -6.593505
# 3         LSTM_pred    233.838400      1.251141         -4.005435
# 4          GRU_pred    216.182422      1.147746         -4.150396
# 5     LSTM_GRU_pred    231.809666      1.238835         -4.150396
# 6       BiLSTM_pred    233.838400      1.251141         -4.005435
# 7   BiLSTM_GRU_pred    233.838400      1.251141         -4.005435
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    242.534032      1.305780         -3.977403
# 10         BNN_pred    244.504465      1.317835         -3.971106
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    232.150140      1.241198         -4.010923
# 2             PV_cw    233.751398      1.250782         -4.005717
# 3         LSTM_pred    233.838400      1.251141         -4.005435
# 4          GRU_pred    233.838400      1.251141         -4.005435
# 5     LSTM_GRU_pred    233.838400      1.251141         -4.005435
# 6       BiLSTM_pred    233.838400      1.251141         -4.005435
# 7   BiLSTM_GRU_pred    233.838400      1.251141         -4.005435
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    242.534032      1.305780         -3.977403
# 10         BNN_pred    233.838400      1.251141         -4.005435
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    228.129601      1.224458         -3.996648
# 2             PV_cw    228.666484      1.243019         -4.050179
# 3         LSTM_pred    233.838400      1.251141         -4.005435
# 4          GRU_pred    203.597474      1.077572         -5.299400
# 5     LSTM_GRU_pred    239.410201      1.320209         -5.258813
# 6       BiLSTM_pred    226.449779      1.212472         -4.022021
# 7   BiLSTM_GRU_pred    250.795483      1.372481         -4.028394
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    229.000599      1.225223         -3.993319
# 10         BNN_pred    218.964893      1.179633         -3.980380
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    232.389241      1.251803         -3.992552
# 1             PV_dw    225.501529      1.240882         -3.610309
# 2             PV_cw    187.703935      1.014588         -4.092388
# 3         LSTM_pred    273.033702      1.568088         -4.028236
# 4          GRU_pred    190.778422      1.117390         -5.241354
# 5     LSTM_GRU_pred    257.806234      1.525181         -5.232967
# 6       BiLSTM_pred    205.878351      1.208415         -3.913642
# 7   BiLSTM_GRU_pred    260.050873      1.443002         -3.919713
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    159.869205      0.883096         -5.291929
# 10         BNN_pred    232.596827      1.304912         -3.812023
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    109.252077      0.498410         -6.684034
# 1             PV_dw    280.858806      1.717276         -3.321889
# 2             PV_cw    134.463967      0.738572         -4.585129
# 3         LSTM_pred    264.567027      1.542650         -4.320486
# 4          GRU_pred     92.447260      0.486828         -5.124387
# 5     LSTM_GRU_pred    167.583727      1.130537         -4.109239
# 6       BiLSTM_pred    173.478010      1.036532         -4.705482
# 7   BiLSTM_GRU_pred    197.138059      1.090518         -4.665998
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     76.072567      0.253479         -5.122377
# 10         BNN_pred    260.550184      1.587460         -3.735383
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.417658      0.748146         -6.545250
# 1             PV_dw    264.543567      1.527810         -3.575355
# 2             PV_cw    144.762626      0.791158         -6.129304
# 3         LSTM_pred    264.567027      1.542650         -4.320486
# 4          GRU_pred    172.703775      1.012369         -5.305966
# 5     LSTM_GRU_pred    269.493219      1.651258         -4.199182
# 6       BiLSTM_pred    199.260081      1.172142         -3.963930
# 7   BiLSTM_GRU_pred    267.753790      1.508645         -4.390083
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    148.523071      0.809095         -5.309425
# 10         BNN_pred    269.646208      1.554342         -3.700785
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    232.389241      1.251803         -3.992552
# 1             PV_dw    225.501529      1.240882         -3.610309
# 2             PV_cw    173.191082      0.972234         -5.368457
# 3         LSTM_pred    273.033702      1.568088         -4.028236
# 4          GRU_pred    168.832992      0.975466         -5.501070
# 5     LSTM_GRU_pred    253.761755      1.499708         -5.390370
# 6       BiLSTM_pred    205.878351      1.208415         -3.913642
# 7   BiLSTM_GRU_pred    276.496762      1.551094         -3.919778
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    148.994172      0.804706         -5.293104
# 10         BNN_pred    242.440073      1.370778         -3.781822
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    125.271802      0.614012         -6.588878
# 1             PV_dw    266.845579      1.507100         -3.976691
# 2             PV_cw     91.323643      0.373535         -6.340266
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    178.476624      0.940734         -4.252280
# 5     LSTM_GRU_pred    206.075684      1.182115         -3.982543
# 6       BiLSTM_pred    251.845749      1.413022         -4.798972
# 7   BiLSTM_GRU_pred    189.174804      1.017642         -5.339660
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    195.953360      1.044968         -4.118773
# 10         BNN_pred    216.389183      1.224916         -4.057310
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    141.005530      0.689606         -6.593505
# 1             PV_dw    221.015532      1.186468         -4.019934
# 2             PV_cw    116.627563      0.561614         -6.561388
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    205.597822      1.100013         -4.400516
# 5     LSTM_GRU_pred    252.898123      1.448803         -4.218266
# 6       BiLSTM_pred    219.718606      1.177678         -4.134905
# 7   BiLSTM_GRU_pred    274.929678      1.527889         -4.003786
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    246.977960      1.346715         -3.981847
# 10         BNN_pred    229.502382      1.247441         -3.946266
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    228.129601      1.224458         -3.996648
# 2             PV_cw    117.194454      0.535014         -6.718054
# 3         LSTM_pred    233.838400      1.251141         -4.005435
# 4          GRU_pred    201.618464      1.065118         -5.449496
# 5     LSTM_GRU_pred    237.372305      1.307527         -5.407759
# 6       BiLSTM_pred    226.449779      1.212472         -4.022021
# 7   BiLSTM_GRU_pred    274.929678      1.527889         -4.003786
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    248.821325      1.350931         -3.965373
# 10         BNN_pred    218.964893      1.179633         -3.980380
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    125.271802      0.614012         -6.588878
# 1             PV_dw    243.097148      1.317921         -3.975602
# 2             PV_cw    105.800812      0.472317         -6.155998
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    218.099520      1.159728         -4.118144
# 5     LSTM_GRU_pred    194.978849      1.033126         -4.064001
# 6       BiLSTM_pred    209.484824      1.113939         -4.783090
# 7   BiLSTM_GRU_pred    190.110213      0.990638         -5.241937
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    229.733327      1.240756         -4.021643
# 10         BNN_pred    180.553338      0.946228         -4.082849
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    141.005530      0.689606         -6.593505
# 1             PV_dw    232.150140      1.241198         -4.010923
# 2             PV_cw    145.966508      0.759457         -6.392203
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    216.182422      1.147746         -4.150396
# 5     LSTM_GRU_pred    207.070375      1.102775         -3.999375
# 6       BiLSTM_pred    218.185419      1.160101         -4.117853
# 7   BiLSTM_GRU_pred    233.838400      1.251141         -4.005435
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    251.568772      1.362429         -3.948692
# 10         BNN_pred    244.504465      1.317835         -3.971106
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.838400      1.251141         -4.005435
# 1             PV_dw    233.838400      1.251141         -4.005435
# 2             PV_cw    132.576105      0.630746         -6.593505
# 3         LSTM_pred    233.838400      1.251141         -4.005435
# 4          GRU_pred    231.809666      1.238835         -4.150396
# 5     LSTM_GRU_pred    231.809666      1.238835         -4.150396
# 6       BiLSTM_pred    233.838400      1.251141         -4.005435
# 7   BiLSTM_GRU_pred    233.838400      1.251141         -4.005435
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    242.534032      1.305780         -3.977403
# 10         BNN_pred    233.838400      1.251141         -4.005435
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    212.647941      1.172455         -4.005435
# 1             PV_dw    227.924681      1.266207         -3.979539
# 2             PV_cw    202.075565      1.107721         -5.411172
# 3         LSTM_pred    205.768455      1.116612         -4.745694
# 4          GRU_pred     37.585135     -0.006271         -8.570596
# 5     LSTM_GRU_pred    235.497195      1.336772         -5.232967
# 6       BiLSTM_pred    202.460907      1.111262         -3.960182
# 7   BiLSTM_GRU_pred    205.469812      1.109312         -4.491038
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    182.219680      1.018321         -4.114535
# 10         BNN_pred    244.103156      1.384588         -3.776767
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    199.445398      1.138039         -4.030814
# 1             PV_dw    188.242853      1.214598         -3.720634
# 2             PV_cw    209.213973      1.242100         -3.335673
# 3         LSTM_pred    211.593721      1.216307         -3.000737
# 4          GRU_pred     32.594616     -0.059508         -5.716928
# 5     LSTM_GRU_pred    179.972101      1.043786         -5.741172
# 6       BiLSTM_pred    210.538526      1.263795         -3.110944
# 7   BiLSTM_GRU_pred    214.188964      1.201327         -3.902397
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    137.933126      0.767008         -5.170217
# 10         BNN_pred    219.334943      1.273729         -4.899319
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     73.094009      0.352238         -3.455562
# 1             PV_dw    156.850778      1.218070         -3.691874
# 2             PV_cw     57.684419      0.111152         -3.532642
# 3         LSTM_pred    145.555979      0.825136         -3.918075
# 4          GRU_pred     79.281918      0.591413         -2.526608
# 5     LSTM_GRU_pred    131.172828      1.077248         -3.732816
# 6       BiLSTM_pred    110.688276      0.644970         -4.713177
# 7   BiLSTM_GRU_pred    -10.501255     -0.679209         -8.158648
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred      0.602498     -0.441093         -9.305677
# 10         BNN_pred    133.718847      0.948579         -4.914090
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     88.910002      0.418256         -6.588878
# 1             PV_dw    243.076809      1.831630         -3.354492
# 2             PV_cw     56.122558      0.080216         -6.195681
# 3         LSTM_pred    173.248475      1.008047         -3.880415
# 4          GRU_pred     45.124555      0.061396         -6.989054
# 5     LSTM_GRU_pred    151.801916      1.140173         -6.238390
# 6       BiLSTM_pred    205.420691      1.341541         -4.646875
# 7   BiLSTM_GRU_pred    135.749247      0.709273         -3.879113
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    132.522534      0.768179         -4.712236
# 10         BNN_pred    276.301642      1.749212         -5.435764
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    140.000968      0.832124         -4.030814
# 1             PV_dw    267.940417      1.938445         -3.253755
# 2             PV_cw     62.907804      0.152505         -6.658164
# 3         LSTM_pred    173.001978      0.995215         -3.673433
# 4          GRU_pred     74.138268      0.379864         -4.713782
# 5     LSTM_GRU_pred    142.547699      0.884783         -7.693565
# 6       BiLSTM_pred    222.237475      1.404836         -4.267146
# 7   BiLSTM_GRU_pred    195.739921      1.111794         -4.184786
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     98.184266      0.448517         -5.170217
# 10         BNN_pred    236.289489      1.421609         -4.764983
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     73.094009      0.352238         -3.455562
# 1             PV_dw    233.032798      1.467022         -4.241807
# 2             PV_cw     19.411340     -0.470453         -7.027762
# 3         LSTM_pred    173.725646      0.952736         -6.331991
# 4          GRU_pred     45.732158      0.068731         -4.583990
# 5     LSTM_GRU_pred    139.837363      0.853592         -3.747378
# 6       BiLSTM_pred    135.130587      0.694639         -4.957414
# 7   BiLSTM_GRU_pred     38.250625     -0.098316         -6.080494
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     94.256796      0.406944         -6.121875
# 10         BNN_pred     98.073200      0.501272         -4.288090
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     88.910002      0.418256         -6.588878
# 1             PV_dw    267.640691      1.611785         -4.031227
# 2             PV_cw      2.797121     -0.492513        -10.383955
# 3         LSTM_pred    207.813185      1.143744         -5.289226
# 4          GRU_pred     12.636585     -0.296859         -8.600887
# 5     LSTM_GRU_pred    179.631980      1.151014         -3.652768
# 6       BiLSTM_pred    174.698384      0.957567         -4.962354
# 7   BiLSTM_GRU_pred    143.105541      0.734247         -4.692914
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    139.141925      0.732739         -4.125100
# 10         BNN_pred    302.140385      1.814225         -3.735531
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    140.628563      0.816599         -4.005435
# 1             PV_dw    296.204152      1.759047         -3.962646
# 2             PV_cw     59.069854      0.108935         -7.371694
# 3         LSTM_pred    207.898358      1.144129         -5.282565
# 4          GRU_pred     25.648382     -0.148677         -7.397437
# 5     LSTM_GRU_pred    176.609588      1.080585         -4.150951
# 6       BiLSTM_pred    215.068099      1.220282         -4.169398
# 7   BiLSTM_GRU_pred    219.236985      1.222446         -4.527154
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    134.364188      0.690812         -4.780814
# 10         BNN_pred    267.156292      1.542631         -3.708057
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     73.094009      0.352238         -3.455562
# 1             PV_dw    211.435811      1.174676         -4.508241
# 2             PV_cw     36.791140     -0.198990         -5.408645
# 3         LSTM_pred    199.109354      1.109259         -6.197950
# 4          GRU_pred    181.435413      0.949401         -4.147544
# 5     LSTM_GRU_pred    167.656525      0.870115         -4.196487
# 6       BiLSTM_pred     99.833271      0.406992         -6.170739
# 7   BiLSTM_GRU_pred    116.436510      0.532521         -6.494355
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    149.474537      0.765609         -5.517928
# 10         BNN_pred    145.016118      0.721741         -4.677949
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     88.910002      0.418256         -6.588878
# 1             PV_dw    220.547830      1.189819         -4.049050
# 2             PV_cw     62.731910      0.143098         -5.924261
# 3         LSTM_pred    190.110213      0.990638         -5.241937
# 4          GRU_pred    218.099520      1.159728         -4.118144
# 5     LSTM_GRU_pred    202.648964      1.083604         -4.038082
# 6       BiLSTM_pred    211.122934      1.117060         -4.776620
# 7   BiLSTM_GRU_pred    164.561277      0.845546         -5.241937
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    200.332848      1.065280         -3.977403
# 10         BNN_pred    222.053843      1.186873         -4.561546
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    140.628563      0.816599         -4.005435
# 1             PV_dw    225.486789      1.206193         -4.032732
# 2             PV_cw    105.888351      0.524378         -6.494355
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    233.751398      1.250782         -4.005717
# 5     LSTM_GRU_pred    207.070375      1.102775         -3.999375
# 6       BiLSTM_pred    218.185419      1.160101         -4.117853
# 7   BiLSTM_GRU_pred    233.838400      1.251141         -4.005435
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    205.244199      1.090976         -4.005435
# 10         BNN_pred    244.504465      1.317835         -3.971106
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    211.268725      1.165190         -4.005435
# 1             PV_dw    191.322344      1.131401         -3.741530
# 2             PV_cw    237.943499      1.367830         -3.981434
# 3         LSTM_pred    225.523963      1.282256         -4.094989
# 4          GRU_pred     37.585135     -0.006271         -8.570596
# 5     LSTM_GRU_pred    189.600906      1.162013         -4.788821
# 6       BiLSTM_pred    191.798134      1.050280         -4.623287
# 7   BiLSTM_GRU_pred    198.542859      1.071738         -4.248311
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    247.575402      1.511792         -3.982215
# 10         BNN_pred    227.153092      1.306653         -4.825588
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    175.637382      0.987846         -3.884565
# 1             PV_dw    314.110494      2.064514         -3.028819
# 2             PV_cw    174.328967      1.003258         -4.378765
# 3         LSTM_pred    153.037120      0.838847         -3.371082
# 4          GRU_pred     74.356599      0.362048         -5.808837
# 5     LSTM_GRU_pred    150.555738      0.824171         -4.865717
# 6       BiLSTM_pred    147.833228      0.853985         -3.874850
# 7   BiLSTM_GRU_pred    174.451356      0.979168         -4.708975
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    203.089748      1.357715         -3.789813
# 10         BNN_pred    121.908558      0.765913         -4.840845
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     77.714977      0.426402         -3.061465
# 1             PV_dw    181.589285      1.821828         -1.860443
# 2             PV_cw    107.406539      1.039430         -2.122334
# 3         LSTM_pred     74.871266      0.260034         -3.436989
# 4          GRU_pred     79.281918      0.591413         -2.526608
# 5     LSTM_GRU_pred     79.944770      0.531003         -3.764684
# 6       BiLSTM_pred     76.295426      0.356006         -4.863959
# 7   BiLSTM_GRU_pred     63.168084      0.168040         -4.315792
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred      4.277705     -0.463977         -7.444926
# 10         BNN_pred     90.988253      0.663752         -5.310970
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     66.267334      0.191599         -6.438495
# 1             PV_dw    252.290578      2.162089         -3.538373
# 2             PV_cw     62.903261      0.166498         -4.494859
# 3         LSTM_pred    127.469781      0.711052         -3.873159
# 4          GRU_pred     45.124555      0.061396         -6.989054
# 5     LSTM_GRU_pred     93.798309      0.617179         -4.703656
# 6       BiLSTM_pred    155.325615      0.992557         -4.789329
# 7   BiLSTM_GRU_pred    111.082438      0.567377         -3.688925
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     81.367665      0.344290         -5.437271
# 10         BNN_pred    120.083802      0.831160         -6.067185
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    110.436469      0.584910         -3.884565
# 1             PV_dw    322.684373      2.532213         -2.994552
# 2             PV_cw     54.099212      0.056925         -6.458072
# 3         LSTM_pred    129.326672      0.726870         -3.866790
# 4          GRU_pred     80.785860      0.459152         -4.621845
# 5     LSTM_GRU_pred     70.854011      0.335671         -7.706782
# 6       BiLSTM_pred    184.160902      1.164681         -4.337044
# 7   BiLSTM_GRU_pred    243.165588      1.487578         -3.457058
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    162.091857      1.058723         -4.316772
# 10         BNN_pred    168.430462      1.209881         -5.032202
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     77.714977      0.426402         -3.061465
# 1             PV_dw    147.385440      1.030040         -3.630637
# 2             PV_cw     80.460908      0.498717         -2.417327
# 3         LSTM_pred    135.070592      0.712477         -4.550707
# 4          GRU_pred     45.732158      0.068731         -4.583990
# 5     LSTM_GRU_pred    111.579611      0.835080         -3.657544
# 6       BiLSTM_pred    169.275266      1.003436         -4.859620
# 7   BiLSTM_GRU_pred     34.524800     -0.163217         -6.106701
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred     47.171333     -0.009600        -10.277123
# 10         BNN_pred     81.314706      0.390663         -7.291218
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     83.744140      0.366750         -6.588878
# 1             PV_dw    188.834793      1.261446         -4.099856
# 2             PV_cw     62.861133      0.154807         -5.883774
# 3         LSTM_pred    200.889133      1.146125         -4.390500
# 4          GRU_pred     12.636585     -0.296859         -8.600887
# 5     LSTM_GRU_pred    115.883348      0.754314         -6.284072
# 6       BiLSTM_pred    224.894033      1.368865         -4.870703
# 7   BiLSTM_GRU_pred     64.372051      0.152101         -4.852514
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    135.473920      0.755371         -4.760271
# 10         BNN_pred    184.496026      1.099678         -5.671148
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    125.729565      0.697612         -4.025445
# 1             PV_dw    246.240367      1.643098         -3.292174
# 2             PV_cw    104.552406      0.549209         -7.061899
# 3         LSTM_pred    202.866942      1.159708         -4.383281
# 4          GRU_pred     25.648382     -0.148677         -7.397437
# 5     LSTM_GRU_pred    135.307258      0.914931         -5.364162
# 6       BiLSTM_pred    201.688715      1.158488         -4.679023
# 7   BiLSTM_GRU_pred    174.268043      0.943141         -4.993216
# 8         QRNN_pred    188.471357      1.220038         -3.322718
# 9          ESN_pred    193.110694      1.166957         -3.982215
# 10         BNN_pred    263.969072      1.586888         -4.685032
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     77.714977      0.426402         -3.061465
# 1             PV_dw    149.951474      0.788864         -5.177382
# 2             PV_cw     72.958878      0.341478         -3.761571
# 3         LSTM_pred    199.109354      1.109259         -6.197950
# 4          GRU_pred    181.435413      0.949401         -4.147544
# 5     LSTM_GRU_pred    153.945373      0.780643         -4.196487
# 6       BiLSTM_pred     99.833271      0.406992         -6.170739
# 7   BiLSTM_GRU_pred    146.978727      0.764072         -5.190956
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    145.561407      0.738403         -5.536777
# 10         BNN_pred    145.016118      0.721741         -4.677949
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     83.744140      0.366750         -6.588878
# 1             PV_dw    193.788072      1.027094         -4.202010
# 2             PV_cw     85.286077      0.355693         -5.243509
# 3         LSTM_pred    190.110213      0.990638         -5.241937
# 4          GRU_pred    218.099520      1.159728         -4.118144
# 5     LSTM_GRU_pred    202.648964      1.083604         -4.038082
# 6       BiLSTM_pred    201.020480      1.059104         -4.816799
# 7   BiLSTM_GRU_pred    131.371629      0.634827         -5.258852
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    187.128824      0.990972         -4.021643
# 10         BNN_pred    174.234960      0.905440         -4.561546
# 11               __    233.838400      1.251141         -4.005435
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    123.409147      0.677584         -4.210182
# 1             PV_dw    225.486789      1.206193         -4.032732
# 2             PV_cw     95.762685      0.437255         -6.494355
# 3         LSTM_pred    214.038378      1.134682         -4.424349
# 4          GRU_pred    233.751398      1.250782         -4.005717
# 5     LSTM_GRU_pred    186.616023      0.977795         -4.716361
# 6       BiLSTM_pred    214.038378      1.134682         -4.424349
# 7   BiLSTM_GRU_pred    209.519985      1.108381         -5.241937
# 8         QRNN_pred    233.838400      1.251141         -4.005435
# 9          ESN_pred    206.095067      1.096383         -4.005435
# 10         BNN_pred    228.716169      1.226887         -4.082561
# 11               __    233.838400      1.251141         -4.005435

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_y2)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_y2)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_y2', file, 'PV')
get_final_results_1('2024_y2', file, 'PV')

get_final_results('2024_y2', dw_file, 'PV_dw')
get_final_results_1('2024_y2', dw_file, 'PV_dw')

get_final_results('2024_y2', cw_file, 'PV_cw')
get_final_results_1('2024_y2', cw_file, 'PV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:40: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-21-0fcd7c9778c9>:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-21-0fcd7c9778c9>:46: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:52: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-21-0fcd7c9778c9>:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-21-0fcd7c9778c9>:58: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:30: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-21-0fcd7c9778c9>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-21-0fcd7c9778c9>:34: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-21-0fcd7c9778c9>:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    166.850204      1.336725         -4.659127
# 1             PV_dw    219.231591      1.638423         -4.236136
# 2             PV_cw    184.801537      1.503447         -4.588535
# 3         LSTM_pred    163.075614      1.223655         -5.258589
# 4          GRU_pred    197.143673      1.618049         -4.596920
# 5     LSTM_GRU_pred    174.738837      1.418009         -4.684593
# 6       BiLSTM_pred    153.722215      1.259093         -4.236136
# 7   BiLSTM_GRU_pred    176.851299      1.436295         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    176.763940      1.447123         -4.236136
# 10         BNN_pred    148.905090      0.988876         -4.888776
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    176.785524      1.573019         -3.480039
# 1             PV_dw    175.651801      1.279498         -4.236136
# 2             PV_cw    104.392456      0.648759         -5.091455
# 3         LSTM_pred    133.942946      1.043305         -5.258589
# 4          GRU_pred    161.906453      1.319798         -4.728584
# 5     LSTM_GRU_pred    128.204069      0.968040         -5.381393
# 6       BiLSTM_pred    120.449769      0.853271         -4.754440
# 7   BiLSTM_GRU_pred    127.601757      0.909623         -5.258589
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    130.900788      0.912800         -5.809844
# 10         BNN_pred    133.729372      0.893965         -4.297262
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    195.931764      1.709876         -2.231160
# 1             PV_dw    113.970196      0.824246         -4.435401
# 2             PV_cw     50.560050      0.188576         -4.236136
# 3         LSTM_pred    118.629669      0.898915         -5.258589
# 4          GRU_pred    145.233811      1.158085         -3.471583
# 5     LSTM_GRU_pred    142.981650      1.253177         -3.572895
# 6       BiLSTM_pred    140.439142      1.137140         -4.236136
# 7   BiLSTM_GRU_pred    167.477065      1.366992         -5.258589
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     57.327037      0.167096         -4.660324
# 10         BNN_pred    137.549342      0.973086         -4.359663
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    212.116869      1.959810         -2.959251
# 1             PV_dw    175.651801      1.279498         -4.236136
# 2             PV_cw     72.465558      0.330177         -5.091576
# 3         LSTM_pred    110.391865      0.804102         -5.258589
# 4          GRU_pred    156.276391      1.308776         -5.439677
# 5     LSTM_GRU_pred    121.388818      0.929558         -6.181226
# 6       BiLSTM_pred    134.884107      1.032379         -4.236136
# 7   BiLSTM_GRU_pred    169.800087      1.390300         -5.258589
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     76.645522      0.365713         -4.960999
# 10         BNN_pred    135.606691      0.914023         -4.290158
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    177.226550      1.577540         -3.478735
# 1             PV_dw    175.651801      1.279498         -4.236136
# 2             PV_cw    117.360002      0.784599         -5.091455
# 3         LSTM_pred    137.200934      1.079845         -5.258589
# 4          GRU_pred    163.559830      1.336247         -4.721865
# 5     LSTM_GRU_pred    129.809487      0.984995         -5.373746
# 6       BiLSTM_pred    134.310784      1.004029         -4.236136
# 7   BiLSTM_GRU_pred    121.264238      0.849019         -5.258589
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    146.321880      1.083229         -5.809844
# 10         BNN_pred    133.729372      0.893965         -4.297262
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    208.396504      1.654530         -4.878345
# 1             PV_dw    183.661153      1.339736         -4.236136
# 2             PV_cw     73.370917      0.456647         -5.100446
# 3         LSTM_pred    169.121885      1.317499         -5.258589
# 4          GRU_pred    197.592647      1.639530         -4.389578
# 5     LSTM_GRU_pred    168.212340      1.459799         -4.487442
# 6       BiLSTM_pred    150.973446      1.243763         -4.236136
# 7   BiLSTM_GRU_pred    171.748101      1.434165         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     41.332534     -0.060960         -4.660324
# 10         BNN_pred    160.997939      1.122589         -4.919161
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    208.396504      1.776030         -4.236136
# 1             PV_dw    219.231591      1.638423         -4.236136
# 2             PV_cw    157.423223      1.135017         -5.091576
# 3         LSTM_pred    160.512247      1.229900         -5.258589
# 4          GRU_pred    190.448869      1.607708         -5.291133
# 5     LSTM_GRU_pred    166.766266      1.387057         -5.398530
# 6       BiLSTM_pred    141.767763      1.147831         -4.236136
# 7   BiLSTM_GRU_pred    171.748101      1.456565         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     82.657430      0.398119         -4.960999
# 10         BNN_pred    149.996384      0.999381         -4.884137
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    167.287506      1.340786         -4.657382
# 1             PV_dw    219.231591      1.638423         -4.236136
# 2             PV_cw    178.741505      1.450005         -4.612125
# 3         LSTM_pred    167.967801      1.287103         -5.258589
# 4          GRU_pred    197.947562      1.625675         -4.593835
# 5     LSTM_GRU_pred    175.527681      1.425670         -4.681450
# 6       BiLSTM_pred    153.722215      1.259093         -4.236136
# 7   BiLSTM_GRU_pred    155.802190      1.253049         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    167.608610      1.366989         -4.236136
# 10         BNN_pred    148.905090      0.988876         -4.888776
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    221.351004      1.761981         -4.878345
# 1             PV_dw    174.225075      1.384843         -5.045630
# 2             PV_cw    108.945543      0.856420         -4.936825
# 3         LSTM_pred    176.366592      1.394336         -4.839321
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    184.125990      1.486637         -4.591153
# 6       BiLSTM_pred    174.795202      1.401166         -4.845794
# 7   BiLSTM_GRU_pred    176.366592      1.394336         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    155.692100      1.156727         -4.660324
# 10         BNN_pred    172.334083      1.419905         -4.780880
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    221.351004      1.882237         -4.236136
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    184.125990      1.346192         -5.091576
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    179.707613      1.445244         -4.608348
# 5     LSTM_GRU_pred    179.707613      1.445244         -4.608348
# 6       BiLSTM_pred    179.801301      1.446015         -4.607982
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.294763         -4.960999
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    179.801301      1.446015         -4.607982
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    179.801301      1.446015         -4.607982
# 3         LSTM_pred    179.801301      1.446015         -4.607982
# 4          GRU_pred    180.593544      1.453272         -4.604890
# 5     LSTM_GRU_pred    180.593544      1.453272         -4.604890
# 6       BiLSTM_pred    179.801301      1.446015         -4.607982
# 7   BiLSTM_GRU_pred    180.593544      1.453272         -4.604890
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.446015         -4.607982
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    166.850204      1.336725         -4.659127
# 1             PV_dw    185.025256      1.296637         -4.674717
# 2             PV_cw    161.928849      1.288754         -4.678861
# 3         LSTM_pred    183.092054      1.282726         -4.682540
# 4          GRU_pred    191.764408      1.599223         -4.553894
# 5     LSTM_GRU_pred    164.824972      1.362285         -4.659214
# 6       BiLSTM_pred    171.716218      1.286804         -4.680759
# 7   BiLSTM_GRU_pred    173.269890      1.201872         -4.721741
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    156.027695      1.152512         -4.689073
# 10         BNN_pred    186.572762      1.314049         -4.668621
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    205.755971      1.820680         -3.406245
# 1             PV_dw    206.225838      1.697550         -3.791267
# 2             PV_cw    120.480075      0.857532         -5.091455
# 3         LSTM_pred    104.762521      0.584123         -5.399291
# 4          GRU_pred    204.220907      1.744925         -3.661796
# 5     LSTM_GRU_pred    166.551836      1.347291         -4.281859
# 6       BiLSTM_pred    146.126451      1.122928         -4.236136
# 7   BiLSTM_GRU_pred    199.675401      1.619610         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    153.024257      1.144272         -5.809844
# 10         BNN_pred    145.081295      1.008244         -4.977665
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    186.115217      1.693444         -2.862087
# 1             PV_dw    187.866140      1.614460         -3.481710
# 2             PV_cw     45.109436     -0.005980         -4.660324
# 3         LSTM_pred     81.104876      0.476021         -4.957256
# 4          GRU_pred    221.874168      2.058197         -3.208894
# 5     LSTM_GRU_pred    165.423277      1.457154         -3.393908
# 6       BiLSTM_pred    113.054793      0.816883         -5.091576
# 7   BiLSTM_GRU_pred    144.953600      1.132094         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    106.494233      0.795088         -4.812167
# 10         BNN_pred    124.868377      0.836683         -5.095593
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.808915      2.091879         -2.862087
# 1             PV_dw    185.374366      1.512547         -3.857958
# 2             PV_cw     79.300890      0.530319         -4.236136
# 3         LSTM_pred     98.928775      0.662191         -4.236136
# 4          GRU_pred    223.034336      1.978285         -4.177015
# 5     LSTM_GRU_pred    164.063528      1.372609         -4.406200
# 6       BiLSTM_pred    134.885740      1.028576         -4.236136
# 7   BiLSTM_GRU_pred    151.645309      1.186379         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    123.180908      0.966466         -4.660324
# 10         BNN_pred    151.018989      1.072613         -4.986752
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    206.207854      1.825114         -3.404969
# 1             PV_dw    206.225838      1.697550         -3.791267
# 2             PV_cw    120.595137      0.971074         -4.236136
# 3         LSTM_pred     77.840168      0.418405         -5.478856
# 4          GRU_pred    193.516904      1.659822         -5.197163
# 5     LSTM_GRU_pred    144.359958      1.115092         -5.391915
# 6       BiLSTM_pred    148.430248      1.034760         -4.236136
# 7   BiLSTM_GRU_pred    171.941381      1.376487         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    166.787101      1.309926         -4.236136
# 10         BNN_pred    145.081295      1.008244         -4.977665
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    176.843751      1.452000         -4.239907
# 1             PV_dw    175.645086      1.250944         -4.236136
# 2             PV_cw    101.074365      0.675391         -4.981029
# 3         LSTM_pred    149.511350      1.121438         -4.957256
# 4          GRU_pred    220.092364      1.979913         -4.249123
# 5     LSTM_GRU_pred    181.400139      1.615943         -4.388287
# 6       BiLSTM_pred    152.903798      1.146617         -5.091576
# 7   BiLSTM_GRU_pred    157.333078      1.179246         -4.962355
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     97.849388      0.672263         -4.812167
# 10         BNN_pred    177.383005      1.268089         -4.843794
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    208.396504      1.753990         -4.236136
# 1             PV_dw    185.025256      1.296637         -4.674717
# 2             PV_cw    155.281255      1.241963         -4.738821
# 3         LSTM_pred    168.463048      1.279108         -4.915087
# 4          GRU_pred    226.349215      2.007241         -4.173128
# 5     LSTM_GRU_pred    170.845595      1.482296         -4.350214
# 6       BiLSTM_pred    154.899719      1.147222         -4.972810
# 7   BiLSTM_GRU_pred    157.333078      1.179246         -4.962355
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    112.147185      0.823509         -4.660324
# 10         BNN_pred    194.903148      1.393531         -4.668621
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    167.287506      1.340786         -4.657382
# 1             PV_dw    185.025256      1.296637         -4.674717
# 2             PV_cw    133.070114      1.008241         -4.798029
# 3         LSTM_pred    170.272188      1.281950         -4.686534
# 4          GRU_pred    196.751779      1.688494         -5.190575
# 5     LSTM_GRU_pred    155.863325      1.281442         -5.299341
# 6       BiLSTM_pred    162.294124      1.204631         -4.718703
# 7   BiLSTM_GRU_pred    149.785194      1.103323         -4.770039
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    137.893777      1.007374         -4.689195
# 10         BNN_pred    186.572762      1.314049         -4.668621
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    189.459993      1.565221         -4.239907
# 1             PV_dw    189.374509      1.561407         -4.236136
# 2             PV_cw    180.655876      1.345261         -4.660324
# 3         LSTM_pred    176.366592      1.263542         -4.960999
# 4          GRU_pred    190.814673      1.550142         -4.565365
# 5     LSTM_GRU_pred    184.125990      1.486637         -4.591153
# 6       BiLSTM_pred    176.366592      1.274679         -5.091576
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    193.101159      1.452994         -4.812167
# 10         BNN_pred    170.663987      1.404260         -4.780880
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    221.351004      1.860337         -4.236136
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    186.490181      1.474814         -4.614173
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    179.707613      1.445244         -4.608348
# 6       BiLSTM_pred    176.366592      1.415396         -4.839321
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.330107         -4.660324
# 10         BNN_pred    188.084147      1.525522         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    179.801301      1.446015         -4.607982
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    179.801301      1.424961         -4.607982
# 3         LSTM_pred    179.707613      1.445244         -4.608348
# 4          GRU_pred    179.707613      1.445244         -4.608348
# 5     LSTM_GRU_pred    180.593544      1.453272         -4.604890
# 6       BiLSTM_pred    179.801301      1.446015         -4.607982
# 7   BiLSTM_GRU_pred    179.707613      1.445244         -4.608348
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.349846         -4.689195
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    188.724792      1.380376         -5.956153
# 1             PV_dw    220.999833      1.704850         -4.449688
# 2             PV_cw    159.473589      1.121657         -5.959856
# 3         LSTM_pred    181.169929      1.420549         -4.236136
# 4          GRU_pred    205.113322      1.753277         -3.659084
# 5     LSTM_GRU_pred    158.038282      1.363993         -4.281859
# 6       BiLSTM_pred    135.211210      1.013332         -4.236136
# 7   BiLSTM_GRU_pred    162.602065      1.125650         -4.803070
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    148.156201      1.020405         -5.959856
# 10         BNN_pred    133.714760      0.899492         -5.258589
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    136.557674      0.931627         -5.956153
# 1             PV_dw    156.748084      1.330053         -2.883542
# 2             PV_cw    136.982351      0.975658         -5.959856
# 3         LSTM_pred    221.031344      1.905340         -5.258589
# 4          GRU_pred     44.719135      0.054422         -6.126230
# 5     LSTM_GRU_pred     99.210914      0.738983         -4.060959
# 6       BiLSTM_pred    131.364447      1.083781         -5.258589
# 7   BiLSTM_GRU_pred     61.396248      0.244624         -5.303824
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    139.239261      1.017609         -4.783630
# 10         BNN_pred     86.679752      0.452616         -5.228681
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    186.679496      1.691844         -4.236136
# 1             PV_dw     67.726242      0.403215         -2.676175
# 2             PV_cw     27.499230     -0.234653         -3.734636
# 3         LSTM_pred     98.584052      0.782208         -5.258589
# 4          GRU_pred     18.758268     -0.368817         -3.324276
# 5     LSTM_GRU_pred    121.255743      1.248797         -2.466263
# 6       BiLSTM_pred     54.195939      0.194688         -5.110742
# 7   BiLSTM_GRU_pred    118.955228      1.126915         -2.917960
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    128.825646      1.111984         -5.014010
# 10         BNN_pred     66.707299      0.233721         -3.118880
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.427065      1.241065         -4.236136
# 1             PV_dw    147.378335      1.319783         -2.677383
# 2             PV_cw     68.436053      0.339541         -4.239907
# 3         LSTM_pred    142.264735      1.283115         -5.258589
# 4          GRU_pred     48.156661      0.099921         -4.109394
# 5     LSTM_GRU_pred    134.293905      1.287211         -3.517267
# 6       BiLSTM_pred     88.555751      0.633484         -5.258589
# 7   BiLSTM_GRU_pred     80.273771      0.497667         -3.966310
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    130.357271      1.095059         -4.972308
# 10         BNN_pred    112.248367      0.789325         -4.179416
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    157.647820      1.288485         -4.236136
# 1             PV_dw    142.336656      1.165245         -3.770532
# 2             PV_cw    123.063496      0.844519         -4.812167
# 3         LSTM_pred    198.109400      1.821596         -5.258589
# 4          GRU_pred     77.140200      0.449245         -4.800333
# 5     LSTM_GRU_pred    121.200706      1.023018         -4.623567
# 6       BiLSTM_pred    128.169770      0.979363         -5.258589
# 7   BiLSTM_GRU_pred     55.150409      0.177508         -5.303824
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    171.085792      1.397451         -4.735410
# 10         BNN_pred    109.815452      0.734860         -4.614346
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    186.679496      1.691844         -4.236136
# 1             PV_dw    169.230339      1.334909         -2.787588
# 2             PV_cw     53.009793      0.172792         -4.926173
# 3         LSTM_pred    112.889860      0.835580         -4.236136
# 4          GRU_pred    191.601853      1.668437         -3.251581
# 5     LSTM_GRU_pred    193.735907      2.107737         -2.467113
# 6       BiLSTM_pred     89.588443      0.583532         -4.236136
# 7   BiLSTM_GRU_pred    161.444547      1.421888         -2.629398
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    134.741064      1.118939         -4.987872
# 10         BNN_pred    160.080629      1.349136         -3.147721
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.427065      1.241065         -4.236136
# 1             PV_dw    229.859555      1.843422         -3.481710
# 2             PV_cw    134.268400      0.975246         -5.054168
# 3         LSTM_pred    158.646964      1.225686         -4.236136
# 4          GRU_pred    224.437244      1.903883         -3.205366
# 5     LSTM_GRU_pred    167.364701      1.607180         -3.358732
# 6       BiLSTM_pred    105.456784      0.727576         -4.236136
# 7   BiLSTM_GRU_pred    153.012860      1.067767         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    126.238767      1.007296         -4.990491
# 10         BNN_pred    162.839289      1.297826         -4.309101
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    210.782960      1.722947         -4.236136
# 1             PV_dw    221.119802      1.705977         -4.441755
# 2             PV_cw    159.663252      1.133301         -4.812167
# 3         LSTM_pred    158.646964      1.225686         -4.236136
# 4          GRU_pred    216.053675      1.908696         -4.200993
# 5     LSTM_GRU_pred    156.340820      1.398677         -4.396966
# 6       BiLSTM_pred    113.144961      0.801143         -4.236136
# 7   BiLSTM_GRU_pred    161.885824      1.149519         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    134.401590      0.969272         -4.792398
# 10         BNN_pred    135.014947      0.916821         -5.258589
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    186.679496      1.691844         -4.236136
# 1             PV_dw    193.669869      1.608371         -4.236136
# 2             PV_cw     74.914813      0.455548         -4.738257
# 3         LSTM_pred    195.917722      1.581993         -4.236136
# 4          GRU_pred    169.378274      1.219601         -4.960999
# 5     LSTM_GRU_pred    196.821351      1.606877         -4.236136
# 6       BiLSTM_pred    194.181365      1.585983         -4.800596
# 7   BiLSTM_GRU_pred    223.560225      1.918224         -4.236136
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    134.741064      1.118939         -4.987872
# 10         BNN_pred    196.839849      1.576731         -4.689195
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.427065      1.241065         -4.236136
# 1             PV_dw    189.374509      1.561407         -4.236136
# 2             PV_cw    156.282997      1.177685         -4.957941
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    190.814673      1.400349         -4.960999
# 5     LSTM_GRU_pred    190.814673      1.550142         -4.565365
# 6       BiLSTM_pred    176.366592      1.415396         -4.839321
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    126.238767      1.007296         -4.990491
# 10         BNN_pred    172.334083      1.419905         -4.780880
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    179.801301      1.381871         -4.607982
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    170.609558      1.229424         -4.812167
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    184.125990      1.486637         -4.591153
# 6       BiLSTM_pred    176.460014      1.416168         -4.838937
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.381438         -4.607982
# 10         BNN_pred    184.719403      1.495579         -4.838937
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    138.631970      0.935705         -5.956153
# 1             PV_dw    174.638243      1.340886         -3.559271
# 2             PV_cw    148.458811      1.039012         -5.959856
# 3         LSTM_pred    106.831843      0.602530         -4.951367
# 4          GRU_pred    178.405385      1.464495         -3.808942
# 5     LSTM_GRU_pred    162.475327      1.482448         -3.795106
# 6       BiLSTM_pred     97.722288      0.509322         -4.992457
# 7   BiLSTM_GRU_pred    148.854095      1.142847         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    119.202433      0.745518         -5.813103
# 10         BNN_pred    148.938952      1.140028         -3.933805
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    133.629567      0.906352         -5.956153
# 1             PV_dw    163.359663      1.448151         -2.883542
# 2             PV_cw     86.220788      0.455551         -5.959856
# 3         LSTM_pred    196.951055      1.910594         -5.258589
# 4          GRU_pred     44.719135      0.054422         -6.126230
# 5     LSTM_GRU_pred     51.682019      0.145987         -4.057113
# 6       BiLSTM_pred    126.770868      1.038318         -5.258589
# 7   BiLSTM_GRU_pred    137.771949      1.111264         -3.920436
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    113.982674      0.767176         -4.892086
# 10         BNN_pred     82.712852      0.412609         -5.247838
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    127.908772      1.077679         -4.236136
# 1             PV_dw     59.171550      0.302572         -2.467113
# 2             PV_cw      0.151629     -0.816361         -2.997366
# 3         LSTM_pred     57.185563      0.255477         -5.258589
# 4          GRU_pred     18.758268     -0.368817         -3.324276
# 5     LSTM_GRU_pred     68.671495      0.481465         -2.561655
# 6       BiLSTM_pred     46.516868      0.080894         -5.110742
# 7   BiLSTM_GRU_pred     57.814106      0.284848         -2.917960
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     90.140058      0.730988         -5.191941
# 10         BNN_pred     50.023748     -0.041900         -2.862087
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    155.330653      1.325487         -4.236136
# 1             PV_dw     97.853742      0.792153         -2.466263
# 2             PV_cw     37.934916     -0.039326         -4.239907
# 3         LSTM_pred     88.420888      0.694934         -5.258589
# 4          GRU_pred     48.156661      0.099921         -4.109394
# 5     LSTM_GRU_pred    122.237287      1.227724         -2.466263
# 6       BiLSTM_pred     81.073069      0.570735         -5.110742
# 7   BiLSTM_GRU_pred    100.484586      0.772941         -3.920436
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     82.643546      0.586736         -5.191445
# 10         BNN_pred     98.388583      0.670403         -2.842942
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    158.567006      1.318833         -4.236136
# 1             PV_dw    140.797817      1.265501         -2.462335
# 2             PV_cw     81.739498      0.498822         -4.239907
# 3         LSTM_pred     88.725164      0.692978         -5.258589
# 4          GRU_pred     99.329497      0.710739         -4.109833
# 5     LSTM_GRU_pred    114.290414      0.996765         -3.049695
# 6       BiLSTM_pred    111.191497      0.944347         -5.258589
# 7   BiLSTM_GRU_pred     94.357977      0.652258         -3.920436
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    109.125263      0.822972         -5.011112
# 10         BNN_pred     96.961824      0.610677         -3.293556
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.340664      1.307031         -4.236136
# 1             PV_dw    100.552343      0.800506         -2.787588
# 2             PV_cw     53.568631      0.186590         -3.617902
# 3         LSTM_pred     82.405176      0.539851         -4.236136
# 4          GRU_pred    115.333382      0.954195         -3.251581
# 5     LSTM_GRU_pred    100.033603      1.086022         -2.561655
# 6       BiLSTM_pred     80.783656      0.516762         -4.236136
# 7   BiLSTM_GRU_pred     96.772201      0.838768         -2.782266
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    134.741064      1.118939         -4.987872
# 10         BNN_pred    123.437929      1.017302         -3.183498
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    161.134442      1.379277         -4.236136
# 1             PV_dw    130.061690      1.037215         -3.716215
# 2             PV_cw    123.803184      0.934748         -4.239907
# 3         LSTM_pred     70.648319      0.352529         -4.236136
# 4          GRU_pred    180.638975      1.596726         -3.295831
# 5     LSTM_GRU_pred    148.424354      1.487368         -3.414125
# 6       BiLSTM_pred     96.048252      0.667038         -4.236136
# 7   BiLSTM_GRU_pred    102.444099      0.713772         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    126.238767      1.007296         -4.990491
# 10         BNN_pred    144.256019      1.150006         -3.408445
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    163.679452      1.337038         -4.236136
# 1             PV_dw    173.668959      1.348085         -3.716215
# 2             PV_cw    125.106653      0.898980         -4.239907
# 3         LSTM_pred     79.556553      0.451810         -4.236136
# 4          GRU_pred    202.629763      1.734460         -4.322369
# 5     LSTM_GRU_pred    157.104832      1.490227         -4.472584
# 6       BiLSTM_pred     72.608924      0.373050         -4.236136
# 7   BiLSTM_GRU_pred    124.517428      0.928113         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    136.609765      1.049062         -4.904076
# 10         BNN_pred    139.212959      1.060357         -3.491978
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.340664      1.307031         -4.236136
# 1             PV_dw    199.132467      1.713663         -4.236136
# 2             PV_cw     66.493716      0.345438         -4.743776
# 3         LSTM_pred    260.029086      2.294918         -4.236136
# 4          GRU_pred    169.378274      1.219601         -4.960999
# 5     LSTM_GRU_pred    201.950140      1.660383         -4.236136
# 6       BiLSTM_pred    194.181365      1.585983         -4.800596
# 7   BiLSTM_GRU_pred    185.182626      1.621029         -4.236136
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    134.741064      1.118939         -4.987872
# 10         BNN_pred    196.839849      1.576731         -4.689195
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    161.134442      1.379277         -4.236136
# 1             PV_dw    190.173182      1.568827         -4.236136
# 2             PV_cw    160.008092      1.214230         -4.957941
# 3         LSTM_pred    176.366592      1.394336         -4.839321
# 4          GRU_pred    190.814673      1.400349         -4.960999
# 5     LSTM_GRU_pred    190.814673      1.550142         -4.565365
# 6       BiLSTM_pred    176.366592      1.415396         -4.839321
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    126.238767      1.007296         -4.990491
# 10         BNN_pred    170.663987      1.404260         -4.780880
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    163.679452      1.337038         -4.236136
# 1             PV_dw    189.374509      1.561407         -4.236136
# 2             PV_cw    151.482942      1.127614         -4.721306
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    184.125990      1.486637         -4.591153
# 6       BiLSTM_pred    176.366592      1.415396         -4.839321
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    178.218447      1.366828         -4.614173
# 10         BNN_pred    189.896352      1.545128         -4.432625
# 11               __    179.801301      1.446015         -4.607982

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    166.850204      1.336725         -4.659127
# 1             PV_dw    187.691900      1.346689         -4.664222
# 2             PV_cw    193.620539      1.581105         -4.561741
# 3         LSTM_pred    163.075614      1.223655         -5.258589
# 4          GRU_pred    214.632878      1.666309         -4.582758
# 5     LSTM_GRU_pred    158.669606      1.311612         -4.683966
# 6       BiLSTM_pred    153.722215      1.259093         -4.236136
# 7   BiLSTM_GRU_pred    192.481086      1.419149         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    203.031815      1.703725         -4.236136
# 10         BNN_pred    151.852918      1.018707         -4.876265
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    176.785524      1.573019         -3.480039
# 1             PV_dw    143.002291      0.966883         -4.914183
# 2             PV_cw    121.730399      0.793906         -4.932477
# 3         LSTM_pred    133.942946      1.043305         -5.258589
# 4          GRU_pred    224.043123      1.814046         -4.598731
# 5     LSTM_GRU_pred    125.545564      0.930722         -5.337405
# 6       BiLSTM_pred    120.449769      0.853271         -4.754440
# 7   BiLSTM_GRU_pred    130.417518      0.823400         -5.258589
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    148.114187      1.075904         -5.809844
# 10         BNN_pred    162.061891      1.189489         -4.227942
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    195.931764      1.709876         -2.231160
# 1             PV_dw    127.007850      0.829099         -4.377329
# 2             PV_cw     68.367352      0.229596         -4.827847
# 3         LSTM_pred    118.629669      0.898915         -5.258589
# 4          GRU_pred    252.907114      2.225881         -4.241101
# 5     LSTM_GRU_pred    142.483202      1.221865         -4.007696
# 6       BiLSTM_pred    140.439142      1.137140         -4.236136
# 7   BiLSTM_GRU_pred    165.617676      1.348241         -5.258589
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    142.428877      1.178002         -4.660324
# 10         BNN_pred    173.211315      1.373404         -3.481710
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    212.116869      1.959810         -2.959251
# 1             PV_dw    139.314858      0.930495         -4.930088
# 2             PV_cw     51.369417      0.004784         -5.270780
# 3         LSTM_pred    110.391865      0.804102         -5.258589
# 4          GRU_pred    247.589807      2.111314         -4.953780
# 5     LSTM_GRU_pred    118.305742      0.885931         -6.133116
# 6       BiLSTM_pred    134.884107      1.032379         -4.236136
# 7   BiLSTM_GRU_pred    167.936998      1.371550         -5.258589
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    162.494278      1.332009         -4.960999
# 10         BNN_pred    153.195988      1.107931         -4.260447
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    177.226550      1.577540         -3.478735
# 1             PV_dw    139.314858      0.930495         -4.930088
# 2             PV_cw    136.672577      0.952324         -4.875233
# 3         LSTM_pred    137.200934      1.079845         -5.258589
# 4          GRU_pred    211.497990      1.700650         -4.574174
# 5     LSTM_GRU_pred    127.147200      0.947488         -5.329820
# 6       BiLSTM_pred    134.310784      1.004029         -4.236136
# 7   BiLSTM_GRU_pred    124.064173      0.762704         -5.258589
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    180.240568      1.438607         -5.809844
# 10         BNN_pred    164.057606      1.213735         -4.220693
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    208.396504      1.654530         -4.878345
# 1             PV_dw    183.825619      1.323352         -4.712307
# 2             PV_cw    142.731739      1.298642         -4.499573
# 3         LSTM_pred    169.121885      1.317499         -5.258589
# 4          GRU_pred    244.396284      2.014527         -4.277590
# 5     LSTM_GRU_pred    159.640831      1.418529         -4.470628
# 6       BiLSTM_pred    150.973446      1.243763         -4.236136
# 7   BiLSTM_GRU_pred    184.952320      1.488709         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    111.988408      0.837833         -4.660324
# 10         BNN_pred    163.461350      1.134999         -4.619356
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    208.396504      1.776030         -4.236136
# 1             PV_dw    187.691900      1.346689         -4.664222
# 2             PV_cw    200.895803      1.583810         -4.641552
# 3         LSTM_pred    160.512247      1.229900         -5.258589
# 4          GRU_pred    239.115097      1.915920         -5.009198
# 5     LSTM_GRU_pred    150.352834      1.272175         -5.399934
# 6       BiLSTM_pred    141.767763      1.147831         -4.236136
# 7   BiLSTM_GRU_pred    187.310113      1.511178         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    128.773245      0.906353         -4.960999
# 10         BNN_pred    151.852918      1.018707         -4.876265
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    167.287506      1.340786         -4.657382
# 1             PV_dw    187.691900      1.346689         -4.664222
# 2             PV_cw    215.656752      1.841626         -4.582935
# 3         LSTM_pred    167.967801      1.287103         -5.258589
# 4          GRU_pred    215.448512      1.656326         -4.579683
# 5     LSTM_GRU_pred    159.447660      1.319215         -4.680823
# 6       BiLSTM_pred    153.722215      1.259093         -4.236136
# 7   BiLSTM_GRU_pred    171.152424      1.235747         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    193.672118      1.623662         -4.236136
# 10         BNN_pred    151.852918      1.018707         -4.876265
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    221.351004      1.761981         -4.878345
# 1             PV_dw    188.084147      1.525522         -4.607982
# 2             PV_cw    114.539258      0.922102         -4.499573
# 3         LSTM_pred    176.366592      1.394336         -4.839321
# 4          GRU_pred    187.466842      1.522063         -4.827741
# 5     LSTM_GRU_pred    184.125990      1.486637         -4.591153
# 6       BiLSTM_pred    174.795202      1.401166         -4.845794
# 7   BiLSTM_GRU_pred    176.366592      1.394336         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    180.593544      1.337497         -4.660324
# 10         BNN_pred    190.695335      1.552199         -4.429651
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    221.351004      1.882237         -4.236136
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    184.125990      1.346192         -5.091576
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    187.989802      1.524752         -4.608348
# 5     LSTM_GRU_pred    179.707613      1.445244         -4.608348
# 6       BiLSTM_pred    179.801301      1.446015         -4.607982
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.294763         -4.960999
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    179.801301      1.446015         -4.607982
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    179.801301      1.446015         -4.607982
# 3         LSTM_pred    179.801301      1.446015         -4.607982
# 4          GRU_pred    180.593544      1.453272         -4.604890
# 5     LSTM_GRU_pred    180.593544      1.453272         -4.604890
# 6       BiLSTM_pred    179.801301      1.446015         -4.607982
# 7   BiLSTM_GRU_pred    180.593544      1.453272         -4.604890
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.446015         -4.607982
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    166.850204      1.336725         -4.659127
# 1             PV_dw    172.781129      1.188740         -4.732915
# 2             PV_cw    163.525206      1.185220         -4.689073
# 3         LSTM_pred    183.092054      1.282726         -4.682540
# 4          GRU_pred    214.045351      1.621189         -4.529689
# 5     LSTM_GRU_pred    167.390431      1.408307         -4.648975
# 6       BiLSTM_pred    171.716218      1.286804         -4.680759
# 7   BiLSTM_GRU_pred    171.401275      1.184723         -4.721741
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    157.256412      1.162976         -4.689073
# 10         BNN_pred    184.407424      1.296685         -4.677156
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    205.755971      1.820680         -3.406245
# 1             PV_dw    156.087360      1.091314         -4.858562
# 2             PV_cw    128.930829      0.848339         -5.091455
# 3         LSTM_pred    104.762521      0.584123         -5.399291
# 4          GRU_pred    186.684066      1.423313         -4.884181
# 5     LSTM_GRU_pred    156.384123      1.347291         -4.281859
# 6       BiLSTM_pred    146.126451      1.122928         -4.236136
# 7   BiLSTM_GRU_pred    202.671139      1.530052         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    189.083485      1.530045         -5.809844
# 10         BNN_pred    155.055532      1.075907         -4.871141
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    186.115217      1.693444         -2.862087
# 1             PV_dw    145.490521      1.006559         -4.574616
# 2             PV_cw     72.002785      0.262875         -4.660324
# 3         LSTM_pred     81.104876      0.476021         -4.957256
# 4          GRU_pred    240.575512      1.994320         -3.880284
# 5     LSTM_GRU_pred    157.081977      1.477242         -3.388580
# 6       BiLSTM_pred    128.642540      0.976583         -4.236136
# 7   BiLSTM_GRU_pred    143.130084      1.113439         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    128.329451      1.040039         -4.812167
# 10         BNN_pred    172.869056      1.272387         -5.101301
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    233.808915      2.091879         -2.862087
# 1             PV_dw    149.822248      1.031276         -4.885035
# 2             PV_cw     98.555736      0.560645         -4.876812
# 3         LSTM_pred     98.928775      0.662191         -4.236136
# 4          GRU_pred    221.947248      1.780288         -4.571212
# 5     LSTM_GRU_pred    153.917503      1.372609         -4.406200
# 6       BiLSTM_pred    134.885740      1.028576         -4.236136
# 7   BiLSTM_GRU_pred    149.811135      1.167956         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    154.148244      1.283805         -4.660324
# 10         BNN_pred    150.741508      1.040253         -4.889403
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    206.207854      1.825114         -3.404969
# 1             PV_dw    149.822248      1.031276         -4.885035
# 2             PV_cw    126.190511      0.836309         -5.279927
# 3         LSTM_pred     77.840168      0.418405         -5.478856
# 4          GRU_pred    200.390478      1.522669         -4.594916
# 5     LSTM_GRU_pred    133.534414      1.106350         -5.395964
# 6       BiLSTM_pred    148.430248      1.034760         -4.236136
# 7   BiLSTM_GRU_pred    170.074882      1.358231         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    193.904475      1.542789         -4.236136
# 10         BNN_pred    161.580008      1.142107         -4.843780
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    176.843751      1.452000         -4.239907
# 1             PV_dw    165.996459      1.127506         -4.740358
# 2             PV_cw     95.334008      0.611783         -4.660324
# 3         LSTM_pred    149.511350      1.121438         -4.957256
# 4          GRU_pred    245.465310      1.993701         -4.240806
# 5     LSTM_GRU_pred    179.572957      1.643143         -4.395084
# 6       BiLSTM_pred    169.049609      1.292192         -4.912621
# 7   BiLSTM_GRU_pred    162.436535      1.230612         -4.962355
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     98.557911      0.681922         -4.812167
# 10         BNN_pred    195.967911      1.409094         -4.884378
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    208.396504      1.753990         -4.236136
# 1             PV_dw    172.781129      1.188740         -4.732915
# 2             PV_cw    137.553712      1.066911         -4.779118
# 3         LSTM_pred    168.463048      1.279108         -4.915087
# 4          GRU_pred    226.763622      1.785484         -4.998621
# 5     LSTM_GRU_pred    175.624858      1.556399         -4.332529
# 6       BiLSTM_pred    154.899719      1.147222         -4.972810
# 7   BiLSTM_GRU_pred    162.436535      1.230612         -4.962355
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    118.478420      0.901570         -4.660324
# 10         BNN_pred    191.097697      1.360107         -4.650885
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    167.287506      1.340786         -4.657382
# 1             PV_dw    172.781129      1.188740         -4.732915
# 2             PV_cw    126.361212      0.847073         -4.878345
# 3         LSTM_pred    170.272188      1.281950         -4.686534
# 4          GRU_pred    214.860590      1.628605         -4.526649
# 5     LSTM_GRU_pred    158.409047      1.326390         -5.287695
# 6       BiLSTM_pred    162.294124      1.204631         -4.718703
# 7   BiLSTM_GRU_pred    154.855367      1.154237         -4.770039
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    144.371583      1.073724         -4.689195
# 10         BNN_pred    191.097697      1.360107         -4.650885
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    189.459993      1.565221         -4.239907
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    184.488197      1.382044         -4.660324
# 3         LSTM_pred    176.366592      1.263542         -4.960999
# 4          GRU_pred    189.062120      1.536431         -4.821264
# 5     LSTM_GRU_pred    184.125990      1.486637         -4.591153
# 6       BiLSTM_pred    176.366592      1.415396         -4.839321
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    187.113153      1.394943         -4.812167
# 10         BNN_pred    195.778686      1.600328         -4.794184
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    221.351004      1.860337         -4.236136
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    178.218447      1.394512         -4.614173
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    187.989802      1.524752         -4.608348
# 5     LSTM_GRU_pred    179.707613      1.445244         -4.608348
# 6       BiLSTM_pred    176.366592      1.415396         -4.839321
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.330107         -4.660324
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    179.801301      1.446015         -4.607982
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    179.801301      1.328100         -4.878345
# 3         LSTM_pred    179.707613      1.445244         -4.608348
# 4          GRU_pred    180.593544      1.453272         -4.604890
# 5     LSTM_GRU_pred    179.707613      1.445244         -4.608348
# 6       BiLSTM_pred    179.801301      1.446015         -4.607982
# 7   BiLSTM_GRU_pred    179.707613      1.445244         -4.608348
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.349846         -4.689195
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    188.724792      1.380376         -5.956153
# 1             PV_dw    153.190575      1.066038         -4.236136
# 2             PV_cw    165.627405      1.131821         -5.956153
# 3         LSTM_pred    181.169929      1.420549         -4.236136
# 4          GRU_pred    224.981715      1.790296         -3.659084
# 5     LSTM_GRU_pred    185.481095      1.706582         -3.778065
# 6       BiLSTM_pred    135.211210      1.013332         -4.236136
# 7   BiLSTM_GRU_pred    162.602065      1.125650         -4.803070
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    141.249908      1.020405         -5.959856
# 10         BNN_pred    184.639434      1.399377         -4.835164
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    136.557674      0.931627         -5.956153
# 1             PV_dw     73.257567      0.270514         -6.020488
# 2             PV_cw    154.684760      1.067022         -5.809394
# 3         LSTM_pred    221.031344      1.905340         -5.258589
# 4          GRU_pred    183.001310      1.616871         -3.907391
# 5     LSTM_GRU_pred    128.620183      1.106993         -4.012899
# 6       BiLSTM_pred    131.364447      1.083781         -5.258589
# 7   BiLSTM_GRU_pred     61.396248      0.244624         -5.303824
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    153.733120      1.115521         -4.742698
# 10         BNN_pred    157.317398      1.297924         -3.943435
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    186.679496      1.691844         -4.236136
# 1             PV_dw    123.942722      1.003602         -4.327503
# 2             PV_cw    132.488597      1.103727         -4.473542
# 3         LSTM_pred     98.584052      0.782208         -5.258589
# 4          GRU_pred    188.624254      2.422475         -1.315435
# 5     LSTM_GRU_pred     95.809180      0.852034         -3.629331
# 6       BiLSTM_pred     54.195939      0.194688         -5.110742
# 7   BiLSTM_GRU_pred    120.458465      1.147859         -2.917960
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    121.120005      1.002384         -5.063676
# 10         BNN_pred    107.224026      0.842522         -3.332396
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.427065      1.241065         -4.236136
# 1             PV_dw    104.789232      0.670786         -4.993460
# 2             PV_cw    167.385845      1.413366         -3.241598
# 3         LSTM_pred    142.264735      1.283115         -5.258589
# 4          GRU_pred    179.792373      1.861678         -2.822760
# 5     LSTM_GRU_pred    144.103653      1.436987         -3.481556
# 6       BiLSTM_pred     88.555751      0.633484         -5.258589
# 7   BiLSTM_GRU_pred     80.273771      0.497667         -3.966310
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    160.050550      1.412581         -4.891909
# 10         BNN_pred    153.499149      1.345189         -3.518797
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    157.647820      1.288485         -4.236136
# 1             PV_dw     91.700482      0.492546         -4.819716
# 2             PV_cw    145.663865      1.109039         -4.659869
# 3         LSTM_pred    198.109400      1.821596         -5.258589
# 4          GRU_pred    242.021753      2.364538         -2.639268
# 5     LSTM_GRU_pred    152.338062      1.415822         -4.503826
# 6       BiLSTM_pred    128.169770      0.979363         -5.258589
# 7   BiLSTM_GRU_pred     55.150409      0.177508         -5.303824
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    181.146481      1.491870         -4.694890
# 10         BNN_pred    159.561221      1.328068         -3.935804
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    186.679496      1.691844         -4.236136
# 1             PV_dw    163.098471      1.303867         -4.236136
# 2             PV_cw    134.154416      0.980878         -5.512457
# 3         LSTM_pred    112.889860      0.835580         -4.236136
# 4          GRU_pred    248.143049      2.200856         -3.266320
# 5     LSTM_GRU_pred    208.559031      2.033956         -3.318190
# 6       BiLSTM_pred     89.588443      0.583532         -4.236136
# 7   BiLSTM_GRU_pred    168.918841      1.510290         -2.629398
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    126.995043      1.016404         -4.987466
# 10         BNN_pred    112.009268      0.792768         -5.313829
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.427065      1.241065         -4.236136
# 1             PV_dw    143.015895      0.999858         -4.236136
# 2             PV_cw    157.834216      1.201015         -4.331320
# 3         LSTM_pred    158.646964      1.225686         -4.236136
# 4          GRU_pred    239.589937      1.969651         -4.266909
# 5     LSTM_GRU_pred    201.920499      2.086165         -3.282402
# 6       BiLSTM_pred    105.456784      0.727576         -4.236136
# 7   BiLSTM_GRU_pred    153.012860      1.067767         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    126.238767      1.007799         -4.990815
# 10         BNN_pred    159.831771      1.197350         -4.728612
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    210.782960      1.722947         -4.236136
# 1             PV_dw    153.190575      1.066038         -4.236136
# 2             PV_cw    164.437408      1.239585         -4.808418
# 3         LSTM_pred    158.646964      1.225686         -4.236136
# 4          GRU_pred    236.102440      1.928694         -4.200993
# 5     LSTM_GRU_pred    195.827137      1.876597         -4.298549
# 6       BiLSTM_pred    113.144961      0.801143         -4.236136
# 7   BiLSTM_GRU_pred    161.885824      1.149519         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    134.356919      0.969272         -4.792398
# 10         BNN_pred    188.082013      1.436901         -4.821154
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    186.679496      1.691844         -4.236136
# 1             PV_dw    229.608071      1.970471         -4.236136
# 2             PV_cw    153.637315      1.163013         -5.419361
# 3         LSTM_pred    195.917722      1.581993         -4.236136
# 4          GRU_pred    194.181365      1.585983         -4.800596
# 5     LSTM_GRU_pred    190.814673      1.400349         -4.960999
# 6       BiLSTM_pred    194.181365      1.585983         -4.800596
# 7   BiLSTM_GRU_pred    231.434256      1.987653         -4.236136
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    126.995043      1.016404         -4.987466
# 10         BNN_pred    147.162957      1.214078         -5.046659
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.427065      1.241065         -4.236136
# 1             PV_dw    188.084147      1.525522         -4.607982
# 2             PV_cw    165.416037      1.267023         -4.303142
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    187.466842      1.522063         -4.827741
# 5     LSTM_GRU_pred    190.814673      1.550142         -4.565365
# 6       BiLSTM_pred    176.366592      1.415396         -4.839321
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    126.238767      1.007799         -4.990815
# 10         BNN_pred    200.198021      1.642963         -4.394578
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    179.801301      1.381871         -4.607982
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    170.609558      1.229424         -4.812167
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    184.125990      1.486637         -4.591153
# 5     LSTM_GRU_pred    184.125990      1.486637         -4.591153
# 6       BiLSTM_pred    176.460014      1.416168         -4.838937
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    179.801301      1.381438         -4.607982
# 10         BNN_pred    179.801301      1.446015         -4.607982
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    138.631970      0.935705         -5.956153
# 1             PV_dw    154.888257      1.105864         -4.343767
# 2             PV_cw    155.907447      1.048128         -5.956153
# 3         LSTM_pred    106.831843      0.602530         -4.951367
# 4          GRU_pred    117.907449      0.895930         -6.011326
# 5     LSTM_GRU_pred    183.587036      1.779599         -3.789959
# 6       BiLSTM_pred     97.722288      0.509322         -4.992457
# 7   BiLSTM_GRU_pred    148.854095      1.142847         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    112.470300      0.745518         -5.813103
# 10         BNN_pred    146.921991      1.089152         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    133.629567      0.906352         -5.956153
# 1             PV_dw     58.128482      0.227028         -4.914031
# 2             PV_cw    140.140116      0.950512         -5.809394
# 3         LSTM_pred    196.951055      1.910594         -5.258589
# 4          GRU_pred    183.001310      1.616871         -3.907391
# 5     LSTM_GRU_pred     74.383943      0.453696         -4.150596
# 6       BiLSTM_pred    126.770868      1.038318         -5.258589
# 7   BiLSTM_GRU_pred    137.771949      1.111264         -3.920436
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    127.708668      0.867101         -4.852146
# 10         BNN_pred    104.420619      0.674776         -5.022451
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    127.908772      1.077679         -4.236136
# 1             PV_dw     63.166444      0.357338         -4.751286
# 2             PV_cw     73.824178      0.439784         -4.797486
# 3         LSTM_pred     57.185563      0.255477         -5.258589
# 4          GRU_pred    188.624254      2.422475         -1.315435
# 5     LSTM_GRU_pred     65.894821      0.430801         -2.911634
# 6       BiLSTM_pred     46.516868      0.080894         -5.110742
# 7   BiLSTM_GRU_pred     57.814106      0.284848         -2.917960
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred     84.199111      0.613460         -5.210961
# 10         BNN_pred     51.144498      0.161083         -3.470792
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    155.330653      1.325487         -4.236136
# 1             PV_dw     85.942709      0.630801         -4.993460
# 2             PV_cw    101.601577      0.746858         -4.584204
# 3         LSTM_pred     88.420888      0.694934         -5.258589
# 4          GRU_pred    179.792373      1.861678         -2.822760
# 5     LSTM_GRU_pred    117.696281      1.197837         -3.563954
# 6       BiLSTM_pred     81.073069      0.570735         -5.110742
# 7   BiLSTM_GRU_pred    100.484586      0.772941         -3.920436
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    106.519541      0.869222         -5.130491
# 10         BNN_pred    115.891072      0.938124         -3.453424
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    158.567006      1.318833         -4.236136
# 1             PV_dw     52.022914      0.148952         -5.129031
# 2             PV_cw    127.608323      0.947760         -4.659869
# 3         LSTM_pred     88.725164      0.692978         -5.258589
# 4          GRU_pred    249.726733      2.460716         -2.541138
# 5     LSTM_GRU_pred    127.014598      1.200780         -4.661109
# 6       BiLSTM_pred    111.191497      0.944347         -5.258589
# 7   BiLSTM_GRU_pred     94.357977      0.652258         -3.920436
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    119.891333      0.946517         -4.962742
# 10         BNN_pred    117.748345      0.882072         -4.966410
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.340664      1.307031         -4.236136
# 1             PV_dw    118.338990      0.885390         -4.225796
# 2             PV_cw    117.383144      0.818567         -5.668695
# 3         LSTM_pred     82.405176      0.539851         -4.236136
# 4          GRU_pred    131.005160      1.221289         -3.968306
# 5     LSTM_GRU_pred    144.678260      1.395450         -2.528078
# 6       BiLSTM_pred     80.783656      0.516762         -4.236136
# 7   BiLSTM_GRU_pred     96.772201      0.838768         -2.782266
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    126.830103      1.024643         -4.988196
# 10         BNN_pred     90.190315      0.593381         -3.357071
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    161.134442      1.379277         -4.236136
# 1             PV_dw    159.169462      1.252802         -4.469306
# 2             PV_cw    122.778334      0.870160         -5.550428
# 3         LSTM_pred     70.648319      0.352529         -4.236136
# 4          GRU_pred    149.204450      1.331295         -4.976602
# 5     LSTM_GRU_pred    185.022687      2.024649         -3.329207
# 6       BiLSTM_pred     96.048252      0.667038         -4.236136
# 7   BiLSTM_GRU_pred    102.444099      0.713772         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    126.238767      1.007799         -4.990815
# 10         BNN_pred    131.650442      1.004595         -4.142338
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    163.679452      1.337038         -4.236136
# 1             PV_dw    136.161624      0.924429         -4.469306
# 2             PV_cw    141.940214      1.034447         -4.808418
# 3         LSTM_pred     79.556553      0.451810         -4.236136
# 4          GRU_pred    154.016587      1.386650         -4.725250
# 5     LSTM_GRU_pred    178.119007      1.807024         -4.420055
# 6       BiLSTM_pred     72.608924      0.373050         -4.236136
# 7   BiLSTM_GRU_pred    124.517428      0.928113         -4.236136
# 8         QRNN_pred     12.857381     -0.615969         -4.577363
# 9          ESN_pred    136.565006      1.049062         -4.904076
# 10         BNN_pred    164.225602      1.294068         -4.512218
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.340664      1.307031         -4.236136
# 1             PV_dw    229.608071      1.892042         -4.660324
# 2             PV_cw    154.996727      1.176624         -5.484089
# 3         LSTM_pred    260.029086      2.294918         -4.236136
# 4          GRU_pred    194.181365      1.585983         -4.800596
# 5     LSTM_GRU_pred    163.509329      1.161826         -4.960999
# 6       BiLSTM_pred    194.181365      1.585983         -4.800596
# 7   BiLSTM_GRU_pred    185.182626      1.621029         -4.236136
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    126.830103      1.024643         -4.988196
# 10         BNN_pred    126.103181      1.014768         -5.079462
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    161.134442      1.379277         -4.236136
# 1             PV_dw    197.724565      1.643112         -4.236136
# 2             PV_cw    149.932679      1.126200         -5.419361
# 3         LSTM_pred    176.366592      1.394336         -4.839321
# 4          GRU_pred    187.466842      1.522063         -4.827741
# 5     LSTM_GRU_pred    190.814673      1.550142         -4.565365
# 6       BiLSTM_pred    176.366592      1.415396         -4.839321
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    126.238767      1.007799         -4.990815
# 10         BNN_pred    187.615979      1.538392         -5.247404
# 11               __    179.801301      1.446015         -4.607982
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    163.679452      1.337038         -4.236136
# 1             PV_dw    179.801301      1.446015         -4.607982
# 2             PV_cw    164.973633      1.178173         -4.812167
# 3         LSTM_pred    176.366592      1.415396         -4.839321
# 4          GRU_pred    192.439198      1.566407         -4.591153
# 5     LSTM_GRU_pred    184.125990      1.486637         -4.591153
# 6       BiLSTM_pred    176.366592      1.415396         -4.839321
# 7   BiLSTM_GRU_pred    176.366592      1.415396         -4.839321
# 8         QRNN_pred    179.801301      1.446015         -4.607982
# 9          ESN_pred    178.218447      1.366828         -4.614173
# 10         BNN_pred    188.084147      1.525522         -4.607982
# 11               __    179.801301      1.446015         -4.607982

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2022_2y)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2022_2y)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2022_2y', file, 'PV')
get_final_results_1('2022_2y', file, 'PV')

get_final_results('2022_2y', dw_file, 'PV_dw')
get_final_results_1('2022_2y', dw_file, 'PV_dw')

get_final_results('2022_2y', cw_file, 'PV_cw')
get_final_results_1('2022_2y', cw_file, 'PV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:21: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-4-b267510ae310>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-4-b267510ae310>:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:31: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:37: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:31: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:37: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     78.604419      0.023017        -15.916361
# 1             PV_dw     82.872664      0.038689        -17.220231
# 2             PV_cw    119.997066      0.171248        -15.653229
# 3         LSTM_pred    110.632486      0.138318        -16.502003
# 4          GRU_pred     43.347819     -0.109453        -17.181310
# 5     LSTM_GRU_pred     89.344811      0.062268        -16.320926
# 6       BiLSTM_pred     82.953348      0.038960        -17.068592
# 7   BiLSTM_GRU_pred    109.795242      0.135356        -16.437575
# 8         QRNN_pred    138.613732      0.236401        -15.774136
# 9          ESN_pred     97.559100      0.091919        -16.035561
# 10         BNN_pred    102.348125      0.108997        -16.483872
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    111.286610      0.141468        -16.035561
# 1             PV_dw     66.755991     -0.025745        -19.668101
# 2             PV_cw    225.003739      0.550610        -13.333204
# 3         LSTM_pred    224.641801      0.540545        -10.578829
# 4          GRU_pred     62.628598     -0.038799        -16.098501
# 5     LSTM_GRU_pred     91.385028      0.067753        -16.320926
# 6       BiLSTM_pred     27.963197     -0.173088        -17.358586
# 7   BiLSTM_GRU_pred    148.280416      0.277951        -11.957792
# 8         QRNN_pred    141.004919      0.250649        -16.035561
# 9          ESN_pred     15.326524     -0.222758        -15.632738
# 10         BNN_pred     12.373774     -0.238775        -18.746504
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    109.605745      0.138603        -15.965790
# 1             PV_dw    105.309126      0.120421        -17.160264
# 2             PV_cw     69.806924     -0.035484        -13.284966
# 3         LSTM_pred    167.497631      0.349968        -11.472676
# 4          GRU_pred    -32.637893     -0.450776        -15.023054
# 5     LSTM_GRU_pred     -7.296783     -0.351722        -14.886407
# 6       BiLSTM_pred    -53.576417     -0.614677        -15.905981
# 7   BiLSTM_GRU_pred    167.605733      0.368180         -7.361510
# 8         QRNN_pred     19.369557     -0.244990        -16.999813
# 9          ESN_pred    -78.465501     -0.693974        -16.654236
# 10         BNN_pred     79.072767      0.015791        -16.199219
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    143.468489      0.265062        -17.054487
# 1             PV_dw     60.542256     -0.053997        -19.402160
# 2             PV_cw    121.791273      0.186165        -13.404050
# 3         LSTM_pred    176.130907      0.379797        -11.472676
# 4          GRU_pred     -9.352158     -0.327129        -16.771894
# 5     LSTM_GRU_pred     -0.539229     -0.300173        -16.320926
# 6       BiLSTM_pred    -19.544191     -0.369548        -18.564296
# 7   BiLSTM_GRU_pred    120.442627      0.177934        -12.306207
# 8         QRNN_pred     47.562855     -0.114319        -16.035561
# 9          ESN_pred     -3.368643     -0.315439        -15.334488
# 10         BNN_pred     19.408161     -0.213211        -19.578937
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     78.240677      0.017829        -16.858938
# 1             PV_dw     66.767777     -0.025732        -19.668101
# 2             PV_cw    254.697626      0.650753        -13.075299
# 3         LSTM_pred    222.188396      0.533093        -11.139071
# 4          GRU_pred     49.842716     -0.087757        -16.098501
# 5     LSTM_GRU_pred     82.231873      0.033176        -16.320926
# 6       BiLSTM_pred     27.963197     -0.173088        -17.358586
# 7   BiLSTM_GRU_pred    127.599970      0.203328        -12.784505
# 8         QRNN_pred    141.004919      0.250649        -16.035561
# 9          ESN_pred     53.100549     -0.078260        -14.699898
# 10         BNN_pred     12.373774     -0.238775        -18.746504
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     61.144234     -0.060540        -16.884504
# 1             PV_dw     88.579444      0.056653        -16.652624
# 2             PV_cw     44.742039     -0.129646        -12.916133
# 3         LSTM_pred     64.377989     -0.030053        -16.628530
# 4          GRU_pred    -63.458088     -0.566953        -18.297807
# 5     LSTM_GRU_pred     16.208962     -0.226895        -14.886407
# 6       BiLSTM_pred      9.419767     -0.270438        -17.068592
# 7   BiLSTM_GRU_pred     59.983629     -0.049400        -16.124881
# 8         QRNN_pred     24.544485     -0.214958        -16.999813
# 9          ESN_pred    -12.286363     -0.360488        -16.035561
# 10         BNN_pred    109.948627      0.136553        -15.452123
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     76.973938      0.012264        -18.535791
# 1             PV_dw     79.847146      0.026891        -17.092429
# 2             PV_cw     39.064163     -0.134936        -13.942706
# 3         LSTM_pred     66.913550     -0.020609        -16.628530
# 4          GRU_pred    -29.895305     -0.405743        -18.508303
# 5     LSTM_GRU_pred     32.850618     -0.150055        -16.320926
# 6       BiLSTM_pred     85.348015      0.047340        -17.068592
# 7   BiLSTM_GRU_pred     68.404417     -0.015365        -17.048775
# 8         QRNN_pred     38.410015     -0.148268        -16.035561
# 9          ESN_pred     75.781239      0.009492        -15.972775
# 10         BNN_pred     88.611766      0.059551        -17.149818
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     99.844030      0.099832        -15.916361
# 1             PV_dw     74.958591      0.009661        -17.220231
# 2             PV_cw    134.389716      0.221857        -13.982487
# 3         LSTM_pred    114.545788      0.152089        -16.502003
# 4          GRU_pred     28.942051     -0.165087        -17.181310
# 5     LSTM_GRU_pred     80.508106      0.030050        -16.320926
# 6       BiLSTM_pred     82.953348      0.038960        -17.068592
# 7   BiLSTM_GRU_pred     80.177650      0.028677        -17.048775
# 8         QRNN_pred    138.613732      0.236401        -15.774136
# 9          ESN_pred    106.584967      0.124067        -16.283886
# 10         BNN_pred    102.348125      0.108997        -16.483872
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     64.011005     -0.040954        -15.965790
# 1             PV_dw     83.889971      0.039948        -16.651209
# 2             PV_cw     40.365080     -0.140426        -14.612838
# 3         LSTM_pred     61.001579     -0.042165        -16.035561
# 4          GRU_pred     64.894444     -0.028071        -16.035561
# 5     LSTM_GRU_pred     67.832245     -0.017747        -14.985792
# 6       BiLSTM_pred     91.260101      0.068559        -16.035561
# 7   BiLSTM_GRU_pred     65.233596     -0.027297        -16.035561
# 8         QRNN_pred     23.810425     -0.211974        -16.999813
# 9          ESN_pred     59.582512     -0.049068        -16.035561
# 10         BNN_pred    122.326457      0.181213        -15.522907
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    116.253486      0.157980        -15.916361
# 1             PV_dw    101.688381      0.106608        -17.092429
# 2             PV_cw     52.420611     -0.077379        -16.163149
# 3         LSTM_pred     63.529097     -0.032749        -16.035561
# 4          GRU_pred    108.513301      0.130850        -15.916361
# 5     LSTM_GRU_pred     92.363602      0.073302        -16.010201
# 6       BiLSTM_pred    128.986221      0.202508        -15.916361
# 7   BiLSTM_GRU_pred     65.587124     -0.025105        -16.035561
# 8         QRNN_pred     20.024012     -0.220684        -16.035561
# 9          ESN_pred    101.963129      0.107675        -15.916361
# 10         BNN_pred    101.864707      0.107279        -16.600561
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    115.768295      0.156283        -15.916361
# 1             PV_dw    115.768295      0.156283        -15.916361
# 2             PV_cw    115.768295      0.156283        -15.916361
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred    100.362599      0.101982        -15.916361
# 5     LSTM_GRU_pred    100.362599      0.101982        -15.916361
# 6       BiLSTM_pred    115.768295      0.156283        -15.916361
# 7   BiLSTM_GRU_pred     89.910368      0.064268        -16.035561
# 8         QRNN_pred    115.768295      0.156283        -15.916361
# 9          ESN_pred    115.768295      0.156283        -15.916361
# 10         BNN_pred    115.768295      0.156283        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     90.168731      0.065255        -15.916361
# 1             PV_dw     70.080994     -0.007944        -17.686597
# 2             PV_cw    111.933164      0.143079        -16.035561
# 3         LSTM_pred    134.406385      0.221532        -15.916361
# 4          GRU_pred     49.934254     -0.083869        -17.181310
# 5     LSTM_GRU_pred     51.763250     -0.077272        -17.181310
# 6       BiLSTM_pred     99.568112      0.099116        -16.035561
# 7   BiLSTM_GRU_pred     97.735613      0.092473        -15.937294
# 8         QRNN_pred    183.728217      0.391071        -15.643967
# 9          ESN_pred    146.711211      0.266029        -16.035561
# 10         BNN_pred     89.267240      0.061957        -16.185676
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    116.807899      0.161073        -15.986496
# 1             PV_dw      3.607984     -0.277671        -21.121904
# 2             PV_cw    156.852903      0.311051        -14.279117
# 3         LSTM_pred    170.060293      0.353839        -12.697586
# 4          GRU_pred     57.096039     -0.061901        -16.098501
# 5     LSTM_GRU_pred    128.199057      0.204335        -16.098501
# 6       BiLSTM_pred     92.067312      0.070110        -17.130757
# 7   BiLSTM_GRU_pred    132.210998      0.219599        -15.706902
# 8         QRNN_pred     83.471568      0.038383        -16.387586
# 9          ESN_pred     57.780634     -0.059794        -15.668627
# 10         BNN_pred     15.617933     -0.226063        -19.860489
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     20.749897     -0.252459        -15.950397
# 1             PV_dw     36.891297     -0.170500        -17.755542
# 2             PV_cw     46.606381     -0.135571        -13.128052
# 3         LSTM_pred    160.461003      0.325048        -12.965380
# 4          GRU_pred     22.858346     -0.221893        -14.195778
# 5     LSTM_GRU_pred    -72.053156     -0.745220        -13.808280
# 6       BiLSTM_pred    -32.594584     -0.519622        -14.231261
# 7   BiLSTM_GRU_pred     56.894929     -0.075069        -15.550297
# 8         QRNN_pred     25.707910     -0.228268        -15.386990
# 9          ESN_pred    -15.336088     -0.384739        -15.184205
# 10         BNN_pred    105.853928      0.122360        -16.148630
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     43.072594     -0.125325        -17.198380
# 1             PV_dw      1.460371     -0.293439        -20.967887
# 2             PV_cw     91.651775      0.066116        -13.146995
# 3         LSTM_pred    167.099688      0.349038        -12.965380
# 4          GRU_pred    -24.279932     -0.398189        -17.295984
# 5     LSTM_GRU_pred     26.428882     -0.193354        -16.771894
# 6       BiLSTM_pred     14.884588     -0.257755        -16.384666
# 7   BiLSTM_GRU_pred    111.117088      0.142268        -14.763563
# 8         QRNN_pred     18.570077     -0.235152        -16.579320
# 9          ESN_pred     60.011058     -0.056157        -13.289114
# 10         BNN_pred     39.467502     -0.133831        -20.411703
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    103.850239      0.114238        -15.986496
# 1             PV_dw      5.094309     -0.271779        -21.121904
# 2             PV_cw    139.533004      0.249594        -14.279117
# 3         LSTM_pred    200.107706      0.460140        -12.697586
# 4          GRU_pred     13.354351     -0.236042        -16.108842
# 5     LSTM_GRU_pred    103.904132      0.114390        -16.098501
# 6       BiLSTM_pred     92.067312      0.070110        -17.130757
# 7   BiLSTM_GRU_pred    124.612451      0.191837        -15.727559
# 8         QRNN_pred     55.773556     -0.071987        -18.057079
# 9          ESN_pred     79.375929      0.021558        -15.668627
# 10         BNN_pred     15.617933     -0.226063        -19.860489
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV      1.474830     -0.337359        -15.950397
# 1             PV_dw     66.372481     -0.030684        -18.220876
# 2             PV_cw     34.316774     -0.175195        -14.594215
# 3         LSTM_pred     68.420453     -0.015946        -16.035561
# 4          GRU_pred    -37.049570     -0.460421        -19.135701
# 5     LSTM_GRU_pred   -116.547128     -0.883682        -17.309483
# 6       BiLSTM_pred     29.734417     -0.183530        -15.402538
# 7   BiLSTM_GRU_pred      9.358624     -0.250092        -16.035561
# 8         QRNN_pred     46.361593     -0.134135        -15.386990
# 9          ESN_pred     39.779480     -0.135494        -16.035561
# 10         BNN_pred    119.872072      0.173912        -13.291966
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     13.408994     -0.241195        -17.198380
# 1             PV_dw     40.883472     -0.118240        -18.101509
# 2             PV_cw     49.858087     -0.094416        -14.979967
# 3         LSTM_pred     74.532600      0.006852        -16.035561
# 4          GRU_pred    -28.024727     -0.398708        -19.751401
# 5     LSTM_GRU_pred    -32.590875     -0.417461        -17.858337
# 6       BiLSTM_pred     99.934055      0.100309        -16.035561
# 7   BiLSTM_GRU_pred     66.284954     -0.024173        -16.035561
# 8         QRNN_pred     39.080033     -0.147642        -16.579320
# 9          ESN_pred     93.782105      0.076702        -16.035561
# 10         BNN_pred     81.775071      0.034415        -16.872342
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     75.351521      0.011248        -15.916361
# 1             PV_dw     66.732657     -0.020559        -17.686597
# 2             PV_cw     81.927458      0.033959        -16.035561
# 3         LSTM_pred    121.400103      0.176480        -15.916361
# 4          GRU_pred     -5.549220     -0.301778        -18.599504
# 5     LSTM_GRU_pred     22.361497     -0.191073        -17.181310
# 6       BiLSTM_pred     99.568112      0.099116        -16.035561
# 7   BiLSTM_GRU_pred    104.552529      0.116811        -15.753327
# 8         QRNN_pred    173.411575      0.360267        -15.643967
# 9          ESN_pred    143.072078      0.254200        -15.972775
# 10         BNN_pred     89.267240      0.061957        -16.185676
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     17.816473     -0.245814        -15.950397
# 1             PV_dw     51.729909     -0.084530        -17.811381
# 2             PV_cw     32.535967     -0.177917        -14.594215
# 3         LSTM_pred     63.054715     -0.034521        -16.035561
# 4          GRU_pred     65.779330     -0.024782        -15.965790
# 5     LSTM_GRU_pred     75.733508      0.011686        -14.985792
# 6       BiLSTM_pred     90.391362      0.065229        -15.402538
# 7   BiLSTM_GRU_pred     63.054715     -0.034521        -16.035561
# 8         QRNN_pred     34.977395     -0.179530        -15.386990
# 9          ESN_pred     51.102546     -0.079701        -15.916361
# 10         BNN_pred    158.194457      0.309963        -13.170092
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     52.489585     -0.081706        -17.198380
# 1             PV_dw    107.506067      0.127275        -15.916361
# 2             PV_cw     55.723880     -0.068813        -15.527827
# 3         LSTM_pred     69.136166     -0.011943        -16.035561
# 4          GRU_pred     97.107262      0.090393        -15.916361
# 5     LSTM_GRU_pred    101.064313      0.104406        -16.010201
# 6       BiLSTM_pred    120.693817      0.173686        -15.916361
# 7   BiLSTM_GRU_pred     69.136166     -0.011943        -16.035561
# 8         QRNN_pred      8.042624     -0.274103        -16.579320
# 9          ESN_pred    115.768295      0.156283        -15.916361
# 10         BNN_pred    108.093847      0.129383        -16.600561
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    115.768295      0.156283        -15.916361
# 1             PV_dw    115.768295      0.156283        -15.916361
# 2             PV_cw     82.303231      0.036100        -16.035561
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred    100.362599      0.101982        -15.916361
# 5     LSTM_GRU_pred    100.362599      0.101982        -15.916361
# 6       BiLSTM_pred    115.768295      0.156283        -15.916361
# 7   BiLSTM_GRU_pred    107.506067      0.127275        -15.916361
# 8         QRNN_pred    131.057212      0.211378        -15.916361
# 9          ESN_pred    115.768295      0.156283        -15.916361
# 10         BNN_pred    115.768295      0.156283        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    119.146665      0.171268        -14.629155
# 1             PV_dw      3.745512     -0.280705        -19.644126
# 2             PV_cw    144.350307      0.260882        -16.035561
# 3         LSTM_pred    179.723144      0.382871        -15.104538
# 4          GRU_pred     41.721699     -0.128173        -15.297751
# 5     LSTM_GRU_pred     97.587518      0.091112        -16.320926
# 6       BiLSTM_pred     40.625889     -0.135681        -16.360910
# 7   BiLSTM_GRU_pred     62.335090     -0.042106        -14.585319
# 8         QRNN_pred    134.349656      0.229486        -12.907763
# 9          ESN_pred    145.845815      0.264937        -13.937626
# 10         BNN_pred     -1.312845     -0.296576        -19.715573
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     60.318850     -0.065826        -14.700679
# 1             PV_dw    -87.422767     -0.733668        -18.861770
# 2             PV_cw    102.606198      0.109493        -16.761842
# 3         LSTM_pred    226.964216      0.582194        -14.420453
# 4          GRU_pred     95.885018      0.079804        -12.941076
# 5     LSTM_GRU_pred     16.984456     -0.272470        -11.830200
# 6       BiLSTM_pred     44.655944     -0.147531        -16.339859
# 7   BiLSTM_GRU_pred    233.628398      0.627052         -9.374585
# 8         QRNN_pred     17.789463     -0.250541        -16.670417
# 9          ESN_pred     66.866221     -0.029056        -13.937626
# 10         BNN_pred    162.378272      0.349042        -14.120806
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     62.094164     -0.168638         -4.630814
# 1             PV_dw     -7.363980     -0.513936        -15.173152
# 2             PV_cw    -32.425435     -0.699284        -11.559794
# 3         LSTM_pred    179.228277      0.441979        -10.918475
# 4          GRU_pred     27.223227     -0.349837        -11.130726
# 5     LSTM_GRU_pred    -58.424526     -0.889127        -10.172647
# 6       BiLSTM_pred   -132.037360     -1.395159        -17.016759
# 7   BiLSTM_GRU_pred     97.908452      0.090818         -5.982036
# 8         QRNN_pred     21.790001     -0.497609         -7.270511
# 9          ESN_pred     65.390761     -0.066633        -12.243861
# 10         BNN_pred    267.004968      0.880406         -8.465902
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     97.704347      0.089202         -5.419056
# 1             PV_dw    -44.608035     -0.631269        -16.789621
# 2             PV_cw    -13.936434     -0.495231        -13.482369
# 3         LSTM_pred    207.693139      0.551781        -11.912401
# 4          GRU_pred     92.944843      0.066036        -12.084270
# 5     LSTM_GRU_pred    -62.308082     -0.753173        -11.869763
# 6       BiLSTM_pred     50.289070     -0.144880        -15.752561
# 7   BiLSTM_GRU_pred    156.410651      0.356899        -10.059275
# 8         QRNN_pred     50.717148     -0.171109         -8.577481
# 9          ESN_pred      1.809950     -0.322412        -16.181628
# 10         BNN_pred    237.563463      0.675002        -14.983414
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     25.630775     -0.272976        -11.176927
# 1             PV_dw   -120.009021     -0.945218        -22.086340
# 2             PV_cw     40.779107     -0.172943        -16.761842
# 3         LSTM_pred    170.049544      0.381469        -14.416120
# 4          GRU_pred     26.115753     -0.286154        -13.887028
# 5     LSTM_GRU_pred     87.472558      0.047243        -11.528593
# 6       BiLSTM_pred     41.849310     -0.168275        -14.903664
# 7   BiLSTM_GRU_pred    277.316768      0.805771         -8.659068
# 8         QRNN_pred    155.854966      0.348504         -6.217198
# 9          ESN_pred     96.620904      0.085799        -12.243861
# 10         BNN_pred    133.866611      0.238963        -18.082248
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     62.094164     -0.168638         -4.630814
# 1             PV_dw      2.744950     -0.354489        -18.807594
# 2             PV_cw    -45.278030     -0.772415        -13.052425
# 3         LSTM_pred     89.842196      0.060195        -14.578634
# 4          GRU_pred    -78.127680     -0.847356        -12.012360
# 5     LSTM_GRU_pred    -77.923453     -0.889874        -14.556675
# 6       BiLSTM_pred   -129.916826     -1.129386        -17.804678
# 7   BiLSTM_GRU_pred    -72.903171     -0.786327        -17.241661
# 8         QRNN_pred     21.790001     -0.497609         -7.270511
# 9          ESN_pred     75.543432     -0.016877        -12.243861
# 10         BNN_pred    166.442933      0.383999        -10.591888
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     97.704347      0.089202         -5.419056
# 1             PV_dw    -17.531173     -0.399405        -20.069569
# 2             PV_cw    -28.240346     -0.529866        -14.942552
# 3         LSTM_pred    121.019689      0.178263        -15.423095
# 4          GRU_pred     -8.917229     -0.363050        -13.577409
# 5     LSTM_GRU_pred    -58.469056     -0.634736        -15.954729
# 6       BiLSTM_pred      2.123646     -0.321631        -15.208580
# 7   BiLSTM_GRU_pred      2.419239     -0.297856        -14.968267
# 8         QRNN_pred     64.121393     -0.094037         -7.411183
# 9          ESN_pred     25.084605     -0.208295        -13.734018
# 10         BNN_pred     47.074145     -0.114110        -21.503211
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     82.534052      0.022431        -11.263503
# 1             PV_dw     -9.789714     -0.344887        -18.814336
# 2             PV_cw     77.360010      0.005678        -16.035561
# 3         LSTM_pred    121.019689      0.178263        -15.423095
# 4          GRU_pred    -59.000947     -0.562517        -17.312039
# 5     LSTM_GRU_pred     29.811871     -0.173139        -16.320926
# 6       BiLSTM_pred     14.973661     -0.247017        -15.002349
# 7   BiLSTM_GRU_pred     79.564520      0.022484        -14.629219
# 8         QRNN_pred    244.028750      0.677899         -5.776538
# 9          ESN_pred    102.561849      0.109367        -12.243861
# 10         BNN_pred     -5.252664     -0.321216        -21.448834
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     62.094164     -0.168638         -4.630814
# 1             PV_dw     -0.386186     -0.320770        -18.996692
# 2             PV_cw    -59.891416     -0.835201        -13.254157
# 3         LSTM_pred     74.068482      0.003942        -14.732060
# 4          GRU_pred    105.222269      0.119229        -13.446381
# 5     LSTM_GRU_pred    -19.063186     -0.398108        -18.647228
# 6       BiLSTM_pred     68.917357     -0.018313        -18.075977
# 7   BiLSTM_GRU_pred    -67.582737     -0.687438        -16.771278
# 8         QRNN_pred     21.790001     -0.497609         -7.270511
# 9          ESN_pred     54.559475     -0.103455        -16.297314
# 10         BNN_pred    183.735765      0.404990        -10.360646
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     97.704347      0.089202         -5.419056
# 1             PV_dw     49.653171     -0.084704        -18.095539
# 2             PV_cw    -43.114518     -0.591559        -14.979074
# 3         LSTM_pred     69.136166     -0.011943        -16.035561
# 4          GRU_pred    101.204145      0.104877        -14.690724
# 5     LSTM_GRU_pred    118.383952      0.166008        -14.777338
# 6       BiLSTM_pred    121.055939      0.175016        -15.173647
# 7   BiLSTM_GRU_pred     75.317489      0.010336        -16.035561
# 8         QRNN_pred     64.121393     -0.094037         -7.411183
# 9          ESN_pred     39.510500     -0.128661        -16.734477
# 10         BNN_pred    108.840834      0.132117        -15.856201
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     82.534052      0.022431        -11.263503
# 1             PV_dw    107.506067      0.127275        -15.916361
# 2             PV_cw     24.658770     -0.212391        -16.035561
# 3         LSTM_pred     69.136166     -0.011943        -16.035561
# 4          GRU_pred    100.809747      0.103569        -15.916361
# 5     LSTM_GRU_pred    119.247653      0.168539        -15.916361
# 6       BiLSTM_pred    119.247653      0.168539        -15.916361
# 7   BiLSTM_GRU_pred    107.506067      0.127275        -15.916361
# 8         QRNN_pred    238.043748      0.627345         -5.638585
# 9          ESN_pred    115.768295      0.156283        -15.916361
# 10         BNN_pred    108.093847      0.129383        -16.600561
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    113.956973      0.152448        -14.384824
# 1             PV_dw    -14.311508     -0.374368        -20.423533
# 2             PV_cw    105.852125      0.121721        -15.725854
# 3         LSTM_pred    186.141279      0.418709        -13.520031
# 4          GRU_pred     41.721699     -0.128173        -15.297751
# 5     LSTM_GRU_pred     22.362281     -0.208262        -15.448263
# 6       BiLSTM_pred     63.430998     -0.039900        -17.389938
# 7   BiLSTM_GRU_pred    152.280940      0.298029        -15.244934
# 8         QRNN_pred     75.377355      0.001498        -16.384258
# 9          ESN_pred     43.388213     -0.113279        -13.145104
# 10         BNN_pred     23.408208     -0.215243        -20.203347
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     26.576579     -0.223227        -15.291875
# 1             PV_dw    -70.230505     -0.646340        -19.020257
# 2             PV_cw     48.890485     -0.119308        -16.818755
# 3         LSTM_pred    100.113729      0.099376        -13.327913
# 4          GRU_pred     95.885018      0.079804        -12.941076
# 5     LSTM_GRU_pred     26.749361     -0.263775        -13.989175
# 6       BiLSTM_pred    -16.721826     -0.488922        -17.665050
# 7   BiLSTM_GRU_pred     80.893968      0.014651        -16.478352
# 8         QRNN_pred     50.389541     -0.116277        -15.254214
# 9          ESN_pred    103.241219      0.111890        -13.937626
# 10         BNN_pred    112.731932      0.153841        -10.566094
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     25.992249     -0.458151         -7.807600
# 1             PV_dw     85.875160      0.017677         -7.080238
# 2             PV_cw    -33.983929     -0.743478        -11.559794
# 3         LSTM_pred    140.469544      0.293722         -9.028811
# 4          GRU_pred     -5.684851     -0.695625        -11.664602
# 5     LSTM_GRU_pred     -9.669356     -0.719623         -9.656268
# 6       BiLSTM_pred    -78.694269     -1.200308        -14.664385
# 7   BiLSTM_GRU_pred     53.966896     -0.255936         -6.069760
# 8         QRNN_pred     13.322328     -0.588893         -6.508957
# 9          ESN_pred     20.242928     -0.311710        -11.874515
# 10         BNN_pred    172.712391      0.510764         -7.585146
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     39.492993     -0.275644         -7.055394
# 1             PV_dw    -43.310975     -0.667811        -14.301845
# 2             PV_cw     33.112754     -0.265397        -14.689766
# 3         LSTM_pred    170.996931      0.418925         -9.876823
# 4          GRU_pred     92.944843      0.066036        -12.084270
# 5     LSTM_GRU_pred   -125.037344     -1.369363        -14.963993
# 6       BiLSTM_pred    -33.727122     -0.674943        -15.760573
# 7   BiLSTM_GRU_pred    105.860830      0.133246        -10.259507
# 8         QRNN_pred     64.520844     -0.116582         -6.537784
# 9          ESN_pred     19.565797     -0.253165        -13.771056
# 10         BNN_pred    202.320134      0.585724         -9.550577
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     68.372035     -0.068325         -7.938712
# 1             PV_dw    -76.312560     -0.738904        -19.384004
# 2             PV_cw    149.894576      0.326055        -13.656513
# 3         LSTM_pred    157.944146      0.357921         -9.876823
# 4          GRU_pred     26.115753     -0.286154        -13.887028
# 5     LSTM_GRU_pred    -46.699656     -0.634116        -16.533737
# 6       BiLSTM_pred    -82.752871     -0.900445        -17.345077
# 7   BiLSTM_GRU_pred    103.602311      0.115965        -12.207894
# 8         QRNN_pred    170.840016      0.464736         -4.928077
# 9          ESN_pred     11.155567     -0.275714        -14.849994
# 10         BNN_pred    106.700048      0.130039        -13.539218
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     25.992249     -0.458151         -7.807600
# 1             PV_dw    133.517720      0.286175         -7.527499
# 2             PV_cw    -44.642283     -0.773964        -13.052425
# 3         LSTM_pred    118.814011      0.178805        -12.972721
# 4          GRU_pred   -131.634108     -1.276609        -16.561194
# 5     LSTM_GRU_pred    -19.416404     -0.618360         -7.976714
# 6       BiLSTM_pred    -99.952047     -1.082278        -16.515487
# 7   BiLSTM_GRU_pred     18.611691     -0.480377         -6.405995
# 8         QRNN_pred     13.322328     -0.588893         -6.508957
# 9          ESN_pred     20.242928     -0.311710        -11.874515
# 10         BNN_pred    244.665813      0.778530         -8.180964
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     46.928518     -0.214238         -6.623607
# 1             PV_dw    -10.080278     -0.431625        -15.393704
# 2             PV_cw     11.198486     -0.368669        -16.129572
# 3         LSTM_pred    171.053060      0.375845        -13.344566
# 4          GRU_pred     -8.917229     -0.363050        -13.577409
# 5     LSTM_GRU_pred   -129.257900     -1.144884        -16.861694
# 6       BiLSTM_pred    -28.510315     -0.504904        -16.819328
# 7   BiLSTM_GRU_pred     13.305672     -0.283116        -17.312426
# 8         QRNN_pred    116.053502      0.197975         -5.651481
# 9          ESN_pred     31.665375     -0.192490        -12.455389
# 10         BNN_pred    239.899766      0.678692        -12.511789
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.453097      0.323516         -6.073162
# 1             PV_dw    -43.537785     -0.531695        -19.190332
# 2             PV_cw    123.101173      0.196817        -14.397370
# 3         LSTM_pred    179.124792      0.406146        -13.344566
# 4          GRU_pred    -59.000947     -0.562517        -17.312039
# 5     LSTM_GRU_pred    -53.026790     -0.564236        -16.918097
# 6       BiLSTM_pred    -68.660455     -0.659018        -17.452284
# 7   BiLSTM_GRU_pred     78.820043      0.013222        -14.688452
# 8         QRNN_pred    135.468316      0.270280         -6.849705
# 9          ESN_pred    -13.031754     -0.359942        -17.340234
# 10         BNN_pred    103.997256      0.115169        -21.223782
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     25.992249     -0.458151         -7.807600
# 1             PV_dw     65.302091     -0.047772        -14.999153
# 2             PV_cw    -58.430227     -0.831555        -13.254157
# 3         LSTM_pred     12.853128     -0.241231        -14.732060
# 4          GRU_pred     73.827188      0.002353        -16.668866
# 5     LSTM_GRU_pred     80.658326      0.017702        -11.779202
# 6       BiLSTM_pred     97.269792      0.089464        -15.902988
# 7   BiLSTM_GRU_pred      9.445409     -0.353722         -9.895650
# 8         QRNN_pred     13.322328     -0.588893         -6.508957
# 9          ESN_pred     20.242928     -0.311710        -11.874515
# 10         BNN_pred    181.837894      0.398314        -10.360646
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     46.928518     -0.214238         -6.623607
# 1             PV_dw     10.636824     -0.240732        -18.095539
# 2             PV_cw    -20.942482     -0.527969        -16.129572
# 3         LSTM_pred     61.001579     -0.042165        -16.035561
# 4          GRU_pred    101.204145      0.104877        -14.690724
# 5     LSTM_GRU_pred     39.034941     -0.137481        -14.386451
# 6       BiLSTM_pred     88.776467      0.059949        -16.933538
# 7   BiLSTM_GRU_pred     69.200878     -0.012340        -16.035561
# 8         QRNN_pred    116.053502      0.197975         -5.651481
# 9          ESN_pred     10.629128     -0.253107        -18.111619
# 10         BNN_pred    116.440253      0.159444        -15.173647
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.453097      0.323516         -6.073162
# 1             PV_dw    103.781060      0.114111        -15.916361
# 2             PV_cw     74.867622     -0.006210        -14.397370
# 3         LSTM_pred     69.136166     -0.011943        -16.035561
# 4          GRU_pred    100.809747      0.103569        -15.916361
# 5     LSTM_GRU_pred     96.868611      0.089423        -16.010201
# 6       BiLSTM_pred    118.387745      0.165532        -15.916361
# 7   BiLSTM_GRU_pred     69.136166     -0.011943        -16.035561
# 8         QRNN_pred    135.468316      0.270280         -6.849705
# 9          ESN_pred    113.116629      0.146997        -15.916361
# 10         BNN_pred     94.908397      0.082379        -17.506638
# 11               __    115.768295      0.156283        -15.916361

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     78.604419      0.023017        -15.916361
# 1             PV_dw     86.470801      0.051036        -18.187175
# 2             PV_cw    110.951409      0.139458        -15.916361
# 3         LSTM_pred    119.699693      0.170025        -15.916361
# 4          GRU_pred    115.768295      0.156283        -15.916361
# 5     LSTM_GRU_pred     89.344811      0.062268        -16.320926
# 6       BiLSTM_pred    108.104983      0.129408        -16.035561
# 7   BiLSTM_GRU_pred    114.206295      0.150815        -15.941015
# 8         QRNN_pred    119.219264      0.168584        -15.774136
# 9          ESN_pred    129.837977      0.206216        -14.965803
# 10         BNN_pred     78.643738      0.023093        -16.607382
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    111.286610      0.141468        -16.035561
# 1             PV_dw     41.730221     -0.123510        -20.023085
# 2             PV_cw    138.301689      0.239166        -13.991512
# 3         LSTM_pred    225.744610      0.575660        -10.259727
# 4          GRU_pred     76.464786      0.012072        -16.532926
# 5     LSTM_GRU_pred     91.385028      0.067753        -16.320926
# 6       BiLSTM_pred    206.611370      0.485764         -9.839228
# 7   BiLSTM_GRU_pred    130.707418      0.210066        -17.287518
# 8         QRNN_pred     98.178977      0.092521        -17.251467
# 9          ESN_pred    190.845266      0.440949        -10.747997
# 10         BNN_pred    -64.936644     -0.579151        -19.848463
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    109.605745      0.138603        -15.965790
# 1             PV_dw     11.250735     -0.264285        -18.315540
# 2             PV_cw    127.830351      0.213956        -12.603605
# 3         LSTM_pred     32.054844     -0.251781        -11.662443
# 4          GRU_pred    221.005298      0.562184        -12.777708
# 5     LSTM_GRU_pred     -7.296783     -0.351722        -14.886407
# 6       BiLSTM_pred    316.536777      0.930007         -4.804590
# 7   BiLSTM_GRU_pred    132.382843      0.228595        -12.633702
# 8         QRNN_pred    -26.319025     -0.489389        -17.860957
# 9          ESN_pred     54.774144     -0.183495         -5.909832
# 10         BNN_pred   -110.104554     -0.855082        -21.670615
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    143.468489      0.265062        -17.054487
# 1             PV_dw     12.068003     -0.247143        -19.441693
# 2             PV_cw    101.978438      0.106951        -13.819093
# 3         LSTM_pred    216.635157      0.544607         -9.555603
# 4          GRU_pred    114.955176      0.155253        -14.270753
# 5     LSTM_GRU_pred     -0.539229     -0.300173        -16.320926
# 6       BiLSTM_pred    213.002152      0.515897         -7.649068
# 7   BiLSTM_GRU_pred    136.828308      0.232940        -17.107400
# 8         QRNN_pred     23.278122     -0.226991        -16.260662
# 9          ESN_pred    239.992463      0.686661         -6.518963
# 10         BNN_pred    -70.452161     -0.624627        -20.682046
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     78.240677      0.017829        -16.858938
# 1             PV_dw     27.004497     -0.183038        -19.474197
# 2             PV_cw    168.195717      0.346945        -13.594821
# 3         LSTM_pred    230.551487      0.593081        -10.259727
# 4          GRU_pred     76.464786      0.012072        -16.532926
# 5     LSTM_GRU_pred     82.231873      0.033176        -16.320926
# 6       BiLSTM_pred    206.611370      0.485764         -9.839228
# 7   BiLSTM_GRU_pred    130.707418      0.210066        -17.287518
# 8         QRNN_pred     87.635744      0.051542        -17.251467
# 9          ESN_pred    221.223934      0.556106        -10.747997
# 10         BNN_pred    -59.031356     -0.553507        -19.620000
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     61.144234     -0.060540        -16.884504
# 1             PV_dw     78.862333      0.020307        -17.370508
# 2             PV_cw     81.767362      0.026806        -14.612838
# 3         LSTM_pred     95.088353      0.082169        -16.738028
# 4          GRU_pred    134.264623      0.224259        -13.442550
# 5     LSTM_GRU_pred     16.208962     -0.226895        -14.886407
# 6       BiLSTM_pred    113.714445      0.150392        -13.416015
# 7   BiLSTM_GRU_pred    148.868681      0.277642        -13.229595
# 8         QRNN_pred     42.313927     -0.144031        -17.510336
# 9          ESN_pred    181.290542      0.459436         -4.460570
# 10         BNN_pred     59.621302     -0.053036        -15.248588
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     76.973938      0.012264        -18.535791
# 1             PV_dw     85.841392      0.048361        -17.497157
# 2             PV_cw     56.644301     -0.065986        -14.985792
# 3         LSTM_pred    115.404310      0.155125        -15.173647
# 4          GRU_pred    118.454972      0.166183        -15.349239
# 5     LSTM_GRU_pred     32.850618     -0.150055        -16.320926
# 6       BiLSTM_pred     96.399387      0.087383        -16.035561
# 7   BiLSTM_GRU_pred     93.543281      0.077426        -16.885157
# 8         QRNN_pred     61.704436     -0.052324        -16.035561
# 9          ESN_pred    346.408223      0.998157         -4.440325
# 10         BNN_pred     63.897903     -0.032054        -17.252590
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     99.844030      0.099832        -15.916361
# 1             PV_dw     83.975629      0.041683        -17.497157
# 2             PV_cw    125.472978      0.191124        -15.916361
# 3         LSTM_pred    124.090705      0.185325        -15.916361
# 4          GRU_pred    115.768295      0.156283        -15.916361
# 5     LSTM_GRU_pred     80.508106      0.030050        -16.320926
# 6       BiLSTM_pred    108.104983      0.129408        -16.035561
# 7   BiLSTM_GRU_pred    114.206295      0.150815        -15.941015
# 8         QRNN_pred    115.639760      0.156018        -15.774136
# 9          ESN_pred    160.191238      0.313052        -14.965803
# 10         BNN_pred     79.258130      0.025340        -16.607382
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     64.011005     -0.040954        -15.965790
# 1             PV_dw     90.204892      0.065678        -15.927305
# 2             PV_cw     77.495060      0.013023        -14.612838
# 3         LSTM_pred     86.980667      0.052298        -16.738028
# 4          GRU_pred    134.264623      0.224259        -13.442550
# 5     LSTM_GRU_pred     67.832245     -0.017747        -14.985792
# 6       BiLSTM_pred    127.574731      0.200090        -13.258478
# 7   BiLSTM_GRU_pred    147.039623      0.271094        -13.229595
# 8         QRNN_pred     68.755799     -0.018169        -17.510336
# 9          ESN_pred    140.024227      0.270508         -5.267151
# 10         BNN_pred     85.270194      0.045765        -14.561053
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    116.253486      0.157980        -15.916361
# 1             PV_dw    112.064456      0.143307        -15.916361
# 2             PV_cw     61.635223     -0.042019        -14.985792
# 3         LSTM_pred    107.146211      0.126017        -15.173647
# 4          GRU_pred    118.454972      0.166183        -15.349239
# 5     LSTM_GRU_pred     92.363602      0.073302        -16.010201
# 6       BiLSTM_pred    110.282781      0.137214        -15.916361
# 7   BiLSTM_GRU_pred     95.076314      0.082937        -16.864513
# 8         QRNN_pred     57.979601     -0.056998        -16.035561
# 9          ESN_pred    139.818760      0.240818        -13.957181
# 10         BNN_pred     99.888448      0.100228        -16.600561
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    115.768295      0.156283        -15.916361
# 1             PV_dw    112.064456      0.143307        -15.916361
# 2             PV_cw    110.314378      0.137167        -15.916361
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred    115.768295      0.156283        -15.916361
# 5     LSTM_GRU_pred    100.362599      0.101982        -15.916361
# 6       BiLSTM_pred    115.768295      0.156283        -15.916361
# 7   BiLSTM_GRU_pred    115.768295      0.156283        -15.916361
# 8         QRNN_pred    115.768295      0.156283        -15.916361
# 9          ESN_pred    115.768295      0.156283        -15.916361
# 10         BNN_pred    115.768295      0.156283        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     90.168731      0.065255        -15.916361
# 1             PV_dw    116.601433      0.159690        -17.333739
# 2             PV_cw    109.072757      0.133014        -15.501378
# 3         LSTM_pred    119.699693      0.170025        -15.916361
# 4          GRU_pred    115.768295      0.156283        -15.916361
# 5     LSTM_GRU_pred     51.763250     -0.077272        -17.181310
# 6       BiLSTM_pred    117.580077      0.162687        -15.916361
# 7   BiLSTM_GRU_pred    115.768295      0.156283        -15.916361
# 8         QRNN_pred    127.437097      0.197203        -15.643967
# 9          ESN_pred    206.769933      0.470375        -14.445255
# 10         BNN_pred     62.612055     -0.036944        -16.086953
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    116.807899      0.161073        -15.986496
# 1             PV_dw     47.357722     -0.100139        -20.814152
# 2             PV_cw     42.743664     -0.117631        -16.815361
# 3         LSTM_pred    206.516202      0.506970        -12.026156
# 4          GRU_pred     82.319841      0.034736        -16.035561
# 5     LSTM_GRU_pred    128.199057      0.204335        -16.098501
# 6       BiLSTM_pred    173.710927      0.368862        -10.638323
# 7   BiLSTM_GRU_pred    133.837115      0.222235        -16.342784
# 8         QRNN_pred     76.362897      0.009261        -19.073307
# 9          ESN_pred    197.501755      0.469336        -14.434207
# 10         BNN_pred     -4.866423     -0.319898        -20.088702
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     20.749897     -0.252459        -15.950397
# 1             PV_dw     49.016060     -0.103825        -18.493148
# 2             PV_cw     11.422116     -0.272941        -13.368470
# 3         LSTM_pred     54.487859     -0.131839        -11.772797
# 4          GRU_pred    155.472173      0.314557        -16.134122
# 5     LSTM_GRU_pred    -72.053156     -0.745220        -13.808280
# 6       BiLSTM_pred    237.289190      0.626066         -6.157249
# 7   BiLSTM_GRU_pred     57.508868     -0.073510        -14.167823
# 8         QRNN_pred    -37.717343     -0.548297        -17.137873
# 9          ESN_pred     80.227270     -0.017041         -5.027505
# 10         BNN_pred    -28.492380     -0.458224        -20.967047
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     43.072594     -0.125325        -17.198380
# 1             PV_dw     57.293251     -0.063573        -19.585025
# 2             PV_cw     12.395647     -0.250798        -15.714282
# 3         LSTM_pred    197.549651      0.475569        -11.296459
# 4          GRU_pred     82.319841      0.034736        -16.035561
# 5     LSTM_GRU_pred     26.428882     -0.193354        -16.771894
# 6       BiLSTM_pred    159.191345      0.322092         -8.442480
# 7   BiLSTM_GRU_pred    129.928423      0.208613        -16.268582
# 8         QRNN_pred     18.157267     -0.246034        -17.165423
# 9          ESN_pred    248.649211      0.739617         -4.908195
# 10         BNN_pred    -25.578830     -0.417805        -20.427397
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    103.850239      0.114238        -15.986496
# 1             PV_dw     50.718088     -0.087660        -20.146290
# 2             PV_cw     32.146501     -0.164462        -15.585690
# 3         LSTM_pred    211.247673      0.524404        -12.026156
# 4          GRU_pred     82.319841      0.034736        -16.035561
# 5     LSTM_GRU_pred    103.904132      0.114390        -16.098501
# 6       BiLSTM_pred    192.947882      0.437284        -10.638323
# 7   BiLSTM_GRU_pred    133.837115      0.222235        -16.342784
# 8         QRNN_pred     91.486835      0.067058        -18.217590
# 9          ESN_pred    265.825420      0.728016         -9.520506
# 10         BNN_pred    -11.672727     -0.349114        -20.088702
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV      1.474830     -0.337359        -15.950397
# 1             PV_dw     90.755991      0.065826        -16.340172
# 2             PV_cw     43.488466     -0.133359        -12.758400
# 3         LSTM_pred    117.242950      0.162952        -15.765770
# 4          GRU_pred    110.794120      0.139415        -15.969312
# 5     LSTM_GRU_pred   -116.547128     -0.883682        -17.309483
# 6       BiLSTM_pred    123.975218      0.186730        -13.816620
# 7   BiLSTM_GRU_pred    118.581277      0.167657        -14.671762
# 8         QRNN_pred     40.318507     -0.161648        -17.064854
# 9          ESN_pred    130.757049      0.261018         -5.004328
# 10         BNN_pred     19.905793     -0.210555        -15.785377
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     13.408994     -0.241195        -17.198380
# 1             PV_dw    105.960794      0.121856        -17.333739
# 2             PV_cw     44.717725     -0.117057        -15.112064
# 3         LSTM_pred    115.404310      0.155125        -15.173647
# 4          GRU_pred    115.768295      0.156283        -15.916361
# 5     LSTM_GRU_pred    -32.590875     -0.417461        -17.858337
# 6       BiLSTM_pred    107.687350      0.128040        -15.916361
# 7   BiLSTM_GRU_pred    119.823173      0.170617        -14.690724
# 8         QRNN_pred     52.015438     -0.093574        -17.092429
# 9          ESN_pred    363.360330      1.068243         -4.951461
# 10         BNN_pred     57.126946     -0.058531        -16.440835
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     75.351521      0.011248        -15.916361
# 1             PV_dw    115.536747      0.155993        -17.333739
# 2             PV_cw     85.677969      0.047263        -15.138503
# 3         LSTM_pred    124.090705      0.185325        -15.916361
# 4          GRU_pred    115.768295      0.156283        -15.916361
# 5     LSTM_GRU_pred     22.361497     -0.191073        -17.181310
# 6       BiLSTM_pred    128.571830      0.201106        -15.916361
# 7   BiLSTM_GRU_pred    115.768295      0.156283        -15.916361
# 8         QRNN_pred    128.830950      0.202341        -15.643967
# 9          ESN_pred    248.986352      0.617631        -12.132442
# 10         BNN_pred     55.344225     -0.064368        -16.086953
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     17.816473     -0.245814        -15.950397
# 1             PV_dw     74.424692      0.007788        -17.510336
# 2             PV_cw     20.206969     -0.222048        -15.233286
# 3         LSTM_pred    108.971239      0.132918        -15.765770
# 4          GRU_pred    110.794120      0.139415        -15.969312
# 5     LSTM_GRU_pred     75.733508      0.011686        -14.985792
# 6       BiLSTM_pred    121.132108      0.176270        -13.816620
# 7   BiLSTM_GRU_pred    118.581277      0.167657        -14.671762
# 8         QRNN_pred     47.343189     -0.111022        -17.064854
# 9          ESN_pred     55.582794     -0.127132         -6.462878
# 10         BNN_pred     91.405522      0.068518        -14.561053
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     52.489585     -0.081706        -17.198380
# 1             PV_dw    115.768295      0.156283        -15.916361
# 2             PV_cw     52.189601     -0.082620        -15.527827
# 3         LSTM_pred    107.146211      0.126017        -15.173647
# 4          GRU_pred    115.768295      0.156283        -15.916361
# 5     LSTM_GRU_pred    101.064313      0.104406        -16.010201
# 6       BiLSTM_pred    100.533068      0.102418        -15.916361
# 7   BiLSTM_GRU_pred    119.823173      0.170617        -14.690724
# 8         QRNN_pred     47.313909     -0.098698        -17.092429
# 9          ESN_pred    242.018159      0.620404         -6.040277
# 10         BNN_pred     99.888448      0.100228        -16.600561
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    115.768295      0.156283        -15.916361
# 1             PV_dw    115.768295      0.156283        -15.916361
# 2             PV_cw     79.504139      0.025822        -16.035561
# 3         LSTM_pred    115.768295      0.156283        -15.916361
# 4          GRU_pred    115.768295      0.156283        -15.916361
# 5     LSTM_GRU_pred    100.362599      0.101982        -15.916361
# 6       BiLSTM_pred    115.768295      0.156283        -15.916361
# 7   BiLSTM_GRU_pred    115.768295      0.156283        -15.916361
# 8         QRNN_pred    115.768295      0.156283        -15.916361
# 9          ESN_pred    108.571536      0.131030        -15.916361
# 10         BNN_pred    107.506067      0.127275        -15.916361
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    119.146665      0.171268        -14.629155
# 1             PV_dw     75.146088      0.006312        -19.736780
# 2             PV_cw     98.085177      0.093162        -16.035561
# 3         LSTM_pred    185.582330      0.419120        -11.585714
# 4          GRU_pred    125.884958      0.202869        -10.309769
# 5     LSTM_GRU_pred     97.587518      0.091112        -16.320926
# 6       BiLSTM_pred    136.283022      0.235434        -11.917096
# 7   BiLSTM_GRU_pred     97.731075      0.091929        -16.145660
# 8         QRNN_pred    134.349656      0.229486        -12.907763
# 9          ESN_pred     87.090930      0.051243        -16.035561
# 10         BNN_pred     -5.442657     -0.314445        -17.968743
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     60.318850     -0.065826        -14.700679
# 1             PV_dw    -14.766438     -0.380089        -22.327513
# 2             PV_cw    119.003665      0.173813        -14.570878
# 3         LSTM_pred     84.147161      0.031014        -12.812843
# 4          GRU_pred     50.193691     -0.115380        -14.016393
# 5     LSTM_GRU_pred     16.984456     -0.272470        -11.830200
# 6       BiLSTM_pred    191.796990      0.460005         -8.951205
# 7   BiLSTM_GRU_pred    136.426111      0.238202        -15.521917
# 8         QRNN_pred    -16.264977     -0.401600        -18.969766
# 9          ESN_pred     47.857373     -0.127230        -14.338896
# 10         BNN_pred    -61.607645     -0.681063        -18.290207
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     62.094164     -0.168638         -4.630814
# 1             PV_dw   -171.818935     -1.556869        -24.666501
# 2             PV_cw    -10.967097     -0.539330        -11.903480
# 3         LSTM_pred    -59.779307     -1.077017         -8.120826
# 4          GRU_pred    195.433498      0.611970         -5.098962
# 5     LSTM_GRU_pred    -58.424526     -0.889127        -10.172647
# 6       BiLSTM_pred    152.466116      0.379951         -7.039506
# 7   BiLSTM_GRU_pred     17.055259     -0.322932        -14.806254
# 8         QRNN_pred    119.819088      0.240891         -5.213812
# 9          ESN_pred     72.278983     -0.078384         -6.893185
# 10         BNN_pred     56.360419     -0.163067        -13.156507
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     97.704347      0.089202         -5.419056
# 1             PV_dw   -104.092416     -0.876697        -21.566426
# 2             PV_cw     62.724770     -0.081012        -10.825735
# 3         LSTM_pred    -26.309612     -0.557720        -12.719744
# 4          GRU_pred     91.833821      0.061566        -10.394380
# 5     LSTM_GRU_pred    -62.308082     -0.753173        -11.869763
# 6       BiLSTM_pred    213.840532      0.577803         -6.983590
# 7   BiLSTM_GRU_pred     -9.869346     -0.413741        -14.107981
# 8         QRNN_pred    113.839258      0.180220         -8.225263
# 9          ESN_pred    144.989839      0.366349         -4.269483
# 10         BNN_pred     23.565708     -0.299653        -17.844943
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     25.630775     -0.272976        -11.176927
# 1             PV_dw    -60.126905     -0.591534        -22.784299
# 2             PV_cw     58.082902     -0.089677        -14.570878
# 3         LSTM_pred    135.376275      0.246700         -9.378621
# 4          GRU_pred     50.193691     -0.115380        -14.016393
# 5     LSTM_GRU_pred     87.472558      0.047243        -11.528593
# 6       BiLSTM_pred    130.372340      0.223736         -8.605033
# 7   BiLSTM_GRU_pred    113.866259      0.153170        -16.391537
# 8         QRNN_pred    117.180961      0.176476         -8.895484
# 9          ESN_pred     -5.289369     -0.442343        -14.338896
# 10         BNN_pred    -47.045334     -0.610048        -20.310591
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     62.094164     -0.168638         -4.630814
# 1             PV_dw    -86.431414     -0.812478        -19.458313
# 2             PV_cw    -22.370110     -0.564908        -16.070362
# 3         LSTM_pred     59.049407     -0.095379         -8.142870
# 4          GRU_pred    210.493844      0.623424         -7.433682
# 5     LSTM_GRU_pred    -77.923453     -0.889874        -14.556675
# 6       BiLSTM_pred    143.354438      0.296115         -9.229582
# 7   BiLSTM_GRU_pred     98.925251      0.094494        -14.560498
# 8         QRNN_pred     76.901743     -0.027405         -6.498499
# 9          ESN_pred     38.801243     -0.257411         -7.067256
# 10         BNN_pred     44.617689     -0.161820        -14.034224
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     97.704347      0.089202         -5.419056
# 1             PV_dw     19.125415     -0.223410        -18.287828
# 2             PV_cw     18.360804     -0.281366        -13.477761
# 3         LSTM_pred     89.094161      0.054136        -11.239693
# 4          GRU_pred    106.571178      0.125609        -11.614083
# 5     LSTM_GRU_pred    -58.469056     -0.634736        -15.954729
# 6       BiLSTM_pred    165.573482      0.353936         -9.427760
# 7   BiLSTM_GRU_pred     88.263459      0.053444        -14.497255
# 8         QRNN_pred    105.087091      0.125156         -8.225263
# 9          ESN_pred     72.424953     -0.046731         -6.303569
# 10         BNN_pred     15.830794     -0.264774        -17.421870
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     82.534052      0.022431        -11.263503
# 1             PV_dw     56.588277     -0.066066        -19.534241
# 2             PV_cw     47.700083     -0.118445        -16.035561
# 3         LSTM_pred    199.205081      0.468436        -10.865276
# 4          GRU_pred    125.884958      0.202869        -10.309769
# 5     LSTM_GRU_pred     29.811871     -0.173139        -16.320926
# 6       BiLSTM_pred    103.244487      0.111855        -11.917096
# 7   BiLSTM_GRU_pred     59.200611     -0.053394        -17.276889
# 8         QRNN_pred    244.028750      0.677899         -5.776538
# 9          ESN_pred     31.954284     -0.194535        -16.035561
# 10         BNN_pred    -11.189688     -0.350842        -18.927642
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     62.094164     -0.168638         -4.630814
# 1             PV_dw     17.347017     -0.210942        -18.623154
# 2             PV_cw    -30.025549     -0.589763        -16.070362
# 3         LSTM_pred    189.462359      0.447074         -6.921079
# 4          GRU_pred     61.298639     -0.058419        -15.865529
# 5     LSTM_GRU_pred    -19.063186     -0.398108        -18.647228
# 6       BiLSTM_pred     68.961547     -0.028256        -13.374151
# 7   BiLSTM_GRU_pred     90.935026      0.064779        -14.602839
# 8         QRNN_pred     76.901743     -0.027405         -6.498499
# 9          ESN_pred     38.801243     -0.257411         -7.067256
# 10         BNN_pred     79.219231      0.021411        -14.119902
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     97.704347      0.089202         -5.419056
# 1             PV_dw     94.577750      0.081367        -15.927305
# 2             PV_cw     10.386417     -0.311093        -13.477761
# 3         LSTM_pred    100.319768      0.101549        -16.689585
# 4          GRU_pred    104.376802      0.116181        -16.604061
# 5     LSTM_GRU_pred    118.383952      0.166008        -14.777338
# 6       BiLSTM_pred    121.621902      0.177827        -13.810586
# 7   BiLSTM_GRU_pred    141.676828      0.250345        -14.130604
# 8         QRNN_pred    105.087091      0.125156         -8.225263
# 9          ESN_pred     72.424953     -0.046731         -6.303569
# 10         BNN_pred     76.736356      0.015011        -15.984639
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     82.534052      0.022431        -11.263503
# 1             PV_dw    109.228499      0.133342        -16.010201
# 2             PV_cw     24.658770     -0.212391        -16.035561
# 3         LSTM_pred    124.180276      0.185666        -15.173647
# 4          GRU_pred    115.768295      0.156283        -15.916361
# 5     LSTM_GRU_pred    119.247653      0.168539        -15.916361
# 6       BiLSTM_pred    107.089366      0.125819        -15.916361
# 7   BiLSTM_GRU_pred     91.075091      0.068692        -17.165596
# 8         QRNN_pred    238.043748      0.627345         -5.638585
# 9          ESN_pred     31.954284     -0.194535        -16.035561
# 10         BNN_pred     91.658237      0.070805        -17.234371
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    113.956973      0.152448        -14.384824
# 1             PV_dw     13.924168     -0.241972        -18.513351
# 2             PV_cw    153.344867      0.293480        -13.606516
# 3         LSTM_pred    174.968792      0.395477        -10.753024
# 4          GRU_pred    125.884958      0.202869        -10.309769
# 5     LSTM_GRU_pred     22.362281     -0.208262        -15.448263
# 6       BiLSTM_pred    179.542090      0.401288         -9.663178
# 7   BiLSTM_GRU_pred     96.297463      0.085823        -14.782948
# 8         QRNN_pred     58.428348     -0.067119        -16.543193
# 9          ESN_pred     56.462571     -0.079675        -13.254700
# 10         BNN_pred    -86.361649     -0.695005        -21.424683
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     26.576579     -0.223227        -15.291875
# 1             PV_dw    -22.762498     -0.472560        -18.886315
# 2             PV_cw    109.251499      0.136066        -15.458191
# 3         LSTM_pred    116.663903      0.170197        -11.112495
# 4          GRU_pred    139.111259      0.282954        -11.498583
# 5     LSTM_GRU_pred     26.749361     -0.263775        -13.989175
# 6       BiLSTM_pred    117.863030      0.172070        -11.709170
# 7   BiLSTM_GRU_pred    140.023140      0.256179        -14.071680
# 8         QRNN_pred     66.589292     -0.043671        -17.367832
# 9          ESN_pred     -3.584113     -0.378014        -15.341157
# 10         BNN_pred    -66.192445     -0.719755        -20.280509
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     25.992249     -0.458151         -7.807600
# 1             PV_dw   -123.936912     -1.537111        -16.868658
# 2             PV_cw    -38.817218     -0.730069        -12.073197
# 3         LSTM_pred    -57.530210     -1.163367         -7.930455
# 4          GRU_pred    136.213036      0.386653         -4.406039
# 5     LSTM_GRU_pred     -9.669356     -0.719623         -9.656268
# 6       BiLSTM_pred    126.458004      0.263382         -4.985438
# 7   BiLSTM_GRU_pred     90.786740      0.046928         -5.178279
# 8         QRNN_pred    102.772907      0.129665         -5.180814
# 9          ESN_pred     52.459877     -0.246625         -5.094311
# 10         BNN_pred     -1.230376     -0.565771        -13.263850
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     39.492993     -0.275644         -7.055394
# 1             PV_dw   -106.917414     -1.108169        -19.810421
# 2             PV_cw    -37.383610     -0.660550        -11.646755
# 3         LSTM_pred    -32.953705     -0.675881         -9.574814
# 4          GRU_pred     39.753534     -0.230713        -10.345011
# 5     LSTM_GRU_pred   -125.037344     -1.369363        -14.963993
# 6       BiLSTM_pred    154.713457      0.348819         -7.471729
# 7   BiLSTM_GRU_pred     18.887739     -0.293449        -11.818330
# 8         QRNN_pred    148.540122      0.402399         -6.025697
# 9          ESN_pred    102.045098      0.120834         -4.366857
# 10         BNN_pred     23.950716     -0.320001        -17.425268
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     68.372035     -0.068325         -7.938712
# 1             PV_dw   -153.482446     -1.226297        -23.934076
# 2             PV_cw     66.633507     -0.058251        -13.337900
# 3         LSTM_pred    123.116349      0.198161         -8.667740
# 4          GRU_pred    139.111259      0.282954        -11.498583
# 5     LSTM_GRU_pred    -46.699656     -0.634116        -16.533737
# 6       BiLSTM_pred    101.863251      0.106872        -10.679118
# 7   BiLSTM_GRU_pred     84.838641      0.036407        -13.829858
# 8         QRNN_pred    157.700765      0.411957         -6.371517
# 9          ESN_pred     -8.517674     -0.525944        -10.008962
# 10         BNN_pred    -63.604299     -0.730949        -19.779258
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     25.992249     -0.458151         -7.807600
# 1             PV_dw    -97.711140     -0.997565        -18.519268
# 2             PV_cw     -1.925877     -0.481577        -12.457933
# 3         LSTM_pred    -36.089342     -0.843077         -9.051979
# 4          GRU_pred    242.962845      0.779854         -5.071762
# 5     LSTM_GRU_pred    -19.416404     -0.618360         -7.976714
# 6       BiLSTM_pred    208.862198      0.623970         -5.846694
# 7   BiLSTM_GRU_pred    161.338859      0.378677         -5.972069
# 8         QRNN_pred     72.308979     -0.060982         -7.190920
# 9          ESN_pred     38.801243     -0.257411         -7.067256
# 10         BNN_pred      8.684603     -0.394382        -14.851931
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     46.928518     -0.214238         -6.623607
# 1             PV_dw    -56.049970     -0.658097        -18.977042
# 2             PV_cw      2.172209     -0.386103        -12.531885
# 3         LSTM_pred     -6.193483     -0.481228         -8.971041
# 4          GRU_pred     89.342872      0.055004        -11.797763
# 5     LSTM_GRU_pred   -129.257900     -1.144884        -16.861694
# 6       BiLSTM_pred    197.344949      0.497585         -6.354152
# 7   BiLSTM_GRU_pred     79.357247      0.014897        -13.498081
# 8         QRNN_pred    118.724467      0.200068         -6.265271
# 9          ESN_pred     64.930841     -0.091992         -5.929078
# 10         BNN_pred    -26.277204     -0.500001        -18.385923
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.453097      0.323516         -6.073162
# 1             PV_dw      6.864060     -0.283272        -18.060710
# 2             PV_cw    136.846314      0.253944        -13.360593
# 3         LSTM_pred    161.202510      0.344295        -10.034987
# 4          GRU_pred    125.884958      0.202869        -10.309769
# 5     LSTM_GRU_pred    -53.026790     -0.564236        -16.918097
# 6       BiLSTM_pred     84.184112      0.035675        -10.046842
# 7   BiLSTM_GRU_pred     42.585452     -0.125983        -14.700022
# 8         QRNN_pred    185.720336      0.508484         -6.421004
# 9          ESN_pred     51.231701     -0.141364         -7.791090
# 10         BNN_pred    -83.050298     -0.720394        -21.262347
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     25.992249     -0.458151         -7.807600
# 1             PV_dw     32.171995     -0.162246        -17.728358
# 2             PV_cw    -76.440223     -0.879434        -16.070362
# 3         LSTM_pred    204.343950      0.503340         -6.627470
# 4          GRU_pred     75.346082     -0.002835        -13.374151
# 5     LSTM_GRU_pred     80.658326      0.017702        -11.779202
# 6       BiLSTM_pred     60.896036     -0.062137        -13.374151
# 7   BiLSTM_GRU_pred    181.508541      0.420821         -6.860605
# 8         QRNN_pred     64.670349     -0.101565         -7.242512
# 9          ESN_pred     38.801243     -0.257411         -7.067256
# 10         BNN_pred     46.656816     -0.109021        -13.777352
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV     46.928518     -0.214238         -6.623607
# 1             PV_dw     71.039282     -0.003935        -15.927305
# 2             PV_cw    -43.520093     -0.596452        -14.873726
# 3         LSTM_pred    113.481997      0.149026        -15.765770
# 4          GRU_pred     97.424337      0.091156        -16.613306
# 5     LSTM_GRU_pred     39.034941     -0.137481        -14.386451
# 6       BiLSTM_pred     93.490994      0.076045        -14.144070
# 7   BiLSTM_GRU_pred    163.101014      0.326526        -13.229595
# 8         QRNN_pred    110.755194      0.156201         -6.310222
# 9          ESN_pred     64.930841     -0.091992         -5.929078
# 10         BNN_pred     83.191607      0.037399        -14.436907
# 11               __    115.768295      0.156283        -15.916361
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    149.453097      0.323516         -6.073162
# 1             PV_dw    101.014698      0.104300        -16.010201
# 2             PV_cw     80.450951      0.018356        -14.192599
# 3         LSTM_pred     98.388187      0.094864        -16.600561
# 4          GRU_pred    115.768295      0.156283        -15.916361
# 5     LSTM_GRU_pred     96.868611      0.089423        -16.010201
# 6       BiLSTM_pred    104.866891      0.117930        -16.010201
# 7   BiLSTM_GRU_pred    103.799092      0.114143        -16.110643
# 8         QRNN_pred    142.258680      0.295853         -6.421004
# 9          ESN_pred    -14.414078     -0.459210        -13.549217
# 10         BNN_pred     74.865738      0.008944        -16.574123
# 11               __    115.768295      0.156283        -15.916361

# %%
S1_results, S2_results, S3_results, S4_results, S5_results, S6_results, S7_results, S8_results, S9_results, S10_results, S11_results, S12_results, S13_results, S14_results, S15_results, S16_results, S17_results, S18_results, S19_results, S20_results, S21_results, S22_results, S23_results, S24_results, S25_results, S26_results, S27_results, S28_results, S29_results, S30_results, S31_results, S32_results, S33_results, S34_results, S35_results, S36_results, S37_results, S38_results, S39_results, S40_results, S41_results, S42_results, S43_results, S44_results = backtest(data_2024_2y1)
S1_results_abs, S2_results_abs, S3_results_abs, S4_results_abs, S5_results_abs, S6_results_abs, S7_results_abs, S8_results_abs, S9_results_abs, S10_results_abs, S11_results_abs, S12_results_abs, S13_results_abs, S14_results_abs, S15_results_abs, S16_results_abs, S17_results_abs, S18_results_abs, S19_results_abs, S20_results_abs, S21_results_abs, S22_results_abs, S23_results_abs, S24_results_abs, S25_results_abs, S26_results_abs, S27_results_abs, S28_results_abs, S29_results_abs, S30_results_abs, S31_results_abs, S32_results_abs, S33_results_abs, S34_results_abs, S35_results_abs, S36_results_abs, S37_results_abs, S38_results_abs, S39_results_abs, S40_results_abs, S41_results_abs, S42_results_abs, S43_results_abs, S44_results_abs = backtest_abs(data_2024_2y1)

strategy_results = {
    'S1_results': S1_results,
    'S2_results': S2_results,
    'S3_results': S3_results,
    'S4_results': S4_results,
    'S5_results': S5_results,
    'S6_results': S6_results,
    'S7_results': S7_results,
    'S8_results': S8_results,
    'S9_results': S9_results,
    'S10_results': S10_results,
    'S11_results': S11_results,
    'S12_results': S12_results,
    'S13_results': S13_results,
    'S14_results': S14_results,
    'S15_results': S15_results,
    'S16_results': S16_results,
    'S17_results': S17_results,
    'S18_results': S18_results,
    'S19_results': S19_results,
    'S20_results': S20_results,
    'S21_results': S21_results,
    'S22_results': S22_results,
    'S23_results': S23_results,
    'S24_results': S24_results,
    'S25_results': S25_results,
    'S26_results': S26_results,
    'S27_results': S27_results,
    'S28_results': S28_results,
    'S29_results': S29_results,
    'S30_results': S30_results,
    'S31_results': S31_results,
    'S32_results': S32_results,
    'S33_results': S33_results,
    'S34_results': S34_results,
    'S35_results': S35_results,
    'S36_results': S36_results,
    'S37_results': S37_results,
    'S38_results': S38_results,
    'S39_results': S39_results,
    'S40_results': S40_results,
    'S41_results': S41_results,
    'S42_results': S42_results,
    'S43_results': S43_results,
    'S44_results': S44_results,
}

strategy_results_abs = {
    'S1_results_abs': S1_results_abs,
    'S2_results_abs': S2_results_abs,
    'S3_results_abs': S3_results_abs,
    'S4_results_abs': S4_results_abs,
    'S5_results_abs': S5_results_abs,
    'S6_results_abs': S6_results_abs,
    'S7_results_abs': S7_results_abs,
    'S8_results_abs': S8_results_abs,
    'S9_results_abs': S9_results_abs,
    'S10_results_abs': S10_results_abs,
    'S11_results_abs': S11_results_abs,
    'S12_results_abs': S12_results_abs,
    'S13_results_abs': S13_results_abs,
    'S14_results_abs': S14_results_abs,
    'S15_results_abs': S15_results_abs,
    'S16_results_abs': S16_results_abs,
    'S17_results_abs': S17_results_abs,
    'S18_results_abs': S18_results_abs,
    'S19_results_abs': S19_results_abs,
    'S20_results_abs': S20_results_abs,
    'S21_results_abs': S21_results_abs,
    'S22_results_abs': S22_results_abs,
    'S23_results_abs': S23_results_abs,
    'S24_results_abs': S24_results_abs,
    'S25_results_abs': S25_results_abs,
    'S26_results_abs': S26_results_abs,
    'S27_results_abs': S27_results_abs,
    'S28_results_abs': S28_results_abs,
    'S29_results_abs': S29_results_abs,
    'S30_results_abs': S30_results_abs,
    'S31_results_abs': S31_results_abs,
    'S32_results_abs': S32_results_abs,
    'S33_results_abs': S33_results_abs,
    'S34_results_abs': S34_results_abs,
    'S35_results_abs': S35_results_abs,
    'S36_results_abs': S36_results_abs,
    'S37_results_abs': S37_results_abs,
    'S38_results_abs': S38_results_abs,
    'S39_results_abs': S39_results_abs,
    'S40_results_abs': S40_results_abs,
    'S41_results_abs': S41_results_abs,
    'S42_results_abs': S42_results_abs,
    'S43_results_abs': S43_results_abs,
    'S44_results_abs': S44_results_abs,
}

get_final_results('2024_2y1', file, 'PV')
get_final_results_1('2024_2y1', file, 'PV')

get_final_results('2024_2y1', dw_file, 'PV_dw')
get_final_results_1('2024_2y1', dw_file, 'PV_dw')

get_final_results('2024_2y1', cw_file, 'PV_cw')
get_final_results_1('2024_2y1', cw_file, 'PV_cw')
# Out:
# Streaming output truncated to the last 5000 lines.
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:31: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'close buy'
# <ipython-input-4-b267510ae310>:37: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# ...
#
#   data['position'].iloc[i] = 'buy'
# <ipython-input-4-b267510ae310>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['position'].iloc[i] = 'buy'
# <ipython-input-4-b267510ae310>:25: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['equity'].iloc[i] = account_balance + (total_shares * data['Close'].iloc[i])
# <ipython-input-4-b267510ae310>:44: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['Daily Return'] = data['equity'].pct_change()

# %%
print("Results:")
for key, value in strategy_results.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# Results:
# S1_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    436.245563      1.289689         -5.989821
# 1             PV_dw    484.955816      1.364434         -4.910198
# 2             PV_cw    448.444474      1.332564         -5.899067
# 3         LSTM_pred    427.725467      1.234715         -5.333169
# 4          GRU_pred    487.028545      1.462926         -6.012203
# 5     LSTM_GRU_pred    461.974102      1.384616         -6.126868
# 6       BiLSTM_pred    445.207509      1.346185         -5.058145
# 7   BiLSTM_GRU_pred    430.301567      1.276309         -5.273359
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    390.963231      1.228872         -4.959104
# 10         BNN_pred    408.929137      1.132615         -6.265898
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S2_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    401.088488      1.234953         -5.145754
# 1             PV_dw    490.812310      1.454896         -5.154366
# 2             PV_cw    397.410209      1.183211         -5.479789
# 3         LSTM_pred    423.830880      1.320506         -5.258589
# 4          GRU_pred    511.775428      1.586334         -5.960144
# 5     LSTM_GRU_pred    479.800078      1.487076         -6.706127
# 6       BiLSTM_pred    385.670475      1.159806         -7.117221
# 7   BiLSTM_GRU_pred    371.569352      1.089860         -6.149131
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    394.055899      1.233264         -5.809844
# 10         BNN_pred    362.460077      1.098644         -5.334570
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S3_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    340.894788      1.050349         -4.801497
# 1             PV_dw    303.281408      0.917832         -6.121725
# 2             PV_cw    202.021192      0.646434         -4.531812
# 3         LSTM_pred    392.543167      1.244730         -5.258589
# 4          GRU_pred    409.685454      1.458305         -3.835304
# 5     LSTM_GRU_pred    415.077977      1.541171         -4.904834
# 6       BiLSTM_pred    376.284726      1.189020         -5.195791
# 7   BiLSTM_GRU_pred    348.837589      1.070406         -5.258589
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    186.381553      0.510006         -5.084295
# 10         BNN_pred    289.885882      0.902511         -5.731124
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S4_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    455.349489      1.416252         -3.375949
# 1             PV_dw    480.813074      1.435745         -5.154366
# 2             PV_cw    263.216138      0.806965         -5.091576
# 3         LSTM_pred    398.986347      1.260275         -5.258589
# 4          GRU_pred    529.737207      1.666207         -6.745508
# 5     LSTM_GRU_pred    497.334323      1.566511         -7.532836
# 6       BiLSTM_pred    402.520690      1.235885         -4.986201
# 7   BiLSTM_GRU_pred    415.537437      1.271576         -5.258589
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    288.439021      0.887497         -4.960999
# 10         BNN_pred    377.464974      1.188613         -5.483891
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S5_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    401.613576      1.236667         -5.143827
# 1             PV_dw    473.307436      1.404035         -5.154366
# 2             PV_cw    375.104161      1.118522         -5.416193
# 3         LSTM_pred    424.057661      1.326846         -5.258589
# 4          GRU_pred    513.926664      1.592983         -5.951675
# 5     LSTM_GRU_pred    481.905813      1.493801         -6.696598
# 6       BiLSTM_pred    402.812518      1.220712         -5.998070
# 7   BiLSTM_GRU_pred    350.073211      1.026832         -6.183886
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    400.127183      1.260481         -5.809844
# 10         BNN_pred    362.460077      1.098644         -5.334570
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S6_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    339.020053      0.984937         -5.054816
# 1             PV_dw    380.312467      1.080911         -5.703458
# 2             PV_cw    266.382631      0.848617         -5.701295
# 3         LSTM_pred    387.618671      1.128723         -5.258589
# 4          GRU_pred    450.289430      1.396640         -5.880429
# 5     LSTM_GRU_pred    435.358418      1.389290         -6.011531
# 6       BiLSTM_pred    409.380484      1.245546         -5.295755
# 7   BiLSTM_GRU_pred    415.624879      1.294120         -4.236136
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    146.147213      0.289147         -5.577143
# 10         BNN_pred    328.751256      0.908405         -5.212025
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S7_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    487.278942      1.457411         -4.236136
# 1             PV_dw    506.294769      1.429990         -4.910198
# 2             PV_cw    339.325412      1.000686         -6.190152
# 3         LSTM_pred    424.578823      1.234573         -5.258589
# 4          GRU_pred    503.567157      1.533851         -6.783814
# 5     LSTM_GRU_pred    478.187044      1.454046         -6.921509
# 6       BiLSTM_pred    430.232792      1.301622         -5.111104
# 7   BiLSTM_GRU_pred    483.320592      1.475828         -4.236136
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    253.648109      0.696111         -5.247218
# 10         BNN_pred    403.589419      1.130401         -6.052404
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S8_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    436.783826      1.291325         -5.987577
# 1             PV_dw    484.955816      1.364434         -4.910198
# 2             PV_cw    459.067827      1.377567         -5.929395
# 3         LSTM_pred    433.730838      1.258494         -5.258589
# 4          GRU_pred    488.027094      1.465970         -6.008168
# 5     LSTM_GRU_pred    462.955827      1.387650         -6.122757
# 6       BiLSTM_pred    445.207509      1.346185         -5.058145
# 7   BiLSTM_GRU_pred    404.719257      1.201351         -5.369396
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    367.504647      1.153114         -4.865448
# 10         BNN_pred    408.929137      1.132615         -6.265898
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S9_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    353.374890      1.031438         -5.001201
# 1             PV_dw    379.149233      1.138743         -6.367967
# 2             PV_cw    310.480863      0.967006         -5.518400
# 3         LSTM_pred    400.005895      1.176778         -5.960133
# 4          GRU_pred    413.539974      1.236345         -5.902432
# 5     LSTM_GRU_pred    420.666389      1.259774         -5.902432
# 6       BiLSTM_pred    422.819769      1.250246         -6.167489
# 7   BiLSTM_GRU_pred    400.005895      1.176778         -5.960133
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    385.233141      1.100768         -5.352671
# 10         BNN_pred    345.158264      1.039732         -5.065511
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S10_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    503.223174      1.501081         -4.236136
# 1             PV_dw    473.054789      1.399488         -5.924068
# 2             PV_cw    353.661368      0.999262         -6.050560
# 3         LSTM_pred    447.959037      1.322343         -6.159250
# 4          GRU_pred    449.683850      1.327393         -5.924539
# 5     LSTM_GRU_pred    449.683850      1.327393         -5.924539
# 6       BiLSTM_pred    452.186731      1.334807         -5.924068
# 7   BiLSTM_GRU_pred    447.959037      1.322343         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    452.186731      1.271366         -5.924068
# 10         BNN_pred    434.240880      1.295739         -5.725530
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S11_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    452.186731      1.334807         -5.924068
# 1             PV_dw    452.186731      1.334807         -5.924068
# 2             PV_cw    452.186731      1.334807         -5.924068
# 3         LSTM_pred    452.186731      1.334807         -5.924068
# 4          GRU_pred    453.161883      1.337738         -5.920093
# 5     LSTM_GRU_pred    453.161883      1.337738         -5.920093
# 6       BiLSTM_pred    452.186731      1.334807         -5.924068
# 7   BiLSTM_GRU_pred    453.161883      1.337738         -5.920093
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    452.186731      1.334807         -5.924068
# 10         BNN_pred    452.186731      1.334807         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S12_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    436.245563      1.289689         -5.989821
# 1             PV_dw    443.294415      1.231152         -6.009864
# 2             PV_cw    426.449862      1.274398         -6.015191
# 3         LSTM_pred    456.237234      1.267942         -6.019921
# 4          GRU_pred    465.186217      1.410292         -5.955930
# 5     LSTM_GRU_pred    429.196911      1.303907         -6.093676
# 6       BiLSTM_pred    433.598446      1.248046         -6.017631
# 7   BiLSTM_GRU_pred    463.994822      1.306116         -6.070318
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    409.872519      1.173643         -5.058102
# 10         BNN_pred    447.780817      1.246710         -5.650880
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S13_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    488.634122      1.486679         -4.377357
# 1             PV_dw    492.204579      1.487496         -5.045697
# 2             PV_cw    355.348750      1.049348         -5.275653
# 3         LSTM_pred    403.020914      1.171408         -6.764814
# 4          GRU_pred    473.508966      1.477267         -4.785083
# 5     LSTM_GRU_pred    474.265696      1.441119         -5.168662
# 6       BiLSTM_pred    378.768476      1.139361         -4.947322
# 7   BiLSTM_GRU_pred    514.371694      1.530502         -4.257231
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    318.823656      0.940904         -5.958381
# 10         BNN_pred    426.706658      1.238901         -5.511214
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S14_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    315.700768      0.990068         -5.610621
# 1             PV_dw    396.455481      1.258074         -4.304576
# 2             PV_cw    230.692467      0.690481         -4.660324
# 3         LSTM_pred    363.844921      1.121220         -4.957256
# 4          GRU_pred    442.781392      1.601488         -3.545093
# 5     LSTM_GRU_pred    364.943724      1.267696         -4.918037
# 6       BiLSTM_pred    303.007187      0.916472         -5.260452
# 7   BiLSTM_GRU_pred    370.667531      1.125578         -5.064745
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    209.332570      0.576044         -4.812167
# 10         BNN_pred    415.008964      1.263488         -5.873190
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S15_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    418.161754      1.295410         -5.281745
# 1             PV_dw    478.303431      1.470981         -5.309429
# 2             PV_cw    287.687521      0.918956         -5.451428
# 3         LSTM_pred    386.330283      1.190866         -4.891461
# 4          GRU_pred    499.521270      1.608385         -5.400323
# 5     LSTM_GRU_pred    484.790033      1.524892         -5.924870
# 6       BiLSTM_pred    357.753178      1.079501         -5.231513
# 7   BiLSTM_GRU_pred    462.629439      1.396822         -5.340903
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    261.620529      0.776296         -4.660324
# 10         BNN_pred    461.266038      1.384197         -5.068470
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S16_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    489.192020      1.488372         -4.375717
# 1             PV_dw    492.204579      1.487496         -5.045697
# 2             PV_cw    368.644416      1.177118         -5.348973
# 3         LSTM_pred    368.830195      1.106407         -6.864502
# 4          GRU_pred    500.692501      1.548577         -6.444777
# 5     LSTM_GRU_pred    441.569705      1.335282         -6.915217
# 6       BiLSTM_pred    381.539901      1.103751         -4.987428
# 7   BiLSTM_GRU_pred    498.670838      1.496316         -4.358150
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    322.346066      0.967485         -5.020333
# 10         BNN_pred    426.706658      1.238901         -5.511214
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S17_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    324.269088      0.988049         -5.445278
# 1             PV_dw    406.079929      1.168121         -5.584403
# 2             PV_cw    255.918130      0.765409         -5.462795
# 3         LSTM_pred    392.197952      1.132657         -6.255681
# 4          GRU_pred    478.116710      1.550309         -5.692271
# 5     LSTM_GRU_pred    425.265858      1.372787         -5.878700
# 6       BiLSTM_pred    439.790156      1.307685         -6.252542
# 7   BiLSTM_GRU_pred    376.271337      1.106780         -6.111661
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    322.805132      0.941369         -4.947026
# 10         BNN_pred    394.940276      1.110916         -5.252082
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S18_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    378.787093      1.146829         -5.306819
# 1             PV_dw    455.094881      1.269575         -6.184723
# 2             PV_cw    353.762960      1.111922         -5.869775
# 3         LSTM_pred    415.150762      1.197530         -6.255681
# 4          GRU_pred    476.734597      1.516291         -5.608913
# 5     LSTM_GRU_pred    445.701798      1.402641         -5.846926
# 6       BiLSTM_pred    405.268255      1.170860         -6.329148
# 7   BiLSTM_GRU_pred    471.973217      1.386273         -6.315841
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    368.585943      1.083890         -5.108082
# 10         BNN_pred    433.888700      1.219497         -5.218599
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S19_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    436.783826      1.291325         -5.987577
# 1             PV_dw    443.294415      1.231152         -6.009864
# 2             PV_cw    312.629859      0.927491         -6.334464
# 3         LSTM_pred    440.457594      1.266885         -6.025056
# 4          GRU_pred    477.888029      1.461869         -6.654887
# 5     LSTM_GRU_pred    415.869432      1.263659         -6.794338
# 6       BiLSTM_pred    422.070484      1.214370         -6.066412
# 7   BiLSTM_GRU_pred    462.373315      1.355585         -6.132411
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    400.269181      1.157383         -4.992504
# 10         BNN_pred    447.780817      1.246710         -5.650880
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S20_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    338.465789      1.036633         -5.387522
# 1             PV_dw    448.225982      1.376383         -5.258945
# 2             PV_cw    313.462754      0.919505         -5.131900
# 3         LSTM_pred    424.722914      1.191957         -6.159250
# 4          GRU_pred    419.579460      1.256176         -5.869279
# 5     LSTM_GRU_pred    420.666389      1.259774         -5.902432
# 6       BiLSTM_pred    419.379135      1.187215         -6.159250
# 7   BiLSTM_GRU_pred    400.005895      1.185393         -5.960133
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    450.446880      1.286656         -5.661888
# 10         BNN_pred    405.078534      1.220923         -5.183866
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S21_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    393.568249      1.192309         -5.250531
# 1             PV_dw    473.054789      1.399488         -5.924068
# 2             PV_cw    382.255020      1.166773         -5.239790
# 3         LSTM_pred    424.722914      1.256032         -6.159250
# 4          GRU_pred    423.631698      1.261848         -5.902432
# 5     LSTM_GRU_pred    420.568840      1.252120         -5.924539
# 6       BiLSTM_pred    429.589633      1.270631         -6.159250
# 7   BiLSTM_GRU_pred    447.959037      1.322343         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    452.186731      1.285417         -5.924068
# 10         BNN_pred    444.310031      1.327746         -5.150817
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S22_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    452.186731      1.334807         -5.924068
# 1             PV_dw    452.186731      1.334807         -5.924068
# 2             PV_cw    352.248354      1.039419         -5.924068
# 3         LSTM_pred    452.071413      1.334486         -5.924539
# 4          GRU_pred    449.683850      1.327393         -5.924539
# 5     LSTM_GRU_pred    450.772527      1.330645         -5.920093
# 6       BiLSTM_pred    452.186731      1.334807         -5.924068
# 7   BiLSTM_GRU_pred    452.071413      1.334486         -5.924539
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    452.186731      1.295132         -5.924068
# 10         BNN_pred    452.186731      1.334807         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S23_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    442.026872      1.353236         -5.924068
# 1             PV_dw    462.534699      1.329377         -4.913038
# 2             PV_cw    386.628009      1.113206         -5.959856
# 3         LSTM_pred    410.901583      1.199119         -5.954065
# 4          GRU_pred    507.613737      1.602255         -4.977367
# 5     LSTM_GRU_pred    423.051169      1.338398         -5.207074
# 6       BiLSTM_pred    359.827486      1.072016         -4.306999
# 7   BiLSTM_GRU_pred    372.166400      1.081357         -6.364288
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    425.480962      1.210175         -6.081904
# 10         BNN_pred    416.311230      1.216887         -5.491681
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S24_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    419.778822      1.296441         -5.956153
# 1             PV_dw    417.423541      1.345543         -3.606852
# 2             PV_cw    319.688802      0.946361         -5.959856
# 3         LSTM_pred    497.808886      1.548444         -5.258589
# 4          GRU_pred    285.510536      0.893094         -6.126230
# 5     LSTM_GRU_pred    320.926051      1.032110         -4.840674
# 6       BiLSTM_pred    422.629581      1.348675         -5.258589
# 7   BiLSTM_GRU_pred    301.264323      0.882287         -5.303824
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    275.599435      0.821705         -5.626038
# 10         BNN_pred    351.786666      1.089644         -6.156381
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S25_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    177.513287      0.677807         -4.236136
# 1             PV_dw    108.712118      0.153125         -6.677344
# 2             PV_cw     93.709248      0.066251         -3.948420
# 3         LSTM_pred    247.628012      0.785041         -5.258589
# 4          GRU_pred    155.247990      0.453002         -3.324276
# 5     LSTM_GRU_pred    181.957301      0.632824         -4.168088
# 6       BiLSTM_pred    225.767568      0.724575         -5.110742
# 7   BiLSTM_GRU_pred    123.117066      0.218629         -6.163107
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    103.037932      0.117722         -5.988678
# 10         BNN_pred    268.265123      1.059387         -3.167569
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S26_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    280.085006      1.068250         -5.784782
# 1             PV_dw    333.550434      1.155659         -4.535468
# 2             PV_cw    162.344373      0.445727         -4.376378
# 3         LSTM_pred    333.147001      1.098606         -5.258589
# 4          GRU_pred    221.787502      0.737009         -4.637862
# 5     LSTM_GRU_pred    315.135079      1.202256         -4.324620
# 6       BiLSTM_pred    329.359710      1.115077         -5.258589
# 7   BiLSTM_GRU_pred    240.002064      0.704994         -4.022340
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    206.803242      0.617545         -5.619264
# 10         BNN_pred    296.005050      1.035662         -4.901476
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S27_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    297.807470      0.970769         -5.956153
# 1             PV_dw    433.683518      1.409316         -4.952399
# 2             PV_cw    175.326333      0.439159         -5.757063
# 3         LSTM_pred    424.668551      1.398942         -5.258589
# 4          GRU_pred    317.091288      1.119494         -4.615608
# 5     LSTM_GRU_pred    303.140991      1.057356         -5.575688
# 6       BiLSTM_pred    420.008373      1.365533         -5.258589
# 7   BiLSTM_GRU_pred    247.173283      0.703983         -5.303824
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    283.261465      0.901181         -5.704717
# 10         BNN_pred    394.278914      1.278902         -5.516860
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S28_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    177.513287      0.677807         -4.236136
# 1             PV_dw    295.755188      0.871360         -5.542770
# 2             PV_cw    101.261554      0.113045         -6.147138
# 3         LSTM_pred    335.118496      1.037137         -5.450710
# 4          GRU_pred    322.771409      1.257009         -3.251581
# 5     LSTM_GRU_pred    263.268588      1.022847         -5.015815
# 6       BiLSTM_pred    236.530968      0.677839         -4.791853
# 7   BiLSTM_GRU_pred    206.945704      0.590816         -6.134661
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    291.463526      0.850951         -6.668929
# 10         BNN_pred    354.008848      1.124532         -3.520463
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S29_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    281.653974      1.075609         -5.924068
# 1             PV_dw    406.140351      1.207073         -4.035806
# 2             PV_cw    242.111970      0.738291         -5.347406
# 3         LSTM_pred    399.829017      1.190585         -5.420122
# 4          GRU_pred    436.931620      1.579797         -4.553474
# 5     LSTM_GRU_pred    363.224603      1.322409         -4.894823
# 6       BiLSTM_pred    295.192785      0.877073         -4.732884
# 7   BiLSTM_GRU_pred    285.349770      0.827409         -5.715549
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    354.131476      1.052939         -6.415825
# 10         BNN_pred    407.726100      1.250440         -5.068387
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S30_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    302.505861      1.010795         -5.924068
# 1             PV_dw    474.397177      1.385320         -5.085186
# 2             PV_cw    249.208345      0.720043         -6.026942
# 3         LSTM_pred    405.236941      1.207879         -5.265486
# 4          GRU_pred    481.462267      1.648531         -5.588246
# 5     LSTM_GRU_pred    373.846824      1.282297         -5.956002
# 6       BiLSTM_pred    355.075725      1.077134         -4.630528
# 7   BiLSTM_GRU_pred    372.587320      1.107361         -5.674027
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    394.403679      1.165358         -6.378346
# 10         BNN_pred    441.049693      1.309280         -5.298739
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S31_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    177.513287      0.677807         -4.236136
# 1             PV_dw    334.279449      1.068705         -5.203789
# 2             PV_cw    132.632060      0.294519         -5.955168
# 3         LSTM_pred    479.117491      1.494092         -4.886879
# 4          GRU_pred    364.416489      1.032138         -5.586480
# 5     LSTM_GRU_pred    389.361259      1.214969         -5.458382
# 6       BiLSTM_pred    350.624675      1.051716         -5.340660
# 7   BiLSTM_GRU_pred    323.181155      1.000388         -5.329398
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    291.463526      0.850951         -6.668929
# 10         BNN_pred    415.440777      1.222303         -4.689195
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S32_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    281.653974      1.075609         -5.924068
# 1             PV_dw    469.736053      1.435378         -5.258945
# 2             PV_cw    284.925328      0.907695         -5.245596
# 3         LSTM_pred    400.005895      1.176778         -5.960133
# 4          GRU_pred    419.579460      1.191314         -5.869279
# 5     LSTM_GRU_pred    428.691201      1.285445         -5.869279
# 6       BiLSTM_pred    419.051167      1.239003         -6.159250
# 7   BiLSTM_GRU_pred    366.659544      1.097256         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    354.131476      1.052939         -6.415825
# 10         BNN_pred    405.078534      1.220923         -5.183866
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S33_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    299.821061      1.000098         -5.924068
# 1             PV_dw    473.054789      1.399488         -5.924068
# 2             PV_cw    279.628440      0.837292         -5.970585
# 3         LSTM_pred    424.722914      1.256032         -6.159250
# 4          GRU_pred    457.407104      1.350912         -5.902432
# 5     LSTM_GRU_pred    459.718286      1.357872         -5.902432
# 6       BiLSTM_pred    429.703165      1.270954         -6.158761
# 7   BiLSTM_GRU_pred    447.959037      1.322343         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    433.935741      1.251450         -5.999469
# 10         BNN_pred    456.661387      1.355468         -5.379702
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S34_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    398.099198      1.199503         -5.924068
# 1             PV_dw    490.406406      1.499650         -5.402131
# 2             PV_cw    447.208281      1.328393         -5.959856
# 3         LSTM_pred    347.942127      0.997913         -6.183303
# 4          GRU_pred    507.613737      1.602255         -4.977367
# 5     LSTM_GRU_pred    422.436614      1.366721         -5.226046
# 6       BiLSTM_pred    362.626319      1.050408         -6.349550
# 7   BiLSTM_GRU_pred    393.800657      1.170537         -4.342090
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    349.032305      0.998786         -6.450171
# 10         BNN_pred    361.946119      1.146687         -5.164804
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S35_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    402.198554      1.271135         -5.956153
# 1             PV_dw    338.027304      1.071943         -5.055326
# 2             PV_cw    380.592727      1.205085         -4.631609
# 3         LSTM_pred    394.840476      1.323418         -3.920436
# 4          GRU_pred    285.510536      0.893094         -6.126230
# 5     LSTM_GRU_pred    285.687017      0.923806         -4.477422
# 6       BiLSTM_pred    293.139990      0.900794         -5.258589
# 7   BiLSTM_GRU_pred    367.165574      1.169248         -4.505471
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    310.176347      0.967343         -4.581121
# 10         BNN_pred    374.286180      1.185332         -5.248408
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S36_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    181.878641      0.709113         -4.236136
# 1             PV_dw     62.378870     -0.139592         -6.518967
# 2             PV_cw     30.063589     -0.493807         -3.704540
# 3         LSTM_pred    167.257190      0.469589         -3.920436
# 4          GRU_pred    155.247990      0.453002         -3.324276
# 5     LSTM_GRU_pred    176.796839      0.632955         -4.485915
# 6       BiLSTM_pred    125.262041      0.239011         -5.110742
# 7   BiLSTM_GRU_pred     82.999410     -0.007421         -4.214060
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred     39.099031     -0.277213         -8.863895
# 10         BNN_pred    155.925087      0.433664         -4.701142
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S37_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    261.743190      1.045591         -4.236136
# 1             PV_dw    236.034627      0.775973         -4.825484
# 2             PV_cw    117.649356      0.221997         -3.831442
# 3         LSTM_pred    238.015234      0.788743         -3.920436
# 4          GRU_pred    221.787502      0.737009         -4.637862
# 5     LSTM_GRU_pred    305.966086      1.236678         -3.279777
# 6       BiLSTM_pred    246.550683      0.795232         -5.110742
# 7   BiLSTM_GRU_pred    215.368320      0.648839         -3.937295
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    180.501454      0.517401         -3.910380
# 10         BNN_pred    262.791851      0.922764         -2.862087
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S38_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    204.024633      0.589037         -6.142908
# 1             PV_dw    372.847891      1.281045         -3.472759
# 2             PV_cw    207.610401      0.704376         -3.288230
# 3         LSTM_pred    252.621529      0.855927         -3.920436
# 4          GRU_pred    317.091288      1.119494         -4.615608
# 5     LSTM_GRU_pred    354.393667      1.391286         -3.521792
# 6       BiLSTM_pred    312.590458      1.033007         -5.258589
# 7   BiLSTM_GRU_pred    316.421530      1.006265         -4.158256
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    307.074309      1.029843         -4.055199
# 10         BNN_pred    278.219367      0.942404         -3.293914
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S39_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    181.878641      0.709113         -4.236136
# 1             PV_dw    224.069703      0.722443         -4.993620
# 2             PV_cw     77.966302     -0.050733         -4.304130
# 3         LSTM_pred    256.451555      0.786032         -5.258589
# 4          GRU_pred    322.771409      1.257009         -3.251581
# 5     LSTM_GRU_pred    144.548350      0.423941         -6.189115
# 6       BiLSTM_pred    286.499818      0.935189         -4.357929
# 7   BiLSTM_GRU_pred     79.512290     -0.021039         -5.843749
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    189.859091      0.501607         -6.663468
# 10         BNN_pred    255.118856      0.915543         -3.616527
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S40_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    252.508996      0.992489         -4.236136
# 1             PV_dw    369.960223      1.223080         -3.716215
# 2             PV_cw    245.145974      0.846269         -4.410941
# 3         LSTM_pred    298.390647      0.894481         -5.258589
# 4          GRU_pred    436.931620      1.579797         -4.553474
# 5     LSTM_GRU_pred    267.380119      0.959593         -5.044871
# 6       BiLSTM_pred    366.728940      1.200506         -4.485937
# 7   BiLSTM_GRU_pred    193.395408      0.515612         -4.246247
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    299.387749      0.901881         -6.664598
# 10         BNN_pred    327.533784      1.094260         -4.189584
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S41_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    280.222699      0.916562         -5.924068
# 1             PV_dw    467.175791      1.478831         -3.716215
# 2             PV_cw    266.924012      0.871319         -4.791681
# 3         LSTM_pred    313.709261      0.950005         -5.258589
# 4          GRU_pred    481.462267      1.648531         -5.588246
# 5     LSTM_GRU_pred    347.327795      1.257885         -4.883393
# 6       BiLSTM_pred    308.163715      0.936587         -5.257802
# 7   BiLSTM_GRU_pred    297.224697      0.876907         -5.020662
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    345.838270      1.049605         -6.668097
# 10         BNN_pred    343.694689      1.134872         -4.457234
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S42_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    181.878641      0.709113         -4.236136
# 1             PV_dw    310.077243      0.977012         -5.299923
# 2             PV_cw     69.635541     -0.094267         -5.427622
# 3         LSTM_pred    510.912663      1.608696         -4.784041
# 4          GRU_pred    364.416489      1.032138         -5.586480
# 5     LSTM_GRU_pred    361.829021      1.128458         -5.236459
# 6       BiLSTM_pred    313.400397      0.933807         -5.340660
# 7   BiLSTM_GRU_pred    333.447153      1.037675         -4.784543
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    199.749484      0.538080         -6.663468
# 10         BNN_pred    402.125989      1.195886         -4.689195
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S43_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    252.508996      0.992489         -4.236136
# 1             PV_dw    450.286130      1.380591         -5.255416
# 2             PV_cw    250.751254      0.836450         -5.438240
# 3         LSTM_pred    400.005895      1.176778         -5.960133
# 4          GRU_pred    419.579460      1.191314         -5.869279
# 5     LSTM_GRU_pred    403.891245      1.211925         -5.869279
# 6       BiLSTM_pred    412.840369      1.224647         -5.960133
# 7   BiLSTM_GRU_pred    343.931867      1.041303         -5.158908
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    338.933295      1.006220         -6.412458
# 10         BNN_pred    405.078534      1.220923         -5.183866
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S44_results:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    274.630928      0.882749         -5.924068
# 1             PV_dw    466.168114      1.391375         -5.258945
# 2             PV_cw    244.037099      0.732141         -5.866338
# 3         LSTM_pred    424.722914      1.256032         -6.159250
# 4          GRU_pred    457.407104      1.350912         -5.902432
# 5     LSTM_GRU_pred    401.726980      1.198467         -5.902432
# 6       BiLSTM_pred    424.722914      1.256032         -6.159250
# 7   BiLSTM_GRU_pred    419.420398      1.241216         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    386.258001      1.148190         -6.415825
# 10         BNN_pred    428.162001      1.282992         -4.974634
# 11               __    452.186731      1.334807         -5.924068

# %%
print("ABS Results:")
for key, value in strategy_results_abs.items():
    print(f"{key}:\n {value}")
    print("\n\n")
# Out:
# ABS Results:
# S1_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    436.245563      1.289689         -5.989821
# 1             PV_dw    500.436252      1.420615         -5.645555
# 2             PV_cw    474.828370      1.410704         -5.864620
# 3         LSTM_pred    427.725467      1.234715         -5.333169
# 4          GRU_pred    469.021856      1.349244         -5.993681
# 5     LSTM_GRU_pred    424.498605      1.291910         -6.126048
# 6       BiLSTM_pred    445.207509      1.346185         -5.058145
# 7   BiLSTM_GRU_pred    449.297433      1.269398         -5.273359
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    396.364080      1.256648         -4.236136
# 10         BNN_pred    409.680989      1.150893         -5.888132
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S2_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    401.088488      1.234953         -5.145754
# 1             PV_dw    460.587112      1.341618         -6.093232
# 2             PV_cw    379.939488      1.103253         -6.341242
# 3         LSTM_pred    423.830880      1.320506         -5.258589
# 4          GRU_pred    512.487286      1.581222         -5.970289
# 5     LSTM_GRU_pred    374.857692      1.145951         -7.446409
# 6       BiLSTM_pred    385.670475      1.159806         -7.117221
# 7   BiLSTM_GRU_pred    374.994330      1.055085         -6.149131
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    320.620735      0.953563         -5.809844
# 10         BNN_pred    472.650867      1.405198         -5.234553
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S3_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    340.894788      1.050349         -4.801497
# 1             PV_dw    408.922120      1.249682         -5.449189
# 2             PV_cw    139.406440      0.240007         -6.858758
# 3         LSTM_pred    392.543167      1.244730         -5.258589
# 4          GRU_pred    378.497443      1.296805         -5.953741
# 5     LSTM_GRU_pred    294.354999      1.015864         -5.657891
# 6       BiLSTM_pred    376.284726      1.189020         -5.195791
# 7   BiLSTM_GRU_pred    346.689356      1.062825         -5.258589
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    227.713511      0.640261         -5.342822
# 10         BNN_pred    487.737869      1.539751         -3.481710
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S4_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    455.349489      1.416252         -3.375949
# 1             PV_dw    484.758181      1.424414         -6.112953
# 2             PV_cw    194.531288      0.465745         -6.946223
# 3         LSTM_pred    398.986347      1.260275         -5.258589
# 4          GRU_pred    467.373370      1.469246         -6.668182
# 5     LSTM_GRU_pred    390.600550      1.217951         -8.285755
# 6       BiLSTM_pred    402.520690      1.235885         -4.986201
# 7   BiLSTM_GRU_pred    413.282973      1.264172         -5.258589
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    309.477409      0.941575         -4.960999
# 10         BNN_pred    467.739699      1.394917         -5.429693
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S5_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    401.613576      1.236667         -5.143827
# 1             PV_dw    481.057613      1.412710         -6.112953
# 2             PV_cw    354.216775      1.023868         -6.267649
# 3         LSTM_pred    424.057661      1.326846         -5.258589
# 4          GRU_pred    460.047513      1.422066         -5.938407
# 5     LSTM_GRU_pred    376.814095      1.152670         -7.435828
# 6       BiLSTM_pred    402.812518      1.220712         -5.998070
# 7   BiLSTM_GRU_pred    353.444510      0.991815         -6.183886
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    336.275691      1.021668         -5.809844
# 10         BNN_pred    452.425187      1.337245         -5.225579
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S6_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    339.020053      0.984937         -5.054816
# 1             PV_dw    528.715770      1.547386         -5.117088
# 2             PV_cw    268.377745      0.845526         -5.078228
# 3         LSTM_pred    387.618671      1.128723         -5.258589
# 4          GRU_pred    460.705466      1.359846         -6.048261
# 5     LSTM_GRU_pred    387.168876      1.247158         -5.989006
# 6       BiLSTM_pred    409.380484      1.245546         -5.295755
# 7   BiLSTM_GRU_pred    431.577301      1.315833         -4.236136
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    205.187353      0.548360         -4.900431
# 10         BNN_pred    437.456870      1.288479         -5.184198
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S7_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    487.278942      1.457411         -4.236136
# 1             PV_dw    502.815671      1.427723         -5.645555
# 2             PV_cw    333.942920      0.972694         -6.116980
# 3         LSTM_pred    424.578823      1.234573         -5.258589
# 4          GRU_pred    473.214697      1.368594         -6.786700
# 5     LSTM_GRU_pred    439.728677      1.358184         -6.923309
# 6       BiLSTM_pred    430.232792      1.301622         -5.111104
# 7   BiLSTM_GRU_pred    503.020605      1.497038         -4.236136
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    300.440335      0.879796         -4.960999
# 10         BNN_pred    437.962176      1.244616         -6.042648
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S8_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    436.783826      1.291325         -5.987577
# 1             PV_dw    502.815671      1.427723         -5.645555
# 2             PV_cw    477.862739      1.440731         -5.891868
# 3         LSTM_pred    433.730838      1.258494         -5.258589
# 4          GRU_pred    470.008313      1.345234         -5.989659
# 5     LSTM_GRU_pred    425.455165      1.294943         -6.121937
# 6       BiLSTM_pred    445.207509      1.346185         -5.058145
# 7   BiLSTM_GRU_pred    423.375365      1.194421         -5.369396
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    382.466541      1.214773         -4.236136
# 10         BNN_pred    409.680989      1.150893         -5.888132
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S9_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    353.374890      1.031438         -5.001201
# 1             PV_dw    436.544172      1.302808         -5.924068
# 2             PV_cw    277.224662      0.845959         -5.578053
# 3         LSTM_pred    400.005895      1.176778         -5.960133
# 4          GRU_pred    430.344315      1.273491         -6.293260
# 5     LSTM_GRU_pred    401.726980      1.198467         -5.902432
# 6       BiLSTM_pred    422.819769      1.250246         -6.167489
# 7   BiLSTM_GRU_pred    400.005895      1.176778         -5.960133
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    448.327105      1.284260         -5.920093
# 10         BNN_pred    405.778479      1.219972         -4.971295
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S10_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    503.223174      1.501081         -4.236136
# 1             PV_dw    450.199705      1.329122         -5.924068
# 2             PV_cw    354.617015      1.002427         -6.050560
# 3         LSTM_pred    447.959037      1.322343         -6.159250
# 4          GRU_pred    428.722108      1.267936         -6.073221
# 5     LSTM_GRU_pred    449.683850      1.327393         -5.924539
# 6       BiLSTM_pred    452.186731      1.334807         -5.924068
# 7   BiLSTM_GRU_pred    447.959037      1.322343         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    462.421201      1.303260         -5.924068
# 10         BNN_pred    468.267986      1.384558         -5.725530
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S11_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    452.186731      1.334807         -5.924068
# 1             PV_dw    450.199705      1.329122         -5.924068
# 2             PV_cw    452.084332      1.334625         -5.924068
# 3         LSTM_pred    452.186731      1.334807         -5.924068
# 4          GRU_pred    453.161883      1.337738         -5.920093
# 5     LSTM_GRU_pred    453.161883      1.337738         -5.920093
# 6       BiLSTM_pred    452.186731      1.334807         -5.924068
# 7   BiLSTM_GRU_pred    453.161883      1.337738         -5.920093
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    462.421201      1.366582         -5.924068
# 10         BNN_pred    452.186731      1.334807         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S12_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    436.245563      1.289689         -5.989821
# 1             PV_dw    442.918555      1.234139         -5.728702
# 2             PV_cw    426.149712      1.225644         -6.018890
# 3         LSTM_pred    456.237234      1.267942         -6.019921
# 4          GRU_pred    457.711195      1.304714         -5.924272
# 5     LSTM_GRU_pred    443.399354      1.356361         -6.080284
# 6       BiLSTM_pred    433.598446      1.248046         -6.017631
# 7   BiLSTM_GRU_pred    461.663182      1.299144         -6.070318
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    418.851689      1.201808         -5.052731
# 10         BNN_pred    446.348564      1.253664         -5.661211
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S13_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    488.634122      1.486679         -4.377357
# 1             PV_dw    419.335809      1.203875         -6.024266
# 2             PV_cw    343.247923      0.975827         -5.721366
# 3         LSTM_pred    403.020914      1.171408         -6.764814
# 4          GRU_pred    419.579466      1.248231         -6.338261
# 5     LSTM_GRU_pred    451.012568      1.410605         -5.712454
# 6       BiLSTM_pred    378.768476      1.139361         -4.947322
# 7   BiLSTM_GRU_pred    518.153267      1.495351         -4.257231
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    375.867703      1.155383         -5.809844
# 10         BNN_pred    426.279237      1.236398         -5.883858
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S14_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    315.700768      0.990068         -5.610621
# 1             PV_dw    469.851324      1.445906         -5.746137
# 2             PV_cw    216.148532      0.579736         -4.660324
# 3         LSTM_pred    363.844921      1.121220         -4.957256
# 4          GRU_pred    349.579104      1.128429         -5.658541
# 5     LSTM_GRU_pred    347.744206      1.248580         -5.006329
# 6       BiLSTM_pred    321.255117      0.981333         -5.260452
# 7   BiLSTM_GRU_pred    368.484530      1.118150         -5.064745
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    202.802894      0.532324         -5.003201
# 10         BNN_pred    478.460304      1.474790         -5.668710
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S15_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    418.161754      1.295410         -5.281745
# 1             PV_dw    456.616261      1.347307         -6.057091
# 2             PV_cw    257.585549      0.727505         -6.704449
# 3         LSTM_pred    386.330283      1.190866         -4.891461
# 4          GRU_pred    426.971970      1.290142         -6.421229
# 5     LSTM_GRU_pred    461.370908      1.493482         -6.477521
# 6       BiLSTM_pred    357.753178      1.079501         -5.231513
# 7   BiLSTM_GRU_pred    460.299974      1.389564         -5.340903
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    322.381089      0.996308         -4.660324
# 10         BNN_pred    461.034592      1.357887         -6.061143
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S16_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    489.192020      1.488372         -4.375717
# 1             PV_dw    411.644092      1.179868         -6.057091
# 2             PV_cw    323.613740      0.950801         -6.746412
# 3         LSTM_pred    368.830195      1.106407         -6.864502
# 4          GRU_pred    409.511570      1.211337         -5.612060
# 5     LSTM_GRU_pred    417.767572      1.301220         -7.475164
# 6       BiLSTM_pred    381.539901      1.103751         -4.987428
# 7   BiLSTM_GRU_pred    496.283972      1.489113         -4.358150
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    368.493430      1.122254         -4.415119
# 10         BNN_pred    445.790041      1.301298         -5.850809
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S17_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    324.269088      0.988049         -5.445278
# 1             PV_dw    479.795020      1.373531         -5.737710
# 2             PV_cw    195.363900      0.505232         -5.577359
# 3         LSTM_pred    392.197952      1.132657         -6.255681
# 4          GRU_pred    451.406083      1.326888         -5.996251
# 5     LSTM_GRU_pred    419.236200      1.369283         -5.887806
# 6       BiLSTM_pred    459.953659      1.367447         -6.252542
# 7   BiLSTM_GRU_pred    382.340239      1.127542         -6.111661
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    301.529990      0.871407         -4.969398
# 10         BNN_pred    454.762430      1.326359         -5.433867
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S18_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    378.787093      1.146829         -5.306819
# 1             PV_dw    434.560299      1.212932         -5.728702
# 2             PV_cw    270.223830      0.811315         -6.519801
# 3         LSTM_pred    415.150762      1.197530         -6.255681
# 4          GRU_pred    462.512796      1.338013         -6.772371
# 5     LSTM_GRU_pred    469.399305      1.488850         -5.823157
# 6       BiLSTM_pred    405.268255      1.170860         -6.329148
# 7   BiLSTM_GRU_pred    478.464133      1.406935         -6.315841
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    391.366997      1.167584         -4.846864
# 10         BNN_pred    464.457456      1.310714         -5.778838
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S19_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    436.783826      1.291325         -5.987577
# 1             PV_dw    442.918555      1.234139         -5.728702
# 2             PV_cw    255.341160      0.685633         -6.372193
# 3         LSTM_pred    440.457594      1.266885         -6.025056
# 4          GRU_pred    456.291611      1.300491         -5.920297
# 5     LSTM_GRU_pred    429.939434      1.315910         -6.779407
# 6       BiLSTM_pred    422.070484      1.214370         -6.066412
# 7   BiLSTM_GRU_pred    468.821899      1.376185         -6.132411
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    425.682051      1.239675         -4.964243
# 10         BNN_pred    454.518444      1.279278         -5.629412
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S20_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    338.465789      1.036633         -5.387522
# 1             PV_dw    463.083969      1.374724         -5.924068
# 2             PV_cw    309.808010      0.900118         -5.054697
# 3         LSTM_pred    424.722914      1.191957         -6.159250
# 4          GRU_pred    432.265882      1.279306         -6.284817
# 5     LSTM_GRU_pred    411.605829      1.230558         -5.902432
# 6       BiLSTM_pred    419.379135      1.245504         -6.159250
# 7   BiLSTM_GRU_pred    400.005895      1.185393         -5.960133
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    446.172306      1.273695         -5.928914
# 10         BNN_pred    411.680520      1.239220         -5.333526
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S21_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    393.568249      1.192309         -5.250531
# 1             PV_dw    450.199705      1.329122         -5.924068
# 2             PV_cw    350.198879      1.063671         -5.733222
# 3         LSTM_pred    424.722914      1.256032         -6.159250
# 4          GRU_pred    428.722108      1.267936         -6.073221
# 5     LSTM_GRU_pred    420.568840      1.252120         -5.924539
# 6       BiLSTM_pred    429.589633      1.270631         -6.159250
# 7   BiLSTM_GRU_pred    447.959037      1.322343         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    473.054789      1.350397         -5.924068
# 10         BNN_pred    468.267986      1.384558         -5.725530
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S22_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    452.186731      1.334807         -5.924068
# 1             PV_dw    452.186731      1.334807         -5.924068
# 2             PV_cw    333.004379      0.938247         -5.924068
# 3         LSTM_pred    452.071413      1.334486         -5.924539
# 4          GRU_pred    450.772527      1.330645         -5.920093
# 5     LSTM_GRU_pred    449.683850      1.327393         -5.924539
# 6       BiLSTM_pred    452.186731      1.334807         -5.924068
# 7   BiLSTM_GRU_pred    452.071413      1.334486         -5.924539
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    462.421201      1.326912         -5.924068
# 10         BNN_pred    452.186731      1.334807         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S23_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    442.026872      1.353236         -5.924068
# 1             PV_dw    471.294449      1.357094         -4.952294
# 2             PV_cw    403.304168      1.146747         -5.956153
# 3         LSTM_pred    410.901583      1.199119         -5.954065
# 4          GRU_pred    165.261058      0.417774         -7.722705
# 5     LSTM_GRU_pred    456.774171      1.465491         -5.174358
# 6       BiLSTM_pred    359.827486      1.072016         -4.306999
# 7   BiLSTM_GRU_pred    372.166400      1.081357         -6.364288
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    423.761256      1.230977         -6.052623
# 10         BNN_pred    440.259837      1.300895         -5.951595
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S24_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    419.778822      1.296441         -5.956153
# 1             PV_dw    355.373479      1.147153         -7.559290
# 2             PV_cw    339.714586      0.993650         -5.809394
# 3         LSTM_pred    497.808886      1.548444         -5.258589
# 4          GRU_pred    227.181285      0.717723         -5.111423
# 5     LSTM_GRU_pred    276.704144      0.864917         -6.086466
# 6       BiLSTM_pred    422.629581      1.348675         -5.258589
# 7   BiLSTM_GRU_pred    301.264323      0.882287         -5.303824
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    260.103527      0.737971         -5.609108
# 10         BNN_pred    421.989718      1.323839         -5.294487
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S25_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    177.513287      0.677807         -4.236136
# 1             PV_dw    316.358545      1.190794         -4.659014
# 2             PV_cw    194.447484      0.697079         -4.954622
# 3         LSTM_pred    247.628012      0.785041         -5.258589
# 4          GRU_pred    277.480119      1.411087         -3.018241
# 5     LSTM_GRU_pred    213.096431      0.817944         -4.031923
# 6       BiLSTM_pred    225.767568      0.724575         -5.110742
# 7   BiLSTM_GRU_pred    123.117066      0.218629         -6.163107
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    152.897364      0.385671         -6.978696
# 10         BNN_pred    232.780440      0.815859         -4.577512
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S26_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    280.085006      1.068250         -5.784782
# 1             PV_dw    381.552330      1.355663         -4.469306
# 2             PV_cw    231.466389      0.790385         -5.298551
# 3         LSTM_pred    333.147001      1.098606         -5.258589
# 4          GRU_pred    227.858432      0.855621         -6.019994
# 5     LSTM_GRU_pred    265.966184      0.991477         -5.638910
# 6       BiLSTM_pred    329.359710      1.115077         -5.258589
# 7   BiLSTM_GRU_pred    240.002064      0.704994         -4.022340
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    197.161916      0.568229         -5.651432
# 10         BNN_pred    493.044485      1.666939         -4.741637
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S27_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    297.807470      0.970769         -5.956153
# 1             PV_dw    424.879129      1.450676         -5.884229
# 2             PV_cw    172.925082      0.462521         -6.965284
# 3         LSTM_pred    424.668551      1.398942         -5.258589
# 4          GRU_pred    339.154115      1.317577         -4.035822
# 5     LSTM_GRU_pred    228.889662      0.731951         -7.239478
# 6       BiLSTM_pred    420.008373      1.365533         -5.258589
# 7   BiLSTM_GRU_pred    247.173283      0.703983         -5.303824
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    260.635298      0.806770         -5.687551
# 10         BNN_pred    442.961427      1.422226         -5.290532
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S28_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    177.513287      0.677807         -4.236136
# 1             PV_dw    477.294364      1.557624         -5.091576
# 2             PV_cw    177.720003      0.535508         -5.878133
# 3         LSTM_pred    335.118496      1.037137         -5.450710
# 4          GRU_pred    177.767893      0.593260         -5.757861
# 5     LSTM_GRU_pred    355.767277      1.281971         -4.972549
# 6       BiLSTM_pred    236.530968      0.677839         -4.791853
# 7   BiLSTM_GRU_pred    206.945704      0.590816         -6.134661
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    306.108918      0.908412         -6.412875
# 10         BNN_pred    207.358644      0.604996         -5.777474
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S29_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    281.653974      1.075609         -5.924068
# 1             PV_dw    535.837878      1.643632         -4.706561
# 2             PV_cw    161.072818      0.398152         -8.722557
# 3         LSTM_pred    399.829017      1.190585         -5.420122
# 4          GRU_pred    158.845594      0.421178         -7.679737
# 5     LSTM_GRU_pred    401.425679      1.492323         -4.760377
# 6       BiLSTM_pred    295.192785      0.877073         -4.732884
# 7   BiLSTM_GRU_pred    285.349770      0.827409         -5.715549
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    355.087455      1.056391         -6.416242
# 10         BNN_pred    482.934737      1.493363         -5.418267
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S30_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    302.505861      1.010795         -5.924068
# 1             PV_dw    580.795009      1.741788         -4.952294
# 2             PV_cw    235.096957      0.697996         -6.111041
# 3         LSTM_pred    405.236941      1.207879         -5.265486
# 4          GRU_pred    180.771499      0.532941         -6.502372
# 5     LSTM_GRU_pred    406.403798      1.423419         -5.854216
# 6       BiLSTM_pred    355.075725      1.077134         -4.630528
# 7   BiLSTM_GRU_pred    372.587320      1.107361         -5.674027
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    390.142848      1.149783         -6.358559
# 10         BNN_pred    469.326962      1.402312         -5.941958
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S31_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    177.513287      0.677807         -4.236136
# 1             PV_dw    470.642694      1.397041         -5.091576
# 2             PV_cw    219.613711      0.747519         -5.772992
# 3         LSTM_pred    479.117491      1.494092         -4.886879
# 4          GRU_pred    395.136192      1.183125         -6.257875
# 5     LSTM_GRU_pred    368.371716      1.043376         -6.016575
# 6       BiLSTM_pred    350.624675      1.051716         -5.340660
# 7   BiLSTM_GRU_pred    323.181155      1.000388         -5.329398
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    306.108918      0.908412         -6.412875
# 10         BNN_pred    305.037415      0.916989         -5.372229
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S32_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    281.653974      1.075609         -5.924068
# 1             PV_dw    436.544172      1.302808         -5.924068
# 2             PV_cw    238.524811      0.716050         -4.944025
# 3         LSTM_pred    400.005895      1.176778         -5.960133
# 4          GRU_pred    430.344315      1.273491         -6.293260
# 5     LSTM_GRU_pred    419.579460      1.256176         -5.869279
# 6       BiLSTM_pred    419.051167      1.239003         -6.159250
# 7   BiLSTM_GRU_pred    366.659544      1.097256         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    355.087455      1.056391         -6.416242
# 10         BNN_pred    466.706605      1.388375         -4.931935
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S33_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    299.821061      1.000098         -5.924068
# 1             PV_dw    442.357162      1.309865         -5.924068
# 2             PV_cw    291.453163      0.882397         -5.970585
# 3         LSTM_pred    424.722914      1.256032         -6.159250
# 4          GRU_pred    457.407104      1.350912         -5.902432
# 5     LSTM_GRU_pred    459.718286      1.357872         -5.902432
# 6       BiLSTM_pred    429.703165      1.270954         -6.158761
# 7   BiLSTM_GRU_pred    447.959037      1.322343         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    440.872854      1.272049         -5.970585
# 10         BNN_pred    464.740334      1.373549         -5.924068
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S34_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    398.099198      1.199503         -5.924068
# 1             PV_dw    389.406121      1.198268         -4.931164
# 2             PV_cw    433.307424      1.261129         -5.973596
# 3         LSTM_pred    347.942127      0.997913         -6.183303
# 4          GRU_pred    165.261058      0.417774         -7.722705
# 5     LSTM_GRU_pred    441.914321      1.447840         -5.691271
# 6       BiLSTM_pred    362.626319      1.050408         -6.349550
# 7   BiLSTM_GRU_pred    393.800657      1.170537         -4.342090
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    388.067264      1.098925         -6.237968
# 10         BNN_pred    429.183194      1.301329         -5.462388
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S35_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    402.198554      1.271135         -5.956153
# 1             PV_dw    357.290989      1.180622         -6.743332
# 2             PV_cw    356.712528      1.080563         -5.809394
# 3         LSTM_pred    394.840476      1.323418         -3.920436
# 4          GRU_pred    227.181285      0.717723         -5.111423
# 5     LSTM_GRU_pred    239.662581      0.717982         -4.413335
# 6       BiLSTM_pred    293.139990      0.900794         -5.258589
# 7   BiLSTM_GRU_pred    367.165574      1.169248         -4.505471
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    320.374615      1.005787         -4.624801
# 10         BNN_pred    250.170402      0.763338         -6.273944
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S36_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    181.878641      0.709113         -4.236136
# 1             PV_dw    269.293396      1.199257         -4.327503
# 2             PV_cw    126.809076      0.302857         -4.904154
# 3         LSTM_pred    167.257190      0.469589         -3.920436
# 4          GRU_pred    277.480119      1.411087         -3.018241
# 5     LSTM_GRU_pred    166.116519      0.575110         -3.449340
# 6       BiLSTM_pred    125.262041      0.239011         -5.110742
# 7   BiLSTM_GRU_pred     76.495650     -0.052269         -4.239520
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    144.809274      0.376905         -6.997434
# 10         BNN_pred    141.747076      0.402724         -5.520850
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S37_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    261.743190      1.045591         -4.236136
# 1             PV_dw    311.803747      1.245644         -4.993460
# 2             PV_cw    142.598837      0.353798         -5.454516
# 3         LSTM_pred    238.015234      0.788743         -3.920436
# 4          GRU_pred    227.858432      0.855621         -6.019994
# 5     LSTM_GRU_pred    243.613368      0.948368         -4.110280
# 6       BiLSTM_pred    246.550683      0.795232         -5.110742
# 7   BiLSTM_GRU_pred    215.368320      0.648839         -3.937295
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    232.225666      0.778885         -4.953939
# 10         BNN_pred    264.803842      0.929080         -5.491398
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S38_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    204.024633      0.589037         -6.142908
# 1             PV_dw    369.095077      1.387777         -7.026220
# 2             PV_cw    206.313773      0.652327         -5.703303
# 3         LSTM_pred    252.621529      0.855927         -3.920436
# 4          GRU_pred    339.154115      1.317577         -4.035822
# 5     LSTM_GRU_pred    241.610080      0.837122         -4.834110
# 6       BiLSTM_pred    312.590458      1.033007         -5.258589
# 7   BiLSTM_GRU_pred    316.421530      1.006265         -4.158256
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    339.637925      1.173439         -4.729225
# 10         BNN_pred    322.909808      1.125543         -5.796052
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S39_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    181.878641      0.709113         -4.236136
# 1             PV_dw    250.293110      0.848494         -3.799675
# 2             PV_cw    171.340909      0.518131         -6.058165
# 3         LSTM_pred    256.451555      0.786032         -5.258589
# 4          GRU_pred    177.767893      0.593260         -5.757861
# 5     LSTM_GRU_pred    283.905318      1.027241         -4.349037
# 6       BiLSTM_pred    286.499818      0.935189         -4.357929
# 7   BiLSTM_GRU_pred     97.080126      0.086524         -5.750171
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    268.565863      0.799422         -5.824829
# 10         BNN_pred    199.019660      0.653804         -4.827642
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S40_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    252.508996      0.992489         -4.236136
# 1             PV_dw    332.152673      1.115196         -3.799675
# 2             PV_cw    169.489485      0.447484         -6.108161
# 3         LSTM_pred    298.390647      0.894481         -5.258589
# 4          GRU_pred    158.845594      0.421178         -7.679737
# 5     LSTM_GRU_pred    373.561873      1.436763         -4.878153
# 6       BiLSTM_pred    366.728940      1.200506         -4.485937
# 7   BiLSTM_GRU_pred    193.395408      0.515612         -4.246247
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    313.891414      0.946698         -6.698283
# 10         BNN_pred    384.963240      1.240459         -4.142338
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S41_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    280.222699      0.916562         -5.924068
# 1             PV_dw    417.855806      1.372421         -5.700580
# 2             PV_cw    266.792809      0.851618         -6.043129
# 3         LSTM_pred    313.709261      0.950005         -5.258589
# 4          GRU_pred    180.771499      0.532941         -6.502372
# 5     LSTM_GRU_pred    376.640108      1.400145         -5.303844
# 6       BiLSTM_pred    308.163715      0.936587         -5.257802
# 7   BiLSTM_GRU_pred    297.224697      0.876907         -5.020662
# 8         QRNN_pred    205.917691      0.578076         -4.577363
# 9          ESN_pred    361.986119      1.094091         -6.595811
# 10         BNN_pred    491.585722      1.538988         -5.023329
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S42_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    181.878641      0.709113         -4.236136
# 1             PV_dw    396.002758      1.233308         -4.236136
# 2             PV_cw    195.784441      0.631892         -5.893123
# 3         LSTM_pred    510.912663      1.608696         -4.784041
# 4          GRU_pred    395.136192      1.183125         -6.257875
# 5     LSTM_GRU_pred    336.994995      0.943091         -6.157772
# 6       BiLSTM_pred    313.400397      0.933807         -5.340660
# 7   BiLSTM_GRU_pred    333.447153      1.037675         -4.784543
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    318.446204      0.954354         -5.575821
# 10         BNN_pred    289.406293      0.864450         -6.406695
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S43_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    252.508996      0.992489         -4.236136
# 1             PV_dw    416.449752      1.254160         -5.258945
# 2             PV_cw    219.714894      0.638476         -5.980206
# 3         LSTM_pred    400.005895      1.176778         -5.960133
# 4          GRU_pred    430.344315      1.273491         -6.293260
# 5     LSTM_GRU_pred    428.691201      1.285445         -5.869279
# 6       BiLSTM_pred    412.840369      1.224647         -5.960133
# 7   BiLSTM_GRU_pred    343.931867      1.041303         -5.158908
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    365.553968      1.093034         -6.411936
# 10         BNN_pred    409.314475      1.233128         -4.931935
# 11               __    452.186731      1.334807         -5.924068
#
#
#
# S44_results_abs:
#           Volatility  Total profit  Sharpe ratio  Max drawdown (%)
# 0                PV    274.630928      0.882749         -5.924068
# 1             PV_dw    463.083969      1.374724         -5.924068
# 2             PV_cw    273.467642      0.813130         -5.999469
# 3         LSTM_pred    424.722914      1.256032         -6.159250
# 4          GRU_pred    457.407104      1.350912         -5.902432
# 5     LSTM_GRU_pred    401.726980      1.198467         -5.902432
# 6       BiLSTM_pred    424.722914      1.256032         -6.159250
# 7   BiLSTM_GRU_pred    419.420398      1.241216         -6.159250
# 8         QRNN_pred    452.186731      1.334807         -5.924068
# 9          ESN_pred    386.258001      1.148370         -6.416242
# 10         BNN_pred    459.818202      1.364731         -5.150817
# 11               __    452.186731      1.334807         -5.924068

# %%
# path_1 = '/content/drive/MyDrive/Strategy/MA/PV/PV/'
# path_2 = '/content/drive/MyDrive/Strategy/MA/PV/DW_PV/'
# path_3 = '/content/drive/MyDrive/Strategy/MA/PV/CW_PV/'

# file_name = 'file.csv'
# file.to_csv(path_1 + file_name)

# filename = 'file.csv'
# dw_file.to_csv(path_2 + file_name)

# filename = 'file.csv'
# cw_file.to_csv(path_3 + file_name)
