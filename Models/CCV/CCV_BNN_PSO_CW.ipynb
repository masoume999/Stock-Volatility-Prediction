# %%
# !pip install pyswarm
# Out:
# Collecting pyswarm
#   Downloading pyswarm-0.6.tar.gz (4.3 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyswarm) (1.26.4)
# Building wheels for collected packages: pyswarm
#   Building wheel for pyswarm (setup.py) ... done
#   Created wheel for pyswarm: filename=pyswarm-0.6-py3-none-any.whl size=4464 sha256=dc5c18b739cb3022b8c0a4ffa05aa242c98fd2def05af12c421ee6276c15a72f
#   Stored in directory: /root/.cache/pip/wheels/71/67/40/62fa158f497f942277cbab8199b05cb61c571ab324e67ad0d6
# Successfully built pyswarm
# Installing collected packages: pyswarm
# Successfully installed pyswarm-0.6

# %%
# from collections import Iterable, OrderedDict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from collections.abc import Iterable
from collections import OrderedDict
from google.colab import drive
from torch.nn import Parameter
from datetime import datetime
from functools import partial
import torch.optim as optim
from pyswarm import pso
import torch.nn as nn
from math import sqrt
import pandas as pd
import numpy as np
import inspect
import torch
import time

# %% [markdown]
# # Load data

# %%
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
# Out:
# Mounted at /content/drive

# %%
def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

# %%
filename = 'CCV_data.csv'
CCV_data = pd.read_csv(path + filename)

# %%
CCV_data
# Out:
#             Date       CCV  ('GARCH', 'normal', 0)  ('GARCH', 'gaussian', 0)  \
# 0     2000-02-02 -0.001801               -0.001864                 -0.001864
# 1     2000-02-03 -0.001563               -0.001554                 -0.001554
# 2     2000-02-04 -0.001145               -0.001080                 -0.001080
# 3     2000-02-07 -0.000751               -0.000627                 -0.000627
# 4     2000-02-08 -0.000376               -0.000202                 -0.000202
# ...          ...       ...                     ...                       ...
# 6179  2024-08-26  0.000446               -0.000358                 -0.000358
# 6180  2024-08-27 -0.000007               -0.000694                 -0.000694
# 6181  2024-08-28 -0.000471               -0.000954                 -0.000954
# 6182  2024-08-29 -0.000957               -0.001147                 -0.001147
# 6183  2024-08-30 -0.001432               -0.001232                 -0.001232
#
#       ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# 0                    -0.001782                 -0.001782
# 1                    -0.001519                 -0.001519
# 2                    -0.001076                 -0.001076
# 3                    -0.000678                 -0.000678
# 4                    -0.000311                 -0.000311
# ...                        ...                       ...
# 6179                 -0.000690                 -0.000690
# 6180                 -0.000899                 -0.000899
# 6181                 -0.001012                 -0.001012
# 6182                 -0.001067                 -0.001067
# 6183                 -0.001030                 -0.001030
#
#       ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)  log_returns  \
# 0                      -0.001782                   -0.001782     0.000077
# 1                      -0.001519                   -0.001519     0.000020
# 2                      -0.001076                   -0.001076     0.000152
# 3                      -0.000678                   -0.000678     0.000090
# 4                      -0.000311                   -0.000311    -0.000335
# ...                          ...                         ...          ...
# 6179                   -0.000690                   -0.000690    -0.000161
# 6180                   -0.000899                   -0.000899    -0.000193
# 6181                   -0.001012                   -0.001012    -0.000154
# 6182                   -0.001067                   -0.001067    -0.000150
# 6183                   -0.001030                   -0.001030    -0.000129
#
#       ('GARCH', 'normal', 1)  ('GARCH', 'gaussian', 1)  ('GARCH', 'ged', 0)  \
# 0                  -0.001725                 -0.001725            -0.001971
# 1                  -0.001557                 -0.001557            -0.001745
# 2                  -0.001163                 -0.001163            -0.001302
# 3                  -0.000738                 -0.000738            -0.000863
# 4                  -0.000335                 -0.000335            -0.000364
# ...                      ...                       ...                  ...
# 6179               -0.000493                 -0.000493            -0.001023
# 6180               -0.000707                 -0.000707            -0.001244
# 6181               -0.000846                 -0.000846            -0.001311
# 6182               -0.000937                 -0.000937            -0.001324
# 6183               -0.000923                 -0.000923            -0.001267
#
#       ('GARCH', 'ged', 1)          vix  unemployment_rate    usd_gbp  \
# 0               -0.001822 -5074.430765        -164.888872 -25.204908
# 1               -0.001612 -4871.204473        -152.205474 -23.159152
# 2               -0.001217 -3989.985998        -116.610418 -17.659121
# 3               -0.000784 -2979.521889         -78.602644 -11.749618
# 4               -0.000368 -1886.674367         -43.682933  -6.356898
# ...                   ...          ...                ...        ...
# 6179            -0.000502  -118.886061          65.925473   7.151391
# 6180            -0.000717  -381.296847          28.527492   3.476358
# 6181            -0.000852  -746.562442         -16.834312  -1.072689
# 6182            -0.000933 -1297.880813         -70.858623  -6.550484
# 6183            -0.000919 -1945.559572        -129.617764 -12.520266
#
#          usd_cny      usd_mxn       gt_data
# 0    -667.139276  -870.717996 -53308.067923
# 1    -618.146493  -799.604126 -49391.829352
# 2    -475.895763  -610.423502 -38026.991031
# 3    -322.833213  -410.827912 -25799.214705
# 4    -182.858321  -230.130383 -14616.177002
# ...          ...          ...           ...
# 6179  185.257251  1524.776491     16.790559
# 6180   76.788614   774.080957  -3946.268810
# 6181  -53.866326  -172.154813  -8749.025243
# 6182 -208.826493 -1344.291544 -14935.055801
# 6183 -376.419611 -2657.323913 -22127.779545
#
# [6184 rows x 19 columns]

# %%
CCV_data.drop(columns=['vix', 'unemployment_rate', 'usd_gbp', 'usd_cny', 'usd_mxn', 'gt_data'], inplace=True)

# %%
CCV_data
# Out:
#             Date       CCV  ('GARCH', 'normal', 0)  ('GARCH', 'gaussian', 0)  \
# 0     2000-02-02 -0.001801               -0.001864                 -0.001864
# 1     2000-02-03 -0.001563               -0.001554                 -0.001554
# 2     2000-02-04 -0.001145               -0.001080                 -0.001080
# 3     2000-02-07 -0.000751               -0.000627                 -0.000627
# 4     2000-02-08 -0.000376               -0.000202                 -0.000202
# ...          ...       ...                     ...                       ...
# 6179  2024-08-26  0.000446               -0.000358                 -0.000358
# 6180  2024-08-27 -0.000007               -0.000694                 -0.000694
# 6181  2024-08-28 -0.000471               -0.000954                 -0.000954
# 6182  2024-08-29 -0.000957               -0.001147                 -0.001147
# 6183  2024-08-30 -0.001432               -0.001232                 -0.001232
#
#       ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# 0                    -0.001782                 -0.001782
# 1                    -0.001519                 -0.001519
# 2                    -0.001076                 -0.001076
# 3                    -0.000678                 -0.000678
# 4                    -0.000311                 -0.000311
# ...                        ...                       ...
# 6179                 -0.000690                 -0.000690
# 6180                 -0.000899                 -0.000899
# 6181                 -0.001012                 -0.001012
# 6182                 -0.001067                 -0.001067
# 6183                 -0.001030                 -0.001030
#
#       ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)  log_returns  \
# 0                      -0.001782                   -0.001782     0.000077
# 1                      -0.001519                   -0.001519     0.000020
# 2                      -0.001076                   -0.001076     0.000152
# 3                      -0.000678                   -0.000678     0.000090
# 4                      -0.000311                   -0.000311    -0.000335
# ...                          ...                         ...          ...
# 6179                   -0.000690                   -0.000690    -0.000161
# 6180                   -0.000899                   -0.000899    -0.000193
# 6181                   -0.001012                   -0.001012    -0.000154
# 6182                   -0.001067                   -0.001067    -0.000150
# 6183                   -0.001030                   -0.001030    -0.000129
#
#       ('GARCH', 'normal', 1)  ('GARCH', 'gaussian', 1)  ('GARCH', 'ged', 0)  \
# 0                  -0.001725                 -0.001725            -0.001971
# 1                  -0.001557                 -0.001557            -0.001745
# 2                  -0.001163                 -0.001163            -0.001302
# 3                  -0.000738                 -0.000738            -0.000863
# 4                  -0.000335                 -0.000335            -0.000364
# ...                      ...                       ...                  ...
# 6179               -0.000493                 -0.000493            -0.001023
# 6180               -0.000707                 -0.000707            -0.001244
# 6181               -0.000846                 -0.000846            -0.001311
# 6182               -0.000937                 -0.000937            -0.001324
# 6183               -0.000923                 -0.000923            -0.001267
#
#       ('GARCH', 'ged', 1)
# 0               -0.001822
# 1               -0.001612
# 2               -0.001217
# 3               -0.000784
# 4               -0.000368
# ...                   ...
# 6179            -0.000502
# 6180            -0.000717
# 6181            -0.000852
# 6182            -0.000933
# 6183            -0.000919
#
# [6184 rows x 13 columns]

# %%
set_index(CCV_data)

# %%
tm_data = CCV_data

# %%
CCV_data = CCV_data.drop(columns=['CCV'])

# %%
CCV_data['CCV'] = tm_data['CCV']

# %%
CCV_data
# Out:
#             ('GARCH', 'normal', 0)  ('GARCH', 'gaussian', 0)  \
# Date
# 2000-02-02               -0.001864                 -0.001864
# 2000-02-03               -0.001554                 -0.001554
# 2000-02-04               -0.001080                 -0.001080
# 2000-02-07               -0.000627                 -0.000627
# 2000-02-08               -0.000202                 -0.000202
# ...                            ...                       ...
# 2024-08-26               -0.000358                 -0.000358
# 2024-08-27               -0.000694                 -0.000694
# 2024-08-28               -0.000954                 -0.000954
# 2024-08-29               -0.001147                 -0.001147
# 2024-08-30               -0.001232                 -0.001232
#
#             ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# Date
# 2000-02-02                 -0.001782                 -0.001782
# 2000-02-03                 -0.001519                 -0.001519
# 2000-02-04                 -0.001076                 -0.001076
# 2000-02-07                 -0.000678                 -0.000678
# 2000-02-08                 -0.000311                 -0.000311
# ...                              ...                       ...
# 2024-08-26                 -0.000690                 -0.000690
# 2024-08-27                 -0.000899                 -0.000899
# 2024-08-28                 -0.001012                 -0.001012
# 2024-08-29                 -0.001067                 -0.001067
# 2024-08-30                 -0.001030                 -0.001030
#
#             ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)  \
# Date
# 2000-02-02                   -0.001782                   -0.001782
# 2000-02-03                   -0.001519                   -0.001519
# 2000-02-04                   -0.001076                   -0.001076
# 2000-02-07                   -0.000678                   -0.000678
# 2000-02-08                   -0.000311                   -0.000311
# ...                                ...                         ...
# 2024-08-26                   -0.000690                   -0.000690
# 2024-08-27                   -0.000899                   -0.000899
# 2024-08-28                   -0.001012                   -0.001012
# 2024-08-29                   -0.001067                   -0.001067
# 2024-08-30                   -0.001030                   -0.001030
#
#             log_returns  ('GARCH', 'normal', 1)  ('GARCH', 'gaussian', 1)  \
# Date
# 2000-02-02     0.000077               -0.001725                 -0.001725
# 2000-02-03     0.000020               -0.001557                 -0.001557
# 2000-02-04     0.000152               -0.001163                 -0.001163
# 2000-02-07     0.000090               -0.000738                 -0.000738
# 2000-02-08    -0.000335               -0.000335                 -0.000335
# ...                 ...                     ...                       ...
# 2024-08-26    -0.000161               -0.000493                 -0.000493
# 2024-08-27    -0.000193               -0.000707                 -0.000707
# 2024-08-28    -0.000154               -0.000846                 -0.000846
# 2024-08-29    -0.000150               -0.000937                 -0.000937
# 2024-08-30    -0.000129               -0.000923                 -0.000923
#
#             ('GARCH', 'ged', 0)  ('GARCH', 'ged', 1)       CCV
# Date
# 2000-02-02            -0.001971            -0.001822 -0.001801
# 2000-02-03            -0.001745            -0.001612 -0.001563
# 2000-02-04            -0.001302            -0.001217 -0.001145
# 2000-02-07            -0.000863            -0.000784 -0.000751
# 2000-02-08            -0.000364            -0.000368 -0.000376
# ...                         ...                  ...       ...
# 2024-08-26            -0.001023            -0.000502  0.000446
# 2024-08-27            -0.001244            -0.000717 -0.000007
# 2024-08-28            -0.001311            -0.000852 -0.000471
# 2024-08-29            -0.001324            -0.000933 -0.000957
# 2024-08-30            -0.001267            -0.000919 -0.001432
#
# [6184 rows x 12 columns]

# %% [markdown]
# # Split train, validation and test data

# %%
# train_end = datetime(2020, 6, 30)
# test_start = datetime(2020, 10, 1)
# val_size = 0.1

# %%
# target = ['CCV', 'CCV', 'PV', 'GKV', 'RSV', 'YZV', 'GKYZV']
# test_data = data.loc[test_start:]

# train_val = data.loc[:train_end]
# train_data, val_data = train_test_split(train_val, test_size=val_size, shuffle=False)

# X_train = train_data.drop(columns=target)
# y_train = train_data[target]

# X_val = val_data.drop(columns=target)
# y_val = val_data[target]

# X_test = test_data.drop(columns=target)
# y_test = test_data[target]

# X_train = np.array(X_train)
# y_train = np.array(y_train)

# X_val = np.array(X_val)
# y_val = np.array(y_val)

# X_test = np.array(X_test)
# y_test = np.array(y_test)

# %%
def split_data(data, target, train_end =datetime(2022, 5, 30), test_start=datetime(2022, 5, 31), test_size=0.1):
  test_data = data.loc[test_start:]

  train_val = data.loc[:train_end]
  train_data, val_data = train_test_split(train_val, test_size=test_size, shuffle=False)

  X_train = train_data.drop(columns=[target])
  y_train = train_data[target]

  X_val = val_data.drop(columns=[target])
  y_val = val_data[target]

  X_test = test_data.drop(columns=[target])
  y_test = test_data[target]

  return np.array(X_train), np.array(y_train), np.array(X_val), np.array(y_val), np.array(X_test), np.array(y_test)

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(CCV_data, 'CCV')

# %% [markdown]
# # Model

# %%
class BDropout(torch.nn.Dropout):

    """Binary dropout with regularization and resampling.

    See: Gal Y., Ghahramani Z., "Dropout as a Bayesian Approximation:
    Representing Model Uncertainty in Deep Learning", 2016.
    """

    # def __init__(self, rate=0.1, reg=1.0, **kwargs):
    #     """Constructs a BDropout.

    #     Args:
    #         rate (float): Dropout probability.
    #         reg (float): Regularization scale.
    #     """
    #     super(BDropout, self).__init__(**kwargs)
    #     self.register_buffer("rate", torch.tensor(rate))
    #     self.p = 1 - self.rate
    #     self.register_buffer("reg", torch.tensor(reg))
    #     self.register_buffer("noise", torch.bernoulli(self.p))


    def __init__(self, rate=0.1, reg=1.0, **kwargs):
        """Constructs a BDropout.

        Args:
            rate (float): Dropout probability.
            reg (float): Regularization scale.
        """
        super(BDropout, self).__init__(p=rate, **kwargs)
        self.register_buffer("rate", torch.tensor(rate))
        self.p = 1 - self.rate
        self.register_buffer("reg", torch.tensor(reg))
        self.register_buffer("noise", torch.bernoulli(self.p))

    def regularization(self, weight, bias):
        """Computes the regularization cost.

        Args:
            weight (Tensor): Weight tensor.
            bias (Tensor): Bias tensor.

        Returns:
            Regularization cost (Tensor).
        """
        self.p = 1 - self.rate
        weight_reg = self.p * (weight**2).sum()
        bias_reg = (bias**2).sum() if bias is not None else 0
        return self.reg * (weight_reg + bias_reg)

    def resample(self):
        """Resamples the dropout noise."""
        self._update_noise(self.noise)

    def _update_noise(self, x):
        """Updates the dropout noise.

        Args:
            x (Tensor): Input.
        """
        self.p = 1 - self.rate
        self.noise.data = torch.bernoulli(self.p.expand(x.shape))

    def forward(self, x, resample=False, mask_dims=0, **kwargs):
        """Computes the binary dropout.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.
            mask_dims (int): Number of dimensions to sample noise for
                (0 for all).

        Returns:
            Output (Tensor).
        """
        sample_shape = x.shape[-mask_dims:]
        if sample_shape != self.noise.shape:
            sample = x.view(-1, *sample_shape)[0]
            self._update_noise(sample)
        elif resample:
            return x * torch.bernoulli(self.p.expand(x.shape))

        return x * self.noise

    def extra_repr(self):
        """Formats module representation.

        Returns:
            Module representation (str).
        """
        return "rate={}".format(self.rate)

# %%
class CDropout(BDropout):

    """Concrete dropout with regularization and resampling.

    See: Gal Y., Hron, J., Kendall, A. "Concrete Dropout", 2017.
    """

    # def __init__(self, temperature=0.1, rate=0.5, reg=1.0, **kwargs):
    #     """Constructs a CDropout.

    #     Args:
    #         temperature (float): Temperature.
    #         rate (float): Initial dropout rate.
    #         reg (float): Regularization scale.
    #     """
    #     super(CDropout, self).__init__(rate, reg, **kwargs)
    #     self.temperature = Parameter(
    #         torch.tensor(temperature), requires_grad=False)

    #     # We need to constrain p to [0, 1], so we train logit(p).
    #     self.logit_p = Parameter(-torch.log(self.p.reciprocal() - 1.0))

    def __init__(self, temperature=0.1, rate=0.5, reg=1.0, **kwargs):
        """Constructs a CDropout.

        Args:
            temperature (float): Temperature.
            rate (float): Initial dropout rate.
            reg (float): Regularization scale.
        """
        super(CDropout, self).__init__(rate, reg, **kwargs)
        self.temperature = torch.nn.Parameter(
            torch.tensor(temperature), requires_grad=False)

        # We need to constrain p to [0, 1], so we train logit(p).
        self.logit_p = torch.nn.Parameter(-torch.log(self.p.reciprocal() - 1.0))

    def regularization(self, weight, bias):
        """Computes the regularization cost.

        Args:
            weight (Tensor): Weight tensor.
            bias (Tensor): Bias tensor.

        Returns:
            Regularization cost (Tensor).
        """
        self.p.data = self.logit_p.sigmoid()
        reg = super(CDropout, self).regularization(weight, bias)
        reg -= -(1 - self.p) * (1 - self.p).log() - self.p * self.p.log()
        return reg

    def _update_noise(self, x):
        """Updates the dropout noise.

        Args:
            x (Tensor): Input.
        """
        self.noise.data = torch.rand_like(x)

    def forward(self, x, resample=False, mask_dims=0, **kwargs):
        """Computes the concrete dropout.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.
            mask_dims (int): Number of dimensions to sample noise for
                (0 for all).

        Returns:
            Output (Tensor).
        """
        sample_shape = x.shape[-mask_dims:]
        noise = self.noise
        if sample_shape != noise.shape:
            sample = x.view(-1, *sample_shape)[0]
            self._update_noise(sample)
            noise = self.noise
        elif resample:
            noise = torch.rand_like(x)

        self.p.data = self.logit_p.sigmoid()
        concrete_p = self.logit_p + noise.log() - (1 - noise).log()
        concrete_noise = (concrete_p / self.temperature).sigmoid()

        return x * concrete_noise

    def extra_repr(self):
        """Formats module representation.

        Returns:
            Module representation (str).
        """
        return "temperature={}".format(self.temperature)

# %%
class BSequential(torch.nn.Sequential):

    """Extension of Sequential module with regularization and resampling."""

    def resample(self):
        """Resample all child modules."""
        for child in self.children():
            if isinstance(child, BDropout):
                child.resample()

    def regularization(self):
        """Computes the total regularization cost of all child modules.

        Returns:
            Total regularization cost (Tensor).
        """
        reg = torch.tensor(0.0)
        children = list(self._modules.values())
        for i, child in enumerate(children):
            if isinstance(child, BSequential):
                reg += child.regularization()
            elif isinstance(child, BDropout):
                for next_child in children[i:]:
                    if hasattr(next_child, "weight") and hasattr(
                            next_child, "bias"):
                        reg += child.regularization(next_child.weight,
                                                    next_child.bias)
                        break
        return reg

    def forward(self, x, resample=False, **kwargs):
        """Computes the model.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.

        Returns:
            Output (Tensor).
        """
        for module in self._modules.values():
            if isinstance(module, (BDropout, BSequential)):
                x = module(x, resample=resample, **kwargs)
            else:
                x = module(x)
        return x

# %%
def bayesian_model(in_features,
                   out_features,
                   hidden_features,
                   nonlin=nn.ReLU,
                   output_nonlin=None,
                   weight_initializer=partial(
                       nn.init.xavier_normal_,
                       gain=nn.init.calculate_gain("relu")),
                   bias_initializer=partial(
                       nn.init.uniform_, a=-1.0, b=1.0),
                   dropout_layers=CDropout,
                   input_dropout=None):
    """Constructs and initializes a Bayesian neural network with dropout."""
    dims = [in_features] + hidden_features
    if not isinstance(dropout_layers, Iterable):
        dropout_layers = [dropout_layers] * len(hidden_features)

    modules = OrderedDict()

    if inspect.isclass(input_dropout):
        input_dropout = input_dropout()
    if input_dropout is not None:
        modules["drop_in"] = input_dropout

    for i, (din, dout) in enumerate(zip(dims[:-1], dims[1:])):
        drop_i = dropout_layers[i]
        if inspect.isclass(drop_i):
            drop_i = drop_i()

        modules["fc_{}".format(i)] = nn.Linear(din, dout)
        if drop_i is not None:
            modules["drop_{}".format(i)] = drop_i
        modules["nonlin_{}".format(i)] = nonlin()

    modules["fc_out"] = nn.Linear(dims[-1], out_features)
    if output_nonlin is not None:
        modules["nonlin_out"] = output_nonlin()

    def init(module):
        if callable(weight_initializer) and hasattr(module, "weight"):
            weight_initializer(module.weight)
        if callable(bias_initializer) and hasattr(module, "bias"):
            if module.bias is not None:
                bias_initializer(module.bias)

    net = BSequential(modules)
    net.apply(init)

    return net

# %%
# Convert NumPy arrays to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# Early stopping implementation
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_val_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_val_loss is None:
            self.best_val_loss = val_loss
        elif val_loss < self.best_val_loss - self.min_delta:
            self.best_val_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# Define parameter bounds
def parameter_bounds():
    # Number of layers: 1 to 5
    num_layers_bounds = (1, 5)

    # Number of neurons per layer: 10 to 200
    num_neurons_bounds = (10, 200)

    # Dropout rate: 0 to 0.5
    dropout_rate_bounds = (0.0, 0.5)

    # Learning rate: 0.0001 to 0.01
    learning_rate_bounds = (0.0001, 0.01)

    # Number of epochs: 50 to 500
    num_epochs_bounds = (150, 500)

    return num_layers_bounds, num_neurons_bounds, dropout_rate_bounds, learning_rate_bounds, num_epochs_bounds

# %%
def objective_function(params):
    # Unpack parameters from PSO
    num_layers, num_neurons, dropout_rate, learning_rate, num_epochs = params

    # Define the model with the given parameters
    model = bayesian_model(
        in_features=X_train.shape[1],
        out_features=1,
        hidden_features=[int(num_neurons)] * int(num_layers),
        nonlin=nn.ReLU,
        output_nonlin=None,
        dropout_layers=CDropout,
        input_dropout=CDropout(temperature=0.1, rate=dropout_rate, reg=1.0)
    )

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Initialize early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=0.01)

    # Track the best validation loss
    best_val_loss = float('inf')

    # Training loop with the number of epochs specified in the params
    for epoch in range(int(num_epochs)):
        model.train()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Validation phase (after each epoch)
        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val)
            val_loss = criterion(val_outputs, y_val)

        # Check and update the best validation loss
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()

        # Early stopping condition
        early_stopping(val_loss.item())
        if early_stopping.early_stop:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    # Return the best validation loss for PSO optimization
    return best_val_loss

# %%
# Define the bounds for each parameter
def get_bounds():
    num_layers_bounds, num_neurons_bounds, dropout_rate_bounds, learning_rate_bounds, num_epochs_bounds = parameter_bounds()
    return [
        [num_layers_bounds[0], num_neurons_bounds[0], dropout_rate_bounds[0], learning_rate_bounds[0], num_epochs_bounds[0]],
        [num_layers_bounds[1], num_neurons_bounds[1], dropout_rate_bounds[1], learning_rate_bounds[1], num_epochs_bounds[1]]
    ]

# %%
bounds = get_bounds()

# %%
lower_bounds = bounds[0]
upper_bounds = bounds[1]

swarmsize = 20
maxiter = 50

# %%
start_time = time.time()

best_params, best_val = pso(objective_function, lb=lower_bounds, ub=upper_bounds, swarmsize=swarmsize, maxiter=maxiter, debug=True)

end_time = time.time()
execution_time = end_time - start_time
# Out:
# No constraints given.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([5055])) that is different to the input size (torch.Size([5055, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([562])) that is different to the input size (torch.Size([562, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 72
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 70
# Early stopping triggered at epoch 81
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 70
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 18
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 28
# New best for swarm at iteration 1: [4.34315292e+00 8.59816613e+01 3.22124866e-01 7.99469469e-03
#  2.10749952e+02] 0.0023719703312963247
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 16
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 71
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 104
# Early stopping triggered at epoch 73
# Best after iteration 1: [4.34315292e+00 8.59816613e+01 3.22124866e-01 7.99469469e-03
#  2.10749952e+02] 0.0023719703312963247
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 70
# Early stopping triggered at epoch 101
# Early stopping triggered at epoch 72
# Early stopping triggered at epoch 86
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 14
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 25
# Best after iteration 2: [4.34315292e+00 8.59816613e+01 3.22124866e-01 7.99469469e-03
#  2.10749952e+02] 0.0023719703312963247
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 78
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 30
# New best for swarm at iteration 3: [4.44471879e+00 6.54271667e+01 1.80716188e-01 9.70390921e-03
#  2.18618788e+02] 0.0010789275402203202
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 49
# Best after iteration 3: [4.44471879e+00 6.54271667e+01 1.80716188e-01 9.70390921e-03
#  2.18618788e+02] 0.0010789275402203202
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 74
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 33
# Best after iteration 4: [4.44471879e+00 6.54271667e+01 1.80716188e-01 9.70390921e-03
#  2.18618788e+02] 0.0010789275402203202
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 18
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 29
# Best after iteration 5: [4.44471879e+00 6.54271667e+01 1.80716188e-01 9.70390921e-03
#  2.18618788e+02] 0.0010789275402203202
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 33
# Best after iteration 6: [4.44471879e+00 6.54271667e+01 1.80716188e-01 9.70390921e-03
#  2.18618788e+02] 0.0010789275402203202
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 51
# Best after iteration 7: [4.44471879e+00 6.54271667e+01 1.80716188e-01 9.70390921e-03
#  2.18618788e+02] 0.0010789275402203202
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 35
# Best after iteration 8: [4.44471879e+00 6.54271667e+01 1.80716188e-01 9.70390921e-03
#  2.18618788e+02] 0.0010789275402203202
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 18
# Early stopping triggered at epoch 29
# New best for swarm at iteration 9: [4.59395145e+00 4.22964878e+01 1.87440818e-01 9.60508262e-03
#  2.14785322e+02] 0.0006178872426971793
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 29
# Best after iteration 9: [4.59395145e+00 4.22964878e+01 1.87440818e-01 9.60508262e-03
#  2.14785322e+02] 0.0006178872426971793
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 30
# Best after iteration 10: [4.59395145e+00 4.22964878e+01 1.87440818e-01 9.60508262e-03
#  2.14785322e+02] 0.0006178872426971793
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 21
# New best for swarm at iteration 11: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 32
# Best after iteration 11: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 26
# Best after iteration 12: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 42
# Best after iteration 13: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Best after iteration 14: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 44
# Best after iteration 15: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 48
# Best after iteration 16: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 23
# Best after iteration 17: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Best after iteration 18: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 35
# Best after iteration 19: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 27
# Best after iteration 20: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Best after iteration 21: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 25
# Best after iteration 22: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 24
# Best after iteration 23: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 34
# Best after iteration 24: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 36
# Best after iteration 25: [4.20484033e+00 5.50596525e+01 1.85309815e-01 9.64816881e-03
#  3.04813997e+02] 0.0003313305787742138
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 24
# New best for swarm at iteration 26: [4.07048093e+00 5.85203428e+01 2.17400765e-01 8.31782698e-03
#  2.88778046e+02] 0.00019361569138709456
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 30
# Best after iteration 26: [4.07048093e+00 5.85203428e+01 2.17400765e-01 8.31782698e-03
#  2.88778046e+02] 0.00019361569138709456
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 29
# Best after iteration 27: [4.07048093e+00 5.85203428e+01 2.17400765e-01 8.31782698e-03
#  2.88778046e+02] 0.00019361569138709456
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 23
# New best for swarm at iteration 28: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Best after iteration 28: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Best after iteration 29: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 30
# Best after iteration 30: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 33
# Best after iteration 31: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 41
# Best after iteration 32: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 45
# Best after iteration 33: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 27
# Best after iteration 34: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 35
# Best after iteration 35: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 19
# Early stopping triggered at epoch 42
# Best after iteration 36: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Best after iteration 37: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 60
# Best after iteration 38: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 18
# Best after iteration 39: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 30
# Best after iteration 40: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 32
# Best after iteration 41: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 50
# Best after iteration 42: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 30
# Best after iteration 43: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 43
# Best after iteration 44: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 19
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Best after iteration 45: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 31
# Best after iteration 46: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 33
# Best after iteration 47: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 43
# Best after iteration 48: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 29
# Best after iteration 49: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 67
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 48
# Best after iteration 50: [4.18954743e+00 6.46260887e+01 1.82411026e-01 9.21563638e-03
#  2.41302045e+02] 0.000152056323713623
# Stopping search: maximum iterations reached --> 50

# %%
execution_time
# Out:
# 8610.192958831787

# %%
best_params
# Out:
# array([4.18954743e+00, 6.46260887e+01, 1.82411026e-01, 9.21563638e-03,
#        2.41302045e+02])

# %%
# Function to train and evaluate the model with given hyperparameters
def train_and_evaluate_model(params):
    n_layers, n_neurons, drop_rate, learning_rate, epochs = params

    # Define the model
    hidden_features = [int(n_neurons)] * int(n_layers)
    model = bayesian_model(
        in_features=X_train.shape[1],
        out_features=1,
        hidden_features=hidden_features,
        dropout_layers=CDropout(rate=drop_rate),  # Dropout layer without partial
    )

    # Define optimizer and loss function
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()

    # Early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

    # Training loop
    for epoch in range(int(epochs)):
        model.train()
        optimizer.zero_grad()

        output = model(X_train)
        loss = criterion(output, y_train)

        loss.backward()
        optimizer.step()

        model.eval()
        val_output = model(X_val)
        val_loss = criterion(val_output, y_val)

        print(f'Epoch {epoch+1}/{int(epochs)}, Loss: {loss.item()}, Val Loss: {val_loss.item()}')

        early_stopping(val_loss.item())
        if early_stopping.early_stop:
            print("Early stopping triggered")
            break

    # Test the model
    model.eval()
    test_output = model(X_test)
    mse = criterion(test_output, y_test)
    rmse = mse ** 0.5
    mae = nn.L1Loss()(y_test, test_output).item()
    mape = torch.mean(torch.abs((y_test - test_output) / y_test)) * 100

    print(f'Test Loss: {mse.item()}')
    print(f'RMSE: {rmse}')
    print(f'MAE: {mae}')
    print(f'MAPE: {mape.item()}%')

    return mse, rmse, mae, mape, test_output

# %%
# best_params = [3.62253629e+00, 1.12321717e+02, 2.77934900e-01, 5.49072091e-03, 2.22486413e+02]

# %%
mse, rmse, mae, mape, test_output = train_and_evaluate_model(best_params)
# Out:
# Epoch 1/241, Loss: 0.5245577096939087, Val Loss: 3.139601707458496
# Epoch 2/241, Loss: 3.1497528553009033, Val Loss: 0.70555180311203
# Epoch 3/241, Loss: 0.7114653587341309, Val Loss: 0.214154452085495
# Epoch 4/241, Loss: 0.22463840246200562, Val Loss: 0.5323261618614197
# Epoch 5/241, Loss: 0.5092867016792297, Val Loss: 0.5312192440032959
# Epoch 6/241, Loss: 0.5410228371620178, Val Loss: 0.3593182861804962
# Epoch 7/241, Loss: 0.36637088656425476, Val Loss: 0.17666761577129364
# Epoch 8/241, Loss: 0.17985667288303375, Val Loss: 0.10737629979848862
# Epoch 9/241, Loss: 0.11048422008752823, Val Loss: 0.11227286607027054
# Epoch 10/241, Loss: 0.12632796168327332, Val Loss: 0.14678208529949188
# Epoch 11/241, Loss: 0.14643464982509613, Val Loss: 0.1547827273607254
# Epoch 12/241, Loss: 0.15021248161792755, Val Loss: 0.11414080113172531
# Epoch 13/241, Loss: 0.11850760132074356, Val Loss: 0.08336006850004196
# Epoch 14/241, Loss: 0.08843683451414108, Val Loss: 0.06427380442619324
# Epoch 15/241, Loss: 0.05929061397910118, Val Loss: 0.04785904660820961
# Epoch 16/241, Loss: 0.048891328275203705, Val Loss: 0.06319393962621689
# Epoch 17/241, Loss: 0.05641883239150047, Val Loss: 0.05809636786580086
# Epoch 18/241, Loss: 0.06221693009138107, Val Loss: 0.06110803410410881
# Epoch 19/241, Loss: 0.06438011676073074, Val Loss: 0.05722873657941818
# Epoch 20/241, Loss: 0.05455111339688301, Val Loss: 0.04139631241559982
# Epoch 21/241, Loss: 0.044100359082221985, Val Loss: 0.03455837815999985
# Epoch 22/241, Loss: 0.03470480442047119, Val Loss: 0.027698354795575142
# Epoch 23/241, Loss: 0.028560280799865723, Val Loss: 0.025172332301735878
# Epoch 24/241, Loss: 0.02726590260863304, Val Loss: 0.02963843010365963
# Epoch 25/241, Loss: 0.029075611382722855, Val Loss: 0.029239211231470108
# Epoch 26/241, Loss: 0.02938762493431568, Val Loss: 0.0334932841360569
# Epoch 27/241, Loss: 0.028812695294618607, Val Loss: 0.028096148744225502
# Epoch 28/241, Loss: 0.027829675003886223, Val Loss: 0.02411573939025402
# Epoch 29/241, Loss: 0.024192076176404953, Val Loss: 0.023828908801078796
# Epoch 30/241, Loss: 0.021707789972424507, Val Loss: 0.021695595234632492
# Epoch 31/241, Loss: 0.019289806485176086, Val Loss: 0.016072463244199753
# Epoch 32/241, Loss: 0.019240323454141617, Val Loss: 0.018293002620339394
# Epoch 33/241, Loss: 0.01798863336443901, Val Loss: 0.01613888144493103
# Epoch 34/241, Loss: 0.017624597996473312, Val Loss: 0.016442129388451576
# Epoch 35/241, Loss: 0.016958467662334442, Val Loss: 0.017591003328561783
# Epoch 36/241, Loss: 0.016364790499210358, Val Loss: 0.01602044329047203
# Epoch 37/241, Loss: 0.01581403985619545, Val Loss: 0.012823017314076424
# Epoch 38/241, Loss: 0.014914055354893208, Val Loss: 0.0141802579164505
# Epoch 39/241, Loss: 0.013509822078049183, Val Loss: 0.01306258887052536
# Epoch 40/241, Loss: 0.013800634071230888, Val Loss: 0.010906887240707874
# Epoch 41/241, Loss: 0.012866918928921223, Val Loss: 0.014412065036594868
# Epoch 42/241, Loss: 0.012943941168487072, Val Loss: 0.014184262603521347
# Epoch 43/241, Loss: 0.01251606922596693, Val Loss: 0.011709400452673435
# Epoch 44/241, Loss: 0.012485602870583534, Val Loss: 0.013392222113907337
# Epoch 45/241, Loss: 0.011589785106480122, Val Loss: 0.011957843787968159
# Epoch 46/241, Loss: 0.011117804795503616, Val Loss: 0.010979765094816685
# Epoch 47/241, Loss: 0.010769117623567581, Val Loss: 0.010898762382566929
# Epoch 48/241, Loss: 0.011135373264551163, Val Loss: 0.009568250738084316
# Epoch 49/241, Loss: 0.010546265169978142, Val Loss: 0.009303325787186623
# Epoch 50/241, Loss: 0.010366514325141907, Val Loss: 0.012672847136855125
# Epoch 51/241, Loss: 0.009919409640133381, Val Loss: 0.009665929712355137
# Epoch 52/241, Loss: 0.010238872841000557, Val Loss: 0.009260719642043114
# Epoch 53/241, Loss: 0.009023232385516167, Val Loss: 0.009865411557257175
# Epoch 54/241, Loss: 0.009136412292718887, Val Loss: 0.00945326779037714
# Epoch 55/241, Loss: 0.009032086469233036, Val Loss: 0.009848304092884064
# Epoch 56/241, Loss: 0.008712138049304485, Val Loss: 0.008916480466723442
# Epoch 57/241, Loss: 0.0086002042517066, Val Loss: 0.008711380884051323
# Epoch 58/241, Loss: 0.008455506525933743, Val Loss: 0.008940554223954678
# Epoch 59/241, Loss: 0.007851109839975834, Val Loss: 0.0091666579246521
# Epoch 60/241, Loss: 0.008239900693297386, Val Loss: 0.0075134532526135445
# Epoch 61/241, Loss: 0.007770846597850323, Val Loss: 0.008670849725604057
# Epoch 62/241, Loss: 0.008213996887207031, Val Loss: 0.007851182483136654
# Epoch 63/241, Loss: 0.007360614370554686, Val Loss: 0.007368617691099644
# Epoch 64/241, Loss: 0.007234909571707249, Val Loss: 0.007787246722728014
# Epoch 65/241, Loss: 0.006995274219661951, Val Loss: 0.0067557417787611485
# Epoch 66/241, Loss: 0.007126528304070234, Val Loss: 0.006942171137779951
# Epoch 67/241, Loss: 0.006810969673097134, Val Loss: 0.006751467008143663
# Epoch 68/241, Loss: 0.00673107523471117, Val Loss: 0.006111083552241325
# Epoch 69/241, Loss: 0.006592014338821173, Val Loss: 0.0063233631663024426
# Epoch 70/241, Loss: 0.006492707412689924, Val Loss: 0.005738913081586361
# Epoch 71/241, Loss: 0.006388484500348568, Val Loss: 0.0056704082526266575
# Epoch 72/241, Loss: 0.006341428495943546, Val Loss: 0.005642448086291552
# Epoch 73/241, Loss: 0.005838961340487003, Val Loss: 0.0053117163479328156
# Epoch 74/241, Loss: 0.005665617994964123, Val Loss: 0.006140946876257658
# Epoch 75/241, Loss: 0.00536483945325017, Val Loss: 0.0050858501344919205
# Epoch 76/241, Loss: 0.005039219278842211, Val Loss: 0.005641900934278965
# Epoch 77/241, Loss: 0.005103619769215584, Val Loss: 0.004504476673901081
# Epoch 78/241, Loss: 0.004921091720461845, Val Loss: 0.0048157148994505405
# Epoch 79/241, Loss: 0.004702811595052481, Val Loss: 0.004228122998028994
# Epoch 80/241, Loss: 0.004430561792105436, Val Loss: 0.0044181207194924355
# Epoch 81/241, Loss: 0.004289067815989256, Val Loss: 0.004058779217302799
# Epoch 82/241, Loss: 0.004182794596999884, Val Loss: 0.004328221082687378
# Epoch 83/241, Loss: 0.003993459511548281, Val Loss: 0.003963558003306389
# Epoch 84/241, Loss: 0.0037958628963679075, Val Loss: 0.004044120665639639
# Epoch 85/241, Loss: 0.0036937003023922443, Val Loss: 0.0033135516569018364
# Epoch 86/241, Loss: 0.0034972995053976774, Val Loss: 0.003019964322447777
# Epoch 87/241, Loss: 0.0035565667785704136, Val Loss: 0.0032318509183824062
# Epoch 88/241, Loss: 0.003552064998075366, Val Loss: 0.0038557343650609255
# Epoch 89/241, Loss: 0.0033987199421972036, Val Loss: 0.003519351128488779
# Epoch 90/241, Loss: 0.003274847287684679, Val Loss: 0.002975909737870097
# Epoch 91/241, Loss: 0.0031445990316569805, Val Loss: 0.003795583499595523
# Epoch 92/241, Loss: 0.0031010848470032215, Val Loss: 0.0032854292076081038
# Epoch 93/241, Loss: 0.0029813118744641542, Val Loss: 0.0031456726137548685
# Epoch 94/241, Loss: 0.0028787762857973576, Val Loss: 0.0027989561203867197
# Epoch 95/241, Loss: 0.002894377103075385, Val Loss: 0.0031489511020481586
# Epoch 96/241, Loss: 0.002852126257494092, Val Loss: 0.002735900692641735
# Epoch 97/241, Loss: 0.002770093735307455, Val Loss: 0.0025438254233449697
# Epoch 98/241, Loss: 0.0027252566069364548, Val Loss: 0.0029018516652286053
# Epoch 99/241, Loss: 0.002844620496034622, Val Loss: 0.002510500606149435
# Epoch 100/241, Loss: 0.002780655864626169, Val Loss: 0.0024561742320656776
# Epoch 101/241, Loss: 0.002657568547874689, Val Loss: 0.0022737905383110046
# Epoch 102/241, Loss: 0.0026114436332136393, Val Loss: 0.0023806176614016294
# Epoch 103/241, Loss: 0.0025953655131161213, Val Loss: 0.0026277448050677776
# Epoch 104/241, Loss: 0.00249928398989141, Val Loss: 0.002295990474522114
# Epoch 105/241, Loss: 0.002550761681050062, Val Loss: 0.0023162460420280695
# Epoch 106/241, Loss: 0.002519455272704363, Val Loss: 0.0022627131547778845
# Epoch 107/241, Loss: 0.0024479986168444157, Val Loss: 0.002731915097683668
# Epoch 108/241, Loss: 0.0023249622900038958, Val Loss: 0.002520099049434066
# Epoch 109/241, Loss: 0.00250250194221735, Val Loss: 0.0026336086448282003
# Epoch 110/241, Loss: 0.0024531700182706118, Val Loss: 0.0020131119526922703
# Epoch 111/241, Loss: 0.00241699256002903, Val Loss: 0.0024818843230605125
# Epoch 112/241, Loss: 0.002420487580820918, Val Loss: 0.002007195493206382
# Epoch 113/241, Loss: 0.002391775604337454, Val Loss: 0.002516065491363406
# Epoch 114/241, Loss: 0.0023041137028485537, Val Loss: 0.0021024509333074093
# Epoch 115/241, Loss: 0.002136925468221307, Val Loss: 0.0025064533110708
# Epoch 116/241, Loss: 0.0021642674691975117, Val Loss: 0.0020834840834140778
# Epoch 117/241, Loss: 0.0021984681952744722, Val Loss: 0.002378840697929263
# Epoch 118/241, Loss: 0.0021159141324460506, Val Loss: 0.0023905783891677856
# Epoch 119/241, Loss: 0.0021247363183647394, Val Loss: 0.0021754992194473743
# Epoch 120/241, Loss: 0.002048227470368147, Val Loss: 0.0021339755039662123
# Early stopping triggered
# Test Loss: 0.0024816952645778656
# RMSE: 0.049816615879535675
# MAE: 0.037404220551252365
# MAPE: 1259986.5%

# %%
print(f'Final Test Metrics -> MSE: {mse}, RMSE: {rmse}, MAE: {mae}, MAPE: {mape.item()}%')
# Out:
# Final Test Metrics -> MSE: 0.0024816952645778656, RMSE: 0.049816615879535675, MAE: 0.037404220551252365, MAPE: 1259986.5%

# %%
# path_1 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/CCV/'

# df_pred = pd.DataFrame(test_output.detach().numpy().flatten(), columns=['bnn_pred'])
# filename = 'BNN_pred.csv'
# df_pred.to_csv(path_1 + filename)
