# %%
# !pip install pyswarm
# Out:
# Requirement already satisfied: pyswarm in /usr/local/lib/python3.10/dist-packages (0.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyswarm) (1.26.4)

# %%
# from collections import Iterable, OrderedDict
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from collections.abc import Iterable
from collections import OrderedDict
from google.colab import drive
from torch.nn import Parameter
from datetime import datetime
from functools import partial
import torch.optim as optim
from pyswarm import pso
import torch.nn as nn
from math import sqrt
import pandas as pd
import numpy as np
import inspect
import torch
import time

# %% [markdown]
# # Load data

# %%
drive.mount('/content/drive')
path = '/content/drive/MyDrive/Volatility/New_data_2000_2024/Not_normal_wc_real/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def set_index(df):
  df.index = pd.to_datetime(df['Date'])
  df.drop(columns=['Date'], inplace=True)

# %%
filename = 'PV_data.csv'
PV_data = pd.read_csv(path + filename)

# %%
PV_data
# Out:
#             Date        PV  log_returns  ('GARCH', 'normal', 0)  \
# 0     2000-02-02 -0.001538     0.000077               -0.001864
# 1     2000-02-03 -0.001355     0.000020               -0.001554
# 2     2000-02-04 -0.000997     0.000152               -0.001080
# 3     2000-02-07 -0.000650     0.000090               -0.000627
# 4     2000-02-08 -0.000319    -0.000335               -0.000202
# ...          ...       ...          ...                     ...
# 6179  2024-08-26  0.000248    -0.000161               -0.000358
# 6180  2024-08-27  0.000029    -0.000193               -0.000694
# 6181  2024-08-28 -0.000205    -0.000154               -0.000954
# 6182  2024-08-29 -0.000456    -0.000150               -0.001147
# 6183  2024-08-30 -0.000703    -0.000129               -0.001232
#
#       ('GARCH', 'normal', 1)  ('GARCH', 'gaussian', 0)  \
# 0                  -0.001725                 -0.001864
# 1                  -0.001557                 -0.001554
# 2                  -0.001163                 -0.001080
# 3                  -0.000738                 -0.000627
# 4                  -0.000335                 -0.000202
# ...                      ...                       ...
# 6179               -0.000493                 -0.000358
# 6180               -0.000707                 -0.000694
# 6181               -0.000846                 -0.000954
# 6182               -0.000937                 -0.001147
# 6183               -0.000923                 -0.001232
#
#       ('GARCH', 'gaussian', 1)  ('GARCH', 'ged', 0)  ('GARCH', 'ged', 1)  \
# 0                    -0.001725            -0.001971            -0.001822
# 1                    -0.001557            -0.001745            -0.001612
# 2                    -0.001163            -0.001302            -0.001217
# 3                    -0.000738            -0.000863            -0.000784
# 4                    -0.000335            -0.000364            -0.000368
# ...                        ...                  ...                  ...
# 6179                 -0.000493            -0.001023            -0.000502
# 6180                 -0.000707            -0.001244            -0.000717
# 6181                 -0.000846            -0.001311            -0.000852
# 6182                 -0.000937            -0.001324            -0.000933
# 6183                 -0.000923            -0.001267            -0.000919
#
#       ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# 0                    -0.001782                 -0.001782
# 1                    -0.001519                 -0.001519
# 2                    -0.001076                 -0.001076
# 3                    -0.000678                 -0.000678
# 4                    -0.000311                 -0.000311
# ...                        ...                       ...
# 6179                 -0.000690                 -0.000690
# 6180                 -0.000899                 -0.000899
# 6181                 -0.001012                 -0.001012
# 6182                 -0.001067                 -0.001067
# 6183                 -0.001030                 -0.001030
#
#       ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)          vix  \
# 0                      -0.001782                   -0.001782 -5074.430765
# 1                      -0.001519                   -0.001519 -4871.204473
# 2                      -0.001076                   -0.001076 -3989.985998
# 3                      -0.000678                   -0.000678 -2979.521889
# 4                      -0.000311                   -0.000311 -1886.674367
# ...                          ...                         ...          ...
# 6179                   -0.000690                   -0.000690  -118.886061
# 6180                   -0.000899                   -0.000899  -381.296847
# 6181                   -0.001012                   -0.001012  -746.562442
# 6182                   -0.001067                   -0.001067 -1297.880813
# 6183                   -0.001030                   -0.001030 -1945.559572
#
#       unemployment_rate    usd_gbp     usd_cny      usd_mxn       gt_data
# 0           -164.888872 -25.204908 -667.139276  -870.717996 -53308.067923
# 1           -152.205474 -23.159152 -618.146493  -799.604126 -49391.829352
# 2           -116.610418 -17.659121 -475.895763  -610.423502 -38026.991031
# 3            -78.602644 -11.749618 -322.833213  -410.827912 -25799.214705
# 4            -43.682933  -6.356898 -182.858321  -230.130383 -14616.177002
# ...                 ...        ...         ...          ...           ...
# 6179          65.925473   7.151391  185.257251  1524.776491     16.790559
# 6180          28.527492   3.476358   76.788614   774.080957  -3946.268810
# 6181         -16.834312  -1.072689  -53.866326  -172.154813  -8749.025243
# 6182         -70.858623  -6.550484 -208.826493 -1344.291544 -14935.055801
# 6183        -129.617764 -12.520266 -376.419611 -2657.323913 -22127.779545
#
# [6184 rows x 19 columns]

# %%
PV_data.drop(columns=['vix', 'unemployment_rate', 'usd_gbp', 'usd_cny', 'usd_mxn', 'gt_data'], inplace=True)

# %%
PV_data
# Out:
#             Date        PV  log_returns  ('GARCH', 'normal', 0)  \
# 0     2000-02-02 -0.001538     0.000077               -0.001864
# 1     2000-02-03 -0.001355     0.000020               -0.001554
# 2     2000-02-04 -0.000997     0.000152               -0.001080
# 3     2000-02-07 -0.000650     0.000090               -0.000627
# 4     2000-02-08 -0.000319    -0.000335               -0.000202
# ...          ...       ...          ...                     ...
# 6179  2024-08-26  0.000248    -0.000161               -0.000358
# 6180  2024-08-27  0.000029    -0.000193               -0.000694
# 6181  2024-08-28 -0.000205    -0.000154               -0.000954
# 6182  2024-08-29 -0.000456    -0.000150               -0.001147
# 6183  2024-08-30 -0.000703    -0.000129               -0.001232
#
#       ('GARCH', 'normal', 1)  ('GARCH', 'gaussian', 0)  \
# 0                  -0.001725                 -0.001864
# 1                  -0.001557                 -0.001554
# 2                  -0.001163                 -0.001080
# 3                  -0.000738                 -0.000627
# 4                  -0.000335                 -0.000202
# ...                      ...                       ...
# 6179               -0.000493                 -0.000358
# 6180               -0.000707                 -0.000694
# 6181               -0.000846                 -0.000954
# 6182               -0.000937                 -0.001147
# 6183               -0.000923                 -0.001232
#
#       ('GARCH', 'gaussian', 1)  ('GARCH', 'ged', 0)  ('GARCH', 'ged', 1)  \
# 0                    -0.001725            -0.001971            -0.001822
# 1                    -0.001557            -0.001745            -0.001612
# 2                    -0.001163            -0.001302            -0.001217
# 3                    -0.000738            -0.000863            -0.000784
# 4                    -0.000335            -0.000364            -0.000368
# ...                        ...                  ...                  ...
# 6179                 -0.000493            -0.001023            -0.000502
# 6180                 -0.000707            -0.001244            -0.000717
# 6181                 -0.000846            -0.001311            -0.000852
# 6182                 -0.000937            -0.001324            -0.000933
# 6183                 -0.000923            -0.001267            -0.000919
#
#       ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# 0                    -0.001782                 -0.001782
# 1                    -0.001519                 -0.001519
# 2                    -0.001076                 -0.001076
# 3                    -0.000678                 -0.000678
# 4                    -0.000311                 -0.000311
# ...                        ...                       ...
# 6179                 -0.000690                 -0.000690
# 6180                 -0.000899                 -0.000899
# 6181                 -0.001012                 -0.001012
# 6182                 -0.001067                 -0.001067
# 6183                 -0.001030                 -0.001030
#
#       ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)
# 0                      -0.001782                   -0.001782
# 1                      -0.001519                   -0.001519
# 2                      -0.001076                   -0.001076
# 3                      -0.000678                   -0.000678
# 4                      -0.000311                   -0.000311
# ...                          ...                         ...
# 6179                   -0.000690                   -0.000690
# 6180                   -0.000899                   -0.000899
# 6181                   -0.001012                   -0.001012
# 6182                   -0.001067                   -0.001067
# 6183                   -0.001030                   -0.001030
#
# [6184 rows x 13 columns]

# %%
set_index(PV_data)

# %%
tm_data = PV_data

# %%
PV_data = PV_data.drop(columns=['PV'])

# %%
PV_data['PV'] = tm_data['PV']

# %%
PV_data
# Out:
#             log_returns  ('GARCH', 'normal', 0)  ('GARCH', 'normal', 1)  \
# Date
# 2000-02-02     0.000077               -0.001864               -0.001725
# 2000-02-03     0.000020               -0.001554               -0.001557
# 2000-02-04     0.000152               -0.001080               -0.001163
# 2000-02-07     0.000090               -0.000627               -0.000738
# 2000-02-08    -0.000335               -0.000202               -0.000335
# ...                 ...                     ...                     ...
# 2024-08-26    -0.000161               -0.000358               -0.000493
# 2024-08-27    -0.000193               -0.000694               -0.000707
# 2024-08-28    -0.000154               -0.000954               -0.000846
# 2024-08-29    -0.000150               -0.001147               -0.000937
# 2024-08-30    -0.000129               -0.001232               -0.000923
#
#             ('GARCH', 'gaussian', 0)  ('GARCH', 'gaussian', 1)  \
# Date
# 2000-02-02                 -0.001864                 -0.001725
# 2000-02-03                 -0.001554                 -0.001557
# 2000-02-04                 -0.001080                 -0.001163
# 2000-02-07                 -0.000627                 -0.000738
# 2000-02-08                 -0.000202                 -0.000335
# ...                              ...                       ...
# 2024-08-26                 -0.000358                 -0.000493
# 2024-08-27                 -0.000694                 -0.000707
# 2024-08-28                 -0.000954                 -0.000846
# 2024-08-29                 -0.001147                 -0.000937
# 2024-08-30                 -0.001232                 -0.000923
#
#             ('GARCH', 'ged', 0)  ('GARCH', 'ged', 1)  \
# Date
# 2000-02-02            -0.001971            -0.001822
# 2000-02-03            -0.001745            -0.001612
# 2000-02-04            -0.001302            -0.001217
# 2000-02-07            -0.000863            -0.000784
# 2000-02-08            -0.000364            -0.000368
# ...                         ...                  ...
# 2024-08-26            -0.001023            -0.000502
# 2024-08-27            -0.001244            -0.000717
# 2024-08-28            -0.001311            -0.000852
# 2024-08-29            -0.001324            -0.000933
# 2024-08-30            -0.001267            -0.000919
#
#             ('FIGARCH', 'normal', 0)  ('FIGARCH', 'normal', 1)  \
# Date
# 2000-02-02                 -0.001782                 -0.001782
# 2000-02-03                 -0.001519                 -0.001519
# 2000-02-04                 -0.001076                 -0.001076
# 2000-02-07                 -0.000678                 -0.000678
# 2000-02-08                 -0.000311                 -0.000311
# ...                              ...                       ...
# 2024-08-26                 -0.000690                 -0.000690
# 2024-08-27                 -0.000899                 -0.000899
# 2024-08-28                 -0.001012                 -0.001012
# 2024-08-29                 -0.001067                 -0.001067
# 2024-08-30                 -0.001030                 -0.001030
#
#             ('FIGARCH', 'gaussian', 0)  ('FIGARCH', 'gaussian', 1)        PV
# Date
# 2000-02-02                   -0.001782                   -0.001782 -0.001538
# 2000-02-03                   -0.001519                   -0.001519 -0.001355
# 2000-02-04                   -0.001076                   -0.001076 -0.000997
# 2000-02-07                   -0.000678                   -0.000678 -0.000650
# 2000-02-08                   -0.000311                   -0.000311 -0.000319
# ...                                ...                         ...       ...
# 2024-08-26                   -0.000690                   -0.000690  0.000248
# 2024-08-27                   -0.000899                   -0.000899  0.000029
# 2024-08-28                   -0.001012                   -0.001012 -0.000205
# 2024-08-29                   -0.001067                   -0.001067 -0.000456
# 2024-08-30                   -0.001030                   -0.001030 -0.000703
#
# [6184 rows x 12 columns]

# %% [markdown]
# # Split train, validation and test data

# %%
# train_end = datetime(2020, 6, 30)
# test_start = datetime(2020, 10, 1)
# val_size = 0.1

# %%
# target = ['PV', 'CCV', 'PV', 'GKV', 'RSV', 'YZV', 'GKYZV']
# test_data = data.loc[test_start:]

# train_val = data.loc[:train_end]
# train_data, val_data = train_test_split(train_val, test_size=val_size, shuffle=False)

# X_train = train_data.drop(columns=target)
# y_train = train_data[target]

# X_val = val_data.drop(columns=target)
# y_val = val_data[target]

# X_test = test_data.drop(columns=target)
# y_test = test_data[target]

# X_train = np.array(X_train)
# y_train = np.array(y_train)

# X_val = np.array(X_val)
# y_val = np.array(y_val)

# X_test = np.array(X_test)
# y_test = np.array(y_test)

# %%
def split_data(data, target, train_end =datetime(2022, 5, 30), test_start=datetime(2022, 5, 31), test_size=0.1):
  test_data = data.loc[test_start:]

  train_val = data.loc[:train_end]
  train_data, val_data = train_test_split(train_val, test_size=test_size, shuffle=False)

  X_train = train_data.drop(columns=[target])
  y_train = train_data[target]

  X_val = val_data.drop(columns=[target])
  y_val = val_data[target]

  X_test = test_data.drop(columns=[target])
  y_test = test_data[target]

  return np.array(X_train), np.array(y_train), np.array(X_val), np.array(y_val), np.array(X_test), np.array(y_test)

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(PV_data, 'PV')

# %% [markdown]
# # Model

# %%
class BDropout(torch.nn.Dropout):

    """Binary dropout with regularization and resampling.

    See: Gal Y., Ghahramani Z., "Dropout as a Bayesian Approximation:
    Representing Model Uncertainty in Deep Learning", 2016.
    """

    # def __init__(self, rate=0.1, reg=1.0, **kwargs):
    #     """Constructs a BDropout.

    #     Args:
    #         rate (float): Dropout probability.
    #         reg (float): Regularization scale.
    #     """
    #     super(BDropout, self).__init__(**kwargs)
    #     self.register_buffer("rate", torch.tensor(rate))
    #     self.p = 1 - self.rate
    #     self.register_buffer("reg", torch.tensor(reg))
    #     self.register_buffer("noise", torch.bernoulli(self.p))


    def __init__(self, rate=0.1, reg=1.0, **kwargs):
        """Constructs a BDropout.

        Args:
            rate (float): Dropout probability.
            reg (float): Regularization scale.
        """
        super(BDropout, self).__init__(p=rate, **kwargs)
        self.register_buffer("rate", torch.tensor(rate))
        self.p = 1 - self.rate
        self.register_buffer("reg", torch.tensor(reg))
        self.register_buffer("noise", torch.bernoulli(self.p))

    def regularization(self, weight, bias):
        """Computes the regularization cost.

        Args:
            weight (Tensor): Weight tensor.
            bias (Tensor): Bias tensor.

        Returns:
            Regularization cost (Tensor).
        """
        self.p = 1 - self.rate
        weight_reg = self.p * (weight**2).sum()
        bias_reg = (bias**2).sum() if bias is not None else 0
        return self.reg * (weight_reg + bias_reg)

    def resample(self):
        """Resamples the dropout noise."""
        self._update_noise(self.noise)

    def _update_noise(self, x):
        """Updates the dropout noise.

        Args:
            x (Tensor): Input.
        """
        self.p = 1 - self.rate
        self.noise.data = torch.bernoulli(self.p.expand(x.shape))

    def forward(self, x, resample=False, mask_dims=0, **kwargs):
        """Computes the binary dropout.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.
            mask_dims (int): Number of dimensions to sample noise for
                (0 for all).

        Returns:
            Output (Tensor).
        """
        sample_shape = x.shape[-mask_dims:]
        if sample_shape != self.noise.shape:
            sample = x.view(-1, *sample_shape)[0]
            self._update_noise(sample)
        elif resample:
            return x * torch.bernoulli(self.p.expand(x.shape))

        return x * self.noise

    def extra_repr(self):
        """Formats module representation.

        Returns:
            Module representation (str).
        """
        return "rate={}".format(self.rate)

# %%
class CDropout(BDropout):

    """Concrete dropout with regularization and resampling.

    See: Gal Y., Hron, J., Kendall, A. "Concrete Dropout", 2017.
    """

    # def __init__(self, temperature=0.1, rate=0.5, reg=1.0, **kwargs):
    #     """Constructs a CDropout.

    #     Args:
    #         temperature (float): Temperature.
    #         rate (float): Initial dropout rate.
    #         reg (float): Regularization scale.
    #     """
    #     super(CDropout, self).__init__(rate, reg, **kwargs)
    #     self.temperature = Parameter(
    #         torch.tensor(temperature), requires_grad=False)

    #     # We need to constrain p to [0, 1], so we train logit(p).
    #     self.logit_p = Parameter(-torch.log(self.p.reciprocal() - 1.0))

    def __init__(self, temperature=0.1, rate=0.5, reg=1.0, **kwargs):
        """Constructs a CDropout.

        Args:
            temperature (float): Temperature.
            rate (float): Initial dropout rate.
            reg (float): Regularization scale.
        """
        super(CDropout, self).__init__(rate, reg, **kwargs)
        self.temperature = torch.nn.Parameter(
            torch.tensor(temperature), requires_grad=False)

        # We need to constrain p to [0, 1], so we train logit(p).
        self.logit_p = torch.nn.Parameter(-torch.log(self.p.reciprocal() - 1.0))

    def regularization(self, weight, bias):
        """Computes the regularization cost.

        Args:
            weight (Tensor): Weight tensor.
            bias (Tensor): Bias tensor.

        Returns:
            Regularization cost (Tensor).
        """
        self.p.data = self.logit_p.sigmoid()
        reg = super(CDropout, self).regularization(weight, bias)
        reg -= -(1 - self.p) * (1 - self.p).log() - self.p * self.p.log()
        return reg

    def _update_noise(self, x):
        """Updates the dropout noise.

        Args:
            x (Tensor): Input.
        """
        self.noise.data = torch.rand_like(x)

    def forward(self, x, resample=False, mask_dims=0, **kwargs):
        """Computes the concrete dropout.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.
            mask_dims (int): Number of dimensions to sample noise for
                (0 for all).

        Returns:
            Output (Tensor).
        """
        sample_shape = x.shape[-mask_dims:]
        noise = self.noise
        if sample_shape != noise.shape:
            sample = x.view(-1, *sample_shape)[0]
            self._update_noise(sample)
            noise = self.noise
        elif resample:
            noise = torch.rand_like(x)

        self.p.data = self.logit_p.sigmoid()
        concrete_p = self.logit_p + noise.log() - (1 - noise).log()
        concrete_noise = (concrete_p / self.temperature).sigmoid()

        return x * concrete_noise

    def extra_repr(self):
        """Formats module representation.

        Returns:
            Module representation (str).
        """
        return "temperature={}".format(self.temperature)

# %%
class BSequential(torch.nn.Sequential):

    """Extension of Sequential module with regularization and resampling."""

    def resample(self):
        """Resample all child modules."""
        for child in self.children():
            if isinstance(child, BDropout):
                child.resample()

    def regularization(self):
        """Computes the total regularization cost of all child modules.

        Returns:
            Total regularization cost (Tensor).
        """
        reg = torch.tensor(0.0)
        children = list(self._modules.values())
        for i, child in enumerate(children):
            if isinstance(child, BSequential):
                reg += child.regularization()
            elif isinstance(child, BDropout):
                for next_child in children[i:]:
                    if hasattr(next_child, "weight") and hasattr(
                            next_child, "bias"):
                        reg += child.regularization(next_child.weight,
                                                    next_child.bias)
                        break
        return reg

    def forward(self, x, resample=False, **kwargs):
        """Computes the model.

        Args:
            x (Tensor): Input.
            resample (bool): Whether to force resample.

        Returns:
            Output (Tensor).
        """
        for module in self._modules.values():
            if isinstance(module, (BDropout, BSequential)):
                x = module(x, resample=resample, **kwargs)
            else:
                x = module(x)
        return x

# %%
def bayesian_model(in_features,
                   out_features,
                   hidden_features,
                   nonlin=nn.ReLU,
                   output_nonlin=None,
                   weight_initializer=partial(
                       nn.init.xavier_normal_,
                       gain=nn.init.calculate_gain("relu")),
                   bias_initializer=partial(
                       nn.init.uniform_, a=-1.0, b=1.0),
                   dropout_layers=CDropout,
                   input_dropout=None):
    """Constructs and initializes a Bayesian neural network with dropout."""
    dims = [in_features] + hidden_features
    if not isinstance(dropout_layers, Iterable):
        dropout_layers = [dropout_layers] * len(hidden_features)

    modules = OrderedDict()

    if inspect.isclass(input_dropout):
        input_dropout = input_dropout()
    if input_dropout is not None:
        modules["drop_in"] = input_dropout

    for i, (din, dout) in enumerate(zip(dims[:-1], dims[1:])):
        drop_i = dropout_layers[i]
        if inspect.isclass(drop_i):
            drop_i = drop_i()

        modules["fc_{}".format(i)] = nn.Linear(din, dout)
        if drop_i is not None:
            modules["drop_{}".format(i)] = drop_i
        modules["nonlin_{}".format(i)] = nonlin()

    modules["fc_out"] = nn.Linear(dims[-1], out_features)
    if output_nonlin is not None:
        modules["nonlin_out"] = output_nonlin()

    def init(module):
        if callable(weight_initializer) and hasattr(module, "weight"):
            weight_initializer(module.weight)
        if callable(bias_initializer) and hasattr(module, "bias"):
            if module.bias is not None:
                bias_initializer(module.bias)

    net = BSequential(modules)
    net.apply(init)

    return net

# %%
# Convert NumPy arrays to PyTorch tensors
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# Early stopping implementation
class EarlyStopping:
    def __init__(self, patience=10, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_val_loss = None
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_val_loss is None:
            self.best_val_loss = val_loss
        elif val_loss < self.best_val_loss - self.min_delta:
            self.best_val_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# Define parameter bounds
def parameter_bounds():
    # Number of layers: 1 to 5
    num_layers_bounds = (1, 5)

    # Number of neurons per layer: 10 to 200
    num_neurons_bounds = (10, 200)

    # Dropout rate: 0 to 0.5
    dropout_rate_bounds = (0.0, 0.5)

    # Learning rate: 0.0001 to 0.01
    learning_rate_bounds = (0.0001, 0.01)

    # Number of epochs: 50 to 500
    num_epochs_bounds = (150, 500)

    return num_layers_bounds, num_neurons_bounds, dropout_rate_bounds, learning_rate_bounds, num_epochs_bounds

# %%
def objective_function(params):
    # Unpack parameters from PSO
    num_layers, num_neurons, dropout_rate, learning_rate, num_epochs = params

    # Define the model with the given parameters
    model = bayesian_model(
        in_features=X_train.shape[1],
        out_features=1,
        hidden_features=[int(num_neurons)] * int(num_layers),
        nonlin=nn.ReLU,
        output_nonlin=None,
        dropout_layers=CDropout,
        input_dropout=CDropout(temperature=0.1, rate=dropout_rate, reg=1.0)
    )

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    # Initialize early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=0.01)

    # Track the best validation loss
    best_val_loss = float('inf')

    # Training loop with the number of epochs specified in the params
    for epoch in range(int(num_epochs)):
        model.train()
        outputs = model(X_train)
        loss = criterion(outputs, y_train)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Validation phase (after each epoch)
        model.eval()
        with torch.no_grad():
            val_outputs = model(X_val)
            val_loss = criterion(val_outputs, y_val)

        # Check and update the best validation loss
        if val_loss.item() < best_val_loss:
            best_val_loss = val_loss.item()

        # Early stopping condition
        early_stopping(val_loss.item())
        if early_stopping.early_stop:
            print(f"Early stopping triggered at epoch {epoch+1}")
            break

    # Return the best validation loss for PSO optimization
    return best_val_loss

# %%
# Define the bounds for each parameter
def get_bounds():
    num_layers_bounds, num_neurons_bounds, dropout_rate_bounds, learning_rate_bounds, num_epochs_bounds = parameter_bounds()
    return [
        [num_layers_bounds[0], num_neurons_bounds[0], dropout_rate_bounds[0], learning_rate_bounds[0], num_epochs_bounds[0]],
        [num_layers_bounds[1], num_neurons_bounds[1], dropout_rate_bounds[1], learning_rate_bounds[1], num_epochs_bounds[1]]
    ]

# %%
bounds = get_bounds()

# %%
lower_bounds = bounds[0]
upper_bounds = bounds[1]

swarmsize = 20
maxiter = 50

# %%
start_time = time.time()

best_params, best_val = pso(objective_function, lb=lower_bounds, ub=upper_bounds, swarmsize=swarmsize, maxiter=maxiter, debug=True)

end_time = time.time()
execution_time = end_time - start_time
# Out:
# No constraints given.
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([5055])) that is different to the input size (torch.Size([5055, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/loss.py:608: UserWarning: Using a target size (torch.Size([562])) that is different to the input size (torch.Size([562, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 93
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 72
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 29
# New best for swarm at iteration 1: [2.04737512e+00 2.00000000e+02 1.40389434e-01 2.49794773e-03
#  1.50000000e+02] 0.0029807137325406075
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 71
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 124
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 13
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 49
# Best after iteration 1: [2.04737512e+00 2.00000000e+02 1.40389434e-01 2.49794773e-03
#  1.50000000e+02] 0.0029807137325406075
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# New best for swarm at iteration 2: [4.69922972e+00 1.62499399e+02 4.69704464e-01 3.32344425e-03
#  2.57970930e+02] 0.002156320260837674
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 86
# Best after iteration 2: [4.69922972e+00 1.62499399e+02 4.69704464e-01 3.32344425e-03
#  2.57970930e+02] 0.002156320260837674
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 69
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 70
# Best after iteration 3: [4.69922972e+00 1.62499399e+02 4.69704464e-01 3.32344425e-03
#  2.57970930e+02] 0.002156320260837674
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 67
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 40
# Best after iteration 4: [4.69922972e+00 1.62499399e+02 4.69704464e-01 3.32344425e-03
#  2.57970930e+02] 0.002156320260837674
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 21
# New best for swarm at iteration 5: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 41
# Best after iteration 5: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 54
# Best after iteration 6: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 62
# Best after iteration 7: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 58
# Best after iteration 8: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 48
# Best after iteration 9: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 44
# Best after iteration 10: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 83
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 69
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Best after iteration 11: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 41
# Best after iteration 12: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 72
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 45
# Best after iteration 13: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 57
# Best after iteration 14: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 66
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 67
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Best after iteration 15: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 34
# Best after iteration 16: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 39
# Best after iteration 17: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 65
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 38
# Best after iteration 18: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Best after iteration 19: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 45
# Best after iteration 20: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 51
# Best after iteration 21: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 31
# Best after iteration 22: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 47
# Best after iteration 23: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 41
# Best after iteration 24: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 39
# Best after iteration 25: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 53
# Best after iteration 26: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 48
# Best after iteration 27: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 42
# Best after iteration 28: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 46
# Best after iteration 29: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 36
# Best after iteration 30: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 46
# Best after iteration 31: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 69
# Early stopping triggered at epoch 61
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Best after iteration 32: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 33
# Best after iteration 33: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 30
# Best after iteration 34: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 26
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 40
# Best after iteration 35: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 59
# Best after iteration 36: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 28
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 45
# Best after iteration 37: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 65
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 56
# Best after iteration 38: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 67
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 69
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 48
# Best after iteration 39: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 68
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 62
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 61
# Best after iteration 40: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 24
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 58
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 45
# Best after iteration 41: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 30
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 34
# Best after iteration 42: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 32
# Early stopping triggered at epoch 34
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 33
# Best after iteration 43: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 34
# Best after iteration 44: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 31
# Early stopping triggered at epoch 69
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 25
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 48
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 35
# Best after iteration 45: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 64
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 39
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 55
# Early stopping triggered at epoch 59
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 48
# Best after iteration 46: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 56
# Early stopping triggered at epoch 67
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 41
# Early stopping triggered at epoch 52
# Early stopping triggered at epoch 57
# Early stopping triggered at epoch 37
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 68
# Early stopping triggered at epoch 43
# Best after iteration 47: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 63
# Early stopping triggered at epoch 21
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 22
# Early stopping triggered at epoch 23
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 47
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 20
# Best after iteration 48: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 49
# Early stopping triggered at epoch 66
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 20
# Early stopping triggered at epoch 53
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 35
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 42
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 63
# Best after iteration 49: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Early stopping triggered at epoch 29
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 33
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 46
# Early stopping triggered at epoch 43
# Early stopping triggered at epoch 45
# Early stopping triggered at epoch 54
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 40
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 60
# Early stopping triggered at epoch 36
# Early stopping triggered at epoch 51
# Early stopping triggered at epoch 50
# Early stopping triggered at epoch 38
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 27
# Early stopping triggered at epoch 44
# Early stopping triggered at epoch 27
# Best after iteration 50: [3.85198321e+00 1.37374725e+02 3.94266624e-01 3.85322419e-03
#  1.71139114e+02] 0.00059751101071015
# Stopping search: maximum iterations reached --> 50

# %%
execution_time
# Out:
# 14924.13723897934

# %%
best_params
# Out:
# array([3.85198321e+00, 1.37374725e+02, 3.94266624e-01, 3.85322419e-03,
#        1.71139114e+02])

# %%
# Function to train and evaluate the model with given hyperparameters
def train_and_evaluate_model(params):
    n_layers, n_neurons, drop_rate, learning_rate, epochs = params

    # Define the model
    hidden_features = [int(n_neurons)] * int(n_layers)
    model = bayesian_model(
        in_features=X_train.shape[1],
        out_features=1,
        hidden_features=hidden_features,
        dropout_layers=CDropout(rate=drop_rate),  # Dropout layer without partial
    )

    # Define optimizer and loss function
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.MSELoss()

    # Early stopping
    early_stopping = EarlyStopping(patience=10, min_delta=1e-4)

    # Training loop
    for epoch in range(int(epochs)):
        model.train()
        optimizer.zero_grad()

        output = model(X_train)
        loss = criterion(output, y_train)

        loss.backward()
        optimizer.step()

        model.eval()
        val_output = model(X_val)
        val_loss = criterion(val_output, y_val)

        print(f'Epoch {epoch+1}/{int(epochs)}, Loss: {loss.item()}, Val Loss: {val_loss.item()}')

        early_stopping(val_loss.item())
        if early_stopping.early_stop:
            print("Early stopping triggered")
            break

    # Test the model
    model.eval()
    test_output = model(X_test)
    mse = criterion(test_output, y_test)
    rmse = mse ** 0.5
    mae = nn.L1Loss()(y_test, test_output).item()
    mape = torch.mean(torch.abs((y_test - test_output) / y_test)) * 100

    print(f'Test Loss: {mse.item()}')
    print(f'RMSE: {rmse}')
    print(f'MAE: {mae}')
    print(f'MAPE: {mape.item()}%')

    return mse, rmse, mae, mape, test_output

# %%
# best_params = [3.62253629e+00, 1.12321717e+02, 2.77934900e-01, 5.49072091e-03, 2.22486413e+02]

# %%
mse, rmse, mae, mape, test_output = train_and_evaluate_model(best_params)
# Out:
# Epoch 1/171, Loss: 0.5780429840087891, Val Loss: 0.49047085642814636
# Epoch 2/171, Loss: 0.5275742411613464, Val Loss: 0.4242425262928009
# Epoch 3/171, Loss: 0.44896215200424194, Val Loss: 0.22186383605003357
# Epoch 4/171, Loss: 0.25159022212028503, Val Loss: 0.19712090492248535
# Epoch 5/171, Loss: 0.2038300484418869, Val Loss: 0.2418231964111328
# Epoch 6/171, Loss: 0.23081357777118683, Val Loss: 0.21445155143737793
# Epoch 7/171, Loss: 0.22284379601478577, Val Loss: 0.15994203090667725
# Epoch 8/171, Loss: 0.16242793202400208, Val Loss: 0.11886969953775406
# Epoch 9/171, Loss: 0.11856881529092789, Val Loss: 0.0986570194363594
# Epoch 10/171, Loss: 0.09633254259824753, Val Loss: 0.09861911833286285
# Epoch 11/171, Loss: 0.10279481112957001, Val Loss: 0.11837908625602722
# Epoch 12/171, Loss: 0.10618966072797775, Val Loss: 0.10307742655277252
# Epoch 13/171, Loss: 0.10140717774629593, Val Loss: 0.09546750038862228
# Epoch 14/171, Loss: 0.08718638122081757, Val Loss: 0.06773412972688675
# Epoch 15/171, Loss: 0.07248660922050476, Val Loss: 0.05977789685130119
# Epoch 16/171, Loss: 0.05800934135913849, Val Loss: 0.046685874462127686
# Epoch 17/171, Loss: 0.053337790071964264, Val Loss: 0.05832323804497719
# Epoch 18/171, Loss: 0.05438125878572464, Val Loss: 0.05640806257724762
# Epoch 19/171, Loss: 0.05703388527035713, Val Loss: 0.05425340682268143
# Epoch 20/171, Loss: 0.055586688220500946, Val Loss: 0.047037847340106964
# Epoch 21/171, Loss: 0.048719629645347595, Val Loss: 0.040272489190101624
# Epoch 22/171, Loss: 0.040288571268320084, Val Loss: 0.03481767326593399
# Epoch 23/171, Loss: 0.033354297280311584, Val Loss: 0.03075558692216873
# Epoch 24/171, Loss: 0.032137561589479446, Val Loss: 0.03384608030319214
# Epoch 25/171, Loss: 0.03189282864332199, Val Loss: 0.035254497081041336
# Epoch 26/171, Loss: 0.03380816429853439, Val Loss: 0.03296676650643349
# Epoch 27/171, Loss: 0.03256040811538696, Val Loss: 0.029143257066607475
# Epoch 28/171, Loss: 0.02846485935151577, Val Loss: 0.023927319794893265
# Epoch 29/171, Loss: 0.02625216729938984, Val Loss: 0.021832309663295746
# Epoch 30/171, Loss: 0.022299811244010925, Val Loss: 0.02350148931145668
# Epoch 31/171, Loss: 0.02099079266190529, Val Loss: 0.018931500613689423
# Epoch 32/171, Loss: 0.021261779591441154, Val Loss: 0.019919514656066895
# Epoch 33/171, Loss: 0.021032439544796944, Val Loss: 0.019629433751106262
# Epoch 34/171, Loss: 0.02064106985926628, Val Loss: 0.02034894749522209
# Epoch 35/171, Loss: 0.0197434239089489, Val Loss: 0.017232593148946762
# Epoch 36/171, Loss: 0.018402324989438057, Val Loss: 0.01546431053429842
# Epoch 37/171, Loss: 0.016141891479492188, Val Loss: 0.01385341677814722
# Epoch 38/171, Loss: 0.015089945867657661, Val Loss: 0.015273897908627987
# Epoch 39/171, Loss: 0.01480172760784626, Val Loss: 0.014976372011005878
# Epoch 40/171, Loss: 0.014617223292589188, Val Loss: 0.013447048142552376
# Epoch 41/171, Loss: 0.01415144745260477, Val Loss: 0.013368286192417145
# Epoch 42/171, Loss: 0.014644215814769268, Val Loss: 0.012735453434288502
# Epoch 43/171, Loss: 0.013321532867848873, Val Loss: 0.012688263319432735
# Epoch 44/171, Loss: 0.012341481633484364, Val Loss: 0.010927659459412098
# Epoch 45/171, Loss: 0.011478491127490997, Val Loss: 0.010741585865616798
# Epoch 46/171, Loss: 0.010983730666339397, Val Loss: 0.011310940608382225
# Epoch 47/171, Loss: 0.010153381153941154, Val Loss: 0.010940153151750565
# Epoch 48/171, Loss: 0.010535250417888165, Val Loss: 0.009771669283509254
# Epoch 49/171, Loss: 0.010237090289592743, Val Loss: 0.010598142631351948
# Epoch 50/171, Loss: 0.009606588631868362, Val Loss: 0.009499609470367432
# Epoch 51/171, Loss: 0.009490853175520897, Val Loss: 0.008618000894784927
# Epoch 52/171, Loss: 0.009094798937439919, Val Loss: 0.00860443152487278
# Epoch 53/171, Loss: 0.008383166044950485, Val Loss: 0.008576012216508389
# Epoch 54/171, Loss: 0.008258813992142677, Val Loss: 0.0077293384820222855
# Epoch 55/171, Loss: 0.007645406760275364, Val Loss: 0.008143500424921513
# Epoch 56/171, Loss: 0.0076676649041473866, Val Loss: 0.007227791007608175
# Epoch 57/171, Loss: 0.007681527175009251, Val Loss: 0.007866976782679558
# Epoch 58/171, Loss: 0.007145054638385773, Val Loss: 0.007504388224333525
# Epoch 59/171, Loss: 0.006883789785206318, Val Loss: 0.007134904153645039
# Epoch 60/171, Loss: 0.006616069469600916, Val Loss: 0.006188685540109873
# Epoch 61/171, Loss: 0.006377632729709148, Val Loss: 0.006297519896179438
# Epoch 62/171, Loss: 0.006255375221371651, Val Loss: 0.005967641714960337
# Epoch 63/171, Loss: 0.006288135889917612, Val Loss: 0.0066187335178256035
# Epoch 64/171, Loss: 0.005925511941313744, Val Loss: 0.006567807402461767
# Epoch 65/171, Loss: 0.005589136853814125, Val Loss: 0.004947501700371504
# Epoch 66/171, Loss: 0.005523331928998232, Val Loss: 0.005656718742102385
# Epoch 67/171, Loss: 0.005366008263081312, Val Loss: 0.005241890903562307
# Epoch 68/171, Loss: 0.005031523760408163, Val Loss: 0.0047571538016200066
# Epoch 69/171, Loss: 0.004849525634199381, Val Loss: 0.004416100215166807
# Epoch 70/171, Loss: 0.004651519935578108, Val Loss: 0.004916575271636248
# Epoch 71/171, Loss: 0.004554297309368849, Val Loss: 0.004327962175011635
# Epoch 72/171, Loss: 0.004294246435165405, Val Loss: 0.004746838007122278
# Epoch 73/171, Loss: 0.004326097201555967, Val Loss: 0.0038863644003868103
# Epoch 74/171, Loss: 0.0041031730361282825, Val Loss: 0.003937084693461657
# Epoch 75/171, Loss: 0.0039017105009406805, Val Loss: 0.003803016385063529
# Epoch 76/171, Loss: 0.0037671055179089308, Val Loss: 0.003773437114432454
# Epoch 77/171, Loss: 0.0036463765427470207, Val Loss: 0.003735831007361412
# Epoch 78/171, Loss: 0.0034927886445075274, Val Loss: 0.0036926972679793835
# Epoch 79/171, Loss: 0.0034516630694270134, Val Loss: 0.0032808929681777954
# Epoch 80/171, Loss: 0.0033080819994211197, Val Loss: 0.0030224339570850134
# Epoch 81/171, Loss: 0.0032341917976737022, Val Loss: 0.003107678610831499
# Epoch 82/171, Loss: 0.0030629485845565796, Val Loss: 0.002760819159448147
# Epoch 83/171, Loss: 0.0028355447575449944, Val Loss: 0.002602995140478015
# Epoch 84/171, Loss: 0.0026763821952044964, Val Loss: 0.0025019636377692223
# Epoch 85/171, Loss: 0.002699116710573435, Val Loss: 0.002634498057886958
# Epoch 86/171, Loss: 0.0024959768634289503, Val Loss: 0.0022469002287834883
# Epoch 87/171, Loss: 0.002506773453205824, Val Loss: 0.0023183797020465136
# Epoch 88/171, Loss: 0.002270026598125696, Val Loss: 0.002030768897384405
# Epoch 89/171, Loss: 0.0022956484463065863, Val Loss: 0.0022793046664446592
# Epoch 90/171, Loss: 0.0021009601186960936, Val Loss: 0.002214440144598484
# Epoch 91/171, Loss: 0.002092398703098297, Val Loss: 0.001840059063397348
# Epoch 92/171, Loss: 0.0019765973556786776, Val Loss: 0.002169980201870203
# Epoch 93/171, Loss: 0.0019283720757812262, Val Loss: 0.0017286790534853935
# Epoch 94/171, Loss: 0.001815456198528409, Val Loss: 0.0017915056087076664
# Epoch 95/171, Loss: 0.0018490833463147283, Val Loss: 0.0017657855059951544
# Epoch 96/171, Loss: 0.0017136011738330126, Val Loss: 0.0018034626264125109
# Epoch 97/171, Loss: 0.0017363071674481034, Val Loss: 0.0014025535201653838
# Epoch 98/171, Loss: 0.0015449777711182833, Val Loss: 0.0015923780156299472
# Epoch 99/171, Loss: 0.00150590599514544, Val Loss: 0.0015244019450619817
# Epoch 100/171, Loss: 0.0014546889578923583, Val Loss: 0.0014006366254761815
# Epoch 101/171, Loss: 0.001428657560609281, Val Loss: 0.001367233577184379
# Epoch 102/171, Loss: 0.0014806266408413649, Val Loss: 0.0016927800606936216
# Epoch 103/171, Loss: 0.0014223059406504035, Val Loss: 0.0013457450550049543
# Epoch 104/171, Loss: 0.0013655363582074642, Val Loss: 0.0013819867745041847
# Epoch 105/171, Loss: 0.0013480596244335175, Val Loss: 0.001213567447848618
# Epoch 106/171, Loss: 0.001299800700508058, Val Loss: 0.0012133743148297071
# Epoch 107/171, Loss: 0.0012814640067517757, Val Loss: 0.0012605286901816726
# Epoch 108/171, Loss: 0.001229971181601286, Val Loss: 0.0012658891500905156
# Epoch 109/171, Loss: 0.0012322831898927689, Val Loss: 0.0013276615645736456
# Epoch 110/171, Loss: 0.0011573806405067444, Val Loss: 0.0012251303996890783
# Epoch 111/171, Loss: 0.001205282169394195, Val Loss: 0.0011438443325459957
# Epoch 112/171, Loss: 0.0011139698326587677, Val Loss: 0.0012069176882505417
# Epoch 113/171, Loss: 0.0011400887742638588, Val Loss: 0.0011455402709543705
# Epoch 114/171, Loss: 0.001139902276918292, Val Loss: 0.0011609477223828435
# Epoch 115/171, Loss: 0.0010738304117694497, Val Loss: 0.0011751718120649457
# Early stopping triggered
# Test Loss: 0.0011393912136554718
# RMSE: 0.0337548702955246
# MAE: 0.025422921404242516
# MAPE: 1678986.875%

# %%
print(f'Final Test Metrics -> MSE: {mse}, RMSE: {rmse}, MAE: {mae}, MAPE: {mape.item()}%')
# Out:
# Final Test Metrics -> MSE: 0.0011393912136554718, RMSE: 0.0337548702955246, MAE: 0.025422921404242516, MAPE: 1678986.875%

# %%
# path_1 = '/content/drive/MyDrive/Volatility/New_data_2000_2024/New_predictions/PV/'

# df_pred = pd.DataFrame(test_output.detach().numpy().flatten(), columns=['bnn_pred'])
# filename = 'BNN_pred.csv'
# df_pred.to_csv(path_1 + filename)
